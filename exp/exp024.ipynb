# %% [markdown]
# # exp024
# 重みでリランク

# %%
import os
import sys
import traceback
import gc
import random
import pickle
import pathlib
import subprocess
from dataclasses import dataclass
from dotenv import load_dotenv
load_dotenv
sys.path.append(os.getenv('UTILS_PATH'))
from tqdm import tqdm
import multiprocessing
import inspect

import pandas as pd
import numpy as np
import itertools
import cudf
import lightgbm as lgb
import matplotlib.pyplot as plt
import seaborn as sns
import line_notify
import my_logger
from noglobal import noglobal
import optuna

# %% [markdown]
# # 設定

# %%
@dataclass
class Cfg:
    loglevel = "INFO"
    exp_name = "exp024"
    seed = 42
    k = 20
    type2id = {"clicks":0, "carts":1, "orders":2}
    id2type = {0:"clicks", 1:"carts", 2:"orders"}
    train_weeks = ["week3"]
    valid_week = "week4"
    valid_session_n = 100_000
    input_dir = os.getenv('INPUT_DIR')
    output_dir = os.getenv('OUTPUT_DIR')
    prep_dir = os.getenv("PREP_DIR")

cfg = Cfg()
os.makedirs(os.path.join(cfg.output_dir, cfg.exp_name), exist_ok=True)
os.makedirs(os.path.join(cfg.output_dir, cfg.exp_name, "cache"), exist_ok=True)
random.seed(cfg.seed)

logger = my_logger.init_logger(cfg.exp_name)

# %%
@noglobal(excepts=["cfg", "logger"])
def evaluate(clicks_labels, carts_labels, orders_labels, 
             clicks_preds, carts_preds, orders_preds, k=20):

    num_clicks = 0
    num_carts = 0
    num_orders = 0
    hit_clicks = 0
    hit_carts = 0
    hit_orders = 0

    for i in range(len(clicks_labels)):
        clicks_label = clicks_labels[i]
        carts_label = carts_labels[i]
        orders_label = orders_labels[i]
        clicks_pred = clicks_preds[i]
        carts_pred = carts_preds[i]
        orders_pred = orders_preds[i]

        if type(clicks_pred) == list:
            clicks_pred = clicks_pred[:k]
        else:
            clicks_pred = []
        if type(carts_pred) == list:
            carts_pred = carts_pred[:k]
        else:
            carts_pred = []    
        if type(orders_pred) == list:
            orders_pred = orders_pred[:k]
        else:
            orders_pred = []

        if not np.isnan(clicks_label):
            num_clicks += 1
            hit_clicks += int(clicks_label in clicks_pred)

        if type(carts_label) == list:
            num_carts += min(len(carts_label), k)
            hit_carts += len(set(carts_pred) & set(carts_label))
            
        if type(orders_label) == list:
            num_orders += min(len(orders_label), k)
            hit_orders += len(set(orders_pred) & set(orders_label))


    recall_clicks = hit_clicks / num_clicks
    recall_carts = hit_carts / num_carts
    recall_orders = hit_orders / num_orders
    w_recall_clicks = recall_clicks * 0.10
    w_recall_carts = recall_carts * 0.30
    w_recall_orders = recall_orders * 0.60
    score = w_recall_clicks + w_recall_carts + w_recall_orders

    results = {}
    results["num_clicks"] = num_clicks
    results["hit_clicks"] = hit_clicks
    results["num_carts"] = num_carts
    results["hit_carts"] = hit_carts
    results["num_orders"] = num_orders
    results["hit_orders"] = hit_orders
    results["recall_clicks"] = format(recall_clicks, ".3f")
    results["recall_carts"] = format(recall_carts, ".3f")
    results["recall_orders"] = format(recall_orders, ".3f")
    results["w_recall_clicks"] = format(w_recall_clicks, ".3f")
    results["w_recall_carts"] = format(w_recall_carts, ".3f")
    results["w_recall_orders"] = format(w_recall_orders, ".3f")
    results["score"] = format(score, ".3f")

    return results

# %%
class Candidate:
    @noglobal(excepts=["cfg", "logger"])
    def __init__(self, pdf, labels=None):
        self.df = cudf.from_pandas(pdf)
        self.target_sessions = pdf["session"].unique().tolist()
        self.results = pd.DataFrame(columns=["name", "num_clicks", "hit_clicks", "num_carts", "hit_carts", "num_orders", "hit_orders", 
                                             "recall_clicks", "recall_carts", "recall_orders", "w_recall_clicks", "w_recall_carts", "w_recall_orders", "score"])
        self.output = pd.DataFrame(columns=["session", "aid", "strategy", "rank"], dtype=int)
        self.labels = labels
    
    @noglobal(excepts=["cfg", "logger"])
    def _entry(self, new_candidate_df, name, k):
        logger.info(f"[add_candidate] {name} : start")
        new_candidate_df["strategy"] = name
        new_candidate_df[f"rank"] = new_candidate_df.groupby("session")["session"].cumcount() + 1
        new_candidate_df = new_candidate_df.to_pandas()
        self.output = pd.concat([self.output, new_candidate_df[["session", "aid", "strategy", "rank"]]])

        if self.labels is not None:
            self._eval(new_candidate_df[["session", "aid"]], name, k)
    
    @noglobal(excepts=["cfg", "logger"])
    def _eval(self, new_candidate_df, name, k):
        new_candidate_df = new_candidate_df.groupby("session")["aid"].apply(list).reset_index()
        eval_df = pd.DataFrame(self.target_sessions, columns=["session"])
        eval_df = eval_df.merge(new_candidate_df, on=["session"], how="left")
        assert eval_df["session"].tolist() == self.labels["session"].tolist()
        eval_result = evaluate(self.labels["clicks_labels"].tolist(), self.labels["carts_labels"].tolist(), self.labels["orders_labels"].tolist(),
                               eval_df["aid"].tolist(), eval_df["aid"].tolist(), eval_df["aid"].tolist(), k)
        
        logger.info(str(eval_result))
        self.results = pd.concat([self.results, pd.DataFrame([[name] + list(eval_result.values())], columns=["name"] + list(eval_result.keys()))])

    @noglobal(excepts=["cfg", "logger"])
    def add(self, strategy, name, usetypes=['clicks', 'carts', 'orders'], trans_map=None, k=20):
        logger.info(f"[make_candidate] {name} : start")
        candidate_df = self.df[self.df["type"].isin(usetypes)].copy()
        
        if strategy == "session_frequent":
            candidate_df = self._session_frequent(candidate_df, k)
        elif strategy == "session_latest":
            candidate_df = self._session_latest(candidate_df, k)
        elif strategy == "total_frequent":
            candidate_df = self._total_frequent(candidate_df, k)
        
        if trans_map is not None:
            candidate_df["aid"] = candidate_df["aid"].map(trans_map)
            candidate_df = candidate_df.dropna(subset=["aid"])
            
        self._entry(candidate_df, name, k)

    @noglobal(excepts=["cfg", "logger"])
    def _session_frequent(self, candidate_df, k):
        candidate_df = candidate_df.groupby(["session", "aid"])["ts"].count().reset_index()
        candidate_df.columns = ["session", "aid", "aid_count"]
        candidate_df = candidate_df.sort_values(["session", "aid_count", "aid"], ascending=(True, False, True))
        candidate_df = candidate_df[candidate_df.groupby("session")["aid_count"].cumcount() < k].copy()
        candidate_df = candidate_df[["session", "aid"]].copy()
        return candidate_df

    @noglobal(excepts=["cfg", "logger"])
    def _session_latest(self, candidate_df, k):
        candidate_df = candidate_df.sort_values(["session", "ts"], ascending=(True, False)).drop_duplicates(subset=["session", "aid"])
        candidate_df = candidate_df.sort_values(["session", "ts"], ascending=(True, False))[candidate_df.groupby("session")["ts"].cumcount() < k].copy()
        candidate_df = candidate_df[["session", "aid"]].copy()
        return candidate_df

    @noglobal(excepts=["cfg", "logger"])
    def _total_frequent(self, candidate_df, k):
        candidate_df = candidate_df.groupby("aid")["ts"].count().reset_index()
        candidate_df.columns = ["aid", "aid_count"]
        topk_freq_aids = candidate_df.sort_values("aid_count", ascending=False)["aid"].to_arrow().to_pylist()[:k]
        sessions = []
        aids = []
        for session, aid in itertools.product(self.target_sessions, topk_freq_aids):
            sessions.append(session)
            aids.append(aid)
        candidate_df = cudf.DataFrame({"session": sessions, "aid": aids})
        return candidate_df

# %%
@noglobal(excepts=["cfg", "logger"])
def make_cand_df(sessions, labels=None, trans_maps=None):

    if labels is not None:
         cand = Candidate(sessions, labels)
    else:
        cand = Candidate(sessions)

    cand.add(strategy="session_frequent", name="session_frequent")
    cand.add(strategy="session_latest", name="session_latest")
    cand.add(strategy="total_frequent", name="total_frequent")
    cand.add(strategy="session_frequent", trans_map=trans_maps["pair0"], name="session_frequent_pair")
    
    for i in range(5):
        cand.add(strategy="session_latest", trans_map=trans_maps[f"pair{str(i)}"], name=f"session_latest_pair{str(i)}")
      
    cand.add(strategy="session_frequent", trans_map=trans_maps["clicks_pair"], name="session_frequent_clicks_pair")
    cand.add(strategy="session_latest", trans_map=trans_maps["clicks_pair"], name="session_latest_clicks_pair")
    # cand.add(strategy="session_frequent", trans_map=trans_maps["carts_pair"], name="session_frequent_carts_pair")
    cand.add(strategy="session_latest", trans_map=trans_maps["carts_pair"], name="session_latest_carts_pair")
    cand.add(strategy="session_latest", trans_map=trans_maps["time_wt_pair"], name="session_latest_time_wt_pair")
    cand.add(strategy="session_latest", trans_map=trans_maps["clicks_carts_pair"], name="session_latest_clicks_carts_pair")
    cand.add(strategy="session_latest", trans_map=trans_maps["clicks_orders_pair"], name="session_latest_clicks_orders_pair")
    # cand.add(strategy="session_frequent", trans_map=trans_maps["orders_pair"], name="session_frequent_orders_pair")
    # cand.add(strategy="session_latest", trans_map=trans_maps["orders_pair"], name="session_latest_orders_pair")
    if labels is not None:
        return cand.output, cand.results
    else:
        return cand.output

# %%
@noglobal(excepts=["cfg", "logger"])
def get_trans_maps():
    """
    aidを別のaidに置き換えるmapping辞書を取得する
    """
    trans_maps = {}
    pair_df_org = pd.read_pickle(cfg.prep_dir + "co_visitation_matrix.pkl")
    pair_df_org = pair_df_org[pair_df_org["cnt"] > 3].copy()
    pair_df_org = pair_df_org.sort_values(["aid_x", "cnt"], ascending=(True, False))

    for i in range(5):
        pair_df = pair_df_org.groupby("aid_x").nth(i).reset_index()[["aid_x", "aid_y"]]
        pair_dict = {k: v for k, v in zip(pair_df["aid_x"].tolist(), pair_df["aid_y"].tolist())}
        trans_maps[f"pair{str(i)}"] = pair_dict

    pair_df = pd.read_pickle(cfg.prep_dir + "co_visitation_matrix_clicks.pkl")
    pair_df = pair_df[pair_df["cnt"] > 3].copy()
    pair_df = pair_df.sort_values(["aid_x", "cnt"], ascending=(True, False))
    pair_df = pair_df.groupby("aid_x").head(1)[["aid_x", "aid_y"]]
    pair_dict = {k: v for k, v in zip(pair_df["aid_x"].tolist(), pair_df["aid_y"].tolist())}
    trans_maps["clicks_pair"] = pair_dict

    pair_df = pd.read_pickle(cfg.prep_dir + "co_visitation_matrix_carts.pkl")
    pair_df = pair_df[pair_df["cnt"] > 3].copy()
    pair_df = pair_df.sort_values(["aid_x", "cnt"], ascending=(True, False))
    pair_df = pair_df.groupby("aid_x").head(1)[["aid_x", "aid_y"]]
    pair_dict = {k: v for k, v in zip(pair_df["aid_x"].tolist(), pair_df["aid_y"].tolist())}
    trans_maps["carts_pair"] = pair_dict

    pair_df = pd.read_pickle(cfg.prep_dir + "co_visitation_matrix_orders.pkl")
    pair_df = pair_df[pair_df["cnt"] > 3].copy()
    pair_df = pair_df.sort_values(["aid_x", "cnt"], ascending=(True, False))
    pair_df = pair_df.groupby("aid_x").head(1)[["aid_x", "aid_y"]]
    pair_dict = {k: v for k, v in zip(pair_df["aid_x"].tolist(), pair_df["aid_y"].tolist())}
    trans_maps["orders_pair"] = pair_dict

    pair_df = pd.read_pickle(cfg.prep_dir + "co_visitation_matrix_time_weighted.pkl")
    pair_df = pair_df.sort_values(["aid_x", "wt"], ascending=(True, False))
    pair_df = pair_df.groupby("aid_x").head(1)[["aid_x", "aid_y"]]
    pair_dict = {k: v for k, v in zip(pair_df["aid_x"].tolist(), pair_df["aid_y"].tolist())}
    trans_maps["time_wt_pair"] = pair_dict

    pair_df = pd.read_pickle(cfg.prep_dir + "co_visitation_matrix_clicks_carts.pkl")
    pair_df = pair_df.sort_values(["aid_x", "cnt"], ascending=(True, False))
    pair_df = pair_df.groupby("aid_x").head(1)[["aid_x", "aid_y"]]
    pair_dict = {k: v for k, v in zip(pair_df["aid_x"].tolist(), pair_df["aid_y"].tolist())}
    trans_maps["clicks_carts_pair"] = pair_dict

    pair_df = pd.read_pickle(cfg.prep_dir + "co_visitation_matrix_clicks_orders.pkl")
    pair_df = pair_df.sort_values(["aid_x", "cnt"], ascending=(True, False))
    pair_df = pair_df.groupby("aid_x").head(1)[["aid_x", "aid_y"]]
    pair_dict = {k: v for k, v in zip(pair_df["aid_x"].tolist(), pair_df["aid_y"].tolist())}
    trans_maps["clicks_orders_pair"] = pair_dict

    return trans_maps

# %%
class Cache:
    @noglobal(excepts=["cfg", "logger"])
    def __init__(self):
        self.cache_dir = (os.path.join(cfg.output_dir, cfg.exp_name, "cache"))
        self.cache_dir_path = pathlib.Path(self.cache_dir)
        self.caches = list(self.cache_dir_path.glob("*.pkl"))

    @noglobal(excepts=["cfg", "logger"])
    def get_abspath(self, filename):
        return (os.path.join(self.cache_dir, f"{cfg.exp_name}_{filename}"))
    
    @noglobal(excepts=["cfg", "logger"])
    def exists(self, path):
        return len([str(c) for c in self.caches if path == str(c)]) > 0

# %%
@noglobal(excepts=["cfg", "logger"])
def make_valid_data(trans_maps):
    valid_week = cfg.valid_week
    dfs = []
    
    logger.info(f"[make_valid] valid_week : {valid_week}")
    # データ読み込み
    logger.info("[make_valid] read_data : start")
    week_sessions = pd.read_pickle(os.getenv("PREP_DIR") + f"train_sessions_{valid_week}.pkl")
    week_labels = pd.read_pickle(os.getenv("PREP_DIR") + f"labels_{valid_week}.pkl")
    valid_session_ids = week_sessions["session"].unique().tolist()
    logger.info("[make_valid] read_data : end")

    # validに使うsessionを絞る (trainに存在するsessionを除外した上で設定した数に絞る)
    logger.info("[make_valid] valid_session_extract : start")
    valid_session_n = min(cfg.valid_session_n, len(valid_session_ids))
    valid_session_ids = random.sample(valid_session_ids, valid_session_n)
    week_sessions = week_sessions[week_sessions["session"].isin(valid_session_ids)].copy()
    week_labels = week_labels[week_labels["session"].isin(valid_session_ids)].copy()
    logger.info("[make_valid] valid_session_extract : end")

    # 候補選出
    logger.info("[make_valid] make_cand_df : start")
    valid, results = make_cand_df(week_sessions, labels=week_labels, trans_maps=trans_maps)

    return valid, week_labels, results

# %%
@noglobal(excepts=["cfg", "logger"])
def make_test_data(trans_maps):
    # testデータ作成
    test_sessions = pd.read_pickle(cfg.prep_dir + f"test_sessions.pkl")

    dfs =[]
    # 候補選出
    logger.info("[make_test] make_cand_df")
    test = make_cand_df(test_sessions, trans_maps=trans_maps)
    return test

# %%
logger.info(f"START")
line_notify.send(f"{cfg.exp_name} | START")

cache = Cache()

logger.info(f"-------- get_trans_maps --------")
cache_path = cache.get_abspath("trans_maps.pkl")
if cache.exists(cache_path):
    logger.info("cache exists. load cache and skip process.")
    with open(cache_path, "rb") as f:
        trans_maps = pickle.load(f)
else:
    trans_maps = get_trans_maps()
    with open(cache_path, "wb") as f:
        pickle.dump(trans_maps, f)

valid, valid_labels, results = make_valid_data(trans_maps)
# Out:
# 0:00:00.484303 	 START
# 0:00:04.961373 	 -------- get_trans_maps --------
# 0:00:04.962371 	 cache exists. load cache and skip process.
# 0:00:06.702783 	 [make_valid] valid_week : week4
# 0:00:06.703665 	 [make_valid] read_data : start
# 0:00:13.218640 	 [make_valid] read_data : end
# 0:00:13.220078 	 [make_valid] valid_session_extract : start
# 0:00:14.180230 	 [make_valid] valid_session_extract : end
# 0:00:14.181712 	 [make_valid] make_cand_df : start
# 0:00:14.236642 	 [make_candidate] session_frequent : start
# 0:00:14.414745 	 [add_candidate] session_frequent : start
# 0:00:16.030109 	 {'num_clicks': 97136, 'hit_clicks': 29631, 'num_carts': 43211, 'hit_carts': 10937, 'num_orders': 20082, 'hit_orders': 10387, 'recall_clicks': '0.305', 'recall_carts': '0.253', 'recall_orders': '0.517', 'w_recall_clicks': '0.031', 'w_recall_carts': '0.076', 'w_recall_orders': '0.310', 'score': '0.417'}
# 0:00:16.046344 	 [make_candidate] session_latest : start
# 0:00:16.231382 	 [add_candidate] session_latest : start
# 0:00:17.953618 	 {'num_clicks': 97136, 'hit_clicks': 29762, 'num_carts': 43211, 'hit_carts': 10988, 'num_orders': 20082, 'hit_orders': 10168, 'recall_clicks': '0.306', 'recall_carts': '0.254', 'recall_orders': '0.506', 'w_recall_clicks': '0.031', 'w_recall_carts': '0.076', 'w_recall_orders': '0.304', 'score': '0.411'}
# 0:00:17.964702 	 [make_candidate] total_frequent : start
# 0:00:18.465508 	 [add_candidate] total_frequent : start
# 0:00:20.683166 	 {'num_clicks': 97136, 'hit_clicks': 1392, 'num_carts': 43211, 'hit_carts': 617, 'num_orders': 20082, 'hit_orders': 112, 'recall_clicks': '0.014', 'recall_carts': '0.014', 'recall_orders': '0.006', 'w_recall_clicks': '0.001', 'w_recall_carts': '0.004', 'w_recall_orders': '0.003', 'score': '0.009'}
# 0:00:20.715703 	 [make_candidate] session_frequent_pair : start
# 0:00:21.172087 	 [add_candidate] session_frequent_pair : start
# 0:00:22.977798 	 {'num_clicks': 97136, 'hit_clicks': 7719, 'num_carts': 43211, 'hit_carts': 3394, 'num_orders': 20082, 'hit_orders': 2563, 'recall_clicks': '0.079', 'recall_carts': '0.079', 'recall_orders': '0.128', 'w_recall_clicks': '0.008', 'w_recall_carts': '0.024', 'w_recall_orders': '0.077', 'score': '0.108'}
# 0:00:22.992311 	 [make_candidate] session_latest_pair0 : start
# 0:00:23.463213 	 [add_candidate] session_latest_pair0 : start
# 0:00:25.076282 	 {'num_clicks': 97136, 'hit_clicks': 7761, 'num_carts': 43211, 'hit_carts': 3395, 'num_orders': 20082, 'hit_orders': 2555, 'recall_clicks': '0.080', 'recall_carts': '0.079', 'recall_orders': '0.127', 'w_recall_clicks': '0.008', 'w_recall_carts': '0.024', 'w_recall_orders': '0.076', 'score': '0.108'}
# 0:00:25.089481 	 [make_candidate] session_latest_pair1 : start
# 0:00:25.410298 	 [add_candidate] session_latest_pair1 : start
# 0:00:27.144909 	 {'num_clicks': 97136, 'hit_clicks': 5561, 'num_carts': 43211, 'hit_carts': 2790, 'num_orders': 20082, 'hit_orders': 1967, 'recall_clicks': '0.057', 'recall_carts': '0.065', 'recall_orders': '0.098', 'w_recall_clicks': '0.006', 'w_recall_carts': '0.019', 'w_recall_orders': '0.059', 'score': '0.084'}
# 0:00:27.157938 	 [make_candidate] session_latest_pair2 : start
# 0:00:27.548827 	 [add_candidate] session_latest_pair2 : start
# 0:00:29.327205 	 {'num_clicks': 97136, 'hit_clicks': 4430, 'num_carts': 43211, 'hit_carts': 2395, 'num_orders': 20082, 'hit_orders': 1808, 'recall_clicks': '0.046', 'recall_carts': '0.055', 'recall_orders': '0.090', 'w_recall_clicks': '0.005', 'w_recall_carts': '0.017', 'w_recall_orders': '0.054', 'score': '0.075'}
# 0:00:29.340871 	 [make_candidate] session_latest_pair3 : start
# 0:00:29.807804 	 [add_candidate] session_latest_pair3 : start
# 0:00:31.675685 	 {'num_clicks': 97136, 'hit_clicks': 3722, 'num_carts': 43211, 'hit_carts': 2083, 'num_orders': 20082, 'hit_orders': 1568, 'recall_clicks': '0.038', 'recall_carts': '0.048', 'recall_orders': '0.078', 'w_recall_clicks': '0.004', 'w_recall_carts': '0.014', 'w_recall_orders': '0.047', 'score': '0.065'}
# 0:00:31.689548 	 [make_candidate] session_latest_pair4 : start
# 0:00:32.055503 	 [add_candidate] session_latest_pair4 : start
# 0:00:33.895522 	 {'num_clicks': 97136, 'hit_clicks': 3158, 'num_carts': 43211, 'hit_carts': 1876, 'num_orders': 20082, 'hit_orders': 1410, 'recall_clicks': '0.033', 'recall_carts': '0.043', 'recall_orders': '0.070', 'w_recall_clicks': '0.003', 'w_recall_carts': '0.013', 'w_recall_orders': '0.042', 'score': '0.058'}
# 0:00:33.910098 	 [make_candidate] session_frequent_clicks_pair : start
# 0:00:34.384747 	 [add_candidate] session_frequent_clicks_pair : start
# 0:00:36.090829 	 {'num_clicks': 97136, 'hit_clicks': 7706, 'num_carts': 43211, 'hit_carts': 2878, 'num_orders': 20082, 'hit_orders': 1963, 'recall_clicks': '0.079', 'recall_carts': '0.067', 'recall_orders': '0.098', 'w_recall_clicks': '0.008', 'w_recall_carts': '0.020', 'w_recall_orders': '0.059', 'score': '0.087'}
# 0:00:36.105433 	 [make_candidate] session_latest_clicks_pair : start
# 0:00:36.608239 	 [add_candidate] session_latest_clicks_pair : start
# 0:00:38.414323 	 {'num_clicks': 97136, 'hit_clicks': 7746, 'num_carts': 43211, 'hit_carts': 2892, 'num_orders': 20082, 'hit_orders': 1955, 'recall_clicks': '0.080', 'recall_carts': '0.067', 'recall_orders': '0.097', 'w_recall_clicks': '0.008', 'w_recall_carts': '0.020', 'w_recall_orders': '0.058', 'score': '0.086'}
# 0:00:38.427845 	 [make_candidate] session_latest_carts_pair : start
# 0:00:38.627045 	 [add_candidate] session_latest_carts_pair : start
# 0:00:40.273794 	 {'num_clicks': 97136, 'hit_clicks': 4225, 'num_carts': 43211, 'hit_carts': 2380, 'num_orders': 20082, 'hit_orders': 1834, 'recall_clicks': '0.043', 'recall_carts': '0.055', 'recall_orders': '0.091', 'w_recall_clicks': '0.004', 'w_recall_carts': '0.017', 'w_recall_orders': '0.055', 'score': '0.076'}
# 0:00:40.284478 	 [make_candidate] session_latest_time_wt_pair : start
# 0:00:40.695301 	 [add_candidate] session_latest_time_wt_pair : start
# 0:00:42.428143 	 {'num_clicks': 97136, 'hit_clicks': 8928, 'num_carts': 43211, 'hit_carts': 2866, 'num_orders': 20082, 'hit_orders': 2121, 'recall_clicks': '0.092', 'recall_carts': '0.066', 'recall_orders': '0.106', 'w_recall_clicks': '0.009', 'w_recall_carts': '0.020', 'w_recall_orders': '0.063', 'score': '0.092'}
# 0:00:42.442739 	 [make_candidate] session_latest_clicks_carts_pair : start
# 0:00:42.904290 	 [add_candidate] session_latest_clicks_carts_pair : start
# 0:00:44.680656 	 {'num_clicks': 97136, 'hit_clicks': 4789, 'num_carts': 43211, 'hit_carts': 3195, 'num_orders': 20082, 'hit_orders': 2119, 'recall_clicks': '0.049', 'recall_carts': '0.074', 'recall_orders': '0.106', 'w_recall_clicks': '0.005', 'w_recall_carts': '0.022', 'w_recall_orders': '0.063', 'score': '0.090'}
# 0:00:44.694211 	 [make_candidate] session_latest_clicks_orders_pair : start
# 0:00:45.103263 	 [add_candidate] session_latest_clicks_orders_pair : start
# 0:00:46.858474 	 {'num_clicks': 97136, 'hit_clicks': 3102, 'num_carts': 43211, 'hit_carts': 2175, 'num_orders': 20082, 'hit_orders': 2221, 'recall_clicks': '0.032', 'recall_carts': '0.050', 'recall_orders': '0.111', 'w_recall_clicks': '0.003', 'w_recall_carts': '0.015', 'w_recall_orders': '0.066', 'score': '0.085'}

# %%
results
# Out:
#                                 name num_clicks hit_clicks num_carts  \
# 0                   session_frequent      97136      29631     43211
# 0                     session_latest      97136      29762     43211
# 0                     total_frequent      97136       1392     43211
# 0              session_frequent_pair      97136       7719     43211
# 0               session_latest_pair0      97136       7761     43211
# 0               session_latest_pair1      97136       5561     43211
# 0               session_latest_pair2      97136       4430     43211
# 0               session_latest_pair3      97136       3722     43211
# 0               session_latest_pair4      97136       3158     43211
# 0       session_frequent_clicks_pair      97136       7706     43211
# 0         session_latest_clicks_pair      97136       7746     43211
# 0          session_latest_carts_pair      97136       4225     43211
# 0        session_latest_time_wt_pair      97136       8928     43211
# 0   session_latest_clicks_carts_pair      97136       4789     43211
# 0  session_latest_clicks_orders_pair      97136       3102     43211
#
#   hit_carts num_orders hit_orders recall_clicks recall_carts recall_orders  \
# 0     10937      20082      10387         0.305        0.253         0.517
# 0     10988      20082      10168         0.306        0.254         0.506
# 0       617      20082        112         0.014        0.014         0.006
# 0      3394      20082       2563         0.079        0.079         0.128
# 0      3395      20082       2555         0.080        0.079         0.127
# 0      2790      20082       1967         0.057        0.065         0.098
# 0      2395      20082       1808         0.046        0.055         0.090
# 0      2083      20082       1568         0.038        0.048         0.078
# 0      1876      20082       1410         0.033        0.043         0.070
# 0      2878      20082       1963         0.079        0.067         0.098
# 0      2892      20082       1955         0.080        0.067         0.097
# 0      2380      20082       1834         0.043        0.055         0.091
# 0      2866      20082       2121         0.092        0.066         0.106
# 0      3195      20082       2119         0.049        0.074         0.106
# 0      2175      20082       2221         0.032        0.050         0.111
#
#   w_recall_clicks w_recall_carts w_recall_orders  score
# 0           0.031          0.076           0.310  0.417
# 0           0.031          0.076           0.304  0.411
# 0           0.001          0.004           0.003  0.009
# 0           0.008          0.024           0.077  0.108
# 0           0.008          0.024           0.076  0.108
# 0           0.006          0.019           0.059  0.084
# 0           0.005          0.017           0.054  0.075
# 0           0.004          0.014           0.047  0.065
# 0           0.003          0.013           0.042  0.058
# 0           0.008          0.020           0.059  0.087
# 0           0.008          0.020           0.058  0.086
# 0           0.004          0.017           0.055  0.076
# 0           0.009          0.020           0.063  0.092
# 0           0.005          0.022           0.063  0.090
# 0           0.003          0.015           0.066  0.085

# %%
def objective_type_recall(df, labels, type_):
    def objective(trial):
        trial_df = df.copy()
        session_frequent = trial.suggest_float("session_frequent", 0, 1)
        session_latest = trial.suggest_float("session_latest", 0, 1)
        total_frequent = trial.suggest_float("total_frequent", 0, 1)
        session_frequent_pair = trial.suggest_float("session_frequent_pair", 0, 1)
        session_latest_pair0 = trial.suggest_float("session_latest_pair0", 0, 1)
        session_latest_pair1 = trial.suggest_float("session_latest_pair1", 0, 1)
        session_latest_pair2 = trial.suggest_float("session_latest_pair2", 0, 1)
        session_latest_pair3 = trial.suggest_float("session_latest_pair3", 0, 1)
        session_latest_pair4 = trial.suggest_float("session_latest_pair4", 0, 1)
        session_frequent_clicks_pair  = trial.suggest_float("session_frequent_clicks_pair", 0, 1)
        session_latest_clicks_pair = trial.suggest_float("session_latest_clicks_pair", 0, 1)
        session_latest_carts_pair  = trial.suggest_float("session_latest_carts_pair", 0, 1)
        session_latest_time_wt_pair = trial.suggest_float("session_latest_time_wt_pair", 0, 1)
        session_latest_clicks_carts_pair = trial.suggest_float("session_latest_clicks_carts_pair", 0, 1)
        session_latest_clicks_orders_pair = trial.suggest_float("session_latest_clicks_orders_pair", 0, 1)

        wt_dict = {
            'session_frequent': session_frequent,
            'session_latest': session_latest, 
            'total_frequent': total_frequent,
            'session_frequent_pair': session_frequent_pair, 
            'session_latest_pair0': session_latest_pair0,
            'session_latest_pair1': session_latest_pair1, 
            'session_latest_pair2': session_latest_pair2,
            'session_latest_pair3': session_latest_pair3, 
            'session_latest_pair4': session_latest_pair4,
            'session_frequent_clicks_pair': session_frequent_clicks_pair, 
            'session_latest_clicks_pair': session_latest_clicks_pair,
            'session_latest_carts_pair': session_latest_carts_pair, 
            'session_latest_time_wt_pair': session_latest_time_wt_pair,
            'session_latest_clicks_carts_pair': session_latest_clicks_carts_pair,
            'session_latest_clicks_orders_pair': session_latest_clicks_orders_pair
        }

        trial_df["rank"] = trial_df["rank"] * trial_df["strategy"].map(wt_dict)
        trial_df = trial_df.sort_values(["session", "rank"])
        trial_df = trial_df.drop_duplicates(subset= ["session", "aid"], keep="first")
        trial_df = trial_df.groupby(["session"]).head(20)
        trial_df = trial_df.groupby("session")["aid"].apply(list).reset_index()

        result = evaluate(labels["clicks_labels"].tolist(),
                          labels["carts_labels"].tolist(),
                          labels["orders_labels"].tolist(),
                          trial_df["aid"].tolist(),
                          trial_df["aid"].tolist(),
                          trial_df["aid"].tolist(),
                          cfg.k)

        return float(result[f"recall_{type_}"])
    return objective

# %%
n_trials = 100

# %% [markdown]
# # パラメータチューニング

# %%
wt = {}
recall = {}

for type_ in ["clicks", "carts", "orders"]:
    logger.info(type_)
    study = optuna.create_study(direction="maximize")
    study.optimize(objective_type_recall(valid, valid_labels, type_), n_trials=n_trials)
    wt[type_] = study.best_params
    recall[type_] = study.best_value
    logger.info(f"{type_}_recall_best_value : {study.best_value}")

score = (recall["clicks"] * 0.1) + (recall["carts"] * 0.3) + (recall["orders"] * 0.6)
logger.info(f"SCORE : {score}")
# Out:
# 0:00:47.150732 	 clicks
# [I 2022-11-30 22:28:15,228] A new study created in memory with name: no-name-37938ae0-4783-4213-8428-405ecfcc3ee1
# [I 2022-11-30 22:28:20,168] Trial 0 finished with value: 0.426 and parameters: {'session_frequent': 0.0431487311769998, 'session_latest': 0.10459141834500896, 'total_frequent': 0.24709062490553668, 'session_frequent_pair': 0.1531079748754559, 'session_latest_pair0': 0.6100389277903023, 'session_latest_pair1': 0.7474496197597524, 'session_latest_pair2': 0.26701313466342413, 'session_latest_pair3': 0.38013900309317117, 'session_latest_pair4': 0.216204328338231, 'session_frequent_clicks_pair': 0.8530581635327349, 'session_latest_clicks_pair': 0.10642223199866441, 'session_latest_carts_pair': 0.779467073088874, 'session_latest_time_wt_pair': 0.22902436640814727, 'session_latest_clicks_carts_pair': 0.6602108227065359, 'session_latest_clicks_orders_pair': 0.5634469801427413}. Best is trial 0 with value: 0.426.
# [I 2022-11-30 22:28:25,224] Trial 1 finished with value: 0.407 and parameters: {'session_frequent': 0.6810114938527232, 'session_latest': 0.21024748532741033, 'total_frequent': 0.5318822952660991, 'session_frequent_pair': 0.26436585795660483, 'session_latest_pair0': 0.47570003294366514, 'session_latest_pair1': 0.8350821156927711, 'session_latest_pair2': 0.731290728128228, 'session_latest_pair3': 0.3278788778914795, 'session_latest_pair4': 0.03497128013877804, 'session_frequent_clicks_pair': 0.8747615790162131, 'session_latest_clicks_pair': 0.6766864741903574, 'session_latest_carts_pair': 0.36617941537072474, 'session_latest_time_wt_pair': 0.307222416125315, 'session_latest_clicks_carts_pair': 0.04603302559923761, 'session_latest_clicks_orders_pair': 0.264661341794892}. Best is trial 0 with value: 0.426.
# [I 2022-11-30 22:28:29,994] Trial 2 finished with value: 0.424 and parameters: {'session_frequent': 0.33208804243115797, 'session_latest': 0.0008739911610015083, 'total_frequent': 0.635979229301771, 'session_frequent_pair': 0.2515660011576458, 'session_latest_pair0': 0.607510531364296, 'session_latest_pair1': 0.3145208000794275, 'session_latest_pair2': 0.48363755397154373, 'session_latest_pair3': 0.05570519814736674, 'session_latest_pair4': 0.47328990919579916, 'session_frequent_clicks_pair': 0.9119673863432526, 'session_latest_clicks_pair': 0.8159503966578702, 'session_latest_carts_pair': 0.6712284753441263, 'session_latest_time_wt_pair': 0.46794642208649495, 'session_latest_clicks_carts_pair': 0.8703514932219976, 'session_latest_clicks_orders_pair': 0.3957305372658152}. Best is trial 0 with value: 0.426.
# [I 2022-11-30 22:28:35,175] Trial 3 finished with value: 0.413 and parameters: {'session_frequent': 0.20473688441321214, 'session_latest': 0.5308384916269596, 'total_frequent': 0.14537412422634988, 'session_frequent_pair': 0.43139549736009675, 'session_latest_pair0': 0.3685740361690091, 'session_latest_pair1': 0.7489265974528783, 'session_latest_pair2': 0.7750117604956259, 'session_latest_pair3': 0.3430731130270177, 'session_latest_pair4': 0.46246913501316955, 'session_frequent_clicks_pair': 0.1574898195443558, 'session_latest_clicks_pair': 0.9358534982313205, 'session_latest_carts_pair': 0.8236839433423482, 'session_latest_time_wt_pair': 0.5175684022685926, 'session_latest_clicks_carts_pair': 0.8288268727455048, 'session_latest_clicks_orders_pair': 0.8708207930132112}. Best is trial 0 with value: 0.426.
# [I 2022-11-30 22:28:40,363] Trial 4 finished with value: 0.396 and parameters: {'session_frequent': 0.18403440687769657, 'session_latest': 0.3264983875005303, 'total_frequent': 0.09575298923787967, 'session_frequent_pair': 0.6698974576722242, 'session_latest_pair0': 0.9198447329814272, 'session_latest_pair1': 0.7621045918688872, 'session_latest_pair2': 0.7541274761964906, 'session_latest_pair3': 0.7896141936686732, 'session_latest_pair4': 0.6355635983996756, 'session_frequent_clicks_pair': 0.4195099515126671, 'session_latest_clicks_pair': 0.03124912114841183, 'session_latest_carts_pair': 0.8203847900451186, 'session_latest_time_wt_pair': 0.6709991446644041, 'session_latest_clicks_carts_pair': 0.8335337674037, 'session_latest_clicks_orders_pair': 0.09217901258351624}. Best is trial 0 with value: 0.426.
# [I 2022-11-30 22:28:45,495] Trial 5 finished with value: 0.298 and parameters: {'session_frequent': 0.18842187075924588, 'session_latest': 0.9707810279624376, 'total_frequent': 0.022686855728330513, 'session_frequent_pair': 0.8583737526797744, 'session_latest_pair0': 0.5336791364848599, 'session_latest_pair1': 0.26202190129173886, 'session_latest_pair2': 0.7442812136586641, 'session_latest_pair3': 0.950146961964689, 'session_latest_pair4': 0.7877512754605145, 'session_frequent_clicks_pair': 0.223941269640081, 'session_latest_clicks_pair': 0.9534378422905063, 'session_latest_carts_pair': 0.6703302394620596, 'session_latest_time_wt_pair': 0.15616412724069606, 'session_latest_clicks_carts_pair': 0.5025447627074886, 'session_latest_clicks_orders_pair': 0.20035087643619975}. Best is trial 0 with value: 0.426.
# [I 2022-11-30 22:28:50,371] Trial 6 finished with value: 0.391 and parameters: {'session_frequent': 0.896633940541977, 'session_latest': 0.8745643592844271, 'total_frequent': 0.8641928684873197, 'session_frequent_pair': 0.8837330433447891, 'session_latest_pair0': 0.325607722854488, 'session_latest_pair1': 0.5091695572726234, 'session_latest_pair2': 0.7459138269364692, 'session_latest_pair3': 0.5704667089331088, 'session_latest_pair4': 0.04609190434526622, 'session_frequent_clicks_pair': 0.8486816381166559, 'session_latest_clicks_pair': 0.026020234513608576, 'session_latest_carts_pair': 0.674313747223732, 'session_latest_time_wt_pair': 0.6669038936747684, 'session_latest_clicks_carts_pair': 0.3370730291342455, 'session_latest_clicks_orders_pair': 0.7882303100325108}. Best is trial 0 with value: 0.426.
# [I 2022-11-30 22:28:55,403] Trial 7 finished with value: 0.422 and parameters: {'session_frequent': 0.16480931801089937, 'session_latest': 0.130211403440883, 'total_frequent': 0.5869148031238722, 'session_frequent_pair': 0.3124887674007829, 'session_latest_pair0': 0.8333375701276956, 'session_latest_pair1': 0.9587435555313872, 'session_latest_pair2': 0.7460727687646997, 'session_latest_pair3': 0.7885468801254437, 'session_latest_pair4': 0.7936740302560547, 'session_frequent_clicks_pair': 0.35195649520059835, 'session_latest_clicks_pair': 0.18194630299852976, 'session_latest_carts_pair': 0.5402746143012994, 'session_latest_time_wt_pair': 0.963543303483032, 'session_latest_clicks_carts_pair': 0.7195615795521796, 'session_latest_clicks_orders_pair': 0.11912166069731855}. Best is trial 0 with value: 0.426.
# [I 2022-11-30 22:29:00,451] Trial 8 finished with value: 0.368 and parameters: {'session_frequent': 0.2188427217255713, 'session_latest': 0.169338964723597, 'total_frequent': 0.040040195747837015, 'session_frequent_pair': 0.6535884563514329, 'session_latest_pair0': 0.3246944268513112, 'session_latest_pair1': 0.566266019136161, 'session_latest_pair2': 0.9395410603360289, 'session_latest_pair3': 0.2930100650422608, 'session_latest_pair4': 0.8584722430345589, 'session_frequent_clicks_pair': 0.28128473900102946, 'session_latest_clicks_pair': 0.448311091343063, 'session_latest_carts_pair': 0.022758279232275025, 'session_latest_time_wt_pair': 0.02871745505006973, 'session_latest_clicks_carts_pair': 0.07736753704326282, 'session_latest_clicks_orders_pair': 0.9350932996325512}. Best is trial 0 with value: 0.426.
# [I 2022-11-30 22:29:05,460] Trial 9 finished with value: 0.384 and parameters: {'session_frequent': 0.9526496063418913, 'session_latest': 0.6325202262959915, 'total_frequent': 0.7007000353768489, 'session_frequent_pair': 0.10896957994667134, 'session_latest_pair0': 0.6608676301944911, 'session_latest_pair1': 0.5023660762658977, 'session_latest_pair2': 0.10188728448974993, 'session_latest_pair3': 0.15103217299741312, 'session_latest_pair4': 0.14384701163924263, 'session_frequent_clicks_pair': 0.5017200174614503, 'session_latest_clicks_pair': 0.26616177740263325, 'session_latest_carts_pair': 0.018341346312514495, 'session_latest_time_wt_pair': 0.7640908464583226, 'session_latest_clicks_carts_pair': 0.7880194249565957, 'session_latest_clicks_orders_pair': 0.5452530309535857}. Best is trial 0 with value: 0.426.
# [I 2022-11-30 22:29:10,601] Trial 10 finished with value: 0.42 and parameters: {'session_frequent': 0.006369562766180503, 'session_latest': 0.42028040586910476, 'total_frequent': 0.2697268655291393, 'session_frequent_pair': 0.007978450496330808, 'session_latest_pair0': 0.030826977550053924, 'session_latest_pair1': 0.011028540731139902, 'session_latest_pair2': 0.15073322272445314, 'session_latest_pair3': 0.5475221757053946, 'session_latest_pair4': 0.28462720040053424, 'session_frequent_clicks_pair': 0.6335044235417205, 'session_latest_clicks_pair': 0.4757888198416032, 'session_latest_carts_pair': 0.9667429592012875, 'session_latest_time_wt_pair': 0.26544485953568164, 'session_latest_clicks_carts_pair': 0.4537793429072163, 'session_latest_clicks_orders_pair': 0.6195917891276892}. Best is trial 0 with value: 0.426.
# [I 2022-11-30 22:29:15,469] Trial 11 finished with value: 0.421 and parameters: {'session_frequent': 0.4966929445944854, 'session_latest': 0.03362126484497213, 'total_frequent': 0.3354923255730939, 'session_frequent_pair': 0.20961380268158195, 'session_latest_pair0': 0.6631267959095305, 'session_latest_pair1': 0.26655337807513574, 'session_latest_pair2': 0.3788797061205528, 'session_latest_pair3': 0.02343008897865484, 'session_latest_pair4': 0.3765497683576119, 'session_frequent_clicks_pair': 0.9922350510886292, 'session_latest_clicks_pair': 0.7209048103815565, 'session_latest_carts_pair': 0.3708606021846101, 'session_latest_time_wt_pair': 0.422806100942231, 'session_latest_clicks_carts_pair': 0.9523962032513107, 'session_latest_clicks_orders_pair': 0.366908701190054}. Best is trial 0 with value: 0.426.
# [I 2022-11-30 22:29:20,539] Trial 12 finished with value: 0.423 and parameters: {'session_frequent': 0.41035431207406325, 'session_latest': 0.003161615634664139, 'total_frequent': 0.35005001249260204, 'session_frequent_pair': 0.4226923543074454, 'session_latest_pair0': 0.7080632740461301, 'session_latest_pair1': 0.2823689589684708, 'session_latest_pair2': 0.3850773718905554, 'session_latest_pair3': 0.047804876020297704, 'session_latest_pair4': 0.5698075958745195, 'session_frequent_clicks_pair': 0.7152087552194906, 'session_latest_clicks_pair': 0.6971420959356357, 'session_latest_carts_pair': 0.9985239236517185, 'session_latest_time_wt_pair': 0.42003944639581364, 'session_latest_clicks_carts_pair': 0.6243225938041707, 'session_latest_clicks_orders_pair': 0.41577619326800075}. Best is trial 0 with value: 0.426.
# [I 2022-11-30 22:29:25,657] Trial 13 finished with value: 0.409 and parameters: {'session_frequent': 0.36630330703303915, 'session_latest': 0.3218988003738351, 'total_frequent': 0.9013302736826307, 'session_frequent_pair': 0.10063697940462846, 'session_latest_pair0': 0.9937285659193222, 'session_latest_pair1': 0.6490390441404429, 'session_latest_pair2': 0.28103494416479274, 'session_latest_pair3': 0.1968875333921279, 'session_latest_pair4': 0.2672338453917841, 'session_frequent_clicks_pair': 0.015227818214981315, 'session_latest_clicks_pair': 0.31940244189992817, 'session_latest_carts_pair': 0.5990251445819855, 'session_latest_time_wt_pair': 0.007490355473256549, 'session_latest_clicks_carts_pair': 0.9578554074078065, 'session_latest_clicks_orders_pair': 0.6897293041620596}. Best is trial 0 with value: 0.426.
# [I 2022-11-30 22:29:30,605] Trial 14 finished with value: 0.426 and parameters: {'session_frequent': 0.008947024075816656, 'session_latest': 0.71231610781119, 'total_frequent': 0.7086078962327357, 'session_frequent_pair': 0.329073371742719, 'session_latest_pair0': 0.5187227209879611, 'session_latest_pair1': 0.3967172662373911, 'session_latest_pair2': 0.5184073471084851, 'session_latest_pair3': 0.4404888887393248, 'session_latest_pair4': 0.24708614292176895, 'session_frequent_clicks_pair': 0.9976904911414209, 'session_latest_clicks_pair': 0.8021657633811334, 'session_latest_carts_pair': 0.7972032365040707, 'session_latest_time_wt_pair': 0.2174817824805893, 'session_latest_clicks_carts_pair': 0.634655376296256, 'session_latest_clicks_orders_pair': 0.4624786104297766}. Best is trial 0 with value: 0.426.
# [I 2022-11-30 22:29:35,611] Trial 15 finished with value: 0.427 and parameters: {'session_frequent': 0.03253393597325588, 'session_latest': 0.7066464095369887, 'total_frequent': 0.7664896971275978, 'session_frequent_pair': 0.3825643751680893, 'session_latest_pair0': 0.19092843736286463, 'session_latest_pair1': 0.3918144852110545, 'session_latest_pair2': 0.5731196411458456, 'session_latest_pair3': 0.45166103754831055, 'session_latest_pair4': 0.20497892273446733, 'session_frequent_clicks_pair': 0.6929347130797531, 'session_latest_clicks_pair': 0.5353817183977772, 'session_latest_carts_pair': 0.8195420833800144, 'session_latest_time_wt_pair': 0.18890300101403149, 'session_latest_clicks_carts_pair': 0.6081116619601334, 'session_latest_clicks_orders_pair': 0.5508089142891692}. Best is trial 15 with value: 0.427.
# [I 2022-11-30 22:29:40,784] Trial 16 finished with value: 0.394 and parameters: {'session_frequent': 0.7308087119878597, 'session_latest': 0.7430207721443715, 'total_frequent': 0.4267304781683711, 'session_frequent_pair': 0.5417948543074452, 'session_latest_pair0': 0.10171906703805489, 'session_latest_pair1': 0.12776151741645758, 'session_latest_pair2': 0.581472101145826, 'session_latest_pair3': 0.6504421425799624, 'session_latest_pair4': 0.16189916837538113, 'session_frequent_clicks_pair': 0.7288741621091913, 'session_latest_clicks_pair': 0.5598515802035724, 'session_latest_carts_pair': 0.4100747037906792, 'session_latest_time_wt_pair': 0.11585884712569647, 'session_latest_clicks_carts_pair': 0.32030388738644555, 'session_latest_clicks_orders_pair': 0.7082759510094692}. Best is trial 15 with value: 0.427.
# [I 2022-11-30 22:29:45,627] Trial 17 finished with value: 0.414 and parameters: {'session_frequent': 0.08979156495726709, 'session_latest': 0.5834677824030042, 'total_frequent': 0.9804527991375515, 'session_frequent_pair': 0.5523097063258715, 'session_latest_pair0': 0.18526937312014768, 'session_latest_pair1': 0.6620118865152579, 'session_latest_pair2': 0.0017679370009134887, 'session_latest_pair3': 0.4260629411645319, 'session_latest_pair4': 0.36644708157324574, 'session_frequent_clicks_pair': 0.5417089149223985, 'session_latest_clicks_pair': 0.3837986118608392, 'session_latest_carts_pair': 0.9156755981110472, 'session_latest_time_wt_pair': 0.32458586224651387, 'session_latest_clicks_carts_pair': 0.5391477580066666, 'session_latest_clicks_orders_pair': 0.5581043436437576}. Best is trial 15 with value: 0.427.
# [I 2022-11-30 22:29:50,688] Trial 18 finished with value: 0.399 and parameters: {'session_frequent': 0.653077425150973, 'session_latest': 0.44253366890372603, 'total_frequent': 0.18807248924114314, 'session_frequent_pair': 0.1703567998945591, 'session_latest_pair0': 0.21667308659986825, 'session_latest_pair1': 0.8950730062535862, 'session_latest_pair2': 0.26386424880669673, 'session_latest_pair3': 0.6783310520029551, 'session_latest_pair4': 0.15312606973118964, 'session_frequent_clicks_pair': 0.7524343256056522, 'session_latest_clicks_pair': 0.1684327813075685, 'session_latest_carts_pair': 0.2456948230783278, 'session_latest_time_wt_pair': 0.11636224521440418, 'session_latest_clicks_carts_pair': 0.3655542366010242, 'session_latest_clicks_orders_pair': 0.29279948354213875}. Best is trial 15 with value: 0.427.
# [I 2022-11-30 22:29:55,653] Trial 19 finished with value: 0.408 and parameters: {'session_frequent': 0.2990941138679882, 'session_latest': 0.8207029108700643, 'total_frequent': 0.7950770901808415, 'session_frequent_pair': 0.009602935458239842, 'session_latest_pair0': 0.7827306831210996, 'session_latest_pair1': 0.4170574538485659, 'session_latest_pair2': 0.2495045962440758, 'session_latest_pair3': 0.2222545267496731, 'session_latest_pair4': 0.9770159916259079, 'session_frequent_clicks_pair': 0.6344050881950068, 'session_latest_clicks_pair': 0.5547705060996242, 'session_latest_carts_pair': 0.7547773541739202, 'session_latest_time_wt_pair': 0.5638608731532586, 'session_latest_clicks_carts_pair': 0.6740296092358966, 'session_latest_clicks_orders_pair': 0.6629539176930489}. Best is trial 15 with value: 0.427.
# [I 2022-11-30 22:30:00,842] Trial 20 finished with value: 0.411 and parameters: {'session_frequent': 0.09056868637958913, 'session_latest': 0.3188320698720428, 'total_frequent': 0.4516228105281994, 'session_frequent_pair': 0.4163028681953609, 'session_latest_pair0': 0.4184445297794971, 'session_latest_pair1': 0.6247584945000085, 'session_latest_pair2': 0.5965028387605545, 'session_latest_pair3': 0.4735469594917983, 'session_latest_pair4': 0.0063287168488463386, 'session_frequent_clicks_pair': 0.8166084626001905, 'session_latest_clicks_pair': 0.19035824229252302, 'session_latest_carts_pair': 0.5033727191962803, 'session_latest_time_wt_pair': 0.37515490022968456, 'session_latest_clicks_carts_pair': 0.1796494706808467, 'session_latest_clicks_orders_pair': 0.7965245853165418}. Best is trial 15 with value: 0.427.
# [I 2022-11-30 22:30:05,659] Trial 21 finished with value: 0.427 and parameters: {'session_frequent': 0.04776271507704488, 'session_latest': 0.6965739740059622, 'total_frequent': 0.7272333231727591, 'session_frequent_pair': 0.34540425605895764, 'session_latest_pair0': 0.5670043236071344, 'session_latest_pair1': 0.4526789915036824, 'session_latest_pair2': 0.48555430925553195, 'session_latest_pair3': 0.40671885074224845, 'session_latest_pair4': 0.25110566605744067, 'session_frequent_clicks_pair': 0.9978597979546567, 'session_latest_clicks_pair': 0.7966128402533592, 'session_latest_carts_pair': 0.865900709877843, 'session_latest_time_wt_pair': 0.21995694384156983, 'session_latest_clicks_carts_pair': 0.5994184377676424, 'session_latest_clicks_orders_pair': 0.4855299862817819}. Best is trial 15 with value: 0.427.
# [I 2022-11-30 22:30:10,694] Trial 22 finished with value: 0.426 and parameters: {'session_frequent': 0.0010897067323143092, 'session_latest': 0.716817228689406, 'total_frequent': 0.7422553238422287, 'session_frequent_pair': 0.34336650890747383, 'session_latest_pair0': 0.5102518612021507, 'session_latest_pair1': 0.3554648881365001, 'session_latest_pair2': 0.535614156653711, 'session_latest_pair3': 0.4881331114462092, 'session_latest_pair4': 0.3408330322216917, 'session_frequent_clicks_pair': 0.9855133255379772, 'session_latest_clicks_pair': 0.8242073792059935, 'session_latest_carts_pair': 0.8871671938674753, 'session_latest_time_wt_pair': 0.23887927826906194, 'session_latest_clicks_carts_pair': 0.5903274891841932, 'session_latest_clicks_orders_pair': 0.38073229407246634}. Best is trial 15 with value: 0.427.
# [I 2022-11-30 22:30:15,580] Trial 23 finished with value: 0.422 and parameters: {'session_frequent': 0.09950478829928151, 'session_latest': 0.8358615738779918, 'total_frequent': 0.5904144684132987, 'session_frequent_pair': 0.1380537390565349, 'session_latest_pair0': 0.582972625831722, 'session_latest_pair1': 0.17265731986402227, 'session_latest_pair2': 0.39151198674955034, 'session_latest_pair3': 0.37578848778541335, 'session_latest_pair4': 0.20475592417672137, 'session_frequent_clicks_pair': 0.7950745906471752, 'session_latest_clicks_pair': 0.6218577536800897, 'session_latest_carts_pair': 0.7337463711517147, 'session_latest_time_wt_pair': 0.1816793348910221, 'session_latest_clicks_carts_pair': 0.7251703785809885, 'session_latest_clicks_orders_pair': 0.5128428497107128}. Best is trial 15 with value: 0.427.
# [I 2022-11-30 22:30:20,625] Trial 24 finished with value: 0.416 and parameters: {'session_frequent': 0.28496662339362433, 'session_latest': 0.6371263513074223, 'total_frequent': 0.8212780930761919, 'session_frequent_pair': 0.629811568070536, 'session_latest_pair0': 0.24391431166017252, 'session_latest_pair1': 0.4640468100980197, 'session_latest_pair2': 0.6520703719099477, 'session_latest_pair3': 0.2856977005264286, 'session_latest_pair4': 0.11372876756423256, 'session_frequent_clicks_pair': 0.6170041218761971, 'session_latest_clicks_pair': 0.4213131983122191, 'session_latest_carts_pair': 0.8872408184055816, 'session_latest_time_wt_pair': 0.08139157810627681, 'session_latest_clicks_carts_pair': 0.3992169039622333, 'session_latest_clicks_orders_pair': 0.6064558947630566}. Best is trial 15 with value: 0.427.
# [I 2022-11-30 22:30:25,694] Trial 25 finished with value: 0.415 and parameters: {'session_frequent': 0.09950486100079975, 'session_latest': 0.5351312280078434, 'total_frequent': 0.9665482840475772, 'session_frequent_pair': 0.46978943206921275, 'session_latest_pair0': 0.4300655281277764, 'session_latest_pair1': 0.5597655253120005, 'session_latest_pair2': 0.4523446267909594, 'session_latest_pair3': 0.6215779292559585, 'session_latest_pair4': 0.41570427942024163, 'session_frequent_clicks_pair': 0.9120291255019447, 'session_latest_clicks_pair': 0.5458373155916415, 'session_latest_carts_pair': 0.8771219686532763, 'session_latest_time_wt_pair': 0.3395764409383409, 'session_latest_clicks_carts_pair': 0.5670103279597629, 'session_latest_clicks_orders_pair': 0.006092202899810384}. Best is trial 15 with value: 0.427.
# [I 2022-11-30 22:30:30,658] Trial 26 finished with value: 0.424 and parameters: {'session_frequent': 0.08287936207090862, 'session_latest': 0.9222566822627976, 'total_frequent': 0.6459804357654902, 'session_frequent_pair': 0.7848147286717297, 'session_latest_pair0': 0.7540715171853802, 'session_latest_pair1': 0.7295064066205863, 'session_latest_pair2': 0.8849345643543003, 'session_latest_pair3': 0.39596819796278965, 'session_latest_pair4': 0.5951122784325058, 'session_frequent_clicks_pair': 0.696626546955206, 'session_latest_clicks_pair': 0.327520628265646, 'session_latest_carts_pair': 0.5780222470507573, 'session_latest_time_wt_pair': 0.25997432013507965, 'session_latest_clicks_carts_pair': 0.24064594035032277, 'session_latest_clicks_orders_pair': 0.4874678557857288}. Best is trial 15 with value: 0.427.
# [I 2022-11-30 22:30:35,521] Trial 27 finished with value: 0.416 and parameters: {'session_frequent': 0.4738502524235494, 'session_latest': 0.7486501506007044, 'total_frequent': 0.7946474617707443, 'session_frequent_pair': 0.36082864578447427, 'session_latest_pair0': 0.5950714509972314, 'session_latest_pair1': 0.43767689996470227, 'session_latest_pair2': 0.6348430797351293, 'session_latest_pair3': 0.5322020499678316, 'session_latest_pair4': 0.30831365562770896, 'session_frequent_clicks_pair': 0.9039434399506214, 'session_latest_clicks_pair': 0.8533534787601491, 'session_latest_carts_pair': 0.732182263528457, 'session_latest_time_wt_pair': 0.1774144404236545, 'session_latest_clicks_carts_pair': 0.45546480561873637, 'session_latest_clicks_orders_pair': 0.7393711082383002}. Best is trial 15 with value: 0.427.
# [I 2022-11-30 22:30:40,598] Trial 28 finished with value: 0.42 and parameters: {'session_frequent': 0.1326546486113615, 'session_latest': 0.6423866906756847, 'total_frequent': 0.5051833625060349, 'session_frequent_pair': 0.9756148918896317, 'session_latest_pair0': 0.11691292265080089, 'session_latest_pair1': 0.5729478156912696, 'session_latest_pair2': 0.3177485441397111, 'session_latest_pair3': 0.2361976553820553, 'session_latest_pair4': 0.2149563709917668, 'session_frequent_clicks_pair': 0.8108863120016281, 'session_latest_clicks_pair': 0.6344289254466063, 'session_latest_carts_pair': 0.9402416799230353, 'session_latest_time_wt_pair': 0.08323390540043925, 'session_latest_clicks_carts_pair': 0.7326363893752386, 'session_latest_clicks_orders_pair': 0.5997256874094089}. Best is trial 15 with value: 0.427.
# [I 2022-11-30 22:30:45,533] Trial 29 finished with value: 0.404 and parameters: {'session_frequent': 0.2492150443712422, 'session_latest': 0.4478644844059946, 'total_frequent': 0.27866145156614003, 'session_frequent_pair': 0.2651692871131204, 'session_latest_pair0': 0.4616581952242982, 'session_latest_pair1': 0.8715352295213461, 'session_latest_pair2': 0.14359771709517416, 'session_latest_pair3': 0.7303743921297317, 'session_latest_pair4': 0.05493990449566638, 'session_frequent_clicks_pair': 0.8801040281843622, 'session_latest_clicks_pair': 0.09609673177421085, 'session_latest_carts_pair': 0.20395275140459151, 'session_latest_time_wt_pair': 0.28300984152876496, 'session_latest_clicks_carts_pair': 0.6704061611508962, 'session_latest_clicks_orders_pair': 0.24126232281989096}. Best is trial 15 with value: 0.427.
# [I 2022-11-30 22:30:50,532] Trial 30 finished with value: 0.422 and parameters: {'session_frequent': 0.5974750453089231, 'session_latest': 0.22183997957104584, 'total_frequent': 0.9092973859391638, 'session_frequent_pair': 0.25342365253791843, 'session_latest_pair0': 0.8631371212655243, 'session_latest_pair1': 0.1925468842222674, 'session_latest_pair2': 0.4365914044929011, 'session_latest_pair3': 0.3606233205673096, 'session_latest_pair4': 0.08827856548927251, 'session_frequent_clicks_pair': 0.5848619933051035, 'session_latest_clicks_pair': 0.7606826159619702, 'session_latest_carts_pair': 0.6204382251301166, 'session_latest_time_wt_pair': 0.34174364371219434, 'session_latest_clicks_carts_pair': 0.5308609543319791, 'session_latest_clicks_orders_pair': 0.30961308701342527}. Best is trial 15 with value: 0.427.
# [I 2022-11-30 22:30:55,321] Trial 31 finished with value: 0.426 and parameters: {'session_frequent': 0.007721107956443422, 'session_latest': 0.726870209363979, 'total_frequent': 0.7130809312551614, 'session_frequent_pair': 0.3300451281479465, 'session_latest_pair0': 0.5207785060869838, 'session_latest_pair1': 0.3600726448067444, 'session_latest_pair2': 0.582616888175371, 'session_latest_pair3': 0.4572928245866692, 'session_latest_pair4': 0.34328352177500615, 'session_frequent_clicks_pair': 0.9924521803398559, 'session_latest_clicks_pair': 0.8322686267531066, 'session_latest_carts_pair': 0.8370753165175702, 'session_latest_time_wt_pair': 0.21174192181539297, 'session_latest_clicks_carts_pair': 0.6156846873787972, 'session_latest_clicks_orders_pair': 0.4604957359408934}. Best is trial 15 with value: 0.427.
# [I 2022-11-30 22:31:00,243] Trial 32 finished with value: 0.426 and parameters: {'session_frequent': 0.025156432704206484, 'session_latest': 0.7116941104705237, 'total_frequent': 0.712664743127761, 'session_frequent_pair': 0.367796870426804, 'session_latest_pair0': 0.5370630998562065, 'session_latest_pair1': 0.3720960559357871, 'session_latest_pair2': 0.5385421105097129, 'session_latest_pair3': 0.48870870574605263, 'session_latest_pair4': 0.23760277818923808, 'session_frequent_clicks_pair': 0.967207738597299, 'session_latest_clicks_pair': 0.8803697358339101, 'session_latest_carts_pair': 0.7844801482818957, 'session_latest_time_wt_pair': 0.24721020000575855, 'session_latest_clicks_carts_pair': 0.5971407772265471, 'session_latest_clicks_orders_pair': 0.349141865882335}. Best is trial 15 with value: 0.427.
# [I 2022-11-30 22:31:05,190] Trial 33 finished with value: 0.425 and parameters: {'session_frequent': 0.04993805870241077, 'session_latest': 0.792613163868715, 'total_frequent': 0.7612724152555883, 'session_frequent_pair': 0.533586637389335, 'session_latest_pair0': 0.6487039701408412, 'session_latest_pair1': 0.3479020128246859, 'session_latest_pair2': 0.8457800191529962, 'session_latest_pair3': 0.5896533339804761, 'session_latest_pair4': 0.4291003875389757, 'session_frequent_clicks_pair': 0.9061551013473788, 'session_latest_clicks_pair': 0.8956049961278398, 'session_latest_carts_pair': 0.8817867628115326, 'session_latest_time_wt_pair': 0.49217948060065453, 'session_latest_clicks_carts_pair': 0.4722245450366215, 'session_latest_clicks_orders_pair': 0.416798177772903}. Best is trial 15 with value: 0.427.
# [I 2022-11-30 22:31:10,191] Trial 34 finished with value: 0.424 and parameters: {'session_frequent': 0.15011670597122947, 'session_latest': 0.5740804691955098, 'total_frequent': 0.6409428079236243, 'session_frequent_pair': 0.20025280944066468, 'session_latest_pair0': 0.3766081250572749, 'session_latest_pair1': 0.8008252196762807, 'session_latest_pair2': 0.6570379071351538, 'session_latest_pair3': 0.3154245763881839, 'session_latest_pair4': 0.5203645979245868, 'session_frequent_clicks_pair': 0.9185091059887545, 'session_latest_clicks_pair': 0.9968298675848835, 'session_latest_carts_pair': 0.8362081229655305, 'session_latest_time_wt_pair': 0.15114516793007543, 'session_latest_clicks_carts_pair': 0.791480200107049, 'session_latest_clicks_orders_pair': 0.45817422041662254}. Best is trial 15 with value: 0.427.
# [I 2022-11-30 22:31:15,144] Trial 35 finished with value: 0.422 and parameters: {'session_frequent': 0.054792534046724434, 'session_latest': 0.685716102957683, 'total_frequent': 0.5553663623003914, 'session_frequent_pair': 0.39559153594730645, 'session_latest_pair0': 0.5648149456010603, 'session_latest_pair1': 0.706976071716595, 'session_latest_pair2': 0.507145036655768, 'session_latest_pair3': 0.11271405854582939, 'session_latest_pair4': 0.1991052512620667, 'session_frequent_clicks_pair': 0.7705114472392363, 'session_latest_clicks_pair': 0.9038370366123321, 'session_latest_carts_pair': 0.6882384558904808, 'session_latest_time_wt_pair': 0.42339274821752343, 'session_latest_clicks_carts_pair': 0.6767046155123443, 'session_latest_clicks_orders_pair': 0.3367607050924316}. Best is trial 15 with value: 0.427.
# [I 2022-11-30 22:31:20,151] Trial 36 finished with value: 0.419 and parameters: {'session_frequent': 0.2535630039030744, 'session_latest': 0.7822518780030734, 'total_frequent': 0.8528532195290723, 'session_frequent_pair': 0.502800006718474, 'session_latest_pair0': 0.28797436500431717, 'session_latest_pair1': 0.4892961786129135, 'session_latest_pair2': 0.6870712985063849, 'session_latest_pair3': 0.48924418191804037, 'session_latest_pair4': 0.4933347666737836, 'session_frequent_clicks_pair': 0.8511493703227871, 'session_latest_clicks_pair': 0.7566427112455499, 'session_latest_carts_pair': 0.7842228757134194, 'session_latest_time_wt_pair': 0.5662853408976761, 'session_latest_clicks_carts_pair': 0.8782330534968941, 'session_latest_clicks_orders_pair': 0.19135770256865037}. Best is trial 15 with value: 0.427.
# [I 2022-11-30 22:31:24,999] Trial 37 finished with value: 0.41 and parameters: {'session_frequent': 0.15711839497755375, 'session_latest': 0.8827694540767794, 'total_frequent': 0.16559377765707156, 'session_frequent_pair': 0.2631495920980861, 'session_latest_pair0': 0.3913576063748568, 'session_latest_pair1': 0.314887219961873, 'session_latest_pair2': 0.443939956003344, 'session_latest_pair3': 0.995518308537706, 'session_latest_pair4': 0.3319972759535773, 'session_frequent_clicks_pair': 0.9498354294780934, 'session_latest_clicks_pair': 0.6290514778026287, 'session_latest_carts_pair': 0.990791750733182, 'session_latest_time_wt_pair': 0.0692052581375191, 'session_latest_clicks_carts_pair': 0.5656572986521465, 'session_latest_clicks_orders_pair': 0.550384106263464}. Best is trial 15 with value: 0.427.
# [I 2022-11-30 22:31:29,984] Trial 38 finished with value: 0.417 and parameters: {'session_frequent': 0.19664250087534582, 'session_latest': 0.9419290943116085, 'total_frequent': 0.4630972953428397, 'session_frequent_pair': 0.4665302109889882, 'session_latest_pair0': 0.49623931274576794, 'session_latest_pair1': 0.21402906528094529, 'session_latest_pair2': 0.8072344340517572, 'session_latest_pair3': 0.4142439626926356, 'session_latest_pair4': 0.4016733836695876, 'session_frequent_clicks_pair': 0.41460787779867203, 'session_latest_clicks_pair': 0.9785869884412257, 'session_latest_carts_pair': 0.700428413005129, 'session_latest_time_wt_pair': 0.9780101754424826, 'session_latest_clicks_carts_pair': 0.7637767246403111, 'session_latest_clicks_orders_pair': 0.40250952888000247}. Best is trial 15 with value: 0.427.
# [I 2022-11-30 22:31:34,934] Trial 39 finished with value: 0.407 and parameters: {'session_frequent': 0.8063336328786966, 'session_latest': 0.9952697700077608, 'total_frequent': 0.7473567509836375, 'session_frequent_pair': 0.34009578103222293, 'session_latest_pair0': 0.44594491575343165, 'session_latest_pair1': 0.39923372944000846, 'session_latest_pair2': 0.5210951952636597, 'session_latest_pair3': 0.5200852945462316, 'session_latest_pair4': 0.26023824896105563, 'session_frequent_clicks_pair': 0.9645115421030068, 'session_latest_clicks_pair': 0.7984333486315557, 'session_latest_carts_pair': 0.8161628617459459, 'session_latest_time_wt_pair': 0.212874302471142, 'session_latest_clicks_carts_pair': 0.41655273661548664, 'session_latest_clicks_orders_pair': 0.48681953094919883}. Best is trial 15 with value: 0.427.
# [I 2022-11-30 22:31:39,905] Trial 40 finished with value: 0.398 and parameters: {'session_frequent': 0.357818716378197, 'session_latest': 0.6680272793045471, 'total_frequent': 0.6455133584240964, 'session_frequent_pair': 0.08385836250424153, 'session_latest_pair0': 0.626848698180585, 'session_latest_pair1': 0.11518098613677202, 'session_latest_pair2': 0.20477763416699568, 'session_latest_pair3': 0.2644156402430814, 'session_latest_pair4': 0.07846464639675776, 'session_frequent_clicks_pair': 0.856068303133382, 'session_latest_clicks_pair': 0.08226735227955645, 'session_latest_carts_pair': 0.9057738924331794, 'session_latest_time_wt_pair': 0.833225424518275, 'session_latest_clicks_carts_pair': 0.5082435948657961, 'session_latest_clicks_orders_pair': 0.8411162129648335}. Best is trial 15 with value: 0.427.
# [I 2022-11-30 22:31:44,732] Trial 41 finished with value: 0.426 and parameters: {'session_frequent': 0.009683186674392743, 'session_latest': 0.598908892690734, 'total_frequent': 0.6648461260155509, 'session_frequent_pair': 0.3153952340167223, 'session_latest_pair0': 0.4891115750532079, 'session_latest_pair1': 0.5274211714572077, 'session_latest_pair2': 0.3334419457013083, 'session_latest_pair3': 0.32773080645109987, 'session_latest_pair4': 0.2957995055618657, 'session_frequent_clicks_pair': 0.933852878830169, 'session_latest_clicks_pair': 0.7868451642214893, 'session_latest_carts_pair': 0.6431498470290004, 'session_latest_time_wt_pair': 0.23258906178044522, 'session_latest_clicks_carts_pair': 0.6445224749096273, 'session_latest_clicks_orders_pair': 0.5269323979187978}. Best is trial 15 with value: 0.427.
# [I 2022-11-30 22:31:49,608] Trial 42 finished with value: 0.427 and parameters: {'session_frequent': 0.052733688516545, 'session_latest': 0.4970336381507502, 'total_frequent': 0.5904115932412665, 'session_frequent_pair': 0.37185599378825923, 'session_latest_pair0': 0.6958090585924469, 'session_latest_pair1': 0.35778111591062794, 'session_latest_pair2': 0.5676396521123521, 'session_latest_pair3': 0.4388454616819423, 'session_latest_pair4': 0.2227225715898669, 'session_frequent_clicks_pair': 0.8473953320641953, 'session_latest_clicks_pair': 0.9200540024560372, 'session_latest_carts_pair': 0.8420021182413451, 'session_latest_time_wt_pair': 0.2960714649349083, 'session_latest_clicks_carts_pair': 0.6086079024098415, 'session_latest_clicks_orders_pair': 0.447809875156894}. Best is trial 15 with value: 0.427.
# [I 2022-11-30 22:31:54,633] Trial 43 finished with value: 0.424 and parameters: {'session_frequent': 0.1359686501707615, 'session_latest': 0.5362569122776903, 'total_frequent': 0.5713104249109089, 'session_frequent_pair': 0.3767556047316357, 'session_latest_pair0': 0.5692360339451228, 'session_latest_pair1': 0.34039130851823135, 'session_latest_pair2': 0.7003195419639995, 'session_latest_pair3': 0.5935779321971325, 'session_latest_pair4': 0.1946178038491627, 'session_frequent_clicks_pair': 0.6793752677131627, 'session_latest_clicks_pair': 0.8950658355526702, 'session_latest_carts_pair': 0.8570167395582541, 'session_latest_time_wt_pair': 0.26920353641552697, 'session_latest_clicks_carts_pair': 0.5740834746032135, 'session_latest_clicks_orders_pair': 0.354730266147257}. Best is trial 15 with value: 0.427.
# [I 2022-11-30 22:31:59,595] Trial 44 finished with value: 0.427 and parameters: {'session_frequent': 0.05600973059925829, 'session_latest': 0.49155433534592863, 'total_frequent': 0.6744564764731709, 'session_frequent_pair': 0.29156049581909876, 'session_latest_pair0': 0.6857156012060752, 'session_latest_pair1': 0.5104003772532106, 'session_latest_pair2': 0.3451427271307762, 'session_latest_pair3': 0.33536515891471, 'session_latest_pair4': 0.12617116858530075, 'session_frequent_clicks_pair': 0.9485386666512432, 'session_latest_clicks_pair': 0.934911138981135, 'session_latest_carts_pair': 0.6339850149108281, 'session_latest_time_wt_pair': 0.14031436857573076, 'session_latest_clicks_carts_pair': 0.6758709675288281, 'session_latest_clicks_orders_pair': 0.6363926673165873}. Best is trial 15 with value: 0.427.
# [I 2022-11-30 22:32:04,617] Trial 45 finished with value: 0.427 and parameters: {'session_frequent': 0.05986469924941076, 'session_latest': 0.48409682411067756, 'total_frequent': 0.6743904328919648, 'session_frequent_pair': 0.2915651679299251, 'session_latest_pair0': 0.710742370523578, 'session_latest_pair1': 0.5330535795049711, 'session_latest_pair2': 0.33684668247605654, 'session_latest_pair3': 0.3568889684155275, 'session_latest_pair4': 0.12434991837591682, 'session_frequent_clicks_pair': 0.8526260165431847, 'session_latest_clicks_pair': 0.9373829993107732, 'session_latest_carts_pair': 0.625717969751776, 'session_latest_time_wt_pair': 0.1225132049108463, 'session_latest_clicks_carts_pair': 0.8453956402262807, 'session_latest_clicks_orders_pair': 0.6570871903477307}. Best is trial 15 with value: 0.427.
# [I 2022-11-30 22:32:09,419] Trial 46 finished with value: 0.418 and parameters: {'session_frequent': 0.22829129527888184, 'session_latest': 0.3732260193334245, 'total_frequent': 0.5940542669773873, 'session_frequent_pair': 0.21421537239152189, 'session_latest_pair0': 0.7203437074680847, 'session_latest_pair1': 0.4565261858865438, 'session_latest_pair2': 0.33521340565749613, 'session_latest_pair3': 0.36290041314697946, 'session_latest_pair4': 0.11947810959201564, 'session_frequent_clicks_pair': 0.8182242520786913, 'session_latest_clicks_pair': 0.9472660002579927, 'session_latest_carts_pair': 0.5666455000191933, 'session_latest_time_wt_pair': 0.05653118610977133, 'session_latest_clicks_carts_pair': 0.8544171819132478, 'session_latest_clicks_orders_pair': 0.6321774433045959}. Best is trial 15 with value: 0.427.
# [I 2022-11-30 22:32:14,430] Trial 47 finished with value: 0.418 and parameters: {'session_frequent': 0.05939661024071587, 'session_latest': 0.4937554093927913, 'total_frequent': 0.680359193434287, 'session_frequent_pair': 0.2869950099598654, 'session_latest_pair0': 0.7050198263669464, 'session_latest_pair1': 0.6067977485131926, 'session_latest_pair2': 0.47054952734251765, 'session_latest_pair3': 0.15869202977044639, 'session_latest_pair4': 0.022847744433087666, 'session_frequent_clicks_pair': 0.8677338193883928, 'session_latest_clicks_pair': 0.930811034750201, 'session_latest_carts_pair': 0.4332127657441762, 'session_latest_time_wt_pair': 0.1359161234948185, 'session_latest_clicks_carts_pair': 0.9037305615963824, 'session_latest_clicks_orders_pair': 0.7425842326737975}. Best is trial 15 with value: 0.427.
# [I 2022-11-30 22:32:19,402] Trial 48 finished with value: 0.415 and parameters: {'session_frequent': 0.19109092499996358, 'session_latest': 0.48532241206479565, 'total_frequent': 0.5142819188762352, 'session_frequent_pair': 0.44131156980302555, 'session_latest_pair0': 0.8750697456093053, 'session_latest_pair1': 0.5342934766512933, 'session_latest_pair2': 0.38672620202876873, 'session_latest_pair3': 0.416020848993381, 'session_latest_pair4': 0.17861256175290618, 'session_frequent_clicks_pair': 0.7764485099009251, 'session_latest_clicks_pair': 0.997709839311127, 'session_latest_carts_pair': 0.5257644228785084, 'session_latest_time_wt_pair': 0.0020784443012231285, 'session_latest_clicks_carts_pair': 0.7926706542694208, 'session_latest_clicks_orders_pair': 0.6629448553190599}. Best is trial 15 with value: 0.427.
# [I 2022-11-30 22:32:24,349] Trial 49 finished with value: 0.426 and parameters: {'session_frequent': 0.12261319637293173, 'session_latest': 0.37313501999376375, 'total_frequent': 0.607978640993851, 'session_frequent_pair': 0.22056553751428212, 'session_latest_pair0': 0.7983651585103978, 'session_latest_pair1': 0.4903001775764118, 'session_latest_pair2': 0.40964514759212606, 'session_latest_pair3': 0.8924726982189386, 'session_latest_pair4': 0.7141185186610542, 'session_frequent_clicks_pair': 0.6669089686085192, 'session_latest_clicks_pair': 0.724005910038626, 'session_latest_carts_pair': 0.6519537292343565, 'session_latest_time_wt_pair': 0.17837994664233137, 'session_latest_clicks_carts_pair': 0.6983181128117406, 'session_latest_clicks_orders_pair': 0.5757992114841646}. Best is trial 15 with value: 0.427.
# [I 2022-11-30 22:32:29,135] Trial 50 finished with value: 0.413 and parameters: {'session_frequent': 0.05574105762374512, 'session_latest': 0.39201874027894235, 'total_frequent': 0.7798811302863049, 'session_frequent_pair': 0.5765387889863636, 'session_latest_pair0': 0.6828684756324666, 'session_latest_pair1': 0.27961280362328916, 'session_latest_pair2': 0.6086494026333209, 'session_latest_pair3': 0.3098527076019841, 'session_latest_pair4': 0.12343490508859811, 'session_frequent_clicks_pair': 0.7287518168734672, 'session_latest_clicks_pair': 0.8622705988071883, 'session_latest_carts_pair': 0.4486319536800232, 'session_latest_time_wt_pair': 0.37921135237065856, 'session_latest_clicks_carts_pair': 0.0033083600128237522, 'session_latest_clicks_orders_pair': 0.9979256780630332}. Best is trial 15 with value: 0.427.
# [I 2022-11-30 22:32:34,080] Trial 51 finished with value: 0.427 and parameters: {'session_frequent': 0.044933401073279304, 'session_latest': 0.5442309263467352, 'total_frequent': 0.840878886994068, 'session_frequent_pair': 0.38043360491215616, 'session_latest_pair0': 0.7520944102553528, 'session_latest_pair1': 0.42219434338849304, 'session_latest_pair2': 0.5647704499324038, 'session_latest_pair3': 0.45000355566299005, 'session_latest_pair4': 0.23886064974998034, 'session_frequent_clicks_pair': 0.9475254870310909, 'session_latest_clicks_pair': 0.9444365597548824, 'session_latest_carts_pair': 0.7667456773949118, 'session_latest_time_wt_pair': 0.1158516005307975, 'session_latest_clicks_carts_pair': 0.6053331235353752, 'session_latest_clicks_orders_pair': 0.44409051798428945}. Best is trial 15 with value: 0.427.
# [I 2022-11-30 22:32:39,170] Trial 52 finished with value: 0.423 and parameters: {'session_frequent': 0.05503216430080034, 'session_latest': 0.5626691971855391, 'total_frequent': 0.8483397168620401, 'session_frequent_pair': 0.29547096003518164, 'session_latest_pair0': 0.7527681654660897, 'session_latest_pair1': 0.43003706580585543, 'session_latest_pair2': 0.5554549944185859, 'session_latest_pair3': 0.4504501088773105, 'session_latest_pair4': 0.07153509087726073, 'session_frequent_clicks_pair': 0.9457057597597939, 'session_latest_clicks_pair': 0.9557305366384691, 'session_latest_carts_pair': 0.7184465970426542, 'session_latest_time_wt_pair': 0.11145388262973101, 'session_latest_clicks_carts_pair': 0.7421587282402597, 'session_latest_clicks_orders_pair': 0.42968669462189274}. Best is trial 15 with value: 0.427.
# [I 2022-11-30 22:32:44,165] Trial 53 finished with value: 0.421 and parameters: {'session_frequent': 0.16967640346150076, 'session_latest': 0.48192282172543716, 'total_frequent': 0.8975982244510574, 'session_frequent_pair': 0.405325727800627, 'session_latest_pair0': 0.8080675867980847, 'session_latest_pair1': 0.5865013359578195, 'session_latest_pair2': 0.34786700239582524, 'session_latest_pair3': 0.35405798629397117, 'session_latest_pair4': 0.15792305480225793, 'session_frequent_clicks_pair': 0.880389314844542, 'session_latest_clicks_pair': 0.9246870397872436, 'session_latest_carts_pair': 0.7633497830716607, 'session_latest_time_wt_pair': 0.04216001623654607, 'session_latest_clicks_carts_pair': 0.82455209973932, 'session_latest_clicks_orders_pair': 0.584676909664952}. Best is trial 15 with value: 0.427.
# [I 2022-11-30 22:32:49,214] Trial 54 finished with value: 0.428 and parameters: {'session_frequent': 0.1288547620458327, 'session_latest': 0.24830321575773234, 'total_frequent': 0.7227793764574809, 'session_frequent_pair': 0.47499655316451955, 'session_latest_pair0': 0.6280648911146486, 'session_latest_pair1': 0.47014197275002273, 'session_latest_pair2': 0.4884810654442218, 'session_latest_pair3': 0.39109681560577597, 'session_latest_pair4': 0.23999297980504505, 'session_frequent_clicks_pair': 0.09567603155275384, 'session_latest_clicks_pair': 0.855150439301764, 'session_latest_carts_pair': 0.6715234627472545, 'session_latest_time_wt_pair': 0.1523801430242092, 'session_latest_clicks_carts_pair': 0.6311574236861779, 'session_latest_clicks_orders_pair': 0.6467304016808947}. Best is trial 54 with value: 0.428.
# [I 2022-11-30 22:32:54,240] Trial 55 finished with value: 0.427 and parameters: {'session_frequent': 0.11469640638029718, 'session_latest': 0.23204537709834372, 'total_frequent': 0.684226548459021, 'session_frequent_pair': 0.46875266915197045, 'session_latest_pair0': 0.6277397968227735, 'session_latest_pair1': 0.6739879841163986, 'session_latest_pair2': 0.4829330212868636, 'session_latest_pair3': 0.261765617583784, 'session_latest_pair4': 0.2543368546637103, 'session_frequent_clicks_pair': 0.13020468036142244, 'session_latest_clicks_pair': 0.8573647848053756, 'session_latest_carts_pair': 0.6510431541645872, 'session_latest_time_wt_pair': 0.2992532915882221, 'session_latest_clicks_carts_pair': 0.9198268487214091, 'session_latest_clicks_orders_pair': 0.6722938939689336}. Best is trial 54 with value: 0.428.
# [I 2022-11-30 22:32:59,309] Trial 56 finished with value: 0.427 and parameters: {'session_frequent': 0.12438760262042697, 'session_latest': 0.22479899036963719, 'total_frequent': 0.5458412911844794, 'session_frequent_pair': 0.5990405671223835, 'session_latest_pair0': 0.6285756684717654, 'session_latest_pair1': 0.6512701857998323, 'session_latest_pair2': 0.28540452488813817, 'session_latest_pair3': 0.21114094834126831, 'session_latest_pair4': 0.2866478534946262, 'session_frequent_clicks_pair': 0.12029120346157071, 'session_latest_clicks_pair': 0.8578921993461606, 'session_latest_carts_pair': 0.6135404769420116, 'session_latest_time_wt_pair': 0.3075570893918971, 'session_latest_clicks_carts_pair': 0.9998517894801947, 'session_latest_clicks_orders_pair': 0.7797888496270817}. Best is trial 54 with value: 0.428.
# [I 2022-11-30 22:33:04,367] Trial 57 finished with value: 0.422 and parameters: {'session_frequent': 0.4288940391754879, 'session_latest': 0.2684173624744718, 'total_frequent': 0.543609379084024, 'session_frequent_pair': 0.7022995627097042, 'session_latest_pair0': 0.9242109475440116, 'session_latest_pair1': 0.5406138543365784, 'session_latest_pair2': 0.2749237864103622, 'session_latest_pair3': 0.19475869468810517, 'session_latest_pair4': 0.30836772337681595, 'session_frequent_clicks_pair': 0.05859360060571814, 'session_latest_clicks_pair': 0.9545733433715531, 'session_latest_carts_pair': 0.5981358560193629, 'session_latest_time_wt_pair': 0.13754861956078823, 'session_latest_clicks_carts_pair': 0.9659733123555825, 'session_latest_clicks_orders_pair': 0.8817732911580032}. Best is trial 54 with value: 0.428.
# ...
# [I 2022-11-30 22:51:55,824] Trial 81 finished with value: 0.528 and parameters: {'session_frequent': 0.008551527598442236, 'session_latest': 0.7893841225139608, 'total_frequent': 0.6864846027254283, 'session_frequent_pair': 0.7080877810005002, 'session_latest_pair0': 0.5590749927191808, 'session_latest_pair1': 0.21606742098487952, 'session_latest_pair2': 0.2086396287058212, 'session_latest_pair3': 0.3105672315014636, 'session_latest_pair4': 0.481908926661415, 'session_frequent_clicks_pair': 0.38222916700818166, 'session_latest_clicks_pair': 0.07393282141383839, 'session_latest_carts_pair': 0.4115719743690564, 'session_latest_time_wt_pair': 0.4666580279964002, 'session_latest_clicks_carts_pair': 0.23846155519805773, 'session_latest_clicks_orders_pair': 0.002101157805899548}. Best is trial 48 with value: 0.574.
# [I 2022-11-30 22:52:01,045] Trial 82 finished with value: 0.526 and parameters: {'session_frequent': 0.05274215987231932, 'session_latest': 0.43927667314884755, 'total_frequent': 0.3460287669530484, 'session_frequent_pair': 0.7691923073046967, 'session_latest_pair0': 0.6017944403568758, 'session_latest_pair1': 0.04000476565847083, 'session_latest_pair2': 0.7593465234054511, 'session_latest_pair3': 0.34499117127175316, 'session_latest_pair4': 0.7772553427563073, 'session_frequent_clicks_pair': 0.26880088972264904, 'session_latest_clicks_pair': 0.1248261924089688, 'session_latest_carts_pair': 0.7467664109779227, 'session_latest_time_wt_pair': 0.4166487045855682, 'session_latest_clicks_carts_pair': 0.17917451214526403, 'session_latest_clicks_orders_pair': 0.32528168813176406}. Best is trial 48 with value: 0.574.
# [I 2022-11-30 22:52:05,910] Trial 83 finished with value: 0.573 and parameters: {'session_frequent': 0.0011266642329456555, 'session_latest': 0.8173850480159229, 'total_frequent': 0.4741896870974343, 'session_frequent_pair': 0.6741702478784246, 'session_latest_pair0': 0.510034976257375, 'session_latest_pair1': 0.25589400895796754, 'session_latest_pair2': 0.5345752376004683, 'session_latest_pair3': 0.23286855403856643, 'session_latest_pair4': 0.5223422611202394, 'session_frequent_clicks_pair': 0.32874561265621666, 'session_latest_clicks_pair': 0.05287235956461579, 'session_latest_carts_pair': 0.3214635782908142, 'session_latest_time_wt_pair': 0.48116813144156156, 'session_latest_clicks_carts_pair': 0.41257930839719975, 'session_latest_clicks_orders_pair': 0.06997977672742667}. Best is trial 48 with value: 0.574.
# [I 2022-11-30 22:52:10,838] Trial 84 finished with value: 0.573 and parameters: {'session_frequent': 0.00011451751190368065, 'session_latest': 0.7448800861850718, 'total_frequent': 0.4595765689383873, 'session_frequent_pair': 0.6135337804201475, 'session_latest_pair0': 0.49528637448984153, 'session_latest_pair1': 0.510845572636393, 'session_latest_pair2': 0.5403403748482338, 'session_latest_pair3': 0.17487490691288493, 'session_latest_pair4': 0.09037347422307511, 'session_frequent_clicks_pair': 0.336828297111711, 'session_latest_clicks_pair': 0.10269649811510562, 'session_latest_carts_pair': 0.35798991542174224, 'session_latest_time_wt_pair': 0.5338068698061434, 'session_latest_clicks_carts_pair': 0.40820886788837657, 'session_latest_clicks_orders_pair': 0.041766166653336365}. Best is trial 48 with value: 0.574.
# [I 2022-11-30 22:52:15,811] Trial 85 finished with value: 0.533 and parameters: {'session_frequent': 0.027227784926505252, 'session_latest': 0.7389784765132082, 'total_frequent': 0.45451652234698153, 'session_frequent_pair': 0.6100283649949862, 'session_latest_pair0': 0.520568400338147, 'session_latest_pair1': 0.5037896502207073, 'session_latest_pair2': 0.5400317557025964, 'session_latest_pair3': 0.17091448987428962, 'session_latest_pair4': 0.0743528492114543, 'session_frequent_clicks_pair': 0.41421445541773727, 'session_latest_clicks_pair': 0.021699128703986617, 'session_latest_carts_pair': 0.34945026285461417, 'session_latest_time_wt_pair': 0.4853296310290656, 'session_latest_clicks_carts_pair': 0.3936513432229139, 'session_latest_clicks_orders_pair': 0.05747757764413274}. Best is trial 48 with value: 0.574.
# [I 2022-11-30 22:52:20,995] Trial 86 finished with value: 0.494 and parameters: {'session_frequent': 0.09594058620274068, 'session_latest': 0.5802501948717272, 'total_frequent': 0.4045705631181753, 'session_frequent_pair': 0.6566455269232857, 'session_latest_pair0': 0.47218300251809797, 'session_latest_pair1': 0.5660494141471927, 'session_latest_pair2': 0.4832637921760047, 'session_latest_pair3': 0.13771814232882873, 'session_latest_pair4': 0.11426124563825592, 'session_frequent_clicks_pair': 0.20425554008205135, 'session_latest_clicks_pair': 0.08834148792177687, 'session_latest_carts_pair': 0.3305239463951644, 'session_latest_time_wt_pair': 0.5398444191452174, 'session_latest_clicks_carts_pair': 0.4255681278105055, 'session_latest_clicks_orders_pair': 0.08625887417585654}. Best is trial 48 with value: 0.574.
# [I 2022-11-30 22:52:26,140] Trial 87 finished with value: 0.477 and parameters: {'session_frequent': 0.06987969563921914, 'session_latest': 0.8260186591246077, 'total_frequent': 0.4636065545546849, 'session_frequent_pair': 0.6188336565908916, 'session_latest_pair0': 0.5019618306676165, 'session_latest_pair1': 0.43328085335019373, 'session_latest_pair2': 0.6081522190389289, 'session_latest_pair3': 0.2106175049841227, 'session_latest_pair4': 0.1525615548251047, 'session_frequent_clicks_pair': 0.34103718494484037, 'session_latest_clicks_pair': 0.034782437530180496, 'session_latest_carts_pair': 0.3966926365664487, 'session_latest_time_wt_pair': 0.5049034632734529, 'session_latest_clicks_carts_pair': 0.4526999476711398, 'session_latest_clicks_orders_pair': 0.013751408837656305}. Best is trial 48 with value: 0.574.
# [I 2022-11-30 22:52:31,188] Trial 88 finished with value: 0.514 and parameters: {'session_frequent': 0.045631606421248666, 'session_latest': 0.753951466740787, 'total_frequent': 0.5255104144529155, 'session_frequent_pair': 0.5504974216497996, 'session_latest_pair0': 0.3248131192261195, 'session_latest_pair1': 0.4821369720008867, 'session_latest_pair2': 0.5310749594783868, 'session_latest_pair3': 0.07629399066705908, 'session_latest_pair4': 0.098519536111348, 'session_frequent_clicks_pair': 0.0414797590288577, 'session_latest_clicks_pair': 0.16478312233389691, 'session_latest_carts_pair': 0.4269882253511456, 'session_latest_time_wt_pair': 0.6944680259602585, 'session_latest_clicks_carts_pair': 0.3529541191466884, 'session_latest_clicks_orders_pair': 0.0354657814155259}. Best is trial 48 with value: 0.574.
# [I 2022-11-30 22:52:36,107] Trial 89 finished with value: 0.565 and parameters: {'session_frequent': 0.02662081877204167, 'session_latest': 0.8533095925827372, 'total_frequent': 0.43557374924419845, 'session_frequent_pair': 0.5937618729905432, 'session_latest_pair0': 0.405361296453076, 'session_latest_pair1': 0.6184189006574936, 'session_latest_pair2': 0.6539752527719326, 'session_latest_pair3': 0.12683819309271405, 'session_latest_pair4': 0.5232608370845279, 'session_frequent_clicks_pair': 0.16331930428916777, 'session_latest_clicks_pair': 0.3023795198690259, 'session_latest_carts_pair': 0.29088667247135896, 'session_latest_time_wt_pair': 0.5721510617494493, 'session_latest_clicks_carts_pair': 0.525438283952191, 'session_latest_clicks_orders_pair': 0.1595763987749985}. Best is trial 48 with value: 0.574.
# [I 2022-11-30 22:52:41,154] Trial 90 finished with value: 0.483 and parameters: {'session_frequent': 0.10039003316228103, 'session_latest': 0.6612061369350598, 'total_frequent': 0.3639741837656301, 'session_frequent_pair': 0.6749552006879125, 'session_latest_pair0': 0.5883281343609271, 'session_latest_pair1': 0.2844455308125199, 'session_latest_pair2': 0.5537248745960138, 'session_latest_pair3': 0.24406832816704174, 'session_latest_pair4': 0.036047755329052356, 'session_frequent_clicks_pair': 0.3070214255237627, 'session_latest_clicks_pair': 0.22337639915131283, 'session_latest_carts_pair': 0.3632561700818547, 'session_latest_time_wt_pair': 0.6575577236271947, 'session_latest_clicks_carts_pair': 0.4145402866914799, 'session_latest_clicks_orders_pair': 0.18470261084791162}. Best is trial 48 with value: 0.574.
# [I 2022-11-30 22:52:46,320] Trial 91 finished with value: 0.571 and parameters: {'session_frequent': 0.0031192233584834213, 'session_latest': 0.39995885070137677, 'total_frequent': 0.2736411837471583, 'session_frequent_pair': 0.7480932712331969, 'session_latest_pair0': 0.453784618335463, 'session_latest_pair1': 0.5216721277636034, 'session_latest_pair2': 0.590975855228356, 'session_latest_pair3': 0.28643853657371166, 'session_latest_pair4': 0.449386098408747, 'session_frequent_clicks_pair': 0.24192338169982336, 'session_latest_clicks_pair': 0.106585586902779, 'session_latest_carts_pair': 0.23412422449978515, 'session_latest_time_wt_pair': 0.5373565368974683, 'session_latest_clicks_carts_pair': 0.3712678918538828, 'session_latest_clicks_orders_pair': 0.24089307774077337}. Best is trial 48 with value: 0.574.
# [I 2022-11-30 22:52:51,409] Trial 92 finished with value: 0.535 and parameters: {'session_frequent': 0.05936193513217483, 'session_latest': 0.8031653162513708, 'total_frequent': 0.5042093722035754, 'session_frequent_pair': 0.6932605651454764, 'session_latest_pair0': 0.48754707453231483, 'session_latest_pair1': 0.23434206557196297, 'session_latest_pair2': 0.8976085817377975, 'session_latest_pair3': 0.3789694867545868, 'session_latest_pair4': 0.5790120961565206, 'session_frequent_clicks_pair': 0.36626674523918723, 'session_latest_clicks_pair': 0.05106656687533569, 'session_latest_carts_pair': 0.30400436092425925, 'session_latest_time_wt_pair': 0.4510468598690861, 'session_latest_clicks_carts_pair': 0.46986926308467386, 'session_latest_clicks_orders_pair': 0.36916132147574265}. Best is trial 48 with value: 0.574.
# [I 2022-11-30 22:52:56,555] Trial 93 finished with value: 0.566 and parameters: {'session_frequent': 0.02343206741702991, 'session_latest': 0.9241031145821378, 'total_frequent': 0.9395062610396961, 'session_frequent_pair': 0.7216901452283665, 'session_latest_pair0': 0.5573532009884953, 'session_latest_pair1': 0.4672034871832139, 'session_latest_pair2': 0.7909319365838119, 'session_latest_pair3': 0.1633188096027378, 'session_latest_pair4': 0.33103634034536, 'session_frequent_clicks_pair': 0.32045050592712465, 'session_latest_clicks_pair': 0.1694779261949179, 'session_latest_carts_pair': 0.17793965395293704, 'session_latest_time_wt_pair': 0.3890870209565772, 'session_latest_clicks_carts_pair': 0.31365692582101357, 'session_latest_clicks_orders_pair': 0.0785033694984308}. Best is trial 48 with value: 0.574.
# [I 2022-11-30 22:53:01,650] Trial 94 finished with value: 0.573 and parameters: {'session_frequent': 0.0030947808348038355, 'session_latest': 0.8869681056444848, 'total_frequent': 0.5561954354179927, 'session_frequent_pair': 0.802426588062666, 'session_latest_pair0': 0.849930094964545, 'session_latest_pair1': 0.41020789519633893, 'session_latest_pair2': 0.5137137971232455, 'session_latest_pair3': 0.3146876276832103, 'session_latest_pair4': 0.19016804864557899, 'session_frequent_clicks_pair': 0.4421129011789401, 'session_latest_clicks_pair': 0.13408908231726044, 'session_latest_carts_pair': 0.4408005541588655, 'session_latest_time_wt_pair': 0.3406313982002964, 'session_latest_clicks_carts_pair': 0.5805706517433499, 'session_latest_clicks_orders_pair': 0.12630720673005538}. Best is trial 48 with value: 0.574.
# [I 2022-11-30 22:53:06,701] Trial 95 finished with value: 0.516 and parameters: {'session_frequent': 0.04733242931731195, 'session_latest': 0.8666032257976776, 'total_frequent': 0.5514253675781229, 'session_frequent_pair': 0.8464782991789871, 'session_latest_pair0': 0.8636532880496113, 'session_latest_pair1': 0.3808682700899899, 'session_latest_pair2': 0.5148971292337226, 'session_latest_pair3': 0.32379792444487765, 'session_latest_pair4': 0.18972973541936644, 'session_frequent_clicks_pair': 0.9149557484568884, 'session_latest_clicks_pair': 0.1954577379570862, 'session_latest_carts_pair': 0.0034970764454830827, 'session_latest_time_wt_pair': 0.33200368195657914, 'session_latest_clicks_carts_pair': 0.5946715959555922, 'session_latest_clicks_orders_pair': 0.1597068150538321}. Best is trial 48 with value: 0.574.
# [I 2022-11-30 22:53:11,923] Trial 96 finished with value: 0.359 and parameters: {'session_frequent': 0.871792521654666, 'session_latest': 0.8197818373605084, 'total_frequent': 0.4827749693747178, 'session_frequent_pair': 0.5058304668718363, 'session_latest_pair0': 0.81225173423249, 'session_latest_pair1': 0.3296862615994913, 'session_latest_pair2': 0.43142927941654013, 'session_latest_pair3': 0.2640168564440753, 'session_latest_pair4': 0.2556784100975286, 'session_frequent_clicks_pair': 0.34888002950660174, 'session_latest_clicks_pair': 0.0029045376707686754, 'session_latest_carts_pair': 0.4382374304577161, 'session_latest_time_wt_pair': 0.27832919272442835, 'session_latest_clicks_carts_pair': 0.489048863596319, 'session_latest_clicks_orders_pair': 0.11775635454536369}. Best is trial 48 with value: 0.574.
# [I 2022-11-30 22:53:17,021] Trial 97 finished with value: 0.543 and parameters: {'session_frequent': 0.07362777654532225, 'session_latest': 0.7203007062560237, 'total_frequent': 0.9728177411550785, 'session_frequent_pair': 0.6363353888451339, 'session_latest_pair0': 0.9970022104350571, 'session_latest_pair1': 0.412650836294711, 'session_latest_pair2': 0.4716293899272421, 'session_latest_pair3': 0.7033915510951966, 'session_latest_pair4': 0.6154497063032649, 'session_frequent_clicks_pair': 0.5298704225190612, 'session_latest_clicks_pair': 0.09234241649800434, 'session_latest_carts_pair': 0.46959290017968996, 'session_latest_time_wt_pair': 0.3530333744525849, 'session_latest_clicks_carts_pair': 0.5815880373928649, 'session_latest_clicks_orders_pair': 0.13229172066224854}. Best is trial 48 with value: 0.574.
# [I 2022-11-30 22:53:21,974] Trial 98 finished with value: 0.553 and parameters: {'session_frequent': 0.02381767993557094, 'session_latest': 0.9534027341975037, 'total_frequent': 0.2917720681706169, 'session_frequent_pair': 0.828901045703401, 'session_latest_pair0': 0.4324042914225247, 'session_latest_pair1': 0.510954285742404, 'session_latest_pair2': 0.5562596443297654, 'session_latest_pair3': 0.20341602311699658, 'session_latest_pair4': 0.15188529229105413, 'session_frequent_clicks_pair': 0.4664042982038568, 'session_latest_clicks_pair': 0.6823994178690493, 'session_latest_carts_pair': 0.2611888681324636, 'session_latest_time_wt_pair': 0.4865247853564522, 'session_latest_clicks_carts_pair': 0.5328892034582953, 'session_latest_clicks_orders_pair': 0.025565157839038864}. Best is trial 48 with value: 0.574.
# [I 2022-11-30 22:53:27,079] Trial 99 finished with value: 0.571 and parameters: {'session_frequent': 0.0024085042193835826, 'session_latest': 0.6233768022614548, 'total_frequent': 0.41885836741908605, 'session_frequent_pair': 0.8055791870834886, 'session_latest_pair0': 0.8860624315965374, 'session_latest_pair1': 0.20643443225025485, 'session_latest_pair2': 0.627965780246075, 'session_latest_pair3': 0.3958496966054893, 'session_latest_pair4': 0.29164655507445447, 'session_frequent_clicks_pair': 0.4327726133629973, 'session_latest_clicks_pair': 0.126855891274339, 'session_latest_carts_pair': 0.3272306013843161, 'session_latest_time_wt_pair': 0.41072965978950804, 'session_latest_clicks_carts_pair': 0.7052631937378868, 'session_latest_clicks_orders_pair': 0.4566067879241083}. Best is trial 48 with value: 0.574.
# 0:25:59.005298 	 orders_recall_best_value : 0.574
# 0:25:59.006625 	 SCORE : 0.4888

# %% [markdown]
# # sub作成

# %%
test = make_test_data(trans_maps)
sub = pd.read_csv(cfg.input_dir + f"sample_submission.csv", usecols=["session_type"])
dfs = []

for type_ in ["clicks", "carts", "orders"]:
    test_type = test.copy()
    test_type["rank"] 
    test_type["rank"] = test_type["rank"] * test_type["strategy"].map(wt[type_])
    test_type = test_type.sort_values(["session", "rank"])
    test_type = test_type.drop_duplicates(subset= ["session", "aid"], keep="first")
    test_type = test_type.groupby(["session"]).head(20)
    test_type["aid"] = test_type["aid"].astype(str)
    test_type = test_type.groupby("session")["aid"].apply(list).reset_index()
    test_type["aid"] = test_type["aid"].apply(lambda x: ' '.join(x))
    test_type["session_type"] = test_type["session"].astype(str) + f"_{type_}"
    test_type =test_type.rename(columns={"aid": "labels"})
    dfs.append(test_type)
test_preds = pd.concat(dfs)

sub = sub.merge(test_preds, on="session_type", how="left")
sub[["session_type", "labels"]].to_csv(cfg.output_dir + f"{cfg.exp_name}/{cfg.exp_name}_sub.csv", index=False)
# Out:
# 0:26:00.032935 	 [make_test] make_cand_df
# 0:26:00.368773 	 [make_candidate] session_frequent : start
# 0:26:00.950101 	 [add_candidate] session_frequent : start
# 0:26:01.311306 	 [make_candidate] session_latest : start
# 0:26:01.630395 	 [add_candidate] session_latest : start
# 0:26:02.041737 	 [make_candidate] total_frequent : start
# 0:26:08.341118 	 [add_candidate] total_frequent : start
# 0:26:11.008232 	 [make_candidate] session_frequent_pair : start
# 0:26:11.870080 	 [add_candidate] session_frequent_pair : start
# 0:26:12.805248 	 [make_candidate] session_latest_pair0 : start
# 0:26:13.605464 	 [add_candidate] session_latest_pair0 : start
# 0:26:14.502327 	 [make_candidate] session_latest_pair1 : start
# 0:26:15.189831 	 [add_candidate] session_latest_pair1 : start
# 0:26:16.385031 	 [make_candidate] session_latest_pair2 : start
# 0:26:16.909922 	 [add_candidate] session_latest_pair2 : start
# 0:26:18.222529 	 [make_candidate] session_latest_pair3 : start
# 0:26:18.719599 	 [add_candidate] session_latest_pair3 : start
# 0:26:19.818053 	 [make_candidate] session_latest_pair4 : start
# 0:26:20.535959 	 [add_candidate] session_latest_pair4 : start
# 0:26:21.787330 	 [make_candidate] session_frequent_clicks_pair : start
# 0:26:22.533042 	 [add_candidate] session_frequent_clicks_pair : start
# 0:26:23.829484 	 [make_candidate] session_latest_clicks_pair : start
# 0:26:24.624165 	 [add_candidate] session_latest_clicks_pair : start
# 0:26:25.945275 	 [make_candidate] session_latest_carts_pair : start
# 0:26:26.666772 	 [add_candidate] session_latest_carts_pair : start
# 0:26:27.999440 	 [make_candidate] session_latest_time_wt_pair : start
# 0:26:28.879740 	 [add_candidate] session_latest_time_wt_pair : start
# 0:26:30.345324 	 [make_candidate] session_latest_clicks_carts_pair : start
# 0:26:31.172903 	 [add_candidate] session_latest_clicks_carts_pair : start
# 0:26:32.707552 	 [make_candidate] session_latest_clicks_orders_pair : start
# 0:26:33.542094 	 [add_candidate] session_latest_clicks_orders_pair : start

# %%
sub.head()
# Out:
#       session_type   session  \
# 0  12899779_clicks  12899779
# 1   12899779_carts  12899779
# 2  12899779_orders  12899779
# 3  12899780_clicks  12899780
# 4   12899780_carts  12899780
#
#                                               labels
# 0  59625 894169 737445 1130911 225209 1854910 485...
# 1  59625 894169 737445 1130911 1854910 225209 485...
# 2  59625 1130911 225209 737445 894169 1854910 485...
# 3  1142000 582732 636101 1502122 736515 973453 20...
# 4  1142000 736515 973453 582732 636101 1502122 48...
