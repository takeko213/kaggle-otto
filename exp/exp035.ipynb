# %% [markdown]
# # exp035
# trainをweek1 - week3に
# lrを0.01に

# %%
import os
import sys
import traceback
import gc
import random
import pickle
import pathlib
import subprocess
from dataclasses import dataclass
from dotenv import load_dotenv
load_dotenv
sys.path.append(os.getenv('UTILS_PATH'))
from tqdm import tqdm
import multiprocessing
import inspect

import pandas as pd
import numpy as np
import itertools
import cudf
import lightgbm as lgb
import matplotlib.pyplot as plt
import seaborn as sns
import line_notify
import my_logger
from noglobal import noglobal

# %% [markdown]
# # 設定

# %%
@dataclass
class Cfg:
    loglevel = "INFO"
    exp_name = "exp035"
    seed = 42
    k = 20
    cand_n = 10
    negative_sample = 1
    type2id = {"clicks":0, "carts":1, "orders":2}
    id2type = {0:"clicks", 1:"carts", 2:"orders"}
    train_weeks = ["week1", "week2", "week3"]
    valid_week = "week4"
    valid_session_n = 100_000
    input_dir = os.getenv('INPUT_DIR')
    output_dir = os.getenv('OUTPUT_DIR')
    prep_dir = os.getenv("PREP_DIR")

cfg = Cfg()
os.makedirs(os.path.join(cfg.output_dir, cfg.exp_name), exist_ok=True)
os.makedirs(os.path.join(cfg.output_dir, cfg.exp_name, "cache"), exist_ok=True)
random.seed(cfg.seed)

logger = my_logger.init_logger(cfg.exp_name)

# %%
class Cache:
    @noglobal(excepts=["cfg", "logger"])
    def __init__(self):
        self.cache_dir = (os.path.join(cfg.output_dir, cfg.exp_name, "cache"))
        self.cache_dir_path = pathlib.Path(self.cache_dir)
        self.caches = list(self.cache_dir_path.glob("*.pkl"))

    @noglobal(excepts=["cfg", "logger"])
    def get_abspath(self, filename):
        return (os.path.join(self.cache_dir, filename))
    
    @noglobal(excepts=["cfg", "logger"])
    def exists(self, path):
        return len([str(c) for c in self.caches if path == str(c)]) > 0


cache = Cache()

# %%
def reduce_mem_usage(df):
    """ iterate through all the columns of a dataframe and modify the data type
        to reduce memory usage.        
    """
    start_mem = df.memory_usage().sum() / 1024**2
    print('Memory usage of dataframe is {:.2f} MB'.format(start_mem))
    
    for col in df.columns:
        col_type = df[col].dtype
        
        if col_type != object:
            c_min = df[col].min()
            c_max = df[col].max()
            if str(col_type)[:3] == 'int':
                if c_min > np.iinfo(np.int8).min and c_max < np.iinfo(np.int8).max:
                    df[col] = df[col].astype(np.int8)
                elif c_min > np.iinfo(np.int16).min and c_max < np.iinfo(np.int16).max:
                    df[col] = df[col].astype(np.int16)
                elif c_min > np.iinfo(np.int32).min and c_max < np.iinfo(np.int32).max:
                    df[col] = df[col].astype(np.int32)
                elif c_min > np.iinfo(np.int64).min and c_max < np.iinfo(np.int64).max:
                    df[col] = df[col].astype(np.int64)  
            else:
                if c_min > np.finfo(np.float16).min and c_max < np.finfo(np.float16).max:
                    df[col] = df[col].astype(np.float16)
                elif c_min > np.finfo(np.float32).min and c_max < np.finfo(np.float32).max:
                    df[col] = df[col].astype(np.float32)
                else:
                    df[col] = df[col].astype(np.float64)
        else:
            df[col] = df[col].astype('category')

    end_mem = df.memory_usage().sum() / 1024**2
    print('Memory usage after optimization is: {:.2f} MB'.format(end_mem))
    print('Decreased by {:.1f}%'.format(100 * (start_mem - end_mem) / start_mem))
    
    return df

# %%
@noglobal(excepts=["cfg", "logger"])
def evaluate(clicks_labels, carts_labels, orders_labels, 
             clicks_preds, carts_preds, orders_preds, k=20):

    num_clicks = 0
    num_carts = 0
    num_orders = 0
    hit_clicks = 0
    hit_carts = 0
    hit_orders = 0

    for i in range(len(clicks_labels)):
        clicks_label = clicks_labels[i]
        carts_label = carts_labels[i]
        orders_label = orders_labels[i]
        clicks_pred = clicks_preds[i]
        carts_pred = carts_preds[i]
        orders_pred = orders_preds[i]

        if type(clicks_pred) == list:
            clicks_pred = clicks_pred[:k]
        else:
            clicks_pred = []
        if type(carts_pred) == list:
            carts_pred = carts_pred[:k]
        else:
            carts_pred = []    
        if type(orders_pred) == list:
            orders_pred = orders_pred[:k]
        else:
            orders_pred = []

        if not np.isnan(clicks_label):
            num_clicks += 1
            hit_clicks += int(clicks_label in clicks_pred)

        if type(carts_label) == list:
            num_carts += min(len(carts_label), k)
            hit_carts += len(set(carts_pred) & set(carts_label))
            
        if type(orders_label) == list:
            num_orders += min(len(orders_label), k)
            hit_orders += len(set(orders_pred) & set(orders_label))


    recall_clicks = hit_clicks / num_clicks
    recall_carts = hit_carts / num_carts
    recall_orders = hit_orders / num_orders
    w_recall_clicks = recall_clicks * 0.10
    w_recall_carts = recall_carts * 0.30
    w_recall_orders = recall_orders * 0.60
    score = w_recall_clicks + w_recall_carts + w_recall_orders

    results = {}
    results["num_clicks"] = num_clicks
    results["hit_clicks"] = hit_clicks
    results["num_carts"] = num_carts
    results["hit_carts"] = hit_carts
    results["num_orders"] = num_orders
    results["hit_orders"] = hit_orders
    results["recall_clicks"] = format(recall_clicks, ".3f")
    results["recall_carts"] = format(recall_carts, ".3f")
    results["recall_orders"] = format(recall_orders, ".3f")
    results["w_recall_clicks"] = format(w_recall_clicks, ".3f")
    results["w_recall_carts"] = format(w_recall_carts, ".3f")
    results["w_recall_orders"] = format(w_recall_orders, ".3f")
    results["score"] = format(score, ".3f")

    return results

# %%
class Candidate:
    @noglobal(excepts=["cfg", "logger"])
    def __init__(self, pdf, labels=None):
        self.df = cudf.from_pandas(pdf)
        self.target_sessions = pdf["session"].unique().tolist()
        self.results = pd.DataFrame(columns=["name", "num_clicks", "hit_clicks", "num_carts", "hit_carts", "num_orders", "hit_orders", 
                                             "recall_clicks", "recall_carts", "recall_orders", "w_recall_clicks", "w_recall_carts", "w_recall_orders", "score"])
        self.output = pd.DataFrame(columns=["session", "aid"], dtype=int)
        self.labels = labels
    
    @noglobal(excepts=["cfg", "logger"])
    def _entry(self, new_candidate_df, name, k):
        logger.info(f"[add_candidate] {name} : start")
        new_candidate_df[f"{name}_rank"] = new_candidate_df.groupby("session")["session"].cumcount()
        new_candidate_df = new_candidate_df.to_pandas()
        self.output = pd.concat([self.output, new_candidate_df[["session", "aid"]]])
        self.output = self.output.drop_duplicates(subset=["session", "aid"])
        
        self.output = self.output.merge(new_candidate_df, on=["session", "aid"], how="left")

        if self.labels is not None:
            self._eval(new_candidate_df[["session", "aid"]], name, k)
    
    @noglobal(excepts=["cfg", "logger"])
    def _eval(self, new_candidate_df, name, k):
        new_candidate_df = new_candidate_df.groupby("session")["aid"].apply(list).reset_index()
        eval_df = pd.DataFrame(self.target_sessions, columns=["session"])
        eval_df = eval_df.merge(new_candidate_df, on=["session"], how="left")
        assert eval_df["session"].tolist() == self.labels["session"].tolist()
        eval_result = evaluate(self.labels["clicks_labels"].tolist(), self.labels["carts_labels"].tolist(), self.labels["orders_labels"].tolist(),
                               eval_df["aid"].tolist(), eval_df["aid"].tolist(), eval_df["aid"].tolist(), k)
        
        print(eval_result)
        self.results = pd.concat([self.results, pd.DataFrame([[name] + list(eval_result.values())], columns=["name"] + list(eval_result.keys()))])

    @noglobal(excepts=["cfg", "logger"])
    def add(self, strategy, name, usetypes=['clicks', 'carts', 'orders'], trans_map=None, k=20):
        logger.info(f"[make_candidate] {name} : start")
        candidate_df = self.df[self.df["type"].isin(usetypes)].copy()
        
        if strategy == "session_frequent":
            candidate_df = self._session_frequent(candidate_df, k)
        elif strategy == "session_latest":
            candidate_df = self._session_latest(candidate_df, k)
        elif strategy == "total_frequent":
            candidate_df = self._total_frequent(candidate_df, k)
        
        if trans_map is not None:
            candidate_df["aid"] = candidate_df["aid"].map(trans_map)
            candidate_df = candidate_df.dropna(subset=["aid"])
            
        self._entry(candidate_df, name, k)

    @noglobal(excepts=["cfg", "logger"])
    def _session_frequent(self, candidate_df, k):
        candidate_df = candidate_df.groupby(["session", "aid"])["ts"].count().reset_index()
        candidate_df.columns = ["session", "aid", "aid_count"]
        candidate_df = candidate_df.sort_values(["session", "aid_count", "aid"], ascending=(True, False, True))
        candidate_df = candidate_df[candidate_df.groupby("session")["aid_count"].cumcount() < k].copy()
        candidate_df = candidate_df[["session", "aid"]].copy()
        return candidate_df

    @noglobal(excepts=["cfg", "logger"])
    def _session_latest(self, candidate_df, k):
        candidate_df = candidate_df.sort_values(["session", "ts"], ascending=(True, False)).drop_duplicates(subset=["session", "aid"])
        candidate_df = candidate_df.sort_values(["session", "ts"], ascending=(True, False))[candidate_df.groupby("session")["ts"].cumcount() < k].copy()
        candidate_df = candidate_df[["session", "aid"]].copy()
        return candidate_df

    @noglobal(excepts=["cfg", "logger"])
    def _total_frequent(self, candidate_df, k):
        candidate_df = candidate_df.groupby("aid")["ts"].count().reset_index()
        candidate_df.columns = ["aid", "aid_count"]
        topk_freq_aids = candidate_df.sort_values("aid_count", ascending=False)["aid"].to_arrow().to_pylist()[:k]
        sessions = []
        aids = []
        for session, aid in itertools.product(self.target_sessions, topk_freq_aids):
            sessions.append(session)
            aids.append(aid)
        candidate_df = cudf.DataFrame({"session": sessions, "aid": aids})
        return candidate_df

# %%
@noglobal(excepts=["cfg", "logger"])
def add_labels(df, labels, type_):
    type_labels = labels[["session", f"{type_}_labels"]].dropna().copy()
    type_labels.columns = ["session", "aid"]
    type_labels = type_labels.explode("aid")
    type_labels["labels"] = 1
    df = df.merge(type_labels, on=["session", "aid"], how="left")
    df["labels"] = df["labels"].fillna(0)
    return df

# %%
@noglobal(excepts=["cfg", "logger"])
def add_ground_truth_candidate(df, labels, type_):
    gt = labels[["session", f"{type_}_labels"]].dropna().copy()
    gt.columns = ["session", "aid"]
    gt = gt.explode("aid")
    df = pd.concat([df, gt])
    df = df.drop_duplicates()
    return df

# %%
@noglobal(excepts=["cfg", "logger"])
def under_sampling(df, label_col):
    cfg = Cfg()
    pos_df = df[df[label_col]==1].copy()
    neg_df = df[df[label_col]==0].copy()
    pos_n = len(pos_df)
    return pd.concat([pos_df, neg_df.sample(pos_n * cfg.negative_sample, random_state=cfg.seed)])

# %%
class Features:
    @noglobal(excepts=["cfg", "logger"])
    def __init__(self, sessions, candidate):
        self.sessions = cudf.from_pandas(sessions)
        self.output = candidate
        self.type_dict = cfg.type2id

    @noglobal(excepts=["cfg", "logger"])
    def add_features(self):
            self._prep()
            self._session_cnt()
            self._session_aid_nunique()
            self._session_last_type()
            # self._session_last_dt()
            self._aid_cnt()
            # self._session_mean_ts()
            # self._aid_mean_ts()
            # self._aid_cnt_ratio_at_session_last()
            # self.output = self.output.drop(columns=["session_last_day"]) # 日時はtrainセット内のみで有効なので削除

    @noglobal(excepts=["cfg", "logger"])
    def _prep(self):
        logger.info("[features] prep : start")
        # ts関連の前処理
        self.sessions["relative_ts"] = self.sessions["ts"] - self.sessions["ts"].min()
        self.sessions["dt"] = cudf.to_datetime(self.sessions["ts"], unit="ms")
        self.sessions["hour"] = self.sessions["dt"].dt.hour
        self.sessions["week"] = self.sessions["dt"].dt.dayofweek
        self.sessions["day"] = self.sessions["dt"].dt.day
        
    @noglobal(excepts=["cfg", "logger"])
    def _session_cnt(self):
        logger.info("[features] session_cnt : start")
        agg_df = self.sessions.groupby(["session", "type"])["ts"].count().reset_index().rename(columns={"ts": "cnt"})
        # session_total_cnt
        features = agg_df.groupby("session")["cnt"].sum().reset_index().rename(columns={"cnt": "session_total_cnt"})
        self.output = self.output.merge(features.to_pandas(), on=["session"], how="left")
        self.output["session_total_cnt"] = self.output["session_total_cnt"].fillna(0)
        # session_{type}_cnt
        for type_ in ["clicks", "carts", "orders"]:
            col_name = f"session_{type_}_cnt"
            features = agg_df[agg_df["type"]==type_].copy()
            features = features.rename(columns={"cnt": col_name})
            features = features[["session", col_name]].copy()
            self.output = self.output.merge(features.to_pandas(), on=["session"], how="left")
            self.output[col_name] = self.output[col_name].fillna(0)
        
    @noglobal(excepts=["cfg", "logger"])
    def _session_aid_nunique(self):
        logger.info("[features] session_aid_nunique : start")
        features = self.sessions.groupby("session")["aid"].nunique().reset_index().rename(columns={"aid": "session_aid_nunique"})
        self.output = self.output.merge(features.to_pandas(), on=["session"], how="left")
        self.output["session_aid_nunique"] = self.output["session_aid_nunique"].fillna(0)
        
    @noglobal(excepts=["cfg", "logger"])
    def _session_last_type(self):
        logger.info("[features] session_last_type : start")
        features = self.sessions.groupby("session").nth(-1).reset_index()[["session", "type"]]
        features = features.rename(columns={"type": "session_last_type"})
        features["session_last_type"] = features["session_last_type"].map(self.type_dict)
        self.output = self.output.merge(features.to_pandas(), on=["session"], how="left")
        
    @noglobal(excepts=["cfg", "logger"])
    def _session_last_dt(self):
        logger.info("[features] session_last_dt : start")
        features = self.sessions.groupby("session").nth(-1).reset_index()[["session", "relative_ts", "week", "day", "hour"]]
        features.columns = ["session", "session_last_ts", "session_last_week", "session_last_day", "session_last_hour"]
        self.output = self.output.merge(features.to_pandas(), on=["session"], how="left")
        
    @noglobal(excepts=["cfg", "logger"])
    def _session_mean_ts(self):
        logger.info("[features] session_mean_ts : start")
        features = self.sessions.groupby("session")["relative_ts"].mean().reset_index().rename(columns={"relative_ts": "session_mean_ts"})
        self.output = self.output.merge(features.to_pandas(), on=["session"], how="left")
        
    @noglobal(excepts=["cfg", "logger"])
    def _aid_mean_ts(self):
        logger.info("[features] aid_mean_ts : start")
        features = self.sessions.groupby("aid")["relative_ts"].mean().reset_index().rename(columns={"relative_ts": "aid_mean_ts"})
        self.output = self.output.merge(features.to_pandas(), on=["aid"], how="left")
       
    @noglobal(excepts=["cfg", "logger"])
    def _aid_session_nunique(self):
        logger.info("[features] aid_session_unique : start")
        features = self.sessions.groupby("aid")["session"].nunique().reset_index().rename(columns={"session": "aid_session_nunique"})
        self.output = self.output.merge(features.to_pandas(), on=["aid"], how="left")

    @noglobal(excepts=["cfg", "logger"]) 
    def _aid_cnt_ratio_at_session_last(self):
        logger.info("[features] aid_cnt_ratio_atsession_last : start")
        for dt_ in ["week", "day", "hour"]:
            features = self.sessions[["aid", dt_]].copy()
            features["total_cnt"] = features.groupby(dt_)["aid"].transform("count")
            features = features.groupby(["aid", dt_])["total_cnt"].agg(["count", "max"]).reset_index()
            features[f"aid_cnt_ratio_at_session_last_{dt_}"] = features["count"] / features["max"]
            features = features.rename(columns={dt_: f"session_last_{dt_}"})
            self.output = self.output.merge(features[["aid", f"session_last_{dt_}", f"aid_cnt_ratio_at_session_last_{dt_}"]].to_pandas(), on=["aid", f"session_last_{dt_}"], how="left")
            self.output[f"aid_cnt_ratio_at_session_last_{dt_}"] = self.output[f"aid_cnt_ratio_at_session_last_{dt_}"].fillna(0)
        
    @noglobal(excepts=["cfg", "logger"])
    def _aid_cnt(self):
        logger.info("[features] aid_cnt : start")
        agg_df = self.sessions.groupby(["session", "aid", "type"])["ts"].count().reset_index().rename(columns={"ts": "cnt"})

        # aid_total_cnt
        features = agg_df.groupby(["session", "aid"])["cnt"].sum().reset_index().rename(columns={"cnt": "aid_total_cnt"})
        self.output = self.output.merge(features.to_pandas(), on=["session", "aid"], how="left")
        self.output["aid_total_cnt"] = self.output["aid_total_cnt"].fillna(0)

        # aid_{type}_cnt
        for type_ in ["clicks", "carts", "orders"]:
            col_name = f"aid_{type_}_cnt"
            features = agg_df[agg_df["type"]==type_].copy()
            features = features.rename(columns={"cnt": col_name})
            features = features[["session", "aid", col_name]].copy()
            self.output = self.output.merge(features.to_pandas(), on=["session", "aid"], how="left")
            self.output[col_name] = self.output[col_name].fillna(0)

# %%
@noglobal(excepts=["cfg", "logger"])
def add_features(sessions, cand_df):
    feat = Features(sessions, cand_df)
    feat.add_features()
    return feat.output

# %%
@noglobal(excepts=["cfg", "logger"])
def make_cand_df(sessions, labels=None, trans_maps=None):

    if labels is not None:
         cand = Candidate(sessions, labels)
    else:
        cand = Candidate(sessions)

    cand.add(strategy="session_frequent", name="session_frequent", k=cfg.cand_n)
    cand.add(strategy="session_latest", name="session_latest", k=cfg.cand_n)
    # cand.add(strategy="total_frequent", name="total_frequent", k=cfg.cand_n)
    cand.add(strategy="session_frequent", trans_map=trans_maps["pair0"], name="session_frequent_pair", k=cfg.cand_n)
    
    for i in range(10):
        cand.add(strategy="session_latest", trans_map=trans_maps[f"pair{str(i)}"], name=f"session_latest_pair{str(i)}", k=cfg.cand_n)
    
    for i in range(10):
        cand.add(strategy="session_latest", trans_map=trans_maps[f"time_wt_pair{str(i)}"], name=f"session_latest_time_wt_pair{str(i)}", k=cfg.cand_n)
    
    cand.add(strategy="session_latest", trans_map=trans_maps["type_wt_pair"], name="session_latest_type_wt_pair", k=cfg.cand_n)
    cand.add(strategy="session_latest", trans_map=trans_maps["clicks2carts_pair"], name="session_latest_clicks2carts_pair", k=cfg.cand_n)
    cand.add(strategy="session_latest", trans_map=trans_maps["clicks2orders_pair"], name="session_latest_clicks2orders_pair", k=cfg.cand_n)
    if labels is not None:
        return cand.output, cand.results
    else:
        return cand.output

# %%
@noglobal(excepts=["cfg", "logger"])
def get_trans_maps():
    """
    aidを別のaidに置き換えるmapping辞書を取得する
    """
    trans_maps = {}

    pair_df_org = pd.read_pickle(cfg.prep_dir + "co_visitation_matrix_v5.pkl")
    pair_df_org = pair_df_org[pair_df_org["cnt"] > 3].copy()
    pair_df_org = pair_df_org.sort_values(["aid_x", "cnt"], ascending=(True, False))
    for i in range(10):
        pair_df = pair_df_org.groupby("aid_x").nth(i).reset_index()[["aid_x", "aid_y"]]
        pair_dict = {k: v for k, v in zip(pair_df["aid_x"].tolist(), pair_df["aid_y"].tolist())}
        trans_maps[f"pair{str(i)}"] = pair_dict

    pair_df = pd.read_pickle(cfg.prep_dir + "co_visitation_matrix_clicks.pkl")
    pair_df = pair_df[pair_df["cnt"] > 3].copy()
    pair_df = pair_df.sort_values(["aid_x", "cnt"], ascending=(True, False))
    pair_df = pair_df.groupby("aid_x").head(1)[["aid_x", "aid_y"]]
    pair_dict = {k: v for k, v in zip(pair_df["aid_x"].tolist(), pair_df["aid_y"].tolist())}
    trans_maps["clicks_pair"] = pair_dict

    pair_df = pd.read_pickle(cfg.prep_dir + "co_visitation_matrix_carts.pkl")
    pair_df = pair_df[pair_df["cnt"] > 3].copy()
    pair_df = pair_df.sort_values(["aid_x", "cnt"], ascending=(True, False))
    pair_df = pair_df.groupby("aid_x").head(1)[["aid_x", "aid_y"]]
    pair_dict = {k: v for k, v in zip(pair_df["aid_x"].tolist(), pair_df["aid_y"].tolist())}
    trans_maps["carts_pair"] = pair_dict

    pair_df = pd.read_pickle(cfg.prep_dir + "co_visitation_matrix_orders.pkl")
    pair_df = pair_df[pair_df["cnt"] > 3].copy()
    pair_df = pair_df.sort_values(["aid_x", "cnt"], ascending=(True, False))
    pair_df = pair_df.groupby("aid_x").head(1)[["aid_x", "aid_y"]]
    pair_dict = {k: v for k, v in zip(pair_df["aid_x"].tolist(), pair_df["aid_y"].tolist())}
    trans_maps["orders_pair"] = pair_dict

    pair_df_org = pd.read_pickle(cfg.prep_dir + "co_visitation_matrix_time_weighted_v2.pkl")
    pair_df_org = pair_df_org.sort_values(["aid_x", "wt"], ascending=(True, False))
    for i in range(10):
        pair_df = pair_df_org.groupby("aid_x").nth(i).reset_index()[["aid_x", "aid_y"]]
        pair_dict = {k: v for k, v in zip(pair_df["aid_x"].tolist(), pair_df["aid_y"].tolist())}
        trans_maps[f"time_wt_pair{str(i)}"] = pair_dict

    pair_df = pd.read_pickle(cfg.prep_dir + "co_visitation_matrix_type_weighted.pkl")
    pair_df = pair_df.sort_values(["aid_x", "wt"], ascending=(True, False))
    pair_df = pair_df.groupby("aid_x").head(1)[["aid_x", "aid_y"]]
    pair_dict = {k: v for k, v in zip(pair_df["aid_x"].tolist(), pair_df["aid_y"].tolist())}
    trans_maps["type_wt_pair"] = pair_dict

    pair_df = pd.read_pickle(cfg.prep_dir + "co_visitation_matrix_clicks2carts.pkl")
    pair_df = pair_df.sort_values(["aid_x", "cnt"], ascending=(True, False))
    pair_df = pair_df.groupby("aid_x").head(1)[["aid_x", "aid_y"]]
    pair_dict = {k: v for k, v in zip(pair_df["aid_x"].tolist(), pair_df["aid_y"].tolist())}
    trans_maps["clicks2carts_pair"] = pair_dict

    pair_df = pd.read_pickle(cfg.prep_dir + "co_visitation_matrix_clicks2orders.pkl")
    pair_df = pair_df.sort_values(["aid_x", "cnt"], ascending=(True, False))
    pair_df = pair_df.groupby("aid_x").head(1)[["aid_x", "aid_y"]]
    pair_dict = {k: v for k, v in zip(pair_df["aid_x"].tolist(), pair_df["aid_y"].tolist())}
    trans_maps["clicks2orders_pair"] = pair_dict

    return trans_maps

# %%
@noglobal(excepts=["cfg", "logger", "cache"])
def make_train_data(trans_maps, type_):
    dfs = []
    for weeks in cfg.train_weeks:
        # データ読み込み
        week_sessions = pd.read_pickle(cfg.prep_dir + f"train_sessions_{weeks}.pkl")
        week_labels = pd.read_pickle(cfg.prep_dir + f"labels_{weeks}.pkl")
        
        cache_file = f"train_cand_{weeks}.pkl"
        cache_path = cache.get_abspath(cache_file)
        print(cache_path)
        if cache.exists(cache_path):
            logger.info(f"[{cache_file}] cache exists. read cache and skip process.")
            cand_df = pd.read_pickle(cache_path)
        else:
            # 候補選出
            cand_df = make_cand_df(week_sessions, trans_maps=trans_maps)
            cand_df = reduce_mem_usage(cand_df)
            cand_df.to_pickle(cache_path)

        cand_df = add_labels(cand_df, week_labels, type_)
        cand_df = under_sampling(cand_df, "labels")

        # 特徴量付与
        train_tmp = add_features(week_sessions, cand_df)
        dfs.append(train_tmp)
        del cand_df, train_tmp
        gc.collect()
        
    train = pd.concat(dfs)
    train = train.reset_index(drop=True)
    train = reduce_mem_usage(train)
    
    return train

# %%
@noglobal(excepts=["cfg", "logger"])
def make_valid_cand(trans_maps):
    valid_week = cfg.valid_week
    # データ読み込み
    week_sessions = pd.read_pickle(os.getenv("PREP_DIR") + f"train_sessions_{valid_week}.pkl")
    week_labels = pd.read_pickle(os.getenv("PREP_DIR") + f"labels_{valid_week}.pkl")
    valid_session_ids = week_sessions["session"].unique().tolist()

    # validに使うsessionを絞る
    valid_session_n = min(cfg.valid_session_n, len(valid_session_ids))
    random.seed(cfg.seed)
    valid_session_ids = random.sample(valid_session_ids, valid_session_n)
    week_sessions = week_sessions[week_sessions["session"].isin(valid_session_ids)].copy()
    week_labels = week_labels[week_labels["session"].isin(valid_session_ids)].copy()

    # 候補選出
    cand_df = make_cand_df(week_sessions, trans_maps=trans_maps)
    cand_df = reduce_mem_usage(cand_df)
    return cand_df, week_sessions, week_labels

# %%
@noglobal(excepts=["cfg", "logger"])
def make_valid_data(cand_df, week_sessions, week_labels, type_):
    # 特徴量付与
    valid = add_features(week_sessions, cand_df)
    valid = add_labels(valid, week_labels, type_)
    valid = valid.reset_index(drop=True)
    valid = reduce_mem_usage(valid)
    return valid

# %%
@noglobal(excepts=["cfg", "logger"])
def model_training(train, valid, features, target, valid_labels, type_):
    params = {'objective': 'binary', 
            'boosting': 'gbdt', 
            'learning_rate': 0.01, 
            'metric': 'binary_logloss', 
            'seed': cfg.seed
            }

    # 学習
    vl_pred_df = valid[["session", "aid"]].copy()

    tr_x, tr_y = train[features], train[target]
    vl_x, vl_y = valid[features], valid[target]
    tr_data = lgb.Dataset(tr_x, label=tr_y)
    vl_data = lgb.Dataset(vl_x, label=vl_y)

    model = lgb.train(params, tr_data, valid_sets=[tr_data, vl_data],
                      num_boost_round=2000000, early_stopping_rounds=100, verbose_eval=100)

    # 特徴量重要度
    fi = pd.DataFrame()
    fi["feature"] = model.feature_name()
    fi["importance"] = model.feature_importance(importance_type="gain")

    # 2値分類の出力を元にk個選定
    vl_pred_df["prob"] = model.predict(vl_x, num_iteration=model.best_iteration)
    vl_pred_df = vl_pred_df.sort_values(["session", "prob"], ascending=(True, False))
    vl_pred_df = vl_pred_df.groupby(["session"]).head(cfg.k)
    vl_pred_df = vl_pred_df.groupby(["session"])["aid"].apply(list).reset_index()
    
    # 評価
    assert valid_labels["session"].tolist() == vl_pred_df["session"].unique().tolist()
    score = evaluate(valid_labels["clicks_labels"].tolist(),
                     valid_labels["carts_labels"].tolist(),
                     valid_labels["orders_labels"].tolist(),
                     vl_pred_df["aid"].tolist(),
                     vl_pred_df["aid"].tolist(),
                     vl_pred_df["aid"].tolist(),
                     cfg.k)
    logger.info(f"{type_} valid score")
    logger.info(score)

    # モデル保存
    model.save_model(cfg.output_dir + f"{cfg.exp_name}/{type_}_model.lgb")

    # 特徴量重要度
    fi_n = fi['feature'].nunique()
    order = list(fi.groupby("feature").mean().sort_values("importance", ascending=False).index)
    plt.figure(figsize=(10, fi_n*0.2))
    sns.barplot(x="importance", y="feature", data=fi, order=order)
    plt.title(f"LGBM importance({type_})")
    plt.tight_layout()
    plt.savefig(cfg.output_dir + f'{cfg.exp_name}/lgbm_importance_{type_}.png')

    return score[f"recall_{type_}"]

# %%
@noglobal(excepts=["cfg", "logger"])
def make_test_data(trans_maps):
    # testデータ作成
    test_sessions = pd.read_pickle(cfg.prep_dir + f"test_sessions.pkl")

    dfs =[]
    # 候補選出
    logger.info("[make_test] make_cand_df")
    cand_df = make_cand_df(test_sessions, trans_maps=trans_maps)
    cand_df = reduce_mem_usage(cand_df)
    # 特徴量付与
    logger.info("[make_test] add_features")
    test = add_features(test_sessions, cand_df)
    test = reduce_mem_usage(test)

    return test

# %%
@noglobal(excepts=["cfg", "logger"])
def inference(test, features):
    pred_dfs = []
    for type_ in ["clicks", "carts", "orders"]:
        pred_df_tmp = test[["session", "aid"]].copy()
        # 推論
        model = lgb.Booster(model_file = cfg.output_dir + f"{cfg.exp_name}/{type_}_model.lgb")

        # 2値分類の出力を元にk個選定
        pred_df_tmp["prob"] = model.predict(test[features], num_iteration=model.best_iteration)
        pred_df_tmp = pred_df_tmp.sort_values(["session", "prob"], ascending=(True, False))
        pred_df_tmp = pred_df_tmp.groupby(["session"]).head(cfg.k)
        pred_df_tmp["aid"] = pred_df_tmp["aid"].astype(str)
        pred_df_tmp = pred_df_tmp.groupby(["session"])["aid"].apply(list).reset_index()
        pred_df_tmp["aid"] = pred_df_tmp["aid"].apply(lambda x: ' '.join(x))
        pred_df_tmp["type"] = type_
        pred_dfs.append(pred_df_tmp)
    del test, model
    gc.collect()
    
    pred_df = pd.concat(pred_dfs)
    # sub作成
    sub = pd.read_csv(cfg.input_dir + f"sample_submission.csv", usecols=["session_type"])
    pred_df["session_type"] = pred_df["session"].astype(str) + "_" + pred_df["type"]
    pred_df = pred_df.rename(columns={"aid": "labels"})
    sub = sub.merge(pred_df[["session_type", "labels"]], on="session_type", how="left")
    sub.to_csv(cfg.output_dir + f"{cfg.exp_name}/{cfg.exp_name}_sub.csv", index=False)

# %%
@noglobal(excepts=["cfg", "logger", "cache"])
def main():
    scores = {}
    logger.info(f"START")
    line_notify.send(f"{cfg.exp_name} | START")
    
    # trans_map作成
    cache_file = "trans_maps.pkl"
    cache_path = cache.get_abspath(cache_file)
    if cache.exists(cache_path):
        logger.info(f"[{cache_file}] cache exists. load cache and skip process.")
        with open(cache_path, "rb") as f:
            trans_maps = pickle.load(f)
    else:
        trans_maps = get_trans_maps()
        with open(cache_path, "wb") as f:
            pickle.dump(trans_maps, f)

    for type_ in ["clicks", "carts", "orders"]:
        # train data作成
        logger.info(f"make {type_}_train_data")
        cache_file = f"{type_}_train.pkl"
        cache_path = cache.get_abspath(cache_file)
        if cache.exists(cache_path):
            logger.info(f"[{cache_file}] cache exists. read cache and skip process.")
            train = pd.read_pickle(cache_path)
        else:
            train = make_train_data(trans_maps, type_)
            train.to_pickle(cache_path)
        
        logger.info(f"make {type_}_valid_data")
        # valid cand作成
        cand_cache_path = cache.get_abspath("valid_cand.pkl")
        sessions_cache_path = cache.get_abspath("valid_sessions.pkl")
        labels_cache_path = cache.get_abspath("valid_labels.pkl")
        if cache.exists(cand_cache_path) & cache.exists(labels_cache_path) & cache.exists(sessions_cache_path):
            logger.info("[valid_cand.pkl] cache exists. read cache and skip process.")
            valid_cand = pd.read_pickle(cand_cache_path)
            valid_sessions = pd.read_pickle(sessions_cache_path)
            valid_labels = pd.read_pickle(labels_cache_path)
        else:
            valid_cand, valid_sessions, valid_labels = make_valid_cand(trans_maps)
            valid_cand.to_pickle(cand_cache_path)
            valid_sessions.to_pickle(sessions_cache_path)
            valid_labels.to_pickle(labels_cache_path)

        # valid data作成
        logger.info(f"make {type_}_valid_data")
        cache_file = f"{type_}_valid.pkl"
        cache_path = cache.get_abspath(cache_file)
        if cache.exists(cache_path):
            logger.info(f"[{cache_file}] cache exists. read cache and skip process.")
            valid = pd.read_pickle(cache_path)
        else:
            valid = make_valid_data(valid_cand, valid_sessions, valid_labels, type_)
            valid.to_pickle(cache_path)

        # モデル学習
        target = "labels"
        not_use_cols = ["session", "aid", target]
        features = [c for c in train.columns if c not in not_use_cols]

        scores[f"recall_{type_}"] = model_training(train, valid, features, target, valid_labels, type_)

        del train, valid, valid_labels
        gc.collect()
    
    scores["total"] = (float(scores["recall_clicks"]) * 0.1) + (float(scores["recall_carts"]) * 0.3) + (float(scores["recall_orders"]) * 0.6)
    report = f"\n{cfg.exp_name}\n"
    report += f'valid_end\n'
    report += str(scores)
    line_notify.send(report)

    # testデータ
    cache_path = cache.get_abspath("test.pkl")
    if cache.exists(cache_path):
        logger.info("cache exists. read cache and skip process.")
        test = pd.read_pickle(cache_path)
    else:
        test = make_test_data(trans_maps)
        test.to_pickle(cache_path)

    logger.info(f"-------- inference --------")
    inference(test, features)

    line_notify.send(f"{cfg.exp_name} | END!!")

# %%
try:
    main()
except Exception as e:
    logger.error(traceback.format_exc())
    line_notify.send(f"{cfg.exp_name} | ERROR!!\n{traceback.format_exc()}")
# Out:
# 0:00:00.735197 	 START
# 0:00:00.928106 	 [trans_maps.pkl] cache exists. load cache and skip process.
# 0:00:05.506912 	 make clicks_train_data
# 0:00:05.507870 	 [clicks_train.pkl] cache exists. read cache and skip process.
# 0:00:06.518898 	 make clicks_valid_data
# 0:00:06.519819 	 [valid_cand.pkl] cache exists. read cache and skip process.
# 0:00:06.886978 	 make clicks_valid_data
# 0:00:06.887964 	 [clicks_valid.pkl] cache exists. read cache and skip process.
# /home/kaggler/.local/lib/python3.8/site-packages/lightgbm/engine.py:181: UserWarning: 'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. Pass 'early_stopping()' callback via 'callbacks' argument instead.
#   _log_warning("'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. "
# /home/kaggler/.local/lib/python3.8/site-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# [LightGBM] [Info] Number of positive: 7374899, number of negative: 7374899
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.902429 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1017
# [LightGBM] [Info] Number of data points in the train set: 14749798, number of used features: 36
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500000 -> initscore=0.000000
# Training until validation scores don't improve for 100 rounds
# [100]	training's binary_logloss: 0.480469	valid_1's binary_logloss: 0.475663
# [200]	training's binary_logloss: 0.434153	valid_1's binary_logloss: 0.426812
# [300]	training's binary_logloss: 0.421368	valid_1's binary_logloss: 0.413312
# [400]	training's binary_logloss: 0.4167	valid_1's binary_logloss: 0.408876
# [500]	training's binary_logloss: 0.414592	valid_1's binary_logloss: 0.406971
# [600]	training's binary_logloss: 0.413434	valid_1's binary_logloss: 0.406001
# [700]	training's binary_logloss: 0.412727	valid_1's binary_logloss: 0.405358
# [800]	training's binary_logloss: 0.412269	valid_1's binary_logloss: 0.404924
# [900]	training's binary_logloss: 0.411918	valid_1's binary_logloss: 0.40458
# [1000]	training's binary_logloss: 0.411667	valid_1's binary_logloss: 0.404331
# [1100]	training's binary_logloss: 0.411459	valid_1's binary_logloss: 0.404127
# [1200]	training's binary_logloss: 0.41128	valid_1's binary_logloss: 0.403937
# [1300]	training's binary_logloss: 0.411145	valid_1's binary_logloss: 0.403802
# [1400]	training's binary_logloss: 0.411021	valid_1's binary_logloss: 0.403678
# [1500]	training's binary_logloss: 0.410909	valid_1's binary_logloss: 0.403576
# [1600]	training's binary_logloss: 0.410823	valid_1's binary_logloss: 0.403494
# [1700]	training's binary_logloss: 0.410739	valid_1's binary_logloss: 0.403419
# [1800]	training's binary_logloss: 0.410656	valid_1's binary_logloss: 0.403349
# [1900]	training's binary_logloss: 0.410576	valid_1's binary_logloss: 0.403281
# [2000]	training's binary_logloss: 0.410491	valid_1's binary_logloss: 0.403214
# [2100]	training's binary_logloss: 0.410407	valid_1's binary_logloss: 0.403144
# [2200]	training's binary_logloss: 0.410327	valid_1's binary_logloss: 0.403087
# [2300]	training's binary_logloss: 0.410254	valid_1's binary_logloss: 0.40303
# [2400]	training's binary_logloss: 0.410178	valid_1's binary_logloss: 0.402974
# [2500]	training's binary_logloss: 0.410091	valid_1's binary_logloss: 0.40291
# [2600]	training's binary_logloss: 0.410017	valid_1's binary_logloss: 0.402856
# [2700]	training's binary_logloss: 0.409944	valid_1's binary_logloss: 0.402802
# [2800]	training's binary_logloss: 0.409884	valid_1's binary_logloss: 0.402761
# [2900]	training's binary_logloss: 0.409807	valid_1's binary_logloss: 0.402703
# [3000]	training's binary_logloss: 0.409735	valid_1's binary_logloss: 0.402647
# [3100]	training's binary_logloss: 0.409667	valid_1's binary_logloss: 0.402597
# [3200]	training's binary_logloss: 0.409604	valid_1's binary_logloss: 0.402546
# [3300]	training's binary_logloss: 0.409541	valid_1's binary_logloss: 0.402499
# [3400]	training's binary_logloss: 0.409488	valid_1's binary_logloss: 0.402458
# [3500]	training's binary_logloss: 0.409429	valid_1's binary_logloss: 0.402423
# [3600]	training's binary_logloss: 0.409375	valid_1's binary_logloss: 0.402395
# [3700]	training's binary_logloss: 0.409321	valid_1's binary_logloss: 0.402365
# [3800]	training's binary_logloss: 0.409271	valid_1's binary_logloss: 0.402334
# [3900]	training's binary_logloss: 0.409219	valid_1's binary_logloss: 0.402303
# [4000]	training's binary_logloss: 0.409168	valid_1's binary_logloss: 0.40227
# [4100]	training's binary_logloss: 0.409118	valid_1's binary_logloss: 0.402236
# [4200]	training's binary_logloss: 0.409071	valid_1's binary_logloss: 0.402206
# [4300]	training's binary_logloss: 0.409024	valid_1's binary_logloss: 0.402178
# [4400]	training's binary_logloss: 0.408981	valid_1's binary_logloss: 0.402152
# [4500]	training's binary_logloss: 0.408937	valid_1's binary_logloss: 0.402126
# [4600]	training's binary_logloss: 0.408898	valid_1's binary_logloss: 0.402105
# [4700]	training's binary_logloss: 0.408852	valid_1's binary_logloss: 0.402078
# [4800]	training's binary_logloss: 0.408803	valid_1's binary_logloss: 0.40205
# [4900]	training's binary_logloss: 0.408755	valid_1's binary_logloss: 0.402025
# [5000]	training's binary_logloss: 0.408705	valid_1's binary_logloss: 0.401995
# [5100]	training's binary_logloss: 0.408657	valid_1's binary_logloss: 0.40197
# [5200]	training's binary_logloss: 0.408612	valid_1's binary_logloss: 0.401945
# [5300]	training's binary_logloss: 0.408565	valid_1's binary_logloss: 0.401919
# [5400]	training's binary_logloss: 0.408522	valid_1's binary_logloss: 0.401897
# [5500]	training's binary_logloss: 0.408487	valid_1's binary_logloss: 0.401878
# [5600]	training's binary_logloss: 0.408449	valid_1's binary_logloss: 0.401859
# [5700]	training's binary_logloss: 0.408401	valid_1's binary_logloss: 0.401834
# [5800]	training's binary_logloss: 0.40836	valid_1's binary_logloss: 0.401814
# [5900]	training's binary_logloss: 0.40832	valid_1's binary_logloss: 0.401794
# [6000]	training's binary_logloss: 0.40828	valid_1's binary_logloss: 0.401771
# [6100]	training's binary_logloss: 0.408239	valid_1's binary_logloss: 0.401749
# [6200]	training's binary_logloss: 0.408203	valid_1's binary_logloss: 0.401733
# [6300]	training's binary_logloss: 0.408167	valid_1's binary_logloss: 0.401717
# [6400]	training's binary_logloss: 0.408132	valid_1's binary_logloss: 0.401703
# [6500]	training's binary_logloss: 0.408095	valid_1's binary_logloss: 0.401687
# [6600]	training's binary_logloss: 0.408054	valid_1's binary_logloss: 0.401667
# [6700]	training's binary_logloss: 0.408011	valid_1's binary_logloss: 0.401646
# [6800]	training's binary_logloss: 0.407972	valid_1's binary_logloss: 0.401625
# [6900]	training's binary_logloss: 0.407929	valid_1's binary_logloss: 0.401604
# [7000]	training's binary_logloss: 0.40789	valid_1's binary_logloss: 0.401585
# [7100]	training's binary_logloss: 0.407852	valid_1's binary_logloss: 0.401569
# [7200]	training's binary_logloss: 0.407809	valid_1's binary_logloss: 0.401547
# [7300]	training's binary_logloss: 0.407766	valid_1's binary_logloss: 0.401526
# [7400]	training's binary_logloss: 0.407729	valid_1's binary_logloss: 0.401508
# [7500]	training's binary_logloss: 0.407698	valid_1's binary_logloss: 0.401495
# [7600]	training's binary_logloss: 0.407663	valid_1's binary_logloss: 0.401478
# [7700]	training's binary_logloss: 0.407631	valid_1's binary_logloss: 0.401464
# [7800]	training's binary_logloss: 0.407599	valid_1's binary_logloss: 0.401449
# [7900]	training's binary_logloss: 0.407568	valid_1's binary_logloss: 0.401434
# [8000]	training's binary_logloss: 0.407537	valid_1's binary_logloss: 0.40142
# [8100]	training's binary_logloss: 0.407503	valid_1's binary_logloss: 0.401403
# [8200]	training's binary_logloss: 0.407471	valid_1's binary_logloss: 0.401389
# [8300]	training's binary_logloss: 0.407442	valid_1's binary_logloss: 0.401378
# [8400]	training's binary_logloss: 0.407412	valid_1's binary_logloss: 0.401365
# [8500]	training's binary_logloss: 0.407382	valid_1's binary_logloss: 0.401351
# [8600]	training's binary_logloss: 0.407354	valid_1's binary_logloss: 0.40134
# [8700]	training's binary_logloss: 0.407327	valid_1's binary_logloss: 0.401328
# [8800]	training's binary_logloss: 0.4073	valid_1's binary_logloss: 0.401316
# [8900]	training's binary_logloss: 0.407271	valid_1's binary_logloss: 0.401305
# [9000]	training's binary_logloss: 0.407244	valid_1's binary_logloss: 0.401294
# [9100]	training's binary_logloss: 0.407217	valid_1's binary_logloss: 0.401283
# [9200]	training's binary_logloss: 0.407187	valid_1's binary_logloss: 0.40127
# [9300]	training's binary_logloss: 0.407161	valid_1's binary_logloss: 0.401261
# [9400]	training's binary_logloss: 0.407129	valid_1's binary_logloss: 0.401245
# [9500]	training's binary_logloss: 0.407094	valid_1's binary_logloss: 0.401228
# [9600]	training's binary_logloss: 0.407064	valid_1's binary_logloss: 0.401213
# [9700]	training's binary_logloss: 0.40703	valid_1's binary_logloss: 0.401196
# [9800]	training's binary_logloss: 0.407001	valid_1's binary_logloss: 0.401185
# [9900]	training's binary_logloss: 0.406972	valid_1's binary_logloss: 0.401171
# [10000]	training's binary_logloss: 0.406942	valid_1's binary_logloss: 0.401158
# [10100]	training's binary_logloss: 0.406913	valid_1's binary_logloss: 0.401147
# [10200]	training's binary_logloss: 0.406884	valid_1's binary_logloss: 0.401137
# [10300]	training's binary_logloss: 0.406859	valid_1's binary_logloss: 0.401128
# [10400]	training's binary_logloss: 0.406832	valid_1's binary_logloss: 0.401118
# [10500]	training's binary_logloss: 0.406808	valid_1's binary_logloss: 0.401111
# [10600]	training's binary_logloss: 0.406783	valid_1's binary_logloss: 0.401101
# [10700]	training's binary_logloss: 0.406759	valid_1's binary_logloss: 0.401093
# [10800]	training's binary_logloss: 0.406732	valid_1's binary_logloss: 0.401083
# [10900]	training's binary_logloss: 0.406709	valid_1's binary_logloss: 0.401076
# [11000]	training's binary_logloss: 0.406681	valid_1's binary_logloss: 0.401065
# [11100]	training's binary_logloss: 0.406657	valid_1's binary_logloss: 0.401059
# [11200]	training's binary_logloss: 0.406631	valid_1's binary_logloss: 0.401049
# [11300]	training's binary_logloss: 0.406607	valid_1's binary_logloss: 0.401041
# [11400]	training's binary_logloss: 0.406583	valid_1's binary_logloss: 0.401034
# [11500]	training's binary_logloss: 0.406558	valid_1's binary_logloss: 0.401026
# [11600]	training's binary_logloss: 0.406537	valid_1's binary_logloss: 0.401019
# [11700]	training's binary_logloss: 0.406513	valid_1's binary_logloss: 0.40101
# [11800]	training's binary_logloss: 0.406488	valid_1's binary_logloss: 0.401004
# [11900]	training's binary_logloss: 0.406466	valid_1's binary_logloss: 0.400996
# [12000]	training's binary_logloss: 0.406443	valid_1's binary_logloss: 0.40099
# [12100]	training's binary_logloss: 0.406423	valid_1's binary_logloss: 0.400985
# [12200]	training's binary_logloss: 0.406401	valid_1's binary_logloss: 0.40098
# [12300]	training's binary_logloss: 0.40638	valid_1's binary_logloss: 0.400974
# [12400]	training's binary_logloss: 0.406361	valid_1's binary_logloss: 0.400969
# [12500]	training's binary_logloss: 0.406341	valid_1's binary_logloss: 0.400964
# [12600]	training's binary_logloss: 0.406322	valid_1's binary_logloss: 0.40096
# [12700]	training's binary_logloss: 0.406304	valid_1's binary_logloss: 0.400955
# [12800]	training's binary_logloss: 0.406284	valid_1's binary_logloss: 0.40095
# [12900]	training's binary_logloss: 0.406266	valid_1's binary_logloss: 0.400947
# [13000]	training's binary_logloss: 0.406248	valid_1's binary_logloss: 0.400942
# [13100]	training's binary_logloss: 0.406229	valid_1's binary_logloss: 0.400937
# [13200]	training's binary_logloss: 0.40621	valid_1's binary_logloss: 0.400933
# [13300]	training's binary_logloss: 0.406192	valid_1's binary_logloss: 0.400928
# [13400]	training's binary_logloss: 0.406174	valid_1's binary_logloss: 0.400925
# [13500]	training's binary_logloss: 0.406156	valid_1's binary_logloss: 0.400922
# [13600]	training's binary_logloss: 0.406139	valid_1's binary_logloss: 0.400919
# [13700]	training's binary_logloss: 0.406122	valid_1's binary_logloss: 0.400916
# [13800]	training's binary_logloss: 0.406104	valid_1's binary_logloss: 0.400912
# [13900]	training's binary_logloss: 0.406087	valid_1's binary_logloss: 0.400909
# [14000]	training's binary_logloss: 0.406069	valid_1's binary_logloss: 0.400905
# [14100]	training's binary_logloss: 0.406051	valid_1's binary_logloss: 0.400902
# [14200]	training's binary_logloss: 0.406033	valid_1's binary_logloss: 0.400899
# [14300]	training's binary_logloss: 0.406016	valid_1's binary_logloss: 0.400895
# [14400]	training's binary_logloss: 0.405998	valid_1's binary_logloss: 0.400893
# [14500]	training's binary_logloss: 0.405981	valid_1's binary_logloss: 0.40089
# [14600]	training's binary_logloss: 0.405964	valid_1's binary_logloss: 0.400886
# [14700]	training's binary_logloss: 0.405946	valid_1's binary_logloss: 0.400883
# [14800]	training's binary_logloss: 0.405929	valid_1's binary_logloss: 0.40088
# [14900]	training's binary_logloss: 0.405912	valid_1's binary_logloss: 0.400877
# [15000]	training's binary_logloss: 0.405894	valid_1's binary_logloss: 0.400874
# [15100]	training's binary_logloss: 0.405877	valid_1's binary_logloss: 0.400871
# [15200]	training's binary_logloss: 0.40586	valid_1's binary_logloss: 0.400869
# [15300]	training's binary_logloss: 0.40584	valid_1's binary_logloss: 0.400865
# [15400]	training's binary_logloss: 0.405822	valid_1's binary_logloss: 0.400862
# [15500]	training's binary_logloss: 0.405805	valid_1's binary_logloss: 0.40086
# [15600]	training's binary_logloss: 0.405789	valid_1's binary_logloss: 0.400858
# [15700]	training's binary_logloss: 0.405773	valid_1's binary_logloss: 0.400856
# [15800]	training's binary_logloss: 0.405757	valid_1's binary_logloss: 0.400854
# [15900]	training's binary_logloss: 0.405739	valid_1's binary_logloss: 0.400851
# [16000]	training's binary_logloss: 0.405723	valid_1's binary_logloss: 0.400849
# [16100]	training's binary_logloss: 0.405706	valid_1's binary_logloss: 0.400847
# [16200]	training's binary_logloss: 0.40569	valid_1's binary_logloss: 0.400845
# [16300]	training's binary_logloss: 0.405673	valid_1's binary_logloss: 0.400843
# [16400]	training's binary_logloss: 0.405657	valid_1's binary_logloss: 0.400841
# [16500]	training's binary_logloss: 0.40564	valid_1's binary_logloss: 0.400838
# [16600]	training's binary_logloss: 0.405623	valid_1's binary_logloss: 0.400836
# [16700]	training's binary_logloss: 0.405608	valid_1's binary_logloss: 0.400834
# [16800]	training's binary_logloss: 0.405591	valid_1's binary_logloss: 0.400832
# [16900]	training's binary_logloss: 0.405577	valid_1's binary_logloss: 0.400831
# [17000]	training's binary_logloss: 0.405562	valid_1's binary_logloss: 0.400829
# [17100]	training's binary_logloss: 0.405546	valid_1's binary_logloss: 0.400827
# [17200]	training's binary_logloss: 0.405531	valid_1's binary_logloss: 0.400825
# [17300]	training's binary_logloss: 0.405516	valid_1's binary_logloss: 0.400823
# [17400]	training's binary_logloss: 0.405501	valid_1's binary_logloss: 0.400821
# [17500]	training's binary_logloss: 0.405486	valid_1's binary_logloss: 0.400819
# [17600]	training's binary_logloss: 0.405471	valid_1's binary_logloss: 0.400818
# [17700]	training's binary_logloss: 0.405457	valid_1's binary_logloss: 0.400817
# [17800]	training's binary_logloss: 0.405441	valid_1's binary_logloss: 0.400816
# [17900]	training's binary_logloss: 0.405426	valid_1's binary_logloss: 0.400814
# [18000]	training's binary_logloss: 0.405411	valid_1's binary_logloss: 0.400812
# [18100]	training's binary_logloss: 0.405396	valid_1's binary_logloss: 0.400811
# [18200]	training's binary_logloss: 0.405382	valid_1's binary_logloss: 0.40081
# [18300]	training's binary_logloss: 0.405367	valid_1's binary_logloss: 0.400809
# [18400]	training's binary_logloss: 0.405353	valid_1's binary_logloss: 0.400808
# [18500]	training's binary_logloss: 0.405338	valid_1's binary_logloss: 0.400806
# [18600]	training's binary_logloss: 0.405322	valid_1's binary_logloss: 0.400804
# [18700]	training's binary_logloss: 0.405307	valid_1's binary_logloss: 0.400803
# [18800]	training's binary_logloss: 0.405293	valid_1's binary_logloss: 0.400802
# [18900]	training's binary_logloss: 0.405278	valid_1's binary_logloss: 0.400802
# Early stopping, best iteration is:
# [18814]	training's binary_logloss: 0.40529	valid_1's binary_logloss: 0.400802
# 1:03:56.787449 	 clicks valid score
# 1:03:56.789087 	 {'num_clicks': 97136, 'hit_clicks': 50832, 'num_carts': 43211, 'hit_carts': 15953, 'num_orders': 20082, 'hit_orders': 11778, 'recall_clicks': '0.523', 'recall_carts': '0.369', 'recall_orders': '0.586', 'w_recall_clicks': '0.052', 'w_recall_carts': '0.111', 'w_recall_orders': '0.352', 'score': '0.515'}
# 1:03:57.487718 	 make carts_train_data
# 1:03:57.489247 	 [carts_train.pkl] cache exists. read cache and skip process.
# 1:03:57.812709 	 make carts_valid_data
# 1:03:57.813766 	 [valid_cand.pkl] cache exists. read cache and skip process.
# 1:03:58.124261 	 make carts_valid_data
# 1:03:58.125667 	 [carts_valid.pkl] cache exists. read cache and skip process.
# /home/kaggler/.local/lib/python3.8/site-packages/lightgbm/engine.py:181: UserWarning: 'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. Pass 'early_stopping()' callback via 'callbacks' argument instead.
#   _log_warning("'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. "
# /home/kaggler/.local/lib/python3.8/site-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# [LightGBM] [Info] Number of positive: 2582861, number of negative: 2582861
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.320406 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1085
# [LightGBM] [Info] Number of data points in the train set: 5165722, number of used features: 36
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500000 -> initscore=0.000000
# Training until validation scores don't improve for 100 rounds
# [100]	training's binary_logloss: 0.505247	valid_1's binary_logloss: 0.497376
# [200]	training's binary_logloss: 0.462489	valid_1's binary_logloss: 0.449163
# [300]	training's binary_logloss: 0.449178	valid_1's binary_logloss: 0.434472
# [400]	training's binary_logloss: 0.44333	valid_1's binary_logloss: 0.42872
# [500]	training's binary_logloss: 0.439939	valid_1's binary_logloss: 0.425668
# [600]	training's binary_logloss: 0.437783	valid_1's binary_logloss: 0.42367
# [700]	training's binary_logloss: 0.436272	valid_1's binary_logloss: 0.422275
# [800]	training's binary_logloss: 0.435128	valid_1's binary_logloss: 0.42115
# [900]	training's binary_logloss: 0.434249	valid_1's binary_logloss: 0.420263
# [1000]	training's binary_logloss: 0.433565	valid_1's binary_logloss: 0.419579
# [1100]	training's binary_logloss: 0.433009	valid_1's binary_logloss: 0.419023
# [1200]	training's binary_logloss: 0.432549	valid_1's binary_logloss: 0.418569
# [1300]	training's binary_logloss: 0.43215	valid_1's binary_logloss: 0.418168
# [1400]	training's binary_logloss: 0.431792	valid_1's binary_logloss: 0.417798
# [1500]	training's binary_logloss: 0.431496	valid_1's binary_logloss: 0.4175
# [1600]	training's binary_logloss: 0.431243	valid_1's binary_logloss: 0.417236
# [1700]	training's binary_logloss: 0.431037	valid_1's binary_logloss: 0.41703
# [1800]	training's binary_logloss: 0.430849	valid_1's binary_logloss: 0.416836
# [1900]	training's binary_logloss: 0.430684	valid_1's binary_logloss: 0.416674
# [2000]	training's binary_logloss: 0.430528	valid_1's binary_logloss: 0.416521
# [2100]	training's binary_logloss: 0.430375	valid_1's binary_logloss: 0.416379
# [2200]	training's binary_logloss: 0.430232	valid_1's binary_logloss: 0.416247
# [2300]	training's binary_logloss: 0.430101	valid_1's binary_logloss: 0.416137
# [2400]	training's binary_logloss: 0.42998	valid_1's binary_logloss: 0.416036
# [2500]	training's binary_logloss: 0.429859	valid_1's binary_logloss: 0.415938
# [2600]	training's binary_logloss: 0.429732	valid_1's binary_logloss: 0.415836
# [2700]	training's binary_logloss: 0.4296	valid_1's binary_logloss: 0.415725
# [2800]	training's binary_logloss: 0.429464	valid_1's binary_logloss: 0.415611
# [2900]	training's binary_logloss: 0.429338	valid_1's binary_logloss: 0.415505
# [3000]	training's binary_logloss: 0.429208	valid_1's binary_logloss: 0.415398
# [3100]	training's binary_logloss: 0.429078	valid_1's binary_logloss: 0.41529
# [3200]	training's binary_logloss: 0.428959	valid_1's binary_logloss: 0.415189
# [3300]	training's binary_logloss: 0.428847	valid_1's binary_logloss: 0.415099
# [3400]	training's binary_logloss: 0.428732	valid_1's binary_logloss: 0.415006
# [3500]	training's binary_logloss: 0.428617	valid_1's binary_logloss: 0.414914
# [3600]	training's binary_logloss: 0.42851	valid_1's binary_logloss: 0.41483
# [3700]	training's binary_logloss: 0.42841	valid_1's binary_logloss: 0.414751
# [3800]	training's binary_logloss: 0.428311	valid_1's binary_logloss: 0.414675
# [3900]	training's binary_logloss: 0.428216	valid_1's binary_logloss: 0.414604
# [4000]	training's binary_logloss: 0.428125	valid_1's binary_logloss: 0.414536
# [4100]	training's binary_logloss: 0.42804	valid_1's binary_logloss: 0.414477
# [4200]	training's binary_logloss: 0.427949	valid_1's binary_logloss: 0.414412
# [4300]	training's binary_logloss: 0.427862	valid_1's binary_logloss: 0.414351
# [4400]	training's binary_logloss: 0.427777	valid_1's binary_logloss: 0.414294
# [4500]	training's binary_logloss: 0.427692	valid_1's binary_logloss: 0.414239
# [4600]	training's binary_logloss: 0.427608	valid_1's binary_logloss: 0.414185
# [4700]	training's binary_logloss: 0.427529	valid_1's binary_logloss: 0.414138
# [4800]	training's binary_logloss: 0.427444	valid_1's binary_logloss: 0.414085
# [4900]	training's binary_logloss: 0.427364	valid_1's binary_logloss: 0.414037
# [5000]	training's binary_logloss: 0.427281	valid_1's binary_logloss: 0.413988
# [5100]	training's binary_logloss: 0.4272	valid_1's binary_logloss: 0.413939
# [5200]	training's binary_logloss: 0.427122	valid_1's binary_logloss: 0.413895
# [5300]	training's binary_logloss: 0.427044	valid_1's binary_logloss: 0.413851
# [5400]	training's binary_logloss: 0.426971	valid_1's binary_logloss: 0.413811
# [5500]	training's binary_logloss: 0.426901	valid_1's binary_logloss: 0.413776
# [5600]	training's binary_logloss: 0.426828	valid_1's binary_logloss: 0.413739
# [5700]	training's binary_logloss: 0.426757	valid_1's binary_logloss: 0.413703
# [5800]	training's binary_logloss: 0.426686	valid_1's binary_logloss: 0.413664
# [5900]	training's binary_logloss: 0.426616	valid_1's binary_logloss: 0.413626
# [6000]	training's binary_logloss: 0.426546	valid_1's binary_logloss: 0.413587
# [6100]	training's binary_logloss: 0.426478	valid_1's binary_logloss: 0.413553
# [6200]	training's binary_logloss: 0.426407	valid_1's binary_logloss: 0.413517
# [6300]	training's binary_logloss: 0.426336	valid_1's binary_logloss: 0.413484
# [6400]	training's binary_logloss: 0.426272	valid_1's binary_logloss: 0.413456
# [6500]	training's binary_logloss: 0.426208	valid_1's binary_logloss: 0.413428
# [6600]	training's binary_logloss: 0.426134	valid_1's binary_logloss: 0.413391
# [6700]	training's binary_logloss: 0.426061	valid_1's binary_logloss: 0.413359
# [6800]	training's binary_logloss: 0.42599	valid_1's binary_logloss: 0.413325
# [6900]	training's binary_logloss: 0.425923	valid_1's binary_logloss: 0.413295
# [7000]	training's binary_logloss: 0.425859	valid_1's binary_logloss: 0.413269
# [7100]	training's binary_logloss: 0.425793	valid_1's binary_logloss: 0.41324
# [7200]	training's binary_logloss: 0.42573	valid_1's binary_logloss: 0.413211
# [7300]	training's binary_logloss: 0.42567	valid_1's binary_logloss: 0.413187
# [7400]	training's binary_logloss: 0.425609	valid_1's binary_logloss: 0.413162
# [7500]	training's binary_logloss: 0.425549	valid_1's binary_logloss: 0.413139
# [7600]	training's binary_logloss: 0.425483	valid_1's binary_logloss: 0.41311
# [7700]	training's binary_logloss: 0.425423	valid_1's binary_logloss: 0.413086
# [7800]	training's binary_logloss: 0.425364	valid_1's binary_logloss: 0.413061
# [7900]	training's binary_logloss: 0.425303	valid_1's binary_logloss: 0.413037
# [8000]	training's binary_logloss: 0.425245	valid_1's binary_logloss: 0.413017
# [8100]	training's binary_logloss: 0.425188	valid_1's binary_logloss: 0.412994
# [8200]	training's binary_logloss: 0.425129	valid_1's binary_logloss: 0.412971
# [8300]	training's binary_logloss: 0.425074	valid_1's binary_logloss: 0.412951
# [8400]	training's binary_logloss: 0.42502	valid_1's binary_logloss: 0.412933
# [8500]	training's binary_logloss: 0.424969	valid_1's binary_logloss: 0.412919
# [8600]	training's binary_logloss: 0.424916	valid_1's binary_logloss: 0.412902
# [8700]	training's binary_logloss: 0.424863	valid_1's binary_logloss: 0.412888
# [8800]	training's binary_logloss: 0.424809	valid_1's binary_logloss: 0.412873
# [8900]	training's binary_logloss: 0.424756	valid_1's binary_logloss: 0.412858
# [9000]	training's binary_logloss: 0.424707	valid_1's binary_logloss: 0.412846
# [9100]	training's binary_logloss: 0.424656	valid_1's binary_logloss: 0.412832
# [9200]	training's binary_logloss: 0.424606	valid_1's binary_logloss: 0.41282
# [9300]	training's binary_logloss: 0.424561	valid_1's binary_logloss: 0.412811
# [9400]	training's binary_logloss: 0.424511	valid_1's binary_logloss: 0.412798
# [9500]	training's binary_logloss: 0.424466	valid_1's binary_logloss: 0.412791
# [9600]	training's binary_logloss: 0.424418	valid_1's binary_logloss: 0.41278
# [9700]	training's binary_logloss: 0.424367	valid_1's binary_logloss: 0.412765
# [9800]	training's binary_logloss: 0.424318	valid_1's binary_logloss: 0.412752
# [9900]	training's binary_logloss: 0.424272	valid_1's binary_logloss: 0.412741
# [10000]	training's binary_logloss: 0.424225	valid_1's binary_logloss: 0.412731
# [10100]	training's binary_logloss: 0.424178	valid_1's binary_logloss: 0.41272
# [10200]	training's binary_logloss: 0.42413	valid_1's binary_logloss: 0.412712
# [10300]	training's binary_logloss: 0.424083	valid_1's binary_logloss: 0.412701
# [10400]	training's binary_logloss: 0.424035	valid_1's binary_logloss: 0.41269
# [10500]	training's binary_logloss: 0.423991	valid_1's binary_logloss: 0.412683
# [10600]	training's binary_logloss: 0.423945	valid_1's binary_logloss: 0.412673
# [10700]	training's binary_logloss: 0.423899	valid_1's binary_logloss: 0.412664
# [10800]	training's binary_logloss: 0.423854	valid_1's binary_logloss: 0.412656
# [10900]	training's binary_logloss: 0.423809	valid_1's binary_logloss: 0.412648
# [11000]	training's binary_logloss: 0.423766	valid_1's binary_logloss: 0.412641
# [11100]	training's binary_logloss: 0.423725	valid_1's binary_logloss: 0.412636
# [11200]	training's binary_logloss: 0.423679	valid_1's binary_logloss: 0.412626
# [11300]	training's binary_logloss: 0.423636	valid_1's binary_logloss: 0.412619
# [11400]	training's binary_logloss: 0.42359	valid_1's binary_logloss: 0.412609
# [11500]	training's binary_logloss: 0.423548	valid_1's binary_logloss: 0.412603
# [11600]	training's binary_logloss: 0.423502	valid_1's binary_logloss: 0.412594
# [11700]	training's binary_logloss: 0.423461	valid_1's binary_logloss: 0.412587
# [11800]	training's binary_logloss: 0.423419	valid_1's binary_logloss: 0.41258
# [11900]	training's binary_logloss: 0.423378	valid_1's binary_logloss: 0.412574
# [12000]	training's binary_logloss: 0.423333	valid_1's binary_logloss: 0.412563
# [12100]	training's binary_logloss: 0.423293	valid_1's binary_logloss: 0.412558
# [12200]	training's binary_logloss: 0.423252	valid_1's binary_logloss: 0.412552
# [12300]	training's binary_logloss: 0.423211	valid_1's binary_logloss: 0.412546
# [12400]	training's binary_logloss: 0.42317	valid_1's binary_logloss: 0.41254
# [12500]	training's binary_logloss: 0.42313	valid_1's binary_logloss: 0.412536
# [12600]	training's binary_logloss: 0.423091	valid_1's binary_logloss: 0.412531
# [12700]	training's binary_logloss: 0.423049	valid_1's binary_logloss: 0.412524
# [12800]	training's binary_logloss: 0.423009	valid_1's binary_logloss: 0.41252
# [12900]	training's binary_logloss: 0.42297	valid_1's binary_logloss: 0.412515
# [13000]	training's binary_logloss: 0.422929	valid_1's binary_logloss: 0.412506
# [13100]	training's binary_logloss: 0.422887	valid_1's binary_logloss: 0.412499
# [13200]	training's binary_logloss: 0.422847	valid_1's binary_logloss: 0.412493
# [13300]	training's binary_logloss: 0.422809	valid_1's binary_logloss: 0.412488
# [13400]	training's binary_logloss: 0.42277	valid_1's binary_logloss: 0.412486
# [13500]	training's binary_logloss: 0.42273	valid_1's binary_logloss: 0.412479
# [13600]	training's binary_logloss: 0.42269	valid_1's binary_logloss: 0.412473
# [13700]	training's binary_logloss: 0.42265	valid_1's binary_logloss: 0.412469
# [13800]	training's binary_logloss: 0.422611	valid_1's binary_logloss: 0.412465
# [13900]	training's binary_logloss: 0.422571	valid_1's binary_logloss: 0.41246
# [14000]	training's binary_logloss: 0.422532	valid_1's binary_logloss: 0.412455
# [14100]	training's binary_logloss: 0.422492	valid_1's binary_logloss: 0.412449
# [14200]	training's binary_logloss: 0.422453	valid_1's binary_logloss: 0.412443
# [14300]	training's binary_logloss: 0.422413	valid_1's binary_logloss: 0.412437
# [14400]	training's binary_logloss: 0.422373	valid_1's binary_logloss: 0.412431
# [14500]	training's binary_logloss: 0.422335	valid_1's binary_logloss: 0.412427
# [14600]	training's binary_logloss: 0.422297	valid_1's binary_logloss: 0.412423
# [14700]	training's binary_logloss: 0.42226	valid_1's binary_logloss: 0.412421
# [14800]	training's binary_logloss: 0.42222	valid_1's binary_logloss: 0.412416
# [14900]	training's binary_logloss: 0.422181	valid_1's binary_logloss: 0.412412
# [15000]	training's binary_logloss: 0.422144	valid_1's binary_logloss: 0.412409
# [15100]	training's binary_logloss: 0.422108	valid_1's binary_logloss: 0.412407
# [15200]	training's binary_logloss: 0.422069	valid_1's binary_logloss: 0.412403
# [15300]	training's binary_logloss: 0.422032	valid_1's binary_logloss: 0.4124
# [15400]	training's binary_logloss: 0.421995	valid_1's binary_logloss: 0.412396
# [15500]	training's binary_logloss: 0.421957	valid_1's binary_logloss: 0.412393
# [15600]	training's binary_logloss: 0.42192	valid_1's binary_logloss: 0.412389
# [15700]	training's binary_logloss: 0.421882	valid_1's binary_logloss: 0.412385
# [15800]	training's binary_logloss: 0.421846	valid_1's binary_logloss: 0.412382
# [15900]	training's binary_logloss: 0.42181	valid_1's binary_logloss: 0.41238
# [16000]	training's binary_logloss: 0.421771	valid_1's binary_logloss: 0.412373
# [16100]	training's binary_logloss: 0.421734	valid_1's binary_logloss: 0.412369
# [16200]	training's binary_logloss: 0.421699	valid_1's binary_logloss: 0.412368
# [16300]	training's binary_logloss: 0.421664	valid_1's binary_logloss: 0.412365
# [16400]	training's binary_logloss: 0.421627	valid_1's binary_logloss: 0.412362
# [16500]	training's binary_logloss: 0.421588	valid_1's binary_logloss: 0.412356
# [16600]	training's binary_logloss: 0.421552	valid_1's binary_logloss: 0.412354
# [16700]	training's binary_logloss: 0.421515	valid_1's binary_logloss: 0.412352
# [16800]	training's binary_logloss: 0.42148	valid_1's binary_logloss: 0.41235
# [16900]	training's binary_logloss: 0.421443	valid_1's binary_logloss: 0.412348
# [17000]	training's binary_logloss: 0.421407	valid_1's binary_logloss: 0.412345
# [17100]	training's binary_logloss: 0.421371	valid_1's binary_logloss: 0.412343
# [17200]	training's binary_logloss: 0.421335	valid_1's binary_logloss: 0.412341
# [17300]	training's binary_logloss: 0.421298	valid_1's binary_logloss: 0.412338
# [17400]	training's binary_logloss: 0.421262	valid_1's binary_logloss: 0.412335
# [17500]	training's binary_logloss: 0.421228	valid_1's binary_logloss: 0.412333
# [17600]	training's binary_logloss: 0.421191	valid_1's binary_logloss: 0.41233
# [17700]	training's binary_logloss: 0.421156	valid_1's binary_logloss: 0.412328
# [17800]	training's binary_logloss: 0.421121	valid_1's binary_logloss: 0.412326
# [17900]	training's binary_logloss: 0.421085	valid_1's binary_logloss: 0.412323
# [18000]	training's binary_logloss: 0.421048	valid_1's binary_logloss: 0.412319
# [18100]	training's binary_logloss: 0.421011	valid_1's binary_logloss: 0.412315
# Early stopping, best iteration is:
# [18061]	training's binary_logloss: 0.421024	valid_1's binary_logloss: 0.412315
# 1:34:13.703821 	 carts valid score
# 1:34:13.705247 	 {'num_clicks': 97136, 'hit_clicks': 49187, 'num_carts': 43211, 'hit_carts': 16651, 'num_orders': 20082, 'hit_orders': 12213, 'recall_clicks': '0.506', 'recall_carts': '0.385', 'recall_orders': '0.608', 'w_recall_clicks': '0.051', 'w_recall_carts': '0.116', 'w_recall_orders': '0.365', 'score': '0.531'}
# 1:34:14.421425 	 make orders_train_data
# 1:34:14.423400 	 [orders_train.pkl] cache exists. read cache and skip process.
# 1:34:14.662311 	 make orders_valid_data
# 1:34:14.663575 	 [valid_cand.pkl] cache exists. read cache and skip process.
# 1:34:14.960103 	 make orders_valid_data
# 1:34:14.961052 	 [orders_valid.pkl] cache exists. read cache and skip process.
# /home/kaggler/.local/lib/python3.8/site-packages/lightgbm/engine.py:181: UserWarning: 'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. Pass 'early_stopping()' callback via 'callbacks' argument instead.
#   _log_warning("'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. "
# /home/kaggler/.local/lib/python3.8/site-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# [LightGBM] [Info] Number of positive: 1862293, number of negative: 1862293
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.305717 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1095
# [LightGBM] [Info] Number of data points in the train set: 3724586, number of used features: 36
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500000 -> initscore=0.000000
# Training until validation scores don't improve for 100 rounds
# [100]	training's binary_logloss: 0.403891	valid_1's binary_logloss: 0.392083
# [200]	training's binary_logloss: 0.335821	valid_1's binary_logloss: 0.313961
# [300]	training's binary_logloss: 0.315833	valid_1's binary_logloss: 0.290019
# [400]	training's binary_logloss: 0.308708	valid_1's binary_logloss: 0.282016
# [500]	training's binary_logloss: 0.305364	valid_1's binary_logloss: 0.278798
# [600]	training's binary_logloss: 0.303383	valid_1's binary_logloss: 0.277121
# [700]	training's binary_logloss: 0.302003	valid_1's binary_logloss: 0.275961
# [800]	training's binary_logloss: 0.300959	valid_1's binary_logloss: 0.27506
# [900]	training's binary_logloss: 0.300088	valid_1's binary_logloss: 0.274315
# [1000]	training's binary_logloss: 0.299406	valid_1's binary_logloss: 0.273709
# [1100]	training's binary_logloss: 0.298857	valid_1's binary_logloss: 0.273205
# [1200]	training's binary_logloss: 0.29841	valid_1's binary_logloss: 0.272806
# [1300]	training's binary_logloss: 0.298037	valid_1's binary_logloss: 0.272475
# [1400]	training's binary_logloss: 0.297718	valid_1's binary_logloss: 0.272184
# [1500]	training's binary_logloss: 0.297448	valid_1's binary_logloss: 0.27195
# [1600]	training's binary_logloss: 0.297221	valid_1's binary_logloss: 0.27175
# [1700]	training's binary_logloss: 0.297025	valid_1's binary_logloss: 0.27159
# [1800]	training's binary_logloss: 0.296843	valid_1's binary_logloss: 0.271442
# [1900]	training's binary_logloss: 0.29667	valid_1's binary_logloss: 0.27131
# [2000]	training's binary_logloss: 0.2965	valid_1's binary_logloss: 0.271182
# [2100]	training's binary_logloss: 0.296345	valid_1's binary_logloss: 0.271074
# [2200]	training's binary_logloss: 0.296191	valid_1's binary_logloss: 0.270967
# [2300]	training's binary_logloss: 0.296033	valid_1's binary_logloss: 0.270857
# [2400]	training's binary_logloss: 0.295876	valid_1's binary_logloss: 0.270745
# [2500]	training's binary_logloss: 0.295724	valid_1's binary_logloss: 0.270635
# [2600]	training's binary_logloss: 0.295586	valid_1's binary_logloss: 0.270543
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In [21], line 2
#       1 try:
# ----> 2     main()
#       3 except Exception as e:
#       4     logger.error(traceback.format_exc())
#
# Cell In [20], line 63, in main()
#      60 not_use_cols = ["session", "aid", target]
#      61 features = [c for c in train.columns if c not in not_use_cols]
# ---> 63 scores[f"recall_{type_}"] = model_training(train, valid, features, target, valid_labels, type_)
#      65 del train, valid, valid_labels
#      66 gc.collect()
#
# Cell In [17], line 18, in model_training(train, valid, features, target, valid_labels, type_)
#      15 tr_data = lgb.Dataset(tr_x, label=tr_y)
#      16 vl_data = lgb.Dataset(vl_x, label=vl_y)
# ---> 18 model = lgb.train(params, tr_data, valid_sets=[tr_data, vl_data],
#      19                   num_boost_round=2000000, early_stopping_rounds=100, verbose_eval=100)
#      21 # 特徴量重要度
#      22 fi = pd.DataFrame()
#
# File ~/.local/lib/python3.8/site-packages/lightgbm/engine.py:292, in train(params, train_set, num_boost_round, valid_sets, valid_names, fobj, feval, init_model, feature_name, categorical_feature, early_stopping_rounds, evals_result, verbose_eval, learning_rates, keep_training_booster, callbacks)
#     284 for cb in callbacks_before_iter:
#     285     cb(callback.CallbackEnv(model=booster,
#     286                             params=params,
#     287                             iteration=i,
#     288                             begin_iteration=init_iteration,
#     289                             end_iteration=init_iteration + num_boost_round,
#     290                             evaluation_result_list=None))
# --> 292 booster.update(fobj=fobj)
#     294 evaluation_result_list = []
#     295 # check evaluation result.
#
# File ~/.local/lib/python3.8/site-packages/lightgbm/basic.py:3021, in Booster.update(self, train_set, fobj)
#    3019 if self.__set_objective_to_none:
#    3020     raise LightGBMError('Cannot update due to null objective function.')
# -> 3021 _safe_call(_LIB.LGBM_BoosterUpdateOneIter(
#    3022     self.handle,
#    3023     ctypes.byref(is_finished)))
#    3024 self.__is_predicted_cur_iter = [False for _ in range(self.__num_dataset)]
#    3025 return is_finished.value == 1
#
# KeyboardInterrupt:
