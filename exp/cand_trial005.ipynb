# %% [markdown]
# # cand_trial005

# %%
import os
import sys
import traceback
import gc
import random
import pickle
import pathlib
import subprocess
from dataclasses import dataclass
from dotenv import load_dotenv
load_dotenv
sys.path.append(os.getenv('UTILS_PATH'))
from tqdm import tqdm
import multiprocessing
import inspect

import pandas as pd
import numpy as np
import itertools
import cudf
import lightgbm as lgb
import matplotlib.pyplot as plt
import seaborn as sns
import line_notify
import my_logger
from noglobal import noglobal
import optuna

# %% [markdown]
# # 設定

# %%
@dataclass
class Cfg:
    loglevel = "INFO"
    exp_name = "cand_trial005"
    seed = 42
    k = 20
    cand_n = 15
    type2id = {"clicks":0, "carts":1, "orders":2}
    id2type = {0:"clicks", 1:"carts", 2:"orders"}
    train_weeks = ["week3"]
    valid_week = "week4"
    valid_session_n = 100_000
    input_dir = os.getenv('INPUT_DIR')
    output_dir = os.getenv('OUTPUT_DIR')
    prep_dir = os.getenv("PREP_DIR")

cfg = Cfg()
os.makedirs(os.path.join(cfg.output_dir, cfg.exp_name), exist_ok=True)
os.makedirs(os.path.join(cfg.output_dir, cfg.exp_name, "cache"), exist_ok=True)
random.seed(cfg.seed)

# %%
class Cache:
    @noglobal(excepts=["cfg", "logger"])
    def __init__(self):
        self.cache_dir = (os.path.join(cfg.output_dir, cfg.exp_name, "cache"))
        self.cache_dir_path = pathlib.Path(self.cache_dir)
        self.caches = list(self.cache_dir_path.glob("*.pkl"))

    @noglobal(excepts=["cfg", "logger"])
    def get_abspath(self, filename):
        return (os.path.join(self.cache_dir, f"{cfg.exp_name}_{filename}"))
    
    @noglobal(excepts=["cfg", "logger"])
    def exists(self, path):
        return len([str(c) for c in self.caches if path == str(c)]) > 0

# %%
logger = my_logger.init_logger(cfg.exp_name)
cache = Cache()

# %%
@noglobal(excepts=["cfg", "logger"])
def evaluate(clicks_labels, carts_labels, orders_labels, 
             clicks_preds, carts_preds, orders_preds, k=20):

    num_clicks = 0
    num_carts = 0
    num_orders = 0
    hit_clicks = 0
    hit_carts = 0
    hit_orders = 0

    for i in range(len(clicks_labels)):
        clicks_label = clicks_labels[i]
        carts_label = carts_labels[i]
        orders_label = orders_labels[i]
        clicks_pred = clicks_preds[i]
        carts_pred = carts_preds[i]
        orders_pred = orders_preds[i]

        if type(clicks_pred) == list:
            clicks_pred = clicks_pred[:k]
        else:
            clicks_pred = []
        if type(carts_pred) == list:
            carts_pred = carts_pred[:k]
        else:
            carts_pred = []    
        if type(orders_pred) == list:
            orders_pred = orders_pred[:k]
        else:
            orders_pred = []

        if not np.isnan(clicks_label):
            num_clicks += 1
            hit_clicks += int(clicks_label in clicks_pred)

        if type(carts_label) == list:
            num_carts += min(len(carts_label), k)
            hit_carts += len(set(carts_pred) & set(carts_label))
            
        if type(orders_label) == list:
            num_orders += min(len(orders_label), k)
            hit_orders += len(set(orders_pred) & set(orders_label))


    recall_clicks = hit_clicks / num_clicks
    recall_carts = hit_carts / num_carts
    recall_orders = hit_orders / num_orders
    w_recall_clicks = recall_clicks * 0.10
    w_recall_carts = recall_carts * 0.30
    w_recall_orders = recall_orders * 0.60
    score = w_recall_clicks + w_recall_carts + w_recall_orders

    results = {}
    results["num_clicks"] = num_clicks
    results["hit_clicks"] = hit_clicks
    results["num_carts"] = num_carts
    results["hit_carts"] = hit_carts
    results["num_orders"] = num_orders
    results["hit_orders"] = hit_orders
    results["recall_clicks"] = format(recall_clicks, ".3f")
    results["recall_carts"] = format(recall_carts, ".3f")
    results["recall_orders"] = format(recall_orders, ".3f")
    results["w_recall_clicks"] = format(w_recall_clicks, ".3f")
    results["w_recall_carts"] = format(w_recall_carts, ".3f")
    results["w_recall_orders"] = format(w_recall_orders, ".3f")
    results["score"] = format(score, ".3f")

    return results

# %%
class Candidate:
    @noglobal(excepts=["cfg", "logger"])
    def __init__(self, pdf, week, labels=None):
        self.df = cudf.from_pandas(pdf)
        self.target_sessions = pdf["session"].unique().tolist()
        self.results = pd.DataFrame(columns=["name", "num_clicks", "hit_clicks", "num_carts", "hit_carts", "num_orders", "hit_orders", 
                                             "recall_clicks", "recall_carts", "recall_orders", "w_recall_clicks", "w_recall_carts", "w_recall_orders", "score"])
        self.output = pd.DataFrame(columns=["session", "aid"], dtype=int)
        self.labels = labels
        self.week = week
    
    @noglobal(excepts=["cfg", "logger"])
    def _entry(self, new_candidate_df, name, k):
        logger.info(f"[add_candidate] {name} : start")
        new_candidate_df = new_candidate_df.to_pandas()
        self.output = pd.concat([self.output, new_candidate_df[["session", "aid"]]])
        self.output = self.output.drop_duplicates(subset=["session", "aid"])

        if self.labels is not None:
            self._eval(new_candidate_df[["session", "aid"]], name, k)
    
    @noglobal(excepts=["cfg", "logger"])
    def _eval(self, new_candidate_df, name, k):
        new_candidate_df = new_candidate_df.groupby("session")["aid"].apply(list).reset_index()
        eval_df = pd.DataFrame(self.target_sessions, columns=["session"])
        eval_df = eval_df.merge(new_candidate_df, on=["session"], how="left")
        assert eval_df["session"].tolist() == self.labels["session"].tolist()
        eval_result = evaluate(self.labels["clicks_labels"].tolist(), self.labels["carts_labels"].tolist(), self.labels["orders_labels"].tolist(),
                               eval_df["aid"].tolist(), eval_df["aid"].tolist(), eval_df["aid"].tolist(), k)
        
        logger.info(name)
        logger.info(eval_result)
        self.results = pd.concat([self.results, pd.DataFrame([[name] + list(eval_result.values())], columns=["name"] + list(eval_result.keys()))])

    @noglobal(excepts=["cfg", "logger"])
    def add(self, strategy, name, usetypes=['clicks', 'carts', 'orders'], trans_map=None, k=20):
        logger.info(f"[make_candidate] {name} : start")
        candidate_df = self.df[self.df["type"].isin(usetypes)].copy()
        
        if strategy == "session_frequent":
            candidate_df = self._session_frequent(candidate_df, k)
        elif strategy == "session_latest":
            candidate_df = self._session_latest(candidate_df, k)
        elif strategy == "total_frequent":
            candidate_df = self._total_frequent(candidate_df, k)
        elif strategy == "w2v_session_total_aid_vec_sim":
            candidate_df = self._w2v_session_total_aid_vec_sim()
        elif strategy == "w2v_session_carts_total_aid_vec_sim":
            candidate_df = self._w2v_session_carts_total_aid_vec_sim()
        
        if trans_map is not None:
            candidate_df["aid"] = candidate_df["aid"].map(trans_map)
            candidate_df = candidate_df.dropna(subset=["aid"])
            
        self._entry(candidate_df, name, k)

    @noglobal(excepts=["cfg", "logger"])
    def _session_frequent(self, candidate_df, k):
        candidate_df = candidate_df.groupby(["session", "aid"])["ts"].count().reset_index()
        candidate_df.columns = ["session", "aid", "aid_count"]
        candidate_df = candidate_df.sort_values(["session", "aid_count", "aid"], ascending=(True, False, True))
        candidate_df = candidate_df[candidate_df.groupby("session")["aid_count"].cumcount() < k].copy()
        candidate_df = candidate_df[["session", "aid"]].copy()
        return candidate_df

    @noglobal(excepts=["cfg", "logger"])
    def _session_latest(self, candidate_df, k):
        candidate_df = candidate_df.sort_values(["session", "ts"], ascending=(True, False)).drop_duplicates(subset=["session", "aid"])
        candidate_df = candidate_df.sort_values(["session", "ts"], ascending=(True, False))[candidate_df.groupby("session")["ts"].cumcount() < k].copy()
        candidate_df = candidate_df[["session", "aid"]].copy()
        return candidate_df

    @noglobal(excepts=["cfg", "logger"])
    def _total_frequent(self, candidate_df, k):
        candidate_df = candidate_df.groupby("aid")["ts"].count().reset_index()
        candidate_df.columns = ["aid", "aid_count"]
        topk_freq_aids = candidate_df.sort_values("aid_count", ascending=False)["aid"].to_arrow().to_pylist()[:k]
        sessions = []
        aids = []
        for session, aid in itertools.product(self.target_sessions, topk_freq_aids):
            sessions.append(session)
            aids.append(aid)
        candidate_df = cudf.DataFrame({"session": sessions, "aid": aids})
        return candidate_df

    @noglobal(excepts=["cfg", "logger"])
    def _w2v_session_total_aid_vec_sim(self):
        if self.week is not None:
            candidate_df = pd.read_pickle(cfg.prep_dir + f"w2v_session_total_avg_similar_aids_{self.week}.pkl")
        else:
            candidate_df = pd.read_pickle(cfg.prep_dir + "w2v_session_total_avg_similar_aids.pkl")
        candidate_df = cudf.from_pandas(candidate_df)
        candidate_df = candidate_df[["session", "aid"]].copy()
        candidate_df = candidate_df[candidate_df["session"].isin(self.target_sessions)]
        return candidate_df

    @noglobal(excepts=["cfg", "logger"])
    def _w2v_session_carts_total_aid_vec_sim(self):
        if self.week is not None:
            candidate_df = pd.read_pickle(cfg.prep_dir + f"w2v_session_carts_total_avg_similar_aids_{self.week}.pkl")
        else:
            candidate_df = pd.read_pickle(cfg.prep_dir + "w2v_session_carts_total_avg_similar_aids.pkl")
        candidate_df = cudf.from_pandas(candidate_df)
        candidate_df = candidate_df[["session", "aid"]].copy()
        candidate_df = candidate_df[candidate_df["session"].isin(self.target_sessions)]
        return candidate_df

# %%
@noglobal(excepts=["cfg", "logger"])
def make_cand_df(sessions, week, labels=None, trans_maps=None):

    if labels is not None:
         cand = Candidate(sessions, week, labels)
    else:
        cand = Candidate(sessions, week)

    cand.add(strategy="session_frequent", name="session_frequent", k=15)
    cand.add(strategy="session_latest", name="session_latest", k=15)
    cand.add(strategy="w2v_session_total_aid_vec_sim", name="w2v_session_total_aid_vec_sim")
    cand.add(strategy="w2v_session_carts_total_aid_vec_sim", name="w2v_session_carts_total_aid_vec_sim")
    
    for i in range(20):
        cand.add(strategy="session_latest", trans_map=trans_maps[f"time_wt_pair{str(i)}"], name=f"session_latest_time_wt_pair{str(i)}", k=5)
        cand.add(strategy="session_latest", trans_map=trans_maps[f"word2vec_pair{str(i)}"], name=f"session_latest_word2vec_pair{str(i)}", k=5)
        cand.add(strategy="session_latest", trans_map=trans_maps[f"pair{str(i)}"], name=f"session_latest_pair{str(i)}", k=5)
        cand.add(strategy="session_latest", trans_map=trans_maps[f"type_wt_pair{str(i)}"], name=f"session_latest_type_wt_pair{str(i)}", k=5)
        cand.add(strategy="session_latest", trans_map=trans_maps[f"clicks2carts_pair{str(i)}"], name=f"session_latest_clicks2carts_pair{str(i)}", k=5)
        cand.add(strategy="session_latest", trans_map=trans_maps[f"clicks2orders_pair{str(i)}"], name=f"session_latest_clicks2orders_pair{str(i)}", k=5)

    if labels is not None:
        return cand.output, cand.results
    else:
        return cand.output

# %%
@noglobal(excepts=["cfg", "logger"])
def get_pair_df(name, wt_col, week):
    if week is not None:
        name = f"{name}_{week}"
    pair_df = pd.read_pickle(cfg.prep_dir + f"{name}.pkl")
    pair_df = pair_df.sort_values(["aid_x", wt_col], ascending=(True, False))
    return pair_df

@noglobal(excepts=["cfg", "logger"])
def get_pair_dict(name, wt_col, week):
    if week is not None:
        name = f"{name}_{week}"
    pair_df = pd.read_pickle(cfg.prep_dir + f"{name}.pkl")
    pair_df = pair_df.sort_values(["aid_x", wt_col], ascending=(True, False))
    pair_df = pair_df.groupby("aid_x").head(1)[["aid_x", "aid_y"]]
    pair_dict = {k: v for k, v in zip(pair_df["aid_x"].tolist(), pair_df["aid_y"].tolist())}
    return pair_dict

@noglobal(excepts=["cfg", "logger"])
def get_trans_maps(week=None):
    """
    aidを別のaidに置き換えるmapping辞書を取得する
    """
    trans_maps = {}
    
    pair_df_org = get_pair_df("co_visitation_matrix", "cnt", week)
    for i in range(20):
        pair_df = pair_df_org.groupby("aid_x").nth(i).reset_index()[["aid_x", "aid_y"]]
        pair_dict = {k: v for k, v in zip(pair_df["aid_x"].tolist(), pair_df["aid_y"].tolist())}
        trans_maps[f"pair{str(i)}"] = pair_dict
    
    pair_df_org = get_pair_df("co_visitation_matrix_time_weighted", "wt", week)
    for i in range(20):
        pair_df = pair_df_org.groupby("aid_x").nth(i).reset_index()[["aid_x", "aid_y"]]
        pair_dict = {k: v for k, v in zip(pair_df["aid_x"].tolist(), pair_df["aid_y"].tolist())}
        trans_maps[f"time_wt_pair{str(i)}"] = pair_dict

    pair_df_org = get_pair_df("co_visitation_matrix_type_weighted", "wt", week)
    for i in range(20):
        pair_df = pair_df_org.groupby("aid_x").nth(i).reset_index()[["aid_x", "aid_y"]]
        pair_dict = {k: v for k, v in zip(pair_df["aid_x"].tolist(), pair_df["aid_y"].tolist())}
        trans_maps[f"type_wt_pair{str(i)}"] = pair_dict

    pair_df_org = get_pair_df("co_visitation_matrix_clicks2carts", "cnt", week)
    for i in range(20):
        pair_df = pair_df_org.groupby("aid_x").nth(i).reset_index()[["aid_x", "aid_y"]]
        pair_dict = {k: v for k, v in zip(pair_df["aid_x"].tolist(), pair_df["aid_y"].tolist())}
        trans_maps[f"clicks2carts_pair{str(i)}"] = pair_dict

    pair_df_org = get_pair_df("co_visitation_matrix_clicks2orders", "cnt", week)
    for i in range(20):
        pair_df = pair_df_org.groupby("aid_x").nth(i).reset_index()[["aid_x", "aid_y"]]
        pair_dict = {k: v for k, v in zip(pair_df["aid_x"].tolist(), pair_df["aid_y"].tolist())}
        trans_maps[f"clicks2orders_pair{str(i)}"] = pair_dict

    pair_df_org = get_pair_df("word2vec_similar", "sim", None)
    for i in range(20):
        pair_df = pair_df_org.groupby("aid_x").nth(i).reset_index()[["aid_x", "aid_y"]]
        pair_dict = {k: v for k, v in zip(pair_df["aid_x"].tolist(), pair_df["aid_y"].tolist())}
        trans_maps[f"word2vec_pair{str(i)}"] = pair_dict

    with open(cfg.prep_dir + "matrix_factorization_embeddings_similar_top20.pkl", "rb") as f:
        nns = pickle.load(f)
    for i in range(20):
        pair_dict = {aid_x:aid_ys[i] for aid_x, aid_ys in enumerate(nns)}
        trans_maps[f"matrix_fact_pair{str(i)}"] = pair_dict

    return trans_maps

# %%
@noglobal(excepts=["cfg", "logger"])
def make_valid_data(trans_maps):
    valid_week = cfg.valid_week
    dfs = []
    
    logger.info(f"[make_valid] valid_week : {valid_week}")
    # データ読み込み
    logger.info("[make_valid] read_data : start")
    week_sessions = pd.read_pickle(os.getenv("PREP_DIR") + f"train_sessions_{valid_week}.pkl")
    week_labels = pd.read_pickle(os.getenv("PREP_DIR") + f"labels_{valid_week}.pkl")
    valid_session_ids = week_sessions["session"].unique().tolist()
    logger.info("[make_valid] read_data : end")

    # validに使うsessionを絞る (trainに存在するsessionを除外した上で設定した数に絞る)
    logger.info("[make_valid] valid_session_extract : start")
    valid_session_n = min(cfg.valid_session_n, len(valid_session_ids))
    valid_session_ids = random.sample(valid_session_ids, valid_session_n)
    week_sessions = week_sessions[week_sessions["session"].isin(valid_session_ids)].copy()
    week_labels = week_labels[week_labels["session"].isin(valid_session_ids)].copy()
    logger.info("[make_valid] valid_session_extract : end")

    # 候補選出
    logger.info("[make_valid] make_cand_df : start")
    valid, results = make_cand_df(week_sessions, valid_week, labels=week_labels, trans_maps=trans_maps)

    return valid, week_labels, results

# %%
logger.info("\n\nSTART\n\n")
cache_file = f"trans_maps.pkl"
cache_path = cache.get_abspath(cache_file)

if cache.exists(cache_path):
    logger.info(f"[{cache_file}] cache exists. load cache and skip process.")
    with open(cache_path, "rb") as f:
        trans_maps = pickle.load(f)
else:
    trans_maps = get_trans_maps("week3")
    with open(cache_path, "wb") as f:
        pickle.dump(trans_maps, f)

valid, valid_labels, results = make_valid_data(trans_maps)
# Out:
# 0:00:00.194983
#
# START
#
#
# 0:39:23.420007 	 [make_valid] valid_week : week4
# 0:39:23.438530 	 [make_valid] read_data : start
# 0:39:30.612576 	 [make_valid] read_data : end
# 0:39:30.613862 	 [make_valid] valid_session_extract : start
# 0:39:31.609226 	 [make_valid] valid_session_extract : end
# 0:39:31.610503 	 [make_valid] make_cand_df : start
# 0:39:31.710751 	 [make_candidate] session_frequent : start
# 0:39:32.123084 	 [add_candidate] session_frequent : start
# 0:39:33.778290 	 session_frequent
# 0:39:33.779876 	 {'num_clicks': 97136, 'hit_clicks': 29467, 'num_carts': 42864, 'hit_carts': 10730, 'num_orders': 19985, 'hit_orders': 10185, 'recall_clicks': '0.303', 'recall_carts': '0.250', 'recall_orders': '0.510', 'w_recall_clicks': '0.030', 'w_recall_carts': '0.075', 'w_recall_orders': '0.306', 'score': '0.411'}
# 0:39:33.789708 	 [make_candidate] session_latest : start
# 0:39:34.071060 	 [add_candidate] session_latest : start
# 0:39:35.891873 	 session_latest
# 0:39:35.893045 	 {'num_clicks': 97136, 'hit_clicks': 29677, 'num_carts': 42864, 'hit_carts': 10822, 'num_orders': 19985, 'hit_orders': 9838, 'recall_clicks': '0.306', 'recall_carts': '0.252', 'recall_orders': '0.492', 'w_recall_clicks': '0.031', 'w_recall_carts': '0.076', 'w_recall_orders': '0.295', 'score': '0.402'}
# 0:39:35.903694 	 [make_candidate] w2v_session_total_aid_vec_sim : start
# 0:39:39.826414 	 [add_candidate] w2v_session_total_aid_vec_sim : start
# 0:39:41.996980 	 w2v_session_total_aid_vec_sim
# 0:39:41.998894 	 {'num_clicks': 97136, 'hit_clicks': 33577, 'num_carts': 43211, 'hit_carts': 8796, 'num_orders': 20082, 'hit_orders': 5541, 'recall_clicks': '0.346', 'recall_carts': '0.204', 'recall_orders': '0.276', 'w_recall_clicks': '0.035', 'w_recall_carts': '0.061', 'w_recall_orders': '0.166', 'score': '0.261'}
# 0:39:42.027833 	 [make_candidate] w2v_session_carts_total_aid_vec_sim : start
# 0:39:42.874784 	 [add_candidate] w2v_session_carts_total_aid_vec_sim : start
# 0:39:43.845164 	 w2v_session_carts_total_aid_vec_sim
# 0:39:43.846975 	 {'num_clicks': 97136, 'hit_clicks': 4803, 'num_carts': 43211, 'hit_carts': 3151, 'num_orders': 20082, 'hit_orders': 4854, 'recall_clicks': '0.049', 'recall_carts': '0.073', 'recall_orders': '0.242', 'w_recall_clicks': '0.005', 'w_recall_carts': '0.022', 'w_recall_orders': '0.145', 'score': '0.172'}
# 0:39:43.855121 	 [make_candidate] session_latest_time_wt_pair0 : start
# 0:39:44.177328 	 [add_candidate] session_latest_time_wt_pair0 : start
# 0:39:46.339267 	 session_latest_time_wt_pair0
# 0:39:46.340316 	 {'num_clicks': 97136, 'hit_clicks': 8556, 'num_carts': 37850, 'hit_carts': 2422, 'num_orders': 17856, 'hit_orders': 1541, 'recall_clicks': '0.088', 'recall_carts': '0.064', 'recall_orders': '0.086', 'w_recall_clicks': '0.009', 'w_recall_carts': '0.019', 'w_recall_orders': '0.052', 'score': '0.080'}
# 0:39:46.350478 	 [make_candidate] session_latest_word2vec_pair0 : start
# 0:39:46.826406 	 [add_candidate] session_latest_word2vec_pair0 : start
# 0:39:48.775641 	 session_latest_word2vec_pair0
# 0:39:48.777117 	 {'num_clicks': 97136, 'hit_clicks': 4513, 'num_carts': 37850, 'hit_carts': 1459, 'num_orders': 17856, 'hit_orders': 806, 'recall_clicks': '0.046', 'recall_carts': '0.039', 'recall_orders': '0.045', 'w_recall_clicks': '0.005', 'w_recall_carts': '0.012', 'w_recall_orders': '0.027', 'score': '0.043'}
# 0:39:48.788073 	 [make_candidate] session_latest_pair0 : start
# 0:39:49.482995 	 [add_candidate] session_latest_pair0 : start
# 0:39:51.584144 	 session_latest_pair0
# 0:39:51.585351 	 {'num_clicks': 97136, 'hit_clicks': 7207, 'num_carts': 37850, 'hit_carts': 2886, 'num_orders': 17856, 'hit_orders': 1915, 'recall_clicks': '0.074', 'recall_carts': '0.076', 'recall_orders': '0.107', 'w_recall_clicks': '0.007', 'w_recall_carts': '0.023', 'w_recall_orders': '0.064', 'score': '0.095'}
# 0:39:51.596325 	 [make_candidate] session_latest_type_wt_pair0 : start
# 0:39:51.910442 	 [add_candidate] session_latest_type_wt_pair0 : start
# 0:39:54.044082 	 session_latest_type_wt_pair0
# 0:39:54.045202 	 {'num_clicks': 97136, 'hit_clicks': 7087, 'num_carts': 37850, 'hit_carts': 3417, 'num_orders': 17856, 'hit_orders': 2357, 'recall_clicks': '0.073', 'recall_carts': '0.090', 'recall_orders': '0.132', 'w_recall_clicks': '0.007', 'w_recall_carts': '0.027', 'w_recall_orders': '0.079', 'score': '0.114'}
# 0:39:54.056650 	 [make_candidate] session_latest_clicks2carts_pair0 : start
# 0:39:54.405375 	 [add_candidate] session_latest_clicks2carts_pair0 : start
# 0:39:56.457300 	 session_latest_clicks2carts_pair0
# 0:39:56.458432 	 {'num_clicks': 97136, 'hit_clicks': 4308, 'num_carts': 37850, 'hit_carts': 2669, 'num_orders': 17856, 'hit_orders': 1511, 'recall_clicks': '0.044', 'recall_carts': '0.071', 'recall_orders': '0.085', 'w_recall_clicks': '0.004', 'w_recall_carts': '0.021', 'w_recall_orders': '0.051', 'score': '0.076'}
# 0:39:56.469082 	 [make_candidate] session_latest_clicks2orders_pair0 : start
# 0:39:56.688828 	 [add_candidate] session_latest_clicks2orders_pair0 : start
# 0:39:58.611259 	 session_latest_clicks2orders_pair0
# 0:39:58.612441 	 {'num_clicks': 97136, 'hit_clicks': 2687, 'num_carts': 37850, 'hit_carts': 1750, 'num_orders': 17856, 'hit_orders': 1638, 'recall_clicks': '0.028', 'recall_carts': '0.046', 'recall_orders': '0.092', 'w_recall_clicks': '0.003', 'w_recall_carts': '0.014', 'w_recall_orders': '0.055', 'score': '0.072'}
# 0:39:58.622627 	 [make_candidate] session_latest_time_wt_pair1 : start
# 0:39:58.911380 	 [add_candidate] session_latest_time_wt_pair1 : start
# 0:40:00.995297 	 session_latest_time_wt_pair1
# 0:40:00.996695 	 {'num_clicks': 97136, 'hit_clicks': 6012, 'num_carts': 37850, 'hit_carts': 1929, 'num_orders': 17856, 'hit_orders': 1111, 'recall_clicks': '0.062', 'recall_carts': '0.051', 'recall_orders': '0.062', 'w_recall_clicks': '0.006', 'w_recall_carts': '0.015', 'w_recall_orders': '0.037', 'score': '0.059'}
# 0:40:01.007489 	 [make_candidate] session_latest_word2vec_pair1 : start
# 0:40:01.388110 	 [add_candidate] session_latest_word2vec_pair1 : start
# 0:40:03.516617 	 session_latest_word2vec_pair1
# 0:40:03.517747 	 {'num_clicks': 97136, 'hit_clicks': 3132, 'num_carts': 37850, 'hit_carts': 1037, 'num_orders': 17856, 'hit_orders': 580, 'recall_clicks': '0.032', 'recall_carts': '0.027', 'recall_orders': '0.032', 'w_recall_clicks': '0.003', 'w_recall_carts': '0.008', 'w_recall_orders': '0.019', 'score': '0.031'}
# 0:40:03.528158 	 [make_candidate] session_latest_pair1 : start
# 0:40:04.226692 	 [add_candidate] session_latest_pair1 : start
# 0:40:06.511223 	 session_latest_pair1
# 0:40:06.512378 	 {'num_clicks': 97136, 'hit_clicks': 5089, 'num_carts': 37850, 'hit_carts': 2221, 'num_orders': 17856, 'hit_orders': 1443, 'recall_clicks': '0.052', 'recall_carts': '0.059', 'recall_orders': '0.081', 'w_recall_clicks': '0.005', 'w_recall_carts': '0.018', 'w_recall_orders': '0.048', 'score': '0.071'}
# 0:40:06.523537 	 [make_candidate] session_latest_type_wt_pair1 : start
# 0:40:06.929253 	 [add_candidate] session_latest_type_wt_pair1 : start
# 0:40:09.182049 	 session_latest_type_wt_pair1
# 0:40:09.183258 	 {'num_clicks': 97136, 'hit_clicks': 4920, 'num_carts': 37850, 'hit_carts': 2618, 'num_orders': 17856, 'hit_orders': 1709, 'recall_clicks': '0.051', 'recall_carts': '0.069', 'recall_orders': '0.096', 'w_recall_clicks': '0.005', 'w_recall_carts': '0.021', 'w_recall_orders': '0.057', 'score': '0.083'}
# 0:40:09.194106 	 [make_candidate] session_latest_clicks2carts_pair1 : start
# 0:40:09.618235 	 [add_candidate] session_latest_clicks2carts_pair1 : start
# 0:40:11.821465 	 session_latest_clicks2carts_pair1
# 0:40:11.822669 	 {'num_clicks': 97136, 'hit_clicks': 2920, 'num_carts': 37850, 'hit_carts': 1926, 'num_orders': 17856, 'hit_orders': 1049, 'recall_clicks': '0.030', 'recall_carts': '0.051', 'recall_orders': '0.059', 'w_recall_clicks': '0.003', 'w_recall_carts': '0.015', 'w_recall_orders': '0.035', 'score': '0.054'}
# 0:40:11.832896 	 [make_candidate] session_latest_clicks2orders_pair1 : start
# 0:40:12.041670 	 [add_candidate] session_latest_clicks2orders_pair1 : start
# 0:40:14.161435 	 session_latest_clicks2orders_pair1
# 0:40:14.162668 	 {'num_clicks': 97136, 'hit_clicks': 1629, 'num_carts': 37850, 'hit_carts': 1075, 'num_orders': 17856, 'hit_orders': 1058, 'recall_clicks': '0.017', 'recall_carts': '0.028', 'recall_orders': '0.059', 'w_recall_clicks': '0.002', 'w_recall_carts': '0.009', 'w_recall_orders': '0.036', 'score': '0.046'}
# 0:40:14.172660 	 [make_candidate] session_latest_time_wt_pair2 : start
# 0:40:14.626847 	 [add_candidate] session_latest_time_wt_pair2 : start
# 0:40:16.990655 	 session_latest_time_wt_pair2
# 0:40:16.991783 	 {'num_clicks': 97136, 'hit_clicks': 4636, 'num_carts': 37850, 'hit_carts': 1522, 'num_orders': 17856, 'hit_orders': 896, 'recall_clicks': '0.048', 'recall_carts': '0.040', 'recall_orders': '0.050', 'w_recall_clicks': '0.005', 'w_recall_carts': '0.012', 'w_recall_orders': '0.030', 'score': '0.047'}
# 0:40:17.003437 	 [make_candidate] session_latest_word2vec_pair2 : start
# 0:40:17.521474 	 [add_candidate] session_latest_word2vec_pair2 : start
# 0:40:19.848863 	 session_latest_word2vec_pair2
# 0:40:19.849987 	 {'num_clicks': 97136, 'hit_clicks': 2525, 'num_carts': 37850, 'hit_carts': 832, 'num_orders': 17856, 'hit_orders': 472, 'recall_clicks': '0.026', 'recall_carts': '0.022', 'recall_orders': '0.026', 'w_recall_clicks': '0.003', 'w_recall_carts': '0.007', 'w_recall_orders': '0.016', 'score': '0.025'}
# 0:40:19.860807 	 [make_candidate] session_latest_pair2 : start
# 0:40:20.289111 	 [add_candidate] session_latest_pair2 : start
# 0:40:22.457029 	 session_latest_pair2
# 0:40:22.458247 	 {'num_clicks': 97136, 'hit_clicks': 3997, 'num_carts': 37850, 'hit_carts': 1857, 'num_orders': 17856, 'hit_orders': 1197, 'recall_clicks': '0.041', 'recall_carts': '0.049', 'recall_orders': '0.067', 'w_recall_clicks': '0.004', 'w_recall_carts': '0.015', 'w_recall_orders': '0.040', 'score': '0.059'}
# 0:40:22.469557 	 [make_candidate] session_latest_type_wt_pair2 : start
# 0:40:22.900739 	 [add_candidate] session_latest_type_wt_pair2 : start
# 0:40:25.199655 	 session_latest_type_wt_pair2
# 0:40:25.200761 	 {'num_clicks': 97136, 'hit_clicks': 3817, 'num_carts': 37850, 'hit_carts': 2214, 'num_orders': 17856, 'hit_orders': 1454, 'recall_clicks': '0.039', 'recall_carts': '0.058', 'recall_orders': '0.081', 'w_recall_clicks': '0.004', 'w_recall_carts': '0.018', 'w_recall_orders': '0.049', 'score': '0.070'}
# 0:40:25.211595 	 [make_candidate] session_latest_clicks2carts_pair2 : start
# 0:40:25.617684 	 [add_candidate] session_latest_clicks2carts_pair2 : start
# 0:40:27.894052 	 session_latest_clicks2carts_pair2
# 0:40:27.895290 	 {'num_clicks': 97136, 'hit_clicks': 2272, 'num_carts': 37850, 'hit_carts': 1587, 'num_orders': 17856, 'hit_orders': 825, 'recall_clicks': '0.023', 'recall_carts': '0.042', 'recall_orders': '0.046', 'w_recall_clicks': '0.002', 'w_recall_carts': '0.013', 'w_recall_orders': '0.028', 'score': '0.043'}
# 0:40:27.906540 	 [make_candidate] session_latest_clicks2orders_pair2 : start
# 0:40:28.160877 	 [add_candidate] session_latest_clicks2orders_pair2 : start
# 0:40:30.253191 	 session_latest_clicks2orders_pair2
# 0:40:30.254318 	 {'num_clicks': 97136, 'hit_clicks': 1169, 'num_carts': 37850, 'hit_carts': 836, 'num_orders': 17856, 'hit_orders': 830, 'recall_clicks': '0.012', 'recall_carts': '0.022', 'recall_orders': '0.046', 'w_recall_clicks': '0.001', 'w_recall_carts': '0.007', 'w_recall_orders': '0.028', 'score': '0.036'}
# 0:40:30.263368 	 [make_candidate] session_latest_time_wt_pair3 : start
# 0:40:30.724233 	 [add_candidate] session_latest_time_wt_pair3 : start
# 0:40:33.076981 	 session_latest_time_wt_pair3
# 0:40:33.078716 	 {'num_clicks': 97136, 'hit_clicks': 3991, 'num_carts': 37850, 'hit_carts': 1363, 'num_orders': 17856, 'hit_orders': 803, 'recall_clicks': '0.041', 'recall_carts': '0.036', 'recall_orders': '0.045', 'w_recall_clicks': '0.004', 'w_recall_carts': '0.011', 'w_recall_orders': '0.027', 'score': '0.042'}
# 0:40:33.088842 	 [make_candidate] session_latest_word2vec_pair3 : start
# 0:40:33.421090 	 [add_candidate] session_latest_word2vec_pair3 : start
# 0:40:35.822290 	 session_latest_word2vec_pair3
# 0:40:35.823602 	 {'num_clicks': 97136, 'hit_clicks': 1970, 'num_carts': 37850, 'hit_carts': 715, 'num_orders': 17856, 'hit_orders': 427, 'recall_clicks': '0.020', 'recall_carts': '0.019', 'recall_orders': '0.024', 'w_recall_clicks': '0.002', 'w_recall_carts': '0.006', 'w_recall_orders': '0.014', 'score': '0.022'}
# 0:40:35.833992 	 [make_candidate] session_latest_pair3 : start
# 0:40:36.284074 	 [add_candidate] session_latest_pair3 : start
# 0:40:38.656156 	 session_latest_pair3
# 0:40:38.657519 	 {'num_clicks': 97136, 'hit_clicks': 3202, 'num_carts': 37850, 'hit_carts': 1547, 'num_orders': 17856, 'hit_orders': 1016, 'recall_clicks': '0.033', 'recall_carts': '0.041', 'recall_orders': '0.057', 'w_recall_clicks': '0.003', 'w_recall_carts': '0.012', 'w_recall_orders': '0.034', 'score': '0.050'}
# 0:40:38.668518 	 [make_candidate] session_latest_type_wt_pair3 : start
# 0:40:39.142951 	 [add_candidate] session_latest_type_wt_pair3 : start
# 0:40:41.512051 	 session_latest_type_wt_pair3
# 0:40:41.513684 	 {'num_clicks': 97136, 'hit_clicks': 3257, 'num_carts': 37850, 'hit_carts': 1960, 'num_orders': 17856, 'hit_orders': 1184, 'recall_clicks': '0.034', 'recall_carts': '0.052', 'recall_orders': '0.066', 'w_recall_clicks': '0.003', 'w_recall_carts': '0.016', 'w_recall_orders': '0.040', 'score': '0.059'}
# 0:40:41.524096 	 [make_candidate] session_latest_clicks2carts_pair3 : start
# 0:40:41.744950 	 [add_candidate] session_latest_clicks2carts_pair3 : start
# 0:40:44.047436 	 session_latest_clicks2carts_pair3
# 0:40:44.048481 	 {'num_clicks': 97136, 'hit_clicks': 1759, 'num_carts': 37850, 'hit_carts': 1268, 'num_orders': 17856, 'hit_orders': 713, 'recall_clicks': '0.018', 'recall_carts': '0.034', 'recall_orders': '0.040', 'w_recall_clicks': '0.002', 'w_recall_carts': '0.010', 'w_recall_orders': '0.024', 'score': '0.036'}
# 0:40:44.058894 	 [make_candidate] session_latest_clicks2orders_pair3 : start
# 0:40:44.334977 	 [add_candidate] session_latest_clicks2orders_pair3 : start
# 0:40:46.517860 	 session_latest_clicks2orders_pair3
# 0:40:46.519248 	 {'num_clicks': 97136, 'hit_clicks': 947, 'num_carts': 37850, 'hit_carts': 593, 'num_orders': 17856, 'hit_orders': 648, 'recall_clicks': '0.010', 'recall_carts': '0.016', 'recall_orders': '0.036', 'w_recall_clicks': '0.001', 'w_recall_carts': '0.005', 'w_recall_orders': '0.022', 'score': '0.027'}
# 0:40:46.530145 	 [make_candidate] session_latest_time_wt_pair4 : start
# 0:40:47.078335 	 [add_candidate] session_latest_time_wt_pair4 : start
# 0:40:49.546313 	 session_latest_time_wt_pair4
# 0:40:49.547445 	 {'num_clicks': 97136, 'hit_clicks': 3407, 'num_carts': 37850, 'hit_carts': 1143, 'num_orders': 17856, 'hit_orders': 703, 'recall_clicks': '0.035', 'recall_carts': '0.030', 'recall_orders': '0.039', 'w_recall_clicks': '0.004', 'w_recall_carts': '0.009', 'w_recall_orders': '0.024', 'score': '0.036'}
# 0:40:49.557983 	 [make_candidate] session_latest_word2vec_pair4 : start
# 0:40:49.899383 	 [add_candidate] session_latest_word2vec_pair4 : start
# 0:40:52.245216 	 session_latest_word2vec_pair4
# 0:40:52.246451 	 {'num_clicks': 97136, 'hit_clicks': 1810, 'num_carts': 37850, 'hit_carts': 600, 'num_orders': 17856, 'hit_orders': 324, 'recall_clicks': '0.019', 'recall_carts': '0.016', 'recall_orders': '0.018', 'w_recall_clicks': '0.002', 'w_recall_carts': '0.005', 'w_recall_orders': '0.011', 'score': '0.018'}
# 0:40:52.257461 	 [make_candidate] session_latest_pair4 : start
# 0:40:52.721460 	 [add_candidate] session_latest_pair4 : start
# 0:40:55.182690 	 session_latest_pair4
# 0:40:55.183864 	 {'num_clicks': 97136, 'hit_clicks': 2772, 'num_carts': 37850, 'hit_carts': 1408, 'num_orders': 17856, 'hit_orders': 909, 'recall_clicks': '0.029', 'recall_carts': '0.037', 'recall_orders': '0.051', 'w_recall_clicks': '0.003', 'w_recall_carts': '0.011', 'w_recall_orders': '0.031', 'score': '0.045'}
# 0:40:55.194651 	 [make_candidate] session_latest_type_wt_pair4 : start
# 0:40:55.589704 	 [add_candidate] session_latest_type_wt_pair4 : start
# 0:40:58.025437 	 session_latest_type_wt_pair4
# 0:40:58.027111 	 {'num_clicks': 97136, 'hit_clicks': 2867, 'num_carts': 37850, 'hit_carts': 1667, 'num_orders': 17856, 'hit_orders': 1054, 'recall_clicks': '0.030', 'recall_carts': '0.044', 'recall_orders': '0.059', 'w_recall_clicks': '0.003', 'w_recall_carts': '0.013', 'w_recall_orders': '0.035', 'score': '0.052'}
# 0:40:58.038024 	 [make_candidate] session_latest_clicks2carts_pair4 : start
# 0:40:58.389676 	 [add_candidate] session_latest_clicks2carts_pair4 : start
# 0:41:00.719521 	 session_latest_clicks2carts_pair4
# 0:41:00.720645 	 {'num_clicks': 97136, 'hit_clicks': 1544, 'num_carts': 37850, 'hit_carts': 1062, 'num_orders': 17856, 'hit_orders': 575, 'recall_clicks': '0.016', 'recall_carts': '0.028', 'recall_orders': '0.032', 'w_recall_clicks': '0.002', 'w_recall_carts': '0.008', 'w_recall_orders': '0.019', 'score': '0.029'}
# 0:41:00.731601 	 [make_candidate] session_latest_clicks2orders_pair4 : start
# 0:41:00.917100 	 [add_candidate] session_latest_clicks2orders_pair4 : start
# 0:41:03.110320 	 session_latest_clicks2orders_pair4
# 0:41:03.111656 	 {'num_clicks': 97136, 'hit_clicks': 799, 'num_carts': 37850, 'hit_carts': 550, 'num_orders': 17856, 'hit_orders': 508, 'recall_clicks': '0.008', 'recall_carts': '0.015', 'recall_orders': '0.028', 'w_recall_clicks': '0.001', 'w_recall_carts': '0.004', 'w_recall_orders': '0.017', 'score': '0.022'}
# 0:41:03.119931 	 [make_candidate] session_latest_time_wt_pair5 : start
# 0:41:03.665005 	 [add_candidate] session_latest_time_wt_pair5 : start
# 0:41:06.143572 	 session_latest_time_wt_pair5
# 0:41:06.144697 	 {'num_clicks': 97136, 'hit_clicks': 3016, 'num_carts': 37850, 'hit_carts': 1048, 'num_orders': 17856, 'hit_orders': 636, 'recall_clicks': '0.031', 'recall_carts': '0.028', 'recall_orders': '0.036', 'w_recall_clicks': '0.003', 'w_recall_carts': '0.008', 'w_recall_orders': '0.021', 'score': '0.033'}
# 0:41:06.154787 	 [make_candidate] session_latest_word2vec_pair5 : start
# 0:41:06.493715 	 [add_candidate] session_latest_word2vec_pair5 : start
# 0:41:09.010318 	 session_latest_word2vec_pair5
# 0:41:09.011514 	 {'num_clicks': 97136, 'hit_clicks': 1690, 'num_carts': 37850, 'hit_carts': 569, 'num_orders': 17856, 'hit_orders': 338, 'recall_clicks': '0.017', 'recall_carts': '0.015', 'recall_orders': '0.019', 'w_recall_clicks': '0.002', 'w_recall_carts': '0.005', 'w_recall_orders': '0.011', 'score': '0.018'}
# 0:41:09.022970 	 [make_candidate] session_latest_pair5 : start
# 0:41:09.476292 	 [add_candidate] session_latest_pair5 : start
# 0:41:12.009886 	 session_latest_pair5
# 0:41:12.011130 	 {'num_clicks': 97136, 'hit_clicks': 2531, 'num_carts': 37850, 'hit_carts': 1316, 'num_orders': 17856, 'hit_orders': 821, 'recall_clicks': '0.026', 'recall_carts': '0.035', 'recall_orders': '0.046', 'w_recall_clicks': '0.003', 'w_recall_carts': '0.010', 'w_recall_orders': '0.028', 'score': '0.041'}
# 0:41:12.021988 	 [make_candidate] session_latest_type_wt_pair5 : start
# 0:41:12.539351 	 [add_candidate] session_latest_type_wt_pair5 : start
# 0:41:15.064965 	 session_latest_type_wt_pair5
# 0:41:15.066319 	 {'num_clicks': 97136, 'hit_clicks': 2551, 'num_carts': 37850, 'hit_carts': 1503, 'num_orders': 17856, 'hit_orders': 925, 'recall_clicks': '0.026', 'recall_carts': '0.040', 'recall_orders': '0.052', 'w_recall_clicks': '0.003', 'w_recall_carts': '0.012', 'w_recall_orders': '0.031', 'score': '0.046'}
# 0:41:15.077298 	 [make_candidate] session_latest_clicks2carts_pair5 : start
# 0:41:15.351143 	 [add_candidate] session_latest_clicks2carts_pair5 : start
# 0:41:17.584588 	 session_latest_clicks2carts_pair5
# 0:41:17.585731 	 {'num_clicks': 97136, 'hit_clicks': 1301, 'num_carts': 37850, 'hit_carts': 906, 'num_orders': 17856, 'hit_orders': 436, 'recall_clicks': '0.013', 'recall_carts': '0.024', 'recall_orders': '0.024', 'w_recall_clicks': '0.001', 'w_recall_carts': '0.007', 'w_recall_orders': '0.015', 'score': '0.023'}
# 0:41:17.596847 	 [make_candidate] session_latest_clicks2orders_pair5 : start
# 0:41:17.942244 	 [add_candidate] session_latest_clicks2orders_pair5 : start
# 0:41:20.199296 	 session_latest_clicks2orders_pair5
# 0:41:20.200547 	 {'num_clicks': 97136, 'hit_clicks': 701, 'num_carts': 37850, 'hit_carts': 456, 'num_orders': 17856, 'hit_orders': 452, 'recall_clicks': '0.007', 'recall_carts': '0.012', 'recall_orders': '0.025', 'w_recall_clicks': '0.001', 'w_recall_carts': '0.004', 'w_recall_orders': '0.015', 'score': '0.020'}
# 0:41:20.209245 	 [make_candidate] session_latest_time_wt_pair6 : start
# 0:41:20.530390 	 [add_candidate] session_latest_time_wt_pair6 : start
# 0:41:23.049479 	 session_latest_time_wt_pair6
# 0:41:23.050555 	 {'num_clicks': 97136, 'hit_clicks': 2749, 'num_carts': 37850, 'hit_carts': 929, 'num_orders': 17856, 'hit_orders': 544, 'recall_clicks': '0.028', 'recall_carts': '0.025', 'recall_orders': '0.030', 'w_recall_clicks': '0.003', 'w_recall_carts': '0.007', 'w_recall_orders': '0.018', 'score': '0.028'}
# 0:41:23.061230 	 [make_candidate] session_latest_word2vec_pair6 : start
# 0:41:23.670810 	 [add_candidate] session_latest_word2vec_pair6 : start
# 0:41:26.394165 	 session_latest_word2vec_pair6
# 0:41:26.395364 	 {'num_clicks': 97136, 'hit_clicks': 1628, 'num_carts': 37850, 'hit_carts': 572, 'num_orders': 17856, 'hit_orders': 276, 'recall_clicks': '0.017', 'recall_carts': '0.015', 'recall_orders': '0.015', 'w_recall_clicks': '0.002', 'w_recall_carts': '0.005', 'w_recall_orders': '0.009', 'score': '0.015'}
# 0:41:26.406906 	 [make_candidate] session_latest_pair6 : start
# 0:41:26.888050 	 [add_candidate] session_latest_pair6 : start
# 0:41:29.451301 	 session_latest_pair6
# 0:41:29.452444 	 {'num_clicks': 97136, 'hit_clicks': 2231, 'num_carts': 37850, 'hit_carts': 1112, 'num_orders': 17856, 'hit_orders': 724, 'recall_clicks': '0.023', 'recall_carts': '0.029', 'recall_orders': '0.041', 'w_recall_clicks': '0.002', 'w_recall_carts': '0.009', 'w_recall_orders': '0.024', 'score': '0.035'}
# 0:41:29.463274 	 [make_candidate] session_latest_type_wt_pair6 : start
# 0:41:29.851093 	 [add_candidate] session_latest_type_wt_pair6 : start
# 0:41:32.448828 	 session_latest_type_wt_pair6
# 0:41:32.449908 	 {'num_clicks': 97136, 'hit_clicks': 2289, 'num_carts': 37850, 'hit_carts': 1365, 'num_orders': 17856, 'hit_orders': 818, 'recall_clicks': '0.024', 'recall_carts': '0.036', 'recall_orders': '0.046', 'w_recall_clicks': '0.002', 'w_recall_carts': '0.011', 'w_recall_orders': '0.027', 'score': '0.041'}
# 0:41:32.461817 	 [make_candidate] session_latest_clicks2carts_pair6 : start
# 0:41:32.909588 	 [add_candidate] session_latest_clicks2carts_pair6 : start
# 0:41:35.379574 	 session_latest_clicks2carts_pair6
# 0:41:35.380651 	 {'num_clicks': 97136, 'hit_clicks': 1160, 'num_carts': 37850, 'hit_carts': 880, 'num_orders': 17856, 'hit_orders': 418, 'recall_clicks': '0.012', 'recall_carts': '0.023', 'recall_orders': '0.023', 'w_recall_clicks': '0.001', 'w_recall_carts': '0.007', 'w_recall_orders': '0.014', 'score': '0.022'}
# 0:41:35.390397 	 [make_candidate] session_latest_clicks2orders_pair6 : start
# 0:41:35.745586 	 [add_candidate] session_latest_clicks2orders_pair6 : start
# 0:41:37.997458 	 session_latest_clicks2orders_pair6
# 0:41:37.998666 	 {'num_clicks': 97136, 'hit_clicks': 592, 'num_carts': 37850, 'hit_carts': 388, 'num_orders': 17856, 'hit_orders': 410, 'recall_clicks': '0.006', 'recall_carts': '0.010', 'recall_orders': '0.023', 'w_recall_clicks': '0.001', 'w_recall_carts': '0.003', 'w_recall_orders': '0.014', 'score': '0.017'}
# 0:41:38.007320 	 [make_candidate] session_latest_time_wt_pair7 : start
# 0:41:38.381979 	 [add_candidate] session_latest_time_wt_pair7 : start
# 0:41:40.916465 	 session_latest_time_wt_pair7
# 0:41:40.917732 	 {'num_clicks': 97136, 'hit_clicks': 2510, 'num_carts': 37850, 'hit_carts': 866, 'num_orders': 17856, 'hit_orders': 500, 'recall_clicks': '0.026', 'recall_carts': '0.023', 'recall_orders': '0.028', 'w_recall_clicks': '0.003', 'w_recall_carts': '0.007', 'w_recall_orders': '0.017', 'score': '0.026'}
# 0:41:40.928859 	 [make_candidate] session_latest_word2vec_pair7 : start
# 0:41:41.544579 	 [add_candidate] session_latest_word2vec_pair7 : start
# 0:41:44.235599 	 session_latest_word2vec_pair7
# 0:41:44.237203 	 {'num_clicks': 97136, 'hit_clicks': 1381, 'num_carts': 37850, 'hit_carts': 469, 'num_orders': 17856, 'hit_orders': 252, 'recall_clicks': '0.014', 'recall_carts': '0.012', 'recall_orders': '0.014', 'w_recall_clicks': '0.001', 'w_recall_carts': '0.004', 'w_recall_orders': '0.008', 'score': '0.014'}
# 0:41:44.247883 	 [make_candidate] session_latest_pair7 : start
# 0:41:44.584130 	 [add_candidate] session_latest_pair7 : start
# 0:41:47.279553 	 session_latest_pair7
# 0:41:47.280838 	 {'num_clicks': 97136, 'hit_clicks': 2060, 'num_carts': 37850, 'hit_carts': 1061, 'num_orders': 17856, 'hit_orders': 661, 'recall_clicks': '0.021', 'recall_carts': '0.028', 'recall_orders': '0.037', 'w_recall_clicks': '0.002', 'w_recall_carts': '0.008', 'w_recall_orders': '0.022', 'score': '0.033'}
# 0:41:47.292193 	 [make_candidate] session_latest_type_wt_pair7 : start
# 0:41:47.870669 	 [add_candidate] session_latest_type_wt_pair7 : start
# 0:41:50.890407 	 session_latest_type_wt_pair7
# 0:41:50.891724 	 {'num_clicks': 97136, 'hit_clicks': 2064, 'num_carts': 37850, 'hit_carts': 1252, 'num_orders': 17856, 'hit_orders': 771, 'recall_clicks': '0.021', 'recall_carts': '0.033', 'recall_orders': '0.043', 'w_recall_clicks': '0.002', 'w_recall_carts': '0.010', 'w_recall_orders': '0.026', 'score': '0.038'}
# 0:41:50.902942 	 [make_candidate] session_latest_clicks2carts_pair7 : start
# 0:41:51.173121 	 [add_candidate] session_latest_clicks2carts_pair7 : start
# 0:41:54.044688 	 session_latest_clicks2carts_pair7
# 0:41:54.046234 	 {'num_clicks': 97136, 'hit_clicks': 1079, 'num_carts': 37850, 'hit_carts': 764, 'num_orders': 17856, 'hit_orders': 364, 'recall_clicks': '0.011', 'recall_carts': '0.020', 'recall_orders': '0.020', 'w_recall_clicks': '0.001', 'w_recall_carts': '0.006', 'w_recall_orders': '0.012', 'score': '0.019'}
# 0:41:54.056661 	 [make_candidate] session_latest_clicks2orders_pair7 : start
# 0:41:54.461524 	 [add_candidate] session_latest_clicks2orders_pair7 : start
# 0:41:57.171469 	 session_latest_clicks2orders_pair7
# 0:41:57.172533 	 {'num_clicks': 97136, 'hit_clicks': 535, 'num_carts': 37850, 'hit_carts': 327, 'num_orders': 17856, 'hit_orders': 338, 'recall_clicks': '0.006', 'recall_carts': '0.009', 'recall_orders': '0.019', 'w_recall_clicks': '0.001', 'w_recall_carts': '0.003', 'w_recall_orders': '0.011', 'score': '0.015'}
# 0:41:57.181382 	 [make_candidate] session_latest_time_wt_pair8 : start
# 0:41:57.676471 	 [add_candidate] session_latest_time_wt_pair8 : start
# 0:42:00.554721 	 session_latest_time_wt_pair8
# 0:42:00.555849 	 {'num_clicks': 97136, 'hit_clicks': 2282, 'num_carts': 37850, 'hit_carts': 776, 'num_orders': 17856, 'hit_orders': 465, 'recall_clicks': '0.023', 'recall_carts': '0.021', 'recall_orders': '0.026', 'w_recall_clicks': '0.002', 'w_recall_carts': '0.006', 'w_recall_orders': '0.016', 'score': '0.024'}
# 0:42:00.567126 	 [make_candidate] session_latest_word2vec_pair8 : start
# 0:42:00.904999 	 [add_candidate] session_latest_word2vec_pair8 : start
# 0:42:04.140087 	 session_latest_word2vec_pair8
# 0:42:04.141222 	 {'num_clicks': 97136, 'hit_clicks': 1295, 'num_carts': 37850, 'hit_carts': 448, 'num_orders': 17856, 'hit_orders': 238, 'recall_clicks': '0.013', 'recall_carts': '0.012', 'recall_orders': '0.013', 'w_recall_clicks': '0.001', 'w_recall_carts': '0.004', 'w_recall_orders': '0.008', 'score': '0.013'}
# 0:42:04.153417 	 [make_candidate] session_latest_pair8 : start
# 0:42:04.672405 	 [add_candidate] session_latest_pair8 : start
# 0:42:07.590602 	 session_latest_pair8
# 0:42:07.591798 	 {'num_clicks': 97136, 'hit_clicks': 1886, 'num_carts': 37850, 'hit_carts': 969, 'num_orders': 17856, 'hit_orders': 598, 'recall_clicks': '0.019', 'recall_carts': '0.026', 'recall_orders': '0.033', 'w_recall_clicks': '0.002', 'w_recall_carts': '0.008', 'w_recall_orders': '0.020', 'score': '0.030'}
# 0:42:07.604287 	 [make_candidate] session_latest_type_wt_pair8 : start
# 0:42:08.069087 	 [add_candidate] session_latest_type_wt_pair8 : start
# 0:42:11.198192 	 session_latest_type_wt_pair8
# 0:42:11.199396 	 {'num_clicks': 97136, 'hit_clicks': 1958, 'num_carts': 37850, 'hit_carts': 1139, 'num_orders': 17856, 'hit_orders': 724, 'recall_clicks': '0.020', 'recall_carts': '0.030', 'recall_orders': '0.041', 'w_recall_clicks': '0.002', 'w_recall_carts': '0.009', 'w_recall_orders': '0.024', 'score': '0.035'}
# 0:42:11.210087 	 [make_candidate] session_latest_clicks2carts_pair8 : start
# 0:42:11.554610 	 [add_candidate] session_latest_clicks2carts_pair8 : start
# 0:42:14.403877 	 session_latest_clicks2carts_pair8
# 0:42:14.405005 	 {'num_clicks': 97136, 'hit_clicks': 946, 'num_carts': 37850, 'hit_carts': 726, 'num_orders': 17856, 'hit_orders': 363, 'recall_clicks': '0.010', 'recall_carts': '0.019', 'recall_orders': '0.020', 'w_recall_clicks': '0.001', 'w_recall_carts': '0.006', 'w_recall_orders': '0.012', 'score': '0.019'}
# 0:42:14.415314 	 [make_candidate] session_latest_clicks2orders_pair8 : start
# 0:42:14.645525 	 [add_candidate] session_latest_clicks2orders_pair8 : start
# 0:42:17.321609 	 session_latest_clicks2orders_pair8
# 0:42:17.322779 	 {'num_clicks': 97136, 'hit_clicks': 489, 'num_carts': 37850, 'hit_carts': 306, 'num_orders': 17856, 'hit_orders': 323, 'recall_clicks': '0.005', 'recall_carts': '0.008', 'recall_orders': '0.018', 'w_recall_clicks': '0.001', 'w_recall_carts': '0.002', 'w_recall_orders': '0.011', 'score': '0.014'}
# 0:42:17.331528 	 [make_candidate] session_latest_time_wt_pair9 : start
# 0:42:17.861171 	 [add_candidate] session_latest_time_wt_pair9 : start
# 0:42:20.917454 	 session_latest_time_wt_pair9
# 0:42:20.918619 	 {'num_clicks': 97136, 'hit_clicks': 2122, 'num_carts': 37850, 'hit_carts': 758, 'num_orders': 17856, 'hit_orders': 457, 'recall_clicks': '0.022', 'recall_carts': '0.020', 'recall_orders': '0.026', 'w_recall_clicks': '0.002', 'w_recall_carts': '0.006', 'w_recall_orders': '0.015', 'score': '0.024'}
# 0:42:20.931168 	 [make_candidate] session_latest_word2vec_pair9 : start
# 0:42:21.453910 	 [add_candidate] session_latest_word2vec_pair9 : start
# 0:42:24.621050 	 session_latest_word2vec_pair9
# 0:42:24.622402 	 {'num_clicks': 97136, 'hit_clicks': 1134, 'num_carts': 37850, 'hit_carts': 385, 'num_orders': 17856, 'hit_orders': 207, 'recall_clicks': '0.012', 'recall_carts': '0.010', 'recall_orders': '0.012', 'w_recall_clicks': '0.001', 'w_recall_carts': '0.003', 'w_recall_orders': '0.007', 'score': '0.011'}
# 0:42:24.633613 	 [make_candidate] session_latest_pair9 : start
# 0:42:25.049779 	 [add_candidate] session_latest_pair9 : start
# 0:42:28.111228 	 session_latest_pair9
# 0:42:28.112377 	 {'num_clicks': 97136, 'hit_clicks': 1714, 'num_carts': 37850, 'hit_carts': 936, 'num_orders': 17856, 'hit_orders': 581, 'recall_clicks': '0.018', 'recall_carts': '0.025', 'recall_orders': '0.033', 'w_recall_clicks': '0.002', 'w_recall_carts': '0.007', 'w_recall_orders': '0.020', 'score': '0.029'}
# 0:42:28.123911 	 [make_candidate] session_latest_type_wt_pair9 : start
# 0:42:28.583161 	 [add_candidate] session_latest_type_wt_pair9 : start
# 0:42:31.535372 	 session_latest_type_wt_pair9
# 0:42:31.536965 	 {'num_clicks': 97136, 'hit_clicks': 1729, 'num_carts': 37850, 'hit_carts': 1213, 'num_orders': 17856, 'hit_orders': 667, 'recall_clicks': '0.018', 'recall_carts': '0.032', 'recall_orders': '0.037', 'w_recall_clicks': '0.002', 'w_recall_carts': '0.010', 'w_recall_orders': '0.022', 'score': '0.034'}
# 0:42:31.548652 	 [make_candidate] session_latest_clicks2carts_pair9 : start
# 0:42:31.936013 	 [add_candidate] session_latest_clicks2carts_pair9 : start
# 0:42:34.953069 	 session_latest_clicks2carts_pair9
# 0:42:34.954644 	 {'num_clicks': 97136, 'hit_clicks': 864, 'num_carts': 37850, 'hit_carts': 606, 'num_orders': 17856, 'hit_orders': 310, 'recall_clicks': '0.009', 'recall_carts': '0.016', 'recall_orders': '0.017', 'w_recall_clicks': '0.001', 'w_recall_carts': '0.005', 'w_recall_orders': '0.010', 'score': '0.016'}
# 0:42:34.964720 	 [make_candidate] session_latest_clicks2orders_pair9 : start
# 0:42:35.207906 	 [add_candidate] session_latest_clicks2orders_pair9 : start
# 0:42:37.977385 	 session_latest_clicks2orders_pair9
# 0:42:37.978430 	 {'num_clicks': 97136, 'hit_clicks': 360, 'num_carts': 37850, 'hit_carts': 256, 'num_orders': 17856, 'hit_orders': 263, 'recall_clicks': '0.004', 'recall_carts': '0.007', 'recall_orders': '0.015', 'w_recall_clicks': '0.000', 'w_recall_carts': '0.002', 'w_recall_orders': '0.009', 'score': '0.011'}
# 0:42:37.987285 	 [make_candidate] session_latest_time_wt_pair10 : start
# 0:42:38.459958 	 [add_candidate] session_latest_time_wt_pair10 : start
# 0:42:41.648313 	 session_latest_time_wt_pair10
# 0:42:41.649423 	 {'num_clicks': 97136, 'hit_clicks': 1974, 'num_carts': 37850, 'hit_carts': 695, 'num_orders': 17856, 'hit_orders': 440, 'recall_clicks': '0.020', 'recall_carts': '0.018', 'recall_orders': '0.025', 'w_recall_clicks': '0.002', 'w_recall_carts': '0.006', 'w_recall_orders': '0.015', 'score': '0.022'}
# 0:42:41.660497 	 [make_candidate] session_latest_word2vec_pair10 : start
# 0:42:42.161737 	 [add_candidate] session_latest_word2vec_pair10 : start
# 0:42:45.406944 	 session_latest_word2vec_pair10
# 0:42:45.408654 	 {'num_clicks': 97136, 'hit_clicks': 1080, 'num_carts': 37850, 'hit_carts': 367, 'num_orders': 17856, 'hit_orders': 234, 'recall_clicks': '0.011', 'recall_carts': '0.010', 'recall_orders': '0.013', 'w_recall_clicks': '0.001', 'w_recall_carts': '0.003', 'w_recall_orders': '0.008', 'score': '0.012'}
# 0:42:45.420951 	 [make_candidate] session_latest_pair10 : start
# 0:42:45.941817 	 [add_candidate] session_latest_pair10 : start
# 0:42:48.956583 	 session_latest_pair10
# 0:42:48.957907 	 {'num_clicks': 97136, 'hit_clicks': 1564, 'num_carts': 37850, 'hit_carts': 859, 'num_orders': 17856, 'hit_orders': 518, 'recall_clicks': '0.016', 'recall_carts': '0.023', 'recall_orders': '0.029', 'w_recall_clicks': '0.002', 'w_recall_carts': '0.007', 'w_recall_orders': '0.017', 'score': '0.026'}
# 0:42:48.968012 	 [make_candidate] session_latest_type_wt_pair10 : start
# 0:42:49.465317 	 [add_candidate] session_latest_type_wt_pair10 : start
# 0:42:52.566158 	 session_latest_type_wt_pair10
# 0:42:52.567442 	 {'num_clicks': 97136, 'hit_clicks': 1586, 'num_carts': 37850, 'hit_carts': 1037, 'num_orders': 17856, 'hit_orders': 622, 'recall_clicks': '0.016', 'recall_carts': '0.027', 'recall_orders': '0.035', 'w_recall_clicks': '0.002', 'w_recall_carts': '0.008', 'w_recall_orders': '0.021', 'score': '0.031'}
# 0:42:52.577648 	 [make_candidate] session_latest_clicks2carts_pair10 : start
# 0:42:52.849155 	 [add_candidate] session_latest_clicks2carts_pair10 : start
# 0:42:55.861013 	 session_latest_clicks2carts_pair10
# 0:42:55.862228 	 {'num_clicks': 97136, 'hit_clicks': 838, 'num_carts': 37850, 'hit_carts': 604, 'num_orders': 17856, 'hit_orders': 294, 'recall_clicks': '0.009', 'recall_carts': '0.016', 'recall_orders': '0.016', 'w_recall_clicks': '0.001', 'w_recall_carts': '0.005', 'w_recall_orders': '0.010', 'score': '0.016'}
# 0:42:55.872812 	 [make_candidate] session_latest_clicks2orders_pair10 : start
# 0:42:56.267751 	 [add_candidate] session_latest_clicks2orders_pair10 : start
# 0:42:59.016470 	 session_latest_clicks2orders_pair10
# 0:42:59.017593 	 {'num_clicks': 97136, 'hit_clicks': 387, 'num_carts': 37850, 'hit_carts': 256, 'num_orders': 17856, 'hit_orders': 255, 'recall_clicks': '0.004', 'recall_carts': '0.007', 'recall_orders': '0.014', 'w_recall_clicks': '0.000', 'w_recall_carts': '0.002', 'w_recall_orders': '0.009', 'score': '0.011'}
# 0:42:59.025261 	 [make_candidate] session_latest_time_wt_pair11 : start
# 0:42:59.365263 	 [add_candidate] session_latest_time_wt_pair11 : start
# 0:43:02.614180 	 session_latest_time_wt_pair11
# 0:43:02.615279 	 {'num_clicks': 97136, 'hit_clicks': 1805, 'num_carts': 37850, 'hit_carts': 707, 'num_orders': 17856, 'hit_orders': 459, 'recall_clicks': '0.019', 'recall_carts': '0.019', 'recall_orders': '0.026', 'w_recall_clicks': '0.002', 'w_recall_carts': '0.006', 'w_recall_orders': '0.015', 'score': '0.023'}
# 0:43:02.626914 	 [make_candidate] session_latest_word2vec_pair11 : start
# 0:43:03.273428 	 [add_candidate] session_latest_word2vec_pair11 : start
# 0:43:06.456389 	 session_latest_word2vec_pair11
# 0:43:06.457716 	 {'num_clicks': 97136, 'hit_clicks': 1016, 'num_carts': 37850, 'hit_carts': 386, 'num_orders': 17856, 'hit_orders': 199, 'recall_clicks': '0.010', 'recall_carts': '0.010', 'recall_orders': '0.011', 'w_recall_clicks': '0.001', 'w_recall_carts': '0.003', 'w_recall_orders': '0.007', 'score': '0.011'}
# 0:43:06.468667 	 [make_candidate] session_latest_pair11 : start
# 0:43:06.864751 	 [add_candidate] session_latest_pair11 : start
# 0:43:09.989749 	 session_latest_pair11
# 0:43:09.990917 	 {'num_clicks': 97136, 'hit_clicks': 1450, 'num_carts': 37850, 'hit_carts': 847, 'num_orders': 17856, 'hit_orders': 529, 'recall_clicks': '0.015', 'recall_carts': '0.022', 'recall_orders': '0.030', 'w_recall_clicks': '0.001', 'w_recall_carts': '0.007', 'w_recall_orders': '0.018', 'score': '0.026'}
# 0:43:10.001947 	 [make_candidate] session_latest_type_wt_pair11 : start
# 0:43:10.451701 	 [add_candidate] session_latest_type_wt_pair11 : start
# 0:43:13.640131 	 session_latest_type_wt_pair11
# 0:43:13.641279 	 {'num_clicks': 97136, 'hit_clicks': 1467, 'num_carts': 37850, 'hit_carts': 1019, 'num_orders': 17856, 'hit_orders': 604, 'recall_clicks': '0.015', 'recall_carts': '0.027', 'recall_orders': '0.034', 'w_recall_clicks': '0.002', 'w_recall_carts': '0.008', 'w_recall_orders': '0.020', 'score': '0.030'}
# 0:43:13.652838 	 [make_candidate] session_latest_clicks2carts_pair11 : start
# 0:43:13.913946 	 [add_candidate] session_latest_clicks2carts_pair11 : start
# 0:43:16.990896 	 session_latest_clicks2carts_pair11
# 0:43:16.992028 	 {'num_clicks': 97136, 'hit_clicks': 735, 'num_carts': 37850, 'hit_carts': 473, 'num_orders': 17856, 'hit_orders': 237, 'recall_clicks': '0.008', 'recall_carts': '0.012', 'recall_orders': '0.013', 'w_recall_clicks': '0.001', 'w_recall_carts': '0.004', 'w_recall_orders': '0.008', 'score': '0.012'}
# 0:43:17.002388 	 [make_candidate] session_latest_clicks2orders_pair11 : start
# 0:43:17.305135 	 [add_candidate] session_latest_clicks2orders_pair11 : start
# 0:43:20.074344 	 session_latest_clicks2orders_pair11
# 0:43:20.075522 	 {'num_clicks': 97136, 'hit_clicks': 327, 'num_carts': 37850, 'hit_carts': 237, 'num_orders': 17856, 'hit_orders': 234, 'recall_clicks': '0.003', 'recall_carts': '0.006', 'recall_orders': '0.013', 'w_recall_clicks': '0.000', 'w_recall_carts': '0.002', 'w_recall_orders': '0.008', 'score': '0.010'}
# 0:43:20.084440 	 [make_candidate] session_latest_time_wt_pair12 : start
# 0:43:20.416374 	 [add_candidate] session_latest_time_wt_pair12 : start
# 0:43:23.664490 	 session_latest_time_wt_pair12
# 0:43:23.665652 	 {'num_clicks': 97136, 'hit_clicks': 1699, 'num_carts': 37850, 'hit_carts': 642, 'num_orders': 17856, 'hit_orders': 359, 'recall_clicks': '0.017', 'recall_carts': '0.017', 'recall_orders': '0.020', 'w_recall_clicks': '0.002', 'w_recall_carts': '0.005', 'w_recall_orders': '0.012', 'score': '0.019'}
# 0:43:23.677063 	 [make_candidate] session_latest_word2vec_pair12 : start
# 0:43:24.239423 	 [add_candidate] session_latest_word2vec_pair12 : start
# 0:43:27.566217 	 session_latest_word2vec_pair12
# 0:43:27.567528 	 {'num_clicks': 97136, 'hit_clicks': 990, 'num_carts': 37850, 'hit_carts': 359, 'num_orders': 17856, 'hit_orders': 208, 'recall_clicks': '0.010', 'recall_carts': '0.009', 'recall_orders': '0.012', 'w_recall_clicks': '0.001', 'w_recall_carts': '0.003', 'w_recall_orders': '0.007', 'score': '0.011'}
# 0:43:27.578516 	 [make_candidate] session_latest_pair12 : start
# 0:43:27.972512 	 [add_candidate] session_latest_pair12 : start
# 0:43:31.132179 	 session_latest_pair12
# 0:43:31.133442 	 {'num_clicks': 97136, 'hit_clicks': 1330, 'num_carts': 37850, 'hit_carts': 775, 'num_orders': 17856, 'hit_orders': 486, 'recall_clicks': '0.014', 'recall_carts': '0.020', 'recall_orders': '0.027', 'w_recall_clicks': '0.001', 'w_recall_carts': '0.006', 'w_recall_orders': '0.016', 'score': '0.024'}
# 0:43:31.144587 	 [make_candidate] session_latest_type_wt_pair12 : start
# 0:43:31.648347 	 [add_candidate] session_latest_type_wt_pair12 : start
# 0:43:34.876657 	 session_latest_type_wt_pair12
# 0:43:34.877839 	 {'num_clicks': 97136, 'hit_clicks': 1459, 'num_carts': 37850, 'hit_carts': 1005, 'num_orders': 17856, 'hit_orders': 583, 'recall_clicks': '0.015', 'recall_carts': '0.027', 'recall_orders': '0.033', 'w_recall_clicks': '0.002', 'w_recall_carts': '0.008', 'w_recall_orders': '0.020', 'score': '0.029'}
# 0:43:34.888676 	 [make_candidate] session_latest_clicks2carts_pair12 : start
# 0:43:35.215432 	 [add_candidate] session_latest_clicks2carts_pair12 : start
# 0:43:38.308209 	 session_latest_clicks2carts_pair12
# 0:43:38.309328 	 {'num_clicks': 97136, 'hit_clicks': 647, 'num_carts': 37850, 'hit_carts': 536, 'num_orders': 17856, 'hit_orders': 262, 'recall_clicks': '0.007', 'recall_carts': '0.014', 'recall_orders': '0.015', 'w_recall_clicks': '0.001', 'w_recall_carts': '0.004', 'w_recall_orders': '0.009', 'score': '0.014'}
# 0:43:38.319475 	 [make_candidate] session_latest_clicks2orders_pair12 : start
# 0:43:38.694445 	 [add_candidate] session_latest_clicks2orders_pair12 : start
# 0:43:41.484409 	 session_latest_clicks2orders_pair12
# 0:43:41.485547 	 {'num_clicks': 97136, 'hit_clicks': 301, 'num_carts': 37850, 'hit_carts': 213, 'num_orders': 17856, 'hit_orders': 202, 'recall_clicks': '0.003', 'recall_carts': '0.006', 'recall_orders': '0.011', 'w_recall_clicks': '0.000', 'w_recall_carts': '0.002', 'w_recall_orders': '0.007', 'score': '0.009'}
# 0:43:41.495464 	 [make_candidate] session_latest_time_wt_pair13 : start
# 0:43:41.910021 	 [add_candidate] session_latest_time_wt_pair13 : start
# 0:43:45.252040 	 session_latest_time_wt_pair13
# 0:43:45.253116 	 {'num_clicks': 97136, 'hit_clicks': 1643, 'num_carts': 37850, 'hit_carts': 587, 'num_orders': 17856, 'hit_orders': 363, 'recall_clicks': '0.017', 'recall_carts': '0.016', 'recall_orders': '0.020', 'w_recall_clicks': '0.002', 'w_recall_carts': '0.005', 'w_recall_orders': '0.012', 'score': '0.019'}
# 0:43:45.264104 	 [make_candidate] session_latest_word2vec_pair13 : start
# 0:43:45.801997 	 [add_candidate] session_latest_word2vec_pair13 : start
# 0:43:49.099900 	 session_latest_word2vec_pair13
# 0:43:49.101197 	 {'num_clicks': 97136, 'hit_clicks': 923, 'num_carts': 37850, 'hit_carts': 348, 'num_orders': 17856, 'hit_orders': 169, 'recall_clicks': '0.010', 'recall_carts': '0.009', 'recall_orders': '0.009', 'w_recall_clicks': '0.001', 'w_recall_carts': '0.003', 'w_recall_orders': '0.006', 'score': '0.009'}
# 0:43:49.112835 	 [make_candidate] session_latest_pair13 : start
# 0:43:49.511937 	 [add_candidate] session_latest_pair13 : start
# 0:43:52.856567 	 session_latest_pair13
# 0:43:52.857692 	 {'num_clicks': 97136, 'hit_clicks': 1268, 'num_carts': 37850, 'hit_carts': 747, 'num_orders': 17856, 'hit_orders': 435, 'recall_clicks': '0.013', 'recall_carts': '0.020', 'recall_orders': '0.024', 'w_recall_clicks': '0.001', 'w_recall_carts': '0.006', 'w_recall_orders': '0.015', 'score': '0.022'}
# 0:43:52.868677 	 [make_candidate] session_latest_type_wt_pair13 : start
# 0:43:53.413363 	 [add_candidate] session_latest_type_wt_pair13 : start
# 0:43:56.781983 	 session_latest_type_wt_pair13
# 0:43:56.783233 	 {'num_clicks': 97136, 'hit_clicks': 1330, 'num_carts': 37850, 'hit_carts': 909, 'num_orders': 17856, 'hit_orders': 561, 'recall_clicks': '0.014', 'recall_carts': '0.024', 'recall_orders': '0.031', 'w_recall_clicks': '0.001', 'w_recall_carts': '0.007', 'w_recall_orders': '0.019', 'score': '0.027'}
# 0:43:56.794616 	 [make_candidate] session_latest_clicks2carts_pair13 : start
# 0:43:57.018415 	 [add_candidate] session_latest_clicks2carts_pair13 : start
# 0:44:00.065306 	 session_latest_clicks2carts_pair13
# 0:44:00.066968 	 {'num_clicks': 97136, 'hit_clicks': 625, 'num_carts': 37850, 'hit_carts': 477, 'num_orders': 17856, 'hit_orders': 238, 'recall_clicks': '0.006', 'recall_carts': '0.013', 'recall_orders': '0.013', 'w_recall_clicks': '0.001', 'w_recall_carts': '0.004', 'w_recall_orders': '0.008', 'score': '0.012'}
# 0:44:00.078326 	 [make_candidate] session_latest_clicks2orders_pair13 : start
# 0:44:00.479561 	 [add_candidate] session_latest_clicks2orders_pair13 : start
# 0:44:03.343351 	 session_latest_clicks2orders_pair13
# 0:44:03.344501 	 {'num_clicks': 97136, 'hit_clicks': 301, 'num_carts': 37850, 'hit_carts': 170, 'num_orders': 17856, 'hit_orders': 194, 'recall_clicks': '0.003', 'recall_carts': '0.004', 'recall_orders': '0.011', 'w_recall_clicks': '0.000', 'w_recall_carts': '0.001', 'w_recall_orders': '0.007', 'score': '0.008'}
# 0:44:03.352690 	 [make_candidate] session_latest_time_wt_pair14 : start
# 0:44:03.695441 	 [add_candidate] session_latest_time_wt_pair14 : start
# 0:44:07.086856 	 session_latest_time_wt_pair14
# 0:44:07.088247 	 {'num_clicks': 97136, 'hit_clicks': 1496, 'num_carts': 37850, 'hit_carts': 619, 'num_orders': 17856, 'hit_orders': 355, 'recall_clicks': '0.015', 'recall_carts': '0.016', 'recall_orders': '0.020', 'w_recall_clicks': '0.002', 'w_recall_carts': '0.005', 'w_recall_orders': '0.012', 'score': '0.018'}
# 0:44:07.100006 	 [make_candidate] session_latest_word2vec_pair14 : start
# 0:44:07.624600 	 [add_candidate] session_latest_word2vec_pair14 : start
# 0:44:10.948928 	 session_latest_word2vec_pair14
# 0:44:10.950165 	 {'num_clicks': 97136, 'hit_clicks': 852, 'num_carts': 37850, 'hit_carts': 308, 'num_orders': 17856, 'hit_orders': 161, 'recall_clicks': '0.009', 'recall_carts': '0.008', 'recall_orders': '0.009', 'w_recall_clicks': '0.001', 'w_recall_carts': '0.002', 'w_recall_orders': '0.005', 'score': '0.009'}
# 0:44:10.961186 	 [make_candidate] session_latest_pair14 : start
# 0:44:11.410085 	 [add_candidate] session_latest_pair14 : start
# 0:44:14.777155 	 session_latest_pair14
# 0:44:14.778320 	 {'num_clicks': 97136, 'hit_clicks': 1261, 'num_carts': 37850, 'hit_carts': 724, 'num_orders': 17856, 'hit_orders': 447, 'recall_clicks': '0.013', 'recall_carts': '0.019', 'recall_orders': '0.025', 'w_recall_clicks': '0.001', 'w_recall_carts': '0.006', 'w_recall_orders': '0.015', 'score': '0.022'}
# 0:44:14.789614 	 [make_candidate] session_latest_type_wt_pair14 : start
# 0:44:15.134387 	 [add_candidate] session_latest_type_wt_pair14 : start
# 0:44:18.322150 	 session_latest_type_wt_pair14
# 0:44:18.323477 	 {'num_clicks': 97136, 'hit_clicks': 1279, 'num_carts': 37850, 'hit_carts': 818, 'num_orders': 17856, 'hit_orders': 472, 'recall_clicks': '0.013', 'recall_carts': '0.022', 'recall_orders': '0.026', 'w_recall_clicks': '0.001', 'w_recall_carts': '0.006', 'w_recall_orders': '0.016', 'score': '0.024'}
# 0:44:18.336298 	 [make_candidate] session_latest_clicks2carts_pair14 : start
# 0:44:18.702190 	 [add_candidate] session_latest_clicks2carts_pair14 : start
# 0:44:21.915328 	 session_latest_clicks2carts_pair14
# 0:44:21.916759 	 {'num_clicks': 97136, 'hit_clicks': 583, 'num_carts': 37850, 'hit_carts': 495, 'num_orders': 17856, 'hit_orders': 208, 'recall_clicks': '0.006', 'recall_carts': '0.013', 'recall_orders': '0.012', 'w_recall_clicks': '0.001', 'w_recall_carts': '0.004', 'w_recall_orders': '0.007', 'score': '0.012'}
# 0:44:21.926316 	 [make_candidate] session_latest_clicks2orders_pair14 : start
# 0:44:22.159611 	 [add_candidate] session_latest_clicks2orders_pair14 : start
# 0:44:25.143761 	 session_latest_clicks2orders_pair14
# 0:44:25.144813 	 {'num_clicks': 97136, 'hit_clicks': 256, 'num_carts': 37850, 'hit_carts': 175, 'num_orders': 17856, 'hit_orders': 154, 'recall_clicks': '0.003', 'recall_carts': '0.005', 'recall_orders': '0.009', 'w_recall_clicks': '0.000', 'w_recall_carts': '0.001', 'w_recall_orders': '0.005', 'score': '0.007'}
# 0:44:25.153209 	 [make_candidate] session_latest_time_wt_pair15 : start
# 0:44:25.629453 	 [add_candidate] session_latest_time_wt_pair15 : start
# 0:44:29.119321 	 session_latest_time_wt_pair15
# 0:44:29.120505 	 {'num_clicks': 97136, 'hit_clicks': 1412, 'num_carts': 37850, 'hit_carts': 535, 'num_orders': 17856, 'hit_orders': 323, 'recall_clicks': '0.015', 'recall_carts': '0.014', 'recall_orders': '0.018', 'w_recall_clicks': '0.001', 'w_recall_carts': '0.004', 'w_recall_orders': '0.011', 'score': '0.017'}
# 0:44:29.132700 	 [make_candidate] session_latest_word2vec_pair15 : start
# 0:44:29.631475 	 [add_candidate] session_latest_word2vec_pair15 : start
# 0:44:33.059889 	 session_latest_word2vec_pair15
# 0:44:33.061078 	 {'num_clicks': 97136, 'hit_clicks': 877, 'num_carts': 37850, 'hit_carts': 306, 'num_orders': 17856, 'hit_orders': 176, 'recall_clicks': '0.009', 'recall_carts': '0.008', 'recall_orders': '0.010', 'w_recall_clicks': '0.001', 'w_recall_carts': '0.002', 'w_recall_orders': '0.006', 'score': '0.009'}
# 0:44:33.072363 	 [make_candidate] session_latest_pair15 : start
# 0:44:33.460636 	 [add_candidate] session_latest_pair15 : start
# 0:44:36.891447 	 session_latest_pair15
# 0:44:36.892550 	 {'num_clicks': 97136, 'hit_clicks': 1172, 'num_carts': 37850, 'hit_carts': 667, 'num_orders': 17856, 'hit_orders': 408, 'recall_clicks': '0.012', 'recall_carts': '0.018', 'recall_orders': '0.023', 'w_recall_clicks': '0.001', 'w_recall_carts': '0.005', 'w_recall_orders': '0.014', 'score': '0.020'}
# 0:44:36.903964 	 [make_candidate] session_latest_type_wt_pair15 : start
# 0:44:37.411714 	 [add_candidate] session_latest_type_wt_pair15 : start
# 0:44:40.876094 	 session_latest_type_wt_pair15
# 0:44:40.877449 	 {'num_clicks': 97136, 'hit_clicks': 1266, 'num_carts': 37850, 'hit_carts': 848, 'num_orders': 17856, 'hit_orders': 474, 'recall_clicks': '0.013', 'recall_carts': '0.022', 'recall_orders': '0.027', 'w_recall_clicks': '0.001', 'w_recall_carts': '0.007', 'w_recall_orders': '0.016', 'score': '0.024'}
# 0:44:40.889037 	 [make_candidate] session_latest_clicks2carts_pair15 : start
# 0:44:41.145253 	 [add_candidate] session_latest_clicks2carts_pair15 : start
# 0:44:44.215170 	 session_latest_clicks2carts_pair15
# 0:44:44.216677 	 {'num_clicks': 97136, 'hit_clicks': 524, 'num_carts': 37850, 'hit_carts': 423, 'num_orders': 17856, 'hit_orders': 216, 'recall_clicks': '0.005', 'recall_carts': '0.011', 'recall_orders': '0.012', 'w_recall_clicks': '0.001', 'w_recall_carts': '0.003', 'w_recall_orders': '0.007', 'score': '0.011'}
# 0:44:44.226710 	 [make_candidate] session_latest_clicks2orders_pair15 : start
# 0:44:44.630327 	 [add_candidate] session_latest_clicks2orders_pair15 : start
# 0:44:47.593894 	 session_latest_clicks2orders_pair15
# 0:44:47.595814 	 {'num_clicks': 97136, 'hit_clicks': 251, 'num_carts': 37850, 'hit_carts': 153, 'num_orders': 17856, 'hit_orders': 138, 'recall_clicks': '0.003', 'recall_carts': '0.004', 'recall_orders': '0.008', 'w_recall_clicks': '0.000', 'w_recall_carts': '0.001', 'w_recall_orders': '0.005', 'score': '0.006'}
# 0:44:47.604388 	 [make_candidate] session_latest_time_wt_pair16 : start
# 0:44:48.014827 	 [add_candidate] session_latest_time_wt_pair16 : start
# 0:44:51.521430 	 session_latest_time_wt_pair16
# 0:44:51.522753 	 {'num_clicks': 97136, 'hit_clicks': 1368, 'num_carts': 37850, 'hit_carts': 536, 'num_orders': 17856, 'hit_orders': 326, 'recall_clicks': '0.014', 'recall_carts': '0.014', 'recall_orders': '0.018', 'w_recall_clicks': '0.001', 'w_recall_carts': '0.004', 'w_recall_orders': '0.011', 'score': '0.017'}
# 0:44:51.534356 	 [make_candidate] session_latest_word2vec_pair16 : start
# 0:44:52.027957 	 [add_candidate] session_latest_word2vec_pair16 : start
# 0:44:55.533916 	 session_latest_word2vec_pair16
# 0:44:55.535003 	 {'num_clicks': 97136, 'hit_clicks': 789, 'num_carts': 37850, 'hit_carts': 268, 'num_orders': 17856, 'hit_orders': 140, 'recall_clicks': '0.008', 'recall_carts': '0.007', 'recall_orders': '0.008', 'w_recall_clicks': '0.001', 'w_recall_carts': '0.002', 'w_recall_orders': '0.005', 'score': '0.008'}
# 0:44:55.547753 	 [make_candidate] session_latest_pair16 : start
# 0:44:56.000571 	 [add_candidate] session_latest_pair16 : start
# 0:44:59.381592 	 session_latest_pair16
# 0:44:59.382776 	 {'num_clicks': 97136, 'hit_clicks': 1102, 'num_carts': 37850, 'hit_carts': 697, 'num_orders': 17856, 'hit_orders': 387, 'recall_clicks': '0.011', 'recall_carts': '0.018', 'recall_orders': '0.022', 'w_recall_clicks': '0.001', 'w_recall_carts': '0.006', 'w_recall_orders': '0.013', 'score': '0.020'}
# 0:44:59.394556 	 [make_candidate] session_latest_type_wt_pair16 : start
# 0:44:59.809406 	 [add_candidate] session_latest_type_wt_pair16 : start
# 0:45:03.202895 	 session_latest_type_wt_pair16
# 0:45:03.204043 	 {'num_clicks': 97136, 'hit_clicks': 1132, 'num_carts': 37850, 'hit_carts': 780, 'num_orders': 17856, 'hit_orders': 445, 'recall_clicks': '0.012', 'recall_carts': '0.021', 'recall_orders': '0.025', 'w_recall_clicks': '0.001', 'w_recall_carts': '0.006', 'w_recall_orders': '0.015', 'score': '0.022'}
# 0:45:03.216465 	 [make_candidate] session_latest_clicks2carts_pair16 : start
# 0:45:03.648162 	 [add_candidate] session_latest_clicks2carts_pair16 : start
# 0:45:06.875224 	 session_latest_clicks2carts_pair16
# 0:45:06.876536 	 {'num_clicks': 97136, 'hit_clicks': 595, 'num_carts': 37850, 'hit_carts': 420, 'num_orders': 17856, 'hit_orders': 190, 'recall_clicks': '0.006', 'recall_carts': '0.011', 'recall_orders': '0.011', 'w_recall_clicks': '0.001', 'w_recall_carts': '0.003', 'w_recall_orders': '0.006', 'score': '0.010'}
# 0:45:06.885940 	 [make_candidate] session_latest_clicks2orders_pair16 : start
# 0:45:07.122172 	 [add_candidate] session_latest_clicks2orders_pair16 : start
# 0:45:10.059953 	 session_latest_clicks2orders_pair16
# 0:45:10.061164 	 {'num_clicks': 97136, 'hit_clicks': 230, 'num_carts': 37850, 'hit_carts': 151, 'num_orders': 17856, 'hit_orders': 141, 'recall_clicks': '0.002', 'recall_carts': '0.004', 'recall_orders': '0.008', 'w_recall_clicks': '0.000', 'w_recall_carts': '0.001', 'w_recall_orders': '0.005', 'score': '0.006'}
# 0:45:10.069221 	 [make_candidate] session_latest_time_wt_pair17 : start
# 0:45:10.589799 	 [add_candidate] session_latest_time_wt_pair17 : start
# 0:45:14.041523 	 session_latest_time_wt_pair17
# 0:45:14.042682 	 {'num_clicks': 97136, 'hit_clicks': 1398, 'num_carts': 37850, 'hit_carts': 524, 'num_orders': 17856, 'hit_orders': 316, 'recall_clicks': '0.014', 'recall_carts': '0.014', 'recall_orders': '0.018', 'w_recall_clicks': '0.001', 'w_recall_carts': '0.004', 'w_recall_orders': '0.011', 'score': '0.016'}
# 0:45:14.054773 	 [make_candidate] session_latest_word2vec_pair17 : start
# 0:45:14.580775 	 [add_candidate] session_latest_word2vec_pair17 : start
# 0:45:18.067019 	 session_latest_word2vec_pair17
# 0:45:18.068147 	 {'num_clicks': 97136, 'hit_clicks': 721, 'num_carts': 37850, 'hit_carts': 269, 'num_orders': 17856, 'hit_orders': 134, 'recall_clicks': '0.007', 'recall_carts': '0.007', 'recall_orders': '0.008', 'w_recall_clicks': '0.001', 'w_recall_carts': '0.002', 'w_recall_orders': '0.005', 'score': '0.007'}
# 0:45:18.080144 	 [make_candidate] session_latest_pair17 : start
# 0:45:18.438794 	 [add_candidate] session_latest_pair17 : start
# 0:45:21.842348 	 session_latest_pair17
# 0:45:21.843661 	 {'num_clicks': 97136, 'hit_clicks': 965, 'num_carts': 37850, 'hit_carts': 587, 'num_orders': 17856, 'hit_orders': 346, 'recall_clicks': '0.010', 'recall_carts': '0.016', 'recall_orders': '0.019', 'w_recall_clicks': '0.001', 'w_recall_carts': '0.005', 'w_recall_orders': '0.012', 'score': '0.017'}
# 0:45:21.855702 	 [make_candidate] session_latest_type_wt_pair17 : start
# 0:45:22.380414 	 [add_candidate] session_latest_type_wt_pair17 : start
# 0:45:25.866094 	 session_latest_type_wt_pair17
# 0:45:25.867219 	 {'num_clicks': 97136, 'hit_clicks': 1080, 'num_carts': 37850, 'hit_carts': 752, 'num_orders': 17856, 'hit_orders': 469, 'recall_clicks': '0.011', 'recall_carts': '0.020', 'recall_orders': '0.026', 'w_recall_clicks': '0.001', 'w_recall_carts': '0.006', 'w_recall_orders': '0.016', 'score': '0.023'}
# 0:45:25.879536 	 [make_candidate] session_latest_clicks2carts_pair17 : start
# 0:45:26.134356 	 [add_candidate] session_latest_clicks2carts_pair17 : start
# 0:45:29.474031 	 session_latest_clicks2carts_pair17
# 0:45:29.475135 	 {'num_clicks': 97136, 'hit_clicks': 486, 'num_carts': 37850, 'hit_carts': 381, 'num_orders': 17856, 'hit_orders': 177, 'recall_clicks': '0.005', 'recall_carts': '0.010', 'recall_orders': '0.010', 'w_recall_clicks': '0.001', 'w_recall_carts': '0.003', 'w_recall_orders': '0.006', 'score': '0.009'}
# 0:45:29.485933 	 [make_candidate] session_latest_clicks2orders_pair17 : start
# 0:45:29.856505 	 [add_candidate] session_latest_clicks2orders_pair17 : start
# 0:45:32.918303 	 session_latest_clicks2orders_pair17
# 0:45:32.919479 	 {'num_clicks': 97136, 'hit_clicks': 219, 'num_carts': 37850, 'hit_carts': 148, 'num_orders': 17856, 'hit_orders': 127, 'recall_clicks': '0.002', 'recall_carts': '0.004', 'recall_orders': '0.007', 'w_recall_clicks': '0.000', 'w_recall_carts': '0.001', 'w_recall_orders': '0.004', 'score': '0.006'}
# 0:45:32.927367 	 [make_candidate] session_latest_time_wt_pair18 : start
# 0:45:33.269853 	 [add_candidate] session_latest_time_wt_pair18 : start
# 0:45:36.881107 	 session_latest_time_wt_pair18
# 0:45:36.882169 	 {'num_clicks': 97136, 'hit_clicks': 1259, 'num_carts': 37850, 'hit_carts': 494, 'num_orders': 17856, 'hit_orders': 291, 'recall_clicks': '0.013', 'recall_carts': '0.013', 'recall_orders': '0.016', 'w_recall_clicks': '0.001', 'w_recall_carts': '0.004', 'w_recall_orders': '0.010', 'score': '0.015'}
# 0:45:36.895259 	 [make_candidate] session_latest_word2vec_pair18 : start
# 0:45:37.398467 	 [add_candidate] session_latest_word2vec_pair18 : start
# 0:45:40.952865 	 session_latest_word2vec_pair18
# 0:45:40.954084 	 {'num_clicks': 97136, 'hit_clicks': 755, 'num_carts': 37850, 'hit_carts': 287, 'num_orders': 17856, 'hit_orders': 131, 'recall_clicks': '0.008', 'recall_carts': '0.008', 'recall_orders': '0.007', 'w_recall_clicks': '0.001', 'w_recall_carts': '0.002', 'w_recall_orders': '0.004', 'score': '0.007'}
# 0:45:40.965350 	 [make_candidate] session_latest_pair18 : start
# 0:45:41.323347 	 [add_candidate] session_latest_pair18 : start
# 0:45:44.759979 	 session_latest_pair18
# 0:45:44.761090 	 {'num_clicks': 97136, 'hit_clicks': 995, 'num_carts': 37850, 'hit_carts': 634, 'num_orders': 17856, 'hit_orders': 390, 'recall_clicks': '0.010', 'recall_carts': '0.017', 'recall_orders': '0.022', 'w_recall_clicks': '0.001', 'w_recall_carts': '0.005', 'w_recall_orders': '0.013', 'score': '0.019'}
# 0:45:44.772977 	 [make_candidate] session_latest_type_wt_pair18 : start
# 0:45:45.348048 	 [add_candidate] session_latest_type_wt_pair18 : start
# 0:45:48.969330 	 session_latest_type_wt_pair18
# 0:45:48.970452 	 {'num_clicks': 97136, 'hit_clicks': 1008, 'num_carts': 37850, 'hit_carts': 777, 'num_orders': 17856, 'hit_orders': 425, 'recall_clicks': '0.010', 'recall_carts': '0.021', 'recall_orders': '0.024', 'w_recall_clicks': '0.001', 'w_recall_carts': '0.006', 'w_recall_orders': '0.014', 'score': '0.021'}
# 0:45:48.983635 	 [make_candidate] session_latest_clicks2carts_pair18 : start
# 0:45:49.365604 	 [add_candidate] session_latest_clicks2carts_pair18 : start
# 0:45:52.762819 	 session_latest_clicks2carts_pair18
# 0:45:52.764164 	 {'num_clicks': 97136, 'hit_clicks': 489, 'num_carts': 37850, 'hit_carts': 348, 'num_orders': 17856, 'hit_orders': 158, 'recall_clicks': '0.005', 'recall_carts': '0.009', 'recall_orders': '0.009', 'w_recall_clicks': '0.001', 'w_recall_carts': '0.003', 'w_recall_orders': '0.005', 'score': '0.009'}
# 0:45:52.774820 	 [make_candidate] session_latest_clicks2orders_pair18 : start
# 0:45:53.178452 	 [add_candidate] session_latest_clicks2orders_pair18 : start
# 0:45:56.363614 	 session_latest_clicks2orders_pair18
# 0:45:56.365053 	 {'num_clicks': 97136, 'hit_clicks': 206, 'num_carts': 37850, 'hit_carts': 135, 'num_orders': 17856, 'hit_orders': 135, 'recall_clicks': '0.002', 'recall_carts': '0.004', 'recall_orders': '0.008', 'w_recall_clicks': '0.000', 'w_recall_carts': '0.001', 'w_recall_orders': '0.005', 'score': '0.006'}
# 0:45:56.374363 	 [make_candidate] session_latest_time_wt_pair19 : start
# 0:45:56.960555 	 [add_candidate] session_latest_time_wt_pair19 : start
# 0:46:00.581602 	 session_latest_time_wt_pair19
# 0:46:00.582781 	 {'num_clicks': 97136, 'hit_clicks': 1241, 'num_carts': 37850, 'hit_carts': 476, 'num_orders': 17856, 'hit_orders': 284, 'recall_clicks': '0.013', 'recall_carts': '0.013', 'recall_orders': '0.016', 'w_recall_clicks': '0.001', 'w_recall_carts': '0.004', 'w_recall_orders': '0.010', 'score': '0.015'}
# 0:46:00.594777 	 [make_candidate] session_latest_word2vec_pair19 : start
# 0:46:01.016107 	 [add_candidate] session_latest_word2vec_pair19 : start
# 0:46:04.515038 	 session_latest_word2vec_pair19
# 0:46:04.516467 	 {'num_clicks': 97136, 'hit_clicks': 709, 'num_carts': 37850, 'hit_carts': 297, 'num_orders': 17856, 'hit_orders': 143, 'recall_clicks': '0.007', 'recall_carts': '0.008', 'recall_orders': '0.008', 'w_recall_clicks': '0.001', 'w_recall_carts': '0.002', 'w_recall_orders': '0.005', 'score': '0.008'}
# 0:46:04.529628 	 [make_candidate] session_latest_pair19 : start
# 0:46:04.970913 	 [add_candidate] session_latest_pair19 : start
# 0:46:09.222262 	 session_latest_pair19
# 0:46:09.223486 	 {'num_clicks': 97136, 'hit_clicks': 970, 'num_carts': 37850, 'hit_carts': 563, 'num_orders': 17856, 'hit_orders': 388, 'recall_clicks': '0.010', 'recall_carts': '0.015', 'recall_orders': '0.022', 'w_recall_clicks': '0.001', 'w_recall_carts': '0.004', 'w_recall_orders': '0.013', 'score': '0.018'}
# 0:46:09.235656 	 [make_candidate] session_latest_type_wt_pair19 : start
# 0:46:09.766204 	 [add_candidate] session_latest_type_wt_pair19 : start
# 0:46:14.026341 	 session_latest_type_wt_pair19
# 0:46:14.027611 	 {'num_clicks': 97136, 'hit_clicks': 971, 'num_carts': 37850, 'hit_carts': 701, 'num_orders': 17856, 'hit_orders': 397, 'recall_clicks': '0.010', 'recall_carts': '0.019', 'recall_orders': '0.022', 'w_recall_clicks': '0.001', 'w_recall_carts': '0.006', 'w_recall_orders': '0.013', 'score': '0.020'}
# 0:46:14.038840 	 [make_candidate] session_latest_clicks2carts_pair19 : start
# 0:46:14.310896 	 [add_candidate] session_latest_clicks2carts_pair19 : start
# 0:46:18.484978 	 session_latest_clicks2carts_pair19
# 0:46:18.486315 	 {'num_clicks': 97136, 'hit_clicks': 428, 'num_carts': 37850, 'hit_carts': 313, 'num_orders': 17856, 'hit_orders': 147, 'recall_clicks': '0.004', 'recall_carts': '0.008', 'recall_orders': '0.008', 'w_recall_clicks': '0.000', 'w_recall_carts': '0.002', 'w_recall_orders': '0.005', 'score': '0.008'}
# 0:46:18.497822 	 [make_candidate] session_latest_clicks2orders_pair19 : start
# 0:46:18.830175 	 [add_candidate] session_latest_clicks2orders_pair19 : start
# 0:46:22.511775 	 session_latest_clicks2orders_pair19
# 0:46:22.513117 	 {'num_clicks': 97136, 'hit_clicks': 208, 'num_carts': 37850, 'hit_carts': 138, 'num_orders': 17856, 'hit_orders': 116, 'recall_clicks': '0.002', 'recall_carts': '0.004', 'recall_orders': '0.006', 'w_recall_clicks': '0.000', 'w_recall_carts': '0.001', 'w_recall_orders': '0.004', 'score': '0.005'}

# %%
results
# Out:
#                                    name num_clicks hit_clicks num_carts  \
# 0                      session_frequent      97136      29467     42864
# 0                        session_latest      97136      29677     42864
# 0         w2v_session_total_aid_vec_sim      97136      33577     43211
# 0   w2v_session_carts_total_aid_vec_sim      97136       4803     43211
# 0          session_latest_time_wt_pair0      97136       8556     37850
# ..                                  ...        ...        ...       ...
# 0        session_latest_word2vec_pair19      97136        709     37850
# 0                 session_latest_pair19      97136        970     37850
# 0         session_latest_type_wt_pair19      97136        971     37850
# 0    session_latest_clicks2carts_pair19      97136        428     37850
# 0   session_latest_clicks2orders_pair19      97136        208     37850
#
#    hit_carts num_orders hit_orders recall_clicks recall_carts recall_orders  \
# 0      10730      19985      10185         0.303        0.250         0.510
# 0      10822      19985       9838         0.306        0.252         0.492
# 0       8796      20082       5541         0.346        0.204         0.276
# 0       3151      20082       4854         0.049        0.073         0.242
# 0       2422      17856       1541         0.088        0.064         0.086
# ..       ...        ...        ...           ...          ...           ...
# 0        297      17856        143         0.007        0.008         0.008
# 0        563      17856        388         0.010        0.015         0.022
# 0        701      17856        397         0.010        0.019         0.022
# 0        313      17856        147         0.004        0.008         0.008
# 0        138      17856        116         0.002        0.004         0.006
#
#    w_recall_clicks w_recall_carts w_recall_orders  score
# 0            0.030          0.075           0.306  0.411
# 0            0.031          0.076           0.295  0.402
# 0            0.035          0.061           0.166  0.261
# 0            0.005          0.022           0.145  0.172
# 0            0.009          0.019           0.052  0.080
# ..             ...            ...             ...    ...
# 0            0.001          0.002           0.005  0.008
# 0            0.001          0.004           0.013  0.018
# 0            0.001          0.006           0.013  0.020
# 0            0.000          0.002           0.005  0.008
# 0            0.000          0.001           0.004  0.005
#
# [124 rows x 14 columns]

# %%
fig, axs = plt.subplots(1, 3)
sns.heatmap(results.set_index("name")[["recall_clicks"]].astype(float),
            annot=True, linewidths=.5, fmt="1.2f", cmap="Reds", cbar=False, ax=axs[0])
sns.heatmap(results.set_index("name")[["recall_carts"]].astype(float),
            annot=True, linewidths=.5, fmt="1.2f", cmap="Reds", cbar=False, ax=axs[1], yticklabels=False)
sns.heatmap(results.set_index("name")[["recall_orders"]].astype(float),
            annot=True, linewidths=.5, fmt="1.2f", cmap="Reds", cbar=False, ax=axs[2], yticklabels=False)
plt.savefig(cfg.output_dir + f'{cfg.exp_name}/candidate_strategy_recalls.png')

# %%
# 予測値を全て使えたときのrecall
valid_all = valid.drop_duplicates(subset= ["session", "aid"])
session_cnt_max = valid_all["session"].value_counts().max()
valid_all = valid_all.groupby("session")["aid"].apply(list).reset_index()

all_results = evaluate(valid_labels["clicks_labels"].tolist(),
                       valid_labels["carts_labels"].tolist(),
                       valid_labels["orders_labels"].tolist(),
                       valid_all["aid"].tolist(),
                       valid_all["aid"].tolist(),
                       valid_all["aid"].tolist(),
                       session_cnt_max)
logger.info("session_cnt_max")
logger.info(session_cnt_max)
logger.info("all_pred_results")
logger.info(all_results)
# Out:
# 0:46:31.302741 	 session_cnt_max
# 0:46:31.304410 	 403
# 0:46:31.305268 	 all_pred_results
# 0:46:31.306654 	 {'num_clicks': 97136, 'hit_clicks': 61458, 'num_carts': 43611, 'hit_carts': 24674, 'num_orders': 20109, 'hit_orders': 15048, 'recall_clicks': '0.633', 'recall_carts': '0.566', 'recall_orders': '0.748', 'w_recall_clicks': '0.063', 'w_recall_carts': '0.170', 'w_recall_orders': '0.449', 'score': '0.682'}
