# %% [markdown]
# # exp027
# candidate追加
# * co-visitaion-matrix clicks_time_weighted
# * co-visitaion-matrix type_weighted

# %%
import os
import sys
import traceback
import gc
import random
import pickle
import pathlib
import subprocess
from dataclasses import dataclass
from dotenv import load_dotenv
load_dotenv
sys.path.append(os.getenv('UTILS_PATH'))
from tqdm import tqdm
import multiprocessing
import inspect

import pandas as pd
import numpy as np
import itertools
import cudf
import lightgbm as lgb
import matplotlib.pyplot as plt
import seaborn as sns
import line_notify
import my_logger
from noglobal import noglobal
import optuna

# %% [markdown]
# # 設定

# %%
@dataclass
class Cfg:
    loglevel = "INFO"
    exp_name = "exp027"
    seed = 42
    k = 20
    type2id = {"clicks":0, "carts":1, "orders":2}
    id2type = {0:"clicks", 1:"carts", 2:"orders"}
    train_weeks = ["week3"]
    valid_week = "week4"
    valid_session_n = 100_000
    input_dir = os.getenv('INPUT_DIR')
    output_dir = os.getenv('OUTPUT_DIR')
    prep_dir = os.getenv("PREP_DIR")

cfg = Cfg()
os.makedirs(os.path.join(cfg.output_dir, cfg.exp_name), exist_ok=True)
os.makedirs(os.path.join(cfg.output_dir, cfg.exp_name, "cache"), exist_ok=True)
random.seed(cfg.seed)

logger = my_logger.init_logger(cfg.exp_name)

# %%
@noglobal(excepts=["cfg", "logger"])
def evaluate(clicks_labels, carts_labels, orders_labels, 
             clicks_preds, carts_preds, orders_preds, k=20):

    num_clicks = 0
    num_carts = 0
    num_orders = 0
    hit_clicks = 0
    hit_carts = 0
    hit_orders = 0

    for i in range(len(clicks_labels)):
        clicks_label = clicks_labels[i]
        carts_label = carts_labels[i]
        orders_label = orders_labels[i]
        clicks_pred = clicks_preds[i]
        carts_pred = carts_preds[i]
        orders_pred = orders_preds[i]

        if type(clicks_pred) == list:
            clicks_pred = clicks_pred[:k]
        else:
            clicks_pred = []
        if type(carts_pred) == list:
            carts_pred = carts_pred[:k]
        else:
            carts_pred = []    
        if type(orders_pred) == list:
            orders_pred = orders_pred[:k]
        else:
            orders_pred = []

        if not np.isnan(clicks_label):
            num_clicks += 1
            hit_clicks += int(clicks_label in clicks_pred)

        if type(carts_label) == list:
            num_carts += min(len(carts_label), k)
            hit_carts += len(set(carts_pred) & set(carts_label))
            
        if type(orders_label) == list:
            num_orders += min(len(orders_label), k)
            hit_orders += len(set(orders_pred) & set(orders_label))


    recall_clicks = hit_clicks / num_clicks
    recall_carts = hit_carts / num_carts
    recall_orders = hit_orders / num_orders
    w_recall_clicks = recall_clicks * 0.10
    w_recall_carts = recall_carts * 0.30
    w_recall_orders = recall_orders * 0.60
    score = w_recall_clicks + w_recall_carts + w_recall_orders

    results = {}
    results["num_clicks"] = num_clicks
    results["hit_clicks"] = hit_clicks
    results["num_carts"] = num_carts
    results["hit_carts"] = hit_carts
    results["num_orders"] = num_orders
    results["hit_orders"] = hit_orders
    results["recall_clicks"] = format(recall_clicks, ".3f")
    results["recall_carts"] = format(recall_carts, ".3f")
    results["recall_orders"] = format(recall_orders, ".3f")
    results["w_recall_clicks"] = format(w_recall_clicks, ".3f")
    results["w_recall_carts"] = format(w_recall_carts, ".3f")
    results["w_recall_orders"] = format(w_recall_orders, ".3f")
    results["score"] = format(score, ".3f")

    return results

# %%
class Candidate:
    @noglobal(excepts=["cfg", "logger"])
    def __init__(self, pdf, labels=None):
        self.df = cudf.from_pandas(pdf)
        self.target_sessions = pdf["session"].unique().tolist()
        self.results = pd.DataFrame(columns=["name", "num_clicks", "hit_clicks", "num_carts", "hit_carts", "num_orders", "hit_orders", 
                                             "recall_clicks", "recall_carts", "recall_orders", "w_recall_clicks", "w_recall_carts", "w_recall_orders", "score"])
        self.output = pd.DataFrame(columns=["session", "aid", "strategy", "rank"], dtype=int)
        self.labels = labels
    
    @noglobal(excepts=["cfg", "logger"])
    def _entry(self, new_candidate_df, name, k):
        logger.info(f"[add_candidate] {name} : start")
        new_candidate_df["strategy"] = name
        new_candidate_df[f"rank"] = new_candidate_df.groupby("session")["session"].cumcount() + 1
        new_candidate_df = new_candidate_df.to_pandas()
        self.output = pd.concat([self.output, new_candidate_df[["session", "aid", "strategy", "rank"]]])

        if self.labels is not None:
            self._eval(new_candidate_df[["session", "aid"]], name, k)
    
    @noglobal(excepts=["cfg", "logger"])
    def _eval(self, new_candidate_df, name, k):
        new_candidate_df = new_candidate_df.groupby("session")["aid"].apply(list).reset_index()
        eval_df = pd.DataFrame(self.target_sessions, columns=["session"])
        eval_df = eval_df.merge(new_candidate_df, on=["session"], how="left")
        assert eval_df["session"].tolist() == self.labels["session"].tolist()
        eval_result = evaluate(self.labels["clicks_labels"].tolist(), self.labels["carts_labels"].tolist(), self.labels["orders_labels"].tolist(),
                               eval_df["aid"].tolist(), eval_df["aid"].tolist(), eval_df["aid"].tolist(), k)
        
        logger.info(str(eval_result))
        self.results = pd.concat([self.results, pd.DataFrame([[name] + list(eval_result.values())], columns=["name"] + list(eval_result.keys()))])

    @noglobal(excepts=["cfg", "logger"])
    def add(self, strategy, name, usetypes=['clicks', 'carts', 'orders'], trans_map=None, k=20):
        logger.info(f"[make_candidate] {name} : start")
        candidate_df = self.df[self.df["type"].isin(usetypes)].copy()
        
        if strategy == "session_frequent":
            candidate_df = self._session_frequent(candidate_df, k)
        elif strategy == "session_latest":
            candidate_df = self._session_latest(candidate_df, k)
        elif strategy == "total_frequent":
            candidate_df = self._total_frequent(candidate_df, k)
        
        if trans_map is not None:
            candidate_df["aid"] = candidate_df["aid"].map(trans_map)
            candidate_df = candidate_df.dropna(subset=["aid"])
            
        self._entry(candidate_df, name, k)

    @noglobal(excepts=["cfg", "logger"])
    def _session_frequent(self, candidate_df, k):
        candidate_df = candidate_df.groupby(["session", "aid"])["ts"].count().reset_index()
        candidate_df.columns = ["session", "aid", "aid_count"]
        candidate_df = candidate_df.sort_values(["session", "aid_count", "aid"], ascending=(True, False, True))
        candidate_df = candidate_df[candidate_df.groupby("session")["aid_count"].cumcount() < k].copy()
        candidate_df = candidate_df[["session", "aid"]].copy()
        return candidate_df

    @noglobal(excepts=["cfg", "logger"])
    def _session_latest(self, candidate_df, k):
        candidate_df = candidate_df.sort_values(["session", "ts"], ascending=(True, False)).drop_duplicates(subset=["session", "aid"])
        candidate_df = candidate_df.sort_values(["session", "ts"], ascending=(True, False))[candidate_df.groupby("session")["ts"].cumcount() < k].copy()
        candidate_df = candidate_df[["session", "aid"]].copy()
        return candidate_df

    @noglobal(excepts=["cfg", "logger"])
    def _total_frequent(self, candidate_df, k):
        candidate_df = candidate_df.groupby("aid")["ts"].count().reset_index()
        candidate_df.columns = ["aid", "aid_count"]
        topk_freq_aids = candidate_df.sort_values("aid_count", ascending=False)["aid"].to_arrow().to_pylist()[:k]
        sessions = []
        aids = []
        for session, aid in itertools.product(self.target_sessions, topk_freq_aids):
            sessions.append(session)
            aids.append(aid)
        candidate_df = cudf.DataFrame({"session": sessions, "aid": aids})
        return candidate_df

# %%
@noglobal(excepts=["cfg", "logger"])
def make_cand_df(sessions, labels=None, trans_maps=None):

    if labels is not None:
         cand = Candidate(sessions, labels)
    else:
        cand = Candidate(sessions)

    cand.add(strategy="session_frequent", name="session_frequent")
    cand.add(strategy="session_latest", name="session_latest")
    cand.add(strategy="total_frequent", name="total_frequent")
    cand.add(strategy="session_frequent", trans_map=trans_maps["pair0"], name="session_frequent_pair")
    
    for i in range(5):
        cand.add(strategy="session_latest", trans_map=trans_maps[f"pair{str(i)}"], name=f"session_latest_pair{str(i)}")
      
    cand.add(strategy="session_frequent", trans_map=trans_maps["clicks_pair"], name="session_frequent_clicks_pair")
    cand.add(strategy="session_latest", trans_map=trans_maps["clicks_pair"], name="session_latest_clicks_pair")
    # cand.add(strategy="session_frequent", trans_map=trans_maps["carts_pair"], name="session_frequent_carts_pair")
    cand.add(strategy="session_latest", trans_map=trans_maps["carts_pair"], name="session_latest_carts_pair")
    cand.add(strategy="session_latest", trans_map=trans_maps["time_wt_pair"], name="session_latest_time_wt_pair")
    cand.add(strategy="session_latest", trans_map=trans_maps["type_wt_pair"], name="session_latest_type_wt_pair")
    cand.add(strategy="session_latest", trans_map=trans_maps["clicks_time_wt_pair"], name="session_latest_clicks_time_wt_pair")
    cand.add(strategy="session_latest", trans_map=trans_maps["clicks_carts_pair"], name="session_latest_clicks_carts_pair")
    cand.add(strategy="session_latest", trans_map=trans_maps["clicks_orders_pair"], name="session_latest_clicks_orders_pair")
    # cand.add(strategy="session_frequent", trans_map=trans_maps["orders_pair"], name="session_frequent_orders_pair")
    # cand.add(strategy="session_latest", trans_map=trans_maps["orders_pair"], name="session_latest_orders_pair")
    if labels is not None:
        return cand.output, cand.results
    else:
        return cand.output

# %%
@noglobal(excepts=["cfg", "logger"])
def get_trans_maps():
    """
    aidを別のaidに置き換えるmapping辞書を取得する
    """
    trans_maps = {}
    pair_df_org = pd.read_pickle(cfg.prep_dir + "co_visitation_matrix.pkl")
    pair_df_org = pair_df_org[pair_df_org["cnt"] > 3].copy()
    pair_df_org = pair_df_org.sort_values(["aid_x", "cnt"], ascending=(True, False))

    for i in range(5):
        pair_df = pair_df_org.groupby("aid_x").nth(i).reset_index()[["aid_x", "aid_y"]]
        pair_dict = {k: v for k, v in zip(pair_df["aid_x"].tolist(), pair_df["aid_y"].tolist())}
        trans_maps[f"pair{str(i)}"] = pair_dict

    pair_df = pd.read_pickle(cfg.prep_dir + "co_visitation_matrix_clicks.pkl")
    pair_df = pair_df[pair_df["cnt"] > 3].copy()
    pair_df = pair_df.sort_values(["aid_x", "cnt"], ascending=(True, False))
    pair_df = pair_df.groupby("aid_x").head(1)[["aid_x", "aid_y"]]
    pair_dict = {k: v for k, v in zip(pair_df["aid_x"].tolist(), pair_df["aid_y"].tolist())}
    trans_maps["clicks_pair"] = pair_dict

    pair_df = pd.read_pickle(cfg.prep_dir + "co_visitation_matrix_carts.pkl")
    pair_df = pair_df[pair_df["cnt"] > 3].copy()
    pair_df = pair_df.sort_values(["aid_x", "cnt"], ascending=(True, False))
    pair_df = pair_df.groupby("aid_x").head(1)[["aid_x", "aid_y"]]
    pair_dict = {k: v for k, v in zip(pair_df["aid_x"].tolist(), pair_df["aid_y"].tolist())}
    trans_maps["carts_pair"] = pair_dict

    pair_df = pd.read_pickle(cfg.prep_dir + "co_visitation_matrix_orders.pkl")
    pair_df = pair_df[pair_df["cnt"] > 3].copy()
    pair_df = pair_df.sort_values(["aid_x", "cnt"], ascending=(True, False))
    pair_df = pair_df.groupby("aid_x").head(1)[["aid_x", "aid_y"]]
    pair_dict = {k: v for k, v in zip(pair_df["aid_x"].tolist(), pair_df["aid_y"].tolist())}
    trans_maps["orders_pair"] = pair_dict

    pair_df = pd.read_pickle(cfg.prep_dir + "co_visitation_matrix_time_weighted.pkl")
    pair_df = pair_df.sort_values(["aid_x", "wt"], ascending=(True, False))
    pair_df = pair_df.groupby("aid_x").head(1)[["aid_x", "aid_y"]]
    pair_dict = {k: v for k, v in zip(pair_df["aid_x"].tolist(), pair_df["aid_y"].tolist())}
    trans_maps["time_wt_pair"] = pair_dict

    pair_df = pd.read_pickle(cfg.prep_dir + "co_visitation_matrix_type_weighted.pkl")
    pair_df = pair_df.sort_values(["aid_x", "wt"], ascending=(True, False))
    pair_df = pair_df.groupby("aid_x").head(1)[["aid_x", "aid_y"]]
    pair_dict = {k: v for k, v in zip(pair_df["aid_x"].tolist(), pair_df["aid_y"].tolist())}
    trans_maps["type_wt_pair"] = pair_dict

    pair_df = pd.read_pickle(cfg.prep_dir + "co_visitation_matrix_clicks_time_weighted.pkl")
    pair_df = pair_df.sort_values(["aid_x", "wt"], ascending=(True, False))
    pair_df = pair_df.groupby("aid_x").head(1)[["aid_x", "aid_y"]]
    pair_dict = {k: v for k, v in zip(pair_df["aid_x"].tolist(), pair_df["aid_y"].tolist())}
    trans_maps["clicks_time_wt_pair"] = pair_dict

    pair_df = pd.read_pickle(cfg.prep_dir + "co_visitation_matrix_clicks_carts.pkl")
    pair_df = pair_df.sort_values(["aid_x", "cnt"], ascending=(True, False))
    pair_df = pair_df.groupby("aid_x").head(1)[["aid_x", "aid_y"]]
    pair_dict = {k: v for k, v in zip(pair_df["aid_x"].tolist(), pair_df["aid_y"].tolist())}
    trans_maps["clicks_carts_pair"] = pair_dict

    pair_df = pd.read_pickle(cfg.prep_dir + "co_visitation_matrix_clicks_orders.pkl")
    pair_df = pair_df.sort_values(["aid_x", "cnt"], ascending=(True, False))
    pair_df = pair_df.groupby("aid_x").head(1)[["aid_x", "aid_y"]]
    pair_dict = {k: v for k, v in zip(pair_df["aid_x"].tolist(), pair_df["aid_y"].tolist())}
    trans_maps["clicks_orders_pair"] = pair_dict

    return trans_maps

# %%
class Cache:
    @noglobal(excepts=["cfg", "logger"])
    def __init__(self):
        self.cache_dir = (os.path.join(cfg.output_dir, cfg.exp_name, "cache"))
        self.cache_dir_path = pathlib.Path(self.cache_dir)
        self.caches = list(self.cache_dir_path.glob("*.pkl"))

    @noglobal(excepts=["cfg", "logger"])
    def get_abspath(self, filename):
        return (os.path.join(self.cache_dir, f"{cfg.exp_name}_{filename}"))
    
    @noglobal(excepts=["cfg", "logger"])
    def exists(self, path):
        return len([str(c) for c in self.caches if path == str(c)]) > 0

# %%
@noglobal(excepts=["cfg", "logger"])
def make_valid_data(trans_maps):
    valid_week = cfg.valid_week
    dfs = []
    
    logger.info(f"[make_valid] valid_week : {valid_week}")
    # データ読み込み
    logger.info("[make_valid] read_data : start")
    week_sessions = pd.read_pickle(os.getenv("PREP_DIR") + f"train_sessions_{valid_week}.pkl")
    week_labels = pd.read_pickle(os.getenv("PREP_DIR") + f"labels_{valid_week}.pkl")
    valid_session_ids = week_sessions["session"].unique().tolist()
    logger.info("[make_valid] read_data : end")

    # validに使うsessionを絞る (trainに存在するsessionを除外した上で設定した数に絞る)
    logger.info("[make_valid] valid_session_extract : start")
    valid_session_n = min(cfg.valid_session_n, len(valid_session_ids))
    valid_session_ids = random.sample(valid_session_ids, valid_session_n)
    week_sessions = week_sessions[week_sessions["session"].isin(valid_session_ids)].copy()
    week_labels = week_labels[week_labels["session"].isin(valid_session_ids)].copy()
    logger.info("[make_valid] valid_session_extract : end")

    # 候補選出
    logger.info("[make_valid] make_cand_df : start")
    valid, results = make_cand_df(week_sessions, labels=week_labels, trans_maps=trans_maps)

    return valid, week_labels, results

# %%
@noglobal(excepts=["cfg", "logger"])
def make_test_data(trans_maps):
    # testデータ作成
    test_sessions = pd.read_pickle(cfg.prep_dir + f"test_sessions.pkl")

    dfs =[]
    # 候補選出
    logger.info("[make_test] make_cand_df")
    test = make_cand_df(test_sessions, trans_maps=trans_maps)
    return test

# %%
logger.info(f"START")
line_notify.send(f"{cfg.exp_name} | START")

cache = Cache()

logger.info(f"-------- get_trans_maps --------")
cache_path = cache.get_abspath("trans_maps.pkl")
if cache.exists(cache_path):
    logger.info("cache exists. load cache and skip process.")
    with open(cache_path, "rb") as f:
        trans_maps = pickle.load(f)
else:
    trans_maps = get_trans_maps()
    with open(cache_path, "wb") as f:
        pickle.dump(trans_maps, f)

valid, valid_labels, results = make_valid_data(trans_maps)
# Out:
# 0:00:00.443043 	 START
# 0:00:04.210211 	 -------- get_trans_maps --------
# 0:01:14.673336 	 [make_valid] valid_week : week4
# 0:01:14.674330 	 [make_valid] read_data : start
# 0:01:23.507267 	 [make_valid] read_data : end
# 0:01:23.508335 	 [make_valid] valid_session_extract : start
# 0:01:24.495709 	 [make_valid] valid_session_extract : end
# 0:01:24.496983 	 [make_valid] make_cand_df : start
# 0:01:24.577126 	 [make_candidate] session_frequent : start
# 0:01:24.926368 	 [add_candidate] session_frequent : start
# 0:01:26.571859 	 {'num_clicks': 97136, 'hit_clicks': 29631, 'num_carts': 43211, 'hit_carts': 10937, 'num_orders': 20082, 'hit_orders': 10387, 'recall_clicks': '0.305', 'recall_carts': '0.253', 'recall_orders': '0.517', 'w_recall_clicks': '0.031', 'w_recall_carts': '0.076', 'w_recall_orders': '0.310', 'score': '0.417'}
# 0:01:26.583781 	 [make_candidate] session_latest : start
# 0:01:26.885197 	 [add_candidate] session_latest : start
# 0:01:28.592304 	 {'num_clicks': 97136, 'hit_clicks': 29762, 'num_carts': 43211, 'hit_carts': 10988, 'num_orders': 20082, 'hit_orders': 10168, 'recall_clicks': '0.306', 'recall_carts': '0.254', 'recall_orders': '0.506', 'w_recall_clicks': '0.031', 'w_recall_carts': '0.076', 'w_recall_orders': '0.304', 'score': '0.411'}
# 0:01:28.603811 	 [make_candidate] total_frequent : start
# 0:01:29.034789 	 [add_candidate] total_frequent : start
# 0:01:31.065924 	 {'num_clicks': 97136, 'hit_clicks': 1392, 'num_carts': 43211, 'hit_carts': 617, 'num_orders': 20082, 'hit_orders': 112, 'recall_clicks': '0.014', 'recall_carts': '0.014', 'recall_orders': '0.006', 'w_recall_clicks': '0.001', 'w_recall_carts': '0.004', 'w_recall_orders': '0.003', 'score': '0.009'}
# 0:01:31.099373 	 [make_candidate] session_frequent_pair : start
# 0:01:31.455675 	 [add_candidate] session_frequent_pair : start
# 0:01:33.078172 	 {'num_clicks': 97136, 'hit_clicks': 7719, 'num_carts': 43211, 'hit_carts': 3394, 'num_orders': 20082, 'hit_orders': 2563, 'recall_clicks': '0.079', 'recall_carts': '0.079', 'recall_orders': '0.128', 'w_recall_clicks': '0.008', 'w_recall_carts': '0.024', 'w_recall_orders': '0.077', 'score': '0.108'}
# 0:01:33.091045 	 [make_candidate] session_latest_pair0 : start
# 0:01:33.627418 	 [add_candidate] session_latest_pair0 : start
# 0:01:35.399093 	 {'num_clicks': 97136, 'hit_clicks': 7761, 'num_carts': 43211, 'hit_carts': 3395, 'num_orders': 20082, 'hit_orders': 2555, 'recall_clicks': '0.080', 'recall_carts': '0.079', 'recall_orders': '0.127', 'w_recall_clicks': '0.008', 'w_recall_carts': '0.024', 'w_recall_orders': '0.076', 'score': '0.108'}
# 0:01:35.412734 	 [make_candidate] session_latest_pair1 : start
# 0:01:35.932342 	 [add_candidate] session_latest_pair1 : start
# 0:01:37.727745 	 {'num_clicks': 97136, 'hit_clicks': 5561, 'num_carts': 43211, 'hit_carts': 2790, 'num_orders': 20082, 'hit_orders': 1967, 'recall_clicks': '0.057', 'recall_carts': '0.065', 'recall_orders': '0.098', 'w_recall_clicks': '0.006', 'w_recall_carts': '0.019', 'w_recall_orders': '0.059', 'score': '0.084'}
# 0:01:37.740683 	 [make_candidate] session_latest_pair2 : start
# 0:01:38.109884 	 [add_candidate] session_latest_pair2 : start
# 0:01:39.877281 	 {'num_clicks': 97136, 'hit_clicks': 4430, 'num_carts': 43211, 'hit_carts': 2395, 'num_orders': 20082, 'hit_orders': 1808, 'recall_clicks': '0.046', 'recall_carts': '0.055', 'recall_orders': '0.090', 'w_recall_clicks': '0.005', 'w_recall_carts': '0.017', 'w_recall_orders': '0.054', 'score': '0.075'}
# 0:01:39.890732 	 [make_candidate] session_latest_pair3 : start
# 0:01:40.419325 	 [add_candidate] session_latest_pair3 : start
# 0:01:42.192883 	 {'num_clicks': 97136, 'hit_clicks': 3722, 'num_carts': 43211, 'hit_carts': 2083, 'num_orders': 20082, 'hit_orders': 1568, 'recall_clicks': '0.038', 'recall_carts': '0.048', 'recall_orders': '0.078', 'w_recall_clicks': '0.004', 'w_recall_carts': '0.014', 'w_recall_orders': '0.047', 'score': '0.065'}
# 0:01:42.207638 	 [make_candidate] session_latest_pair4 : start
# 0:01:42.664271 	 [add_candidate] session_latest_pair4 : start
# 0:01:44.442765 	 {'num_clicks': 97136, 'hit_clicks': 3158, 'num_carts': 43211, 'hit_carts': 1876, 'num_orders': 20082, 'hit_orders': 1410, 'recall_clicks': '0.033', 'recall_carts': '0.043', 'recall_orders': '0.070', 'w_recall_clicks': '0.003', 'w_recall_carts': '0.013', 'w_recall_orders': '0.042', 'score': '0.058'}
# 0:01:44.456881 	 [make_candidate] session_frequent_clicks_pair : start
# 0:01:44.757581 	 [add_candidate] session_frequent_clicks_pair : start
# 0:01:46.440426 	 {'num_clicks': 97136, 'hit_clicks': 7706, 'num_carts': 43211, 'hit_carts': 2878, 'num_orders': 20082, 'hit_orders': 1963, 'recall_clicks': '0.079', 'recall_carts': '0.067', 'recall_orders': '0.098', 'w_recall_clicks': '0.008', 'w_recall_carts': '0.020', 'w_recall_orders': '0.059', 'score': '0.087'}
# 0:01:46.453726 	 [make_candidate] session_latest_clicks_pair : start
# 0:01:46.857651 	 [add_candidate] session_latest_clicks_pair : start
# 0:01:48.683796 	 {'num_clicks': 97136, 'hit_clicks': 7746, 'num_carts': 43211, 'hit_carts': 2892, 'num_orders': 20082, 'hit_orders': 1955, 'recall_clicks': '0.080', 'recall_carts': '0.067', 'recall_orders': '0.097', 'w_recall_clicks': '0.008', 'w_recall_carts': '0.020', 'w_recall_orders': '0.058', 'score': '0.086'}
# 0:01:48.698581 	 [make_candidate] session_latest_carts_pair : start
# 0:01:49.097744 	 [add_candidate] session_latest_carts_pair : start
# 0:01:50.698417 	 {'num_clicks': 97136, 'hit_clicks': 4225, 'num_carts': 43211, 'hit_carts': 2380, 'num_orders': 20082, 'hit_orders': 1834, 'recall_clicks': '0.043', 'recall_carts': '0.055', 'recall_orders': '0.091', 'w_recall_clicks': '0.004', 'w_recall_carts': '0.017', 'w_recall_orders': '0.055', 'score': '0.076'}
# 0:01:50.709991 	 [make_candidate] session_latest_time_wt_pair : start
# 0:01:51.126700 	 [add_candidate] session_latest_time_wt_pair : start
# 0:01:52.982478 	 {'num_clicks': 97136, 'hit_clicks': 8928, 'num_carts': 43211, 'hit_carts': 2866, 'num_orders': 20082, 'hit_orders': 2121, 'recall_clicks': '0.092', 'recall_carts': '0.066', 'recall_orders': '0.106', 'w_recall_clicks': '0.009', 'w_recall_carts': '0.020', 'w_recall_orders': '0.063', 'score': '0.092'}
# 0:01:52.996537 	 [make_candidate] session_latest_type_wt_pair : start
# 0:01:53.473561 	 [add_candidate] session_latest_type_wt_pair : start
# 0:01:55.178142 	 {'num_clicks': 97136, 'hit_clicks': 7563, 'num_carts': 43211, 'hit_carts': 3986, 'num_orders': 20082, 'hit_orders': 3079, 'recall_clicks': '0.078', 'recall_carts': '0.092', 'recall_orders': '0.153', 'w_recall_clicks': '0.008', 'w_recall_carts': '0.028', 'w_recall_orders': '0.092', 'score': '0.127'}
# 0:01:55.191720 	 [make_candidate] session_latest_clicks_time_wt_pair : start
# 0:01:55.528720 	 [add_candidate] session_latest_clicks_time_wt_pair : start
# 0:01:57.369958 	 {'num_clicks': 97136, 'hit_clicks': 8973, 'num_carts': 43211, 'hit_carts': 2687, 'num_orders': 20082, 'hit_orders': 1893, 'recall_clicks': '0.092', 'recall_carts': '0.062', 'recall_orders': '0.094', 'w_recall_clicks': '0.009', 'w_recall_carts': '0.019', 'w_recall_orders': '0.057', 'score': '0.084'}
# 0:01:57.383965 	 [make_candidate] session_latest_clicks_carts_pair : start
# 0:01:57.751149 	 [add_candidate] session_latest_clicks_carts_pair : start
# 0:01:59.565355 	 {'num_clicks': 97136, 'hit_clicks': 4789, 'num_carts': 43211, 'hit_carts': 3195, 'num_orders': 20082, 'hit_orders': 2119, 'recall_clicks': '0.049', 'recall_carts': '0.074', 'recall_orders': '0.106', 'w_recall_clicks': '0.005', 'w_recall_carts': '0.022', 'w_recall_orders': '0.063', 'score': '0.090'}
# 0:01:59.578134 	 [make_candidate] session_latest_clicks_orders_pair : start
# 0:01:59.952647 	 [add_candidate] session_latest_clicks_orders_pair : start
# 0:02:01.719482 	 {'num_clicks': 97136, 'hit_clicks': 3102, 'num_carts': 43211, 'hit_carts': 2175, 'num_orders': 20082, 'hit_orders': 2221, 'recall_clicks': '0.032', 'recall_carts': '0.050', 'recall_orders': '0.111', 'w_recall_clicks': '0.003', 'w_recall_carts': '0.015', 'w_recall_orders': '0.066', 'score': '0.085'}

# %%
results
# Out:
#                                  name num_clicks hit_clicks num_carts  \
# 0                    session_frequent      97136      29631     43211
# 0                      session_latest      97136      29762     43211
# 0                      total_frequent      97136       1392     43211
# 0               session_frequent_pair      97136       7719     43211
# 0                session_latest_pair0      97136       7761     43211
# 0                session_latest_pair1      97136       5561     43211
# 0                session_latest_pair2      97136       4430     43211
# 0                session_latest_pair3      97136       3722     43211
# 0                session_latest_pair4      97136       3158     43211
# 0        session_frequent_clicks_pair      97136       7706     43211
# 0          session_latest_clicks_pair      97136       7746     43211
# 0           session_latest_carts_pair      97136       4225     43211
# 0         session_latest_time_wt_pair      97136       8928     43211
# 0         session_latest_type_wt_pair      97136       7563     43211
# 0  session_latest_clicks_time_wt_pair      97136       8973     43211
# 0    session_latest_clicks_carts_pair      97136       4789     43211
# 0   session_latest_clicks_orders_pair      97136       3102     43211
#
#   hit_carts num_orders hit_orders recall_clicks recall_carts recall_orders  \
# 0     10937      20082      10387         0.305        0.253         0.517
# 0     10988      20082      10168         0.306        0.254         0.506
# 0       617      20082        112         0.014        0.014         0.006
# 0      3394      20082       2563         0.079        0.079         0.128
# 0      3395      20082       2555         0.080        0.079         0.127
# 0      2790      20082       1967         0.057        0.065         0.098
# 0      2395      20082       1808         0.046        0.055         0.090
# 0      2083      20082       1568         0.038        0.048         0.078
# 0      1876      20082       1410         0.033        0.043         0.070
# 0      2878      20082       1963         0.079        0.067         0.098
# 0      2892      20082       1955         0.080        0.067         0.097
# 0      2380      20082       1834         0.043        0.055         0.091
# 0      2866      20082       2121         0.092        0.066         0.106
# 0      3986      20082       3079         0.078        0.092         0.153
# 0      2687      20082       1893         0.092        0.062         0.094
# 0      3195      20082       2119         0.049        0.074         0.106
# 0      2175      20082       2221         0.032        0.050         0.111
#
#   w_recall_clicks w_recall_carts w_recall_orders  score
# 0           0.031          0.076           0.310  0.417
# 0           0.031          0.076           0.304  0.411
# 0           0.001          0.004           0.003  0.009
# 0           0.008          0.024           0.077  0.108
# 0           0.008          0.024           0.076  0.108
# 0           0.006          0.019           0.059  0.084
# 0           0.005          0.017           0.054  0.075
# 0           0.004          0.014           0.047  0.065
# 0           0.003          0.013           0.042  0.058
# 0           0.008          0.020           0.059  0.087
# 0           0.008          0.020           0.058  0.086
# 0           0.004          0.017           0.055  0.076
# 0           0.009          0.020           0.063  0.092
# 0           0.008          0.028           0.092  0.127
# 0           0.009          0.019           0.057  0.084
# 0           0.005          0.022           0.063  0.090
# 0           0.003          0.015           0.066  0.085

# %%
fig, axs = plt.subplots(1, 3)
sns.heatmap(results.set_index("name")[["recall_clicks"]].astype(float),
            annot=True, linewidths=.5, fmt="1.2f", cmap="Reds", cbar=False, ax=axs[0])
sns.heatmap(results.set_index("name")[["recall_carts"]].astype(float),
            annot=True, linewidths=.5, fmt="1.2f", cmap="Reds", cbar=False, ax=axs[1], yticklabels=False)
sns.heatmap(results.set_index("name")[["recall_orders"]].astype(float),
            annot=True, linewidths=.5, fmt="1.2f", cmap="Reds", cbar=False, ax=axs[2], yticklabels=False)
plt.savefig(cfg.output_dir + f'{cfg.exp_name}/candidate_strategy_recalls.png')

# %%
# 予測値を全て使えたときのrecall
valid_all = valid.drop_duplicates(subset= ["session", "aid"])
session_cnt_max = valid_all["session"].value_counts().max()
valid_all = valid_all.groupby("session")["aid"].apply(list).reset_index()

all_results = evaluate(valid_labels["clicks_labels"].tolist(),
                       valid_labels["carts_labels"].tolist(),
                       valid_labels["orders_labels"].tolist(),
                       valid_all["aid"].tolist(),
                       valid_all["aid"].tolist(),
                       valid_all["aid"].tolist(),
                       session_cnt_max)
logger.info("all_pred_results")
logger.info(all_results)
# Out:
# 0:02:05.465083 	 all_pred_results
# 0:02:05.466483 	 {'num_clicks': 97136, 'hit_clicks': 43163, 'num_carts': 43611, 'hit_carts': 16801, 'num_orders': 20109, 'hit_orders': 12563, 'recall_clicks': '0.444', 'recall_carts': '0.385', 'recall_orders': '0.625', 'w_recall_clicks': '0.044', 'w_recall_carts': '0.116', 'w_recall_orders': '0.375', 'score': '0.535'}

# %%
def objective_type_recall(df, labels, type_):
    def objective(trial):
        trial_df = df.copy()
        session_frequent = trial.suggest_float("session_frequent", 0, 1)
        session_latest = trial.suggest_float("session_latest", 0, 1)
        total_frequent = trial.suggest_float("total_frequent", 0, 1)
        session_frequent_pair = trial.suggest_float("session_frequent_pair", 0, 1)
        session_latest_pair0 = trial.suggest_float("session_latest_pair0", 0, 1)
        session_latest_pair1 = trial.suggest_float("session_latest_pair1", 0, 1)
        session_latest_pair2 = trial.suggest_float("session_latest_pair2", 0, 1)
        session_latest_pair3 = trial.suggest_float("session_latest_pair3", 0, 1)
        session_latest_pair4 = trial.suggest_float("session_latest_pair4", 0, 1)
        session_frequent_clicks_pair  = trial.suggest_float("session_frequent_clicks_pair", 0, 1)
        session_latest_clicks_pair = trial.suggest_float("session_latest_clicks_pair", 0, 1)
        session_latest_carts_pair  = trial.suggest_float("session_latest_carts_pair", 0, 1)
        session_latest_time_wt_pair = trial.suggest_float("session_latest_time_wt_pair", 0, 1)
        session_latest_clicks_time_wt_pair = trial.suggest_float("session_latest_clicks_time_wt_pair", 0, 1)
        session_latest_type_wt_pair = trial.suggest_float("session_latest_type_wt_pair", 0, 1)
        session_latest_clicks_carts_pair = trial.suggest_float("session_latest_clicks_carts_pair", 0, 1)
        session_latest_clicks_orders_pair = trial.suggest_float("session_latest_clicks_orders_pair", 0, 1)

        wt_dict = {
            'session_frequent': session_frequent,
            'session_latest': session_latest, 
            'total_frequent': total_frequent,
            'session_frequent_pair': session_frequent_pair, 
            'session_latest_pair0': session_latest_pair0,
            'session_latest_pair1': session_latest_pair1, 
            'session_latest_pair2': session_latest_pair2,
            'session_latest_pair3': session_latest_pair3, 
            'session_latest_pair4': session_latest_pair4,
            'session_frequent_clicks_pair': session_frequent_clicks_pair, 
            'session_latest_clicks_pair': session_latest_clicks_pair,
            'session_latest_carts_pair': session_latest_carts_pair, 
            'session_latest_time_wt_pair': session_latest_time_wt_pair,
            'session_latest_clicks_time_wt_pair': session_latest_clicks_time_wt_pair,
            'session_latest_type_wt_pair': session_latest_type_wt_pair,
            'session_latest_clicks_carts_pair': session_latest_clicks_carts_pair,
            'session_latest_clicks_orders_pair': session_latest_clicks_orders_pair
        }

        trial_df["rank"] = trial_df["rank"] * trial_df["strategy"].map(wt_dict)
        trial_df = trial_df.sort_values(["session", "rank"])
        trial_df = trial_df.drop_duplicates(subset= ["session", "aid"], keep="first")
        trial_df = trial_df.groupby(["session"]).head(20)
        trial_df = trial_df.groupby("session")["aid"].apply(list).reset_index()

        result = evaluate(labels["clicks_labels"].tolist(),
                          labels["carts_labels"].tolist(),
                          labels["orders_labels"].tolist(),
                          trial_df["aid"].tolist(),
                          trial_df["aid"].tolist(),
                          trial_df["aid"].tolist(),
                          cfg.k)

        return float(result[f"recall_{type_}"])
    return objective

# %%
n_trials = 100

# %% [markdown]
# # パラメータチューニング

# %%
wt = {}
recall = {}

for type_ in ["clicks", "carts", "orders"]:
    logger.info(type_)
    study = optuna.create_study(direction="maximize")
    study.optimize(objective_type_recall(valid, valid_labels, type_), n_trials=n_trials)
    wt[type_] = study.best_params
    recall[type_] = study.best_value
    logger.info(f"{type_}_recall_best_value : {study.best_value}")

score = (recall["clicks"] * 0.1) + (recall["carts"] * 0.3) + (recall["orders"] * 0.6)
logger.info(f"SCORE : {score}")
# Out:
# 0:02:05.557996 	 clicks
# [I 2022-12-05 02:26:53,308] A new study created in memory with name: no-name-a5b27511-1fa3-4340-b136-37a33ae8719e
# [I 2022-12-05 02:26:58,506] Trial 0 finished with value: 0.413 and parameters: {'session_frequent': 0.9914982218395929, 'session_latest': 0.14980637230172167, 'total_frequent': 0.234144863346342, 'session_frequent_pair': 0.924017739146729, 'session_latest_pair0': 0.2134438014569412, 'session_latest_pair1': 0.6464114666523771, 'session_latest_pair2': 0.9077299740992274, 'session_latest_pair3': 0.3523742097842879, 'session_latest_pair4': 0.4131395721399669, 'session_frequent_clicks_pair': 0.3264688292255704, 'session_latest_clicks_pair': 0.42345790830264196, 'session_latest_carts_pair': 0.1460944604027089, 'session_latest_time_wt_pair': 0.5496826459380051, 'session_latest_clicks_time_wt_pair': 0.353807936430487, 'session_latest_type_wt_pair': 0.0035431729220953834, 'session_latest_clicks_carts_pair': 0.3016983158191455, 'session_latest_clicks_orders_pair': 0.3100512195578691}. Best is trial 0 with value: 0.413.
# [I 2022-12-05 02:27:03,701] Trial 1 finished with value: 0.387 and parameters: {'session_frequent': 0.04225858072203359, 'session_latest': 0.9305986463623372, 'total_frequent': 0.053889620262201565, 'session_frequent_pair': 0.044533787073481435, 'session_latest_pair0': 0.43702952986983645, 'session_latest_pair1': 0.9977453261776535, 'session_latest_pair2': 0.3610421591996892, 'session_latest_pair3': 0.5491458080186415, 'session_latest_pair4': 0.8064821077886097, 'session_frequent_clicks_pair': 0.262025576257332, 'session_latest_clicks_pair': 0.5701102489861812, 'session_latest_carts_pair': 0.5375941172876997, 'session_latest_time_wt_pair': 0.9152477156261933, 'session_latest_clicks_time_wt_pair': 0.5519170419727424, 'session_latest_type_wt_pair': 0.3707876434319106, 'session_latest_clicks_carts_pair': 0.9277995715053023, 'session_latest_clicks_orders_pair': 0.41517448195483575}. Best is trial 0 with value: 0.413.
# [I 2022-12-05 02:27:08,651] Trial 2 finished with value: 0.395 and parameters: {'session_frequent': 0.31819911288806413, 'session_latest': 0.7422529749699996, 'total_frequent': 0.16849300558961622, 'session_frequent_pair': 0.9977035610974778, 'session_latest_pair0': 0.13348410013264822, 'session_latest_pair1': 0.1830058822640963, 'session_latest_pair2': 0.9391935778758433, 'session_latest_pair3': 0.11421699035909494, 'session_latest_pair4': 0.9848997759773985, 'session_frequent_clicks_pair': 0.9034600424385603, 'session_latest_clicks_pair': 0.9824026994065339, 'session_latest_carts_pair': 0.2748310388862396, 'session_latest_time_wt_pair': 0.9484195327876445, 'session_latest_clicks_time_wt_pair': 0.8820826579694144, 'session_latest_type_wt_pair': 0.8639550210363783, 'session_latest_clicks_carts_pair': 0.9882149057264765, 'session_latest_clicks_orders_pair': 0.7141670447340466}. Best is trial 0 with value: 0.413.
# [I 2022-12-05 02:27:13,786] Trial 3 finished with value: 0.407 and parameters: {'session_frequent': 0.13861048621622696, 'session_latest': 0.5458227557963221, 'total_frequent': 0.19721776893617327, 'session_frequent_pair': 0.9108660238987614, 'session_latest_pair0': 0.2928932328304463, 'session_latest_pair1': 0.43503325200594156, 'session_latest_pair2': 0.010162214330611041, 'session_latest_pair3': 0.9123580766308513, 'session_latest_pair4': 0.3636830966548673, 'session_frequent_clicks_pair': 0.29054776787866576, 'session_latest_clicks_pair': 0.5142875660492542, 'session_latest_carts_pair': 0.404744502364323, 'session_latest_time_wt_pair': 0.734958797623961, 'session_latest_clicks_time_wt_pair': 0.21366121521440773, 'session_latest_type_wt_pair': 0.44308581022679816, 'session_latest_clicks_carts_pair': 0.7906320179989567, 'session_latest_clicks_orders_pair': 0.8050613500274321}. Best is trial 0 with value: 0.413.
# [I 2022-12-05 02:27:18,972] Trial 4 finished with value: 0.411 and parameters: {'session_frequent': 0.8538616156001275, 'session_latest': 0.30645198369900917, 'total_frequent': 0.7769088830169415, 'session_frequent_pair': 0.6548376313530312, 'session_latest_pair0': 0.23917036053073104, 'session_latest_pair1': 0.8095209053720906, 'session_latest_pair2': 0.7268034948670664, 'session_latest_pair3': 0.8837709185665908, 'session_latest_pair4': 0.017828716811133405, 'session_frequent_clicks_pair': 0.921708582502679, 'session_latest_clicks_pair': 0.8925755043950365, 'session_latest_carts_pair': 0.25421750402455967, 'session_latest_time_wt_pair': 0.7467718566053324, 'session_latest_clicks_time_wt_pair': 0.7712759520834465, 'session_latest_type_wt_pair': 0.45775509583481666, 'session_latest_clicks_carts_pair': 0.2852091804047182, 'session_latest_clicks_orders_pair': 0.9044070661134086}. Best is trial 0 with value: 0.413.
# [I 2022-12-05 02:27:23,883] Trial 5 finished with value: 0.423 and parameters: {'session_frequent': 0.13614635263828756, 'session_latest': 0.875866338526018, 'total_frequent': 0.6127407463894872, 'session_frequent_pair': 0.955261798209304, 'session_latest_pair0': 0.8457710648688437, 'session_latest_pair1': 0.8562536885581794, 'session_latest_pair2': 0.38566999685696235, 'session_latest_pair3': 0.5004193205467147, 'session_latest_pair4': 0.2236116596260178, 'session_frequent_clicks_pair': 0.8845705270986849, 'session_latest_clicks_pair': 0.7985981935018318, 'session_latest_carts_pair': 0.27461754275936323, 'session_latest_time_wt_pair': 0.13819576316838544, 'session_latest_clicks_time_wt_pair': 0.8631673848483269, 'session_latest_type_wt_pair': 0.28589503943773675, 'session_latest_clicks_carts_pair': 0.8259189221940159, 'session_latest_clicks_orders_pair': 0.9190404237287165}. Best is trial 5 with value: 0.423.
. Best is trial 65 with value: 0.572.
# [I 2022-12-05 02:51:38,547] Trial 90 finished with value: 0.52 and parameters: {'session_frequent': 0.09106042327370509, 'session_latest': 0.9436567888201766, 'total_frequent': 0.6177871560564263, 'session_frequent_pair': 0.8596427879180074, 'session_latest_pair0': 0.0435650429207787, 'session_latest_pair1': 0.7379676706395569, 'session_latest_pair2': 0.724849889265346, 'session_latest_pair3': 0.4265605880724156, 'session_latest_pair4': 0.2041460774525758, 'session_frequent_clicks_pair': 0.4559615575658829, 'session_latest_clicks_pair': 0.9973340155917554, 'session_latest_carts_pair': 0.39948523913459066, 'session_latest_time_wt_pair': 0.8866021386772772, 'session_latest_clicks_time_wt_pair': 0.9419921727780436, 'session_latest_type_wt_pair': 0.18503933183185906, 'session_latest_clicks_carts_pair': 0.31955585871467806, 'session_latest_clicks_orders_pair': 0.7689976829639398}. Best is trial 65 with value: 0.572.
# [I 2022-12-05 02:51:43,850] Trial 91 finished with value: 0.565 and parameters: {'session_frequent': 0.021842991747076428, 'session_latest': 0.6732333509417476, 'total_frequent': 0.5603527193150986, 'session_frequent_pair': 0.7707743501343607, 'session_latest_pair0': 0.1392525402962288, 'session_latest_pair1': 0.8068514449020999, 'session_latest_pair2': 0.6098051061537539, 'session_latest_pair3': 0.8082498218170157, 'session_latest_pair4': 0.3646823301149027, 'session_frequent_clicks_pair': 0.8251887898257796, 'session_latest_clicks_pair': 0.4322946029277305, 'session_latest_carts_pair': 0.14924384798380108, 'session_latest_time_wt_pair': 0.5598530246071433, 'session_latest_clicks_time_wt_pair': 0.9748981961496266, 'session_latest_type_wt_pair': 0.3260536817229696, 'session_latest_clicks_carts_pair': 0.0918113046078212, 'session_latest_clicks_orders_pair': 0.6956174687686358}. Best is trial 65 with value: 0.572.
# [I 2022-12-05 02:51:49,037] Trial 92 finished with value: 0.528 and parameters: {'session_frequent': 0.04730662105909599, 'session_latest': 0.7105740218875212, 'total_frequent': 0.5154573477655384, 'session_frequent_pair': 0.8231192021031556, 'session_latest_pair0': 0.11433806269511934, 'session_latest_pair1': 0.9697180820543003, 'session_latest_pair2': 0.5404220885009042, 'session_latest_pair3': 0.7880725916007225, 'session_latest_pair4': 0.29417188803756533, 'session_frequent_clicks_pair': 0.8706081685732734, 'session_latest_clicks_pair': 0.3526951398622295, 'session_latest_carts_pair': 0.08089957804796533, 'session_latest_time_wt_pair': 0.6958686206592914, 'session_latest_clicks_time_wt_pair': 0.8549202276442398, 'session_latest_type_wt_pair': 0.2465991303927874, 'session_latest_clicks_carts_pair': 0.032013337130115574, 'session_latest_clicks_orders_pair': 0.6054086304334463}. Best is trial 65 with value: 0.572.
# [I 2022-12-05 02:51:54,027] Trial 93 finished with value: 0.565 and parameters: {'session_frequent': 0.02004464501745056, 'session_latest': 0.6317477142631535, 'total_frequent': 0.584830519883394, 'session_frequent_pair': 0.7986597300397805, 'session_latest_pair0': 0.08443492377249659, 'session_latest_pair1': 0.9184474945723967, 'session_latest_pair2': 0.5162508226965932, 'session_latest_pair3': 0.832550677762699, 'session_latest_pair4': 0.3975465768120373, 'session_frequent_cl
. Best is trial 65 with value: 0.572.
# [I 2022-12-05 02:52:14,843] Trial 97 finished with value: 0.426 and parameters: {'session_frequent': 0.5404189004226078, 'session_latest': 0.6906552340582784, 'total_frequent': 0.4979076774527209, 'session_frequent_pair': 0.6792641496867147, 'session_latest_pair0': 0.27653100787632917, 'session_latest_pair1': 0.8447276741650336, 'session_latest_pair2': 0.5796786192150293, 'session_latest_pair3': 0.6505862032952054, 'session_latest_pair4': 0.32693303643248944, 'session_frequent_clicks_pair': 0.4226794299609561, 'session_latest_clicks_pair': 0.5223168418119697, 'session_latest_carts_pair': 0.010456226172236321, 'session_latest_time_wt_pair': 0.7703809701737707, 'session_latest_clicks_time_wt_pair': 0.7883565220024594, 'session_latest_type_wt_pair': 0.36277730524548196, 'session_latest_clicks_carts_pair': 0.23213611646806492, 'session_latest_clicks_orders_pair': 0.8408572858868787}. Best is trial 65 with value: 0.572.
# [I 2022-12-05 02:52:20,035] Trial 98 finished with value: 0.435 and parameters: {'session_frequent': 0.7133292947348358, 'session_latest': 0.6043666619717935, 'total_frequent': 0.6421217963484213, 'session_frequent_pair': 0.8742166385556802, 'session_latest_pair0': 0.23999359275149681, 'session_latest_pair1': 0.8736909685593335, 'session_latest_pair2': 0.8544283743447706, 'session_latest_pair3': 0.3375294758429105, 'session_latest_pair4': 0.26961683722897783, 'session_frequent_clicks_pair': 0.49218239790358975, 'session_latest_clicks_pair': 0.16241697247414996, 'session_latest_carts_pair': 0.2162324479756224, 'session_latest_time_wt_pair': 0.6772056497773139, 'session_latest_clicks_time_wt_pair': 0.9299765550174514, 'session_latest_type_wt_pair': 0.13251121203984384, 'session_latest_clicks_carts_pair': 0.17428353901911836, 'session_latest_clicks_orders_pair': 0.9145924011402213}. Best is trial 65 with value: 0.572.
# [I 2022-12-05 02:52:25,095] Trial 99 finished with value: 0.544 and parameters: {'session_frequent': 0.043633270478618175, 'session_latest': 0.5762906326507693, 'total_frequent': 0.401804564538222, 'session_frequent_pair': 0.759098977530129, 'session_latest_pair0': 0.06727893825269023, 'session_latest_pair1': 0.8157124042577312, 'session_latest_pair2': 0.8069016762672362, 'session_latest_pair3': 0.5972820007568507, 'session_latest_pair4': 0.4774850580903709, 'session_frequent_clicks_pair': 0.7125208073763774, 'session_latest_clicks_pair': 0.7517057801283384, 'session_latest_carts_pair': 0.0515816080257848, 'session_latest_time_wt_pair': 0.8431339527310576, 'session_latest_clicks_time_wt_pair': 0.8604434317947038, 'session_latest_type_wt_pair': 0.10690471981384901, 'session_latest_clicks_carts_pair': 0.2763265709040214, 'session_latest_clicks_orders_pair': 0.9433219356871685}. Best is trial 65 with value: 0.572.
# 0:27:37.348019 	 orders_recall_best_value : 0.572
# 0:27:37.349475 	 SCORE : 0.4875999999999999

# %% [markdown]
# # sub作成

# %%
test = make_test_data(trans_maps)
sub = pd.read_csv(cfg.input_dir + f"sample_submission.csv", usecols=["session_type"])
dfs = []

for type_ in ["clicks", "carts", "orders"]:
    test_type = test.copy()
    test_type["rank"] 
    test_type["rank"] = test_type["rank"] * test_type["strategy"].map(wt[type_])
    test_type = test_type.sort_values(["session", "rank"])
    test_type = test_type.drop_duplicates(subset= ["session", "aid"], keep="first")
    test_type = test_type.groupby(["session"]).head(20)
    test_type["aid"] = test_type["aid"].astype(str)
    test_type = test_type.groupby("session")["aid"].apply(list).reset_index()
    test_type["aid"] = test_type["aid"].apply(lambda x: ' '.join(x))
    test_type["session_type"] = test_type["session"].astype(str) + f"_{type_}"
    test_type =test_type.rename(columns={"aid": "labels"})
    dfs.append(test_type)
test_preds = pd.concat(dfs)

sub = sub.merge(test_preds, on="session_type", how="left")
sub[["session_type", "labels"]].to_csv(cfg.output_dir + f"{cfg.exp_name}/{cfg.exp_name}_sub.csv", index=False)
# Out:
# 0:27:38.441807 	 [make_test] make_cand_df
# 0:27:38.738515 	 [make_candidate] session_frequent : start
# 0:27:39.191228 	 [add_candidate] session_frequent : start
# 0:27:39.559573 	 [make_candidate] session_latest : start
# 0:27:39.882427 	 [add_candidate] session_latest : start
# 0:27:40.278358 	 [make_candidate] total_frequent : start
# 0:27:46.317027 	 [add_candidate] total_frequent : start
# 0:27:48.901800 	 [make_candidate] session_frequent_pair : start
# 0:27:49.750029 	 [add_candidate] session_frequent_pair : start
# 0:27:50.636789 	 [make_candidate] session_latest_pair0 : start
# 0:27:51.414615 	 [add_candidate] session_latest_pair0 : start
# 0:27:52.302268 	 [make_candidate] session_latest_pair1 : start
# 0:27:52.984353 	 [add_candidate] session_latest_pair1 : start
# 0:27:54.212209 	 [make_candidate] session_latest_pair2 : start
# 0:27:54.710095 	 [add_candidate] session_latest_pair2 : start
# 0:27:55.820918 	 [make_candidate] session_latest_pair3 : start
# 0:27:56.494731 	 [add_candidate] session_latest_pair3 : start
# 0:27:57.674757 	 [make_candidate] session_latest_pair4 : start
# 0:27:58.158372 	 [add_candidate] session_latest_pair4 : start
# 0:27:59.238955 	 [make_candidate] session_frequent_clicks_pair : start
# 0:27:59.911482 	 [add_candidate] session_frequent_clicks_pair : start
# 0:28:01.393559 	 [make_candidate] session_latest_clicks_pair : start
# 0:28:01.984701 	 [add_candidate] session_latest_clicks_pair : start
# 0:28:03.408962 	 [make_candidate] session_latest_carts_pair : start
# 0:28:04.100157 	 [add_candidate] session_latest_carts_pair : start
# 0:28:05.455808 	 [make_candidate] session_latest_time_wt_pair : start
# 0:28:06.083578 	 [add_candidate] session_latest_time_wt_pair : start
# 0:28:07.473986 	 [make_candidate] session_latest_type_wt_pair : start
# 0:28:08.354003 	 [add_candidate] session_latest_type_wt_pair : start
# 0:28:09.816849 	 [make_candidate] session_latest_clicks_time_wt_pair : start
# 0:28:10.759281 	 [add_candidate] session_latest_clicks_time_wt_pair : start
# 0:28:12.260953 	 [make_candidate] session_latest_clicks_carts_pair : start
# 0:28:13.132253 	 [add_candidate] session_latest_clicks_carts_pair : start
# 0:28:14.699184 	 [make_candidate] session_latest_clicks_orders_pair : start
# 0:28:15.596958 	 [add_candidate] session_latest_clicks_orders_pair : start

# %%
sub.head()
# Out:
#       session_type   session  \
# 0  12899779_clicks  12899779
# 1   12899779_carts  12899779
# 2  12899779_orders  12899779
# 3  12899780_clicks  12899780
# 4   12899780_carts  12899780
#
#                                               labels
# 0  59625 737445 1854910 894169 1130911 225209 485...
# 1  59625 1130911 894169 1854910 737445 485256 225...
# 2  59625 1130911 225209 737445 485256 1854910 894...
# 3  1142000 1502122 582732 1712906 889686 736515 4...
# 4  1142000 1502122 736515 636101 1712906 973453 4...
