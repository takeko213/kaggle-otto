# %% [markdown]
# # exp028
# rank数調整

# %%
import os
import sys
import traceback
import gc
import random
import pickle
import pathlib
import subprocess
from dataclasses import dataclass
from dotenv import load_dotenv
load_dotenv
sys.path.append(os.getenv('UTILS_PATH'))
from tqdm import tqdm
import multiprocessing
import inspect

import pandas as pd
import numpy as np
import itertools
import cudf
import lightgbm as lgb
import matplotlib.pyplot as plt
import seaborn as sns
import line_notify
import my_logger
from noglobal import noglobal
import optuna

# %% [markdown]
# # 設定

# %%
@dataclass
class Cfg:
    loglevel = "INFO"
    exp_name = "exp028"
    seed = 42
    k = 20
    cand_n = 10
    type2id = {"clicks":0, "carts":1, "orders":2}
    id2type = {0:"clicks", 1:"carts", 2:"orders"}
    train_weeks = ["week3"]
    valid_week = "week4"
    valid_session_n = 100_000
    input_dir = os.getenv('INPUT_DIR')
    output_dir = os.getenv('OUTPUT_DIR')
    prep_dir = os.getenv("PREP_DIR")

cfg = Cfg()
os.makedirs(os.path.join(cfg.output_dir, cfg.exp_name), exist_ok=True)
os.makedirs(os.path.join(cfg.output_dir, cfg.exp_name, "cache"), exist_ok=True)
random.seed(cfg.seed)

logger = my_logger.init_logger(cfg.exp_name)

# %%
@noglobal(excepts=["cfg", "logger"])
def evaluate(clicks_labels, carts_labels, orders_labels, 
             clicks_preds, carts_preds, orders_preds, k=20):

    num_clicks = 0
    num_carts = 0
    num_orders = 0
    hit_clicks = 0
    hit_carts = 0
    hit_orders = 0

    for i in range(len(clicks_labels)):
        clicks_label = clicks_labels[i]
        carts_label = carts_labels[i]
        orders_label = orders_labels[i]
        clicks_pred = clicks_preds[i]
        carts_pred = carts_preds[i]
        orders_pred = orders_preds[i]

        if type(clicks_pred) == list:
            clicks_pred = clicks_pred[:k]
        else:
            clicks_pred = []
        if type(carts_pred) == list:
            carts_pred = carts_pred[:k]
        else:
            carts_pred = []    
        if type(orders_pred) == list:
            orders_pred = orders_pred[:k]
        else:
            orders_pred = []

        if not np.isnan(clicks_label):
            num_clicks += 1
            hit_clicks += int(clicks_label in clicks_pred)

        if type(carts_label) == list:
            num_carts += min(len(carts_label), k)
            hit_carts += len(set(carts_pred) & set(carts_label))
            
        if type(orders_label) == list:
            num_orders += min(len(orders_label), k)
            hit_orders += len(set(orders_pred) & set(orders_label))


    recall_clicks = hit_clicks / num_clicks
    recall_carts = hit_carts / num_carts
    recall_orders = hit_orders / num_orders
    w_recall_clicks = recall_clicks * 0.10
    w_recall_carts = recall_carts * 0.30
    w_recall_orders = recall_orders * 0.60
    score = w_recall_clicks + w_recall_carts + w_recall_orders

    results = {}
    results["num_clicks"] = num_clicks
    results["hit_clicks"] = hit_clicks
    results["num_carts"] = num_carts
    results["hit_carts"] = hit_carts
    results["num_orders"] = num_orders
    results["hit_orders"] = hit_orders
    results["recall_clicks"] = format(recall_clicks, ".3f")
    results["recall_carts"] = format(recall_carts, ".3f")
    results["recall_orders"] = format(recall_orders, ".3f")
    results["w_recall_clicks"] = format(w_recall_clicks, ".3f")
    results["w_recall_carts"] = format(w_recall_carts, ".3f")
    results["w_recall_orders"] = format(w_recall_orders, ".3f")
    results["score"] = format(score, ".3f")

    return results

# %%
class Candidate:
    @noglobal(excepts=["cfg", "logger"])
    def __init__(self, pdf, labels=None):
        self.df = cudf.from_pandas(pdf)
        self.target_sessions = pdf["session"].unique().tolist()
        self.results = pd.DataFrame(columns=["name", "num_clicks", "hit_clicks", "num_carts", "hit_carts", "num_orders", "hit_orders", 
                                             "recall_clicks", "recall_carts", "recall_orders", "w_recall_clicks", "w_recall_carts", "w_recall_orders", "score"])
        self.output = pd.DataFrame(columns=["session", "aid", "strategy", "rank"], dtype=int)
        self.labels = labels
    
    @noglobal(excepts=["cfg", "logger"])
    def _entry(self, new_candidate_df, name, k):
        logger.info(f"[add_candidate] {name} : start")
        new_candidate_df["strategy"] = name
        new_candidate_df[f"rank"] = new_candidate_df.groupby("session")["session"].cumcount() + 1
        new_candidate_df = new_candidate_df.to_pandas()
        self.output = pd.concat([self.output, new_candidate_df[["session", "aid", "strategy", "rank"]]])

        if self.labels is not None:
            self._eval(new_candidate_df[["session", "aid"]], name, k)
    
    @noglobal(excepts=["cfg", "logger"])
    def _eval(self, new_candidate_df, name, k):
        new_candidate_df = new_candidate_df.groupby("session")["aid"].apply(list).reset_index()
        eval_df = pd.DataFrame(self.target_sessions, columns=["session"])
        eval_df = eval_df.merge(new_candidate_df, on=["session"], how="left")
        assert eval_df["session"].tolist() == self.labels["session"].tolist()
        eval_result = evaluate(self.labels["clicks_labels"].tolist(), self.labels["carts_labels"].tolist(), self.labels["orders_labels"].tolist(),
                               eval_df["aid"].tolist(), eval_df["aid"].tolist(), eval_df["aid"].tolist(), k)
        
        logger.info(str(eval_result))
        self.results = pd.concat([self.results, pd.DataFrame([[name] + list(eval_result.values())], columns=["name"] + list(eval_result.keys()))])

    @noglobal(excepts=["cfg", "logger"])
    def add(self, strategy, name, usetypes=['clicks', 'carts', 'orders'], trans_map=None, k=20):
        logger.info(f"[make_candidate] {name} : start")
        candidate_df = self.df[self.df["type"].isin(usetypes)].copy()
        
        if strategy == "session_frequent":
            candidate_df = self._session_frequent(candidate_df, k)
        elif strategy == "session_latest":
            candidate_df = self._session_latest(candidate_df, k)
        elif strategy == "total_frequent":
            candidate_df = self._total_frequent(candidate_df, k)
        
        if trans_map is not None:
            candidate_df["aid"] = candidate_df["aid"].map(trans_map)
            candidate_df = candidate_df.dropna(subset=["aid"])
            
        self._entry(candidate_df, name, k)

    @noglobal(excepts=["cfg", "logger"])
    def _session_frequent(self, candidate_df, k):
        candidate_df = candidate_df.groupby(["session", "aid"])["ts"].count().reset_index()
        candidate_df.columns = ["session", "aid", "aid_count"]
        candidate_df = candidate_df.sort_values(["session", "aid_count", "aid"], ascending=(True, False, True))
        candidate_df = candidate_df[candidate_df.groupby("session")["aid_count"].cumcount() < k].copy()
        candidate_df = candidate_df[["session", "aid"]].copy()
        return candidate_df

    @noglobal(excepts=["cfg", "logger"])
    def _session_latest(self, candidate_df, k):
        candidate_df = candidate_df.sort_values(["session", "ts"], ascending=(True, False)).drop_duplicates(subset=["session", "aid"])
        candidate_df = candidate_df.sort_values(["session", "ts"], ascending=(True, False))[candidate_df.groupby("session")["ts"].cumcount() < k].copy()
        candidate_df = candidate_df[["session", "aid"]].copy()
        return candidate_df

    @noglobal(excepts=["cfg", "logger"])
    def _total_frequent(self, candidate_df, k):
        candidate_df = candidate_df.groupby("aid")["ts"].count().reset_index()
        candidate_df.columns = ["aid", "aid_count"]
        topk_freq_aids = candidate_df.sort_values("aid_count", ascending=False)["aid"].to_arrow().to_pylist()[:k]
        sessions = []
        aids = []
        for session, aid in itertools.product(self.target_sessions, topk_freq_aids):
            sessions.append(session)
            aids.append(aid)
        candidate_df = cudf.DataFrame({"session": sessions, "aid": aids})
        return candidate_df

# %%
@noglobal(excepts=["cfg", "logger"])
def make_cand_df(sessions, labels=None, trans_maps=None):

    if labels is not None:
         cand = Candidate(sessions, labels)
    else:
        cand = Candidate(sessions)

    cand.add(strategy="session_frequent", name="session_frequent", k=cfg.cand_n)
    cand.add(strategy="session_latest", name="session_latest", k=cfg.cand_n)
    # cand.add(strategy="total_frequent", name="total_frequent", k=cfg.cand_n)
    cand.add(strategy="session_frequent", trans_map=trans_maps["pair0"], name="session_frequent_pair", k=cfg.cand_n)
    
    for i in range(10):
        cand.add(strategy="session_latest", trans_map=trans_maps[f"pair{str(i)}"], name=f"session_latest_pair{str(i)}", k=cfg.cand_n)
      
    cand.add(strategy="session_frequent", trans_map=trans_maps["clicks_pair"], name="session_frequent_clicks_pair", k=cfg.cand_n)
    cand.add(strategy="session_latest", trans_map=trans_maps["clicks_pair"], name="session_latest_clicks_pair", k=cfg.cand_n)
    # cand.add(strategy="session_frequent", trans_map=trans_maps["carts_pair"], name="session_frequent_carts_pair")
    cand.add(strategy="session_latest", trans_map=trans_maps["carts_pair"], name="session_latest_carts_pair", k=cfg.cand_n)
    cand.add(strategy="session_latest", trans_map=trans_maps["time_wt_pair"], name="session_latest_time_wt_pair", k=cfg.cand_n)
    cand.add(strategy="session_latest", trans_map=trans_maps["type_wt_pair"], name="session_latest_type_wt_pair", k=cfg.cand_n)
    cand.add(strategy="session_latest", trans_map=trans_maps["clicks_time_wt_pair"], name="session_latest_clicks_time_wt_pair", k=cfg.cand_n)
    cand.add(strategy="session_latest", trans_map=trans_maps["clicks_carts_pair"], name="session_latest_clicks_carts_pair", k=cfg.cand_n)
    cand.add(strategy="session_latest", trans_map=trans_maps["clicks_orders_pair"], name="session_latest_clicks_orders_pair", k=cfg.cand_n)
    # cand.add(strategy="session_frequent", trans_map=trans_maps["orders_pair"], name="session_frequent_orders_pair")
    # cand.add(strategy="session_latest", trans_map=trans_maps["orders_pair"], name="session_latest_orders_pair")
    if labels is not None:
        return cand.output, cand.results
    else:
        return cand.output

# %%
@noglobal(excepts=["cfg", "logger"])
def get_trans_maps():
    """
    aidを別のaidに置き換えるmapping辞書を取得する
    """
    trans_maps = {}
    pair_df_org = pd.read_pickle(cfg.prep_dir + "co_visitation_matrix.pkl")
    pair_df_org = pair_df_org[pair_df_org["cnt"] > 3].copy()
    pair_df_org = pair_df_org.sort_values(["aid_x", "cnt"], ascending=(True, False))

    for i in range(10):
        pair_df = pair_df_org.groupby("aid_x").nth(i).reset_index()[["aid_x", "aid_y"]]
        pair_dict = {k: v for k, v in zip(pair_df["aid_x"].tolist(), pair_df["aid_y"].tolist())}
        trans_maps[f"pair{str(i)}"] = pair_dict

    pair_df = pd.read_pickle(cfg.prep_dir + "co_visitation_matrix_clicks.pkl")
    pair_df = pair_df[pair_df["cnt"] > 3].copy()
    pair_df = pair_df.sort_values(["aid_x", "cnt"], ascending=(True, False))
    pair_df = pair_df.groupby("aid_x").head(1)[["aid_x", "aid_y"]]
    pair_dict = {k: v for k, v in zip(pair_df["aid_x"].tolist(), pair_df["aid_y"].tolist())}
    trans_maps["clicks_pair"] = pair_dict

    pair_df = pd.read_pickle(cfg.prep_dir + "co_visitation_matrix_carts.pkl")
    pair_df = pair_df[pair_df["cnt"] > 3].copy()
    pair_df = pair_df.sort_values(["aid_x", "cnt"], ascending=(True, False))
    pair_df = pair_df.groupby("aid_x").head(1)[["aid_x", "aid_y"]]
    pair_dict = {k: v for k, v in zip(pair_df["aid_x"].tolist(), pair_df["aid_y"].tolist())}
    trans_maps["carts_pair"] = pair_dict

    pair_df = pd.read_pickle(cfg.prep_dir + "co_visitation_matrix_orders.pkl")
    pair_df = pair_df[pair_df["cnt"] > 3].copy()
    pair_df = pair_df.sort_values(["aid_x", "cnt"], ascending=(True, False))
    pair_df = pair_df.groupby("aid_x").head(1)[["aid_x", "aid_y"]]
    pair_dict = {k: v for k, v in zip(pair_df["aid_x"].tolist(), pair_df["aid_y"].tolist())}
    trans_maps["orders_pair"] = pair_dict

    pair_df = pd.read_pickle(cfg.prep_dir + "co_visitation_matrix_time_weighted.pkl")
    pair_df = pair_df.sort_values(["aid_x", "wt"], ascending=(True, False))
    pair_df = pair_df.groupby("aid_x").head(1)[["aid_x", "aid_y"]]
    pair_dict = {k: v for k, v in zip(pair_df["aid_x"].tolist(), pair_df["aid_y"].tolist())}
    trans_maps["time_wt_pair"] = pair_dict

    pair_df = pd.read_pickle(cfg.prep_dir + "co_visitation_matrix_type_weighted.pkl")
    pair_df = pair_df.sort_values(["aid_x", "wt"], ascending=(True, False))
    pair_df = pair_df.groupby("aid_x").head(1)[["aid_x", "aid_y"]]
    pair_dict = {k: v for k, v in zip(pair_df["aid_x"].tolist(), pair_df["aid_y"].tolist())}
    trans_maps["type_wt_pair"] = pair_dict

    pair_df = pd.read_pickle(cfg.prep_dir + "co_visitation_matrix_clicks_time_weighted.pkl")
    pair_df = pair_df.sort_values(["aid_x", "wt"], ascending=(True, False))
    pair_df = pair_df.groupby("aid_x").head(1)[["aid_x", "aid_y"]]
    pair_dict = {k: v for k, v in zip(pair_df["aid_x"].tolist(), pair_df["aid_y"].tolist())}
    trans_maps["clicks_time_wt_pair"] = pair_dict

    pair_df = pd.read_pickle(cfg.prep_dir + "co_visitation_matrix_clicks_carts.pkl")
    pair_df = pair_df.sort_values(["aid_x", "cnt"], ascending=(True, False))
    pair_df = pair_df.groupby("aid_x").head(1)[["aid_x", "aid_y"]]
    pair_dict = {k: v for k, v in zip(pair_df["aid_x"].tolist(), pair_df["aid_y"].tolist())}
    trans_maps["clicks_carts_pair"] = pair_dict

    pair_df = pd.read_pickle(cfg.prep_dir + "co_visitation_matrix_clicks_orders.pkl")
    pair_df = pair_df.sort_values(["aid_x", "cnt"], ascending=(True, False))
    pair_df = pair_df.groupby("aid_x").head(1)[["aid_x", "aid_y"]]
    pair_dict = {k: v for k, v in zip(pair_df["aid_x"].tolist(), pair_df["aid_y"].tolist())}
    trans_maps["clicks_orders_pair"] = pair_dict

    return trans_maps

# %%
class Cache:
    @noglobal(excepts=["cfg", "logger"])
    def __init__(self):
        self.cache_dir = (os.path.join(cfg.output_dir, cfg.exp_name, "cache"))
        self.cache_dir_path = pathlib.Path(self.cache_dir)
        self.caches = list(self.cache_dir_path.glob("*.pkl"))

    @noglobal(excepts=["cfg", "logger"])
    def get_abspath(self, filename):
        return (os.path.join(self.cache_dir, f"{cfg.exp_name}_{filename}"))
    
    @noglobal(excepts=["cfg", "logger"])
    def exists(self, path):
        return len([str(c) for c in self.caches if path == str(c)]) > 0

# %%
@noglobal(excepts=["cfg", "logger"])
def make_valid_data(trans_maps):
    valid_week = cfg.valid_week
    dfs = []
    
    logger.info(f"[make_valid] valid_week : {valid_week}")
    # データ読み込み
    logger.info("[make_valid] read_data : start")
    week_sessions = pd.read_pickle(os.getenv("PREP_DIR") + f"train_sessions_{valid_week}.pkl")
    week_labels = pd.read_pickle(os.getenv("PREP_DIR") + f"labels_{valid_week}.pkl")
    valid_session_ids = week_sessions["session"].unique().tolist()
    logger.info("[make_valid] read_data : end")

    # validに使うsessionを絞る (trainに存在するsessionを除外した上で設定した数に絞る)
    logger.info("[make_valid] valid_session_extract : start")
    valid_session_n = min(cfg.valid_session_n, len(valid_session_ids))
    valid_session_ids = random.sample(valid_session_ids, valid_session_n)
    week_sessions = week_sessions[week_sessions["session"].isin(valid_session_ids)].copy()
    week_labels = week_labels[week_labels["session"].isin(valid_session_ids)].copy()
    logger.info("[make_valid] valid_session_extract : end")

    # 候補選出
    logger.info("[make_valid] make_cand_df : start")
    valid, results = make_cand_df(week_sessions, labels=week_labels, trans_maps=trans_maps)

    return valid, week_labels, results

# %%
@noglobal(excepts=["cfg", "logger"])
def make_test_data(trans_maps):
    # testデータ作成
    test_sessions = pd.read_pickle(cfg.prep_dir + f"test_sessions.pkl")

    dfs =[]
    # 候補選出
    logger.info("[make_test] make_cand_df")
    test = make_cand_df(test_sessions, trans_maps=trans_maps)
    return test

# %%
logger.info(f"START")
line_notify.send(f"{cfg.exp_name} | START")

cache = Cache()

logger.info(f"-------- get_trans_maps --------")
cache_path = cache.get_abspath("trans_maps.pkl")
if cache.exists(cache_path):
    logger.info("cache exists. load cache and skip process.")
    with open(cache_path, "rb") as f:
        trans_maps = pickle.load(f)
else:
    trans_maps = get_trans_maps()
    with open(cache_path, "wb") as f:
        pickle.dump(trans_maps, f)

valid, valid_labels, results = make_valid_data(trans_maps)
# Out:
# 0:00:00.469213 	 START
# 0:00:00.605371 	 -------- get_trans_maps --------
# 0:00:00.606720 	 cache exists. load cache and skip process.
# 0:00:03.765343 	 [make_valid] valid_week : week4
# 0:00:03.766478 	 [make_valid] read_data : start
# 0:00:10.019723 	 [make_valid] read_data : end
# 0:00:10.020841 	 [make_valid] valid_session_extract : start
# 0:00:11.122378 	 [make_valid] valid_session_extract : end
# 0:00:11.123756 	 [make_valid] make_cand_df : start
# 0:00:11.180253 	 [make_candidate] session_frequent : start
# 0:00:11.430678 	 [add_candidate] session_frequent : start
# 0:00:13.370989 	 {'num_clicks': 97136, 'hit_clicks': 29086, 'num_carts': 41843, 'hit_carts': 10282, 'num_orders': 19599, 'hit_orders': 9741, 'recall_clicks': '0.299', 'recall_carts': '0.246', 'recall_orders': '0.497', 'w_recall_clicks': '0.030', 'w_recall_carts': '0.074', 'w_recall_orders': '0.298', 'score': '0.402'}
# 0:00:13.386286 	 [make_candidate] session_latest : start
# 0:00:13.668890 	 [add_candidate] session_latest : start
# 0:00:15.267122 	 {'num_clicks': 97136, 'hit_clicks': 29497, 'num_carts': 41843, 'hit_carts': 10523, 'num_orders': 19599, 'hit_orders': 9242, 'recall_clicks': '0.304', 'recall_carts': '0.251', 'recall_orders': '0.472', 'w_recall_clicks': '0.030', 'w_recall_carts': '0.075', 'w_recall_orders': '0.283', 'score': '0.389'}
# 0:00:15.278256 	 [make_candidate] session_frequent_pair : start
# 0:00:15.608242 	 [add_candidate] session_frequent_pair : start
# 0:00:17.183969 	 {'num_clicks': 97136, 'hit_clicks': 7470, 'num_carts': 41843, 'hit_carts': 3116, 'num_orders': 19599, 'hit_orders': 2316, 'recall_clicks': '0.077', 'recall_carts': '0.074', 'recall_orders': '0.118', 'w_recall_clicks': '0.008', 'w_recall_carts': '0.022', 'w_recall_orders': '0.071', 'score': '0.101'}
# 0:00:17.196779 	 [make_candidate] session_latest_pair0 : start
# 0:00:17.676863 	 [add_candidate] session_latest_pair0 : start
# 0:00:19.589789 	 {'num_clicks': 97136, 'hit_clicks': 7620, 'num_carts': 41843, 'hit_carts': 3167, 'num_orders': 19599, 'hit_orders': 2282, 'recall_clicks': '0.078', 'recall_carts': '0.076', 'recall_orders': '0.116', 'w_recall_clicks': '0.008', 'w_recall_carts': '0.023', 'w_recall_orders': '0.070', 'score': '0.100'}
# 0:00:19.601210 	 [make_candidate] session_latest_pair1 : start
# 0:00:20.019997 	 [add_candidate] session_latest_pair1 : start
# 0:00:21.611403 	 {'num_clicks': 97136, 'hit_clicks': 5418, 'num_carts': 41843, 'hit_carts': 2560, 'num_orders': 19599, 'hit_orders': 1735, 'recall_clicks': '0.056', 'recall_carts': '0.061', 'recall_orders': '0.089', 'w_recall_clicks': '0.006', 'w_recall_carts': '0.018', 'w_recall_orders': '0.053', 'score': '0.077'}
# 0:00:21.623847 	 [make_candidate] session_latest_pair2 : start
# 0:00:22.039578 	 [add_candidate] session_latest_pair2 : start
# 0:00:23.992750 	 {'num_clicks': 97136, 'hit_clicks': 4271, 'num_carts': 41843, 'hit_carts': 2160, 'num_orders': 19599, 'hit_orders': 1538, 'recall_clicks': '0.044', 'recall_carts': '0.052', 'recall_orders': '0.078', 'w_recall_clicks': '0.004', 'w_recall_carts': '0.015', 'w_recall_orders': '0.047', 'score': '0.067'}
# 0:00:24.005044 	 [make_candidate] session_latest_pair3 : start
# 0:00:24.533284 	 [add_candidate] session_latest_pair3 : start
# 0:00:26.141984 	 {'num_clicks': 97136, 'hit_clicks': 3583, 'num_carts': 41843, 'hit_carts': 1837, 'num_orders': 19599, 'hit_orders': 1321, 'recall_clicks': '0.037', 'recall_carts': '0.044', 'recall_orders': '0.067', 'w_recall_clicks': '0.004', 'w_recall_carts': '0.013', 'w_recall_orders': '0.040', 'score': '0.057'}
# 0:00:26.155461 	 [make_candidate] session_latest_pair4 : start
# 0:00:26.654063 	 [add_candidate] session_latest_pair4 : start
# 0:00:28.634695 	 {'num_clicks': 97136, 'hit_clicks': 3032, 'num_carts': 41843, 'hit_carts': 1660, 'num_orders': 19599, 'hit_orders': 1185, 'recall_clicks': '0.031', 'recall_carts': '0.040', 'recall_orders': '0.060', 'w_recall_clicks': '0.003', 'w_recall_carts': '0.012', 'w_recall_orders': '0.036', 'score': '0.051'}
# 0:00:28.646880 	 [make_candidate] session_latest_pair5 : start
# 0:00:28.980657 	 [add_candidate] session_latest_pair5 : start
# 0:00:30.566476 	 {'num_clicks': 97136, 'hit_clicks': 2872, 'num_carts': 41843, 'hit_carts': 1545, 'num_orders': 19599, 'hit_orders': 1030, 'recall_clicks': '0.030', 'recall_carts': '0.037', 'recall_orders': '0.053', 'w_recall_clicks': '0.003', 'w_recall_carts': '0.011', 'w_recall_orders': '0.032', 'score': '0.046'}
# 0:00:30.579705 	 [make_candidate] session_latest_pair6 : start
# 0:00:30.990134 	 [add_candidate] session_latest_pair6 : start
# 0:00:32.627791 	 {'num_clicks': 97136, 'hit_clicks': 2570, 'num_carts': 41843, 'hit_carts': 1437, 'num_orders': 19599, 'hit_orders': 949, 'recall_clicks': '0.026', 'recall_carts': '0.034', 'recall_orders': '0.048', 'w_recall_clicks': '0.003', 'w_recall_carts': '0.010', 'w_recall_orders': '0.029', 'score': '0.042'}
# 0:00:32.639941 	 [make_candidate] session_latest_pair7 : start
# 0:00:33.174559 	 [add_candidate] session_latest_pair7 : start
# 0:00:35.137954 	 {'num_clicks': 97136, 'hit_clicks': 2317, 'num_carts': 41843, 'hit_carts': 1324, 'num_orders': 19599, 'hit_orders': 927, 'recall_clicks': '0.024', 'recall_carts': '0.032', 'recall_orders': '0.047', 'w_recall_clicks': '0.002', 'w_recall_carts': '0.009', 'w_recall_orders': '0.028', 'score': '0.040'}
# 0:00:35.150938 	 [make_candidate] session_latest_pair8 : start
# 0:00:35.637717 	 [add_candidate] session_latest_pair8 : start
# 0:00:37.258318 	 {'num_clicks': 97136, 'hit_clicks': 2118, 'num_carts': 41843, 'hit_carts': 1189, 'num_orders': 19599, 'hit_orders': 785, 'recall_clicks': '0.022', 'recall_carts': '0.028', 'recall_orders': '0.040', 'w_recall_clicks': '0.002', 'w_recall_carts': '0.009', 'w_recall_orders': '0.024', 'score': '0.035'}
# 0:00:37.270364 	 [make_candidate] session_latest_pair9 : start
# 0:00:37.588712 	 [add_candidate] session_latest_pair9 : start
# 0:00:39.530470 	 {'num_clicks': 97136, 'hit_clicks': 1925, 'num_carts': 41843, 'hit_carts': 1208, 'num_orders': 19599, 'hit_orders': 798, 'recall_clicks': '0.020', 'recall_carts': '0.029', 'recall_orders': '0.041', 'w_recall_clicks': '0.002', 'w_recall_carts': '0.009', 'w_recall_orders': '0.024', 'score': '0.035'}
# 0:00:39.544215 	 [make_candidate] session_frequent_clicks_pair : start
# 0:00:39.921720 	 [add_candidate] session_frequent_clicks_pair : start
# 0:00:41.534399 	 {'num_clicks': 97136, 'hit_clicks': 7439, 'num_carts': 41843, 'hit_carts': 2650, 'num_orders': 19599, 'hit_orders': 1783, 'recall_clicks': '0.077', 'recall_carts': '0.063', 'recall_orders': '0.091', 'w_recall_clicks': '0.008', 'w_recall_carts': '0.019', 'w_recall_orders': '0.055', 'score': '0.081'}
# 0:00:41.547138 	 [make_candidate] session_latest_clicks_pair : start
# 0:00:42.061648 	 [add_candidate] session_latest_clicks_pair : start
# 0:00:43.672128 	 {'num_clicks': 97136, 'hit_clicks': 7626, 'num_carts': 41843, 'hit_carts': 2703, 'num_orders': 19599, 'hit_orders': 1741, 'recall_clicks': '0.079', 'recall_carts': '0.065', 'recall_orders': '0.089', 'w_recall_clicks': '0.008', 'w_recall_carts': '0.019', 'w_recall_orders': '0.053', 'score': '0.081'}
# 0:00:43.685841 	 [make_candidate] session_latest_carts_pair : start
# 0:00:43.924056 	 [add_candidate] session_latest_carts_pair : start
# 0:00:45.690328 	 {'num_clicks': 97136, 'hit_clicks': 4147, 'num_carts': 41843, 'hit_carts': 2226, 'num_orders': 19599, 'hit_orders': 1637, 'recall_clicks': '0.043', 'recall_carts': '0.053', 'recall_orders': '0.084', 'w_recall_clicks': '0.004', 'w_recall_carts': '0.016', 'w_recall_orders': '0.050', 'score': '0.070'}
# 0:00:45.701775 	 [make_candidate] session_latest_time_wt_pair : start
# 0:00:46.227086 	 [add_candidate] session_latest_time_wt_pair : start
# 0:00:47.906494 	 {'num_clicks': 97136, 'hit_clicks': 8789, 'num_carts': 41843, 'hit_carts': 2685, 'num_orders': 19599, 'hit_orders': 1892, 'recall_clicks': '0.090', 'recall_carts': '0.064', 'recall_orders': '0.097', 'w_recall_clicks': '0.009', 'w_recall_carts': '0.019', 'w_recall_orders': '0.058', 'score': '0.086'}
# 0:00:47.919671 	 [make_candidate] session_latest_type_wt_pair : start
# 0:00:48.430475 	 [add_candidate] session_latest_type_wt_pair : start
# 0:00:50.088101 	 {'num_clicks': 97136, 'hit_clicks': 7411, 'num_carts': 41843, 'hit_carts': 3719, 'num_orders': 19599, 'hit_orders': 2775, 'recall_clicks': '0.076', 'recall_carts': '0.089', 'recall_orders': '0.142', 'w_recall_clicks': '0.008', 'w_recall_carts': '0.027', 'w_recall_orders': '0.085', 'score': '0.119'}
# 0:00:50.100938 	 [make_candidate] session_latest_clicks_time_wt_pair : start
# 0:00:50.448504 	 [add_candidate] session_latest_clicks_time_wt_pair : start
# 0:00:52.480123 	 {'num_clicks': 97136, 'hit_clicks': 8846, 'num_carts': 41843, 'hit_carts': 2517, 'num_orders': 19599, 'hit_orders': 1700, 'recall_clicks': '0.091', 'recall_carts': '0.060', 'recall_orders': '0.087', 'w_recall_clicks': '0.009', 'w_recall_carts': '0.018', 'w_recall_orders': '0.052', 'score': '0.079'}
# 0:00:52.494052 	 [make_candidate] session_latest_clicks_carts_pair : start
# 0:00:52.897177 	 [add_candidate] session_latest_clicks_carts_pair : start
# 0:00:54.551205 	 {'num_clicks': 97136, 'hit_clicks': 4696, 'num_carts': 41843, 'hit_carts': 3006, 'num_orders': 19599, 'hit_orders': 1904, 'recall_clicks': '0.048', 'recall_carts': '0.072', 'recall_orders': '0.097', 'w_recall_clicks': '0.005', 'w_recall_carts': '0.022', 'w_recall_orders': '0.058', 'score': '0.085'}
# 0:00:54.563854 	 [make_candidate] session_latest_clicks_orders_pair : start
# 0:00:54.935873 	 [add_candidate] session_latest_clicks_orders_pair : start
# 0:00:56.876814 	 {'num_clicks': 97136, 'hit_clicks': 3034, 'num_carts': 41843, 'hit_carts': 2037, 'num_orders': 19599, 'hit_orders': 1999, 'recall_clicks': '0.031', 'recall_carts': '0.049', 'recall_orders': '0.102', 'w_recall_clicks': '0.003', 'w_recall_carts': '0.015', 'w_recall_orders': '0.061', 'score': '0.079'}

# %%
results
# Out:
#                                  name num_clicks hit_clicks num_carts  \
# 0                    session_frequent      97136      29086     41843
# 0                      session_latest      97136      29497     41843
# 0               session_frequent_pair      97136       7470     41843
# 0                session_latest_pair0      97136       7620     41843
# 0                session_latest_pair1      97136       5418     41843
# 0                session_latest_pair2      97136       4271     41843
# 0                session_latest_pair3      97136       3583     41843
# 0                session_latest_pair4      97136       3032     41843
# 0                session_latest_pair5      97136       2872     41843
# 0                session_latest_pair6      97136       2570     41843
# 0                session_latest_pair7      97136       2317     41843
# 0                session_latest_pair8      97136       2118     41843
# 0                session_latest_pair9      97136       1925     41843
# 0        session_frequent_clicks_pair      97136       7439     41843
# 0          session_latest_clicks_pair      97136       7626     41843
# 0           session_latest_carts_pair      97136       4147     41843
# 0         session_latest_time_wt_pair      97136       8789     41843
# 0         session_latest_type_wt_pair      97136       7411     41843
# 0  session_latest_clicks_time_wt_pair      97136       8846     41843
# 0    session_latest_clicks_carts_pair      97136       4696     41843
# 0   session_latest_clicks_orders_pair      97136       3034     41843
#
#   hit_carts num_orders hit_orders recall_clicks recall_carts recall_orders  \
# 0     10282      19599       9741         0.299        0.246         0.497
# 0     10523      19599       9242         0.304        0.251         0.472
# 0      3116      19599       2316         0.077        0.074         0.118
# 0      3167      19599       2282         0.078        0.076         0.116
# 0      2560      19599       1735         0.056        0.061         0.089
# 0      2160      19599       1538         0.044        0.052         0.078
# 0      1837      19599       1321         0.037        0.044         0.067
# 0      1660      19599       1185         0.031        0.040         0.060
# 0      1545      19599       1030         0.030        0.037         0.053
# 0      1437      19599        949         0.026        0.034         0.048
# 0      1324      19599        927         0.024        0.032         0.047
# 0      1189      19599        785         0.022        0.028         0.040
# 0      1208      19599        798         0.020        0.029         0.041
# 0      2650      19599       1783         0.077        0.063         0.091
# 0      2703      19599       1741         0.079        0.065         0.089
# 0      2226      19599       1637         0.043        0.053         0.084
# 0      2685      19599       1892         0.090        0.064         0.097
# 0      3719      19599       2775         0.076        0.089         0.142
# 0      2517      19599       1700         0.091        0.060         0.087
# 0      3006      19599       1904         0.048        0.072         0.097
# 0      2037      19599       1999         0.031        0.049         0.102
#
#   w_recall_clicks w_recall_carts w_recall_orders  score
# 0           0.030          0.074           0.298  0.402
# 0           0.030          0.075           0.283  0.389
# 0           0.008          0.022           0.071  0.101
# 0           0.008          0.023           0.070  0.100
# 0           0.006          0.018           0.053  0.077
# 0           0.004          0.015           0.047  0.067
# 0           0.004          0.013           0.040  0.057
# 0           0.003          0.012           0.036  0.051
# 0           0.003          0.011           0.032  0.046
# 0           0.003          0.010           0.029  0.042
# 0           0.002          0.009           0.028  0.040
# 0           0.002          0.009           0.024  0.035
# 0           0.002          0.009           0.024  0.035
# 0           0.008          0.019           0.055  0.081
# 0           0.008          0.019           0.053  0.081
# 0           0.004          0.016           0.050  0.070
# 0           0.009          0.019           0.058  0.086
# 0           0.008          0.027           0.085  0.119
# 0           0.009          0.018           0.052  0.079
# 0           0.005          0.022           0.058  0.085
# 0           0.003          0.015           0.061  0.079

# %%
fig, axs = plt.subplots(1, 3)
sns.heatmap(results.set_index("name")[["recall_clicks"]].astype(float),
            annot=True, linewidths=.5, fmt="1.2f", cmap="Reds", cbar=False, ax=axs[0])
sns.heatmap(results.set_index("name")[["recall_carts"]].astype(float),
            annot=True, linewidths=.5, fmt="1.2f", cmap="Reds", cbar=False, ax=axs[1], yticklabels=False)
sns.heatmap(results.set_index("name")[["recall_orders"]].astype(float),
            annot=True, linewidths=.5, fmt="1.2f", cmap="Reds", cbar=False, ax=axs[2], yticklabels=False)
plt.savefig(cfg.output_dir + f'{cfg.exp_name}/candidate_strategy_recalls.png')

# %%
# 予測値を全て使えたときのrecall
valid_all = valid.drop_duplicates(subset= ["session", "aid"])
session_cnt_max = valid_all["session"].value_counts().max()
valid_all = valid_all.groupby("session")["aid"].apply(list).reset_index()

all_results = evaluate(valid_labels["clicks_labels"].tolist(),
                       valid_labels["carts_labels"].tolist(),
                       valid_labels["orders_labels"].tolist(),
                       valid_all["aid"].tolist(),
                       valid_all["aid"].tolist(),
                       valid_all["aid"].tolist(),
                       session_cnt_max)
logger.info("session_cnt_max")
logger.info(session_cnt_max)
logger.info("all_pred_results")
logger.info(all_results)
# Out:
# 0:01:00.316232 	 session_cnt_max
# 0:01:00.317549 	 142
# 0:01:00.318283 	 all_pred_results
# 0:01:00.318923 	 {'num_clicks': 97136, 'hit_clicks': 46957, 'num_carts': 43611, 'hit_carts': 18110, 'num_orders': 20109, 'hit_orders': 12774, 'recall_clicks': '0.483', 'recall_carts': '0.415', 'recall_orders': '0.635', 'w_recall_clicks': '0.048', 'w_recall_carts': '0.125', 'w_recall_orders': '0.381', 'score': '0.554'}

# %%
def objective_type_recall(df, labels, type_):
    def objective(trial):
        trial_df = df.copy()
        session_frequent = trial.suggest_float("session_frequent", 0, 1)
        session_latest = trial.suggest_float("session_latest", 0, 1)
        total_frequent = trial.suggest_float("total_frequent", 0, 1)
        session_frequent_pair = trial.suggest_float("session_frequent_pair", 0, 1)
        session_latest_pair0 = trial.suggest_float("session_latest_pair0", 0, 1)
        session_latest_pair1 = trial.suggest_float("session_latest_pair1", 0, 1)
        session_latest_pair2 = trial.suggest_float("session_latest_pair2", 0, 1)
        session_latest_pair3 = trial.suggest_float("session_latest_pair3", 0, 1)
        session_latest_pair4 = trial.suggest_float("session_latest_pair4", 0, 1)
        session_frequent_clicks_pair  = trial.suggest_float("session_frequent_clicks_pair", 0, 1)
        session_latest_clicks_pair = trial.suggest_float("session_latest_clicks_pair", 0, 1)
        session_latest_carts_pair  = trial.suggest_float("session_latest_carts_pair", 0, 1)
        session_latest_time_wt_pair = trial.suggest_float("session_latest_time_wt_pair", 0, 1)
        session_latest_clicks_time_wt_pair = trial.suggest_float("session_latest_clicks_time_wt_pair", 0, 1)
        session_latest_type_wt_pair = trial.suggest_float("session_latest_type_wt_pair", 0, 1)
        session_latest_clicks_carts_pair = trial.suggest_float("session_latest_clicks_carts_pair", 0, 1)
        session_latest_clicks_orders_pair = trial.suggest_float("session_latest_clicks_orders_pair", 0, 1)

        wt_dict = {
            'session_frequent': session_frequent,
            'session_latest': session_latest, 
            'total_frequent': total_frequent,
            'session_frequent_pair': session_frequent_pair, 
            'session_latest_pair0': session_latest_pair0,
            'session_latest_pair1': session_latest_pair1, 
            'session_latest_pair2': session_latest_pair2,
            'session_latest_pair3': session_latest_pair3, 
            'session_latest_pair4': session_latest_pair4,
            'session_frequent_clicks_pair': session_frequent_clicks_pair, 
            'session_latest_clicks_pair': session_latest_clicks_pair,
            'session_latest_carts_pair': session_latest_carts_pair, 
            'session_latest_time_wt_pair': session_latest_time_wt_pair,
            'session_latest_clicks_time_wt_pair': session_latest_clicks_time_wt_pair,
            'session_latest_type_wt_pair': session_latest_type_wt_pair,
            'session_latest_clicks_carts_pair': session_latest_clicks_carts_pair,
            'session_latest_clicks_orders_pair': session_latest_clicks_orders_pair
        }

        trial_df["rank"] = trial_df["rank"] * trial_df["strategy"].map(wt_dict)
        trial_df = trial_df.sort_values(["session", "rank"])
        trial_df = trial_df.drop_duplicates(subset= ["session", "aid"], keep="first")
        trial_df = trial_df.groupby(["session"]).head(20)
        trial_df = trial_df.groupby("session")["aid"].apply(list).reset_index()

        result = evaluate(labels["clicks_labels"].tolist(),
                          labels["carts_labels"].tolist(),
                          labels["orders_labels"].tolist(),
                          trial_df["aid"].tolist(),
                          trial_df["aid"].tolist(),
                          trial_df["aid"].tolist(),
                          cfg.k)

        return float(result[f"recall_{type_}"])
    return objective

# %%
n_trials = 100

# %% [markdown]
# # パラメータチューニング

# %%
wt = {}
recall = {}

for type_ in ["clicks", "carts", "orders"]:
    logger.info(type_)
    study = optuna.create_study(direction="maximize")
    study.optimize(objective_type_recall(valid, valid_labels, type_), n_trials=n_trials)
    wt[type_] = study.best_params
    recall[type_] = study.best_value
    logger.info(f"{type_}_recall_best_value : {study.best_value}")

score = (recall["clicks"] * 0.1) + (recall["carts"] * 0.3) + (recall["orders"] * 0.6)
logger.info(f"SCORE : {score}")
# Out:
# 0:01:00.482376 	 clicks
# [I 2022-12-05 07:01:30,467] A new study created in memory with name: no-name-7d48ef85-560e-4b56-a6e1-ed28e1d95c87
# [I 2022-12-05 07:01:34,705] Trial 0 finished with value: 0.441 and parameters: {'session_frequent': 0.09714164325176355, 'session_latest': 0.8262731371696287, 'total_frequent': 0.2268308921357286, 'session_frequent_pair': 0.068897163980426, 'session_latest_pair0': 0.6663411220174368, 'session_latest_pair1': 0.2048582286898053, 'session_latest_pair2': 0.15126850858931296, 'session_latest_pair3': 0.4438301610849382, 'session_latest_pair4': 0.900606303402299, 'session_frequent_clicks_pair': 0.8099166871021428, 'session_latest_clicks_pair': 0.03456157322430031, 'session_latest_carts_pair': 0.21163866950448784, 'session_latest_time_wt_pair': 0.6473569807822797, 'session_latest_clicks_time_wt_pair': 0.4621667677400044, 'session_latest_type_wt_pair': 0.6003358121400898, 'session_latest_clicks_carts_pair': 0.6740550662498368, 'session_latest_clicks_orders_pair': 0.22944524300455538}. Best is trial 0 with value: 0.441.
# [I 2022-12-05 07:01:38,636] Trial 1 finished with value: 0.435 and parameters: {'session_frequent': 0.7826856503493373, 'session_latest': 0.40389479199988343, 'total_frequent': 0.4413916103245943, 'session_frequent_pair': 0.9953701931849023, 'session_latest_pair0': 0.6236725421054006, 'session_latest_pair1': 0.6270705167478049, 'session_latest_pair2': 0.04115437677948541, 'session_latest_pair3': 0.30140010468107925, 'session_latest_pair4': 0.580505792649678, 'session_frequent_clicks_pair': 0.8135941684155932, 'session_latest_clicks_pair': 0.8930725897505308, 'session_latest_carts_pair': 0.644752012173688, 'session_latest_time_wt_pair': 0.0020384850586231407, 'session_latest_clicks_time_wt_pair': 0.026883951553757446, 'session_latest_type_wt_pair': 0.1805932316829062, 'session_latest_clicks_carts_pair': 0.6918424070015781, 'session_latest_clicks_orders_pair': 0.4733939742191893}. Best is trial 0 with value: 0.441.
# [I 2022-12-05 07:01:42,563] Trial 2 finished with value: 0.448 and parameters: {'session_frequent': 0.20887005446871332, 'session_latest': 0.9203013051979336, 'total_frequent': 0.40366717121569673, 'session_frequent_pair': 0.31330111536335137, 'session_latest_pair0': 0.6505221461527262, 'session_latest_pair1': 0.7253919405101155, 'session_latest_pair2': 0.9790764545260556, 'session_latest_pair3': 0.5982984595656228, 'session_latest_pair4': 0.7750106986417579, 'session_frequent_clicks_pair': 0.861992287758003, 'session_latest_clicks_pair': 0.1849931746712632, 'session_latest_carts_pair': 0.5674566950333344, 'session_latest_time_wt_pair': 0.19952533194991273, 'session_latest_clicks_time_wt_pair': 0.7365837109466497, 'session_latest_type_wt_pair': 0.7459581803868277, 'session_latest_clicks_carts_pair': 0.20908000713160635, 'session_latest_clicks_orders_pair': 0.7979403441207116}. Best is trial 2 with value: 0.448.
# [I 2022-12-05 07:01:46,688] Trial 3 finished with value: 0.419 and parameters: {'session_frequent': 0.9243854355374577, 'session_latest': 0.30333729920124053, 'total_frequent': 0.7052165840129714, 'session_frequent_pair': 0.9294496234872358, 'session_latest_pair0': 0.8615333519844656, 'session_latest_pair1': 0.2439365115447888, 'session_latest_pair2': 0.6164911279603281, 'session_latest_pair3': 0.06413463421326893, 'session_latest_pair4': 0.33080938737921217, 'session_frequent_clicks_pair': 0.35051880877532127, 'session_latest_clicks_pair': 0.3617193381012064, 'session_latest_carts_pair': 0.3357590343858936, 'session_latest_time_wt_pair': 0.5688662530024174, 'session_latest_clicks_time_wt_pair': 0.29194077280875286, 'session_latest_type_wt_pair': 0.04026300207798761, 'session_latest_clicks_carts_pair': 0.012952264989096962, 'session_latest_clicks_orders_pair': 0.0012289227468988972}. Best is trial 2 with value: 0.448.
# [I 2022-12-05 07:01:50,601] Trial 4 finished with value: 0.424 and parameters: {'session_frequent': 0.7034062232779917, 'session_latest': 0.9751666471628326, 'total_frequent': 0.8323714774700268, 'session_frequent_pair': 0.13604121042475614, 'session_latest_pair0': 0.0016566843213493554, 'session_latest_pair1': 0.9671077932359357, 'session_latest_pair2': 0.9467497727081859, 'session_latest_pair3': 0.29046807444566236, 'session_latest_pair4': 0.9990930813799557, 'session_frequent_clicks_pair': 0.40359165224668014, 'session_latest_clicks_pair': 0.34462992035326123, 'session_latest_carts_pair': 0.32077634391292675, 'session_latest_time_wt_pair': 0.18982956945182095, 'session_latest_clicks_time_wt_pair': 0.2002028589543393, 'session_latest_type_wt_pair': 0.40519819928657197, 'session_latest_clicks_carts_pair': 0.44546970502036964, 'session_latest_clicks_orders_pair': 0.11413336326197698}. Best is trial 2 with value: 0.448.
# [I 2022-12-05 07:01:54,834] Trial 5 finished with value: 0.443 and parameters: {'session_frequent': 0.6762148754992372, 'session_latest': 0.27751407867803746, 'total_frequent': 0.3689978592250811, 'session_frequent_pair': 0.1441913553189288, 'session_latest_pair0': 0.3281716324822762, 'session_latest_pair1': 0.1467743413347069, 'session_latest_pair2': 0.581373552947502, 'session_latest_pair3': 0.39774015260430506, 'session_latest_pair4': 0.3673662868433313, 'session_frequent_clicks_pair': 0.02519139724772812, 'session_latest_clicks_pair': 0.5223718106211921, 'session_latest_carts_pair': 0.20603532569855376, 'session_latest_time_wt_pair': 0.05199446105039174, 'session_latest_clicks_time_wt_pair': 0.24081458750343654, 'session_latest_type_wt_pair': 0.6221609940489202, 'session_latest_clicks_carts_pair': 0.580193983585992, 'session_latest_clicks_orders_pair': 0.6196339276578906}. Best is trial 2 with value: 0.448.
# [I 2022-12-05 07:01:58,730] Trial 6 finished with value: 0.432 and parameters: {'session_frequent': 0.3619156062894645, 'session_latest': 0.9373675570037797, 'total_frequent': 0.31267490955625254, 'session_frequent_pair': 0.670400606832864, 'session_latest_pair0': 0.34531373745766114, 'session_latest_pair1': 0.6320676686001743, 'session_latest_pair2': 0.5476070223508834, 'session_latest_pair3': 0.06860433252439857, 'session_latest_pair4': 0.21945846699264182, 'session_frequent_clicks_pair': 0.4545594710480123, 'session_latest_clicks_pair': 0.8457551044218131, 'session_latest_carts_pair': 0.6866803361898992, 'session_latest_time_wt_pair': 0.34224364378634964, 'session_latest_clicks_time_wt_pair': 0.0837137980729048, 'session_latest_type_wt_pair': 0.8363820084058674, 'session_latest_clicks_carts_pair': 0.5123028041477146, 'session_latest_clicks_orders_pair': 0.9835536285830286}. Best is trial 2 with value: 0.448.
# [I 2022-12-05 07:02:02,919] Trial 7 finished with value: 0.452 and parameters: {'session_frequent': 0.16949335573282742, 'session_latest': 0.25703944767175946, 'total_frequent': 0.2736272262256879, 'session_frequent_pair': 0.6798932942550291, 'session_latest_pair0': 0.19510655595406545, 'session_latest_pair1': 0.47416934366222874, 'session_latest_pair2': 0.42432142233121795, 'session_latest_pair3': 0.6115129277454333, 'session_latest_pair4': 0.16722650177868537, 'session_frequent_clicks_pair': 0.5106180048357888, 'session_latest_clicks_pair': 0.6778179019542078, 'session_latest_carts_pair': 0.3752015692403542, 'session_latest_time_wt_pair': 0.3992883373332743, 'session_latest_clicks_time_wt_pair': 0.24988078250392953, 'session_latest_type_wt_pair': 0.8018691930672573, 'session_latest_clicks_carts_pair': 0.15966034089918657, 'session_latest_clicks_orders_pair': 0.916033816060755}. Best is trial 7 with value: 0.452.
# [I 2022-12-05 07:02:06,737] Trial 8 finished with value: 0.438 and parameters: {'session_frequent': 0.47742948354862813, 'session_latest': 0.7625531456351221, 'total_frequent': 0.2772509866021241, 'session_frequent_pair': 0.4209385302390586, 'session_latest_pair0': 0.6466693513269601, 'session_latest_pair1': 0.6931487302974305, 'session_latest_pair2': 0.3563934223111834, 'session_latest_pair3': 0.4324264878810312, 'session_latest_pair4': 0.6516747159634505, 'session_frequent_clicks_pair': 0.8641899887202824, 'session_latest_clicks_pair': 0.1826063390629884, 'session_latest_carts_pair': 0.8251292030849892, 'session_latest_time_wt_pair': 0.9062918870082528, 'session_latest_clicks_time_wt_pair': 0.9354557721856503, 'session_latest_type_wt_pair': 0.900290751845702, 'session_latest_clicks_carts_pair': 0.38684783705658354, 'session_latest_clicks_orders_pair': 0.1268708315029199}. Best is trial 7 with value: 0.452.
# [I 2022-12-05 07:02:10,624] Trial 9 finished with value: 0.444 and parameters: {'session_frequent': 0.6385672036365058, 'session_latest': 0.4465314540282549, 'total_frequent': 0.9038289545718649, 'session_frequent_pair': 0.25859227666907436, 'session_latest_pair0': 0.9255048849501778, 'session_latest_pair1': 0.2896008471482512, 'session_latest_pair2': 0.9429871996245373, 'session_latest_pair3': 0.9288289489482274, 'session_latest_pair4': 0.6121507696947349, 'session_frequent_clicks_pair': 0.8075685430836161, 'session_latest_clicks_pair': 0.792220537588373, 'session_latest_carts_pair': 0.408910559720988, 'session_latest_time_wt_pair': 0.08337018254874062, 'session_latest_clicks_time_wt_pair': 0.46365212173800385, 'session_latest_type_wt_pair': 0.30519725890442706, 'session_latest_clicks_carts_pair': 0.5251413976485001, 'session_latest_clicks_orders_pair': 0.2765348557052918}. Best is trial 7 with value: 0.452.
# [I 2022-12-05 07:02:14,853] Trial 10 finished with value: 0.447 and parameters: {'session_frequent': 0.04627769844774615, 'session_latest': 0.009595295526513226, 'total_frequent': 0.03246852996683833, 'session_frequent_pair': 0.6636318539360169, 'session_latest_pair0': 0.014445603930625328, 'session_latest_pair1': 0.4248452112285859, 'session_latest_pair2': 0.3265094796770076, 'session_latest_pair3': 0.7634143467580994, 'session_latest_pair4': 0.0020045700308411463, 'session_frequent_clicks_pair': 0.17211846384447577, 'session_latest_clicks_pair': 0.6953245793268718, 'session_latest_carts_pair': 0.012181290233128528, 'session_latest_time_wt_pair': 0.7856812937869896, 'session_latest_clicks_time_wt_pair': 0.6513076640099771, 'session_latest_type_wt_pair': 0.9690411133089758, 'session_latest_clicks_carts_pair': 0.9912691034438941, 'session_latest_clicks_orders_pair': 0.9190142037267532}. Best is trial 7 with value: 0.452.
# [I 2022-12-05 07:02:18,742] Trial 11 finished with value: 0.448 and parameters: {'session_frequent': 0.2629465357027735, 'session_latest': 0.6159358371648919, 'total_frequent': 0.5910155284325382, 'session_frequent_pair': 0.48631052411330666, 'session_latest_pair0': 0.25807808858421133, 'session_latest_pair1': 0.8806154843614815, 'session_latest_pair2': 0.7472186467576344, 'session_latest_pair3': 0.6844809093954864, 'session_latest_pair4': 0.805364433974595, 'session_frequent_clicks_pair': 0.6626415256717786, 'session_latest_clicks_pair': 0.5342207638817965, 'session_latest_carts_pair': 0.5520980539929865, 'session_latest_time_wt_pair': 0.3774461368298677, 'session_latest_clicks_time_wt_pair': 0.7533603560378657, 'session_latest_type_wt_pair': 0.7565905324735616, 'session_latest_clicks_carts_pair': 0.13359464302567312, 'session_latest_clicks_orders_pair': 0.7513520779522176}. Best is trial 7 with value: 0.452.
# [I 2022-12-05 07:02:22,971] Trial 12 finished with value: 0.451 and parameters: {'session_frequent': 0.21064964139639586, 'session_latest': 0.06829629316020044, 'total_frequent': 0.09186314060000342, 'session_frequent_pair': 0.754974380663041, 'session_latest_pair0': 0.19037271772983186, 'session_latest_pair1': 0.4588832821590799, 'session_latest_pair2': 0.3598454845340219, 'session_latest_pair3': 0.6328140299393087, 'session_latest_pair4': 0.011321437608492135, 'session_frequent_clicks_pair': 0.6130826048911917, 'session_latest_clicks_pair': 0.6602862469467263, 'session_latest_carts_pair': 0.8810667387571338, 'session_latest_time_wt_pair': 0.32985492139198036, 'session_latest_clicks_time_wt_pair': 0.6852923790236582, 'session_latest_type_wt_pair': 0.7361695267856108, 'session_latest_clicks_carts_pair': 0.2539182016332717, 'session_latest_clicks_orders_pair': 0.8150332981973777}. Best is trial 7 with value: 0.452.
# [I 2022-12-05 07:02:26,897] Trial 13 finished with value: 0.45 and parameters: {'session_frequent': 0.4164720197031586, 'session_latest': 0.040739062891643016, 'total_frequent': 0.00394281491649677, 'session_frequent_pair': 0.7565357685127249, 'session_latest_pair0': 0.17940738533239037, 'session_latest_pair1': 0.4367174996413305, 'session_latest_pair2': 0.34479234779254175, 'session_latest_pair3': 0.8565140197868497, 'session_latest_pair4': 0.03560478337744868, 'session_frequent_clicks_pair': 0.6040387805228649, 'session_latest_clicks_pair': 0.6995180912873618, 'session_latest_carts_pair': 0.9843752415306563, 'session_latest_time_wt_pair': 0.3872279909422895, 'session_latest_clicks_time_wt_pair': 0.9587451843503554, 'session_latest_type_wt_pair': 0.5763166021481588, 'session_latest_clicks_carts_pair': 0.2760110467390412, 'session_latest_clicks_orders_pair': 0.814063287970258}. Best is trial 7 with value: 0.452.
# [I 2022-12-05 07:02:30,892] Trial 14 finished with value: 0.44 and parameters: {'session_frequent': 0.2150666437291825, 'session_latest': 0.1749348742525446, 'total_frequent': 0.148955520843364, 'session_frequent_pair': 0.8213046773942926, 'session_latest_pair0': 0.44370866618625715, 'session_latest_pair1': 0.018871299585685286, 'session_latest_pair2': 0.4287779746945643, 'session_latest_pair3': 0.6215563736645998, 'session_latest_pair4': 0.15769134164481508, 'session_frequent_clicks_pair': 0.6106879136684584, 'session_latest_clicks_pair': 0.9670871615885349, 'session_latest_carts_pair': 0.9955327867350089, 'session_latest_time_wt_pair': 0.4577539728853003, 'session_latest_clicks_time_wt_pair': 0.5645154812232424, 'session_latest_type_wt_pair': 0.6863356252589284, 'session_latest_clicks_carts_pair': 0.0064333579476476, 'session_latest_clicks_orders_pair': 0.6064178357026484}. Best is trial 7 with value: 0.452.
# [I 2022-12-05 07:02:35,102] Trial 15 finished with value: 0.454 and parameters: {'session_frequent': 0.017549345135919103, 'session_latest': 0.13548557250683751, 'total_frequent': 0.1334721593085916, 'session_frequent_pair': 0.6092036193237407, 'session_latest_pair0': 0.13558791939937231, 'session_latest_pair1': 0.50989434014774, 'session_latest_pair2': 0.1946392133235518, 'session_latest_pair3': 0.7779128853416494, 'session_latest_pair4': 0.15096129853557713, 'session_frequent_clicks_pair': 0.24871260710872095, 'session_latest_clicks_pair': 0.6391550464616538, 'session_latest_carts_pair': 0.7918702585079544, 'session_latest_time_wt_pair': 0.2615501679815691, 'session_latest_clicks_time_wt_pair': 0.3774208621443893, 'session_latest_type_wt_pair': 0.4707035957410354, 'session_latest_clicks_carts_pair': 0.31345080209159304, 'session_latest_clicks_orders_pair': 0.4405051383772619}. Best is trial 15 with value: 0.454.
# [I 2022-12-05 07:02:38,990] Trial 16 finished with value: 0.453 and parameters: {'session_frequent': 0.017668820055673197, 'session_latest': 0.1914649241683954, 'total_frequent': 0.5490848953151346, 'session_frequent_pair': 0.5780282390374865, 'session_latest_pair0': 0.093878807088767, 'session_latest_pair1': 0.5593552063921465, 'session_latest_pair2': 0.2006142779428241, 'session_latest_pair3': 0.7838297060312372, 'session_latest_pair4': 0.40867682290825025, 'session_frequent_clicks_pair': 0.2544647958461144, 'session_latest_clicks_pair': 0.42336396676880084, 'session_latest_carts_pair': 0.7711309893542778, 'session_latest_time_wt_pair': 0.22184171493520488, 'session_latest_clicks_time_wt_pair': 0.34603378672230545, 'session_latest_type_wt_pair': 0.42905261938440603, 'session_latest_clicks_carts_pair': 0.34816653452826, 'session_latest_clicks_orders_pair': 0.44308698711279704}. Best is trial 15 with value: 0.454.
# [I 2022-12-05 07:02:43,211] Trial 17 finished with value: 0.45 and parameters: {'session_frequent': 0.036812665031674754, 'session_latest': 0.5946099665524374, 'total_frequent': 0.5568260471821586, 'session_frequent_pair': 0.5530321408095112, 'session_latest_pair0': 0.09129381969814285, 'session_latest_pair1': 0.5723375136809775, 'session_latest_pair2': 0.19173518308239282, 'session_latest_pair3': 0.9804374495297881, 'session_latest_pair4': 0.41998996482866185, 'session_frequent_clicks_pair': 0.27916600876166353, 'session_latest_clicks_pair': 0.3778482147162726, 'session_latest_carts_pair': 0.7782078756402592, 'session_latest_time_wt_pair': 0.20430057870675794, 'session_latest_clicks_time_wt_pair': 0.361931908483941, 'session_latest_type_wt_pair': 0.4258490695942383, 'session_latest_clicks_carts_pair': 0.3432909988598944, 'session_latest_clicks_orders_pair': 0.41166357984689356}. Best is trial 15 with value: 0.454.
# [I 2022-12-05 07:02:47,114] Trial 18 finished with value: 0.453 and parameters: {'session_frequent': 0.2989704125369087, 'session_latest': 0.15405056038231427, 'total_frequent': 0.6439837581097272, 'session_frequent_pair': 0.5619297580753829, 'session_latest_pair0': 0.46909223054144916, 'session_latest_pair1': 0.7716051183511855, 'session_latest_pair2': 0.20313703956252932, 'session_latest_pair3': 0.7963470719957316, 'session_latest_pair4': 0.5015466193843914, 'session_frequent_clicks_pair': 0.177367343145867, 'session_latest_clicks_pair': 0.45207748270513654, 'session_latest_carts_pair': 0.7259143447707598, 'session_latest_time_wt_pair': 0.24894170379296315, 'session_latest_clicks_time_wt_pair': 0.36164015146521356, 'session_latest_type_wt_pair': 0.2747907856138688, 'session_latest_clicks_carts_pair': 0.7720221684780653, 'session_latest_clicks_orders_pair': 0.37842258484238267}. Best is trial 15 with value: 0.454.
# [I 2022-12-05 07:02:51,336] Trial 19 finished with value: 0.447 and parameters: {'session_frequent': 0.3497879008179244, 'session_latest': 0.12845621101385413, 'total_frequent': 0.6619727454959029, 'session_frequent_pair': 0.37716441433352055, 'session_latest_pair0': 0.44105933873172115, 'session_latest_pair1': 0.8331103203427284, 'session_latest_pair2': 0.04187444588654532, 'session_latest_pair3': 0.8429000174047732, 'session_latest_pair4': 0.5195776735248826, 'session_frequent_clicks_pair': 0.04780689963958193, 'session_latest_clicks_pair': 0.5967138709168848, 'session_latest_carts_pair': 0.6737979764409494, 'session_latest_time_wt_pair': 0.5498829691869993, 'session_latest_clicks_time_wt_pair': 0.13528013089189347, 'session_latest_type_wt_pair': 0.2543102144152409, 'session_latest_clicks_carts_pair': 0.926840336115601, 'session_latest_clicks_orders_pair': 0.34576936276782766}. Best is trial 15 with value: 0.454.
# [I 2022-12-05 07:02:55,190] Trial 20 finished with value: 0.453 and parameters: {'session_frequent': 0.12971938238939473, 'session_latest': 0.31944690113235297, 'total_frequent': 0.7668899821182054, 'session_frequent_pair': 0.5836409300130511, 'session_latest_pair0': 0.11338547797849755, 'session_latest_pair1': 0.35163840087782916, 'session_latest_pair2': 0.24281208087467865, 'session_latest_pair3': 0.7317616386366774, 'session_latest_pair4': 0.2792489914772139, 'session_frequent_clicks_pair': 0.25246566966935463, 'session_latest_clicks_pair': 0.2413712020156913, 'session_latest_carts_pair': 0.8876569350403709, 'session_latest_time_wt_pair': 0.13443832282354637, 'session_latest_clicks_time_wt_pair': 0.5514596747192644, 'session_latest_type_wt_pair': 0.4513466367466892, 'session_latest_clicks_carts_pair': 0.3603295582396708, 'session_latest_clicks_orders_pair': 0.5600561370824397}. Best is trial 15 with value: 0.454.
# [I 2022-12-05 07:02:59,090] Trial 21 finished with value: 0.452 and parameters: {'session_frequent': 0.12166778274699315, 'session_latest': 0.360487042810154, 'total_frequent': 0.7685634656404892, 'session_frequent_pair': 0.48257215465712067, 'session_latest_pair0': 0.5201373980258404, 'session_latest_pair1': 0.3723322160730392, 'session_latest_pair2': 0.22962181204014515, 'session_latest_pair3': 0.7393635379861632, 'session_latest_pair4': 0.26539377300906797, 'session_frequent_clicks_pair': 0.1389883228724746, 'session_latest_clicks_pair': 0.24489493655760708, 'session_latest_carts_pair': 0.886332399201793, 'session_latest_time_wt_pair': 0.1360093237657152, 'session_latest_clicks_time_wt_pair': 0.5537919870840994, 'session_latest_type_wt_pair': 0.510226341713456, 'session_latest_clicks_carts_pair': 0.8196199783731714, 'session_latest_clicks_orders_pair': 0.5760744182411268}. Best is trial 15 with value: 0.454.
# [I 2022-12-05 07:03:03,320] Trial 22 finished with value: 0.453 and parameters: {'session_frequent': 0.004239516397475263, 'session_latest': 0.17236520864083038, 'total_frequent': 0.4946213933226967, 'session_frequent_pair': 0.6395124856598999, 'session_latest_pair0': 0.3149507595941485, 'session_latest_pair1': 0.781408164827053, 'session_latest_pair2': 0.11028594692719924, 'session_latest_pair3': 0.8564955512398968, 'session_latest_pair4': 0.45597941918110046, 'session_frequent_clicks_pair': 0.15917044776562037, 'session_latest_clicks_pair': 0.4210867297874716, 'session_latest_carts_pair': 0.7553913765034135, 'session_latest_time_wt_pair': 0.2826575783096285, 'session_latest_clicks_time_wt_pair': 0.3680301529930803, 'session_latest_type_wt_pair': 0.3377433415324797, 'session_latest_clicks_carts_pair': 0.6464478210593262, 'session_latest_clicks_orders_pair': 0.42586699546086837}. Best is trial 15 with value: 0.454.
# [I 2022-12-05 07:03:07,208] Trial 23 finished with value: 0.448 and parameters: {'session_frequent': 0.0012527827666665731, 'session_latest': 0.5220646120822342, 'total_frequent': 0.472336813509904, 'session_frequent_pair': 0.8379103921531206, 'session_latest_pair0': 0.3193461599585662, 'session_latest_pair1': 0.3274358379103001, 'session_latest_pair2': 0.10387298606262209, 'session_latest_pair3': 0.9101538981784058, 'session_latest_pair4': 0.11706675069989561, 'session_frequent_clicks_pair': 0.2855011771470931, 'session_latest_clicks_pair': 0.03181033945456932, 'session_latest_carts_pair': 0.9039786823271106, 'session_latest_time_wt_pair': 0.28857636939722964, 'session_latest_clicks_time_wt_pair': 0.42486692683997107, 'session_latest_type_wt_pair': 0.3683270071857289, 'session_latest_clicks_carts_pair': 0.597654768657549, 'session_latest_clicks_orders_pair': 0.5370690167776508}. Best is trial 15 with value: 0.454.
# [I 2022-12-05 07:03:11,470] Trial 24 finished with value: 0.454 and parameters: {'session_frequent': 0.2800763562711345, 'session_latest': 0.12266711800750583, 'total_frequent': 0.989688917290616, 'session_frequent_pair': 0.5610165294484967, 'session_latest_pair0': 0.7846873759551093, 'session_latest_pair1': 0.9484642732670309, 'session_latest_pair2': 0.2469149361235391, 'session_latest_pair3': 0.5334567149873539, 'session_latest_pair4': 0.2533263102118938, 'session_frequent_clicks_pair': 0.9920117448930361, 'session_latest_clicks_pair': 0.2860309213490729, 'session_latest_carts_pair': 0.6558939434333566, 'session_latest_time_wt_pair': 0.10402355969007104, 'session_latest_clicks_time_wt_pair': 0.5590960360434268, 'session_latest_type_wt_pair': 0.19531424675152254, 'session_latest_clicks_carts_pair': 0.42760046040150584, 'session_latest_clicks_orders_pair': 0.6713810096330843}. Best is trial 15 with value: 0.454.
# [I 2022-12-05 07:03:15,464] Trial 25 finished with value: 0.446 and parameters: {'session_frequent': 0.5551269988057403, 'session_latest': 0.23694943051422043, 'total_frequent': 0.9088794006200269, 'session_frequent_pair': 0.4198573445272009, 'session_latest_pair0': 0.789194414637051, 'session_latest_pair1': 0.9083678902341359, 'session_latest_pair2': 0.08770531643603038, 'session_latest_pair3': 0.5189859896825852, 'session_latest_pair4': 0.10334919742938947, 'session_frequent_clicks_pair': 0.7159951835068262, 'session_latest_clicks_pair': 0.2780153478690187, 'session_latest_carts_pair': 0.6046768793601363, 'session_latest_time_wt_pair': 0.4860356512644396, 'session_latest_clicks_time_wt_pair': 0.8241191506508148, 'session_latest_type_wt_pair': 0.12096674199756619, 'session_latest_clicks_carts_pair': 0.4633334762485773, 'session_latest_clicks_orders_pair': 0.6723180380372269}. Best is trial 15 with value: 0.454.
# [I 2022-12-05 07:03:19,369] Trial 26 finished with value: 0.452 and parameters: {'session_frequent': 0.10256295940977356, 'session_latest': 0.08005165537152825, 'total_frequent': 0.2240211009295323, 'session_frequent_pair': 0.6406894170037525, 'session_latest_pair0': 0.7773553380480658, 'session_latest_pair1': 0.9993631938784655, 'session_latest_pair2': 0.0028402474067233396, 'session_latest_pair3': 0.5294512399766456, 'session_latest_pair4': 0.30782712189238903, 'session_frequent_clicks_pair': 0.9795139241959857, 'session_latest_clicks_pair': 0.14068030282525062, 'session_latest_carts_pair': 0.5063332330027978, 'session_latest_time_wt_pair': 0.12772840174523095, 'session_latest_clicks_time_wt_pair': 0.6152410899781874, 'session_latest_type_wt_pair': 0.17645282358634518, 'session_latest_clicks_carts_pair': 0.6687365483934221, 'session_latest_clicks_orders_pair': 0.6879590037161368}. Best is trial 15 with value: 0.454.
# [I 2022-12-05 07:03:23,594] Trial 27 finished with value: 0.45 and parameters: {'session_frequent': 0.46215052437075904, 'session_latest': 0.12497390569871353, 'total_frequent': 0.9854123674593875, 'session_frequent_pair': 0.7320714833215833, 'session_latest_pair0': 0.5598327982599316, 'session_latest_pair1': 0.8374709723669157, 'session_latest_pair2': 0.27760676977778814, 'session_latest_pair3': 0.3230690668270428, 'session_latest_pair4': 0.4338707029310367, 'session_frequent_clicks_pair': 0.09444358696037924, 'session_latest_clicks_pair': 0.5713924236804339, 'session_latest_carts_pair': 0.4521608122742603, 'session_latest_time_wt_pair': 0.6931061056491029, 'session_latest_clicks_time_wt_pair': 0.41328318732907593, 'session_latest_type_wt_pair': 0.007177016873521458, 'session_latest_clicks_carts_pair': 0.42349816394635637, 'session_latest_clicks_orders_pair': 0.3063715478052802}. Best is trial 15 with value: 0.454.
# [I 2022-12-05 07:03:27,519] Trial 28 finished with value: 0.454 and parameters: {'session_frequent': 0.3012202088642187, 'session_latest': 0.004873812599566374, 'total_frequent': 0.12782429233545264, 'session_frequent_pair': 0.8435733759724031, 'session_latest_pair0': 0.3594575828837032, 'session_latest_pair1': 0.7783310507697169, 'session_latest_pair2': 0.11960595724159598, 'session_latest_pair3': 0.19954949297549418, 'session_latest_pair4': 0.2266735322654213, 'session_frequent_clicks_pair': 0.9929149359726382, 'session_latest_clicks_pair': 0.4347026606991854, 'session_latest_carts_pair': 0.7659869084711147, 'session_latest_time_wt_pair': 0.001225512901129544, 'session_latest_clicks_time_wt_pair': 0.5143677725124094, 'session_latest_type_wt_pair': 0.5244256339426999, 'session_latest_clicks_carts_pair': 0.5797873519577253, 'session_latest_clicks_orders_pair': 0.4770696748522604}. Best is trial 15 with value: 0.454.
# [I 2022-12-05 07:03:31,779] Trial 29 finished with value: 0.452 and parameters: {'session_frequent': 0.5605599258846392, 'session_latest': 0.0011400765859099354, 'total_frequent': 0.1688879351400281, 'session_frequent_pair': 0.8549989707144968, 'session_latest_pair0': 0.9870987592480702, 'session_latest_pair1': 0.9341255043098936, 'session_latest_pair2': 0.46680364024878895, 'session_latest_pair3': 0.1748809385496647, 'session_latest_pair4': 0.07630296540364023, 'session_frequent_clicks_pair': 0.933792125084233, 'session_latest_clicks_pair': 0.4740505241855979, 'session_latest_carts_pair': 0.801234194600468, 'session_latest_time_wt_pair': 0.06889044034268853, 'session_latest_clicks_time_wt_pair': 0.501932826326463, 'session_latest_type_wt_pair': 0.5375778526292055, 'session_latest_clicks_carts_pair': 0.29110672003719273, 'session_latest_clicks_orders_pair': 0.19210028266719575}. Best is trial 15 with value: 0.454.
# [I 2022-12-05 07:03:35,721] Trial 30 finished with value: 0.452 and parameters: {'session_frequent': 0.3304372461045449, 'session_latest': 0.08248608898390426, 'total_frequent': 0.1220924190476026, 'session_frequent_pair': 0.9140501726714138, 'session_latest_pair0': 0.7195175488507843, 'session_latest_pair1': 0.684919426528068, 'session_latest_pair2': 0.153252266725295, 'session_latest_pair3': 0.15838094934692232, 'session_latest_pair4': 0.2131265280414468, 'session_frequent_clicks_pair': 0.9528500869070086, 'session_latest_clicks_pair': 0.12802433882478748, 'session_latest_carts_pair': 0.7065089063264782, 'session_latest_time_wt_pair': 0.03425997352812771, 'session_latest_clicks_time_wt_pair': 0.4798770753683284, 'session_latest_type_wt_pair': 0.646282558867583, 'session_latest_clicks_carts_pair': 0.5581529483893114, 'session_latest_clicks_orders_pair': 0.5002607635562357}. Best is trial 15 with value: 0.454.
# [I 2022-12-05 07:03:40,012] Trial 31 finished with value: 0.454 and parameters: {'session_frequent': 0.09320290191783681, 'session_latest': 0.20587152009509846, 'total_frequent': 0.0975332675978906, 'session_frequent_pair': 0.6266070286652303, 'session_latest_pair0': 0.40383521991398036, 'session_latest_pair1': 0.7852286283740817, 'session_latest_pair2': 0.11327649451509751, 'session_latest_pair3': 0.22009719300687464, 'session_latest_pair4': 0.2147581864605303, 'session_frequent_clicks_pair': 0.7256607227741138, 'session_latest_clicks_pair': 0.3326970633163617, 'session_latest_carts_pair': 0.7402379372791914, 'session_latest_time_wt_pair': 0.12547679296746922, 'session_latest_clicks_time_wt_pair': 0.3169271065436109, 'session_latest_type_wt_pair': 0.3367568368435698, 'session_latest_clicks_carts_pair': 0.6456672190844742, 'session_latest_clicks_orders_pair': 0.4863086392405308}. Best is trial 15 with value: 0.454.
# [I 2022-12-05 07:03:43,934] Trial 32 finished with value: 0.451 and parameters: {'session_frequent': 0.2564624815788626, 'session_latest': 0.21011153014901487, 'total_frequent': 0.05557005666650755, 'session_frequent_pair': 0.5096079046515604, 'session_latest_pair0': 0.3805238111506757, 'session_latest_pair1': 0.840232929234665, 'session_latest_pair2': 0.2799420845351034, 'session_latest_pair3': 0.21038878325461016, 'session_latest_pair4': 0.21293675488875358, 'session_frequent_clicks_pair': 0.7590293365115772, 'session_latest_clicks_pair': 0.3018755706523043, 'session_latest_carts_pair': 0.6187407370588482, 'session_latest_time_wt_pair': 0.009150704178607916, 'session_latest_clicks_time_wt_pair': 0.29406765790337885, 'session_latest_type_wt_pair': 0.18631420855806913, 'session_latest_clicks_carts_pair': 0.7636183679710912, 'session_latest_clicks_orders_pair': 0.47727956226016843}. Best is trial 15 with value: 0.454.
# [I 2022-12-05 07:03:47,796] Trial 33 finished with value: 0.45 and parameters: {'session_frequent': 0.16163864984052695, 'session_latest': 0.1061677878109023, 'total_frequent': 0.21534733935918382, 'session_frequent_pair': 0.774457584337682, 'session_latest_pair0': 0.5717537729437738, 'session_latest_pair1': 0.7474462490456166, 'session_latest_pair2': 0.15046582220498048, 'session_latest_pair3': 0.003509865214670116, 'session_latest_pair4': 0.15817919009938486, 'session_frequent_clicks_pair': 0.8995621510154072, 'session_latest_clicks_pair': 0.6063491484626795, 'session_latest_carts_pair': 0.6594804650050468, 'session_latest_time_wt_pair': 0.1264848601521269, 'session_latest_clicks_time_wt_pair': 0.524388732042921, 'session_latest_type_wt_pair': 0.49137644244326545, 'session_latest_clicks_carts_pair': 0.6211866687053634, 'session_latest_clicks_orders_pair': 0.6614630596973677}. Best is trial 15 with value: 0.454.
# [I 2022-12-05 07:03:52,000] Trial 34 finished with value: 0.45 and parameters: {'session_frequent': 0.07228852748289266, 'session_latest': 0.3907587318085016, 'total_frequent': 0.08585568651674441, 'session_frequent_pair': 0.9281303378295426, 'session_latest_pair0': 0.4082640530374287, 'session_latest_pair1': 0.5367943257074984, 'session_latest_pair2': 0.048359288750970425, 'session_latest_pair3': 0.34378950201982794, 'session_latest_pair4': 0.33508855146471855, 'session_frequent_clicks_pair': 0.8091903478647355, 'session_latest_clicks_pair': 0.333044489264491, 'session_latest_carts_pair': 0.8295699329348718, 'session_latest_time_wt_pair': 0.17911545786195726, 'session_latest_clicks_time_wt_pair': 0.604610225269556, 'session_latest_type_wt_pair': 0.24034445669669244, 'session_latest_clicks_carts_pair': 0.7161060924120184, 'session_latest_clicks_orders_pair': 0.4972041452728721}. Best is trial 15 with value: 0.454.
# [I 2022-12-05 07:03:55,951] Trial 35 finished with value: 0.453 and parameters: {'session_frequent': 0.9800906527370303, 'session_latest': 0.050899833669633465, 'total_frequent': 0.38221726215756247, 'session_frequent_pair': 0.9881320544514187, 'session_latest_pair0': 0.5008833574988438, 'session_latest_pair1': 0.6339619627336479, 'session_latest_pair2': 0.13136716195642414, 'session_latest_pair3': 0.23810708714329612, 'session_latest_pair4': 0.2635765806426757, 'session_frequent_clicks_pair': 0.9861877796415275, 'session_latest_clicks_pair': 0.7605459100620928, 'session_latest_carts_pair': 0.5616631080561074, 'session_latest_time_wt_pair': 0.003627437663047947, 'session_latest_clicks_time_wt_pair': 0.14807832022662287, 'session_latest_type_wt_pair': 0.0720986086952799, 'session_latest_clicks_carts_pair': 0.4905219548602012, 'session_latest_clicks_orders_pair': 0.7483700137778814}. Best is trial 15 with value: 0.454.
# [I 2022-12-05 07:04:00,220] Trial 36 finished with value: 0.444 and parameters: {'session_frequent': 0.41210083576936896, 'session_latest': 0.30833764683312215, 'total_frequent': 0.3379956149488381, 'session_frequent_pair': 0.27055225310268605, 'session_latest_pair0': 0.25829929047268535, 'session_latest_pair1': 0.944967713379715, 'session_latest_pair2': 0.29776989049504665, 'session_latest_pair3': 0.1126506686022001, 'session_latest_pair4': 0.3582960354281616, 'session_frequent_clicks_pair': 0.505243545754234, 'session_latest_clicks_pair': 0.0855561763671393, 'session_latest_carts_pair': 0.9385977585844558, 'session_latest_time_wt_pair': 0.10061981578883844, 'session_latest_clicks_time_wt_pair': 0.4333993378523306, 'session_latest_type_wt_pair': 0.3591323191040616, 'session_latest_clicks_carts_pair': 0.40918158107419367, 'session_latest_clicks_orders_pair': 0.3614009297668969}. Best is trial 15 with value: 0.454.
# [I 2022-12-05 07:04:04,100] Trial 37 finished with value: 0.435 and parameters: {'session_frequent': 0.285979898313971, 'session_latest': 0.8310390140405616, 'total_frequent': 0.17594515782488623, 'session_frequent_pair': 0.7150661034635091, 'session_latest_pair0': 0.2630966519167294, 'session_latest_pair1': 0.800209682830216, 'session_latest_pair2': 0.6838546807937416, 'session_latest_pair3': 0.38074882911469976, 'session_latest_pair4': 0.07722995101331243, 'session_frequent_clicks_pair': 0.8824779233927316, 'session_latest_clicks_pair': 0.4858971236019759, 'session_latest_carts_pair': 0.7196440772761954, 'session_latest_time_wt_pair': 0.17507704454433087, 'session_latest_clicks_time_wt_pair': 0.022846753338561565, 'session_latest_type_wt_pair': 0.5660618040250409, 'session_latest_clicks_carts_pair': 0.8569346513257144, 'session_latest_clicks_orders_pair': 0.5285066642811935}. Best is trial 15 with value: 0.454.
# [I 2022-12-05 07:04:08,346] Trial 38 finished with value: 0.454 and parameters: {'session_frequent': 0.1757475101649821, 'session_latest': 0.00271442584218339, 'total_frequent': 0.2739893617115744, 'session_frequent_pair': 0.6193363786934696, 'session_latest_pair0': 0.5744506232178851, 'session_latest_pair1': 0.16959276134336893, 'session_latest_pair2': 0.0738145909277163, 'session_latest_pair3': 0.46439927677059406, 'session_latest_pair4': 0.20491665458399724, 'session_frequent_clicks_pair': 0.3604733226715361, 'session_latest_clicks_pair': 0.3796775410859888, 'session_latest_carts_pair': 0.62231026568518, 'session_latest_time_wt_pair': 0.2549750969807237, 'session_latest_clicks_time_wt_pair': 0.28750027096748165, 'session_latest_type_wt_pair': 0.48169917849832095, 'session_latest_clicks_carts_pair': 0.5559323679717665, 'session_latest_clicks_orders_pair': 0.6084967231250783}. Best is trial 15 with value: 0.454.
# [I 2022-12-05 07:04:12,240] Trial 39 finished with value: 0.449 and parameters: {'session_frequent': 0.17626308249457803, 'session_latest': 0.033598594051670067, 'total_frequent': 0.2734283898033704, 'session_frequent_pair': 0.051680905789457, 'session_latest_pair0': 0.5587530803486753, 'session_latest_pair1': 0.15418125290883894, 'session_latest_pair2': 0.001803693269927742, 'session_latest_pair3': 0.2774921774527086, 'session_latest_pair4': 0.17515735553905876, 'session_frequent_clicks_pair': 0.40095626218411706, 'session_latest_clicks_pair': 0.38501301110196484, 'session_latest_carts_pair': 0.5301896072189357, 'session_latest_time_wt_pair': 0.2667885662549351, 'session_latest_clicks_time_wt_pair': 0.2834197096093011, 'session_latest_type_wt_pair': 0.46141478180416545, 'session_latest_clicks_carts_pair': 0.527526824905447, 'session_latest_clicks_orders_pair': 0.22956544594841463}. Best is trial 15 with value: 0.454.
# [I 2022-12-05 07:04:16,143] Trial 40 finished with value: 0.44 and parameters: {'session_frequent': 0.3948316728835473, 'session_latest': 0.2354228987663135, 'total_frequent': 0.42894504886807244, 'session_frequent_pair': 0.5316464261215214, 'session_latest_pair0': 0.6765389760112829, 'session_latest_pair1': 0.05139913898842788, 'session_latest_pair2': 0.06026513909133795, 'session_latest_pair3': 0.468855189822137, 'session_latest_pair4': 0.2310528203247739, 'session_frequent_clicks_pair': 0.5541401820817657, 'session_latest_clicks_pair': 0.21585419290459484, 'session_latest_carts_pair': 0.458814561844347, 'session_latest_time_wt_pair': 0.061393411064380066, 'session_latest_clicks_time_wt_pair': 0.1731381029883698, 'session_latest_type_wt_pair': 0.19014304812250926, 'session_latest_clicks_carts_pair': 0.7200127495491075, 'session_latest_clicks_orders_pair': 0.6260530929449915}. Best is trial 15 with value: 0.454.
# [I 2022-12-05 07:04:20,342] Trial 41 finished with value: 0.455 and parameters: {'session_frequent': 0.07994880243437218, 'session_latest': 0.11256093359510175, 'total_frequent': 0.10410775100524022, 'session_frequent_pair': 0.6341218907851172, 'session_latest_pair0': 0.6084537507979062, 'session_latest_pair1': 0.2351200146866237, 'session_latest_pair2': 0.17792686728185467, 'session_latest_pair3': 0.5586973800080982, 'session_latest_pair4': 0.14985910848571538, 'session_frequent_clicks_pair': 0.3432978122224453, 'session_latest_clicks_pair': 0.3145474689544048, 'session_latest_carts_pair': 0.6218687806147238, 'session_latest_time_wt_pair': 0.16922390924525557, 'session_latest_clicks_time_wt_pair': 0.3247082107841853, 'session_latest_type_wt_pair': 0.3864625344535889, 'session_latest_clicks_carts_pair': 0.5747907572208489, 'session_latest_clicks_orders_pair': 0.7185954735219}. Best is trial 41 with value: 0.455.
# [I 2022-12-05 07:04:24,171] Trial 42 finished with value: 0.455 and parameters: {'session_frequent': 0.22086191985439318, 'session_latest': 0.09022102592664366, 'total_frequent': 0.20041704451189474, 'session_frequent_pair': 0.6862167258265937, 'session_latest_pair0': 0.7524970282186639, 'session_latest_pair1': 0.24866723603635477, 'session_latest_pair2': 0.15783057065468004, 'session_latest_pair3': 0.5698664802408145, 'session_latest_pair4': 0.2934103754735888, 'session_frequent_clicks_pair': 0.42220654215106784, 'session_latest_clicks_pair': 0.33042201918146796, 'session_latest_carts_pair': 0.6198069447206651, 'session_latest_time_wt_pair': 0.16453204098818908, 'session_latest_clicks_time_wt_pair': 0.09086627215101475, 'session_latest_type_wt_pair': 0.3863242948947794, 'session_latest_clicks_carts_pair': 0.5793212171276422, 'session_latest_clicks_orders_pair': 0.7516757230873139}. Best is trial 41 with value: 0.455.
# [I 2022-12-05 07:04:28,377] Trial 43 finished with value: 0.455 and parameters: {'session_frequent': 0.09323848438754079, 'session_latest': 0.005886154418723741, 'total_frequent': 0.19975405077236583, 'session_frequent_pair': 0.6974278048135334, 'session_latest_pair0': 0.6004315421057081, 'session_latest_pair1': 0.23852664377708707, 'session_latest_pair2': 0.13999909124189594, 'session_latest_pair3': 0.5761325807316371, 'session_latest_pair4': 0.3135054775042502, 'session_frequent_clicks_pair': 0.3679413791057696, 'session_latest_clicks_pair': 0.3491476208690204, 'session_latest_carts_pair': 0.5871469949283599, 'session_latest_time_wt_pair': 0.1587477396202927, 'session_latest_clicks_time_wt_pair': 0.09970595136280275, 'session_latest_type_wt_pair': 0.3926563416283644, 'session_latest_clicks_carts_pair': 0.5809997474783858, 'session_latest_clicks_orders_pair': 0.7395208104749464}. Best is trial 41 with value: 0.455.
# [I 2022-12-05 07:04:32,327] Trial 44 finished with value: 0.455 and parameters: {'session_frequent': 0.08163437067739088, 'session_latest': 0.07774509007752337, 'total_frequent': 0.1959006895379241, 'session_frequent_pair': 0.7031336193562219, 'session_latest_pair0': 0.6143396253588486, 'session_latest_pair1': 0.21966410977070225, 'session_latest_pair2': 0.1598083902077742, 'session_latest_pair3': 0.6582360533129246, 'session_latest_pair4': 0.31519472582929864, 'session_frequent_clicks_pair': 0.36872972645514435, 'session_latest_clicks_pair': 0.3365143222702938, 'session_latest_carts_pair': 0.5900736607917815, 'session_latest_time_wt_pair': 0.3281851477686525, 'session_latest_clicks_time_wt_pair': 0.2122142995850115, 'session_latest_type_wt_pair': 0.3972794894286671, 'session_latest_clicks_carts_pair': 0.6523162368869511, 'session_latest_clicks_orders_pair': 0.747264001519842}. Best is trial 41 with value: 0.455.
# [I 2022-12-05 07:04:36,529] Trial 45 finished with value: 0.456 and parameters: {'session_frequent': 0.15913100832885863, 'session_latest': 0.07373483074175934, 'total_frequent': 0.29734812368653296, 'session_frequent_pair': 0.6996794119532036, 'session_latest_pair0': 0.6096444910942211, 'session_latest_pair1': 0.23743395740840695, 'session_latest_pair2': 0.17315343523890653, 'session_latest_pair3': 0.5600386796324526, 'session_latest_pair4': 0.37795127828163, 'session_frequent_clicks_pair': 0.3524957159312321, 'session_latest_clicks_pair': 0.3917322572740754, 'session_latest_carts_pair': 0.5975473137109806, 'session_latest_time_wt_pair': 0.33937289071111354, 'session_latest_clicks_time_wt_pair': 0.10997143127938322, 'session_latest_type_wt_pair': 0.3837165795029641, 'session_latest_clicks_carts_pair': 0.54380546025518, 'session_latest_clicks_orders_pair': 0.8693490668918752}. Best is trial 45 with value: 0.456.
# [I 2022-12-05 07:04:40,446] Trial 46 finished with value: 0.454 and parameters: {'session_frequent': 0.07087109530669511, 'session_latest': 0.06912648513103768, 'total_frequent': 0.3308601219438697, 'session_frequent_pair': 0.6999103885558796, 'session_latest_pair0': 0.6170658303643409, 'session_latest_pair1': 0.23210121653120147, 'session_latest_pair2': 0.8601615751475001, 'session_latest_pair3': 0.6775527397528012, 'session_latest_pair4': 0.5548894737258607, 'session_frequent_clicks_pair': 0.45575258101917854, 'session_latest_clicks_pair': 0.17111036598294468, 'session_latest_carts_pair': 0.5856170357135327, 'session_latest_time_wt_pair': 0.4426196868296767, 'session_latest_clicks_time_wt_pair': 0.06808860044466589, 'session_latest_type_wt_pair': 0.3960525382244947, 'session_latest_clicks_carts_pair': 0.4820277272031842, 'session_latest_clicks_orders_pair': 0.9218214288603446}. Best is trial 45 with value: 0.456.
# [I 2022-12-05 07:04:44,344] Trial 47 finished with value: 0.449 and parameters: {'session_frequent': 0.22879228751494327, 'session_latest': 0.2856973179540993, 'total_frequent': 0.20571418909521463, 'session_frequent_pair': 0.7977524127503057, 'session_latest_pair0': 0.7147758873679366, 'session_latest_pair1': 0.08493032621253596, 'session_latest_pair2': 0.16859876432463297, 'session_latest_pair3': 0.5601930690449388, 'session_latest_pair4': 0.3823122958747244, 'session_frequent_clicks_pair': 0.3395209280459063, 'session_latest_clicks_pair': 0.3010533726621667, 'session_latest_carts_pair': 0.28700186723539556, 'session_latest_time_wt_pair': 0.32491867891416515, 'session_latest_clicks_time_wt_pair': 0.09029162332302211, 'session_latest_type_wt_pair': 0.2913579634091098, 'session_latest_clicks_carts_pair': 0.7012433473508372, 'session_latest_clicks_orders_pair': 0.8480262532665893}. Best is trial 45 with value: 0.456.
# [I 2022-12-05 07:04:48,623] Trial 48 finished with value: 0.456 and parameters: {'session_frequent': 0.13418467224594405, 'session_latest': 0.09732278225799768, 'total_frequent': 0.24201241381913324, 'session_frequent_pair': 0.6746017515700988, 'session_latest_pair0': 0.6296879828952412, 'session_latest_pair1': 0.2768849151016723, 'session_latest_pair2': 0.3800974146774063, 'session_latest_pair3': 0.6671800219792278, 'session_latest_pair4': 0.3102020292957862, 'session_frequent_clicks_pair': 0.4470752668761794, 'session_latest_clicks_pair': 0.5043761362046797, 'session_latest_carts_pair': 0.4571756690939958, 'session_latest_time_wt_pair': 0.3511996098532387, 'session_latest_clicks_time_wt_pair': 0.23500814773327516, 'session_latest_type_wt_pair': 0.3954441379198947, 'session_latest_clicks_carts_pair': 0.6062320056308154, 'session_latest_clicks_orders_pair': 0.7449097696339295}. Best is trial 45 with value: 0.456.
# [I 2022-12-05 07:04:52,583] Trial 49 finished with value: 0.448 and parameters: {'session_frequent': 0.7738686561104966, 'session_latest': 0.4623803312320195, 'total_frequent': 0.24940079454920136, 'session_frequent_pair': 0.6870992111656132, 'session_latest_pair0': 0.6659275862770229, 'session_latest_pair1': 0.29007739330271476, 'session_latest_pair2': 0.32515883039629523, 'session_latest_pair3': 0.6566185844393368, 'session_latest_pair4': 0.322195493061877, 'session_frequent_clicks_pair': 0.43665578694552987, 'session_latest_clicks_pair': 0.5339662892241147, 'session_latest_carts_pair': 0.4747821812086916, 'session_latest_time_wt_pair': 0.3637990786334043, 'session_latest_clicks_time_wt_pair': 0.2298443971122095, 'session_latest_type_wt_pair': 0.31218702639148493, 'session_latest_clicks_carts_pair': 0.5191653020440621, 'session_latest_clicks_orders_pair': 0.8618802578894794}. Best is trial 45 with value: 0.456.
# [I 2022-12-05 07:04:56,813] Trial 50 finished with value: 0.455 and parameters: {'session_frequent': 0.147627412106084, 'session_latest': 0.044938026578325206, 'total_frequent': 0.3254167858484758, 'session_frequent_pair': 0.7320724480082798, 'session_latest_pair0': 0.8809044049992523, 'session_latest_pair1': 0.10137721117731904, 'session_latest_pair2': 0.3946334143450353, 'session_latest_pair3': 0.5869787796600635, 'session_latest_pair4': 0.4681255454580789, 'session_frequent_clicks_pair': 0.5494365588217514, 'session_latest_clicks_pair': 0.40080459145930464, 'session_latest_carts_pair': 0.397380239236143, 'session_latest_time_wt_pair': 0.41928874114524417, 'session_latest_clicks_time_wt_pair': 0.06270101214794097, 'session_latest_type_wt_pair': 0.41289254156302824, 'session_latest_clicks_carts_pair': 0.6144439187052249, 'session_latest_clicks_orders_pair': 0.7745046935653045}. Best is trial 45 with value: 0.456.
# ...
# [I 2022-12-05 07:20:41,583] Trial 83 finished with value: 0.567 and parameters: {'session_frequent': 0.00020705086386507005, 'session_latest': 0.11092744882757119, 'total_frequent': 0.45673283333051395, 'session_frequent_pair': 0.2451970766091196, 'session_latest_pair0': 0.17882584250461986, 'session_latest_pair1': 0.4618360785973578, 'session_latest_pair2': 0.9837609581654595, 'session_latest_pair3': 0.49534080053419405, 'session_latest_pair4': 0.10369792968427695, 'session_frequent_clicks_pair': 0.36602610962516413, 'session_latest_clicks_pair': 0.3777525503724792, 'session_latest_carts_pair': 0.3178166992634698, 'session_latest_time_wt_pair': 0.24962781048819332, 'session_latest_clicks_time_wt_pair': 0.8658941187389291, 'session_latest_type_wt_pair': 0.01342085898996604, 'session_latest_clicks_carts_pair': 0.12359871586546535, 'session_latest_clicks_orders_pair': 0.2862869979968982}. Best is trial 81 with value: 0.572.
# [I 2022-12-05 07:20:45,490] Trial 84 finished with value: 0.565 and parameters: {'session_frequent': 0.003918257967230035, 'session_latest': 0.1158327379549911, 'total_frequent': 0.549321934138733, 'session_frequent_pair': 0.2597841457543454, 'session_latest_pair0': 0.3330944032300746, 'session_latest_pair1': 0.48688403066017966, 'session_latest_pair2': 0.9996708790012403, 'session_latest_pair3': 0.48736555802677867, 'session_latest_pair4': 0.09496214592012615, 'session_frequent_clicks_pair': 0.5850398538771271, 'session_latest_clicks_pair': 0.37000462000300116, 'session_latest_carts_pair': 0.34162030008198435, 'session_latest_time_wt_pair': 0.23824100538513626, 'session_latest_clicks_time_wt_pair': 0.8687693428984586, 'session_latest_type_wt_pair': 0.03610108258053908, 'session_latest_clicks_carts_pair': 0.026928962603096393, 'session_latest_clicks_orders_pair': 0.3138924864373659}. Best is trial 81 with value: 0.572.
# [I 2022-12-05 07:20:49,768] Trial 85 finished with value: 0.508 and parameters: {'session_frequent': 0.07114565633442675, 'session_latest': 0.11199875165715095, 'total_frequent': 0.45267465410160107, 'session_frequent_pair': 0.2543935238261388, 'session_latest_pair0': 0.3208177826520495, 'session_latest_pair1': 0.4911462052650374, 'session_latest_pair2': 0.9869837647550267, 'session_latest_pair3': 0.4878340409487076, 'session_latest_pair4': 0.05844650995247427, 'session_frequent_clicks_pair': 0.5509173883556169, 'session_latest_clicks_pair': 0.462791721484907, 'session_latest_carts_pair': 0.3395653991509183, 'session_latest_time_wt_pair': 0.20692461052987068, 'session_latest_clicks_time_wt_pair': 0.8518682141306628, 'session_latest_type_wt_pair': 0.004863689498849969, 'session_latest_clicks_carts_pair': 0.02671544408524075, 'session_latest_clicks_orders_pair': 0.28617509705012734}. Best is trial 81 with value: 0.572.
# [I 2022-12-05 07:20:53,727] Trial 86 finished with value: 0.57 and parameters: {'session_frequent': 0.02280472609589589, 'session_latest': 0.17794371533472778, 'total_frequent': 0.4711409731490659, 'session_frequent_pair': 0.41467167571069696, 'session_latest_pair0': 0.178219078602325, 'session_latest_pair1': 0.29195957494628444, 'session_latest_pair2': 0.8060807494084647, 'session_latest_pair3': 0.3678151388600476, 'session_latest_pair4': 0.17413450360169666, 'session_frequent_clicks_pair': 0.375424705429669, 'session_latest_clicks_pair': 0.3320306031971581, 'session_latest_carts_pair': 0.4541248543497389, 'session_latest_time_wt_pair': 0.2938663388789198, 'session_latest_clicks_time_wt_pair': 0.8265161119761371, 'session_latest_type_wt_pair': 0.06646445468572867, 'session_latest_clicks_carts_pair': 0.19422690160232592, 'session_latest_clicks_orders_pair': 0.06388701672321957}. Best is trial 81 with value: 0.572.
# [I 2022-12-05 07:20:57,649] Trial 87 finished with value: 0.563 and parameters: {'session_frequent': 0.023073421449539236, 'session_latest': 0.17720820740409451, 'total_frequent': 0.47156641762516843, 'session_frequent_pair': 0.38766074971466624, 'session_latest_pair0': 0.1857520513580774, 'session_latest_pair1': 0.29886775247543684, 'session_latest_pair2': 0.7976068689307486, 'session_latest_pair3': 0.37165310867825074, 'session_latest_pair4': 0.18187709484763886, 'session_frequent_clicks_pair': 0.3188808639597485, 'session_latest_clicks_pair': 0.32991794941164104, 'session_latest_carts_pair': 0.4610781971352268, 'session_latest_time_wt_pair': 0.2743212770476312, 'session_latest_clicks_time_wt_pair': 0.9349043946079063, 'session_latest_type_wt_pair': 0.062244537469382175, 'session_latest_clicks_carts_pair': 0.2022520741714902, 'session_latest_clicks_orders_pair': 0.016745968633327515}. Best is trial 81 with value: 0.572.
# [I 2022-12-05 07:21:01,837] Trial 88 finished with value: 0.555 and parameters: {'session_frequent': 0.11659378909588367, 'session_latest': 0.0034643662125660446, 'total_frequent': 0.5361987962685397, 'session_frequent_pair': 0.447218290955428, 'session_latest_pair0': 0.2665198241442742, 'session_latest_pair1': 0.23257402030772864, 'session_latest_pair2': 0.9260659321296467, 'session_latest_pair3': 0.3578034636735007, 'session_latest_pair4': 0.11446226739121204, 'session_frequent_clicks_pair': 0.5180807976634542, 'session_latest_clicks_pair': 0.564552609335924, 'session_latest_carts_pair': 0.5360025961660957, 'session_latest_time_wt_pair': 0.38165535181850013, 'session_latest_clicks_time_wt_pair': 0.8229904452746133, 'session_latest_type_wt_pair': 0.1063020325071452, 'session_latest_clicks_carts_pair': 0.23248313896719167, 'session_latest_clicks_orders_pair': 0.05989764448355693}. Best is trial 81 with value: 0.572.
# [I 2022-12-05 07:21:05,778] Trial 89 finished with value: 0.558 and parameters: {'session_frequent': 0.05878809677234634, 'session_latest': 0.14607734755745394, 'total_frequent': 0.43283813521493875, 'session_frequent_pair': 0.33155810456360313, 'session_latest_pair0': 0.16790119889984104, 'session_latest_pair1': 0.1711741263400327, 'session_latest_pair2': 0.8817064042985591, 'session_latest_pair3': 0.429458991755842, 'session_latest_pair4': 0.16670959470042063, 'session_frequent_clicks_pair': 0.6026262466165306, 'session_latest_clicks_pair': 0.40311974010039703, 'session_latest_carts_pair': 0.41299844521907936, 'session_latest_time_wt_pair': 0.30618048349713667, 'session_latest_clicks_time_wt_pair': 0.8738167489293717, 'session_latest_type_wt_pair': 0.1384579795319735, 'session_latest_clicks_carts_pair': 0.16380658362820535, 'session_latest_clicks_orders_pair': 0.10013718148322083}. Best is trial 81 with value: 0.572.
# [I 2022-12-05 07:21:10,027] Trial 90 finished with value: 0.519 and parameters: {'session_frequent': 0.09049565153503994, 'session_latest': 0.23291392027190988, 'total_frequent': 0.3835242181183191, 'session_frequent_pair': 0.2902772745797744, 'session_latest_pair0': 0.23143134060193013, 'session_latest_pair1': 0.390187806787531, 'session_latest_pair2': 0.9065452714392622, 'session_latest_pair3': 0.3226433958450199, 'session_latest_pair4': 0.2482826298230674, 'session_frequent_clicks_pair': 0.47295283630678986, 'session_latest_clicks_pair': 0.5047591763722336, 'session_latest_carts_pair': 0.4488861307006862, 'session_latest_time_wt_pair': 0.15117702630459295, 'session_latest_clicks_time_wt_pair': 0.7991608930113139, 'session_latest_type_wt_pair': 0.02286562079333465, 'session_latest_clicks_carts_pair': 0.07431822012930168, 'session_latest_clicks_orders_pair': 0.11261191502682605}. Best is trial 81 with value: 0.572.
# [I 2022-12-05 07:21:13,885] Trial 91 finished with value: 0.569 and parameters: {'session_frequent': 0.0023808605765010885, 'session_latest': 0.1215810044336359, 'total_frequent': 0.49253133564032703, 'session_frequent_pair': 0.20040774313803297, 'session_latest_pair0': 0.37697362266530515, 'session_latest_pair1': 0.5103044273159842, 'session_latest_pair2': 0.9993540020815713, 'session_latest_pair3': 0.48092823128047735, 'session_latest_pair4': 0.09497602572853531, 'session_frequent_clicks_pair': 0.5833461357266408, 'session_latest_clicks_pair': 0.39386031990085046, 'session_latest_carts_pair': 0.38329226659094995, 'session_latest_time_wt_pair': 0.20102730343016614, 'session_latest_clicks_time_wt_pair': 0.8731351712248573, 'session_latest_type_wt_pair': 0.05025748977355979, 'session_latest_clicks_carts_pair': 0.12357382346386465, 'session_latest_clicks_orders_pair': 0.3618826620981165}. Best is trial 81 with value: 0.572.
# [I 2022-12-05 07:21:18,150] Trial 92 finished with value: 0.568 and parameters: {'session_frequent': 0.024055024923269847, 'session_latest': 0.1814592072122257, 'total_frequent': 0.4781310243127561, 'session_frequent_pair': 0.20248705259250124, 'session_latest_pair0': 0.3933640546326707, 'session_latest_pair1': 0.530314336955548, 'session_latest_pair2': 0.9344605254178324, 'session_latest_pair3': 0.5506203830718535, 'session_latest_pair4': 0.12340845648029454, 'session_frequent_clicks_pair': 0.5375474367026731, 'session_latest_clicks_pair': 0.37680161801251894, 'session_latest_carts_pair': 0.37739659003321446, 'session_latest_time_wt_pair': 0.23852920762812477, 'session_latest_clicks_time_wt_pair': 0.8244051331917501, 'session_latest_type_wt_pair': 0.09358993413551844, 'session_latest_clicks_carts_pair': 0.12750164366399935, 'session_latest_clicks_orders_pair': 0.39658188123993315}. Best is trial 81 with value: 0.572.
# [I 2022-12-05 07:21:22,045] Trial 93 finished with value: 0.552 and parameters: {'session_frequent': 0.0551515998171976, 'session_latest': 0.18865347580248815, 'total_frequent': 0.49844410762292485, 'session_frequent_pair': 0.21004993751528062, 'session_latest_pair0': 0.40699723639206076, 'session_latest_pair1': 0.5269772043710468, 'session_latest_pair2': 0.999551175951895, 'session_latest_pair3': 0.4695513940616499, 'session_latest_pair4': 0.10557021717394151, 'session_frequent_clicks_pair': 0.5372895330491492, 'session_latest_clicks_pair': 0.41092383185271986, 'session_latest_carts_pair': 0.3838781649100937, 'session_latest_time_wt_pair': 0.12243113078850201, 'session_latest_clicks_time_wt_pair': 0.8187904263741309, 'session_latest_type_wt_pair': 0.057144975357860936, 'session_latest_clicks_carts_pair': 0.12831177685538558, 'session_latest_clicks_orders_pair': 0.3897639347701037}. Best is trial 81 with value: 0.572.
# [I 2022-12-05 07:21:26,006] Trial 94 finished with value: 0.566 and parameters: {'session_frequent': 0.019884231025552604, 'session_latest': 0.1333799140308245, 'total_frequent': 0.3705148583408017, 'session_frequent_pair': 0.1931010045207519, 'session_latest_pair0': 0.482360093304282, 'session_latest_pair1': 0.45938352490229983, 'session_latest_pair2': 0.8441105633054693, 'session_latest_pair3': 0.549895749049519, 'session_latest_pair4': 0.04625692327801184, 'session_frequent_clicks_pair': 0.6243042086274126, 'session_latest_clicks_pair': 0.37913527917490236, 'session_latest_carts_pair': 0.5114501712791704, 'session_latest_time_wt_pair': 0.24647324838615048, 'session_latest_clicks_time_wt_pair': 0.9631184746622828, 'session_latest_type_wt_pair': 0.08201307718515063, 'session_latest_clicks_carts_pair': 0.18119967193275874, 'session_latest_clicks_orders_pair': 0.35958520296717655}. Best is trial 81 with value: 0.572.
# [I 2022-12-05 07:21:30,191] Trial 95 finished with value: 0.567 and parameters: {'session_frequent': 0.00020713598593829477, 'session_latest': 0.0669754277764516, 'total_frequent': 0.48851547684883734, 'session_frequent_pair': 0.22913323726355503, 'session_latest_pair0': 0.36955930562760636, 'session_latest_pair1': 0.580335995036699, 'session_latest_pair2': 0.7505974087911185, 'session_latest_pair3': 0.43977744630297444, 'session_latest_pair4': 0.1279050813369473, 'session_frequent_clicks_pair': 0.40757743623954534, 'session_latest_clicks_pair': 0.4524410571363309, 'session_latest_carts_pair': 0.36730420039953804, 'session_latest_time_wt_pair': 0.2793185274553623, 'session_latest_clicks_time_wt_pair': 0.8656202997547597, 'session_latest_type_wt_pair': 0.0008332393481698674, 'session_latest_clicks_carts_pair': 0.14938888769418057, 'session_latest_clicks_orders_pair': 0.4365387949710897}. Best is trial 81 with value: 0.572.
# [I 2022-12-05 07:21:34,088] Trial 96 finished with value: 0.564 and parameters: {'session_frequent': 0.05662618243955732, 'session_latest': 0.07808200584275932, 'total_frequent': 0.49374768254089346, 'session_frequent_pair': 0.16764727517930902, 'session_latest_pair0': 0.3559759065007215, 'session_latest_pair1': 0.6040868194546306, 'session_latest_pair2': 0.7230442574369839, 'session_latest_pair3': 0.4384004924940645, 'session_latest_pair4': 0.14634665796746682, 'session_frequent_clicks_pair': 0.5807194407919696, 'session_latest_clicks_pair': 0.45190533479311035, 'session_latest_carts_pair': 0.3684093294584271, 'session_latest_time_wt_pair': 0.3384924303021311, 'session_latest_clicks_time_wt_pair': 0.9199114622562352, 'session_latest_type_wt_pair': 0.09805921519638536, 'session_latest_clicks_carts_pair': 0.15010035909052194, 'session_latest_clicks_orders_pair': 0.45695850620811035}. Best is trial 81 with value: 0.572.
# [I 2022-12-05 07:21:38,263] Trial 97 finished with value: 0.554 and parameters: {'session_frequent': 0.1776185169502695, 'session_latest': 0.03854467540562703, 'total_frequent': 0.5331639274089319, 'session_frequent_pair': 0.2257462993269947, 'session_latest_pair0': 0.3740432023045661, 'session_latest_pair1': 0.5831439544868696, 'session_latest_pair2': 0.7705042213799262, 'session_latest_pair3': 0.3930230517382935, 'session_latest_pair4': 0.2137710596900445, 'session_frequent_clicks_pair': 0.4021501002423711, 'session_latest_clicks_pair': 0.48650424130302294, 'session_latest_carts_pair': 0.439158690137591, 'session_latest_time_wt_pair': 0.28075182367135465, 'session_latest_clicks_time_wt_pair': 0.8905373859193191, 'session_latest_type_wt_pair': 0.11622841180822492, 'session_latest_clicks_carts_pair': 0.19605156405849467, 'session_latest_clicks_orders_pair': 0.42734154729338825}. Best is trial 81 with value: 0.572.
# [I 2022-12-05 07:21:42,157] Trial 98 finished with value: 0.541 and parameters: {'session_frequent': 0.08614953287791074, 'session_latest': 0.16483190124589112, 'total_frequent': 0.44422664694931335, 'session_frequent_pair': 0.5929422040077222, 'session_latest_pair0': 0.5027620091039093, 'session_latest_pair1': 0.520730350505058, 'session_latest_pair2': 0.9399380177738895, 'session_latest_pair3': 0.5064309055096133, 'session_latest_pair4': 0.07971606420042257, 'session_frequent_clicks_pair': 0.37216443780122355, 'session_latest_clicks_pair': 0.3108019864660938, 'session_latest_carts_pair': 0.3016111817926656, 'session_latest_time_wt_pair': 0.4301846779263685, 'session_latest_clicks_time_wt_pair': 0.8349193742135528, 'session_latest_type_wt_pair': 0.1522782689854449, 'session_latest_clicks_carts_pair': 0.1190305674855936, 'session_latest_clicks_orders_pair': 0.2575718353850774}. Best is trial 81 with value: 0.572.
# [I 2022-12-05 07:21:46,385] Trial 99 finished with value: 0.525 and parameters: {'session_frequent': 0.14231964833502503, 'session_latest': 0.08389019964457015, 'total_frequent': 0.41015987787736835, 'session_frequent_pair': 0.24057278529811926, 'session_latest_pair0': 0.5409918937283008, 'session_latest_pair1': 0.4128286535226337, 'session_latest_pair2': 0.8253141835468436, 'session_latest_pair3': 0.382175751721639, 'session_latest_pair4': 0.12401230079166407, 'session_frequent_clicks_pair': 0.3450535456147763, 'session_latest_clicks_pair': 0.5963548301688115, 'session_latest_carts_pair': 0.4038561713384836, 'session_latest_time_wt_pair': 0.2185062501554949, 'session_latest_clicks_time_wt_pair': 0.7763840808983968, 'session_latest_type_wt_pair': 0.011454819998703784, 'session_latest_clicks_carts_pair': 0.24764823238944494, 'session_latest_clicks_orders_pair': 0.3981925452206117}. Best is trial 81 with value: 0.572.
# 0:21:16.403692 	 orders_recall_best_value : 0.572
# 0:21:16.404850 	 SCORE : 0.49409999999999993

# %% [markdown]
# # sub作成

# %%
test = make_test_data(trans_maps)
sub = pd.read_csv(cfg.input_dir + f"sample_submission.csv", usecols=["session_type"])
dfs = []

for type_ in ["clicks", "carts", "orders"]:
    test_type = test.copy()
    test_type["rank"] 
    test_type["rank"] = test_type["rank"] * test_type["strategy"].map(wt[type_])
    test_type = test_type.sort_values(["session", "rank"])
    test_type = test_type.drop_duplicates(subset= ["session", "aid"], keep="first")
    test_type = test_type.groupby(["session"]).head(20)
    test_type["aid"] = test_type["aid"].astype(str)
    test_type = test_type.groupby("session")["aid"].apply(list).reset_index()
    test_type["aid"] = test_type["aid"].apply(lambda x: ' '.join(x))
    test_type["session_type"] = test_type["session"].astype(str) + f"_{type_}"
    test_type =test_type.rename(columns={"aid": "labels"})
    dfs.append(test_type)
test_preds = pd.concat(dfs)

sub = sub.merge(test_preds, on="session_type", how="left")
sub[["session_type", "labels"]].to_csv(cfg.output_dir + f"{cfg.exp_name}/{cfg.exp_name}_sub.csv", index=False)
# Out:
# 0:21:17.511870 	 [make_test] make_cand_df
# 0:21:17.877780 	 [make_candidate] session_frequent : start
# 0:21:18.459984 	 [add_candidate] session_frequent : start
# 0:21:18.808813 	 [make_candidate] session_latest : start
# 0:21:19.119670 	 [add_candidate] session_latest : start
# 0:21:19.512896 	 [make_candidate] session_frequent_pair : start
# 0:21:20.053649 	 [add_candidate] session_frequent_pair : start
# 0:21:20.509670 	 [make_candidate] session_latest_pair0 : start
# 0:21:21.107047 	 [add_candidate] session_latest_pair0 : start
# 0:21:21.600217 	 [make_candidate] session_latest_pair1 : start
# 0:21:22.257632 	 [add_candidate] session_latest_pair1 : start
# 0:21:22.804631 	 [make_candidate] session_latest_pair2 : start
# 0:21:23.425425 	 [add_candidate] session_latest_pair2 : start
# 0:21:24.016921 	 [make_candidate] session_latest_pair3 : start
# 0:21:24.668705 	 [add_candidate] session_latest_pair3 : start
# 0:21:25.309170 	 [make_candidate] session_latest_pair4 : start
# 0:21:25.946392 	 [add_candidate] session_latest_pair4 : start
# 0:21:26.621883 	 [make_candidate] session_latest_pair5 : start
# 0:21:27.338815 	 [add_candidate] session_latest_pair5 : start
# 0:21:28.069173 	 [make_candidate] session_latest_pair6 : start
# 0:21:28.730143 	 [add_candidate] session_latest_pair6 : start
# 0:21:29.478696 	 [make_candidate] session_latest_pair7 : start
# 0:21:30.224540 	 [add_candidate] session_latest_pair7 : start
# 0:21:31.050838 	 [make_candidate] session_latest_pair8 : start
# 0:21:31.745064 	 [add_candidate] session_latest_pair8 : start
# 0:21:32.712720 	 [make_candidate] session_latest_pair9 : start
# 0:21:33.434639 	 [add_candidate] session_latest_pair9 : start
# 0:21:34.739141 	 [make_candidate] session_frequent_clicks_pair : start
# 0:21:35.269916 	 [add_candidate] session_frequent_clicks_pair : start
# 0:21:36.396962 	 [make_candidate] session_latest_clicks_pair : start
# 0:21:37.112749 	 [add_candidate] session_latest_clicks_pair : start
# 0:21:38.414571 	 [make_candidate] session_latest_carts_pair : start
# 0:21:38.829737 	 [add_candidate] session_latest_carts_pair : start
# 0:21:39.995122 	 [make_candidate] session_latest_time_wt_pair : start
# 0:21:40.725469 	 [add_candidate] session_latest_time_wt_pair : start
# 0:21:41.895723 	 [make_candidate] session_latest_type_wt_pair : start
# 0:21:42.690537 	 [add_candidate] session_latest_type_wt_pair : start
# 0:21:44.127261 	 [make_candidate] session_latest_clicks_time_wt_pair : start
# 0:21:44.743896 	 [add_candidate] session_latest_clicks_time_wt_pair : start
# 0:21:46.291190 	 [make_candidate] session_latest_clicks_carts_pair : start
# 0:21:46.874561 	 [add_candidate] session_latest_clicks_carts_pair : start
# 0:21:48.227263 	 [make_candidate] session_latest_clicks_orders_pair : start
# 0:21:48.968594 	 [add_candidate] session_latest_clicks_orders_pair : start

# %%
sub.head()
# Out:
#       session_type   session  \
# 0  12899779_clicks  12899779
# 1   12899779_carts  12899779
# 2  12899779_orders  12899779
# 3  12899780_clicks  12899780
# 4   12899780_carts  12899780
#
#                                               labels
# 0  59625 737445 1854910 1130911 225209 894169 251...
# 1  59625 1130911 894169 1854910 737445 225209 251...
# 2  59625 1130911 225209 737445 1854910 894169 251...
# 3  1142000 1502122 736515 889686 1712906 973453 4...
# 4  1142000 736515 973453 1502122 582732 636101 48...
