# %% [markdown]
# # cand_trial
# n数調整

# %%
import os
import sys
import traceback
import gc
import random
import pickle
import pathlib
import subprocess
from dataclasses import dataclass
from dotenv import load_dotenv
load_dotenv
sys.path.append(os.getenv('UTILS_PATH'))
from tqdm import tqdm
import multiprocessing
import inspect

import pandas as pd
import polars as pl
import numpy as np
import itertools
import cudf
import lightgbm as lgb
import matplotlib.pyplot as plt
import seaborn as sns
import line_notify
import my_logger
from noglobal import noglobal

# %% [markdown]
# # 設定

# %%
@dataclass
class Cfg:
    loglevel = "INFO"
    exp_name = "cand_trial013"
    seed = 42
    k = 20
    cand_n = 15
    negative_sample = 1
    train_chunk_n_dict = {"clicks":2, "carts":1, "orders":1}
    test_chunk_n = 2
    type2id = {"clicks":0, "carts":1, "orders":2}
    id2type = {0:"clicks", 1:"carts", 2:"orders"}
    train_week = "week3"
    valid_week = "week4"
    valid_session_n = 100_000
    input_dir = os.getenv('INPUT_DIR')
    output_dir = os.getenv('OUTPUT_DIR')
    prep_dir = os.getenv("PREP_DIR")

    clicks_params = {'objective': 'binary', 'boosting': 'gbdt', 'learning_rate': 0.1, 'metric': 'binary_logloss', 'seed': 42, 'feature_pre_filter': False, 'lambda_l1': 5.485903737168179, 'lambda_l2': 0.005594683492536064, 'num_leaves': 79, 'feature_fraction': 0.552, 'bagging_fraction': 0.9295272232672004, 'bagging_freq': 2, 'min_child_samples': 10}
    carts_params = {'objective': 'binary', 'boosting': 'gbdt', 'learning_rate': 0.1, 'metric': 'binary_logloss', 'seed': 42, 'feature_pre_filter': False, 'lambda_l1': 8.709050252544463, 'lambda_l2': 0.06935262036337767, 'num_leaves': 252, 'feature_fraction': 0.4, 'bagging_fraction': 1.0, 'bagging_freq': 0, 'min_child_samples': 5}
    orders_params = {'objective': 'binary', 'boosting': 'gbdt', 'learning_rate': 0.1, 'metric': 'binary_logloss', 'seed': 42, 'feature_pre_filter': False, 'lambda_l1': 9.356310279757256, 'lambda_l2': 1.3120983078968551e-08, 'num_leaves': 174, 'feature_fraction': 0.5, 'bagging_fraction': 1.0, 'bagging_freq': 0, 'min_child_samples': 20}

cfg = Cfg()
os.makedirs(os.path.join(cfg.output_dir, cfg.exp_name), exist_ok=True)
os.makedirs(os.path.join(cfg.output_dir, cfg.exp_name, "cache"), exist_ok=True)
random.seed(cfg.seed)

logger = my_logger.init_logger(cfg.exp_name)

# %%
class Cache:
    @noglobal(excepts=["cfg", "logger"])
    def __init__(self):
        self.cache_dir = (os.path.join(cfg.output_dir, cfg.exp_name, "cache"))
        self.cache_dir_path = pathlib.Path(self.cache_dir)
        self.caches = list(self.cache_dir_path.glob("*"))

    def update(self):
        self.caches = list(self.cache_dir_path.glob("*"))

    @noglobal(excepts=["cfg", "logger"])
    def get_abspath(self, filename):
        return (os.path.join(self.cache_dir, filename))
    
    @noglobal(excepts=["cfg", "logger"])
    def exists(self, path):
        self.update()
        return len([str(c) for c in self.caches if path == str(c)]) > 0

cache = Cache()

# %%
@noglobal(excepts=["cfg", "logger"])
def evaluate(clicks_labels, carts_labels, orders_labels, 
             clicks_preds, carts_preds, orders_preds, k=20):

    num_clicks = 0
    num_carts = 0
    num_orders = 0
    hit_clicks = 0
    hit_carts = 0
    hit_orders = 0

    for i in range(len(clicks_labels)):
        clicks_label = clicks_labels[i]
        carts_label = carts_labels[i]
        orders_label = orders_labels[i]
        clicks_pred = clicks_preds[i]
        carts_pred = carts_preds[i]
        orders_pred = orders_preds[i]

        if type(clicks_pred) == list:
            clicks_pred = clicks_pred[:k]
        else:
            clicks_pred = []
        if type(carts_pred) == list:
            carts_pred = carts_pred[:k]
        else:
            carts_pred = []    
        if type(orders_pred) == list:
            orders_pred = orders_pred[:k]
        else:
            orders_pred = []

        if not np.isnan(clicks_label):
            num_clicks += 1
            hit_clicks += int(clicks_label in clicks_pred)

        if type(carts_label) == np.ndarray:
            num_carts += min(len(carts_label), k)
            hit_carts += len(set(carts_pred) & set(carts_label))
            
        if type(orders_label) == np.ndarray:
            num_orders += min(len(orders_label), k)
            hit_orders += len(set(orders_pred) & set(orders_label))


    recall_clicks = hit_clicks / num_clicks
    recall_carts = hit_carts / num_carts
    recall_orders = hit_orders / num_orders
    w_recall_clicks = recall_clicks * 0.10
    w_recall_carts = recall_carts * 0.30
    w_recall_orders = recall_orders * 0.60
    score = w_recall_clicks + w_recall_carts + w_recall_orders

    results = {}
    results["num_clicks"] = num_clicks
    results["hit_clicks"] = hit_clicks
    results["num_carts"] = num_carts
    results["hit_carts"] = hit_carts
    results["num_orders"] = num_orders
    results["hit_orders"] = hit_orders
    results["recall_clicks"] = format(recall_clicks, ".6f")
    results["recall_carts"] = format(recall_carts, ".6f")
    results["recall_orders"] = format(recall_orders, ".6f")
    results["w_recall_clicks"] = format(w_recall_clicks, ".6f")
    results["w_recall_carts"] = format(w_recall_carts, ".6f")
    results["w_recall_orders"] = format(w_recall_orders, ".6f")
    results["score"] = format(score, ".6f")

    return results

# %%
class Candidate:
    @noglobal(excepts=["cfg", "logger"])
    def __init__(self, pl_df):
        self.df = cudf.from_pandas(pl_df.to_pandas())
        self.sessions = []
        self.aids = []

    @noglobal(excepts=["cfg", "logger"])
    def add(self, strategy, name, usetypes=['clicks', 'carts', 'orders'], trans_map=None, k=20):
        logger.info(f"[add_candidate] {name} : start")
        candidate_df = self.df[self.df["type"].isin(usetypes)].copy()
        
        if strategy == "session_frequent":
            candidate_df = self._session_frequent(candidate_df, k)
        elif strategy == "session_latest":
            candidate_df = self._session_latest(candidate_df, k)
        elif strategy == "total_frequent":
            candidate_df = self._total_frequent(candidate_df, k)
        elif strategy == "repurchase":
            candidate_df = self._repurchase(candidate_df)
        elif strategy == "clstr_freq":
            candidate_df = self._clstr_freq(candidate_df, k)
        
        if trans_map is not None:
            candidate_df["aid"] = candidate_df["aid"].map(trans_map).astype("int32")
            candidate_df = candidate_df.dropna(subset=["aid"])
        candidate_df = candidate_df.drop_duplicates(subset=["session", "aid"])
        
        self.sessions.extend(candidate_df["session"].to_arrow().to_pylist())
        self.aids.extend(candidate_df["aid"].to_arrow().to_pylist())

    @noglobal(excepts=["cfg", "logger"])
    def get_dataframe(self):
        cand_df = pl.DataFrame([
            pl.Series("session", self.sessions, pl.Int32),
            pl.Series("aid", self.aids, pl.Int32)
            ]).unique()
        return cand_df

    @noglobal(excepts=["cfg", "logger"])
    def _repurchase(self, candidate_df):
        return candidate_df[["session", "aid"]].drop_duplicates()

    @noglobal(excepts=["cfg", "logger"])
    def _clstr_freq(self, candidate_df, k):
        session_clstr = pd.read_parquet(cfg.prep_dir + "w2v_session_cluster_c10000_week4.parquet")
        session_clstr = {session:clstr for session, clstr in zip(session_clstr["session"].tolist(), session_clstr["clstr"].tolist())}
        clstr_freq = pd.read_parquet(cfg.prep_dir + "w2v_cluster_freq_c10000_week4.parquet")
        clstr_freq = clstr_freq[clstr_freq["rank"]<k]
        clstr_freq = clstr_freq.groupby("clstr")["aid"].apply(list).to_dict()

        sessions = []
        aids = []
        for session in candidate_df["session"].to_pandas().unique():
            clstr = session_clstr[session]
            most_freq_aids = clstr_freq[clstr]
            aids.extend(most_freq_aids)
            sessions.extend([session for _ in range(len(most_freq_aids))])
        candidate_df = cudf.DataFrame({"session": sessions, "aid": aids})
        return candidate_df

    @noglobal(excepts=["cfg", "logger"])
    def _session_frequent(self, candidate_df, k):
        candidate_df = candidate_df.groupby(["session", "aid"])["ts"].count().reset_index()
        candidate_df.columns = ["session", "aid", "aid_count"]
        candidate_df = candidate_df.sort_values(["session", "aid_count", "aid"], ascending=(True, False, True))
        candidate_df = candidate_df[candidate_df.groupby("session")["aid_count"].cumcount() < k].copy()
        candidate_df = candidate_df[["session", "aid"]].copy()
        return candidate_df

    @noglobal(excepts=["cfg", "logger"])
    def _session_latest(self, candidate_df, k):
        candidate_df = candidate_df.sort_values(["session", "ts"], ascending=(True, False)).drop_duplicates(subset=["session", "aid"])
        candidate_df = candidate_df.sort_values(["session", "ts"], ascending=(True, False))[candidate_df.groupby("session")["ts"].cumcount() < k].copy()
        candidate_df = candidate_df[["session", "aid"]].copy()
        return candidate_df

    @noglobal(excepts=["cfg", "logger"])
    def _total_frequent(self, candidate_df, k):
        candidate_df = candidate_df.groupby("aid")["ts"].count().reset_index()
        candidate_df.columns = ["aid", "aid_count"]
        topk_freq_aids = candidate_df.sort_values("aid_count", ascending=False)["aid"].to_arrow().to_pylist()[:k]
        sessions = []
        aids = []
        for session, aid in itertools.product(self.target_sessions, topk_freq_aids):
            sessions.append(session)
            aids.append(aid)
        candidate_df = cudf.DataFrame({"session": sessions, "aid": aids})
        return candidate_df

# %%
@noglobal(excepts=["cfg", "logger"])
def make_cand_df(sessions, trans_maps=None):
    cand = Candidate(sessions)
    cand.add(strategy="repurchase", name="repurchase")
    cand.add(strategy="clstr_freq", name="clstr_freq", k=30)
    #cand.add(strategy="session_frequent", name="session_frequent", k=15)
    #cand.add(strategy="session_latest", name="session_latest", k=30)
    
    for i in range(20):
        cand.add(strategy="session_latest", trans_map=trans_maps[f"time_wt_pair{str(i)}"], name=f"session_latest_time_wt_pair{str(i)}", k=15)
        cand.add(strategy="session_latest", trans_map=trans_maps[f"word2vec_pair{str(i)}"], name=f"session_latest_word2vec_pair{str(i)}", k=15)
        cand.add(strategy="session_latest", trans_map=trans_maps[f"pair{str(i)}"], name=f"session_latest_pair{str(i)}", k=15)
        cand.add(strategy="session_latest", trans_map=trans_maps[f"type_wt_pair{str(i)}"], name=f"session_latest_type_wt_pair{str(i)}", k=15)
        cand.add(strategy="session_latest", trans_map=trans_maps[f"clicks2carts_pair{str(i)}"], name=f"session_latest_clicks2carts_pair{str(i)}", k=15)
        cand.add(strategy="session_latest", trans_map=trans_maps[f"clicks2orders_pair{str(i)}"], name=f"session_latest_clicks2orders_pair{str(i)}", k=15)

    return cand.get_dataframe()

# %%
@noglobal(excepts=["cfg", "logger"])
def get_pair_df(name, wt_col, week):
    if week is not None:
        name = f"{name}_{week}"
    return pl.read_parquet(cfg.prep_dir + f"{name}.parquet").sort(wt_col, reverse=True)

@noglobal(excepts=["cfg", "logger"])
def get_trans_maps(week=None):
    """
    aidを別のaidに置き換えるmapping辞書を取得する
    """
    trans_maps = {}

    pair_df_org = get_pair_df("co_visitation_matrix", "cnt", week)
    for i in range(20):
        pair_df = pair_df_org.groupby("aid_x").head(i+1)
        pair_dict = {k: v for k, v in zip(pair_df.get_column("aid_x").to_list(), pair_df.get_column("aid_y").to_list())}
        trans_maps[f"pair{str(i)}"] = pair_dict
    
    pair_df_org = get_pair_df("co_visitation_matrix_time_weighted", "wt", week)
    for i in range(20):
        pair_df = pair_df_org.groupby("aid_x").head(i+1)
        pair_dict = {k: v for k, v in zip(pair_df.get_column("aid_x").to_list(), pair_df.get_column("aid_y").to_list())}
        trans_maps[f"time_wt_pair{str(i)}"] = pair_dict

    pair_df_org = get_pair_df("co_visitation_matrix_type_weighted", "wt", week)
    for i in range(20):
        pair_df = pair_df_org.groupby("aid_x").head(i+1)
        pair_dict = {k: v for k, v in zip(pair_df.get_column("aid_x").to_list(), pair_df.get_column("aid_y").to_list())}
        trans_maps[f"type_wt_pair{str(i)}"] = pair_dict

    pair_df_org = get_pair_df("co_visitation_matrix_clicks2carts", "cnt", week)
    for i in range(20):
        pair_df = pair_df_org.groupby("aid_x").head(i+1)
        pair_dict = {k: v for k, v in zip(pair_df.get_column("aid_x").to_list(), pair_df.get_column("aid_y").to_list())}
        trans_maps[f"clicks2carts_pair{str(i)}"] = pair_dict

    pair_df_org = get_pair_df("co_visitation_matrix_clicks2orders", "cnt", week)
    for i in range(20):
        pair_df = pair_df_org.groupby("aid_x").head(i+1)
        pair_dict = {k: v for k, v in zip(pair_df.get_column("aid_x").to_list(), pair_df.get_column("aid_y").to_list())}
        trans_maps[f"clicks2orders_pair{str(i)}"] = pair_dict

    pair_df_org = get_pair_df("word2vec_similar", "sim", None)
    for i in range(20):
        pair_df = pair_df = pair_df_org.groupby("aid_x").head(i+1)
        pair_dict = {k: v for k, v in zip(pair_df.get_column("aid_x").to_list(), pair_df.get_column("aid_y").to_list())}
        trans_maps[f"word2vec_pair{str(i)}"] = pair_dict

    return trans_maps

# %%
@noglobal(excepts=["cfg", "logger", "cache"])
def make_valid_cand():
    # データ読み込み
    week_sessions = pl.read_parquet(cfg.prep_dir + f"train_sessions_{cfg.valid_week}.parquet")
    week_sessions = week_sessions.select([
        pl.col("session").cast(pl.Int32),
        pl.col("aid").cast(pl.Int32),
        pl.col("ts"),
        pl.col("type")
        ])
    
    week_labels = pl.read_parquet(cfg.prep_dir + f"labels_{cfg.valid_week}.parquet")
    week_labels = week_labels.select([
        pl.col("session").cast(pl.Int32),
        pl.col("clicks_labels").cast(pl.Int32),
        pl.col("carts_labels"),
        pl.col("orders_labels")
        ])
    valid_sessions = week_sessions.get_column("session").unique().to_list()
    
    trans_map_cache_file = f"trans_maps_{cfg.valid_week}.pkl"
    trans_map_cache_path = cache.get_abspath(trans_map_cache_file)
    with open(trans_map_cache_path, "rb") as f:
        trans_maps = pickle.load(f)

    # validに使うsessionを絞る
    use_session_n = min(cfg.valid_session_n, len(valid_sessions))
    random.seed(cfg.seed)
    use_sessions = random.sample(valid_sessions, use_session_n)
    week_sessions = week_sessions.filter(pl.col("session").is_in(use_sessions))
    week_labels = week_labels.filter(pl.col("session").is_in(use_sessions))

    # 候補選出
    cand_df = make_cand_df(week_sessions, trans_maps=trans_maps)
    return cand_df, week_sessions, week_labels

# %%
logger.info("\n\nSTART\n\n")
cache_file = f"trans_maps_{cfg.valid_week}.pkl"
cache_path = cache.get_abspath(cache_file)

if cache.exists(cache_path):
    logger.info(f"[{cache_file}] cache exists. load cache and skip process.")
    with open(cache_path, "rb") as f:
        trans_maps = pickle.load(f)
else:
    trans_maps = get_trans_maps(cfg.valid_week)
    with open(cache_path, "wb") as f:
        pickle.dump(trans_maps, f)

cand_df, _, labels = make_valid_cand()

cand_df = cand_df.to_pandas()
labels = labels.to_pandas()
vl_pred_df = cand_df.groupby("session")["aid"].apply(list).reset_index()
session_n_max = cand_df["session"].value_counts().max()
session_n_mean = cand_df["session"].value_counts().mean()
session_n_min = cand_df["session"].value_counts().min()
session_n_median = cand_df["session"].value_counts().median()

score = evaluate(labels["clicks_labels"].tolist(),
                 labels["carts_labels"].tolist(),
                 labels["orders_labels"].tolist(),
                 vl_pred_df["aid"].tolist(),
                 vl_pred_df["aid"].tolist(),
                 vl_pred_df["aid"].tolist(),
                 session_n_max)

logger.info(f"session_n_max : {str(session_n_max)}, session_n_min : {str(session_n_min)},  session_n_mean : {str(session_n_mean)},  session_n_median : {str(session_n_median)}")
logger.info(f"score : {str(score)}")
# Out:
# 0:00:00.312859
#
# START
#
#
# 0:00:00.316227 	 [trans_maps_week4.pkl] cache exists. load cache and skip process.
# 0:01:00.066075 	 [add_candidate] repurchase : start
# 0:01:00.563028 	 [add_candidate] clstr_freq : start
# 0:01:04.616196 	 [add_candidate] session_latest_time_wt_pair0 : start
# 0:01:05.191486 	 [add_candidate] session_latest_word2vec_pair0 : start
# 0:01:05.865468 	 [add_candidate] session_latest_pair0 : start
# 0:01:06.418255 	 [add_candidate] session_latest_type_wt_pair0 : start
# 0:01:06.978098 	 [add_candidate] session_latest_clicks2carts_pair0 : start
# 0:01:07.451710 	 [add_candidate] session_latest_clicks2orders_pair0 : start
# 0:01:07.832664 	 [add_candidate] session_latest_time_wt_pair1 : start
# 0:01:08.347211 	 [add_candidate] session_latest_word2vec_pair1 : start
# 0:01:08.865470 	 [add_candidate] session_latest_pair1 : start
# 0:01:09.382414 	 [add_candidate] session_latest_type_wt_pair1 : start
# 0:01:09.904149 	 [add_candidate] session_latest_clicks2carts_pair1 : start
# 0:01:10.344780 	 [add_candidate] session_latest_clicks2orders_pair1 : start
# 0:01:10.722328 	 [add_candidate] session_latest_time_wt_pair2 : start
# 0:01:11.243935 	 [add_candidate] session_latest_word2vec_pair2 : start
# 0:01:11.776071 	 [add_candidate] session_latest_pair2 : start
# 0:01:12.298230 	 [add_candidate] session_latest_type_wt_pair2 : start
# 0:01:12.841256 	 [add_candidate] session_latest_clicks2carts_pair2 : start
# 0:01:13.292386 	 [add_candidate] session_latest_clicks2orders_pair2 : start
# 0:01:13.703151 	 [add_candidate] session_latest_time_wt_pair3 : start
# 0:01:14.229789 	 [add_candidate] session_latest_word2vec_pair3 : start
# 0:01:14.786759 	 [add_candidate] session_latest_pair3 : start
# 0:01:15.332539 	 [add_candidate] session_latest_type_wt_pair3 : start
# 0:01:15.888205 	 [add_candidate] session_latest_clicks2carts_pair3 : start
# 0:01:16.350973 	 [add_candidate] session_latest_clicks2orders_pair3 : start
# 0:01:16.744605 	 [add_candidate] session_latest_time_wt_pair4 : start
# 0:01:17.268927 	 [add_candidate] session_latest_word2vec_pair4 : start
# 0:01:17.793406 	 [add_candidate] session_latest_pair4 : start
# 0:01:18.312868 	 [add_candidate] session_latest_type_wt_pair4 : start
# 0:01:18.877761 	 [add_candidate] session_latest_clicks2carts_pair4 : start
# 0:01:19.330896 	 [add_candidate] session_latest_clicks2orders_pair4 : start
# 0:01:19.710293 	 [add_candidate] session_latest_time_wt_pair5 : start
# 0:01:20.236970 	 [add_candidate] session_latest_word2vec_pair5 : start
# 0:01:20.777742 	 [add_candidate] session_latest_pair5 : start
# 0:01:21.302129 	 [add_candidate] session_latest_type_wt_pair5 : start
# 0:01:21.845321 	 [add_candidate] session_latest_clicks2carts_pair5 : start
# 0:01:22.294554 	 [add_candidate] session_latest_clicks2orders_pair5 : start
# 0:01:22.686245 	 [add_candidate] session_latest_time_wt_pair6 : start
# 0:01:23.201348 	 [add_candidate] session_latest_word2vec_pair6 : start
# 0:01:23.735820 	 [add_candidate] session_latest_pair6 : start
# 0:01:24.253570 	 [add_candidate] session_latest_type_wt_pair6 : start
# 0:01:24.795890 	 [add_candidate] session_latest_clicks2carts_pair6 : start
# 0:01:25.246030 	 [add_candidate] session_latest_clicks2orders_pair6 : start
# 0:01:25.664883 	 [add_candidate] session_latest_time_wt_pair7 : start
# 0:01:26.228468 	 [add_candidate] session_latest_word2vec_pair7 : start
# 0:01:26.789533 	 [add_candidate] session_latest_pair7 : start
# 0:01:27.337383 	 [add_candidate] session_latest_type_wt_pair7 : start
# 0:01:27.938337 	 [add_candidate] session_latest_clicks2carts_pair7 : start
# 0:01:28.382742 	 [add_candidate] session_latest_clicks2orders_pair7 : start
# 0:01:28.763816 	 [add_candidate] session_latest_time_wt_pair8 : start
# 0:01:29.288692 	 [add_candidate] session_latest_word2vec_pair8 : start
# 0:01:29.812264 	 [add_candidate] session_latest_pair8 : start
# 0:01:30.349247 	 [add_candidate] session_latest_type_wt_pair8 : start
# 0:01:30.939259 	 [add_candidate] session_latest_clicks2carts_pair8 : start
# 0:01:31.394302 	 [add_candidate] session_latest_clicks2orders_pair8 : start
# 0:01:31.800321 	 [add_candidate] session_latest_time_wt_pair9 : start
# 0:01:32.323168 	 [add_candidate] session_latest_word2vec_pair9 : start
# 0:01:32.853623 	 [add_candidate] session_latest_pair9 : start
# 0:01:33.389376 	 [add_candidate] session_latest_type_wt_pair9 : start
# 0:01:33.949018 	 [add_candidate] session_latest_clicks2carts_pair9 : start
# 0:01:34.407165 	 [add_candidate] session_latest_clicks2orders_pair9 : start
# 0:01:34.805268 	 [add_candidate] session_latest_time_wt_pair10 : start
# 0:01:35.340362 	 [add_candidate] session_latest_word2vec_pair10 : start
# 0:01:35.859450 	 [add_candidate] session_latest_pair10 : start
# 0:01:36.390509 	 [add_candidate] session_latest_type_wt_pair10 : start
# 0:01:36.926059 	 [add_candidate] session_latest_clicks2carts_pair10 : start
# 0:01:37.390025 	 [add_candidate] session_latest_clicks2orders_pair10 : start
# 0:01:37.776955 	 [add_candidate] session_latest_time_wt_pair11 : start
# 0:01:38.342188 	 [add_candidate] session_latest_word2vec_pair11 : start
# 0:01:38.875303 	 [add_candidate] session_latest_pair11 : start
# 0:01:39.409742 	 [add_candidate] session_latest_type_wt_pair11 : start
# 0:01:39.955507 	 [add_candidate] session_latest_clicks2carts_pair11 : start
# 0:01:40.410649 	 [add_candidate] session_latest_clicks2orders_pair11 : start
# 0:01:40.782562 	 [add_candidate] session_latest_time_wt_pair12 : start
# 0:01:41.311611 	 [add_candidate] session_latest_word2vec_pair12 : start
# 0:01:41.860592 	 [add_candidate] session_latest_pair12 : start
# 0:01:42.420279 	 [add_candidate] session_latest_type_wt_pair12 : start
# 0:01:42.973929 	 [add_candidate] session_latest_clicks2carts_pair12 : start
# 0:01:43.427909 	 [add_candidate] session_latest_clicks2orders_pair12 : start
# 0:01:43.793323 	 [add_candidate] session_latest_time_wt_pair13 : start
# 0:01:44.315744 	 [add_candidate] session_latest_word2vec_pair13 : start
# 0:01:44.851493 	 [add_candidate] session_latest_pair13 : start
# 0:01:45.384789 	 [add_candidate] session_latest_type_wt_pair13 : start
# 0:01:45.902892 	 [add_candidate] session_latest_clicks2carts_pair13 : start
# 0:01:46.339983 	 [add_candidate] session_latest_clicks2orders_pair13 : start
# 0:01:46.727638 	 [add_candidate] session_latest_time_wt_pair14 : start
# 0:01:47.275393 	 [add_candidate] session_latest_word2vec_pair14 : start
# 0:01:47.815977 	 [add_candidate] session_latest_pair14 : start
# 0:01:48.338160 	 [add_candidate] session_latest_type_wt_pair14 : start
# 0:01:48.880077 	 [add_candidate] session_latest_clicks2carts_pair14 : start
# 0:01:49.326545 	 [add_candidate] session_latest_clicks2orders_pair14 : start
# 0:01:49.711306 	 [add_candidate] session_latest_time_wt_pair15 : start
# 0:01:50.263574 	 [add_candidate] session_latest_word2vec_pair15 : start
# 0:01:50.831644 	 [add_candidate] session_latest_pair15 : start
# 0:01:51.370982 	 [add_candidate] session_latest_type_wt_pair15 : start
# 0:01:51.925009 	 [add_candidate] session_latest_clicks2carts_pair15 : start
# 0:01:52.387515 	 [add_candidate] session_latest_clicks2orders_pair15 : start
# 0:01:52.765577 	 [add_candidate] session_latest_time_wt_pair16 : start
# 0:01:53.290470 	 [add_candidate] session_latest_word2vec_pair16 : start
# 0:01:53.842719 	 [add_candidate] session_latest_pair16 : start
# 0:01:54.379469 	 [add_candidate] session_latest_type_wt_pair16 : start
# 0:01:54.907519 	 [add_candidate] session_latest_clicks2carts_pair16 : start
# 0:01:55.353867 	 [add_candidate] session_latest_clicks2orders_pair16 : start
# 0:01:55.741262 	 [add_candidate] session_latest_time_wt_pair17 : start
# 0:01:56.272937 	 [add_candidate] session_latest_word2vec_pair17 : start
# 0:01:56.802623 	 [add_candidate] session_latest_pair17 : start
# 0:01:57.322286 	 [add_candidate] session_latest_type_wt_pair17 : start
# 0:01:57.866484 	 [add_candidate] session_latest_clicks2carts_pair17 : start
# 0:01:58.325012 	 [add_candidate] session_latest_clicks2orders_pair17 : start
# 0:01:58.708587 	 [add_candidate] session_latest_time_wt_pair18 : start
# 0:01:59.233802 	 [add_candidate] session_latest_word2vec_pair18 : start
# 0:01:59.776415 	 [add_candidate] session_latest_pair18 : start
# 0:02:00.320162 	 [add_candidate] session_latest_type_wt_pair18 : start
# 0:02:00.869143 	 [add_candidate] session_latest_clicks2carts_pair18 : start
# 0:02:01.324326 	 [add_candidate] session_latest_clicks2orders_pair18 : start
# 0:02:01.718739 	 [add_candidate] session_latest_time_wt_pair19 : start
# 0:02:02.255377 	 [add_candidate] session_latest_word2vec_pair19 : start
# 0:02:02.794297 	 [add_candidate] session_latest_pair19 : start
# 0:02:03.318900 	 [add_candidate] session_latest_type_wt_pair19 : start
# 0:02:03.859197 	 [add_candidate] session_latest_clicks2carts_pair19 : start
# 0:02:04.312393 	 [add_candidate] session_latest_clicks2orders_pair19 : start
# 0:02:19.015584 	 session_n_max : 1013, session_n_min : 43,  session_n_mean : 186.15311,  session_n_median : 111.0
# 0:02:19.016838 	 score : {'num_clicks': 97136, 'hit_clicks': 59751, 'num_carts': 43611, 'hit_carts': 20295, 'num_orders': 20109, 'hit_orders': 13394, 'recall_clicks': '0.615127', 'recall_carts': '0.465364', 'recall_orders': '0.666070', 'w_recall_clicks': '0.061513', 'w_recall_carts': '0.139609', 'w_recall_orders': '0.399642', 'score': '0.600764'}
