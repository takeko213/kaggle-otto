# %% [markdown]
# # exp064
# 類似ユーザ追加 carts, ordersのcv確認のみ

# %%
import os
import sys
import traceback
import gc
import random
import pickle
import pathlib
import subprocess
from dataclasses import dataclass
from dotenv import load_dotenv
load_dotenv
sys.path.append(os.getenv('UTILS_PATH'))
from tqdm import tqdm
import multiprocessing
import inspect

import pandas as pd
import polars as pl
import numpy as np
import itertools
import cudf
import lightgbm as lgb
import matplotlib.pyplot as plt
import seaborn as sns
import line_notify
import my_logger
from noglobal import noglobal

# %% [markdown]
# # 設定

# %%
@dataclass
class Cfg:
    loglevel = "INFO"
    exp_name = "exp064"
    run_inf = False
    seed = 42
    k = 20
    cand_n = 15
    negative_sample = 1
    train_chunk_n_dict = {"clicks":2, "carts":1, "orders":1}
    test_chunk_n = 5
    type2id = {"clicks":0, "carts":1, "orders":2}
    id2type = {0:"clicks", 1:"carts", 2:"orders"}
    train_week = "week3"
    valid_week = "week4"
    valid_session_n = 100_000
    input_dir = os.getenv('INPUT_DIR')
    output_dir = os.getenv('OUTPUT_DIR')
    prep_dir = os.getenv("PREP_DIR")

    clicks_params = {'objective': 'binary', 'boosting': 'gbdt', 'learning_rate': 0.1, 'metric': 'binary_logloss', 'seed': 42, 'feature_pre_filter': False, 'lambda_l1': 5.485903737168179, 'lambda_l2': 0.005594683492536064, 'num_leaves': 79, 'feature_fraction': 0.552, 'bagging_fraction': 0.9295272232672004, 'bagging_freq': 2, 'min_child_samples': 10}
    carts_params = {'objective': 'binary', 'boosting': 'gbdt', 'learning_rate': 0.1, 'metric': 'binary_logloss', 'seed': 42, 'feature_pre_filter': False, 'lambda_l1': 8.709050252544463, 'lambda_l2': 0.06935262036337767, 'num_leaves': 252, 'feature_fraction': 0.4, 'bagging_fraction': 1.0, 'bagging_freq': 0, 'min_child_samples': 5}
    orders_params = {'objective': 'binary', 'boosting': 'gbdt', 'learning_rate': 0.1, 'metric': 'binary_logloss', 'seed': 42, 'feature_pre_filter': False, 'lambda_l1': 9.356310279757256, 'lambda_l2': 1.3120983078968551e-08, 'num_leaves': 174, 'feature_fraction': 0.5, 'bagging_fraction': 1.0, 'bagging_freq': 0, 'min_child_samples': 20}

cfg = Cfg()
os.makedirs(os.path.join(cfg.output_dir, cfg.exp_name), exist_ok=True)
os.makedirs(os.path.join(cfg.output_dir, cfg.exp_name, "cache"), exist_ok=True)
random.seed(cfg.seed)

logger = my_logger.init_logger(cfg.exp_name)

# %%
class Cache:
    @noglobal(excepts=["cfg", "logger"])
    def __init__(self):
        self.cache_dir = (os.path.join(cfg.output_dir, cfg.exp_name, "cache"))
        self.cache_dir_path = pathlib.Path(self.cache_dir)
        self.caches = list(self.cache_dir_path.glob("*"))

    def update(self):
        self.caches = list(self.cache_dir_path.glob("*"))

    @noglobal(excepts=["cfg", "logger"])
    def get_abspath(self, filename):
        return (os.path.join(self.cache_dir, filename))
    
    @noglobal(excepts=["cfg", "logger"])
    def exists(self, path):
        self.update()
        return len([str(c) for c in self.caches if path == str(c)]) > 0

cache = Cache()

# %%
def reduce_mem_usage(df):
    """ iterate through all the columns of a dataframe and modify the data type
        to reduce memory usage.        
    """
    start_mem = df.memory_usage().sum() / 1024**2
    print('Memory usage of dataframe is {:.2f} MB'.format(start_mem))
    
    for col in df.columns:
        col_type = df[col].dtype
        
        if col_type != object:
            c_min = df[col].min()
            c_max = df[col].max()
            if str(col_type)[:3] == 'int':
                if c_min > np.iinfo(np.int8).min and c_max < np.iinfo(np.int8).max:
                    df[col] = df[col].astype(np.int8)
                elif c_min > np.iinfo(np.int16).min and c_max < np.iinfo(np.int16).max:
                    df[col] = df[col].astype(np.int16)
                elif c_min > np.iinfo(np.int32).min and c_max < np.iinfo(np.int32).max:
                    df[col] = df[col].astype(np.int32)
                elif c_min > np.iinfo(np.int64).min and c_max < np.iinfo(np.int64).max:
                    df[col] = df[col].astype(np.int64)  
            else:
                if c_min > np.finfo(np.float16).min and c_max < np.finfo(np.float16).max:
                    df[col] = df[col].astype(np.float32)
                elif c_min > np.finfo(np.float32).min and c_max < np.finfo(np.float32).max:
                    df[col] = df[col].astype(np.float32)
                else:
                    df[col] = df[col].astype(np.float64)
        else:
            df[col] = df[col].astype('category')

    end_mem = df.memory_usage().sum() / 1024**2
    print('Memory usage after optimization is: {:.2f} MB'.format(end_mem))
    print('Decreased by {:.1f}%'.format(100 * (start_mem - end_mem) / start_mem))
    
    return df

# %%
@noglobal(excepts=["cfg", "logger"])
def evaluate(clicks_labels, carts_labels, orders_labels, 
             clicks_preds, carts_preds, orders_preds, k=20):

    num_clicks = 0
    num_carts = 0
    num_orders = 0
    hit_clicks = 0
    hit_carts = 0
    hit_orders = 0

    for i in range(len(clicks_labels)):
        clicks_label = clicks_labels[i]
        carts_label = carts_labels[i]
        orders_label = orders_labels[i]
        clicks_pred = clicks_preds[i]
        carts_pred = carts_preds[i]
        orders_pred = orders_preds[i]

        if type(clicks_pred) == list:
            clicks_pred = clicks_pred[:k]
        else:
            clicks_pred = []
        if type(carts_pred) == list:
            carts_pred = carts_pred[:k]
        else:
            carts_pred = []    
        if type(orders_pred) == list:
            orders_pred = orders_pred[:k]
        else:
            orders_pred = []

        if not np.isnan(clicks_label):
            num_clicks += 1
            hit_clicks += int(clicks_label in clicks_pred)

        if type(carts_label) == np.ndarray:
            num_carts += min(len(carts_label), k)
            hit_carts += len(set(carts_pred) & set(carts_label))
            
        if type(orders_label) == np.ndarray:
            num_orders += min(len(orders_label), k)
            hit_orders += len(set(orders_pred) & set(orders_label))


    recall_clicks = hit_clicks / num_clicks
    recall_carts = hit_carts / num_carts
    recall_orders = hit_orders / num_orders
    w_recall_clicks = recall_clicks * 0.10
    w_recall_carts = recall_carts * 0.30
    w_recall_orders = recall_orders * 0.60
    score = w_recall_clicks + w_recall_carts + w_recall_orders

    results = {}
    results["num_clicks"] = num_clicks
    results["hit_clicks"] = hit_clicks
    results["num_carts"] = num_carts
    results["hit_carts"] = hit_carts
    results["num_orders"] = num_orders
    results["hit_orders"] = hit_orders
    results["recall_clicks"] = format(recall_clicks, ".6f")
    results["recall_carts"] = format(recall_carts, ".6f")
    results["recall_orders"] = format(recall_orders, ".6f")
    results["w_recall_clicks"] = format(w_recall_clicks, ".6f")
    results["w_recall_carts"] = format(w_recall_carts, ".6f")
    results["w_recall_orders"] = format(w_recall_orders, ".6f")
    results["score"] = format(score, ".6f")

    return results

# %%
class Candidate:
    @noglobal(excepts=["cfg", "logger"])
    def __init__(self, pl_df, week):
        self.df = cudf.from_pandas(pl_df.to_pandas())
        self.sessions = []
        self.aids = []
        self.week = week

    @noglobal(excepts=["cfg", "logger"])
    def add(self, strategy, name, usetypes=['clicks', 'carts', 'orders'], trans_map=None, k=20):
        logger.info(f"[add_candidate] {name} : start")
        candidate_df = self.df[self.df["type"].isin(usetypes)].copy()
        
        if strategy == "session_frequent":
            candidate_df = self._session_frequent(candidate_df, k)
        elif strategy == "session_latest":
            candidate_df = self._session_latest(candidate_df, k)
        elif strategy == "total_frequent":
            candidate_df = self._total_frequent(candidate_df, k)
        elif strategy == "repurchase":
            candidate_df = self._repurchase(candidate_df)
        elif strategy == "clstr_freq":
            candidate_df = self._clstr_freq(candidate_df, k)
        
        if trans_map is not None:
            candidate_df["aid"] = candidate_df["aid"].map(trans_map).astype("int32")
            candidate_df = candidate_df.dropna(subset=["aid"])
        candidate_df = candidate_df.drop_duplicates(subset=["session", "aid"])
        
        self.sessions.extend(candidate_df["session"].to_arrow().to_pylist())
        self.aids.extend(candidate_df["aid"].to_arrow().to_pylist())

    @noglobal(excepts=["cfg", "logger"])
    def get_dataframe(self):
        cand_df = pl.DataFrame([
            pl.Series("session", self.sessions, pl.Int32),
            pl.Series("aid", self.aids, pl.Int32)
            ]).unique()
        return cand_df

    @noglobal(excepts=["cfg", "logger"])
    def _repurchase(self, candidate_df):
        return candidate_df[["session", "aid"]].drop_duplicates()

    @noglobal(excepts=["cfg", "logger"])
    def _clstr_freq(self, candidate_df, k):
        if self.week is None:
            session_clstr = pd.read_parquet(cfg.prep_dir + "w2v_session_cluster_c10000.parquet")
            clstr_freq = pd.read_parquet(cfg.prep_dir + "w2v_cluster_freq_c10000.parquet")
        else:
            session_clstr = pd.read_parquet(cfg.prep_dir + f"w2v_session_cluster_c10000_{self.week}.parquet")
            clstr_freq = pd.read_parquet(cfg.prep_dir + f"w2v_cluster_freq_c10000_{self.week}.parquet")
        session_clstr = {session:clstr for session, clstr in zip(session_clstr["session"].tolist(), session_clstr["clstr"].tolist())}
        clstr_freq = clstr_freq[clstr_freq["rank"]<k]
        clstr_freq = clstr_freq.groupby("clstr")["aid"].apply(list).to_dict()

        sessions = []
        aids = []
        for session in candidate_df["session"].to_pandas().unique():
            clstr = session_clstr[session]
            most_freq_aids = clstr_freq[clstr]
            aids.extend(most_freq_aids)
            sessions.extend([session for _ in range(len(most_freq_aids))])
        candidate_df = cudf.DataFrame({"session": sessions, "aid": aids})
        return candidate_df

    @noglobal(excepts=["cfg", "logger"])
    def _session_frequent(self, candidate_df, k):
        candidate_df = candidate_df.groupby(["session", "aid"])["ts"].count().reset_index()
        candidate_df.columns = ["session", "aid", "aid_count"]
        candidate_df = candidate_df.sort_values(["session", "aid_count", "aid"], ascending=(True, False, True))
        candidate_df = candidate_df[candidate_df.groupby("session")["aid_count"].cumcount() < k].copy()
        candidate_df = candidate_df[["session", "aid"]].copy()
        return candidate_df

    @noglobal(excepts=["cfg", "logger"])
    def _session_latest(self, candidate_df, k):
        candidate_df = candidate_df.sort_values(["session", "ts"], ascending=(True, False)).drop_duplicates(subset=["session", "aid"])
        candidate_df = candidate_df.sort_values(["session", "ts"], ascending=(True, False))[candidate_df.groupby("session")["ts"].cumcount() < k].copy()
        candidate_df = candidate_df[["session", "aid"]].copy()
        return candidate_df

    @noglobal(excepts=["cfg", "logger"])
    def _total_frequent(self, candidate_df, k):
        candidate_df = candidate_df.groupby("aid")["ts"].count().reset_index()
        candidate_df.columns = ["aid", "aid_count"]
        topk_freq_aids = candidate_df.sort_values("aid_count", ascending=False)["aid"].to_arrow().to_pylist()[:k]
        sessions = []
        aids = []
        for session, aid in itertools.product(self.target_sessions, topk_freq_aids):
            sessions.append(session)
            aids.append(aid)
        candidate_df = cudf.DataFrame({"session": sessions, "aid": aids})
        return candidate_df

# %%
@noglobal(excepts=["cfg", "logger"])
def add_labels(df, labels, type_):
    if type_ == "clicks":
        type_labels = (labels.select([pl.col("session"), 
                                      pl.col(f"{type_}_labels").cast(pl.Int32).alias("aid"),
                                      pl.lit(1).alias("labels")])
        )
    else:
        type_labels = (labels.explode(f"{type_}_labels")
                             .select([pl.col("session"), 
                                      pl.col(f"{type_}_labels").cast(pl.Int32).alias("aid"),
                                      pl.lit(1).alias("labels")])
        )

    df = (df.join(type_labels, on=["session", "aid"], how="left")
            .select([pl.exclude("labels"),
                     pl.col("labels").fill_null(0)])
    )        
    return df

# %%
@noglobal(excepts=["cfg", "logger"])
def add_ground_truth_candidate(df, labels, type_):
    gt = labels[["session", f"{type_}_labels"]].dropna().copy()
    gt.columns = ["session", "aid"]
    gt = gt.explode("aid")
    df = pd.concat([df, gt])
    df = df.drop_duplicates()
    return df

# %%
@noglobal(excepts=["cfg", "logger"])
def under_sampling(df, label_col):
    cfg = Cfg()
    pos_df = df.filter(pl.col(label_col)==1)
    neg_df = df.filter(pl.col(label_col)==0)
    pos_n = pos_df.shape[0]
    return pl.concat([pos_df, neg_df.sample(pos_n * cfg.negative_sample, seed=cfg.seed)])

# %%
class Features:
    @noglobal(excepts=["cfg", "logger"])
    def __init__(self, sessions, candidate, week):
        self.sessions = cudf.from_pandas(sessions.to_pandas())
        self.output = candidate
        self.type_dict = cfg.type2id
        self.week = week
        self.latest_aid_n = 10

    @noglobal(excepts=["cfg", "logger"])
    def add_features(self):
        # self._prep()
        self._session_cnt()
        self._session_aid_nunique()
        self._session_last_type()
        self._aid_cnt()
        self._all_times_aid_features()
        self._w2v_vectors()
        self._relative_ts()
        self._add_aid_latest()
        self._co_visit_rank("co_visitation_matrix")
        self._co_visit_rank("co_visitation_matrix_time_weighted", "wt")
        self._co_visit_rank("co_visitation_matrix_type_weighted", "wt")
        self._co_visit_rank("co_visitation_matrix_clicks2carts")
        self._co_visit_rank("co_visitation_matrix_clicks2orders")
        self._latest_aid_w2v_sims()
        self._drop_aid_latest()
        self._clstr_rank()
        # self._session_mean_ts()
        # self._aid_mean_ts()
        # self._aid_cnt_ratio_at_session_last()
        # self.output = self.output.drop(columns=["session_last_day"]) # 日時はtrainセット内のみで有効なので削除

    @noglobal(excepts=["cfg", "logger"])
    def _prep(self):
        logger.info("[features] prep : start")
        # ts関連の前処理
        self.sessions["relative_ts"] = self.sessions["ts"] - self.sessions["ts"].min()
        self.sessions["dt"] = cudf.to_datetime(self.sessions["ts"], unit="ms")
        self.sessions["hour"] = self.sessions["dt"].dt.hour
        self.sessions["week"] = self.sessions["dt"].dt.dayofweek
        self.sessions["day"] = self.sessions["dt"].dt.day
        
    @noglobal(excepts=["cfg", "logger"])
    def _session_cnt(self):
        logger.info("[features] session_cnt : start")
        agg_df = self.sessions.groupby(["session", "type"])["ts"].count().reset_index().rename(columns={"ts": "cnt"})
        # session_total_cnt
        features = agg_df.groupby("session")["cnt"].sum().reset_index().rename(columns={"cnt": "session_total_cnt"})
        self.output = self.output.join(pl.from_pandas(features.to_pandas()), on=["session"], how="left")
        self.output = self.output.select([pl.exclude("session_total_cnt"), pl.col("session_total_cnt").fill_null(0)])
        # session_{type}_cnt
        for type_ in ["clicks", "carts", "orders"]:
            col_name = f"session_{type_}_cnt"
            features = agg_df[agg_df["type"]==type_].copy()
            features = features.rename(columns={"cnt": col_name})
            features = features[["session", col_name]].copy()
            self.output = self.output.join(pl.from_pandas(features.to_pandas()), on=["session"], how="left")
            self.output = self.output.select([pl.exclude(col_name), pl.col(col_name).fill_null(0)])
        
    @noglobal(excepts=["cfg", "logger"])
    def _session_aid_nunique(self):
        logger.info("[features] session_aid_nunique : start")
        features = self.sessions.groupby("session")["aid"].nunique().reset_index().rename(columns={"aid": "session_aid_nunique"})
        self.output = self.output.join(pl.from_pandas(features.to_pandas()), on=["session"], how="left")
        self.output = self.output.select([pl.exclude("session_aid_nunique"), pl.col("session_aid_nunique").fill_null(0)])
        
    @noglobal(excepts=["cfg", "logger"])
    def _session_last_type(self):
        logger.info("[features] session_last_type : start")
        features = self.sessions.groupby("session").nth(-1).reset_index()[["session", "type"]]
        features = features.rename(columns={"type": "session_last_type"})
        features["session_last_type"] = features["session_last_type"].map(self.type_dict)
        self.output = self.output.join(pl.from_pandas(features.to_pandas()), on=["session"], how="left")
        
    @noglobal(excepts=["cfg", "logger"])
    def _session_last_dt(self):
        logger.info("[features] session_last_dt : start")
        features = self.sessions.groupby("session").nth(-1).reset_index()[["session", "relative_ts", "week", "day", "hour"]]
        features.columns = ["session", "session_last_ts", "session_last_week", "session_last_day", "session_last_hour"]
        self.output = self.output.join(pl.from_pandas(features.to_pandas()), on=["session"], how="left")
        
    @noglobal(excepts=["cfg", "logger"])
    def _session_mean_ts(self):
        logger.info("[features] session_mean_ts : start")
        features = self.sessions.groupby("session")["relative_ts"].mean().reset_index().rename(columns={"relative_ts": "session_mean_ts"})
        self.output = self.output.join(pl.from_pandas(features.to_pandas()), on=["session"], how="left")
        
    @noglobal(excepts=["cfg", "logger"])
    def _aid_mean_ts(self):
        logger.info("[features] aid_mean_ts : start")
        features = self.sessions.groupby("aid")["relative_ts"].mean().reset_index().rename(columns={"relative_ts": "aid_mean_ts"})
        self.output = self.output.join(pl.from_pandas(features.to_pandas()), on=["aid"], how="left")
       
    @noglobal(excepts=["cfg", "logger"])
    def _aid_session_nunique(self):
        logger.info("[features] aid_session_unique : start")
        features = self.sessions.groupby("aid")["session"].nunique().reset_index().rename(columns={"session": "aid_session_nunique"})
        self.output = self.output.join(pl.from_pandas(features.to_pandas()), on=["aid"], how="left")

    @noglobal(excepts=["cfg", "logger"]) 
    def _aid_cnt_ratio_at_session_last(self):
        logger.info("[features] aid_cnt_ratio_atsession_last : start")
        for dt_ in ["week", "day", "hour"]:
            features = self.sessions[["aid", dt_]].copy()
            features["total_cnt"] = features.groupby(dt_)["aid"].transform("count")
            features = features.groupby(["aid", dt_])["total_cnt"].agg(["count", "max"]).reset_index()
            features[f"aid_cnt_ratio_at_session_last_{dt_}"] = features["count"] / features["max"]
            features = features.rename(columns={dt_: f"session_last_{dt_}"})
            self.output = self.output.join(pl.from_pandas(features[["aid", f"session_last_{dt_}", f"aid_cnt_ratio_at_session_last_{dt_}"]].to_pandas()), on=["aid", f"session_last_{dt_}"], how="left")
            self.output = self.output.select([pl.exclude(f"aid_cnt_ratio_at_session_last_{dt_}"), pl.col(f"aid_cnt_ratio_at_session_last_{dt_}").fill_null(0)])
        
    @noglobal(excepts=["cfg", "logger"])
    def _aid_cnt(self):
        logger.info("[features] aid_cnt : start")
        agg_df = self.sessions.groupby(["session", "aid", "type"])["ts"].count().reset_index().rename(columns={"ts": "cnt"})

        # aid_total_cnt
        features = agg_df.groupby(["session", "aid"])["cnt"].sum().reset_index().rename(columns={"cnt": "aid_total_cnt"})
        self.output = self.output.join(pl.from_pandas(features.to_pandas()), on=["session", "aid"], how="left")
        self.output = self.output.select([pl.exclude(f"aid_total_cnt"), pl.col(f"aid_total_cnt").fill_null(0)])

        # aid_{type}_cnt
        for type_ in ["clicks", "carts", "orders"]:
            col_name = f"aid_{type_}_cnt"
            logger.info(f"[features] {col_name} : start")
            features = agg_df[agg_df["type"]==type_].copy()
            features = features.rename(columns={"cnt": col_name})
            features = features[["session", "aid", col_name]].copy()
            self.output = self.output.join(pl.from_pandas(features.to_pandas()), on=["session", "aid"], how="left")
            self.output = self.output.select([pl.exclude(col_name), pl.col(col_name).fill_null(0)])

    @noglobal(excepts=["cfg", "logger"])
    def _all_times_aid_features(self):
        feats = ["all_times_aid_freq",
                 "all_times_aid_clicks_freq",
                 "all_times_aid_carts_freq",
                 "all_times_aid_orders_freq",
                 "all_times_aid_session_freq",
                 "all_times_aid_session_clicks_freq",
                 "all_times_aid_session_carts_freq",
                 "all_times_aid_session_orders_freq",
                 "all_times_aid_carts_ratio_with_clicks",
                 "all_times_aid_orders_ratio_with_clicks",
                 "all_times_aid_date_std",
                 "all_times_aid_hour_std",
                 "all_times_aid_day_of_week_std"]
        
        for feat in feats:
            logger.info(f"[features] {feat} : start")
            if self.week is None:
                with open(cfg.prep_dir + f"{feat}.pkl", "rb") as f:
                    feat_map = pickle.load(f)
            else:
                with open(cfg.prep_dir + f"{feat}_{self.week}.pkl", "rb") as f:
                    feat_map = pickle.load(f)

            feat_df = pl.DataFrame(
                [
                    pl.Series("aid", feat_map.keys(), dtype=pl.Int32),
                    pl.Series(feat, feat_map.values())
                ]
            )
            self.output = self.output.join(feat_df, on="aid", how="left")

    @noglobal(excepts=["cfg", "logger"])
    def _w2v_vectors(self):
        logger.info(f"[features] w2v_vectors : start")
        w2v_vecs = pl.read_parquet(cfg.prep_dir + "w2v_vector_n5.parquet")
        w2v_vecs = w2v_vecs.select(
            [
                pl.exclude("aid"),
                pl.col("aid").cast(pl.Int32)
            ]
        )
        self.output = self.output.join(w2v_vecs, on="aid", how="left")

    @noglobal(excepts=["cfg", "logger"])
    def _relative_ts(self):
        logger.info(f"[features] relative_ts : start")
        features = self.sessions.sort_values(["session", "ts"]).drop_duplicates(subset=["session", "aid"], keep="last")
        features["relative_ts_in_session"] = features.groupby("session")["ts"].transform("max") - features["ts"]
        features = features.sort_values(["session", "ts"], ascending=(True, False)).reset_index(drop=True)
        features["ts_rank_in_session"] = features.groupby("session").cumcount()
        features = features[["session", "aid", "relative_ts_in_session", "ts_rank_in_session"]]
        self.output = self.output.join(pl.from_pandas(features.to_pandas()), on=["session", "aid"], how="left")

    @noglobal(excepts=["cfg", "logger"])
    def _add_aid_latest(self):
        sorted_df = self.sessions.sort_values(["session", "ts"], ascending=(True, False), ignore_index=True)
        for i in range(self.latest_aid_n):
            latest_aid = sorted_df.groupby("session").nth(i)["aid"].reset_index().rename(columns={"aid": f"aid_latest{i}"})
            latest_aid[f"aid_latest{i}"] = latest_aid[f"aid_latest{i}"].astype("int32")
            self.output = self.output.join(pl.from_pandas(latest_aid.to_pandas()), on="session", how="left")
            self.output = self.output.select([pl.exclude(f"aid_latest{i}"), pl.col(f"aid_latest{i}").fill_null(-1)])
    
    @noglobal(excepts=["cfg", "logger"])
    def _drop_aid_latest(self):
        drop_cols = [f"aid_latest{str(i)}" for i in range(self.latest_aid_n)]
        self.output = self.output.select(pl.exclude(drop_cols))

    @noglobal(excepts=["cfg", "logger"])
    def _co_visit_rank(self, co_visit_name, wt_col="cnt"):
        logger.info(f"[features] co_visit_rank({co_visit_name}) : start")
        if self.week is None:
            co_visit_df = pl.read_parquet(cfg.prep_dir + f"{co_visit_name}.parquet")
        else:
            co_visit_df = pl.read_parquet(cfg.prep_dir + f"{co_visit_name}_{self.week}.parquet")

        co_visit_df = co_visit_df.select(
            [
                pl.col("aid_x").cast(pl.Int32),
                pl.col("aid_y").cast(pl.Int32),
                pl.col("rank").cast(pl.Int32)
            ]
        )

        for i in range(self.latest_aid_n):
            col_name = f"{co_visit_name}_lt{i}"
            logger.info(f"[features] co_visit_rank({col_name}) : start")
            self.output = self.output.join(co_visit_df, left_on=[f"aid_latest{i}", "aid"], right_on=["aid_x", "aid_y"], how="left")
            self.output = self.output.select([pl.exclude("rank"), pl.col("rank").fill_null(-1).alias(col_name)])

    @noglobal(excepts=["cfg", "logger"])
    def _clstr_rank(self):
        if self.week is None:
            session_clstr = pl.read_parquet(cfg.prep_dir + "w2v_session_cluster_c10000.parquet").select([pl.col("session").cast(pl.Int32), pl.col("clstr").cast(pl.Int32)])
            clstr_freq = pl.read_parquet(cfg.prep_dir + "w2v_cluster_freq_c10000.parquet").select([pl.col("clstr").cast(pl.Int32), pl.col("aid").cast(pl.Int32), pl.col("rank").cast(pl.Int32).alias("clstr_freq_rank")])
        else:
            session_clstr = pl.read_parquet(cfg.prep_dir + f"w2v_session_cluster_c10000_{self.week}.parquet").select([pl.col("session").cast(pl.Int32), pl.col("clstr").cast(pl.Int32)])
            clstr_freq = pl.read_parquet(cfg.prep_dir + f"w2v_cluster_freq_c10000_{self.week}.parquet").select([pl.col("clstr").cast(pl.Int32), pl.col("aid").cast(pl.Int32), pl.col("rank").cast(pl.Int32).alias("clstr_freq_rank")])

        self.output = self.output.join(session_clstr, on="session", how="left").join(clstr_freq, on=["clstr", "aid"], how="left")
        self.output = self.output.select(pl.exclude("clstr"))

    @noglobal(excepts=["cfg", "logger"])
    def _latest_aid_w2v_sims(self, vec_n=50):
        logger.info("[features] latest_aid_w2v_sims : start")
        w2v_vecs = pd.read_parquet(cfg.prep_dir + f"w2v_vector_n{vec_n}.parquet")
        w2v_cols = [f"w2v_{i}" for i in range(vec_n)]
        w2v_dict = {aid:vecs for aid, vecs in zip(w2v_vecs["aid"].tolist(), w2v_vecs[w2v_cols].values)}

        for i in range(self.latest_aid_n):
            sims = []
            for aid, latest_aid in tqdm(zip(self.output.get_column("aid").to_list(), self.output.get_column(f"aid_latest{i}").to_list()), total=len(self.output)):
                if latest_aid == -1:
                    sims.append(-1)
                else:
                    aid_vecs = w2v_dict[aid]
                    latest_aid_vecs = w2v_dict[latest_aid]
                    sim = np.dot(aid_vecs, latest_aid_vecs) / (np.linalg.norm(aid_vecs)*np.linalg.norm(latest_aid_vecs))
                    sims.append(sim)
            self.output = self.output.with_column(pl.Series(sims, dtype=pl.Float32).alias(f"w2v_sim_lt{i}"))

# %%
@noglobal(excepts=["cfg", "logger"])
def add_features(sessions, cand_df, week=None):
    feat = Features(sessions, cand_df, week)
    feat.add_features()
    return feat.output

# %%
@noglobal(excepts=["cfg", "logger"])
def make_cand_df(sessions, week, trans_maps=None):
    cand = Candidate(sessions, week)
    cand.add(strategy="repurchase", name="repurchase")
    cand.add(strategy="clstr_freq", name="clstr_freq", k=30)
    #cand.add(strategy="session_frequent", name="session_frequent", k=15)
    #cand.add(strategy="session_latest", name="session_latest", k=30)
    
    for i in range(20):
        cand.add(strategy="session_latest", trans_map=trans_maps[f"time_wt_pair{str(i)}"], name=f"session_latest_time_wt_pair{str(i)}", k=15)
        cand.add(strategy="session_latest", trans_map=trans_maps[f"word2vec_pair{str(i)}"], name=f"session_latest_word2vec_pair{str(i)}", k=15)
        cand.add(strategy="session_latest", trans_map=trans_maps[f"pair{str(i)}"], name=f"session_latest_pair{str(i)}", k=15)
        cand.add(strategy="session_latest", trans_map=trans_maps[f"type_wt_pair{str(i)}"], name=f"session_latest_type_wt_pair{str(i)}", k=15)
        cand.add(strategy="session_latest", trans_map=trans_maps[f"clicks2carts_pair{str(i)}"], name=f"session_latest_clicks2carts_pair{str(i)}", k=15)
        cand.add(strategy="session_latest", trans_map=trans_maps[f"clicks2orders_pair{str(i)}"], name=f"session_latest_clicks2orders_pair{str(i)}", k=15)

    return cand.get_dataframe()

# %%
@noglobal(excepts=["cfg", "logger"])
def get_pair_df(name, wt_col, week):
    if week is not None:
        name = f"{name}_{week}"
    return pl.read_parquet(cfg.prep_dir + f"{name}.parquet").sort(wt_col, reverse=True)

@noglobal(excepts=["cfg", "logger"])
def get_trans_maps(week=None):
    """
    aidを別のaidに置き換えるmapping辞書を取得する
    """
    trans_maps = {}

    pair_df_org = get_pair_df("co_visitation_matrix", "cnt", week)
    for i in range(20):
        pair_df = pair_df_org.groupby("aid_x").head(i+1)
        pair_dict = {k: v for k, v in zip(pair_df.get_column("aid_x").to_list(), pair_df.get_column("aid_y").to_list())}
        trans_maps[f"pair{str(i)}"] = pair_dict
    
    pair_df_org = get_pair_df("co_visitation_matrix_time_weighted", "wt", week)
    for i in range(20):
        pair_df = pair_df_org.groupby("aid_x").head(i+1)
        pair_dict = {k: v for k, v in zip(pair_df.get_column("aid_x").to_list(), pair_df.get_column("aid_y").to_list())}
        trans_maps[f"time_wt_pair{str(i)}"] = pair_dict

    pair_df_org = get_pair_df("co_visitation_matrix_type_weighted", "wt", week)
    for i in range(20):
        pair_df = pair_df_org.groupby("aid_x").head(i+1)
        pair_dict = {k: v for k, v in zip(pair_df.get_column("aid_x").to_list(), pair_df.get_column("aid_y").to_list())}
        trans_maps[f"type_wt_pair{str(i)}"] = pair_dict

    pair_df_org = get_pair_df("co_visitation_matrix_clicks2carts", "cnt", week)
    for i in range(20):
        pair_df = pair_df_org.groupby("aid_x").head(i+1)
        pair_dict = {k: v for k, v in zip(pair_df.get_column("aid_x").to_list(), pair_df.get_column("aid_y").to_list())}
        trans_maps[f"clicks2carts_pair{str(i)}"] = pair_dict

    pair_df_org = get_pair_df("co_visitation_matrix_clicks2orders", "cnt", week)
    for i in range(20):
        pair_df = pair_df_org.groupby("aid_x").head(i+1)
        pair_dict = {k: v for k, v in zip(pair_df.get_column("aid_x").to_list(), pair_df.get_column("aid_y").to_list())}
        trans_maps[f"clicks2orders_pair{str(i)}"] = pair_dict

    pair_df_org = get_pair_df("word2vec_similar", "sim", None)
    for i in range(20):
        pair_df = pair_df = pair_df_org.groupby("aid_x").head(i+1)
        pair_dict = {k: v for k, v in zip(pair_df.get_column("aid_x").to_list(), pair_df.get_column("aid_y").to_list())}
        trans_maps[f"word2vec_pair{str(i)}"] = pair_dict

    return trans_maps

# %%
@noglobal(excepts=["cfg", "logger", "cache"])
def make_train_data(type_):
    train_chunk_n = cfg.train_chunk_n_dict[type_]
    
    # データ読み込み
    week_sessions = pl.read_parquet(cfg.prep_dir + f"train_sessions_{cfg.train_week}.parquet")
    week_sessions = week_sessions.select([
        pl.col("session").cast(pl.Int32),
        pl.col("aid").cast(pl.Int32),
        pl.col("ts"),
        pl.col("type")
        ])
    
    week_labels = pl.read_parquet(cfg.prep_dir + f"labels_{cfg.train_week}.parquet")
    week_labels = (week_labels.select([
        pl.col("session").cast(pl.Int32),
        pl.col("clicks_labels").cast(pl.Int32),
        pl.col("carts_labels"),
        pl.col("orders_labels")])
        .filter(pl.col(f"{type_}_labels").is_not_null())
    )
    sessions_lists = np.array_split(week_labels.get_column("session").unique().to_list(), train_chunk_n)

    # cand作成
    cand_dfs = []
    cache_file = f"{type_}_train_cand.parquet"
    cache_path = cache.get_abspath(cache_file)
    if cache.exists(cache_path):
        logger.info(f"[{cache_file}] cache exists. read cache and skip process.")
        cand_df = pl.read_parquet(cache_path)
    else:
        train_chunk_n = cfg.train_chunk_n_dict[type_]
        trans_map_cache_file = f"trans_maps_{cfg.train_week}.pkl"
        trans_map_cache_path = cache.get_abspath(trans_map_cache_file)
        with open(trans_map_cache_path, "rb") as f:
            trans_maps = pickle.load(f)
        
        for chunk in range(train_chunk_n):
            use_sessions = list(sessions_lists[chunk])    
            # 候補選出
            week_sessions_chunk = week_sessions.filter(pl.col("session").is_in(use_sessions))
            cand_df_chunk = make_cand_df(week_sessions_chunk, cfg.train_week, trans_maps=trans_maps)

            # candラベル付け・サンプリング
            week_labels_chunk = week_labels.filter(pl.col("session").is_in(use_sessions))
            cand_df_chunk = add_labels(cand_df_chunk, week_labels_chunk, type_)
            cand_df_chunk = under_sampling(cand_df_chunk, "labels")
            cand_dfs.append(cand_df_chunk)
            del cand_df_chunk, week_labels_chunk, week_sessions_chunk
            gc.collect()
        cand_df = pl.concat(cand_dfs)
        del cand_dfs
        gc.collect()
        cand_df.write_parquet(cache_path)

    # データ確認
    pos_cnt = cand_df.filter(pl.col("labels")==1).shape[0]
    neg_cnt = cand_df.filter(pl.col("labels")==0).shape[0]
    logger.info(f"train({type_}) pos : {str(pos_cnt)}  neg : {str(neg_cnt)}")

    # 特徴量付与
    train = add_features(week_sessions, cand_df, cfg.train_week)
    del cand_df, week_sessions
    gc.collect()

    return train

# %%
@noglobal(excepts=["cfg", "logger", "cache"])
def make_valid_cand():
    # データ読み込み
    week_sessions = pl.read_parquet(cfg.prep_dir + f"train_sessions_{cfg.valid_week}.parquet")
    week_sessions = week_sessions.select([
        pl.col("session").cast(pl.Int32),
        pl.col("aid").cast(pl.Int32),
        pl.col("ts"),
        pl.col("type")
        ])
    
    week_labels = pl.read_parquet(cfg.prep_dir + f"labels_{cfg.valid_week}.parquet")
    week_labels = week_labels.select([
        pl.col("session").cast(pl.Int32),
        pl.col("clicks_labels").cast(pl.Int32),
        pl.col("carts_labels"),
        pl.col("orders_labels")
        ])
    valid_sessions = week_sessions.get_column("session").unique().to_list()
    
    trans_map_cache_file = f"trans_maps_{cfg.valid_week}.pkl"
    trans_map_cache_path = cache.get_abspath(trans_map_cache_file)
    with open(trans_map_cache_path, "rb") as f:
        trans_maps = pickle.load(f)

    # validに使うsessionを絞る
    use_session_n = min(cfg.valid_session_n, len(valid_sessions))
    random.seed(cfg.seed)
    use_sessions = random.sample(valid_sessions, use_session_n)
    week_sessions = week_sessions.filter(pl.col("session").is_in(use_sessions))
    week_labels = week_labels.filter(pl.col("session").is_in(use_sessions))

    # 候補選出
    cand_df = make_cand_df(week_sessions, cfg.valid_week, trans_maps=trans_maps)
    return cand_df, week_sessions, week_labels

# %%
@noglobal(excepts=["cfg", "logger"])
def make_valid_data(cand_df, week_sessions, week_labels, type_):
    # 特徴量付与
    valid = add_features(week_sessions, cand_df, cfg.valid_week)
    valid = add_labels(valid, week_labels, type_)

    # データ確認
    pos_cnt = valid.filter(pl.col("labels")==1).shape[0]
    neg_cnt = valid.filter(pl.col("labels")==0).shape[0]
    logger.info(f"valid({type_}) pos : {str(pos_cnt)}  neg : {str(neg_cnt)}")
    
    return valid

# %%
@noglobal(excepts=["cfg", "logger"])
def model_training(train, valid, features, target, valid_labels, type_):
    if type_ == "clicks":
        params = cfg.clicks_params
    elif type_ == "carts":
        params = cfg.carts_params
    elif type_ == "orders":
        params = cfg.orders_params

    train = train.to_pandas()
    valid = valid.to_pandas()
    valid_labels = valid_labels.to_pandas()

    # 学習
    vl_pred_df = valid[["session", "aid"]].copy()

    tr_x, tr_y = train[features], train[target]
    vl_x, vl_y = valid[features], valid[target]
    tr_data = lgb.Dataset(tr_x, label=tr_y)
    vl_data = lgb.Dataset(vl_x, label=vl_y)

    if os.path.exists(cfg.output_dir + f"{cfg.exp_name}/{type_}_model.lgb"):
        logger.info(f"[{type_}_model.lgb] cache exists. read cache and skip process.")
        model = lgb.Booster(model_file = cfg.output_dir + f"{cfg.exp_name}/{type_}_model.lgb")
    else:
        model = lgb.train(params, tr_data, valid_sets=[tr_data, vl_data],
                        num_boost_round=2000000, early_stopping_rounds=100, verbose_eval=100)

    # 特徴量重要度
    fi = pd.DataFrame()
    fi["feature"] = model.feature_name()
    fi["importance"] = model.feature_importance(importance_type="gain")

    # 2値分類の出力を元にk個選定
    vl_pred_df["prob"] = model.predict(vl_x, num_iteration=model.best_iteration)
    vl_pred_df = vl_pred_df.sort_values(["session", "prob"], ascending=(True, False))
    vl_pred_df = vl_pred_df.groupby(["session"]).head(cfg.k)
    vl_pred_df = vl_pred_df.groupby(["session"])["aid"].apply(list).reset_index()
    
    # 評価
    assert valid_labels["session"].tolist() == vl_pred_df["session"].unique().tolist()
    score = evaluate(valid_labels["clicks_labels"].tolist(),
                     valid_labels["carts_labels"].tolist(),
                     valid_labels["orders_labels"].tolist(),
                     vl_pred_df["aid"].tolist(),
                     vl_pred_df["aid"].tolist(),
                     vl_pred_df["aid"].tolist(),
                     cfg.k)
    logger.info(f"{type_} valid score")
    logger.info(score)

    # モデル保存
    model.save_model(cfg.output_dir + f"{cfg.exp_name}/{type_}_model.lgb")

    # 特徴量重要度
    fi_n = fi['feature'].nunique()
    order = list(fi.groupby("feature").mean().sort_values("importance", ascending=False).index)
    plt.figure(figsize=(10, fi_n*0.2))
    sns.barplot(x="importance", y="feature", data=fi, order=order)
    plt.title(f"LGBM importance({type_})")
    plt.tight_layout()
    plt.savefig(cfg.output_dir + f'{cfg.exp_name}/lgbm_importance_{type_}.png')
    return score[f"recall_{type_}"]

# %%
@noglobal(excepts=["cfg", "logger", "cache"])
def make_test_data():
    # testデータ作成
    test_sessions = pl.read_parquet(cfg.prep_dir + f"test_sessions.parquet")
    test_sessions = test_sessions.select(
        [
            pl.col("session").cast(pl.Int32),
            pl.col("aid").cast(pl.Int32),
            pl.col("ts"),
            pl.col("type")
        ]
    )
    sessions_lists = np.array_split(test_sessions.get_column("session").unique().to_list(), cfg.test_chunk_n)
    trans_map_cache_file = f"trans_maps.pkl"
    trans_map_cache_path = cache.get_abspath(trans_map_cache_file)
    with open(trans_map_cache_path, "rb") as f:
        trans_maps = pickle.load(f)

    for chunk in range(cfg.test_chunk_n):
        use_sessions = list(sessions_lists[chunk])
        cache_file = f"test_{chunk}.parquet"
        cache_path = cache.get_abspath(cache_file)
        if cache.exists(cache_path):
            logger.info(f"[{cache_file}] cache exists. read cache and skip process.")
        else:
            test_sessions_chunk = test_sessions.filter(pl.col("session").is_in(use_sessions))
            # 候補選出
            logger.info("[make_test] make_cand_df")
            cand_df = make_cand_df(test_sessions_chunk, None, trans_maps=trans_maps)
            # 特徴量付与
            logger.info("[make_test] add_features")
            test = add_features(test_sessions, cand_df)
            test.write_parquet(cache_path)

# %%
@noglobal(excepts=["cfg", "logger", "cache"])
def inference(features):
    pred_dfs = []
    for chunk in range(cfg.test_chunk_n):
        cache_file = f"test_{chunk}.parquet"
        cache_path = cache.get_abspath(cache_file)
        test = pl.read_parquet(cache_path).to_pandas()

        for type_ in ["clicks", "carts", "orders"]:    
            pred_df_tmp = test[["session", "aid"]].copy()
            # 推論
            model = lgb.Booster(model_file = cfg.output_dir + f"{cfg.exp_name}/{type_}_model.lgb")
            # 2値分類の出力を元にk個選定
            pred_df_tmp["prob"] = model.predict(test[features], num_iteration=model.best_iteration)
            pred_df_tmp = pred_df_tmp.sort_values(["session", "prob"], ascending=(True, False))
            pred_df_tmp = pred_df_tmp.groupby(["session"]).head(30)
            pred_df_tmp["aid"] = pred_df_tmp["aid"].astype(str)
            pred_df_tmp = pred_df_tmp.groupby(["session"])["aid"].apply(list).reset_index()
            pred_df_tmp["aid"] = pred_df_tmp["aid"].apply(lambda x: ' '.join(x))
            pred_df_tmp["type"] = type_
            pred_dfs.append(pred_df_tmp)
        del test, model
        gc.collect()
    
    pred_df = pd.concat(pred_dfs)
    # sub作成
    sub = pd.read_csv(cfg.input_dir + f"sample_submission.csv", usecols=["session_type"])
    pred_df["session_type"] = pred_df["session"].astype(str) + "_" + pred_df["type"]
    pred_df = pred_df.rename(columns={"aid": "labels"})
    sub = sub.merge(pred_df[["session_type", "labels"]], on="session_type", how="left")
    sub.to_csv(cfg.output_dir + f"{cfg.exp_name}/t88_{cfg.exp_name}_sub_k30.csv", index=False)

# %%
@noglobal(excepts=["cfg", "logger", "cache"])
def main():
    scores = {}
    logger.info(f"START")
    line_notify.send(f"{cfg.exp_name} | START")
    
    # trans_map作成
    weeks = [None, cfg.train_week, cfg.valid_week]
    for week in weeks:
        if week is None:
            cache_file = "trans_maps.pkl"
        else:    
            cache_file = f"trans_maps_{week}.pkl"
        cache_path = cache.get_abspath(cache_file)
        if cache.exists(cache_path):
            logger.info(f"[{cache_file}] cache exists. skip process.")
        else:
            trans_maps = get_trans_maps(week)
            with open(cache_path, "wb") as f:
                pickle.dump(trans_maps, f)

    for type_ in ["clicks", "carts", "orders"]:
        # train data作成
        logger.info(f"make {type_}_train_data")
        cache_file = f"{type_}_train.parquet"
        cache_path = cache.get_abspath(cache_file)
        if cache.exists(cache_path):
            logger.info(f"[{cache_file}] cache exists. read cache and skip process.")
            train = pl.read_parquet(cache_path)
        else:
            train = make_train_data(type_)
            train.write_parquet(cache_path)

        logger.info(f"make {type_}_valid_data")
        # valid cand作成
        cand_cache_path = cache.get_abspath("valid_cand.parquet")
        sessions_cache_path = cache.get_abspath("valid_sessions.parquet")
        labels_cache_path = cache.get_abspath("valid_labels.parquet")
        if cache.exists(cand_cache_path) & cache.exists(labels_cache_path) & cache.exists(sessions_cache_path):
            logger.info("[valid_cand.parquet] cache exists. read cache and skip process.")
            valid_cand = pl.read_parquet(cand_cache_path)
            valid_sessions = pl.read_parquet(sessions_cache_path)
            valid_labels = pl.read_parquet(labels_cache_path)
        else:
            valid_cand, valid_sessions, valid_labels = make_valid_cand()
            valid_cand.write_parquet(cand_cache_path)
            valid_sessions.write_parquet(sessions_cache_path)
            valid_labels.write_parquet(labels_cache_path)

        # valid data作成
        logger.info(f"make {type_}_valid_data")
        cache_file = f"{type_}_valid.parquet"
        cache_path = cache.get_abspath(cache_file)
        if cache.exists(cache_path):
            logger.info(f"[{cache_file}] cache exists. read cache and skip process.")
            valid = pl.read_parquet(cache_path)
        else:
            valid = make_valid_data(valid_cand, valid_sessions, valid_labels, type_)
            valid.write_parquet(cache_path)

        # モデル学習
        target = "labels"
        not_use_cols = ["session", "aid", target]
        features = [c for c in train.columns if c not in not_use_cols]

        scores[f"recall_{type_}"] = model_training(train, valid, features, target, valid_labels, type_)

        del train, valid, valid_labels
        gc.collect()
    
    scores["total"] = (float(scores["recall_clicks"]) * 0.1) + (float(scores["recall_carts"]) * 0.3) + (float(scores["recall_orders"]) * 0.6)
    report = f"\n{cfg.exp_name}\n"
    report += f'valid_end\n'
    report += str(scores)
    line_notify.send(report)

    # testデータ
    if cfg.run_inf:
        make_test_data()

        logger.info(f"-------- inference --------")
        inference(features)

    line_notify.send(f"{cfg.exp_name} | END!!")

# %%
try:
    main()
except Exception as e:
    logger.error(traceback.format_exc())
    line_notify.send(f"{cfg.exp_name} | ERROR!!\n{traceback.format_exc()}")
# Out:
# 0:00:00.874168 	 START
# 0:00:01.187588 	 [trans_maps.pkl] cache exists. skip process.
# 0:00:01.190505 	 [trans_maps_week3.pkl] cache exists. skip process.
# 0:00:01.194161 	 [trans_maps_week4.pkl] cache exists. skip process.
# 0:00:01.195200 	 make clicks_train_data
# 0:00:01.197477 	 [clicks_train.parquet] cache exists. read cache and skip process.
# 0:00:05.106776 	 make clicks_valid_data
# 0:00:48.235785 	 [add_candidate] repurchase : start
# 0:00:48.691158 	 [add_candidate] clstr_freq : start
# 0:00:52.553409 	 [add_candidate] session_latest_time_wt_pair0 : start
# 0:00:53.055690 	 [add_candidate] session_latest_word2vec_pair0 : start
# 0:00:53.533691 	 [add_candidate] session_latest_pair0 : start
# 0:00:54.003408 	 [add_candidate] session_latest_type_wt_pair0 : start
# 0:00:54.474239 	 [add_candidate] session_latest_clicks2carts_pair0 : start
# 0:00:54.878521 	 [add_candidate] session_latest_clicks2orders_pair0 : start
# 0:00:55.240664 	 [add_candidate] session_latest_time_wt_pair1 : start
# 0:00:55.750157 	 [add_candidate] session_latest_word2vec_pair1 : start
# 0:00:56.258235 	 [add_candidate] session_latest_pair1 : start
# 0:00:56.775815 	 [add_candidate] session_latest_type_wt_pair1 : start
# 0:00:57.291776 	 [add_candidate] session_latest_clicks2carts_pair1 : start
# 0:00:57.745485 	 [add_candidate] session_latest_clicks2orders_pair1 : start
# 0:00:58.134115 	 [add_candidate] session_latest_time_wt_pair2 : start
# 0:00:58.676646 	 [add_candidate] session_latest_word2vec_pair2 : start
# 0:00:59.226256 	 [add_candidate] session_latest_pair2 : start
# 0:00:59.775508 	 [add_candidate] session_latest_type_wt_pair2 : start
# 0:01:00.330968 	 [add_candidate] session_latest_clicks2carts_pair2 : start
# 0:01:00.761597 	 [add_candidate] session_latest_clicks2orders_pair2 : start
# 0:01:01.142140 	 [add_candidate] session_latest_time_wt_pair3 : start
# 0:01:01.662648 	 [add_candidate] session_latest_word2vec_pair3 : start
# 0:01:02.193475 	 [add_candidate] session_latest_pair3 : start
# 0:01:02.693348 	 [add_candidate] session_latest_type_wt_pair3 : start
# 0:01:03.187402 	 [add_candidate] session_latest_clicks2carts_pair3 : start
# 0:01:03.606142 	 [add_candidate] session_latest_clicks2orders_pair3 : start
# 0:01:03.967709 	 [add_candidate] session_latest_time_wt_pair4 : start
# 0:01:04.488754 	 [add_candidate] session_latest_word2vec_pair4 : start
# 0:01:05.009667 	 [add_candidate] session_latest_pair4 : start
# 0:01:05.548588 	 [add_candidate] session_latest_type_wt_pair4 : start
# 0:01:06.077304 	 [add_candidate] session_latest_clicks2carts_pair4 : start
# 0:01:06.524999 	 [add_candidate] session_latest_clicks2orders_pair4 : start
# 0:01:06.900941 	 [add_candidate] session_latest_time_wt_pair5 : start
# 0:01:07.419896 	 [add_candidate] session_latest_word2vec_pair5 : start
# 0:01:07.936383 	 [add_candidate] session_latest_pair5 : start
# 0:01:08.452721 	 [add_candidate] session_latest_type_wt_pair5 : start
# 0:01:08.977115 	 [add_candidate] session_latest_clicks2carts_pair5 : start
# 0:01:09.417026 	 [add_candidate] session_latest_clicks2orders_pair5 : start
# 0:01:09.782933 	 [add_candidate] session_latest_time_wt_pair6 : start
# 0:01:10.305772 	 [add_candidate] session_latest_word2vec_pair6 : start
# 0:01:10.873570 	 [add_candidate] session_latest_pair6 : start
# 0:01:11.388323 	 [add_candidate] session_latest_type_wt_pair6 : start
# 0:01:11.885963 	 [add_candidate] session_latest_clicks2carts_pair6 : start
# 0:01:12.304751 	 [add_candidate] session_latest_clicks2orders_pair6 : start
# 0:01:12.667508 	 [add_candidate] session_latest_time_wt_pair7 : start
# 0:01:13.189488 	 [add_candidate] session_latest_word2vec_pair7 : start
# 0:01:13.720413 	 [add_candidate] session_latest_pair7 : start
# 0:01:14.253473 	 [add_candidate] session_latest_type_wt_pair7 : start
# 0:01:14.761729 	 [add_candidate] session_latest_clicks2carts_pair7 : start
# 0:01:15.197558 	 [add_candidate] session_latest_clicks2orders_pair7 : start
# 0:01:15.557087 	 [add_candidate] session_latest_time_wt_pair8 : start
# 0:01:16.115397 	 [add_candidate] session_latest_word2vec_pair8 : start
# 0:01:16.656047 	 [add_candidate] session_latest_pair8 : start
# 0:01:17.209589 	 [add_candidate] session_latest_type_wt_pair8 : start
# 0:01:17.721223 	 [add_candidate] session_latest_clicks2carts_pair8 : start
# 0:01:18.141485 	 [add_candidate] session_latest_clicks2orders_pair8 : start
# 0:01:18.507996 	 [add_candidate] session_latest_time_wt_pair9 : start
# 0:01:19.007047 	 [add_candidate] session_latest_word2vec_pair9 : start
# 0:01:19.555044 	 [add_candidate] session_latest_pair9 : start
# 0:01:20.113581 	 [add_candidate] session_latest_type_wt_pair9 : start
# 0:01:20.663631 	 [add_candidate] session_latest_clicks2carts_pair9 : start
# 0:01:21.044005 	 [add_candidate] session_latest_clicks2orders_pair9 : start
# 0:01:21.361311 	 [add_candidate] session_latest_time_wt_pair10 : start
# 0:01:21.815873 	 [add_candidate] session_latest_word2vec_pair10 : start
# 0:01:22.271867 	 [add_candidate] session_latest_pair10 : start
# 0:01:22.768710 	 [add_candidate] session_latest_type_wt_pair10 : start
# 0:01:23.280418 	 [add_candidate] session_latest_clicks2carts_pair10 : start
# 0:01:23.733460 	 [add_candidate] session_latest_clicks2orders_pair10 : start
# 0:01:24.094450 	 [add_candidate] session_latest_time_wt_pair11 : start
# 0:01:24.615789 	 [add_candidate] session_latest_word2vec_pair11 : start
# 0:01:25.118138 	 [add_candidate] session_latest_pair11 : start
# 0:01:25.640234 	 [add_candidate] session_latest_type_wt_pair11 : start
# 0:01:26.157953 	 [add_candidate] session_latest_clicks2carts_pair11 : start
# 0:01:26.597390 	 [add_candidate] session_latest_clicks2orders_pair11 : start
# 0:01:26.960399 	 [add_candidate] session_latest_time_wt_pair12 : start
# 0:01:27.472290 	 [add_candidate] session_latest_word2vec_pair12 : start
# 0:01:27.995788 	 [add_candidate] session_latest_pair12 : start
# 0:01:28.521224 	 [add_candidate] session_latest_type_wt_pair12 : start
# 0:01:29.043254 	 [add_candidate] session_latest_clicks2carts_pair12 : start
# 0:01:29.490700 	 [add_candidate] session_latest_clicks2orders_pair12 : start
# 0:01:29.863219 	 [add_candidate] session_latest_time_wt_pair13 : start
# 0:01:30.402103 	 [add_candidate] session_latest_word2vec_pair13 : start
# 0:01:30.943352 	 [add_candidate] session_latest_pair13 : start
# 0:01:31.466673 	 [add_candidate] session_latest_type_wt_pair13 : start
# 0:01:31.988373 	 [add_candidate] session_latest_clicks2carts_pair13 : start
# 0:01:32.423215 	 [add_candidate] session_latest_clicks2orders_pair13 : start
# 0:01:32.785918 	 [add_candidate] session_latest_time_wt_pair14 : start
# 0:01:33.309420 	 [add_candidate] session_latest_word2vec_pair14 : start
# 0:01:33.836405 	 [add_candidate] session_latest_pair14 : start
# 0:01:34.364136 	 [add_candidate] session_latest_type_wt_pair14 : start
# 0:01:34.877626 	 [add_candidate] session_latest_clicks2carts_pair14 : start
# 0:01:35.310461 	 [add_candidate] session_latest_clicks2orders_pair14 : start
# 0:01:35.693171 	 [add_candidate] session_latest_time_wt_pair15 : start
# 0:01:36.216135 	 [add_candidate] session_latest_word2vec_pair15 : start
# 0:01:36.720207 	 [add_candidate] session_latest_pair15 : start
# 0:01:37.230183 	 [add_candidate] session_latest_type_wt_pair15 : start
# 0:01:37.738096 	 [add_candidate] session_latest_clicks2carts_pair15 : start
# 0:01:38.186607 	 [add_candidate] session_latest_clicks2orders_pair15 : start
# 0:01:38.565454 	 [add_candidate] session_latest_time_wt_pair16 : start
# 0:01:39.073666 	 [add_candidate] session_latest_word2vec_pair16 : start
# 0:01:39.606961 	 [add_candidate] session_latest_pair16 : start
# 0:01:40.134113 	 [add_candidate] session_latest_type_wt_pair16 : start
# 0:01:40.683591 	 [add_candidate] session_latest_clicks2carts_pair16 : start
# 0:01:41.127761 	 [add_candidate] session_latest_clicks2orders_pair16 : start
# 0:01:41.508047 	 [add_candidate] session_latest_time_wt_pair17 : start
# 0:01:42.039273 	 [add_candidate] session_latest_word2vec_pair17 : start
# 0:01:42.577038 	 [add_candidate] session_latest_pair17 : start
# 0:01:43.094099 	 [add_candidate] session_latest_type_wt_pair17 : start
# 0:01:43.637533 	 [add_candidate] session_latest_clicks2carts_pair17 : start
# 0:01:44.068645 	 [add_candidate] session_latest_clicks2orders_pair17 : start
# 0:01:44.439162 	 [add_candidate] session_latest_time_wt_pair18 : start
# 0:01:44.942351 	 [add_candidate] session_latest_word2vec_pair18 : start
# 0:01:45.451420 	 [add_candidate] session_latest_pair18 : start
# 0:01:45.952654 	 [add_candidate] session_latest_type_wt_pair18 : start
# 0:01:46.466123 	 [add_candidate] session_latest_clicks2carts_pair18 : start
# 0:01:46.903808 	 [add_candidate] session_latest_clicks2orders_pair18 : start
# 0:01:47.275949 	 [add_candidate] session_latest_time_wt_pair19 : start
# 0:01:47.795392 	 [add_candidate] session_latest_word2vec_pair19 : start
# 0:01:48.312681 	 [add_candidate] session_latest_pair19 : start
# 0:01:48.829955 	 [add_candidate] session_latest_type_wt_pair19 : start
# 0:01:49.352984 	 [add_candidate] session_latest_clicks2carts_pair19 : start
# 0:01:49.790279 	 [add_candidate] session_latest_clicks2orders_pair19 : start
# 0:01:59.309799 	 make clicks_valid_data
# 0:01:59.312885 	 [clicks_valid.parquet] cache exists. read cache and skip process.
# 0:02:17.133896 	 [clicks_model.lgb] cache exists. read cache and skip process.
# 0:03:44.170222 	 clicks valid score
# 0:03:44.171426 	 {'num_clicks': 97136, 'hit_clicks': 49397, 'num_carts': 43211, 'hit_carts': 14795, 'num_orders': 20082, 'hit_orders': 11085, 'recall_clicks': '0.508534', 'recall_carts': '0.342390', 'recall_orders': '0.551987', 'w_recall_clicks': '0.050853', 'w_recall_carts': '0.102717', 'w_recall_orders': '0.331192', 'score': '0.484762'}
# 0:03:45.513822 	 make carts_train_data
# 0:04:19.990161 	 [add_candidate] repurchase : start
# 0:04:23.562781 	 [add_candidate] clstr_freq : start
# 0:04:45.581605 	 [add_candidate] session_latest_time_wt_pair0 : start
# 0:04:48.426663 	 [add_candidate] session_latest_word2vec_pair0 : start
# 0:04:51.356847 	 [add_candidate] session_latest_pair0 : start
# 0:04:54.130556 	 [add_candidate] session_latest_type_wt_pair0 : start
# 0:04:56.979583 	 [add_candidate] session_latest_clicks2carts_pair0 : start
# 0:04:59.722323 	 [add_candidate] session_latest_clicks2orders_pair0 : start
# 0:05:02.184070 	 [add_candidate] session_latest_time_wt_pair1 : start
# 0:05:05.006160 	 [add_candidate] session_latest_word2vec_pair1 : start
# 0:05:07.984034 	 [add_candidate] session_latest_pair1 : start
# 0:05:10.876369 	 [add_candidate] session_latest_type_wt_pair1 : start
# 0:05:13.797496 	 [add_candidate] session_latest_clicks2carts_pair1 : start
# 0:05:16.598631 	 [add_candidate] session_latest_clicks2orders_pair1 : start
# 0:05:19.094312 	 [add_candidate] session_latest_time_wt_pair2 : start
# 0:05:22.017982 	 [add_candidate] session_latest_word2vec_pair2 : start
# 0:05:24.940745 	 [add_candidate] session_latest_pair2 : start
# 0:05:27.889337 	 [add_candidate] session_latest_type_wt_pair2 : start
# 0:05:30.891743 	 [add_candidate] session_latest_clicks2carts_pair2 : start
# 0:05:33.696648 	 [add_candidate] session_latest_clicks2orders_pair2 : start
# 0:05:36.263122 	 [add_candidate] session_latest_time_wt_pair3 : start
# 0:05:39.188772 	 [add_candidate] session_latest_word2vec_pair3 : start
# 0:05:42.000718 	 [add_candidate] session_latest_pair3 : start
# 0:05:44.897848 	 [add_candidate] session_latest_type_wt_pair3 : start
# 0:05:47.890166 	 [add_candidate] session_latest_clicks2carts_pair3 : start
# 0:05:50.695877 	 [add_candidate] session_latest_clicks2orders_pair3 : start
# 0:05:53.458311 	 [add_candidate] session_latest_time_wt_pair4 : start
# 0:05:56.470254 	 [add_candidate] session_latest_word2vec_pair4 : start
# 0:05:59.533651 	 [add_candidate] session_latest_pair4 : start
# 0:06:02.437701 	 [add_candidate] session_latest_type_wt_pair4 : start
# 0:06:05.440662 	 [add_candidate] session_latest_clicks2carts_pair4 : start
# 0:06:08.231685 	 [add_candidate] session_latest_clicks2orders_pair4 : start
# 0:06:10.862979 	 [add_candidate] session_latest_time_wt_pair5 : start
# 0:06:13.857969 	 [add_candidate] session_latest_word2vec_pair5 : start
# 0:06:16.952291 	 [add_candidate] session_latest_pair5 : start
# 0:06:19.950678 	 [add_candidate] session_latest_type_wt_pair5 : start
# 0:06:22.916348 	 [add_candidate] session_latest_clicks2carts_pair5 : start
# 0:06:25.743960 	 [add_candidate] session_latest_clicks2orders_pair5 : start
# 0:06:28.921851 	 [add_candidate] session_latest_time_wt_pair6 : start
# 0:06:31.937093 	 [add_candidate] session_latest_word2vec_pair6 : start
# 0:06:34.925592 	 [add_candidate] session_latest_pair6 : start
# 0:06:38.046575 	 [add_candidate] session_latest_type_wt_pair6 : start
# 0:06:41.045625 	 [add_candidate] session_latest_clicks2carts_pair6 : start
# 0:06:43.888160 	 [add_candidate] session_latest_clicks2orders_pair6 : start
# 0:06:46.346404 	 [add_candidate] session_latest_time_wt_pair7 : start
# 0:06:49.352230 	 [add_candidate] session_latest_word2vec_pair7 : start
# 0:06:52.290337 	 [add_candidate] session_latest_pair7 : start
# 0:06:55.323995 	 [add_candidate] session_latest_type_wt_pair7 : start
# 0:06:58.352255 	 [add_candidate] session_latest_clicks2carts_pair7 : start
# 0:07:01.157371 	 [add_candidate] session_latest_clicks2orders_pair7 : start
# 0:07:03.665948 	 [add_candidate] session_latest_time_wt_pair8 : start
# 0:07:06.640609 	 [add_candidate] session_latest_word2vec_pair8 : start
# 0:07:09.662037 	 [add_candidate] session_latest_pair8 : start
# 0:07:12.727815 	 [add_candidate] session_latest_type_wt_pair8 : start
# 0:07:15.816852 	 [add_candidate] session_latest_clicks2carts_pair8 : start
# 0:07:18.664694 	 [add_candidate] session_latest_clicks2orders_pair8 : start
# 0:07:21.252111 	 [add_candidate] session_latest_time_wt_pair9 : start
# 0:07:24.281534 	 [add_candidate] session_latest_word2vec_pair9 : start
# 0:07:27.352083 	 [add_candidate] session_latest_pair9 : start
# 0:07:30.484604 	 [add_candidate] session_latest_type_wt_pair9 : start
# 0:07:33.487055 	 [add_candidate] session_latest_clicks2carts_pair9 : start
# 0:07:36.335357 	 [add_candidate] session_latest_clicks2orders_pair9 : start
# 0:07:38.856571 	 [add_candidate] session_latest_time_wt_pair10 : start
# 0:07:41.689068 	 [add_candidate] session_latest_word2vec_pair10 : start
# 0:07:44.656445 	 [add_candidate] session_latest_pair10 : start
# 0:07:47.626436 	 [add_candidate] session_latest_type_wt_pair10 : start
# 0:07:50.602450 	 [add_candidate] session_latest_clicks2carts_pair10 : start
# 0:07:53.511811 	 [add_candidate] session_latest_clicks2orders_pair10 : start
# 0:07:56.108702 	 [add_candidate] session_latest_time_wt_pair11 : start
# 0:07:59.098041 	 [add_candidate] session_latest_word2vec_pair11 : start
# 0:08:02.165609 	 [add_candidate] session_latest_pair11 : start
# 0:08:05.179780 	 [add_candidate] session_latest_type_wt_pair11 : start
# 0:08:08.235749 	 [add_candidate] session_latest_clicks2carts_pair11 : start
# 0:08:11.082082 	 [add_candidate] session_latest_clicks2orders_pair11 : start
# 0:08:13.635857 	 [add_candidate] session_latest_time_wt_pair12 : start
# 0:08:16.585302 	 [add_candidate] session_latest_word2vec_pair12 : start
# 0:08:19.677474 	 [add_candidate] session_latest_pair12 : start
# 0:08:22.695565 	 [add_candidate] session_latest_type_wt_pair12 : start
# 0:08:25.704714 	 [add_candidate] session_latest_clicks2carts_pair12 : start
# 0:08:28.587069 	 [add_candidate] session_latest_clicks2orders_pair12 : start
# 0:08:31.164620 	 [add_candidate] session_latest_time_wt_pair13 : start
# 0:08:34.226908 	 [add_candidate] session_latest_word2vec_pair13 : start
# 0:08:37.234908 	 [add_candidate] session_latest_pair13 : start
# 0:08:40.327015 	 [add_candidate] session_latest_type_wt_pair13 : start
# 0:08:43.341174 	 [add_candidate] session_latest_clicks2carts_pair13 : start
# 0:08:46.192263 	 [add_candidate] session_latest_clicks2orders_pair13 : start
# 0:08:48.816604 	 [add_candidate] session_latest_time_wt_pair14 : start
# 0:08:51.858651 	 [add_candidate] session_latest_word2vec_pair14 : start
# 0:08:55.016958 	 [add_candidate] session_latest_pair14 : start
# 0:08:58.055486 	 [add_candidate] session_latest_type_wt_pair14 : start
# 0:09:01.086664 	 [add_candidate] session_latest_clicks2carts_pair14 : start
# 0:09:03.909448 	 [add_candidate] session_latest_clicks2orders_pair14 : start
# 0:09:06.481778 	 [add_candidate] session_latest_time_wt_pair15 : start
# 0:09:09.483541 	 [add_candidate] session_latest_word2vec_pair15 : start
# 0:09:12.442405 	 [add_candidate] session_latest_pair15 : start
# 0:09:15.436727 	 [add_candidate] session_latest_type_wt_pair15 : start
# 0:09:18.536266 	 [add_candidate] session_latest_clicks2carts_pair15 : start
# 0:09:21.397568 	 [add_candidate] session_latest_clicks2orders_pair15 : start
# 0:09:23.978074 	 [add_candidate] session_latest_time_wt_pair16 : start
# 0:09:27.011688 	 [add_candidate] session_latest_word2vec_pair16 : start
# 0:09:30.079341 	 [add_candidate] session_latest_pair16 : start
# 0:09:33.120138 	 [add_candidate] session_latest_type_wt_pair16 : start
# 0:09:36.157290 	 [add_candidate] session_latest_clicks2carts_pair16 : start
# 0:09:39.136114 	 [add_candidate] session_latest_clicks2orders_pair16 : start
# 0:09:41.652046 	 [add_candidate] session_latest_time_wt_pair17 : start
# 0:09:44.681280 	 [add_candidate] session_latest_word2vec_pair17 : start
# 0:09:47.754236 	 [add_candidate] session_latest_pair17 : start
# 0:09:50.738684 	 [add_candidate] session_latest_type_wt_pair17 : start
# 0:09:53.726619 	 [add_candidate] session_latest_clicks2carts_pair17 : start
# 0:09:56.566140 	 [add_candidate] session_latest_clicks2orders_pair17 : start
# 0:09:59.128842 	 [add_candidate] session_latest_time_wt_pair18 : start
# 0:10:02.058102 	 [add_candidate] session_latest_word2vec_pair18 : start
# 0:10:05.069034 	 [add_candidate] session_latest_pair18 : start
# 0:10:08.042174 	 [add_candidate] session_latest_type_wt_pair18 : start
# 0:10:11.106486 	 [add_candidate] session_latest_clicks2carts_pair18 : start
# 0:10:13.905728 	 [add_candidate] session_latest_clicks2orders_pair18 : start
# 0:10:16.427362 	 [add_candidate] session_latest_time_wt_pair19 : start
# 0:10:19.322927 	 [add_candidate] session_latest_word2vec_pair19 : start
# 0:10:22.379402 	 [add_candidate] session_latest_pair19 : start
# 0:10:25.427109 	 [add_candidate] session_latest_type_wt_pair19 : start
# 0:10:28.507262 	 [add_candidate] session_latest_clicks2carts_pair19 : start
# 0:10:31.310303 	 [add_candidate] session_latest_clicks2orders_pair19 : start
# 0:13:05.608753 	 train(carts) pos : 916690  neg : 916690
# 0:13:07.147501 	 [features] session_cnt : start
# 0:13:08.356577 	 [features] session_aid_nunique : start
# 0:13:08.697086 	 [features] session_last_type : start
# 0:13:09.204286 	 [features] aid_cnt : start
# 0:13:10.918299 	 [features] aid_clicks_cnt : start
# 0:13:12.403780 	 [features] aid_carts_cnt : start
# 0:13:12.601840 	 [features] aid_orders_cnt : start
# 0:13:12.720552 	 [features] all_times_aid_freq : start
# 0:13:13.256722 	 [features] all_times_aid_clicks_freq : start
# 0:13:13.820157 	 [features] all_times_aid_carts_freq : start
# 0:13:14.151770 	 [features] all_times_aid_orders_freq : start
# 0:13:14.344953 	 [features] all_times_aid_session_freq : start
# 0:13:14.874860 	 [features] all_times_aid_session_clicks_freq : start
# 0:13:15.420390 	 [features] all_times_aid_session_carts_freq : start
# 0:13:15.747047 	 [features] all_times_aid_session_orders_freq : start
# 0:13:15.938901 	 [features] all_times_aid_carts_ratio_with_clicks : start
# 0:13:16.564018 	 [features] all_times_aid_orders_ratio_with_clicks : start
# 0:13:17.210781 	 [features] all_times_aid_date_std : start
# 0:13:17.888036 	 [features] all_times_aid_hour_std : start
# 0:13:18.550378 	 [features] all_times_aid_day_of_week_std : start
# 0:13:19.252199 	 [features] w2v_vectors : start
# 0:13:19.968050 	 [features] relative_ts : start
# 0:13:25.184361 	 [features] co_visit_rank(co_visitation_matrix) : start
# 0:13:47.063436 	 [features] co_visit_rank(co_visitation_matrix_lt0) : start
# 0:14:09.776549 	 [features] co_visit_rank(co_visitation_matrix_lt1) : start
# 0:14:32.238235 	 [features] co_visit_rank(co_visitation_matrix_lt2) : start
# 0:14:57.902714 	 [features] co_visit_rank(co_visitation_matrix_lt3) : start
# 0:15:20.880493 	 [features] co_visit_rank(co_visitation_matrix_lt4) : start
# 0:15:43.656984 	 [features] co_visit_rank(co_visitation_matrix_lt5) : start
# 0:16:07.610571 	 [features] co_visit_rank(co_visitation_matrix_lt6) : start
# 0:16:30.537897 	 [features] co_visit_rank(co_visitation_matrix_lt7) : start
# 0:16:53.222455 	 [features] co_visit_rank(co_visitation_matrix_lt8) : start
# 0:17:16.006625 	 [features] co_visit_rank(co_visitation_matrix_lt9) : start
# 0:17:38.193403 	 [features] co_visit_rank(co_visitation_matrix_time_weighted) : start
# 0:18:29.860882 	 [features] co_visit_rank(co_visitation_matrix_time_weighted_lt0) : start
# 0:19:21.014357 	 [features] co_visit_rank(co_visitation_matrix_time_weighted_lt1) : start
# 0:20:10.063947 	 [features] co_visit_rank(co_visitation_matrix_time_weighted_lt2) : start
# 0:20:58.118343 	 [features] co_visit_rank(co_visitation_matrix_time_weighted_lt3) : start
# 0:21:47.420914 	 [features] co_visit_rank(co_visitation_matrix_time_weighted_lt4) : start
# 0:22:37.505620 	 [features] co_visit_rank(co_visitation_matrix_time_weighted_lt5) : start
# 0:23:26.517780 	 [features] co_visit_rank(co_visitation_matrix_time_weighted_lt6) : start
# 0:24:15.936242 	 [features] co_visit_rank(co_visitation_matrix_time_weighted_lt7) : start
# 0:25:03.907408 	 [features] co_visit_rank(co_visitation_matrix_time_weighted_lt8) : start
# 0:25:53.397336 	 [features] co_visit_rank(co_visitation_matrix_time_weighted_lt9) : start
# 0:26:41.345287 	 [features] co_visit_rank(co_visitation_matrix_type_weighted) : start
# 0:27:14.894256 	 [features] co_visit_rank(co_visitation_matrix_type_weighted_lt0) : start
# 0:28:08.414971 	 [features] co_visit_rank(co_visitation_matrix_type_weighted_lt1) : start
# 0:28:59.026704 	 [features] co_visit_rank(co_visitation_matrix_type_weighted_lt2) : start
# 0:29:50.853442 	 [features] co_visit_rank(co_visitation_matrix_type_weighted_lt3) : start
# 0:30:42.444690 	 [features] co_visit_rank(co_visitation_matrix_type_weighted_lt4) : start
# 0:31:34.198183 	 [features] co_visit_rank(co_visitation_matrix_type_weighted_lt5) : start
# 0:32:26.009413 	 [features] co_visit_rank(co_visitation_matrix_type_weighted_lt6) : start
# 0:33:16.729723 	 [features] co_visit_rank(co_visitation_matrix_type_weighted_lt7) : start
# 0:34:07.946512 	 [features] co_visit_rank(co_visitation_matrix_type_weighted_lt8) : start
# 0:34:58.038227 	 [features] co_visit_rank(co_visitation_matrix_type_weighted_lt9) : start
# 0:35:49.885056 	 [features] co_visit_rank(co_visitation_matrix_clicks2carts) : start
# 0:35:53.363633 	 [features] co_visit_rank(co_visitation_matrix_clicks2carts_lt0) : start
# 0:35:54.779599 	 [features] co_visit_rank(co_visitation_matrix_clicks2carts_lt1) : start
# 0:35:56.179369 	 [features] co_visit_rank(co_visitation_matrix_clicks2carts_lt2) : start
# 0:35:57.567130 	 [features] co_visit_rank(co_visitation_matrix_clicks2carts_lt3) : start
# 0:35:58.952012 	 [features] co_visit_rank(co_visitation_matrix_clicks2carts_lt4) : start
# 0:36:00.256181 	 [features] co_visit_rank(co_visitation_matrix_clicks2carts_lt5) : start
# 0:36:01.551485 	 [features] co_visit_rank(co_visitation_matrix_clicks2carts_lt6) : start
# 0:36:02.848680 	 [features] co_visit_rank(co_visitation_matrix_clicks2carts_lt7) : start
# 0:36:04.185349 	 [features] co_visit_rank(co_visitation_matrix_clicks2carts_lt8) : start
# 0:36:05.507750 	 [features] co_visit_rank(co_visitation_matrix_clicks2carts_lt9) : start
# 0:36:07.037414 	 [features] co_visit_rank(co_visitation_matrix_clicks2orders) : start
# 0:36:08.093485 	 [features] co_visit_rank(co_visitation_matrix_clicks2orders_lt0) : start
# 0:36:08.427972 	 [features] co_visit_rank(co_visitation_matrix_clicks2orders_lt1) : start
# 0:36:08.728207 	 [features] co_visit_rank(co_visitation_matrix_clicks2orders_lt2) : start
# 0:36:09.037154 	 [features] co_visit_rank(co_visitation_matrix_clicks2orders_lt3) : start
# 0:36:09.339724 	 [features] co_visit_rank(co_visitation_matrix_clicks2orders_lt4) : start
# 0:36:09.640957 	 [features] co_visit_rank(co_visitation_matrix_clicks2orders_lt5) : start
# 0:36:09.927804 	 [features] co_visit_rank(co_visitation_matrix_clicks2orders_lt6) : start
# 0:36:10.226794 	 [features] co_visit_rank(co_visitation_matrix_clicks2orders_lt7) : start
# 0:36:10.541570 	 [features] co_visit_rank(co_visitation_matrix_clicks2orders_lt8) : start
# 0:36:10.831788 	 [features] co_visit_rank(co_visitation_matrix_clicks2orders_lt9) : start
# 0:36:11.155839 	 [features] latest_aid_w2v_sims : start
# 100%|██████████| 1833380/1833380 [00:17<00:00, 103581.84it/s]
# 100%|██████████| 1833380/1833380 [00:15<00:00, 118897.53it/s]
# 100%|██████████| 1833380/1833380 [00:14<00:00, 130658.37it/s]
# 100%|██████████| 1833380/1833380 [00:12<00:00, 141626.44it/s]
# 100%|██████████| 1833380/1833380 [00:12<00:00, 150275.14it/s]
# 100%|██████████| 1833380/1833380 [00:11<00:00, 161897.25it/s]
# 100%|██████████| 1833380/1833380 [00:10<00:00, 169660.75it/s]
# 100%|██████████| 1833380/1833380 [00:09<00:00, 183909.08it/s]
# 100%|██████████| 1833380/1833380 [00:09<00:00, 192754.76it/s]
# 100%|██████████| 1833380/1833380 [00:08<00:00, 206705.70it/s]
# 0:38:54.461128 	 make carts_valid_data
# 0:38:54.468306 	 [valid_cand.parquet] cache exists. read cache and skip process.
# 0:38:55.706322 	 make carts_valid_data
# 0:38:55.746909 	 [features] session_cnt : start
# 0:38:57.429171 	 [features] session_aid_nunique : start
# 0:38:57.820835 	 [features] session_last_type : start
# 0:38:58.093606 	 [features] aid_cnt : start
# 0:38:58.769135 	 [features] aid_clicks_cnt : start
# 0:38:59.379740 	 [features] aid_carts_cnt : start
# 0:38:59.850885 	 [features] aid_orders_cnt : start
# 0:39:00.319161 	 [features] all_times_aid_freq : start
# 0:39:01.330231 	 [features] all_times_aid_clicks_freq : start
# 0:39:02.300617 	 [features] all_times_aid_carts_freq : start
# 0:39:02.893245 	 [features] all_times_aid_orders_freq : start
# 0:39:03.300941 	 [features] all_times_aid_session_freq : start
# 0:39:04.122336 	 [features] all_times_aid_session_clicks_freq : start
# 0:39:04.957026 	 [features] all_times_aid_session_carts_freq : start
# 0:39:05.510265 	 [features] all_times_aid_session_orders_freq : start
# 0:39:05.923345 	 [features] all_times_aid_carts_ratio_with_clicks : start
# 0:39:06.838507 	 [features] all_times_aid_orders_ratio_with_clicks : start
# 0:39:07.795889 	 [features] all_times_aid_date_std : start
# 0:39:08.731652 	 [features] all_times_aid_hour_std : start
# 0:39:09.640024 	 [features] all_times_aid_day_of_week_std : start
# 0:39:10.590301 	 [features] w2v_vectors : start
# 0:39:11.229119 	 [features] relative_ts : start
# 0:39:16.206806 	 [features] co_visit_rank(co_visitation_matrix) : start
# 0:39:37.460431 	 [features] co_visit_rank(co_visitation_matrix_lt0) : start
# 0:40:01.481522 	 [features] co_visit_rank(co_visitation_matrix_lt1) : start
# 0:40:25.727676 	 [features] co_visit_rank(co_visitation_matrix_lt2) : start
# 0:40:49.660104 	 [features] co_visit_rank(co_visitation_matrix_lt3) : start
# 0:41:13.451341 	 [features] co_visit_rank(co_visitation_matrix_lt4) : start
# 0:41:37.202107 	 [features] co_visit_rank(co_visitation_matrix_lt5) : start
# 0:42:01.968581 	 [features] co_visit_rank(co_visitation_matrix_lt6) : start
# 0:42:25.515610 	 [features] co_visit_rank(co_visitation_matrix_lt7) : start
# 0:42:49.265114 	 [features] co_visit_rank(co_visitation_matrix_lt8) : start
# 0:43:14.076220 	 [features] co_visit_rank(co_visitation_matrix_lt9) : start
# 0:43:38.562135 	 [features] co_visit_rank(co_visitation_matrix_time_weighted) : start
# 0:44:29.111802 	 [features] co_visit_rank(co_visitation_matrix_time_weighted_lt0) : start
# 0:45:25.514461 	 [features] co_visit_rank(co_visitation_matrix_time_weighted_lt1) : start
# 0:46:15.453896 	 [features] co_visit_rank(co_visitation_matrix_time_weighted_lt2) : start
# 0:47:05.864673 	 [features] co_visit_rank(co_visitation_matrix_time_weighted_lt3) : start
# 0:48:00.731186 	 [features] co_visit_rank(co_visitation_matrix_time_weighted_lt4) : start
# 0:48:52.492781 	 [features] co_visit_rank(co_visitation_matrix_time_weighted_lt5) : start
# 0:49:47.256780 	 [features] co_visit_rank(co_visitation_matrix_time_weighted_lt6) : start
# 0:50:38.257991 	 [features] co_visit_rank(co_visitation_matrix_time_weighted_lt7) : start
# 0:51:37.117188 	 [features] co_visit_rank(co_visitation_matrix_time_weighted_lt8) : start
# 0:52:26.922813 	 [features] co_visit_rank(co_visitation_matrix_time_weighted_lt9) : start
# 0:53:20.438217 	 [features] co_visit_rank(co_visitation_matrix_type_weighted) : start
# 0:53:54.333803 	 [features] co_visit_rank(co_visitation_matrix_type_weighted_lt0) : start
# 0:54:47.984571 	 [features] co_visit_rank(co_visitation_matrix_type_weighted_lt1) : start
# 0:55:41.582553 	 [features] co_visit_rank(co_visitation_matrix_type_weighted_lt2) : start
# 0:56:39.050349 	 [features] co_visit_rank(co_visitation_matrix_type_weighted_lt3) : start
# 0:57:31.390345 	 [features] co_visit_rank(co_visitation_matrix_type_weighted_lt4) : start
# 0:58:24.754086 	 [features] co_visit_rank(co_visitation_matrix_type_weighted_lt5) : start
# 0:59:24.738137 	 [features] co_visit_rank(co_visitation_matrix_type_weighted_lt6) : start
# 1:00:16.757085 	 [features] co_visit_rank(co_visitation_matrix_type_weighted_lt7) : start
# 1:01:10.535008 	 [features] co_visit_rank(co_visitation_matrix_type_weighted_lt8) : start
# 1:02:03.008181 	 [features] co_visit_rank(co_visitation_matrix_type_weighted_lt9) : start
# 1:03:02.082669 	 [features] co_visit_rank(co_visitation_matrix_clicks2carts) : start
# 1:03:05.613082 	 [features] co_visit_rank(co_visitation_matrix_clicks2carts_lt0) : start
# 1:03:07.774151 	 [features] co_visit_rank(co_visitation_matrix_clicks2carts_lt1) : start
# 1:03:09.740281 	 [features] co_visit_rank(co_visitation_matrix_clicks2carts_lt2) : start
# 1:03:11.625113 	 [features] co_visit_rank(co_visitation_matrix_clicks2carts_lt3) : start
# 1:03:13.474667 	 [features] co_visit_rank(co_visitation_matrix_clicks2carts_lt4) : start
# 1:03:15.324491 	 [features] co_visit_rank(co_visitation_matrix_clicks2carts_lt5) : start
# 1:03:17.146657 	 [features] co_visit_rank(co_visitation_matrix_clicks2carts_lt6) : start
# 1:03:18.948867 	 [features] co_visit_rank(co_visitation_matrix_clicks2carts_lt7) : start
# 1:03:20.780695 	 [features] co_visit_rank(co_visitation_matrix_clicks2carts_lt8) : start
# 1:03:22.622119 	 [features] co_visit_rank(co_visitation_matrix_clicks2carts_lt9) : start
# 1:03:24.380736 	 [features] co_visit_rank(co_visitation_matrix_clicks2orders) : start
# 1:03:25.390575 	 [features] co_visit_rank(co_visitation_matrix_clicks2orders_lt0) : start
# 1:03:26.244391 	 [features] co_visit_rank(co_visitation_matrix_clicks2orders_lt1) : start
# 1:03:27.034797 	 [features] co_visit_rank(co_visitation_matrix_clicks2orders_lt2) : start
# 1:03:27.837397 	 [features] co_visit_rank(co_visitation_matrix_clicks2orders_lt3) : start
# 1:03:28.610235 	 [features] co_visit_rank(co_visitation_matrix_clicks2orders_lt4) : start
# 1:03:29.360572 	 [features] co_visit_rank(co_visitation_matrix_clicks2orders_lt5) : start
# 1:03:30.112769 	 [features] co_visit_rank(co_visitation_matrix_clicks2orders_lt6) : start
# 1:03:30.878095 	 [features] co_visit_rank(co_visitation_matrix_clicks2orders_lt7) : start
# 1:03:31.649117 	 [features] co_visit_rank(co_visitation_matrix_clicks2orders_lt8) : start
# 1:03:32.376784 	 [features] co_visit_rank(co_visitation_matrix_clicks2orders_lt9) : start
# 1:03:33.113076 	 [features] latest_aid_w2v_sims : start
# 100%|██████████| 17915065/17915065 [02:43<00:00, 109758.59it/s]
# 100%|██████████| 17915065/17915065 [02:16<00:00, 130800.35it/s]
# 100%|██████████| 17915065/17915065 [02:01<00:00, 147874.20it/s]
# 100%|██████████| 17915065/17915065 [01:48<00:00, 164587.84it/s]
# 100%|██████████| 17915065/17915065 [01:40<00:00, 178448.33it/s]
# 100%|██████████| 17915065/17915065 [01:32<00:00, 194391.86it/s]
# 100%|██████████| 17915065/17915065 [01:25<00:00, 209880.53it/s]
# 100%|██████████| 17915065/17915065 [01:22<00:00, 217097.99it/s]
# 100%|██████████| 17915065/17915065 [01:17<00:00, 230025.42it/s]
# 100%|██████████| 17915065/17915065 [01:12<00:00, 246744.01it/s]
# 1:21:17.208944 	 valid(carts) pos : 20192  neg : 17894873
# /home/kaggler/.local/lib/python3.8/site-packages/lightgbm/engine.py:181: UserWarning: 'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. Pass 'early_stopping()' callback via 'callbacks' argument instead.
#   _log_warning("'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. "
# /home/kaggler/.local/lib/python3.8/site-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# [LightGBM] [Info] Number of positive: 916690, number of negative: 916690
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.587569 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 21297
# [LightGBM] [Info] Number of data points in the train set: 1833380, number of used features: 91
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500000 -> initscore=0.000000
# Training until validation scores don't improve for 100 rounds
# [100]	training's binary_logloss: 0.30557	valid_1's binary_logloss: 0.325619
# [200]	training's binary_logloss: 0.293616	valid_1's binary_logloss: 0.32228
# [300]	training's binary_logloss: 0.285735	valid_1's binary_logloss: 0.321725
# [400]	training's binary_logloss: 0.278707	valid_1's binary_logloss: 0.321542
# [500]	training's binary_logloss: 0.272321	valid_1's binary_logloss: 0.321438
# [600]	training's binary_logloss: 0.266462	valid_1's binary_logloss: 0.32132
# [700]	training's binary_logloss: 0.26088	valid_1's binary_logloss: 0.321561
# Early stopping, best iteration is:
# [600]	training's binary_logloss: 0.266462	valid_1's binary_logloss: 0.32132
# 1:47:21.841465 	 carts valid score
# 1:47:21.843266 	 {'num_clicks': 97136, 'hit_clicks': 47759, 'num_carts': 43211, 'hit_carts': 15475, 'num_orders': 20082, 'hit_orders': 11791, 'recall_clicks': '0.491671', 'recall_carts': '0.358126', 'recall_orders': '0.587143', 'w_recall_clicks': '0.049167', 'w_recall_carts': '0.107438', 'w_recall_orders': '0.352286', 'score': '0.508891'}
# 1:47:23.063115 	 make orders_train_data
# 1:48:04.322957 	 [add_candidate] repurchase : start
# 1:48:06.330517 	 [add_candidate] clstr_freq : start
# 1:48:18.126295 	 [add_candidate] session_latest_time_wt_pair0 : start
# 1:48:19.826005 	 [add_candidate] session_latest_word2vec_pair0 : start
# 1:48:21.428460 	 [add_candidate] session_latest_pair0 : start
# 1:48:23.135762 	 [add_candidate] session_latest_type_wt_pair0 : start
# 1:48:24.695170 	 [add_candidate] session_latest_clicks2carts_pair0 : start
# 1:48:26.176300 	 [add_candidate] session_latest_clicks2orders_pair0 : start
# 1:48:27.481530 	 [add_candidate] session_latest_time_wt_pair1 : start
# 1:48:29.124037 	 [add_candidate] session_latest_word2vec_pair1 : start
# 1:48:30.746010 	 [add_candidate] session_latest_pair1 : start
# 1:48:32.336219 	 [add_candidate] session_latest_type_wt_pair1 : start
# 1:48:33.932156 	 [add_candidate] session_latest_clicks2carts_pair1 : start
# 1:48:35.423261 	 [add_candidate] session_latest_clicks2orders_pair1 : start
# 1:48:36.755553 	 [add_candidate] session_latest_time_wt_pair2 : start
# 1:48:38.395323 	 [add_candidate] session_latest_word2vec_pair2 : start
# 1:48:40.121794 	 [add_candidate] session_latest_pair2 : start
# 1:48:41.749972 	 [add_candidate] session_latest_type_wt_pair2 : start
# 1:48:43.375507 	 [add_candidate] session_latest_clicks2carts_pair2 : start
# 1:48:44.887619 	 [add_candidate] session_latest_clicks2orders_pair2 : start
# 1:48:46.305436 	 [add_candidate] session_latest_time_wt_pair3 : start
# 1:48:47.908103 	 [add_candidate] session_latest_word2vec_pair3 : start
# 1:48:49.564453 	 [add_candidate] session_latest_pair3 : start
# 1:48:51.221140 	 [add_candidate] session_latest_type_wt_pair3 : start
# 1:48:52.934112 	 [add_candidate] session_latest_clicks2carts_pair3 : start
# 1:48:54.478730 	 [add_candidate] session_latest_clicks2orders_pair3 : start
# 1:48:55.831496 	 [add_candidate] session_latest_time_wt_pair4 : start
# 1:48:57.442022 	 [add_candidate] session_latest_word2vec_pair4 : start
# 1:48:59.158833 	 [add_candidate] session_latest_pair4 : start
# 1:49:00.816060 	 [add_candidate] session_latest_type_wt_pair4 : start
# 1:49:02.530798 	 [add_candidate] session_latest_clicks2carts_pair4 : start
# 1:49:04.069998 	 [add_candidate] session_latest_clicks2orders_pair4 : start
# 1:49:05.437078 	 [add_candidate] session_latest_time_wt_pair5 : start
# 1:49:07.040457 	 [add_candidate] session_latest_word2vec_pair5 : start
# 1:49:08.786782 	 [add_candidate] session_latest_pair5 : start
# 1:49:10.412591 	 [add_candidate] session_latest_type_wt_pair5 : start
# 1:49:12.172083 	 [add_candidate] session_latest_clicks2carts_pair5 : start
# 1:49:13.688885 	 [add_candidate] session_latest_clicks2orders_pair5 : start
# 1:49:15.160614 	 [add_candidate] session_latest_time_wt_pair6 : start
# 1:49:16.803769 	 [add_candidate] session_latest_word2vec_pair6 : start
# 1:49:18.506461 	 [add_candidate] session_latest_pair6 : start
# 1:49:20.232987 	 [add_candidate] session_latest_type_wt_pair6 : start
# 1:49:21.935100 	 [add_candidate] session_latest_clicks2carts_pair6 : start
# 1:49:23.447644 	 [add_candidate] session_latest_clicks2orders_pair6 : start
# 1:49:24.802993 	 [add_candidate] session_latest_time_wt_pair7 : start
# 1:49:26.457853 	 [add_candidate] session_latest_word2vec_pair7 : start
# 1:49:28.195896 	 [add_candidate] session_latest_pair7 : start
# 1:49:29.819263 	 [add_candidate] session_latest_type_wt_pair7 : start
# 1:49:31.553908 	 [add_candidate] session_latest_clicks2carts_pair7 : start
# 1:49:33.101742 	 [add_candidate] session_latest_clicks2orders_pair7 : start
# 1:49:34.464076 	 [add_candidate] session_latest_time_wt_pair8 : start
# 1:49:36.103638 	 [add_candidate] session_latest_word2vec_pair8 : start
# 1:49:37.779337 	 [add_candidate] session_latest_pair8 : start
# 1:49:39.414554 	 [add_candidate] session_latest_type_wt_pair8 : start
# 1:49:41.153447 	 [add_candidate] session_latest_clicks2carts_pair8 : start
# 1:49:42.701114 	 [add_candidate] session_latest_clicks2orders_pair8 : start
# 1:49:44.196342 	 [add_candidate] session_latest_time_wt_pair9 : start
# 1:49:45.935472 	 [add_candidate] session_latest_word2vec_pair9 : start
# 1:49:47.634622 	 [add_candidate] session_latest_pair9 : start
# 1:49:49.320905 	 [add_candidate] session_latest_type_wt_pair9 : start
# 1:49:50.959924 	 [add_candidate] session_latest_clicks2carts_pair9 : start
# 1:49:52.477239 	 [add_candidate] session_latest_clicks2orders_pair9 : start
# 1:49:53.888544 	 [add_candidate] session_latest_time_wt_pair10 : start
# 1:49:55.543595 	 [add_candidate] session_latest_word2vec_pair10 : start
# 1:49:57.194335 	 [add_candidate] session_latest_pair10 : start
# 1:49:58.956349 	 [add_candidate] session_latest_type_wt_pair10 : start
# 1:50:00.599931 	 [add_candidate] session_latest_clicks2carts_pair10 : start
# 1:50:02.216874 	 [add_candidate] session_latest_clicks2orders_pair10 : start
# 1:50:03.564063 	 [add_candidate] session_latest_time_wt_pair11 : start
# 1:50:05.206721 	 [add_candidate] session_latest_word2vec_pair11 : start
# 1:50:06.970003 	 [add_candidate] session_latest_pair11 : start
# 1:50:08.685875 	 [add_candidate] session_latest_type_wt_pair11 : start
# 1:50:10.483733 	 [add_candidate] session_latest_clicks2carts_pair11 : start
# 1:50:12.060533 	 [add_candidate] session_latest_clicks2orders_pair11 : start
# 1:50:13.435493 	 [add_candidate] session_latest_time_wt_pair12 : start
# 1:50:15.096442 	 [add_candidate] session_latest_word2vec_pair12 : start
# 1:50:16.788840 	 [add_candidate] session_latest_pair12 : start
# 1:50:18.426281 	 [add_candidate] session_latest_type_wt_pair12 : start
# 1:50:20.191828 	 [add_candidate] session_latest_clicks2carts_pair12 : start
# 1:50:21.715180 	 [add_candidate] session_latest_clicks2orders_pair12 : start
# 1:50:23.169878 	 [add_candidate] session_latest_time_wt_pair13 : start
# 1:50:24.871619 	 [add_candidate] session_latest_word2vec_pair13 : start
# 1:50:26.552097 	 [add_candidate] session_latest_pair13 : start
# 1:50:28.244589 	 [add_candidate] session_latest_type_wt_pair13 : start
# 1:50:30.026072 	 [add_candidate] session_latest_clicks2carts_pair13 : start
# 1:50:31.590688 	 [add_candidate] session_latest_clicks2orders_pair13 : start
# 1:50:32.946250 	 [add_candidate] session_latest_time_wt_pair14 : start
# 1:50:34.703953 	 [add_candidate] session_latest_word2vec_pair14 : start
# 1:50:36.456757 	 [add_candidate] session_latest_pair14 : start
# 1:50:38.145589 	 [add_candidate] session_latest_type_wt_pair14 : start
# 1:50:39.864607 	 [add_candidate] session_latest_clicks2carts_pair14 : start
# 1:50:41.477673 	 [add_candidate] session_latest_clicks2orders_pair14 : start
# 1:50:42.847542 	 [add_candidate] session_latest_time_wt_pair15 : start
# 1:50:44.494234 	 [add_candidate] session_latest_word2vec_pair15 : start
# 1:50:46.152780 	 [add_candidate] session_latest_pair15 : start
# 1:50:47.826077 	 [add_candidate] session_latest_type_wt_pair15 : start
# 1:50:49.624711 	 [add_candidate] session_latest_clicks2carts_pair15 : start
# 1:50:51.223654 	 [add_candidate] session_latest_clicks2orders_pair15 : start
# 1:50:52.611469 	 [add_candidate] session_latest_time_wt_pair16 : start
# 1:50:54.305345 	 [add_candidate] session_latest_word2vec_pair16 : start
# 1:50:55.974800 	 [add_candidate] session_latest_pair16 : start
# 1:50:57.651505 	 [add_candidate] session_latest_type_wt_pair16 : start
# 1:50:59.394302 	 [add_candidate] session_latest_clicks2carts_pair16 : start
# 1:51:00.978086 	 [add_candidate] session_latest_clicks2orders_pair16 : start
# 1:51:02.367586 	 [add_candidate] session_latest_time_wt_pair17 : start
# 1:51:04.159198 	 [add_candidate] session_latest_word2vec_pair17 : start
# 1:51:05.825163 	 [add_candidate] session_latest_pair17 : start
# 1:51:07.568918 	 [add_candidate] session_latest_type_wt_pair17 : start
# 1:51:09.245377 	 [add_candidate] session_latest_clicks2carts_pair17 : start
# 1:51:10.878623 	 [add_candidate] session_latest_clicks2orders_pair17 : start
# 1:51:12.286952 	 [add_candidate] session_latest_time_wt_pair18 : start
# 1:51:13.956003 	 [add_candidate] session_latest_word2vec_pair18 : start
# 1:51:15.647411 	 [add_candidate] session_latest_pair18 : start
# 1:51:17.416791 	 [add_candidate] session_latest_type_wt_pair18 : start
# 1:51:19.161520 	 [add_candidate] session_latest_clicks2carts_pair18 : start
# 1:51:20.730350 	 [add_candidate] session_latest_clicks2orders_pair18 : start
# 1:51:22.235272 	 [add_candidate] session_latest_time_wt_pair19 : start
# 1:51:23.954525 	 [add_candidate] session_latest_word2vec_pair19 : start
# 1:51:25.618720 	 [add_candidate] session_latest_pair19 : start
# 1:51:27.394873 	 [add_candidate] session_latest_type_wt_pair19 : start
# 1:51:29.098809 	 [add_candidate] session_latest_clicks2carts_pair19 : start
# 1:51:30.636729 	 [add_candidate] session_latest_clicks2orders_pair19 : start
# 1:52:31.847632 	 train(orders) pos : 611384  neg : 611384
# 1:52:33.289378 	 [features] session_cnt : start
# 1:52:34.460500 	 [features] session_aid_nunique : start
# 1:52:34.813780 	 [features] session_last_type : start
# 1:52:35.256711 	 [features] aid_cnt : start
# 1:52:36.892190 	 [features] aid_clicks_cnt : start
# 1:52:38.344784 	 [features] aid_carts_cnt : start
# 1:52:38.539645 	 [features] aid_orders_cnt : start
# 1:52:38.626417 	 [features] all_times_aid_freq : start
# 1:52:39.120547 	 [features] all_times_aid_clicks_freq : start
# 1:52:39.625906 	 [features] all_times_aid_carts_freq : start
# 1:52:39.947612 	 [features] all_times_aid_orders_freq : start
# 1:52:40.130898 	 [features] all_times_aid_session_freq : start
# 1:52:40.618212 	 [features] all_times_aid_session_clicks_freq : start
# 1:52:41.114252 	 [features] all_times_aid_session_carts_freq : start
# 1:52:41.431674 	 [features] all_times_aid_session_orders_freq : start
# 1:52:41.602770 	 [features] all_times_aid_carts_ratio_with_clicks : start
# 1:52:42.138361 	 [features] all_times_aid_orders_ratio_with_clicks : start
# 1:52:42.705607 	 [features] all_times_aid_date_std : start
# 1:52:43.294826 	 [features] all_times_aid_hour_std : start
# 1:52:43.855831 	 [features] all_times_aid_day_of_week_std : start
# 1:52:44.478320 	 [features] w2v_vectors : start
# 1:52:44.856233 	 [features] relative_ts : start
# 1:52:49.820627 	 [features] co_visit_rank(co_visitation_matrix) : start
# 1:53:00.268675 	 [features] co_visit_rank(co_visitation_matrix_lt0) : start
# 1:53:23.690711 	 [features] co_visit_rank(co_visitation_matrix_lt1) : start
# 1:53:49.255481 	 [features] co_visit_rank(co_visitation_matrix_lt2) : start
# 1:54:15.189918 	 [features] co_visit_rank(co_visitation_matrix_lt3) : start
# 1:54:41.737881 	 [features] co_visit_rank(co_visitation_matrix_lt4) : start
# 1:55:08.542206 	 [features] co_visit_rank(co_visitation_matrix_lt5) : start
# 1:55:32.527048 	 [features] co_visit_rank(co_visitation_matrix_lt6) : start
# 1:55:57.034593 	 [features] co_visit_rank(co_visitation_matrix_lt7) : start
# 1:56:20.974355 	 [features] co_visit_rank(co_visitation_matrix_lt8) : start
# 1:56:46.756182 	 [features] co_visit_rank(co_visitation_matrix_lt9) : start
# 1:57:10.138735 	 [features] co_visit_rank(co_visitation_matrix_time_weighted) : start
# 1:58:01.836767 	 [features] co_visit_rank(co_visitation_matrix_time_weighted_lt0) : start
# 1:58:55.463979 	 [features] co_visit_rank(co_visitation_matrix_time_weighted_lt1) : start
# 1:59:46.469905 	 [features] co_visit_rank(co_visitation_matrix_time_weighted_lt2) : start
# 2:00:36.422358 	 [features] co_visit_rank(co_visitation_matrix_time_weighted_lt3) : start
# 2:01:38.163563 	 [features] co_visit_rank(co_visitation_matrix_time_weighted_lt4) : start
# 2:02:27.824072 	 [features] co_visit_rank(co_visitation_matrix_time_weighted_lt5) : start
# 2:03:19.982473 	 [features] co_visit_rank(co_visitation_matrix_time_weighted_lt6) : start
# 2:04:09.923038 	 [features] co_visit_rank(co_visitation_matrix_time_weighted_lt7) : start
# 2:05:09.794675 	 [features] co_visit_rank(co_visitation_matrix_time_weighted_lt8) : start
# 2:05:59.331217 	 [features] co_visit_rank(co_visitation_matrix_time_weighted_lt9) : start
# 2:06:49.759487 	 [features] co_visit_rank(co_visitation_matrix_type_weighted) : start
# 2:07:22.421111 	 [features] co_visit_rank(co_visitation_matrix_type_weighted_lt0) : start
# 2:08:14.994632 	 [features] co_visit_rank(co_visitation_matrix_type_weighted_lt1) : start
# 2:09:11.690225 	 [features] co_visit_rank(co_visitation_matrix_type_weighted_lt2) : start
# 2:10:03.996145 	 [features] co_visit_rank(co_visitation_matrix_type_weighted_lt3) : start
# 2:11:05.002666 	 [features] co_visit_rank(co_visitation_matrix_type_weighted_lt4) : start
# 2:11:57.293985 	 [features] co_visit_rank(co_visitation_matrix_type_weighted_lt5) : start
# 2:12:59.330150 	 [features] co_visit_rank(co_visitation_matrix_type_weighted_lt6) : start
# 2:13:51.657784 	 [features] co_visit_rank(co_visitation_matrix_type_weighted_lt7) : start
# 2:14:44.251884 	 [features] co_visit_rank(co_visitation_matrix_type_weighted_lt8) : start
# 2:15:42.926728 	 [features] co_visit_rank(co_visitation_matrix_type_weighted_lt9) : start
# 2:16:35.577845 	 [features] co_visit_rank(co_visitation_matrix_clicks2carts) : start
# 2:16:39.335175 	 [features] co_visit_rank(co_visitation_matrix_clicks2carts_lt0) : start
# 2:16:40.893728 	 [features] co_visit_rank(co_visitation_matrix_clicks2carts_lt1) : start
# 2:16:42.372442 	 [features] co_visit_rank(co_visitation_matrix_clicks2carts_lt2) : start
# 2:16:43.620237 	 [features] co_visit_rank(co_visitation_matrix_clicks2carts_lt3) : start
# 2:16:44.909055 	 [features] co_visit_rank(co_visitation_matrix_clicks2carts_lt4) : start
# 2:16:46.178563 	 [features] co_visit_rank(co_visitation_matrix_clicks2carts_lt5) : start
# 2:16:47.483319 	 [features] co_visit_rank(co_visitation_matrix_clicks2carts_lt6) : start
# 2:16:48.730053 	 [features] co_visit_rank(co_visitation_matrix_clicks2carts_lt7) : start
# 2:16:49.961106 	 [features] co_visit_rank(co_visitation_matrix_clicks2carts_lt8) : start
# 2:16:51.197836 	 [features] co_visit_rank(co_visitation_matrix_clicks2carts_lt9) : start
# 2:16:52.449446 	 [features] co_visit_rank(co_visitation_matrix_clicks2orders) : start
# 2:16:53.457557 	 [features] co_visit_rank(co_visitation_matrix_clicks2orders_lt0) : start
# 2:16:53.745665 	 [features] co_visit_rank(co_visitation_matrix_clicks2orders_lt1) : start
# 2:16:54.038620 	 [features] co_visit_rank(co_visitation_matrix_clicks2orders_lt2) : start
# 2:16:54.343253 	 [features] co_visit_rank(co_visitation_matrix_clicks2orders_lt3) : start
# 2:16:54.623564 	 [features] co_visit_rank(co_visitation_matrix_clicks2orders_lt4) : start
# 2:16:54.914829 	 [features] co_visit_rank(co_visitation_matrix_clicks2orders_lt5) : start
# 2:16:55.191042 	 [features] co_visit_rank(co_visitation_matrix_clicks2orders_lt6) : start
# 2:16:55.485108 	 [features] co_visit_rank(co_visitation_matrix_clicks2orders_lt7) : start
# 2:16:55.777884 	 [features] co_visit_rank(co_visitation_matrix_clicks2orders_lt8) : start
# 2:16:56.070179 	 [features] co_visit_rank(co_visitation_matrix_clicks2orders_lt9) : start
# 2:16:56.359862 	 [features] latest_aid_w2v_sims : start
# 100%|██████████| 1222768/1222768 [00:12<00:00, 98330.30it/s]
# 100%|██████████| 1222768/1222768 [00:11<00:00, 107993.94it/s]
# 100%|██████████| 1222768/1222768 [00:10<00:00, 117464.79it/s]
# 100%|██████████| 1222768/1222768 [00:09<00:00, 124031.54it/s]
# 100%|██████████| 1222768/1222768 [00:09<00:00, 131430.75it/s]
# 100%|██████████| 1222768/1222768 [00:08<00:00, 138981.21it/s]
# 100%|██████████| 1222768/1222768 [00:08<00:00, 146084.28it/s]
# 100%|██████████| 1222768/1222768 [00:07<00:00, 154132.18it/s]
# 100%|██████████| 1222768/1222768 [00:07<00:00, 159340.34it/s]
# 100%|██████████| 1222768/1222768 [00:07<00:00, 169674.73it/s]
# 2:18:47.167179 	 make orders_valid_data
# 2:18:47.179180 	 [valid_cand.parquet] cache exists. read cache and skip process.
# 2:18:49.566875 	 make orders_valid_data
# 2:18:49.615471 	 [features] session_cnt : start
# 2:18:51.669829 	 [features] session_aid_nunique : start
# 2:18:52.100747 	 [features] session_last_type : start
# 2:18:52.378633 	 [features] aid_cnt : start
# 2:18:53.076555 	 [features] aid_clicks_cnt : start
# 2:18:53.681161 	 [features] aid_carts_cnt : start
# 2:18:54.156769 	 [features] aid_orders_cnt : start
# 2:18:54.625589 	 [features] all_times_aid_freq : start
# 2:18:55.494667 	 [features] all_times_aid_clicks_freq : start
# 2:18:56.477680 	 [features] all_times_aid_carts_freq : start
# 2:18:57.095162 	 [features] all_times_aid_orders_freq : start
# 2:18:57.529022 	 [features] all_times_aid_session_freq : start
# 2:18:58.412816 	 [features] all_times_aid_session_clicks_freq : start
# 2:18:59.308852 	 [features] all_times_aid_session_carts_freq : start
# 2:18:59.854943 	 [features] all_times_aid_session_orders_freq : start
# 2:19:00.264729 	 [features] all_times_aid_carts_ratio_with_clicks : start
# 2:19:01.136218 	 [features] all_times_aid_orders_ratio_with_clicks : start
# 2:19:02.030555 	 [features] all_times_aid_date_std : start
# 2:19:02.905144 	 [features] all_times_aid_hour_std : start
# 2:19:03.798446 	 [features] all_times_aid_day_of_week_std : start
# 2:19:04.697345 	 [features] w2v_vectors : start
# 2:19:05.689000 	 [features] relative_ts : start
# 2:19:10.715679 	 [features] co_visit_rank(co_visitation_matrix) : start
# 2:19:31.942597 	 [features] co_visit_rank(co_visitation_matrix_lt0) : start
# 2:19:55.293097 	 [features] co_visit_rank(co_visitation_matrix_lt1) : start
# 2:20:20.817563 	 [features] co_visit_rank(co_visitation_matrix_lt2) : start
# 2:20:45.627981 	 [features] co_visit_rank(co_visitation_matrix_lt3) : start
# 2:21:09.118354 	 [features] co_visit_rank(co_visitation_matrix_lt4) : start
# 2:21:32.577511 	 [features] co_visit_rank(co_visitation_matrix_lt5) : start
# 2:21:57.073282 	 [features] co_visit_rank(co_visitation_matrix_lt6) : start
# 2:22:20.343062 	 [features] co_visit_rank(co_visitation_matrix_lt7) : start
# 2:22:44.910340 	 [features] co_visit_rank(co_visitation_matrix_lt8) : start
# 2:23:09.554535 	 [features] co_visit_rank(co_visitation_matrix_lt9) : start
# 2:23:32.918631 	 [features] co_visit_rank(co_visitation_matrix_time_weighted) : start
# 2:24:23.563915 	 [features] co_visit_rank(co_visitation_matrix_time_weighted_lt0) : start
# 2:25:20.861511 	 [features] co_visit_rank(co_visitation_matrix_time_weighted_lt1) : start
# 2:26:09.985954 	 [features] co_visit_rank(co_visitation_matrix_time_weighted_lt2) : start
# 2:27:00.562042 	 [features] co_visit_rank(co_visitation_matrix_time_weighted_lt3) : start
# 2:27:50.276309 	 [features] co_visit_rank(co_visitation_matrix_time_weighted_lt4) : start
# 2:28:42.896036 	 [features] co_visit_rank(co_visitation_matrix_time_weighted_lt5) : start
# 2:29:32.206309 	 [features] co_visit_rank(co_visitation_matrix_time_weighted_lt6) : start
# 2:30:23.123798 	 [features] co_visit_rank(co_visitation_matrix_time_weighted_lt7) : start
# 2:31:12.154695 	 [features] co_visit_rank(co_visitation_matrix_time_weighted_lt8) : start
# 2:32:01.839015 	 [features] co_visit_rank(co_visitation_matrix_time_weighted_lt9) : start
# 2:32:51.148335 	 [features] co_visit_rank(co_visitation_matrix_type_weighted) : start
# 2:33:25.136739 	 [features] co_visit_rank(co_visitation_matrix_type_weighted_lt0) : start
# 2:34:18.165122 	 [features] co_visit_rank(co_visitation_matrix_type_weighted_lt1) : start
# 2:35:14.950724 	 [features] co_visit_rank(co_visitation_matrix_type_weighted_lt2) : start
# 2:36:07.229229 	 [features] co_visit_rank(co_visitation_matrix_type_weighted_lt3) : start
# 2:36:59.115245 	 [features] co_visit_rank(co_visitation_matrix_type_weighted_lt4) : start
# 2:37:56.887600 	 [features] co_visit_rank(co_visitation_matrix_type_weighted_lt5) : start
# 2:38:50.138233 	 [features] co_visit_rank(co_visitation_matrix_type_weighted_lt6) : start
# 2:39:43.854106 	 [features] co_visit_rank(co_visitation_matrix_type_weighted_lt7) : start
# 2:40:37.410058 	 [features] co_visit_rank(co_visitation_matrix_type_weighted_lt8) : start
# 2:41:29.997080 	 [features] co_visit_rank(co_visitation_matrix_type_weighted_lt9) : start
# 2:42:31.724547 	 [features] co_visit_rank(co_visitation_matrix_clicks2carts) : start
# 2:42:35.088801 	 [features] co_visit_rank(co_visitation_matrix_clicks2carts_lt0) : start
# 2:42:37.080337 	 [features] co_visit_rank(co_visitation_matrix_clicks2carts_lt1) : start
# 2:42:38.994339 	 [features] co_visit_rank(co_visitation_matrix_clicks2carts_lt2) : start
# 2:42:40.832454 	 [features] co_visit_rank(co_visitation_matrix_clicks2carts_lt3) : start
# 2:42:42.649292 	 [features] co_visit_rank(co_visitation_matrix_clicks2carts_lt4) : start
# 2:42:44.471002 	 [features] co_visit_rank(co_visitation_matrix_clicks2carts_lt5) : start
# 2:42:46.272098 	 [features] co_visit_rank(co_visitation_matrix_clicks2carts_lt6) : start
# 2:42:48.028644 	 [features] co_visit_rank(co_visitation_matrix_clicks2carts_lt7) : start
# 2:42:49.766903 	 [features] co_visit_rank(co_visitation_matrix_clicks2carts_lt8) : start
# 2:42:51.498595 	 [features] co_visit_rank(co_visitation_matrix_clicks2carts_lt9) : start
# 2:42:53.230452 	 [features] co_visit_rank(co_visitation_matrix_clicks2orders) : start
# 2:42:54.249151 	 [features] co_visit_rank(co_visitation_matrix_clicks2orders_lt0) : start
# 2:42:55.094626 	 [features] co_visit_rank(co_visitation_matrix_clicks2orders_lt1) : start
# 2:42:55.888321 	 [features] co_visit_rank(co_visitation_matrix_clicks2orders_lt2) : start
# 2:42:56.670982 	 [features] co_visit_rank(co_visitation_matrix_clicks2orders_lt3) : start
# 2:42:57.417215 	 [features] co_visit_rank(co_visitation_matrix_clicks2orders_lt4) : start
# 2:42:58.177113 	 [features] co_visit_rank(co_visitation_matrix_clicks2orders_lt5) : start
# 2:42:58.917147 	 [features] co_visit_rank(co_visitation_matrix_clicks2orders_lt6) : start
# 2:42:59.667059 	 [features] co_visit_rank(co_visitation_matrix_clicks2orders_lt7) : start
# 2:43:00.413491 	 [features] co_visit_rank(co_visitation_matrix_clicks2orders_lt8) : start
# 2:43:01.163709 	 [features] co_visit_rank(co_visitation_matrix_clicks2orders_lt9) : start
# 2:43:01.892027 	 [features] latest_aid_w2v_sims : start
# 100%|██████████| 17915065/17915065 [02:44<00:00, 108811.60it/s]
# 100%|██████████| 17915065/17915065 [02:18<00:00, 129693.06it/s]
# 100%|██████████| 17915065/17915065 [02:02<00:00, 146337.60it/s]
# 100%|██████████| 17915065/17915065 [01:50<00:00, 161722.48it/s]
# 100%|██████████| 17915065/17915065 [01:41<00:00, 176167.55it/s]
# 100%|██████████| 17915065/17915065 [01:33<00:00, 190678.60it/s]
# 100%|██████████| 17915065/17915065 [01:27<00:00, 204936.52it/s]
# 100%|██████████| 17915065/17915065 [01:21<00:00, 220130.98it/s]
# 100%|██████████| 17915065/17915065 [01:16<00:00, 235029.18it/s]
# 100%|██████████| 17915065/17915065 [01:11<00:00, 250461.70it/s]
# 3:00:48.833214 	 valid(orders) pos : 13374  neg : 17901691
# /home/kaggler/.local/lib/python3.8/site-packages/lightgbm/engine.py:181: UserWarning: 'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. Pass 'early_stopping()' callback via 'callbacks' argument instead.
#   _log_warning("'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. "
# /home/kaggler/.local/lib/python3.8/site-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# [LightGBM] [Info] Number of positive: 611384, number of negative: 611384
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.066455 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 21306
# [LightGBM] [Info] Number of data points in the train set: 1222768, number of used features: 91
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500000 -> initscore=0.000000
# Training until validation scores don't improve for 100 rounds
# [100]	training's binary_logloss: 0.190815	valid_1's binary_logloss: 0.220948
# [200]	training's binary_logloss: 0.179882	valid_1's binary_logloss: 0.219784
# [300]	training's binary_logloss: 0.172413	valid_1's binary_logloss: 0.219668
# [400]	training's binary_logloss: 0.165965	valid_1's binary_logloss: 0.219586
# [500]	training's binary_logloss: 0.16032	valid_1's binary_logloss: 0.219607
# [600]	training's binary_logloss: 0.15494	valid_1's binary_logloss: 0.219523
# Early stopping, best iteration is:
# [552]	training's binary_logloss: 0.157452	valid_1's binary_logloss: 0.219434
# 3:04:46.506644 	 orders valid score
# 3:04:46.513282 	 {'num_clicks': 97136, 'hit_clicks': 45990, 'num_carts': 43211, 'hit_carts': 14967, 'num_orders': 20082, 'hit_orders': 11924, 'recall_clicks': '0.473460', 'recall_carts': '0.346370', 'recall_orders': '0.593766', 'w_recall_clicks': '0.047346', 'w_recall_carts': '0.103911', 'w_recall_orders': '0.356259', 'score': '0.507516'}
