# %% [markdown]
# # cand_trial
# time_weighted weight数違い確認

# %%
import os
import sys
import traceback
import gc
import random
import pickle
import pathlib
import subprocess
from dataclasses import dataclass
from dotenv import load_dotenv
load_dotenv
sys.path.append(os.getenv('UTILS_PATH'))
from tqdm import tqdm
import multiprocessing
import inspect

import pandas as pd
import polars as pl
import numpy as np
import itertools
import cudf
import lightgbm as lgb
import matplotlib.pyplot as plt
import seaborn as sns
import line_notify
import my_logger
from noglobal import noglobal

# %% [markdown]
# # 設定

# %%
@dataclass
class Cfg:
    loglevel = "INFO"
    exp_name = "cand_trial011"
    seed = 42
    k = 20
    cand_n = 15
    negative_sample = 1
    train_chunk_n_dict = {"clicks":2, "carts":1, "orders":1}
    test_chunk_n = 2
    type2id = {"clicks":0, "carts":1, "orders":2}
    id2type = {0:"clicks", 1:"carts", 2:"orders"}
    train_week = "week3"
    valid_week = "week4"
    valid_session_n = 100_000
    input_dir = os.getenv('INPUT_DIR')
    output_dir = os.getenv('OUTPUT_DIR')
    prep_dir = os.getenv("PREP_DIR")

    clicks_params = {'objective': 'binary', 'boosting': 'gbdt', 'learning_rate': 0.1, 'metric': 'binary_logloss', 'seed': 42, 'feature_pre_filter': False, 'lambda_l1': 5.485903737168179, 'lambda_l2': 0.005594683492536064, 'num_leaves': 79, 'feature_fraction': 0.552, 'bagging_fraction': 0.9295272232672004, 'bagging_freq': 2, 'min_child_samples': 10}
    carts_params = {'objective': 'binary', 'boosting': 'gbdt', 'learning_rate': 0.1, 'metric': 'binary_logloss', 'seed': 42, 'feature_pre_filter': False, 'lambda_l1': 8.709050252544463, 'lambda_l2': 0.06935262036337767, 'num_leaves': 252, 'feature_fraction': 0.4, 'bagging_fraction': 1.0, 'bagging_freq': 0, 'min_child_samples': 5}
    orders_params = {'objective': 'binary', 'boosting': 'gbdt', 'learning_rate': 0.1, 'metric': 'binary_logloss', 'seed': 42, 'feature_pre_filter': False, 'lambda_l1': 9.356310279757256, 'lambda_l2': 1.3120983078968551e-08, 'num_leaves': 174, 'feature_fraction': 0.5, 'bagging_fraction': 1.0, 'bagging_freq': 0, 'min_child_samples': 20}

cfg = Cfg()
os.makedirs(os.path.join(cfg.output_dir, cfg.exp_name), exist_ok=True)
os.makedirs(os.path.join(cfg.output_dir, cfg.exp_name, "cache"), exist_ok=True)
random.seed(cfg.seed)

logger = my_logger.init_logger(cfg.exp_name)

# %%
class Cache:
    @noglobal(excepts=["cfg", "logger"])
    def __init__(self):
        self.cache_dir = (os.path.join(cfg.output_dir, cfg.exp_name, "cache"))
        self.cache_dir_path = pathlib.Path(self.cache_dir)
        self.caches = list(self.cache_dir_path.glob("*"))

    def update(self):
        self.caches = list(self.cache_dir_path.glob("*"))

    @noglobal(excepts=["cfg", "logger"])
    def get_abspath(self, filename):
        return (os.path.join(self.cache_dir, filename))
    
    @noglobal(excepts=["cfg", "logger"])
    def exists(self, path):
        self.update()
        return len([str(c) for c in self.caches if path == str(c)]) > 0

cache = Cache()

# %%
@noglobal(excepts=["cfg", "logger"])
def evaluate(clicks_labels, carts_labels, orders_labels, 
             clicks_preds, carts_preds, orders_preds, k=20):

    num_clicks = 0
    num_carts = 0
    num_orders = 0
    hit_clicks = 0
    hit_carts = 0
    hit_orders = 0

    for i in range(len(clicks_labels)):
        clicks_label = clicks_labels[i]
        carts_label = carts_labels[i]
        orders_label = orders_labels[i]
        clicks_pred = clicks_preds[i]
        carts_pred = carts_preds[i]
        orders_pred = orders_preds[i]

        if type(clicks_pred) == list:
            clicks_pred = clicks_pred[:k]
        else:
            clicks_pred = []
        if type(carts_pred) == list:
            carts_pred = carts_pred[:k]
        else:
            carts_pred = []    
        if type(orders_pred) == list:
            orders_pred = orders_pred[:k]
        else:
            orders_pred = []

        if not np.isnan(clicks_label):
            num_clicks += 1
            hit_clicks += int(clicks_label in clicks_pred)

        if type(carts_label) == np.ndarray:
            num_carts += min(len(carts_label), k)
            hit_carts += len(set(carts_pred) & set(carts_label))
            
        if type(orders_label) == np.ndarray:
            num_orders += min(len(orders_label), k)
            hit_orders += len(set(orders_pred) & set(orders_label))


    recall_clicks = hit_clicks / num_clicks
    recall_carts = hit_carts / num_carts
    recall_orders = hit_orders / num_orders
    w_recall_clicks = recall_clicks * 0.10
    w_recall_carts = recall_carts * 0.30
    w_recall_orders = recall_orders * 0.60
    score = w_recall_clicks + w_recall_carts + w_recall_orders

    results = {}
    results["num_clicks"] = num_clicks
    results["hit_clicks"] = hit_clicks
    results["num_carts"] = num_carts
    results["hit_carts"] = hit_carts
    results["num_orders"] = num_orders
    results["hit_orders"] = hit_orders
    results["recall_clicks"] = format(recall_clicks, ".6f")
    results["recall_carts"] = format(recall_carts, ".6f")
    results["recall_orders"] = format(recall_orders, ".6f")
    results["w_recall_clicks"] = format(w_recall_clicks, ".6f")
    results["w_recall_carts"] = format(w_recall_carts, ".6f")
    results["w_recall_orders"] = format(w_recall_orders, ".6f")
    results["score"] = format(score, ".6f")

    return results

# %%
class Candidate:
    @noglobal(excepts=["cfg", "logger"])
    def __init__(self, pl_df):
        self.df = cudf.from_pandas(pl_df.to_pandas())
        self.sessions = []
        self.aids = []

    @noglobal(excepts=["cfg", "logger"])
    def add(self, strategy, name, usetypes=['clicks', 'carts', 'orders'], trans_map=None, k=20):
        logger.info(f"[add_candidate] {name} : start")
        candidate_df = self.df[self.df["type"].isin(usetypes)].copy()
        
        if strategy == "session_frequent":
            candidate_df = self._session_frequent(candidate_df, k)
        elif strategy == "session_latest":
            candidate_df = self._session_latest(candidate_df, k)
        elif strategy == "total_frequent":
            candidate_df = self._total_frequent(candidate_df, k)
        elif strategy == "repurchase":
            candidate_df = self._repurchase(candidate_df)
        
        if trans_map is not None:
            candidate_df["aid"] = candidate_df["aid"].map(trans_map).astype("int32")
            candidate_df = candidate_df.dropna(subset=["aid"])
        candidate_df = candidate_df.drop_duplicates(subset=["session", "aid"])
        
        self.sessions.extend(candidate_df["session"].to_arrow().to_pylist())
        self.aids.extend(candidate_df["aid"].to_arrow().to_pylist())

    @noglobal(excepts=["cfg", "logger"])
    def get_dataframe(self):
        cand_df = pl.DataFrame([
            pl.Series("session", self.sessions, pl.Int32),
            pl.Series("aid", self.aids, pl.Int32)
            ]).unique()
        return cand_df

    @noglobal(excepts=["cfg", "logger"])
    def _repurchase(self, candidate_df):
        return candidate_df[["session", "aid"]].drop_duplicates()

    @noglobal(excepts=["cfg", "logger"])
    def _session_frequent(self, candidate_df, k):
        candidate_df = candidate_df.groupby(["session", "aid"])["ts"].count().reset_index()
        candidate_df.columns = ["session", "aid", "aid_count"]
        candidate_df = candidate_df.sort_values(["session", "aid_count", "aid"], ascending=(True, False, True))
        candidate_df = candidate_df[candidate_df.groupby("session")["aid_count"].cumcount() < k].copy()
        candidate_df = candidate_df[["session", "aid"]].copy()
        return candidate_df

    @noglobal(excepts=["cfg", "logger"])
    def _session_latest(self, candidate_df, k):
        candidate_df = candidate_df.sort_values(["session", "ts"], ascending=(True, False)).drop_duplicates(subset=["session", "aid"])
        candidate_df = candidate_df.sort_values(["session", "ts"], ascending=(True, False))[candidate_df.groupby("session")["ts"].cumcount() < k].copy()
        candidate_df = candidate_df[["session", "aid"]].copy()
        return candidate_df

    @noglobal(excepts=["cfg", "logger"])
    def _total_frequent(self, candidate_df, k):
        candidate_df = candidate_df.groupby("aid")["ts"].count().reset_index()
        candidate_df.columns = ["aid", "aid_count"]
        topk_freq_aids = candidate_df.sort_values("aid_count", ascending=False)["aid"].to_arrow().to_pylist()[:k]
        sessions = []
        aids = []
        for session, aid in itertools.product(self.target_sessions, topk_freq_aids):
            sessions.append(session)
            aids.append(aid)
        candidate_df = cudf.DataFrame({"session": sessions, "aid": aids})
        return candidate_df

# %%
@noglobal(excepts=["cfg", "logger"])
def make_cand_df(sessions, trans_maps=None):
    cand = Candidate(sessions)
    cand.add(strategy="repurchase", name="repurchase")
    #cand.add(strategy="session_frequent", name="session_frequent", k=15)
    #cand.add(strategy="session_latest", name="session_latest", k=30)
    
    for i in range(20):
        cand.add(strategy="session_latest", trans_map=trans_maps[f"time_wt_pair{str(i)}"], name=f"session_latest_time_wt_pair{str(i)}", k=20)
        cand.add(strategy="session_latest", trans_map=trans_maps[f"word2vec_pair{str(i)}"], name=f"session_latest_word2vec_pair{str(i)}", k=20)
        cand.add(strategy="session_latest", trans_map=trans_maps[f"pair{str(i)}"], name=f"session_latest_pair{str(i)}", k=20)
        cand.add(strategy="session_latest", trans_map=trans_maps[f"type_wt_pair{str(i)}"], name=f"session_latest_type_wt_pair{str(i)}", k=20)
        cand.add(strategy="session_latest", trans_map=trans_maps[f"clicks2carts_pair{str(i)}"], name=f"session_latest_clicks2carts_pair{str(i)}", k=20)
        cand.add(strategy="session_latest", trans_map=trans_maps[f"clicks2orders_pair{str(i)}"], name=f"session_latest_clicks2orders_pair{str(i)}", k=20)

    return cand.get_dataframe()

# %%
@noglobal(excepts=["cfg", "logger"])
def get_pair_df(name, wt_col, week):
    if week is not None:
        name = f"{name}_{week}"
    return pl.read_parquet(cfg.prep_dir + f"{name}.parquet").sort(wt_col, reverse=True)

@noglobal(excepts=["cfg", "logger"])
def get_trans_maps(week=None):
    """
    aidを別のaidに置き換えるmapping辞書を取得する
    """
    trans_maps = {}

    pair_df_org = get_pair_df("co_visitation_matrix", "cnt", week)
    for i in range(20):
        pair_df = pair_df_org.groupby("aid_x").head(i+1)
        pair_dict = {k: v for k, v in zip(pair_df.get_column("aid_x").to_list(), pair_df.get_column("aid_y").to_list())}
        trans_maps[f"pair{str(i)}"] = pair_dict
    
    pair_df_org = get_pair_df("co_visitation_matrix_time_weighted", "wt", week)
    for i in range(20):
        pair_df = pair_df_org.groupby("aid_x").head(i+1)
        pair_dict = {k: v for k, v in zip(pair_df.get_column("aid_x").to_list(), pair_df.get_column("aid_y").to_list())}
        trans_maps[f"time_wt_pair{str(i)}"] = pair_dict

    pair_df_org = get_pair_df("co_visitation_matrix_type_weighted", "wt", week)
    for i in range(20):
        pair_df = pair_df_org.groupby("aid_x").head(i+1)
        pair_dict = {k: v for k, v in zip(pair_df.get_column("aid_x").to_list(), pair_df.get_column("aid_y").to_list())}
        trans_maps[f"type_wt_pair{str(i)}"] = pair_dict

    pair_df_org = get_pair_df("co_visitation_matrix_clicks2carts", "cnt", week)
    for i in range(20):
        pair_df = pair_df_org.groupby("aid_x").head(i+1)
        pair_dict = {k: v for k, v in zip(pair_df.get_column("aid_x").to_list(), pair_df.get_column("aid_y").to_list())}
        trans_maps[f"clicks2carts_pair{str(i)}"] = pair_dict

    pair_df_org = get_pair_df("co_visitation_matrix_clicks2orders", "cnt", week)
    for i in range(20):
        pair_df = pair_df_org.groupby("aid_x").head(i+1)
        pair_dict = {k: v for k, v in zip(pair_df.get_column("aid_x").to_list(), pair_df.get_column("aid_y").to_list())}
        trans_maps[f"clicks2orders_pair{str(i)}"] = pair_dict

    pair_df_org = get_pair_df("word2vec_similar", "sim", None)
    for i in range(20):
        pair_df = pair_df = pair_df_org.groupby("aid_x").head(i+1)
        pair_dict = {k: v for k, v in zip(pair_df.get_column("aid_x").to_list(), pair_df.get_column("aid_y").to_list())}
        trans_maps[f"word2vec_pair{str(i)}"] = pair_dict

    pair_df_org = get_pair_df("co_visitation_matrix_time_weighted_weight5", "wt", week)
    for i in range(20):
        pair_df = pair_df_org.groupby("aid_x").head(i+1)
        pair_dict = {k: v for k, v in zip(pair_df.get_column("aid_x").to_list(), pair_df.get_column("aid_y").to_list())}
        trans_maps[f"time_wt5_pair{str(i)}"] = pair_dict

    pair_df_org = get_pair_df("co_visitation_matrix_time_weighted_weight10", "wt", week)
    for i in range(20):
        pair_df = pair_df_org.groupby("aid_x").head(i+1)
        pair_dict = {k: v for k, v in zip(pair_df.get_column("aid_x").to_list(), pair_df.get_column("aid_y").to_list())}
        trans_maps[f"time_wt10_pair{str(i)}"] = pair_dict

    return trans_maps

# %%
@noglobal(excepts=["cfg", "logger", "cache"])
def make_valid_cand():
    # データ読み込み
    week_sessions = pl.read_parquet(cfg.prep_dir + f"train_sessions_{cfg.valid_week}.parquet")
    week_sessions = week_sessions.select([
        pl.col("session").cast(pl.Int32),
        pl.col("aid").cast(pl.Int32),
        pl.col("ts"),
        pl.col("type")
        ])
    
    week_labels = pl.read_parquet(cfg.prep_dir + f"labels_{cfg.valid_week}.parquet")
    week_labels = week_labels.select([
        pl.col("session").cast(pl.Int32),
        pl.col("clicks_labels").cast(pl.Int32),
        pl.col("carts_labels"),
        pl.col("orders_labels")
        ])
    valid_sessions = week_sessions.get_column("session").unique().to_list()
    
    trans_map_cache_file = f"trans_maps_{cfg.valid_week}.pkl"
    trans_map_cache_path = cache.get_abspath(trans_map_cache_file)
    with open(trans_map_cache_path, "rb") as f:
        trans_maps = pickle.load(f)

    # validに使うsessionを絞る
    use_session_n = min(cfg.valid_session_n, len(valid_sessions))
    random.seed(cfg.seed)
    use_sessions = random.sample(valid_sessions, use_session_n)
    week_sessions = week_sessions.filter(pl.col("session").is_in(use_sessions))
    week_labels = week_labels.filter(pl.col("session").is_in(use_sessions))

    # 候補選出
    cand_df = make_cand_df(week_sessions, trans_maps=trans_maps)
    return cand_df, week_sessions, week_labels

# %%
logger.info("\n\nSTART\n\n")
cache_file = f"trans_maps_{cfg.valid_week}.pkl"
cache_path = cache.get_abspath(cache_file)

if cache.exists(cache_path):
    logger.info(f"[{cache_file}] cache exists. load cache and skip process.")
    with open(cache_path, "rb") as f:
        trans_maps = pickle.load(f)
else:
    trans_maps = get_trans_maps(cfg.valid_week)
    with open(cache_path, "wb") as f:
        pickle.dump(trans_maps, f)

cand_df, _, labels = make_valid_cand()

cand_df = cand_df.to_pandas()
labels = labels.to_pandas()
vl_pred_df = cand_df.groupby("session")["aid"].apply(list).reset_index()
session_n_max = cand_df["session"].value_counts().max()
session_n_mean = cand_df["session"].value_counts().mean()
session_n_median = cand_df["session"].value_counts().median()

score = evaluate(labels["clicks_labels"].tolist(),
                 labels["carts_labels"].tolist(),
                 labels["orders_labels"].tolist(),
                 vl_pred_df["aid"].tolist(),
                 vl_pred_df["aid"].tolist(),
                 vl_pred_df["aid"].tolist(),
                 session_n_max)

session_n_max = cand_df["session"].value_counts().max()
session_n_mean = cand_df["session"].value_counts().mean()
session_n_median = cand_df["session"].value_counts().median()
logger.info(f"session_n_max : {str(session_n_max)},  session_n_mean : {str(session_n_mean)},  session_n_median : {str(session_n_median)}")
logger.info(f"score : {str(score)}")
# Out:
# 0:00:00.262139
#
# START
#
#
# 0:26:31.127610 	 [add_candidate] repurchase : start
# 0:26:31.959630 	 [add_candidate] session_latest_time_wt_pair0 : start
# 0:26:32.792028 	 [add_candidate] session_latest_word2vec_pair0 : start
# 0:26:33.479962 	 [add_candidate] session_latest_pair0 : start
# 0:26:34.365216 	 [add_candidate] session_latest_type_wt_pair0 : start
# 0:26:35.016414 	 [add_candidate] session_latest_clicks2carts_pair0 : start
# 0:26:35.572871 	 [add_candidate] session_latest_clicks2orders_pair0 : start
# 0:26:36.052827 	 [add_candidate] session_latest_time_wt_pair1 : start
# 0:26:36.790451 	 [add_candidate] session_latest_word2vec_pair1 : start
# 0:26:37.502163 	 [add_candidate] session_latest_pair1 : start
# 0:26:38.341189 	 [add_candidate] session_latest_type_wt_pair1 : start
# 0:26:38.998653 	 [add_candidate] session_latest_clicks2carts_pair1 : start
# 0:26:39.552078 	 [add_candidate] session_latest_clicks2orders_pair1 : start
# 0:26:40.034269 	 [add_candidate] session_latest_time_wt_pair2 : start
# 0:26:40.719614 	 [add_candidate] session_latest_word2vec_pair2 : start
# 0:26:41.379060 	 [add_candidate] session_latest_pair2 : start
# 0:26:42.090404 	 [add_candidate] session_latest_type_wt_pair2 : start
# 0:26:42.740153 	 [add_candidate] session_latest_clicks2carts_pair2 : start
# 0:26:43.310939 	 [add_candidate] session_latest_clicks2orders_pair2 : start
# 0:26:43.780911 	 [add_candidate] session_latest_time_wt_pair3 : start
# 0:26:44.516093 	 [add_candidate] session_latest_word2vec_pair3 : start
# 0:26:45.163952 	 [add_candidate] session_latest_pair3 : start
# 0:26:46.331450 	 [add_candidate] session_latest_type_wt_pair3 : start
# 0:26:46.978660 	 [add_candidate] session_latest_clicks2carts_pair3 : start
# 0:26:47.537616 	 [add_candidate] session_latest_clicks2orders_pair3 : start
# 0:26:48.015229 	 [add_candidate] session_latest_time_wt_pair4 : start
# 0:26:48.730782 	 [add_candidate] session_latest_word2vec_pair4 : start
# 0:26:49.369022 	 [add_candidate] session_latest_pair4 : start
# 0:26:50.060215 	 [add_candidate] session_latest_type_wt_pair4 : start
# 0:26:50.704265 	 [add_candidate] session_latest_clicks2carts_pair4 : start
# 0:26:51.336333 	 [add_candidate] session_latest_clicks2orders_pair4 : start
# 0:26:51.799472 	 [add_candidate] session_latest_time_wt_pair5 : start
# 0:26:52.514560 	 [add_candidate] session_latest_word2vec_pair5 : start
# 0:26:53.150964 	 [add_candidate] session_latest_pair5 : start
# 0:26:53.861853 	 [add_candidate] session_latest_type_wt_pair5 : start
# 0:26:54.423167 	 [add_candidate] session_latest_clicks2carts_pair5 : start
# 0:26:54.899006 	 [add_candidate] session_latest_clicks2orders_pair5 : start
# 0:26:55.308115 	 [add_candidate] session_latest_time_wt_pair6 : start
# 0:26:55.953068 	 [add_candidate] session_latest_word2vec_pair6 : start
# 0:26:56.526411 	 [add_candidate] session_latest_pair6 : start
# 0:26:57.408779 	 [add_candidate] session_latest_type_wt_pair6 : start
# 0:26:58.005138 	 [add_candidate] session_latest_clicks2carts_pair6 : start
# 0:26:58.482706 	 [add_candidate] session_latest_clicks2orders_pair6 : start
# 0:26:58.901339 	 [add_candidate] session_latest_time_wt_pair7 : start
# 0:26:59.559073 	 [add_candidate] session_latest_word2vec_pair7 : start
# 0:27:00.147202 	 [add_candidate] session_latest_pair7 : start
# 0:27:00.749095 	 [add_candidate] session_latest_type_wt_pair7 : start
# 0:27:01.325910 	 [add_candidate] session_latest_clicks2carts_pair7 : start
# 0:27:01.821062 	 [add_candidate] session_latest_clicks2orders_pair7 : start
# 0:27:02.231291 	 [add_candidate] session_latest_time_wt_pair8 : start
# 0:27:02.897682 	 [add_candidate] session_latest_word2vec_pair8 : start
# 0:27:04.230084 	 [add_candidate] session_latest_pair8 : start
# 0:27:05.086597 	 [add_candidate] session_latest_type_wt_pair8 : start
# 0:27:05.710546 	 [add_candidate] session_latest_clicks2carts_pair8 : start
# 0:27:06.185053 	 [add_candidate] session_latest_clicks2orders_pair8 : start
# 0:27:06.585052 	 [add_candidate] session_latest_time_wt_pair9 : start
# 0:27:07.208156 	 [add_candidate] session_latest_word2vec_pair9 : start
# 0:27:07.775547 	 [add_candidate] session_latest_pair9 : start
# 0:27:08.500637 	 [add_candidate] session_latest_type_wt_pair9 : start
# 0:27:09.134115 	 [add_candidate] session_latest_clicks2carts_pair9 : start
# 0:27:09.611606 	 [add_candidate] session_latest_clicks2orders_pair9 : start
# 0:27:10.040872 	 [add_candidate] session_latest_time_wt_pair10 : start
# 0:27:10.678397 	 [add_candidate] session_latest_word2vec_pair10 : start
# 0:27:11.258240 	 [add_candidate] session_latest_pair10 : start
# 0:27:12.093433 	 [add_candidate] session_latest_type_wt_pair10 : start
# 0:27:12.673647 	 [add_candidate] session_latest_clicks2carts_pair10 : start
# 0:27:13.152672 	 [add_candidate] session_latest_clicks2orders_pair10 : start
# 0:27:13.566686 	 [add_candidate] session_latest_time_wt_pair11 : start
# 0:27:14.201980 	 [add_candidate] session_latest_word2vec_pair11 : start
# 0:27:14.766437 	 [add_candidate] session_latest_pair11 : start
# 0:27:15.507446 	 [add_candidate] session_latest_type_wt_pair11 : start
# 0:27:16.089533 	 [add_candidate] session_latest_clicks2carts_pair11 : start
# 0:27:16.571958 	 [add_candidate] session_latest_clicks2orders_pair11 : start
# 0:27:16.980767 	 [add_candidate] session_latest_time_wt_pair12 : start
# 0:27:17.616328 	 [add_candidate] session_latest_word2vec_pair12 : start
# 0:27:18.184372 	 [add_candidate] session_latest_pair12 : start
# 0:27:18.952101 	 [add_candidate] session_latest_type_wt_pair12 : start
# 0:27:19.588173 	 [add_candidate] session_latest_clicks2carts_pair12 : start
# 0:27:20.083264 	 [add_candidate] session_latest_clicks2orders_pair12 : start
# 0:27:20.514378 	 [add_candidate] session_latest_time_wt_pair13 : start
# 0:27:21.171982 	 [add_candidate] session_latest_word2vec_pair13 : start
# 0:27:21.738294 	 [add_candidate] session_latest_pair13 : start
# 0:27:22.350659 	 [add_candidate] session_latest_type_wt_pair13 : start
# 0:27:22.928202 	 [add_candidate] session_latest_clicks2carts_pair13 : start
# 0:27:23.417813 	 [add_candidate] session_latest_clicks2orders_pair13 : start
# 0:27:23.830164 	 [add_candidate] session_latest_time_wt_pair14 : start
# 0:27:24.450610 	 [add_candidate] session_latest_word2vec_pair14 : start
# 0:27:25.015332 	 [add_candidate] session_latest_pair14 : start
# 0:27:26.069150 	 [add_candidate] session_latest_type_wt_pair14 : start
# 0:27:26.724519 	 [add_candidate] session_latest_clicks2carts_pair14 : start
# 0:27:27.211394 	 [add_candidate] session_latest_clicks2orders_pair14 : start
# 0:27:27.607465 	 [add_candidate] session_latest_time_wt_pair15 : start
# 0:27:28.251391 	 [add_candidate] session_latest_word2vec_pair15 : start
# 0:27:28.816319 	 [add_candidate] session_latest_pair15 : start
# 0:27:29.422924 	 [add_candidate] session_latest_type_wt_pair15 : start
# 0:27:30.005357 	 [add_candidate] session_latest_clicks2carts_pair15 : start
# 0:27:30.519097 	 [add_candidate] session_latest_clicks2orders_pair15 : start
# 0:27:30.988381 	 [add_candidate] session_latest_time_wt_pair16 : start
# 0:27:31.625148 	 [add_candidate] session_latest_word2vec_pair16 : start
# 0:27:32.198720 	 [add_candidate] session_latest_pair16 : start
# 0:27:32.827721 	 [add_candidate] session_latest_type_wt_pair16 : start
# 0:27:33.431526 	 [add_candidate] session_latest_clicks2carts_pair16 : start
# 0:27:33.977240 	 [add_candidate] session_latest_clicks2orders_pair16 : start
# 0:27:34.375469 	 [add_candidate] session_latest_time_wt_pair17 : start
# 0:27:34.989998 	 [add_candidate] session_latest_word2vec_pair17 : start
# 0:27:35.563107 	 [add_candidate] session_latest_pair17 : start
# 0:27:36.227383 	 [add_candidate] session_latest_type_wt_pair17 : start
# 0:27:36.812981 	 [add_candidate] session_latest_clicks2carts_pair17 : start
# 0:27:37.300994 	 [add_candidate] session_latest_clicks2orders_pair17 : start
# 0:27:37.716088 	 [add_candidate] session_latest_time_wt_pair18 : start
# 0:27:38.286478 	 [add_candidate] session_latest_word2vec_pair18 : start
# 0:27:38.870836 	 [add_candidate] session_latest_pair18 : start
# 0:27:39.497540 	 [add_candidate] session_latest_type_wt_pair18 : start
# 0:27:40.083351 	 [add_candidate] session_latest_clicks2carts_pair18 : start
# 0:27:40.557544 	 [add_candidate] session_latest_clicks2orders_pair18 : start
# 0:27:40.972621 	 [add_candidate] session_latest_time_wt_pair19 : start
# 0:27:41.536386 	 [add_candidate] session_latest_word2vec_pair19 : start
# 0:27:42.121254 	 [add_candidate] session_latest_pair19 : start
# 0:27:42.764894 	 [add_candidate] session_latest_type_wt_pair19 : start
# 0:27:43.340729 	 [add_candidate] session_latest_clicks2carts_pair19 : start
# 0:27:43.850380 	 [add_candidate] session_latest_clicks2orders_pair19 : start
# 0:28:06.440593 	 session_n_max : 1277,  session_n_mean : 172.39559,  session_n_median : 93.0
# 0:28:06.441835 	 score : {'num_clicks': 97136, 'hit_clicks': 57651, 'num_carts': 43611, 'hit_carts': 20007, 'num_orders': 20109, 'hit_orders': 13335, 'recall_clicks': '0.593508', 'recall_carts': '0.458760', 'recall_orders': '0.663136', 'w_recall_clicks': '0.059351', 'w_recall_carts': '0.137628', 'w_recall_orders': '0.397882', 'score': '0.594860'}
