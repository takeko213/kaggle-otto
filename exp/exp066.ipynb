# %% [markdown]
# # exp066
# exp064 lr0.01

# %%
import os
import sys
import traceback
import gc
import random
import pickle
import pathlib
import subprocess
from dataclasses import dataclass
from dotenv import load_dotenv
load_dotenv
sys.path.append(os.getenv('UTILS_PATH'))
from tqdm import tqdm
import multiprocessing
import inspect

import pandas as pd
import polars as pl
import numpy as np
import itertools
import cudf
import lightgbm as lgb
import matplotlib.pyplot as plt
import seaborn as sns
import line_notify
import my_logger
from noglobal import noglobal

# %% [markdown]
# # 設定

# %%
@dataclass
class Cfg:
    loglevel = "INFO"
    exp_name = "exp066"
    run_inf = True
    seed = 42
    k = 20
    cand_n = 15
    negative_sample = 1
    train_chunk_n_dict = {"clicks":2, "carts":1, "orders":1}
    test_chunk_n = 3
    type2id = {"clicks":0, "carts":1, "orders":2}
    id2type = {0:"clicks", 1:"carts", 2:"orders"}
    train_week = "week3"
    valid_week = "week4"
    valid_session_n = 100_000
    input_dir = os.getenv('INPUT_DIR')
    output_dir = os.getenv('OUTPUT_DIR')
    prep_dir = os.getenv("PREP_DIR")

    clicks_params = {'objective': 'binary', 'boosting': 'gbdt', 'learning_rate': 0.01, 'metric': 'binary_logloss', 'seed': 42, 'feature_pre_filter': False, 'lambda_l1': 5.485903737168179, 'lambda_l2': 0.005594683492536064, 'num_leaves': 79, 'feature_fraction': 0.552, 'bagging_fraction': 0.9295272232672004, 'bagging_freq': 2, 'min_child_samples': 10}
    carts_params = {'objective': 'binary', 'boosting': 'gbdt', 'learning_rate': 0.01, 'metric': 'binary_logloss', 'seed': 42, 'feature_pre_filter': False, 'lambda_l1': 8.709050252544463, 'lambda_l2': 0.06935262036337767, 'num_leaves': 252, 'feature_fraction': 0.4, 'bagging_fraction': 1.0, 'bagging_freq': 0, 'min_child_samples': 5}
    orders_params = {'objective': 'binary', 'boosting': 'gbdt', 'learning_rate': 0.01, 'metric': 'binary_logloss', 'seed': 42, 'feature_pre_filter': False, 'lambda_l1': 9.356310279757256, 'lambda_l2': 1.3120983078968551e-08, 'num_leaves': 174, 'feature_fraction': 0.5, 'bagging_fraction': 1.0, 'bagging_freq': 0, 'min_child_samples': 20}

cfg = Cfg()
os.makedirs(os.path.join(cfg.output_dir, cfg.exp_name), exist_ok=True)
os.makedirs(os.path.join(cfg.output_dir, cfg.exp_name, "cache"), exist_ok=True)
random.seed(cfg.seed)

logger = my_logger.init_logger(cfg.exp_name)

# %%
class Cache:
    @noglobal(excepts=["cfg", "logger"])
    def __init__(self):
        self.cache_dir = (os.path.join(cfg.output_dir, cfg.exp_name, "cache"))
        self.cache_dir_path = pathlib.Path(self.cache_dir)
        self.caches = list(self.cache_dir_path.glob("*"))

    def update(self):
        self.caches = list(self.cache_dir_path.glob("*"))

    @noglobal(excepts=["cfg", "logger"])
    def get_abspath(self, filename):
        return (os.path.join(self.cache_dir, filename))
    
    @noglobal(excepts=["cfg", "logger"])
    def exists(self, path):
        self.update()
        return len([str(c) for c in self.caches if path == str(c)]) > 0

cache = Cache()

# %%
def reduce_mem_usage(df):
    """ iterate through all the columns of a dataframe and modify the data type
        to reduce memory usage.        
    """
    start_mem = df.memory_usage().sum() / 1024**2
    print('Memory usage of dataframe is {:.2f} MB'.format(start_mem))
    
    for col in df.columns:
        col_type = df[col].dtype
        
        if col_type != object:
            c_min = df[col].min()
            c_max = df[col].max()
            if str(col_type)[:3] == 'int':
                if c_min > np.iinfo(np.int8).min and c_max < np.iinfo(np.int8).max:
                    df[col] = df[col].astype(np.int8)
                elif c_min > np.iinfo(np.int16).min and c_max < np.iinfo(np.int16).max:
                    df[col] = df[col].astype(np.int16)
                elif c_min > np.iinfo(np.int32).min and c_max < np.iinfo(np.int32).max:
                    df[col] = df[col].astype(np.int32)
                elif c_min > np.iinfo(np.int64).min and c_max < np.iinfo(np.int64).max:
                    df[col] = df[col].astype(np.int64)  
            else:
                if c_min > np.finfo(np.float16).min and c_max < np.finfo(np.float16).max:
                    df[col] = df[col].astype(np.float32)
                elif c_min > np.finfo(np.float32).min and c_max < np.finfo(np.float32).max:
                    df[col] = df[col].astype(np.float32)
                else:
                    df[col] = df[col].astype(np.float64)
        else:
            df[col] = df[col].astype('category')

    end_mem = df.memory_usage().sum() / 1024**2
    print('Memory usage after optimization is: {:.2f} MB'.format(end_mem))
    print('Decreased by {:.1f}%'.format(100 * (start_mem - end_mem) / start_mem))
    
    return df

# %%
@noglobal(excepts=["cfg", "logger"])
def evaluate(clicks_labels, carts_labels, orders_labels, 
             clicks_preds, carts_preds, orders_preds, k=20):

    num_clicks = 0
    num_carts = 0
    num_orders = 0
    hit_clicks = 0
    hit_carts = 0
    hit_orders = 0

    for i in range(len(clicks_labels)):
        clicks_label = clicks_labels[i]
        carts_label = carts_labels[i]
        orders_label = orders_labels[i]
        clicks_pred = clicks_preds[i]
        carts_pred = carts_preds[i]
        orders_pred = orders_preds[i]

        if type(clicks_pred) == list:
            clicks_pred = clicks_pred[:k]
        else:
            clicks_pred = []
        if type(carts_pred) == list:
            carts_pred = carts_pred[:k]
        else:
            carts_pred = []    
        if type(orders_pred) == list:
            orders_pred = orders_pred[:k]
        else:
            orders_pred = []

        if not np.isnan(clicks_label):
            num_clicks += 1
            hit_clicks += int(clicks_label in clicks_pred)

        if type(carts_label) == np.ndarray:
            num_carts += min(len(carts_label), k)
            hit_carts += len(set(carts_pred) & set(carts_label))
            
        if type(orders_label) == np.ndarray:
            num_orders += min(len(orders_label), k)
            hit_orders += len(set(orders_pred) & set(orders_label))


    recall_clicks = hit_clicks / num_clicks
    recall_carts = hit_carts / num_carts
    recall_orders = hit_orders / num_orders
    w_recall_clicks = recall_clicks * 0.10
    w_recall_carts = recall_carts * 0.30
    w_recall_orders = recall_orders * 0.60
    score = w_recall_clicks + w_recall_carts + w_recall_orders

    results = {}
    results["num_clicks"] = num_clicks
    results["hit_clicks"] = hit_clicks
    results["num_carts"] = num_carts
    results["hit_carts"] = hit_carts
    results["num_orders"] = num_orders
    results["hit_orders"] = hit_orders
    results["recall_clicks"] = format(recall_clicks, ".6f")
    results["recall_carts"] = format(recall_carts, ".6f")
    results["recall_orders"] = format(recall_orders, ".6f")
    results["w_recall_clicks"] = format(w_recall_clicks, ".6f")
    results["w_recall_carts"] = format(w_recall_carts, ".6f")
    results["w_recall_orders"] = format(w_recall_orders, ".6f")
    results["score"] = format(score, ".6f")

    return results

# %%
class Candidate:
    @noglobal(excepts=["cfg", "logger"])
    def __init__(self, pl_df, week):
        self.df = cudf.from_pandas(pl_df.to_pandas())
        self.sessions = []
        self.aids = []
        self.week = week

    @noglobal(excepts=["cfg", "logger"])
    def add(self, strategy, name, usetypes=['clicks', 'carts', 'orders'], trans_map=None, k=20):
        logger.info(f"[add_candidate] {name} : start")
        candidate_df = self.df[self.df["type"].isin(usetypes)].copy()
        
        if strategy == "session_frequent":
            candidate_df = self._session_frequent(candidate_df, k)
        elif strategy == "session_latest":
            candidate_df = self._session_latest(candidate_df, k)
        elif strategy == "total_frequent":
            candidate_df = self._total_frequent(candidate_df, k)
        elif strategy == "repurchase":
            candidate_df = self._repurchase(candidate_df)
        elif strategy == "clstr_freq":
            candidate_df = self._clstr_freq(candidate_df, k)
        
        if trans_map is not None:
            candidate_df["aid"] = candidate_df["aid"].map(trans_map).astype("int32")
            candidate_df = candidate_df.dropna(subset=["aid"])
        candidate_df = candidate_df.drop_duplicates(subset=["session", "aid"])
        
        self.sessions.extend(candidate_df["session"].to_arrow().to_pylist())
        self.aids.extend(candidate_df["aid"].to_arrow().to_pylist())

    @noglobal(excepts=["cfg", "logger"])
    def get_dataframe(self):
        cand_df = pl.DataFrame([
            pl.Series("session", self.sessions, pl.Int32),
            pl.Series("aid", self.aids, pl.Int32)
            ]).unique()
        return cand_df

    @noglobal(excepts=["cfg", "logger"])
    def _repurchase(self, candidate_df):
        return candidate_df[["session", "aid"]].drop_duplicates()

    @noglobal(excepts=["cfg", "logger"])
    def _clstr_freq(self, candidate_df, k):
        if self.week is None:
            session_clstr = pd.read_parquet(cfg.prep_dir + "w2v_session_cluster_c10000.parquet")
            clstr_freq = pd.read_parquet(cfg.prep_dir + "w2v_cluster_freq_c10000.parquet")
        else:
            session_clstr = pd.read_parquet(cfg.prep_dir + f"w2v_session_cluster_c10000_{self.week}.parquet")
            clstr_freq = pd.read_parquet(cfg.prep_dir + f"w2v_cluster_freq_c10000_{self.week}.parquet")
        session_clstr = {session:clstr for session, clstr in zip(session_clstr["session"].tolist(), session_clstr["clstr"].tolist())}
        clstr_freq = clstr_freq[clstr_freq["rank"]<k]
        clstr_freq = clstr_freq.groupby("clstr")["aid"].apply(list).to_dict()

        sessions = []
        aids = []
        for session in candidate_df["session"].to_pandas().unique():
            clstr = session_clstr[session]
            most_freq_aids = clstr_freq[clstr]
            aids.extend(most_freq_aids)
            sessions.extend([session for _ in range(len(most_freq_aids))])
        candidate_df = cudf.DataFrame({"session": sessions, "aid": aids})
        return candidate_df

    @noglobal(excepts=["cfg", "logger"])
    def _session_frequent(self, candidate_df, k):
        candidate_df = candidate_df.groupby(["session", "aid"])["ts"].count().reset_index()
        candidate_df.columns = ["session", "aid", "aid_count"]
        candidate_df = candidate_df.sort_values(["session", "aid_count", "aid"], ascending=(True, False, True))
        candidate_df = candidate_df[candidate_df.groupby("session")["aid_count"].cumcount() < k].copy()
        candidate_df = candidate_df[["session", "aid"]].copy()
        return candidate_df

    @noglobal(excepts=["cfg", "logger"])
    def _session_latest(self, candidate_df, k):
        candidate_df = candidate_df.sort_values(["session", "ts"], ascending=(True, False)).drop_duplicates(subset=["session", "aid"])
        candidate_df = candidate_df.sort_values(["session", "ts"], ascending=(True, False))[candidate_df.groupby("session")["ts"].cumcount() < k].copy()
        candidate_df = candidate_df[["session", "aid"]].copy()
        return candidate_df

    @noglobal(excepts=["cfg", "logger"])
    def _total_frequent(self, candidate_df, k):
        candidate_df = candidate_df.groupby("aid")["ts"].count().reset_index()
        candidate_df.columns = ["aid", "aid_count"]
        topk_freq_aids = candidate_df.sort_values("aid_count", ascending=False)["aid"].to_arrow().to_pylist()[:k]
        sessions = []
        aids = []
        for session, aid in itertools.product(self.target_sessions, topk_freq_aids):
            sessions.append(session)
            aids.append(aid)
        candidate_df = cudf.DataFrame({"session": sessions, "aid": aids})
        return candidate_df

# %%
@noglobal(excepts=["cfg", "logger"])
def add_labels(df, labels, type_):
    if type_ == "clicks":
        type_labels = (labels.select([pl.col("session"), 
                                      pl.col(f"{type_}_labels").cast(pl.Int32).alias("aid"),
                                      pl.lit(1).alias("labels")])
        )
    else:
        type_labels = (labels.explode(f"{type_}_labels")
                             .select([pl.col("session"), 
                                      pl.col(f"{type_}_labels").cast(pl.Int32).alias("aid"),
                                      pl.lit(1).alias("labels")])
        )

    df = (df.join(type_labels, on=["session", "aid"], how="left")
            .select([pl.exclude("labels"),
                     pl.col("labels").fill_null(0)])
    )        
    return df

# %%
@noglobal(excepts=["cfg", "logger"])
def add_ground_truth_candidate(df, labels, type_):
    gt = labels[["session", f"{type_}_labels"]].dropna().copy()
    gt.columns = ["session", "aid"]
    gt = gt.explode("aid")
    df = pd.concat([df, gt])
    df = df.drop_duplicates()
    return df

# %%
@noglobal(excepts=["cfg", "logger"])
def under_sampling(df, label_col):
    cfg = Cfg()
    pos_df = df.filter(pl.col(label_col)==1)
    neg_df = df.filter(pl.col(label_col)==0)
    pos_n = pos_df.shape[0]
    return pl.concat([pos_df, neg_df.sample(pos_n * cfg.negative_sample, seed=cfg.seed)])

# %%
class Features:
    @noglobal(excepts=["cfg", "logger"])
    def __init__(self, sessions, candidate, week):
        self.sessions = cudf.from_pandas(sessions.to_pandas())
        self.output = candidate
        self.type_dict = cfg.type2id
        self.week = week
        self.latest_aid_n = 10

    @noglobal(excepts=["cfg", "logger"])
    def add_features(self):
        # self._prep()
        self._session_cnt()
        self._session_aid_nunique()
        self._session_last_type()
        self._aid_cnt()
        self._all_times_aid_features()
        self._w2v_vectors()
        self._relative_ts()
        self._add_aid_latest()
        self._co_visit_rank("co_visitation_matrix")
        self._co_visit_rank("co_visitation_matrix_time_weighted", "wt")
        self._co_visit_rank("co_visitation_matrix_type_weighted", "wt")
        self._co_visit_rank("co_visitation_matrix_clicks2carts")
        self._co_visit_rank("co_visitation_matrix_clicks2orders")
        self._latest_aid_w2v_sims()
        self._drop_aid_latest()
        self._clstr_rank()
        # self._session_mean_ts()
        # self._aid_mean_ts()
        # self._aid_cnt_ratio_at_session_last()
        # self.output = self.output.drop(columns=["session_last_day"]) # 日時はtrainセット内のみで有効なので削除

    @noglobal(excepts=["cfg", "logger"])
    def _prep(self):
        logger.info("[features] prep : start")
        # ts関連の前処理
        self.sessions["relative_ts"] = self.sessions["ts"] - self.sessions["ts"].min()
        self.sessions["dt"] = cudf.to_datetime(self.sessions["ts"], unit="ms")
        self.sessions["hour"] = self.sessions["dt"].dt.hour
        self.sessions["week"] = self.sessions["dt"].dt.dayofweek
        self.sessions["day"] = self.sessions["dt"].dt.day
        
    @noglobal(excepts=["cfg", "logger"])
    def _session_cnt(self):
        logger.info("[features] session_cnt : start")
        agg_df = self.sessions.groupby(["session", "type"])["ts"].count().reset_index().rename(columns={"ts": "cnt"})
        # session_total_cnt
        features = agg_df.groupby("session")["cnt"].sum().reset_index().rename(columns={"cnt": "session_total_cnt"})
        self.output = self.output.join(pl.from_pandas(features.to_pandas()), on=["session"], how="left")
        self.output = self.output.select([pl.exclude("session_total_cnt"), pl.col("session_total_cnt").fill_null(0)])
        # session_{type}_cnt
        for type_ in ["clicks", "carts", "orders"]:
            col_name = f"session_{type_}_cnt"
            features = agg_df[agg_df["type"]==type_].copy()
            features = features.rename(columns={"cnt": col_name})
            features = features[["session", col_name]].copy()
            self.output = self.output.join(pl.from_pandas(features.to_pandas()), on=["session"], how="left")
            self.output = self.output.select([pl.exclude(col_name), pl.col(col_name).fill_null(0)])
        
    @noglobal(excepts=["cfg", "logger"])
    def _session_aid_nunique(self):
        logger.info("[features] session_aid_nunique : start")
        features = self.sessions.groupby("session")["aid"].nunique().reset_index().rename(columns={"aid": "session_aid_nunique"})
        self.output = self.output.join(pl.from_pandas(features.to_pandas()), on=["session"], how="left")
        self.output = self.output.select([pl.exclude("session_aid_nunique"), pl.col("session_aid_nunique").fill_null(0)])
        
    @noglobal(excepts=["cfg", "logger"])
    def _session_last_type(self):
        logger.info("[features] session_last_type : start")
        features = self.sessions.groupby("session").nth(-1).reset_index()[["session", "type"]]
        features = features.rename(columns={"type": "session_last_type"})
        features["session_last_type"] = features["session_last_type"].map(self.type_dict)
        self.output = self.output.join(pl.from_pandas(features.to_pandas()), on=["session"], how="left")
        
    @noglobal(excepts=["cfg", "logger"])
    def _session_last_dt(self):
        logger.info("[features] session_last_dt : start")
        features = self.sessions.groupby("session").nth(-1).reset_index()[["session", "relative_ts", "week", "day", "hour"]]
        features.columns = ["session", "session_last_ts", "session_last_week", "session_last_day", "session_last_hour"]
        self.output = self.output.join(pl.from_pandas(features.to_pandas()), on=["session"], how="left")
        
    @noglobal(excepts=["cfg", "logger"])
    def _session_mean_ts(self):
        logger.info("[features] session_mean_ts : start")
        features = self.sessions.groupby("session")["relative_ts"].mean().reset_index().rename(columns={"relative_ts": "session_mean_ts"})
        self.output = self.output.join(pl.from_pandas(features.to_pandas()), on=["session"], how="left")
        
    @noglobal(excepts=["cfg", "logger"])
    def _aid_mean_ts(self):
        logger.info("[features] aid_mean_ts : start")
        features = self.sessions.groupby("aid")["relative_ts"].mean().reset_index().rename(columns={"relative_ts": "aid_mean_ts"})
        self.output = self.output.join(pl.from_pandas(features.to_pandas()), on=["aid"], how="left")
       
    @noglobal(excepts=["cfg", "logger"])
    def _aid_session_nunique(self):
        logger.info("[features] aid_session_unique : start")
        features = self.sessions.groupby("aid")["session"].nunique().reset_index().rename(columns={"session": "aid_session_nunique"})
        self.output = self.output.join(pl.from_pandas(features.to_pandas()), on=["aid"], how="left")

    @noglobal(excepts=["cfg", "logger"]) 
    def _aid_cnt_ratio_at_session_last(self):
        logger.info("[features] aid_cnt_ratio_atsession_last : start")
        for dt_ in ["week", "day", "hour"]:
            features = self.sessions[["aid", dt_]].copy()
            features["total_cnt"] = features.groupby(dt_)["aid"].transform("count")
            features = features.groupby(["aid", dt_])["total_cnt"].agg(["count", "max"]).reset_index()
            features[f"aid_cnt_ratio_at_session_last_{dt_}"] = features["count"] / features["max"]
            features = features.rename(columns={dt_: f"session_last_{dt_}"})
            self.output = self.output.join(pl.from_pandas(features[["aid", f"session_last_{dt_}", f"aid_cnt_ratio_at_session_last_{dt_}"]].to_pandas()), on=["aid", f"session_last_{dt_}"], how="left")
            self.output = self.output.select([pl.exclude(f"aid_cnt_ratio_at_session_last_{dt_}"), pl.col(f"aid_cnt_ratio_at_session_last_{dt_}").fill_null(0)])
        
    @noglobal(excepts=["cfg", "logger"])
    def _aid_cnt(self):
        logger.info("[features] aid_cnt : start")
        agg_df = self.sessions.groupby(["session", "aid", "type"])["ts"].count().reset_index().rename(columns={"ts": "cnt"})

        # aid_total_cnt
        features = agg_df.groupby(["session", "aid"])["cnt"].sum().reset_index().rename(columns={"cnt": "aid_total_cnt"})
        self.output = self.output.join(pl.from_pandas(features.to_pandas()), on=["session", "aid"], how="left")
        self.output = self.output.select([pl.exclude(f"aid_total_cnt"), pl.col(f"aid_total_cnt").fill_null(0)])

        # aid_{type}_cnt
        for type_ in ["clicks", "carts", "orders"]:
            col_name = f"aid_{type_}_cnt"
            logger.info(f"[features] {col_name} : start")
            features = agg_df[agg_df["type"]==type_].copy()
            features = features.rename(columns={"cnt": col_name})
            features = features[["session", "aid", col_name]].copy()
            self.output = self.output.join(pl.from_pandas(features.to_pandas()), on=["session", "aid"], how="left")
            self.output = self.output.select([pl.exclude(col_name), pl.col(col_name).fill_null(0)])

    @noglobal(excepts=["cfg", "logger"])
    def _all_times_aid_features(self):
        feats = ["all_times_aid_freq",
                 "all_times_aid_clicks_freq",
                 "all_times_aid_carts_freq",
                 "all_times_aid_orders_freq",
                 "all_times_aid_session_freq",
                 "all_times_aid_session_clicks_freq",
                 "all_times_aid_session_carts_freq",
                 "all_times_aid_session_orders_freq",
                 "all_times_aid_carts_ratio_with_clicks",
                 "all_times_aid_orders_ratio_with_clicks",
                 "all_times_aid_date_std",
                 "all_times_aid_hour_std",
                 "all_times_aid_day_of_week_std"]
        
        for feat in feats:
            logger.info(f"[features] {feat} : start")
            if self.week is None:
                with open(cfg.prep_dir + f"{feat}.pkl", "rb") as f:
                    feat_map = pickle.load(f)
            else:
                with open(cfg.prep_dir + f"{feat}_{self.week}.pkl", "rb") as f:
                    feat_map = pickle.load(f)

            feat_df = pl.DataFrame(
                [
                    pl.Series("aid", feat_map.keys(), dtype=pl.Int32),
                    pl.Series(feat, feat_map.values())
                ]
            )
            self.output = self.output.join(feat_df, on="aid", how="left")

    @noglobal(excepts=["cfg", "logger"])
    def _w2v_vectors(self):
        logger.info(f"[features] w2v_vectors : start")
        w2v_vecs = pl.read_parquet(cfg.prep_dir + "w2v_vector_n5.parquet")
        w2v_vecs = w2v_vecs.select(
            [
                pl.exclude("aid"),
                pl.col("aid").cast(pl.Int32)
            ]
        )
        self.output = self.output.join(w2v_vecs, on="aid", how="left")

    @noglobal(excepts=["cfg", "logger"])
    def _relative_ts(self):
        logger.info(f"[features] relative_ts : start")
        features = self.sessions.sort_values(["session", "ts"]).drop_duplicates(subset=["session", "aid"], keep="last")
        features["relative_ts_in_session"] = features.groupby("session")["ts"].transform("max") - features["ts"]
        features = features.sort_values(["session", "ts"], ascending=(True, False)).reset_index(drop=True)
        features["ts_rank_in_session"] = features.groupby("session").cumcount()
        features = features[["session", "aid", "relative_ts_in_session", "ts_rank_in_session"]]
        self.output = self.output.join(pl.from_pandas(features.to_pandas()), on=["session", "aid"], how="left")

    @noglobal(excepts=["cfg", "logger"])
    def _add_aid_latest(self):
        sorted_df = self.sessions.sort_values(["session", "ts"], ascending=(True, False), ignore_index=True)
        for i in range(self.latest_aid_n):
            latest_aid = sorted_df.groupby("session").nth(i)["aid"].reset_index().rename(columns={"aid": f"aid_latest{i}"})
            latest_aid[f"aid_latest{i}"] = latest_aid[f"aid_latest{i}"].astype("int32")
            self.output = self.output.join(pl.from_pandas(latest_aid.to_pandas()), on="session", how="left")
            self.output = self.output.select([pl.exclude(f"aid_latest{i}"), pl.col(f"aid_latest{i}").fill_null(-1)])
    
    @noglobal(excepts=["cfg", "logger"])
    def _drop_aid_latest(self):
        drop_cols = [f"aid_latest{str(i)}" for i in range(self.latest_aid_n)]
        self.output = self.output.select(pl.exclude(drop_cols))

    @noglobal(excepts=["cfg", "logger"])
    def _co_visit_rank(self, co_visit_name, wt_col="cnt"):
        logger.info(f"[features] co_visit_rank({co_visit_name}) : start")
        if self.week is None:
            co_visit_df = pl.read_parquet(cfg.prep_dir + f"{co_visit_name}.parquet")
        else:
            co_visit_df = pl.read_parquet(cfg.prep_dir + f"{co_visit_name}_{self.week}.parquet")

        co_visit_df = co_visit_df.select(
            [
                pl.col("aid_x").cast(pl.Int32),
                pl.col("aid_y").cast(pl.Int32),
                pl.col("rank").cast(pl.Int32)
            ]
        )

        for i in range(self.latest_aid_n):
            col_name = f"{co_visit_name}_lt{i}"
            logger.info(f"[features] co_visit_rank({col_name}) : start")
            self.output = self.output.join(co_visit_df, left_on=[f"aid_latest{i}", "aid"], right_on=["aid_x", "aid_y"], how="left")
            self.output = self.output.select([pl.exclude("rank"), pl.col("rank").fill_null(-1).alias(col_name)])

    @noglobal(excepts=["cfg", "logger"])
    def _clstr_rank(self):
        if self.week is None:
            session_clstr = pl.read_parquet(cfg.prep_dir + "w2v_session_cluster_c10000.parquet").select([pl.col("session").cast(pl.Int32), pl.col("clstr").cast(pl.Int32)])
            clstr_freq = pl.read_parquet(cfg.prep_dir + "w2v_cluster_freq_c10000.parquet").select([pl.col("clstr").cast(pl.Int32), pl.col("aid").cast(pl.Int32), pl.col("rank").cast(pl.Int32).alias("clstr_freq_rank")])
        else:
            session_clstr = pl.read_parquet(cfg.prep_dir + f"w2v_session_cluster_c10000_{self.week}.parquet").select([pl.col("session").cast(pl.Int32), pl.col("clstr").cast(pl.Int32)])
            clstr_freq = pl.read_parquet(cfg.prep_dir + f"w2v_cluster_freq_c10000_{self.week}.parquet").select([pl.col("clstr").cast(pl.Int32), pl.col("aid").cast(pl.Int32), pl.col("rank").cast(pl.Int32).alias("clstr_freq_rank")])

        self.output = self.output.join(session_clstr, on="session", how="left").join(clstr_freq, on=["clstr", "aid"], how="left")
        self.output = self.output.select(pl.exclude("clstr"))

    @noglobal(excepts=["cfg", "logger"])
    def _latest_aid_w2v_sims(self, vec_n=50):
        logger.info("[features] latest_aid_w2v_sims : start")
        w2v_vecs = pd.read_parquet(cfg.prep_dir + f"w2v_vector_n{vec_n}.parquet")
        w2v_cols = [f"w2v_{i}" for i in range(vec_n)]
        w2v_dict = {aid:vecs for aid, vecs in zip(w2v_vecs["aid"].tolist(), w2v_vecs[w2v_cols].values)}

        for i in range(self.latest_aid_n):
            sims = []
            for aid, latest_aid in tqdm(zip(self.output.get_column("aid").to_list(), self.output.get_column(f"aid_latest{i}").to_list()), total=len(self.output)):
                if latest_aid == -1:
                    sims.append(-1)
                else:
                    aid_vecs = w2v_dict[aid]
                    latest_aid_vecs = w2v_dict[latest_aid]
                    sim = np.dot(aid_vecs, latest_aid_vecs) / (np.linalg.norm(aid_vecs)*np.linalg.norm(latest_aid_vecs))
                    sims.append(sim)
            self.output = self.output.with_column(pl.Series(sims, dtype=pl.Float32).alias(f"w2v_sim_lt{i}"))

# %%
@noglobal(excepts=["cfg", "logger"])
def add_features(sessions, cand_df, week=None):
    feat = Features(sessions, cand_df, week)
    feat.add_features()
    return feat.output

# %%
@noglobal(excepts=["cfg", "logger"])
def make_cand_df(sessions, week, trans_maps=None):
    cand = Candidate(sessions, week)
    cand.add(strategy="repurchase", name="repurchase")
    cand.add(strategy="clstr_freq", name="clstr_freq", k=30)
    #cand.add(strategy="session_frequent", name="session_frequent", k=15)
    #cand.add(strategy="session_latest", name="session_latest", k=30)
    
    for i in range(20):
        cand.add(strategy="session_latest", trans_map=trans_maps[f"time_wt_pair{str(i)}"], name=f"session_latest_time_wt_pair{str(i)}", k=15)
        cand.add(strategy="session_latest", trans_map=trans_maps[f"word2vec_pair{str(i)}"], name=f"session_latest_word2vec_pair{str(i)}", k=15)
        cand.add(strategy="session_latest", trans_map=trans_maps[f"pair{str(i)}"], name=f"session_latest_pair{str(i)}", k=15)
        cand.add(strategy="session_latest", trans_map=trans_maps[f"type_wt_pair{str(i)}"], name=f"session_latest_type_wt_pair{str(i)}", k=15)
        cand.add(strategy="session_latest", trans_map=trans_maps[f"clicks2carts_pair{str(i)}"], name=f"session_latest_clicks2carts_pair{str(i)}", k=15)
        cand.add(strategy="session_latest", trans_map=trans_maps[f"clicks2orders_pair{str(i)}"], name=f"session_latest_clicks2orders_pair{str(i)}", k=15)

    return cand.get_dataframe()

# %%
@noglobal(excepts=["cfg", "logger"])
def get_pair_df(name, wt_col, week):
    if week is not None:
        name = f"{name}_{week}"
    return pl.read_parquet(cfg.prep_dir + f"{name}.parquet").sort(wt_col, reverse=True)

@noglobal(excepts=["cfg", "logger"])
def get_trans_maps(week=None):
    """
    aidを別のaidに置き換えるmapping辞書を取得する
    """
    trans_maps = {}

    pair_df_org = get_pair_df("co_visitation_matrix", "cnt", week)
    for i in range(20):
        pair_df = pair_df_org.groupby("aid_x").head(i+1)
        pair_dict = {k: v for k, v in zip(pair_df.get_column("aid_x").to_list(), pair_df.get_column("aid_y").to_list())}
        trans_maps[f"pair{str(i)}"] = pair_dict
    
    pair_df_org = get_pair_df("co_visitation_matrix_time_weighted", "wt", week)
    for i in range(20):
        pair_df = pair_df_org.groupby("aid_x").head(i+1)
        pair_dict = {k: v for k, v in zip(pair_df.get_column("aid_x").to_list(), pair_df.get_column("aid_y").to_list())}
        trans_maps[f"time_wt_pair{str(i)}"] = pair_dict

    pair_df_org = get_pair_df("co_visitation_matrix_type_weighted", "wt", week)
    for i in range(20):
        pair_df = pair_df_org.groupby("aid_x").head(i+1)
        pair_dict = {k: v for k, v in zip(pair_df.get_column("aid_x").to_list(), pair_df.get_column("aid_y").to_list())}
        trans_maps[f"type_wt_pair{str(i)}"] = pair_dict

    pair_df_org = get_pair_df("co_visitation_matrix_clicks2carts", "cnt", week)
    for i in range(20):
        pair_df = pair_df_org.groupby("aid_x").head(i+1)
        pair_dict = {k: v for k, v in zip(pair_df.get_column("aid_x").to_list(), pair_df.get_column("aid_y").to_list())}
        trans_maps[f"clicks2carts_pair{str(i)}"] = pair_dict

    pair_df_org = get_pair_df("co_visitation_matrix_clicks2orders", "cnt", week)
    for i in range(20):
        pair_df = pair_df_org.groupby("aid_x").head(i+1)
        pair_dict = {k: v for k, v in zip(pair_df.get_column("aid_x").to_list(), pair_df.get_column("aid_y").to_list())}
        trans_maps[f"clicks2orders_pair{str(i)}"] = pair_dict

    pair_df_org = get_pair_df("word2vec_similar", "sim", None)
    for i in range(20):
        pair_df = pair_df = pair_df_org.groupby("aid_x").head(i+1)
        pair_dict = {k: v for k, v in zip(pair_df.get_column("aid_x").to_list(), pair_df.get_column("aid_y").to_list())}
        trans_maps[f"word2vec_pair{str(i)}"] = pair_dict

    return trans_maps

# %%
@noglobal(excepts=["cfg", "logger", "cache"])
def make_train_data(type_):
    train_chunk_n = cfg.train_chunk_n_dict[type_]
    
    # データ読み込み
    week_sessions = pl.read_parquet(cfg.prep_dir + f"train_sessions_{cfg.train_week}.parquet")
    week_sessions = week_sessions.select([
        pl.col("session").cast(pl.Int32),
        pl.col("aid").cast(pl.Int32),
        pl.col("ts"),
        pl.col("type")
        ])
    
    week_labels = pl.read_parquet(cfg.prep_dir + f"labels_{cfg.train_week}.parquet")
    week_labels = (week_labels.select([
        pl.col("session").cast(pl.Int32),
        pl.col("clicks_labels").cast(pl.Int32),
        pl.col("carts_labels"),
        pl.col("orders_labels")])
        .filter(pl.col(f"{type_}_labels").is_not_null())
    )
    sessions_lists = np.array_split(week_labels.get_column("session").unique().to_list(), train_chunk_n)

    # cand作成
    cand_dfs = []
    cache_file = f"{type_}_train_cand.parquet"
    cache_path = cache.get_abspath(cache_file)
    if cache.exists(cache_path):
        logger.info(f"[{cache_file}] cache exists. read cache and skip process.")
        cand_df = pl.read_parquet(cache_path)
    else:
        train_chunk_n = cfg.train_chunk_n_dict[type_]
        trans_map_cache_file = f"trans_maps_{cfg.train_week}.pkl"
        trans_map_cache_path = cache.get_abspath(trans_map_cache_file)
        with open(trans_map_cache_path, "rb") as f:
            trans_maps = pickle.load(f)
        
        for chunk in range(train_chunk_n):
            use_sessions = list(sessions_lists[chunk])    
            # 候補選出
            week_sessions_chunk = week_sessions.filter(pl.col("session").is_in(use_sessions))
            cand_df_chunk = make_cand_df(week_sessions_chunk, cfg.train_week, trans_maps=trans_maps)

            # candラベル付け・サンプリング
            week_labels_chunk = week_labels.filter(pl.col("session").is_in(use_sessions))
            cand_df_chunk = add_labels(cand_df_chunk, week_labels_chunk, type_)
            cand_df_chunk = under_sampling(cand_df_chunk, "labels")
            cand_dfs.append(cand_df_chunk)
            del cand_df_chunk, week_labels_chunk, week_sessions_chunk
            gc.collect()
        cand_df = pl.concat(cand_dfs)
        del cand_dfs
        gc.collect()
        cand_df.write_parquet(cache_path)

    # データ確認
    pos_cnt = cand_df.filter(pl.col("labels")==1).shape[0]
    neg_cnt = cand_df.filter(pl.col("labels")==0).shape[0]
    logger.info(f"train({type_}) pos : {str(pos_cnt)}  neg : {str(neg_cnt)}")

    # 特徴量付与
    train = add_features(week_sessions, cand_df, cfg.train_week)
    del cand_df, week_sessions
    gc.collect()

    return train

# %%
@noglobal(excepts=["cfg", "logger", "cache"])
def make_valid_cand():
    # データ読み込み
    week_sessions = pl.read_parquet(cfg.prep_dir + f"train_sessions_{cfg.valid_week}.parquet")
    week_sessions = week_sessions.select([
        pl.col("session").cast(pl.Int32),
        pl.col("aid").cast(pl.Int32),
        pl.col("ts"),
        pl.col("type")
        ])
    
    week_labels = pl.read_parquet(cfg.prep_dir + f"labels_{cfg.valid_week}.parquet")
    week_labels = week_labels.select([
        pl.col("session").cast(pl.Int32),
        pl.col("clicks_labels").cast(pl.Int32),
        pl.col("carts_labels"),
        pl.col("orders_labels")
        ])
    valid_sessions = week_sessions.get_column("session").unique().to_list()
    
    trans_map_cache_file = f"trans_maps_{cfg.valid_week}.pkl"
    trans_map_cache_path = cache.get_abspath(trans_map_cache_file)
    with open(trans_map_cache_path, "rb") as f:
        trans_maps = pickle.load(f)

    # validに使うsessionを絞る
    use_session_n = min(cfg.valid_session_n, len(valid_sessions))
    random.seed(cfg.seed)
    use_sessions = random.sample(valid_sessions, use_session_n)
    week_sessions = week_sessions.filter(pl.col("session").is_in(use_sessions))
    week_labels = week_labels.filter(pl.col("session").is_in(use_sessions))

    # 候補選出
    cand_df = make_cand_df(week_sessions, cfg.valid_week, trans_maps=trans_maps)
    return cand_df, week_sessions, week_labels

# %%
@noglobal(excepts=["cfg", "logger"])
def make_valid_data(cand_df, week_sessions, week_labels, type_):
    # 特徴量付与
    valid = add_features(week_sessions, cand_df, cfg.valid_week)
    valid = add_labels(valid, week_labels, type_)

    # データ確認
    pos_cnt = valid.filter(pl.col("labels")==1).shape[0]
    neg_cnt = valid.filter(pl.col("labels")==0).shape[0]
    logger.info(f"valid({type_}) pos : {str(pos_cnt)}  neg : {str(neg_cnt)}")
    
    return valid

# %%
@noglobal(excepts=["cfg", "logger"])
def model_training(train, valid, features, target, valid_labels, type_):
    if type_ == "clicks":
        params = cfg.clicks_params
    elif type_ == "carts":
        params = cfg.carts_params
    elif type_ == "orders":
        params = cfg.orders_params

    train = train.to_pandas()
    valid = valid.to_pandas()
    valid_labels = valid_labels.to_pandas()

    # 学習
    vl_pred_df = valid[["session", "aid"]].copy()

    tr_x, tr_y = train[features], train[target]
    vl_x, vl_y = valid[features], valid[target]
    tr_data = lgb.Dataset(tr_x, label=tr_y)
    vl_data = lgb.Dataset(vl_x, label=vl_y)

    if os.path.exists(cfg.output_dir + f"{cfg.exp_name}/{type_}_model.lgb"):
        logger.info(f"[{type_}_model.lgb] cache exists. read cache and skip process.")
        model = lgb.Booster(model_file = cfg.output_dir + f"{cfg.exp_name}/{type_}_model.lgb")
    else:
        model = lgb.train(params, tr_data, valid_sets=[tr_data, vl_data],
                        num_boost_round=2000000, early_stopping_rounds=100, verbose_eval=100)

    # 特徴量重要度
    fi = pd.DataFrame()
    fi["feature"] = model.feature_name()
    fi["importance"] = model.feature_importance(importance_type="gain")

    # 2値分類の出力を元にk個選定
    vl_pred_df["prob"] = model.predict(vl_x, num_iteration=model.best_iteration)
    vl_pred_df = vl_pred_df.sort_values(["session", "prob"], ascending=(True, False))
    vl_pred_df = vl_pred_df.groupby(["session"]).head(cfg.k)
    vl_pred_df = vl_pred_df.groupby(["session"])["aid"].apply(list).reset_index()
    
    # 評価
    assert valid_labels["session"].tolist() == vl_pred_df["session"].unique().tolist()
    score = evaluate(valid_labels["clicks_labels"].tolist(),
                     valid_labels["carts_labels"].tolist(),
                     valid_labels["orders_labels"].tolist(),
                     vl_pred_df["aid"].tolist(),
                     vl_pred_df["aid"].tolist(),
                     vl_pred_df["aid"].tolist(),
                     cfg.k)
    logger.info(f"{type_} valid score")
    logger.info(score)

    # モデル保存
    model.save_model(cfg.output_dir + f"{cfg.exp_name}/{type_}_model.lgb")

    # 特徴量重要度
    fi_n = fi['feature'].nunique()
    order = list(fi.groupby("feature").mean().sort_values("importance", ascending=False).index)
    plt.figure(figsize=(10, fi_n*0.2))
    sns.barplot(x="importance", y="feature", data=fi, order=order)
    plt.title(f"LGBM importance({type_})")
    plt.tight_layout()
    plt.savefig(cfg.output_dir + f'{cfg.exp_name}/lgbm_importance_{type_}.png')
    return score[f"recall_{type_}"]

# %%
@noglobal(excepts=["cfg", "logger", "cache"])
def make_test_data():
    # testデータ作成
    test_sessions = pl.read_parquet(cfg.prep_dir + f"test_sessions.parquet")
    test_sessions = test_sessions.select(
        [
            pl.col("session").cast(pl.Int32),
            pl.col("aid").cast(pl.Int32),
            pl.col("ts"),
            pl.col("type")
        ]
    )
    sessions_lists = np.array_split(test_sessions.get_column("session").unique().to_list(), cfg.test_chunk_n)
    trans_map_cache_file = f"trans_maps.pkl"
    trans_map_cache_path = cache.get_abspath(trans_map_cache_file)
    with open(trans_map_cache_path, "rb") as f:
        trans_maps = pickle.load(f)

    for chunk in range(cfg.test_chunk_n):
        use_sessions = list(sessions_lists[chunk])
        cache_file = f"test_{chunk}.parquet"
        cache_path = cache.get_abspath(cache_file)
        if cache.exists(cache_path):
            logger.info(f"[{cache_file}] cache exists. read cache and skip process.")
        else:
            test_sessions_chunk = test_sessions.filter(pl.col("session").is_in(use_sessions))
            # 候補選出
            logger.info("[make_test] make_cand_df")
            cand_df = make_cand_df(test_sessions_chunk, None, trans_maps=trans_maps)
            # 特徴量付与
            logger.info("[make_test] add_features")
            test = add_features(test_sessions, cand_df)
            test.write_parquet(cache_path)

# %%
@noglobal(excepts=["cfg", "logger", "cache"])
def inference(features):
    pred_dfs = []
    for chunk in range(cfg.test_chunk_n):
        cache_file = f"test_{chunk}.parquet"
        cache_path = cache.get_abspath(cache_file)
        test = pl.read_parquet(cache_path).to_pandas()

        for type_ in ["clicks", "carts", "orders"]:    
            pred_df_tmp = test[["session", "aid"]].copy()
            # 推論
            model = lgb.Booster(model_file = cfg.output_dir + f"{cfg.exp_name}/{type_}_model.lgb")
            # 2値分類の出力を元にk個選定
            pred_df_tmp["prob"] = model.predict(test[features], num_iteration=model.best_iteration)
            pred_df_tmp = pred_df_tmp.sort_values(["session", "prob"], ascending=(True, False))
            pred_df_tmp = pred_df_tmp.groupby(["session"]).head(30)
            pred_df_tmp["aid"] = pred_df_tmp["aid"].astype(str)
            pred_df_tmp = pred_df_tmp.groupby(["session"])["aid"].apply(list).reset_index()
            pred_df_tmp["aid"] = pred_df_tmp["aid"].apply(lambda x: ' '.join(x))
            pred_df_tmp["type"] = type_
            pred_dfs.append(pred_df_tmp)
        del test, model
        gc.collect()
    
    pred_df = pd.concat(pred_dfs)
    # sub作成
    sub = pd.read_csv(cfg.input_dir + f"sample_submission.csv", usecols=["session_type"])
    pred_df["session_type"] = pred_df["session"].astype(str) + "_" + pred_df["type"]
    pred_df = pred_df.rename(columns={"aid": "labels"})
    sub = sub.merge(pred_df[["session_type", "labels"]], on="session_type", how="left")
    sub.to_csv(cfg.output_dir + f"{cfg.exp_name}/t88_{cfg.exp_name}_sub_k30.csv", index=False)

# %%
@noglobal(excepts=["cfg", "logger", "cache"])
def main():
    scores = {}
    logger.info(f"START")
    line_notify.send(f"{cfg.exp_name} | START")
    
    # trans_map作成
    weeks = [None, cfg.train_week, cfg.valid_week]
    for week in weeks:
        if week is None:
            cache_file = "trans_maps.pkl"
        else:    
            cache_file = f"trans_maps_{week}.pkl"
        cache_path = cache.get_abspath(cache_file)
        if cache.exists(cache_path):
            logger.info(f"[{cache_file}] cache exists. skip process.")
        else:
            trans_maps = get_trans_maps(week)
            with open(cache_path, "wb") as f:
                pickle.dump(trans_maps, f)

    for type_ in ["clicks", "carts", "orders"]:
        # train data作成
        logger.info(f"make {type_}_train_data")
        cache_file = f"{type_}_train.parquet"
        cache_path = cache.get_abspath(cache_file)
        if cache.exists(cache_path):
            logger.info(f"[{cache_file}] cache exists. read cache and skip process.")
            train = pl.read_parquet(cache_path)
        else:
            train = make_train_data(type_)
            train.write_parquet(cache_path)

        logger.info(f"make {type_}_valid_data")
        # valid cand作成
        cand_cache_path = cache.get_abspath("valid_cand.parquet")
        sessions_cache_path = cache.get_abspath("valid_sessions.parquet")
        labels_cache_path = cache.get_abspath("valid_labels.parquet")
        if cache.exists(cand_cache_path) & cache.exists(labels_cache_path) & cache.exists(sessions_cache_path):
            logger.info("[valid_cand.parquet] cache exists. read cache and skip process.")
            valid_cand = pl.read_parquet(cand_cache_path)
            valid_sessions = pl.read_parquet(sessions_cache_path)
            valid_labels = pl.read_parquet(labels_cache_path)
        else:
            valid_cand, valid_sessions, valid_labels = make_valid_cand()
            valid_cand.write_parquet(cand_cache_path)
            valid_sessions.write_parquet(sessions_cache_path)
            valid_labels.write_parquet(labels_cache_path)

        # valid data作成
        logger.info(f"make {type_}_valid_data")
        cache_file = f"{type_}_valid.parquet"
        cache_path = cache.get_abspath(cache_file)
        if cache.exists(cache_path):
            logger.info(f"[{cache_file}] cache exists. read cache and skip process.")
            valid = pl.read_parquet(cache_path)
        else:
            valid = make_valid_data(valid_cand, valid_sessions, valid_labels, type_)
            valid.write_parquet(cache_path)

        # モデル学習
        target = "labels"
        not_use_cols = ["session", "aid", target]
        features = [c for c in train.columns if c not in not_use_cols]

        scores[f"recall_{type_}"] = model_training(train, valid, features, target, valid_labels, type_)

        del train, valid, valid_labels
        gc.collect()
    
    scores["total"] = (float(scores["recall_clicks"]) * 0.1) + (float(scores["recall_carts"]) * 0.3) + (float(scores["recall_orders"]) * 0.6)
    report = f"\n{cfg.exp_name}\n"
    report += f'valid_end\n'
    report += str(scores)
    line_notify.send(report)

    # testデータ
    if cfg.run_inf:
        make_test_data()

        logger.info(f"-------- inference --------")
        inference(features)

    line_notify.send(f"{cfg.exp_name} | END!!")

# %%
try:
    main()
except Exception as e:
    logger.error(traceback.format_exc())
    line_notify.send(f"{cfg.exp_name} | ERROR!!\n{traceback.format_exc()}")
# Out:
# 0:00:00.832793 	 START
# 0:00:01.022998 	 [trans_maps.pkl] cache exists. skip process.
# 0:00:01.026567 	 [trans_maps_week3.pkl] cache exists. skip process.
# 0:00:01.029250 	 [trans_maps_week4.pkl] cache exists. skip process.
# 0:00:01.030528 	 make clicks_train_data
# 0:00:38.474166 	 [add_candidate] repurchase : start
# 0:00:44.830992 	 [add_candidate] clstr_freq : start
# 0:01:35.960452 	 [add_candidate] session_latest_time_wt_pair0 : start
# 0:01:40.965464 	 [add_candidate] session_latest_word2vec_pair0 : start
# 0:01:46.217746 	 [add_candidate] session_latest_pair0 : start
# 0:01:51.248688 	 [add_candidate] session_latest_type_wt_pair0 : start
# 0:01:56.210484 	 [add_candidate] session_latest_clicks2carts_pair0 : start
# 0:02:01.210503 	 [add_candidate] session_latest_clicks2orders_pair0 : start
# 0:02:05.616921 	 [add_candidate] session_latest_time_wt_pair1 : start
# 0:02:10.624780 	 [add_candidate] session_latest_word2vec_pair1 : start
# 0:02:15.917634 	 [add_candidate] session_latest_pair1 : start
# 0:02:21.129488 	 [add_candidate] session_latest_type_wt_pair1 : start
# 0:02:26.245293 	 [add_candidate] session_latest_clicks2carts_pair1 : start
# 0:02:31.063370 	 [add_candidate] session_latest_clicks2orders_pair1 : start
# 0:02:35.597752 	 [add_candidate] session_latest_time_wt_pair2 : start
# 0:02:40.766230 	 [add_candidate] session_latest_word2vec_pair2 : start
# 0:02:46.052117 	 [add_candidate] session_latest_pair2 : start
# 0:02:51.515658 	 [add_candidate] session_latest_type_wt_pair2 : start
# 0:02:56.811160 	 [add_candidate] session_latest_clicks2carts_pair2 : start
# 0:03:01.880295 	 [add_candidate] session_latest_clicks2orders_pair2 : start
# 0:03:06.516769 	 [add_candidate] session_latest_time_wt_pair3 : start
# 0:03:11.589218 	 [add_candidate] session_latest_word2vec_pair3 : start
# 0:03:16.915910 	 [add_candidate] session_latest_pair3 : start
# 0:03:22.192010 	 [add_candidate] session_latest_type_wt_pair3 : start
# 0:03:27.410019 	 [add_candidate] session_latest_clicks2carts_pair3 : start
# 0:03:32.474413 	 [add_candidate] session_latest_clicks2orders_pair3 : start
# 0:03:37.050520 	 [add_candidate] session_latest_time_wt_pair4 : start
# 0:03:42.265865 	 [add_candidate] session_latest_word2vec_pair4 : start
# 0:03:47.770420 	 [add_candidate] session_latest_pair4 : start
# 0:03:53.081794 	 [add_candidate] session_latest_type_wt_pair4 : start
# 0:03:58.513057 	 [add_candidate] session_latest_clicks2carts_pair4 : start
# 0:04:03.611318 	 [add_candidate] session_latest_clicks2orders_pair4 : start
# 0:04:08.190756 	 [add_candidate] session_latest_time_wt_pair5 : start
# 0:04:13.464334 	 [add_candidate] session_latest_word2vec_pair5 : start
# 0:04:18.966697 	 [add_candidate] session_latest_pair5 : start
# 0:04:24.345789 	 [add_candidate] session_latest_type_wt_pair5 : start
# 0:04:29.698673 	 [add_candidate] session_latest_clicks2carts_pair5 : start
# 0:04:34.885653 	 [add_candidate] session_latest_clicks2orders_pair5 : start
# 0:04:39.532831 	 [add_candidate] session_latest_time_wt_pair6 : start
# 0:04:44.644992 	 [add_candidate] session_latest_word2vec_pair6 : start
# 0:04:50.061952 	 [add_candidate] session_latest_pair6 : start
# 0:04:55.423472 	 [add_candidate] session_latest_type_wt_pair6 : start
# 0:05:00.865735 	 [add_candidate] session_latest_clicks2carts_pair6 : start
# 0:05:06.052449 	 [add_candidate] session_latest_clicks2orders_pair6 : start
# 0:05:10.695812 	 [add_candidate] session_latest_time_wt_pair7 : start
# 0:05:16.096713 	 [add_candidate] session_latest_word2vec_pair7 : start
# 0:05:21.687361 	 [add_candidate] session_latest_pair7 : start
# 0:05:27.197629 	 [add_candidate] session_latest_type_wt_pair7 : start
# 0:05:32.665381 	 [add_candidate] session_latest_clicks2carts_pair7 : start
# 0:05:38.006197 	 [add_candidate] session_latest_clicks2orders_pair7 : start
# 0:05:42.771770 	 [add_candidate] session_latest_time_wt_pair8 : start
# 0:05:48.017382 	 [add_candidate] session_latest_word2vec_pair8 : start
# 0:05:53.523078 	 [add_candidate] session_latest_pair8 : start
# 0:05:58.900888 	 [add_candidate] session_latest_type_wt_pair8 : start
# 0:06:04.226557 	 [add_candidate] session_latest_clicks2carts_pair8 : start
# 0:06:09.294256 	 [add_candidate] session_latest_clicks2orders_pair8 : start
# 0:06:13.950346 	 [add_candidate] session_latest_time_wt_pair9 : start
# 0:06:19.472126 	 [add_candidate] session_latest_word2vec_pair9 : start
# 0:06:25.105489 	 [add_candidate] session_latest_pair9 : start
# 0:06:30.689536 	 [add_candidate] session_latest_type_wt_pair9 : start
# 0:06:36.107442 	 [add_candidate] session_latest_clicks2carts_pair9 : start
# 0:06:41.345298 	 [add_candidate] session_latest_clicks2orders_pair9 : start
# 0:06:45.868574 	 [add_candidate] session_latest_time_wt_pair10 : start
# 0:06:51.319866 	 [add_candidate] session_latest_word2vec_pair10 : start
# 0:06:56.843414 	 [add_candidate] session_latest_pair10 : start
# 0:07:02.386782 	 [add_candidate] session_latest_type_wt_pair10 : start
# 0:07:07.960322 	 [add_candidate] session_latest_clicks2carts_pair10 : start
# 0:07:13.370819 	 [add_candidate] session_latest_clicks2orders_pair10 : start
# 0:07:18.290803 	 [add_candidate] session_latest_time_wt_pair11 : start
# 0:07:23.903782 	 [add_candidate] session_latest_word2vec_pair11 : start
# 0:07:29.523881 	 [add_candidate] session_latest_pair11 : start
# 0:07:35.106524 	 [add_candidate] session_latest_type_wt_pair11 : start
# 0:07:40.653890 	 [add_candidate] session_latest_clicks2carts_pair11 : start
# 0:07:46.041569 	 [add_candidate] session_latest_clicks2orders_pair11 : start
# 0:07:50.886099 	 [add_candidate] session_latest_time_wt_pair12 : start
# 0:07:56.385669 	 [add_candidate] session_latest_word2vec_pair12 : start
# 0:08:02.250523 	 [add_candidate] session_latest_pair12 : start
# 0:08:07.880282 	 [add_candidate] session_latest_type_wt_pair12 : start
# 0:08:13.519535 	 [add_candidate] session_latest_clicks2carts_pair12 : start
# 0:08:18.860215 	 [add_candidate] session_latest_clicks2orders_pair12 : start
# 0:08:23.667968 	 [add_candidate] session_latest_time_wt_pair13 : start
# 0:08:29.430230 	 [add_candidate] session_latest_word2vec_pair13 : start
# 0:08:35.237865 	 [add_candidate] session_latest_pair13 : start
# 0:08:40.768036 	 [add_candidate] session_latest_type_wt_pair13 : start
# 0:08:46.645731 	 [add_candidate] session_latest_clicks2carts_pair13 : start
# 0:08:52.114490 	 [add_candidate] session_latest_clicks2orders_pair13 : start
# 0:08:56.837255 	 [add_candidate] session_latest_time_wt_pair14 : start
# 0:09:02.375386 	 [add_candidate] session_latest_word2vec_pair14 : start
# 0:09:08.160368 	 [add_candidate] session_latest_pair14 : start
# 0:09:13.947768 	 [add_candidate] session_latest_type_wt_pair14 : start
# 0:09:19.687371 	 [add_candidate] session_latest_clicks2carts_pair14 : start
# 0:09:25.022930 	 [add_candidate] session_latest_clicks2orders_pair14 : start
# 0:09:29.944162 	 [add_candidate] session_latest_time_wt_pair15 : start
# 0:09:35.619194 	 [add_candidate] session_latest_word2vec_pair15 : start
# 0:09:41.251591 	 [add_candidate] session_latest_pair15 : start
# 0:09:46.923290 	 [add_candidate] session_latest_type_wt_pair15 : start
# 0:09:52.636687 	 [add_candidate] session_latest_clicks2carts_pair15 : start
# 0:09:57.920509 	 [add_candidate] session_latest_clicks2orders_pair15 : start
# 0:10:02.787412 	 [add_candidate] session_latest_time_wt_pair16 : start
# 0:10:08.411923 	 [add_candidate] session_latest_word2vec_pair16 : start
# 0:10:14.197651 	 [add_candidate] session_latest_pair16 : start
# 0:10:19.862836 	 [add_candidate] session_latest_type_wt_pair16 : start
# 0:10:25.456615 	 [add_candidate] session_latest_clicks2carts_pair16 : start
# 0:10:30.906718 	 [add_candidate] session_latest_clicks2orders_pair16 : start
# 0:10:35.766660 	 [add_candidate] session_latest_time_wt_pair17 : start
# 0:10:41.396565 	 [add_candidate] session_latest_word2vec_pair17 : start
# 0:10:47.041426 	 [add_candidate] session_latest_pair17 : start
# 0:10:52.634757 	 [add_candidate] session_latest_type_wt_pair17 : start
# 0:10:58.167648 	 [add_candidate] session_latest_clicks2carts_pair17 : start
# 0:11:03.613607 	 [add_candidate] session_latest_clicks2orders_pair17 : start
# 0:11:08.321671 	 [add_candidate] session_latest_time_wt_pair18 : start
# 0:11:13.821341 	 [add_candidate] session_latest_word2vec_pair18 : start
# 0:11:19.490065 	 [add_candidate] session_latest_pair18 : start
# 0:11:25.248119 	 [add_candidate] session_latest_type_wt_pair18 : start
# 0:11:31.279234 	 [add_candidate] session_latest_clicks2carts_pair18 : start
# 0:11:36.784548 	 [add_candidate] session_latest_clicks2orders_pair18 : start
# 0:11:41.675904 	 [add_candidate] session_latest_time_wt_pair19 : start
# 0:11:47.401151 	 [add_candidate] session_latest_word2vec_pair19 : start
# 0:11:53.219212 	 [add_candidate] session_latest_pair19 : start
# 0:12:00.414459 	 [add_candidate] session_latest_type_wt_pair19 : start
# 0:12:08.527336 	 [add_candidate] session_latest_clicks2carts_pair19 : start
# 0:12:15.070911 	 [add_candidate] session_latest_clicks2orders_pair19 : start
# 0:24:24.690834 	 [add_candidate] repurchase : start
# 0:24:28.784519 	 [add_candidate] clstr_freq : start
# 0:25:21.800807 	 [add_candidate] session_latest_time_wt_pair0 : start
# 0:25:27.029880 	 [add_candidate] session_latest_word2vec_pair0 : start
# 0:25:32.212309 	 [add_candidate] session_latest_pair0 : start
# 0:25:37.442935 	 [add_candidate] session_latest_type_wt_pair0 : start
# 0:25:42.635575 	 [add_candidate] session_latest_clicks2carts_pair0 : start
# 0:25:46.970799 	 [add_candidate] session_latest_clicks2orders_pair0 : start
# 0:25:50.581857 	 [add_candidate] session_latest_time_wt_pair1 : start
# 0:25:55.602047 	 [add_candidate] session_latest_word2vec_pair1 : start
# 0:26:00.835802 	 [add_candidate] session_latest_pair1 : start
# 0:26:05.980982 	 [add_candidate] session_latest_type_wt_pair1 : start
# 0:26:11.254882 	 [add_candidate] session_latest_clicks2carts_pair1 : start
# 0:26:15.606604 	 [add_candidate] session_latest_clicks2orders_pair1 : start
# 0:26:19.241435 	 [add_candidate] session_latest_time_wt_pair2 : start
# 0:26:24.288529 	 [add_candidate] session_latest_word2vec_pair2 : start
# 0:26:29.486354 	 [add_candidate] session_latest_pair2 : start
# 0:26:34.580874 	 [add_candidate] session_latest_type_wt_pair2 : start
# 0:26:39.752293 	 [add_candidate] session_latest_clicks2carts_pair2 : start
# 0:26:44.203966 	 [add_candidate] session_latest_clicks2orders_pair2 : start
# 0:26:47.730669 	 [add_candidate] session_latest_time_wt_pair3 : start
# 0:26:52.800423 	 [add_candidate] session_latest_word2vec_pair3 : start
# 0:26:58.080245 	 [add_candidate] session_latest_pair3 : start
# 0:27:03.209059 	 [add_candidate] session_latest_type_wt_pair3 : start
# 0:27:08.306898 	 [add_candidate] session_latest_clicks2carts_pair3 : start
# 0:27:12.618922 	 [add_candidate] session_latest_clicks2orders_pair3 : start
# 0:27:16.228447 	 [add_candidate] session_latest_time_wt_pair4 : start
# 0:27:21.301248 	 [add_candidate] session_latest_word2vec_pair4 : start
# 0:27:26.523387 	 [add_candidate] session_latest_pair4 : start
# 0:27:31.598131 	 [add_candidate] session_latest_type_wt_pair4 : start
# 0:27:36.701035 	 [add_candidate] session_latest_clicks2carts_pair4 : start
# 0:27:41.072068 	 [add_candidate] session_latest_clicks2orders_pair4 : start
# 0:27:44.665702 	 [add_candidate] session_latest_time_wt_pair5 : start
# 0:27:49.799235 	 [add_candidate] session_latest_word2vec_pair5 : start
# 0:27:55.057478 	 [add_candidate] session_latest_pair5 : start
# 0:28:00.189290 	 [add_candidate] session_latest_type_wt_pair5 : start
# 0:28:05.398539 	 [add_candidate] session_latest_clicks2carts_pair5 : start
# 0:28:09.809323 	 [add_candidate] session_latest_clicks2orders_pair5 : start
# 0:28:13.478396 	 [add_candidate] session_latest_time_wt_pair6 : start
# 0:28:18.583258 	 [add_candidate] session_latest_word2vec_pair6 : start
# 0:28:23.880167 	 [add_candidate] session_latest_pair6 : start
# 0:28:29.027137 	 [add_candidate] session_latest_type_wt_pair6 : start
# 0:28:34.187484 	 [add_candidate] session_latest_clicks2carts_pair6 : start
# 0:28:38.596337 	 [add_candidate] session_latest_clicks2orders_pair6 : start
# 0:28:42.258116 	 [add_candidate] session_latest_time_wt_pair7 : start
# 0:28:47.344093 	 [add_candidate] session_latest_word2vec_pair7 : start
# 0:28:52.631773 	 [add_candidate] session_latest_pair7 : start
# 0:28:57.862225 	 [add_candidate] session_latest_type_wt_pair7 : start
# 0:29:03.052792 	 [add_candidate] session_latest_clicks2carts_pair7 : start
# 0:29:07.390373 	 [add_candidate] session_latest_clicks2orders_pair7 : start
# 0:29:10.966481 	 [add_candidate] session_latest_time_wt_pair8 : start
# 0:29:16.065157 	 [add_candidate] session_latest_word2vec_pair8 : start
# 0:29:21.243244 	 [add_candidate] session_latest_pair8 : start
# 0:29:26.361360 	 [add_candidate] session_latest_type_wt_pair8 : start
# 0:29:31.607384 	 [add_candidate] session_latest_clicks2carts_pair8 : start
# 0:29:36.032989 	 [add_candidate] session_latest_clicks2orders_pair8 : start
# 0:29:39.624436 	 [add_candidate] session_latest_time_wt_pair9 : start
# 0:29:44.722317 	 [add_candidate] session_latest_word2vec_pair9 : start
# 0:29:50.012516 	 [add_candidate] session_latest_pair9 : start
# 0:29:55.303806 	 [add_candidate] session_latest_type_wt_pair9 : start
# 0:30:00.614426 	 [add_candidate] session_latest_clicks2carts_pair9 : start
# 0:30:05.021462 	 [add_candidate] session_latest_clicks2orders_pair9 : start
# 0:30:08.627157 	 [add_candidate] session_latest_time_wt_pair10 : start
# 0:30:13.701330 	 [add_candidate] session_latest_word2vec_pair10 : start
# 0:30:19.051125 	 [add_candidate] session_latest_pair10 : start
# 0:30:24.206923 	 [add_candidate] session_latest_type_wt_pair10 : start
# 0:30:29.403833 	 [add_candidate] session_latest_clicks2carts_pair10 : start
# 0:30:33.793504 	 [add_candidate] session_latest_clicks2orders_pair10 : start
# 0:30:37.377330 	 [add_candidate] session_latest_time_wt_pair11 : start
# 0:30:42.458329 	 [add_candidate] session_latest_word2vec_pair11 : start
# 0:30:47.666479 	 [add_candidate] session_latest_pair11 : start
# 0:30:52.876757 	 [add_candidate] session_latest_type_wt_pair11 : start
# 0:30:58.159471 	 [add_candidate] session_latest_clicks2carts_pair11 : start
# 0:31:02.545276 	 [add_candidate] session_latest_clicks2orders_pair11 : start
# 0:31:06.199635 	 [add_candidate] session_latest_time_wt_pair12 : start
# 0:31:11.269685 	 [add_candidate] session_latest_word2vec_pair12 : start
# 0:31:16.544923 	 [add_candidate] session_latest_pair12 : start
# 0:31:21.745617 	 [add_candidate] session_latest_type_wt_pair12 : start
# 0:31:26.942603 	 [add_candidate] session_latest_clicks2carts_pair12 : start
# 0:31:31.363333 	 [add_candidate] session_latest_clicks2orders_pair12 : start
# 0:31:34.994701 	 [add_candidate] session_latest_time_wt_pair13 : start
# 0:31:40.129332 	 [add_candidate] session_latest_word2vec_pair13 : start
# 0:31:45.401088 	 [add_candidate] session_latest_pair13 : start
# 0:31:50.583881 	 [add_candidate] session_latest_type_wt_pair13 : start
# 0:31:55.756708 	 [add_candidate] session_latest_clicks2carts_pair13 : start
# 0:32:00.238117 	 [add_candidate] session_latest_clicks2orders_pair13 : start
# 0:32:03.785213 	 [add_candidate] session_latest_time_wt_pair14 : start
# 0:32:08.997490 	 [add_candidate] session_latest_word2vec_pair14 : start
# 0:32:14.154763 	 [add_candidate] session_latest_pair14 : start
# 0:32:19.378175 	 [add_candidate] session_latest_type_wt_pair14 : start
# 0:32:24.561007 	 [add_candidate] session_latest_clicks2carts_pair14 : start
# 0:32:28.984494 	 [add_candidate] session_latest_clicks2orders_pair14 : start
# 0:32:32.647007 	 [add_candidate] session_latest_time_wt_pair15 : start
# 0:32:37.829107 	 [add_candidate] session_latest_word2vec_pair15 : start
# 0:32:43.233114 	 [add_candidate] session_latest_pair15 : start
# 0:32:48.409898 	 [add_candidate] session_latest_type_wt_pair15 : start
# 0:32:53.567040 	 [add_candidate] session_latest_clicks2carts_pair15 : start
# 0:32:58.048689 	 [add_candidate] session_latest_clicks2orders_pair15 : start
# 0:33:01.660188 	 [add_candidate] session_latest_time_wt_pair16 : start
# 0:33:06.895720 	 [add_candidate] session_latest_word2vec_pair16 : start
# 0:33:12.334085 	 [add_candidate] session_latest_pair16 : start
# 0:33:17.499153 	 [add_candidate] session_latest_type_wt_pair16 : start
# 0:33:22.709955 	 [add_candidate] session_latest_clicks2carts_pair16 : start
# 0:33:27.201382 	 [add_candidate] session_latest_clicks2orders_pair16 : start
# 0:33:30.804724 	 [add_candidate] session_latest_time_wt_pair17 : start
# 0:33:35.956307 	 [add_candidate] session_latest_word2vec_pair17 : start
# 0:33:41.321665 	 [add_candidate] session_latest_pair17 : start
# 0:33:46.805015 	 [add_candidate] session_latest_type_wt_pair17 : start
# 0:33:52.463290 	 [add_candidate] session_latest_clicks2carts_pair17 : start
# 0:33:57.280321 	 [add_candidate] session_latest_clicks2orders_pair17 : start
# 0:34:01.084023 	 [add_candidate] session_latest_time_wt_pair18 : start
# 0:34:06.300600 	 [add_candidate] session_latest_word2vec_pair18 : start
# 0:34:11.702835 	 [add_candidate] session_latest_pair18 : start
# 0:34:16.935217 	 [add_candidate] session_latest_type_wt_pair18 : start
# 0:34:22.125482 	 [add_candidate] session_latest_clicks2carts_pair18 : start
# 0:34:26.556656 	 [add_candidate] session_latest_clicks2orders_pair18 : start
# 0:34:30.149840 	 [add_candidate] session_latest_time_wt_pair19 : start
# 0:34:35.304430 	 [add_candidate] session_latest_word2vec_pair19 : start
# 0:34:40.695228 	 [add_candidate] session_latest_pair19 : start
# 0:34:45.906643 	 [add_candidate] session_latest_type_wt_pair19 : start
# 0:34:51.129984 	 [add_candidate] session_latest_clicks2carts_pair19 : start
# 0:34:55.574319 	 [add_candidate] session_latest_clicks2orders_pair19 : start
# 0:40:19.327779 	 train(clicks) pos : 2756882  neg : 2756882
# 0:40:24.975473 	 [features] session_cnt : start
# 0:40:27.313566 	 [features] session_aid_nunique : start
# 0:40:27.941902 	 [features] session_last_type : start
# 0:40:28.634951 	 [features] aid_cnt : start
# 0:40:30.603685 	 [features] aid_clicks_cnt : start
# 0:40:32.350002 	 [features] aid_carts_cnt : start
# 0:40:33.654196 	 [features] aid_orders_cnt : start
# 0:40:33.930522 	 [features] all_times_aid_freq : start
# 0:40:34.815641 	 [features] all_times_aid_clicks_freq : start
# 0:40:35.562914 	 [features] all_times_aid_carts_freq : start
# 0:40:36.061958 	 [features] all_times_aid_orders_freq : start
# 0:40:36.385313 	 [features] all_times_aid_session_freq : start
# 0:40:37.104458 	 [features] all_times_aid_session_clicks_freq : start
# 0:40:37.846196 	 [features] all_times_aid_session_carts_freq : start
# 0:40:38.311646 	 [features] all_times_aid_session_orders_freq : start
# 0:40:38.634517 	 [features] all_times_aid_carts_ratio_with_clicks : start
# 0:40:39.461082 	 [features] all_times_aid_orders_ratio_with_clicks : start
# 0:40:40.303765 	 [features] all_times_aid_date_std : start
# 0:40:41.188217 	 [features] all_times_aid_hour_std : start
# 0:40:42.049940 	 [features] all_times_aid_day_of_week_std : start
# 0:40:42.924977 	 [features] w2v_vectors : start
# 0:40:43.839367 	 [features] relative_ts : start
# 0:40:51.066805 	 [features] co_visit_rank(co_visitation_matrix) : start
# 0:41:12.587740 	 [features] co_visit_rank(co_visitation_matrix_lt0) : start
# 0:41:37.168321 	 [features] co_visit_rank(co_visitation_matrix_lt1) : start
# 0:42:01.183208 	 [features] co_visit_rank(co_visitation_matrix_lt2) : start
# 0:42:24.336128 	 [features] co_visit_rank(co_visitation_matrix_lt3) : start
# 0:42:47.246154 	 [features] co_visit_rank(co_visitation_matrix_lt4) : start
# 0:43:09.451838 	 [features] co_visit_rank(co_visitation_matrix_lt5) : start
# 0:43:31.782639 	 [features] co_visit_rank(co_visitation_matrix_lt6) : start
# 0:43:54.007113 	 [features] co_visit_rank(co_visitation_matrix_lt7) : start
# 0:44:15.969642 	 [features] co_visit_rank(co_visitation_matrix_lt8) : start
# 0:44:37.946995 	 [features] co_visit_rank(co_visitation_matrix_lt9) : start
# 0:44:59.853659 	 [features] co_visit_rank(co_visitation_matrix_time_weighted) : start
# 0:45:50.302951 	 [features] co_visit_rank(co_visitation_matrix_time_weighted_lt0) : start
# 0:46:41.368523 	 [features] co_visit_rank(co_visitation_matrix_time_weighted_lt1) : start
# 0:47:31.721112 	 [features] co_visit_rank(co_visitation_matrix_time_weighted_lt2) : start
# 0:48:21.188426 	 [features] co_visit_rank(co_visitation_matrix_time_weighted_lt3) : start
# 0:49:10.704107 	 [features] co_visit_rank(co_visitation_matrix_time_weighted_lt4) : start
# 0:49:59.791699 	 [features] co_visit_rank(co_visitation_matrix_time_weighted_lt5) : start
# 0:50:49.390884 	 [features] co_visit_rank(co_visitation_matrix_time_weighted_lt6) : start
# 0:51:38.100824 	 [features] co_visit_rank(co_visitation_matrix_time_weighted_lt7) : start
# 0:52:27.046123 	 [features] co_visit_rank(co_visitation_matrix_time_weighted_lt8) : start
# 0:53:16.007807 	 [features] co_visit_rank(co_visitation_matrix_time_weighted_lt9) : start
# 0:54:04.580426 	 [features] co_visit_rank(co_visitation_matrix_type_weighted) : start
# 0:54:38.571500 	 [features] co_visit_rank(co_visitation_matrix_type_weighted_lt0) : start
# 0:55:41.388062 	 [features] co_visit_rank(co_visitation_matrix_type_weighted_lt1) : start
# 0:56:35.829185 	 [features] co_visit_rank(co_visitation_matrix_type_weighted_lt2) : start
# 0:57:29.336339 	 [features] co_visit_rank(co_visitation_matrix_type_weighted_lt3) : start
# 0:58:22.868951 	 [features] co_visit_rank(co_visitation_matrix_type_weighted_lt4) : start
# 0:59:15.475312 	 [features] co_visit_rank(co_visitation_matrix_type_weighted_lt5) : start
# 1:00:07.831877 	 [features] co_visit_rank(co_visitation_matrix_type_weighted_lt6) : start
# 1:01:00.016469 	 [features] co_visit_rank(co_visitation_matrix_type_weighted_lt7) : start
# 1:01:51.876308 	 [features] co_visit_rank(co_visitation_matrix_type_weighted_lt8) : start
# 1:02:44.297721 	 [features] co_visit_rank(co_visitation_matrix_type_weighted_lt9) : start
# 1:03:36.539710 	 [features] co_visit_rank(co_visitation_matrix_clicks2carts) : start
# 1:03:40.356992 	 [features] co_visit_rank(co_visitation_matrix_clicks2carts_lt0) : start
# 1:03:42.507849 	 [features] co_visit_rank(co_visitation_matrix_clicks2carts_lt1) : start
# 1:03:44.628215 	 [features] co_visit_rank(co_visitation_matrix_clicks2carts_lt2) : start
# 1:03:46.260060 	 [features] co_visit_rank(co_visitation_matrix_clicks2carts_lt3) : start
# 1:03:47.813721 	 [features] co_visit_rank(co_visitation_matrix_clicks2carts_lt4) : start
# 1:03:49.276560 	 [features] co_visit_rank(co_visitation_matrix_clicks2carts_lt5) : start
# 1:03:50.696224 	 [features] co_visit_rank(co_visitation_matrix_clicks2carts_lt6) : start
# 1:03:52.118809 	 [features] co_visit_rank(co_visitation_matrix_clicks2carts_lt7) : start
# 1:03:53.504895 	 [features] co_visit_rank(co_visitation_matrix_clicks2carts_lt8) : start
# 1:03:54.898753 	 [features] co_visit_rank(co_visitation_matrix_clicks2carts_lt9) : start
# 1:03:56.342077 	 [features] co_visit_rank(co_visitation_matrix_clicks2orders) : start
# 1:03:57.374548 	 [features] co_visit_rank(co_visitation_matrix_clicks2orders_lt0) : start
# 1:03:57.881915 	 [features] co_visit_rank(co_visitation_matrix_clicks2orders_lt1) : start
# 1:03:58.356832 	 [features] co_visit_rank(co_visitation_matrix_clicks2orders_lt2) : start
# 1:03:58.816418 	 [features] co_visit_rank(co_visitation_matrix_clicks2orders_lt3) : start
# 1:03:59.274145 	 [features] co_visit_rank(co_visitation_matrix_clicks2orders_lt4) : start
# 1:03:59.713513 	 [features] co_visit_rank(co_visitation_matrix_clicks2orders_lt5) : start
# 1:04:00.155571 	 [features] co_visit_rank(co_visitation_matrix_clicks2orders_lt6) : start
# 1:04:00.598672 	 [features] co_visit_rank(co_visitation_matrix_clicks2orders_lt7) : start
# 1:04:01.034606 	 [features] co_visit_rank(co_visitation_matrix_clicks2orders_lt8) : start
# 1:04:01.481863 	 [features] co_visit_rank(co_visitation_matrix_clicks2orders_lt9) : start
# 1:04:01.918297 	 [features] latest_aid_w2v_sims : start
# 100%|██████████| 5513764/5513764 [00:54<00:00, 101114.92it/s]
# 100%|██████████| 5513764/5513764 [00:40<00:00, 137280.54it/s]
# 100%|██████████| 5513764/5513764 [00:33<00:00, 165487.07it/s]
# 100%|██████████| 5513764/5513764 [00:29<00:00, 188663.30it/s]
# 100%|██████████| 5513764/5513764 [00:25<00:00, 215082.19it/s]
# 100%|██████████| 5513764/5513764 [00:22<00:00, 250050.48it/s]
# 100%|██████████| 5513764/5513764 [00:20<00:00, 274075.54it/s]
# 100%|██████████| 5513764/5513764 [00:18<00:00, 298155.43it/s]
# 100%|██████████| 5513764/5513764 [00:16<00:00, 324814.93it/s]
# 100%|██████████| 5513764/5513764 [00:15<00:00, 353645.48it/s]
# 1:09:27.604839 	 make clicks_valid_data
# 1:09:27.612495 	 [valid_cand.parquet] cache exists. read cache and skip process.
# 1:09:29.896583 	 make clicks_valid_data
# 1:09:29.937532 	 [features] session_cnt : start
# 1:09:31.808711 	 [features] session_aid_nunique : start
# 1:09:32.239940 	 [features] session_last_type : start
# 1:09:32.525235 	 [features] aid_cnt : start
# 1:09:33.236461 	 [features] aid_clicks_cnt : start
# 1:09:33.863843 	 [features] aid_carts_cnt : start
# 1:09:34.360077 	 [features] aid_orders_cnt : start
# 1:09:34.848720 	 [features] all_times_aid_freq : start
# 1:09:35.984509 	 [features] all_times_aid_clicks_freq : start
# 1:09:37.004861 	 [features] all_times_aid_carts_freq : start
# 1:09:37.626098 	 [features] all_times_aid_orders_freq : start
# 1:09:38.079740 	 [features] all_times_aid_session_freq : start
# 1:09:38.929781 	 [features] all_times_aid_session_clicks_freq : start
# 1:09:39.781976 	 [features] all_times_aid_session_carts_freq : start
# 1:09:40.411479 	 [features] all_times_aid_session_orders_freq : start
# 1:09:40.903722 	 [features] all_times_aid_carts_ratio_with_clicks : start
# 1:09:41.843893 	 [features] all_times_aid_orders_ratio_with_clicks : start
# 1:09:42.791248 	 [features] all_times_aid_date_std : start
# 1:09:43.732022 	 [features] all_times_aid_hour_std : start
# 1:09:44.699879 	 [features] all_times_aid_day_of_week_std : start
# 1:09:45.686538 	 [features] w2v_vectors : start
# 1:09:46.713816 	 [features] relative_ts : start
# 1:09:52.085542 	 [features] co_visit_rank(co_visitation_matrix) : start
# 1:10:13.260673 	 [features] co_visit_rank(co_visitation_matrix_lt0) : start
# 1:10:39.247170 	 [features] co_visit_rank(co_visitation_matrix_lt1) : start
# 1:11:03.668910 	 [features] co_visit_rank(co_visitation_matrix_lt2) : start
# 1:11:27.363338 	 [features] co_visit_rank(co_visitation_matrix_lt3) : start
# 1:11:50.585891 	 [features] co_visit_rank(co_visitation_matrix_lt4) : start
# 1:12:13.214045 	 [features] co_visit_rank(co_visitation_matrix_lt5) : start
# 1:12:35.666330 	 [features] co_visit_rank(co_visitation_matrix_lt6) : start
# 1:12:57.692694 	 [features] co_visit_rank(co_visitation_matrix_lt7) : start
# 1:13:19.838613 	 [features] co_visit_rank(co_visitation_matrix_lt8) : start
# 1:13:41.818349 	 [features] co_visit_rank(co_visitation_matrix_lt9) : start
# 1:14:03.665180 	 [features] co_visit_rank(co_visitation_matrix_time_weighted) : start
# 1:14:53.166226 	 [features] co_visit_rank(co_visitation_matrix_time_weighted_lt0) : start
# 1:15:45.464038 	 [features] co_visit_rank(co_visitation_matrix_time_weighted_lt1) : start
# 1:16:35.583693 	 [features] co_visit_rank(co_visitation_matrix_time_weighted_lt2) : start
# 1:17:25.044143 	 [features] co_visit_rank(co_visitation_matrix_time_weighted_lt3) : start
# 1:18:14.665070 	 [features] co_visit_rank(co_visitation_matrix_time_weighted_lt4) : start
# 1:19:04.127513 	 [features] co_visit_rank(co_visitation_matrix_time_weighted_lt5) : start
# 1:19:53.259264 	 [features] co_visit_rank(co_visitation_matrix_time_weighted_lt6) : start
# 1:20:41.188022 	 [features] co_visit_rank(co_visitation_matrix_time_weighted_lt7) : start
# 1:21:29.872343 	 [features] co_visit_rank(co_visitation_matrix_time_weighted_lt8) : start
# 1:22:18.495271 	 [features] co_visit_rank(co_visitation_matrix_time_weighted_lt9) : start
# 1:23:08.423260 	 [features] co_visit_rank(co_visitation_matrix_type_weighted) : start
# 1:23:42.166254 	 [features] co_visit_rank(co_visitation_matrix_type_weighted_lt0) : start
# 1:24:35.453652 	 [features] co_visit_rank(co_visitation_matrix_type_weighted_lt1) : start
# 1:25:27.397237 	 [features] co_visit_rank(co_visitation_matrix_type_weighted_lt2) : start
# 1:26:19.160712 	 [features] co_visit_rank(co_visitation_matrix_type_weighted_lt3) : start
# 1:27:11.980840 	 [features] co_visit_rank(co_visitation_matrix_type_weighted_lt4) : start
# 1:28:06.853928 	 [features] co_visit_rank(co_visitation_matrix_type_weighted_lt5) : start
# 1:28:59.991506 	 [features] co_visit_rank(co_visitation_matrix_type_weighted_lt6) : start
# 1:29:54.604811 	 [features] co_visit_rank(co_visitation_matrix_type_weighted_lt7) : start
# 1:30:47.759588 	 [features] co_visit_rank(co_visitation_matrix_type_weighted_lt8) : start
# 1:31:40.411913 	 [features] co_visit_rank(co_visitation_matrix_type_weighted_lt9) : start
# 1:32:33.766056 	 [features] co_visit_rank(co_visitation_matrix_clicks2carts) : start
# 1:32:37.317360 	 [features] co_visit_rank(co_visitation_matrix_clicks2carts_lt0) : start
# 1:32:40.555919 	 [features] co_visit_rank(co_visitation_matrix_clicks2carts_lt1) : start
# 1:32:43.227437 	 [features] co_visit_rank(co_visitation_matrix_clicks2carts_lt2) : start
# 1:32:45.326601 	 [features] co_visit_rank(co_visitation_matrix_clicks2carts_lt3) : start
# 1:32:47.242445 	 [features] co_visit_rank(co_visitation_matrix_clicks2carts_lt4) : start
# 1:32:49.180928 	 [features] co_visit_rank(co_visitation_matrix_clicks2carts_lt5) : start
# 1:32:51.044039 	 [features] co_visit_rank(co_visitation_matrix_clicks2carts_lt6) : start
# 1:32:52.887253 	 [features] co_visit_rank(co_visitation_matrix_clicks2carts_lt7) : start
# 1:32:54.746887 	 [features] co_visit_rank(co_visitation_matrix_clicks2carts_lt8) : start
# 1:32:56.626710 	 [features] co_visit_rank(co_visitation_matrix_clicks2carts_lt9) : start
# 1:32:58.501239 	 [features] co_visit_rank(co_visitation_matrix_clicks2orders) : start
# 1:32:59.507652 	 [features] co_visit_rank(co_visitation_matrix_clicks2orders_lt0) : start
# 1:33:00.415010 	 [features] co_visit_rank(co_visitation_matrix_clicks2orders_lt1) : start
# 1:33:01.291798 	 [features] co_visit_rank(co_visitation_matrix_clicks2orders_lt2) : start
# 1:33:02.145873 	 [features] co_visit_rank(co_visitation_matrix_clicks2orders_lt3) : start
# 1:33:03.002333 	 [features] co_visit_rank(co_visitation_matrix_clicks2orders_lt4) : start
# 1:33:03.927536 	 [features] co_visit_rank(co_visitation_matrix_clicks2orders_lt5) : start
# 1:33:04.751088 	 [features] co_visit_rank(co_visitation_matrix_clicks2orders_lt6) : start
# 1:33:05.618461 	 [features] co_visit_rank(co_visitation_matrix_clicks2orders_lt7) : start
# 1:33:06.445999 	 [features] co_visit_rank(co_visitation_matrix_clicks2orders_lt8) : start
# 1:33:07.291488 	 [features] co_visit_rank(co_visitation_matrix_clicks2orders_lt9) : start
# 1:33:08.111952 	 [features] latest_aid_w2v_sims : start
# 100%|██████████| 17915065/17915065 [02:59<00:00, 99656.49it/s]
# 100%|██████████| 17915065/17915065 [02:28<00:00, 120503.85it/s]
# 100%|██████████| 17915065/17915065 [02:11<00:00, 135828.94it/s]
# 100%|██████████| 17915065/17915065 [01:59<00:00, 150005.34it/s]
# 100%|██████████| 17915065/17915065 [01:48<00:00, 165043.51it/s]
# 100%|██████████| 17915065/17915065 [01:39<00:00, 179286.72it/s]
# 100%|██████████| 17915065/17915065 [01:33<00:00, 191601.61it/s]
# 100%|██████████| 17915065/17915065 [01:27<00:00, 204396.49it/s]
# 100%|██████████| 17915065/17915065 [01:21<00:00, 219096.15it/s]
# 100%|██████████| 17915065/17915065 [01:16<00:00, 234130.42it/s]
# 1:52:20.585317 	 valid(clicks) pos : 59174  neg : 17855891
# /home/kaggler/.local/lib/python3.8/site-packages/lightgbm/engine.py:181: UserWarning: 'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. Pass 'early_stopping()' callback via 'callbacks' argument instead.
#   _log_warning("'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. "
# /home/kaggler/.local/lib/python3.8/site-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# [LightGBM] [Info] Number of positive: 2756882, number of negative: 2756882
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.893355 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 21134
# [LightGBM] [Info] Number of data points in the train set: 5513764, number of used features: 91
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500000 -> initscore=0.000000
# Training until validation scores don't improve for 100 rounds
# [100]	training's binary_logloss: 0.405948	valid_1's binary_logloss: 0.397251
# [200]	training's binary_logloss: 0.332044	valid_1's binary_logloss: 0.3215
# [300]	training's binary_logloss: 0.309335	valid_1's binary_logloss: 0.29871
# [400]	training's binary_logloss: 0.301402	valid_1's binary_logloss: 0.291264
# [500]	training's binary_logloss: 0.297922	valid_1's binary_logloss: 0.288332
# [600]	training's binary_logloss: 0.296097	valid_1's binary_logloss: 0.286868
# [700]	training's binary_logloss: 0.294863	valid_1's binary_logloss: 0.285922
# [800]	training's binary_logloss: 0.29391	valid_1's binary_logloss: 0.285211
# [900]	training's binary_logloss: 0.293151	valid_1's binary_logloss: 0.284695
# [1000]	training's binary_logloss: 0.292513	valid_1's binary_logloss: 0.284269
# [1100]	training's binary_logloss: 0.291973	valid_1's binary_logloss: 0.283926
# [1200]	training's binary_logloss: 0.291494	valid_1's binary_logloss: 0.283624
# [1300]	training's binary_logloss: 0.291072	valid_1's binary_logloss: 0.28335
# [1400]	training's binary_logloss: 0.290701	valid_1's binary_logloss: 0.283144
# [1500]	training's binary_logloss: 0.29037	valid_1's binary_logloss: 0.282978
# [1600]	training's binary_logloss: 0.290055	valid_1's binary_logloss: 0.282775
# [1700]	training's binary_logloss: 0.289772	valid_1's binary_logloss: 0.28262
# [1800]	training's binary_logloss: 0.289501	valid_1's binary_logloss: 0.282502
# [1900]	training's binary_logloss: 0.28926	valid_1's binary_logloss: 0.282386
# [2000]	training's binary_logloss: 0.289023	valid_1's binary_logloss: 0.282261
# [2100]	training's binary_logloss: 0.288796	valid_1's binary_logloss: 0.282172
# [2200]	training's binary_logloss: 0.28859	valid_1's binary_logloss: 0.282093
# [2300]	training's binary_logloss: 0.288385	valid_1's binary_logloss: 0.282008
# [2400]	training's binary_logloss: 0.288192	valid_1's binary_logloss: 0.281933
# [2500]	training's binary_logloss: 0.288	valid_1's binary_logloss: 0.281854
# [2600]	training's binary_logloss: 0.287811	valid_1's binary_logloss: 0.281798
# [2700]	training's binary_logloss: 0.287633	valid_1's binary_logloss: 0.281738
# [2800]	training's binary_logloss: 0.287455	valid_1's binary_logloss: 0.281681
# [2900]	training's binary_logloss: 0.287285	valid_1's binary_logloss: 0.281622
# [3000]	training's binary_logloss: 0.287107	valid_1's binary_logloss: 0.281559
# [3100]	training's binary_logloss: 0.286946	valid_1's binary_logloss: 0.281513
# [3200]	training's binary_logloss: 0.286786	valid_1's binary_logloss: 0.281469
# [3300]	training's binary_logloss: 0.28663	valid_1's binary_logloss: 0.281426
# [3400]	training's binary_logloss: 0.286471	valid_1's binary_logloss: 0.281373
# [3500]	training's binary_logloss: 0.286313	valid_1's binary_logloss: 0.281318
# [3600]	training's binary_logloss: 0.286167	valid_1's binary_logloss: 0.281262
# [3700]	training's binary_logloss: 0.286018	valid_1's binary_logloss: 0.281237
# [3800]	training's binary_logloss: 0.28587	valid_1's binary_logloss: 0.281207
# [3900]	training's binary_logloss: 0.285717	valid_1's binary_logloss: 0.28116
# [4000]	training's binary_logloss: 0.285565	valid_1's binary_logloss: 0.281118
# [4100]	training's binary_logloss: 0.28542	valid_1's binary_logloss: 0.281072
# [4200]	training's binary_logloss: 0.285276	valid_1's binary_logloss: 0.281034
# [4300]	training's binary_logloss: 0.285132	valid_1's binary_logloss: 0.281004
# [4400]	training's binary_logloss: 0.284997	valid_1's binary_logloss: 0.280968
# [4500]	training's binary_logloss: 0.284858	valid_1's binary_logloss: 0.28094
# [4600]	training's binary_logloss: 0.284719	valid_1's binary_logloss: 0.280908
# [4700]	training's binary_logloss: 0.284586	valid_1's binary_logloss: 0.280873
# [4800]	training's binary_logloss: 0.284462	valid_1's binary_logloss: 0.280852
# [4900]	training's binary_logloss: 0.284336	valid_1's binary_logloss: 0.280838
# [5000]	training's binary_logloss: 0.284193	valid_1's binary_logloss: 0.280797
# [5100]	training's binary_logloss: 0.284063	valid_1's binary_logloss: 0.280769
# [5200]	training's binary_logloss: 0.283934	valid_1's binary_logloss: 0.280752
# [5300]	training's binary_logloss: 0.283806	valid_1's binary_logloss: 0.280735
# [5400]	training's binary_logloss: 0.283675	valid_1's binary_logloss: 0.280711
# [5500]	training's binary_logloss: 0.283553	valid_1's binary_logloss: 0.280687
# [5600]	training's binary_logloss: 0.283434	valid_1's binary_logloss: 0.280662
# [5700]	training's binary_logloss: 0.283313	valid_1's binary_logloss: 0.280648
# [5800]	training's binary_logloss: 0.283185	valid_1's binary_logloss: 0.280637
# [5900]	training's binary_logloss: 0.283061	valid_1's binary_logloss: 0.280608
# [6000]	training's binary_logloss: 0.282941	valid_1's binary_logloss: 0.280593
# [6100]	training's binary_logloss: 0.282819	valid_1's binary_logloss: 0.280576
# [6200]	training's binary_logloss: 0.282694	valid_1's binary_logloss: 0.280546
# [6300]	training's binary_logloss: 0.282579	valid_1's binary_logloss: 0.280536
# [6400]	training's binary_logloss: 0.282454	valid_1's binary_logloss: 0.280496
# [6500]	training's binary_logloss: 0.282332	valid_1's binary_logloss: 0.280477
# [6600]	training's binary_logloss: 0.28221	valid_1's binary_logloss: 0.280461
# [6700]	training's binary_logloss: 0.282096	valid_1's binary_logloss: 0.280453
# [6800]	training's binary_logloss: 0.281975	valid_1's binary_logloss: 0.280425
# [6900]	training's binary_logloss: 0.281861	valid_1's binary_logloss: 0.280412
# [7000]	training's binary_logloss: 0.281736	valid_1's binary_logloss: 0.280395
# [7100]	training's binary_logloss: 0.281619	valid_1's binary_logloss: 0.280377
# [7200]	training's binary_logloss: 0.281501	valid_1's binary_logloss: 0.280368
# [7300]	training's binary_logloss: 0.28139	valid_1's binary_logloss: 0.280341
# [7400]	training's binary_logloss: 0.281275	valid_1's binary_logloss: 0.280332
# [7500]	training's binary_logloss: 0.281166	valid_1's binary_logloss: 0.28032
# [7600]	training's binary_logloss: 0.281054	valid_1's binary_logloss: 0.280312
# [7700]	training's binary_logloss: 0.280938	valid_1's binary_logloss: 0.280284
# Early stopping, best iteration is:
# [7688]	training's binary_logloss: 0.280952	valid_1's binary_logloss: 0.280282
# 3:08:51.318673 	 clicks valid score
# 3:08:51.321245 	 {'num_clicks': 97136, 'hit_clicks': 49604, 'num_carts': 43211, 'hit_carts': 14851, 'num_orders': 20082, 'hit_orders': 11142, 'recall_clicks': '0.510665', 'recall_carts': '0.343686', 'recall_orders': '0.554825', 'w_recall_clicks': '0.051067', 'w_recall_carts': '0.103106', 'w_recall_orders': '0.332895', 'score': '0.487067'}
# 3:08:53.499021 	 make carts_train_data
# 3:08:53.504565 	 [carts_train.parquet] cache exists. read cache and skip process.
# 3:08:55.873896 	 make carts_valid_data
# 3:08:55.880333 	 [valid_cand.parquet] cache exists. read cache and skip process.
# 3:08:57.329456 	 make carts_valid_data
# 3:08:57.332943 	 [carts_valid.parquet] cache exists. read cache and skip process.
# 3:09:17.565066 	 [carts_model.lgb] cache exists. read cache and skip process.
# 3:24:30.337892 	 carts valid score
# 3:24:30.340068 	 {'num_clicks': 97136, 'hit_clicks': 47820, 'num_carts': 43211, 'hit_carts': 15499, 'num_orders': 20082, 'hit_orders': 11801, 'recall_clicks': '0.492299', 'recall_carts': '0.358682', 'recall_orders': '0.587641', 'w_recall_clicks': '0.049230', 'w_recall_carts': '0.107605', 'w_recall_orders': '0.352584', 'score': '0.509419'}
# 3:24:32.091439 	 make orders_train_data
# 3:24:32.095937 	 [orders_train.parquet] cache exists. read cache and skip process.
# 3:24:33.502107 	 make orders_valid_data
# 3:24:33.508429 	 [valid_cand.parquet] cache exists. read cache and skip process.
# 3:24:34.915519 	 make orders_valid_data
# 3:24:34.918064 	 [orders_valid.parquet] cache exists. read cache and skip process.
# 3:24:53.727881 	 [orders_model.lgb] cache exists. read cache and skip process.
# 3:30:12.052618 	 orders valid score
# 3:30:12.054072 	 {'num_clicks': 97136, 'hit_clicks': 46174, 'num_carts': 43211, 'hit_carts': 15084, 'num_orders': 20082, 'hit_orders': 11947, 'recall_clicks': '0.475354', 'recall_carts': '0.349078', 'recall_orders': '0.594911', 'w_recall_clicks': '0.047535', 'w_recall_carts': '0.104723', 'w_recall_orders': '0.356947', 'score': '0.509205'}
# 3:30:55.424783 	 [make_test] make_cand_df
# 3:30:55.602839 	 [add_candidate] repurchase : start
# 3:30:56.891313 	 [add_candidate] clstr_freq : start
# 3:31:10.405248 	 [add_candidate] session_latest_time_wt_pair0 : start
# 3:31:11.763564 	 [add_candidate] session_latest_word2vec_pair0 : start
# 3:31:12.865698 	 [add_candidate] session_latest_pair0 : start
# 3:31:14.010894 	 [add_candidate] session_latest_type_wt_pair0 : start
# 3:31:15.151376 	 [add_candidate] session_latest_clicks2carts_pair0 : start
# 3:31:16.420755 	 [add_candidate] session_latest_clicks2orders_pair0 : start
# 3:31:17.364875 	 [add_candidate] session_latest_time_wt_pair1 : start
# 3:31:18.545615 	 [add_candidate] session_latest_word2vec_pair1 : start
# 3:31:19.779458 	 [add_candidate] session_latest_pair1 : start
# 3:31:20.854628 	 [add_candidate] session_latest_type_wt_pair1 : start
# 3:31:21.984177 	 [add_candidate] session_latest_clicks2carts_pair1 : start
# 3:31:23.202747 	 [add_candidate] session_latest_clicks2orders_pair1 : start
# 3:31:24.074880 	 [add_candidate] session_latest_time_wt_pair2 : start
# 3:31:25.183866 	 [add_candidate] session_latest_word2vec_pair2 : start
# 3:31:26.484839 	 [add_candidate] session_latest_pair2 : start
# 3:31:27.569159 	 [add_candidate] session_latest_type_wt_pair2 : start
# 3:31:28.713836 	 [add_candidate] session_latest_clicks2carts_pair2 : start
# 3:31:29.800132 	 [add_candidate] session_latest_clicks2orders_pair2 : start
# 3:31:30.761778 	 [add_candidate] session_latest_time_wt_pair3 : start
# 3:31:32.000544 	 [add_candidate] session_latest_word2vec_pair3 : start
# 3:31:33.185375 	 [add_candidate] session_latest_pair3 : start
# 3:31:34.428422 	 [add_candidate] session_latest_type_wt_pair3 : start
# 3:31:35.585492 	 [add_candidate] session_latest_clicks2carts_pair3 : start
# 3:31:36.815788 	 [add_candidate] session_latest_clicks2orders_pair3 : start
# 3:31:37.748347 	 [add_candidate] session_latest_time_wt_pair4 : start
# 3:31:38.922457 	 [add_candidate] session_latest_word2vec_pair4 : start
# 3:31:40.119006 	 [add_candidate] session_latest_pair4 : start
# 3:31:41.252981 	 [add_candidate] session_latest_type_wt_pair4 : start
# 3:31:42.391542 	 [add_candidate] session_latest_clicks2carts_pair4 : start
# 3:31:43.649924 	 [add_candidate] session_latest_clicks2orders_pair4 : start
# 3:31:44.577770 	 [add_candidate] session_latest_time_wt_pair5 : start
# 3:31:45.828467 	 [add_candidate] session_latest_word2vec_pair5 : start
# 3:31:46.993566 	 [add_candidate] session_latest_pair5 : start
# 3:31:48.311682 	 [add_candidate] session_latest_type_wt_pair5 : start
# 3:31:49.469090 	 [add_candidate] session_latest_clicks2carts_pair5 : start
# 3:31:50.652736 	 [add_candidate] session_latest_clicks2orders_pair5 : start
# 3:31:51.535152 	 [add_candidate] session_latest_time_wt_pair6 : start
# 3:31:52.688910 	 [add_candidate] session_latest_word2vec_pair6 : start
# 3:31:53.855558 	 [add_candidate] session_latest_pair6 : start
# 3:31:55.020332 	 [add_candidate] session_latest_type_wt_pair6 : start
# 3:31:56.327078 	 [add_candidate] session_latest_clicks2carts_pair6 : start
# 3:31:57.378866 	 [add_candidate] session_latest_clicks2orders_pair6 : start
# 3:31:58.303655 	 [add_candidate] session_latest_time_wt_pair7 : start
# 3:31:59.570351 	 [add_candidate] session_latest_word2vec_pair7 : start
# 3:32:00.695998 	 [add_candidate] session_latest_pair7 : start
# 3:32:01.875121 	 [add_candidate] session_latest_type_wt_pair7 : start
# 3:32:03.058276 	 [add_candidate] session_latest_clicks2carts_pair7 : start
# 3:32:04.233969 	 [add_candidate] session_latest_clicks2orders_pair7 : start
# 3:32:05.162575 	 [add_candidate] session_latest_time_wt_pair8 : start
# 3:32:06.313223 	 [add_candidate] session_latest_word2vec_pair8 : start
# 3:32:07.545402 	 [add_candidate] session_latest_pair8 : start
# 3:32:08.670767 	 [add_candidate] session_latest_type_wt_pair8 : start
# 3:32:09.854406 	 [add_candidate] session_latest_clicks2carts_pair8 : start
# 3:32:11.067977 	 [add_candidate] session_latest_clicks2orders_pair8 : start
# 3:32:11.936016 	 [add_candidate] session_latest_time_wt_pair9 : start
# 3:32:13.075613 	 [add_candidate] session_latest_word2vec_pair9 : start
# 3:32:14.274783 	 [add_candidate] session_latest_pair9 : start
# 3:32:15.563421 	 [add_candidate] session_latest_type_wt_pair9 : start
# 3:32:16.710385 	 [add_candidate] session_latest_clicks2carts_pair9 : start
# 3:32:17.823523 	 [add_candidate] session_latest_clicks2orders_pair9 : start
# 3:32:18.907783 	 [add_candidate] session_latest_time_wt_pair10 : start
# 3:32:20.007875 	 [add_candidate] session_latest_word2vec_pair10 : start
# 3:32:21.158778 	 [add_candidate] session_latest_pair10 : start
# 3:32:22.496604 	 [add_candidate] session_latest_type_wt_pair10 : start
# 3:32:23.622353 	 [add_candidate] session_latest_clicks2carts_pair10 : start
# 3:32:24.699825 	 [add_candidate] session_latest_clicks2orders_pair10 : start
# 3:32:25.687166 	 [add_candidate] session_latest_time_wt_pair11 : start
# 3:32:26.950438 	 [add_candidate] session_latest_word2vec_pair11 : start
# 3:32:28.068621 	 [add_candidate] session_latest_pair11 : start
# 3:32:29.233694 	 [add_candidate] session_latest_type_wt_pair11 : start
# 3:32:30.566161 	 [add_candidate] session_latest_clicks2carts_pair11 : start
# 3:32:31.590066 	 [add_candidate] session_latest_clicks2orders_pair11 : start
# 3:32:32.548728 	 [add_candidate] session_latest_time_wt_pair12 : start
# 3:32:33.891911 	 [add_candidate] session_latest_word2vec_pair12 : start
# 3:32:35.027399 	 [add_candidate] session_latest_pair12 : start
# 3:32:36.187597 	 [add_candidate] session_latest_type_wt_pair12 : start
# 3:32:37.361869 	 [add_candidate] session_latest_clicks2carts_pair12 : start
# 3:32:38.604373 	 [add_candidate] session_latest_clicks2orders_pair12 : start
# 3:32:39.540092 	 [add_candidate] session_latest_time_wt_pair13 : start
# 3:32:40.739278 	 [add_candidate] session_latest_word2vec_pair13 : start
# 3:32:41.979993 	 [add_candidate] session_latest_pair13 : start
# 3:32:43.128097 	 [add_candidate] session_latest_type_wt_pair13 : start
# 3:32:44.426776 	 [add_candidate] session_latest_clicks2carts_pair13 : start
# 3:32:45.488332 	 [add_candidate] session_latest_clicks2orders_pair13 : start
# 3:32:46.509752 	 [add_candidate] session_latest_time_wt_pair14 : start
# 3:32:47.643562 	 [add_candidate] session_latest_word2vec_pair14 : start
# 3:32:48.781976 	 [add_candidate] session_latest_pair14 : start
# 3:32:50.121239 	 [add_candidate] session_latest_type_wt_pair14 : start
# 3:32:51.282303 	 [add_candidate] session_latest_clicks2carts_pair14 : start
# 3:32:52.370514 	 [add_candidate] session_latest_clicks2orders_pair14 : start
# 3:32:53.395320 	 [add_candidate] session_latest_time_wt_pair15 : start
# 3:32:54.576658 	 [add_candidate] session_latest_word2vec_pair15 : start
# 3:32:55.845903 	 [add_candidate] session_latest_pair15 : start
# 3:32:57.146533 	 [add_candidate] session_latest_type_wt_pair15 : start
# 3:32:58.258363 	 [add_candidate] session_latest_clicks2carts_pair15 : start
# 3:32:59.316595 	 [add_candidate] session_latest_clicks2orders_pair15 : start
# 3:33:00.292392 	 [add_candidate] session_latest_time_wt_pair16 : start
# 3:33:01.501529 	 [add_candidate] session_latest_word2vec_pair16 : start
# 3:33:02.788844 	 [add_candidate] session_latest_pair16 : start
# 3:33:03.962339 	 [add_candidate] session_latest_type_wt_pair16 : start
# ...
# 100%|██████████| 81458309/81458309 [07:06<00:00, 191170.67it/s]
# 100%|██████████| 81458309/81458309 [06:16<00:00, 216487.51it/s]
# 100%|██████████| 81458309/81458309 [05:30<00:00, 246450.69it/s]
# 100%|██████████| 81458309/81458309 [05:10<00:00, 262015.66it/s]
# 100%|██████████| 81458309/81458309 [04:41<00:00, 289121.72it/s]
# 100%|██████████| 81458309/81458309 [04:21<00:00, 311482.41it/s]
# 100%|██████████| 81458309/81458309 [03:59<00:00, 339866.20it/s]
# 7:06:45.353746 	 [make_test] make_cand_df
# 7:06:45.690953 	 [add_candidate] repurchase : start
# 7:06:47.234283 	 [add_candidate] clstr_freq : start
# 7:07:02.848650 	 [add_candidate] session_latest_time_wt_pair0 : start
# 7:07:06.148643 	 [add_candidate] session_latest_word2vec_pair0 : start
# 7:07:09.380554 	 [add_candidate] session_latest_pair0 : start
# 7:07:11.264026 	 [add_candidate] session_latest_type_wt_pair0 : start
# 7:07:12.975452 	 [add_candidate] session_latest_clicks2carts_pair0 : start
# 7:07:14.729219 	 [add_candidate] session_latest_clicks2orders_pair0 : start
# 7:07:16.189359 	 [add_candidate] session_latest_time_wt_pair1 : start
# 7:07:17.710626 	 [add_candidate] session_latest_word2vec_pair1 : start
# 7:07:20.272399 	 [add_candidate] session_latest_pair1 : start
# 7:07:22.046406 	 [add_candidate] session_latest_type_wt_pair1 : start
# 7:07:23.819152 	 [add_candidate] session_latest_clicks2carts_pair1 : start
# 7:07:25.574799 	 [add_candidate] session_latest_clicks2orders_pair1 : start
# 7:07:27.103304 	 [add_candidate] session_latest_time_wt_pair2 : start
# 7:07:28.570065 	 [add_candidate] session_latest_word2vec_pair2 : start
# 7:07:31.235258 	 [add_candidate] session_latest_pair2 : start
# 7:07:32.986002 	 [add_candidate] session_latest_type_wt_pair2 : start
# 7:07:34.890998 	 [add_candidate] session_latest_clicks2carts_pair2 : start
# 7:07:36.773727 	 [add_candidate] session_latest_clicks2orders_pair2 : start
# 7:07:37.992709 	 [add_candidate] session_latest_time_wt_pair3 : start
# 7:07:39.431414 	 [add_candidate] session_latest_word2vec_pair3 : start
# 7:07:42.200379 	 [add_candidate] session_latest_pair3 : start
# 7:07:43.727408 	 [add_candidate] session_latest_type_wt_pair3 : start
# 7:07:45.702525 	 [add_candidate] session_latest_clicks2carts_pair3 : start
# 7:07:47.563828 	 [add_candidate] session_latest_clicks2orders_pair3 : start
# 7:07:48.872455 	 [add_candidate] session_latest_time_wt_pair4 : start
# 7:07:50.338049 	 [add_candidate] session_latest_word2vec_pair4 : start
# 7:07:53.043669 	 [add_candidate] session_latest_pair4 : start
# 7:07:54.839121 	 [add_candidate] session_latest_type_wt_pair4 : start
# 7:07:56.184647 	 [add_candidate] session_latest_clicks2carts_pair4 : start
# 7:07:58.109144 	 [add_candidate] session_latest_clicks2orders_pair4 : start
# 7:07:59.456961 	 [add_candidate] session_latest_time_wt_pair5 : start
# 7:08:00.832981 	 [add_candidate] session_latest_word2vec_pair5 : start
# 7:08:03.282217 	 [add_candidate] session_latest_pair5 : start
# 7:08:04.795794 	 [add_candidate] session_latest_type_wt_pair5 : start
# 7:08:06.164341 	 [add_candidate] session_latest_clicks2carts_pair5 : start
# 7:08:08.119644 	 [add_candidate] session_latest_clicks2orders_pair5 : start
# 7:08:09.384753 	 [add_candidate] session_latest_time_wt_pair6 : start
# 7:08:10.901053 	 [add_candidate] session_latest_word2vec_pair6 : start
# 7:08:13.164954 	 [add_candidate] session_latest_pair6 : start
# 7:08:14.895123 	 [add_candidate] session_latest_type_wt_pair6 : start
# 7:08:16.552312 	 [add_candidate] session_latest_clicks2carts_pair6 : start
# 7:08:18.534666 	 [add_candidate] session_latest_clicks2orders_pair6 : start
# 7:08:19.990915 	 [add_candidate] session_latest_time_wt_pair7 : start
# 7:08:21.373570 	 [add_candidate] session_latest_word2vec_pair7 : start
# 7:08:23.817827 	 [add_candidate] session_latest_pair7 : start
# 7:08:25.638618 	 [add_candidate] session_latest_type_wt_pair7 : start
# 7:08:27.184777 	 [add_candidate] session_latest_clicks2carts_pair7 : start
# 7:08:29.268980 	 [add_candidate] session_latest_clicks2orders_pair7 : start
# 7:08:30.730403 	 [add_candidate] session_latest_time_wt_pair8 : start
# 7:08:32.230960 	 [add_candidate] session_latest_word2vec_pair8 : start
# 7:08:34.792485 	 [add_candidate] session_latest_pair8 : start
# 7:08:36.336691 	 [add_candidate] session_latest_type_wt_pair8 : start
# 7:08:38.948050 	 [add_candidate] session_latest_clicks2carts_pair8 : start
# 7:08:41.193012 	 [add_candidate] session_latest_clicks2orders_pair8 : start
# 7:08:42.689000 	 [add_candidate] session_latest_time_wt_pair9 : start
# 7:08:44.702929 	 [add_candidate] session_latest_word2vec_pair9 : start
# 7:08:46.938111 	 [add_candidate] session_latest_pair9 : start
# 7:08:48.466175 	 [add_candidate] session_latest_type_wt_pair9 : start
# 7:08:51.056456 	 [add_candidate] session_latest_clicks2carts_pair9 : start
# 7:08:53.134324 	 [add_candidate] session_latest_clicks2orders_pair9 : start
# 7:08:54.480175 	 [add_candidate] session_latest_time_wt_pair10 : start
# 7:08:56.542615 	 [add_candidate] session_latest_word2vec_pair10 : start
# 7:08:58.811207 	 [add_candidate] session_latest_pair10 : start
# 7:09:00.446129 	 [add_candidate] session_latest_type_wt_pair10 : start
# 7:09:02.969289 	 [add_candidate] session_latest_clicks2carts_pair10 : start
# 7:09:05.071019 	 [add_candidate] session_latest_clicks2orders_pair10 : start
# 7:09:06.394883 	 [add_candidate] session_latest_time_wt_pair11 : start
# 7:09:08.119072 	 [add_candidate] session_latest_word2vec_pair11 : start
# 7:09:10.494700 	 [add_candidate] session_latest_pair11 : start
# 7:09:12.382605 	 [add_candidate] session_latest_type_wt_pair11 : start
# 7:09:15.099472 	 [add_candidate] session_latest_clicks2carts_pair11 : start
# 7:09:17.341678 	 [add_candidate] session_latest_clicks2orders_pair11 : start
# 7:09:18.743896 	 [add_candidate] session_latest_time_wt_pair12 : start
# 7:09:20.215928 	 [add_candidate] session_latest_word2vec_pair12 : start
# 7:09:22.567265 	 [add_candidate] session_latest_pair12 : start
# 7:09:24.252001 	 [add_candidate] session_latest_type_wt_pair12 : start
# 7:09:26.963183 	 [add_candidate] session_latest_clicks2carts_pair12 : start
# 7:09:29.102164 	 [add_candidate] session_latest_clicks2orders_pair12 : start
# 7:09:30.508758 	 [add_candidate] session_latest_time_wt_pair13 : start
# 7:09:32.030487 	 [add_candidate] session_latest_word2vec_pair13 : start
# 7:09:34.224628 	 [add_candidate] session_latest_pair13 : start
# 7:09:35.718452 	 [add_candidate] session_latest_type_wt_pair13 : start
# 7:09:38.327238 	 [add_candidate] session_latest_clicks2carts_pair13 : start
# 7:09:40.527567 	 [add_candidate] session_latest_clicks2orders_pair13 : start
# 7:09:42.111515 	 [add_candidate] session_latest_time_wt_pair14 : start
# 7:09:43.908266 	 [add_candidate] session_latest_word2vec_pair14 : start
# 7:09:46.233564 	 [add_candidate] session_latest_pair14 : start
# 7:09:47.688427 	 [add_candidate] session_latest_type_wt_pair14 : start
# 7:09:50.290829 	 [add_candidate] session_latest_clicks2carts_pair14 : start
# 7:09:52.409531 	 [add_candidate] session_latest_clicks2orders_pair14 : start
# 7:09:53.918589 	 [add_candidate] session_latest_time_wt_pair15 : start
# 7:09:55.698055 	 [add_candidate] session_latest_word2vec_pair15 : start
# 7:09:58.035487 	 [add_candidate] session_latest_pair15 : start
# 7:09:59.523091 	 [add_candidate] session_latest_type_wt_pair15 : start
# 7:10:02.106630 	 [add_candidate] session_latest_clicks2carts_pair15 : start
# 7:10:04.156854 	 [add_candidate] session_latest_clicks2orders_pair15 : start
# 7:10:05.733251 	 [add_candidate] session_latest_time_wt_pair16 : start
# 7:10:07.524280 	 [add_candidate] session_latest_word2vec_pair16 : start
# 7:10:09.794628 	 [add_candidate] session_latest_pair16 : start
# 7:10:11.327003 	 [add_candidate] session_latest_type_wt_pair16 : start
# 7:10:13.948046 	 [add_candidate] session_latest_clicks2carts_pair16 : start
# 7:10:16.032082 	 [add_candidate] session_latest_clicks2orders_pair16 : start
# 7:10:17.494839 	 [add_candidate] session_latest_time_wt_pair17 : start
# 7:10:19.159027 	 [add_candidate] session_latest_word2vec_pair17 : start
# 7:10:21.655272 	 [add_candidate] session_latest_pair17 : start
# 7:10:23.268414 	 [add_candidate] session_latest_type_wt_pair17 : start
# 7:10:25.964479 	 [add_candidate] session_latest_clicks2carts_pair17 : start
# 7:10:28.044543 	 [add_candidate] session_latest_clicks2orders_pair17 : start
# 7:10:29.530807 	 [add_candidate] session_latest_time_wt_pair18 : start
# 7:10:31.206369 	 [add_candidate] session_latest_word2vec_pair18 : start
# 7:10:33.840758 	 [add_candidate] session_latest_pair18 : start
# 7:10:35.659952 	 [add_candidate] session_latest_type_wt_pair18 : start
# 7:10:38.333617 	 [add_candidate] session_latest_clicks2carts_pair18 : start
# 7:10:40.475682 	 [add_candidate] session_latest_clicks2orders_pair18 : start
# 7:10:42.032244 	 [add_candidate] session_latest_time_wt_pair19 : start
# 7:10:43.789068 	 [add_candidate] session_latest_word2vec_pair19 : start
# 7:10:46.405951 	 [add_candidate] session_latest_pair19 : start
# 7:10:48.208072 	 [add_candidate] session_latest_type_wt_pair19 : start
# 7:10:50.863209 	 [add_candidate] session_latest_clicks2carts_pair19 : start
# 7:10:53.020181 	 [add_candidate] session_latest_clicks2orders_pair19 : start
# 7:11:27.943290 	 [make_test] add_features
# 7:11:28.534768 	 [features] session_cnt : start
# 7:11:38.390371 	 [features] session_aid_nunique : start
# 7:11:40.717404 	 [features] session_last_type : start
# 7:11:42.073934 	 [features] aid_cnt : start
# 7:11:45.958574 	 [features] aid_clicks_cnt : start
# 7:11:49.571992 	 [features] aid_carts_cnt : start
# 7:11:52.017034 	 [features] aid_orders_cnt : start
# 7:11:54.334977 	 [features] all_times_aid_freq : start
# 7:11:56.839911 	 [features] all_times_aid_clicks_freq : start
# 7:11:59.265607 	 [features] all_times_aid_carts_freq : start
# 7:12:01.263745 	 [features] all_times_aid_orders_freq : start
# 7:12:02.830310 	 [features] all_times_aid_session_freq : start
# 7:12:05.047517 	 [features] all_times_aid_session_clicks_freq : start
# 7:12:07.243974 	 [features] all_times_aid_session_carts_freq : start
# 7:12:09.111033 	 [features] all_times_aid_session_orders_freq : start
# 7:12:10.614757 	 [features] all_times_aid_carts_ratio_with_clicks : start
# 7:12:12.854413 	 [features] all_times_aid_orders_ratio_with_clicks : start
# 7:12:15.142924 	 [features] all_times_aid_date_std : start
# 7:12:17.477788 	 [features] all_times_aid_hour_std : start
# 7:12:19.916007 	 [features] all_times_aid_day_of_week_std : start
# 7:12:22.263016 	 [features] w2v_vectors : start
# 7:12:24.417749 	 [features] relative_ts : start
# 7:12:51.214865 	 [features] co_visit_rank(co_visitation_matrix) : start
# 7:13:18.392121 	 [features] co_visit_rank(co_visitation_matrix_lt0) : start
# 7:13:57.571000 	 [features] co_visit_rank(co_visitation_matrix_lt1) : start
# 7:14:30.604799 	 [features] co_visit_rank(co_visitation_matrix_lt2) : start
# 7:15:02.624767 	 [features] co_visit_rank(co_visitation_matrix_lt3) : start
# 7:15:33.833773 	 [features] co_visit_rank(co_visitation_matrix_lt4) : start
# 7:16:04.090670 	 [features] co_visit_rank(co_visitation_matrix_lt5) : start
# 7:16:34.184751 	 [features] co_visit_rank(co_visitation_matrix_lt6) : start
# 7:17:04.392956 	 [features] co_visit_rank(co_visitation_matrix_lt7) : start
# 7:17:34.471752 	 [features] co_visit_rank(co_visitation_matrix_lt8) : start
# 7:18:04.353425 	 [features] co_visit_rank(co_visitation_matrix_lt9) : start
# 7:18:34.363476 	 [features] co_visit_rank(co_visitation_matrix_time_weighted) : start
# 7:19:28.595622 	 [features] co_visit_rank(co_visitation_matrix_time_weighted_lt0) : start
# 7:21:14.245784 	 [features] co_visit_rank(co_visitation_matrix_time_weighted_lt1) : start
# 7:22:25.461682 	 [features] co_visit_rank(co_visitation_matrix_time_weighted_lt2) : start
# 7:23:30.451835 	 [features] co_visit_rank(co_visitation_matrix_time_weighted_lt3) : start
# 7:24:33.811836 	 [features] co_visit_rank(co_visitation_matrix_time_weighted_lt4) : start
# 7:25:34.596742 	 [features] co_visit_rank(co_visitation_matrix_time_weighted_lt5) : start
# 7:26:39.145658 	 [features] co_visit_rank(co_visitation_matrix_time_weighted_lt6) : start
# 7:27:38.935838 	 [features] co_visit_rank(co_visitation_matrix_time_weighted_lt7) : start
# 7:28:37.412466 	 [features] co_visit_rank(co_visitation_matrix_time_weighted_lt8) : start
# 7:29:35.170824 	 [features] co_visit_rank(co_visitation_matrix_time_weighted_lt9) : start
# 7:30:33.981986 	 [features] co_visit_rank(co_visitation_matrix_type_weighted) : start
# 7:31:11.203371 	 [features] co_visit_rank(co_visitation_matrix_type_weighted_lt0) : start
# 7:32:22.827171 	 [features] co_visit_rank(co_visitation_matrix_type_weighted_lt1) : start
# 7:33:30.261590 	 [features] co_visit_rank(co_visitation_matrix_type_weighted_lt2) : start
# 7:34:41.947153 	 [features] co_visit_rank(co_visitation_matrix_type_weighted_lt3) : start
# 7:35:47.828062 	 [features] co_visit_rank(co_visitation_matrix_type_weighted_lt4) : start
# 7:36:51.737615 	 [features] co_visit_rank(co_visitation_matrix_type_weighted_lt5) : start
# 7:37:55.324885 	 [features] co_visit_rank(co_visitation_matrix_type_weighted_lt6) : start
# 7:38:58.446540 	 [features] co_visit_rank(co_visitation_matrix_type_weighted_lt7) : start
# 7:40:02.874780 	 [features] co_visit_rank(co_visitation_matrix_type_weighted_lt8) : start
# 7:41:06.349688 	 [features] co_visit_rank(co_visitation_matrix_type_weighted_lt9) : start
# 7:42:10.941674 	 [features] co_visit_rank(co_visitation_matrix_clicks2carts) : start
# 7:42:15.259918 	 [features] co_visit_rank(co_visitation_matrix_clicks2carts_lt0) : start
# 7:42:24.208494 	 [features] co_visit_rank(co_visitation_matrix_clicks2carts_lt1) : start
# 7:42:30.779257 	 [features] co_visit_rank(co_visitation_matrix_clicks2carts_lt2) : start
# 7:42:35.955476 	 [features] co_visit_rank(co_visitation_matrix_clicks2carts_lt3) : start
# 7:42:40.983729 	 [features] co_visit_rank(co_visitation_matrix_clicks2carts_lt4) : start
# 7:42:45.923300 	 [features] co_visit_rank(co_visitation_matrix_clicks2carts_lt5) : start
# 7:42:50.701314 	 [features] co_visit_rank(co_visitation_matrix_clicks2carts_lt6) : start
# 7:42:55.148961 	 [features] co_visit_rank(co_visitation_matrix_clicks2carts_lt7) : start
# 7:42:59.402625 	 [features] co_visit_rank(co_visitation_matrix_clicks2carts_lt8) : start
# 7:43:03.709839 	 [features] co_visit_rank(co_visitation_matrix_clicks2carts_lt9) : start
# 7:43:07.982410 	 [features] co_visit_rank(co_visitation_matrix_clicks2orders) : start
# 7:43:09.103313 	 [features] co_visit_rank(co_visitation_matrix_clicks2orders_lt0) : start
# 7:43:12.393240 	 [features] co_visit_rank(co_visitation_matrix_clicks2orders_lt1) : start
# 7:43:15.518903 	 [features] co_visit_rank(co_visitation_matrix_clicks2orders_lt2) : start
# 7:43:18.497002 	 [features] co_visit_rank(co_visitation_matrix_clicks2orders_lt3) : start
# 7:43:21.468022 	 [features] co_visit_rank(co_visitation_matrix_clicks2orders_lt4) : start
# 7:43:24.348256 	 [features] co_visit_rank(co_visitation_matrix_clicks2orders_lt5) : start
# 7:43:27.186346 	 [features] co_visit_rank(co_visitation_matrix_clicks2orders_lt6) : start
# 7:43:30.016002 	 [features] co_visit_rank(co_visitation_matrix_clicks2orders_lt7) : start
# 7:43:32.783128 	 [features] co_visit_rank(co_visitation_matrix_clicks2orders_lt8) : start
# 7:43:35.525942 	 [features] co_visit_rank(co_visitation_matrix_clicks2orders_lt9) : start
# 7:43:38.255388 	 [features] latest_aid_w2v_sims : start
# 100%|██████████| 79878884/79878884 [12:37<00:00, 105419.43it/s]
# 100%|██████████| 79878884/79878884 [09:40<00:00, 137510.15it/s]
# 100%|██████████| 79878884/79878884 [08:07<00:00, 163803.85it/s]
# 100%|██████████| 79878884/79878884 [07:12<00:00, 184904.10it/s]
# 100%|██████████| 79878884/79878884 [06:19<00:00, 210392.99it/s]
# 100%|██████████| 79878884/79878884 [05:35<00:00, 237828.66it/s]
# 100%|██████████| 79878884/79878884 [05:02<00:00, 264339.11it/s]
# 100%|██████████| 79878884/79878884 [04:32<00:00, 293160.45it/s]
# 100%|██████████| 79878884/79878884 [04:09<00:00, 320043.51it/s]
# 100%|██████████| 79878884/79878884 [03:47<00:00, 351798.36it/s]
# 8:55:50.798509 	 -------- inference --------
