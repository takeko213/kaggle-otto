# %% [markdown]
# # cand_trial004

# %%
import os
import sys
import traceback
import gc
import random
import pickle
import pathlib
import subprocess
from dataclasses import dataclass
from dotenv import load_dotenv
load_dotenv
sys.path.append(os.getenv('UTILS_PATH'))
from tqdm import tqdm
import multiprocessing
import inspect

import pandas as pd
import numpy as np
import itertools
import cudf
import lightgbm as lgb
import matplotlib.pyplot as plt
import seaborn as sns
import line_notify
import my_logger
from noglobal import noglobal
import optuna

# %% [markdown]
# # 設定

# %%
@dataclass
class Cfg:
    loglevel = "INFO"
    exp_name = "cand_trial004"
    seed = 42
    k = 20
    cand_n = 15
    type2id = {"clicks":0, "carts":1, "orders":2}
    id2type = {0:"clicks", 1:"carts", 2:"orders"}
    train_weeks = ["week3"]
    valid_week = "week4"
    valid_session_n = 100_000
    input_dir = os.getenv('INPUT_DIR')
    output_dir = os.getenv('OUTPUT_DIR')
    prep_dir = os.getenv("PREP_DIR")

cfg = Cfg()
os.makedirs(os.path.join(cfg.output_dir, cfg.exp_name), exist_ok=True)
os.makedirs(os.path.join(cfg.output_dir, cfg.exp_name, "cache"), exist_ok=True)
random.seed(cfg.seed)

# %%
class Cache:
    @noglobal(excepts=["cfg", "logger"])
    def __init__(self):
        self.cache_dir = (os.path.join(cfg.output_dir, cfg.exp_name, "cache"))
        self.cache_dir_path = pathlib.Path(self.cache_dir)
        self.caches = list(self.cache_dir_path.glob("*.pkl"))

    @noglobal(excepts=["cfg", "logger"])
    def get_abspath(self, filename):
        return (os.path.join(self.cache_dir, f"{cfg.exp_name}_{filename}"))
    
    @noglobal(excepts=["cfg", "logger"])
    def exists(self, path):
        return len([str(c) for c in self.caches if path == str(c)]) > 0

# %%
logger = my_logger.init_logger(cfg.exp_name)
cache = Cache()

# %%
@noglobal(excepts=["cfg", "logger"])
def evaluate(clicks_labels, carts_labels, orders_labels, 
             clicks_preds, carts_preds, orders_preds, k=20):

    num_clicks = 0
    num_carts = 0
    num_orders = 0
    hit_clicks = 0
    hit_carts = 0
    hit_orders = 0

    for i in range(len(clicks_labels)):
        clicks_label = clicks_labels[i]
        carts_label = carts_labels[i]
        orders_label = orders_labels[i]
        clicks_pred = clicks_preds[i]
        carts_pred = carts_preds[i]
        orders_pred = orders_preds[i]

        if type(clicks_pred) == list:
            clicks_pred = clicks_pred[:k]
        else:
            clicks_pred = []
        if type(carts_pred) == list:
            carts_pred = carts_pred[:k]
        else:
            carts_pred = []    
        if type(orders_pred) == list:
            orders_pred = orders_pred[:k]
        else:
            orders_pred = []

        if not np.isnan(clicks_label):
            num_clicks += 1
            hit_clicks += int(clicks_label in clicks_pred)

        if type(carts_label) == list:
            num_carts += min(len(carts_label), k)
            hit_carts += len(set(carts_pred) & set(carts_label))
            
        if type(orders_label) == list:
            num_orders += min(len(orders_label), k)
            hit_orders += len(set(orders_pred) & set(orders_label))


    recall_clicks = hit_clicks / num_clicks
    recall_carts = hit_carts / num_carts
    recall_orders = hit_orders / num_orders
    w_recall_clicks = recall_clicks * 0.10
    w_recall_carts = recall_carts * 0.30
    w_recall_orders = recall_orders * 0.60
    score = w_recall_clicks + w_recall_carts + w_recall_orders

    results = {}
    results["num_clicks"] = num_clicks
    results["hit_clicks"] = hit_clicks
    results["num_carts"] = num_carts
    results["hit_carts"] = hit_carts
    results["num_orders"] = num_orders
    results["hit_orders"] = hit_orders
    results["recall_clicks"] = format(recall_clicks, ".3f")
    results["recall_carts"] = format(recall_carts, ".3f")
    results["recall_orders"] = format(recall_orders, ".3f")
    results["w_recall_clicks"] = format(w_recall_clicks, ".3f")
    results["w_recall_carts"] = format(w_recall_carts, ".3f")
    results["w_recall_orders"] = format(w_recall_orders, ".3f")
    results["score"] = format(score, ".3f")

    return results

# %%
class Candidate:
    @noglobal(excepts=["cfg", "logger"])
    def __init__(self, pdf, week, labels=None):
        self.df = cudf.from_pandas(pdf)
        self.target_sessions = pdf["session"].unique().tolist()
        self.results = pd.DataFrame(columns=["name", "num_clicks", "hit_clicks", "num_carts", "hit_carts", "num_orders", "hit_orders", 
                                             "recall_clicks", "recall_carts", "recall_orders", "w_recall_clicks", "w_recall_carts", "w_recall_orders", "score"])
        self.output = pd.DataFrame(columns=["session", "aid"], dtype=int)
        self.labels = labels
        self.week = week
    
    @noglobal(excepts=["cfg", "logger"])
    def _entry(self, new_candidate_df, name, k):
        logger.info(f"[add_candidate] {name} : start")
        new_candidate_df = new_candidate_df.to_pandas()
        self.output = pd.concat([self.output, new_candidate_df[["session", "aid"]]])
        self.output = self.output.drop_duplicates(subset=["session", "aid"])

        if self.labels is not None:
            self._eval(new_candidate_df[["session", "aid"]], name, k)
    
    @noglobal(excepts=["cfg", "logger"])
    def _eval(self, new_candidate_df, name, k):
        new_candidate_df = new_candidate_df.groupby("session")["aid"].apply(list).reset_index()
        eval_df = pd.DataFrame(self.target_sessions, columns=["session"])
        eval_df = eval_df.merge(new_candidate_df, on=["session"], how="left")
        assert eval_df["session"].tolist() == self.labels["session"].tolist()
        eval_result = evaluate(self.labels["clicks_labels"].tolist(), self.labels["carts_labels"].tolist(), self.labels["orders_labels"].tolist(),
                               eval_df["aid"].tolist(), eval_df["aid"].tolist(), eval_df["aid"].tolist(), k)
        
        logger.info(name)
        logger.info(eval_result)
        self.results = pd.concat([self.results, pd.DataFrame([[name] + list(eval_result.values())], columns=["name"] + list(eval_result.keys()))])

    @noglobal(excepts=["cfg", "logger"])
    def add(self, strategy, name, usetypes=['clicks', 'carts', 'orders'], trans_map=None, k=20):
        logger.info(f"[make_candidate] {name} : start")
        candidate_df = self.df[self.df["type"].isin(usetypes)].copy()
        
        if strategy == "session_frequent":
            candidate_df = self._session_frequent(candidate_df, k)
        elif strategy == "session_latest":
            candidate_df = self._session_latest(candidate_df, k)
        elif strategy == "total_frequent":
            candidate_df = self._total_frequent(candidate_df, k)
        elif strategy == "w2v_session_total_aid_vec_sim":
            candidate_df = self._w2v_session_total_aid_vec_sim()
        elif strategy == "w2v_session_carts_total_aid_vec_sim":
            candidate_df = self._w2v_session_carts_total_aid_vec_sim()
        
        if trans_map is not None:
            candidate_df["aid"] = candidate_df["aid"].map(trans_map)
            candidate_df = candidate_df.dropna(subset=["aid"])
            
        self._entry(candidate_df, name, k)

    @noglobal(excepts=["cfg", "logger"])
    def _session_frequent(self, candidate_df, k):
        candidate_df = candidate_df.groupby(["session", "aid"])["ts"].count().reset_index()
        candidate_df.columns = ["session", "aid", "aid_count"]
        candidate_df = candidate_df.sort_values(["session", "aid_count", "aid"], ascending=(True, False, True))
        candidate_df = candidate_df[candidate_df.groupby("session")["aid_count"].cumcount() < k].copy()
        candidate_df = candidate_df[["session", "aid"]].copy()
        return candidate_df

    @noglobal(excepts=["cfg", "logger"])
    def _session_latest(self, candidate_df, k):
        candidate_df = candidate_df.sort_values(["session", "ts"], ascending=(True, False)).drop_duplicates(subset=["session", "aid"])
        candidate_df = candidate_df.sort_values(["session", "ts"], ascending=(True, False))[candidate_df.groupby("session")["ts"].cumcount() < k].copy()
        candidate_df = candidate_df[["session", "aid"]].copy()
        return candidate_df

    @noglobal(excepts=["cfg", "logger"])
    def _total_frequent(self, candidate_df, k):
        candidate_df = candidate_df.groupby("aid")["ts"].count().reset_index()
        candidate_df.columns = ["aid", "aid_count"]
        topk_freq_aids = candidate_df.sort_values("aid_count", ascending=False)["aid"].to_arrow().to_pylist()[:k]
        sessions = []
        aids = []
        for session, aid in itertools.product(self.target_sessions, topk_freq_aids):
            sessions.append(session)
            aids.append(aid)
        candidate_df = cudf.DataFrame({"session": sessions, "aid": aids})
        return candidate_df

    @noglobal(excepts=["cfg", "logger"])
    def _w2v_session_total_aid_vec_sim(self):
        if self.week is not None:
            candidate_df = pd.read_pickle(cfg.prep_dir + f"w2v_session_total_avg_similar_aids_{self.week}.pkl")
        else:
            candidate_df = pd.read_pickle(cfg.prep_dir + "w2v_session_total_avg_similar_aids.pkl")
        candidate_df = cudf.from_pandas(candidate_df)
        candidate_df = candidate_df[["session", "aid"]].copy()
        candidate_df = candidate_df[candidate_df["session"].isin(self.target_sessions)]
        return candidate_df

    @noglobal(excepts=["cfg", "logger"])
    def _w2v_session_carts_total_aid_vec_sim(self):
        if self.week is not None:
            candidate_df = pd.read_pickle(cfg.prep_dir + f"w2v_session_carts_total_avg_similar_aids_{self.week}.pkl")
        else:
            candidate_df = pd.read_pickle(cfg.prep_dir + "w2v_session_carts_total_avg_similar_aids.pkl")
        candidate_df = cudf.from_pandas(candidate_df)
        candidate_df = candidate_df[["session", "aid"]].copy()
        candidate_df = candidate_df[candidate_df["session"].isin(self.target_sessions)]
        return candidate_df

# %%
@noglobal(excepts=["cfg", "logger"])
def make_cand_df(sessions, week, labels=None, trans_maps=None):

    if labels is not None:
         cand = Candidate(sessions, week, labels)
    else:
        cand = Candidate(sessions, week)

    cand.add(strategy="session_frequent", name="session_frequent", k=15)
    cand.add(strategy="session_latest", name="session_latest", k=15)
    cand.add(strategy="w2v_session_total_aid_vec_sim", name="w2v_session_total_aid_vec_sim")
    cand.add(strategy="w2v_session_carts_total_aid_vec_sim", name="w2v_session_carts_total_aid_vec_sim")
    
    for i in range(20):
        cand.add(strategy="session_latest", trans_map=trans_maps[f"time_wt_pair{str(i)}"], name=f"session_latest_time_wt_pair{str(i)}", k=5)
        cand.add(strategy="session_latest", trans_map=trans_maps[f"word2vec_pair{str(i)}"], name=f"session_latest_word2vec_pair{str(i)}", k=5)
        cand.add(strategy="session_latest", trans_map=trans_maps[f"pair{str(i)}"], name=f"session_latest_pair{str(i)}", k=5)
        cand.add(strategy="session_latest", trans_map=trans_maps[f"type_wt_pair{str(i)}"], name=f"session_latest_type_wt_pair{str(i)}", k=5)
        cand.add(strategy="session_latest", trans_map=trans_maps[f"clicks2carts_pair{str(i)}"], name=f"session_latest_clicks2carts_pair{str(i)}", k=5)
        cand.add(strategy="session_latest", trans_map=trans_maps[f"clicks2orders_pair{str(i)}"], name=f"session_latest_clicks2orders_pair{str(i)}", k=5)

    if labels is not None:
        return cand.output, cand.results
    else:
        return cand.output

# %%
@noglobal(excepts=["cfg", "logger"])
def get_pair_df(name, wt_col, week):
    if week is not None:
        name = f"{name}_{week}"
    pair_df = pd.read_pickle(cfg.prep_dir + f"{name}.pkl")
    pair_df = pair_df.sort_values(["aid_x", wt_col], ascending=(True, False))
    return pair_df

@noglobal(excepts=["cfg", "logger"])
def get_pair_dict(name, wt_col, week):
    if week is not None:
        name = f"{name}_{week}"
    pair_df = pd.read_pickle(cfg.prep_dir + f"{name}.pkl")
    pair_df = pair_df.sort_values(["aid_x", wt_col], ascending=(True, False))
    pair_df = pair_df.groupby("aid_x").head(1)[["aid_x", "aid_y"]]
    pair_dict = {k: v for k, v in zip(pair_df["aid_x"].tolist(), pair_df["aid_y"].tolist())}
    return pair_dict

@noglobal(excepts=["cfg", "logger"])
def get_trans_maps(week=None):
    """
    aidを別のaidに置き換えるmapping辞書を取得する
    """
    trans_maps = {}
    
    pair_df_org = get_pair_df("co_visitation_matrix", "cnt", week)
    for i in range(20):
        pair_df = pair_df_org.groupby("aid_x").nth(i).reset_index()[["aid_x", "aid_y"]]
        pair_dict = {k: v for k, v in zip(pair_df["aid_x"].tolist(), pair_df["aid_y"].tolist())}
        trans_maps[f"pair{str(i)}"] = pair_dict
    
    pair_df_org = get_pair_df("co_visitation_matrix_time_weighted", "wt", week)
    for i in range(20):
        pair_df = pair_df_org.groupby("aid_x").nth(i).reset_index()[["aid_x", "aid_y"]]
        pair_dict = {k: v for k, v in zip(pair_df["aid_x"].tolist(), pair_df["aid_y"].tolist())}
        trans_maps[f"time_wt_pair{str(i)}"] = pair_dict

    pair_df_org = get_pair_df("co_visitation_matrix_type_weighted", "wt", week)
    for i in range(20):
        pair_df = pair_df_org.groupby("aid_x").nth(i).reset_index()[["aid_x", "aid_y"]]
        pair_dict = {k: v for k, v in zip(pair_df["aid_x"].tolist(), pair_df["aid_y"].tolist())}
        trans_maps[f"type_wt_pair{str(i)}"] = pair_dict

    pair_df_org = get_pair_df("co_visitation_matrix_clicks2carts", "cnt", week)
    for i in range(20):
        pair_df = pair_df_org.groupby("aid_x").nth(i).reset_index()[["aid_x", "aid_y"]]
        pair_dict = {k: v for k, v in zip(pair_df["aid_x"].tolist(), pair_df["aid_y"].tolist())}
        trans_maps[f"clicks2carts_pair{str(i)}"] = pair_dict

    pair_df_org = get_pair_df("co_visitation_matrix_clicks2orders", "cnt", week)
    for i in range(20):
        pair_df = pair_df_org.groupby("aid_x").nth(i).reset_index()[["aid_x", "aid_y"]]
        pair_dict = {k: v for k, v in zip(pair_df["aid_x"].tolist(), pair_df["aid_y"].tolist())}
        trans_maps[f"clicks2orders_pair{str(i)}"] = pair_dict

    pair_df_org = get_pair_df("word2vec_similar", "sim", None)
    for i in range(20):
        pair_df = pair_df_org.groupby("aid_x").nth(i).reset_index()[["aid_x", "aid_y"]]
        pair_dict = {k: v for k, v in zip(pair_df["aid_x"].tolist(), pair_df["aid_y"].tolist())}
        trans_maps[f"word2vec_pair{str(i)}"] = pair_dict

    with open(cfg.prep_dir + "matrix_factorization_embeddings_similar_top20.pkl", "rb") as f:
        nns = pickle.load(f)
    for i in range(20):
        pair_dict = {aid_x:aid_ys[i] for aid_x, aid_ys in enumerate(nns)}
        trans_maps[f"matrix_fact_pair{str(i)}"] = pair_dict

    return trans_maps

# %%
@noglobal(excepts=["cfg", "logger"])
def make_valid_data(trans_maps):
    valid_week = cfg.valid_week
    dfs = []
    
    logger.info(f"[make_valid] valid_week : {valid_week}")
    # データ読み込み
    logger.info("[make_valid] read_data : start")
    week_sessions = pd.read_pickle(os.getenv("PREP_DIR") + f"train_sessions_{valid_week}.pkl")
    week_labels = pd.read_pickle(os.getenv("PREP_DIR") + f"labels_{valid_week}.pkl")
    valid_session_ids = week_sessions["session"].unique().tolist()
    logger.info("[make_valid] read_data : end")

    # validに使うsessionを絞る (trainに存在するsessionを除外した上で設定した数に絞る)
    logger.info("[make_valid] valid_session_extract : start")
    valid_session_n = min(cfg.valid_session_n, len(valid_session_ids))
    valid_session_ids = random.sample(valid_session_ids, valid_session_n)
    week_sessions = week_sessions[week_sessions["session"].isin(valid_session_ids)].copy()
    week_labels = week_labels[week_labels["session"].isin(valid_session_ids)].copy()
    logger.info("[make_valid] valid_session_extract : end")

    # 候補選出
    logger.info("[make_valid] make_cand_df : start")
    valid, results = make_cand_df(week_sessions, valid_week, labels=week_labels, trans_maps=trans_maps)

    return valid, week_labels, results

# %%
logger.info("\n\nSTART\n\n")
cache_file = f"trans_maps.pkl"
cache_path = cache.get_abspath(cache_file)

if cache.exists(cache_path):
    logger.info(f"[{cache_file}] cache exists. load cache and skip process.")
    with open(cache_path, "rb") as f:
        trans_maps = pickle.load(f)
else:
    trans_maps = get_trans_maps()
    with open(cache_path, "wb") as f:
        pickle.dump(trans_maps, f)

valid, valid_labels, results = make_valid_data(trans_maps)
# Out:
# 0:00:00.217592
#
# START
#
#
# 0:41:41.070133 	 [make_valid] valid_week : week4
# 0:41:41.095795 	 [make_valid] read_data : start
# 0:41:48.706030 	 [make_valid] read_data : end
# 0:41:48.707267 	 [make_valid] valid_session_extract : start
# 0:41:49.746154 	 [make_valid] valid_session_extract : end
# 0:41:49.747653 	 [make_valid] make_cand_df : start
# 0:41:49.889338 	 [make_candidate] session_frequent : start
# 0:41:50.273015 	 [add_candidate] session_frequent : start
# 0:41:51.915387 	 session_frequent
# 0:41:51.916808 	 {'num_clicks': 97136, 'hit_clicks': 29467, 'num_carts': 42864, 'hit_carts': 10730, 'num_orders': 19985, 'hit_orders': 10185, 'recall_clicks': '0.303', 'recall_carts': '0.250', 'recall_orders': '0.510', 'w_recall_clicks': '0.030', 'w_recall_carts': '0.075', 'w_recall_orders': '0.306', 'score': '0.411'}
# 0:41:51.931472 	 [make_candidate] session_latest : start
# 0:41:52.137966 	 [add_candidate] session_latest : start
# 0:41:53.951173 	 session_latest
# 0:41:53.952556 	 {'num_clicks': 97136, 'hit_clicks': 29677, 'num_carts': 42864, 'hit_carts': 10822, 'num_orders': 19985, 'hit_orders': 9838, 'recall_clicks': '0.306', 'recall_carts': '0.252', 'recall_orders': '0.492', 'w_recall_clicks': '0.031', 'w_recall_carts': '0.076', 'w_recall_orders': '0.295', 'score': '0.402'}
# 0:41:53.964023 	 [make_candidate] w2v_session_total_aid_vec_sim : start
# 0:42:04.049955 	 [add_candidate] w2v_session_total_aid_vec_sim : start
# 0:42:06.320890 	 w2v_session_total_aid_vec_sim
# 0:42:06.322975 	 {'num_clicks': 97136, 'hit_clicks': 33577, 'num_carts': 43211, 'hit_carts': 8796, 'num_orders': 20082, 'hit_orders': 5541, 'recall_clicks': '0.346', 'recall_carts': '0.204', 'recall_orders': '0.276', 'w_recall_clicks': '0.035', 'w_recall_carts': '0.061', 'w_recall_orders': '0.166', 'score': '0.261'}
# 0:42:06.355897 	 [make_candidate] w2v_session_carts_total_aid_vec_sim : start
# 0:42:08.331282 	 [add_candidate] w2v_session_carts_total_aid_vec_sim : start
# 0:42:09.271101 	 w2v_session_carts_total_aid_vec_sim
# 0:42:09.272262 	 {'num_clicks': 97136, 'hit_clicks': 4803, 'num_carts': 43211, 'hit_carts': 3151, 'num_orders': 20082, 'hit_orders': 4854, 'recall_clicks': '0.049', 'recall_carts': '0.073', 'recall_orders': '0.242', 'w_recall_clicks': '0.005', 'w_recall_carts': '0.022', 'w_recall_orders': '0.145', 'score': '0.172'}
# 0:42:09.279615 	 [make_candidate] session_latest_time_wt_pair0 : start
# 0:42:09.698921 	 [add_candidate] session_latest_time_wt_pair0 : start
# 0:42:11.711138 	 session_latest_time_wt_pair0
# 0:42:11.712422 	 {'num_clicks': 97136, 'hit_clicks': 8458, 'num_carts': 37850, 'hit_carts': 2410, 'num_orders': 17856, 'hit_orders': 1542, 'recall_clicks': '0.087', 'recall_carts': '0.064', 'recall_orders': '0.086', 'w_recall_clicks': '0.009', 'w_recall_carts': '0.019', 'w_recall_orders': '0.052', 'score': '0.080'}
# 0:42:11.721805 	 [make_candidate] session_latest_word2vec_pair0 : start
# 0:42:12.045765 	 [add_candidate] session_latest_word2vec_pair0 : start
# 0:42:13.916312 	 session_latest_word2vec_pair0
# 0:42:13.917725 	 {'num_clicks': 97136, 'hit_clicks': 4513, 'num_carts': 37850, 'hit_carts': 1459, 'num_orders': 17856, 'hit_orders': 806, 'recall_clicks': '0.046', 'recall_carts': '0.039', 'recall_orders': '0.045', 'w_recall_clicks': '0.005', 'w_recall_carts': '0.012', 'w_recall_orders': '0.027', 'score': '0.043'}
# 0:42:13.927133 	 [make_candidate] session_latest_pair0 : start
# 0:42:14.587774 	 [add_candidate] session_latest_pair0 : start
# 0:42:16.616802 	 session_latest_pair0
# 0:42:16.618032 	 {'num_clicks': 97136, 'hit_clicks': 7296, 'num_carts': 37850, 'hit_carts': 2826, 'num_orders': 17856, 'hit_orders': 1885, 'recall_clicks': '0.075', 'recall_carts': '0.075', 'recall_orders': '0.106', 'w_recall_clicks': '0.008', 'w_recall_carts': '0.022', 'w_recall_orders': '0.063', 'score': '0.093'}
# 0:42:16.628115 	 [make_candidate] session_latest_type_wt_pair0 : start
# 0:42:17.122590 	 [add_candidate] session_latest_type_wt_pair0 : start
# 0:42:19.188189 	 session_latest_type_wt_pair0
# 0:42:19.189872 	 {'num_clicks': 97136, 'hit_clicks': 7082, 'num_carts': 37850, 'hit_carts': 3305, 'num_orders': 17856, 'hit_orders': 2294, 'recall_clicks': '0.073', 'recall_carts': '0.087', 'recall_orders': '0.128', 'w_recall_clicks': '0.007', 'w_recall_carts': '0.026', 'w_recall_orders': '0.077', 'score': '0.111'}
# 0:42:19.199349 	 [make_candidate] session_latest_clicks2carts_pair0 : start
# 0:42:19.454130 	 [add_candidate] session_latest_clicks2carts_pair0 : start
# 0:42:21.483408 	 session_latest_clicks2carts_pair0
# 0:42:21.484721 	 {'num_clicks': 97136, 'hit_clicks': 4440, 'num_carts': 37850, 'hit_carts': 2661, 'num_orders': 17856, 'hit_orders': 1555, 'recall_clicks': '0.046', 'recall_carts': '0.070', 'recall_orders': '0.087', 'w_recall_clicks': '0.005', 'w_recall_carts': '0.021', 'w_recall_orders': '0.052', 'score': '0.078'}
# 0:42:21.494676 	 [make_candidate] session_latest_clicks2orders_pair0 : start
# 0:42:21.810856 	 [add_candidate] session_latest_clicks2orders_pair0 : start
# 0:42:23.719248 	 session_latest_clicks2orders_pair0
# 0:42:23.720361 	 {'num_clicks': 97136, 'hit_clicks': 2874, 'num_carts': 37850, 'hit_carts': 1788, 'num_orders': 17856, 'hit_orders': 1636, 'recall_clicks': '0.030', 'recall_carts': '0.047', 'recall_orders': '0.092', 'w_recall_clicks': '0.003', 'w_recall_carts': '0.014', 'w_recall_orders': '0.055', 'score': '0.072'}
# 0:42:23.729884 	 [make_candidate] session_latest_time_wt_pair1 : start
# 0:42:24.442378 	 [add_candidate] session_latest_time_wt_pair1 : start
# 0:42:26.509756 	 session_latest_time_wt_pair1
# 0:42:26.510915 	 {'num_clicks': 97136, 'hit_clicks': 5948, 'num_carts': 37850, 'hit_carts': 1868, 'num_orders': 17856, 'hit_orders': 1074, 'recall_clicks': '0.061', 'recall_carts': '0.049', 'recall_orders': '0.060', 'w_recall_clicks': '0.006', 'w_recall_carts': '0.015', 'w_recall_orders': '0.036', 'score': '0.057'}
# 0:42:26.521003 	 [make_candidate] session_latest_word2vec_pair1 : start
# 0:42:26.853504 	 [add_candidate] session_latest_word2vec_pair1 : start
# 0:42:28.927962 	 session_latest_word2vec_pair1
# 0:42:28.929164 	 {'num_clicks': 97136, 'hit_clicks': 3132, 'num_carts': 37850, 'hit_carts': 1037, 'num_orders': 17856, 'hit_orders': 580, 'recall_clicks': '0.032', 'recall_carts': '0.027', 'recall_orders': '0.032', 'w_recall_clicks': '0.003', 'w_recall_carts': '0.008', 'w_recall_orders': '0.019', 'score': '0.031'}
# 0:42:28.939821 	 [make_candidate] session_latest_pair1 : start
# 0:42:29.637714 	 [add_candidate] session_latest_pair1 : start
# 0:42:31.722198 	 session_latest_pair1
# 0:42:31.723441 	 {'num_clicks': 97136, 'hit_clicks': 5060, 'num_carts': 37850, 'hit_carts': 2181, 'num_orders': 17856, 'hit_orders': 1373, 'recall_clicks': '0.052', 'recall_carts': '0.058', 'recall_orders': '0.077', 'w_recall_clicks': '0.005', 'w_recall_carts': '0.017', 'w_recall_orders': '0.046', 'score': '0.069'}
# 0:42:31.733274 	 [make_candidate] session_latest_type_wt_pair1 : start
# 0:42:32.045130 	 [add_candidate] session_latest_type_wt_pair1 : start
# 0:42:34.327312 	 session_latest_type_wt_pair1
# 0:42:34.328543 	 {'num_clicks': 97136, 'hit_clicks': 4994, 'num_carts': 37850, 'hit_carts': 2510, 'num_orders': 17856, 'hit_orders': 1625, 'recall_clicks': '0.051', 'recall_carts': '0.066', 'recall_orders': '0.091', 'w_recall_clicks': '0.005', 'w_recall_carts': '0.020', 'w_recall_orders': '0.055', 'score': '0.080'}
# 0:42:34.337492 	 [make_candidate] session_latest_clicks2carts_pair1 : start
# 0:42:34.689919 	 [add_candidate] session_latest_clicks2carts_pair1 : start
# 0:42:36.904713 	 session_latest_clicks2carts_pair1
# 0:42:36.906398 	 {'num_clicks': 97136, 'hit_clicks': 3026, 'num_carts': 37850, 'hit_carts': 1917, 'num_orders': 17856, 'hit_orders': 1060, 'recall_clicks': '0.031', 'recall_carts': '0.051', 'recall_orders': '0.059', 'w_recall_clicks': '0.003', 'w_recall_carts': '0.015', 'w_recall_orders': '0.036', 'score': '0.054'}
# 0:42:36.916424 	 [make_candidate] session_latest_clicks2orders_pair1 : start
# 0:42:37.367792 	 [add_candidate] session_latest_clicks2orders_pair1 : start
# 0:42:39.464542 	 session_latest_clicks2orders_pair1
# 0:42:39.465702 	 {'num_clicks': 97136, 'hit_clicks': 1735, 'num_carts': 37850, 'hit_carts': 1095, 'num_orders': 17856, 'hit_orders': 1070, 'recall_clicks': '0.018', 'recall_carts': '0.029', 'recall_orders': '0.060', 'w_recall_clicks': '0.002', 'w_recall_carts': '0.009', 'w_recall_orders': '0.036', 'score': '0.046'}
# 0:42:39.474162 	 [make_candidate] session_latest_time_wt_pair2 : start
# 0:42:39.961131 	 [add_candidate] session_latest_time_wt_pair2 : start
# 0:42:42.138012 	 session_latest_time_wt_pair2
# 0:42:42.139205 	 {'num_clicks': 97136, 'hit_clicks': 4681, 'num_carts': 37850, 'hit_carts': 1531, 'num_orders': 17856, 'hit_orders': 880, 'recall_clicks': '0.048', 'recall_carts': '0.040', 'recall_orders': '0.049', 'w_recall_clicks': '0.005', 'w_recall_carts': '0.012', 'w_recall_orders': '0.030', 'score': '0.047'}
# 0:42:42.149605 	 [make_candidate] session_latest_word2vec_pair2 : start
# 0:42:42.603531 	 [add_candidate] session_latest_word2vec_pair2 : start
# 0:42:44.903407 	 session_latest_word2vec_pair2
# 0:42:44.904825 	 {'num_clicks': 97136, 'hit_clicks': 2525, 'num_carts': 37850, 'hit_carts': 832, 'num_orders': 17856, 'hit_orders': 472, 'recall_clicks': '0.026', 'recall_carts': '0.022', 'recall_orders': '0.026', 'w_recall_clicks': '0.003', 'w_recall_carts': '0.007', 'w_recall_orders': '0.016', 'score': '0.025'}
# 0:42:44.915820 	 [make_candidate] session_latest_pair2 : start
# 0:42:45.520903 	 [add_candidate] session_latest_pair2 : start
# 0:42:47.791444 	 session_latest_pair2
# 0:42:47.792794 	 {'num_clicks': 97136, 'hit_clicks': 3941, 'num_carts': 37850, 'hit_carts': 1802, 'num_orders': 17856, 'hit_orders': 1171, 'recall_clicks': '0.041', 'recall_carts': '0.048', 'recall_orders': '0.066', 'w_recall_clicks': '0.004', 'w_recall_carts': '0.014', 'w_recall_orders': '0.039', 'score': '0.058'}
# 0:42:47.808544 	 [make_candidate] session_latest_type_wt_pair2 : start
# 0:42:48.092545 	 [add_candidate] session_latest_type_wt_pair2 : start
# 0:42:50.388078 	 session_latest_type_wt_pair2
# 0:42:50.389282 	 {'num_clicks': 97136, 'hit_clicks': 3690, 'num_carts': 37850, 'hit_carts': 2109, 'num_orders': 17856, 'hit_orders': 1362, 'recall_clicks': '0.038', 'recall_carts': '0.056', 'recall_orders': '0.076', 'w_recall_clicks': '0.004', 'w_recall_carts': '0.017', 'w_recall_orders': '0.046', 'score': '0.066'}
# 0:42:50.400248 	 [make_candidate] session_latest_clicks2carts_pair2 : start
# 0:42:50.697336 	 [add_candidate] session_latest_clicks2carts_pair2 : start
# 0:42:52.921376 	 session_latest_clicks2carts_pair2
# 0:42:52.922827 	 {'num_clicks': 97136, 'hit_clicks': 2370, 'num_carts': 37850, 'hit_carts': 1560, 'num_orders': 17856, 'hit_orders': 853, 'recall_clicks': '0.024', 'recall_carts': '0.041', 'recall_orders': '0.048', 'w_recall_clicks': '0.002', 'w_recall_carts': '0.012', 'w_recall_orders': '0.029', 'score': '0.043'}
# 0:42:52.933755 	 [make_candidate] session_latest_clicks2orders_pair2 : start
# 0:42:53.370402 	 [add_candidate] session_latest_clicks2orders_pair2 : start
# 0:42:55.465101 	 session_latest_clicks2orders_pair2
# 0:42:55.466377 	 {'num_clicks': 97136, 'hit_clicks': 1293, 'num_carts': 37850, 'hit_carts': 840, 'num_orders': 17856, 'hit_orders': 817, 'recall_clicks': '0.013', 'recall_carts': '0.022', 'recall_orders': '0.046', 'w_recall_clicks': '0.001', 'w_recall_carts': '0.007', 'w_recall_orders': '0.027', 'score': '0.035'}
# 0:42:55.475915 	 [make_candidate] session_latest_time_wt_pair3 : start
# 0:42:55.958904 	 [add_candidate] session_latest_time_wt_pair3 : start
# 0:42:58.302555 	 session_latest_time_wt_pair3
# 0:42:58.304198 	 {'num_clicks': 97136, 'hit_clicks': 3873, 'num_carts': 37850, 'hit_carts': 1321, 'num_orders': 17856, 'hit_orders': 792, 'recall_clicks': '0.040', 'recall_carts': '0.035', 'recall_orders': '0.044', 'w_recall_clicks': '0.004', 'w_recall_carts': '0.010', 'w_recall_orders': '0.027', 'score': '0.041'}
# 0:42:58.314994 	 [make_candidate] session_latest_word2vec_pair3 : start
# 0:42:58.760941 	 [add_candidate] session_latest_word2vec_pair3 : start
# 0:43:01.095297 	 session_latest_word2vec_pair3
# 0:43:01.096908 	 {'num_clicks': 97136, 'hit_clicks': 1970, 'num_carts': 37850, 'hit_carts': 715, 'num_orders': 17856, 'hit_orders': 427, 'recall_clicks': '0.020', 'recall_carts': '0.019', 'recall_orders': '0.024', 'w_recall_clicks': '0.002', 'w_recall_carts': '0.006', 'w_recall_orders': '0.014', 'score': '0.022'}
# 0:43:01.109032 	 [make_candidate] session_latest_pair3 : start
# 0:43:01.659381 	 [add_candidate] session_latest_pair3 : start
# 0:43:04.023208 	 session_latest_pair3
# 0:43:04.024538 	 {'num_clicks': 97136, 'hit_clicks': 3288, 'num_carts': 37850, 'hit_carts': 1508, 'num_orders': 17856, 'hit_orders': 990, 'recall_clicks': '0.034', 'recall_carts': '0.040', 'recall_orders': '0.055', 'w_recall_clicks': '0.003', 'w_recall_carts': '0.012', 'w_recall_orders': '0.033', 'score': '0.049'}
# 0:43:04.034669 	 [make_candidate] session_latest_type_wt_pair3 : start
# 0:43:04.332778 	 [add_candidate] session_latest_type_wt_pair3 : start
# 0:43:06.708519 	 session_latest_type_wt_pair3
# 0:43:06.709843 	 {'num_clicks': 97136, 'hit_clicks': 3251, 'num_carts': 37850, 'hit_carts': 1832, 'num_orders': 17856, 'hit_orders': 1137, 'recall_clicks': '0.033', 'recall_carts': '0.048', 'recall_orders': '0.064', 'w_recall_clicks': '0.003', 'w_recall_carts': '0.015', 'w_recall_orders': '0.038', 'score': '0.056'}
# 0:43:06.720269 	 [make_candidate] session_latest_clicks2carts_pair3 : start
# 0:43:07.019865 	 [add_candidate] session_latest_clicks2carts_pair3 : start
# 0:43:09.168726 	 session_latest_clicks2carts_pair3
# 0:43:09.169908 	 {'num_clicks': 97136, 'hit_clicks': 1868, 'num_carts': 37850, 'hit_carts': 1261, 'num_orders': 17856, 'hit_orders': 671, 'recall_clicks': '0.019', 'recall_carts': '0.033', 'recall_orders': '0.038', 'w_recall_clicks': '0.002', 'w_recall_carts': '0.010', 'w_recall_orders': '0.023', 'score': '0.034'}
# 0:43:09.180395 	 [make_candidate] session_latest_clicks2orders_pair3 : start
# 0:43:09.572256 	 [add_candidate] session_latest_clicks2orders_pair3 : start
# 0:43:11.781935 	 session_latest_clicks2orders_pair3
# 0:43:11.783504 	 {'num_clicks': 97136, 'hit_clicks': 1014, 'num_carts': 37850, 'hit_carts': 655, 'num_orders': 17856, 'hit_orders': 636, 'recall_clicks': '0.010', 'recall_carts': '0.017', 'recall_orders': '0.036', 'w_recall_clicks': '0.001', 'w_recall_carts': '0.005', 'w_recall_orders': '0.021', 'score': '0.028'}
# 0:43:11.792404 	 [make_candidate] session_latest_time_wt_pair4 : start
# 0:43:12.271589 	 [add_candidate] session_latest_time_wt_pair4 : start
# 0:43:14.678478 	 session_latest_time_wt_pair4
# 0:43:14.679639 	 {'num_clicks': 97136, 'hit_clicks': 3368, 'num_carts': 37850, 'hit_carts': 1142, 'num_orders': 17856, 'hit_orders': 685, 'recall_clicks': '0.035', 'recall_carts': '0.030', 'recall_orders': '0.038', 'w_recall_clicks': '0.003', 'w_recall_carts': '0.009', 'w_recall_orders': '0.023', 'score': '0.036'}
# 0:43:14.690090 	 [make_candidate] session_latest_word2vec_pair4 : start
# 0:43:15.118419 	 [add_candidate] session_latest_word2vec_pair4 : start
# 0:43:17.542818 	 session_latest_word2vec_pair4
# 0:43:17.544147 	 {'num_clicks': 97136, 'hit_clicks': 1810, 'num_carts': 37850, 'hit_carts': 600, 'num_orders': 17856, 'hit_orders': 324, 'recall_clicks': '0.019', 'recall_carts': '0.016', 'recall_orders': '0.018', 'w_recall_clicks': '0.002', 'w_recall_carts': '0.005', 'w_recall_orders': '0.011', 'score': '0.018'}
# 0:43:17.554422 	 [make_candidate] session_latest_pair4 : start
# 0:43:18.257262 	 [add_candidate] session_latest_pair4 : start
# 0:43:20.674384 	 session_latest_pair4
# 0:43:20.675846 	 {'num_clicks': 97136, 'hit_clicks': 2732, 'num_carts': 37850, 'hit_carts': 1340, 'num_orders': 17856, 'hit_orders': 884, 'recall_clicks': '0.028', 'recall_carts': '0.035', 'recall_orders': '0.050', 'w_recall_clicks': '0.003', 'w_recall_carts': '0.011', 'w_recall_orders': '0.030', 'score': '0.043'}
# 0:43:20.687237 	 [make_candidate] session_latest_type_wt_pair4 : start
# 0:43:21.018788 	 [add_candidate] session_latest_type_wt_pair4 : start
# 0:43:23.540893 	 session_latest_type_wt_pair4
# 0:43:23.542138 	 {'num_clicks': 97136, 'hit_clicks': 2896, 'num_carts': 37850, 'hit_carts': 1598, 'num_orders': 17856, 'hit_orders': 991, 'recall_clicks': '0.030', 'recall_carts': '0.042', 'recall_orders': '0.055', 'w_recall_clicks': '0.003', 'w_recall_carts': '0.013', 'w_recall_orders': '0.033', 'score': '0.049'}
# 0:43:23.552771 	 [make_candidate] session_latest_clicks2carts_pair4 : start
# 0:43:23.945068 	 [add_candidate] session_latest_clicks2carts_pair4 : start
# 0:43:26.304148 	 session_latest_clicks2carts_pair4
# 0:43:26.305238 	 {'num_clicks': 97136, 'hit_clicks': 1571, 'num_carts': 37850, 'hit_carts': 1095, 'num_orders': 17856, 'hit_orders': 563, 'recall_clicks': '0.016', 'recall_carts': '0.029', 'recall_orders': '0.032', 'w_recall_clicks': '0.002', 'w_recall_carts': '0.009', 'w_recall_orders': '0.019', 'score': '0.029'}
# 0:43:26.315401 	 [make_candidate] session_latest_clicks2orders_pair4 : start
# 0:43:26.502172 	 [add_candidate] session_latest_clicks2orders_pair4 : start
# 0:43:28.749753 	 session_latest_clicks2orders_pair4
# 0:43:28.750981 	 {'num_clicks': 97136, 'hit_clicks': 894, 'num_carts': 37850, 'hit_carts': 541, 'num_orders': 17856, 'hit_orders': 518, 'recall_clicks': '0.009', 'recall_carts': '0.014', 'recall_orders': '0.029', 'w_recall_clicks': '0.001', 'w_recall_carts': '0.004', 'w_recall_orders': '0.017', 'score': '0.023'}
# 0:43:28.760632 	 [make_candidate] session_latest_time_wt_pair5 : start
# 0:43:29.353127 	 [add_candidate] session_latest_time_wt_pair5 : start
# 0:43:31.762785 	 session_latest_time_wt_pair5
# 0:43:31.764042 	 {'num_clicks': 97136, 'hit_clicks': 3047, 'num_carts': 37850, 'hit_carts': 1020, 'num_orders': 17856, 'hit_orders': 616, 'recall_clicks': '0.031', 'recall_carts': '0.027', 'recall_orders': '0.034', 'w_recall_clicks': '0.003', 'w_recall_carts': '0.008', 'w_recall_orders': '0.021', 'score': '0.032'}
# 0:43:31.775827 	 [make_candidate] session_latest_word2vec_pair5 : start
# 0:43:32.290970 	 [add_candidate] session_latest_word2vec_pair5 : start
# 0:43:34.824399 	 session_latest_word2vec_pair5
# 0:43:34.825580 	 {'num_clicks': 97136, 'hit_clicks': 1690, 'num_carts': 37850, 'hit_carts': 569, 'num_orders': 17856, 'hit_orders': 338, 'recall_clicks': '0.017', 'recall_carts': '0.015', 'recall_orders': '0.019', 'w_recall_clicks': '0.002', 'w_recall_carts': '0.005', 'w_recall_orders': '0.011', 'score': '0.018'}
# 0:43:34.836164 	 [make_candidate] session_latest_pair5 : start
# 0:43:35.388082 	 [add_candidate] session_latest_pair5 : start
# 0:43:37.863296 	 session_latest_pair5
# 0:43:37.864667 	 {'num_clicks': 97136, 'hit_clicks': 2597, 'num_carts': 37850, 'hit_carts': 1205, 'num_orders': 17856, 'hit_orders': 753, 'recall_clicks': '0.027', 'recall_carts': '0.032', 'recall_orders': '0.042', 'w_recall_clicks': '0.003', 'w_recall_carts': '0.010', 'w_recall_orders': '0.025', 'score': '0.038'}
# 0:43:37.875733 	 [make_candidate] session_latest_type_wt_pair5 : start
# 0:43:38.448966 	 [add_candidate] session_latest_type_wt_pair5 : start
# 0:43:40.996779 	 session_latest_type_wt_pair5
# 0:43:40.998021 	 {'num_clicks': 97136, 'hit_clicks': 2597, 'num_carts': 37850, 'hit_carts': 1446, 'num_orders': 17856, 'hit_orders': 904, 'recall_clicks': '0.027', 'recall_carts': '0.038', 'recall_orders': '0.051', 'w_recall_clicks': '0.003', 'w_recall_carts': '0.011', 'w_recall_orders': '0.030', 'score': '0.045'}
# 0:43:41.008843 	 [make_candidate] session_latest_clicks2carts_pair5 : start
# 0:43:41.388325 	 [add_candidate] session_latest_clicks2carts_pair5 : start
# 0:43:43.758550 	 session_latest_clicks2carts_pair5
# 0:43:43.759740 	 {'num_clicks': 97136, 'hit_clicks': 1415, 'num_carts': 37850, 'hit_carts': 913, 'num_orders': 17856, 'hit_orders': 465, 'recall_clicks': '0.015', 'recall_carts': '0.024', 'recall_orders': '0.026', 'w_recall_clicks': '0.001', 'w_recall_carts': '0.007', 'w_recall_orders': '0.016', 'score': '0.024'}
# 0:43:43.769516 	 [make_candidate] session_latest_clicks2orders_pair5 : start
# 0:43:43.942136 	 [add_candidate] session_latest_clicks2orders_pair5 : start
# 0:43:46.200212 	 session_latest_clicks2orders_pair5
# 0:43:46.201502 	 {'num_clicks': 97136, 'hit_clicks': 732, 'num_carts': 37850, 'hit_carts': 496, 'num_orders': 17856, 'hit_orders': 458, 'recall_clicks': '0.008', 'recall_carts': '0.013', 'recall_orders': '0.026', 'w_recall_clicks': '0.001', 'w_recall_carts': '0.004', 'w_recall_orders': '0.015', 'score': '0.020'}
# 0:43:46.210990 	 [make_candidate] session_latest_time_wt_pair6 : start
# 0:43:46.799143 	 [add_candidate] session_latest_time_wt_pair6 : start
# 0:43:49.316973 	 session_latest_time_wt_pair6
# 0:43:49.318091 	 {'num_clicks': 97136, 'hit_clicks': 2701, 'num_carts': 37850, 'hit_carts': 941, 'num_orders': 17856, 'hit_orders': 545, 'recall_clicks': '0.028', 'recall_carts': '0.025', 'recall_orders': '0.031', 'w_recall_clicks': '0.003', 'w_recall_carts': '0.007', 'w_recall_orders': '0.018', 'score': '0.029'}
# 0:43:49.329064 	 [make_candidate] session_latest_word2vec_pair6 : start
# 0:43:49.876190 	 [add_candidate] session_latest_word2vec_pair6 : start
# 0:43:52.421259 	 session_latest_word2vec_pair6
# 0:43:52.422530 	 {'num_clicks': 97136, 'hit_clicks': 1628, 'num_carts': 37850, 'hit_carts': 572, 'num_orders': 17856, 'hit_orders': 276, 'recall_clicks': '0.017', 'recall_carts': '0.015', 'recall_orders': '0.015', 'w_recall_clicks': '0.002', 'w_recall_carts': '0.005', 'w_recall_orders': '0.009', 'score': '0.015'}
# 0:43:52.433512 	 [make_candidate] session_latest_pair6 : start
# 0:43:52.934987 	 [add_candidate] session_latest_pair6 : start
# 0:43:55.498113 	 session_latest_pair6
# 0:43:55.499310 	 {'num_clicks': 97136, 'hit_clicks': 2314, 'num_carts': 37850, 'hit_carts': 1130, 'num_orders': 17856, 'hit_orders': 681, 'recall_clicks': '0.024', 'recall_carts': '0.030', 'recall_orders': '0.038', 'w_recall_clicks': '0.002', 'w_recall_carts': '0.009', 'w_recall_orders': '0.023', 'score': '0.034'}
# 0:43:55.510218 	 [make_candidate] session_latest_type_wt_pair6 : start
# 0:43:56.077245 	 [add_candidate] session_latest_type_wt_pair6 : start
# 0:43:58.673798 	 session_latest_type_wt_pair6
# 0:43:58.675313 	 {'num_clicks': 97136, 'hit_clicks': 2255, 'num_carts': 37850, 'hit_carts': 1306, 'num_orders': 17856, 'hit_orders': 834, 'recall_clicks': '0.023', 'recall_carts': '0.035', 'recall_orders': '0.047', 'w_recall_clicks': '0.002', 'w_recall_carts': '0.010', 'w_recall_orders': '0.028', 'score': '0.041'}
# 0:43:58.686147 	 [make_candidate] session_latest_clicks2carts_pair6 : start
# 0:43:58.908245 	 [add_candidate] session_latest_clicks2carts_pair6 : start
# 0:44:01.228699 	 session_latest_clicks2carts_pair6
# 0:44:01.229821 	 {'num_clicks': 97136, 'hit_clicks': 1251, 'num_carts': 37850, 'hit_carts': 841, 'num_orders': 17856, 'hit_orders': 433, 'recall_clicks': '0.013', 'recall_carts': '0.022', 'recall_orders': '0.024', 'w_recall_clicks': '0.001', 'w_recall_carts': '0.007', 'w_recall_orders': '0.015', 'score': '0.023'}
# 0:44:01.239885 	 [make_candidate] session_latest_clicks2orders_pair6 : start
# 0:44:01.551965 	 [add_candidate] session_latest_clicks2orders_pair6 : start
# 0:44:03.839619 	 session_latest_clicks2orders_pair6
# 0:44:03.840747 	 {'num_clicks': 97136, 'hit_clicks': 657, 'num_carts': 37850, 'hit_carts': 414, 'num_orders': 17856, 'hit_orders': 404, 'recall_clicks': '0.007', 'recall_carts': '0.011', 'recall_orders': '0.023', 'w_recall_clicks': '0.001', 'w_recall_carts': '0.003', 'w_recall_orders': '0.014', 'score': '0.018'}
# 0:44:03.849699 	 [make_candidate] session_latest_time_wt_pair7 : start
# 0:44:04.396482 	 [add_candidate] session_latest_time_wt_pair7 : start
# 0:44:07.012472 	 session_latest_time_wt_pair7
# 0:44:07.013801 	 {'num_clicks': 97136, 'hit_clicks': 2432, 'num_carts': 37850, 'hit_carts': 866, 'num_orders': 17856, 'hit_orders': 523, 'recall_clicks': '0.025', 'recall_carts': '0.023', 'recall_orders': '0.029', 'w_recall_clicks': '0.003', 'w_recall_carts': '0.007', 'w_recall_orders': '0.018', 'score': '0.027'}
# 0:44:07.024308 	 [make_candidate] session_latest_word2vec_pair7 : start
# 0:44:07.471779 	 [add_candidate] session_latest_word2vec_pair7 : start
# 0:44:10.081774 	 session_latest_word2vec_pair7
# 0:44:10.082977 	 {'num_clicks': 97136, 'hit_clicks': 1381, 'num_carts': 37850, 'hit_carts': 469, 'num_orders': 17856, 'hit_orders': 252, 'recall_clicks': '0.014', 'recall_carts': '0.012', 'recall_orders': '0.014', 'w_recall_clicks': '0.001', 'w_recall_carts': '0.004', 'w_recall_orders': '0.008', 'score': '0.014'}
# 0:44:10.093604 	 [make_candidate] session_latest_pair7 : start
# 0:44:10.652598 	 [add_candidate] session_latest_pair7 : start
# 0:44:13.268912 	 session_latest_pair7
# 0:44:13.270126 	 {'num_clicks': 97136, 'hit_clicks': 2090, 'num_carts': 37850, 'hit_carts': 1055, 'num_orders': 17856, 'hit_orders': 674, 'recall_clicks': '0.022', 'recall_carts': '0.028', 'recall_orders': '0.038', 'w_recall_clicks': '0.002', 'w_recall_carts': '0.008', 'w_recall_orders': '0.023', 'score': '0.033'}
# 0:44:13.281695 	 [make_candidate] session_latest_type_wt_pair7 : start
# 0:44:13.852174 	 [add_candidate] session_latest_type_wt_pair7 : start
# 0:44:16.506403 	 session_latest_type_wt_pair7
# 0:44:16.507626 	 {'num_clicks': 97136, 'hit_clicks': 2057, 'num_carts': 37850, 'hit_carts': 1196, 'num_orders': 17856, 'hit_orders': 733, 'recall_clicks': '0.021', 'recall_carts': '0.032', 'recall_orders': '0.041', 'w_recall_clicks': '0.002', 'w_recall_carts': '0.009', 'w_recall_orders': '0.025', 'score': '0.036'}
# 0:44:16.518780 	 [make_candidate] session_latest_clicks2carts_pair7 : start
# 0:44:16.740368 	 [add_candidate] session_latest_clicks2carts_pair7 : start
# 0:44:19.589596 	 session_latest_clicks2carts_pair7
# 0:44:19.590881 	 {'num_clicks': 97136, 'hit_clicks': 1073, 'num_carts': 37850, 'hit_carts': 793, 'num_orders': 17856, 'hit_orders': 358, 'recall_clicks': '0.011', 'recall_carts': '0.021', 'recall_orders': '0.020', 'w_recall_clicks': '0.001', 'w_recall_carts': '0.006', 'w_recall_orders': '0.012', 'score': '0.019'}
# 0:44:19.602337 	 [make_candidate] session_latest_clicks2orders_pair7 : start
# 0:44:19.918396 	 [add_candidate] session_latest_clicks2orders_pair7 : start
# 0:44:22.600943 	 session_latest_clicks2orders_pair7
# 0:44:22.602285 	 {'num_clicks': 97136, 'hit_clicks': 600, 'num_carts': 37850, 'hit_carts': 378, 'num_orders': 17856, 'hit_orders': 381, 'recall_clicks': '0.006', 'recall_carts': '0.010', 'recall_orders': '0.021', 'w_recall_clicks': '0.001', 'w_recall_carts': '0.003', 'w_recall_orders': '0.013', 'score': '0.016'}
# 0:44:22.612637 	 [make_candidate] session_latest_time_wt_pair8 : start
# 0:44:23.179245 	 [add_candidate] session_latest_time_wt_pair8 : start
# 0:44:26.176842 	 session_latest_time_wt_pair8
# 0:44:26.178077 	 {'num_clicks': 97136, 'hit_clicks': 2318, 'num_carts': 37850, 'hit_carts': 761, 'num_orders': 17856, 'hit_orders': 442, 'recall_clicks': '0.024', 'recall_carts': '0.020', 'recall_orders': '0.025', 'w_recall_clicks': '0.002', 'w_recall_carts': '0.006', 'w_recall_orders': '0.015', 'score': '0.023'}
# 0:44:26.189001 	 [make_candidate] session_latest_word2vec_pair8 : start
# 0:44:26.673149 	 [add_candidate] session_latest_word2vec_pair8 : start
# 0:44:29.651948 	 session_latest_word2vec_pair8
# 0:44:29.653136 	 {'num_clicks': 97136, 'hit_clicks': 1295, 'num_carts': 37850, 'hit_carts': 448, 'num_orders': 17856, 'hit_orders': 238, 'recall_clicks': '0.013', 'recall_carts': '0.012', 'recall_orders': '0.013', 'w_recall_clicks': '0.001', 'w_recall_carts': '0.004', 'w_recall_orders': '0.008', 'score': '0.013'}
# 0:44:29.664663 	 [make_candidate] session_latest_pair8 : start
# 0:44:30.228073 	 [add_candidate] session_latest_pair8 : start
# 0:44:33.281878 	 session_latest_pair8
# 0:44:33.282968 	 {'num_clicks': 97136, 'hit_clicks': 1911, 'num_carts': 37850, 'hit_carts': 923, 'num_orders': 17856, 'hit_orders': 555, 'recall_clicks': '0.020', 'recall_carts': '0.024', 'recall_orders': '0.031', 'w_recall_clicks': '0.002', 'w_recall_carts': '0.007', 'w_recall_orders': '0.019', 'score': '0.028'}
# 0:44:33.294244 	 [make_candidate] session_latest_type_wt_pair8 : start
# 0:44:33.882751 	 [add_candidate] session_latest_type_wt_pair8 : start
# 0:44:36.763492 	 session_latest_type_wt_pair8
# 0:44:36.765621 	 {'num_clicks': 97136, 'hit_clicks': 1894, 'num_carts': 37850, 'hit_carts': 1137, 'num_orders': 17856, 'hit_orders': 682, 'recall_clicks': '0.019', 'recall_carts': '0.030', 'recall_orders': '0.038', 'w_recall_clicks': '0.002', 'w_recall_carts': '0.009', 'w_recall_orders': '0.023', 'score': '0.034'}
# 0:44:36.777976 	 [make_candidate] session_latest_clicks2carts_pair8 : start
# 0:44:37.044961 	 [add_candidate] session_latest_clicks2carts_pair8 : start
# 0:44:39.959085 	 session_latest_clicks2carts_pair8
# 0:44:39.960249 	 {'num_clicks': 97136, 'hit_clicks': 983, 'num_carts': 37850, 'hit_carts': 709, 'num_orders': 17856, 'hit_orders': 354, 'recall_clicks': '0.010', 'recall_carts': '0.019', 'recall_orders': '0.020', 'w_recall_clicks': '0.001', 'w_recall_carts': '0.006', 'w_recall_orders': '0.012', 'score': '0.019'}
# 0:44:39.970459 	 [make_candidate] session_latest_clicks2orders_pair8 : start
# 0:44:40.332017 	 [add_candidate] session_latest_clicks2orders_pair8 : start
# 0:44:43.028955 	 session_latest_clicks2orders_pair8
# 0:44:43.030273 	 {'num_clicks': 97136, 'hit_clicks': 442, 'num_carts': 37850, 'hit_carts': 313, 'num_orders': 17856, 'hit_orders': 331, 'recall_clicks': '0.005', 'recall_carts': '0.008', 'recall_orders': '0.019', 'w_recall_clicks': '0.000', 'w_recall_carts': '0.002', 'w_recall_orders': '0.011', 'score': '0.014'}
# 0:44:43.039973 	 [make_candidate] session_latest_time_wt_pair9 : start
# 0:44:43.593544 	 [add_candidate] session_latest_time_wt_pair9 : start
# 0:44:46.637566 	 session_latest_time_wt_pair9
# 0:44:46.638805 	 {'num_clicks': 97136, 'hit_clicks': 2075, 'num_carts': 37850, 'hit_carts': 702, 'num_orders': 17856, 'hit_orders': 428, 'recall_clicks': '0.021', 'recall_carts': '0.019', 'recall_orders': '0.024', 'w_recall_clicks': '0.002', 'w_recall_carts': '0.006', 'w_recall_orders': '0.014', 'score': '0.022'}
# 0:44:46.650221 	 [make_candidate] session_latest_word2vec_pair9 : start
# 0:44:47.213015 	 [add_candidate] session_latest_word2vec_pair9 : start
# 0:44:50.256550 	 session_latest_word2vec_pair9
# 0:44:50.257735 	 {'num_clicks': 97136, 'hit_clicks': 1134, 'num_carts': 37850, 'hit_carts': 385, 'num_orders': 17856, 'hit_orders': 207, 'recall_clicks': '0.012', 'recall_carts': '0.010', 'recall_orders': '0.012', 'w_recall_clicks': '0.001', 'w_recall_carts': '0.003', 'w_recall_orders': '0.007', 'score': '0.011'}
# 0:44:50.268742 	 [make_candidate] session_latest_pair9 : start
# 0:44:50.850644 	 [add_candidate] session_latest_pair9 : start
# 0:44:53.885418 	 session_latest_pair9
# 0:44:53.886541 	 {'num_clicks': 97136, 'hit_clicks': 1703, 'num_carts': 37850, 'hit_carts': 938, 'num_orders': 17856, 'hit_orders': 560, 'recall_clicks': '0.018', 'recall_carts': '0.025', 'recall_orders': '0.031', 'w_recall_clicks': '0.002', 'w_recall_carts': '0.007', 'w_recall_orders': '0.019', 'score': '0.028'}
# 0:44:53.897327 	 [make_candidate] session_latest_type_wt_pair9 : start
# 0:44:54.465219 	 [add_candidate] session_latest_type_wt_pair9 : start
# 0:44:57.533046 	 session_latest_type_wt_pair9
# 0:44:57.534595 	 {'num_clicks': 97136, 'hit_clicks': 1761, 'num_carts': 37850, 'hit_carts': 1115, 'num_orders': 17856, 'hit_orders': 653, 'recall_clicks': '0.018', 'recall_carts': '0.029', 'recall_orders': '0.037', 'w_recall_clicks': '0.002', 'w_recall_carts': '0.009', 'w_recall_orders': '0.022', 'score': '0.033'}
# 0:44:57.545552 	 [make_candidate] session_latest_clicks2carts_pair9 : start
# 0:44:57.827964 	 [add_candidate] session_latest_clicks2carts_pair9 : start
# 0:45:00.783712 	 session_latest_clicks2carts_pair9
# 0:45:00.784954 	 {'num_clicks': 97136, 'hit_clicks': 896, 'num_carts': 37850, 'hit_carts': 632, 'num_orders': 17856, 'hit_orders': 325, 'recall_clicks': '0.009', 'recall_carts': '0.017', 'recall_orders': '0.018', 'w_recall_clicks': '0.001', 'w_recall_carts': '0.005', 'w_recall_orders': '0.011', 'score': '0.017'}
# 0:45:00.794684 	 [make_candidate] session_latest_clicks2orders_pair9 : start
# 0:45:01.131774 	 [add_candidate] session_latest_clicks2orders_pair9 : start
# 0:45:03.860443 	 session_latest_clicks2orders_pair9
# 0:45:03.861645 	 {'num_clicks': 97136, 'hit_clicks': 437, 'num_carts': 37850, 'hit_carts': 290, 'num_orders': 17856, 'hit_orders': 290, 'recall_clicks': '0.004', 'recall_carts': '0.008', 'recall_orders': '0.016', 'w_recall_clicks': '0.000', 'w_recall_carts': '0.002', 'w_recall_orders': '0.010', 'score': '0.012'}
# 0:45:03.870265 	 [make_candidate] session_latest_time_wt_pair10 : start
# 0:45:04.359987 	 [add_candidate] session_latest_time_wt_pair10 : start
# 0:45:07.362225 	 session_latest_time_wt_pair10
# 0:45:07.363590 	 {'num_clicks': 97136, 'hit_clicks': 1931, 'num_carts': 37850, 'hit_carts': 693, 'num_orders': 17856, 'hit_orders': 422, 'recall_clicks': '0.020', 'recall_carts': '0.018', 'recall_orders': '0.024', 'w_recall_clicks': '0.002', 'w_recall_carts': '0.005', 'w_recall_orders': '0.014', 'score': '0.022'}
# 0:45:07.375349 	 [make_candidate] session_latest_word2vec_pair10 : start
# 0:45:07.857020 	 [add_candidate] session_latest_word2vec_pair10 : start
# 0:45:10.938441 	 session_latest_word2vec_pair10
# 0:45:10.939699 	 {'num_clicks': 97136, 'hit_clicks': 1080, 'num_carts': 37850, 'hit_carts': 367, 'num_orders': 17856, 'hit_orders': 234, 'recall_clicks': '0.011', 'recall_carts': '0.010', 'recall_orders': '0.013', 'w_recall_clicks': '0.001', 'w_recall_carts': '0.003', 'w_recall_orders': '0.008', 'score': '0.012'}
# 0:45:10.950497 	 [make_candidate] session_latest_pair10 : start
# 0:45:11.453373 	 [add_candidate] session_latest_pair10 : start
# 0:45:14.577675 	 session_latest_pair10
# 0:45:14.578792 	 {'num_clicks': 97136, 'hit_clicks': 1616, 'num_carts': 37850, 'hit_carts': 837, 'num_orders': 17856, 'hit_orders': 541, 'recall_clicks': '0.017', 'recall_carts': '0.022', 'recall_orders': '0.030', 'w_recall_clicks': '0.002', 'w_recall_carts': '0.007', 'w_recall_orders': '0.018', 'score': '0.026'}
# 0:45:14.589703 	 [make_candidate] session_latest_type_wt_pair10 : start
# 0:45:15.085356 	 [add_candidate] session_latest_type_wt_pair10 : start
# 0:45:18.178204 	 session_latest_type_wt_pair10
# 0:45:18.179451 	 {'num_clicks': 97136, 'hit_clicks': 1550, 'num_carts': 37850, 'hit_carts': 1006, 'num_orders': 17856, 'hit_orders': 619, 'recall_clicks': '0.016', 'recall_carts': '0.027', 'recall_orders': '0.035', 'w_recall_clicks': '0.002', 'w_recall_carts': '0.008', 'w_recall_orders': '0.021', 'score': '0.030'}
# 0:45:18.190740 	 [make_candidate] session_latest_clicks2carts_pair10 : start
# 0:45:18.424060 	 [add_candidate] session_latest_clicks2carts_pair10 : start
# 0:45:21.408170 	 session_latest_clicks2carts_pair10
# 0:45:21.409339 	 {'num_clicks': 97136, 'hit_clicks': 859, 'num_carts': 37850, 'hit_carts': 588, 'num_orders': 17856, 'hit_orders': 325, 'recall_clicks': '0.009', 'recall_carts': '0.016', 'recall_orders': '0.018', 'w_recall_clicks': '0.001', 'w_recall_carts': '0.005', 'w_recall_orders': '0.011', 'score': '0.016'}
# 0:45:21.419287 	 [make_candidate] session_latest_clicks2orders_pair10 : start
# 0:45:21.718451 	 [add_candidate] session_latest_clicks2orders_pair10 : start
# 0:45:24.504647 	 session_latest_clicks2orders_pair10
# 0:45:24.505756 	 {'num_clicks': 97136, 'hit_clicks': 430, 'num_carts': 37850, 'hit_carts': 255, 'num_orders': 17856, 'hit_orders': 244, 'recall_clicks': '0.004', 'recall_carts': '0.007', 'recall_orders': '0.014', 'w_recall_clicks': '0.000', 'w_recall_carts': '0.002', 'w_recall_orders': '0.008', 'score': '0.011'}
# 0:45:24.514353 	 [make_candidate] session_latest_time_wt_pair11 : start
# 0:45:25.068944 	 [add_candidate] session_latest_time_wt_pair11 : start
# 0:45:28.280013 	 session_latest_time_wt_pair11
# 0:45:28.281232 	 {'num_clicks': 97136, 'hit_clicks': 1782, 'num_carts': 37850, 'hit_carts': 663, 'num_orders': 17856, 'hit_orders': 418, 'recall_clicks': '0.018', 'recall_carts': '0.018', 'recall_orders': '0.023', 'w_recall_clicks': '0.002', 'w_recall_carts': '0.005', 'w_recall_orders': '0.014', 'score': '0.021'}
# 0:45:28.292480 	 [make_candidate] session_latest_word2vec_pair11 : start
# 0:45:28.848463 	 [add_candidate] session_latest_word2vec_pair11 : start
# 0:45:32.007825 	 session_latest_word2vec_pair11
# 0:45:32.008992 	 {'num_clicks': 97136, 'hit_clicks': 1016, 'num_carts': 37850, 'hit_carts': 386, 'num_orders': 17856, 'hit_orders': 199, 'recall_clicks': '0.010', 'recall_carts': '0.010', 'recall_orders': '0.011', 'w_recall_clicks': '0.001', 'w_recall_carts': '0.003', 'w_recall_orders': '0.007', 'score': '0.011'}
# 0:45:32.020263 	 [make_candidate] session_latest_pair11 : start
# 0:45:32.502106 	 [add_candidate] session_latest_pair11 : start
# 0:45:35.534677 	 session_latest_pair11
# 0:45:35.535960 	 {'num_clicks': 97136, 'hit_clicks': 1409, 'num_carts': 37850, 'hit_carts': 784, 'num_orders': 17856, 'hit_orders': 489, 'recall_clicks': '0.015', 'recall_carts': '0.021', 'recall_orders': '0.027', 'w_recall_clicks': '0.001', 'w_recall_carts': '0.006', 'w_recall_orders': '0.016', 'score': '0.024'}
# 0:45:35.547909 	 [make_candidate] session_latest_type_wt_pair11 : start
# 0:45:36.058184 	 [add_candidate] session_latest_type_wt_pair11 : start
# 0:45:39.233955 	 session_latest_type_wt_pair11
# 0:45:39.235217 	 {'num_clicks': 97136, 'hit_clicks': 1533, 'num_carts': 37850, 'hit_carts': 971, 'num_orders': 17856, 'hit_orders': 551, 'recall_clicks': '0.016', 'recall_carts': '0.026', 'recall_orders': '0.031', 'w_recall_clicks': '0.002', 'w_recall_carts': '0.008', 'w_recall_orders': '0.019', 'score': '0.028'}
# 0:45:39.246172 	 [make_candidate] session_latest_clicks2carts_pair11 : start
# 0:45:39.471615 	 [add_candidate] session_latest_clicks2carts_pair11 : start
# 0:45:42.488763 	 session_latest_clicks2carts_pair11
# 0:45:42.489979 	 {'num_clicks': 97136, 'hit_clicks': 807, 'num_carts': 37850, 'hit_carts': 503, 'num_orders': 17856, 'hit_orders': 235, 'recall_clicks': '0.008', 'recall_carts': '0.013', 'recall_orders': '0.013', 'w_recall_clicks': '0.001', 'w_recall_carts': '0.004', 'w_recall_orders': '0.008', 'score': '0.013'}
# 0:45:42.499561 	 [make_candidate] session_latest_clicks2orders_pair11 : start
# 0:45:42.896255 	 [add_candidate] session_latest_clicks2orders_pair11 : start
# 0:45:45.737069 	 session_latest_clicks2orders_pair11
# 0:45:45.738350 	 {'num_clicks': 97136, 'hit_clicks': 366, 'num_carts': 37850, 'hit_carts': 258, 'num_orders': 17856, 'hit_orders': 238, 'recall_clicks': '0.004', 'recall_carts': '0.007', 'recall_orders': '0.013', 'w_recall_clicks': '0.000', 'w_recall_carts': '0.002', 'w_recall_orders': '0.008', 'score': '0.010'}
# 0:45:45.747137 	 [make_candidate] session_latest_time_wt_pair12 : start
# 0:45:46.306777 	 [add_candidate] session_latest_time_wt_pair12 : start
# 0:45:49.557559 	 session_latest_time_wt_pair12
# 0:45:49.558836 	 {'num_clicks': 97136, 'hit_clicks': 1728, 'num_carts': 37850, 'hit_carts': 637, 'num_orders': 17856, 'hit_orders': 389, 'recall_clicks': '0.018', 'recall_carts': '0.017', 'recall_orders': '0.022', 'w_recall_clicks': '0.002', 'w_recall_carts': '0.005', 'w_recall_orders': '0.013', 'score': '0.020'}
# 0:45:49.570889 	 [make_candidate] session_latest_word2vec_pair12 : start
# 0:45:50.055609 	 [add_candidate] session_latest_word2vec_pair12 : start
# 0:45:53.327437 	 session_latest_word2vec_pair12
# 0:45:53.328678 	 {'num_clicks': 97136, 'hit_clicks': 990, 'num_carts': 37850, 'hit_carts': 359, 'num_orders': 17856, 'hit_orders': 208, 'recall_clicks': '0.010', 'recall_carts': '0.009', 'recall_orders': '0.012', 'w_recall_clicks': '0.001', 'w_recall_carts': '0.003', 'w_recall_orders': '0.007', 'score': '0.011'}
# 0:45:53.340444 	 [make_candidate] session_latest_pair12 : start
# 0:45:53.887075 	 [add_candidate] session_latest_pair12 : start
# 0:45:57.119778 	 session_latest_pair12
# 0:45:57.120883 	 {'num_clicks': 97136, 'hit_clicks': 1319, 'num_carts': 37850, 'hit_carts': 755, 'num_orders': 17856, 'hit_orders': 480, 'recall_clicks': '0.014', 'recall_carts': '0.020', 'recall_orders': '0.027', 'w_recall_clicks': '0.001', 'w_recall_carts': '0.006', 'w_recall_orders': '0.016', 'score': '0.023'}
# 0:45:57.132574 	 [make_candidate] session_latest_type_wt_pair12 : start
# 0:45:57.654009 	 [add_candidate] session_latest_type_wt_pair12 : start
# 0:46:00.898325 	 session_latest_type_wt_pair12
# 0:46:00.899441 	 {'num_clicks': 97136, 'hit_clicks': 1459, 'num_carts': 37850, 'hit_carts': 961, 'num_orders': 17856, 'hit_orders': 600, 'recall_clicks': '0.015', 'recall_carts': '0.025', 'recall_orders': '0.034', 'w_recall_clicks': '0.002', 'w_recall_carts': '0.008', 'w_recall_orders': '0.020', 'score': '0.029'}
# 0:46:00.910085 	 [make_candidate] session_latest_clicks2carts_pair12 : start
# 0:46:01.142771 	 [add_candidate] session_latest_clicks2carts_pair12 : start
# 0:46:04.229895 	 session_latest_clicks2carts_pair12
# 0:46:04.231070 	 {'num_clicks': 97136, 'hit_clicks': 733, 'num_carts': 37850, 'hit_carts': 497, 'num_orders': 17856, 'hit_orders': 249, 'recall_clicks': '0.008', 'recall_carts': '0.013', 'recall_orders': '0.014', 'w_recall_clicks': '0.001', 'w_recall_carts': '0.004', 'w_recall_orders': '0.008', 'score': '0.013'}
# 0:46:04.240993 	 [make_candidate] session_latest_clicks2orders_pair12 : start
# 0:46:04.673233 	 [add_candidate] session_latest_clicks2orders_pair12 : start
# 0:46:07.564256 	 session_latest_clicks2orders_pair12
# 0:46:07.565728 	 {'num_clicks': 97136, 'hit_clicks': 312, 'num_carts': 37850, 'hit_carts': 216, 'num_orders': 17856, 'hit_orders': 186, 'recall_clicks': '0.003', 'recall_carts': '0.006', 'recall_orders': '0.010', 'w_recall_clicks': '0.000', 'w_recall_carts': '0.002', 'w_recall_orders': '0.006', 'score': '0.008'}
# 0:46:07.573830 	 [make_candidate] session_latest_time_wt_pair13 : start
# 0:46:08.066092 	 [add_candidate] session_latest_time_wt_pair13 : start
# 0:46:11.278732 	 session_latest_time_wt_pair13
# 0:46:11.279932 	 {'num_clicks': 97136, 'hit_clicks': 1624, 'num_carts': 37850, 'hit_carts': 620, 'num_orders': 17856, 'hit_orders': 391, 'recall_clicks': '0.017', 'recall_carts': '0.016', 'recall_orders': '0.022', 'w_recall_clicks': '0.002', 'w_recall_carts': '0.005', 'w_recall_orders': '0.013', 'score': '0.020'}
# 0:46:11.290986 	 [make_candidate] session_latest_word2vec_pair13 : start
# 0:46:11.827550 	 [add_candidate] session_latest_word2vec_pair13 : start
# 0:46:15.180573 	 session_latest_word2vec_pair13
# 0:46:15.181713 	 {'num_clicks': 97136, 'hit_clicks': 923, 'num_carts': 37850, 'hit_carts': 348, 'num_orders': 17856, 'hit_orders': 169, 'recall_clicks': '0.010', 'recall_carts': '0.009', 'recall_orders': '0.009', 'w_recall_clicks': '0.001', 'w_recall_carts': '0.003', 'w_recall_orders': '0.006', 'score': '0.009'}
# 0:46:15.194191 	 [make_candidate] session_latest_pair13 : start
# 0:46:15.763385 	 [add_candidate] session_latest_pair13 : start
# 0:46:19.077512 	 session_latest_pair13
# 0:46:19.078794 	 {'num_clicks': 97136, 'hit_clicks': 1330, 'num_carts': 37850, 'hit_carts': 683, 'num_orders': 17856, 'hit_orders': 439, 'recall_clicks': '0.014', 'recall_carts': '0.018', 'recall_orders': '0.025', 'w_recall_clicks': '0.001', 'w_recall_carts': '0.005', 'w_recall_orders': '0.015', 'score': '0.022'}
# 0:46:19.090219 	 [make_candidate] session_latest_type_wt_pair13 : start
# 0:46:19.515318 	 [add_candidate] session_latest_type_wt_pair13 : start
# 0:46:22.715248 	 session_latest_type_wt_pair13
# 0:46:22.716491 	 {'num_clicks': 97136, 'hit_clicks': 1277, 'num_carts': 37850, 'hit_carts': 891, 'num_orders': 17856, 'hit_orders': 518, 'recall_clicks': '0.013', 'recall_carts': '0.024', 'recall_orders': '0.029', 'w_recall_clicks': '0.001', 'w_recall_carts': '0.007', 'w_recall_orders': '0.017', 'score': '0.026'}
# 0:46:22.727746 	 [make_candidate] session_latest_clicks2carts_pair13 : start
# 0:46:23.098810 	 [add_candidate] session_latest_clicks2carts_pair13 : start
# 0:46:26.288749 	 session_latest_clicks2carts_pair13
# 0:46:26.289947 	 {'num_clicks': 97136, 'hit_clicks': 573, 'num_carts': 37850, 'hit_carts': 470, 'num_orders': 17856, 'hit_orders': 239, 'recall_clicks': '0.006', 'recall_carts': '0.012', 'recall_orders': '0.013', 'w_recall_clicks': '0.001', 'w_recall_carts': '0.004', 'w_recall_orders': '0.008', 'score': '0.012'}
# 0:46:26.299987 	 [make_candidate] session_latest_clicks2orders_pair13 : start
# 0:46:26.572974 	 [add_candidate] session_latest_clicks2orders_pair13 : start
# 0:46:29.637960 	 session_latest_clicks2orders_pair13
# 0:46:29.639189 	 {'num_clicks': 97136, 'hit_clicks': 331, 'num_carts': 37850, 'hit_carts': 197, 'num_orders': 17856, 'hit_orders': 207, 'recall_clicks': '0.003', 'recall_carts': '0.005', 'recall_orders': '0.012', 'w_recall_clicks': '0.000', 'w_recall_carts': '0.002', 'w_recall_orders': '0.007', 'score': '0.009'}
# 0:46:29.648398 	 [make_candidate] session_latest_time_wt_pair14 : start
# 0:46:30.350492 	 [add_candidate] session_latest_time_wt_pair14 : start
# 0:46:33.695774 	 session_latest_time_wt_pair14
# 0:46:33.697189 	 {'num_clicks': 97136, 'hit_clicks': 1563, 'num_carts': 37850, 'hit_carts': 563, 'num_orders': 17856, 'hit_orders': 355, 'recall_clicks': '0.016', 'recall_carts': '0.015', 'recall_orders': '0.020', 'w_recall_clicks': '0.002', 'w_recall_carts': '0.004', 'w_recall_orders': '0.012', 'score': '0.018'}
# 0:46:33.709012 	 [make_candidate] session_latest_word2vec_pair14 : start
# 0:46:34.156290 	 [add_candidate] session_latest_word2vec_pair14 : start
# 0:46:37.544968 	 session_latest_word2vec_pair14
# 0:46:37.546432 	 {'num_clicks': 97136, 'hit_clicks': 852, 'num_carts': 37850, 'hit_carts': 308, 'num_orders': 17856, 'hit_orders': 161, 'recall_clicks': '0.009', 'recall_carts': '0.008', 'recall_orders': '0.009', 'w_recall_clicks': '0.001', 'w_recall_carts': '0.002', 'w_recall_orders': '0.005', 'score': '0.009'}
# 0:46:37.558684 	 [make_candidate] session_latest_pair14 : start
# 0:46:38.161229 	 [add_candidate] session_latest_pair14 : start
# 0:46:41.362853 	 session_latest_pair14
# 0:46:41.364557 	 {'num_clicks': 97136, 'hit_clicks': 1222, 'num_carts': 37850, 'hit_carts': 698, 'num_orders': 17856, 'hit_orders': 427, 'recall_clicks': '0.013', 'recall_carts': '0.018', 'recall_orders': '0.024', 'w_recall_clicks': '0.001', 'w_recall_carts': '0.006', 'w_recall_orders': '0.014', 'score': '0.021'}
# 0:46:41.376163 	 [make_candidate] session_latest_type_wt_pair14 : start
# 0:46:41.806708 	 [add_candidate] session_latest_type_wt_pair14 : start
# 0:46:45.221632 	 session_latest_type_wt_pair14
# 0:46:45.222822 	 {'num_clicks': 97136, 'hit_clicks': 1284, 'num_carts': 37850, 'hit_carts': 804, 'num_orders': 17856, 'hit_orders': 493, 'recall_clicks': '0.013', 'recall_carts': '0.021', 'recall_orders': '0.028', 'w_recall_clicks': '0.001', 'w_recall_carts': '0.006', 'w_recall_orders': '0.017', 'score': '0.024'}
# 0:46:45.234309 	 [make_candidate] session_latest_clicks2carts_pair14 : start
# 0:46:45.683826 	 [add_candidate] session_latest_clicks2carts_pair14 : start
# 0:46:48.929737 	 session_latest_clicks2carts_pair14
# 0:46:48.931191 	 {'num_clicks': 97136, 'hit_clicks': 668, 'num_carts': 37850, 'hit_carts': 486, 'num_orders': 17856, 'hit_orders': 223, 'recall_clicks': '0.007', 'recall_carts': '0.013', 'recall_orders': '0.012', 'w_recall_clicks': '0.001', 'w_recall_carts': '0.004', 'w_recall_orders': '0.007', 'score': '0.012'}
# 0:46:48.941711 	 [make_candidate] session_latest_clicks2orders_pair14 : start
# 0:46:49.190215 	 [add_candidate] session_latest_clicks2orders_pair14 : start
# 0:46:52.260071 	 session_latest_clicks2orders_pair14
# 0:46:52.261201 	 {'num_clicks': 97136, 'hit_clicks': 307, 'num_carts': 37850, 'hit_carts': 175, 'num_orders': 17856, 'hit_orders': 176, 'recall_clicks': '0.003', 'recall_carts': '0.005', 'recall_orders': '0.010', 'w_recall_clicks': '0.000', 'w_recall_carts': '0.001', 'w_recall_orders': '0.006', 'score': '0.008'}
# 0:46:52.270536 	 [make_candidate] session_latest_time_wt_pair15 : start
# 0:46:52.924371 	 [add_candidate] session_latest_time_wt_pair15 : start
# 0:46:56.307235 	 session_latest_time_wt_pair15
# 0:46:56.308385 	 {'num_clicks': 97136, 'hit_clicks': 1434, 'num_carts': 37850, 'hit_carts': 556, 'num_orders': 17856, 'hit_orders': 308, 'recall_clicks': '0.015', 'recall_carts': '0.015', 'recall_orders': '0.017', 'w_recall_clicks': '0.001', 'w_recall_carts': '0.004', 'w_recall_orders': '0.010', 'score': '0.016'}
# 0:46:56.320174 	 [make_candidate] session_latest_word2vec_pair15 : start
# 0:46:56.724071 	 [add_candidate] session_latest_word2vec_pair15 : start
# 0:47:00.165221 	 session_latest_word2vec_pair15
# 0:47:00.166373 	 {'num_clicks': 97136, 'hit_clicks': 877, 'num_carts': 37850, 'hit_carts': 306, 'num_orders': 17856, 'hit_orders': 176, 'recall_clicks': '0.009', 'recall_carts': '0.008', 'recall_orders': '0.010', 'w_recall_clicks': '0.001', 'w_recall_carts': '0.002', 'w_recall_orders': '0.006', 'score': '0.009'}
# 0:47:00.177991 	 [make_candidate] session_latest_pair15 : start
# 0:47:00.751316 	 [add_candidate] session_latest_pair15 : start
# 0:47:04.139606 	 session_latest_pair15
# 0:47:04.140778 	 {'num_clicks': 97136, 'hit_clicks': 1216, 'num_carts': 37850, 'hit_carts': 679, 'num_orders': 17856, 'hit_orders': 428, 'recall_clicks': '0.013', 'recall_carts': '0.018', 'recall_orders': '0.024', 'w_recall_clicks': '0.001', 'w_recall_carts': '0.005', 'w_recall_orders': '0.014', 'score': '0.021'}
# 0:47:04.151807 	 [make_candidate] session_latest_type_wt_pair15 : start
# 0:47:04.526227 	 [add_candidate] session_latest_type_wt_pair15 : start
# 0:47:07.906357 	 session_latest_type_wt_pair15
# 0:47:07.907482 	 {'num_clicks': 97136, 'hit_clicks': 1230, 'num_carts': 37850, 'hit_carts': 795, 'num_orders': 17856, 'hit_orders': 455, 'recall_clicks': '0.013', 'recall_carts': '0.021', 'recall_orders': '0.025', 'w_recall_clicks': '0.001', 'w_recall_carts': '0.006', 'w_recall_orders': '0.015', 'score': '0.023'}
# 0:47:07.919083 	 [make_candidate] session_latest_clicks2carts_pair15 : start
# 0:47:08.289577 	 [add_candidate] session_latest_clicks2carts_pair15 : start
# 0:47:11.404493 	 session_latest_clicks2carts_pair15
# 0:47:11.405752 	 {'num_clicks': 97136, 'hit_clicks': 582, 'num_carts': 37850, 'hit_carts': 435, 'num_orders': 17856, 'hit_orders': 222, 'recall_clicks': '0.006', 'recall_carts': '0.011', 'recall_orders': '0.012', 'w_recall_clicks': '0.001', 'w_recall_carts': '0.003', 'w_recall_orders': '0.007', 'score': '0.012'}
# 0:47:11.415633 	 [make_candidate] session_latest_clicks2orders_pair15 : start
# 0:47:11.603926 	 [add_candidate] session_latest_clicks2orders_pair15 : start
# 0:47:14.665657 	 session_latest_clicks2orders_pair15
# 0:47:14.667321 	 {'num_clicks': 97136, 'hit_clicks': 301, 'num_carts': 37850, 'hit_carts': 178, 'num_orders': 17856, 'hit_orders': 170, 'recall_clicks': '0.003', 'recall_carts': '0.005', 'recall_orders': '0.010', 'w_recall_clicks': '0.000', 'w_recall_carts': '0.001', 'w_recall_orders': '0.006', 'score': '0.007'}
# 0:47:14.676717 	 [make_candidate] session_latest_time_wt_pair16 : start
# 0:47:15.207623 	 [add_candidate] session_latest_time_wt_pair16 : start
# 0:47:18.620167 	 session_latest_time_wt_pair16
# 0:47:18.621298 	 {'num_clicks': 97136, 'hit_clicks': 1306, 'num_carts': 37850, 'hit_carts': 521, 'num_orders': 17856, 'hit_orders': 334, 'recall_clicks': '0.013', 'recall_carts': '0.014', 'recall_orders': '0.019', 'w_recall_clicks': '0.001', 'w_recall_carts': '0.004', 'w_recall_orders': '0.011', 'score': '0.017'}
# 0:47:18.632990 	 [make_candidate] session_latest_word2vec_pair16 : start
# 0:47:19.071003 	 [add_candidate] session_latest_word2vec_pair16 : start
# 0:47:22.568215 	 session_latest_word2vec_pair16
# 0:47:22.569371 	 {'num_clicks': 97136, 'hit_clicks': 789, 'num_carts': 37850, 'hit_carts': 268, 'num_orders': 17856, 'hit_orders': 140, 'recall_clicks': '0.008', 'recall_carts': '0.007', 'recall_orders': '0.008', 'w_recall_clicks': '0.001', 'w_recall_carts': '0.002', 'w_recall_orders': '0.005', 'score': '0.008'}
# 0:47:22.581441 	 [make_candidate] session_latest_pair16 : start
# 0:47:23.141137 	 [add_candidate] session_latest_pair16 : start
# 0:47:26.468270 	 session_latest_pair16
# 0:47:26.469666 	 {'num_clicks': 97136, 'hit_clicks': 1071, 'num_carts': 37850, 'hit_carts': 671, 'num_orders': 17856, 'hit_orders': 382, 'recall_clicks': '0.011', 'recall_carts': '0.018', 'recall_orders': '0.021', 'w_recall_clicks': '0.001', 'w_recall_carts': '0.005', 'w_recall_orders': '0.013', 'score': '0.019'}
# 0:47:26.481122 	 [make_candidate] session_latest_type_wt_pair16 : start
# 0:47:26.794374 	 [add_candidate] session_latest_type_wt_pair16 : start
# 0:47:30.405531 	 session_latest_type_wt_pair16
# 0:47:30.406677 	 {'num_clicks': 97136, 'hit_clicks': 1175, 'num_carts': 37850, 'hit_carts': 775, 'num_orders': 17856, 'hit_orders': 454, 'recall_clicks': '0.012', 'recall_carts': '0.020', 'recall_orders': '0.025', 'w_recall_clicks': '0.001', 'w_recall_carts': '0.006', 'w_recall_orders': '0.015', 'score': '0.023'}
# 0:47:30.418488 	 [make_candidate] session_latest_clicks2carts_pair16 : start
# 0:47:30.847832 	 [add_candidate] session_latest_clicks2carts_pair16 : start
# 0:47:33.981308 	 session_latest_clicks2carts_pair16
# 0:47:33.982419 	 {'num_clicks': 97136, 'hit_clicks': 583, 'num_carts': 37850, 'hit_carts': 403, 'num_orders': 17856, 'hit_orders': 193, 'recall_clicks': '0.006', 'recall_carts': '0.011', 'recall_orders': '0.011', 'w_recall_clicks': '0.001', 'w_recall_carts': '0.003', 'w_recall_orders': '0.006', 'score': '0.010'}
# 0:47:33.992526 	 [make_candidate] session_latest_clicks2orders_pair16 : start
# 0:47:34.252220 	 [add_candidate] session_latest_clicks2orders_pair16 : start
# 0:47:37.287894 	 session_latest_clicks2orders_pair16
# 0:47:37.289053 	 {'num_clicks': 97136, 'hit_clicks': 255, 'num_carts': 37850, 'hit_carts': 157, 'num_orders': 17856, 'hit_orders': 135, 'recall_clicks': '0.003', 'recall_carts': '0.004', 'recall_orders': '0.008', 'w_recall_clicks': '0.000', 'w_recall_carts': '0.001', 'w_recall_orders': '0.005', 'score': '0.006'}
# 0:47:37.297786 	 [make_candidate] session_latest_time_wt_pair17 : start
# 0:47:37.692108 	 [add_candidate] session_latest_time_wt_pair17 : start
# 0:47:41.276055 	 session_latest_time_wt_pair17
# 0:47:41.277203 	 {'num_clicks': 97136, 'hit_clicks': 1295, 'num_carts': 37850, 'hit_carts': 513, 'num_orders': 17856, 'hit_orders': 296, 'recall_clicks': '0.013', 'recall_carts': '0.014', 'recall_orders': '0.017', 'w_recall_clicks': '0.001', 'w_recall_carts': '0.004', 'w_recall_orders': '0.010', 'score': '0.015'}
# 0:47:41.289442 	 [make_candidate] session_latest_word2vec_pair17 : start
# 0:47:41.703015 	 [add_candidate] session_latest_word2vec_pair17 : start
# 0:47:45.237304 	 session_latest_word2vec_pair17
# 0:47:45.238478 	 {'num_clicks': 97136, 'hit_clicks': 721, 'num_carts': 37850, 'hit_carts': 269, 'num_orders': 17856, 'hit_orders': 134, 'recall_clicks': '0.007', 'recall_carts': '0.007', 'recall_orders': '0.008', 'w_recall_clicks': '0.001', 'w_recall_carts': '0.002', 'w_recall_orders': '0.005', 'score': '0.007'}
# 0:47:45.250402 	 [make_candidate] session_latest_pair17 : start
# 0:47:45.929521 	 [add_candidate] session_latest_pair17 : start
# 0:47:49.366280 	 session_latest_pair17
# 0:47:49.367549 	 {'num_clicks': 97136, 'hit_clicks': 1044, 'num_carts': 37850, 'hit_carts': 583, 'num_orders': 17856, 'hit_orders': 350, 'recall_clicks': '0.011', 'recall_carts': '0.015', 'recall_orders': '0.020', 'w_recall_clicks': '0.001', 'w_recall_carts': '0.005', 'w_recall_orders': '0.012', 'score': '0.017'}
# 0:47:49.381037 	 [make_candidate] session_latest_type_wt_pair17 : start
# 0:47:49.811543 	 [add_candidate] session_latest_type_wt_pair17 : start
# 0:47:53.389556 	 session_latest_type_wt_pair17
# 0:47:53.390774 	 {'num_clicks': 97136, 'hit_clicks': 1073, 'num_carts': 37850, 'hit_carts': 756, 'num_orders': 17856, 'hit_orders': 434, 'recall_clicks': '0.011', 'recall_carts': '0.020', 'recall_orders': '0.024', 'w_recall_clicks': '0.001', 'w_recall_carts': '0.006', 'w_recall_orders': '0.015', 'score': '0.022'}
# 0:47:53.403790 	 [make_candidate] session_latest_clicks2carts_pair17 : start
# 0:47:53.849553 	 [add_candidate] session_latest_clicks2carts_pair17 : start
# 0:47:57.177497 	 session_latest_clicks2carts_pair17
# 0:47:57.178680 	 {'num_clicks': 97136, 'hit_clicks': 521, 'num_carts': 37850, 'hit_carts': 376, 'num_orders': 17856, 'hit_orders': 190, 'recall_clicks': '0.005', 'recall_carts': '0.010', 'recall_orders': '0.011', 'w_recall_clicks': '0.001', 'w_recall_carts': '0.003', 'w_recall_orders': '0.006', 'score': '0.010'}
# 0:47:57.189403 	 [make_candidate] session_latest_clicks2orders_pair17 : start
# 0:47:57.385401 	 [add_candidate] session_latest_clicks2orders_pair17 : start
# 0:48:00.472476 	 session_latest_clicks2orders_pair17
# 0:48:00.473888 	 {'num_clicks': 97136, 'hit_clicks': 240, 'num_carts': 37850, 'hit_carts': 145, 'num_orders': 17856, 'hit_orders': 140, 'recall_clicks': '0.002', 'recall_carts': '0.004', 'recall_orders': '0.008', 'w_recall_clicks': '0.000', 'w_recall_carts': '0.001', 'w_recall_orders': '0.005', 'score': '0.006'}
# 0:48:00.482607 	 [make_candidate] session_latest_time_wt_pair18 : start
# 0:48:01.011089 	 [add_candidate] session_latest_time_wt_pair18 : start
# 0:48:04.628136 	 session_latest_time_wt_pair18
# 0:48:04.629461 	 {'num_clicks': 97136, 'hit_clicks': 1281, 'num_carts': 37850, 'hit_carts': 490, 'num_orders': 17856, 'hit_orders': 276, 'recall_clicks': '0.013', 'recall_carts': '0.013', 'recall_orders': '0.015', 'w_recall_clicks': '0.001', 'w_recall_carts': '0.004', 'w_recall_orders': '0.009', 'score': '0.014'}
# 0:48:04.641021 	 [make_candidate] session_latest_word2vec_pair18 : start
# 0:48:05.129879 	 [add_candidate] session_latest_word2vec_pair18 : start
# 0:48:08.751588 	 session_latest_word2vec_pair18
# 0:48:08.752857 	 {'num_clicks': 97136, 'hit_clicks': 755, 'num_carts': 37850, 'hit_carts': 287, 'num_orders': 17856, 'hit_orders': 131, 'recall_clicks': '0.008', 'recall_carts': '0.008', 'recall_orders': '0.007', 'w_recall_clicks': '0.001', 'w_recall_carts': '0.002', 'w_recall_orders': '0.004', 'score': '0.007'}
# 0:48:08.766226 	 [make_candidate] session_latest_pair18 : start
# 0:48:09.323129 	 [add_candidate] session_latest_pair18 : start
# 0:48:12.866688 	 session_latest_pair18
# 0:48:12.868259 	 {'num_clicks': 97136, 'hit_clicks': 1018, 'num_carts': 37850, 'hit_carts': 618, 'num_orders': 17856, 'hit_orders': 363, 'recall_clicks': '0.010', 'recall_carts': '0.016', 'recall_orders': '0.020', 'w_recall_clicks': '0.001', 'w_recall_carts': '0.005', 'w_recall_orders': '0.012', 'score': '0.018'}
# 0:48:12.880306 	 [make_candidate] session_latest_type_wt_pair18 : start
# 0:48:13.339507 	 [add_candidate] session_latest_type_wt_pair18 : start
# 0:48:16.885080 	 session_latest_type_wt_pair18
# 0:48:16.886545 	 {'num_clicks': 97136, 'hit_clicks': 990, 'num_carts': 37850, 'hit_carts': 704, 'num_orders': 17856, 'hit_orders': 401, 'recall_clicks': '0.010', 'recall_carts': '0.019', 'recall_orders': '0.022', 'w_recall_clicks': '0.001', 'w_recall_carts': '0.006', 'w_recall_orders': '0.013', 'score': '0.020'}
# 0:48:16.898763 	 [make_candidate] session_latest_clicks2carts_pair18 : start
# 0:48:17.265850 	 [add_candidate] session_latest_clicks2carts_pair18 : start
# 0:48:20.647622 	 session_latest_clicks2carts_pair18
# 0:48:20.648867 	 {'num_clicks': 97136, 'hit_clicks': 513, 'num_carts': 37850, 'hit_carts': 357, 'num_orders': 17856, 'hit_orders': 175, 'recall_clicks': '0.005', 'recall_carts': '0.009', 'recall_orders': '0.010', 'w_recall_clicks': '0.001', 'w_recall_carts': '0.003', 'w_recall_orders': '0.006', 'score': '0.009'}
# 0:48:20.659397 	 [make_candidate] session_latest_clicks2orders_pair18 : start
# 0:48:20.860888 	 [add_candidate] session_latest_clicks2orders_pair18 : start
# 0:48:24.025355 	 session_latest_clicks2orders_pair18
# 0:48:24.026901 	 {'num_clicks': 97136, 'hit_clicks': 241, 'num_carts': 37850, 'hit_carts': 149, 'num_orders': 17856, 'hit_orders': 142, 'recall_clicks': '0.002', 'recall_carts': '0.004', 'recall_orders': '0.008', 'w_recall_clicks': '0.000', 'w_recall_carts': '0.001', 'w_recall_orders': '0.005', 'score': '0.006'}
# 0:48:24.037582 	 [make_candidate] session_latest_time_wt_pair19 : start
# 0:48:24.585540 	 [add_candidate] session_latest_time_wt_pair19 : start
# 0:48:28.292151 	 session_latest_time_wt_pair19
# 0:48:28.293555 	 {'num_clicks': 97136, 'hit_clicks': 1169, 'num_carts': 37850, 'hit_carts': 499, 'num_orders': 17856, 'hit_orders': 286, 'recall_clicks': '0.012', 'recall_carts': '0.013', 'recall_orders': '0.016', 'w_recall_clicks': '0.001', 'w_recall_carts': '0.004', 'w_recall_orders': '0.010', 'score': '0.015'}
# 0:48:28.306976 	 [make_candidate] session_latest_word2vec_pair19 : start
# 0:48:28.748229 	 [add_candidate] session_latest_word2vec_pair19 : start
# 0:48:32.368099 	 session_latest_word2vec_pair19
# 0:48:32.369677 	 {'num_clicks': 97136, 'hit_clicks': 709, 'num_carts': 37850, 'hit_carts': 297, 'num_orders': 17856, 'hit_orders': 143, 'recall_clicks': '0.007', 'recall_carts': '0.008', 'recall_orders': '0.008', 'w_recall_clicks': '0.001', 'w_recall_carts': '0.002', 'w_recall_orders': '0.005', 'score': '0.008'}
# 0:48:32.382341 	 [make_candidate] session_latest_pair19 : start
# 0:48:33.065249 	 [add_candidate] session_latest_pair19 : start
# 0:48:37.219080 	 session_latest_pair19
# 0:48:37.220279 	 {'num_clicks': 97136, 'hit_clicks': 911, 'num_carts': 37850, 'hit_carts': 588, 'num_orders': 17856, 'hit_orders': 353, 'recall_clicks': '0.009', 'recall_carts': '0.016', 'recall_orders': '0.020', 'w_recall_clicks': '0.001', 'w_recall_carts': '0.005', 'w_recall_orders': '0.012', 'score': '0.017'}
# 0:48:37.233788 	 [make_candidate] session_latest_type_wt_pair19 : start
# 0:48:37.697842 	 [add_candidate] session_latest_type_wt_pair19 : start
# 0:48:42.051251 	 session_latest_type_wt_pair19
# 0:48:42.052685 	 {'num_clicks': 97136, 'hit_clicks': 994, 'num_carts': 37850, 'hit_carts': 678, 'num_orders': 17856, 'hit_orders': 436, 'recall_clicks': '0.010', 'recall_carts': '0.018', 'recall_orders': '0.024', 'w_recall_clicks': '0.001', 'w_recall_carts': '0.005', 'w_recall_orders': '0.015', 'score': '0.021'}
# 0:48:42.065491 	 [make_candidate] session_latest_clicks2carts_pair19 : start
# 0:48:42.461956 	 [add_candidate] session_latest_clicks2carts_pair19 : start
# 0:48:46.503523 	 session_latest_clicks2carts_pair19
# 0:48:46.504650 	 {'num_clicks': 97136, 'hit_clicks': 471, 'num_carts': 37850, 'hit_carts': 314, 'num_orders': 17856, 'hit_orders': 150, 'recall_clicks': '0.005', 'recall_carts': '0.008', 'recall_orders': '0.008', 'w_recall_clicks': '0.000', 'w_recall_carts': '0.002', 'w_recall_orders': '0.005', 'score': '0.008'}
# 0:48:46.515507 	 [make_candidate] session_latest_clicks2orders_pair19 : start
# 0:48:46.786895 	 [add_candidate] session_latest_clicks2orders_pair19 : start
# 0:48:50.604506 	 session_latest_clicks2orders_pair19
# 0:48:50.605963 	 {'num_clicks': 97136, 'hit_clicks': 200, 'num_carts': 37850, 'hit_carts': 142, 'num_orders': 17856, 'hit_orders': 127, 'recall_clicks': '0.002', 'recall_carts': '0.004', 'recall_orders': '0.007', 'w_recall_clicks': '0.000', 'w_recall_carts': '0.001', 'w_recall_orders': '0.004', 'score': '0.006'}

# %%
results
# Out:
#                                    name num_clicks hit_clicks num_carts  \
# 0                      session_frequent      97136      29467     42864
# 0                        session_latest      97136      29677     42864
# 0         w2v_session_total_aid_vec_sim      97136      33577     43211
# 0   w2v_session_carts_total_aid_vec_sim      97136       4803     43211
# 0          session_latest_time_wt_pair0      97136       8458     37850
# ..                                  ...        ...        ...       ...
# 0        session_latest_word2vec_pair19      97136        709     37850
# 0                 session_latest_pair19      97136        911     37850
# 0         session_latest_type_wt_pair19      97136        994     37850
# 0    session_latest_clicks2carts_pair19      97136        471     37850
# 0   session_latest_clicks2orders_pair19      97136        200     37850
#
#    hit_carts num_orders hit_orders recall_clicks recall_carts recall_orders  \
# 0      10730      19985      10185         0.303        0.250         0.510
# 0      10822      19985       9838         0.306        0.252         0.492
# 0       8796      20082       5541         0.346        0.204         0.276
# 0       3151      20082       4854         0.049        0.073         0.242
# 0       2410      17856       1542         0.087        0.064         0.086
# ..       ...        ...        ...           ...          ...           ...
# 0        297      17856        143         0.007        0.008         0.008
# 0        588      17856        353         0.009        0.016         0.020
# 0        678      17856        436         0.010        0.018         0.024
# 0        314      17856        150         0.005        0.008         0.008
# 0        142      17856        127         0.002        0.004         0.007
#
#    w_recall_clicks w_recall_carts w_recall_orders  score
# 0            0.030          0.075           0.306  0.411
# 0            0.031          0.076           0.295  0.402
# 0            0.035          0.061           0.166  0.261
# 0            0.005          0.022           0.145  0.172
# 0            0.009          0.019           0.052  0.080
# ..             ...            ...             ...    ...
# 0            0.001          0.002           0.005  0.008
# 0            0.001          0.005           0.012  0.017
# 0            0.001          0.005           0.015  0.021
# 0            0.000          0.002           0.005  0.008
# 0            0.000          0.001           0.004  0.006
#
# [124 rows x 14 columns]

# %%
fig, axs = plt.subplots(1, 3)
sns.heatmap(results.set_index("name")[["recall_clicks"]].astype(float),
            annot=True, linewidths=.5, fmt="1.2f", cmap="Reds", cbar=False, ax=axs[0])
sns.heatmap(results.set_index("name")[["recall_carts"]].astype(float),
            annot=True, linewidths=.5, fmt="1.2f", cmap="Reds", cbar=False, ax=axs[1], yticklabels=False)
sns.heatmap(results.set_index("name")[["recall_orders"]].astype(float),
            annot=True, linewidths=.5, fmt="1.2f", cmap="Reds", cbar=False, ax=axs[2], yticklabels=False)
plt.savefig(cfg.output_dir + f'{cfg.exp_name}/candidate_strategy_recalls.png')

# %%
# 予測値を全て使えたときのrecall
valid_all = valid.drop_duplicates(subset= ["session", "aid"])
session_cnt_max = valid_all["session"].value_counts().max()
valid_all = valid_all.groupby("session")["aid"].apply(list).reset_index()

all_results = evaluate(valid_labels["clicks_labels"].tolist(),
                       valid_labels["carts_labels"].tolist(),
                       valid_labels["orders_labels"].tolist(),
                       valid_all["aid"].tolist(),
                       valid_all["aid"].tolist(),
                       valid_all["aid"].tolist(),
                       session_cnt_max)
logger.info("session_cnt_max")
logger.info(session_cnt_max)
logger.info("all_pred_results")
logger.info(all_results)
# Out:
# 0:48:58.584509 	 session_cnt_max
# 0:48:58.585698 	 413
# 0:48:58.586614 	 all_pred_results
# 0:48:58.587382 	 {'num_clicks': 97136, 'hit_clicks': 61156, 'num_carts': 43611, 'hit_carts': 24192, 'num_orders': 20109, 'hit_orders': 14893, 'recall_clicks': '0.630', 'recall_carts': '0.555', 'recall_orders': '0.741', 'w_recall_clicks': '0.063', 'w_recall_carts': '0.166', 'w_recall_orders': '0.444', 'score': '0.674'}
