# %% [markdown]
# # exp045
# cand_trial調整

# %%
import os
import sys
import traceback
import gc
import random
import pickle
import pathlib
import subprocess
from dataclasses import dataclass
from dotenv import load_dotenv
load_dotenv
sys.path.append(os.getenv('UTILS_PATH'))
from tqdm import tqdm
import multiprocessing
import inspect

import pandas as pd
import numpy as np
import itertools
import cudf
import lightgbm as lgb
import matplotlib.pyplot as plt
import seaborn as sns
import line_notify
import my_logger
from noglobal import noglobal

# %% [markdown]
# # 設定

# %%
@dataclass
class Cfg:
    loglevel = "INFO"
    exp_name = "exp045"
    seed = 42
    k = 20
    cand_n = 15
    negative_sample = 1
    train_chunk_n = 10
    type2id = {"clicks":0, "carts":1, "orders":2}
    id2type = {0:"clicks", 1:"carts", 2:"orders"}
    train_weeks = ["week3"]
    valid_week = "week4"
    valid_session_n = 100_000
    input_dir = os.getenv('INPUT_DIR')
    output_dir = os.getenv('OUTPUT_DIR')
    prep_dir = os.getenv("PREP_DIR")

cfg = Cfg()
os.makedirs(os.path.join(cfg.output_dir, cfg.exp_name), exist_ok=True)
os.makedirs(os.path.join(cfg.output_dir, cfg.exp_name, "cache"), exist_ok=True)
random.seed(cfg.seed)

logger = my_logger.init_logger(cfg.exp_name)

# %%
class Cache:
    @noglobal(excepts=["cfg", "logger"])
    def __init__(self):
        self.cache_dir = (os.path.join(cfg.output_dir, cfg.exp_name, "cache"))
        self.cache_dir_path = pathlib.Path(self.cache_dir)
        self.caches = list(self.cache_dir_path.glob("*.pkl"))

    @noglobal(excepts=["cfg", "logger"])
    def get_abspath(self, filename):
        return (os.path.join(self.cache_dir, filename))
    
    @noglobal(excepts=["cfg", "logger"])
    def exists(self, path):
        return len([str(c) for c in self.caches if path == str(c)]) > 0


cache = Cache()

# %%
def reduce_mem_usage(df):
    """ iterate through all the columns of a dataframe and modify the data type
        to reduce memory usage.        
    """
    start_mem = df.memory_usage().sum() / 1024**2
    print('Memory usage of dataframe is {:.2f} MB'.format(start_mem))
    
    for col in df.columns:
        col_type = df[col].dtype
        
        if col_type != object:
            c_min = df[col].min()
            c_max = df[col].max()
            if str(col_type)[:3] == 'int':
                if c_min > np.iinfo(np.int8).min and c_max < np.iinfo(np.int8).max:
                    df[col] = df[col].astype(np.int8)
                elif c_min > np.iinfo(np.int16).min and c_max < np.iinfo(np.int16).max:
                    df[col] = df[col].astype(np.int16)
                elif c_min > np.iinfo(np.int32).min and c_max < np.iinfo(np.int32).max:
                    df[col] = df[col].astype(np.int32)
                elif c_min > np.iinfo(np.int64).min and c_max < np.iinfo(np.int64).max:
                    df[col] = df[col].astype(np.int64)  
            else:
                if c_min > np.finfo(np.float16).min and c_max < np.finfo(np.float16).max:
                    df[col] = df[col].astype(np.float16)
                elif c_min > np.finfo(np.float32).min and c_max < np.finfo(np.float32).max:
                    df[col] = df[col].astype(np.float32)
                else:
                    df[col] = df[col].astype(np.float64)
        else:
            df[col] = df[col].astype('category')

    end_mem = df.memory_usage().sum() / 1024**2
    print('Memory usage after optimization is: {:.2f} MB'.format(end_mem))
    print('Decreased by {:.1f}%'.format(100 * (start_mem - end_mem) / start_mem))
    
    return df

# %%
@noglobal(excepts=["cfg", "logger"])
def evaluate(clicks_labels, carts_labels, orders_labels, 
             clicks_preds, carts_preds, orders_preds, k=20):

    num_clicks = 0
    num_carts = 0
    num_orders = 0
    hit_clicks = 0
    hit_carts = 0
    hit_orders = 0

    for i in range(len(clicks_labels)):
        clicks_label = clicks_labels[i]
        carts_label = carts_labels[i]
        orders_label = orders_labels[i]
        clicks_pred = clicks_preds[i]
        carts_pred = carts_preds[i]
        orders_pred = orders_preds[i]

        if type(clicks_pred) == list:
            clicks_pred = clicks_pred[:k]
        else:
            clicks_pred = []
        if type(carts_pred) == list:
            carts_pred = carts_pred[:k]
        else:
            carts_pred = []    
        if type(orders_pred) == list:
            orders_pred = orders_pred[:k]
        else:
            orders_pred = []

        if not np.isnan(clicks_label):
            num_clicks += 1
            hit_clicks += int(clicks_label in clicks_pred)

        if type(carts_label) == list:
            num_carts += min(len(carts_label), k)
            hit_carts += len(set(carts_pred) & set(carts_label))
            
        if type(orders_label) == list:
            num_orders += min(len(orders_label), k)
            hit_orders += len(set(orders_pred) & set(orders_label))


    recall_clicks = hit_clicks / num_clicks
    recall_carts = hit_carts / num_carts
    recall_orders = hit_orders / num_orders
    w_recall_clicks = recall_clicks * 0.10
    w_recall_carts = recall_carts * 0.30
    w_recall_orders = recall_orders * 0.60
    score = w_recall_clicks + w_recall_carts + w_recall_orders

    results = {}
    results["num_clicks"] = num_clicks
    results["hit_clicks"] = hit_clicks
    results["num_carts"] = num_carts
    results["hit_carts"] = hit_carts
    results["num_orders"] = num_orders
    results["hit_orders"] = hit_orders
    results["recall_clicks"] = format(recall_clicks, ".3f")
    results["recall_carts"] = format(recall_carts, ".3f")
    results["recall_orders"] = format(recall_orders, ".3f")
    results["w_recall_clicks"] = format(w_recall_clicks, ".3f")
    results["w_recall_carts"] = format(w_recall_carts, ".3f")
    results["w_recall_orders"] = format(w_recall_orders, ".3f")
    results["score"] = format(score, ".3f")

    return results

# %%
class Candidate:
    @noglobal(excepts=["cfg", "logger"])
    def __init__(self, pdf, labels=None):
        self.df = cudf.from_pandas(pdf)
        self.target_sessions = pdf["session"].unique().tolist()
        self.results = pd.DataFrame(columns=["name", "num_clicks", "hit_clicks", "num_carts", "hit_carts", "num_orders", "hit_orders", 
                                             "recall_clicks", "recall_carts", "recall_orders", "w_recall_clicks", "w_recall_carts", "w_recall_orders", "score"])
        self.output = pd.DataFrame(columns=["session", "aid"], dtype=int)
        self.labels = labels
    
    @noglobal(excepts=["cfg", "logger"])
    def _entry(self, new_candidate_df, name, k):
        logger.info(f"[add_candidate] {name} : start")
        new_candidate_df[f"{name}_rank"] = new_candidate_df.groupby("session")["session"].cumcount()
        new_candidate_df = new_candidate_df.to_pandas()
        self.output = pd.concat([self.output, new_candidate_df[["session", "aid"]]])
        self.output = self.output.drop_duplicates(subset=["session", "aid"])
        
        self.output = self.output.merge(new_candidate_df, on=["session", "aid"], how="left")

        if self.labels is not None:
            self._eval(new_candidate_df[["session", "aid"]], name, k)
    
    @noglobal(excepts=["cfg", "logger"])
    def _eval(self, new_candidate_df, name, k):
        new_candidate_df = new_candidate_df.groupby("session")["aid"].apply(list).reset_index()
        eval_df = pd.DataFrame(self.target_sessions, columns=["session"])
        eval_df = eval_df.merge(new_candidate_df, on=["session"], how="left")
        assert eval_df["session"].tolist() == self.labels["session"].tolist()
        eval_result = evaluate(self.labels["clicks_labels"].tolist(), self.labels["carts_labels"].tolist(), self.labels["orders_labels"].tolist(),
                               eval_df["aid"].tolist(), eval_df["aid"].tolist(), eval_df["aid"].tolist(), k)
        
        print(eval_result)
        self.results = pd.concat([self.results, pd.DataFrame([[name] + list(eval_result.values())], columns=["name"] + list(eval_result.keys()))])

    @noglobal(excepts=["cfg", "logger"])
    def add(self, strategy, name, usetypes=['clicks', 'carts', 'orders'], trans_map=None, k=20):
        logger.info(f"[make_candidate] {name} : start")
        candidate_df = self.df[self.df["type"].isin(usetypes)].copy()
        
        if strategy == "session_frequent":
            candidate_df = self._session_frequent(candidate_df, k)
        elif strategy == "session_latest":
            candidate_df = self._session_latest(candidate_df, k)
        elif strategy == "total_frequent":
            candidate_df = self._total_frequent(candidate_df, k)
        
        if trans_map is not None:
            candidate_df["aid"] = candidate_df["aid"].map(trans_map)
            candidate_df = candidate_df.dropna(subset=["aid"])
            
        self._entry(candidate_df, name, k)

    @noglobal(excepts=["cfg", "logger"])
    def _session_frequent(self, candidate_df, k):
        candidate_df = candidate_df.groupby(["session", "aid"])["ts"].count().reset_index()
        candidate_df.columns = ["session", "aid", "aid_count"]
        candidate_df = candidate_df.sort_values(["session", "aid_count", "aid"], ascending=(True, False, True))
        candidate_df = candidate_df[candidate_df.groupby("session")["aid_count"].cumcount() < k].copy()
        candidate_df = candidate_df[["session", "aid"]].copy()
        return candidate_df

    @noglobal(excepts=["cfg", "logger"])
    def _session_latest(self, candidate_df, k):
        candidate_df = candidate_df.sort_values(["session", "ts"], ascending=(True, False)).drop_duplicates(subset=["session", "aid"])
        candidate_df = candidate_df.sort_values(["session", "ts"], ascending=(True, False))[candidate_df.groupby("session")["ts"].cumcount() < k].copy()
        candidate_df = candidate_df[["session", "aid"]].copy()
        return candidate_df

    @noglobal(excepts=["cfg", "logger"])
    def _total_frequent(self, candidate_df, k):
        candidate_df = candidate_df.groupby("aid")["ts"].count().reset_index()
        candidate_df.columns = ["aid", "aid_count"]
        topk_freq_aids = candidate_df.sort_values("aid_count", ascending=False)["aid"].to_arrow().to_pylist()[:k]
        sessions = []
        aids = []
        for session, aid in itertools.product(self.target_sessions, topk_freq_aids):
            sessions.append(session)
            aids.append(aid)
        candidate_df = cudf.DataFrame({"session": sessions, "aid": aids})
        return candidate_df

# %%
@noglobal(excepts=["cfg", "logger"])
def add_labels(df, labels, type_):
    type_labels = labels[["session", f"{type_}_labels"]].dropna().copy()
    type_labels.columns = ["session", "aid"]
    type_labels = type_labels.explode("aid")
    type_labels["labels"] = 1
    df = df.merge(type_labels, on=["session", "aid"], how="left")
    df["labels"] = df["labels"].fillna(0)
    return df

# %%
@noglobal(excepts=["cfg", "logger"])
def add_ground_truth_candidate(df, labels, type_):
    gt = labels[["session", f"{type_}_labels"]].dropna().copy()
    gt.columns = ["session", "aid"]
    gt = gt.explode("aid")
    df = pd.concat([df, gt])
    df = df.drop_duplicates()
    return df

# %%
@noglobal(excepts=["cfg", "logger"])
def under_sampling(df, label_col):
    cfg = Cfg()
    pos_df = df[df[label_col]==1].copy()
    neg_df = df[df[label_col]==0].copy()
    pos_n = len(pos_df)
    return pd.concat([pos_df, neg_df.sample(pos_n * cfg.negative_sample, random_state=cfg.seed)])

# %%
class Features:
    @noglobal(excepts=["cfg", "logger"])
    def __init__(self, sessions, candidate, week):
        self.sessions = cudf.from_pandas(sessions)
        self.output = candidate
        self.type_dict = cfg.type2id
        self.week = week

    @noglobal(excepts=["cfg", "logger"])
    def add_features(self):
            self._prep()
            self._session_cnt()
            self._session_aid_nunique()
            self._session_last_type()
            # self._session_last_dt()
            self._aid_cnt()
            self._all_times_aid_features()
            self._w2v_vectors()
            # self._session_mean_ts()
            # self._aid_mean_ts()
            # self._aid_cnt_ratio_at_session_last()
            # self.output = self.output.drop(columns=["session_last_day"]) # 日時はtrainセット内のみで有効なので削除

    @noglobal(excepts=["cfg", "logger"])
    def _prep(self):
        logger.info("[features] prep : start")
        # ts関連の前処理
        self.sessions["relative_ts"] = self.sessions["ts"] - self.sessions["ts"].min()
        self.sessions["dt"] = cudf.to_datetime(self.sessions["ts"], unit="ms")
        self.sessions["hour"] = self.sessions["dt"].dt.hour
        self.sessions["week"] = self.sessions["dt"].dt.dayofweek
        self.sessions["day"] = self.sessions["dt"].dt.day
        
    @noglobal(excepts=["cfg", "logger"])
    def _session_cnt(self):
        logger.info("[features] session_cnt : start")
        agg_df = self.sessions.groupby(["session", "type"])["ts"].count().reset_index().rename(columns={"ts": "cnt"})
        # session_total_cnt
        features = agg_df.groupby("session")["cnt"].sum().reset_index().rename(columns={"cnt": "session_total_cnt"})
        self.output = self.output.merge(features.to_pandas(), on=["session"], how="left")
        self.output["session_total_cnt"] = self.output["session_total_cnt"].fillna(0)
        # session_{type}_cnt
        for type_ in ["clicks", "carts", "orders"]:
            col_name = f"session_{type_}_cnt"
            features = agg_df[agg_df["type"]==type_].copy()
            features = features.rename(columns={"cnt": col_name})
            features = features[["session", col_name]].copy()
            self.output = self.output.merge(features.to_pandas(), on=["session"], how="left")
            self.output[col_name] = self.output[col_name].fillna(0)
        
    @noglobal(excepts=["cfg", "logger"])
    def _session_aid_nunique(self):
        logger.info("[features] session_aid_nunique : start")
        features = self.sessions.groupby("session")["aid"].nunique().reset_index().rename(columns={"aid": "session_aid_nunique"})
        self.output = self.output.merge(features.to_pandas(), on=["session"], how="left")
        self.output["session_aid_nunique"] = self.output["session_aid_nunique"].fillna(0)
        
    @noglobal(excepts=["cfg", "logger"])
    def _session_last_type(self):
        logger.info("[features] session_last_type : start")
        features = self.sessions.groupby("session").nth(-1).reset_index()[["session", "type"]]
        features = features.rename(columns={"type": "session_last_type"})
        features["session_last_type"] = features["session_last_type"].map(self.type_dict)
        self.output = self.output.merge(features.to_pandas(), on=["session"], how="left")
        
    @noglobal(excepts=["cfg", "logger"])
    def _session_last_dt(self):
        logger.info("[features] session_last_dt : start")
        features = self.sessions.groupby("session").nth(-1).reset_index()[["session", "relative_ts", "week", "day", "hour"]]
        features.columns = ["session", "session_last_ts", "session_last_week", "session_last_day", "session_last_hour"]
        self.output = self.output.merge(features.to_pandas(), on=["session"], how="left")
        
    @noglobal(excepts=["cfg", "logger"])
    def _session_mean_ts(self):
        logger.info("[features] session_mean_ts : start")
        features = self.sessions.groupby("session")["relative_ts"].mean().reset_index().rename(columns={"relative_ts": "session_mean_ts"})
        self.output = self.output.merge(features.to_pandas(), on=["session"], how="left")
        
    @noglobal(excepts=["cfg", "logger"])
    def _aid_mean_ts(self):
        logger.info("[features] aid_mean_ts : start")
        features = self.sessions.groupby("aid")["relative_ts"].mean().reset_index().rename(columns={"relative_ts": "aid_mean_ts"})
        self.output = self.output.merge(features.to_pandas(), on=["aid"], how="left")
       
    @noglobal(excepts=["cfg", "logger"])
    def _aid_session_nunique(self):
        logger.info("[features] aid_session_unique : start")
        features = self.sessions.groupby("aid")["session"].nunique().reset_index().rename(columns={"session": "aid_session_nunique"})
        self.output = self.output.merge(features.to_pandas(), on=["aid"], how="left")

    @noglobal(excepts=["cfg", "logger"]) 
    def _aid_cnt_ratio_at_session_last(self):
        logger.info("[features] aid_cnt_ratio_atsession_last : start")
        for dt_ in ["week", "day", "hour"]:
            features = self.sessions[["aid", dt_]].copy()
            features["total_cnt"] = features.groupby(dt_)["aid"].transform("count")
            features = features.groupby(["aid", dt_])["total_cnt"].agg(["count", "max"]).reset_index()
            features[f"aid_cnt_ratio_at_session_last_{dt_}"] = features["count"] / features["max"]
            features = features.rename(columns={dt_: f"session_last_{dt_}"})
            self.output = self.output.merge(features[["aid", f"session_last_{dt_}", f"aid_cnt_ratio_at_session_last_{dt_}"]].to_pandas(), on=["aid", f"session_last_{dt_}"], how="left")
            self.output[f"aid_cnt_ratio_at_session_last_{dt_}"] = self.output[f"aid_cnt_ratio_at_session_last_{dt_}"].fillna(0)
        
    @noglobal(excepts=["cfg", "logger"])
    def _aid_cnt(self):
        logger.info("[features] aid_cnt : start")
        agg_df = self.sessions.groupby(["session", "aid", "type"])["ts"].count().reset_index().rename(columns={"ts": "cnt"})

        # aid_total_cnt
        features = agg_df.groupby(["session", "aid"])["cnt"].sum().reset_index().rename(columns={"cnt": "aid_total_cnt"})
        self.output = self.output.merge(features.to_pandas(), on=["session", "aid"], how="left")
        self.output["aid_total_cnt"] = self.output["aid_total_cnt"].fillna(0)

        # aid_{type}_cnt
        for type_ in ["clicks", "carts", "orders"]:
            col_name = f"aid_{type_}_cnt"
            features = agg_df[agg_df["type"]==type_].copy()
            features = features.rename(columns={"cnt": col_name})
            features = features[["session", "aid", col_name]].copy()
            self.output = self.output.merge(features.to_pandas(), on=["session", "aid"], how="left")
            self.output[col_name] = self.output[col_name].fillna(0)

    @noglobal(excepts=["cfg", "logger"])
    def _all_times_aid_features(self):
        feats = ["all_times_aid_freq",
                 "all_times_aid_clicks_freq",
                 "all_times_aid_carts_freq",
                 "all_times_aid_orders_freq",
                 "all_times_aid_session_freq",
                 "all_times_aid_session_clicks_freq",
                 "all_times_aid_session_carts_freq",
                 "all_times_aid_session_orders_freq",
                 "all_times_aid_carts_ratio_with_clicks",
                 "all_times_aid_orders_ratio_with_clicks",
                 "all_times_aid_date_std",
                 "all_times_aid_hour_std",
                 "all_times_aid_day_of_week_std"]
        
        for feat in feats:
            if self.week is None:
                with open(cfg.prep_dir + f"{feat}.pkl", "rb") as f:
                    feat_map = pickle.load(f)
            else:
                with open(cfg.prep_dir + f"{feat}_{self.week}.pkl", "rb") as f:
                    feat_map = pickle.load(f)
            self.output[feat] = self.output["aid"].map(feat_map)

    @noglobal(excepts=["cfg", "logger"])
    def _w2v_vectors(self):
        w2v_vecs = pd.read_pickle(cfg.prep_dir + "w2v_vector_n5.pkl")
        self.output = self.output.merge(w2v_vecs, on="aid", how="left")

# %%
@noglobal(excepts=["cfg", "logger"])
def add_features(sessions, cand_df, week=None):
    feat = Features(sessions, cand_df, week)
    feat.add_features()
    return feat.output

# %%
@noglobal(excepts=["cfg", "logger"])
def make_cand_df(sessions, labels=None, trans_maps=None):

    if labels is not None:
         cand = Candidate(sessions, labels)
    else:
        cand = Candidate(sessions)

    cand.add(strategy="session_frequent", name="session_frequent", k=15)
    cand.add(strategy="session_latest", name="session_latest", k=15)
    
    for i in range(20):
        cand.add(strategy="session_latest", trans_map=trans_maps[f"time_wt_pair{str(i)}"], name=f"session_latest_time_wt_pair{str(i)}", k=5)
        cand.add(strategy="session_latest", trans_map=trans_maps[f"word2vec_pair{str(i)}"], name=f"session_latest_word2vec_pair{str(i)}", k=5)
        cand.add(strategy="session_latest", trans_map=trans_maps[f"pair{str(i)}"], name=f"session_latest_pair{str(i)}", k=5)
    for i in range(5):
        cand.add(strategy="session_latest", trans_map=trans_maps[f"type_wt_pair{str(i)}"], name=f"session_latest_type_wt_pair{str(i)}", k=5)
        cand.add(strategy="session_latest", trans_map=trans_maps[f"clicks2carts_pair{str(i)}"], name=f"session_latest_clicks2carts_pair{str(i)}", k=5)
        cand.add(strategy="session_latest", trans_map=trans_maps[f"clicks2orders_pair{str(i)}"], name=f"session_latest_clicks2orders_pair{str(i)}", k=5)
        

    if labels is not None:
        return cand.output, cand.results
    else:
        return cand.output

# %%
@noglobal(excepts=["cfg", "logger"])
def get_pair_df(name, wt_col, week):
    if week is not None:
        name = f"{name}_{week}"
    pair_df = pd.read_pickle(cfg.prep_dir + f"{name}.pkl")
    pair_df = pair_df.sort_values(["aid_x", wt_col], ascending=(True, False))
    return pair_df

@noglobal(excepts=["cfg", "logger"])
def get_pair_dict(name, wt_col, week):
    if week is not None:
        name = f"{name}_{week}"
    pair_df = pd.read_pickle(cfg.prep_dir + f"{name}.pkl")
    pair_df = pair_df.sort_values(["aid_x", wt_col], ascending=(True, False))
    pair_df = pair_df.groupby("aid_x").head(1)[["aid_x", "aid_y"]]
    pair_dict = {k: v for k, v in zip(pair_df["aid_x"].tolist(), pair_df["aid_y"].tolist())}
    return pair_dict

@noglobal(excepts=["cfg", "logger"])
def get_trans_maps(week=None):
    """
    aidを別のaidに置き換えるmapping辞書を取得する
    """
    trans_maps = {}
    
    pair_df_org = get_pair_df("co_visitation_matrix", "cnt", week)
    for i in range(20):
        pair_df = pair_df_org.groupby("aid_x").nth(i).reset_index()[["aid_x", "aid_y"]]
        pair_dict = {k: v for k, v in zip(pair_df["aid_x"].tolist(), pair_df["aid_y"].tolist())}
        trans_maps[f"pair{str(i)}"] = pair_dict
    
    pair_df_org = get_pair_df("co_visitation_matrix_time_weighted", "wt", week)
    for i in range(20):
        pair_df = pair_df_org.groupby("aid_x").nth(i).reset_index()[["aid_x", "aid_y"]]
        pair_dict = {k: v for k, v in zip(pair_df["aid_x"].tolist(), pair_df["aid_y"].tolist())}
        trans_maps[f"time_wt_pair{str(i)}"] = pair_dict

    pair_df_org = get_pair_df("co_visitation_matrix_type_weighted", "wt", week)
    for i in range(5):
        pair_df = pair_df_org.groupby("aid_x").nth(i).reset_index()[["aid_x", "aid_y"]]
        pair_dict = {k: v for k, v in zip(pair_df["aid_x"].tolist(), pair_df["aid_y"].tolist())}
        trans_maps[f"type_wt_pair{str(i)}"] = pair_dict

    pair_df_org = get_pair_df("co_visitation_matrix_clicks2carts", "cnt", week)
    for i in range(5):
        pair_df = pair_df_org.groupby("aid_x").nth(i).reset_index()[["aid_x", "aid_y"]]
        pair_dict = {k: v for k, v in zip(pair_df["aid_x"].tolist(), pair_df["aid_y"].tolist())}
        trans_maps[f"clicks2carts_pair{str(i)}"] = pair_dict

    pair_df_org = get_pair_df("co_visitation_matrix_clicks2orders", "cnt", week)
    for i in range(5):
        pair_df = pair_df_org.groupby("aid_x").nth(i).reset_index()[["aid_x", "aid_y"]]
        pair_dict = {k: v for k, v in zip(pair_df["aid_x"].tolist(), pair_df["aid_y"].tolist())}
        trans_maps[f"clicks2orders_pair{str(i)}"] = pair_dict

    pair_df_org = get_pair_df("word2vec_similar", "sim", None)
    for i in range(20):
        pair_df = pair_df_org.groupby("aid_x").nth(i).reset_index()[["aid_x", "aid_y"]]
        pair_dict = {k: v for k, v in zip(pair_df["aid_x"].tolist(), pair_df["aid_y"].tolist())}
        trans_maps[f"word2vec_pair{str(i)}"] = pair_dict

    return trans_maps

# %%
@noglobal(excepts=["cfg", "logger", "cache"])
def make_train_data(type_):
    dfs = []
    for weeks in cfg.train_weeks:
        # データ読み込み
        week_sessions = pd.read_pickle(cfg.prep_dir + f"train_sessions_{weeks}.pkl")
        week_labels = pd.read_pickle(cfg.prep_dir + f"labels_{weeks}.pkl")
        sessions_lists = np.array_split(week_sessions["session"].unique().tolist(), cfg.train_chunk_n)

        # cand作成
        for chunk in range(cfg.train_chunk_n):
            cache_file = f"train_cand_{weeks}_{chunk}.pkl"
            cache_path = cache.get_abspath(cache_file)
            print(cache_path)
            if cache.exists(cache_path):
                logger.info(f"[{cache_file}] cache exists. read cache and skip process.")
                cand_df = pd.read_pickle(cache_path)
            else:
                trans_map_cache_file = f"trans_maps_{weeks}.pkl"
                trans_map_cache_path = cache.get_abspath(trans_map_cache_file)
                with open(trans_map_cache_path, "rb") as f:
                    trans_maps = pickle.load(f)
                # 候補選出
                week_sessions_chunk = week_sessions[week_sessions["session"].isin(sessions_lists[chunk])].reset_index(drop=True)
                cand_df = make_cand_df(week_sessions_chunk, trans_maps=trans_maps)
                cand_df = reduce_mem_usage(cand_df)
                cand_df.to_pickle(cache_path)
                del week_sessions_chunk
                gc.collect()

        # candラベル付け・サンプリング
        dfs = []
        for chunk in range(cfg.train_chunk_n):
            cache_file = f"train_cand_{weeks}_{chunk}.pkl"
            cache_path = cache.get_abspath(cache_file)
            cand_df_chunk = pd.read_pickle(cache_path)
            week_labels_chunk = week_labels[week_labels["session"].isin(sessions_lists[chunk])].reset_index(drop=True)
            cand_df_chunk = add_labels(cand_df_chunk, week_labels_chunk, type_)
            cand_df_chunk = under_sampling(cand_df_chunk, "labels")
            dfs.append(cand_df_chunk)
            del cand_df_chunk, week_labels_chunk
            gc.collect()
        cand_df = pd.cancat(dfs)
        del dfs
        gc.collect()

        # 特徴量付与
        train_tmp = add_features(week_sessions, cand_df, weeks)
        dfs.append(train_tmp)
        del cand_df, train_tmp
        gc.collect()
        
    train = pd.concat(dfs)
    train = train.reset_index(drop=True)
    train = reduce_mem_usage(train)
    
    return train

# %%
@noglobal(excepts=["cfg", "logger", "cache"])
def make_valid_cand():
    valid_week = cfg.valid_week
    # データ読み込み
    week_sessions = pd.read_pickle(os.getenv("PREP_DIR") + f"train_sessions_{valid_week}.pkl")
    week_labels = pd.read_pickle(os.getenv("PREP_DIR") + f"labels_{valid_week}.pkl")
    valid_session_ids = week_sessions["session"].unique().tolist()
    trans_map_cache_file = f"trans_maps_{valid_week}.pkl"
    trans_map_cache_path = cache.get_abspath(trans_map_cache_file)
    with open(trans_map_cache_path, "rb") as f:
        trans_maps = pickle.load(f)

    # validに使うsessionを絞る
    valid_session_n = min(cfg.valid_session_n, len(valid_session_ids))
    random.seed(cfg.seed)
    valid_session_ids = random.sample(valid_session_ids, valid_session_n)
    week_sessions = week_sessions[week_sessions["session"].isin(valid_session_ids)].copy()
    week_labels = week_labels[week_labels["session"].isin(valid_session_ids)].copy()

    # 候補選出
    cand_df = make_cand_df(week_sessions, trans_maps=trans_maps)
    cand_df = reduce_mem_usage(cand_df)
    return cand_df, week_sessions, week_labels

# %%
@noglobal(excepts=["cfg", "logger"])
def make_valid_data(cand_df, week_sessions, week_labels, type_):
    # 特徴量付与
    valid = add_features(week_sessions, cand_df, cfg.valid_week)
    valid = add_labels(valid, week_labels, type_)
    valid = valid.reset_index(drop=True)
    valid = reduce_mem_usage(valid)
    return valid

# %%
@noglobal(excepts=["cfg", "logger"])
def model_training(train, valid, features, target, valid_labels, type_):
    params = {'objective': 'binary', 
            'boosting': 'gbdt', 
            'learning_rate': 0.1, 
            'metric': 'binary_logloss', 
            'seed': cfg.seed
            }

    # 学習
    vl_pred_df = valid[["session", "aid"]].copy()

    tr_x, tr_y = train[features], train[target]
    vl_x, vl_y = valid[features], valid[target]
    tr_data = lgb.Dataset(tr_x, label=tr_y)
    vl_data = lgb.Dataset(vl_x, label=vl_y)

    model = lgb.train(params, tr_data, valid_sets=[tr_data, vl_data],
                      num_boost_round=2000000, early_stopping_rounds=100, verbose_eval=100)

    # 特徴量重要度
    fi = pd.DataFrame()
    fi["feature"] = model.feature_name()
    fi["importance"] = model.feature_importance(importance_type="gain")

    # 2値分類の出力を元にk個選定
    vl_pred_df["prob"] = model.predict(vl_x, num_iteration=model.best_iteration)
    vl_pred_df = vl_pred_df.sort_values(["session", "prob"], ascending=(True, False))
    vl_pred_df = vl_pred_df.groupby(["session"]).head(cfg.k)
    vl_pred_df = vl_pred_df.groupby(["session"])["aid"].apply(list).reset_index()
    
    # 評価
    assert valid_labels["session"].tolist() == vl_pred_df["session"].unique().tolist()
    score = evaluate(valid_labels["clicks_labels"].tolist(),
                     valid_labels["carts_labels"].tolist(),
                     valid_labels["orders_labels"].tolist(),
                     vl_pred_df["aid"].tolist(),
                     vl_pred_df["aid"].tolist(),
                     vl_pred_df["aid"].tolist(),
                     cfg.k)
    logger.info(f"{type_} valid score")
    logger.info(score)

    # モデル保存
    model.save_model(cfg.output_dir + f"{cfg.exp_name}/{type_}_model.lgb")

    # 特徴量重要度
    fi_n = fi['feature'].nunique()
    order = list(fi.groupby("feature").mean().sort_values("importance", ascending=False).index)
    plt.figure(figsize=(10, fi_n*0.2))
    sns.barplot(x="importance", y="feature", data=fi, order=order)
    plt.title(f"LGBM importance({type_})")
    plt.tight_layout()
    plt.savefig(cfg.output_dir + f'{cfg.exp_name}/lgbm_importance_{type_}.png')

    return score[f"recall_{type_}"]

# %%
@noglobal(excepts=["cfg", "logger", "cache"])
def make_test_data():
    # testデータ作成
    test_sessions = pd.read_pickle(cfg.prep_dir + f"test_sessions.pkl")
    trans_map_cache_file = f"trans_maps.pkl"
    trans_map_cache_path = cache.get_abspath(trans_map_cache_file)
    with open(trans_map_cache_path, "rb") as f:
        trans_maps = pickle.load(f)

    dfs =[]
    # 候補選出
    logger.info("[make_test] make_cand_df")
    cand_df = make_cand_df(test_sessions, trans_maps=trans_maps)
    cand_df = reduce_mem_usage(cand_df)
    # 特徴量付与
    logger.info("[make_test] add_features")
    test = add_features(test_sessions, cand_df)
    test = reduce_mem_usage(test)

    return test

# %%
@noglobal(excepts=["cfg", "logger"])
def inference(test, features):
    pred_dfs = []
    for type_ in ["clicks", "carts", "orders"]:
        pred_df_tmp = test[["session", "aid"]].copy()
        # 推論
        model = lgb.Booster(model_file = cfg.output_dir + f"{cfg.exp_name}/{type_}_model.lgb")

        # 2値分類の出力を元にk個選定
        pred_df_tmp["prob"] = model.predict(test[features], num_iteration=model.best_iteration)
        pred_df_tmp = pred_df_tmp.sort_values(["session", "prob"], ascending=(True, False))
        pred_df_tmp = pred_df_tmp.groupby(["session"]).head(cfg.k)
        pred_df_tmp["aid"] = pred_df_tmp["aid"].astype(str)
        pred_df_tmp = pred_df_tmp.groupby(["session"])["aid"].apply(list).reset_index()
        pred_df_tmp["aid"] = pred_df_tmp["aid"].apply(lambda x: ' '.join(x))
        pred_df_tmp["type"] = type_
        pred_dfs.append(pred_df_tmp)
    del test, model
    gc.collect()
    
    pred_df = pd.concat(pred_dfs)
    # sub作成
    sub = pd.read_csv(cfg.input_dir + f"sample_submission.csv", usecols=["session_type"])
    pred_df["session_type"] = pred_df["session"].astype(str) + "_" + pred_df["type"]
    pred_df = pred_df.rename(columns={"aid": "labels"})
    sub = sub.merge(pred_df[["session_type", "labels"]], on="session_type", how="left")
    sub.to_csv(cfg.output_dir + f"{cfg.exp_name}/{cfg.exp_name}_sub.csv", index=False)

# %%
@noglobal(excepts=["cfg", "logger", "cache"])
def main():
    scores = {}
    logger.info(f"START")
    line_notify.send(f"{cfg.exp_name} | START")
    
    # trans_map作成
    weeks = [None] + cfg.train_weeks + [cfg.valid_week]
    for week in weeks:
        if week is None:
            cache_file = "trans_maps.pkl"
        else:    
            cache_file = f"trans_maps_{week}.pkl"
        cache_path = cache.get_abspath(cache_file)
        if cache.exists(cache_path):
            logger.info(f"[{cache_file}] cache exists. load cache and skip process.")
            with open(cache_path, "rb") as f:
                trans_maps = pickle.load(f)
        else:
            trans_maps = get_trans_maps(week)
            with open(cache_path, "wb") as f:
                pickle.dump(trans_maps, f)

    for type_ in ["clicks", "carts", "orders"]:
        # train data作成
        logger.info(f"make {type_}_train_data")
        cache_file = f"{type_}_train.pkl"
        cache_path = cache.get_abspath(cache_file)
        if cache.exists(cache_path):
            logger.info(f"[{cache_file}] cache exists. read cache and skip process.")
            train = pd.read_pickle(cache_path)
        else:
            train = make_train_data(type_)
            train.to_pickle(cache_path)
        
        logger.info(f"make {type_}_valid_data")
        # valid cand作成
        cand_cache_path = cache.get_abspath("valid_cand.pkl")
        sessions_cache_path = cache.get_abspath("valid_sessions.pkl")
        labels_cache_path = cache.get_abspath("valid_labels.pkl")
        if cache.exists(cand_cache_path) & cache.exists(labels_cache_path) & cache.exists(sessions_cache_path):
            logger.info("[valid_cand.pkl] cache exists. read cache and skip process.")
            valid_cand = pd.read_pickle(cand_cache_path)
            valid_sessions = pd.read_pickle(sessions_cache_path)
            valid_labels = pd.read_pickle(labels_cache_path)
        else:
            valid_cand, valid_sessions, valid_labels = make_valid_cand()
            valid_cand.to_pickle(cand_cache_path)
            valid_sessions.to_pickle(sessions_cache_path)
            valid_labels.to_pickle(labels_cache_path)

        # valid data作成
        logger.info(f"make {type_}_valid_data")
        cache_file = f"{type_}_valid.pkl"
        cache_path = cache.get_abspath(cache_file)
        if cache.exists(cache_path):
            logger.info(f"[{cache_file}] cache exists. read cache and skip process.")
            valid = pd.read_pickle(cache_path)
        else:
            valid = make_valid_data(valid_cand, valid_sessions, valid_labels, type_)
            valid.to_pickle(cache_path)

        # モデル学習
        target = "labels"
        not_use_cols = ["session", "aid", target]
        features = [c for c in train.columns if c not in not_use_cols]

        scores[f"recall_{type_}"] = model_training(train, valid, features, target, valid_labels, type_)

        del train, valid, valid_labels
        gc.collect()
    
    scores["total"] = (float(scores["recall_clicks"]) * 0.1) + (float(scores["recall_carts"]) * 0.3) + (float(scores["recall_orders"]) * 0.6)
    report = f"\n{cfg.exp_name}\n"
    report += f'valid_end\n'
    report += str(scores)
    line_notify.send(report)

    # testデータ
    cache_path = cache.get_abspath("test.pkl")
    if cache.exists(cache_path):
        logger.info("cache exists. read cache and skip process.")
        test = pd.read_pickle(cache_path)
    else:
        test = make_test_data()
        test.to_pickle(cache_path)

    logger.info(f"-------- inference --------")
    inference(test, features)

    line_notify.send(f"{cfg.exp_name} | END!!")

# %%
try:
    main()
except Exception as e:
    logger.error(traceback.format_exc())
    line_notify.send(f"{cfg.exp_name} | ERROR!!\n{traceback.format_exc()}")
# Out:
# 0:00:00.802111 	 START
# 0:00:04.959260 	 [trans_maps.pkl] cache exists. load cache and skip process.
# 0:00:20.214466 	 [trans_maps_week3.pkl] cache exists. load cache and skip process.
# 0:00:36.378388 	 [trans_maps_week4.pkl] cache exists. load cache and skip process.
# 0:00:53.211135 	 make clicks_train_data
# /mnt/otto-recommender-system/output/exp045/cache/train_cand_week3_0.pkl
# 0:01:16.295956 	 [make_candidate] session_frequent : start
# 0:01:16.860359 	 [add_candidate] session_frequent : start
# 0:01:17.760540 	 [make_candidate] session_latest : start
# 0:01:18.013709 	 [add_candidate] session_latest : start
# 0:01:19.210384 	 [make_candidate] session_latest_time_wt_pair0 : start
# 0:01:19.657115 	 [add_candidate] session_latest_time_wt_pair0 : start
# 0:01:21.124935 	 [make_candidate] session_latest_word2vec_pair0 : start
# 0:01:21.591363 	 [add_candidate] session_latest_word2vec_pair0 : start
# 0:01:23.406528 	 [make_candidate] session_latest_pair0 : start
# 0:01:24.058298 	 [add_candidate] session_latest_pair0 : start
# 0:01:26.166237 	 [make_candidate] session_latest_time_wt_pair1 : start
# 0:01:26.747503 	 [add_candidate] session_latest_time_wt_pair1 : start
# 0:01:29.202024 	 [make_candidate] session_latest_word2vec_pair1 : start
# 0:01:29.867020 	 [add_candidate] session_latest_word2vec_pair1 : start
# 0:01:33.217266 	 [make_candidate] session_latest_pair1 : start
# 0:01:33.980083 	 [add_candidate] session_latest_pair1 : start
# 0:01:37.565493 	 [make_candidate] session_latest_time_wt_pair2 : start
# 0:01:38.386949 	 [add_candidate] session_latest_time_wt_pair2 : start
# 0:01:42.326367 	 [make_candidate] session_latest_word2vec_pair2 : start
# 0:01:43.218479 	 [add_candidate] session_latest_word2vec_pair2 : start
# 0:01:47.753275 	 [make_candidate] session_latest_pair2 : start
# 0:01:48.657689 	 [add_candidate] session_latest_pair2 : start
# 0:01:53.572203 	 [make_candidate] session_latest_time_wt_pair3 : start
# 0:01:54.447073 	 [add_candidate] session_latest_time_wt_pair3 : start
# 0:01:59.681292 	 [make_candidate] session_latest_word2vec_pair3 : start
# 0:02:00.698115 	 [add_candidate] session_latest_word2vec_pair3 : start
# 0:02:06.662617 	 [make_candidate] session_latest_pair3 : start
# 0:02:07.642382 	 [add_candidate] session_latest_pair3 : start
# 0:02:14.050719 	 [make_candidate] session_latest_time_wt_pair4 : start
# 0:02:15.019028 	 [add_candidate] session_latest_time_wt_pair4 : start
# 0:02:22.554233 	 [make_candidate] session_latest_word2vec_pair4 : start
# 0:02:23.442110 	 [add_candidate] session_latest_word2vec_pair4 : start
# 0:02:31.616845 	 [make_candidate] session_latest_pair4 : start
# 0:02:32.655710 	 [add_candidate] session_latest_pair4 : start
# 0:02:41.377547 	 [make_candidate] session_latest_time_wt_pair5 : start
# 0:02:42.458553 	 [add_candidate] session_latest_time_wt_pair5 : start
# 0:02:51.513680 	 [make_candidate] session_latest_word2vec_pair5 : start
# 0:02:52.600475 	 [add_candidate] session_latest_word2vec_pair5 : start
# 0:03:02.195801 	 [make_candidate] session_latest_pair5 : start
# 0:03:03.252766 	 [add_candidate] session_latest_pair5 : start
# 0:03:13.841716 	 [make_candidate] session_latest_time_wt_pair6 : start
# 0:03:15.000809 	 [add_candidate] session_latest_time_wt_pair6 : start
# 0:03:25.825424 	 [make_candidate] session_latest_word2vec_pair6 : start
# 0:03:26.851658 	 [add_candidate] session_latest_word2vec_pair6 : start
# 0:03:38.218238 	 [make_candidate] session_latest_pair6 : start
# 0:03:39.423809 	 [add_candidate] session_latest_pair6 : start
# 0:03:51.174387 	 [make_candidate] session_latest_time_wt_pair7 : start
# 0:03:52.426386 	 [add_candidate] session_latest_time_wt_pair7 : start
# 0:04:05.324107 	 [make_candidate] session_latest_word2vec_pair7 : start
# 0:04:06.589969 	 [add_candidate] session_latest_word2vec_pair7 : start
# 0:04:19.633724 	 [make_candidate] session_latest_pair7 : start
# 0:04:20.805379 	 [add_candidate] session_latest_pair7 : start
# 0:04:34.460412 	 [make_candidate] session_latest_time_wt_pair8 : start
# 0:04:35.855831 	 [add_candidate] session_latest_time_wt_pair8 : start
# 0:04:50.187826 	 [make_candidate] session_latest_word2vec_pair8 : start
# 0:04:51.585210 	 [add_candidate] session_latest_word2vec_pair8 : start
# 0:05:06.689486 	 [make_candidate] session_latest_pair8 : start
# 0:05:07.976854 	 [add_candidate] session_latest_pair8 : start
# 0:05:23.604526 	 [make_candidate] session_latest_time_wt_pair9 : start
# 0:05:24.951537 	 [add_candidate] session_latest_time_wt_pair9 : start
# 0:05:41.821852 	 [make_candidate] session_latest_word2vec_pair9 : start
# 0:05:43.224072 	 [add_candidate] session_latest_word2vec_pair9 : start
# 0:06:03.087242 	 [make_candidate] session_latest_pair9 : start
# 0:06:04.378923 	 [add_candidate] session_latest_pair9 : start
# 0:06:24.327565 	 [make_candidate] session_latest_time_wt_pair10 : start
# 0:06:25.797865 	 [add_candidate] session_latest_time_wt_pair10 : start
# 0:06:46.733978 	 [make_candidate] session_latest_word2vec_pair10 : start
# 0:06:48.313787 	 [add_candidate] session_latest_word2vec_pair10 : start
# 0:07:10.337642 	 [make_candidate] session_latest_pair10 : start
# 0:07:11.926707 	 [add_candidate] session_latest_pair10 : start
# 0:07:34.400006 	 [make_candidate] session_latest_time_wt_pair11 : start
# 0:07:35.952913 	 [add_candidate] session_latest_time_wt_pair11 : start
# 0:07:58.988634 	 [make_candidate] session_latest_word2vec_pair11 : start
# 0:08:00.559137 	 [add_candidate] session_latest_word2vec_pair11 : start
# 0:08:24.185472 	 [make_candidate] session_latest_pair11 : start
# 0:08:25.928497 	 [add_candidate] session_latest_pair11 : start
# 0:08:50.509008 	 [make_candidate] session_latest_time_wt_pair12 : start
# 0:08:52.254607 	 [add_candidate] session_latest_time_wt_pair12 : start
# 0:09:17.785878 	 [make_candidate] session_latest_word2vec_pair12 : start
# 0:09:19.532952 	 [add_candidate] session_latest_word2vec_pair12 : start
# 0:09:45.895903 	 [make_candidate] session_latest_pair12 : start
# 0:09:47.673223 	 [add_candidate] session_latest_pair12 : start
# 0:10:15.486608 	 [make_candidate] session_latest_time_wt_pair13 : start
# 0:10:17.531055 	 [add_candidate] session_latest_time_wt_pair13 : start
# 0:10:45.509822 	 [make_candidate] session_latest_word2vec_pair13 : start
# 0:10:47.411354 	 [add_candidate] session_latest_word2vec_pair13 : start
# 0:11:16.470950 	 [make_candidate] session_latest_pair13 : start
# 0:11:18.282038 	 [add_candidate] session_latest_pair13 : start
# 0:11:48.485489 	 [make_candidate] session_latest_time_wt_pair14 : start
# 0:11:50.575847 	 [add_candidate] session_latest_time_wt_pair14 : start
# 0:12:20.993485 	 [make_candidate] session_latest_word2vec_pair14 : start
# 0:12:23.140441 	 [add_candidate] session_latest_word2vec_pair14 : start
# 0:12:54.904984 	 [make_candidate] session_latest_pair14 : start
# 0:12:57.180512 	 [add_candidate] session_latest_pair14 : start
# 0:13:29.798750 	 [make_candidate] session_latest_time_wt_pair15 : start
# 0:13:32.081260 	 [add_candidate] session_latest_time_wt_pair15 : start
# 0:14:04.847126 	 [make_candidate] session_latest_word2vec_pair15 : start
# 0:14:07.282703 	 [add_candidate] session_latest_word2vec_pair15 : start
# 0:14:41.224036 	 [make_candidate] session_latest_pair15 : start
# 0:14:43.462350 	 [add_candidate] session_latest_pair15 : start
# 0:15:19.664984 	 [make_candidate] session_latest_time_wt_pair16 : start
# 0:15:22.212859 	 [add_candidate] session_latest_time_wt_pair16 : start
# 0:15:58.752065 	 [make_candidate] session_latest_word2vec_pair16 : start
# 0:16:01.536728 	 [add_candidate] session_latest_word2vec_pair16 : start
# 0:16:41.105395 	 [make_candidate] session_latest_pair16 : start
# 0:16:43.920310 	 [add_candidate] session_latest_pair16 : start
# 0:17:22.378384 	 [make_candidate] session_latest_time_wt_pair17 : start
# 0:17:25.029924 	 [add_candidate] session_latest_time_wt_pair17 : start
# 0:18:06.271131 	 [make_candidate] session_latest_word2vec_pair17 : start
# 0:18:09.016300 	 [add_candidate] session_latest_word2vec_pair17 : start
# 0:18:50.303625 	 [make_candidate] session_latest_pair17 : start
# 0:18:53.170331 	 [add_candidate] session_latest_pair17 : start
# 0:19:35.008885 	 [make_candidate] session_latest_time_wt_pair18 : start
# 0:19:37.990237 	 [add_candidate] session_latest_time_wt_pair18 : start
# 0:20:20.737648 	 [make_candidate] session_latest_word2vec_pair18 : start
# 0:20:23.638111 	 [add_candidate] session_latest_word2vec_pair18 : start
# 0:21:08.858128 	 [make_candidate] session_latest_pair18 : start
# 0:21:11.837059 	 [add_candidate] session_latest_pair18 : start
# 0:21:56.493303 	 [make_candidate] session_latest_time_wt_pair19 : start
# 0:21:59.673693 	 [add_candidate] session_latest_time_wt_pair19 : start
# 0:22:47.582433 	 [make_candidate] session_latest_word2vec_pair19 : start
# 0:22:51.005038 	 [add_candidate] session_latest_word2vec_pair19 : start
# 0:23:40.599277 	 [make_candidate] session_latest_pair19 : start
# 0:23:43.910268 	 [add_candidate] session_latest_pair19 : start
# 0:24:33.467965 	 [make_candidate] session_latest_type_wt_pair0 : start
# 0:24:37.154644 	 [add_candidate] session_latest_type_wt_pair0 : start
# 0:25:28.102211 	 [make_candidate] session_latest_clicks2carts_pair0 : start
# 0:25:31.383858 	 [add_candidate] session_latest_clicks2carts_pair0 : start
# 0:26:23.454660 	 [make_candidate] session_latest_clicks2orders_pair0 : start
# 0:26:26.877585 	 [add_candidate] session_latest_clicks2orders_pair0 : start
# 0:27:19.476079 	 [make_candidate] session_latest_type_wt_pair1 : start
# 0:27:23.303123 	 [add_candidate] session_latest_type_wt_pair1 : start
# 0:28:15.701685 	 [make_candidate] session_latest_clicks2carts_pair1 : start
# 0:28:19.376466 	 [add_candidate] session_latest_clicks2carts_pair1 : start
# 0:29:12.527123 	 [make_candidate] session_latest_clicks2orders_pair1 : start
# 0:29:15.818908 	 [add_candidate] session_latest_clicks2orders_pair1 : start
# 0:30:11.814477 	 [make_candidate] session_latest_type_wt_pair2 : start
# 0:30:15.744297 	 [add_candidate] session_latest_type_wt_pair2 : start
# 0:31:16.848197 	 [make_candidate] session_latest_clicks2carts_pair2 : start
# 0:31:20.687441 	 [add_candidate] session_latest_clicks2carts_pair2 : start
# 0:32:24.538143 	 [make_candidate] session_latest_clicks2orders_pair2 : start
# 0:32:28.131457 	 [add_candidate] session_latest_clicks2orders_pair2 : start
# 0:33:36.022825 	 [make_candidate] session_latest_type_wt_pair3 : start
# 0:33:40.095710 	 [add_candidate] session_latest_type_wt_pair3 : start
# 0:34:57.162024 	 [make_candidate] session_latest_clicks2carts_pair3 : start
# 0:35:00.983342 	 [add_candidate] session_latest_clicks2carts_pair3 : start
# 0:36:07.421456 	 [make_candidate] session_latest_clicks2orders_pair3 : start
# 0:36:11.202947 	 [add_candidate] session_latest_clicks2orders_pair3 : start
# 0:37:19.809565 	 [make_candidate] session_latest_type_wt_pair4 : start
# 0:37:24.297908 	 [add_candidate] session_latest_type_wt_pair4 : start
# 0:38:39.056226 	 [make_candidate] session_latest_clicks2carts_pair4 : start
# 0:38:43.016622 	 [add_candidate] session_latest_clicks2carts_pair4 : start
# 0:39:55.305922 	 [make_candidate] session_latest_clicks2orders_pair4 : start
# 0:39:59.137571 	 [add_candidate] session_latest_clicks2orders_pair4 : start
# Memory usage of dataframe is 32963.24 MB
# Memory usage after optimization is: 8755.86 MB
# Decreased by 73.4%
# /mnt/otto-recommender-system/output/exp045/cache/train_cand_week3_1.pkl
# 0:47:04.005654 	 [make_candidate] session_frequent : start
# 0:47:04.607477 	 [add_candidate] session_frequent : start
# 0:47:05.778977 	 [make_candidate] session_latest : start
# 0:47:06.029315 	 [add_candidate] session_latest : start
# 0:47:07.160766 	 [make_candidate] session_latest_time_wt_pair0 : start
# 0:47:07.646510 	 [add_candidate] session_latest_time_wt_pair0 : start
# 0:47:09.183900 	 [make_candidate] session_latest_word2vec_pair0 : start
# 0:47:09.729007 	 [add_candidate] session_latest_word2vec_pair0 : start
# 0:47:11.582792 	 [make_candidate] session_latest_pair0 : start
# 0:47:12.248284 	 [add_candidate] session_latest_pair0 : start
# 0:47:14.401315 	 [make_candidate] session_latest_time_wt_pair1 : start
# 0:47:15.052318 	 [add_candidate] session_latest_time_wt_pair1 : start
# 0:47:17.368113 	 [make_candidate] session_latest_word2vec_pair1 : start
# 0:47:17.931568 	 [add_candidate] session_latest_word2vec_pair1 : start
# 0:47:21.133444 	 [make_candidate] session_latest_pair1 : start
# 0:47:21.907092 	 [add_candidate] session_latest_pair1 : start
# 0:47:25.350653 	 [make_candidate] session_latest_time_wt_pair2 : start
# 0:47:26.051062 	 [add_candidate] session_latest_time_wt_pair2 : start
# 0:47:29.882600 	 [make_candidate] session_latest_word2vec_pair2 : start
# 0:47:30.520992 	 [add_candidate] session_latest_word2vec_pair2 : start
# 0:47:34.861534 	 [make_candidate] session_latest_pair2 : start
# 0:47:35.639083 	 [add_candidate] session_latest_pair2 : start
# 0:47:40.397177 	 [make_candidate] session_latest_time_wt_pair3 : start
# 0:47:41.301255 	 [add_candidate] session_latest_time_wt_pair3 : start
# 0:47:46.311162 	 [make_candidate] session_latest_word2vec_pair3 : start
# 0:47:47.057222 	 [add_candidate] session_latest_word2vec_pair3 : start
# 0:47:52.721489 	 [make_candidate] session_latest_pair3 : start
# 0:47:53.366958 	 [add_candidate] session_latest_pair3 : start
# 0:47:59.070212 	 [make_candidate] session_latest_time_wt_pair4 : start
# 0:47:59.915274 	 [add_candidate] session_latest_time_wt_pair4 : start
# 0:48:06.211020 	 [make_candidate] session_latest_word2vec_pair4 : start
# 0:48:07.092175 	 [add_candidate] session_latest_word2vec_pair4 : start
# 0:48:15.087198 	 [make_candidate] session_latest_pair4 : start
# 0:48:15.759813 	 [add_candidate] session_latest_pair4 : start
# 0:48:23.993087 	 [make_candidate] session_latest_time_wt_pair5 : start
# 0:48:24.950695 	 [add_candidate] session_latest_time_wt_pair5 : start
# 0:48:33.706252 	 [make_candidate] session_latest_word2vec_pair5 : start
# 0:48:34.444190 	 [add_candidate] session_latest_word2vec_pair5 : start
# 0:48:43.443098 	 [make_candidate] session_latest_pair5 : start
# 0:48:44.457445 	 [add_candidate] session_latest_pair5 : start
# 0:48:54.264608 	 [make_candidate] session_latest_time_wt_pair6 : start
# 0:48:55.078305 	 [add_candidate] session_latest_time_wt_pair6 : start
# 0:49:05.267150 	 [make_candidate] session_latest_word2vec_pair6 : start
# 0:49:06.274130 	 [add_candidate] session_latest_word2vec_pair6 : start
# 0:49:17.289964 	 [make_candidate] session_latest_pair6 : start
# 0:49:18.400948 	 [add_candidate] session_latest_pair6 : start
# 0:49:29.769051 	 [make_candidate] session_latest_time_wt_pair7 : start
# 0:49:30.884524 	 [add_candidate] session_latest_time_wt_pair7 : start
# 0:49:43.129918 	 [make_candidate] session_latest_word2vec_pair7 : start
# 0:49:44.264599 	 [add_candidate] session_latest_word2vec_pair7 : start
# 0:49:57.041099 	 [make_candidate] session_latest_pair7 : start
# 0:49:58.081449 	 [add_candidate] session_latest_pair7 : start
# 0:50:10.954620 	 [make_candidate] session_latest_time_wt_pair8 : start
# 0:50:12.073410 	 [add_candidate] session_latest_time_wt_pair8 : start
# 0:50:25.748468 	 [make_candidate] session_latest_word2vec_pair8 : start
# 0:50:27.048164 	 [add_candidate] session_latest_word2vec_pair8 : start
# 0:50:41.424602 	 [make_candidate] session_latest_pair8 : start
# 0:50:42.771089 	 [add_candidate] session_latest_pair8 : start
# 0:50:57.854924 	 [make_candidate] session_latest_time_wt_pair9 : start
# 0:50:59.194062 	 [add_candidate] session_latest_time_wt_pair9 : start
# 0:51:14.720693 	 [make_candidate] session_latest_word2vec_pair9 : start
# 0:51:16.122049 	 [add_candidate] session_latest_word2vec_pair9 : start
# 0:51:32.443327 	 [make_candidate] session_latest_pair9 : start
# 0:51:33.771586 	 [add_candidate] session_latest_pair9 : start
# 0:51:51.195122 	 [make_candidate] session_latest_time_wt_pair10 : start
# 0:51:52.602453 	 [add_candidate] session_latest_time_wt_pair10 : start
# 0:52:10.060021 	 [make_candidate] session_latest_word2vec_pair10 : start
# 0:52:11.556171 	 [add_candidate] session_latest_word2vec_pair10 : start
# 0:52:32.687054 	 [make_candidate] session_latest_pair10 : start
# 0:52:34.183719 	 [add_candidate] session_latest_pair10 : start
# 0:52:55.960015 	 [make_candidate] session_latest_time_wt_pair11 : start
# 0:52:57.554911 	 [add_candidate] session_latest_time_wt_pair11 : start
# 0:53:19.641312 	 [make_candidate] session_latest_word2vec_pair11 : start
# 0:53:21.199969 	 [add_candidate] session_latest_word2vec_pair11 : start
# 0:53:44.324455 	 [make_candidate] session_latest_pair11 : start
# 0:53:45.727128 	 [add_candidate] session_latest_pair11 : start
# 0:54:09.726086 	 [make_candidate] session_latest_time_wt_pair12 : start
# 0:54:11.327866 	 [add_candidate] session_latest_time_wt_pair12 : start
# 0:54:35.815211 	 [make_candidate] session_latest_word2vec_pair12 : start
# 0:54:37.523556 	 [add_candidate] session_latest_word2vec_pair12 : start
# 0:55:02.879693 	 [make_candidate] session_latest_pair12 : start
# 0:55:04.614408 	 [add_candidate] session_latest_pair12 : start
# 0:55:30.899793 	 [make_candidate] session_latest_time_wt_pair13 : start
# 0:55:32.685936 	 [add_candidate] session_latest_time_wt_pair13 : start
# 0:55:59.646186 	 [make_candidate] session_latest_word2vec_pair13 : start
# 0:56:01.362931 	 [add_candidate] session_latest_word2vec_pair13 : start
# 0:56:29.590480 	 [make_candidate] session_latest_pair13 : start
# 0:56:31.429969 	 [add_candidate] session_latest_pair13 : start
# 0:57:00.369211 	 [make_candidate] session_latest_time_wt_pair14 : start
# 0:57:02.292450 	 [add_candidate] session_latest_time_wt_pair14 : start
# 0:57:32.470213 	 [make_candidate] session_latest_word2vec_pair14 : start
# 0:57:34.446786 	 [add_candidate] session_latest_word2vec_pair14 : start
# 0:58:05.254481 	 [make_candidate] session_latest_pair14 : start
# 0:58:07.242706 	 [add_candidate] session_latest_pair14 : start
# 0:58:38.836971 	 [make_candidate] session_latest_time_wt_pair15 : start
# 0:58:40.996600 	 [add_candidate] session_latest_time_wt_pair15 : start
# 0:59:14.143145 	 [make_candidate] session_latest_word2vec_pair15 : start
# 0:59:16.376187 	 [add_candidate] session_latest_word2vec_pair15 : start
# 0:59:49.700303 	 [make_candidate] session_latest_pair15 : start
# 0:59:51.909926 	 [add_candidate] session_latest_pair15 : start
# 1:00:26.099159 	 [make_candidate] session_latest_time_wt_pair16 : start
# 1:00:28.367768 	 [add_candidate] session_latest_time_wt_pair16 : start
# 1:01:03.421901 	 [make_candidate] session_latest_word2vec_pair16 : start
# 1:01:05.774625 	 [add_candidate] session_latest_word2vec_pair16 : start
# 1:01:41.641013 	 [make_candidate] session_latest_pair16 : start
# 1:01:44.092794 	 [add_candidate] session_latest_pair16 : start
# 1:02:21.370996 	 [make_candidate] session_latest_time_wt_pair17 : start
# 1:02:23.957472 	 [add_candidate] session_latest_time_wt_pair17 : start
# 1:03:01.774105 	 [make_candidate] session_latest_word2vec_pair17 : start
# 1:03:04.352650 	 [add_candidate] session_latest_word2vec_pair17 : start
# 1:03:43.546651 	 [make_candidate] session_latest_pair17 : start
# 1:03:46.070419 	 [add_candidate] session_latest_pair17 : start
# 1:04:26.280218 	 [make_candidate] session_latest_time_wt_pair18 : start
# 1:04:29.074294 	 [add_candidate] session_latest_time_wt_pair18 : start
# 1:05:10.110113 	 [make_candidate] session_latest_word2vec_pair18 : start
# 1:05:12.898155 	 [add_candidate] session_latest_word2vec_pair18 : start
# 1:05:54.402677 	 [make_candidate] session_latest_pair18 : start
# 1:05:57.205584 	 [add_candidate] session_latest_pair18 : start
# 1:06:40.030004 	 [make_candidate] session_latest_time_wt_pair19 : start
# 1:06:43.122513 	 [add_candidate] session_latest_time_wt_pair19 : start
# 1:07:26.714617 	 [make_candidate] session_latest_word2vec_pair19 : start
# 1:07:29.620101 	 [add_candidate] session_latest_word2vec_pair19 : start
# 1:08:14.581476 	 [make_candidate] session_latest_pair19 : start
# 1:08:17.572290 	 [add_candidate] session_latest_pair19 : start
# 1:09:04.417479 	 [make_candidate] session_latest_type_wt_pair0 : start
# 1:09:07.592134 	 [add_candidate] session_latest_type_wt_pair0 : start
# 1:09:53.913658 	 [make_candidate] session_latest_clicks2carts_pair0 : start
# 1:09:56.827040 	 [add_candidate] session_latest_clicks2carts_pair0 : start
# 1:10:44.657181 	 [make_candidate] session_latest_clicks2orders_pair0 : start
# 1:10:47.866699 	 [add_candidate] session_latest_clicks2orders_pair0 : start
# 1:11:36.261709 	 [make_candidate] session_latest_type_wt_pair1 : start
# 1:11:39.533647 	 [add_candidate] session_latest_type_wt_pair1 : start
# 1:12:29.480215 	 [make_candidate] session_latest_clicks2carts_pair1 : start
# 1:12:32.649258 	 [add_candidate] session_latest_clicks2carts_pair1 : start
# 1:13:21.795235 	 [make_candidate] session_latest_clicks2orders_pair1 : start
# 1:13:24.975054 	 [add_candidate] session_latest_clicks2orders_pair1 : start
# 1:14:15.140517 	 [make_candidate] session_latest_type_wt_pair2 : start
# 1:14:18.660754 	 [add_candidate] session_latest_type_wt_pair2 : start
# 1:15:09.764085 	 [make_candidate] session_latest_clicks2carts_pair2 : start
# 1:15:13.242033 	 [add_candidate] session_latest_clicks2carts_pair2 : start
# 1:16:05.253051 	 [make_candidate] session_latest_clicks2orders_pair2 : start
# 1:16:08.704333 	 [add_candidate] session_latest_clicks2orders_pair2 : start
# 1:17:01.423734 	 [make_candidate] session_latest_type_wt_pair3 : start
# 1:17:05.060954 	 [add_candidate] session_latest_type_wt_pair3 : start
# 1:17:59.757583 	 [make_candidate] session_latest_clicks2carts_pair3 : start
# 1:18:03.404361 	 [add_candidate] session_latest_clicks2carts_pair3 : start
# 1:18:59.352738 	 [make_candidate] session_latest_clicks2orders_pair3 : start
# 1:19:02.846977 	 [add_candidate] session_latest_clicks2orders_pair3 : start
# 1:19:59.157755 	 [make_candidate] session_latest_type_wt_pair4 : start
# 1:20:02.954806 	 [add_candidate] session_latest_type_wt_pair4 : start
# 1:21:04.086322 	 [make_candidate] session_latest_clicks2carts_pair4 : start
# 1:21:07.838268 	 [add_candidate] session_latest_clicks2carts_pair4 : start
# 1:22:14.793157 	 [make_candidate] session_latest_clicks2orders_pair4 : start
# 1:22:18.466195 	 [add_candidate] session_latest_clicks2orders_pair4 : start
# Memory usage of dataframe is 30375.51 MB
# Memory usage after optimization is: 8068.49 MB
# Decreased by 73.4%
# /mnt/otto-recommender-system/output/exp045/cache/train_cand_week3_2.pkl
# 1:28:32.745646 	 [make_candidate] session_frequent : start
# 1:28:33.252050 	 [add_candidate] session_frequent : start
# 1:28:34.064234 	 [make_candidate] session_latest : start
# 1:28:34.302422 	 [add_candidate] session_latest : start
# 1:28:35.300229 	 [make_candidate] session_latest_time_wt_pair0 : start
# 1:28:35.732097 	 [add_candidate] session_latest_time_wt_pair0 : start
# 1:28:36.909603 	 [make_candidate] session_latest_word2vec_pair0 : start
# 1:28:37.356468 	 [add_candidate] session_latest_word2vec_pair0 : start
# 1:28:39.102047 	 [make_candidate] session_latest_pair0 : start
# 1:28:39.664415 	 [add_candidate] session_latest_pair0 : start
# 1:28:41.567764 	 [make_candidate] session_latest_time_wt_pair1 : start
# 1:28:42.242965 	 [add_candidate] session_latest_time_wt_pair1 : start
# 1:28:44.491160 	 [make_candidate] session_latest_word2vec_pair1 : start
# 1:28:45.009034 	 [add_candidate] session_latest_word2vec_pair1 : start
# 1:28:47.453958 	 [make_candidate] session_latest_pair1 : start
# 1:28:48.006683 	 [add_candidate] session_latest_pair1 : start
# 1:28:51.187029 	 [make_candidate] session_latest_time_wt_pair2 : start
# 1:28:51.947058 	 [add_candidate] session_latest_time_wt_pair2 : start
# 1:28:55.453829 	 [make_candidate] session_latest_word2vec_pair2 : start
# 1:28:56.163826 	 [add_candidate] session_latest_word2vec_pair2 : start
# 1:29:00.012627 	 [make_candidate] session_latest_pair2 : start
# 1:29:00.767923 	 [add_candidate] session_latest_pair2 : start
# 1:29:05.137097 	 [make_candidate] session_latest_time_wt_pair3 : start
# 1:29:05.964338 	 [add_candidate] session_latest_time_wt_pair3 : start
# 1:29:10.656896 	 [make_candidate] session_latest_word2vec_pair3 : start
# 1:29:11.250256 	 [add_candidate] session_latest_word2vec_pair3 : start
# 1:29:16.729433 	 [make_candidate] session_latest_pair3 : start
# 1:29:17.598699 	 [add_candidate] session_latest_pair3 : start
# 1:29:23.379035 	 [make_candidate] session_latest_time_wt_pair4 : start
# 1:29:24.168167 	 [add_candidate] session_latest_time_wt_pair4 : start
# 1:29:29.922782 	 [make_candidate] session_latest_word2vec_pair4 : start
# 1:29:30.820833 	 [add_candidate] session_latest_word2vec_pair4 : start
# 1:29:37.429057 	 [make_candidate] session_latest_pair4 : start
# 1:29:38.406240 	 [add_candidate] session_latest_pair4 : start
# 1:29:45.523222 	 [make_candidate] session_latest_time_wt_pair5 : start
# 1:29:46.221450 	 [add_candidate] session_latest_time_wt_pair5 : start
# 1:29:55.867530 	 [make_candidate] session_latest_word2vec_pair5 : start
# 1:29:56.814926 	 [add_candidate] session_latest_word2vec_pair5 : start
# 1:30:05.597065 	 [make_candidate] session_latest_pair5 : start
# 1:30:06.318593 	 [add_candidate] session_latest_pair5 : start
# 1:30:15.453962 	 [make_candidate] session_latest_time_wt_pair6 : start
# 1:30:16.182420 	 [add_candidate] session_latest_time_wt_pair6 : start
# 1:30:25.647664 	 [make_candidate] session_latest_word2vec_pair6 : start
# 1:30:26.631137 	 [add_candidate] session_latest_word2vec_pair6 : start
# 1:30:36.595580 	 [make_candidate] session_latest_pair6 : start
# 1:30:37.554616 	 [add_candidate] session_latest_pair6 : start
# 1:30:48.360635 	 [make_candidate] session_latest_time_wt_pair7 : start
# 1:30:49.400555 	 [add_candidate] session_latest_time_wt_pair7 : start
# 1:31:00.682892 	 [make_candidate] session_latest_word2vec_pair7 : start
# 1:31:01.816902 	 [add_candidate] session_latest_word2vec_pair7 : start
# 1:31:13.835461 	 [make_candidate] session_latest_pair7 : start
# 1:31:14.975892 	 [add_candidate] session_latest_pair7 : start
# 1:31:27.410691 	 [make_candidate] session_latest_time_wt_pair8 : start
# 1:31:28.591792 	 [add_candidate] session_latest_time_wt_pair8 : start
# 1:31:41.255545 	 [make_candidate] session_latest_word2vec_pair8 : start
# 1:31:42.402620 	 [add_candidate] session_latest_word2vec_pair8 : start
# 1:31:55.843172 	 [make_candidate] session_latest_pair8 : start
# 1:31:56.963245 	 [add_candidate] session_latest_pair8 : start
# 1:32:11.550892 	 [make_candidate] session_latest_time_wt_pair9 : start
# 1:32:12.767393 	 [add_candidate] session_latest_time_wt_pair9 : start
# 1:32:27.783512 	 [make_candidate] session_latest_word2vec_pair9 : start
# 1:32:28.974383 	 [add_candidate] session_latest_word2vec_pair9 : start
# 1:32:44.618236 	 [make_candidate] session_latest_pair9 : start
# 1:32:45.949858 	 [add_candidate] session_latest_pair9 : start
# 1:33:02.107200 	 [make_candidate] session_latest_time_wt_pair10 : start
# 1:33:03.509292 	 [add_candidate] session_latest_time_wt_pair10 : start
# 1:33:20.442040 	 [make_candidate] session_latest_word2vec_pair10 : start
# 1:33:21.874992 	 [add_candidate] session_latest_word2vec_pair10 : start
# 1:33:38.923927 	 [make_candidate] session_latest_pair10 : start
# 1:33:40.320890 	 [add_candidate] session_latest_pair10 : start
# 1:33:59.147020 	 [make_candidate] session_latest_time_wt_pair11 : start
# 1:34:00.681524 	 [add_candidate] session_latest_time_wt_pair11 : start
# 1:34:19.400538 	 [make_candidate] session_latest_word2vec_pair11 : start
# 1:34:20.932023 	 [add_candidate] session_latest_word2vec_pair11 : start
# 1:34:43.264296 	 [make_candidate] session_latest_pair11 : start
# 1:34:44.799472 	 [add_candidate] session_latest_pair11 : start
# 1:35:08.160639 	 [make_candidate] session_latest_time_wt_pair12 : start
# 1:35:09.855401 	 [add_candidate] session_latest_time_wt_pair12 : start
# 1:35:33.501072 	 [make_candidate] session_latest_word2vec_pair12 : start
# 1:35:35.253242 	 [add_candidate] session_latest_word2vec_pair12 : start
# 1:35:59.537237 	 [make_candidate] session_latest_pair12 : start
# 1:36:01.205705 	 [add_candidate] session_latest_pair12 : start
# 1:36:26.637305 	 [make_candidate] session_latest_time_wt_pair13 : start
# 1:36:28.477384 	 [add_candidate] session_latest_time_wt_pair13 : start
# 1:36:54.416252 	 [make_candidate] session_latest_word2vec_pair13 : start
# 1:36:56.259433 	 [add_candidate] session_latest_word2vec_pair13 : start
# 1:37:23.175136 	 [make_candidate] session_latest_pair13 : start
# 1:37:24.978393 	 [add_candidate] session_latest_pair13 : start
# 1:37:52.729053 	 [make_candidate] session_latest_time_wt_pair14 : start
# 1:37:54.614398 	 [add_candidate] session_latest_time_wt_pair14 : start
# 1:38:23.185860 	 [make_candidate] session_latest_word2vec_pair14 : start
# 1:38:25.206595 	 [add_candidate] session_latest_word2vec_pair14 : start
# 1:38:54.364743 	 [make_candidate] session_latest_pair14 : start
# 1:38:56.341333 	 [add_candidate] session_latest_pair14 : start
# 1:39:26.276905 	 [make_candidate] session_latest_time_wt_pair15 : start
# 1:39:28.221585 	 [add_candidate] session_latest_time_wt_pair15 : start
# 1:39:59.126775 	 [make_candidate] session_latest_word2vec_pair15 : start
# 1:40:01.167039 	 [add_candidate] session_latest_word2vec_pair15 : start
# 1:40:32.873969 	 [make_candidate] session_latest_pair15 : start
# 1:40:34.938847 	 [add_candidate] session_latest_pair15 : start
# 1:41:07.262700 	 [make_candidate] session_latest_time_wt_pair16 : start
# 1:41:09.523495 	 [add_candidate] session_latest_time_wt_pair16 : start
# 1:41:42.458187 	 [make_candidate] session_latest_word2vec_pair16 : start
# 1:41:44.765536 	 [add_candidate] session_latest_word2vec_pair16 : start
# 1:42:18.932846 	 [make_candidate] session_latest_pair16 : start
# 1:42:21.196320 	 [add_candidate] session_latest_pair16 : start
# 1:42:56.554746 	 [make_candidate] session_latest_time_wt_pair17 : start
# 1:42:58.936806 	 [add_candidate] session_latest_time_wt_pair17 : start
# 1:43:34.821686 	 [make_candidate] session_latest_word2vec_pair17 : start
# 1:43:37.317109 	 [add_candidate] session_latest_word2vec_pair17 : start
# 1:44:14.171867 	 [make_candidate] session_latest_pair17 : start
# 1:44:16.658752 	 [add_candidate] session_latest_pair17 : start
# 1:44:54.175137 	 [make_candidate] session_latest_time_wt_pair18 : start
# 1:44:56.672791 	 [add_candidate] session_latest_time_wt_pair18 : start
# 1:45:35.526009 	 [make_candidate] session_latest_word2vec_pair18 : start
# 1:45:38.276773 	 [add_candidate] session_latest_word2vec_pair18 : start
# 1:46:18.118547 	 [make_candidate] session_latest_pair18 : start
# 1:46:20.824524 	 [add_candidate] session_latest_pair18 : start
# 1:47:01.470857 	 [make_candidate] session_latest_time_wt_pair19 : start
# 1:47:04.295042 	 [add_candidate] session_latest_time_wt_pair19 : start
# 1:47:46.218317 	 [make_candidate] session_latest_word2vec_pair19 : start
# 1:47:49.008854 	 [add_candidate] session_latest_word2vec_pair19 : start
# 1:48:31.421244 	 [make_candidate] session_latest_pair19 : start
# 1:48:34.382196 	 [add_candidate] session_latest_pair19 : start
# 1:49:17.802057 	 [make_candidate] session_latest_type_wt_pair0 : start
# 1:49:20.772207 	 [add_candidate] session_latest_type_wt_pair0 : start
# 1:50:04.592933 	 [make_candidate] session_latest_clicks2carts_pair0 : start
# 1:50:07.661425 	 [add_candidate] session_latest_clicks2carts_pair0 : start
# 1:50:52.544582 	 [make_candidate] session_latest_clicks2orders_pair0 : start
# 1:50:55.420969 	 [add_candidate] session_latest_clicks2orders_pair0 : start
# 1:51:40.422324 	 [make_candidate] session_latest_type_wt_pair1 : start
# 1:51:43.582482 	 [add_candidate] session_latest_type_wt_pair1 : start
# 1:52:29.357416 	 [make_candidate] session_latest_clicks2carts_pair1 : start
# 1:52:32.270723 	 [add_candidate] session_latest_clicks2carts_pair1 : start
# 1:53:18.285557 	 [make_candidate] session_latest_clicks2orders_pair1 : start
# 1:53:21.490972 	 [add_candidate] session_latest_clicks2orders_pair1 : start
# 1:54:08.958055 	 [make_candidate] session_latest_type_wt_pair2 : start
# 1:54:12.266459 	 [add_candidate] session_latest_type_wt_pair2 : start
# 1:55:00.150047 	 [make_candidate] session_latest_clicks2carts_pair2 : start
# 1:55:03.365327 	 [add_candidate] session_latest_clicks2carts_pair2 : start
# 1:55:51.688142 	 [make_candidate] session_latest_clicks2orders_pair2 : start
# 1:55:54.882350 	 [add_candidate] session_latest_clicks2orders_pair2 : start
# 1:56:43.774544 	 [make_candidate] session_latest_type_wt_pair3 : start
# 1:56:47.258636 	 [add_candidate] session_latest_type_wt_pair3 : start
# 1:57:37.366106 	 [make_candidate] session_latest_clicks2carts_pair3 : start
# 1:57:40.700953 	 [add_candidate] session_latest_clicks2carts_pair3 : start
# 1:58:30.994064 	 [make_candidate] session_latest_clicks2orders_pair3 : start
# 1:58:34.377291 	 [add_candidate] session_latest_clicks2orders_pair3 : start
# 1:59:25.520330 	 [make_candidate] session_latest_type_wt_pair4 : start
# 1:59:29.082760 	 [add_candidate] session_latest_type_wt_pair4 : start
# 2:00:22.034445 	 [make_candidate] session_latest_clicks2carts_pair4 : start
# 2:00:25.603342 	 [add_candidate] session_latest_clicks2carts_pair4 : start
# 2:01:19.794710 	 [make_candidate] session_latest_clicks2orders_pair4 : start
# 2:01:23.337835 	 [add_candidate] session_latest_clicks2orders_pair4 : start
# Memory usage of dataframe is 28547.91 MB
# Memory usage after optimization is: 7583.04 MB
# Decreased by 73.4%
# /mnt/otto-recommender-system/output/exp045/cache/train_cand_week3_3.pkl
# 2:07:10.540893 	 [make_candidate] session_frequent : start
# 2:07:11.086386 	 [add_candidate] session_frequent : start
# 2:07:11.791246 	 [make_candidate] session_latest : start
# 2:07:12.043198 	 [add_candidate] session_latest : start
# 2:07:12.946916 	 [make_candidate] session_latest_time_wt_pair0 : start
# 2:07:13.385139 	 [add_candidate] session_latest_time_wt_pair0 : start
# 2:07:14.421601 	 [make_candidate] session_latest_word2vec_pair0 : start
# 2:07:14.857895 	 [add_candidate] session_latest_word2vec_pair0 : start
# 2:07:16.471577 	 [make_candidate] session_latest_pair0 : start
# 2:07:17.022419 	 [add_candidate] session_latest_pair0 : start
# 2:07:18.689975 	 [make_candidate] session_latest_time_wt_pair1 : start
# 2:07:19.344783 	 [add_candidate] session_latest_time_wt_pair1 : start
# 2:07:21.281788 	 [make_candidate] session_latest_word2vec_pair1 : start
# 2:07:21.754252 	 [add_candidate] session_latest_word2vec_pair1 : start
# 2:07:24.015776 	 [make_candidate] session_latest_pair1 : start
# 2:07:24.596684 	 [add_candidate] session_latest_pair1 : start
# 2:07:27.123122 	 [make_candidate] session_latest_time_wt_pair2 : start
# 2:07:27.619701 	 [add_candidate] session_latest_time_wt_pair2 : start
# 2:07:31.149323 	 [make_candidate] session_latest_word2vec_pair2 : start
# 2:07:31.827780 	 [add_candidate] session_latest_word2vec_pair2 : start
# 2:07:35.855463 	 [make_candidate] session_latest_pair2 : start
# 2:07:36.574182 	 [add_candidate] session_latest_pair2 : start
# 2:07:40.799260 	 [make_candidate] session_latest_time_wt_pair3 : start
# 2:07:41.578629 	 [add_candidate] session_latest_time_wt_pair3 : start
# 2:07:46.287651 	 [make_candidate] session_latest_word2vec_pair3 : start
# 2:07:46.872960 	 [add_candidate] session_latest_word2vec_pair3 : start
# 2:07:52.072716 	 [make_candidate] session_latest_pair3 : start
# 2:07:52.966759 	 [add_candidate] session_latest_pair3 : start
# 2:07:58.319442 	 [make_candidate] session_latest_time_wt_pair4 : start
# 2:07:59.225211 	 [add_candidate] session_latest_time_wt_pair4 : start
# 2:08:05.153272 	 [make_candidate] session_latest_word2vec_pair4 : start
# 2:08:06.028028 	 [add_candidate] session_latest_word2vec_pair4 : start
# 2:08:12.503235 	 [make_candidate] session_latest_pair4 : start
# 2:08:13.175879 	 [add_candidate] session_latest_pair4 : start
# 2:08:19.856500 	 [make_candidate] session_latest_time_wt_pair5 : start
# 2:08:20.557008 	 [add_candidate] session_latest_time_wt_pair5 : start
# 2:08:27.951676 	 [make_candidate] session_latest_word2vec_pair5 : start
# 2:08:28.802948 	 [add_candidate] session_latest_word2vec_pair5 : start
# 2:08:37.550967 	 [make_candidate] session_latest_pair5 : start
# 2:08:38.386386 	 [add_candidate] session_latest_pair5 : start
# 2:08:47.223204 	 [make_candidate] session_latest_time_wt_pair6 : start
# 2:08:47.939260 	 [add_candidate] session_latest_time_wt_pair6 : start
# 2:08:57.622730 	 [make_candidate] session_latest_word2vec_pair6 : start
# 2:08:58.589000 	 [add_candidate] session_latest_word2vec_pair6 : start
# 2:09:08.622832 	 [make_candidate] session_latest_pair6 : start
# 2:09:09.423117 	 [add_candidate] session_latest_pair6 : start
# 2:09:20.052032 	 [make_candidate] session_latest_time_wt_pair7 : start
# 2:09:21.164517 	 [add_candidate] session_latest_time_wt_pair7 : start
# 2:09:32.460544 	 [make_candidate] session_latest_word2vec_pair7 : start
# 2:09:33.332700 	 [add_candidate] session_latest_word2vec_pair7 : start
# 2:09:44.995482 	 [make_candidate] session_latest_pair7 : start
# 2:09:46.158724 	 [add_candidate] session_latest_pair7 : start
# 2:09:58.202400 	 [make_candidate] session_latest_time_wt_pair8 : start
# 2:09:59.139049 	 [add_candidate] session_latest_time_wt_pair8 : start
# 2:10:12.104038 	 [make_candidate] session_latest_word2vec_pair8 : start
# 2:10:13.218519 	 [add_candidate] session_latest_word2vec_pair8 : start
# 2:10:26.969095 	 [make_candidate] session_latest_pair8 : start
# 2:10:28.108242 	 [add_candidate] session_latest_pair8 : start
# 2:10:42.379957 	 [make_candidate] session_latest_time_wt_pair9 : start
# 2:10:43.558349 	 [add_candidate] session_latest_time_wt_pair9 : start
# 2:10:58.351279 	 [make_candidate] session_latest_word2vec_pair9 : start
# 2:10:59.573724 	 [add_candidate] session_latest_word2vec_pair9 : start
# 2:11:15.078902 	 [make_candidate] session_latest_pair9 : start
# 2:11:16.319550 	 [add_candidate] session_latest_pair9 : start
# 2:11:32.536376 	 [make_candidate] session_latest_time_wt_pair10 : start
# 2:11:33.947639 	 [add_candidate] session_latest_time_wt_pair10 : start
# 2:11:50.534976 	 [make_candidate] session_latest_word2vec_pair10 : start
# 2:11:51.930866 	 [add_candidate] session_latest_word2vec_pair10 : start
# 2:12:09.269767 	 [make_candidate] session_latest_pair10 : start
# 2:12:10.532351 	 [add_candidate] session_latest_pair10 : start
# 2:12:28.439497 	 [make_candidate] session_latest_time_wt_pair11 : start
# 2:12:29.877356 	 [add_candidate] session_latest_time_wt_pair11 : start
# 2:12:48.628413 	 [make_candidate] session_latest_word2vec_pair11 : start
# 2:12:50.159536 	 [add_candidate] session_latest_word2vec_pair11 : start
# 2:13:09.468574 	 [make_candidate] session_latest_pair11 : start
# 2:13:11.051949 	 [add_candidate] session_latest_pair11 : start
# 2:13:33.377372 	 [make_candidate] session_latest_time_wt_pair12 : start
# 2:13:34.695413 	 [add_candidate] session_latest_time_wt_pair12 : start
# 2:13:57.981588 	 [make_candidate] session_latest_word2vec_pair12 : start
# 2:13:59.502970 	 [add_candidate] session_latest_word2vec_pair12 : start
# 2:14:23.228629 	 [make_candidate] session_latest_pair12 : start
# 2:14:24.858807 	 [add_candidate] session_latest_pair12 : start
# 2:14:49.267697 	 [make_candidate] session_latest_time_wt_pair13 : start
# 2:14:50.880045 	 [add_candidate] session_latest_time_wt_pair13 : start
# 2:15:16.305163 	 [make_candidate] session_latest_word2vec_pair13 : start
# 2:15:18.084059 	 [add_candidate] session_latest_word2vec_pair13 : start
# 2:15:44.156612 	 [make_candidate] session_latest_pair13 : start
# 2:15:45.975264 	 [add_candidate] session_latest_pair13 : start
# 2:16:12.542386 	 [make_candidate] session_latest_time_wt_pair14 : start
# 2:16:14.448625 	 [add_candidate] session_latest_time_wt_pair14 : start
# 2:16:42.257412 	 [make_candidate] session_latest_word2vec_pair14 : start
# 2:16:44.254041 	 [add_candidate] session_latest_word2vec_pair14 : start
# 2:17:12.599343 	 [make_candidate] session_latest_pair14 : start
# 2:17:14.585679 	 [add_candidate] session_latest_pair14 : start
# 2:17:43.615229 	 [make_candidate] session_latest_time_wt_pair15 : start
# 2:17:45.609992 	 [add_candidate] session_latest_time_wt_pair15 : start
# 2:18:15.216316 	 [make_candidate] session_latest_word2vec_pair15 : start
# 2:18:17.371132 	 [add_candidate] session_latest_word2vec_pair15 : start
# 2:18:48.157169 	 [make_candidate] session_latest_pair15 : start
# 2:18:50.299917 	 [add_candidate] session_latest_pair15 : start
# 2:19:22.140579 	 [make_candidate] session_latest_time_wt_pair16 : start
# 2:19:24.357131 	 [add_candidate] session_latest_time_wt_pair16 : start
# 2:19:56.907904 	 [make_candidate] session_latest_word2vec_pair16 : start
# 2:19:59.132629 	 [add_candidate] session_latest_word2vec_pair16 : start
# 2:20:32.440435 	 [make_candidate] session_latest_pair16 : start
# 2:20:34.702560 	 [add_candidate] session_latest_pair16 : start
# 2:21:08.894729 	 [make_candidate] session_latest_time_wt_pair17 : start
# 2:21:10.928416 	 [add_candidate] session_latest_time_wt_pair17 : start
# 2:21:46.458582 	 [make_candidate] session_latest_word2vec_pair17 : start
# 2:21:48.891299 	 [add_candidate] session_latest_word2vec_pair17 : start
# 2:22:24.771102 	 [make_candidate] session_latest_pair17 : start
# 2:22:27.262866 	 [add_candidate] session_latest_pair17 : start
# 2:23:04.646166 	 [make_candidate] session_latest_time_wt_pair18 : start
# 2:23:07.090239 	 [add_candidate] session_latest_time_wt_pair18 : start
# 2:23:45.198401 	 [make_candidate] session_latest_word2vec_pair18 : start
# 2:23:47.799848 	 [add_candidate] session_latest_word2vec_pair18 : start
# 2:24:26.715688 	 [make_candidate] session_latest_pair18 : start
# 2:24:29.101170 	 [add_candidate] session_latest_pair18 : start
# 2:25:08.669798 	 [make_candidate] session_latest_time_wt_pair19 : start
# 2:25:11.272223 	 [add_candidate] session_latest_time_wt_pair19 : start
# 2:25:51.850701 	 [make_candidate] session_latest_word2vec_pair19 : start
# 2:25:54.649045 	 [add_candidate] session_latest_word2vec_pair19 : start
# 2:26:36.116534 	 [make_candidate] session_latest_pair19 : start
# 2:26:38.912725 	 [add_candidate] session_latest_pair19 : start
# 2:27:21.169887 	 [make_candidate] session_latest_type_wt_pair0 : start
# 2:27:23.971796 	 [add_candidate] session_latest_type_wt_pair0 : start
# 2:28:06.648907 	 [make_candidate] session_latest_clicks2carts_pair0 : start
# 2:28:09.545270 	 [add_candidate] session_latest_clicks2carts_pair0 : start
# 2:28:53.121758 	 [make_candidate] session_latest_clicks2orders_pair0 : start
# 2:28:55.953554 	 [add_candidate] session_latest_clicks2orders_pair0 : start
# 2:29:40.005586 	 [make_candidate] session_latest_type_wt_pair1 : start
# 2:29:42.824489 	 [add_candidate] session_latest_type_wt_pair1 : start
# 2:30:27.457732 	 [make_candidate] session_latest_clicks2carts_pair1 : start
# 2:30:30.416887 	 [add_candidate] session_latest_clicks2carts_pair1 : start
# 2:31:15.474636 	 [make_candidate] session_latest_clicks2orders_pair1 : start
# 2:31:18.463081 	 [add_candidate] session_latest_clicks2orders_pair1 : start
# 2:32:04.083266 	 [make_candidate] session_latest_type_wt_pair2 : start
# 2:32:07.121356 	 [add_candidate] session_latest_type_wt_pair2 : start
# 2:32:53.382596 	 [make_candidate] session_latest_clicks2carts_pair2 : start
# 2:32:56.516858 	 [add_candidate] session_latest_clicks2carts_pair2 : start
# 2:33:43.911133 	 [make_candidate] session_latest_clicks2orders_pair2 : start
# 2:33:46.862131 	 [add_candidate] session_latest_clicks2orders_pair2 : start
# 2:34:34.937173 	 [make_candidate] session_latest_type_wt_pair3 : start
# 2:34:38.193753 	 [add_candidate] session_latest_type_wt_pair3 : start
# 2:35:26.224392 	 [make_candidate] session_latest_clicks2carts_pair3 : start
# 2:35:29.317857 	 [add_candidate] session_latest_clicks2carts_pair3 : start
# 2:36:18.685507 	 [make_candidate] session_latest_clicks2orders_pair3 : start
# 2:36:21.898579 	 [add_candidate] session_latest_clicks2orders_pair3 : start
# 2:37:12.026139 	 [make_candidate] session_latest_type_wt_pair4 : start
# 2:37:15.466230 	 [add_candidate] session_latest_type_wt_pair4 : start
# 2:38:07.322546 	 [make_candidate] session_latest_clicks2carts_pair4 : start
# 2:38:10.570172 	 [add_candidate] session_latest_clicks2carts_pair4 : start
# 2:39:03.004643 	 [make_candidate] session_latest_clicks2orders_pair4 : start
# 2:39:06.461977 	 [add_candidate] session_latest_clicks2orders_pair4 : start
# Memory usage of dataframe is 27434.02 MB
# Memory usage after optimization is: 7287.16 MB
# Decreased by 73.4%
# /mnt/otto-recommender-system/output/exp045/cache/train_cand_week3_4.pkl
# 2:44:41.776148 	 [make_candidate] session_frequent : start
# 2:44:42.200880 	 [add_candidate] session_frequent : start
# 2:44:42.723008 	 [make_candidate] session_latest : start
# 2:44:42.908979 	 [add_candidate] session_latest : start
# 2:44:43.724488 	 [make_candidate] session_latest_time_wt_pair0 : start
# 2:44:44.135910 	 [add_candidate] session_latest_time_wt_pair0 : start
# 2:44:45.117782 	 [make_candidate] session_latest_word2vec_pair0 : start
# 2:44:45.571385 	 [add_candidate] session_latest_word2vec_pair0 : start
# 2:44:47.101209 	 [make_candidate] session_latest_pair0 : start
# 2:44:47.666584 	 [add_candidate] session_latest_pair0 : start
# 2:44:49.344723 	 [make_candidate] session_latest_time_wt_pair1 : start
# 2:44:49.989909 	 [add_candidate] session_latest_time_wt_pair1 : start
# 2:44:51.824445 	 [make_candidate] session_latest_word2vec_pair1 : start
# 2:44:52.403987 	 [add_candidate] session_latest_word2vec_pair1 : start
# 2:44:54.586473 	 [make_candidate] session_latest_pair1 : start
# 2:44:55.187400 	 [add_candidate] session_latest_pair1 : start
# 2:44:57.552635 	 [make_candidate] session_latest_time_wt_pair2 : start
# 2:44:58.008056 	 [add_candidate] session_latest_time_wt_pair2 : start
# 2:45:00.755508 	 [make_candidate] session_latest_word2vec_pair2 : start
# 2:45:01.462855 	 [add_candidate] session_latest_word2vec_pair2 : start
# 2:45:05.202372 	 [make_candidate] session_latest_pair2 : start
# 2:45:05.977952 	 [add_candidate] session_latest_pair2 : start
# 2:45:10.014093 	 [make_candidate] session_latest_time_wt_pair3 : start
# 2:45:10.786218 	 [add_candidate] session_latest_time_wt_pair3 : start
# 2:45:15.149821 	 [make_candidate] session_latest_word2vec_pair3 : start
# 2:45:15.938095 	 [add_candidate] session_latest_word2vec_pair3 : start
# 2:45:20.549326 	 [make_candidate] session_latest_pair3 : start
# 2:45:21.375681 	 [add_candidate] session_latest_pair3 : start
# 2:45:26.500271 	 [make_candidate] session_latest_time_wt_pair4 : start
# 2:45:27.191496 	 [add_candidate] session_latest_time_wt_pair4 : start
# 2:45:32.704373 	 [make_candidate] session_latest_word2vec_pair4 : start
# 2:45:33.587928 	 [add_candidate] session_latest_word2vec_pair4 : start
# 2:45:39.701373 	 [make_candidate] session_latest_pair4 : start
# 2:45:40.337412 	 [add_candidate] session_latest_pair4 : start
# 2:45:46.820243 	 [make_candidate] session_latest_time_wt_pair5 : start
# 2:45:47.793806 	 [add_candidate] session_latest_time_wt_pair5 : start
# 2:45:54.578855 	 [make_candidate] session_latest_word2vec_pair5 : start
# 2:45:55.432268 	 [add_candidate] session_latest_word2vec_pair5 : start
# 2:46:02.937827 	 [make_candidate] session_latest_pair5 : start
# 2:46:03.793658 	 [add_candidate] session_latest_pair5 : start
# 2:46:12.322830 	 [make_candidate] session_latest_time_wt_pair6 : start
# 2:46:13.221788 	 [add_candidate] session_latest_time_wt_pair6 : start
# 2:46:22.273371 	 [make_candidate] session_latest_word2vec_pair6 : start
# 2:46:23.202924 	 [add_candidate] session_latest_word2vec_pair6 : start
# 2:46:32.618209 	 [make_candidate] session_latest_pair6 : start
# 2:46:33.603601 	 [add_candidate] session_latest_pair6 : start
# 2:46:43.699275 	 [make_candidate] session_latest_time_wt_pair7 : start
# 2:46:44.435632 	 [add_candidate] session_latest_time_wt_pair7 : start
# 2:46:55.040980 	 [make_candidate] session_latest_word2vec_pair7 : start
# 2:46:56.118990 	 [add_candidate] session_latest_word2vec_pair7 : start
# 2:47:07.497473 	 [make_candidate] session_latest_pair7 : start
# 2:47:08.344646 	 [add_candidate] session_latest_pair7 : start
# 2:47:20.170923 	 [make_candidate] session_latest_time_wt_pair8 : start
# 2:47:21.220596 	 [add_candidate] session_latest_time_wt_pair8 : start
# 2:47:33.533246 	 [make_candidate] session_latest_word2vec_pair8 : start
# 2:47:34.614104 	 [add_candidate] session_latest_word2vec_pair8 : start
# 2:47:47.224980 	 [make_candidate] session_latest_pair8 : start
# 2:47:48.345118 	 [add_candidate] session_latest_pair8 : start
# 2:48:02.646076 	 [make_candidate] session_latest_time_wt_pair9 : start
# 2:48:03.800719 	 [add_candidate] session_latest_time_wt_pair9 : start
# 2:48:17.564996 	 [make_candidate] session_latest_word2vec_pair9 : start
# ...
# 2:57:20.019914 	 [add_candidate] session_latest_pair16 : start
# 2:57:52.776566 	 [make_candidate] session_latest_time_wt_pair17 : start
# 2:57:54.955252 	 [add_candidate] session_latest_time_wt_pair17 : start
# 2:58:28.268164 	 [make_candidate] session_latest_word2vec_pair17 : start
# 2:58:30.370860 	 [add_candidate] session_latest_word2vec_pair17 : start
# 2:59:04.690596 	 [make_candidate] session_latest_pair17 : start
# 2:59:06.863175 	 [add_candidate] session_latest_pair17 : start
# 2:59:42.131691 	 [make_candidate] session_latest_time_wt_pair18 : start
# 2:59:44.489598 	 [add_candidate] session_latest_time_wt_pair18 : start
# 3:00:20.134632 	 [make_candidate] session_latest_word2vec_pair18 : start
# 3:00:22.542186 	 [add_candidate] session_latest_word2vec_pair18 : start
# 3:00:59.514290 	 [make_candidate] session_latest_pair18 : start
# 3:01:02.023457 	 [add_candidate] session_latest_pair18 : start
# 3:01:39.443308 	 [make_candidate] session_latest_time_wt_pair19 : start
# 3:01:41.987227 	 [add_candidate] session_latest_time_wt_pair19 : start
# 3:02:20.300946 	 [make_candidate] session_latest_word2vec_pair19 : start
# 3:02:22.727265 	 [add_candidate] session_latest_word2vec_pair19 : start
# 3:03:02.566445 	 [make_candidate] session_latest_pair19 : start
# 3:03:05.201321 	 [add_candidate] session_latest_pair19 : start
# 3:03:45.597248 	 [make_candidate] session_latest_type_wt_pair0 : start
# 3:03:48.342880 	 [add_candidate] session_latest_type_wt_pair0 : start
# 3:04:29.480287 	 [make_candidate] session_latest_clicks2carts_pair0 : start
# 3:04:32.078242 	 [add_candidate] session_latest_clicks2carts_pair0 : start
# 3:05:13.690067 	 [make_candidate] session_latest_clicks2orders_pair0 : start
# 3:05:16.541855 	 [add_candidate] session_latest_clicks2orders_pair0 : start
# 3:05:58.207316 	 [make_candidate] session_latest_type_wt_pair1 : start
# 3:06:01.091789 	 [add_candidate] session_latest_type_wt_pair1 : start
# 3:06:42.995884 	 [make_candidate] session_latest_clicks2carts_pair1 : start
# 3:06:45.592779 	 [add_candidate] session_latest_clicks2carts_pair1 : start
# 3:07:28.353933 	 [make_candidate] session_latest_clicks2orders_pair1 : start
# 3:07:31.135968 	 [add_candidate] session_latest_clicks2orders_pair1 : start
# 3:08:14.446505 	 [make_candidate] session_latest_type_wt_pair2 : start
# 3:08:17.267153 	 [add_candidate] session_latest_type_wt_pair2 : start
# 3:09:01.137795 	 [make_candidate] session_latest_clicks2carts_pair2 : start
# 3:09:03.966516 	 [add_candidate] session_latest_clicks2carts_pair2 : start
# 3:09:48.763449 	 [make_candidate] session_latest_clicks2orders_pair2 : start
# 3:09:51.820535 	 [add_candidate] session_latest_clicks2orders_pair2 : start
# 3:10:37.390642 	 [make_candidate] session_latest_type_wt_pair3 : start
# 3:10:40.609172 	 [add_candidate] session_latest_type_wt_pair3 : start
# 3:11:26.483718 	 [make_candidate] session_latest_clicks2carts_pair3 : start
# 3:11:29.588910 	 [add_candidate] session_latest_clicks2carts_pair3 : start
# 3:12:16.101309 	 [make_candidate] session_latest_clicks2orders_pair3 : start
# 3:12:19.002333 	 [add_candidate] session_latest_clicks2orders_pair3 : start
# 3:13:06.813540 	 [make_candidate] session_latest_type_wt_pair4 : start
# 3:13:10.091564 	 [add_candidate] session_latest_type_wt_pair4 : start
# 3:13:58.763625 	 [make_candidate] session_latest_clicks2carts_pair4 : start
# 3:14:01.851997 	 [add_candidate] session_latest_clicks2carts_pair4 : start
# 3:14:51.566725 	 [make_candidate] session_latest_clicks2orders_pair4 : start
# 3:14:54.846701 	 [add_candidate] session_latest_clicks2orders_pair4 : start
# Memory usage of dataframe is 25913.50 MB
# Memory usage after optimization is: 6883.27 MB
# Decreased by 73.4%
# /mnt/otto-recommender-system/output/exp045/cache/train_cand_week3_5.pkl
# 3:20:13.475618 	 [make_candidate] session_frequent : start
# 3:20:13.903155 	 [add_candidate] session_frequent : start
# 3:20:14.319246 	 [make_candidate] session_latest : start
# 3:20:14.505580 	 [add_candidate] session_latest : start
# 3:20:15.025778 	 [make_candidate] session_latest_time_wt_pair0 : start
# 3:20:15.414341 	 [add_candidate] session_latest_time_wt_pair0 : start
# 3:20:16.239697 	 [make_candidate] session_latest_word2vec_pair0 : start
# 3:20:16.658936 	 [add_candidate] session_latest_word2vec_pair0 : start
# 3:20:17.749789 	 [make_candidate] session_latest_pair0 : start
# 3:20:18.211735 	 [add_candidate] session_latest_pair0 : start
# 3:20:19.749754 	 [make_candidate] session_latest_time_wt_pair1 : start
# 3:20:20.295680 	 [add_candidate] session_latest_time_wt_pair1 : start
# 3:20:22.045938 	 [make_candidate] session_latest_word2vec_pair1 : start
# 3:20:22.451473 	 [add_candidate] session_latest_word2vec_pair1 : start
# 3:20:24.411397 	 [make_candidate] session_latest_pair1 : start
# 3:20:25.056409 	 [add_candidate] session_latest_pair1 : start
# 3:20:27.194726 	 [make_candidate] session_latest_time_wt_pair2 : start
# 3:20:27.637208 	 [add_candidate] session_latest_time_wt_pair2 : start
# 3:20:29.975129 	 [make_candidate] session_latest_word2vec_pair2 : start
# 3:20:30.644765 	 [add_candidate] session_latest_word2vec_pair2 : start
# 3:20:33.766020 	 [make_candidate] session_latest_pair2 : start
# 3:20:34.488372 	 [add_candidate] session_latest_pair2 : start
# 3:20:38.019889 	 [make_candidate] session_latest_time_wt_pair3 : start
# 3:20:38.536814 	 [add_candidate] session_latest_time_wt_pair3 : start
# 3:20:42.249207 	 [make_candidate] session_latest_word2vec_pair3 : start
# 3:20:43.070370 	 [add_candidate] session_latest_word2vec_pair3 : start
# 3:20:47.420932 	 [make_candidate] session_latest_pair3 : start
# 3:20:48.208809 	 [add_candidate] session_latest_pair3 : start
# 3:20:52.828054 	 [make_candidate] session_latest_time_wt_pair4 : start
# 3:20:53.654578 	 [add_candidate] session_latest_time_wt_pair4 : start
# 3:20:58.546769 	 [make_candidate] session_latest_word2vec_pair4 : start
# 3:20:59.270320 	 [add_candidate] session_latest_word2vec_pair4 : start
# 3:21:04.562862 	 [make_candidate] session_latest_pair4 : start
# 3:21:05.121456 	 [add_candidate] session_latest_pair4 : start
# 3:21:10.979143 	 [make_candidate] session_latest_time_wt_pair5 : start
# 3:21:11.865156 	 [add_candidate] session_latest_time_wt_pair5 : start
# 3:21:18.052253 	 [make_candidate] session_latest_word2vec_pair5 : start
# 3:21:18.891675 	 [add_candidate] session_latest_word2vec_pair5 : start
# 3:21:25.349013 	 [make_candidate] session_latest_pair5 : start
# 3:21:26.232098 	 [add_candidate] session_latest_pair5 : start
# 3:21:33.129627 	 [make_candidate] session_latest_time_wt_pair6 : start
# 3:21:34.043611 	 [add_candidate] session_latest_time_wt_pair6 : start
# 3:21:42.329483 	 [make_candidate] session_latest_word2vec_pair6 : start
# 3:21:43.302113 	 [add_candidate] session_latest_word2vec_pair6 : start
# 3:21:52.187379 	 [make_candidate] session_latest_pair6 : start
# 3:21:53.230550 	 [add_candidate] session_latest_pair6 : start
# 3:22:02.315895 	 [make_candidate] session_latest_time_wt_pair7 : start
# 3:22:03.290962 	 [add_candidate] session_latest_time_wt_pair7 : start
# 3:22:12.920500 	 [make_candidate] session_latest_word2vec_pair7 : start
# 3:22:13.855451 	 [add_candidate] session_latest_word2vec_pair7 : start
# 3:22:24.141141 	 [make_candidate] session_latest_pair7 : start
# 3:22:25.216811 	 [add_candidate] session_latest_pair7 : start
# 3:22:36.018029 	 [make_candidate] session_latest_time_wt_pair8 : start
# 3:22:37.079852 	 [add_candidate] session_latest_time_wt_pair8 : start
# 3:22:48.371353 	 [make_candidate] session_latest_word2vec_pair8 : start
# 3:22:49.446853 	 [add_candidate] session_latest_word2vec_pair8 : start
# 3:23:00.935952 	 [make_candidate] session_latest_pair8 : start
# 3:23:02.039834 	 [add_candidate] session_latest_pair8 : start
# 3:23:14.765250 	 [make_candidate] session_latest_time_wt_pair9 : start
# 3:23:15.854102 	 [add_candidate] session_latest_time_wt_pair9 : start
# 3:23:28.612685 	 [make_candidate] session_latest_word2vec_pair9 : start
# 3:23:29.674279 	 [add_candidate] session_latest_word2vec_pair9 : start
# 3:23:42.804990 	 [make_candidate] session_latest_pair9 : start
# 3:23:43.981253 	 [add_candidate] session_latest_pair9 : start
# 3:23:57.767217 	 [make_candidate] session_latest_time_wt_pair10 : start
# 3:23:59.011274 	 [add_candidate] session_latest_time_wt_pair10 : start
# 3:24:13.306255 	 [make_candidate] session_latest_word2vec_pair10 : start
# 3:24:14.377548 	 [add_candidate] session_latest_word2vec_pair10 : start
# 3:24:29.196723 	 [make_candidate] session_latest_pair10 : start
# 3:24:30.537067 	 [add_candidate] session_latest_pair10 : start
# 3:24:46.088717 	 [make_candidate] session_latest_time_wt_pair11 : start
# 3:24:47.428161 	 [add_candidate] session_latest_time_wt_pair11 : start
# 3:25:03.528290 	 [make_candidate] session_latest_word2vec_pair11 : start
# 3:25:04.831676 	 [add_candidate] session_latest_word2vec_pair11 : start
# 3:25:21.607946 	 [make_candidate] session_latest_pair11 : start
# 3:25:22.975097 	 [add_candidate] session_latest_pair11 : start
# 3:25:40.040994 	 [make_candidate] session_latest_time_wt_pair12 : start
# 3:25:41.409521 	 [add_candidate] session_latest_time_wt_pair12 : start
# 3:25:59.393233 	 [make_candidate] session_latest_word2vec_pair12 : start
# 3:26:01.016395 	 [add_candidate] session_latest_word2vec_pair12 : start
# 3:26:19.305541 	 [make_candidate] session_latest_pair12 : start
# 3:26:20.697897 	 [add_candidate] session_latest_pair12 : start
# 3:26:40.214146 	 [make_candidate] session_latest_time_wt_pair13 : start
# 3:26:41.731804 	 [add_candidate] session_latest_time_wt_pair13 : start
# 3:27:01.481460 	 [make_candidate] session_latest_word2vec_pair13 : start
# 3:27:02.976335 	 [add_candidate] session_latest_word2vec_pair13 : start
# 3:27:23.814770 	 [make_candidate] session_latest_pair13 : start
# 3:27:25.328467 	 [add_candidate] session_latest_pair13 : start
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In [21], line 2
#       1 try:
# ----> 2     main()
#       3 except Exception as e:
#       4     logger.error(traceback.format_exc())
#
# Cell In [20], line 33, in main()
#      31     train = pd.read_pickle(cache_path)
#      32 else:
# ---> 33     train = make_train_data(type_)
#      34     train.to_pickle(cache_path)
#      36 logger.info(f"make {type_}_valid_data")
#
# Cell In [14], line 25, in make_train_data(type_)
#      23 # 候補選出
#      24 week_sessions_chunk = week_sessions[week_sessions["session"].isin(sessions_lists[chunk])].reset_index(drop=True)
# ---> 25 cand_df = make_cand_df(week_sessions_chunk, trans_maps=trans_maps)
#      26 cand_df = reduce_mem_usage(cand_df)
#      27 cand_df.to_pickle(cache_path)
#
# Cell In [12], line 15, in make_cand_df(sessions, labels, trans_maps)
#      13     cand.add(strategy="session_latest", trans_map=trans_maps[f"time_wt_pair{str(i)}"], name=f"session_latest_time_wt_pair{str(i)}", k=5)
#      14     cand.add(strategy="session_latest", trans_map=trans_maps[f"word2vec_pair{str(i)}"], name=f"session_latest_word2vec_pair{str(i)}", k=5)
# ---> 15     cand.add(strategy="session_latest", trans_map=trans_maps[f"pair{str(i)}"], name=f"session_latest_pair{str(i)}", k=5)
#      16 for i in range(5):
#      17     cand.add(strategy="session_latest", trans_map=trans_maps[f"type_wt_pair{str(i)}"], name=f"session_latest_type_wt_pair{str(i)}", k=5)
#
# Cell In [6], line 52, in Candidate.add(self, strategy, name, usetypes, trans_map, k)
#      49     candidate_df["aid"] = candidate_df["aid"].map(trans_map)
#      50     candidate_df = candidate_df.dropna(subset=["aid"])
# ---> 52 self._entry(candidate_df, name, k)
#
# Cell In [6], line 19, in Candidate._entry(self, new_candidate_df, name, k)
#      16 self.output = pd.concat([self.output, new_candidate_df[["session", "aid"]]])
#      17 self.output = self.output.drop_duplicates(subset=["session", "aid"])
# ---> 19 self.output = self.output.merge(new_candidate_df, on=["session", "aid"], how="left")
#      21 if self.labels is not None:
#      22     self._eval(new_candidate_df[["session", "aid"]], name, k)
#
# File /opt/conda/lib/python3.8/site-packages/pandas/core/frame.py:9354, in DataFrame.merge(self, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#    9335 @Substitution("")
#    9336 @Appender(_merge_doc, indents=2)
#    9337 def merge(
#    (...)
#    9350     validate: str | None = None,
#    9351 ) -> DataFrame:
#    9352     from pandas.core.reshape.merge import merge
# -> 9354     return merge(
#    9355         self,
#    9356         right,
#    9357         how=how,
#    9358         on=on,
#    9359         left_on=left_on,
#    9360         right_on=right_on,
#    9361         left_index=left_index,
#    9362         right_index=right_index,
#    9363         sort=sort,
#    9364         suffixes=suffixes,
#    9365         copy=copy,
#    9366         indicator=indicator,
#    9367         validate=validate,
#    9368     )
#
# File /opt/conda/lib/python3.8/site-packages/pandas/core/reshape/merge.py:122, in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#      90 @Substitution("\nleft : DataFrame or named Series")
#      91 @Appender(_merge_doc, indents=0)
#      92 def merge(
#    (...)
#     105     validate: str | None = None,
#     106 ) -> DataFrame:
#     107     op = _MergeOperation(
#     108         left,
#     109         right,
#    (...)
#     120         validate=validate,
#     121     )
# --> 122     return op.get_result()
#
# File /opt/conda/lib/python3.8/site-packages/pandas/core/reshape/merge.py:716, in _MergeOperation.get_result(self)
#     713 if self.indicator:
#     714     self.left, self.right = self._indicator_pre_merge(self.left, self.right)
# --> 716 join_index, left_indexer, right_indexer = self._get_join_info()
#     718 llabels, rlabels = _items_overlap_with_suffix(
#     719     self.left._info_axis, self.right._info_axis, self.suffixes
#     720 )
#     722 lindexers = {1: left_indexer} if left_indexer is not None else {}
#
# File /opt/conda/lib/python3.8/site-packages/pandas/core/reshape/merge.py:967, in _MergeOperation._get_join_info(self)
#     963     join_index, right_indexer, left_indexer = _left_join_on_index(
#     964         right_ax, left_ax, self.right_join_keys, sort=self.sort
#     965     )
#     966 else:
# --> 967     (left_indexer, right_indexer) = self._get_join_indexers()
#     969     if self.right_index:
#     970         if len(self.left) > 0:
#
# File /opt/conda/lib/python3.8/site-packages/pandas/core/reshape/merge.py:941, in _MergeOperation._get_join_indexers(self)
#     939 def _get_join_indexers(self) -> tuple[npt.NDArray[np.intp], npt.NDArray[np.intp]]:
#     940     """return the join indexers"""
# --> 941     return get_join_indexers(
#     942         self.left_join_keys, self.right_join_keys, sort=self.sort, how=self.how
#     943     )
#
# File /opt/conda/lib/python3.8/site-packages/pandas/core/reshape/merge.py:1498, in get_join_indexers(left_keys, right_keys, sort, how, **kwargs)
#    1492 lkey, rkey = _get_join_keys(llab, rlab, shape, sort)
#    1494 # factorize keys to a dense i8 space
#    1495 # `count` is the num. of unique keys
#    1496 # set(lkey) | set(rkey) == range(count)
# -> 1498 lkey, rkey, count = _factorize_keys(lkey, rkey, sort=sort, how=how)
#    1499 # preserve left frame order if how == 'left' and sort == False
#    1500 kwargs = copy.copy(kwargs)
#
# File /opt/conda/lib/python3.8/site-packages/pandas/core/reshape/merge.py:2187, in _factorize_keys(lk, rk, sort, how)
#    2182 rizer = klass(max(len(lk), len(rk)))
#    2184 # Argument 1 to "factorize" of "ObjectFactorizer" has incompatible type
#    2185 # "Union[ndarray[Any, dtype[signedinteger[_64Bit]]],
#    2186 # ndarray[Any, dtype[object_]]]"; expected "ndarray[Any, dtype[object_]]"
# -> 2187 llab = rizer.factorize(lk)  # type: ignore[arg-type]
#    2188 # Argument 1 to "factorize" of "ObjectFactorizer" has incompatible type
#    2189 # "Union[ndarray[Any, dtype[signedinteger[_64Bit]]],
#    2190 # ndarray[Any, dtype[object_]]]"; expected "ndarray[Any, dtype[object_]]"
#    2191 rlab = rizer.factorize(rk)  # type: ignore[arg-type]
#
# KeyboardInterrupt:
