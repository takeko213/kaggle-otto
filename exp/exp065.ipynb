# %% [markdown]
# # exp065
# 類似ユーザ追加 carts, ordersのcv確認のみ
# co-visit i k 20

# %%
import os
import sys
import traceback
import gc
import random
import pickle
import pathlib
import subprocess
from dataclasses import dataclass
from dotenv import load_dotenv
load_dotenv
sys.path.append(os.getenv('UTILS_PATH'))
from tqdm import tqdm
import multiprocessing
import inspect

import pandas as pd
import polars as pl
import numpy as np
import itertools
import cudf
import lightgbm as lgb
import matplotlib.pyplot as plt
import seaborn as sns
import line_notify
import my_logger
from noglobal import noglobal

# %% [markdown]
# # 設定

# %%
@dataclass
class Cfg:
    loglevel = "INFO"
    exp_name = "exp065"
    run_inf = False
    seed = 42
    k = 20
    cand_n = 15
    negative_sample = 1
    train_chunk_n_dict = {"clicks":2, "carts":1, "orders":1}
    test_chunk_n = 5
    type2id = {"clicks":0, "carts":1, "orders":2}
    id2type = {0:"clicks", 1:"carts", 2:"orders"}
    train_week = "week3"
    valid_week = "week4"
    valid_session_n = 100_000
    input_dir = os.getenv('INPUT_DIR')
    output_dir = os.getenv('OUTPUT_DIR')
    prep_dir = os.getenv("PREP_DIR")

    clicks_params = {'objective': 'binary', 'boosting': 'gbdt', 'learning_rate': 0.1, 'metric': 'binary_logloss', 'seed': 42, 'feature_pre_filter': False, 'lambda_l1': 5.485903737168179, 'lambda_l2': 0.005594683492536064, 'num_leaves': 79, 'feature_fraction': 0.552, 'bagging_fraction': 0.9295272232672004, 'bagging_freq': 2, 'min_child_samples': 10}
    carts_params = {'objective': 'binary', 'boosting': 'gbdt', 'learning_rate': 0.1, 'metric': 'binary_logloss', 'seed': 42, 'feature_pre_filter': False, 'lambda_l1': 8.709050252544463, 'lambda_l2': 0.06935262036337767, 'num_leaves': 252, 'feature_fraction': 0.4, 'bagging_fraction': 1.0, 'bagging_freq': 0, 'min_child_samples': 5}
    orders_params = {'objective': 'binary', 'boosting': 'gbdt', 'learning_rate': 0.1, 'metric': 'binary_logloss', 'seed': 42, 'feature_pre_filter': False, 'lambda_l1': 9.356310279757256, 'lambda_l2': 1.3120983078968551e-08, 'num_leaves': 174, 'feature_fraction': 0.5, 'bagging_fraction': 1.0, 'bagging_freq': 0, 'min_child_samples': 20}

cfg = Cfg()
os.makedirs(os.path.join(cfg.output_dir, cfg.exp_name), exist_ok=True)
os.makedirs(os.path.join(cfg.output_dir, cfg.exp_name, "cache"), exist_ok=True)
random.seed(cfg.seed)

logger = my_logger.init_logger(cfg.exp_name)

# %%
class Cache:
    @noglobal(excepts=["cfg", "logger"])
    def __init__(self):
        self.cache_dir = (os.path.join(cfg.output_dir, cfg.exp_name, "cache"))
        self.cache_dir_path = pathlib.Path(self.cache_dir)
        self.caches = list(self.cache_dir_path.glob("*"))

    def update(self):
        self.caches = list(self.cache_dir_path.glob("*"))

    @noglobal(excepts=["cfg", "logger"])
    def get_abspath(self, filename):
        return (os.path.join(self.cache_dir, filename))
    
    @noglobal(excepts=["cfg", "logger"])
    def exists(self, path):
        self.update()
        return len([str(c) for c in self.caches if path == str(c)]) > 0

cache = Cache()

# %%
def reduce_mem_usage(df):
    """ iterate through all the columns of a dataframe and modify the data type
        to reduce memory usage.        
    """
    start_mem = df.memory_usage().sum() / 1024**2
    print('Memory usage of dataframe is {:.2f} MB'.format(start_mem))
    
    for col in df.columns:
        col_type = df[col].dtype
        
        if col_type != object:
            c_min = df[col].min()
            c_max = df[col].max()
            if str(col_type)[:3] == 'int':
                if c_min > np.iinfo(np.int8).min and c_max < np.iinfo(np.int8).max:
                    df[col] = df[col].astype(np.int8)
                elif c_min > np.iinfo(np.int16).min and c_max < np.iinfo(np.int16).max:
                    df[col] = df[col].astype(np.int16)
                elif c_min > np.iinfo(np.int32).min and c_max < np.iinfo(np.int32).max:
                    df[col] = df[col].astype(np.int32)
                elif c_min > np.iinfo(np.int64).min and c_max < np.iinfo(np.int64).max:
                    df[col] = df[col].astype(np.int64)  
            else:
                if c_min > np.finfo(np.float16).min and c_max < np.finfo(np.float16).max:
                    df[col] = df[col].astype(np.float32)
                elif c_min > np.finfo(np.float32).min and c_max < np.finfo(np.float32).max:
                    df[col] = df[col].astype(np.float32)
                else:
                    df[col] = df[col].astype(np.float64)
        else:
            df[col] = df[col].astype('category')

    end_mem = df.memory_usage().sum() / 1024**2
    print('Memory usage after optimization is: {:.2f} MB'.format(end_mem))
    print('Decreased by {:.1f}%'.format(100 * (start_mem - end_mem) / start_mem))
    
    return df

# %%
@noglobal(excepts=["cfg", "logger"])
def evaluate(clicks_labels, carts_labels, orders_labels, 
             clicks_preds, carts_preds, orders_preds, k=20):

    num_clicks = 0
    num_carts = 0
    num_orders = 0
    hit_clicks = 0
    hit_carts = 0
    hit_orders = 0

    for i in range(len(clicks_labels)):
        clicks_label = clicks_labels[i]
        carts_label = carts_labels[i]
        orders_label = orders_labels[i]
        clicks_pred = clicks_preds[i]
        carts_pred = carts_preds[i]
        orders_pred = orders_preds[i]

        if type(clicks_pred) == list:
            clicks_pred = clicks_pred[:k]
        else:
            clicks_pred = []
        if type(carts_pred) == list:
            carts_pred = carts_pred[:k]
        else:
            carts_pred = []    
        if type(orders_pred) == list:
            orders_pred = orders_pred[:k]
        else:
            orders_pred = []

        if not np.isnan(clicks_label):
            num_clicks += 1
            hit_clicks += int(clicks_label in clicks_pred)

        if type(carts_label) == np.ndarray:
            num_carts += min(len(carts_label), k)
            hit_carts += len(set(carts_pred) & set(carts_label))
            
        if type(orders_label) == np.ndarray:
            num_orders += min(len(orders_label), k)
            hit_orders += len(set(orders_pred) & set(orders_label))


    recall_clicks = hit_clicks / num_clicks
    recall_carts = hit_carts / num_carts
    recall_orders = hit_orders / num_orders
    w_recall_clicks = recall_clicks * 0.10
    w_recall_carts = recall_carts * 0.30
    w_recall_orders = recall_orders * 0.60
    score = w_recall_clicks + w_recall_carts + w_recall_orders

    results = {}
    results["num_clicks"] = num_clicks
    results["hit_clicks"] = hit_clicks
    results["num_carts"] = num_carts
    results["hit_carts"] = hit_carts
    results["num_orders"] = num_orders
    results["hit_orders"] = hit_orders
    results["recall_clicks"] = format(recall_clicks, ".6f")
    results["recall_carts"] = format(recall_carts, ".6f")
    results["recall_orders"] = format(recall_orders, ".6f")
    results["w_recall_clicks"] = format(w_recall_clicks, ".6f")
    results["w_recall_carts"] = format(w_recall_carts, ".6f")
    results["w_recall_orders"] = format(w_recall_orders, ".6f")
    results["score"] = format(score, ".6f")

    return results

# %%
class Candidate:
    @noglobal(excepts=["cfg", "logger"])
    def __init__(self, pl_df, week):
        self.df = cudf.from_pandas(pl_df.to_pandas())
        self.sessions = []
        self.aids = []
        self.week = week

    @noglobal(excepts=["cfg", "logger"])
    def add(self, strategy, name, usetypes=['clicks', 'carts', 'orders'], trans_map=None, k=20):
        logger.info(f"[add_candidate] {name} : start")
        candidate_df = self.df[self.df["type"].isin(usetypes)].copy()
        
        if strategy == "session_frequent":
            candidate_df = self._session_frequent(candidate_df, k)
        elif strategy == "session_latest":
            candidate_df = self._session_latest(candidate_df, k)
        elif strategy == "total_frequent":
            candidate_df = self._total_frequent(candidate_df, k)
        elif strategy == "repurchase":
            candidate_df = self._repurchase(candidate_df)
        elif strategy == "clstr_freq":
            candidate_df = self._clstr_freq(candidate_df, k)
        
        if trans_map is not None:
            candidate_df["aid"] = candidate_df["aid"].map(trans_map).astype("int32")
            candidate_df = candidate_df.dropna(subset=["aid"])
        candidate_df = candidate_df.drop_duplicates(subset=["session", "aid"])
        
        self.sessions.extend(candidate_df["session"].to_arrow().to_pylist())
        self.aids.extend(candidate_df["aid"].to_arrow().to_pylist())

    @noglobal(excepts=["cfg", "logger"])
    def get_dataframe(self):
        cand_df = pl.DataFrame([
            pl.Series("session", self.sessions, pl.Int32),
            pl.Series("aid", self.aids, pl.Int32)
            ]).unique()
        return cand_df

    @noglobal(excepts=["cfg", "logger"])
    def _repurchase(self, candidate_df):
        return candidate_df[["session", "aid"]].drop_duplicates()

    @noglobal(excepts=["cfg", "logger"])
    def _clstr_freq(self, candidate_df, k):
        if self.week is None:
            session_clstr = pd.read_parquet(cfg.prep_dir + "w2v_session_cluster_c10000.parquet")
            clstr_freq = pd.read_parquet(cfg.prep_dir + "w2v_cluster_freq_c10000.parquet")
        else:
            session_clstr = pd.read_parquet(cfg.prep_dir + f"w2v_session_cluster_c10000_{self.week}.parquet")
            clstr_freq = pd.read_parquet(cfg.prep_dir + f"w2v_cluster_freq_c10000_{self.week}.parquet")
        session_clstr = {session:clstr for session, clstr in zip(session_clstr["session"].tolist(), session_clstr["clstr"].tolist())}
        clstr_freq = clstr_freq[clstr_freq["rank"]<k]
        clstr_freq = clstr_freq.groupby("clstr")["aid"].apply(list).to_dict()

        sessions = []
        aids = []
        for session in candidate_df["session"].to_pandas().unique():
            clstr = session_clstr[session]
            most_freq_aids = clstr_freq[clstr]
            aids.extend(most_freq_aids)
            sessions.extend([session for _ in range(len(most_freq_aids))])
        candidate_df = cudf.DataFrame({"session": sessions, "aid": aids})
        return candidate_df

    @noglobal(excepts=["cfg", "logger"])
    def _session_frequent(self, candidate_df, k):
        candidate_df = candidate_df.groupby(["session", "aid"])["ts"].count().reset_index()
        candidate_df.columns = ["session", "aid", "aid_count"]
        candidate_df = candidate_df.sort_values(["session", "aid_count", "aid"], ascending=(True, False, True))
        candidate_df = candidate_df[candidate_df.groupby("session")["aid_count"].cumcount() < k].copy()
        candidate_df = candidate_df[["session", "aid"]].copy()
        return candidate_df

    @noglobal(excepts=["cfg", "logger"])
    def _session_latest(self, candidate_df, k):
        candidate_df = candidate_df.sort_values(["session", "ts"], ascending=(True, False)).drop_duplicates(subset=["session", "aid"])
        candidate_df = candidate_df.sort_values(["session", "ts"], ascending=(True, False))[candidate_df.groupby("session")["ts"].cumcount() < k].copy()
        candidate_df = candidate_df[["session", "aid"]].copy()
        return candidate_df

    @noglobal(excepts=["cfg", "logger"])
    def _total_frequent(self, candidate_df, k):
        candidate_df = candidate_df.groupby("aid")["ts"].count().reset_index()
        candidate_df.columns = ["aid", "aid_count"]
        topk_freq_aids = candidate_df.sort_values("aid_count", ascending=False)["aid"].to_arrow().to_pylist()[:k]
        sessions = []
        aids = []
        for session, aid in itertools.product(self.target_sessions, topk_freq_aids):
            sessions.append(session)
            aids.append(aid)
        candidate_df = cudf.DataFrame({"session": sessions, "aid": aids})
        return candidate_df

# %%
@noglobal(excepts=["cfg", "logger"])
def add_labels(df, labels, type_):
    if type_ == "clicks":
        type_labels = (labels.select([pl.col("session"), 
                                      pl.col(f"{type_}_labels").cast(pl.Int32).alias("aid"),
                                      pl.lit(1).alias("labels")])
        )
    else:
        type_labels = (labels.explode(f"{type_}_labels")
                             .select([pl.col("session"), 
                                      pl.col(f"{type_}_labels").cast(pl.Int32).alias("aid"),
                                      pl.lit(1).alias("labels")])
        )

    df = (df.join(type_labels, on=["session", "aid"], how="left")
            .select([pl.exclude("labels"),
                     pl.col("labels").fill_null(0)])
    )        
    return df

# %%
@noglobal(excepts=["cfg", "logger"])
def add_ground_truth_candidate(df, labels, type_):
    gt = labels[["session", f"{type_}_labels"]].dropna().copy()
    gt.columns = ["session", "aid"]
    gt = gt.explode("aid")
    df = pd.concat([df, gt])
    df = df.drop_duplicates()
    return df

# %%
@noglobal(excepts=["cfg", "logger"])
def under_sampling(df, label_col):
    cfg = Cfg()
    pos_df = df.filter(pl.col(label_col)==1)
    neg_df = df.filter(pl.col(label_col)==0)
    pos_n = pos_df.shape[0]
    return pl.concat([pos_df, neg_df.sample(pos_n * cfg.negative_sample, seed=cfg.seed)])

# %%
class Features:
    @noglobal(excepts=["cfg", "logger"])
    def __init__(self, sessions, candidate, week):
        self.sessions = cudf.from_pandas(sessions.to_pandas())
        self.output = candidate
        self.type_dict = cfg.type2id
        self.week = week
        self.latest_aid_n = 10

    @noglobal(excepts=["cfg", "logger"])
    def add_features(self):
        # self._prep()
        self._session_cnt()
        self._session_aid_nunique()
        self._session_last_type()
        self._aid_cnt()
        self._all_times_aid_features()
        self._w2v_vectors()
        self._relative_ts()
        self._add_aid_latest()
        self._co_visit_rank("co_visitation_matrix")
        self._co_visit_rank("co_visitation_matrix_time_weighted", "wt")
        self._co_visit_rank("co_visitation_matrix_type_weighted", "wt")
        self._co_visit_rank("co_visitation_matrix_clicks2carts")
        self._co_visit_rank("co_visitation_matrix_clicks2orders")
        self._latest_aid_w2v_sims()
        self._drop_aid_latest()
        self._clstr_rank()
        # self._session_mean_ts()
        # self._aid_mean_ts()
        # self._aid_cnt_ratio_at_session_last()
        # self.output = self.output.drop(columns=["session_last_day"]) # 日時はtrainセット内のみで有効なので削除

    @noglobal(excepts=["cfg", "logger"])
    def _prep(self):
        logger.info("[features] prep : start")
        # ts関連の前処理
        self.sessions["relative_ts"] = self.sessions["ts"] - self.sessions["ts"].min()
        self.sessions["dt"] = cudf.to_datetime(self.sessions["ts"], unit="ms")
        self.sessions["hour"] = self.sessions["dt"].dt.hour
        self.sessions["week"] = self.sessions["dt"].dt.dayofweek
        self.sessions["day"] = self.sessions["dt"].dt.day
        
    @noglobal(excepts=["cfg", "logger"])
    def _session_cnt(self):
        logger.info("[features] session_cnt : start")
        agg_df = self.sessions.groupby(["session", "type"])["ts"].count().reset_index().rename(columns={"ts": "cnt"})
        # session_total_cnt
        features = agg_df.groupby("session")["cnt"].sum().reset_index().rename(columns={"cnt": "session_total_cnt"})
        self.output = self.output.join(pl.from_pandas(features.to_pandas()), on=["session"], how="left")
        self.output = self.output.select([pl.exclude("session_total_cnt"), pl.col("session_total_cnt").fill_null(0)])
        # session_{type}_cnt
        for type_ in ["clicks", "carts", "orders"]:
            col_name = f"session_{type_}_cnt"
            features = agg_df[agg_df["type"]==type_].copy()
            features = features.rename(columns={"cnt": col_name})
            features = features[["session", col_name]].copy()
            self.output = self.output.join(pl.from_pandas(features.to_pandas()), on=["session"], how="left")
            self.output = self.output.select([pl.exclude(col_name), pl.col(col_name).fill_null(0)])
        
    @noglobal(excepts=["cfg", "logger"])
    def _session_aid_nunique(self):
        logger.info("[features] session_aid_nunique : start")
        features = self.sessions.groupby("session")["aid"].nunique().reset_index().rename(columns={"aid": "session_aid_nunique"})
        self.output = self.output.join(pl.from_pandas(features.to_pandas()), on=["session"], how="left")
        self.output = self.output.select([pl.exclude("session_aid_nunique"), pl.col("session_aid_nunique").fill_null(0)])
        
    @noglobal(excepts=["cfg", "logger"])
    def _session_last_type(self):
        logger.info("[features] session_last_type : start")
        features = self.sessions.groupby("session").nth(-1).reset_index()[["session", "type"]]
        features = features.rename(columns={"type": "session_last_type"})
        features["session_last_type"] = features["session_last_type"].map(self.type_dict)
        self.output = self.output.join(pl.from_pandas(features.to_pandas()), on=["session"], how="left")
        
    @noglobal(excepts=["cfg", "logger"])
    def _session_last_dt(self):
        logger.info("[features] session_last_dt : start")
        features = self.sessions.groupby("session").nth(-1).reset_index()[["session", "relative_ts", "week", "day", "hour"]]
        features.columns = ["session", "session_last_ts", "session_last_week", "session_last_day", "session_last_hour"]
        self.output = self.output.join(pl.from_pandas(features.to_pandas()), on=["session"], how="left")
        
    @noglobal(excepts=["cfg", "logger"])
    def _session_mean_ts(self):
        logger.info("[features] session_mean_ts : start")
        features = self.sessions.groupby("session")["relative_ts"].mean().reset_index().rename(columns={"relative_ts": "session_mean_ts"})
        self.output = self.output.join(pl.from_pandas(features.to_pandas()), on=["session"], how="left")
        
    @noglobal(excepts=["cfg", "logger"])
    def _aid_mean_ts(self):
        logger.info("[features] aid_mean_ts : start")
        features = self.sessions.groupby("aid")["relative_ts"].mean().reset_index().rename(columns={"relative_ts": "aid_mean_ts"})
        self.output = self.output.join(pl.from_pandas(features.to_pandas()), on=["aid"], how="left")
       
    @noglobal(excepts=["cfg", "logger"])
    def _aid_session_nunique(self):
        logger.info("[features] aid_session_unique : start")
        features = self.sessions.groupby("aid")["session"].nunique().reset_index().rename(columns={"session": "aid_session_nunique"})
        self.output = self.output.join(pl.from_pandas(features.to_pandas()), on=["aid"], how="left")

    @noglobal(excepts=["cfg", "logger"]) 
    def _aid_cnt_ratio_at_session_last(self):
        logger.info("[features] aid_cnt_ratio_atsession_last : start")
        for dt_ in ["week", "day", "hour"]:
            features = self.sessions[["aid", dt_]].copy()
            features["total_cnt"] = features.groupby(dt_)["aid"].transform("count")
            features = features.groupby(["aid", dt_])["total_cnt"].agg(["count", "max"]).reset_index()
            features[f"aid_cnt_ratio_at_session_last_{dt_}"] = features["count"] / features["max"]
            features = features.rename(columns={dt_: f"session_last_{dt_}"})
            self.output = self.output.join(pl.from_pandas(features[["aid", f"session_last_{dt_}", f"aid_cnt_ratio_at_session_last_{dt_}"]].to_pandas()), on=["aid", f"session_last_{dt_}"], how="left")
            self.output = self.output.select([pl.exclude(f"aid_cnt_ratio_at_session_last_{dt_}"), pl.col(f"aid_cnt_ratio_at_session_last_{dt_}").fill_null(0)])
        
    @noglobal(excepts=["cfg", "logger"])
    def _aid_cnt(self):
        logger.info("[features] aid_cnt : start")
        agg_df = self.sessions.groupby(["session", "aid", "type"])["ts"].count().reset_index().rename(columns={"ts": "cnt"})

        # aid_total_cnt
        features = agg_df.groupby(["session", "aid"])["cnt"].sum().reset_index().rename(columns={"cnt": "aid_total_cnt"})
        self.output = self.output.join(pl.from_pandas(features.to_pandas()), on=["session", "aid"], how="left")
        self.output = self.output.select([pl.exclude(f"aid_total_cnt"), pl.col(f"aid_total_cnt").fill_null(0)])

        # aid_{type}_cnt
        for type_ in ["clicks", "carts", "orders"]:
            col_name = f"aid_{type_}_cnt"
            logger.info(f"[features] {col_name} : start")
            features = agg_df[agg_df["type"]==type_].copy()
            features = features.rename(columns={"cnt": col_name})
            features = features[["session", "aid", col_name]].copy()
            self.output = self.output.join(pl.from_pandas(features.to_pandas()), on=["session", "aid"], how="left")
            self.output = self.output.select([pl.exclude(col_name), pl.col(col_name).fill_null(0)])

    @noglobal(excepts=["cfg", "logger"])
    def _all_times_aid_features(self):
        feats = ["all_times_aid_freq",
                 "all_times_aid_clicks_freq",
                 "all_times_aid_carts_freq",
                 "all_times_aid_orders_freq",
                 "all_times_aid_session_freq",
                 "all_times_aid_session_clicks_freq",
                 "all_times_aid_session_carts_freq",
                 "all_times_aid_session_orders_freq",
                 "all_times_aid_carts_ratio_with_clicks",
                 "all_times_aid_orders_ratio_with_clicks",
                 "all_times_aid_date_std",
                 "all_times_aid_hour_std",
                 "all_times_aid_day_of_week_std"]
        
        for feat in feats:
            logger.info(f"[features] {feat} : start")
            if self.week is None:
                with open(cfg.prep_dir + f"{feat}.pkl", "rb") as f:
                    feat_map = pickle.load(f)
            else:
                with open(cfg.prep_dir + f"{feat}_{self.week}.pkl", "rb") as f:
                    feat_map = pickle.load(f)

            feat_df = pl.DataFrame(
                [
                    pl.Series("aid", feat_map.keys(), dtype=pl.Int32),
                    pl.Series(feat, feat_map.values())
                ]
            )
            self.output = self.output.join(feat_df, on="aid", how="left")

    @noglobal(excepts=["cfg", "logger"])
    def _w2v_vectors(self):
        logger.info(f"[features] w2v_vectors : start")
        w2v_vecs = pl.read_parquet(cfg.prep_dir + "w2v_vector_n5.parquet")
        w2v_vecs = w2v_vecs.select(
            [
                pl.exclude("aid"),
                pl.col("aid").cast(pl.Int32)
            ]
        )
        self.output = self.output.join(w2v_vecs, on="aid", how="left")

    @noglobal(excepts=["cfg", "logger"])
    def _relative_ts(self):
        logger.info(f"[features] relative_ts : start")
        features = self.sessions.sort_values(["session", "ts"]).drop_duplicates(subset=["session", "aid"], keep="last")
        features["relative_ts_in_session"] = features.groupby("session")["ts"].transform("max") - features["ts"]
        features = features.sort_values(["session", "ts"], ascending=(True, False)).reset_index(drop=True)
        features["ts_rank_in_session"] = features.groupby("session").cumcount()
        features = features[["session", "aid", "relative_ts_in_session", "ts_rank_in_session"]]
        self.output = self.output.join(pl.from_pandas(features.to_pandas()), on=["session", "aid"], how="left")

    @noglobal(excepts=["cfg", "logger"])
    def _add_aid_latest(self):
        sorted_df = self.sessions.sort_values(["session", "ts"], ascending=(True, False), ignore_index=True)
        for i in range(self.latest_aid_n):
            latest_aid = sorted_df.groupby("session").nth(i)["aid"].reset_index().rename(columns={"aid": f"aid_latest{i}"})
            latest_aid[f"aid_latest{i}"] = latest_aid[f"aid_latest{i}"].astype("int32")
            self.output = self.output.join(pl.from_pandas(latest_aid.to_pandas()), on="session", how="left")
            self.output = self.output.select([pl.exclude(f"aid_latest{i}"), pl.col(f"aid_latest{i}").fill_null(-1)])
    
    @noglobal(excepts=["cfg", "logger"])
    def _drop_aid_latest(self):
        drop_cols = [f"aid_latest{str(i)}" for i in range(self.latest_aid_n)]
        self.output = self.output.select(pl.exclude(drop_cols))

    @noglobal(excepts=["cfg", "logger"])
    def _co_visit_rank(self, co_visit_name, wt_col="cnt"):
        logger.info(f"[features] co_visit_rank({co_visit_name}) : start")
        if self.week is None:
            co_visit_df = pl.read_parquet(cfg.prep_dir + f"{co_visit_name}.parquet")
        else:
            co_visit_df = pl.read_parquet(cfg.prep_dir + f"{co_visit_name}_{self.week}.parquet")

        co_visit_df = co_visit_df.select(
            [
                pl.col("aid_x").cast(pl.Int32),
                pl.col("aid_y").cast(pl.Int32),
                pl.col("rank").cast(pl.Int32)
            ]
        )

        for i in range(self.latest_aid_n):
            col_name = f"{co_visit_name}_lt{i}"
            logger.info(f"[features] co_visit_rank({col_name}) : start")
            self.output = self.output.join(co_visit_df, left_on=[f"aid_latest{i}", "aid"], right_on=["aid_x", "aid_y"], how="left")
            self.output = self.output.select([pl.exclude("rank"), pl.col("rank").fill_null(-1).alias(col_name)])

    @noglobal(excepts=["cfg", "logger"])
    def _clstr_rank(self):
        if self.week is None:
            session_clstr = pl.read_parquet(cfg.prep_dir + "w2v_session_cluster_c10000.parquet").select([pl.col("session").cast(pl.Int32), pl.col("clstr").cast(pl.Int32)])
            clstr_freq = pl.read_parquet(cfg.prep_dir + "w2v_cluster_freq_c10000.parquet").select([pl.col("clstr").cast(pl.Int32), pl.col("aid").cast(pl.Int32), pl.col("rank").cast(pl.Int32).alias("clstr_freq_rank")])
        else:
            session_clstr = pl.read_parquet(cfg.prep_dir + f"w2v_session_cluster_c10000_{self.week}.parquet").select([pl.col("session").cast(pl.Int32), pl.col("clstr").cast(pl.Int32)])
            clstr_freq = pl.read_parquet(cfg.prep_dir + f"w2v_cluster_freq_c10000_{self.week}.parquet").select([pl.col("clstr").cast(pl.Int32), pl.col("aid").cast(pl.Int32), pl.col("rank").cast(pl.Int32).alias("clstr_freq_rank")])

        self.output = self.output.join(session_clstr, on="session", how="left").join(clstr_freq, on=["clstr", "aid"], how="left")
        self.output = self.output.select(pl.exclude("clstr"))

    @noglobal(excepts=["cfg", "logger"])
    def _latest_aid_w2v_sims(self, vec_n=50):
        logger.info("[features] latest_aid_w2v_sims : start")
        w2v_vecs = pd.read_parquet(cfg.prep_dir + f"w2v_vector_n{vec_n}.parquet")
        w2v_cols = [f"w2v_{i}" for i in range(vec_n)]
        w2v_dict = {aid:vecs for aid, vecs in zip(w2v_vecs["aid"].tolist(), w2v_vecs[w2v_cols].values)}

        for i in range(self.latest_aid_n):
            sims = []
            for aid, latest_aid in tqdm(zip(self.output.get_column("aid").to_list(), self.output.get_column(f"aid_latest{i}").to_list()), total=len(self.output)):
                if latest_aid == -1:
                    sims.append(-1)
                else:
                    aid_vecs = w2v_dict[aid]
                    latest_aid_vecs = w2v_dict[latest_aid]
                    sim = np.dot(aid_vecs, latest_aid_vecs) / (np.linalg.norm(aid_vecs)*np.linalg.norm(latest_aid_vecs))
                    sims.append(sim)
            self.output = self.output.with_column(pl.Series(sims, dtype=pl.Float32).alias(f"w2v_sim_lt{i}"))

# %%
@noglobal(excepts=["cfg", "logger"])
def add_features(sessions, cand_df, week=None):
    feat = Features(sessions, cand_df, week)
    feat.add_features()
    return feat.output

# %%
@noglobal(excepts=["cfg", "logger"])
def make_cand_df(sessions, week, trans_maps=None):
    cand = Candidate(sessions, week)
    cand.add(strategy="repurchase", name="repurchase")
    cand.add(strategy="clstr_freq", name="clstr_freq", k=30)
    #cand.add(strategy="session_frequent", name="session_frequent", k=15)
    #cand.add(strategy="session_latest", name="session_latest", k=30)
    
    for i in range(20):
        cand.add(strategy="session_latest", trans_map=trans_maps[f"time_wt_pair{str(i)}"], name=f"session_latest_time_wt_pair{str(i)}", k=20)
        cand.add(strategy="session_latest", trans_map=trans_maps[f"word2vec_pair{str(i)}"], name=f"session_latest_word2vec_pair{str(i)}", k=20)
        cand.add(strategy="session_latest", trans_map=trans_maps[f"pair{str(i)}"], name=f"session_latest_pair{str(i)}", k=20)
        cand.add(strategy="session_latest", trans_map=trans_maps[f"type_wt_pair{str(i)}"], name=f"session_latest_type_wt_pair{str(i)}", k=20)
        cand.add(strategy="session_latest", trans_map=trans_maps[f"clicks2carts_pair{str(i)}"], name=f"session_latest_clicks2carts_pair{str(i)}", k=20)
        cand.add(strategy="session_latest", trans_map=trans_maps[f"clicks2orders_pair{str(i)}"], name=f"session_latest_clicks2orders_pair{str(i)}", k=20)

    return cand.get_dataframe()

# %%
@noglobal(excepts=["cfg", "logger"])
def get_pair_df(name, wt_col, week):
    if week is not None:
        name = f"{name}_{week}"
    return pl.read_parquet(cfg.prep_dir + f"{name}.parquet").sort(wt_col, reverse=True)

@noglobal(excepts=["cfg", "logger"])
def get_trans_maps(week=None):
    """
    aidを別のaidに置き換えるmapping辞書を取得する
    """
    trans_maps = {}

    pair_df_org = get_pair_df("co_visitation_matrix", "cnt", week)
    for i in range(20):
        pair_df = pair_df_org.groupby("aid_x").head(i+1)
        pair_dict = {k: v for k, v in zip(pair_df.get_column("aid_x").to_list(), pair_df.get_column("aid_y").to_list())}
        trans_maps[f"pair{str(i)}"] = pair_dict
    
    pair_df_org = get_pair_df("co_visitation_matrix_time_weighted", "wt", week)
    for i in range(20):
        pair_df = pair_df_org.groupby("aid_x").head(i+1)
        pair_dict = {k: v for k, v in zip(pair_df.get_column("aid_x").to_list(), pair_df.get_column("aid_y").to_list())}
        trans_maps[f"time_wt_pair{str(i)}"] = pair_dict

    pair_df_org = get_pair_df("co_visitation_matrix_type_weighted", "wt", week)
    for i in range(20):
        pair_df = pair_df_org.groupby("aid_x").head(i+1)
        pair_dict = {k: v for k, v in zip(pair_df.get_column("aid_x").to_list(), pair_df.get_column("aid_y").to_list())}
        trans_maps[f"type_wt_pair{str(i)}"] = pair_dict

    pair_df_org = get_pair_df("co_visitation_matrix_clicks2carts", "cnt", week)
    for i in range(20):
        pair_df = pair_df_org.groupby("aid_x").head(i+1)
        pair_dict = {k: v for k, v in zip(pair_df.get_column("aid_x").to_list(), pair_df.get_column("aid_y").to_list())}
        trans_maps[f"clicks2carts_pair{str(i)}"] = pair_dict

    pair_df_org = get_pair_df("co_visitation_matrix_clicks2orders", "cnt", week)
    for i in range(20):
        pair_df = pair_df_org.groupby("aid_x").head(i+1)
        pair_dict = {k: v for k, v in zip(pair_df.get_column("aid_x").to_list(), pair_df.get_column("aid_y").to_list())}
        trans_maps[f"clicks2orders_pair{str(i)}"] = pair_dict

    pair_df_org = get_pair_df("word2vec_similar", "sim", None)
    for i in range(20):
        pair_df = pair_df = pair_df_org.groupby("aid_x").head(i+1)
        pair_dict = {k: v for k, v in zip(pair_df.get_column("aid_x").to_list(), pair_df.get_column("aid_y").to_list())}
        trans_maps[f"word2vec_pair{str(i)}"] = pair_dict

    return trans_maps

# %%
@noglobal(excepts=["cfg", "logger", "cache"])
def make_train_data(type_):
    train_chunk_n = cfg.train_chunk_n_dict[type_]
    
    # データ読み込み
    week_sessions = pl.read_parquet(cfg.prep_dir + f"train_sessions_{cfg.train_week}.parquet")
    week_sessions = week_sessions.select([
        pl.col("session").cast(pl.Int32),
        pl.col("aid").cast(pl.Int32),
        pl.col("ts"),
        pl.col("type")
        ])
    
    week_labels = pl.read_parquet(cfg.prep_dir + f"labels_{cfg.train_week}.parquet")
    week_labels = (week_labels.select([
        pl.col("session").cast(pl.Int32),
        pl.col("clicks_labels").cast(pl.Int32),
        pl.col("carts_labels"),
        pl.col("orders_labels")])
        .filter(pl.col(f"{type_}_labels").is_not_null())
    )
    sessions_lists = np.array_split(week_labels.get_column("session").unique().to_list(), train_chunk_n)

    # cand作成
    cand_dfs = []
    cache_file = f"{type_}_train_cand.parquet"
    cache_path = cache.get_abspath(cache_file)
    if cache.exists(cache_path):
        logger.info(f"[{cache_file}] cache exists. read cache and skip process.")
        cand_df = pl.read_parquet(cache_path)
    else:
        train_chunk_n = cfg.train_chunk_n_dict[type_]
        trans_map_cache_file = f"trans_maps_{cfg.train_week}.pkl"
        trans_map_cache_path = cache.get_abspath(trans_map_cache_file)
        with open(trans_map_cache_path, "rb") as f:
            trans_maps = pickle.load(f)
        
        for chunk in range(train_chunk_n):
            use_sessions = list(sessions_lists[chunk])    
            # 候補選出
            week_sessions_chunk = week_sessions.filter(pl.col("session").is_in(use_sessions))
            cand_df_chunk = make_cand_df(week_sessions_chunk, cfg.train_week, trans_maps=trans_maps)

            # candラベル付け・サンプリング
            week_labels_chunk = week_labels.filter(pl.col("session").is_in(use_sessions))
            cand_df_chunk = add_labels(cand_df_chunk, week_labels_chunk, type_)
            cand_df_chunk = under_sampling(cand_df_chunk, "labels")
            cand_dfs.append(cand_df_chunk)
            del cand_df_chunk, week_labels_chunk, week_sessions_chunk
            gc.collect()
        cand_df = pl.concat(cand_dfs)
        del cand_dfs
        gc.collect()
        cand_df.write_parquet(cache_path)

    # データ確認
    pos_cnt = cand_df.filter(pl.col("labels")==1).shape[0]
    neg_cnt = cand_df.filter(pl.col("labels")==0).shape[0]
    logger.info(f"train({type_}) pos : {str(pos_cnt)}  neg : {str(neg_cnt)}")

    # 特徴量付与
    train = add_features(week_sessions, cand_df, cfg.train_week)
    del cand_df, week_sessions
    gc.collect()

    return train

# %%
@noglobal(excepts=["cfg", "logger", "cache"])
def make_valid_cand():
    # データ読み込み
    week_sessions = pl.read_parquet(cfg.prep_dir + f"train_sessions_{cfg.valid_week}.parquet")
    week_sessions = week_sessions.select([
        pl.col("session").cast(pl.Int32),
        pl.col("aid").cast(pl.Int32),
        pl.col("ts"),
        pl.col("type")
        ])
    
    week_labels = pl.read_parquet(cfg.prep_dir + f"labels_{cfg.valid_week}.parquet")
    week_labels = week_labels.select([
        pl.col("session").cast(pl.Int32),
        pl.col("clicks_labels").cast(pl.Int32),
        pl.col("carts_labels"),
        pl.col("orders_labels")
        ])
    valid_sessions = week_sessions.get_column("session").unique().to_list()
    
    trans_map_cache_file = f"trans_maps_{cfg.valid_week}.pkl"
    trans_map_cache_path = cache.get_abspath(trans_map_cache_file)
    with open(trans_map_cache_path, "rb") as f:
        trans_maps = pickle.load(f)

    # validに使うsessionを絞る
    use_session_n = min(cfg.valid_session_n, len(valid_sessions))
    random.seed(cfg.seed)
    use_sessions = random.sample(valid_sessions, use_session_n)
    week_sessions = week_sessions.filter(pl.col("session").is_in(use_sessions))
    week_labels = week_labels.filter(pl.col("session").is_in(use_sessions))

    # 候補選出
    cand_df = make_cand_df(week_sessions, cfg.valid_week, trans_maps=trans_maps)
    return cand_df, week_sessions, week_labels

# %%
@noglobal(excepts=["cfg", "logger"])
def make_valid_data(cand_df, week_sessions, week_labels, type_):
    # 特徴量付与
    valid = add_features(week_sessions, cand_df, cfg.valid_week)
    valid = add_labels(valid, week_labels, type_)

    # データ確認
    pos_cnt = valid.filter(pl.col("labels")==1).shape[0]
    neg_cnt = valid.filter(pl.col("labels")==0).shape[0]
    logger.info(f"valid({type_}) pos : {str(pos_cnt)}  neg : {str(neg_cnt)}")
    
    return valid

# %%
@noglobal(excepts=["cfg", "logger"])
def model_training(train, valid, features, target, valid_labels, type_):
    if type_ == "clicks":
        params = cfg.clicks_params
    elif type_ == "carts":
        params = cfg.carts_params
    elif type_ == "orders":
        params = cfg.orders_params

    train = train.to_pandas()
    valid = valid.to_pandas()
    valid_labels = valid_labels.to_pandas()

    # 学習
    vl_pred_df = valid[["session", "aid"]].copy()

    tr_x, tr_y = train[features], train[target]
    vl_x, vl_y = valid[features], valid[target]
    tr_data = lgb.Dataset(tr_x, label=tr_y)
    vl_data = lgb.Dataset(vl_x, label=vl_y)

    if os.path.exists(cfg.output_dir + f"{cfg.exp_name}/{type_}_model.lgb"):
        logger.info(f"[{type_}_model.lgb] cache exists. read cache and skip process.")
        model = lgb.Booster(model_file = cfg.output_dir + f"{cfg.exp_name}/{type_}_model.lgb")
    else:
        model = lgb.train(params, tr_data, valid_sets=[tr_data, vl_data],
                        num_boost_round=2000000, early_stopping_rounds=100, verbose_eval=100)

    # 特徴量重要度
    fi = pd.DataFrame()
    fi["feature"] = model.feature_name()
    fi["importance"] = model.feature_importance(importance_type="gain")

    # 2値分類の出力を元にk個選定
    vl_pred_df["prob"] = model.predict(vl_x, num_iteration=model.best_iteration)
    vl_pred_df = vl_pred_df.sort_values(["session", "prob"], ascending=(True, False))
    vl_pred_df = vl_pred_df.groupby(["session"]).head(cfg.k)
    vl_pred_df = vl_pred_df.groupby(["session"])["aid"].apply(list).reset_index()
    
    # 評価
    assert valid_labels["session"].tolist() == vl_pred_df["session"].unique().tolist()
    score = evaluate(valid_labels["clicks_labels"].tolist(),
                     valid_labels["carts_labels"].tolist(),
                     valid_labels["orders_labels"].tolist(),
                     vl_pred_df["aid"].tolist(),
                     vl_pred_df["aid"].tolist(),
                     vl_pred_df["aid"].tolist(),
                     cfg.k)
    logger.info(f"{type_} valid score")
    logger.info(score)

    # モデル保存
    model.save_model(cfg.output_dir + f"{cfg.exp_name}/{type_}_model.lgb")

    # 特徴量重要度
    fi_n = fi['feature'].nunique()
    order = list(fi.groupby("feature").mean().sort_values("importance", ascending=False).index)
    plt.figure(figsize=(10, fi_n*0.2))
    sns.barplot(x="importance", y="feature", data=fi, order=order)
    plt.title(f"LGBM importance({type_})")
    plt.tight_layout()
    plt.savefig(cfg.output_dir + f'{cfg.exp_name}/lgbm_importance_{type_}.png')
    return score[f"recall_{type_}"]

# %%
@noglobal(excepts=["cfg", "logger", "cache"])
def make_test_data():
    # testデータ作成
    test_sessions = pl.read_parquet(cfg.prep_dir + f"test_sessions.parquet")
    test_sessions = test_sessions.select(
        [
            pl.col("session").cast(pl.Int32),
            pl.col("aid").cast(pl.Int32),
            pl.col("ts"),
            pl.col("type")
        ]
    )
    sessions_lists = np.array_split(test_sessions.get_column("session").unique().to_list(), cfg.test_chunk_n)
    trans_map_cache_file = f"trans_maps.pkl"
    trans_map_cache_path = cache.get_abspath(trans_map_cache_file)
    with open(trans_map_cache_path, "rb") as f:
        trans_maps = pickle.load(f)

    for chunk in range(cfg.test_chunk_n):
        use_sessions = list(sessions_lists[chunk])
        cache_file = f"test_{chunk}.parquet"
        cache_path = cache.get_abspath(cache_file)
        if cache.exists(cache_path):
            logger.info(f"[{cache_file}] cache exists. read cache and skip process.")
        else:
            test_sessions_chunk = test_sessions.filter(pl.col("session").is_in(use_sessions))
            # 候補選出
            logger.info("[make_test] make_cand_df")
            cand_df = make_cand_df(test_sessions_chunk, None, trans_maps=trans_maps)
            # 特徴量付与
            logger.info("[make_test] add_features")
            test = add_features(test_sessions, cand_df)
            test.write_parquet(cache_path)

# %%
@noglobal(excepts=["cfg", "logger", "cache"])
def inference(features):
    pred_dfs = []
    for chunk in range(cfg.test_chunk_n):
        cache_file = f"test_{chunk}.parquet"
        cache_path = cache.get_abspath(cache_file)
        test = pl.read_parquet(cache_path).to_pandas()

        for type_ in ["clicks", "carts", "orders"]:    
            pred_df_tmp = test[["session", "aid"]].copy()
            # 推論
            model = lgb.Booster(model_file = cfg.output_dir + f"{cfg.exp_name}/{type_}_model.lgb")
            # 2値分類の出力を元にk個選定
            pred_df_tmp["prob"] = model.predict(test[features], num_iteration=model.best_iteration)
            pred_df_tmp = pred_df_tmp.sort_values(["session", "prob"], ascending=(True, False))
            pred_df_tmp = pred_df_tmp.groupby(["session"]).head(30)
            pred_df_tmp["aid"] = pred_df_tmp["aid"].astype(str)
            pred_df_tmp = pred_df_tmp.groupby(["session"])["aid"].apply(list).reset_index()
            pred_df_tmp["aid"] = pred_df_tmp["aid"].apply(lambda x: ' '.join(x))
            pred_df_tmp["type"] = type_
            pred_dfs.append(pred_df_tmp)
        del test, model
        gc.collect()
    
    pred_df = pd.concat(pred_dfs)
    # sub作成
    sub = pd.read_csv(cfg.input_dir + f"sample_submission.csv", usecols=["session_type"])
    pred_df["session_type"] = pred_df["session"].astype(str) + "_" + pred_df["type"]
    pred_df = pred_df.rename(columns={"aid": "labels"})
    sub = sub.merge(pred_df[["session_type", "labels"]], on="session_type", how="left")
    sub.to_csv(cfg.output_dir + f"{cfg.exp_name}/t88_{cfg.exp_name}_sub_k30.csv", index=False)

# %%
@noglobal(excepts=["cfg", "logger", "cache"])
def main():
    scores = {}
    logger.info(f"START")
    line_notify.send(f"{cfg.exp_name} | START")
    
    # trans_map作成
    weeks = [None, cfg.train_week, cfg.valid_week]
    for week in weeks:
        if week is None:
            cache_file = "trans_maps.pkl"
        else:    
            cache_file = f"trans_maps_{week}.pkl"
        cache_path = cache.get_abspath(cache_file)
        if cache.exists(cache_path):
            logger.info(f"[{cache_file}] cache exists. skip process.")
        else:
            trans_maps = get_trans_maps(week)
            with open(cache_path, "wb") as f:
                pickle.dump(trans_maps, f)

    for type_ in ["clicks", "carts", "orders"]:
        # train data作成
        logger.info(f"make {type_}_train_data")
        cache_file = f"{type_}_train.parquet"
        cache_path = cache.get_abspath(cache_file)
        if cache.exists(cache_path):
            logger.info(f"[{cache_file}] cache exists. read cache and skip process.")
            train = pl.read_parquet(cache_path)
        else:
            train = make_train_data(type_)
            train.write_parquet(cache_path)

        logger.info(f"make {type_}_valid_data")
        # valid cand作成
        cand_cache_path = cache.get_abspath("valid_cand.parquet")
        sessions_cache_path = cache.get_abspath("valid_sessions.parquet")
        labels_cache_path = cache.get_abspath("valid_labels.parquet")
        if cache.exists(cand_cache_path) & cache.exists(labels_cache_path) & cache.exists(sessions_cache_path):
            logger.info("[valid_cand.parquet] cache exists. read cache and skip process.")
            valid_cand = pl.read_parquet(cand_cache_path)
            valid_sessions = pl.read_parquet(sessions_cache_path)
            valid_labels = pl.read_parquet(labels_cache_path)
        else:
            valid_cand, valid_sessions, valid_labels = make_valid_cand()
            valid_cand.write_parquet(cand_cache_path)
            valid_sessions.write_parquet(sessions_cache_path)
            valid_labels.write_parquet(labels_cache_path)

        # valid data作成
        logger.info(f"make {type_}_valid_data")
        cache_file = f"{type_}_valid.parquet"
        cache_path = cache.get_abspath(cache_file)
        if cache.exists(cache_path):
            logger.info(f"[{cache_file}] cache exists. read cache and skip process.")
            valid = pl.read_parquet(cache_path)
        else:
            valid = make_valid_data(valid_cand, valid_sessions, valid_labels, type_)
            valid.write_parquet(cache_path)

        # モデル学習
        target = "labels"
        not_use_cols = ["session", "aid", target]
        features = [c for c in train.columns if c not in not_use_cols]

        scores[f"recall_{type_}"] = model_training(train, valid, features, target, valid_labels, type_)

        del train, valid, valid_labels
        gc.collect()
    
    scores["total"] = (float(scores["recall_clicks"]) * 0.1) + (float(scores["recall_carts"]) * 0.3) + (float(scores["recall_orders"]) * 0.6)
    report = f"\n{cfg.exp_name}\n"
    report += f'valid_end\n'
    report += str(scores)
    line_notify.send(report)

    # testデータ
    if cfg.run_inf:
        make_test_data()

        logger.info(f"-------- inference --------")
        inference(features)

    line_notify.send(f"{cfg.exp_name} | END!!")

# %%
try:
    main()
except Exception as e:
    logger.error(traceback.format_exc())
    line_notify.send(f"{cfg.exp_name} | ERROR!!\n{traceback.format_exc()}")
# Out:
# 0:00:00.755989 	 START
# 0:00:00.963086 	 [trans_maps.pkl] cache exists. skip process.
# 0:00:00.965507 	 [trans_maps_week3.pkl] cache exists. skip process.
# 0:00:00.968176 	 [trans_maps_week4.pkl] cache exists. skip process.
# 0:00:00.969102 	 make clicks_train_data
# 0:00:00.972014 	 [clicks_train.parquet] cache exists. read cache and skip process.
# 0:00:03.757818 	 make clicks_valid_data
# 0:00:41.112075 	 [add_candidate] repurchase : start
# 0:00:41.483756 	 [add_candidate] clstr_freq : start
# 0:00:45.042854 	 [add_candidate] session_latest_time_wt_pair0 : start
# 0:00:45.689632 	 [add_candidate] session_latest_word2vec_pair0 : start
# 0:00:46.230746 	 [add_candidate] session_latest_pair0 : start
# 0:00:46.729325 	 [add_candidate] session_latest_type_wt_pair0 : start
# 0:00:47.233375 	 [add_candidate] session_latest_clicks2carts_pair0 : start
# 0:00:47.678790 	 [add_candidate] session_latest_clicks2orders_pair0 : start
# 0:00:48.153081 	 [add_candidate] session_latest_time_wt_pair1 : start
# 0:00:48.651387 	 [add_candidate] session_latest_word2vec_pair1 : start
# 0:00:49.154315 	 [add_candidate] session_latest_pair1 : start
# 0:00:49.687597 	 [add_candidate] session_latest_type_wt_pair1 : start
# 0:00:50.149450 	 [add_candidate] session_latest_clicks2carts_pair1 : start
# 0:00:50.534620 	 [add_candidate] session_latest_clicks2orders_pair1 : start
# 0:00:50.857195 	 [add_candidate] session_latest_time_wt_pair2 : start
# 0:00:51.310911 	 [add_candidate] session_latest_word2vec_pair2 : start
# 0:00:51.771322 	 [add_candidate] session_latest_pair2 : start
# 0:00:52.226440 	 [add_candidate] session_latest_type_wt_pair2 : start
# 0:00:52.697298 	 [add_candidate] session_latest_clicks2carts_pair2 : start
# 0:00:53.083711 	 [add_candidate] session_latest_clicks2orders_pair2 : start
# 0:00:53.400412 	 [add_candidate] session_latest_time_wt_pair3 : start
# 0:00:53.893673 	 [add_candidate] session_latest_word2vec_pair3 : start
# 0:00:54.391364 	 [add_candidate] session_latest_pair3 : start
# 0:00:54.902029 	 [add_candidate] session_latest_type_wt_pair3 : start
# 0:00:55.420968 	 [add_candidate] session_latest_clicks2carts_pair3 : start
# 0:00:55.864584 	 [add_candidate] session_latest_clicks2orders_pair3 : start
# 0:00:56.242788 	 [add_candidate] session_latest_time_wt_pair4 : start
# 0:00:56.832805 	 [add_candidate] session_latest_word2vec_pair4 : start
# 0:00:57.354047 	 [add_candidate] session_latest_pair4 : start
# 0:00:57.894198 	 [add_candidate] session_latest_type_wt_pair4 : start
# 0:00:58.424898 	 [add_candidate] session_latest_clicks2carts_pair4 : start
# 0:00:58.891532 	 [add_candidate] session_latest_clicks2orders_pair4 : start
# 0:00:59.259562 	 [add_candidate] session_latest_time_wt_pair5 : start
# 0:00:59.735130 	 [add_candidate] session_latest_word2vec_pair5 : start
# 0:01:00.196574 	 [add_candidate] session_latest_pair5 : start
# 0:01:00.661886 	 [add_candidate] session_latest_type_wt_pair5 : start
# 0:01:01.134577 	 [add_candidate] session_latest_clicks2carts_pair5 : start
# 0:01:01.534792 	 [add_candidate] session_latest_clicks2orders_pair5 : start
# 0:01:01.857238 	 [add_candidate] session_latest_time_wt_pair6 : start
# 0:01:02.325873 	 [add_candidate] session_latest_word2vec_pair6 : start
# 0:01:02.808899 	 [add_candidate] session_latest_pair6 : start
# 0:01:03.320379 	 [add_candidate] session_latest_type_wt_pair6 : start
# 0:01:03.832576 	 [add_candidate] session_latest_clicks2carts_pair6 : start
# 0:01:04.283895 	 [add_candidate] session_latest_clicks2orders_pair6 : start
# 0:01:04.646742 	 [add_candidate] session_latest_time_wt_pair7 : start
# 0:01:05.151433 	 [add_candidate] session_latest_word2vec_pair7 : start
# 0:01:05.769112 	 [add_candidate] session_latest_pair7 : start
# 0:01:06.330908 	 [add_candidate] session_latest_type_wt_pair7 : start
# 0:01:06.880151 	 [add_candidate] session_latest_clicks2carts_pair7 : start
# 0:01:07.328174 	 [add_candidate] session_latest_clicks2orders_pair7 : start
# 0:01:07.710535 	 [add_candidate] session_latest_time_wt_pair8 : start
# 0:01:08.260783 	 [add_candidate] session_latest_word2vec_pair8 : start
# 0:01:08.791157 	 [add_candidate] session_latest_pair8 : start
# 0:01:09.332161 	 [add_candidate] session_latest_type_wt_pair8 : start
# 0:01:09.882226 	 [add_candidate] session_latest_clicks2carts_pair8 : start
# 0:01:10.365714 	 [add_candidate] session_latest_clicks2orders_pair8 : start
# 0:01:10.753070 	 [add_candidate] session_latest_time_wt_pair9 : start
# 0:01:11.278774 	 [add_candidate] session_latest_word2vec_pair9 : start
# 0:01:11.799691 	 [add_candidate] session_latest_pair9 : start
# 0:01:12.339700 	 [add_candidate] session_latest_type_wt_pair9 : start
# 0:01:12.927000 	 [add_candidate] session_latest_clicks2carts_pair9 : start
# 0:01:13.413742 	 [add_candidate] session_latest_clicks2orders_pair9 : start
# 0:01:13.826035 	 [add_candidate] session_latest_time_wt_pair10 : start
# 0:01:14.384101 	 [add_candidate] session_latest_word2vec_pair10 : start
# 0:01:14.952796 	 [add_candidate] session_latest_pair10 : start
# 0:01:15.513859 	 [add_candidate] session_latest_type_wt_pair10 : start
# 0:01:16.080093 	 [add_candidate] session_latest_clicks2carts_pair10 : start
# 0:01:16.556899 	 [add_candidate] session_latest_clicks2orders_pair10 : start
# 0:01:16.959751 	 [add_candidate] session_latest_time_wt_pair11 : start
# 0:01:17.518878 	 [add_candidate] session_latest_word2vec_pair11 : start
# 0:01:18.078543 	 [add_candidate] session_latest_pair11 : start
# 0:01:18.621855 	 [add_candidate] session_latest_type_wt_pair11 : start
# 0:01:19.150279 	 [add_candidate] session_latest_clicks2carts_pair11 : start
# 0:01:19.593351 	 [add_candidate] session_latest_clicks2orders_pair11 : start
# 0:01:19.953566 	 [add_candidate] session_latest_time_wt_pair12 : start
# 0:01:20.481411 	 [add_candidate] session_latest_word2vec_pair12 : start
# 0:01:21.089175 	 [add_candidate] session_latest_pair12 : start
# 0:01:21.611463 	 [add_candidate] session_latest_type_wt_pair12 : start
# 0:01:22.126117 	 [add_candidate] session_latest_clicks2carts_pair12 : start
# 0:01:22.557939 	 [add_candidate] session_latest_clicks2orders_pair12 : start
# 0:01:22.963048 	 [add_candidate] session_latest_time_wt_pair13 : start
# 0:01:23.533537 	 [add_candidate] session_latest_word2vec_pair13 : start
# 0:01:24.113950 	 [add_candidate] session_latest_pair13 : start
# 0:01:24.682503 	 [add_candidate] session_latest_type_wt_pair13 : start
# 0:01:25.250380 	 [add_candidate] session_latest_clicks2carts_pair13 : start
# 0:01:25.751260 	 [add_candidate] session_latest_clicks2orders_pair13 : start
# 0:01:26.127300 	 [add_candidate] session_latest_time_wt_pair14 : start
# 0:01:26.782858 	 [add_candidate] session_latest_word2vec_pair14 : start
# 0:01:27.301620 	 [add_candidate] session_latest_pair14 : start
# 0:01:27.775440 	 [add_candidate] session_latest_type_wt_pair14 : start
# 0:01:28.255738 	 [add_candidate] session_latest_clicks2carts_pair14 : start
# 0:01:28.655692 	 [add_candidate] session_latest_clicks2orders_pair14 : start
# 0:01:28.977629 	 [add_candidate] session_latest_time_wt_pair15 : start
# 0:01:29.460370 	 [add_candidate] session_latest_word2vec_pair15 : start
# 0:01:29.950465 	 [add_candidate] session_latest_pair15 : start
# 0:01:30.412343 	 [add_candidate] session_latest_type_wt_pair15 : start
# 0:01:30.898809 	 [add_candidate] session_latest_clicks2carts_pair15 : start
# 0:01:31.334577 	 [add_candidate] session_latest_clicks2orders_pair15 : start
# 0:01:31.700110 	 [add_candidate] session_latest_time_wt_pair16 : start
# 0:01:32.230955 	 [add_candidate] session_latest_word2vec_pair16 : start
# 0:01:32.746532 	 [add_candidate] session_latest_pair16 : start
# 0:01:33.251372 	 [add_candidate] session_latest_type_wt_pair16 : start
# 0:01:33.795288 	 [add_candidate] session_latest_clicks2carts_pair16 : start
# 0:01:34.298985 	 [add_candidate] session_latest_clicks2orders_pair16 : start
# 0:01:34.696055 	 [add_candidate] session_latest_time_wt_pair17 : start
# 0:01:35.252648 	 [add_candidate] session_latest_word2vec_pair17 : start
# 0:01:35.772186 	 [add_candidate] session_latest_pair17 : start
# 0:01:36.279768 	 [add_candidate] session_latest_type_wt_pair17 : start
# 0:01:36.879419 	 [add_candidate] session_latest_clicks2carts_pair17 : start
# 0:01:37.332074 	 [add_candidate] session_latest_clicks2orders_pair17 : start
# 0:01:37.722376 	 [add_candidate] session_latest_time_wt_pair18 : start
# 0:01:38.256582 	 [add_candidate] session_latest_word2vec_pair18 : start
# 0:01:38.802101 	 [add_candidate] session_latest_pair18 : start
# 0:01:39.332595 	 [add_candidate] session_latest_type_wt_pair18 : start
# 0:01:39.889344 	 [add_candidate] session_latest_clicks2carts_pair18 : start
# 0:01:40.347749 	 [add_candidate] session_latest_clicks2orders_pair18 : start
# 0:01:40.752107 	 [add_candidate] session_latest_time_wt_pair19 : start
# 0:01:41.276571 	 [add_candidate] session_latest_word2vec_pair19 : start
# 0:01:41.813340 	 [add_candidate] session_latest_pair19 : start
# 0:01:42.343225 	 [add_candidate] session_latest_type_wt_pair19 : start
# 0:01:42.919936 	 [add_candidate] session_latest_clicks2carts_pair19 : start
# 0:01:43.443859 	 [add_candidate] session_latest_clicks2orders_pair19 : start
# 0:01:53.725032 	 make clicks_valid_data
# 0:01:53.727592 	 [clicks_valid.parquet] cache exists. read cache and skip process.
# 0:02:04.331950 	 [clicks_model.lgb] cache exists. read cache and skip process.
# 0:03:35.149014 	 clicks valid score
# 0:03:35.150976 	 {'num_clicks': 97136, 'hit_clicks': 49397, 'num_carts': 43211, 'hit_carts': 14795, 'num_orders': 20082, 'hit_orders': 11085, 'recall_clicks': '0.508534', 'recall_carts': '0.342390', 'recall_orders': '0.551987', 'w_recall_clicks': '0.050853', 'w_recall_carts': '0.102717', 'w_recall_orders': '0.331192', 'score': '0.484762'}
# 0:03:36.308403 	 make carts_train_data
# 0:04:15.765573 	 [add_candidate] repurchase : start
# 0:04:19.337083 	 [add_candidate] clstr_freq : start
# 0:04:41.425295 	 [add_candidate] session_latest_time_wt_pair0 : start
# 0:04:44.455146 	 [add_candidate] session_latest_word2vec_pair0 : start
# 0:04:47.573621 	 [add_candidate] session_latest_pair0 : start
# 0:04:50.463762 	 [add_candidate] session_latest_type_wt_pair0 : start
# 0:04:53.475121 	 [add_candidate] session_latest_clicks2carts_pair0 : start
# 0:04:56.338260 	 [add_candidate] session_latest_clicks2orders_pair0 : start
# 0:04:58.998928 	 [add_candidate] session_latest_time_wt_pair1 : start
# 0:05:02.076692 	 [add_candidate] session_latest_word2vec_pair1 : start
# 0:05:05.289340 	 [add_candidate] session_latest_pair1 : start
# 0:05:08.347587 	 [add_candidate] session_latest_type_wt_pair1 : start
# 0:05:11.431786 	 [add_candidate] session_latest_clicks2carts_pair1 : start
# 0:05:14.448224 	 [add_candidate] session_latest_clicks2orders_pair1 : start
# 0:05:17.106689 	 [add_candidate] session_latest_time_wt_pair2 : start
# 0:05:20.192468 	 [add_candidate] session_latest_word2vec_pair2 : start
# 0:05:23.293718 	 [add_candidate] session_latest_pair2 : start
# 0:05:26.382514 	 [add_candidate] session_latest_type_wt_pair2 : start
# 0:05:29.414393 	 [add_candidate] session_latest_clicks2carts_pair2 : start
# 0:05:32.190572 	 [add_candidate] session_latest_clicks2orders_pair2 : start
# 0:05:34.728155 	 [add_candidate] session_latest_time_wt_pair3 : start
# 0:05:37.728877 	 [add_candidate] session_latest_word2vec_pair3 : start
# 0:05:40.818092 	 [add_candidate] session_latest_pair3 : start
# 0:05:44.028545 	 [add_candidate] session_latest_type_wt_pair3 : start
# 0:05:47.137005 	 [add_candidate] session_latest_clicks2carts_pair3 : start
# 0:05:50.130606 	 [add_candidate] session_latest_clicks2orders_pair3 : start
# 0:05:52.783740 	 [add_candidate] session_latest_time_wt_pair4 : start
# 0:05:55.966213 	 [add_candidate] session_latest_word2vec_pair4 : start
# 0:05:59.141068 	 [add_candidate] session_latest_pair4 : start
# 0:06:02.160087 	 [add_candidate] session_latest_type_wt_pair4 : start
# 0:06:05.298946 	 [add_candidate] session_latest_clicks2carts_pair4 : start
# 0:06:08.282886 	 [add_candidate] session_latest_clicks2orders_pair4 : start
# 0:06:10.953230 	 [add_candidate] session_latest_time_wt_pair5 : start
# 0:06:14.121781 	 [add_candidate] session_latest_word2vec_pair5 : start
# 0:06:17.302528 	 [add_candidate] session_latest_pair5 : start
# 0:06:20.403611 	 [add_candidate] session_latest_type_wt_pair5 : start
# 0:06:23.677102 	 [add_candidate] session_latest_clicks2carts_pair5 : start
# 0:06:26.648908 	 [add_candidate] session_latest_clicks2orders_pair5 : start
# 0:06:29.338680 	 [add_candidate] session_latest_time_wt_pair6 : start
# 0:06:32.425774 	 [add_candidate] session_latest_word2vec_pair6 : start
# 0:06:35.627250 	 [add_candidate] session_latest_pair6 : start
# 0:06:38.799514 	 [add_candidate] session_latest_type_wt_pair6 : start
# 0:06:41.982224 	 [add_candidate] session_latest_clicks2carts_pair6 : start
# 0:06:45.129787 	 [add_candidate] session_latest_clicks2orders_pair6 : start
# 0:06:47.773589 	 [add_candidate] session_latest_time_wt_pair7 : start
# 0:06:50.964997 	 [add_candidate] session_latest_word2vec_pair7 : start
# 0:06:54.254296 	 [add_candidate] session_latest_pair7 : start
# 0:06:57.367549 	 [add_candidate] session_latest_type_wt_pair7 : start
# 0:07:00.391734 	 [add_candidate] session_latest_clicks2carts_pair7 : start
# 0:07:03.451963 	 [add_candidate] session_latest_clicks2orders_pair7 : start
# 0:07:06.131874 	 [add_candidate] session_latest_time_wt_pair8 : start
# 0:07:09.248498 	 [add_candidate] session_latest_word2vec_pair8 : start
# 0:07:12.416793 	 [add_candidate] session_latest_pair8 : start
# 0:07:15.608896 	 [add_candidate] session_latest_type_wt_pair8 : start
# 0:07:18.942024 	 [add_candidate] session_latest_clicks2carts_pair8 : start
# 0:07:21.978797 	 [add_candidate] session_latest_clicks2orders_pair8 : start
# 0:07:24.711621 	 [add_candidate] session_latest_time_wt_pair9 : start
# 0:07:27.880358 	 [add_candidate] session_latest_word2vec_pair9 : start
# 0:07:31.004878 	 [add_candidate] session_latest_pair9 : start
# 0:07:34.220739 	 [add_candidate] session_latest_type_wt_pair9 : start
# 0:07:37.533337 	 [add_candidate] session_latest_clicks2carts_pair9 : start
# 0:07:40.486604 	 [add_candidate] session_latest_clicks2orders_pair9 : start
# 0:07:43.121977 	 [add_candidate] session_latest_time_wt_pair10 : start
# 0:07:46.217562 	 [add_candidate] session_latest_word2vec_pair10 : start
# 0:07:49.377183 	 [add_candidate] session_latest_pair10 : start
# 0:07:52.502510 	 [add_candidate] session_latest_type_wt_pair10 : start
# 0:07:55.698902 	 [add_candidate] session_latest_clicks2carts_pair10 : start
# 0:07:58.648339 	 [add_candidate] session_latest_clicks2orders_pair10 : start
# 0:08:01.358299 	 [add_candidate] session_latest_time_wt_pair11 : start
# 0:08:04.586763 	 [add_candidate] session_latest_word2vec_pair11 : start
# 0:08:07.796148 	 [add_candidate] session_latest_pair11 : start
# 0:08:11.071374 	 [add_candidate] session_latest_type_wt_pair11 : start
# 0:08:14.292059 	 [add_candidate] session_latest_clicks2carts_pair11 : start
# 0:08:17.324850 	 [add_candidate] session_latest_clicks2orders_pair11 : start
# 0:08:19.951927 	 [add_candidate] session_latest_time_wt_pair12 : start
# 0:08:23.145995 	 [add_candidate] session_latest_word2vec_pair12 : start
# 0:08:26.351326 	 [add_candidate] session_latest_pair12 : start
# 0:08:29.649281 	 [add_candidate] session_latest_type_wt_pair12 : start
# 0:08:32.886309 	 [add_candidate] session_latest_clicks2carts_pair12 : start
# 0:08:35.965616 	 [add_candidate] session_latest_clicks2orders_pair12 : start
# 0:08:38.732559 	 [add_candidate] session_latest_time_wt_pair13 : start
# 0:08:42.000818 	 [add_candidate] session_latest_word2vec_pair13 : start
# 0:08:45.344226 	 [add_candidate] session_latest_pair13 : start
# 0:08:48.676866 	 [add_candidate] session_latest_type_wt_pair13 : start
# 0:08:51.984686 	 [add_candidate] session_latest_clicks2carts_pair13 : start
# 0:08:54.971097 	 [add_candidate] session_latest_clicks2orders_pair13 : start
# 0:08:57.777842 	 [add_candidate] session_latest_time_wt_pair14 : start
# 0:09:00.940714 	 [add_candidate] session_latest_word2vec_pair14 : start
# 0:09:04.154122 	 [add_candidate] session_latest_pair14 : start
# 0:09:07.416814 	 [add_candidate] session_latest_type_wt_pair14 : start
# 0:09:10.650435 	 [add_candidate] session_latest_clicks2carts_pair14 : start
# 0:09:13.687727 	 [add_candidate] session_latest_clicks2orders_pair14 : start
# 0:09:16.272753 	 [add_candidate] session_latest_time_wt_pair15 : start
# 0:09:19.426901 	 [add_candidate] session_latest_word2vec_pair15 : start
# 0:09:22.541131 	 [add_candidate] session_latest_pair15 : start
# 0:09:25.701613 	 [add_candidate] session_latest_type_wt_pair15 : start
# 0:09:28.949358 	 [add_candidate] session_latest_clicks2carts_pair15 : start
# 0:09:31.930892 	 [add_candidate] session_latest_clicks2orders_pair15 : start
# 0:09:34.640897 	 [add_candidate] session_latest_time_wt_pair16 : start
# 0:09:37.954747 	 [add_candidate] session_latest_word2vec_pair16 : start
# 0:09:41.450494 	 [add_candidate] session_latest_pair16 : start
# 0:09:44.567168 	 [add_candidate] session_latest_type_wt_pair16 : start
# 0:09:47.810232 	 [add_candidate] session_latest_clicks2carts_pair16 : start
# 0:09:50.887470 	 [add_candidate] session_latest_clicks2orders_pair16 : start
# 0:09:53.561644 	 [add_candidate] session_latest_time_wt_pair17 : start
# 0:09:56.773125 	 [add_candidate] session_latest_word2vec_pair17 : start
# 0:09:59.962353 	 [add_candidate] session_latest_pair17 : start
# 0:10:03.257163 	 [add_candidate] session_latest_type_wt_pair17 : start
# 0:10:06.385945 	 [add_candidate] session_latest_clicks2carts_pair17 : start
# 0:10:09.420417 	 [add_candidate] session_latest_clicks2orders_pair17 : start
# 0:10:12.092264 	 [add_candidate] session_latest_time_wt_pair18 : start
# 0:10:15.230600 	 [add_candidate] session_latest_word2vec_pair18 : start
# 0:10:18.461472 	 [add_candidate] session_latest_pair18 : start
# 0:10:21.636851 	 [add_candidate] session_latest_type_wt_pair18 : start
# 0:10:24.834446 	 [add_candidate] session_latest_clicks2carts_pair18 : start
# 0:10:27.836948 	 [add_candidate] session_latest_clicks2orders_pair18 : start
# 0:10:30.505508 	 [add_candidate] session_latest_time_wt_pair19 : start
# 0:10:33.699972 	 [add_candidate] session_latest_word2vec_pair19 : start
# 0:10:36.931571 	 [add_candidate] session_latest_pair19 : start
# 0:10:40.210155 	 [add_candidate] session_latest_type_wt_pair19 : start
# 0:10:43.461920 	 [add_candidate] session_latest_clicks2carts_pair19 : start
# 0:10:46.433959 	 [add_candidate] session_latest_clicks2orders_pair19 : start
# 0:13:26.757606 	 train(carts) pos : 922342  neg : 922342
# 0:13:31.193646 	 [features] session_cnt : start
# 0:13:32.460349 	 [features] session_aid_nunique : start
# 0:13:32.959209 	 [features] session_last_type : start
# 0:13:33.501100 	 [features] aid_cnt : start
# 0:13:35.271790 	 [features] aid_clicks_cnt : start
# 0:13:36.908025 	 [features] aid_carts_cnt : start
# 0:13:37.137624 	 [features] aid_orders_cnt : start
# 0:13:37.255363 	 [features] all_times_aid_freq : start
# 0:13:37.820511 	 [features] all_times_aid_clicks_freq : start
# 0:13:38.383621 	 [features] all_times_aid_carts_freq : start
# 0:13:38.726550 	 [features] all_times_aid_orders_freq : start
# 0:13:38.928704 	 [features] all_times_aid_session_freq : start
# 0:13:39.486203 	 [features] all_times_aid_session_clicks_freq : start
# 0:13:40.060220 	 [features] all_times_aid_session_carts_freq : start
# 0:13:40.404694 	 [features] all_times_aid_session_orders_freq : start
# 0:13:40.605505 	 [features] all_times_aid_carts_ratio_with_clicks : start
# 0:13:41.247447 	 [features] all_times_aid_orders_ratio_with_clicks : start
# 0:13:41.988288 	 [features] all_times_aid_date_std : start
# 0:13:42.666216 	 [features] all_times_aid_hour_std : start
# 0:13:43.344177 	 [features] all_times_aid_day_of_week_std : start
# 0:13:44.053580 	 [features] w2v_vectors : start
# 0:13:44.827212 	 [features] relative_ts : start
# 0:13:50.001672 	 [features] co_visit_rank(co_visitation_matrix) : start
# 0:14:11.859880 	 [features] co_visit_rank(co_visitation_matrix_lt0) : start
# 0:14:35.081075 	 [features] co_visit_rank(co_visitation_matrix_lt1) : start
# 0:14:58.635117 	 [features] co_visit_rank(co_visitation_matrix_lt2) : start
# 0:15:21.852659 	 [features] co_visit_rank(co_visitation_matrix_lt3) : start
# 0:15:44.741311 	 [features] co_visit_rank(co_visitation_matrix_lt4) : start
# 0:16:08.281043 	 [features] co_visit_rank(co_visitation_matrix_lt5) : start
# 0:16:31.967769 	 [features] co_visit_rank(co_visitation_matrix_lt6) : start
# 0:16:56.203315 	 [features] co_visit_rank(co_visitation_matrix_lt7) : start
# 0:17:19.572667 	 [features] co_visit_rank(co_visitation_matrix_lt8) : start
# 0:17:42.628459 	 [features] co_visit_rank(co_visitation_matrix_lt9) : start
# 0:18:06.670592 	 [features] co_visit_rank(co_visitation_matrix_time_weighted) : start
# 0:18:57.477027 	 [features] co_visit_rank(co_visitation_matrix_time_weighted_lt0) : start
# 0:19:51.015734 	 [features] co_visit_rank(co_visitation_matrix_time_weighted_lt1) : start
# 0:20:40.797749 	 [features] co_visit_rank(co_visitation_matrix_time_weighted_lt2) : start
# 0:21:33.793094 	 [features] co_visit_rank(co_visitation_matrix_time_weighted_lt3) : start
# 0:22:22.381499 	 [features] co_visit_rank(co_visitation_matrix_time_weighted_lt4) : start
# 0:23:12.763256 	 [features] co_visit_rank(co_visitation_matrix_time_weighted_lt5) : start
# 0:24:01.092780 	 [features] co_visit_rank(co_visitation_matrix_time_weighted_lt6) : start
# 0:24:49.045993 	 [features] co_visit_rank(co_visitation_matrix_time_weighted_lt7) : start
# 0:25:38.031860 	 [features] co_visit_rank(co_visitation_matrix_time_weighted_lt8) : start
# 0:26:26.349119 	 [features] co_visit_rank(co_visitation_matrix_time_weighted_lt9) : start
# 0:27:14.696295 	 [features] co_visit_rank(co_visitation_matrix_type_weighted) : start
# 0:27:47.795016 	 [features] co_visit_rank(co_visitation_matrix_type_weighted_lt0) : start
# 0:28:42.343364 	 [features] co_visit_rank(co_visitation_matrix_type_weighted_lt1) : start
# 0:29:33.565502 	 [features] co_visit_rank(co_visitation_matrix_type_weighted_lt2) : start
# 0:30:24.615785 	 [features] co_visit_rank(co_visitation_matrix_type_weighted_lt3) : start
# 0:31:15.016963 	 [features] co_visit_rank(co_visitation_matrix_type_weighted_lt4) : start
# 0:32:05.839871 	 [features] co_visit_rank(co_visitation_matrix_type_weighted_lt5) : start
# 0:32:56.717555 	 [features] co_visit_rank(co_visitation_matrix_type_weighted_lt6) : start
# 0:33:48.233235 	 [features] co_visit_rank(co_visitation_matrix_type_weighted_lt7) : start
# 0:34:39.804810 	 [features] co_visit_rank(co_visitation_matrix_type_weighted_lt8) : start
# 0:35:31.635500 	 [features] co_visit_rank(co_visitation_matrix_type_weighted_lt9) : start
# 0:36:24.220284 	 [features] co_visit_rank(co_visitation_matrix_clicks2carts) : start
# 0:36:27.846169 	 [features] co_visit_rank(co_visitation_matrix_clicks2carts_lt0) : start
# 0:36:29.377320 	 [features] co_visit_rank(co_visitation_matrix_clicks2carts_lt1) : start
# 0:36:30.980454 	 [features] co_visit_rank(co_visitation_matrix_clicks2carts_lt2) : start
# 0:36:32.387565 	 [features] co_visit_rank(co_visitation_matrix_clicks2carts_lt3) : start
# 0:36:33.669444 	 [features] co_visit_rank(co_visitation_matrix_clicks2carts_lt4) : start
# 0:36:34.927113 	 [features] co_visit_rank(co_visitation_matrix_clicks2carts_lt5) : start
# 0:36:36.211265 	 [features] co_visit_rank(co_visitation_matrix_clicks2carts_lt6) : start
# 0:36:37.518554 	 [features] co_visit_rank(co_visitation_matrix_clicks2carts_lt7) : start
# 0:36:38.779228 	 [features] co_visit_rank(co_visitation_matrix_clicks2carts_lt8) : start
# 0:36:40.026032 	 [features] co_visit_rank(co_visitation_matrix_clicks2carts_lt9) : start
# 0:36:41.246515 	 [features] co_visit_rank(co_visitation_matrix_clicks2orders) : start
# 0:36:42.150029 	 [features] co_visit_rank(co_visitation_matrix_clicks2orders_lt0) : start
# 0:36:42.467167 	 [features] co_visit_rank(co_visitation_matrix_clicks2orders_lt1) : start
# 0:36:42.765613 	 [features] co_visit_rank(co_visitation_matrix_clicks2orders_lt2) : start
# 0:36:43.053027 	 [features] co_visit_rank(co_visitation_matrix_clicks2orders_lt3) : start
# 0:36:43.350470 	 [features] co_visit_rank(co_visitation_matrix_clicks2orders_lt4) : start
# 0:36:43.633966 	 [features] co_visit_rank(co_visitation_matrix_clicks2orders_lt5) : start
# 0:36:43.922446 	 [features] co_visit_rank(co_visitation_matrix_clicks2orders_lt6) : start
# 0:36:44.221351 	 [features] co_visit_rank(co_visitation_matrix_clicks2orders_lt7) : start
# 0:36:44.517159 	 [features] co_visit_rank(co_visitation_matrix_clicks2orders_lt8) : start
# 0:36:44.811859 	 [features] co_visit_rank(co_visitation_matrix_clicks2orders_lt9) : start
# 0:36:45.125906 	 [features] latest_aid_w2v_sims : start
# 100%|██████████| 1844684/1844684 [00:17<00:00, 103936.60it/s]
# 100%|██████████| 1844684/1844684 [00:15<00:00, 116938.14it/s]
# 100%|██████████| 1844684/1844684 [00:14<00:00, 128249.18it/s]
# 100%|██████████| 1844684/1844684 [00:13<00:00, 138169.41it/s]
# 100%|██████████| 1844684/1844684 [00:12<00:00, 148185.93it/s]
# 100%|██████████| 1844684/1844684 [00:11<00:00, 157904.62it/s]
# 100%|██████████| 1844684/1844684 [00:10<00:00, 168249.79it/s]
# 100%|██████████| 1844684/1844684 [00:10<00:00, 176543.45it/s]
# 100%|██████████| 1844684/1844684 [00:09<00:00, 188029.05it/s]
# 100%|██████████| 1844684/1844684 [00:09<00:00, 197529.84it/s]
# 0:39:47.174043 	 make carts_valid_data
# 0:39:47.186495 	 [valid_cand.parquet] cache exists. read cache and skip process.
# 0:39:48.564188 	 make carts_valid_data
# 0:39:48.601787 	 [features] session_cnt : start
# 0:39:50.389693 	 [features] session_aid_nunique : start
# 0:39:50.814153 	 [features] session_last_type : start
# 0:39:51.090988 	 [features] aid_cnt : start
# 0:39:51.786088 	 [features] aid_clicks_cnt : start
# 0:39:52.410926 	 [features] aid_carts_cnt : start
# 0:39:52.909928 	 [features] aid_orders_cnt : start
# 0:39:53.406164 	 [features] all_times_aid_freq : start
# 0:39:54.471653 	 [features] all_times_aid_clicks_freq : start
# 0:39:55.472481 	 [features] all_times_aid_carts_freq : start
# 0:39:56.045678 	 [features] all_times_aid_orders_freq : start
# 0:39:56.467134 	 [features] all_times_aid_session_freq : start
# 0:39:57.304151 	 [features] all_times_aid_session_clicks_freq : start
# 0:39:58.196484 	 [features] all_times_aid_session_carts_freq : start
# 0:39:58.749399 	 [features] all_times_aid_session_orders_freq : start
# 0:39:59.165591 	 [features] all_times_aid_carts_ratio_with_clicks : start
# 0:40:00.060501 	 [features] all_times_aid_orders_ratio_with_clicks : start
# 0:40:00.949373 	 [features] all_times_aid_date_std : start
# 0:40:01.836269 	 [features] all_times_aid_hour_std : start
# 0:40:02.709113 	 [features] all_times_aid_day_of_week_std : start
# 0:40:03.606612 	 [features] w2v_vectors : start
# 0:40:04.226376 	 [features] relative_ts : start
# 0:40:09.414384 	 [features] co_visit_rank(co_visitation_matrix) : start
# 0:40:30.707239 	 [features] co_visit_rank(co_visitation_matrix_lt0) : start
# 0:40:54.641995 	 [features] co_visit_rank(co_visitation_matrix_lt1) : start
# 0:41:19.070912 	 [features] co_visit_rank(co_visitation_matrix_lt2) : start
# 0:41:43.076497 	 [features] co_visit_rank(co_visitation_matrix_lt3) : start
# 0:42:06.703605 	 [features] co_visit_rank(co_visitation_matrix_lt4) : start
# 0:42:30.266530 	 [features] co_visit_rank(co_visitation_matrix_lt5) : start
# 0:42:53.737569 	 [features] co_visit_rank(co_visitation_matrix_lt6) : start
# 0:43:17.119972 	 [features] co_visit_rank(co_visitation_matrix_lt7) : start
# 0:43:40.734390 	 [features] co_visit_rank(co_visitation_matrix_lt8) : start
# 0:44:04.374821 	 [features] co_visit_rank(co_visitation_matrix_lt9) : start
# 0:44:27.811488 	 [features] co_visit_rank(co_visitation_matrix_time_weighted) : start
# 0:45:24.787141 	 [features] co_visit_rank(co_visitation_matrix_time_weighted_lt0) : start
# 0:46:14.913668 	 [features] co_visit_rank(co_visitation_matrix_time_weighted_lt1) : start
# 0:47:05.732381 	 [features] co_visit_rank(co_visitation_matrix_time_weighted_lt2) : start
# 0:47:55.791008 	 [features] co_visit_rank(co_visitation_matrix_time_weighted_lt3) : start
# 0:48:45.155348 	 [features] co_visit_rank(co_visitation_matrix_time_weighted_lt4) : start
# 0:49:36.110667 	 [features] co_visit_rank(co_visitation_matrix_time_weighted_lt5) : start
# 0:50:25.796703 	 [features] co_visit_rank(co_visitation_matrix_time_weighted_lt6) : start
# 0:51:16.475970 	 [features] co_visit_rank(co_visitation_matrix_time_weighted_lt7) : start
# 0:52:05.829413 	 [features] co_visit_rank(co_visitation_matrix_time_weighted_lt8) : start
# 0:52:55.280822 	 [features] co_visit_rank(co_visitation_matrix_time_weighted_lt9) : start
# 0:53:45.292481 	 [features] co_visit_rank(co_visitation_matrix_type_weighted) : start
# 0:54:25.021119 	 [features] co_visit_rank(co_visitation_matrix_type_weighted_lt0) : start
# 0:55:20.916610 	 [features] co_visit_rank(co_visitation_matrix_type_weighted_lt1) : start
# 0:56:12.991937 	 [features] co_visit_rank(co_visitation_matrix_type_weighted_lt2) : start
# 0:57:04.072695 	 [features] co_visit_rank(co_visitation_matrix_type_weighted_lt3) : start
# 0:57:55.553517 	 [features] co_visit_rank(co_visitation_matrix_type_weighted_lt4) : start
# 0:58:46.181749 	 [features] co_visit_rank(co_visitation_matrix_type_weighted_lt5) : start
# 0:59:37.323734 	 [features] co_visit_rank(co_visitation_matrix_type_weighted_lt6) : start
# 1:00:31.002785 	 [features] co_visit_rank(co_visitation_matrix_type_weighted_lt7) : start
# 1:01:24.718811 	 [features] co_visit_rank(co_visitation_matrix_type_weighted_lt8) : start
# 1:02:17.570364 	 [features] co_visit_rank(co_visitation_matrix_type_weighted_lt9) : start
# 1:03:11.329652 	 [features] co_visit_rank(co_visitation_matrix_clicks2carts) : start
# 1:03:14.819147 	 [features] co_visit_rank(co_visitation_matrix_clicks2carts_lt0) : start
# 1:03:16.956043 	 [features] co_visit_rank(co_visitation_matrix_clicks2carts_lt1) : start
# 1:03:18.966320 	 [features] co_visit_rank(co_visitation_matrix_clicks2carts_lt2) : start
# 1:03:20.859285 	 [features] co_visit_rank(co_visitation_matrix_clicks2carts_lt3) : start
# 1:03:22.758968 	 [features] co_visit_rank(co_visitation_matrix_clicks2carts_lt4) : start
# 1:03:24.630134 	 [features] co_visit_rank(co_visitation_matrix_clicks2carts_lt5) : start
# 1:03:26.466091 	 [features] co_visit_rank(co_visitation_matrix_clicks2carts_lt6) : start
# 1:03:28.289644 	 [features] co_visit_rank(co_visitation_matrix_clicks2carts_lt7) : start
# 1:03:30.136924 	 [features] co_visit_rank(co_visitation_matrix_clicks2carts_lt8) : start
# 1:03:31.941628 	 [features] co_visit_rank(co_visitation_matrix_clicks2carts_lt9) : start
# 1:03:33.752687 	 [features] co_visit_rank(co_visitation_matrix_clicks2orders) : start
# 1:03:34.703790 	 [features] co_visit_rank(co_visitation_matrix_clicks2orders_lt0) : start
# 1:03:35.573498 	 [features] co_visit_rank(co_visitation_matrix_clicks2orders_lt1) : start
# 1:03:36.381266 	 [features] co_visit_rank(co_visitation_matrix_clicks2orders_lt2) : start
# 1:03:37.184285 	 [features] co_visit_rank(co_visitation_matrix_clicks2orders_lt3) : start
# 1:03:37.964154 	 [features] co_visit_rank(co_visitation_matrix_clicks2orders_lt4) : start
# 1:03:38.759302 	 [features] co_visit_rank(co_visitation_matrix_clicks2orders_lt5) : start
# 1:03:39.560615 	 [features] co_visit_rank(co_visitation_matrix_clicks2orders_lt6) : start
# 1:03:40.331290 	 [features] co_visit_rank(co_visitation_matrix_clicks2orders_lt7) : start
# 1:03:41.126919 	 [features] co_visit_rank(co_visitation_matrix_clicks2orders_lt8) : start
# 1:03:41.901881 	 [features] co_visit_rank(co_visitation_matrix_clicks2orders_lt9) : start
# 1:03:42.667839 	 [features] latest_aid_w2v_sims : start
# 100%|██████████| 18710489/18710489 [03:00<00:00, 103462.26it/s]
# 100%|██████████| 18710489/18710489 [02:32<00:00, 123083.94it/s]
# 100%|██████████| 18710489/18710489 [02:12<00:00, 141085.01it/s]
# 100%|██████████| 18710489/18710489 [02:03<00:00, 151994.76it/s]
# 100%|██████████| 18710489/18710489 [01:55<00:00, 162685.58it/s]
# 100%|██████████| 18710489/18710489 [01:48<00:00, 172862.46it/s]
# 100%|██████████| 18710489/18710489 [01:39<00:00, 187470.68it/s]
# 100%|██████████| 18710489/18710489 [01:33<00:00, 199992.22it/s]
# 100%|██████████| 18710489/18710489 [01:28<00:00, 212227.95it/s]
# 100%|██████████| 18710489/18710489 [01:22<00:00, 225779.87it/s]
# 1:23:43.258098 	 valid(carts) pos : 20306  neg : 18690183
# /home/kaggler/.local/lib/python3.8/site-packages/lightgbm/engine.py:181: UserWarning: 'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. Pass 'early_stopping()' callback via 'callbacks' argument instead.
#   _log_warning("'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. "
# /home/kaggler/.local/lib/python3.8/site-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# [LightGBM] [Info] Number of positive: 922342, number of negative: 922342
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.325107 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 21303
# [LightGBM] [Info] Number of data points in the train set: 1844684, number of used features: 91
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500000 -> initscore=0.000000
# Training until validation scores don't improve for 100 rounds
# [100]	training's binary_logloss: 0.303327	valid_1's binary_logloss: 0.327088
# [200]	training's binary_logloss: 0.291357	valid_1's binary_logloss: 0.323747
# [300]	training's binary_logloss: 0.283404	valid_1's binary_logloss: 0.32287
# [400]	training's binary_logloss: 0.276866	valid_1's binary_logloss: 0.322779
# [500]	training's binary_logloss: 0.270441	valid_1's binary_logloss: 0.32269
# [600]	training's binary_logloss: 0.264591	valid_1's binary_logloss: 0.322643
# [700]	training's binary_logloss: 0.259028	valid_1's binary_logloss: 0.322717
# Early stopping, best iteration is:
# [670]	training's binary_logloss: 0.260712	valid_1's binary_logloss: 0.32258
# 1:47:07.425015 	 carts valid score
# 1:47:07.426624 	 {'num_clicks': 97136, 'hit_clicks': 47730, 'num_carts': 43211, 'hit_carts': 15489, 'num_orders': 20082, 'hit_orders': 11774, 'recall_clicks': '0.491373', 'recall_carts': '0.358450', 'recall_orders': '0.586296', 'w_recall_clicks': '0.049137', 'w_recall_carts': '0.107535', 'w_recall_orders': '0.351778', 'score': '0.508450'}
# 1:47:08.743780 	 make orders_train_data
# 1:47:46.956479 	 [add_candidate] repurchase : start
# 1:47:49.110009 	 [add_candidate] clstr_freq : start
# 1:48:00.809654 	 [add_candidate] session_latest_time_wt_pair0 : start
# 1:48:02.636769 	 [add_candidate] session_latest_word2vec_pair0 : start
# 1:48:04.418742 	 [add_candidate] session_latest_pair0 : start
# 1:48:06.103070 	 [add_candidate] session_latest_type_wt_pair0 : start
# 1:48:07.848644 	 [add_candidate] session_latest_clicks2carts_pair0 : start
# 1:48:09.515734 	 [add_candidate] session_latest_clicks2orders_pair0 : start
# 1:48:10.943569 	 [add_candidate] session_latest_time_wt_pair1 : start
# 1:48:12.613171 	 [add_candidate] session_latest_word2vec_pair1 : start
# 1:48:14.481992 	 [add_candidate] session_latest_pair1 : start
# 1:48:16.201159 	 [add_candidate] session_latest_type_wt_pair1 : start
# 1:48:17.906061 	 [add_candidate] session_latest_clicks2carts_pair1 : start
# 1:48:19.604624 	 [add_candidate] session_latest_clicks2orders_pair1 : start
# 1:48:21.084615 	 [add_candidate] session_latest_time_wt_pair2 : start
# 1:48:22.816314 	 [add_candidate] session_latest_word2vec_pair2 : start
# 1:48:24.565876 	 [add_candidate] session_latest_pair2 : start
# 1:48:26.306267 	 [add_candidate] session_latest_type_wt_pair2 : start
# 1:48:28.143888 	 [add_candidate] session_latest_clicks2carts_pair2 : start
# 1:48:29.843531 	 [add_candidate] session_latest_clicks2orders_pair2 : start
# 1:48:31.342258 	 [add_candidate] session_latest_time_wt_pair3 : start
# 1:48:33.058302 	 [add_candidate] session_latest_word2vec_pair3 : start
# 1:48:34.809773 	 [add_candidate] session_latest_pair3 : start
# 1:48:36.533575 	 [add_candidate] session_latest_type_wt_pair3 : start
# 1:48:38.366148 	 [add_candidate] session_latest_clicks2carts_pair3 : start
# 1:48:40.040820 	 [add_candidate] session_latest_clicks2orders_pair3 : start
# 1:48:41.486573 	 [add_candidate] session_latest_time_wt_pair4 : start
# 1:48:43.249716 	 [add_candidate] session_latest_word2vec_pair4 : start
# 1:48:45.027608 	 [add_candidate] session_latest_pair4 : start
# 1:48:46.776203 	 [add_candidate] session_latest_type_wt_pair4 : start
# 1:48:48.522557 	 [add_candidate] session_latest_clicks2carts_pair4 : start
# 1:48:50.258781 	 [add_candidate] session_latest_clicks2orders_pair4 : start
# 1:48:51.780358 	 [add_candidate] session_latest_time_wt_pair5 : start
# 1:48:53.551001 	 [add_candidate] session_latest_word2vec_pair5 : start
# 1:48:55.412037 	 [add_candidate] session_latest_pair5 : start
# 1:48:57.183501 	 [add_candidate] session_latest_type_wt_pair5 : start
# 1:48:58.950135 	 [add_candidate] session_latest_clicks2carts_pair5 : start
# 1:49:00.685757 	 [add_candidate] session_latest_clicks2orders_pair5 : start
# 1:49:02.142570 	 [add_candidate] session_latest_time_wt_pair6 : start
# 1:49:03.940656 	 [add_candidate] session_latest_word2vec_pair6 : start
# 1:49:05.828881 	 [add_candidate] session_latest_pair6 : start
# 1:49:07.638325 	 [add_candidate] session_latest_type_wt_pair6 : start
# 1:49:09.393113 	 [add_candidate] session_latest_clicks2carts_pair6 : start
# 1:49:11.065058 	 [add_candidate] session_latest_clicks2orders_pair6 : start
# 1:49:12.628954 	 [add_candidate] session_latest_time_wt_pair7 : start
# 1:49:14.399944 	 [add_candidate] session_latest_word2vec_pair7 : start
# 1:49:16.196212 	 [add_candidate] session_latest_pair7 : start
# 1:49:17.955689 	 [add_candidate] session_latest_type_wt_pair7 : start
# 1:49:19.825247 	 [add_candidate] session_latest_clicks2carts_pair7 : start
# 1:49:21.467716 	 [add_candidate] session_latest_clicks2orders_pair7 : start
# 1:49:22.932338 	 [add_candidate] session_latest_time_wt_pair8 : start
# 1:49:24.683496 	 [add_candidate] session_latest_word2vec_pair8 : start
# 1:49:26.580857 	 [add_candidate] session_latest_pair8 : start
# 1:49:28.545653 	 [add_candidate] session_latest_type_wt_pair8 : start
# 1:49:30.345992 	 [add_candidate] session_latest_clicks2carts_pair8 : start
# 1:49:32.171359 	 [add_candidate] session_latest_clicks2orders_pair8 : start
# 1:49:33.646932 	 [add_candidate] session_latest_time_wt_pair9 : start
# 1:49:35.467664 	 [add_candidate] session_latest_word2vec_pair9 : start
# 1:49:37.261542 	 [add_candidate] session_latest_pair9 : start
# 1:49:39.023710 	 [add_candidate] session_latest_type_wt_pair9 : start
# 1:49:40.819860 	 [add_candidate] session_latest_clicks2carts_pair9 : start
# 1:49:42.480947 	 [add_candidate] session_latest_clicks2orders_pair9 : start
# 1:49:43.948086 	 [add_candidate] session_latest_time_wt_pair10 : start
# 1:49:45.707517 	 [add_candidate] session_latest_word2vec_pair10 : start
# 1:49:47.617525 	 [add_candidate] session_latest_pair10 : start
# 1:49:49.447317 	 [add_candidate] session_latest_type_wt_pair10 : start
# 1:49:51.206289 	 [add_candidate] session_latest_clicks2carts_pair10 : start
# 1:49:52.857672 	 [add_candidate] session_latest_clicks2orders_pair10 : start
# 1:49:54.305874 	 [add_candidate] session_latest_time_wt_pair11 : start
# 1:49:56.063011 	 [add_candidate] session_latest_word2vec_pair11 : start
# 1:49:57.955947 	 [add_candidate] session_latest_pair11 : start
# 1:49:59.779845 	 [add_candidate] session_latest_type_wt_pair11 : start
# 1:50:01.597221 	 [add_candidate] session_latest_clicks2carts_pair11 : start
# 1:50:03.253867 	 [add_candidate] session_latest_clicks2orders_pair11 : start
# 1:50:04.759849 	 [add_candidate] session_latest_time_wt_pair12 : start
# 1:50:06.553139 	 [add_candidate] session_latest_word2vec_pair12 : start
# 1:50:08.456955 	 [add_candidate] session_latest_pair12 : start
# 1:50:10.251275 	 [add_candidate] session_latest_type_wt_pair12 : start
# 1:50:12.023798 	 [add_candidate] session_latest_clicks2carts_pair12 : start
# 1:50:13.679525 	 [add_candidate] session_latest_clicks2orders_pair12 : start
# 1:50:15.139947 	 [add_candidate] session_latest_time_wt_pair13 : start
# 1:50:16.891701 	 [add_candidate] session_latest_word2vec_pair13 : start
# 1:50:18.790886 	 [add_candidate] session_latest_pair13 : start
# 1:50:20.637984 	 [add_candidate] session_latest_type_wt_pair13 : start
# 1:50:22.447054 	 [add_candidate] session_latest_clicks2carts_pair13 : start
# 1:50:24.122363 	 [add_candidate] session_latest_clicks2orders_pair13 : start
# 1:50:25.576426 	 [add_candidate] session_latest_time_wt_pair14 : start
# 1:50:27.477054 	 [add_candidate] session_latest_word2vec_pair14 : start
# 1:50:29.315468 	 [add_candidate] session_latest_pair14 : start
# 1:50:31.126012 	 [add_candidate] session_latest_type_wt_pair14 : start
# 1:50:33.026368 	 [add_candidate] session_latest_clicks2carts_pair14 : start
# 1:50:34.720917 	 [add_candidate] session_latest_clicks2orders_pair14 : start
# 1:50:36.168931 	 [add_candidate] session_latest_time_wt_pair15 : start
# 1:50:38.020815 	 [add_candidate] session_latest_word2vec_pair15 : start
# 1:50:39.838912 	 [add_candidate] session_latest_pair15 : start
# 1:50:41.612898 	 [add_candidate] session_latest_type_wt_pair15 : start
# 1:50:43.437541 	 [add_candidate] session_latest_clicks2carts_pair15 : start
# 1:50:45.139445 	 [add_candidate] session_latest_clicks2orders_pair15 : start
# 1:50:46.587255 	 [add_candidate] session_latest_time_wt_pair16 : start
# 1:50:48.428423 	 [add_candidate] session_latest_word2vec_pair16 : start
# 1:50:50.254492 	 [add_candidate] session_latest_pair16 : start
# 1:50:52.034359 	 [add_candidate] session_latest_type_wt_pair16 : start
# 1:50:53.867843 	 [add_candidate] session_latest_clicks2carts_pair16 : start
# 1:50:55.562271 	 [add_candidate] session_latest_clicks2orders_pair16 : start
# 1:50:57.050938 	 [add_candidate] session_latest_time_wt_pair17 : start
# 1:50:58.831336 	 [add_candidate] session_latest_word2vec_pair17 : start
# 1:51:00.622146 	 [add_candidate] session_latest_pair17 : start
# 1:51:02.404041 	 [add_candidate] session_latest_type_wt_pair17 : start
# 1:51:04.237235 	 [add_candidate] session_latest_clicks2carts_pair17 : start
# 1:51:05.913780 	 [add_candidate] session_latest_clicks2orders_pair17 : start
# 1:51:07.385079 	 [add_candidate] session_latest_time_wt_pair18 : start
# 1:51:09.246700 	 [add_candidate] session_latest_word2vec_pair18 : start
# 1:51:11.035947 	 [add_candidate] session_latest_pair18 : start
# 1:51:12.798436 	 [add_candidate] session_latest_type_wt_pair18 : start
# 1:51:14.582150 	 [add_candidate] session_latest_clicks2carts_pair18 : start
# 1:51:16.244486 	 [add_candidate] session_latest_clicks2orders_pair18 : start
# 1:51:17.706527 	 [add_candidate] session_latest_time_wt_pair19 : start
# 1:51:19.498860 	 [add_candidate] session_latest_word2vec_pair19 : start
# 1:51:21.538479 	 [add_candidate] session_latest_pair19 : start
# 1:51:23.398189 	 [add_candidate] session_latest_type_wt_pair19 : start
# 1:51:25.214033 	 [add_candidate] session_latest_clicks2carts_pair19 : start
# 1:51:26.905195 	 [add_candidate] session_latest_clicks2orders_pair19 : start
# 1:52:32.624223 	 train(orders) pos : 613255  neg : 613255
# 1:52:34.045310 	 [features] session_cnt : start
# 1:52:35.081924 	 [features] session_aid_nunique : start
# 1:52:35.409873 	 [features] session_last_type : start
# 1:52:35.864236 	 [features] aid_cnt : start
# 1:52:37.579175 	 [features] aid_clicks_cnt : start
# 1:52:39.030462 	 [features] aid_carts_cnt : start
# 1:52:39.295476 	 [features] aid_orders_cnt : start
# 1:52:39.396246 	 [features] all_times_aid_freq : start
# 1:52:39.904061 	 [features] all_times_aid_clicks_freq : start
# 1:52:40.402332 	 [features] all_times_aid_carts_freq : start
# 1:52:40.721789 	 [features] all_times_aid_orders_freq : start
# 1:52:40.933979 	 [features] all_times_aid_session_freq : start
# 1:52:41.422970 	 [features] all_times_aid_session_clicks_freq : start
# 1:52:41.942950 	 [features] all_times_aid_session_carts_freq : start
# 1:52:42.260885 	 [features] all_times_aid_session_orders_freq : start
# 1:52:42.443369 	 [features] all_times_aid_carts_ratio_with_clicks : start
# 1:52:43.033486 	 [features] all_times_aid_orders_ratio_with_clicks : start
# 1:52:43.623721 	 [features] all_times_aid_date_std : start
# 1:52:44.212651 	 [features] all_times_aid_hour_std : start
# 1:52:44.805606 	 [features] all_times_aid_day_of_week_std : start
# 1:52:45.427556 	 [features] w2v_vectors : start
# 1:52:45.836213 	 [features] relative_ts : start
# 1:52:50.938743 	 [features] co_visit_rank(co_visitation_matrix) : start
# 1:53:01.080164 	 [features] co_visit_rank(co_visitation_matrix_lt0) : start
# 1:53:23.831864 	 [features] co_visit_rank(co_visitation_matrix_lt1) : start
# 1:53:47.302002 	 [features] co_visit_rank(co_visitation_matrix_lt2) : start
# 1:54:10.922114 	 [features] co_visit_rank(co_visitation_matrix_lt3) : start
# 1:54:36.563602 	 [features] co_visit_rank(co_visitation_matrix_lt4) : start
# 1:55:00.126890 	 [features] co_visit_rank(co_visitation_matrix_lt5) : start
# 1:55:25.053764 	 [features] co_visit_rank(co_visitation_matrix_lt6) : start
# 1:55:51.078011 	 [features] co_visit_rank(co_visitation_matrix_lt7) : start
# 1:56:16.696823 	 [features] co_visit_rank(co_visitation_matrix_lt8) : start
# 1:56:42.434927 	 [features] co_visit_rank(co_visitation_matrix_lt9) : start
# 1:57:08.277501 	 [features] co_visit_rank(co_visitation_matrix_time_weighted) : start
# 1:57:59.644759 	 [features] co_visit_rank(co_visitation_matrix_time_weighted_lt0) : start
# 1:58:55.123454 	 [features] co_visit_rank(co_visitation_matrix_time_weighted_lt1) : start
# 1:59:53.661934 	 [features] co_visit_rank(co_visitation_matrix_time_weighted_lt2) : start
# 2:00:43.186191 	 [features] co_visit_rank(co_visitation_matrix_time_weighted_lt3) : start
# 2:01:44.251399 	 [features] co_visit_rank(co_visitation_matrix_time_weighted_lt4) : start
# 2:02:33.764244 	 [features] co_visit_rank(co_visitation_matrix_time_weighted_lt5) : start
# 2:03:23.638204 	 [features] co_visit_rank(co_visitation_matrix_time_weighted_lt6) : start
# 2:04:17.156345 	 [features] co_visit_rank(co_visitation_matrix_time_weighted_lt7) : start
# 2:05:06.824132 	 [features] co_visit_rank(co_visitation_matrix_time_weighted_lt8) : start
# 2:05:57.067899 	 [features] co_visit_rank(co_visitation_matrix_time_weighted_lt9) : start
# 2:06:46.435633 	 [features] co_visit_rank(co_visitation_matrix_type_weighted) : start
# 2:07:23.316602 	 [features] co_visit_rank(co_visitation_matrix_type_weighted_lt0) : start
# 2:08:20.805218 	 [features] co_visit_rank(co_visitation_matrix_type_weighted_lt1) : start
# 2:09:13.123026 	 [features] co_visit_rank(co_visitation_matrix_type_weighted_lt2) : start
# 2:10:07.310094 	 [features] co_visit_rank(co_visitation_matrix_type_weighted_lt3) : start
# 2:10:59.294277 	 [features] co_visit_rank(co_visitation_matrix_type_weighted_lt4) : start
# 2:11:55.307404 	 [features] co_visit_rank(co_visitation_matrix_type_weighted_lt5) : start
# 2:12:47.489666 	 [features] co_visit_rank(co_visitation_matrix_type_weighted_lt6) : start
# 2:13:41.746563 	 [features] co_visit_rank(co_visitation_matrix_type_weighted_lt7) : start
# 2:14:31.865790 	 [features] co_visit_rank(co_visitation_matrix_type_weighted_lt8) : start
# 2:15:23.722112 	 [features] co_visit_rank(co_visitation_matrix_type_weighted_lt9) : start
# 2:16:13.682667 	 [features] co_visit_rank(co_visitation_matrix_clicks2carts) : start
# 2:16:16.760551 	 [features] co_visit_rank(co_visitation_matrix_clicks2carts_lt0) : start
# 2:16:18.311048 	 [features] co_visit_rank(co_visitation_matrix_clicks2carts_lt1) : start
# 2:16:19.907790 	 [features] co_visit_rank(co_visitation_matrix_clicks2carts_lt2) : start
# 2:16:21.493989 	 [features] co_visit_rank(co_visitation_matrix_clicks2carts_lt3) : start
# 2:16:22.834602 	 [features] co_visit_rank(co_visitation_matrix_clicks2carts_lt4) : start
# 2:16:24.171623 	 [features] co_visit_rank(co_visitation_matrix_clicks2carts_lt5) : start
# 2:16:25.491560 	 [features] co_visit_rank(co_visitation_matrix_clicks2carts_lt6) : start
# 2:16:26.751140 	 [features] co_visit_rank(co_visitation_matrix_clicks2carts_lt7) : start
# 2:16:28.071100 	 [features] co_visit_rank(co_visitation_matrix_clicks2carts_lt8) : start
# 2:16:29.266926 	 [features] co_visit_rank(co_visitation_matrix_clicks2carts_lt9) : start
# 2:16:30.513228 	 [features] co_visit_rank(co_visitation_matrix_clicks2orders) : start
# 2:16:31.483294 	 [features] co_visit_rank(co_visitation_matrix_clicks2orders_lt0) : start
# 2:16:31.772985 	 [features] co_visit_rank(co_visitation_matrix_clicks2orders_lt1) : start
# 2:16:32.080688 	 [features] co_visit_rank(co_visitation_matrix_clicks2orders_lt2) : start
# 2:16:32.356004 	 [features] co_visit_rank(co_visitation_matrix_clicks2orders_lt3) : start
# 2:16:32.632876 	 [features] co_visit_rank(co_visitation_matrix_clicks2orders_lt4) : start
# 2:16:32.931645 	 [features] co_visit_rank(co_visitation_matrix_clicks2orders_lt5) : start
# 2:16:33.208457 	 [features] co_visit_rank(co_visitation_matrix_clicks2orders_lt6) : start
# 2:16:33.483842 	 [features] co_visit_rank(co_visitation_matrix_clicks2orders_lt7) : start
# 2:16:33.767151 	 [features] co_visit_rank(co_visitation_matrix_clicks2orders_lt8) : start
# 2:16:34.064834 	 [features] co_visit_rank(co_visitation_matrix_clicks2orders_lt9) : start
# 2:16:34.349516 	 [features] latest_aid_w2v_sims : start
# 100%|██████████| 1226510/1226510 [00:12<00:00, 101800.80it/s]
# 100%|██████████| 1226510/1226510 [00:11<00:00, 111243.66it/s]
# 100%|██████████| 1226510/1226510 [00:10<00:00, 119493.12it/s]
# 100%|██████████| 1226510/1226510 [00:09<00:00, 124705.33it/s]
# 100%|██████████| 1226510/1226510 [00:09<00:00, 133604.56it/s]
# 100%|██████████| 1226510/1226510 [00:08<00:00, 137344.75it/s]
# 100%|██████████| 1226510/1226510 [00:08<00:00, 147215.42it/s]
# 100%|██████████| 1226510/1226510 [00:08<00:00, 152555.75it/s]
# 100%|██████████| 1226510/1226510 [00:07<00:00, 160453.36it/s]
# 100%|██████████| 1226510/1226510 [00:07<00:00, 169055.57it/s]
# 2:18:25.390808 	 make orders_valid_data
# 2:18:25.400364 	 [valid_cand.parquet] cache exists. read cache and skip process.
# 2:18:28.062654 	 make orders_valid_data
# 2:18:28.098631 	 [features] session_cnt : start
# 2:18:30.289911 	 [features] session_aid_nunique : start
# 2:18:30.735515 	 [features] session_last_type : start
# 2:18:31.072089 	 [features] aid_cnt : start
# 2:18:31.847148 	 [features] aid_clicks_cnt : start
# 2:18:32.479966 	 [features] aid_carts_cnt : start
# 2:18:32.972147 	 [features] aid_orders_cnt : start
# 2:18:33.462267 	 [features] all_times_aid_freq : start
# 2:18:34.338758 	 [features] all_times_aid_clicks_freq : start
# 2:18:35.247032 	 [features] all_times_aid_carts_freq : start
# 2:18:35.880764 	 [features] all_times_aid_orders_freq : start
# 2:18:36.364244 	 [features] all_times_aid_session_freq : start
# 2:18:37.209893 	 [features] all_times_aid_session_clicks_freq : start
# 2:18:38.092262 	 [features] all_times_aid_session_carts_freq : start
# 2:18:38.701921 	 [features] all_times_aid_session_orders_freq : start
# 2:18:39.120803 	 [features] all_times_aid_carts_ratio_with_clicks : start
# 2:18:40.010177 	 [features] all_times_aid_orders_ratio_with_clicks : start
# 2:18:40.927420 	 [features] all_times_aid_date_std : start
# 2:18:41.861138 	 [features] all_times_aid_hour_std : start
# 2:18:42.809191 	 [features] all_times_aid_day_of_week_std : start
# 2:18:43.748155 	 [features] w2v_vectors : start
# 2:18:44.758975 	 [features] relative_ts : start
# 2:18:49.983922 	 [features] co_visit_rank(co_visitation_matrix) : start
# 2:19:10.856928 	 [features] co_visit_rank(co_visitation_matrix_lt0) : start
# 2:19:34.516097 	 [features] co_visit_rank(co_visitation_matrix_lt1) : start
# 2:19:58.275095 	 [features] co_visit_rank(co_visitation_matrix_lt2) : start
# 2:20:21.649440 	 [features] co_visit_rank(co_visitation_matrix_lt3) : start
# 2:20:45.134404 	 [features] co_visit_rank(co_visitation_matrix_lt4) : start
# 2:21:08.373297 	 [features] co_visit_rank(co_visitation_matrix_lt5) : start
# 2:21:31.784297 	 [features] co_visit_rank(co_visitation_matrix_lt6) : start
# 2:21:55.071245 	 [features] co_visit_rank(co_visitation_matrix_lt7) : start
# 2:22:18.584793 	 [features] co_visit_rank(co_visitation_matrix_lt8) : start
# 2:22:41.888826 	 [features] co_visit_rank(co_visitation_matrix_lt9) : start
# 2:23:05.453737 	 [features] co_visit_rank(co_visitation_matrix_time_weighted) : start
# 2:23:55.791739 	 [features] co_visit_rank(co_visitation_matrix_time_weighted_lt0) : start
# 2:24:47.855777 	 [features] co_visit_rank(co_visitation_matrix_time_weighted_lt1) : start
# 2:25:36.380655 	 [features] co_visit_rank(co_visitation_matrix_time_weighted_lt2) : start
# 2:26:25.306987 	 [features] co_visit_rank(co_visitation_matrix_time_weighted_lt3) : start
# 2:27:13.252919 	 [features] co_visit_rank(co_visitation_matrix_time_weighted_lt4) : start
# 2:28:01.315972 	 [features] co_visit_rank(co_visitation_matrix_time_weighted_lt5) : start
# 2:28:49.665983 	 [features] co_visit_rank(co_visitation_matrix_time_weighted_lt6) : start
# 2:29:37.838384 	 [features] co_visit_rank(co_visitation_matrix_time_weighted_lt7) : start
# 2:30:25.686853 	 [features] co_visit_rank(co_visitation_matrix_time_weighted_lt8) : start
# 2:31:13.726785 	 [features] co_visit_rank(co_visitation_matrix_time_weighted_lt9) : start
# 2:32:01.786294 	 [features] co_visit_rank(co_visitation_matrix_type_weighted) : start
# 2:32:35.244698 	 [features] co_visit_rank(co_visitation_matrix_type_weighted_lt0) : start
# 2:33:26.624830 	 [features] co_visit_rank(co_visitation_matrix_type_weighted_lt1) : start
# 2:34:18.069320 	 [features] co_visit_rank(co_visitation_matrix_type_weighted_lt2) : start
# 2:35:09.268252 	 [features] co_visit_rank(co_visitation_matrix_type_weighted_lt3) : start
# 2:36:00.442267 	 [features] co_visit_rank(co_visitation_matrix_type_weighted_lt4) : start
# 2:36:52.440450 	 [features] co_visit_rank(co_visitation_matrix_type_weighted_lt5) : start
# 2:37:43.348343 	 [features] co_visit_rank(co_visitation_matrix_type_weighted_lt6) : start
# 2:38:35.076619 	 [features] co_visit_rank(co_visitation_matrix_type_weighted_lt7) : start
# 2:39:25.986049 	 [features] co_visit_rank(co_visitation_matrix_type_weighted_lt8) : start
# 2:40:19.573214 	 [features] co_visit_rank(co_visitation_matrix_type_weighted_lt9) : start
# 2:41:12.553070 	 [features] co_visit_rank(co_visitation_matrix_clicks2carts) : start
# 2:41:16.051382 	 [features] co_visit_rank(co_visitation_matrix_clicks2carts_lt0) : start
# 2:41:18.593340 	 [features] co_visit_rank(co_visitation_matrix_clicks2carts_lt1) : start
# 2:41:20.669769 	 [features] co_visit_rank(co_visitation_matrix_clicks2carts_lt2) : start
# 2:41:22.551264 	 [features] co_visit_rank(co_visitation_matrix_clicks2carts_lt3) : start
# 2:41:24.374285 	 [features] co_visit_rank(co_visitation_matrix_clicks2carts_lt4) : start
# 2:41:26.219406 	 [features] co_visit_rank(co_visitation_matrix_clicks2carts_lt5) : start
# 2:41:27.979210 	 [features] co_visit_rank(co_visitation_matrix_clicks2carts_lt6) : start
# 2:41:29.790509 	 [features] co_visit_rank(co_visitation_matrix_clicks2carts_lt7) : start
# 2:41:31.600385 	 [features] co_visit_rank(co_visitation_matrix_clicks2carts_lt8) : start
# 2:41:33.443582 	 [features] co_visit_rank(co_visitation_matrix_clicks2carts_lt9) : start
# 2:41:35.256904 	 [features] co_visit_rank(co_visitation_matrix_clicks2orders) : start
# 2:41:36.258538 	 [features] co_visit_rank(co_visitation_matrix_clicks2orders_lt0) : start
# 2:41:37.116612 	 [features] co_visit_rank(co_visitation_matrix_clicks2orders_lt1) : start
# 2:41:37.935075 	 [features] co_visit_rank(co_visitation_matrix_clicks2orders_lt2) : start
# 2:41:38.752336 	 [features] co_visit_rank(co_visitation_matrix_clicks2orders_lt3) : start
# 2:41:39.557478 	 [features] co_visit_rank(co_visitation_matrix_clicks2orders_lt4) : start
# 2:41:40.342422 	 [features] co_visit_rank(co_visitation_matrix_clicks2orders_lt5) : start
# 2:41:41.130834 	 [features] co_visit_rank(co_visitation_matrix_clicks2orders_lt6) : start
# 2:41:41.929264 	 [features] co_visit_rank(co_visitation_matrix_clicks2orders_lt7) : start
# 2:41:42.701879 	 [features] co_visit_rank(co_visitation_matrix_clicks2orders_lt8) : start
# 2:41:43.479082 	 [features] co_visit_rank(co_visitation_matrix_clicks2orders_lt9) : start
# 2:41:44.239306 	 [features] latest_aid_w2v_sims : start
# 100%|██████████| 18710489/18710489 [02:56<00:00, 105778.25it/s]
# 100%|██████████| 18710489/18710489 [02:33<00:00, 121717.28it/s]
# 100%|██████████| 18710489/18710489 [02:15<00:00, 138520.12it/s]
# 100%|██████████| 18710489/18710489 [02:00<00:00, 155202.41it/s]
# 100%|██████████| 18710489/18710489 [01:49<00:00, 171220.22it/s]
# 100%|██████████| 18710489/18710489 [01:43<00:00, 180724.20it/s]
# 100%|██████████| 18710489/18710489 [01:38<00:00, 190254.41it/s]
# 100%|██████████| 18710489/18710489 [01:32<00:00, 203087.11it/s]
# 100%|██████████| 18710489/18710489 [01:26<00:00, 216388.03it/s]
# 100%|██████████| 18710489/18710489 [01:21<00:00, 229458.23it/s]
# 3:01:22.987646 	 valid(orders) pos : 13414  neg : 18697075
# /home/kaggler/.local/lib/python3.8/site-packages/lightgbm/engine.py:181: UserWarning: 'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. Pass 'early_stopping()' callback via 'callbacks' argument instead.
#   _log_warning("'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. "
# /home/kaggler/.local/lib/python3.8/site-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# [LightGBM] [Info] Number of positive: 613255, number of negative: 613255
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.116563 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 21308
# [LightGBM] [Info] Number of data points in the train set: 1226510, number of used features: 91
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500000 -> initscore=0.000000
# Training until validation scores don't improve for 100 rounds
# [100]	training's binary_logloss: 0.189391	valid_1's binary_logloss: 0.22379
# [200]	training's binary_logloss: 0.178537	valid_1's binary_logloss: 0.222476
# [300]	training's binary_logloss: 0.171082	valid_1's binary_logloss: 0.222184
# Early stopping, best iteration is:
# [295]	training's binary_logloss: 0.171371	valid_1's binary_logloss: 0.222149
# 3:12:07.800151 	 orders valid score
# 3:12:07.802621 	 {'num_clicks': 97136, 'hit_clicks': 46124, 'num_carts': 43211, 'hit_carts': 15037, 'num_orders': 20082, 'hit_orders': 11919, 'recall_clicks': '0.474839', 'recall_carts': '0.347990', 'recall_orders': '0.593517', 'w_recall_clicks': '0.047484', 'w_recall_carts': '0.104397', 'w_recall_orders': '0.356110', 'score': '0.507991'}
