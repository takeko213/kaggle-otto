# %% [markdown]
# # cand_trial002

# %%
import os
import sys
import traceback
import gc
import random
import pickle
import pathlib
import subprocess
from dataclasses import dataclass
from dotenv import load_dotenv
load_dotenv
sys.path.append(os.getenv('UTILS_PATH'))
from tqdm import tqdm
import multiprocessing
import inspect

import pandas as pd
import numpy as np
import itertools
import cudf
import lightgbm as lgb
import matplotlib.pyplot as plt
import seaborn as sns
import line_notify
import my_logger
from noglobal import noglobal
import optuna

# %% [markdown]
# # 設定

# %%
@dataclass
class Cfg:
    loglevel = "INFO"
    exp_name = "cand_trial"
    seed = 42
    k = 20
    cand_n = 15
    type2id = {"clicks":0, "carts":1, "orders":2}
    id2type = {0:"clicks", 1:"carts", 2:"orders"}
    train_weeks = ["week3"]
    valid_week = "week4"
    valid_session_n = 100_000
    input_dir = os.getenv('INPUT_DIR')
    output_dir = os.getenv('OUTPUT_DIR')
    prep_dir = os.getenv("PREP_DIR")

cfg = Cfg()
os.makedirs(os.path.join(cfg.output_dir, cfg.exp_name), exist_ok=True)
os.makedirs(os.path.join(cfg.output_dir, cfg.exp_name, "cache"), exist_ok=True)
random.seed(cfg.seed)

logger = my_logger.init_logger(cfg.exp_name)

# %%
@noglobal(excepts=["cfg", "logger"])
def evaluate(clicks_labels, carts_labels, orders_labels, 
             clicks_preds, carts_preds, orders_preds, k=20):

    num_clicks = 0
    num_carts = 0
    num_orders = 0
    hit_clicks = 0
    hit_carts = 0
    hit_orders = 0

    for i in range(len(clicks_labels)):
        clicks_label = clicks_labels[i]
        carts_label = carts_labels[i]
        orders_label = orders_labels[i]
        clicks_pred = clicks_preds[i]
        carts_pred = carts_preds[i]
        orders_pred = orders_preds[i]

        if type(clicks_pred) == list:
            clicks_pred = clicks_pred[:k]
        else:
            clicks_pred = []
        if type(carts_pred) == list:
            carts_pred = carts_pred[:k]
        else:
            carts_pred = []    
        if type(orders_pred) == list:
            orders_pred = orders_pred[:k]
        else:
            orders_pred = []

        if not np.isnan(clicks_label):
            num_clicks += 1
            hit_clicks += int(clicks_label in clicks_pred)

        if type(carts_label) == list:
            num_carts += min(len(carts_label), k)
            hit_carts += len(set(carts_pred) & set(carts_label))
            
        if type(orders_label) == list:
            num_orders += min(len(orders_label), k)
            hit_orders += len(set(orders_pred) & set(orders_label))


    recall_clicks = hit_clicks / num_clicks
    recall_carts = hit_carts / num_carts
    recall_orders = hit_orders / num_orders
    w_recall_clicks = recall_clicks * 0.10
    w_recall_carts = recall_carts * 0.30
    w_recall_orders = recall_orders * 0.60
    score = w_recall_clicks + w_recall_carts + w_recall_orders

    results = {}
    results["num_clicks"] = num_clicks
    results["hit_clicks"] = hit_clicks
    results["num_carts"] = num_carts
    results["hit_carts"] = hit_carts
    results["num_orders"] = num_orders
    results["hit_orders"] = hit_orders
    results["recall_clicks"] = format(recall_clicks, ".3f")
    results["recall_carts"] = format(recall_carts, ".3f")
    results["recall_orders"] = format(recall_orders, ".3f")
    results["w_recall_clicks"] = format(w_recall_clicks, ".3f")
    results["w_recall_carts"] = format(w_recall_carts, ".3f")
    results["w_recall_orders"] = format(w_recall_orders, ".3f")
    results["score"] = format(score, ".3f")

    return results

# %%
class Candidate:
    @noglobal(excepts=["cfg", "logger"])
    def __init__(self, pdf, labels=None):
        self.df = cudf.from_pandas(pdf)
        self.target_sessions = pdf["session"].unique().tolist()
        self.results = pd.DataFrame(columns=["name", "num_clicks", "hit_clicks", "num_carts", "hit_carts", "num_orders", "hit_orders", 
                                             "recall_clicks", "recall_carts", "recall_orders", "w_recall_clicks", "w_recall_carts", "w_recall_orders", "score"])
        self.output = pd.DataFrame(columns=["session", "aid"], dtype=int)
        self.labels = labels
    
    @noglobal(excepts=["cfg", "logger"])
    def _entry(self, new_candidate_df, name, k):
        logger.info(f"[add_candidate] {name} : start")
        new_candidate_df = new_candidate_df.to_pandas()
        self.output = pd.concat([self.output, new_candidate_df[["session", "aid"]]])
        self.output = self.output.drop_duplicates(subset=["session", "aid"])

        if self.labels is not None:
            self._eval(new_candidate_df[["session", "aid"]], name, k)
    
    @noglobal(excepts=["cfg", "logger"])
    def _eval(self, new_candidate_df, name, k):
        new_candidate_df = new_candidate_df.groupby("session")["aid"].apply(list).reset_index()
        eval_df = pd.DataFrame(self.target_sessions, columns=["session"])
        eval_df = eval_df.merge(new_candidate_df, on=["session"], how="left")
        assert eval_df["session"].tolist() == self.labels["session"].tolist()
        eval_result = evaluate(self.labels["clicks_labels"].tolist(), self.labels["carts_labels"].tolist(), self.labels["orders_labels"].tolist(),
                               eval_df["aid"].tolist(), eval_df["aid"].tolist(), eval_df["aid"].tolist(), k)
        
        logger.info(name)
        logger.info(eval_result)
        self.results = pd.concat([self.results, pd.DataFrame([[name] + list(eval_result.values())], columns=["name"] + list(eval_result.keys()))])

    @noglobal(excepts=["cfg", "logger"])
    def add(self, strategy, name, usetypes=['clicks', 'carts', 'orders'], trans_map=None, k=20):
        logger.info(f"[make_candidate] {name} : start")
        candidate_df = self.df[self.df["type"].isin(usetypes)].copy()
        
        if strategy == "session_frequent":
            candidate_df = self._session_frequent(candidate_df, k)
        elif strategy == "session_latest":
            candidate_df = self._session_latest(candidate_df, k)
        elif strategy == "total_frequent":
            candidate_df = self._total_frequent(candidate_df, k)
        
        if trans_map is not None:
            candidate_df["aid"] = candidate_df["aid"].map(trans_map)
            candidate_df = candidate_df.dropna(subset=["aid"])
            
        self._entry(candidate_df, name, k)

    @noglobal(excepts=["cfg", "logger"])
    def _session_frequent(self, candidate_df, k):
        candidate_df = candidate_df.groupby(["session", "aid"])["ts"].count().reset_index()
        candidate_df.columns = ["session", "aid", "aid_count"]
        candidate_df = candidate_df.sort_values(["session", "aid_count", "aid"], ascending=(True, False, True))
        candidate_df = candidate_df[candidate_df.groupby("session")["aid_count"].cumcount() < k].copy()
        candidate_df = candidate_df[["session", "aid"]].copy()
        return candidate_df

    @noglobal(excepts=["cfg", "logger"])
    def _session_latest(self, candidate_df, k):
        candidate_df = candidate_df.sort_values(["session", "ts"], ascending=(True, False)).drop_duplicates(subset=["session", "aid"])
        candidate_df = candidate_df.sort_values(["session", "ts"], ascending=(True, False))[candidate_df.groupby("session")["ts"].cumcount() < k].copy()
        candidate_df = candidate_df[["session", "aid"]].copy()
        return candidate_df

    @noglobal(excepts=["cfg", "logger"])
    def _total_frequent(self, candidate_df, k):
        candidate_df = candidate_df.groupby("aid")["ts"].count().reset_index()
        candidate_df.columns = ["aid", "aid_count"]
        topk_freq_aids = candidate_df.sort_values("aid_count", ascending=False)["aid"].to_arrow().to_pylist()[:k]
        sessions = []
        aids = []
        for session, aid in itertools.product(self.target_sessions, topk_freq_aids):
            sessions.append(session)
            aids.append(aid)
        candidate_df = cudf.DataFrame({"session": sessions, "aid": aids})
        return candidate_df

# %%
@noglobal(excepts=["cfg", "logger"])
def make_cand_df(sessions, labels=None, trans_maps=None):

    if labels is not None:
         cand = Candidate(sessions, labels)
    else:
        cand = Candidate(sessions)

    cand.add(strategy="session_frequent", name="session_frequent", k=15)
    cand.add(strategy="session_latest", name="session_latest", k=15)
    
    for i in range(20):
        cand.add(strategy="session_latest", trans_map=trans_maps[f"time_wt_pair{str(i)}"], name=f"session_latest_time_wt_pair{str(i)}", k=5)
        cand.add(strategy="session_latest", trans_map=trans_maps[f"word2vec_pair{str(i)}"], name=f"session_latest_word2vec_pair{str(i)}", k=5)
        cand.add(strategy="session_latest", trans_map=trans_maps[f"pair{str(i)}"], name=f"session_latest_pair{str(i)}", k=5)
        cand.add(strategy="session_latest", trans_map=trans_maps[f"type_wt_pair{str(i)}"], name=f"session_latest_type_wt_pair{str(i)}", k=5)
        cand.add(strategy="session_latest", trans_map=trans_maps[f"clicks2carts_pair{str(i)}"], name=f"session_latest_clicks2carts_pair{str(i)}", k=5)
        cand.add(strategy="session_latest", trans_map=trans_maps[f"clicks2orders_pair{str(i)}"], name=f"session_latest_clicks2orders_pair{str(i)}", k=5)

    if labels is not None:
        return cand.output, cand.results
    else:
        return cand.output

# %%
@noglobal(excepts=["cfg", "logger"])
def get_pair_df(name, wt_col, week):
    if week is not None:
        name = f"{name}_{week}"
    pair_df = pd.read_pickle(cfg.prep_dir + f"{name}.pkl")
    pair_df = pair_df.sort_values(["aid_x", wt_col], ascending=(True, False))
    return pair_df

@noglobal(excepts=["cfg", "logger"])
def get_pair_dict(name, wt_col, week):
    if week is not None:
        name = f"{name}_{week}"
    pair_df = pd.read_pickle(cfg.prep_dir + f"{name}.pkl")
    pair_df = pair_df.sort_values(["aid_x", wt_col], ascending=(True, False))
    pair_df = pair_df.groupby("aid_x").head(1)[["aid_x", "aid_y"]]
    pair_dict = {k: v for k, v in zip(pair_df["aid_x"].tolist(), pair_df["aid_y"].tolist())}
    return pair_dict

@noglobal(excepts=["cfg", "logger"])
def get_trans_maps(week=None):
    """
    aidを別のaidに置き換えるmapping辞書を取得する
    """
    trans_maps = {}
    
    pair_df_org = get_pair_df("co_visitation_matrix", "cnt", week)
    for i in range(20):
        pair_df = pair_df_org.groupby("aid_x").nth(i).reset_index()[["aid_x", "aid_y"]]
        pair_dict = {k: v for k, v in zip(pair_df["aid_x"].tolist(), pair_df["aid_y"].tolist())}
        trans_maps[f"pair{str(i)}"] = pair_dict
    
    pair_df_org = get_pair_df("co_visitation_matrix_time_weighted", "wt", week)
    for i in range(20):
        pair_df = pair_df_org.groupby("aid_x").nth(i).reset_index()[["aid_x", "aid_y"]]
        pair_dict = {k: v for k, v in zip(pair_df["aid_x"].tolist(), pair_df["aid_y"].tolist())}
        trans_maps[f"time_wt_pair{str(i)}"] = pair_dict

    pair_df_org = get_pair_df("co_visitation_matrix_type_weighted", "wt", week)
    for i in range(20):
        pair_df = pair_df_org.groupby("aid_x").nth(i).reset_index()[["aid_x", "aid_y"]]
        pair_dict = {k: v for k, v in zip(pair_df["aid_x"].tolist(), pair_df["aid_y"].tolist())}
        trans_maps[f"type_wt_pair{str(i)}"] = pair_dict

    pair_df_org = get_pair_df("co_visitation_matrix_clicks2carts", "cnt", week)
    for i in range(20):
        pair_df = pair_df_org.groupby("aid_x").nth(i).reset_index()[["aid_x", "aid_y"]]
        pair_dict = {k: v for k, v in zip(pair_df["aid_x"].tolist(), pair_df["aid_y"].tolist())}
        trans_maps[f"clicks2carts_pair{str(i)}"] = pair_dict

    pair_df_org = get_pair_df("co_visitation_matrix_clicks2orders", "cnt", week)
    for i in range(20):
        pair_df = pair_df_org.groupby("aid_x").nth(i).reset_index()[["aid_x", "aid_y"]]
        pair_dict = {k: v for k, v in zip(pair_df["aid_x"].tolist(), pair_df["aid_y"].tolist())}
        trans_maps[f"clicks2orders_pair{str(i)}"] = pair_dict

    pair_df_org = get_pair_df("word2vec_similar", "sim", None)
    for i in range(20):
        pair_df = pair_df_org.groupby("aid_x").nth(i).reset_index()[["aid_x", "aid_y"]]
        pair_dict = {k: v for k, v in zip(pair_df["aid_x"].tolist(), pair_df["aid_y"].tolist())}
        trans_maps[f"word2vec_pair{str(i)}"] = pair_dict

    with open(cfg.prep_dir + "matrix_factorization_embeddings_similar_top20.pkl", "rb") as f:
        nns = pickle.load(f)
    for i in range(20):
        pair_dict = {aid_x:aid_ys[i] for aid_x, aid_ys in enumerate(nns)}
        trans_maps[f"matrix_fact_pair{str(i)}"] = pair_dict

    return trans_maps

# %%
class Cache:
    @noglobal(excepts=["cfg", "logger"])
    def __init__(self):
        self.cache_dir = (os.path.join(cfg.output_dir, cfg.exp_name, "cache"))
        self.cache_dir_path = pathlib.Path(self.cache_dir)
        self.caches = list(self.cache_dir_path.glob("*.pkl"))

    @noglobal(excepts=["cfg", "logger"])
    def get_abspath(self, filename):
        return (os.path.join(self.cache_dir, f"{cfg.exp_name}_{filename}"))
    
    @noglobal(excepts=["cfg", "logger"])
    def exists(self, path):
        return len([str(c) for c in self.caches if path == str(c)]) > 0

# %%
@noglobal(excepts=["cfg", "logger"])
def make_valid_data(trans_maps):
    valid_week = cfg.valid_week
    dfs = []
    
    logger.info(f"[make_valid] valid_week : {valid_week}")
    # データ読み込み
    logger.info("[make_valid] read_data : start")
    week_sessions = pd.read_pickle(os.getenv("PREP_DIR") + f"train_sessions_{valid_week}.pkl")
    week_labels = pd.read_pickle(os.getenv("PREP_DIR") + f"labels_{valid_week}.pkl")
    valid_session_ids = week_sessions["session"].unique().tolist()
    logger.info("[make_valid] read_data : end")

    # validに使うsessionを絞る (trainに存在するsessionを除外した上で設定した数に絞る)
    logger.info("[make_valid] valid_session_extract : start")
    valid_session_n = min(cfg.valid_session_n, len(valid_session_ids))
    valid_session_ids = random.sample(valid_session_ids, valid_session_n)
    week_sessions = week_sessions[week_sessions["session"].isin(valid_session_ids)].copy()
    week_labels = week_labels[week_labels["session"].isin(valid_session_ids)].copy()
    logger.info("[make_valid] valid_session_extract : end")

    # 候補選出
    logger.info("[make_valid] make_cand_df : start")
    valid, results = make_cand_df(week_sessions, labels=week_labels, trans_maps=trans_maps)

    return valid, week_labels, results

# %%
logger.info("\n\nSTART\n\n")
trans_maps = get_trans_maps(cfg.valid_week)
valid, valid_labels, results = make_valid_data(trans_maps)
# Out:
# 0:00:00.341841
#
# START
#
#
# 0:33:50.836607 	 [make_valid] valid_week : week4
# 0:33:50.838549 	 [make_valid] read_data : start
# 0:34:01.857589 	 [make_valid] read_data : end
# 0:34:01.858762 	 [make_valid] valid_session_extract : start
# 0:34:02.890646 	 [make_valid] valid_session_extract : end
# 0:34:02.892106 	 [make_valid] make_cand_df : start
# 0:34:02.955403 	 [make_candidate] session_frequent : start
# 0:34:03.214984 	 [add_candidate] session_frequent : start
# 0:34:05.217854 	 session_frequent
# 0:34:05.219046 	 {'num_clicks': 97136, 'hit_clicks': 29467, 'num_carts': 42864, 'hit_carts': 10730, 'num_orders': 19985, 'hit_orders': 10185, 'recall_clicks': '0.303', 'recall_carts': '0.250', 'recall_orders': '0.510', 'w_recall_clicks': '0.030', 'w_recall_carts': '0.075', 'w_recall_orders': '0.306', 'score': '0.411'}
# 0:34:05.233995 	 [make_candidate] session_latest : start
# 0:34:05.394689 	 [add_candidate] session_latest : start
# 0:34:07.077766 	 session_latest
# 0:34:07.078910 	 {'num_clicks': 97136, 'hit_clicks': 29677, 'num_carts': 42864, 'hit_carts': 10822, 'num_orders': 19985, 'hit_orders': 9838, 'recall_clicks': '0.306', 'recall_carts': '0.252', 'recall_orders': '0.492', 'w_recall_clicks': '0.031', 'w_recall_carts': '0.076', 'w_recall_orders': '0.295', 'score': '0.402'}
# 0:34:07.089465 	 [make_candidate] session_latest_time_wt_pair0 : start
# 0:34:07.498518 	 [add_candidate] session_latest_time_wt_pair0 : start
# 0:34:09.451633 	 session_latest_time_wt_pair0
# 0:34:09.452668 	 {'num_clicks': 97136, 'hit_clicks': 7618, 'num_carts': 37850, 'hit_carts': 2266, 'num_orders': 17856, 'hit_orders': 1476, 'recall_clicks': '0.078', 'recall_carts': '0.060', 'recall_orders': '0.083', 'w_recall_clicks': '0.008', 'w_recall_carts': '0.018', 'w_recall_orders': '0.050', 'score': '0.075'}
# 0:34:09.461915 	 [make_candidate] session_latest_word2vec_pair0 : start
# 0:34:09.986692 	 [add_candidate] session_latest_word2vec_pair0 : start
# 0:34:11.914706 	 session_latest_word2vec_pair0
# 0:34:11.915758 	 {'num_clicks': 97136, 'hit_clicks': 4513, 'num_carts': 37850, 'hit_carts': 1459, 'num_orders': 17856, 'hit_orders': 806, 'recall_clicks': '0.046', 'recall_carts': '0.039', 'recall_orders': '0.045', 'w_recall_clicks': '0.005', 'w_recall_carts': '0.012', 'w_recall_orders': '0.027', 'score': '0.043'}
# 0:34:11.924250 	 [make_candidate] session_latest_pair0 : start
# 0:34:12.438357 	 [add_candidate] session_latest_pair0 : start
# 0:34:14.053845 	 session_latest_pair0
# 0:34:14.054986 	 {'num_clicks': 97136, 'hit_clicks': 6545, 'num_carts': 37850, 'hit_carts': 2105, 'num_orders': 17856, 'hit_orders': 1450, 'recall_clicks': '0.067', 'recall_carts': '0.056', 'recall_orders': '0.081', 'w_recall_clicks': '0.007', 'w_recall_carts': '0.017', 'w_recall_orders': '0.049', 'score': '0.072'}
# 0:34:14.064047 	 [make_candidate] session_latest_type_wt_pair0 : start
# 0:34:14.617479 	 [add_candidate] session_latest_type_wt_pair0 : start
# 0:34:16.482545 	 session_latest_type_wt_pair0
# 0:34:16.483637 	 {'num_clicks': 97136, 'hit_clicks': 6448, 'num_carts': 37850, 'hit_carts': 2324, 'num_orders': 17856, 'hit_orders': 1686, 'recall_clicks': '0.066', 'recall_carts': '0.061', 'recall_orders': '0.094', 'w_recall_clicks': '0.007', 'w_recall_carts': '0.018', 'w_recall_orders': '0.057', 'score': '0.082'}
# 0:34:16.491952 	 [make_candidate] session_latest_clicks2carts_pair0 : start
# 0:34:16.726639 	 [add_candidate] session_latest_clicks2carts_pair0 : start
# 0:34:18.565251 	 session_latest_clicks2carts_pair0
# 0:34:18.566406 	 {'num_clicks': 97136, 'hit_clicks': 4076, 'num_carts': 37850, 'hit_carts': 1700, 'num_orders': 17856, 'hit_orders': 1165, 'recall_clicks': '0.042', 'recall_carts': '0.045', 'recall_orders': '0.065', 'w_recall_clicks': '0.004', 'w_recall_carts': '0.013', 'w_recall_orders': '0.039', 'score': '0.057'}
# 0:34:18.575353 	 [make_candidate] session_latest_clicks2orders_pair0 : start
# 0:34:18.859503 	 [add_candidate] session_latest_clicks2orders_pair0 : start
# 0:34:20.357055 	 session_latest_clicks2orders_pair0
# 0:34:20.358059 	 {'num_clicks': 97136, 'hit_clicks': 2474, 'num_carts': 37850, 'hit_carts': 1174, 'num_orders': 17856, 'hit_orders': 801, 'recall_clicks': '0.025', 'recall_carts': '0.031', 'recall_orders': '0.045', 'w_recall_clicks': '0.003', 'w_recall_carts': '0.009', 'w_recall_orders': '0.027', 'score': '0.039'}
# 0:34:20.366143 	 [make_candidate] session_latest_time_wt_pair1 : start
# 0:34:20.832913 	 [add_candidate] session_latest_time_wt_pair1 : start
# 0:34:22.738449 	 session_latest_time_wt_pair1
# 0:34:22.739753 	 {'num_clicks': 97136, 'hit_clicks': 5373, 'num_carts': 37850, 'hit_carts': 1660, 'num_orders': 17856, 'hit_orders': 1017, 'recall_clicks': '0.055', 'recall_carts': '0.044', 'recall_orders': '0.057', 'w_recall_clicks': '0.006', 'w_recall_carts': '0.013', 'w_recall_orders': '0.034', 'score': '0.053'}
# 0:34:22.749715 	 [make_candidate] session_latest_word2vec_pair1 : start
# 0:34:23.094754 	 [add_candidate] session_latest_word2vec_pair1 : start
# 0:34:25.042031 	 session_latest_word2vec_pair1
# 0:34:25.043018 	 {'num_clicks': 97136, 'hit_clicks': 3132, 'num_carts': 37850, 'hit_carts': 1037, 'num_orders': 17856, 'hit_orders': 580, 'recall_clicks': '0.032', 'recall_carts': '0.027', 'recall_orders': '0.032', 'w_recall_clicks': '0.003', 'w_recall_carts': '0.008', 'w_recall_orders': '0.019', 'score': '0.031'}
# 0:34:25.051973 	 [make_candidate] session_latest_pair1 : start
# 0:34:25.747082 	 [add_candidate] session_latest_pair1 : start
# 0:34:27.689876 	 session_latest_pair1
# 0:34:27.690954 	 {'num_clicks': 97136, 'hit_clicks': 4546, 'num_carts': 37850, 'hit_carts': 1556, 'num_orders': 17856, 'hit_orders': 975, 'recall_clicks': '0.047', 'recall_carts': '0.041', 'recall_orders': '0.055', 'w_recall_clicks': '0.005', 'w_recall_carts': '0.012', 'w_recall_orders': '0.033', 'score': '0.050'}
# 0:34:27.700909 	 [make_candidate] session_latest_type_wt_pair1 : start
# 0:34:28.074097 	 [add_candidate] session_latest_type_wt_pair1 : start
# 0:34:29.737627 	 session_latest_type_wt_pair1
# 0:34:29.738821 	 {'num_clicks': 97136, 'hit_clicks': 4502, 'num_carts': 37850, 'hit_carts': 1629, 'num_orders': 17856, 'hit_orders': 1146, 'recall_clicks': '0.046', 'recall_carts': '0.043', 'recall_orders': '0.064', 'w_recall_clicks': '0.005', 'w_recall_carts': '0.013', 'w_recall_orders': '0.039', 'score': '0.056'}
# 0:34:29.748270 	 [make_candidate] session_latest_clicks2carts_pair1 : start
# 0:34:30.131379 	 [add_candidate] session_latest_clicks2carts_pair1 : start
# 0:34:32.070237 	 session_latest_clicks2carts_pair1
# 0:34:32.071296 	 {'num_clicks': 97136, 'hit_clicks': 2792, 'num_carts': 37850, 'hit_carts': 1165, 'num_orders': 17856, 'hit_orders': 788, 'recall_clicks': '0.029', 'recall_carts': '0.031', 'recall_orders': '0.044', 'w_recall_clicks': '0.003', 'w_recall_carts': '0.009', 'w_recall_orders': '0.026', 'score': '0.039'}
# 0:34:32.080311 	 [make_candidate] session_latest_clicks2orders_pair1 : start
# 0:34:32.238805 	 [add_candidate] session_latest_clicks2orders_pair1 : start
# 0:34:33.787995 	 session_latest_clicks2orders_pair1
# 0:34:33.789050 	 {'num_clicks': 97136, 'hit_clicks': 1539, 'num_carts': 37850, 'hit_carts': 672, 'num_orders': 17856, 'hit_orders': 464, 'recall_clicks': '0.016', 'recall_carts': '0.018', 'recall_orders': '0.026', 'w_recall_clicks': '0.002', 'w_recall_carts': '0.005', 'w_recall_orders': '0.016', 'score': '0.023'}
# 0:34:33.796739 	 [make_candidate] session_latest_time_wt_pair2 : start
# 0:34:34.199638 	 [add_candidate] session_latest_time_wt_pair2 : start
# 0:34:36.215957 	 session_latest_time_wt_pair2
# 0:34:36.217002 	 {'num_clicks': 97136, 'hit_clicks': 4175, 'num_carts': 37850, 'hit_carts': 1366, 'num_orders': 17856, 'hit_orders': 864, 'recall_clicks': '0.043', 'recall_carts': '0.036', 'recall_orders': '0.048', 'w_recall_clicks': '0.004', 'w_recall_carts': '0.011', 'w_recall_orders': '0.029', 'score': '0.044'}
# 0:34:36.226920 	 [make_candidate] session_latest_word2vec_pair2 : start
# 0:34:36.760709 	 [add_candidate] session_latest_word2vec_pair2 : start
# 0:34:38.798838 	 session_latest_word2vec_pair2
# 0:34:38.800207 	 {'num_clicks': 97136, 'hit_clicks': 2525, 'num_carts': 37850, 'hit_carts': 832, 'num_orders': 17856, 'hit_orders': 472, 'recall_clicks': '0.026', 'recall_carts': '0.022', 'recall_orders': '0.026', 'w_recall_clicks': '0.003', 'w_recall_carts': '0.007', 'w_recall_orders': '0.016', 'score': '0.025'}
# 0:34:38.809202 	 [make_candidate] session_latest_pair2 : start
# 0:34:39.324557 	 [add_candidate] session_latest_pair2 : start
# 0:34:41.371835 	 session_latest_pair2
# 0:34:41.372886 	 {'num_clicks': 97136, 'hit_clicks': 3634, 'num_carts': 37850, 'hit_carts': 1301, 'num_orders': 17856, 'hit_orders': 848, 'recall_clicks': '0.037', 'recall_carts': '0.034', 'recall_orders': '0.047', 'w_recall_clicks': '0.004', 'w_recall_carts': '0.010', 'w_recall_orders': '0.028', 'score': '0.043'}
# 0:34:41.383063 	 [make_candidate] session_latest_type_wt_pair2 : start
# 0:34:41.712766 	 [add_candidate] session_latest_type_wt_pair2 : start
# 0:34:43.484409 	 session_latest_type_wt_pair2
# 0:34:43.485517 	 {'num_clicks': 97136, 'hit_clicks': 3486, 'num_carts': 37850, 'hit_carts': 1353, 'num_orders': 17856, 'hit_orders': 928, 'recall_clicks': '0.036', 'recall_carts': '0.036', 'recall_orders': '0.052', 'w_recall_clicks': '0.004', 'w_recall_carts': '0.011', 'w_recall_orders': '0.031', 'score': '0.045'}
# 0:34:43.495309 	 [make_candidate] session_latest_clicks2carts_pair2 : start
# 0:34:43.911614 	 [add_candidate] session_latest_clicks2carts_pair2 : start
# 0:34:45.897157 	 session_latest_clicks2carts_pair2
# 0:34:45.898304 	 {'num_clicks': 97136, 'hit_clicks': 2130, 'num_carts': 37850, 'hit_carts': 991, 'num_orders': 17856, 'hit_orders': 601, 'recall_clicks': '0.022', 'recall_carts': '0.026', 'recall_orders': '0.034', 'w_recall_clicks': '0.002', 'w_recall_carts': '0.008', 'w_recall_orders': '0.020', 'score': '0.030'}
# 0:34:45.908060 	 [make_candidate] session_latest_clicks2orders_pair2 : start
# 0:34:46.062677 	 [add_candidate] session_latest_clicks2orders_pair2 : start
# 0:34:47.693168 	 session_latest_clicks2orders_pair2
# 0:34:47.694228 	 {'num_clicks': 97136, 'hit_clicks': 1141, 'num_carts': 37850, 'hit_carts': 526, 'num_orders': 17856, 'hit_orders': 337, 'recall_clicks': '0.012', 'recall_carts': '0.014', 'recall_orders': '0.019', 'w_recall_clicks': '0.001', 'w_recall_carts': '0.004', 'w_recall_orders': '0.011', 'score': '0.017'}
# 0:34:47.702171 	 [make_candidate] session_latest_time_wt_pair3 : start
# 0:34:48.113533 	 [add_candidate] session_latest_time_wt_pair3 : start
# 0:34:50.210394 	 session_latest_time_wt_pair3
# 0:34:50.211575 	 {'num_clicks': 97136, 'hit_clicks': 3595, 'num_carts': 37850, 'hit_carts': 1288, 'num_orders': 17856, 'hit_orders': 690, 'recall_clicks': '0.037', 'recall_carts': '0.034', 'recall_orders': '0.039', 'w_recall_clicks': '0.004', 'w_recall_carts': '0.010', 'w_recall_orders': '0.023', 'score': '0.037'}
# 0:34:50.221905 	 [make_candidate] session_latest_word2vec_pair3 : start
# 0:34:50.747389 	 [add_candidate] session_latest_word2vec_pair3 : start
# 0:34:52.837317 	 session_latest_word2vec_pair3
# 0:34:52.838394 	 {'num_clicks': 97136, 'hit_clicks': 1970, 'num_carts': 37850, 'hit_carts': 715, 'num_orders': 17856, 'hit_orders': 427, 'recall_clicks': '0.020', 'recall_carts': '0.019', 'recall_orders': '0.024', 'w_recall_clicks': '0.002', 'w_recall_carts': '0.006', 'w_recall_orders': '0.014', 'score': '0.022'}
# 0:34:52.848058 	 [make_candidate] session_latest_pair3 : start
# 0:34:53.272446 	 [add_candidate] session_latest_pair3 : start
# 0:34:55.065600 	 session_latest_pair3
# 0:34:55.066751 	 {'num_clicks': 97136, 'hit_clicks': 2997, 'num_carts': 37850, 'hit_carts': 1064, 'num_orders': 17856, 'hit_orders': 686, 'recall_clicks': '0.031', 'recall_carts': '0.028', 'recall_orders': '0.038', 'w_recall_clicks': '0.003', 'w_recall_carts': '0.008', 'w_recall_orders': '0.023', 'score': '0.035'}
# 0:34:55.076795 	 [make_candidate] session_latest_type_wt_pair3 : start
# 0:34:55.595828 	 [add_candidate] session_latest_type_wt_pair3 : start
# 0:34:57.680999 	 session_latest_type_wt_pair3
# 0:34:57.682110 	 {'num_clicks': 97136, 'hit_clicks': 3009, 'num_carts': 37850, 'hit_carts': 1121, 'num_orders': 17856, 'hit_orders': 795, 'recall_clicks': '0.031', 'recall_carts': '0.030', 'recall_orders': '0.045', 'w_recall_clicks': '0.003', 'w_recall_carts': '0.009', 'w_recall_orders': '0.027', 'score': '0.039'}
# 0:34:57.691468 	 [make_candidate] session_latest_clicks2carts_pair3 : start
# 0:34:57.939175 	 [add_candidate] session_latest_clicks2carts_pair3 : start
# 0:34:59.962138 	 session_latest_clicks2carts_pair3
# 0:34:59.963234 	 {'num_clicks': 97136, 'hit_clicks': 1694, 'num_carts': 37850, 'hit_carts': 811, 'num_orders': 17856, 'hit_orders': 486, 'recall_clicks': '0.017', 'recall_carts': '0.021', 'recall_orders': '0.027', 'w_recall_clicks': '0.002', 'w_recall_carts': '0.006', 'w_recall_orders': '0.016', 'score': '0.025'}
# 0:34:59.972124 	 [make_candidate] session_latest_clicks2orders_pair3 : start
# 0:35:00.266360 	 [add_candidate] session_latest_clicks2orders_pair3 : start
# 0:35:01.844355 	 session_latest_clicks2orders_pair3
# 0:35:01.845399 	 {'num_clicks': 97136, 'hit_clicks': 931, 'num_carts': 37850, 'hit_carts': 435, 'num_orders': 17856, 'hit_orders': 272, 'recall_clicks': '0.010', 'recall_carts': '0.011', 'recall_orders': '0.015', 'w_recall_clicks': '0.001', 'w_recall_carts': '0.003', 'w_recall_orders': '0.009', 'score': '0.014'}
# 0:35:01.852963 	 [make_candidate] session_latest_time_wt_pair4 : start
# 0:35:02.127124 	 [add_candidate] session_latest_time_wt_pair4 : start
# 0:35:04.259031 	 session_latest_time_wt_pair4
# 0:35:04.260448 	 {'num_clicks': 97136, 'hit_clicks': 3085, 'num_carts': 37850, 'hit_carts': 1059, 'num_orders': 17856, 'hit_orders': 661, 'recall_clicks': '0.032', 'recall_carts': '0.028', 'recall_orders': '0.037', 'w_recall_clicks': '0.003', 'w_recall_carts': '0.008', 'w_recall_orders': '0.022', 'score': '0.034'}
# 0:35:04.270595 	 [make_candidate] session_latest_word2vec_pair4 : start
# 0:35:04.715559 	 [add_candidate] session_latest_word2vec_pair4 : start
# 0:35:06.709353 	 session_latest_word2vec_pair4
# 0:35:06.710588 	 {'num_clicks': 97136, 'hit_clicks': 1810, 'num_carts': 37850, 'hit_carts': 600, 'num_orders': 17856, 'hit_orders': 324, 'recall_clicks': '0.019', 'recall_carts': '0.016', 'recall_orders': '0.018', 'w_recall_clicks': '0.002', 'w_recall_carts': '0.005', 'w_recall_orders': '0.011', 'score': '0.018'}
# 0:35:06.720297 	 [make_candidate] session_latest_pair4 : start
# 0:35:07.231702 	 [add_candidate] session_latest_pair4 : start
# 0:35:09.539169 	 session_latest_pair4
# 0:35:09.540578 	 {'num_clicks': 97136, 'hit_clicks': 2561, 'num_carts': 37850, 'hit_carts': 908, 'num_orders': 17856, 'hit_orders': 617, 'recall_clicks': '0.026', 'recall_carts': '0.024', 'recall_orders': '0.035', 'w_recall_clicks': '0.003', 'w_recall_carts': '0.007', 'w_recall_orders': '0.021', 'score': '0.031'}
# 0:35:09.550274 	 [make_candidate] session_latest_type_wt_pair4 : start
# 0:35:09.912602 	 [add_candidate] session_latest_type_wt_pair4 : start
# 0:35:12.203736 	 session_latest_type_wt_pair4
# 0:35:12.204854 	 {'num_clicks': 97136, 'hit_clicks': 2539, 'num_carts': 37850, 'hit_carts': 931, 'num_orders': 17856, 'hit_orders': 686, 'recall_clicks': '0.026', 'recall_carts': '0.025', 'recall_orders': '0.038', 'w_recall_clicks': '0.003', 'w_recall_carts': '0.007', 'w_recall_orders': '0.023', 'score': '0.033'}
# 0:35:12.214540 	 [make_candidate] session_latest_clicks2carts_pair4 : start
# 0:35:12.486053 	 [add_candidate] session_latest_clicks2carts_pair4 : start
# 0:35:14.409536 	 session_latest_clicks2carts_pair4
# 0:35:14.410733 	 {'num_clicks': 97136, 'hit_clicks': 1514, 'num_carts': 37850, 'hit_carts': 675, 'num_orders': 17856, 'hit_orders': 391, 'recall_clicks': '0.016', 'recall_carts': '0.018', 'recall_orders': '0.022', 'w_recall_clicks': '0.002', 'w_recall_carts': '0.005', 'w_recall_orders': '0.013', 'score': '0.020'}
# 0:35:14.420469 	 [make_candidate] session_latest_clicks2orders_pair4 : start
# 0:35:14.827602 	 [add_candidate] session_latest_clicks2orders_pair4 : start
# 0:35:16.884268 	 session_latest_clicks2orders_pair4
# 0:35:16.885350 	 {'num_clicks': 97136, 'hit_clicks': 734, 'num_carts': 37850, 'hit_carts': 355, 'num_orders': 17856, 'hit_orders': 217, 'recall_clicks': '0.008', 'recall_carts': '0.009', 'recall_orders': '0.012', 'w_recall_clicks': '0.001', 'w_recall_carts': '0.003', 'w_recall_orders': '0.007', 'score': '0.011'}
# 0:35:16.893800 	 [make_candidate] session_latest_time_wt_pair5 : start
# 0:35:17.193702 	 [add_candidate] session_latest_time_wt_pair5 : start
# 0:35:19.592040 	 session_latest_time_wt_pair5
# 0:35:19.593310 	 {'num_clicks': 97136, 'hit_clicks': 2645, 'num_carts': 37850, 'hit_carts': 938, 'num_orders': 17856, 'hit_orders': 550, 'recall_clicks': '0.027', 'recall_carts': '0.025', 'recall_orders': '0.031', 'w_recall_clicks': '0.003', 'w_recall_carts': '0.007', 'w_recall_orders': '0.018', 'score': '0.029'}
# 0:35:19.603847 	 [make_candidate] session_latest_word2vec_pair5 : start
# 0:35:20.005743 	 [add_candidate] session_latest_word2vec_pair5 : start
# 0:35:22.014108 	 session_latest_word2vec_pair5
# 0:35:22.015229 	 {'num_clicks': 97136, 'hit_clicks': 1690, 'num_carts': 37850, 'hit_carts': 569, 'num_orders': 17856, 'hit_orders': 338, 'recall_clicks': '0.017', 'recall_carts': '0.015', 'recall_orders': '0.019', 'w_recall_clicks': '0.002', 'w_recall_carts': '0.005', 'w_recall_orders': '0.011', 'score': '0.018'}
# 0:35:22.024561 	 [make_candidate] session_latest_pair5 : start
# 0:35:22.561121 	 [add_candidate] session_latest_pair5 : start
# 0:35:24.908233 	 session_latest_pair5
# 0:35:24.909312 	 {'num_clicks': 97136, 'hit_clicks': 2317, 'num_carts': 37850, 'hit_carts': 784, 'num_orders': 17856, 'hit_orders': 575, 'recall_clicks': '0.024', 'recall_carts': '0.021', 'recall_orders': '0.032', 'w_recall_clicks': '0.002', 'w_recall_carts': '0.006', 'w_recall_orders': '0.019', 'score': '0.028'}
# 0:35:24.918954 	 [make_candidate] session_latest_type_wt_pair5 : start
# 0:35:25.362752 	 [add_candidate] session_latest_type_wt_pair5 : start
# 0:35:27.730506 	 session_latest_type_wt_pair5
# 0:35:27.731575 	 {'num_clicks': 97136, 'hit_clicks': 2285, 'num_carts': 37850, 'hit_carts': 819, 'num_orders': 17856, 'hit_orders': 582, 'recall_clicks': '0.024', 'recall_carts': '0.022', 'recall_orders': '0.033', 'w_recall_clicks': '0.002', 'w_recall_carts': '0.006', 'w_recall_orders': '0.020', 'score': '0.028'}
# 0:35:27.741144 	 [make_candidate] session_latest_clicks2carts_pair5 : start
# 0:35:28.088855 	 [add_candidate] session_latest_clicks2carts_pair5 : start
# 0:35:30.053618 	 session_latest_clicks2carts_pair5
# 0:35:30.054677 	 {'num_clicks': 97136, 'hit_clicks': 1265, 'num_carts': 37850, 'hit_carts': 531, 'num_orders': 17856, 'hit_orders': 325, 'recall_clicks': '0.013', 'recall_carts': '0.014', 'recall_orders': '0.018', 'w_recall_clicks': '0.001', 'w_recall_carts': '0.004', 'w_recall_orders': '0.011', 'score': '0.016'}
# 0:35:30.063904 	 [make_candidate] session_latest_clicks2orders_pair5 : start
# 0:35:30.210963 	 [add_candidate] session_latest_clicks2orders_pair5 : start
# 0:35:32.287175 	 session_latest_clicks2orders_pair5
# 0:35:32.288476 	 {'num_clicks': 97136, 'hit_clicks': 648, 'num_carts': 37850, 'hit_carts': 292, 'num_orders': 17856, 'hit_orders': 206, 'recall_clicks': '0.007', 'recall_carts': '0.008', 'recall_orders': '0.012', 'w_recall_clicks': '0.001', 'w_recall_carts': '0.002', 'w_recall_orders': '0.007', 'score': '0.010'}
# 0:35:32.296622 	 [make_candidate] session_latest_time_wt_pair6 : start
# 0:35:32.718539 	 [add_candidate] session_latest_time_wt_pair6 : start
# 0:35:34.802290 	 session_latest_time_wt_pair6
# 0:35:34.803362 	 {'num_clicks': 97136, 'hit_clicks': 2386, 'num_carts': 37850, 'hit_carts': 791, 'num_orders': 17856, 'hit_orders': 485, 'recall_clicks': '0.025', 'recall_carts': '0.021', 'recall_orders': '0.027', 'w_recall_clicks': '0.002', 'w_recall_carts': '0.006', 'w_recall_orders': '0.016', 'score': '0.025'}
# 0:35:34.813682 	 [make_candidate] session_latest_word2vec_pair6 : start
# 0:35:35.347704 	 [add_candidate] session_latest_word2vec_pair6 : start
# 0:35:37.699542 	 session_latest_word2vec_pair6
# 0:35:37.700808 	 {'num_clicks': 97136, 'hit_clicks': 1628, 'num_carts': 37850, 'hit_carts': 572, 'num_orders': 17856, 'hit_orders': 276, 'recall_clicks': '0.017', 'recall_carts': '0.015', 'recall_orders': '0.015', 'w_recall_clicks': '0.002', 'w_recall_carts': '0.005', 'w_recall_orders': '0.009', 'score': '0.015'}
# 0:35:37.710541 	 [make_candidate] session_latest_pair6 : start
# 0:35:38.014747 	 [add_candidate] session_latest_pair6 : start
# 0:35:40.078917 	 session_latest_pair6
# 0:35:40.080361 	 {'num_clicks': 97136, 'hit_clicks': 1998, 'num_carts': 37850, 'hit_carts': 712, 'num_orders': 17856, 'hit_orders': 494, 'recall_clicks': '0.021', 'recall_carts': '0.019', 'recall_orders': '0.028', 'w_recall_clicks': '0.002', 'w_recall_carts': '0.006', 'w_recall_orders': '0.017', 'score': '0.024'}
# 0:35:40.090121 	 [make_candidate] session_latest_type_wt_pair6 : start
# 0:35:40.518045 	 [add_candidate] session_latest_type_wt_pair6 : start
# 0:35:42.941780 	 session_latest_type_wt_pair6
# 0:35:42.942785 	 {'num_clicks': 97136, 'hit_clicks': 2097, 'num_carts': 37850, 'hit_carts': 800, 'num_orders': 17856, 'hit_orders': 563, 'recall_clicks': '0.022', 'recall_carts': '0.021', 'recall_orders': '0.032', 'w_recall_clicks': '0.002', 'w_recall_carts': '0.006', 'w_recall_orders': '0.019', 'score': '0.027'}
# 0:35:42.952510 	 [make_candidate] session_latest_clicks2carts_pair6 : start
# 0:35:43.293052 	 [add_candidate] session_latest_clicks2carts_pair6 : start
# 0:35:45.537865 	 session_latest_clicks2carts_pair6
# 0:35:45.539021 	 {'num_clicks': 97136, 'hit_clicks': 1146, 'num_carts': 37850, 'hit_carts': 477, 'num_orders': 17856, 'hit_orders': 310, 'recall_clicks': '0.012', 'recall_carts': '0.013', 'recall_orders': '0.017', 'w_recall_clicks': '0.001', 'w_recall_carts': '0.004', 'w_recall_orders': '0.010', 'score': '0.015'}
# 0:35:45.548694 	 [make_candidate] session_latest_clicks2orders_pair6 : start
# 0:35:45.712594 	 [add_candidate] session_latest_clicks2orders_pair6 : start
# 0:35:47.502114 	 session_latest_clicks2orders_pair6
# 0:35:47.503187 	 {'num_clicks': 97136, 'hit_clicks': 543, 'num_carts': 37850, 'hit_carts': 235, 'num_orders': 17856, 'hit_orders': 160, 'recall_clicks': '0.006', 'recall_carts': '0.006', 'recall_orders': '0.009', 'w_recall_clicks': '0.001', 'w_recall_carts': '0.002', 'w_recall_orders': '0.005', 'score': '0.008'}
# 0:35:47.511476 	 [make_candidate] session_latest_time_wt_pair7 : start
# 0:35:47.996393 	 [add_candidate] session_latest_time_wt_pair7 : start
# 0:35:50.411054 	 session_latest_time_wt_pair7
# 0:35:50.412058 	 {'num_clicks': 97136, 'hit_clicks': 2122, 'num_carts': 37850, 'hit_carts': 767, 'num_orders': 17856, 'hit_orders': 452, 'recall_clicks': '0.022', 'recall_carts': '0.020', 'recall_orders': '0.025', 'w_recall_clicks': '0.002', 'w_recall_carts': '0.006', 'w_recall_orders': '0.015', 'score': '0.023'}
# 0:35:50.422317 	 [make_candidate] session_latest_word2vec_pair7 : start
# 0:35:50.744208 	 [add_candidate] session_latest_word2vec_pair7 : start
# 0:35:53.168894 	 session_latest_word2vec_pair7
# 0:35:53.170173 	 {'num_clicks': 97136, 'hit_clicks': 1381, 'num_carts': 37850, 'hit_carts': 469, 'num_orders': 17856, 'hit_orders': 252, 'recall_clicks': '0.014', 'recall_carts': '0.012', 'recall_orders': '0.014', 'w_recall_clicks': '0.001', 'w_recall_carts': '0.004', 'w_recall_orders': '0.008', 'score': '0.014'}
# 0:35:53.179885 	 [make_candidate] session_latest_pair7 : start
# 0:35:53.570371 	 [add_candidate] session_latest_pair7 : start
# 0:35:55.808592 	 session_latest_pair7
# 0:35:55.809666 	 {'num_clicks': 97136, 'hit_clicks': 1852, 'num_carts': 37850, 'hit_carts': 668, 'num_orders': 17856, 'hit_orders': 421, 'recall_clicks': '0.019', 'recall_carts': '0.018', 'recall_orders': '0.024', 'w_recall_clicks': '0.002', 'w_recall_carts': '0.005', 'w_recall_orders': '0.014', 'score': '0.021'}
# 0:35:55.819649 	 [make_candidate] session_latest_type_wt_pair7 : start
# 0:35:56.363158 	 [add_candidate] session_latest_type_wt_pair7 : start
# 0:35:58.817607 	 session_latest_type_wt_pair7
# 0:35:58.818667 	 {'num_clicks': 97136, 'hit_clicks': 1822, 'num_carts': 37850, 'hit_carts': 663, 'num_orders': 17856, 'hit_orders': 477, 'recall_clicks': '0.019', 'recall_carts': '0.018', 'recall_orders': '0.027', 'w_recall_clicks': '0.002', 'w_recall_carts': '0.005', 'w_recall_orders': '0.016', 'score': '0.023'}
# 0:35:58.829579 	 [make_candidate] session_latest_clicks2carts_pair7 : start
# 0:35:59.246949 	 [add_candidate] session_latest_clicks2carts_pair7 : start
# 0:36:01.576504 	 session_latest_clicks2carts_pair7
# 0:36:01.577582 	 {'num_clicks': 97136, 'hit_clicks': 977, 'num_carts': 37850, 'hit_carts': 438, 'num_orders': 17856, 'hit_orders': 265, 'recall_clicks': '0.010', 'recall_carts': '0.012', 'recall_orders': '0.015', 'w_recall_clicks': '0.001', 'w_recall_carts': '0.003', 'w_recall_orders': '0.009', 'score': '0.013'}
# 0:36:01.586975 	 [make_candidate] session_latest_clicks2orders_pair7 : start
# 0:36:01.731565 	 [add_candidate] session_latest_clicks2orders_pair7 : start
# 0:36:03.553370 	 session_latest_clicks2orders_pair7
# 0:36:03.554370 	 {'num_clicks': 97136, 'hit_clicks': 511, 'num_carts': 37850, 'hit_carts': 236, 'num_orders': 17856, 'hit_orders': 147, 'recall_clicks': '0.005', 'recall_carts': '0.006', 'recall_orders': '0.008', 'w_recall_clicks': '0.001', 'w_recall_carts': '0.002', 'w_recall_orders': '0.005', 'score': '0.007'}
# 0:36:03.561942 	 [make_candidate] session_latest_time_wt_pair8 : start
# 0:36:03.994705 	 [add_candidate] session_latest_time_wt_pair8 : start
# 0:36:06.510023 	 session_latest_time_wt_pair8
# 0:36:06.511174 	 {'num_clicks': 97136, 'hit_clicks': 2053, 'num_carts': 37850, 'hit_carts': 682, 'num_orders': 17856, 'hit_orders': 417, 'recall_clicks': '0.021', 'recall_carts': '0.018', 'recall_orders': '0.023', 'w_recall_clicks': '0.002', 'w_recall_carts': '0.005', 'w_recall_orders': '0.014', 'score': '0.022'}
# 0:36:06.521415 	 [make_candidate] session_latest_word2vec_pair8 : start
# 0:36:06.992095 	 [add_candidate] session_latest_word2vec_pair8 : start
# 0:36:09.240828 	 session_latest_word2vec_pair8
# 0:36:09.241918 	 {'num_clicks': 97136, 'hit_clicks': 1295, 'num_carts': 37850, 'hit_carts': 448, 'num_orders': 17856, 'hit_orders': 238, 'recall_clicks': '0.013', 'recall_carts': '0.012', 'recall_orders': '0.013', 'w_recall_clicks': '0.001', 'w_recall_carts': '0.004', 'w_recall_orders': '0.008', 'score': '0.013'}
# 0:36:09.252183 	 [make_candidate] session_latest_pair8 : start
# 0:36:09.618283 	 [add_candidate] session_latest_pair8 : start
# 0:36:12.098428 	 session_latest_pair8
# 0:36:12.099681 	 {'num_clicks': 97136, 'hit_clicks': 1795, 'num_carts': 37850, 'hit_carts': 643, 'num_orders': 17856, 'hit_orders': 432, 'recall_clicks': '0.018', 'recall_carts': '0.017', 'recall_orders': '0.024', 'w_recall_clicks': '0.002', 'w_recall_carts': '0.005', 'w_recall_orders': '0.015', 'score': '0.021'}
# 0:36:12.109923 	 [make_candidate] session_latest_type_wt_pair8 : start
# 0:36:12.674253 	 [add_candidate] session_latest_type_wt_pair8 : start
# 0:36:15.160903 	 session_latest_type_wt_pair8
# 0:36:15.161902 	 {'num_clicks': 97136, 'hit_clicks': 1697, 'num_carts': 37850, 'hit_carts': 640, 'num_orders': 17856, 'hit_orders': 458, 'recall_clicks': '0.017', 'recall_carts': '0.017', 'recall_orders': '0.026', 'w_recall_clicks': '0.002', 'w_recall_carts': '0.005', 'w_recall_orders': '0.015', 'score': '0.022'}
# 0:36:15.172017 	 [make_candidate] session_latest_clicks2carts_pair8 : start
# 0:36:15.361733 	 [add_candidate] session_latest_clicks2carts_pair8 : start
# 0:36:17.436887 	 session_latest_clicks2carts_pair8
# 0:36:17.438029 	 {'num_clicks': 97136, 'hit_clicks': 928, 'num_carts': 37850, 'hit_carts': 397, 'num_orders': 17856, 'hit_orders': 264, 'recall_clicks': '0.010', 'recall_carts': '0.010', 'recall_orders': '0.015', 'w_recall_clicks': '0.001', 'w_recall_carts': '0.003', 'w_recall_orders': '0.009', 'score': '0.013'}
# 0:36:17.447374 	 [make_candidate] session_latest_clicks2orders_pair8 : start
# 0:36:17.709260 	 [add_candidate] session_latest_clicks2orders_pair8 : start
# 0:36:19.890590 	 session_latest_clicks2orders_pair8
# 0:36:19.891649 	 {'num_clicks': 97136, 'hit_clicks': 453, 'num_carts': 37850, 'hit_carts': 194, 'num_orders': 17856, 'hit_orders': 130, 'recall_clicks': '0.005', 'recall_carts': '0.005', 'recall_orders': '0.007', 'w_recall_clicks': '0.000', 'w_recall_carts': '0.002', 'w_recall_orders': '0.004', 'score': '0.006'}
# 0:36:19.899994 	 [make_candidate] session_latest_time_wt_pair9 : start
# 0:36:20.400004 	 [add_candidate] session_latest_time_wt_pair9 : start
# 0:36:22.665507 	 session_latest_time_wt_pair9
# 0:36:22.666502 	 {'num_clicks': 97136, 'hit_clicks': 1852, 'num_carts': 37850, 'hit_carts': 665, 'num_orders': 17856, 'hit_orders': 437, 'recall_clicks': '0.019', 'recall_carts': '0.018', 'recall_orders': '0.024', 'w_recall_clicks': '0.002', 'w_recall_carts': '0.005', 'w_recall_orders': '0.015', 'score': '0.022'}
# 0:36:22.675994 	 [make_candidate] session_latest_word2vec_pair9 : start
# 0:36:22.967137 	 [add_candidate] session_latest_word2vec_pair9 : start
# 0:36:25.513817 	 session_latest_word2vec_pair9
# 0:36:25.514972 	 {'num_clicks': 97136, 'hit_clicks': 1134, 'num_carts': 37850, 'hit_carts': 385, 'num_orders': 17856, 'hit_orders': 207, 'recall_clicks': '0.012', 'recall_carts': '0.010', 'recall_orders': '0.012', 'w_recall_clicks': '0.001', 'w_recall_carts': '0.003', 'w_recall_orders': '0.007', 'score': '0.011'}
# 0:36:25.525094 	 [make_candidate] session_latest_pair9 : start
# 0:36:25.919095 	 [add_candidate] session_latest_pair9 : start
# 0:36:28.465605 	 session_latest_pair9
# 0:36:28.466706 	 {'num_clicks': 97136, 'hit_clicks': 1559, 'num_carts': 37850, 'hit_carts': 596, 'num_orders': 17856, 'hit_orders': 386, 'recall_clicks': '0.016', 'recall_carts': '0.016', 'recall_orders': '0.022', 'w_recall_clicks': '0.002', 'w_recall_carts': '0.005', 'w_recall_orders': '0.013', 'score': '0.019'}
# 0:36:28.476362 	 [make_candidate] session_latest_type_wt_pair9 : start
# 0:36:29.135564 	 [add_candidate] session_latest_type_wt_pair9 : start
# 0:36:31.416051 	 session_latest_type_wt_pair9
# 0:36:31.417133 	 {'num_clicks': 97136, 'hit_clicks': 1635, 'num_carts': 37850, 'hit_carts': 594, 'num_orders': 17856, 'hit_orders': 454, 'recall_clicks': '0.017', 'recall_carts': '0.016', 'recall_orders': '0.025', 'w_recall_clicks': '0.002', 'w_recall_carts': '0.005', 'w_recall_orders': '0.015', 'score': '0.022'}
# 0:36:31.427044 	 [make_candidate] session_latest_clicks2carts_pair9 : start
# 0:36:31.683439 	 [add_candidate] session_latest_clicks2carts_pair9 : start
# 0:36:34.420862 	 session_latest_clicks2carts_pair9
# 0:36:34.421880 	 {'num_clicks': 97136, 'hit_clicks': 816, 'num_carts': 37850, 'hit_carts': 338, 'num_orders': 17856, 'hit_orders': 232, 'recall_clicks': '0.008', 'recall_carts': '0.009', 'recall_orders': '0.013', 'w_recall_clicks': '0.001', 'w_recall_carts': '0.003', 'w_recall_orders': '0.008', 'score': '0.011'}
# 0:36:34.430876 	 [make_candidate] session_latest_clicks2orders_pair9 : start
# 0:36:34.816138 	 [add_candidate] session_latest_clicks2orders_pair9 : start
# 0:36:37.083564 	 session_latest_clicks2orders_pair9
# 0:36:37.084676 	 {'num_clicks': 97136, 'hit_clicks': 386, 'num_carts': 37850, 'hit_carts': 202, 'num_orders': 17856, 'hit_orders': 131, 'recall_clicks': '0.004', 'recall_carts': '0.005', 'recall_orders': '0.007', 'w_recall_clicks': '0.000', 'w_recall_carts': '0.002', 'w_recall_orders': '0.004', 'score': '0.006'}
# 0:36:37.093093 	 [make_candidate] session_latest_time_wt_pair10 : start
# 0:36:37.385640 	 [add_candidate] session_latest_time_wt_pair10 : start
# 0:36:40.354572 	 session_latest_time_wt_pair10
# 0:36:40.355677 	 {'num_clicks': 97136, 'hit_clicks': 1720, 'num_carts': 37850, 'hit_carts': 583, 'num_orders': 17856, 'hit_orders': 388, 'recall_clicks': '0.018', 'recall_carts': '0.015', 'recall_orders': '0.022', 'w_recall_clicks': '0.002', 'w_recall_carts': '0.005', 'w_recall_orders': '0.013', 'score': '0.019'}
# 0:36:40.365875 	 [make_candidate] session_latest_word2vec_pair10 : start
# 0:36:40.934279 	 [add_candidate] session_latest_word2vec_pair10 : start
# 0:36:43.978538 	 session_latest_word2vec_pair10
# 0:36:43.979760 	 {'num_clicks': 97136, 'hit_clicks': 1080, 'num_carts': 37850, 'hit_carts': 367, 'num_orders': 17856, 'hit_orders': 234, 'recall_clicks': '0.011', 'recall_carts': '0.010', 'recall_orders': '0.013', 'w_recall_clicks': '0.001', 'w_recall_carts': '0.003', 'w_recall_orders': '0.008', 'score': '0.012'}
# 0:36:43.990508 	 [make_candidate] session_latest_pair10 : start
# 0:36:44.367207 	 [add_candidate] session_latest_pair10 : start
# 0:36:47.327760 	 session_latest_pair10
# 0:36:47.328845 	 {'num_clicks': 97136, 'hit_clicks': 1394, 'num_carts': 37850, 'hit_carts': 514, 'num_orders': 17856, 'hit_orders': 325, 'recall_clicks': '0.014', 'recall_carts': '0.014', 'recall_orders': '0.018', 'w_recall_clicks': '0.001', 'w_recall_carts': '0.004', 'w_recall_orders': '0.011', 'score': '0.016'}
# 0:36:47.339249 	 [make_candidate] session_latest_type_wt_pair10 : start
# 0:36:47.817249 	 [add_candidate] session_latest_type_wt_pair10 : start
# 0:36:50.472393 	 session_latest_type_wt_pair10
# 0:36:50.473549 	 {'num_clicks': 97136, 'hit_clicks': 1471, 'num_carts': 37850, 'hit_carts': 581, 'num_orders': 17856, 'hit_orders': 397, 'recall_clicks': '0.015', 'recall_carts': '0.015', 'recall_orders': '0.022', 'w_recall_clicks': '0.002', 'w_recall_carts': '0.005', 'w_recall_orders': '0.013', 'score': '0.019'}
# 0:36:50.483883 	 [make_candidate] session_latest_clicks2carts_pair10 : start
# 0:36:50.760977 	 [add_candidate] session_latest_clicks2carts_pair10 : start
# 0:36:53.551653 	 session_latest_clicks2carts_pair10
# 0:36:53.552733 	 {'num_clicks': 97136, 'hit_clicks': 787, 'num_carts': 37850, 'hit_carts': 320, 'num_orders': 17856, 'hit_orders': 232, 'recall_clicks': '0.008', 'recall_carts': '0.008', 'recall_orders': '0.013', 'w_recall_clicks': '0.001', 'w_recall_carts': '0.003', 'w_recall_orders': '0.008', 'score': '0.011'}
# 0:36:53.562243 	 [make_candidate] session_latest_clicks2orders_pair10 : start
# 0:36:53.945002 	 [add_candidate] session_latest_clicks2orders_pair10 : start
# 0:36:56.251057 	 session_latest_clicks2orders_pair10
# 0:36:56.252110 	 {'num_clicks': 97136, 'hit_clicks': 380, 'num_carts': 37850, 'hit_carts': 178, 'num_orders': 17856, 'hit_orders': 113, 'recall_clicks': '0.004', 'recall_carts': '0.005', 'recall_orders': '0.006', 'w_recall_clicks': '0.000', 'w_recall_carts': '0.001', 'w_recall_orders': '0.004', 'score': '0.006'}
# 0:36:56.259905 	 [make_candidate] session_latest_time_wt_pair11 : start
# 0:36:56.758824 	 [add_candidate] session_latest_time_wt_pair11 : start
# 0:36:59.745044 	 session_latest_time_wt_pair11
# 0:36:59.746086 	 {'num_clicks': 97136, 'hit_clicks': 1571, 'num_carts': 37850, 'hit_carts': 588, 'num_orders': 17856, 'hit_orders': 362, 'recall_clicks': '0.016', 'recall_carts': '0.016', 'recall_orders': '0.020', 'w_recall_clicks': '0.002', 'w_recall_carts': '0.005', 'w_recall_orders': '0.012', 'score': '0.018'}
# 0:36:59.756717 	 [make_candidate] session_latest_word2vec_pair11 : start
# 0:37:00.167139 	 [add_candidate] session_latest_word2vec_pair11 : start
# 0:37:02.917943 	 session_latest_word2vec_pair11
# 0:37:02.919205 	 {'num_clicks': 97136, 'hit_clicks': 1016, 'num_carts': 37850, 'hit_carts': 386, 'num_orders': 17856, 'hit_orders': 199, 'recall_clicks': '0.010', 'recall_carts': '0.010', 'recall_orders': '0.011', 'w_recall_clicks': '0.001', 'w_recall_carts': '0.003', 'w_recall_orders': '0.007', 'score': '0.011'}
# 0:37:02.930064 	 [make_candidate] session_latest_pair11 : start
# 0:37:03.337305 	 [add_candidate] session_latest_pair11 : start
# 0:37:06.323085 	 session_latest_pair11
# 0:37:06.324168 	 {'num_clicks': 97136, 'hit_clicks': 1288, 'num_carts': 37850, 'hit_carts': 518, 'num_orders': 17856, 'hit_orders': 332, 'recall_clicks': '0.013', 'recall_carts': '0.014', 'recall_orders': '0.019', 'w_recall_clicks': '0.001', 'w_recall_carts': '0.004', 'w_recall_orders': '0.011', 'score': '0.017'}
# 0:37:06.334366 	 [make_candidate] session_latest_type_wt_pair11 : start
# 0:37:06.818787 	 [add_candidate] session_latest_type_wt_pair11 : start
# 0:37:09.861609 	 session_latest_type_wt_pair11
# 0:37:09.862618 	 {'num_clicks': 97136, 'hit_clicks': 1349, 'num_carts': 37850, 'hit_carts': 520, 'num_orders': 17856, 'hit_orders': 392, 'recall_clicks': '0.014', 'recall_carts': '0.014', 'recall_orders': '0.022', 'w_recall_clicks': '0.001', 'w_recall_carts': '0.004', 'w_recall_orders': '0.013', 'score': '0.019'}
# 0:37:09.873321 	 [make_candidate] session_latest_clicks2carts_pair11 : start
# 0:37:10.248608 	 [add_candidate] session_latest_clicks2carts_pair11 : start
# 0:37:12.780434 	 session_latest_clicks2carts_pair11
# 0:37:12.781446 	 {'num_clicks': 97136, 'hit_clicks': 707, 'num_carts': 37850, 'hit_carts': 292, 'num_orders': 17856, 'hit_orders': 195, 'recall_clicks': '0.007', 'recall_carts': '0.008', 'recall_orders': '0.011', 'w_recall_clicks': '0.001', 'w_recall_carts': '0.002', 'w_recall_orders': '0.007', 'score': '0.010'}
# 0:37:12.790724 	 [make_candidate] session_latest_clicks2orders_pair11 : start
# 0:37:13.004659 	 [add_candidate] session_latest_clicks2orders_pair11 : start
# 0:37:15.658285 	 session_latest_clicks2orders_pair11
# 0:37:15.659354 	 {'num_clicks': 97136, 'hit_clicks': 319, 'num_carts': 37850, 'hit_carts': 160, 'num_orders': 17856, 'hit_orders': 112, 'recall_clicks': '0.003', 'recall_carts': '0.004', 'recall_orders': '0.006', 'w_recall_clicks': '0.000', 'w_recall_carts': '0.001', 'w_recall_orders': '0.004', 'score': '0.005'}
# 0:37:15.667354 	 [make_candidate] session_latest_time_wt_pair12 : start
# 0:37:16.161728 	 [add_candidate] session_latest_time_wt_pair12 : start
# 0:37:18.867987 	 session_latest_time_wt_pair12
# 0:37:18.869061 	 {'num_clicks': 97136, 'hit_clicks': 1496, 'num_carts': 37850, 'hit_carts': 576, 'num_orders': 17856, 'hit_orders': 338, 'recall_clicks': '0.015', 'recall_carts': '0.015', 'recall_orders': '0.019', 'w_recall_clicks': '0.002', 'w_recall_carts': '0.005', 'w_recall_orders': '0.011', 'score': '0.017'}
# 0:37:18.879058 	 [make_candidate] session_latest_word2vec_pair12 : start
# 0:37:19.207758 	 [add_candidate] session_latest_word2vec_pair12 : start
# 0:37:22.223197 	 session_latest_word2vec_pair12
# 0:37:22.224303 	 {'num_clicks': 97136, 'hit_clicks': 990, 'num_carts': 37850, 'hit_carts': 359, 'num_orders': 17856, 'hit_orders': 208, 'recall_clicks': '0.010', 'recall_carts': '0.009', 'recall_orders': '0.012', 'w_recall_clicks': '0.001', 'w_recall_carts': '0.003', 'w_recall_orders': '0.007', 'score': '0.011'}
# 0:37:22.235073 	 [make_candidate] session_latest_pair12 : start
# 0:37:22.733370 	 [add_candidate] session_latest_pair12 : start
# 0:37:25.744617 	 session_latest_pair12
# 0:37:25.745659 	 {'num_clicks': 97136, 'hit_clicks': 1223, 'num_carts': 37850, 'hit_carts': 464, 'num_orders': 17856, 'hit_orders': 277, 'recall_clicks': '0.013', 'recall_carts': '0.012', 'recall_orders': '0.016', 'w_recall_clicks': '0.001', 'w_recall_carts': '0.004', 'w_recall_orders': '0.009', 'score': '0.014'}
# 0:37:25.755986 	 [make_candidate] session_latest_type_wt_pair12 : start
# 0:37:26.136810 	 [add_candidate] session_latest_type_wt_pair12 : start
# 0:37:29.181570 	 session_latest_type_wt_pair12
# 0:37:29.182608 	 {'num_clicks': 97136, 'hit_clicks': 1316, 'num_carts': 37850, 'hit_carts': 492, 'num_orders': 17856, 'hit_orders': 365, 'recall_clicks': '0.014', 'recall_carts': '0.013', 'recall_orders': '0.020', 'w_recall_clicks': '0.001', 'w_recall_carts': '0.004', 'w_recall_orders': '0.012', 'score': '0.018'}
# 0:37:29.194027 	 [make_candidate] session_latest_clicks2carts_pair12 : start
# 0:37:29.604192 	 [add_candidate] session_latest_clicks2carts_pair12 : start
# 0:37:32.194211 	 session_latest_clicks2carts_pair12
# 0:37:32.195345 	 {'num_clicks': 97136, 'hit_clicks': 642, 'num_carts': 37850, 'hit_carts': 257, 'num_orders': 17856, 'hit_orders': 184, 'recall_clicks': '0.007', 'recall_carts': '0.007', 'recall_orders': '0.010', 'w_recall_clicks': '0.001', 'w_recall_carts': '0.002', 'w_recall_orders': '0.006', 'score': '0.009'}
# 0:37:32.204353 	 [make_candidate] session_latest_clicks2orders_pair12 : start
# 0:37:32.414821 	 [add_candidate] session_latest_clicks2orders_pair12 : start
# 0:37:34.753674 	 session_latest_clicks2orders_pair12
# 0:37:34.754723 	 {'num_clicks': 97136, 'hit_clicks': 301, 'num_carts': 37850, 'hit_carts': 142, 'num_orders': 17856, 'hit_orders': 108, 'recall_clicks': '0.003', 'recall_carts': '0.004', 'recall_orders': '0.006', 'w_recall_clicks': '0.000', 'w_recall_carts': '0.001', 'w_recall_orders': '0.004', 'score': '0.005'}
# 0:37:34.761783 	 [make_candidate] session_latest_time_wt_pair13 : start
# 0:37:35.322231 	 [add_candidate] session_latest_time_wt_pair13 : start
# 0:37:38.430057 	 session_latest_time_wt_pair13
# 0:37:38.431293 	 {'num_clicks': 97136, 'hit_clicks': 1354, 'num_carts': 37850, 'hit_carts': 530, 'num_orders': 17856, 'hit_orders': 341, 'recall_clicks': '0.014', 'recall_carts': '0.014', 'recall_orders': '0.019', 'w_recall_clicks': '0.001', 'w_recall_carts': '0.004', 'w_recall_orders': '0.011', 'score': '0.017'}
# 0:37:38.441627 	 [make_candidate] session_latest_word2vec_pair13 : start
# 0:37:38.838382 	 [add_candidate] session_latest_word2vec_pair13 : start
# 0:37:41.963006 	 session_latest_word2vec_pair13
# 0:37:41.964027 	 {'num_clicks': 97136, 'hit_clicks': 923, 'num_carts': 37850, 'hit_carts': 348, 'num_orders': 17856, 'hit_orders': 169, 'recall_clicks': '0.010', 'recall_carts': '0.009', 'recall_orders': '0.009', 'w_recall_clicks': '0.001', 'w_recall_carts': '0.003', 'w_recall_orders': '0.006', 'score': '0.009'}
# 0:37:41.974576 	 [make_candidate] session_latest_pair13 : start
# 0:37:42.487647 	 [add_candidate] session_latest_pair13 : start
# 0:37:45.640165 	 session_latest_pair13
# 0:37:45.641179 	 {'num_clicks': 97136, 'hit_clicks': 1154, 'num_carts': 37850, 'hit_carts': 433, 'num_orders': 17856, 'hit_orders': 285, 'recall_clicks': '0.012', 'recall_carts': '0.011', 'recall_orders': '0.016', 'w_recall_clicks': '0.001', 'w_recall_carts': '0.003', 'w_recall_orders': '0.010', 'score': '0.014'}
# 0:37:45.651123 	 [make_candidate] session_latest_type_wt_pair13 : start
# 0:37:46.075414 	 [add_candidate] session_latest_type_wt_pair13 : start
# 0:37:48.965096 	 session_latest_type_wt_pair13
# 0:37:48.966208 	 {'num_clicks': 97136, 'hit_clicks': 1146, 'num_carts': 37850, 'hit_carts': 496, 'num_orders': 17856, 'hit_orders': 326, 'recall_clicks': '0.012', 'recall_carts': '0.013', 'recall_orders': '0.018', 'w_recall_clicks': '0.001', 'w_recall_carts': '0.004', 'w_recall_orders': '0.011', 'score': '0.016'}
# 0:37:48.976428 	 [make_candidate] session_latest_clicks2carts_pair13 : start
# 0:37:49.378056 	 [add_candidate] session_latest_clicks2carts_pair13 : start
# 0:37:52.344798 	 session_latest_clicks2carts_pair13
# 0:37:52.345795 	 {'num_clicks': 97136, 'hit_clicks': 586, 'num_carts': 37850, 'hit_carts': 233, 'num_orders': 17856, 'hit_orders': 150, 'recall_clicks': '0.006', 'recall_carts': '0.006', 'recall_orders': '0.008', 'w_recall_clicks': '0.001', 'w_recall_carts': '0.002', 'w_recall_orders': '0.005', 'score': '0.007'}
# 0:37:52.354997 	 [make_candidate] session_latest_clicks2orders_pair13 : start
# 0:37:52.578701 	 [add_candidate] session_latest_clicks2orders_pair13 : start
# 0:37:55.019567 	 session_latest_clicks2orders_pair13
# 0:37:55.020702 	 {'num_clicks': 97136, 'hit_clicks': 312, 'num_carts': 37850, 'hit_carts': 121, 'num_orders': 17856, 'hit_orders': 86, 'recall_clicks': '0.003', 'recall_carts': '0.003', 'recall_orders': '0.005', 'w_recall_clicks': '0.000', 'w_recall_carts': '0.001', 'w_recall_orders': '0.003', 'score': '0.004'}
# 0:37:55.028579 	 [make_candidate] session_latest_time_wt_pair14 : start
# 0:37:55.576128 	 [add_candidate] session_latest_time_wt_pair14 : start
# 0:37:58.741528 	 session_latest_time_wt_pair14
# 0:37:58.742726 	 {'num_clicks': 97136, 'hit_clicks': 1285, 'num_carts': 37850, 'hit_carts': 504, 'num_orders': 17856, 'hit_orders': 286, 'recall_clicks': '0.013', 'recall_carts': '0.013', 'recall_orders': '0.016', 'w_recall_clicks': '0.001', 'w_recall_carts': '0.004', 'w_recall_orders': '0.010', 'score': '0.015'}
# 0:37:58.753799 	 [make_candidate] session_latest_word2vec_pair14 : start
# 0:37:59.204122 	 [add_candidate] session_latest_word2vec_pair14 : start
# 0:38:02.438156 	 session_latest_word2vec_pair14
# 0:38:02.439262 	 {'num_clicks': 97136, 'hit_clicks': 852, 'num_carts': 37850, 'hit_carts': 308, 'num_orders': 17856, 'hit_orders': 161, 'recall_clicks': '0.009', 'recall_carts': '0.008', 'recall_orders': '0.009', 'w_recall_clicks': '0.001', 'w_recall_carts': '0.002', 'w_recall_orders': '0.005', 'score': '0.009'}
# 0:38:02.450357 	 [make_candidate] session_latest_pair14 : start
# 0:38:02.925585 	 [add_candidate] session_latest_pair14 : start
# 0:38:05.870260 	 session_latest_pair14
# 0:38:05.871267 	 {'num_clicks': 97136, 'hit_clicks': 1112, 'num_carts': 37850, 'hit_carts': 417, 'num_orders': 17856, 'hit_orders': 292, 'recall_clicks': '0.011', 'recall_carts': '0.011', 'recall_orders': '0.016', 'w_recall_clicks': '0.001', 'w_recall_carts': '0.003', 'w_recall_orders': '0.010', 'score': '0.014'}
# 0:38:05.881948 	 [make_candidate] session_latest_type_wt_pair14 : start
# 0:38:06.243133 	 [add_candidate] session_latest_type_wt_pair14 : start
# 0:38:09.439301 	 session_latest_type_wt_pair14
# 0:38:09.440562 	 {'num_clicks': 97136, 'hit_clicks': 1108, 'num_carts': 37850, 'hit_carts': 416, 'num_orders': 17856, 'hit_orders': 328, 'recall_clicks': '0.011', 'recall_carts': '0.011', 'recall_orders': '0.018', 'w_recall_clicks': '0.001', 'w_recall_carts': '0.003', 'w_recall_orders': '0.011', 'score': '0.015'}
# 0:38:09.450912 	 [make_candidate] session_latest_clicks2carts_pair14 : start
# 0:38:09.821128 	 [add_candidate] session_latest_clicks2carts_pair14 : start
# 0:38:12.882514 	 session_latest_clicks2carts_pair14
# 0:38:12.883666 	 {'num_clicks': 97136, 'hit_clicks': 601, 'num_carts': 37850, 'hit_carts': 223, 'num_orders': 17856, 'hit_orders': 143, 'recall_clicks': '0.006', 'recall_carts': '0.006', 'recall_orders': '0.008', 'w_recall_clicks': '0.001', 'w_recall_carts': '0.002', 'w_recall_orders': '0.005', 'score': '0.007'}
# 0:38:12.892951 	 [make_candidate] session_latest_clicks2orders_pair14 : start
# 0:38:13.124076 	 [add_candidate] session_latest_clicks2orders_pair14 : start
# 0:38:15.620920 	 session_latest_clicks2orders_pair14
# 0:38:15.622061 	 {'num_clicks': 97136, 'hit_clicks': 239, 'num_carts': 37850, 'hit_carts': 101, 'num_orders': 17856, 'hit_orders': 65, 'recall_clicks': '0.002', 'recall_carts': '0.003', 'recall_orders': '0.004', 'w_recall_clicks': '0.000', 'w_recall_carts': '0.001', 'w_recall_orders': '0.002', 'score': '0.003'}
# 0:38:15.629690 	 [make_candidate] session_latest_time_wt_pair15 : start
# 0:38:16.207823 	 [add_candidate] session_latest_time_wt_pair15 : start
# 0:38:19.458390 	 session_latest_time_wt_pair15
# 0:38:19.459613 	 {'num_clicks': 97136, 'hit_clicks': 1199, 'num_carts': 37850, 'hit_carts': 434, 'num_orders': 17856, 'hit_orders': 278, 'recall_clicks': '0.012', 'recall_carts': '0.011', 'recall_orders': '0.016', 'w_recall_clicks': '0.001', 'w_recall_carts': '0.003', 'w_recall_orders': '0.009', 'score': '0.014'}
# 0:38:19.470292 	 [make_candidate] session_latest_word2vec_pair15 : start
# 0:38:19.881672 	 [add_candidate] session_latest_word2vec_pair15 : start
# 0:38:22.832060 	 session_latest_word2vec_pair15
# 0:38:22.833140 	 {'num_clicks': 97136, 'hit_clicks': 877, 'num_carts': 37850, 'hit_carts': 306, 'num_orders': 17856, 'hit_orders': 176, 'recall_clicks': '0.009', 'recall_carts': '0.008', 'recall_orders': '0.010', 'w_recall_clicks': '0.001', 'w_recall_carts': '0.002', 'w_recall_orders': '0.006', 'score': '0.009'}
# 0:38:22.843800 	 [make_candidate] session_latest_pair15 : start
# 0:38:23.218523 	 [add_candidate] session_latest_pair15 : start
# 0:38:26.495637 	 session_latest_pair15
# 0:38:26.496680 	 {'num_clicks': 97136, 'hit_clicks': 1024, 'num_carts': 37850, 'hit_carts': 369, 'num_orders': 17856, 'hit_orders': 260, 'recall_clicks': '0.011', 'recall_carts': '0.010', 'recall_orders': '0.015', 'w_recall_clicks': '0.001', 'w_recall_carts': '0.003', 'w_recall_orders': '0.009', 'score': '0.013'}
# 0:38:26.508404 	 [make_candidate] session_latest_type_wt_pair15 : start
# 0:38:26.967891 	 [add_candidate] session_latest_type_wt_pair15 : start
# 0:38:30.206975 	 session_latest_type_wt_pair15
# 0:38:30.207978 	 {'num_clicks': 97136, 'hit_clicks': 1085, 'num_carts': 37850, 'hit_carts': 422, 'num_orders': 17856, 'hit_orders': 311, 'recall_clicks': '0.011', 'recall_carts': '0.011', 'recall_orders': '0.017', 'w_recall_clicks': '0.001', 'w_recall_carts': '0.003', 'w_recall_orders': '0.010', 'score': '0.015'}
# 0:38:30.218665 	 [make_candidate] session_latest_clicks2carts_pair15 : start
# 0:38:30.435762 	 [add_candidate] session_latest_clicks2carts_pair15 : start
# 0:38:33.247581 	 session_latest_clicks2carts_pair15
# 0:38:33.248706 	 {'num_clicks': 97136, 'hit_clicks': 488, 'num_carts': 37850, 'hit_carts': 241, 'num_orders': 17856, 'hit_orders': 148, 'recall_clicks': '0.005', 'recall_carts': '0.006', 'recall_orders': '0.008', 'w_recall_clicks': '0.001', 'w_recall_carts': '0.002', 'w_recall_orders': '0.005', 'score': '0.007'}
# 0:38:33.258523 	 [make_candidate] session_latest_clicks2orders_pair15 : start
# 0:38:33.602396 	 [add_candidate] session_latest_clicks2orders_pair15 : start
# 0:38:36.097012 	 session_latest_clicks2orders_pair15
# 0:38:36.098032 	 {'num_clicks': 97136, 'hit_clicks': 238, 'num_carts': 37850, 'hit_carts': 110, 'num_orders': 17856, 'hit_orders': 70, 'recall_clicks': '0.002', 'recall_carts': '0.003', 'recall_orders': '0.004', 'w_recall_clicks': '0.000', 'w_recall_carts': '0.001', 'w_recall_orders': '0.002', 'score': '0.003'}
# 0:38:36.105494 	 [make_candidate] session_latest_time_wt_pair16 : start
# 0:38:36.482200 	 [add_candidate] session_latest_time_wt_pair16 : start
# 0:38:39.815885 	 session_latest_time_wt_pair16
# 0:38:39.816940 	 {'num_clicks': 97136, 'hit_clicks': 1148, 'num_carts': 37850, 'hit_carts': 443, 'num_orders': 17856, 'hit_orders': 298, 'recall_clicks': '0.012', 'recall_carts': '0.012', 'recall_orders': '0.017', 'w_recall_clicks': '0.001', 'w_recall_carts': '0.004', 'w_recall_orders': '0.010', 'score': '0.015'}
# 0:38:39.828182 	 [make_candidate] session_latest_word2vec_pair16 : start
# 0:38:40.325067 	 [add_candidate] session_latest_word2vec_pair16 : start
# 0:38:43.718642 	 session_latest_word2vec_pair16
# 0:38:43.719900 	 {'num_clicks': 97136, 'hit_clicks': 789, 'num_carts': 37850, 'hit_carts': 268, 'num_orders': 17856, 'hit_orders': 140, 'recall_clicks': '0.008', 'recall_carts': '0.007', 'recall_orders': '0.008', 'w_recall_clicks': '0.001', 'w_recall_carts': '0.002', 'w_recall_orders': '0.005', 'score': '0.008'}
# 0:38:43.731018 	 [make_candidate] session_latest_pair16 : start
# 0:38:44.128555 	 [add_candidate] session_latest_pair16 : start
# 0:38:47.494743 	 session_latest_pair16
# 0:38:47.495865 	 {'num_clicks': 97136, 'hit_clicks': 918, 'num_carts': 37850, 'hit_carts': 377, 'num_orders': 17856, 'hit_orders': 260, 'recall_clicks': '0.009', 'recall_carts': '0.010', 'recall_orders': '0.015', 'w_recall_clicks': '0.001', 'w_recall_carts': '0.003', 'w_recall_orders': '0.009', 'score': '0.013'}
# 0:38:47.505595 	 [make_candidate] session_latest_type_wt_pair16 : start
# 0:38:47.784188 	 [add_candidate] session_latest_type_wt_pair16 : start
# 0:38:50.850068 	 session_latest_type_wt_pair16
# 0:38:50.851146 	 {'num_clicks': 97136, 'hit_clicks': 975, 'num_carts': 37850, 'hit_carts': 376, 'num_orders': 17856, 'hit_orders': 270, 'recall_clicks': '0.010', 'recall_carts': '0.010', 'recall_orders': '0.015', 'w_recall_clicks': '0.001', 'w_recall_carts': '0.003', 'w_recall_orders': '0.009', 'score': '0.013'}
# 0:38:50.861259 	 [make_candidate] session_latest_clicks2carts_pair16 : start
# 0:38:51.197418 	 [add_candidate] session_latest_clicks2carts_pair16 : start
# 0:38:54.410502 	 session_latest_clicks2carts_pair16
# 0:38:54.411793 	 {'num_clicks': 97136, 'hit_clicks': 488, 'num_carts': 37850, 'hit_carts': 200, 'num_orders': 17856, 'hit_orders': 129, 'recall_clicks': '0.005', 'recall_carts': '0.005', 'recall_orders': '0.007', 'w_recall_clicks': '0.001', 'w_recall_carts': '0.002', 'w_recall_orders': '0.004', 'score': '0.006'}
# 0:38:54.420977 	 [make_candidate] session_latest_clicks2orders_pair16 : start
# 0:38:54.674771 	 [add_candidate] session_latest_clicks2orders_pair16 : start
# 0:38:57.286964 	 session_latest_clicks2orders_pair16
# 0:38:57.287979 	 {'num_clicks': 97136, 'hit_clicks': 201, 'num_carts': 37850, 'hit_carts': 98, 'num_orders': 17856, 'hit_orders': 60, 'recall_clicks': '0.002', 'recall_carts': '0.003', 'recall_orders': '0.003', 'w_recall_clicks': '0.000', 'w_recall_carts': '0.001', 'w_recall_orders': '0.002', 'score': '0.003'}
# 0:38:57.295099 	 [make_candidate] session_latest_time_wt_pair17 : start
# 0:38:57.770539 	 [add_candidate] session_latest_time_wt_pair17 : start
# 0:39:01.224048 	 session_latest_time_wt_pair17
# 0:39:01.225164 	 {'num_clicks': 97136, 'hit_clicks': 1125, 'num_carts': 37850, 'hit_carts': 443, 'num_orders': 17856, 'hit_orders': 270, 'recall_clicks': '0.012', 'recall_carts': '0.012', 'recall_orders': '0.015', 'w_recall_clicks': '0.001', 'w_recall_carts': '0.004', 'w_recall_orders': '0.009', 'score': '0.014'}
# 0:39:01.235327 	 [make_candidate] session_latest_word2vec_pair17 : start
# 0:39:01.640761 	 [add_candidate] session_latest_word2vec_pair17 : start
# 0:39:04.737268 	 session_latest_word2vec_pair17
# 0:39:04.738447 	 {'num_clicks': 97136, 'hit_clicks': 721, 'num_carts': 37850, 'hit_carts': 269, 'num_orders': 17856, 'hit_orders': 134, 'recall_clicks': '0.007', 'recall_carts': '0.007', 'recall_orders': '0.008', 'w_recall_clicks': '0.001', 'w_recall_carts': '0.002', 'w_recall_orders': '0.005', 'score': '0.007'}
# 0:39:04.749086 	 [make_candidate] session_latest_pair17 : start
# 0:39:05.273310 	 [add_candidate] session_latest_pair17 : start
# 0:39:08.672538 	 session_latest_pair17
# 0:39:08.673679 	 {'num_clicks': 97136, 'hit_clicks': 871, 'num_carts': 37850, 'hit_carts': 341, 'num_orders': 17856, 'hit_orders': 219, 'recall_clicks': '0.009', 'recall_carts': '0.009', 'recall_orders': '0.012', 'w_recall_clicks': '0.001', 'w_recall_carts': '0.003', 'w_recall_orders': '0.007', 'score': '0.011'}
# 0:39:08.684252 	 [make_candidate] session_latest_type_wt_pair17 : start
# 0:39:09.027981 	 [add_candidate] session_latest_type_wt_pair17 : start
# 0:39:12.483415 	 session_latest_type_wt_pair17
# 0:39:12.484436 	 {'num_clicks': 97136, 'hit_clicks': 979, 'num_carts': 37850, 'hit_carts': 361, 'num_orders': 17856, 'hit_orders': 307, 'recall_clicks': '0.010', 'recall_carts': '0.010', 'recall_orders': '0.017', 'w_recall_clicks': '0.001', 'w_recall_carts': '0.003', 'w_recall_orders': '0.010', 'score': '0.014'}
# 0:39:12.495332 	 [make_candidate] session_latest_clicks2carts_pair17 : start
# 0:39:12.809692 	 [add_candidate] session_latest_clicks2carts_pair17 : start
# 0:39:15.746267 	 session_latest_clicks2carts_pair17
# 0:39:15.747401 	 {'num_clicks': 97136, 'hit_clicks': 424, 'num_carts': 37850, 'hit_carts': 190, 'num_orders': 17856, 'hit_orders': 117, 'recall_clicks': '0.004', 'recall_carts': '0.005', 'recall_orders': '0.007', 'w_recall_clicks': '0.000', 'w_recall_carts': '0.002', 'w_recall_orders': '0.004', 'score': '0.006'}
# 0:39:15.756983 	 [make_candidate] session_latest_clicks2orders_pair17 : start
# 0:39:15.984774 	 [add_candidate] session_latest_clicks2orders_pair17 : start
# 0:39:18.891959 	 session_latest_clicks2orders_pair17
# 0:39:18.893320 	 {'num_clicks': 97136, 'hit_clicks': 209, 'num_carts': 37850, 'hit_carts': 97, 'num_orders': 17856, 'hit_orders': 63, 'recall_clicks': '0.002', 'recall_carts': '0.003', 'recall_orders': '0.004', 'w_recall_clicks': '0.000', 'w_recall_carts': '0.001', 'w_recall_orders': '0.002', 'score': '0.003'}
# 0:39:18.901076 	 [make_candidate] session_latest_time_wt_pair18 : start
# 0:39:19.388358 	 [add_candidate] session_latest_time_wt_pair18 : start
# 0:39:22.517162 	 session_latest_time_wt_pair18
# 0:39:22.518389 	 {'num_clicks': 97136, 'hit_clicks': 1034, 'num_carts': 37850, 'hit_carts': 394, 'num_orders': 17856, 'hit_orders': 233, 'recall_clicks': '0.011', 'recall_carts': '0.010', 'recall_orders': '0.013', 'w_recall_clicks': '0.001', 'w_recall_carts': '0.003', 'w_recall_orders': '0.008', 'score': '0.012'}
# 0:39:22.530220 	 [make_candidate] session_latest_word2vec_pair18 : start
# 0:39:22.938474 	 [add_candidate] session_latest_word2vec_pair18 : start
# 0:39:26.358867 	 session_latest_word2vec_pair18
# 0:39:26.360089 	 {'num_clicks': 97136, 'hit_clicks': 755, 'num_carts': 37850, 'hit_carts': 287, 'num_orders': 17856, 'hit_orders': 131, 'recall_clicks': '0.008', 'recall_carts': '0.008', 'recall_orders': '0.007', 'w_recall_clicks': '0.001', 'w_recall_carts': '0.002', 'w_recall_orders': '0.004', 'score': '0.007'}
# 0:39:26.371548 	 [make_candidate] session_latest_pair18 : start
# 0:39:26.877751 	 [add_candidate] session_latest_pair18 : start
# 0:39:30.359386 	 session_latest_pair18
# 0:39:30.360655 	 {'num_clicks': 97136, 'hit_clicks': 825, 'num_carts': 37850, 'hit_carts': 318, 'num_orders': 17856, 'hit_orders': 251, 'recall_clicks': '0.008', 'recall_carts': '0.008', 'recall_orders': '0.014', 'w_recall_clicks': '0.001', 'w_recall_carts': '0.003', 'w_recall_orders': '0.008', 'score': '0.012'}
# 0:39:30.371681 	 [make_candidate] session_latest_type_wt_pair18 : start
# 0:39:30.732074 	 [add_candidate] session_latest_type_wt_pair18 : start
# 0:39:33.920658 	 session_latest_type_wt_pair18
# 0:39:33.921824 	 {'num_clicks': 97136, 'hit_clicks': 856, 'num_carts': 37850, 'hit_carts': 346, 'num_orders': 17856, 'hit_orders': 282, 'recall_clicks': '0.009', 'recall_carts': '0.009', 'recall_orders': '0.016', 'w_recall_clicks': '0.001', 'w_recall_carts': '0.003', 'w_recall_orders': '0.009', 'score': '0.013'}
# 0:39:33.933247 	 [make_candidate] session_latest_clicks2carts_pair18 : start
# 0:39:34.368686 	 [add_candidate] session_latest_clicks2carts_pair18 : start
# 0:39:37.661187 	 session_latest_clicks2carts_pair18
# 0:39:37.662196 	 {'num_clicks': 97136, 'hit_clicks': 474, 'num_carts': 37850, 'hit_carts': 204, 'num_orders': 17856, 'hit_orders': 142, 'recall_clicks': '0.005', 'recall_carts': '0.005', 'recall_orders': '0.008', 'w_recall_clicks': '0.000', 'w_recall_carts': '0.002', 'w_recall_orders': '0.005', 'score': '0.007'}
# 0:39:37.670675 	 [make_candidate] session_latest_clicks2orders_pair18 : start
# 0:39:37.913450 	 [add_candidate] session_latest_clicks2orders_pair18 : start
# 0:39:40.723207 	 session_latest_clicks2orders_pair18
# 0:39:40.724446 	 {'num_clicks': 97136, 'hit_clicks': 203, 'num_carts': 37850, 'hit_carts': 91, 'num_orders': 17856, 'hit_orders': 50, 'recall_clicks': '0.002', 'recall_carts': '0.002', 'recall_orders': '0.003', 'w_recall_clicks': '0.000', 'w_recall_carts': '0.001', 'w_recall_orders': '0.002', 'score': '0.003'}
# 0:39:40.731591 	 [make_candidate] session_latest_time_wt_pair19 : start
# 0:39:41.351572 	 [add_candidate] session_latest_time_wt_pair19 : start
# 0:39:44.922829 	 session_latest_time_wt_pair19
# 0:39:44.923949 	 {'num_clicks': 97136, 'hit_clicks': 1008, 'num_carts': 37850, 'hit_carts': 374, 'num_orders': 17856, 'hit_orders': 216, 'recall_clicks': '0.010', 'recall_carts': '0.010', 'recall_orders': '0.012', 'w_recall_clicks': '0.001', 'w_recall_carts': '0.003', 'w_recall_orders': '0.007', 'score': '0.011'}
# 0:39:44.934817 	 [make_candidate] session_latest_word2vec_pair19 : start
# 0:39:45.351704 	 [add_candidate] session_latest_word2vec_pair19 : start
# 0:39:48.564413 	 session_latest_word2vec_pair19
# 0:39:48.565524 	 {'num_clicks': 97136, 'hit_clicks': 709, 'num_carts': 37850, 'hit_carts': 297, 'num_orders': 17856, 'hit_orders': 143, 'recall_clicks': '0.007', 'recall_carts': '0.008', 'recall_orders': '0.008', 'w_recall_clicks': '0.001', 'w_recall_carts': '0.002', 'w_recall_orders': '0.005', 'score': '0.008'}
# 0:39:48.575905 	 [make_candidate] session_latest_pair19 : start
# 0:39:49.067578 	 [add_candidate] session_latest_pair19 : start
# 0:39:52.554984 	 session_latest_pair19
# 0:39:52.556050 	 {'num_clicks': 97136, 'hit_clicks': 810, 'num_carts': 37850, 'hit_carts': 311, 'num_orders': 17856, 'hit_orders': 224, 'recall_clicks': '0.008', 'recall_carts': '0.008', 'recall_orders': '0.013', 'w_recall_clicks': '0.001', 'w_recall_carts': '0.002', 'w_recall_orders': '0.008', 'score': '0.011'}
# 0:39:52.566585 	 [make_candidate] session_latest_type_wt_pair19 : start
# 0:39:52.934030 	 [add_candidate] session_latest_type_wt_pair19 : start
# 0:39:56.435068 	 session_latest_type_wt_pair19
# 0:39:56.436049 	 {'num_clicks': 97136, 'hit_clicks': 875, 'num_carts': 37850, 'hit_carts': 378, 'num_orders': 17856, 'hit_orders': 233, 'recall_clicks': '0.009', 'recall_carts': '0.010', 'recall_orders': '0.013', 'w_recall_clicks': '0.001', 'w_recall_carts': '0.003', 'w_recall_orders': '0.008', 'score': '0.012'}
# 0:39:56.447146 	 [make_candidate] session_latest_clicks2carts_pair19 : start
# 0:39:56.792604 	 [add_candidate] session_latest_clicks2carts_pair19 : start
# 0:39:59.840659 	 session_latest_clicks2carts_pair19
# 0:39:59.842054 	 {'num_clicks': 97136, 'hit_clicks': 396, 'num_carts': 37850, 'hit_carts': 208, 'num_orders': 17856, 'hit_orders': 122, 'recall_clicks': '0.004', 'recall_carts': '0.005', 'recall_orders': '0.007', 'w_recall_clicks': '0.000', 'w_recall_carts': '0.002', 'w_recall_orders': '0.004', 'score': '0.006'}
# 0:39:59.851181 	 [make_candidate] session_latest_clicks2orders_pair19 : start
# 0:40:00.030090 	 [add_candidate] session_latest_clicks2orders_pair19 : start
# 0:40:03.057688 	 session_latest_clicks2orders_pair19
# 0:40:03.058838 	 {'num_clicks': 97136, 'hit_clicks': 218, 'num_carts': 37850, 'hit_carts': 103, 'num_orders': 17856, 'hit_orders': 64, 'recall_clicks': '0.002', 'recall_carts': '0.003', 'recall_orders': '0.004', 'w_recall_clicks': '0.000', 'w_recall_carts': '0.001', 'w_recall_orders': '0.002', 'score': '0.003'}

# %%
results
# Out:
#                                    name num_clicks hit_clicks num_carts  \
# 0                      session_frequent      97136      29467     42864
# 0                        session_latest      97136      29677     42864
# 0          session_latest_time_wt_pair0      97136       7618     37850
# 0         session_latest_word2vec_pair0      97136       4513     37850
# 0                  session_latest_pair0      97136       6545     37850
# ..                                  ...        ...        ...       ...
# 0        session_latest_word2vec_pair19      97136        709     37850
# 0                 session_latest_pair19      97136        810     37850
# 0         session_latest_type_wt_pair19      97136        875     37850
# 0    session_latest_clicks2carts_pair19      97136        396     37850
# 0   session_latest_clicks2orders_pair19      97136        218     37850
#
#    hit_carts num_orders hit_orders recall_clicks recall_carts recall_orders  \
# 0      10730      19985      10185         0.303        0.250         0.510
# 0      10822      19985       9838         0.306        0.252         0.492
# 0       2266      17856       1476         0.078        0.060         0.083
# 0       1459      17856        806         0.046        0.039         0.045
# 0       2105      17856       1450         0.067        0.056         0.081
# ..       ...        ...        ...           ...          ...           ...
# 0        297      17856        143         0.007        0.008         0.008
# 0        311      17856        224         0.008        0.008         0.013
# 0        378      17856        233         0.009        0.010         0.013
# 0        208      17856        122         0.004        0.005         0.007
# 0        103      17856         64         0.002        0.003         0.004
#
#    w_recall_clicks w_recall_carts w_recall_orders  score
# 0            0.030          0.075           0.306  0.411
# 0            0.031          0.076           0.295  0.402
# 0            0.008          0.018           0.050  0.075
# 0            0.005          0.012           0.027  0.043
# 0            0.007          0.017           0.049  0.072
# ..             ...            ...             ...    ...
# 0            0.001          0.002           0.005  0.008
# 0            0.001          0.002           0.008  0.011
# 0            0.001          0.003           0.008  0.012
# 0            0.000          0.002           0.004  0.006
# 0            0.000          0.001           0.002  0.003
#
# [122 rows x 14 columns]

# %%
fig, axs = plt.subplots(1, 3)
sns.heatmap(results.set_index("name")[["recall_clicks"]].astype(float),
            annot=True, linewidths=.5, fmt="1.2f", cmap="Reds", cbar=False, ax=axs[0])
sns.heatmap(results.set_index("name")[["recall_carts"]].astype(float),
            annot=True, linewidths=.5, fmt="1.2f", cmap="Reds", cbar=False, ax=axs[1], yticklabels=False)
sns.heatmap(results.set_index("name")[["recall_orders"]].astype(float),
            annot=True, linewidths=.5, fmt="1.2f", cmap="Reds", cbar=False, ax=axs[2], yticklabels=False)
plt.savefig(cfg.output_dir + f'{cfg.exp_name}/candidate_strategy_recalls.png')

# %%
# 予測値を全て使えたときのrecall
valid_all = valid.drop_duplicates(subset= ["session", "aid"])
session_cnt_max = valid_all["session"].value_counts().max()
valid_all = valid_all.groupby("session")["aid"].apply(list).reset_index()

all_results = evaluate(valid_labels["clicks_labels"].tolist(),
                       valid_labels["carts_labels"].tolist(),
                       valid_labels["orders_labels"].tolist(),
                       valid_all["aid"].tolist(),
                       valid_all["aid"].tolist(),
                       valid_all["aid"].tolist(),
                       session_cnt_max)
logger.info("session_cnt_max")
logger.info(session_cnt_max)
logger.info("all_pred_results")
logger.info(all_results)
# Out:
# 0:40:10.131829 	 session_cnt_max
# 0:40:10.133054 	 377
# 0:40:10.133807 	 all_pred_results
# 0:40:10.134423 	 {'num_clicks': 97136, 'hit_clicks': 57048, 'num_carts': 43611, 'hit_carts': 18858, 'num_orders': 20109, 'hit_orders': 12800, 'recall_clicks': '0.587', 'recall_carts': '0.432', 'recall_orders': '0.637', 'w_recall_clicks': '0.059', 'w_recall_carts': '0.130', 'w_recall_orders': '0.382', 'score': '0.570'}
