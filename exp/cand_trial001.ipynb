# %% [markdown]
# # cand_trial001

# %%
import os
import sys
import traceback
import gc
import random
import pickle
import pathlib
import subprocess
from dataclasses import dataclass
from dotenv import load_dotenv
load_dotenv
sys.path.append(os.getenv('UTILS_PATH'))
from tqdm import tqdm
import multiprocessing
import inspect

import pandas as pd
import numpy as np
import itertools
import cudf
import lightgbm as lgb
import matplotlib.pyplot as plt
import seaborn as sns
import line_notify
import my_logger
from noglobal import noglobal
import optuna

# %% [markdown]
# # 設定

# %%
@dataclass
class Cfg:
    loglevel = "INFO"
    exp_name = "cand_trial"
    seed = 42
    k = 20
    cand_n = 15
    type2id = {"clicks":0, "carts":1, "orders":2}
    id2type = {0:"clicks", 1:"carts", 2:"orders"}
    train_weeks = ["week3"]
    valid_week = "week4"
    valid_session_n = 100_000
    input_dir = os.getenv('INPUT_DIR')
    output_dir = os.getenv('OUTPUT_DIR')
    prep_dir = os.getenv("PREP_DIR")

cfg = Cfg()
os.makedirs(os.path.join(cfg.output_dir, cfg.exp_name), exist_ok=True)
os.makedirs(os.path.join(cfg.output_dir, cfg.exp_name, "cache"), exist_ok=True)
random.seed(cfg.seed)

logger = my_logger.init_logger(cfg.exp_name)

# %%
@noglobal(excepts=["cfg", "logger"])
def evaluate(clicks_labels, carts_labels, orders_labels, 
             clicks_preds, carts_preds, orders_preds, k=20):

    num_clicks = 0
    num_carts = 0
    num_orders = 0
    hit_clicks = 0
    hit_carts = 0
    hit_orders = 0

    for i in range(len(clicks_labels)):
        clicks_label = clicks_labels[i]
        carts_label = carts_labels[i]
        orders_label = orders_labels[i]
        clicks_pred = clicks_preds[i]
        carts_pred = carts_preds[i]
        orders_pred = orders_preds[i]

        if type(clicks_pred) == list:
            clicks_pred = clicks_pred[:k]
        else:
            clicks_pred = []
        if type(carts_pred) == list:
            carts_pred = carts_pred[:k]
        else:
            carts_pred = []    
        if type(orders_pred) == list:
            orders_pred = orders_pred[:k]
        else:
            orders_pred = []

        if not np.isnan(clicks_label):
            num_clicks += 1
            hit_clicks += int(clicks_label in clicks_pred)

        if type(carts_label) == list:
            num_carts += min(len(carts_label), k)
            hit_carts += len(set(carts_pred) & set(carts_label))
            
        if type(orders_label) == list:
            num_orders += min(len(orders_label), k)
            hit_orders += len(set(orders_pred) & set(orders_label))


    recall_clicks = hit_clicks / num_clicks
    recall_carts = hit_carts / num_carts
    recall_orders = hit_orders / num_orders
    w_recall_clicks = recall_clicks * 0.10
    w_recall_carts = recall_carts * 0.30
    w_recall_orders = recall_orders * 0.60
    score = w_recall_clicks + w_recall_carts + w_recall_orders

    results = {}
    results["num_clicks"] = num_clicks
    results["hit_clicks"] = hit_clicks
    results["num_carts"] = num_carts
    results["hit_carts"] = hit_carts
    results["num_orders"] = num_orders
    results["hit_orders"] = hit_orders
    results["recall_clicks"] = format(recall_clicks, ".3f")
    results["recall_carts"] = format(recall_carts, ".3f")
    results["recall_orders"] = format(recall_orders, ".3f")
    results["w_recall_clicks"] = format(w_recall_clicks, ".3f")
    results["w_recall_carts"] = format(w_recall_carts, ".3f")
    results["w_recall_orders"] = format(w_recall_orders, ".3f")
    results["score"] = format(score, ".3f")

    return results

# %%
class Candidate:
    @noglobal(excepts=["cfg", "logger"])
    def __init__(self, pdf, labels=None):
        self.df = cudf.from_pandas(pdf)
        self.target_sessions = pdf["session"].unique().tolist()
        self.results = pd.DataFrame(columns=["name", "num_clicks", "hit_clicks", "num_carts", "hit_carts", "num_orders", "hit_orders", 
                                             "recall_clicks", "recall_carts", "recall_orders", "w_recall_clicks", "w_recall_carts", "w_recall_orders", "score"])
        self.output = pd.DataFrame(columns=["session", "aid"], dtype=int)
        self.labels = labels
    
    @noglobal(excepts=["cfg", "logger"])
    def _entry(self, new_candidate_df, name, k):
        new_candidate_df[f"{name}_rank"] = new_candidate_df.groupby("session")["session"].cumcount()
        new_candidate_df = new_candidate_df.to_pandas()
        self.output = pd.concat([self.output, new_candidate_df[["session", "aid"]]])
        self.output = self.output.drop_duplicates(subset=["session", "aid"])
        
        self.output = self.output.merge(new_candidate_df, on=["session", "aid"], how="left")

        if self.labels is not None:
            self._eval(new_candidate_df[["session", "aid"]], name, k)
    
    @noglobal(excepts=["cfg", "logger"])
    def _eval(self, new_candidate_df, name, k):
        new_candidate_df = new_candidate_df.groupby("session")["aid"].apply(list).reset_index()
        eval_df = pd.DataFrame(self.target_sessions, columns=["session"])
        eval_df = eval_df.merge(new_candidate_df, on=["session"], how="left")
        assert eval_df["session"].tolist() == self.labels["session"].tolist()
        eval_result = evaluate(self.labels["clicks_labels"].tolist(), self.labels["carts_labels"].tolist(), self.labels["orders_labels"].tolist(),
                               eval_df["aid"].tolist(), eval_df["aid"].tolist(), eval_df["aid"].tolist(), k)
        
        logger.info(name)
        logger.info(eval_result)
        self.results = pd.concat([self.results, pd.DataFrame([[name] + list(eval_result.values())], columns=["name"] + list(eval_result.keys()))])

    @noglobal(excepts=["cfg", "logger"])
    def add(self, strategy, name, usetypes=['clicks', 'carts', 'orders'], trans_map=None, k=20):
        candidate_df = self.df[self.df["type"].isin(usetypes)].copy()
        
        if strategy == "session_frequent":
            candidate_df = self._session_frequent(candidate_df, k)
        elif strategy == "session_latest":
            candidate_df = self._session_latest(candidate_df, k)
        elif strategy == "total_frequent":
            candidate_df = self._total_frequent(candidate_df, k)
        
        if trans_map is not None:
            candidate_df["aid"] = candidate_df["aid"].map(trans_map)
            candidate_df = candidate_df.dropna(subset=["aid"])
            
        self._entry(candidate_df, name, k)

    @noglobal(excepts=["cfg", "logger"])
    def _session_frequent(self, candidate_df, k):
        candidate_df = candidate_df.groupby(["session", "aid"])["ts"].count().reset_index()
        candidate_df.columns = ["session", "aid", "aid_count"]
        candidate_df = candidate_df.sort_values(["session", "aid_count", "aid"], ascending=(True, False, True))
        candidate_df = candidate_df[candidate_df.groupby("session")["aid_count"].cumcount() < k].copy()
        candidate_df = candidate_df[["session", "aid"]].copy()
        return candidate_df

    @noglobal(excepts=["cfg", "logger"])
    def _session_latest(self, candidate_df, k):
        candidate_df = candidate_df.sort_values(["session", "ts"], ascending=(True, False)).drop_duplicates(subset=["session", "aid"])
        candidate_df = candidate_df.sort_values(["session", "ts"], ascending=(True, False))[candidate_df.groupby("session")["ts"].cumcount() < k].copy()
        candidate_df = candidate_df[["session", "aid"]].copy()
        return candidate_df

    @noglobal(excepts=["cfg", "logger"])
    def _total_frequent(self, candidate_df, k):
        candidate_df = candidate_df.groupby("aid")["ts"].count().reset_index()
        candidate_df.columns = ["aid", "aid_count"]
        topk_freq_aids = candidate_df.sort_values("aid_count", ascending=False)["aid"].to_arrow().to_pylist()[:k]
        sessions = []
        aids = []
        for session, aid in itertools.product(self.target_sessions, topk_freq_aids):
            sessions.append(session)
            aids.append(aid)
        candidate_df = cudf.DataFrame({"session": sessions, "aid": aids})
        return candidate_df

# %%
@noglobal(excepts=["cfg", "logger"])
def make_cand_df(sessions, labels=None, trans_maps=None):

    if labels is not None:
         cand = Candidate(sessions, labels)
    else:
        cand = Candidate(sessions)

    cand.add(strategy="session_frequent", name="session_frequent", k=15)
    cand.add(strategy="session_latest", name="session_latest", k=15)
    
    for i in range(20):
        cand.add(strategy="session_latest", trans_map=trans_maps[f"time_wt_pair{str(i)}"], name=f"session_latest_time_wt_pair{str(i)}", k=5)
        cand.add(strategy="session_latest", trans_map=trans_maps[f"word2vec_pair{str(i)}"], name=f"session_latest_word2vec_pair{str(i)}", k=5)
        cand.add(strategy="session_latest", trans_map=trans_maps[f"pair{str(i)}"], name=f"session_latest_pair{str(i)}", k=5)
    for i in range(5):
        cand.add(strategy="session_latest", trans_map=trans_maps[f"type_wt_pair{str(i)}"], name=f"session_latest_type_wt_pair{str(i)}", k=5)
        cand.add(strategy="session_latest", trans_map=trans_maps[f"clicks2carts_pair{str(i)}"], name=f"session_latest_clicks2carts_pair{str(i)}", k=5)
        cand.add(strategy="session_latest", trans_map=trans_maps[f"clicks2orders_pair{str(i)}"], name=f"session_latest_clicks2orders_pair{str(i)}", k=5)
        

    if labels is not None:
        return cand.output, cand.results
    else:
        return cand.output

# %%
@noglobal(excepts=["cfg", "logger"])
def get_pair_df(name, wt_col, week):
    if week is not None:
        name = f"{name}_{week}"
    pair_df = pd.read_pickle(cfg.prep_dir + f"{name}.pkl")
    pair_df = pair_df.sort_values(["aid_x", wt_col], ascending=(True, False))
    return pair_df

@noglobal(excepts=["cfg", "logger"])
def get_pair_dict(name, wt_col, week):
    if week is not None:
        name = f"{name}_{week}"
    pair_df = pd.read_pickle(cfg.prep_dir + f"{name}.pkl")
    pair_df = pair_df.sort_values(["aid_x", wt_col], ascending=(True, False))
    pair_df = pair_df.groupby("aid_x").head(1)[["aid_x", "aid_y"]]
    pair_dict = {k: v for k, v in zip(pair_df["aid_x"].tolist(), pair_df["aid_y"].tolist())}
    return pair_dict

@noglobal(excepts=["cfg", "logger"])
def get_trans_maps(week=None):
    """
    aidを別のaidに置き換えるmapping辞書を取得する
    """
    trans_maps = {}
    
    pair_df_org = get_pair_df("co_visitation_matrix", "cnt", week)
    for i in range(20):
        pair_df = pair_df_org.groupby("aid_x").nth(i).reset_index()[["aid_x", "aid_y"]]
        pair_dict = {k: v for k, v in zip(pair_df["aid_x"].tolist(), pair_df["aid_y"].tolist())}
        trans_maps[f"pair{str(i)}"] = pair_dict
    
    pair_df_org = get_pair_df("co_visitation_matrix_time_weighted", "wt", week)
    for i in range(20):
        pair_df = pair_df_org.groupby("aid_x").nth(i).reset_index()[["aid_x", "aid_y"]]
        pair_dict = {k: v for k, v in zip(pair_df["aid_x"].tolist(), pair_df["aid_y"].tolist())}
        trans_maps[f"time_wt_pair{str(i)}"] = pair_dict

    pair_df_org = get_pair_df("co_visitation_matrix_type_weighted", "wt", week)
    for i in range(20):
        pair_df = pair_df_org.groupby("aid_x").nth(i).reset_index()[["aid_x", "aid_y"]]
        pair_dict = {k: v for k, v in zip(pair_df["aid_x"].tolist(), pair_df["aid_y"].tolist())}
        trans_maps[f"type_wt_pair{str(i)}"] = pair_dict

    pair_df_org = get_pair_df("co_visitation_matrix_clicks2carts", "cnt", week)
    for i in range(20):
        pair_df = pair_df_org.groupby("aid_x").nth(i).reset_index()[["aid_x", "aid_y"]]
        pair_dict = {k: v for k, v in zip(pair_df["aid_x"].tolist(), pair_df["aid_y"].tolist())}
        trans_maps[f"clicks2carts_pair{str(i)}"] = pair_dict

    pair_df_org = get_pair_df("co_visitation_matrix_clicks2orders", "cnt", week)
    for i in range(20):
        pair_df = pair_df_org.groupby("aid_x").nth(i).reset_index()[["aid_x", "aid_y"]]
        pair_dict = {k: v for k, v in zip(pair_df["aid_x"].tolist(), pair_df["aid_y"].tolist())}
        trans_maps[f"clicks2orders_pair{str(i)}"] = pair_dict

    pair_df_org = get_pair_df("word2vec_similar", "sim", None)
    for i in range(20):
        pair_df = pair_df_org.groupby("aid_x").nth(i).reset_index()[["aid_x", "aid_y"]]
        pair_dict = {k: v for k, v in zip(pair_df["aid_x"].tolist(), pair_df["aid_y"].tolist())}
        trans_maps[f"word2vec_pair{str(i)}"] = pair_dict

    

    return trans_maps

# %%
class Cache:
    @noglobal(excepts=["cfg", "logger"])
    def __init__(self):
        self.cache_dir = (os.path.join(cfg.output_dir, cfg.exp_name, "cache"))
        self.cache_dir_path = pathlib.Path(self.cache_dir)
        self.caches = list(self.cache_dir_path.glob("*.pkl"))

    @noglobal(excepts=["cfg", "logger"])
    def get_abspath(self, filename):
        return (os.path.join(self.cache_dir, f"{cfg.exp_name}_{filename}"))
    
    @noglobal(excepts=["cfg", "logger"])
    def exists(self, path):
        return len([str(c) for c in self.caches if path == str(c)]) > 0

# %%
@noglobal(excepts=["cfg", "logger"])
def make_valid_data(trans_maps):
    valid_week = cfg.valid_week
    dfs = []
    
    logger.info(f"[make_valid] valid_week : {valid_week}")
    # データ読み込み
    logger.info("[make_valid] read_data : start")
    week_sessions = pd.read_pickle(os.getenv("PREP_DIR") + f"train_sessions_{valid_week}.pkl")
    week_labels = pd.read_pickle(os.getenv("PREP_DIR") + f"labels_{valid_week}.pkl")
    valid_session_ids = week_sessions["session"].unique().tolist()
    logger.info("[make_valid] read_data : end")

    # validに使うsessionを絞る (trainに存在するsessionを除外した上で設定した数に絞る)
    logger.info("[make_valid] valid_session_extract : start")
    valid_session_n = min(cfg.valid_session_n, len(valid_session_ids))
    valid_session_ids = random.sample(valid_session_ids, valid_session_n)
    week_sessions = week_sessions[week_sessions["session"].isin(valid_session_ids)].copy()
    week_labels = week_labels[week_labels["session"].isin(valid_session_ids)].copy()
    logger.info("[make_valid] valid_session_extract : end")

    # 候補選出
    logger.info("[make_valid] make_cand_df : start")
    valid, results = make_cand_df(week_sessions, labels=week_labels, trans_maps=trans_maps)

    return valid, week_labels, results

# %%
logger.info("\n\nSTART\n\n")
trans_maps = get_trans_maps(cfg.valid_week)
valid, valid_labels, results = make_valid_data(trans_maps)
# Out:
# 0:00:00.371581
#
# START
#
#
# 0:03:38.141996 	 [make_valid] valid_week : week4
# 0:03:38.144208 	 [make_valid] read_data : start
# 0:03:45.586664 	 [make_valid] read_data : end
# 0:03:45.588624 	 [make_valid] valid_session_extract : start
# 0:03:46.872074 	 [make_valid] valid_session_extract : end
# 0:03:46.873438 	 [make_valid] make_cand_df : start
# 0:03:48.875679 	 session_frequent
# 0:03:48.877090 	 {'num_clicks': 97136, 'hit_clicks': 29467, 'num_carts': 42864, 'hit_carts': 10730, 'num_orders': 19985, 'hit_orders': 10185, 'recall_clicks': '0.303', 'recall_carts': '0.250', 'recall_orders': '0.510', 'w_recall_clicks': '0.030', 'w_recall_carts': '0.075', 'w_recall_orders': '0.306', 'score': '0.411'}
# 0:03:51.299289 	 session_latest
# 0:03:51.305331 	 {'num_clicks': 97136, 'hit_clicks': 29677, 'num_carts': 42864, 'hit_carts': 10822, 'num_orders': 19985, 'hit_orders': 9838, 'recall_clicks': '0.306', 'recall_carts': '0.252', 'recall_orders': '0.492', 'w_recall_clicks': '0.031', 'w_recall_carts': '0.076', 'w_recall_orders': '0.295', 'score': '0.402'}
# 0:03:53.526066 	 session_latest_time_wt_pair0
# 0:03:53.527470 	 {'num_clicks': 97136, 'hit_clicks': 7631, 'num_carts': 37850, 'hit_carts': 2267, 'num_orders': 17856, 'hit_orders': 1479, 'recall_clicks': '0.079', 'recall_carts': '0.060', 'recall_orders': '0.083', 'w_recall_clicks': '0.008', 'w_recall_carts': '0.018', 'w_recall_orders': '0.050', 'score': '0.076'}
# 0:03:56.065740 	 session_latest_word2vec_pair0
# 0:03:56.067249 	 {'num_clicks': 97136, 'hit_clicks': 4513, 'num_carts': 37850, 'hit_carts': 1459, 'num_orders': 17856, 'hit_orders': 806, 'recall_clicks': '0.046', 'recall_carts': '0.039', 'recall_orders': '0.045', 'w_recall_clicks': '0.005', 'w_recall_carts': '0.012', 'w_recall_orders': '0.027', 'score': '0.043'}
# 0:03:58.377176 	 session_latest_pair0
# 0:03:58.378671 	 {'num_clicks': 97136, 'hit_clicks': 6545, 'num_carts': 37850, 'hit_carts': 2105, 'num_orders': 17856, 'hit_orders': 1450, 'recall_clicks': '0.067', 'recall_carts': '0.056', 'recall_orders': '0.081', 'w_recall_clicks': '0.007', 'w_recall_carts': '0.017', 'w_recall_orders': '0.049', 'score': '0.072'}
# 0:04:00.969626 	 session_latest_time_wt_pair1
# 0:04:00.970895 	 {'num_clicks': 97136, 'hit_clicks': 5382, 'num_carts': 37850, 'hit_carts': 1666, 'num_orders': 17856, 'hit_orders': 1020, 'recall_clicks': '0.055', 'recall_carts': '0.044', 'recall_orders': '0.057', 'w_recall_clicks': '0.006', 'w_recall_carts': '0.013', 'w_recall_orders': '0.034', 'score': '0.053'}
# 0:04:03.396664 	 session_latest_word2vec_pair1
# 0:04:03.398100 	 {'num_clicks': 97136, 'hit_clicks': 3132, 'num_carts': 37850, 'hit_carts': 1037, 'num_orders': 17856, 'hit_orders': 580, 'recall_clicks': '0.032', 'recall_carts': '0.027', 'recall_orders': '0.032', 'w_recall_clicks': '0.003', 'w_recall_carts': '0.008', 'w_recall_orders': '0.019', 'score': '0.031'}
# 0:04:05.779610 	 session_latest_pair1
# 0:04:05.780795 	 {'num_clicks': 97136, 'hit_clicks': 4546, 'num_carts': 37850, 'hit_carts': 1556, 'num_orders': 17856, 'hit_orders': 975, 'recall_clicks': '0.047', 'recall_carts': '0.041', 'recall_orders': '0.055', 'w_recall_clicks': '0.005', 'w_recall_carts': '0.012', 'w_recall_orders': '0.033', 'score': '0.050'}
# 0:04:08.378734 	 session_latest_time_wt_pair2
# 0:04:08.380030 	 {'num_clicks': 97136, 'hit_clicks': 4206, 'num_carts': 37850, 'hit_carts': 1372, 'num_orders': 17856, 'hit_orders': 872, 'recall_clicks': '0.043', 'recall_carts': '0.036', 'recall_orders': '0.049', 'w_recall_clicks': '0.004', 'w_recall_carts': '0.011', 'w_recall_orders': '0.029', 'score': '0.045'}
# 0:04:10.870475 	 session_latest_word2vec_pair2
# 0:04:10.871789 	 {'num_clicks': 97136, 'hit_clicks': 2525, 'num_carts': 37850, 'hit_carts': 832, 'num_orders': 17856, 'hit_orders': 472, 'recall_clicks': '0.026', 'recall_carts': '0.022', 'recall_orders': '0.026', 'w_recall_clicks': '0.003', 'w_recall_carts': '0.007', 'w_recall_orders': '0.016', 'score': '0.025'}
# 0:04:13.694772 	 session_latest_pair2
# 0:04:13.696148 	 {'num_clicks': 97136, 'hit_clicks': 3634, 'num_carts': 37850, 'hit_carts': 1301, 'num_orders': 17856, 'hit_orders': 848, 'recall_clicks': '0.037', 'recall_carts': '0.034', 'recall_orders': '0.047', 'w_recall_clicks': '0.004', 'w_recall_carts': '0.010', 'w_recall_orders': '0.028', 'score': '0.043'}
# 0:04:16.355058 	 session_latest_time_wt_pair3
# 0:04:16.356233 	 {'num_clicks': 97136, 'hit_clicks': 3570, 'num_carts': 37850, 'hit_carts': 1271, 'num_orders': 17856, 'hit_orders': 683, 'recall_clicks': '0.037', 'recall_carts': '0.034', 'recall_orders': '0.038', 'w_recall_clicks': '0.004', 'w_recall_carts': '0.010', 'w_recall_orders': '0.023', 'score': '0.037'}
# 0:04:19.553666 	 session_latest_word2vec_pair3
# 0:04:19.555020 	 {'num_clicks': 97136, 'hit_clicks': 1970, 'num_carts': 37850, 'hit_carts': 715, 'num_orders': 17856, 'hit_orders': 427, 'recall_clicks': '0.020', 'recall_carts': '0.019', 'recall_orders': '0.024', 'w_recall_clicks': '0.002', 'w_recall_carts': '0.006', 'w_recall_orders': '0.014', 'score': '0.022'}
# 0:04:22.499423 	 session_latest_pair3
# 0:04:22.500577 	 {'num_clicks': 97136, 'hit_clicks': 2997, 'num_carts': 37850, 'hit_carts': 1064, 'num_orders': 17856, 'hit_orders': 686, 'recall_clicks': '0.031', 'recall_carts': '0.028', 'recall_orders': '0.038', 'w_recall_clicks': '0.003', 'w_recall_carts': '0.008', 'w_recall_orders': '0.023', 'score': '0.035'}
# 0:04:25.795453 	 session_latest_time_wt_pair4
# 0:04:25.796863 	 {'num_clicks': 97136, 'hit_clicks': 3073, 'num_carts': 37850, 'hit_carts': 1060, 'num_orders': 17856, 'hit_orders': 654, 'recall_clicks': '0.032', 'recall_carts': '0.028', 'recall_orders': '0.037', 'w_recall_clicks': '0.003', 'w_recall_carts': '0.008', 'w_recall_orders': '0.022', 'score': '0.034'}
# 0:04:28.827604 	 session_latest_word2vec_pair4
# 0:04:28.828784 	 {'num_clicks': 97136, 'hit_clicks': 1810, 'num_carts': 37850, 'hit_carts': 600, 'num_orders': 17856, 'hit_orders': 324, 'recall_clicks': '0.019', 'recall_carts': '0.016', 'recall_orders': '0.018', 'w_recall_clicks': '0.002', 'w_recall_carts': '0.005', 'w_recall_orders': '0.011', 'score': '0.018'}
# 0:04:32.202707 	 session_latest_pair4
# 0:04:32.203943 	 {'num_clicks': 97136, 'hit_clicks': 2561, 'num_carts': 37850, 'hit_carts': 908, 'num_orders': 17856, 'hit_orders': 617, 'recall_clicks': '0.026', 'recall_carts': '0.024', 'recall_orders': '0.035', 'w_recall_clicks': '0.003', 'w_recall_carts': '0.007', 'w_recall_orders': '0.021', 'score': '0.031'}
# 0:04:35.797632 	 session_latest_time_wt_pair5
# 0:04:35.798809 	 {'num_clicks': 97136, 'hit_clicks': 2658, 'num_carts': 37850, 'hit_carts': 928, 'num_orders': 17856, 'hit_orders': 543, 'recall_clicks': '0.027', 'recall_carts': '0.025', 'recall_orders': '0.030', 'w_recall_clicks': '0.003', 'w_recall_carts': '0.007', 'w_recall_orders': '0.018', 'score': '0.028'}
# 0:04:39.059434 	 session_latest_word2vec_pair5
# 0:04:39.060521 	 {'num_clicks': 97136, 'hit_clicks': 1690, 'num_carts': 37850, 'hit_carts': 569, 'num_orders': 17856, 'hit_orders': 338, 'recall_clicks': '0.017', 'recall_carts': '0.015', 'recall_orders': '0.019', 'w_recall_clicks': '0.002', 'w_recall_carts': '0.005', 'w_recall_orders': '0.011', 'score': '0.018'}
# 0:04:42.826694 	 session_latest_pair5
# 0:04:42.827939 	 {'num_clicks': 97136, 'hit_clicks': 2317, 'num_carts': 37850, 'hit_carts': 784, 'num_orders': 17856, 'hit_orders': 575, 'recall_clicks': '0.024', 'recall_carts': '0.021', 'recall_orders': '0.032', 'w_recall_clicks': '0.002', 'w_recall_carts': '0.006', 'w_recall_orders': '0.019', 'score': '0.028'}
# 0:04:46.388303 	 session_latest_time_wt_pair6
# 0:04:46.389468 	 {'num_clicks': 97136, 'hit_clicks': 2354, 'num_carts': 37850, 'hit_carts': 796, 'num_orders': 17856, 'hit_orders': 486, 'recall_clicks': '0.024', 'recall_carts': '0.021', 'recall_orders': '0.027', 'w_recall_clicks': '0.002', 'w_recall_carts': '0.006', 'w_recall_orders': '0.016', 'score': '0.025'}
# 0:04:50.550753 	 session_latest_word2vec_pair6
# 0:04:50.552078 	 {'num_clicks': 97136, 'hit_clicks': 1628, 'num_carts': 37850, 'hit_carts': 572, 'num_orders': 17856, 'hit_orders': 276, 'recall_clicks': '0.017', 'recall_carts': '0.015', 'recall_orders': '0.015', 'w_recall_clicks': '0.002', 'w_recall_carts': '0.005', 'w_recall_orders': '0.009', 'score': '0.015'}
# 0:04:54.629249 	 session_latest_pair6
# 0:04:54.630397 	 {'num_clicks': 97136, 'hit_clicks': 1998, 'num_carts': 37850, 'hit_carts': 712, 'num_orders': 17856, 'hit_orders': 494, 'recall_clicks': '0.021', 'recall_carts': '0.019', 'recall_orders': '0.028', 'w_recall_clicks': '0.002', 'w_recall_carts': '0.006', 'w_recall_orders': '0.017', 'score': '0.024'}
# 0:04:58.731842 	 session_latest_time_wt_pair7
# 0:04:58.733142 	 {'num_clicks': 97136, 'hit_clicks': 2127, 'num_carts': 37850, 'hit_carts': 772, 'num_orders': 17856, 'hit_orders': 447, 'recall_clicks': '0.022', 'recall_carts': '0.020', 'recall_orders': '0.025', 'w_recall_clicks': '0.002', 'w_recall_carts': '0.006', 'w_recall_orders': '0.015', 'score': '0.023'}
# 0:05:03.292559 	 session_latest_word2vec_pair7
# 0:05:03.293703 	 {'num_clicks': 97136, 'hit_clicks': 1381, 'num_carts': 37850, 'hit_carts': 469, 'num_orders': 17856, 'hit_orders': 252, 'recall_clicks': '0.014', 'recall_carts': '0.012', 'recall_orders': '0.014', 'w_recall_clicks': '0.001', 'w_recall_carts': '0.004', 'w_recall_orders': '0.008', 'score': '0.014'}
# 0:05:07.500729 	 session_latest_pair7
# 0:05:07.502176 	 {'num_clicks': 97136, 'hit_clicks': 1852, 'num_carts': 37850, 'hit_carts': 668, 'num_orders': 17856, 'hit_orders': 421, 'recall_clicks': '0.019', 'recall_carts': '0.018', 'recall_orders': '0.024', 'w_recall_clicks': '0.002', 'w_recall_carts': '0.005', 'w_recall_orders': '0.014', 'score': '0.021'}
# 0:05:12.272286 	 session_latest_time_wt_pair8
# 0:05:12.273603 	 {'num_clicks': 97136, 'hit_clicks': 2093, 'num_carts': 37850, 'hit_carts': 702, 'num_orders': 17856, 'hit_orders': 417, 'recall_clicks': '0.022', 'recall_carts': '0.019', 'recall_orders': '0.023', 'w_recall_clicks': '0.002', 'w_recall_carts': '0.006', 'w_recall_orders': '0.014', 'score': '0.022'}
# 0:05:16.925463 	 session_latest_word2vec_pair8
# 0:05:16.926767 	 {'num_clicks': 97136, 'hit_clicks': 1295, 'num_carts': 37850, 'hit_carts': 448, 'num_orders': 17856, 'hit_orders': 238, 'recall_clicks': '0.013', 'recall_carts': '0.012', 'recall_orders': '0.013', 'w_recall_clicks': '0.001', 'w_recall_carts': '0.004', 'w_recall_orders': '0.008', 'score': '0.013'}
# 0:05:21.859763 	 session_latest_pair8
# 0:05:21.860880 	 {'num_clicks': 97136, 'hit_clicks': 1795, 'num_carts': 37850, 'hit_carts': 643, 'num_orders': 17856, 'hit_orders': 432, 'recall_clicks': '0.018', 'recall_carts': '0.017', 'recall_orders': '0.024', 'w_recall_clicks': '0.002', 'w_recall_carts': '0.005', 'w_recall_orders': '0.015', 'score': '0.021'}
# 0:05:26.509163 	 session_latest_time_wt_pair9
# 0:05:26.510258 	 {'num_clicks': 97136, 'hit_clicks': 1849, 'num_carts': 37850, 'hit_carts': 670, 'num_orders': 17856, 'hit_orders': 435, 'recall_clicks': '0.019', 'recall_carts': '0.018', 'recall_orders': '0.024', 'w_recall_clicks': '0.002', 'w_recall_carts': '0.005', 'w_recall_orders': '0.015', 'score': '0.022'}
# 0:05:31.700168 	 session_latest_word2vec_pair9
# 0:05:31.701452 	 {'num_clicks': 97136, 'hit_clicks': 1134, 'num_carts': 37850, 'hit_carts': 385, 'num_orders': 17856, 'hit_orders': 207, 'recall_clicks': '0.012', 'recall_carts': '0.010', 'recall_orders': '0.012', 'w_recall_clicks': '0.001', 'w_recall_carts': '0.003', 'w_recall_orders': '0.007', 'score': '0.011'}
# 0:05:36.631556 	 session_latest_pair9
# 0:05:36.632888 	 {'num_clicks': 97136, 'hit_clicks': 1559, 'num_carts': 37850, 'hit_carts': 596, 'num_orders': 17856, 'hit_orders': 386, 'recall_clicks': '0.016', 'recall_carts': '0.016', 'recall_orders': '0.022', 'w_recall_clicks': '0.002', 'w_recall_carts': '0.005', 'w_recall_orders': '0.013', 'score': '0.019'}
# 0:05:42.013986 	 session_latest_time_wt_pair10
# 0:05:42.015163 	 {'num_clicks': 97136, 'hit_clicks': 1728, 'num_carts': 37850, 'hit_carts': 561, 'num_orders': 17856, 'hit_orders': 397, 'recall_clicks': '0.018', 'recall_carts': '0.015', 'recall_orders': '0.022', 'w_recall_clicks': '0.002', 'w_recall_carts': '0.004', 'w_recall_orders': '0.013', 'score': '0.020'}
# 0:05:47.535890 	 session_latest_word2vec_pair10
# 0:05:47.537414 	 {'num_clicks': 97136, 'hit_clicks': 1080, 'num_carts': 37850, 'hit_carts': 367, 'num_orders': 17856, 'hit_orders': 234, 'recall_clicks': '0.011', 'recall_carts': '0.010', 'recall_orders': '0.013', 'w_recall_clicks': '0.001', 'w_recall_carts': '0.003', 'w_recall_orders': '0.008', 'score': '0.012'}
# 0:05:52.920486 	 session_latest_pair10
# 0:05:52.921924 	 {'num_clicks': 97136, 'hit_clicks': 1394, 'num_carts': 37850, 'hit_carts': 514, 'num_orders': 17856, 'hit_orders': 325, 'recall_clicks': '0.014', 'recall_carts': '0.014', 'recall_orders': '0.018', 'w_recall_clicks': '0.001', 'w_recall_carts': '0.004', 'w_recall_orders': '0.011', 'score': '0.016'}
# 0:05:58.842549 	 session_latest_time_wt_pair11
# 0:05:58.843713 	 {'num_clicks': 97136, 'hit_clicks': 1582, 'num_carts': 37850, 'hit_carts': 599, 'num_orders': 17856, 'hit_orders': 367, 'recall_clicks': '0.016', 'recall_carts': '0.016', 'recall_orders': '0.021', 'w_recall_clicks': '0.002', 'w_recall_carts': '0.005', 'w_recall_orders': '0.012', 'score': '0.019'}
# 0:06:04.557947 	 session_latest_word2vec_pair11
# 0:06:04.559281 	 {'num_clicks': 97136, 'hit_clicks': 1016, 'num_carts': 37850, 'hit_carts': 386, 'num_orders': 17856, 'hit_orders': 199, 'recall_clicks': '0.010', 'recall_carts': '0.010', 'recall_orders': '0.011', 'w_recall_clicks': '0.001', 'w_recall_carts': '0.003', 'w_recall_orders': '0.007', 'score': '0.011'}
# 0:06:10.694268 	 session_latest_pair11
# 0:06:10.695660 	 {'num_clicks': 97136, 'hit_clicks': 1288, 'num_carts': 37850, 'hit_carts': 518, 'num_orders': 17856, 'hit_orders': 332, 'recall_clicks': '0.013', 'recall_carts': '0.014', 'recall_orders': '0.019', 'w_recall_clicks': '0.001', 'w_recall_carts': '0.004', 'w_recall_orders': '0.011', 'score': '0.017'}
# 0:06:16.710181 	 session_latest_time_wt_pair12
# 0:06:16.711556 	 {'num_clicks': 97136, 'hit_clicks': 1499, 'num_carts': 37850, 'hit_carts': 585, 'num_orders': 17856, 'hit_orders': 340, 'recall_clicks': '0.015', 'recall_carts': '0.015', 'recall_orders': '0.019', 'w_recall_clicks': '0.002', 'w_recall_carts': '0.005', 'w_recall_orders': '0.011', 'score': '0.018'}
# 0:06:23.139060 	 session_latest_word2vec_pair12
# 0:06:23.140229 	 {'num_clicks': 97136, 'hit_clicks': 990, 'num_carts': 37850, 'hit_carts': 359, 'num_orders': 17856, 'hit_orders': 208, 'recall_clicks': '0.010', 'recall_carts': '0.009', 'recall_orders': '0.012', 'w_recall_clicks': '0.001', 'w_recall_carts': '0.003', 'w_recall_orders': '0.007', 'score': '0.011'}
# 0:06:29.217108 	 session_latest_pair12
# 0:06:29.218556 	 {'num_clicks': 97136, 'hit_clicks': 1223, 'num_carts': 37850, 'hit_carts': 464, 'num_orders': 17856, 'hit_orders': 277, 'recall_clicks': '0.013', 'recall_carts': '0.012', 'recall_orders': '0.016', 'w_recall_clicks': '0.001', 'w_recall_carts': '0.004', 'w_recall_orders': '0.009', 'score': '0.014'}
# 0:06:36.107254 	 session_latest_time_wt_pair13
# 0:06:36.108492 	 {'num_clicks': 97136, 'hit_clicks': 1359, 'num_carts': 37850, 'hit_carts': 530, 'num_orders': 17856, 'hit_orders': 345, 'recall_clicks': '0.014', 'recall_carts': '0.014', 'recall_orders': '0.019', 'w_recall_clicks': '0.001', 'w_recall_carts': '0.004', 'w_recall_orders': '0.012', 'score': '0.017'}
# 0:06:42.996804 	 session_latest_word2vec_pair13
# 0:06:42.998293 	 {'num_clicks': 97136, 'hit_clicks': 923, 'num_carts': 37850, 'hit_carts': 348, 'num_orders': 17856, 'hit_orders': 169, 'recall_clicks': '0.010', 'recall_carts': '0.009', 'recall_orders': '0.009', 'w_recall_clicks': '0.001', 'w_recall_carts': '0.003', 'w_recall_orders': '0.006', 'score': '0.009'}
# 0:06:49.718419 	 session_latest_pair13
# 0:06:49.719864 	 {'num_clicks': 97136, 'hit_clicks': 1154, 'num_carts': 37850, 'hit_carts': 433, 'num_orders': 17856, 'hit_orders': 285, 'recall_clicks': '0.012', 'recall_carts': '0.011', 'recall_orders': '0.016', 'w_recall_clicks': '0.001', 'w_recall_carts': '0.003', 'w_recall_orders': '0.010', 'score': '0.014'}
# 0:06:57.108957 	 session_latest_time_wt_pair14
# 0:06:57.110118 	 {'num_clicks': 97136, 'hit_clicks': 1290, 'num_carts': 37850, 'hit_carts': 496, 'num_orders': 17856, 'hit_orders': 288, 'recall_clicks': '0.013', 'recall_carts': '0.013', 'recall_orders': '0.016', 'w_recall_clicks': '0.001', 'w_recall_carts': '0.004', 'w_recall_orders': '0.010', 'score': '0.015'}
# 0:07:04.640633 	 session_latest_word2vec_pair14
# 0:07:04.641937 	 {'num_clicks': 97136, 'hit_clicks': 852, 'num_carts': 37850, 'hit_carts': 308, 'num_orders': 17856, 'hit_orders': 161, 'recall_clicks': '0.009', 'recall_carts': '0.008', 'recall_orders': '0.009', 'w_recall_clicks': '0.001', 'w_recall_carts': '0.002', 'w_recall_orders': '0.005', 'score': '0.009'}
# 0:07:12.679884 	 session_latest_pair14
# 0:07:12.681114 	 {'num_clicks': 97136, 'hit_clicks': 1112, 'num_carts': 37850, 'hit_carts': 417, 'num_orders': 17856, 'hit_orders': 292, 'recall_clicks': '0.011', 'recall_carts': '0.011', 'recall_orders': '0.016', 'w_recall_clicks': '0.001', 'w_recall_carts': '0.003', 'w_recall_orders': '0.010', 'score': '0.014'}
# 0:07:20.695214 	 session_latest_time_wt_pair15
# 0:07:20.696422 	 {'num_clicks': 97136, 'hit_clicks': 1182, 'num_carts': 37850, 'hit_carts': 448, 'num_orders': 17856, 'hit_orders': 271, 'recall_clicks': '0.012', 'recall_carts': '0.012', 'recall_orders': '0.015', 'w_recall_clicks': '0.001', 'w_recall_carts': '0.004', 'w_recall_orders': '0.009', 'score': '0.014'}
# 0:07:29.135752 	 session_latest_word2vec_pair15
# 0:07:29.137190 	 {'num_clicks': 97136, 'hit_clicks': 877, 'num_carts': 37850, 'hit_carts': 306, 'num_orders': 17856, 'hit_orders': 176, 'recall_clicks': '0.009', 'recall_carts': '0.008', 'recall_orders': '0.010', 'w_recall_clicks': '0.001', 'w_recall_carts': '0.002', 'w_recall_orders': '0.006', 'score': '0.009'}
# 0:07:38.667335 	 session_latest_pair15
# 0:07:38.668696 	 {'num_clicks': 97136, 'hit_clicks': 1024, 'num_carts': 37850, 'hit_carts': 369, 'num_orders': 17856, 'hit_orders': 260, 'recall_clicks': '0.011', 'recall_carts': '0.010', 'recall_orders': '0.015', 'w_recall_clicks': '0.001', 'w_recall_carts': '0.003', 'w_recall_orders': '0.009', 'score': '0.013'}
# 0:07:47.568233 	 session_latest_time_wt_pair16
# 0:07:47.569444 	 {'num_clicks': 97136, 'hit_clicks': 1141, 'num_carts': 37850, 'hit_carts': 432, 'num_orders': 17856, 'hit_orders': 292, 'recall_clicks': '0.012', 'recall_carts': '0.011', 'recall_orders': '0.016', 'w_recall_clicks': '0.001', 'w_recall_carts': '0.003', 'w_recall_orders': '0.010', 'score': '0.014'}
# 0:07:56.689857 	 session_latest_word2vec_pair16
# 0:07:56.691022 	 {'num_clicks': 97136, 'hit_clicks': 789, 'num_carts': 37850, 'hit_carts': 268, 'num_orders': 17856, 'hit_orders': 140, 'recall_clicks': '0.008', 'recall_carts': '0.007', 'recall_orders': '0.008', 'w_recall_clicks': '0.001', 'w_recall_carts': '0.002', 'w_recall_orders': '0.005', 'score': '0.008'}
# 0:08:05.749422 	 session_latest_pair16
# 0:08:05.750941 	 {'num_clicks': 97136, 'hit_clicks': 918, 'num_carts': 37850, 'hit_carts': 377, 'num_orders': 17856, 'hit_orders': 260, 'recall_clicks': '0.009', 'recall_carts': '0.010', 'recall_orders': '0.015', 'w_recall_clicks': '0.001', 'w_recall_carts': '0.003', 'w_recall_orders': '0.009', 'score': '0.013'}
# 0:08:15.036306 	 session_latest_time_wt_pair17
# 0:08:15.037554 	 {'num_clicks': 97136, 'hit_clicks': 1140, 'num_carts': 37850, 'hit_carts': 455, 'num_orders': 17856, 'hit_orders': 266, 'recall_clicks': '0.012', 'recall_carts': '0.012', 'recall_orders': '0.015', 'w_recall_clicks': '0.001', 'w_recall_carts': '0.004', 'w_recall_orders': '0.009', 'score': '0.014'}
# 0:08:24.441169 	 session_latest_word2vec_pair17
# 0:08:24.442574 	 {'num_clicks': 97136, 'hit_clicks': 721, 'num_carts': 37850, 'hit_carts': 269, 'num_orders': 17856, 'hit_orders': 134, 'recall_clicks': '0.007', 'recall_carts': '0.007', 'recall_orders': '0.008', 'w_recall_clicks': '0.001', 'w_recall_carts': '0.002', 'w_recall_orders': '0.005', 'score': '0.007'}
# 0:08:34.338524 	 session_latest_pair17
# 0:08:34.339689 	 {'num_clicks': 97136, 'hit_clicks': 871, 'num_carts': 37850, 'hit_carts': 341, 'num_orders': 17856, 'hit_orders': 219, 'recall_clicks': '0.009', 'recall_carts': '0.009', 'recall_orders': '0.012', 'w_recall_clicks': '0.001', 'w_recall_carts': '0.003', 'w_recall_orders': '0.007', 'score': '0.011'}
# 0:08:44.055159 	 session_latest_time_wt_pair18
# 0:08:44.056739 	 {'num_clicks': 97136, 'hit_clicks': 1022, 'num_carts': 37850, 'hit_carts': 390, 'num_orders': 17856, 'hit_orders': 242, 'recall_clicks': '0.011', 'recall_carts': '0.010', 'recall_orders': '0.014', 'w_recall_clicks': '0.001', 'w_recall_carts': '0.003', 'w_recall_orders': '0.008', 'score': '0.012'}
# 0:08:54.411105 	 session_latest_word2vec_pair18
# 0:08:54.412471 	 {'num_clicks': 97136, 'hit_clicks': 755, 'num_carts': 37850, 'hit_carts': 287, 'num_orders': 17856, 'hit_orders': 131, 'recall_clicks': '0.008', 'recall_carts': '0.008', 'recall_orders': '0.007', 'w_recall_clicks': '0.001', 'w_recall_carts': '0.002', 'w_recall_orders': '0.004', 'score': '0.007'}
# 0:09:04.778168 	 session_latest_pair18
# 0:09:04.779416 	 {'num_clicks': 97136, 'hit_clicks': 825, 'num_carts': 37850, 'hit_carts': 318, 'num_orders': 17856, 'hit_orders': 251, 'recall_clicks': '0.008', 'recall_carts': '0.008', 'recall_orders': '0.014', 'w_recall_clicks': '0.001', 'w_recall_carts': '0.003', 'w_recall_orders': '0.008', 'score': '0.012'}
# 0:09:15.493146 	 session_latest_time_wt_pair19
# 0:09:15.494661 	 {'num_clicks': 97136, 'hit_clicks': 994, 'num_carts': 37850, 'hit_carts': 364, 'num_orders': 17856, 'hit_orders': 217, 'recall_clicks': '0.010', 'recall_carts': '0.010', 'recall_orders': '0.012', 'w_recall_clicks': '0.001', 'w_recall_carts': '0.003', 'w_recall_orders': '0.007', 'score': '0.011'}
# 0:09:26.471909 	 session_latest_word2vec_pair19
# 0:09:26.473082 	 {'num_clicks': 97136, 'hit_clicks': 709, 'num_carts': 37850, 'hit_carts': 297, 'num_orders': 17856, 'hit_orders': 143, 'recall_clicks': '0.007', 'recall_carts': '0.008', 'recall_orders': '0.008', 'w_recall_clicks': '0.001', 'w_recall_carts': '0.002', 'w_recall_orders': '0.005', 'score': '0.008'}
# 0:09:37.311210 	 session_latest_pair19
# 0:09:37.312373 	 {'num_clicks': 97136, 'hit_clicks': 810, 'num_carts': 37850, 'hit_carts': 311, 'num_orders': 17856, 'hit_orders': 224, 'recall_clicks': '0.008', 'recall_carts': '0.008', 'recall_orders': '0.013', 'w_recall_clicks': '0.001', 'w_recall_carts': '0.002', 'w_recall_orders': '0.008', 'score': '0.011'}
# 0:09:48.717981 	 session_latest_type_wt_pair0
# 0:09:48.719432 	 {'num_clicks': 97136, 'hit_clicks': 6448, 'num_carts': 37850, 'hit_carts': 2324, 'num_orders': 17856, 'hit_orders': 1686, 'recall_clicks': '0.066', 'recall_carts': '0.061', 'recall_orders': '0.094', 'w_recall_clicks': '0.007', 'w_recall_carts': '0.018', 'w_recall_orders': '0.057', 'score': '0.082'}
# 0:09:59.508256 	 session_latest_clicks2carts_pair0
# 0:09:59.509622 	 {'num_clicks': 97136, 'hit_clicks': 4076, 'num_carts': 37850, 'hit_carts': 1700, 'num_orders': 17856, 'hit_orders': 1165, 'recall_clicks': '0.042', 'recall_carts': '0.045', 'recall_orders': '0.065', 'w_recall_clicks': '0.004', 'w_recall_carts': '0.013', 'w_recall_orders': '0.039', 'score': '0.057'}
# 0:10:11.063988 	 session_latest_clicks2orders_pair0
# 0:10:11.065226 	 {'num_clicks': 97136, 'hit_clicks': 2474, 'num_carts': 37850, 'hit_carts': 1174, 'num_orders': 17856, 'hit_orders': 801, 'recall_clicks': '0.025', 'recall_carts': '0.031', 'recall_orders': '0.045', 'w_recall_clicks': '0.003', 'w_recall_carts': '0.009', 'w_recall_orders': '0.027', 'score': '0.039'}
# 0:10:22.659349 	 session_latest_type_wt_pair1
# 0:10:22.660460 	 {'num_clicks': 97136, 'hit_clicks': 4502, 'num_carts': 37850, 'hit_carts': 1629, 'num_orders': 17856, 'hit_orders': 1146, 'recall_clicks': '0.046', 'recall_carts': '0.043', 'recall_orders': '0.064', 'w_recall_clicks': '0.005', 'w_recall_carts': '0.013', 'w_recall_orders': '0.039', 'score': '0.056'}
# 0:10:34.313046 	 session_latest_clicks2carts_pair1
# 0:10:34.314260 	 {'num_clicks': 97136, 'hit_clicks': 2792, 'num_carts': 37850, 'hit_carts': 1165, 'num_orders': 17856, 'hit_orders': 788, 'recall_clicks': '0.029', 'recall_carts': '0.031', 'recall_orders': '0.044', 'w_recall_clicks': '0.003', 'w_recall_carts': '0.009', 'w_recall_orders': '0.026', 'score': '0.039'}
# 0:10:46.088603 	 session_latest_clicks2orders_pair1
# 0:10:46.089777 	 {'num_clicks': 97136, 'hit_clicks': 1539, 'num_carts': 37850, 'hit_carts': 672, 'num_orders': 17856, 'hit_orders': 464, 'recall_clicks': '0.016', 'recall_carts': '0.018', 'recall_orders': '0.026', 'w_recall_clicks': '0.002', 'w_recall_carts': '0.005', 'w_recall_orders': '0.016', 'score': '0.023'}
# 0:10:58.560079 	 session_latest_type_wt_pair2
# 0:10:58.561330 	 {'num_clicks': 97136, 'hit_clicks': 3486, 'num_carts': 37850, 'hit_carts': 1353, 'num_orders': 17856, 'hit_orders': 928, 'recall_clicks': '0.036', 'recall_carts': '0.036', 'recall_orders': '0.052', 'w_recall_clicks': '0.004', 'w_recall_carts': '0.011', 'w_recall_orders': '0.031', 'score': '0.045'}
# 0:11:09.883744 	 session_latest_clicks2carts_pair2
# 0:11:09.885226 	 {'num_clicks': 97136, 'hit_clicks': 2130, 'num_carts': 37850, 'hit_carts': 991, 'num_orders': 17856, 'hit_orders': 601, 'recall_clicks': '0.022', 'recall_carts': '0.026', 'recall_orders': '0.034', 'w_recall_clicks': '0.002', 'w_recall_carts': '0.008', 'w_recall_orders': '0.020', 'score': '0.030'}
# 0:11:22.196692 	 session_latest_clicks2orders_pair2
# 0:11:22.197863 	 {'num_clicks': 97136, 'hit_clicks': 1141, 'num_carts': 37850, 'hit_carts': 526, 'num_orders': 17856, 'hit_orders': 337, 'recall_clicks': '0.012', 'recall_carts': '0.014', 'recall_orders': '0.019', 'w_recall_clicks': '0.001', 'w_recall_carts': '0.004', 'w_recall_orders': '0.011', 'score': '0.017'}
# 0:11:34.979173 	 session_latest_type_wt_pair3
# 0:11:34.980586 	 {'num_clicks': 97136, 'hit_clicks': 3009, 'num_carts': 37850, 'hit_carts': 1121, 'num_orders': 17856, 'hit_orders': 795, 'recall_clicks': '0.031', 'recall_carts': '0.030', 'recall_orders': '0.045', 'w_recall_clicks': '0.003', 'w_recall_carts': '0.009', 'w_recall_orders': '0.027', 'score': '0.039'}
# 0:11:46.680018 	 session_latest_clicks2carts_pair3
# 0:11:46.681398 	 {'num_clicks': 97136, 'hit_clicks': 1694, 'num_carts': 37850, 'hit_carts': 811, 'num_orders': 17856, 'hit_orders': 486, 'recall_clicks': '0.017', 'recall_carts': '0.021', 'recall_orders': '0.027', 'w_recall_clicks': '0.002', 'w_recall_carts': '0.006', 'w_recall_orders': '0.016', 'score': '0.025'}
# 0:11:58.923486 	 session_latest_clicks2orders_pair3
# 0:11:58.924891 	 {'num_clicks': 97136, 'hit_clicks': 931, 'num_carts': 37850, 'hit_carts': 435, 'num_orders': 17856, 'hit_orders': 272, 'recall_clicks': '0.010', 'recall_carts': '0.011', 'recall_orders': '0.015', 'w_recall_clicks': '0.001', 'w_recall_carts': '0.003', 'w_recall_orders': '0.009', 'score': '0.014'}
# 0:12:12.429622 	 session_latest_type_wt_pair4
# 0:12:12.430989 	 {'num_clicks': 97136, 'hit_clicks': 2539, 'num_carts': 37850, 'hit_carts': 931, 'num_orders': 17856, 'hit_orders': 686, 'recall_clicks': '0.026', 'recall_carts': '0.025', 'recall_orders': '0.038', 'w_recall_clicks': '0.003', 'w_recall_carts': '0.007', 'w_recall_orders': '0.023', 'score': '0.033'}
# 0:12:25.356637 	 session_latest_clicks2carts_pair4
# 0:12:25.358050 	 {'num_clicks': 97136, 'hit_clicks': 1514, 'num_carts': 37850, 'hit_carts': 675, 'num_orders': 17856, 'hit_orders': 391, 'recall_clicks': '0.016', 'recall_carts': '0.018', 'recall_orders': '0.022', 'w_recall_clicks': '0.002', 'w_recall_carts': '0.005', 'w_recall_orders': '0.013', 'score': '0.020'}
# 0:12:38.046421 	 session_latest_clicks2orders_pair4
# 0:12:38.047790 	 {'num_clicks': 97136, 'hit_clicks': 734, 'num_carts': 37850, 'hit_carts': 355, 'num_orders': 17856, 'hit_orders': 217, 'recall_clicks': '0.008', 'recall_carts': '0.009', 'recall_orders': '0.012', 'w_recall_clicks': '0.001', 'w_recall_carts': '0.003', 'w_recall_orders': '0.007', 'score': '0.011'}

# %%
results
# Out:
#                                   name num_clicks hit_clicks num_carts  \
# 0                     session_frequent      97136      29467     42864
# 0                       session_latest      97136      29677     42864
# 0         session_latest_time_wt_pair0      97136       7631     37850
# 0        session_latest_word2vec_pair0      97136       4513     37850
# 0                 session_latest_pair0      97136       6545     37850
# ..                                 ...        ...        ...       ...
# 0    session_latest_clicks2carts_pair3      97136       1694     37850
# 0   session_latest_clicks2orders_pair3      97136        931     37850
# 0         session_latest_type_wt_pair4      97136       2539     37850
# 0    session_latest_clicks2carts_pair4      97136       1514     37850
# 0   session_latest_clicks2orders_pair4      97136        734     37850
#
#    hit_carts num_orders hit_orders recall_clicks recall_carts recall_orders  \
# 0      10730      19985      10185         0.303        0.250         0.510
# 0      10822      19985       9838         0.306        0.252         0.492
# 0       2267      17856       1479         0.079        0.060         0.083
# 0       1459      17856        806         0.046        0.039         0.045
# 0       2105      17856       1450         0.067        0.056         0.081
# ..       ...        ...        ...           ...          ...           ...
# 0        811      17856        486         0.017        0.021         0.027
# 0        435      17856        272         0.010        0.011         0.015
# 0        931      17856        686         0.026        0.025         0.038
# 0        675      17856        391         0.016        0.018         0.022
# 0        355      17856        217         0.008        0.009         0.012
#
#    w_recall_clicks w_recall_carts w_recall_orders  score
# 0            0.030          0.075           0.306  0.411
# 0            0.031          0.076           0.295  0.402
# 0            0.008          0.018           0.050  0.076
# 0            0.005          0.012           0.027  0.043
# 0            0.007          0.017           0.049  0.072
# ..             ...            ...             ...    ...
# 0            0.002          0.006           0.016  0.025
# 0            0.001          0.003           0.009  0.014
# 0            0.003          0.007           0.023  0.033
# 0            0.002          0.005           0.013  0.020
# 0            0.001          0.003           0.007  0.011
#
# [77 rows x 14 columns]

# %%
fig, axs = plt.subplots(1, 3)
sns.heatmap(results.set_index("name")[["recall_clicks"]].astype(float),
            annot=True, linewidths=.5, fmt="1.2f", cmap="Reds", cbar=False, ax=axs[0])
sns.heatmap(results.set_index("name")[["recall_carts"]].astype(float),
            annot=True, linewidths=.5, fmt="1.2f", cmap="Reds", cbar=False, ax=axs[1], yticklabels=False)
sns.heatmap(results.set_index("name")[["recall_orders"]].astype(float),
            annot=True, linewidths=.5, fmt="1.2f", cmap="Reds", cbar=False, ax=axs[2], yticklabels=False)
plt.savefig(cfg.output_dir + f'{cfg.exp_name}/candidate_strategy_recalls.png')

# %%
# 予測値を全て使えたときのrecall
valid_all = valid.drop_duplicates(subset= ["session", "aid"])
session_cnt_max = valid_all["session"].value_counts().max()
valid_all = valid_all.groupby("session")["aid"].apply(list).reset_index()

all_results = evaluate(valid_labels["clicks_labels"].tolist(),
                       valid_labels["carts_labels"].tolist(),
                       valid_labels["orders_labels"].tolist(),
                       valid_all["aid"].tolist(),
                       valid_all["aid"].tolist(),
                       valid_all["aid"].tolist(),
                       session_cnt_max)
logger.info("session_cnt_max")
logger.info(session_cnt_max)
logger.info("all_pred_results")
logger.info(all_results)
# Out:
# 0:12:48.502745 	 session_cnt_max
# 0:12:48.504379 	 308
# 0:12:48.505455 	 all_pred_results
# 0:12:48.506563 	 {'num_clicks': 97136, 'hit_clicks': 56375, 'num_carts': 43611, 'hit_carts': 18342, 'num_orders': 20109, 'hit_orders': 12600, 'recall_clicks': '0.580', 'recall_carts': '0.421', 'recall_orders': '0.627', 'w_recall_clicks': '0.058', 'w_recall_carts': '0.126', 'w_recall_orders': '0.376', 'score': '0.560'}
