# %%
import os
import sys
import traceback
import gc
import random
import pickle
import pathlib
import subprocess
from dataclasses import dataclass
from dotenv import load_dotenv
load_dotenv
sys.path.append(os.getenv('UTILS_PATH'))
from tqdm import tqdm
import multiprocessing
import inspect

import pandas as pd
import numpy as np
import itertools
import cudf
import lightgbm as lgb
import matplotlib.pyplot as plt
import seaborn as sns
import line_notify
import my_logger
from noglobal import noglobal
import optuna

# %% [markdown]
# # 設定

# %%
@dataclass
class Cfg:
    loglevel = "INFO"
    exp_name = "cv_score_issue"
    seed = 42
    k = 20
    cand_n = 15
    type2id = {"clicks":0, "carts":1, "orders":2}
    id2type = {0:"clicks", 1:"carts", 2:"orders"}
    train_weeks = ["week3"]
    valid_week = "week4"
    valid_session_n = 100_000
    input_dir = os.getenv('INPUT_DIR')
    output_dir = os.getenv('OUTPUT_DIR')
    prep_dir = os.getenv("PREP_DIR")

cfg = Cfg()
os.makedirs(os.path.join(cfg.output_dir, cfg.exp_name), exist_ok=True)
os.makedirs(os.path.join(cfg.output_dir, cfg.exp_name, "cache"), exist_ok=True)
random.seed(cfg.seed)

# %%
class Cache:
    @noglobal(excepts=["cfg", "logger"])
    def __init__(self):
        self.cache_dir = (os.path.join(cfg.output_dir, cfg.exp_name, "cache"))
        self.cache_dir_path = pathlib.Path(self.cache_dir)
        self.caches = list(self.cache_dir_path.glob("*.pkl"))

    @noglobal(excepts=["cfg", "logger"])
    def get_abspath(self, filename):
        return (os.path.join(self.cache_dir, f"{cfg.exp_name}_{filename}"))
    
    @noglobal(excepts=["cfg", "logger"])
    def exists(self, path):
        return len([str(c) for c in self.caches if path == str(c)]) > 0

# %%
logger = my_logger.init_logger(cfg.exp_name)
cache = Cache()

# %%
@noglobal(excepts=["cfg", "logger"])
def evaluate(clicks_labels, carts_labels, orders_labels, 
             clicks_preds, carts_preds, orders_preds, k=20):

    num_clicks = 0
    num_carts = 0
    num_orders = 0
    hit_clicks = 0
    hit_carts = 0
    hit_orders = 0

    for i in range(len(clicks_labels)):
        clicks_label = clicks_labels[i]
        carts_label = carts_labels[i]
        orders_label = orders_labels[i]
        clicks_pred = clicks_preds[i]
        carts_pred = carts_preds[i]
        orders_pred = orders_preds[i]

        if type(clicks_pred) == list:
            clicks_pred = clicks_pred[:k]
        else:
            clicks_pred = []
        if type(carts_pred) == list:
            carts_pred = carts_pred[:k]
        else:
            carts_pred = []    
        if type(orders_pred) == list:
            orders_pred = orders_pred[:k]
        else:
            orders_pred = []

        if not np.isnan(clicks_label):
            num_clicks += 1
            hit_clicks += int(clicks_label in clicks_pred)

        if type(carts_label) == list:
            num_carts += min(len(carts_label), k)
            hit_carts += len(set(carts_pred) & set(carts_label))
            
        if type(orders_label) == list:
            num_orders += min(len(orders_label), k)
            hit_orders += len(set(orders_pred) & set(orders_label))


    recall_clicks = hit_clicks / num_clicks
    recall_carts = hit_carts / num_carts
    recall_orders = hit_orders / num_orders
    w_recall_clicks = recall_clicks * 0.10
    w_recall_carts = recall_carts * 0.30
    w_recall_orders = recall_orders * 0.60
    score = w_recall_clicks + w_recall_carts + w_recall_orders

    results = {}
    results["num_clicks"] = num_clicks
    results["hit_clicks"] = hit_clicks
    results["num_carts"] = num_carts
    results["hit_carts"] = hit_carts
    results["num_orders"] = num_orders
    results["hit_orders"] = hit_orders
    results["recall_clicks"] = format(recall_clicks, ".3f")
    results["recall_carts"] = format(recall_carts, ".3f")
    results["recall_orders"] = format(recall_orders, ".3f")
    results["w_recall_clicks"] = format(w_recall_clicks, ".3f")
    results["w_recall_carts"] = format(w_recall_carts, ".3f")
    results["w_recall_orders"] = format(w_recall_orders, ".3f")
    results["score"] = format(score, ".3f")

    return results

# %%
class Candidate:
    @noglobal(excepts=["cfg", "logger"])
    def __init__(self, pdf, week, labels=None):
        self.df = cudf.from_pandas(pdf)
        self.target_sessions = pdf["session"].unique().tolist()
        self.results = pd.DataFrame(columns=["name", "num_clicks", "hit_clicks", "num_carts", "hit_carts", "num_orders", "hit_orders", 
                                             "recall_clicks", "recall_carts", "recall_orders", "w_recall_clicks", "w_recall_carts", "w_recall_orders", "score"])
        self.output = pd.DataFrame(columns=["session", "aid"], dtype=int)
        self.labels = labels
        self.week = week
    
    @noglobal(excepts=["cfg", "logger"])
    def _entry(self, new_candidate_df, name, k):
        logger.info(f"[add_candidate] {name} : start")
        new_candidate_df = new_candidate_df.to_pandas()
        self.output = pd.concat([self.output, new_candidate_df[["session", "aid"]]])
        self.output = self.output.drop_duplicates(subset=["session", "aid"])

        if self.labels is not None:
            self._eval(new_candidate_df[["session", "aid"]], name, k)
    
    @noglobal(excepts=["cfg", "logger"])
    def _eval(self, new_candidate_df, name, k):
        new_candidate_df = new_candidate_df.groupby("session")["aid"].apply(list).reset_index()
        eval_df = pd.DataFrame(self.target_sessions, columns=["session"])
        eval_df = eval_df.merge(new_candidate_df, on=["session"], how="left")
        assert eval_df["session"].tolist() == self.labels["session"].tolist()
        eval_result = evaluate(self.labels["clicks_labels"].tolist(), self.labels["carts_labels"].tolist(), self.labels["orders_labels"].tolist(),
                               eval_df["aid"].tolist(), eval_df["aid"].tolist(), eval_df["aid"].tolist(), k)
        
        logger.info(name)
        logger.info(eval_result)
        self.results = pd.concat([self.results, pd.DataFrame([[name] + list(eval_result.values())], columns=["name"] + list(eval_result.keys()))])

    @noglobal(excepts=["cfg", "logger"])
    def add(self, strategy, name, usetypes=['clicks', 'carts', 'orders'], trans_map=None, k=20):
        logger.info(f"[make_candidate] {name} : start")
        candidate_df = self.df[self.df["type"].isin(usetypes)].copy()
        
        if strategy == "session_frequent":
            candidate_df = self._session_frequent(candidate_df, k)
        elif strategy == "session_latest":
            candidate_df = self._session_latest(candidate_df, k)
        elif strategy == "total_frequent":
            candidate_df = self._total_frequent(candidate_df, k)
        elif strategy == "w2v_session_total_aid_vec_sim":
            candidate_df = self._w2v_session_total_aid_vec_sim()
        elif strategy == "w2v_session_carts_total_aid_vec_sim":
            candidate_df = self._w2v_session_carts_total_aid_vec_sim()
        
        if trans_map is not None:
            candidate_df["aid"] = candidate_df["aid"].map(trans_map)
            candidate_df = candidate_df.dropna(subset=["aid"])
            
        self._entry(candidate_df, name, k)

    @noglobal(excepts=["cfg", "logger"])
    def _session_frequent(self, candidate_df, k):
        candidate_df = candidate_df.groupby(["session", "aid"])["ts"].count().reset_index()
        candidate_df.columns = ["session", "aid", "aid_count"]
        candidate_df = candidate_df.sort_values(["session", "aid_count", "aid"], ascending=(True, False, True))
        candidate_df = candidate_df[candidate_df.groupby("session")["aid_count"].cumcount() < k].copy()
        candidate_df = candidate_df[["session", "aid"]].copy()
        return candidate_df

    @noglobal(excepts=["cfg", "logger"])
    def _session_latest(self, candidate_df, k):
        candidate_df = candidate_df.sort_values(["session", "ts"], ascending=(True, False)).drop_duplicates(subset=["session", "aid"])
        candidate_df = candidate_df.sort_values(["session", "ts"], ascending=(True, False))[candidate_df.groupby("session")["ts"].cumcount() < k].copy()
        candidate_df = candidate_df[["session", "aid"]].copy()
        return candidate_df

    @noglobal(excepts=["cfg", "logger"])
    def _total_frequent(self, candidate_df, k):
        candidate_df = candidate_df.groupby("aid")["ts"].count().reset_index()
        candidate_df.columns = ["aid", "aid_count"]
        topk_freq_aids = candidate_df.sort_values("aid_count", ascending=False)["aid"].to_arrow().to_pylist()[:k]
        sessions = []
        aids = []
        for session, aid in itertools.product(self.target_sessions, topk_freq_aids):
            sessions.append(session)
            aids.append(aid)
        candidate_df = cudf.DataFrame({"session": sessions, "aid": aids})
        return candidate_df

    @noglobal(excepts=["cfg", "logger"])
    def _w2v_session_total_aid_vec_sim(self):
        if self.week is not None:
            candidate_df = pd.read_pickle(cfg.prep_dir + f"w2v_session_total_avg_similar_aids_{self.week}.pkl")
        else:
            candidate_df = pd.read_pickle(cfg.prep_dir + "w2v_session_total_avg_similar_aids.pkl")
        candidate_df = cudf.from_pandas(candidate_df)
        candidate_df = candidate_df[["session", "aid"]].copy()
        candidate_df = candidate_df[candidate_df["session"].isin(self.target_sessions)]
        return candidate_df

    @noglobal(excepts=["cfg", "logger"])
    def _w2v_session_carts_total_aid_vec_sim(self):
        if self.week is not None:
            candidate_df = pd.read_pickle(cfg.prep_dir + f"w2v_session_carts_total_avg_similar_aids_{self.week}.pkl")
        else:
            candidate_df = pd.read_pickle(cfg.prep_dir + "w2v_session_carts_total_avg_similar_aids.pkl")
        candidate_df = cudf.from_pandas(candidate_df)
        candidate_df = candidate_df[["session", "aid"]].copy()
        candidate_df = candidate_df[candidate_df["session"].isin(self.target_sessions)]
        return candidate_df

# %%
@noglobal(excepts=["cfg", "logger"])
def make_cand_df(sessions, week, labels=None, trans_maps=None):

    if labels is not None:
         cand = Candidate(sessions, week, labels)
    else:
        cand = Candidate(sessions, week)

    cand.add(strategy="session_frequent", name="session_frequent", k=15)
    cand.add(strategy="session_latest", name="session_latest", k=15)
    cand.add(strategy="w2v_session_total_aid_vec_sim", name="w2v_session_total_aid_vec_sim")
    cand.add(strategy="w2v_session_carts_total_aid_vec_sim", name="w2v_session_carts_total_aid_vec_sim")
    
    for i in range(20):
        cand.add(strategy="session_latest", trans_map=trans_maps[f"time_wt_pair{str(i)}"], name=f"session_latest_time_wt_pair{str(i)}", k=5)
        cand.add(strategy="session_latest", trans_map=trans_maps[f"word2vec_pair{str(i)}"], name=f"session_latest_word2vec_pair{str(i)}", k=5)
        cand.add(strategy="session_latest", trans_map=trans_maps[f"pair{str(i)}"], name=f"session_latest_pair{str(i)}", k=5)
        cand.add(strategy="session_latest", trans_map=trans_maps[f"type_wt_pair{str(i)}"], name=f"session_latest_type_wt_pair{str(i)}", k=5)
        cand.add(strategy="session_latest", trans_map=trans_maps[f"clicks2carts_pair{str(i)}"], name=f"session_latest_clicks2carts_pair{str(i)}", k=5)
        cand.add(strategy="session_latest", trans_map=trans_maps[f"clicks2orders_pair{str(i)}"], name=f"session_latest_clicks2orders_pair{str(i)}", k=5)

    if labels is not None:
        return cand.output, cand.results
    else:
        return cand.output

# %%
@noglobal(excepts=["cfg", "logger"])
def get_pair_df(name, wt_col, week):
    if week is not None:
        name = f"{name}_{week}"
    pair_df = pd.read_pickle(cfg.prep_dir + f"{name}.pkl")
    pair_df = pair_df.sort_values(["aid_x", wt_col], ascending=(True, False))
    return pair_df

@noglobal(excepts=["cfg", "logger"])
def get_pair_dict(name, wt_col, week):
    if week is not None:
        name = f"{name}_{week}"
    pair_df = pd.read_pickle(cfg.prep_dir + f"{name}.pkl")
    pair_df = pair_df.sort_values(["aid_x", wt_col], ascending=(True, False))
    pair_df = pair_df.groupby("aid_x").head(1)[["aid_x", "aid_y"]]
    pair_dict = {k: v for k, v in zip(pair_df["aid_x"].tolist(), pair_df["aid_y"].tolist())}
    return pair_dict

@noglobal(excepts=["cfg", "logger"])
def get_trans_maps(week=None):
    """
    aidを別のaidに置き換えるmapping辞書を取得する
    """
    trans_maps = {}
    
    pair_df_org = get_pair_df("co_visitation_matrix", "cnt", week)
    for i in range(20):
        pair_df = pair_df_org.groupby("aid_x").nth(i).reset_index()[["aid_x", "aid_y"]]
        pair_dict = {k: v for k, v in zip(pair_df["aid_x"].tolist(), pair_df["aid_y"].tolist())}
        trans_maps[f"pair{str(i)}"] = pair_dict
    
    pair_df_org = get_pair_df("co_visitation_matrix_time_weighted", "wt", week)
    for i in range(20):
        pair_df = pair_df_org.groupby("aid_x").nth(i).reset_index()[["aid_x", "aid_y"]]
        pair_dict = {k: v for k, v in zip(pair_df["aid_x"].tolist(), pair_df["aid_y"].tolist())}
        trans_maps[f"time_wt_pair{str(i)}"] = pair_dict

    pair_df_org = get_pair_df("co_visitation_matrix_type_weighted", "wt", week)
    for i in range(20):
        pair_df = pair_df_org.groupby("aid_x").nth(i).reset_index()[["aid_x", "aid_y"]]
        pair_dict = {k: v for k, v in zip(pair_df["aid_x"].tolist(), pair_df["aid_y"].tolist())}
        trans_maps[f"type_wt_pair{str(i)}"] = pair_dict

    pair_df_org = get_pair_df("co_visitation_matrix_clicks2carts", "cnt", week)
    for i in range(20):
        pair_df = pair_df_org.groupby("aid_x").nth(i).reset_index()[["aid_x", "aid_y"]]
        pair_dict = {k: v for k, v in zip(pair_df["aid_x"].tolist(), pair_df["aid_y"].tolist())}
        trans_maps[f"clicks2carts_pair{str(i)}"] = pair_dict

    pair_df_org = get_pair_df("co_visitation_matrix_clicks2orders", "cnt", week)
    for i in range(20):
        pair_df = pair_df_org.groupby("aid_x").nth(i).reset_index()[["aid_x", "aid_y"]]
        pair_dict = {k: v for k, v in zip(pair_df["aid_x"].tolist(), pair_df["aid_y"].tolist())}
        trans_maps[f"clicks2orders_pair{str(i)}"] = pair_dict

    pair_df_org = get_pair_df("word2vec_similar", "sim", None)
    for i in range(20):
        pair_df = pair_df_org.groupby("aid_x").nth(i).reset_index()[["aid_x", "aid_y"]]
        pair_dict = {k: v for k, v in zip(pair_df["aid_x"].tolist(), pair_df["aid_y"].tolist())}
        trans_maps[f"word2vec_pair{str(i)}"] = pair_dict

    with open(cfg.prep_dir + "matrix_factorization_embeddings_similar_top20.pkl", "rb") as f:
        nns = pickle.load(f)
    for i in range(20):
        pair_dict = {aid_x:aid_ys[i] for aid_x, aid_ys in enumerate(nns)}
        trans_maps[f"matrix_fact_pair{str(i)}"] = pair_dict

    return trans_maps

# %%
@noglobal(excepts=["cfg", "logger"])
def make_valid_data(trans_maps, valid_week):
    dfs = []
    
    logger.info(f"[make_valid] valid_week : {valid_week}")
    # データ読み込み
    logger.info("[make_valid] read_data : start")
    week_sessions = pd.read_pickle(os.getenv("PREP_DIR") + f"train_sessions_{valid_week}.pkl")
    week_labels = pd.read_pickle(os.getenv("PREP_DIR") + f"labels_{valid_week}.pkl")
    valid_session_ids = week_sessions["session"].unique().tolist()
    logger.info("[make_valid] read_data : end")

    # validに使うsessionを絞る (trainに存在するsessionを除外した上で設定した数に絞る)
    logger.info("[make_valid] valid_session_extract : start")
    valid_session_n = min(cfg.valid_session_n, len(valid_session_ids))
    valid_session_ids = random.sample(valid_session_ids, valid_session_n)
    week_sessions = week_sessions[week_sessions["session"].isin(valid_session_ids)].copy()
    week_labels = week_labels[week_labels["session"].isin(valid_session_ids)].copy()
    logger.info("[make_valid] valid_session_extract : end")

    # 候補選出
    logger.info("[make_valid] make_cand_df : start")
    valid, results = make_cand_df(week_sessions, valid_week, labels=week_labels, trans_maps=trans_maps)

    return valid, week_labels, results

# %%
results = []

for trans_maps_week, trans_maps_name in zip([None, "week3", "week4"],["test", "week3", "week4"]):
    for valid_week in ["week3", "week4"]:
        if trans_maps_week is None:
            trans_maps_path = cfg.output_dir + "cv_score_issue/trans_maps.pkl"
        else:
            trans_maps_path = cfg.output_dir + f"cv_score_issue/trans_maps_{trans_maps_week}.pkl"
        with open(trans_maps_path, "rb") as f:
            trans_maps = pickle.load(f)  
        valid, valid_labels, result = make_valid_data(trans_maps, valid_week)
        result.columns = result.columns + f"tm_{trans_maps_name}_vl_{valid_week}"
        results.append(result)
# Out:
# 0:00:23.116899 	 [make_valid] valid_week : week3
# 0:00:23.118903 	 [make_valid] read_data : start
# 0:00:29.780289 	 [make_valid] read_data : end
# 0:00:29.781435 	 [make_valid] valid_session_extract : start
# 0:00:30.829677 	 [make_valid] valid_session_extract : end
# 0:00:30.831237 	 [make_valid] make_cand_df : start
# 0:00:30.898276 	 [make_candidate] session_frequent : start
# 0:00:31.202997 	 [add_candidate] session_frequent : start
# 0:00:32.807742 	 session_frequent
# 0:00:32.809052 	 {'num_clicks': 97259, 'hit_clicks': 28853, 'num_carts': 40687, 'hit_carts': 10215, 'num_orders': 19728, 'hit_orders': 9987, 'recall_clicks': '0.297', 'recall_carts': '0.251', 'recall_orders': '0.506', 'w_recall_clicks': '0.030', 'w_recall_carts': '0.075', 'w_recall_orders': '0.304', 'score': '0.409'}
# 0:00:32.824820 	 [make_candidate] session_latest : start
# 0:00:33.101390 	 [add_candidate] session_latest : start
# 0:00:34.866920 	 session_latest
# 0:00:34.868100 	 {'num_clicks': 97259, 'hit_clicks': 29069, 'num_carts': 40687, 'hit_carts': 10280, 'num_orders': 19728, 'hit_orders': 9669, 'recall_clicks': '0.299', 'recall_carts': '0.253', 'recall_orders': '0.490', 'w_recall_clicks': '0.030', 'w_recall_carts': '0.076', 'w_recall_orders': '0.294', 'score': '0.400'}
# 0:00:34.878478 	 [make_candidate] w2v_session_total_aid_vec_sim : start
# 0:00:39.392896 	 [add_candidate] w2v_session_total_aid_vec_sim : start
# 0:00:41.656421 	 w2v_session_total_aid_vec_sim
# 0:00:41.657757 	 {'num_clicks': 97259, 'hit_clicks': 33501, 'num_carts': 41074, 'hit_carts': 8529, 'num_orders': 19811, 'hit_orders': 5749, 'recall_clicks': '0.344', 'recall_carts': '0.208', 'recall_orders': '0.290', 'w_recall_clicks': '0.034', 'w_recall_carts': '0.062', 'w_recall_orders': '0.174', 'score': '0.271'}
# 0:00:41.687000 	 [make_candidate] w2v_session_carts_total_aid_vec_sim : start
# 0:00:42.522500 	 [add_candidate] w2v_session_carts_total_aid_vec_sim : start
# 0:00:43.275565 	 w2v_session_carts_total_aid_vec_sim
# 0:00:43.277252 	 {'num_clicks': 97259, 'hit_clicks': 4565, 'num_carts': 41074, 'hit_carts': 3028, 'num_orders': 19811, 'hit_orders': 5018, 'recall_clicks': '0.047', 'recall_carts': '0.074', 'recall_orders': '0.253', 'w_recall_clicks': '0.005', 'w_recall_carts': '0.022', 'w_recall_orders': '0.152', 'score': '0.179'}
# 0:00:43.285651 	 [make_candidate] session_latest_time_wt_pair0 : start
# 0:00:43.666221 	 [add_candidate] session_latest_time_wt_pair0 : start
# 0:00:45.652427 	 session_latest_time_wt_pair0
# 0:00:45.653574 	 {'num_clicks': 97259, 'hit_clicks': 8657, 'num_carts': 36150, 'hit_carts': 2368, 'num_orders': 17756, 'hit_orders': 1551, 'recall_clicks': '0.089', 'recall_carts': '0.066', 'recall_orders': '0.087', 'w_recall_clicks': '0.009', 'w_recall_carts': '0.020', 'w_recall_orders': '0.052', 'score': '0.081'}
# 0:00:45.663133 	 [make_candidate] session_latest_word2vec_pair0 : start
# 0:00:46.211393 	 [add_candidate] session_latest_word2vec_pair0 : start
# 0:00:48.075589 	 session_latest_word2vec_pair0
# 0:00:48.076705 	 {'num_clicks': 97259, 'hit_clicks': 4717, 'num_carts': 36150, 'hit_carts': 1404, 'num_orders': 17756, 'hit_orders': 901, 'recall_clicks': '0.048', 'recall_carts': '0.039', 'recall_orders': '0.051', 'w_recall_clicks': '0.005', 'w_recall_carts': '0.012', 'w_recall_orders': '0.030', 'score': '0.047'}
# 0:00:48.087439 	 [make_candidate] session_latest_pair0 : start
# 0:00:48.639184 	 [add_candidate] session_latest_pair0 : start
# 0:00:50.709716 	 session_latest_pair0
# 0:00:50.711018 	 {'num_clicks': 97259, 'hit_clicks': 7656, 'num_carts': 36150, 'hit_carts': 2718, 'num_orders': 17756, 'hit_orders': 1892, 'recall_clicks': '0.079', 'recall_carts': '0.075', 'recall_orders': '0.107', 'w_recall_clicks': '0.008', 'w_recall_carts': '0.023', 'w_recall_orders': '0.064', 'score': '0.094'}
# 0:00:50.722337 	 [make_candidate] session_latest_type_wt_pair0 : start
# 0:00:51.052110 	 [add_candidate] session_latest_type_wt_pair0 : start
# 0:00:53.060777 	 session_latest_type_wt_pair0
# 0:00:53.062237 	 {'num_clicks': 97259, 'hit_clicks': 7378, 'num_carts': 36150, 'hit_carts': 3158, 'num_orders': 17756, 'hit_orders': 2269, 'recall_clicks': '0.076', 'recall_carts': '0.087', 'recall_orders': '0.128', 'w_recall_clicks': '0.008', 'w_recall_carts': '0.026', 'w_recall_orders': '0.077', 'score': '0.110'}
# 0:00:53.072821 	 [make_candidate] session_latest_clicks2carts_pair0 : start
# 0:00:53.430450 	 [add_candidate] session_latest_clicks2carts_pair0 : start
# 0:00:55.363720 	 session_latest_clicks2carts_pair0
# 0:00:55.364882 	 {'num_clicks': 97259, 'hit_clicks': 4525, 'num_carts': 36150, 'hit_carts': 2508, 'num_orders': 17756, 'hit_orders': 1589, 'recall_clicks': '0.047', 'recall_carts': '0.069', 'recall_orders': '0.089', 'w_recall_clicks': '0.005', 'w_recall_carts': '0.021', 'w_recall_orders': '0.054', 'score': '0.079'}
# 0:00:55.374874 	 [make_candidate] session_latest_clicks2orders_pair0 : start
# 0:00:55.756329 	 [add_candidate] session_latest_clicks2orders_pair0 : start
# 0:00:57.627137 	 session_latest_clicks2orders_pair0
# 0:00:57.628309 	 {'num_clicks': 97259, 'hit_clicks': 2995, 'num_carts': 36150, 'hit_carts': 1739, 'num_orders': 17756, 'hit_orders': 1663, 'recall_clicks': '0.031', 'recall_carts': '0.048', 'recall_orders': '0.094', 'w_recall_clicks': '0.003', 'w_recall_carts': '0.014', 'w_recall_orders': '0.056', 'score': '0.074'}
# 0:00:57.637861 	 [make_candidate] session_latest_time_wt_pair1 : start
# 0:00:57.955108 	 [add_candidate] session_latest_time_wt_pair1 : start
# 0:00:59.980728 	 session_latest_time_wt_pair1
# 0:00:59.981845 	 {'num_clicks': 97259, 'hit_clicks': 5930, 'num_carts': 36150, 'hit_carts': 1755, 'num_orders': 17756, 'hit_orders': 1128, 'recall_clicks': '0.061', 'recall_carts': '0.049', 'recall_orders': '0.064', 'w_recall_clicks': '0.006', 'w_recall_carts': '0.015', 'w_recall_orders': '0.038', 'score': '0.059'}
# 0:00:59.992103 	 [make_candidate] session_latest_word2vec_pair1 : start
# 0:01:00.474350 	 [add_candidate] session_latest_word2vec_pair1 : start
# 0:01:02.558179 	 session_latest_word2vec_pair1
# 0:01:02.559992 	 {'num_clicks': 97259, 'hit_clicks': 3181, 'num_carts': 36150, 'hit_carts': 1027, 'num_orders': 17756, 'hit_orders': 602, 'recall_clicks': '0.033', 'recall_carts': '0.028', 'recall_orders': '0.034', 'w_recall_clicks': '0.003', 'w_recall_carts': '0.009', 'w_recall_orders': '0.020', 'score': '0.032'}
# 0:01:02.569532 	 [make_candidate] session_latest_pair1 : start
# 0:01:02.899820 	 [add_candidate] session_latest_pair1 : start
# 0:01:04.987273 	 session_latest_pair1
# 0:01:04.988396 	 {'num_clicks': 97259, 'hit_clicks': 5048, 'num_carts': 36150, 'hit_carts': 2035, 'num_orders': 17756, 'hit_orders': 1368, 'recall_clicks': '0.052', 'recall_carts': '0.056', 'recall_orders': '0.077', 'w_recall_clicks': '0.005', 'w_recall_carts': '0.017', 'w_recall_orders': '0.046', 'score': '0.068'}
# 0:01:04.998564 	 [make_candidate] session_latest_type_wt_pair1 : start
# 0:01:05.402589 	 [add_candidate] session_latest_type_wt_pair1 : start
# 0:01:07.597245 	 session_latest_type_wt_pair1
# 0:01:07.598428 	 {'num_clicks': 97259, 'hit_clicks': 4963, 'num_carts': 36150, 'hit_carts': 2412, 'num_orders': 17756, 'hit_orders': 1646, 'recall_clicks': '0.051', 'recall_carts': '0.067', 'recall_orders': '0.093', 'w_recall_clicks': '0.005', 'w_recall_carts': '0.020', 'w_recall_orders': '0.056', 'score': '0.081'}
# 0:01:07.608794 	 [make_candidate] session_latest_clicks2carts_pair1 : start
# 0:01:07.996237 	 [add_candidate] session_latest_clicks2carts_pair1 : start
# 0:01:10.117281 	 session_latest_clicks2carts_pair1
# 0:01:10.118533 	 {'num_clicks': 97259, 'hit_clicks': 3046, 'num_carts': 36150, 'hit_carts': 1818, 'num_orders': 17756, 'hit_orders': 1095, 'recall_clicks': '0.031', 'recall_carts': '0.050', 'recall_orders': '0.062', 'w_recall_clicks': '0.003', 'w_recall_carts': '0.015', 'w_recall_orders': '0.037', 'score': '0.055'}
# 0:01:10.128603 	 [make_candidate] session_latest_clicks2orders_pair1 : start
# 0:01:10.381405 	 [add_candidate] session_latest_clicks2orders_pair1 : start
# 0:01:12.421745 	 session_latest_clicks2orders_pair1
# 0:01:12.422910 	 {'num_clicks': 97259, 'hit_clicks': 1849, 'num_carts': 36150, 'hit_carts': 1161, 'num_orders': 17756, 'hit_orders': 1131, 'recall_clicks': '0.019', 'recall_carts': '0.032', 'recall_orders': '0.064', 'w_recall_clicks': '0.002', 'w_recall_carts': '0.010', 'w_recall_orders': '0.038', 'score': '0.050'}
# 0:01:12.431763 	 [make_candidate] session_latest_time_wt_pair2 : start
# 0:01:12.964055 	 [add_candidate] session_latest_time_wt_pair2 : start
# 0:01:15.029218 	 session_latest_time_wt_pair2
# 0:01:15.030412 	 {'num_clicks': 97259, 'hit_clicks': 4804, 'num_carts': 36150, 'hit_carts': 1434, 'num_orders': 17756, 'hit_orders': 897, 'recall_clicks': '0.049', 'recall_carts': '0.040', 'recall_orders': '0.051', 'w_recall_clicks': '0.005', 'w_recall_carts': '0.012', 'w_recall_orders': '0.030', 'score': '0.047'}
# 0:01:15.040958 	 [make_candidate] session_latest_word2vec_pair2 : start
# 0:01:15.571213 	 [add_candidate] session_latest_word2vec_pair2 : start
# 0:01:17.865512 	 session_latest_word2vec_pair2
# 0:01:17.866659 	 {'num_clicks': 97259, 'hit_clicks': 2594, 'num_carts': 36150, 'hit_carts': 817, 'num_orders': 17756, 'hit_orders': 494, 'recall_clicks': '0.027', 'recall_carts': '0.023', 'recall_orders': '0.028', 'w_recall_clicks': '0.003', 'w_recall_carts': '0.007', 'w_recall_orders': '0.017', 'score': '0.026'}
# 0:01:17.877320 	 [make_candidate] session_latest_pair2 : start
# 0:01:18.413882 	 [add_candidate] session_latest_pair2 : start
# 0:01:20.730733 	 session_latest_pair2
# 0:01:20.731850 	 {'num_clicks': 97259, 'hit_clicks': 4043, 'num_carts': 36150, 'hit_carts': 1657, 'num_orders': 17756, 'hit_orders': 1167, 'recall_clicks': '0.042', 'recall_carts': '0.046', 'recall_orders': '0.066', 'w_recall_clicks': '0.004', 'w_recall_carts': '0.014', 'w_recall_orders': '0.039', 'score': '0.057'}
# 0:01:20.743620 	 [make_candidate] session_latest_type_wt_pair2 : start
# 0:01:21.284981 	 [add_candidate] session_latest_type_wt_pair2 : start
# 0:01:23.607771 	 session_latest_type_wt_pair2
# 0:01:23.608992 	 {'num_clicks': 97259, 'hit_clicks': 3890, 'num_carts': 36150, 'hit_carts': 2009, 'num_orders': 17756, 'hit_orders': 1342, 'recall_clicks': '0.040', 'recall_carts': '0.056', 'recall_orders': '0.076', 'w_recall_clicks': '0.004', 'w_recall_carts': '0.017', 'w_recall_orders': '0.045', 'score': '0.066'}
# 0:01:23.619597 	 [make_candidate] session_latest_clicks2carts_pair2 : start
# 0:01:23.929578 	 [add_candidate] session_latest_clicks2carts_pair2 : start
# 0:01:26.187254 	 session_latest_clicks2carts_pair2
# 0:01:26.188563 	 {'num_clicks': 97259, 'hit_clicks': 2293, 'num_carts': 36150, 'hit_carts': 1419, 'num_orders': 17756, 'hit_orders': 830, 'recall_clicks': '0.024', 'recall_carts': '0.039', 'recall_orders': '0.047', 'w_recall_clicks': '0.002', 'w_recall_carts': '0.012', 'w_recall_orders': '0.028', 'score': '0.042'}
# 0:01:26.199737 	 [make_candidate] session_latest_clicks2orders_pair2 : start
# 0:01:26.532669 	 [add_candidate] session_latest_clicks2orders_pair2 : start
# 0:01:28.486744 	 session_latest_clicks2orders_pair2
# 0:01:28.487898 	 {'num_clicks': 97259, 'hit_clicks': 1387, 'num_carts': 36150, 'hit_carts': 867, 'num_orders': 17756, 'hit_orders': 847, 'recall_clicks': '0.014', 'recall_carts': '0.024', 'recall_orders': '0.048', 'w_recall_clicks': '0.001', 'w_recall_carts': '0.007', 'w_recall_orders': '0.029', 'score': '0.037'}
# 0:01:28.497308 	 [make_candidate] session_latest_time_wt_pair3 : start
# 0:01:28.863263 	 [add_candidate] session_latest_time_wt_pair3 : start
# 0:01:31.180067 	 session_latest_time_wt_pair3
# 0:01:31.181575 	 {'num_clicks': 97259, 'hit_clicks': 3918, 'num_carts': 36150, 'hit_carts': 1268, 'num_orders': 17756, 'hit_orders': 802, 'recall_clicks': '0.040', 'recall_carts': '0.035', 'recall_orders': '0.045', 'w_recall_clicks': '0.004', 'w_recall_carts': '0.011', 'w_recall_orders': '0.027', 'score': '0.042'}
# 0:01:31.191817 	 [make_candidate] session_latest_word2vec_pair3 : start
# 0:01:31.667966 	 [add_candidate] session_latest_word2vec_pair3 : start
# 0:01:33.939764 	 session_latest_word2vec_pair3
# 0:01:33.940902 	 {'num_clicks': 97259, 'hit_clicks': 2204, 'num_carts': 36150, 'hit_carts': 683, 'num_orders': 17756, 'hit_orders': 406, 'recall_clicks': '0.023', 'recall_carts': '0.019', 'recall_orders': '0.023', 'w_recall_clicks': '0.002', 'w_recall_carts': '0.006', 'w_recall_orders': '0.014', 'score': '0.022'}
# 0:01:33.950993 	 [make_candidate] session_latest_pair3 : start
# 0:01:34.258788 	 [add_candidate] session_latest_pair3 : start
# 0:01:36.497186 	 session_latest_pair3
# 0:01:36.498495 	 {'num_clicks': 97259, 'hit_clicks': 3247, 'num_carts': 36150, 'hit_carts': 1475, 'num_orders': 17756, 'hit_orders': 1060, 'recall_clicks': '0.033', 'recall_carts': '0.041', 'recall_orders': '0.060', 'w_recall_clicks': '0.003', 'w_recall_carts': '0.012', 'w_recall_orders': '0.036', 'score': '0.051'}
# 0:01:36.508700 	 [make_candidate] session_latest_type_wt_pair3 : start
# 0:01:36.939647 	 [add_candidate] session_latest_type_wt_pair3 : start
# 0:01:39.222570 	 session_latest_type_wt_pair3
# 0:01:39.223714 	 {'num_clicks': 97259, 'hit_clicks': 3305, 'num_carts': 36150, 'hit_carts': 1714, 'num_orders': 17756, 'hit_orders': 1168, 'recall_clicks': '0.034', 'recall_carts': '0.047', 'recall_orders': '0.066', 'w_recall_clicks': '0.003', 'w_recall_carts': '0.014', 'w_recall_orders': '0.039', 'score': '0.057'}
# 0:01:39.233635 	 [make_candidate] session_latest_clicks2carts_pair3 : start
# 0:01:39.647994 	 [add_candidate] session_latest_clicks2carts_pair3 : start
# 0:01:41.926664 	 session_latest_clicks2carts_pair3
# 0:01:41.927838 	 {'num_clicks': 97259, 'hit_clicks': 1914, 'num_carts': 36150, 'hit_carts': 1211, 'num_orders': 17756, 'hit_orders': 678, 'recall_clicks': '0.020', 'recall_carts': '0.033', 'recall_orders': '0.038', 'w_recall_clicks': '0.002', 'w_recall_carts': '0.010', 'w_recall_orders': '0.023', 'score': '0.035'}
# 0:01:41.938324 	 [make_candidate] session_latest_clicks2orders_pair3 : start
# 0:01:42.305455 	 [add_candidate] session_latest_clicks2orders_pair3 : start
# 0:01:44.269942 	 session_latest_clicks2orders_pair3
# 0:01:44.271038 	 {'num_clicks': 97259, 'hit_clicks': 1023, 'num_carts': 36150, 'hit_carts': 688, 'num_orders': 17756, 'hit_orders': 636, 'recall_clicks': '0.011', 'recall_carts': '0.019', 'recall_orders': '0.036', 'w_recall_clicks': '0.001', 'w_recall_carts': '0.006', 'w_recall_orders': '0.021', 'score': '0.028'}
# 0:01:44.280016 	 [make_candidate] session_latest_time_wt_pair4 : start
# 0:01:44.593683 	 [add_candidate] session_latest_time_wt_pair4 : start
# 0:01:46.871381 	 session_latest_time_wt_pair4
# 0:01:46.872511 	 {'num_clicks': 97259, 'hit_clicks': 3347, 'num_carts': 36150, 'hit_carts': 1134, 'num_orders': 17756, 'hit_orders': 709, 'recall_clicks': '0.034', 'recall_carts': '0.031', 'recall_orders': '0.040', 'w_recall_clicks': '0.003', 'w_recall_carts': '0.009', 'w_recall_orders': '0.024', 'score': '0.037'}
# 0:01:46.883610 	 [make_candidate] session_latest_word2vec_pair4 : start
# 0:01:47.311083 	 [add_candidate] session_latest_word2vec_pair4 : start
# 0:01:49.709495 	 session_latest_word2vec_pair4
# 0:01:49.711002 	 {'num_clicks': 97259, 'hit_clicks': 1862, 'num_carts': 36150, 'hit_carts': 676, 'num_orders': 17756, 'hit_orders': 384, 'recall_clicks': '0.019', 'recall_carts': '0.019', 'recall_orders': '0.022', 'w_recall_clicks': '0.002', 'w_recall_carts': '0.006', 'w_recall_orders': '0.013', 'score': '0.021'}
# 0:01:49.722526 	 [make_candidate] session_latest_pair4 : start
# 0:01:50.240327 	 [add_candidate] session_latest_pair4 : start
# 0:01:52.581138 	 session_latest_pair4
# 0:01:52.582711 	 {'num_clicks': 97259, 'hit_clicks': 2890, 'num_carts': 36150, 'hit_carts': 1310, 'num_orders': 17756, 'hit_orders': 829, 'recall_clicks': '0.030', 'recall_carts': '0.036', 'recall_orders': '0.047', 'w_recall_clicks': '0.003', 'w_recall_carts': '0.011', 'w_recall_orders': '0.028', 'score': '0.042'}
# 0:01:52.593820 	 [make_candidate] session_latest_type_wt_pair4 : start
# 0:01:52.934217 	 [add_candidate] session_latest_type_wt_pair4 : start
# 0:01:55.281335 	 session_latest_type_wt_pair4
# 0:01:55.282496 	 {'num_clicks': 97259, 'hit_clicks': 2878, 'num_carts': 36150, 'hit_carts': 1459, 'num_orders': 17756, 'hit_orders': 919, 'recall_clicks': '0.030', 'recall_carts': '0.040', 'recall_orders': '0.052', 'w_recall_clicks': '0.003', 'w_recall_carts': '0.012', 'w_recall_orders': '0.031', 'score': '0.046'}
# 0:01:55.293591 	 [make_candidate] session_latest_clicks2carts_pair4 : start
# 0:01:55.728623 	 [add_candidate] session_latest_clicks2carts_pair4 : start
# 0:01:57.938046 	 session_latest_clicks2carts_pair4
# 0:01:57.939234 	 {'num_clicks': 97259, 'hit_clicks': 1653, 'num_carts': 36150, 'hit_carts': 1067, 'num_orders': 17756, 'hit_orders': 579, 'recall_clicks': '0.017', 'recall_carts': '0.030', 'recall_orders': '0.033', 'w_recall_clicks': '0.002', 'w_recall_carts': '0.009', 'w_recall_orders': '0.020', 'score': '0.030'}
# 0:01:57.949049 	 [make_candidate] session_latest_clicks2orders_pair4 : start
# 0:01:58.128006 	 [add_candidate] session_latest_clicks2orders_pair4 : start
# 0:02:00.134659 	 session_latest_clicks2orders_pair4
# 0:02:00.135815 	 {'num_clicks': 97259, 'hit_clicks': 874, 'num_carts': 36150, 'hit_carts': 545, 'num_orders': 17756, 'hit_orders': 548, 'recall_clicks': '0.009', 'recall_carts': '0.015', 'recall_orders': '0.031', 'w_recall_clicks': '0.001', 'w_recall_carts': '0.005', 'w_recall_orders': '0.019', 'score': '0.024'}
# 0:02:00.144305 	 [make_candidate] session_latest_time_wt_pair5 : start
# 0:02:00.567452 	 [add_candidate] session_latest_time_wt_pair5 : start
# 0:02:02.913490 	 session_latest_time_wt_pair5
# 0:02:02.914639 	 {'num_clicks': 97259, 'hit_clicks': 2996, 'num_carts': 36150, 'hit_carts': 974, 'num_orders': 17756, 'hit_orders': 595, 'recall_clicks': '0.031', 'recall_carts': '0.027', 'recall_orders': '0.034', 'w_recall_clicks': '0.003', 'w_recall_carts': '0.008', 'w_recall_orders': '0.020', 'score': '0.031'}
# 0:02:02.924550 	 [make_candidate] session_latest_word2vec_pair5 : start
# 0:02:03.433023 	 [add_candidate] session_latest_word2vec_pair5 : start
# 0:02:05.838969 	 session_latest_word2vec_pair5
# 0:02:05.840229 	 {'num_clicks': 97259, 'hit_clicks': 1753, 'num_carts': 36150, 'hit_carts': 565, 'num_orders': 17756, 'hit_orders': 335, 'recall_clicks': '0.018', 'recall_carts': '0.016', 'recall_orders': '0.019', 'w_recall_clicks': '0.002', 'w_recall_carts': '0.005', 'w_recall_orders': '0.011', 'score': '0.018'}
# 0:02:05.851295 	 [make_candidate] session_latest_pair5 : start
# 0:02:06.199966 	 [add_candidate] session_latest_pair5 : start
# 0:02:08.667166 	 session_latest_pair5
# 0:02:08.668381 	 {'num_clicks': 97259, 'hit_clicks': 2607, 'num_carts': 36150, 'hit_carts': 1198, 'num_orders': 17756, 'hit_orders': 750, 'recall_clicks': '0.027', 'recall_carts': '0.033', 'recall_orders': '0.042', 'w_recall_clicks': '0.003', 'w_recall_carts': '0.010', 'w_recall_orders': '0.025', 'score': '0.038'}
# 0:02:08.679373 	 [make_candidate] session_latest_type_wt_pair5 : start
# 0:02:09.237389 	 [add_candidate] session_latest_type_wt_pair5 : start
# 0:02:11.627992 	 session_latest_type_wt_pair5
# 0:02:11.629285 	 {'num_clicks': 97259, 'hit_clicks': 2524, 'num_carts': 36150, 'hit_carts': 1417, 'num_orders': 17756, 'hit_orders': 903, 'recall_clicks': '0.026', 'recall_carts': '0.039', 'recall_orders': '0.051', 'w_recall_clicks': '0.003', 'w_recall_carts': '0.012', 'w_recall_orders': '0.031', 'score': '0.045'}
# 0:02:11.639632 	 [make_candidate] session_latest_clicks2carts_pair5 : start
# 0:02:11.909097 	 [add_candidate] session_latest_clicks2carts_pair5 : start
# 0:02:14.174268 	 session_latest_clicks2carts_pair5
# 0:02:14.175361 	 {'num_clicks': 97259, 'hit_clicks': 1468, 'num_carts': 36150, 'hit_carts': 943, 'num_orders': 17756, 'hit_orders': 520, 'recall_clicks': '0.015', 'recall_carts': '0.026', 'recall_orders': '0.029', 'w_recall_clicks': '0.002', 'w_recall_carts': '0.008', 'w_recall_orders': '0.018', 'score': '0.027'}
# 0:02:14.185571 	 [make_candidate] session_latest_clicks2orders_pair5 : start
# 0:02:14.505878 	 [add_candidate] session_latest_clicks2orders_pair5 : start
# 0:02:16.656569 	 session_latest_clicks2orders_pair5
# 0:02:16.657665 	 {'num_clicks': 97259, 'hit_clicks': 721, 'num_carts': 36150, 'hit_carts': 450, 'num_orders': 17756, 'hit_orders': 460, 'recall_clicks': '0.007', 'recall_carts': '0.012', 'recall_orders': '0.026', 'w_recall_clicks': '0.001', 'w_recall_carts': '0.004', 'w_recall_orders': '0.016', 'score': '0.020'}
# 0:02:16.667238 	 [make_candidate] session_latest_time_wt_pair6 : start
# 0:02:17.040861 	 [add_candidate] session_latest_time_wt_pair6 : start
# 0:02:19.473228 	 session_latest_time_wt_pair6
# 0:02:19.474553 	 {'num_clicks': 97259, 'hit_clicks': 2768, 'num_carts': 36150, 'hit_carts': 938, 'num_orders': 17756, 'hit_orders': 563, 'recall_clicks': '0.028', 'recall_carts': '0.026', 'recall_orders': '0.032', 'w_recall_clicks': '0.003', 'w_recall_carts': '0.008', 'w_recall_orders': '0.019', 'score': '0.030'}
# 0:02:19.485032 	 [make_candidate] session_latest_word2vec_pair6 : start
# 0:02:20.022230 	 [add_candidate] session_latest_word2vec_pair6 : start
# 0:02:22.360109 	 session_latest_word2vec_pair6
# 0:02:22.361177 	 {'num_clicks': 97259, 'hit_clicks': 1424, 'num_carts': 36150, 'hit_carts': 521, 'num_orders': 17756, 'hit_orders': 261, 'recall_clicks': '0.015', 'recall_carts': '0.014', 'recall_orders': '0.015', 'w_recall_clicks': '0.001', 'w_recall_carts': '0.004', 'w_recall_orders': '0.009', 'score': '0.015'}
# 0:02:22.372129 	 [make_candidate] session_latest_pair6 : start
# 0:02:22.788666 	 [add_candidate] session_latest_pair6 : start
# 0:02:25.225134 	 session_latest_pair6
# 0:02:25.226290 	 {'num_clicks': 97259, 'hit_clicks': 2276, 'num_carts': 36150, 'hit_carts': 1005, 'num_orders': 17756, 'hit_orders': 683, 'recall_clicks': '0.023', 'recall_carts': '0.028', 'recall_orders': '0.038', 'w_recall_clicks': '0.002', 'w_recall_carts': '0.008', 'w_recall_orders': '0.023', 'score': '0.034'}
# 0:02:25.237343 	 [make_candidate] session_latest_type_wt_pair6 : start
# 0:02:25.798294 	 [add_candidate] session_latest_type_wt_pair6 : start
# 0:02:28.259016 	 session_latest_type_wt_pair6
# 0:02:28.260268 	 {'num_clicks': 97259, 'hit_clicks': 2351, 'num_carts': 36150, 'hit_carts': 1311, 'num_orders': 17756, 'hit_orders': 813, 'recall_clicks': '0.024', 'recall_carts': '0.036', 'recall_orders': '0.046', 'w_recall_clicks': '0.002', 'w_recall_carts': '0.011', 'w_recall_orders': '0.027', 'score': '0.041'}
# 0:02:28.271269 	 [make_candidate] session_latest_clicks2carts_pair6 : start
# 0:02:28.545341 	 [add_candidate] session_latest_clicks2carts_pair6 : start
# 0:02:30.973350 	 session_latest_clicks2carts_pair6
# 0:02:30.974514 	 {'num_clicks': 97259, 'hit_clicks': 1240, 'num_carts': 36150, 'hit_carts': 776, 'num_orders': 17756, 'hit_orders': 400, 'recall_clicks': '0.013', 'recall_carts': '0.021', 'recall_orders': '0.023', 'w_recall_clicks': '0.001', 'w_recall_carts': '0.006', 'w_recall_orders': '0.014', 'score': '0.021'}
# 0:02:30.984562 	 [make_candidate] session_latest_clicks2orders_pair6 : start
# 0:02:31.297919 	 [add_candidate] session_latest_clicks2orders_pair6 : start
# 0:02:33.553245 	 session_latest_clicks2orders_pair6
# 0:02:33.554374 	 {'num_clicks': 97259, 'hit_clicks': 733, 'num_carts': 36150, 'hit_carts': 424, 'num_orders': 17756, 'hit_orders': 400, 'recall_clicks': '0.008', 'recall_carts': '0.012', 'recall_orders': '0.023', 'w_recall_clicks': '0.001', 'w_recall_carts': '0.004', 'w_recall_orders': '0.014', 'score': '0.018'}
# 0:02:33.562667 	 [make_candidate] session_latest_time_wt_pair7 : start
# 0:02:33.927480 	 [add_candidate] session_latest_time_wt_pair7 : start
# 0:02:36.326214 	 session_latest_time_wt_pair7
# 0:02:36.327497 	 {'num_clicks': 97259, 'hit_clicks': 2615, 'num_carts': 36150, 'hit_carts': 802, 'num_orders': 17756, 'hit_orders': 497, 'recall_clicks': '0.027', 'recall_carts': '0.022', 'recall_orders': '0.028', 'w_recall_clicks': '0.003', 'w_recall_carts': '0.007', 'w_recall_orders': '0.017', 'score': '0.026'}
# 0:02:36.338744 	 [make_candidate] session_latest_word2vec_pair7 : start
# 0:02:36.841483 	 [add_candidate] session_latest_word2vec_pair7 : start
# 0:02:39.379081 	 session_latest_word2vec_pair7
# 0:02:39.380563 	 {'num_clicks': 97259, 'hit_clicks': 1414, 'num_carts': 36150, 'hit_carts': 469, 'num_orders': 17756, 'hit_orders': 255, 'recall_clicks': '0.015', 'recall_carts': '0.013', 'recall_orders': '0.014', 'w_recall_clicks': '0.001', 'w_recall_carts': '0.004', 'w_recall_orders': '0.009', 'score': '0.014'}
# 0:02:39.390840 	 [make_candidate] session_latest_pair7 : start
# 0:02:39.819261 	 [add_candidate] session_latest_pair7 : start
# 0:02:42.439729 	 session_latest_pair7
# 0:02:42.440802 	 {'num_clicks': 97259, 'hit_clicks': 2108, 'num_carts': 36150, 'hit_carts': 1040, 'num_orders': 17756, 'hit_orders': 623, 'recall_clicks': '0.022', 'recall_carts': '0.029', 'recall_orders': '0.035', 'w_recall_clicks': '0.002', 'w_recall_carts': '0.009', 'w_recall_orders': '0.021', 'score': '0.032'}
# 0:02:42.451583 	 [make_candidate] session_latest_type_wt_pair7 : start
# 0:02:43.010976 	 [add_candidate] session_latest_type_wt_pair7 : start
# 0:02:45.574615 	 session_latest_type_wt_pair7
# 0:02:45.575851 	 {'num_clicks': 97259, 'hit_clicks': 2075, 'num_carts': 36150, 'hit_carts': 1187, 'num_orders': 17756, 'hit_orders': 700, 'recall_clicks': '0.021', 'recall_carts': '0.033', 'recall_orders': '0.039', 'w_recall_clicks': '0.002', 'w_recall_carts': '0.010', 'w_recall_orders': '0.024', 'score': '0.036'}
# 0:02:45.586807 	 [make_candidate] session_latest_clicks2carts_pair7 : start
# 0:02:45.940623 	 [add_candidate] session_latest_clicks2carts_pair7 : start
# 0:02:48.676081 	 session_latest_clicks2carts_pair7
# 0:02:48.677245 	 {'num_clicks': 97259, 'hit_clicks': 1130, 'num_carts': 36150, 'hit_carts': 725, 'num_orders': 17756, 'hit_orders': 407, 'recall_clicks': '0.012', 'recall_carts': '0.020', 'recall_orders': '0.023', 'w_recall_clicks': '0.001', 'w_recall_carts': '0.006', 'w_recall_orders': '0.014', 'score': '0.021'}
# 0:02:48.687449 	 [make_candidate] session_latest_clicks2orders_pair7 : start
# 0:02:48.896955 	 [add_candidate] session_latest_clicks2orders_pair7 : start
# 0:02:51.349647 	 session_latest_clicks2orders_pair7
# 0:02:51.350817 	 {'num_clicks': 97259, 'hit_clicks': 526, 'num_carts': 36150, 'hit_carts': 332, 'num_orders': 17756, 'hit_orders': 320, 'recall_clicks': '0.005', 'recall_carts': '0.009', 'recall_orders': '0.018', 'w_recall_clicks': '0.001', 'w_recall_carts': '0.003', 'w_recall_orders': '0.011', 'score': '0.014'}
# 0:02:51.360313 	 [make_candidate] session_latest_time_wt_pair8 : start
# 0:02:51.856211 	 [add_candidate] session_latest_time_wt_pair8 : start
# 0:02:54.694754 	 session_latest_time_wt_pair8
# 0:02:54.695966 	 {'num_clicks': 97259, 'hit_clicks': 2289, 'num_carts': 36150, 'hit_carts': 762, 'num_orders': 17756, 'hit_orders': 479, 'recall_clicks': '0.024', 'recall_carts': '0.021', 'recall_orders': '0.027', 'w_recall_clicks': '0.002', 'w_recall_carts': '0.006', 'w_recall_orders': '0.016', 'score': '0.025'}
# 0:02:54.707583 	 [make_candidate] session_latest_word2vec_pair8 : start
# 0:02:55.097442 	 [add_candidate] session_latest_word2vec_pair8 : start
# 0:02:58.068075 	 session_latest_word2vec_pair8
# 0:02:58.069324 	 {'num_clicks': 97259, 'hit_clicks': 1274, 'num_carts': 36150, 'hit_carts': 429, 'num_orders': 17756, 'hit_orders': 235, 'recall_clicks': '0.013', 'recall_carts': '0.012', 'recall_orders': '0.013', 'w_recall_clicks': '0.001', 'w_recall_carts': '0.004', 'w_recall_orders': '0.008', 'score': '0.013'}
# 0:02:58.080518 	 [make_candidate] session_latest_pair8 : start
# 0:02:58.657244 	 [add_candidate] session_latest_pair8 : start
# 0:03:01.596768 	 session_latest_pair8
# 0:03:01.597915 	 {'num_clicks': 97259, 'hit_clicks': 1829, 'num_carts': 36150, 'hit_carts': 1008, 'num_orders': 17756, 'hit_orders': 618, 'recall_clicks': '0.019', 'recall_carts': '0.028', 'recall_orders': '0.035', 'w_recall_clicks': '0.002', 'w_recall_carts': '0.008', 'w_recall_orders': '0.021', 'score': '0.031'}
# 0:03:01.609614 	 [make_candidate] session_latest_type_wt_pair8 : start
# 0:03:01.981015 	 [add_candidate] session_latest_type_wt_pair8 : start
# 0:03:04.896191 	 session_latest_type_wt_pair8
# 0:03:04.897313 	 {'num_clicks': 97259, 'hit_clicks': 1887, 'num_carts': 36150, 'hit_carts': 1119, 'num_orders': 17756, 'hit_orders': 661, 'recall_clicks': '0.019', 'recall_carts': '0.031', 'recall_orders': '0.037', 'w_recall_clicks': '0.002', 'w_recall_carts': '0.009', 'w_recall_orders': '0.022', 'score': '0.034'}
# 0:03:04.908346 	 [make_candidate] session_latest_clicks2carts_pair8 : start
# 0:03:05.295360 	 [add_candidate] session_latest_clicks2carts_pair8 : start
# 0:03:07.945297 	 session_latest_clicks2carts_pair8
# 0:03:07.946653 	 {'num_clicks': 97259, 'hit_clicks': 1048, 'num_carts': 36150, 'hit_carts': 685, 'num_orders': 17756, 'hit_orders': 359, 'recall_clicks': '0.011', 'recall_carts': '0.019', 'recall_orders': '0.020', 'w_recall_clicks': '0.001', 'w_recall_carts': '0.006', 'w_recall_orders': '0.012', 'score': '0.019'}
# 0:03:07.956277 	 [make_candidate] session_latest_clicks2orders_pair8 : start
# 0:03:08.173016 	 [add_candidate] session_latest_clicks2orders_pair8 : start
# 0:03:10.779089 	 session_latest_clicks2orders_pair8
# 0:03:10.780490 	 {'num_clicks': 97259, 'hit_clicks': 527, 'num_carts': 36150, 'hit_carts': 312, 'num_orders': 17756, 'hit_orders': 295, 'recall_clicks': '0.005', 'recall_carts': '0.009', 'recall_orders': '0.017', 'w_recall_clicks': '0.001', 'w_recall_carts': '0.003', 'w_recall_orders': '0.010', 'score': '0.013'}
# 0:03:10.790097 	 [make_candidate] session_latest_time_wt_pair9 : start
# 0:03:11.237530 	 [add_candidate] session_latest_time_wt_pair9 : start
# 0:03:14.168337 	 session_latest_time_wt_pair9
# 0:03:14.169747 	 {'num_clicks': 97259, 'hit_clicks': 2145, 'num_carts': 36150, 'hit_carts': 766, 'num_orders': 17756, 'hit_orders': 447, 'recall_clicks': '0.022', 'recall_carts': '0.021', 'recall_orders': '0.025', 'w_recall_clicks': '0.002', 'w_recall_carts': '0.006', 'w_recall_orders': '0.015', 'score': '0.024'}
# 0:03:14.180075 	 [make_candidate] session_latest_word2vec_pair9 : start
# 0:03:14.529548 	 [add_candidate] session_latest_word2vec_pair9 : start
# 0:03:17.499412 	 session_latest_word2vec_pair9
# 0:03:17.500548 	 {'num_clicks': 97259, 'hit_clicks': 1226, 'num_carts': 36150, 'hit_carts': 386, 'num_orders': 17756, 'hit_orders': 228, 'recall_clicks': '0.013', 'recall_carts': '0.011', 'recall_orders': '0.013', 'w_recall_clicks': '0.001', 'w_recall_carts': '0.003', 'w_recall_orders': '0.008', 'score': '0.012'}
# 0:03:17.511033 	 [make_candidate] session_latest_pair9 : start
# 0:03:18.069683 	 [add_candidate] session_latest_pair9 : start
# 0:03:20.886043 	 session_latest_pair9
# 0:03:20.887244 	 {'num_clicks': 97259, 'hit_clicks': 1789, 'num_carts': 36150, 'hit_carts': 898, 'num_orders': 17756, 'hit_orders': 538, 'recall_clicks': '0.018', 'recall_carts': '0.025', 'recall_orders': '0.030', 'w_recall_clicks': '0.002', 'w_recall_carts': '0.007', 'w_recall_orders': '0.018', 'score': '0.027'}
# 0:03:20.898125 	 [make_candidate] session_latest_type_wt_pair9 : start
# 0:03:21.299767 	 [add_candidate] session_latest_type_wt_pair9 : start
# 0:03:24.322514 	 session_latest_type_wt_pair9
# 0:03:24.323866 	 {'num_clicks': 97259, 'hit_clicks': 1802, 'num_carts': 36150, 'hit_carts': 1042, 'num_orders': 17756, 'hit_orders': 662, 'recall_clicks': '0.019', 'recall_carts': '0.029', 'recall_orders': '0.037', 'w_recall_clicks': '0.002', 'w_recall_carts': '0.009', 'w_recall_orders': '0.022', 'score': '0.033'}
# 0:03:24.334556 	 [make_candidate] session_latest_clicks2carts_pair9 : start
# 0:03:24.703048 	 [add_candidate] session_latest_clicks2carts_pair9 : start
# 0:03:27.489997 	 session_latest_clicks2carts_pair9
# 0:03:27.491183 	 {'num_clicks': 97259, 'hit_clicks': 935, 'num_carts': 36150, 'hit_carts': 573, 'num_orders': 17756, 'hit_orders': 310, 'recall_clicks': '0.010', 'recall_carts': '0.016', 'recall_orders': '0.017', 'w_recall_clicks': '0.001', 'w_recall_carts': '0.005', 'w_recall_orders': '0.010', 'score': '0.016'}
# 0:03:27.501758 	 [make_candidate] session_latest_clicks2orders_pair9 : start
# 0:03:27.739959 	 [add_candidate] session_latest_clicks2orders_pair9 : start
# 0:03:30.389834 	 session_latest_clicks2orders_pair9
# 0:03:30.391030 	 {'num_clicks': 97259, 'hit_clicks': 487, 'num_carts': 36150, 'hit_carts': 267, 'num_orders': 17756, 'hit_orders': 265, 'recall_clicks': '0.005', 'recall_carts': '0.007', 'recall_orders': '0.015', 'w_recall_clicks': '0.001', 'w_recall_carts': '0.002', 'w_recall_orders': '0.009', 'score': '0.012'}
# 0:03:30.400090 	 [make_candidate] session_latest_time_wt_pair10 : start
# 0:03:30.968170 	 [add_candidate] session_latest_time_wt_pair10 : start
# 0:03:33.832412 	 session_latest_time_wt_pair10
# 0:03:33.833609 	 {'num_clicks': 97259, 'hit_clicks': 2023, 'num_carts': 36150, 'hit_carts': 674, 'num_orders': 17756, 'hit_orders': 412, 'recall_clicks': '0.021', 'recall_carts': '0.019', 'recall_orders': '0.023', 'w_recall_clicks': '0.002', 'w_recall_carts': '0.006', 'w_recall_orders': '0.014', 'score': '0.022'}
# 0:03:33.844783 	 [make_candidate] session_latest_word2vec_pair10 : start
# 0:03:34.370060 	 [add_candidate] session_latest_word2vec_pair10 : start
# 0:03:37.364168 	 session_latest_word2vec_pair10
# 0:03:37.365380 	 {'num_clicks': 97259, 'hit_clicks': 1097, 'num_carts': 36150, 'hit_carts': 393, 'num_orders': 17756, 'hit_orders': 202, 'recall_clicks': '0.011', 'recall_carts': '0.011', 'recall_orders': '0.011', 'w_recall_clicks': '0.001', 'w_recall_carts': '0.003', 'w_recall_orders': '0.007', 'score': '0.011'}
# 0:03:37.376933 	 [make_candidate] session_latest_pair10 : start
# 0:03:37.870595 	 [add_candidate] session_latest_pair10 : start
# 0:03:40.828235 	 session_latest_pair10
# 0:03:40.829596 	 {'num_clicks': 97259, 'hit_clicks': 1582, 'num_carts': 36150, 'hit_carts': 832, 'num_orders': 17756, 'hit_orders': 474, 'recall_clicks': '0.016', 'recall_carts': '0.023', 'recall_orders': '0.027', 'w_recall_clicks': '0.002', 'w_recall_carts': '0.007', 'w_recall_orders': '0.016', 'score': '0.025'}
# 0:03:40.839968 	 [make_candidate] session_latest_type_wt_pair10 : start
# 0:03:41.227378 	 [add_candidate] session_latest_type_wt_pair10 : start
# 0:03:44.207308 	 session_latest_type_wt_pair10
# 0:03:44.208488 	 {'num_clicks': 97259, 'hit_clicks': 1570, 'num_carts': 36150, 'hit_carts': 975, 'num_orders': 17756, 'hit_orders': 579, 'recall_clicks': '0.016', 'recall_carts': '0.027', 'recall_orders': '0.033', 'w_recall_clicks': '0.002', 'w_recall_carts': '0.008', 'w_recall_orders': '0.020', 'score': '0.029'}
# 0:03:44.219176 	 [make_candidate] session_latest_clicks2carts_pair10 : start
# 0:03:44.627650 	 [add_candidate] session_latest_clicks2carts_pair10 : start
# 0:03:47.509153 	 session_latest_clicks2carts_pair10
# 0:03:47.510514 	 {'num_clicks': 97259, 'hit_clicks': 838, 'num_carts': 36150, 'hit_carts': 560, 'num_orders': 17756, 'hit_orders': 280, 'recall_clicks': '0.009', 'recall_carts': '0.015', 'recall_orders': '0.016', 'w_recall_clicks': '0.001', 'w_recall_carts': '0.005', 'w_recall_orders': '0.009', 'score': '0.015'}
# 0:03:47.520327 	 [make_candidate] session_latest_clicks2orders_pair10 : start
# 0:03:47.716219 	 [add_candidate] session_latest_clicks2orders_pair10 : start
# 0:03:50.241260 	 session_latest_clicks2orders_pair10
# 0:03:50.242434 	 {'num_clicks': 97259, 'hit_clicks': 420, 'num_carts': 36150, 'hit_carts': 251, 'num_orders': 17756, 'hit_orders': 253, 'recall_clicks': '0.004', 'recall_carts': '0.007', 'recall_orders': '0.014', 'w_recall_clicks': '0.000', 'w_recall_carts': '0.002', 'w_recall_orders': '0.009', 'score': '0.011'}
# 0:03:50.251206 	 [make_candidate] session_latest_time_wt_pair11 : start
# 0:03:50.776536 	 [add_candidate] session_latest_time_wt_pair11 : start
# 0:03:53.871460 	 session_latest_time_wt_pair11
# 0:03:53.872683 	 {'num_clicks': 97259, 'hit_clicks': 1804, 'num_carts': 36150, 'hit_carts': 715, 'num_orders': 17756, 'hit_orders': 368, 'recall_clicks': '0.019', 'recall_carts': '0.020', 'recall_orders': '0.021', 'w_recall_clicks': '0.002', 'w_recall_carts': '0.006', 'w_recall_orders': '0.012', 'score': '0.020'}
# 0:03:53.883722 	 [make_candidate] session_latest_word2vec_pair11 : start
# 0:03:54.270794 	 [add_candidate] session_latest_word2vec_pair11 : start
# 0:03:57.343674 	 session_latest_word2vec_pair11
# 0:03:57.344835 	 {'num_clicks': 97259, 'hit_clicks': 1025, 'num_carts': 36150, 'hit_carts': 354, 'num_orders': 17756, 'hit_orders': 209, 'recall_clicks': '0.011', 'recall_carts': '0.010', 'recall_orders': '0.012', 'w_recall_clicks': '0.001', 'w_recall_carts': '0.003', 'w_recall_orders': '0.007', 'score': '0.011'}
# 0:03:57.355856 	 [make_candidate] session_latest_pair11 : start
# 0:03:57.700967 	 [add_candidate] session_latest_pair11 : start
# 0:04:00.832460 	 session_latest_pair11
# 0:04:00.833585 	 {'num_clicks': 97259, 'hit_clicks': 1531, 'num_carts': 36150, 'hit_carts': 790, 'num_orders': 17756, 'hit_orders': 504, 'recall_clicks': '0.016', 'recall_carts': '0.022', 'recall_orders': '0.028', 'w_recall_clicks': '0.002', 'w_recall_carts': '0.007', 'w_recall_orders': '0.017', 'score': '0.025'}
# 0:04:00.844955 	 [make_candidate] session_latest_type_wt_pair11 : start
# 0:04:01.387524 	 [add_candidate] session_latest_type_wt_pair11 : start
# 0:04:04.281055 	 session_latest_type_wt_pair11
# 0:04:04.282513 	 {'num_clicks': 97259, 'hit_clicks': 1523, 'num_carts': 36150, 'hit_carts': 964, 'num_orders': 17756, 'hit_orders': 575, 'recall_clicks': '0.016', 'recall_carts': '0.027', 'recall_orders': '0.032', 'w_recall_clicks': '0.002', 'w_recall_carts': '0.008', 'w_recall_orders': '0.019', 'score': '0.029'}
# 0:04:04.293872 	 [make_candidate] session_latest_clicks2carts_pair11 : start
# 0:04:04.552732 	 [add_candidate] session_latest_clicks2carts_pair11 : start
# 0:04:07.481179 	 session_latest_clicks2carts_pair11
# 0:04:07.482370 	 {'num_clicks': 97259, 'hit_clicks': 764, 'num_carts': 36150, 'hit_carts': 535, 'num_orders': 17756, 'hit_orders': 249, 'recall_clicks': '0.008', 'recall_carts': '0.015', 'recall_orders': '0.014', 'w_recall_clicks': '0.001', 'w_recall_carts': '0.004', 'w_recall_orders': '0.008', 'score': '0.014'}
# 0:04:07.492467 	 [make_candidate] session_latest_clicks2orders_pair11 : start
# 0:04:07.842473 	 [add_candidate] session_latest_clicks2orders_pair11 : start
# 0:04:10.548249 	 session_latest_clicks2orders_pair11
# 0:04:10.549569 	 {'num_clicks': 97259, 'hit_clicks': 391, 'num_carts': 36150, 'hit_carts': 233, 'num_orders': 17756, 'hit_orders': 210, 'recall_clicks': '0.004', 'recall_carts': '0.006', 'recall_orders': '0.012', 'w_recall_clicks': '0.000', 'w_recall_carts': '0.002', 'w_recall_orders': '0.007', 'score': '0.009'}
# 0:04:10.558102 	 [make_candidate] session_latest_time_wt_pair12 : start
# 0:04:10.972371 	 [add_candidate] session_latest_time_wt_pair12 : start
# 0:04:13.976954 	 session_latest_time_wt_pair12
# 0:04:13.978086 	 {'num_clicks': 97259, 'hit_clicks': 1689, 'num_carts': 36150, 'hit_carts': 616, 'num_orders': 17756, 'hit_orders': 339, 'recall_clicks': '0.017', 'recall_carts': '0.017', 'recall_orders': '0.019', 'w_recall_clicks': '0.002', 'w_recall_carts': '0.005', 'w_recall_orders': '0.011', 'score': '0.018'}
# 0:04:13.988296 	 [make_candidate] session_latest_word2vec_pair12 : start
# 0:04:14.538673 	 [add_candidate] session_latest_word2vec_pair12 : start
# 0:04:17.609316 	 session_latest_word2vec_pair12
# 0:04:17.610670 	 {'num_clicks': 97259, 'hit_clicks': 1080, 'num_carts': 36150, 'hit_carts': 352, 'num_orders': 17756, 'hit_orders': 240, 'recall_clicks': '0.011', 'recall_carts': '0.010', 'recall_orders': '0.014', 'w_recall_clicks': '0.001', 'w_recall_carts': '0.003', 'w_recall_orders': '0.008', 'score': '0.012'}
# 0:04:17.622669 	 [make_candidate] session_latest_pair12 : start
# 0:04:18.190989 	 [add_candidate] session_latest_pair12 : start
# 0:04:21.287716 	 session_latest_pair12
# 0:04:21.288918 	 {'num_clicks': 97259, 'hit_clicks': 1371, 'num_carts': 36150, 'hit_carts': 744, 'num_orders': 17756, 'hit_orders': 450, 'recall_clicks': '0.014', 'recall_carts': '0.021', 'recall_orders': '0.025', 'w_recall_clicks': '0.001', 'w_recall_carts': '0.006', 'w_recall_orders': '0.015', 'score': '0.023'}
# 0:04:21.299899 	 [make_candidate] session_latest_type_wt_pair12 : start
# 0:04:21.802994 	 [add_candidate] session_latest_type_wt_pair12 : start
# 0:04:24.891330 	 session_latest_type_wt_pair12
# 0:04:24.892629 	 {'num_clicks': 97259, 'hit_clicks': 1469, 'num_carts': 36150, 'hit_carts': 868, 'num_orders': 17756, 'hit_orders': 534, 'recall_clicks': '0.015', 'recall_carts': '0.024', 'recall_orders': '0.030', 'w_recall_clicks': '0.002', 'w_recall_carts': '0.007', 'w_recall_orders': '0.018', 'score': '0.027'}
# 0:04:24.903995 	 [make_candidate] session_latest_clicks2carts_pair12 : start
# 0:04:25.168867 	 [add_candidate] session_latest_clicks2carts_pair12 : start
# 0:04:28.136635 	 session_latest_clicks2carts_pair12
# 0:04:28.137892 	 {'num_clicks': 97259, 'hit_clicks': 740, 'num_carts': 36150, 'hit_carts': 505, 'num_orders': 17756, 'hit_orders': 274, 'recall_clicks': '0.008', 'recall_carts': '0.014', 'recall_orders': '0.015', 'w_recall_clicks': '0.001', 'w_recall_carts': '0.004', 'w_recall_orders': '0.009', 'score': '0.014'}
# 0:04:28.148094 	 [make_candidate] session_latest_clicks2orders_pair12 : start
# 0:04:28.461916 	 [add_candidate] session_latest_clicks2orders_pair12 : start
# 0:04:31.195790 	 session_latest_clicks2orders_pair12
# 0:04:31.196966 	 {'num_clicks': 97259, 'hit_clicks': 328, 'num_carts': 36150, 'hit_carts': 228, 'num_orders': 17756, 'hit_orders': 207, 'recall_clicks': '0.003', 'recall_carts': '0.006', 'recall_orders': '0.012', 'w_recall_clicks': '0.000', 'w_recall_carts': '0.002', 'w_recall_orders': '0.007', 'score': '0.009'}
# 0:04:31.206003 	 [make_candidate] session_latest_time_wt_pair13 : start
# 0:04:31.545486 	 [add_candidate] session_latest_time_wt_pair13 : start
# 0:04:34.611681 	 session_latest_time_wt_pair13
# 0:04:34.612915 	 {'num_clicks': 97259, 'hit_clicks': 1634, 'num_carts': 36150, 'hit_carts': 609, 'num_orders': 17756, 'hit_orders': 337, 'recall_clicks': '0.017', 'recall_carts': '0.017', 'recall_orders': '0.019', 'w_recall_clicks': '0.002', 'w_recall_carts': '0.005', 'w_recall_orders': '0.011', 'score': '0.018'}
# 0:04:34.624280 	 [make_candidate] session_latest_word2vec_pair13 : start
# 0:04:35.180094 	 [add_candidate] session_latest_word2vec_pair13 : start
# 0:04:38.272488 	 session_latest_word2vec_pair13
# 0:04:38.273983 	 {'num_clicks': 97259, 'hit_clicks': 913, 'num_carts': 36150, 'hit_carts': 320, 'num_orders': 17756, 'hit_orders': 178, 'recall_clicks': '0.009', 'recall_carts': '0.009', 'recall_orders': '0.010', 'w_recall_clicks': '0.001', 'w_recall_carts': '0.003', 'w_recall_orders': '0.006', 'score': '0.010'}
# 0:04:38.284596 	 [make_candidate] session_latest_pair13 : start
# 0:04:38.689768 	 [add_candidate] session_latest_pair13 : start
# 0:04:41.836515 	 session_latest_pair13
# 0:04:41.837591 	 {'num_clicks': 97259, 'hit_clicks': 1354, 'num_carts': 36150, 'hit_carts': 684, 'num_orders': 17756, 'hit_orders': 418, 'recall_clicks': '0.014', 'recall_carts': '0.019', 'recall_orders': '0.024', 'w_recall_clicks': '0.001', 'w_recall_carts': '0.006', 'w_recall_orders': '0.014', 'score': '0.021'}
# 0:04:41.848517 	 [make_candidate] session_latest_type_wt_pair13 : start
# 0:04:42.149704 	 [add_candidate] session_latest_type_wt_pair13 : start
# 0:04:45.324378 	 session_latest_type_wt_pair13
# 0:04:45.325603 	 {'num_clicks': 97259, 'hit_clicks': 1339, 'num_carts': 36150, 'hit_carts': 826, 'num_orders': 17756, 'hit_orders': 454, 'recall_clicks': '0.014', 'recall_carts': '0.023', 'recall_orders': '0.026', 'w_recall_clicks': '0.001', 'w_recall_carts': '0.007', 'w_recall_orders': '0.015', 'score': '0.024'}
# 0:04:45.336556 	 [make_candidate] session_latest_clicks2carts_pair13 : start
# 0:04:45.589817 	 [add_candidate] session_latest_clicks2carts_pair13 : start
# 0:04:48.558676 	 session_latest_clicks2carts_pair13
# 0:04:48.559895 	 {'num_clicks': 97259, 'hit_clicks': 692, 'num_carts': 36150, 'hit_carts': 438, 'num_orders': 17756, 'hit_orders': 242, 'recall_clicks': '0.007', 'recall_carts': '0.012', 'recall_orders': '0.014', 'w_recall_clicks': '0.001', 'w_recall_carts': '0.004', 'w_recall_orders': '0.008', 'score': '0.013'}
# 0:04:48.570288 	 [make_candidate] session_latest_clicks2orders_pair13 : start
# 0:04:48.984839 	 [add_candidate] session_latest_clicks2orders_pair13 : start
# 0:04:51.759212 	 session_latest_clicks2orders_pair13
# 0:04:51.760509 	 {'num_clicks': 97259, 'hit_clicks': 322, 'num_carts': 36150, 'hit_carts': 166, 'num_orders': 17756, 'hit_orders': 167, 'recall_clicks': '0.003', 'recall_carts': '0.005', 'recall_orders': '0.009', 'w_recall_clicks': '0.000', 'w_recall_carts': '0.001', 'w_recall_orders': '0.006', 'score': '0.007'}
# 0:04:51.768449 	 [make_candidate] session_latest_time_wt_pair14 : start
# 0:04:52.110506 	 [add_candidate] session_latest_time_wt_pair14 : start
# 0:04:55.199586 	 session_latest_time_wt_pair14
# 0:04:55.200646 	 {'num_clicks': 97259, 'hit_clicks': 1609, 'num_carts': 36150, 'hit_carts': 597, 'num_orders': 17756, 'hit_orders': 361, 'recall_clicks': '0.017', 'recall_carts': '0.017', 'recall_orders': '0.020', 'w_recall_clicks': '0.002', 'w_recall_carts': '0.005', 'w_recall_orders': '0.012', 'score': '0.019'}
# 0:04:55.211061 	 [make_candidate] session_latest_word2vec_pair14 : start
# 0:04:55.511688 	 [add_candidate] session_latest_word2vec_pair14 : start
# 0:04:58.672216 	 session_latest_word2vec_pair14
# 0:04:58.673615 	 {'num_clicks': 97259, 'hit_clicks': 933, 'num_carts': 36150, 'hit_carts': 314, 'num_orders': 17756, 'hit_orders': 187, 'recall_clicks': '0.010', 'recall_carts': '0.009', 'recall_orders': '0.011', 'w_recall_clicks': '0.001', 'w_recall_carts': '0.003', 'w_recall_orders': '0.006', 'score': '0.010'}
# 0:04:58.685148 	 [make_candidate] session_latest_pair14 : start
# 0:04:59.043841 	 [add_candidate] session_latest_pair14 : start
# 0:05:02.188666 	 session_latest_pair14
# 0:05:02.190000 	 {'num_clicks': 97259, 'hit_clicks': 1261, 'num_carts': 36150, 'hit_carts': 702, 'num_orders': 17756, 'hit_orders': 417, 'recall_clicks': '0.013', 'recall_carts': '0.019', 'recall_orders': '0.023', 'w_recall_clicks': '0.001', 'w_recall_carts': '0.006', 'w_recall_orders': '0.014', 'score': '0.021'}
# 0:05:02.202267 	 [make_candidate] session_latest_type_wt_pair14 : start
# 0:05:02.747414 	 [add_candidate] session_latest_type_wt_pair14 : start
# 0:05:05.870807 	 session_latest_type_wt_pair14
# 0:05:05.871906 	 {'num_clicks': 97259, 'hit_clicks': 1269, 'num_carts': 36150, 'hit_carts': 829, 'num_orders': 17756, 'hit_orders': 459, 'recall_clicks': '0.013', 'recall_carts': '0.023', 'recall_orders': '0.026', 'w_recall_clicks': '0.001', 'w_recall_carts': '0.007', 'w_recall_orders': '0.016', 'score': '0.024'}
# 0:05:05.882381 	 [make_candidate] session_latest_clicks2carts_pair14 : start
# 0:05:06.253902 	 [add_candidate] session_latest_clicks2carts_pair14 : start
# 0:05:09.246069 	 session_latest_clicks2carts_pair14
# 0:05:09.247404 	 {'num_clicks': 97259, 'hit_clicks': 669, 'num_carts': 36150, 'hit_carts': 453, 'num_orders': 17756, 'hit_orders': 239, 'recall_clicks': '0.007', 'recall_carts': '0.013', 'recall_orders': '0.013', 'w_recall_clicks': '0.001', 'w_recall_carts': '0.004', 'w_recall_orders': '0.008', 'score': '0.013'}
# 0:05:09.256674 	 [make_candidate] session_latest_clicks2orders_pair14 : start
# 0:05:09.454862 	 [add_candidate] session_latest_clicks2orders_pair14 : start
# 0:05:12.116642 	 session_latest_clicks2orders_pair14
# 0:05:12.117771 	 {'num_clicks': 97259, 'hit_clicks': 302, 'num_carts': 36150, 'hit_carts': 189, 'num_orders': 17756, 'hit_orders': 174, 'recall_clicks': '0.003', 'recall_carts': '0.005', 'recall_orders': '0.010', 'w_recall_clicks': '0.000', 'w_recall_carts': '0.002', 'w_recall_orders': '0.006', 'score': '0.008'}
# 0:05:12.126381 	 [make_candidate] session_latest_time_wt_pair15 : start
# 0:05:12.596395 	 [add_candidate] session_latest_time_wt_pair15 : start
# 0:05:15.872043 	 session_latest_time_wt_pair15
# ...
# 0:38:53.556282 	 [make_candidate] session_latest_clicks2orders_pair14 : start
# 0:38:53.883967 	 [add_candidate] session_latest_clicks2orders_pair14 : start
# 0:38:56.230223 	 session_latest_clicks2orders_pair14
# 0:38:56.231250 	 {'num_clicks': 97121, 'hit_clicks': 276, 'num_carts': 37741, 'hit_carts': 125, 'num_orders': 17683, 'hit_orders': 77, 'recall_clicks': '0.003', 'recall_carts': '0.003', 'recall_orders': '0.004', 'w_recall_clicks': '0.000', 'w_recall_carts': '0.001', 'w_recall_orders': '0.003', 'score': '0.004'}
# 0:38:56.238748 	 [make_candidate] session_latest_time_wt_pair15 : start
# 0:38:56.715780 	 [add_candidate] session_latest_time_wt_pair15 : start
# 0:38:59.666451 	 session_latest_time_wt_pair15
# 0:38:59.667549 	 {'num_clicks': 97121, 'hit_clicks': 1273, 'num_carts': 37741, 'hit_carts': 452, 'num_orders': 17683, 'hit_orders': 245, 'recall_clicks': '0.013', 'recall_carts': '0.012', 'recall_orders': '0.014', 'w_recall_clicks': '0.001', 'w_recall_carts': '0.004', 'w_recall_orders': '0.008', 'score': '0.013'}
# 0:38:59.677924 	 [make_candidate] session_latest_word2vec_pair15 : start
# 0:39:00.038371 	 [add_candidate] session_latest_word2vec_pair15 : start
# 0:39:03.062285 	 session_latest_word2vec_pair15
# 0:39:03.063454 	 {'num_clicks': 97121, 'hit_clicks': 793, 'num_carts': 37741, 'hit_carts': 297, 'num_orders': 17683, 'hit_orders': 153, 'recall_clicks': '0.008', 'recall_carts': '0.008', 'recall_orders': '0.009', 'w_recall_clicks': '0.001', 'w_recall_carts': '0.002', 'w_recall_orders': '0.005', 'score': '0.008'}
# 0:39:03.073372 	 [make_candidate] session_latest_pair15 : start
# 0:39:03.554136 	 [add_candidate] session_latest_pair15 : start
# 0:39:06.573132 	 session_latest_pair15
# 0:39:06.574311 	 {'num_clicks': 97121, 'hit_clicks': 1046, 'num_carts': 37741, 'hit_carts': 383, 'num_orders': 17683, 'hit_orders': 286, 'recall_clicks': '0.011', 'recall_carts': '0.010', 'recall_orders': '0.016', 'w_recall_clicks': '0.001', 'w_recall_carts': '0.003', 'w_recall_orders': '0.010', 'score': '0.014'}
# 0:39:06.584089 	 [make_candidate] session_latest_type_wt_pair15 : start
# 0:39:07.072418 	 [add_candidate] session_latest_type_wt_pair15 : start
# 0:39:10.136164 	 session_latest_type_wt_pair15
# 0:39:10.137377 	 {'num_clicks': 97121, 'hit_clicks': 1084, 'num_carts': 37741, 'hit_carts': 407, 'num_orders': 17683, 'hit_orders': 294, 'recall_clicks': '0.011', 'recall_carts': '0.011', 'recall_orders': '0.017', 'w_recall_clicks': '0.001', 'w_recall_carts': '0.003', 'w_recall_orders': '0.010', 'score': '0.014'}
# 0:39:10.148286 	 [make_candidate] session_latest_clicks2carts_pair15 : start
# 0:39:10.432804 	 [add_candidate] session_latest_clicks2carts_pair15 : start
# 0:39:13.111672 	 session_latest_clicks2carts_pair15
# 0:39:13.112870 	 {'num_clicks': 97121, 'hit_clicks': 536, 'num_carts': 37741, 'hit_carts': 217, 'num_orders': 17683, 'hit_orders': 135, 'recall_clicks': '0.006', 'recall_carts': '0.006', 'recall_orders': '0.008', 'w_recall_clicks': '0.001', 'w_recall_carts': '0.002', 'w_recall_orders': '0.005', 'score': '0.007'}
# 0:39:13.121935 	 [make_candidate] session_latest_clicks2orders_pair15 : start
# 0:39:13.467682 	 [add_candidate] session_latest_clicks2orders_pair15 : start
# 0:39:16.077651 	 session_latest_clicks2orders_pair15
# 0:39:16.078785 	 {'num_clicks': 97121, 'hit_clicks': 265, 'num_carts': 37741, 'hit_carts': 106, 'num_orders': 17683, 'hit_orders': 65, 'recall_clicks': '0.003', 'recall_carts': '0.003', 'recall_orders': '0.004', 'w_recall_clicks': '0.000', 'w_recall_carts': '0.001', 'w_recall_orders': '0.002', 'score': '0.003'}
# 0:39:16.085948 	 [make_candidate] session_latest_time_wt_pair16 : start
# 0:39:16.601994 	 [add_candidate] session_latest_time_wt_pair16 : start
# 0:39:19.588577 	 session_latest_time_wt_pair16
# 0:39:19.589814 	 {'num_clicks': 97121, 'hit_clicks': 1284, 'num_carts': 37741, 'hit_carts': 461, 'num_orders': 17683, 'hit_orders': 287, 'recall_clicks': '0.013', 'recall_carts': '0.012', 'recall_orders': '0.016', 'w_recall_clicks': '0.001', 'w_recall_carts': '0.004', 'w_recall_orders': '0.010', 'score': '0.015'}
# 0:39:19.600008 	 [make_candidate] session_latest_word2vec_pair16 : start
# 0:39:20.088387 	 [add_candidate] session_latest_word2vec_pair16 : start
# 0:39:22.954604 	 session_latest_word2vec_pair16
# 0:39:22.955675 	 {'num_clicks': 97121, 'hit_clicks': 813, 'num_carts': 37741, 'hit_carts': 275, 'num_orders': 17683, 'hit_orders': 142, 'recall_clicks': '0.008', 'recall_carts': '0.007', 'recall_orders': '0.008', 'w_recall_clicks': '0.001', 'w_recall_carts': '0.002', 'w_recall_orders': '0.005', 'score': '0.008'}
# 0:39:22.965706 	 [make_candidate] session_latest_pair16 : start
# 0:39:23.296851 	 [add_candidate] session_latest_pair16 : start
# 0:39:26.329936 	 session_latest_pair16
# 0:39:26.331084 	 {'num_clicks': 97121, 'hit_clicks': 949, 'num_carts': 37741, 'hit_carts': 390, 'num_orders': 17683, 'hit_orders': 235, 'recall_clicks': '0.010', 'recall_carts': '0.010', 'recall_orders': '0.013', 'w_recall_clicks': '0.001', 'w_recall_carts': '0.003', 'w_recall_orders': '0.008', 'score': '0.012'}
# 0:39:26.341396 	 [make_candidate] session_latest_type_wt_pair16 : start
# 0:39:26.837734 	 [add_candidate] session_latest_type_wt_pair16 : start
# 0:39:29.887596 	 session_latest_type_wt_pair16
# 0:39:29.888774 	 {'num_clicks': 97121, 'hit_clicks': 1067, 'num_carts': 37741, 'hit_carts': 409, 'num_orders': 17683, 'hit_orders': 312, 'recall_clicks': '0.011', 'recall_carts': '0.011', 'recall_orders': '0.018', 'w_recall_clicks': '0.001', 'w_recall_carts': '0.003', 'w_recall_orders': '0.011', 'score': '0.015'}
# 0:39:29.900071 	 [make_candidate] session_latest_clicks2carts_pair16 : start
# 0:39:30.087084 	 [add_candidate] session_latest_clicks2carts_pair16 : start
# 0:39:33.070291 	 session_latest_clicks2carts_pair16
# 0:39:33.071569 	 {'num_clicks': 97121, 'hit_clicks': 473, 'num_carts': 37741, 'hit_carts': 224, 'num_orders': 17683, 'hit_orders': 132, 'recall_clicks': '0.005', 'recall_carts': '0.006', 'recall_orders': '0.007', 'w_recall_clicks': '0.000', 'w_recall_carts': '0.002', 'w_recall_orders': '0.004', 'score': '0.007'}
# 0:39:33.079508 	 [make_candidate] session_latest_clicks2orders_pair16 : start
# 0:39:33.238194 	 [add_candidate] session_latest_clicks2orders_pair16 : start
# 0:39:35.765410 	 session_latest_clicks2orders_pair16
# 0:39:35.766736 	 {'num_clicks': 97121, 'hit_clicks': 199, 'num_carts': 37741, 'hit_carts': 114, 'num_orders': 17683, 'hit_orders': 74, 'recall_clicks': '0.002', 'recall_carts': '0.003', 'recall_orders': '0.004', 'w_recall_clicks': '0.000', 'w_recall_carts': '0.001', 'w_recall_orders': '0.003', 'score': '0.004'}
# 0:39:35.773715 	 [make_candidate] session_latest_time_wt_pair17 : start
# 0:39:36.250185 	 [add_candidate] session_latest_time_wt_pair17 : start
# 0:39:39.377203 	 session_latest_time_wt_pair17
# 0:39:39.378380 	 {'num_clicks': 97121, 'hit_clicks': 1172, 'num_carts': 37741, 'hit_carts': 431, 'num_orders': 17683, 'hit_orders': 275, 'recall_clicks': '0.012', 'recall_carts': '0.011', 'recall_orders': '0.016', 'w_recall_clicks': '0.001', 'w_recall_carts': '0.003', 'w_recall_orders': '0.009', 'score': '0.014'}
# 0:39:39.387993 	 [make_candidate] session_latest_word2vec_pair17 : start
# 0:39:39.752595 	 [add_candidate] session_latest_word2vec_pair17 : start
# 0:39:42.726005 	 session_latest_word2vec_pair17
# 0:39:42.727255 	 {'num_clicks': 97121, 'hit_clicks': 712, 'num_carts': 37741, 'hit_carts': 275, 'num_orders': 17683, 'hit_orders': 162, 'recall_clicks': '0.007', 'recall_carts': '0.007', 'recall_orders': '0.009', 'w_recall_clicks': '0.001', 'w_recall_carts': '0.002', 'w_recall_orders': '0.005', 'score': '0.008'}
# 0:39:42.737793 	 [make_candidate] session_latest_pair17 : start
# 0:39:42.993801 	 [add_candidate] session_latest_pair17 : start
# 0:39:46.086936 	 session_latest_pair17
# 0:39:46.088100 	 {'num_clicks': 97121, 'hit_clicks': 913, 'num_carts': 37741, 'hit_carts': 379, 'num_orders': 17683, 'hit_orders': 233, 'recall_clicks': '0.009', 'recall_carts': '0.010', 'recall_orders': '0.013', 'w_recall_clicks': '0.001', 'w_recall_carts': '0.003', 'w_recall_orders': '0.008', 'score': '0.012'}
# 0:39:46.098599 	 [make_candidate] session_latest_type_wt_pair17 : start
# 0:39:46.639128 	 [add_candidate] session_latest_type_wt_pair17 : start
# 0:39:49.741698 	 session_latest_type_wt_pair17
# 0:39:49.742698 	 {'num_clicks': 97121, 'hit_clicks': 956, 'num_carts': 37741, 'hit_carts': 402, 'num_orders': 17683, 'hit_orders': 296, 'recall_clicks': '0.010', 'recall_carts': '0.011', 'recall_orders': '0.017', 'w_recall_clicks': '0.001', 'w_recall_carts': '0.003', 'w_recall_orders': '0.010', 'score': '0.014'}
# 0:39:49.753278 	 [make_candidate] session_latest_clicks2carts_pair17 : start
# 0:39:50.103809 	 [add_candidate] session_latest_clicks2carts_pair17 : start
# 0:39:53.043029 	 session_latest_clicks2carts_pair17
# 0:39:53.044218 	 {'num_clicks': 97121, 'hit_clicks': 469, 'num_carts': 37741, 'hit_carts': 205, 'num_orders': 17683, 'hit_orders': 133, 'recall_clicks': '0.005', 'recall_carts': '0.005', 'recall_orders': '0.008', 'w_recall_clicks': '0.000', 'w_recall_carts': '0.002', 'w_recall_orders': '0.005', 'score': '0.007'}
# 0:39:53.053561 	 [make_candidate] session_latest_clicks2orders_pair17 : start
# 0:39:53.251053 	 [add_candidate] session_latest_clicks2orders_pair17 : start
# 0:39:55.780789 	 session_latest_clicks2orders_pair17
# 0:39:55.781955 	 {'num_clicks': 97121, 'hit_clicks': 220, 'num_carts': 37741, 'hit_carts': 84, 'num_orders': 17683, 'hit_orders': 64, 'recall_clicks': '0.002', 'recall_carts': '0.002', 'recall_orders': '0.004', 'w_recall_clicks': '0.000', 'w_recall_carts': '0.001', 'w_recall_orders': '0.002', 'score': '0.003'}
# 0:39:55.789346 	 [make_candidate] session_latest_time_wt_pair18 : start
# 0:39:56.262030 	 [add_candidate] session_latest_time_wt_pair18 : start
# 0:39:59.414632 	 session_latest_time_wt_pair18
# 0:39:59.416445 	 {'num_clicks': 97121, 'hit_clicks': 1073, 'num_carts': 37741, 'hit_carts': 392, 'num_orders': 17683, 'hit_orders': 258, 'recall_clicks': '0.011', 'recall_carts': '0.010', 'recall_orders': '0.015', 'w_recall_clicks': '0.001', 'w_recall_carts': '0.003', 'w_recall_orders': '0.009', 'score': '0.013'}
# 0:39:59.427235 	 [make_candidate] session_latest_word2vec_pair18 : start
# 0:39:59.862430 	 [add_candidate] session_latest_word2vec_pair18 : start
# 0:40:03.012619 	 session_latest_word2vec_pair18
# 0:40:03.014124 	 {'num_clicks': 97121, 'hit_clicks': 719, 'num_carts': 37741, 'hit_carts': 265, 'num_orders': 17683, 'hit_orders': 124, 'recall_clicks': '0.007', 'recall_carts': '0.007', 'recall_orders': '0.007', 'w_recall_clicks': '0.001', 'w_recall_carts': '0.002', 'w_recall_orders': '0.004', 'score': '0.007'}
# 0:40:03.024915 	 [make_candidate] session_latest_pair18 : start
# 0:40:03.503327 	 [add_candidate] session_latest_pair18 : start
# 0:40:06.910500 	 session_latest_pair18
# 0:40:06.911595 	 {'num_clicks': 97121, 'hit_clicks': 873, 'num_carts': 37741, 'hit_carts': 339, 'num_orders': 17683, 'hit_orders': 221, 'recall_clicks': '0.009', 'recall_carts': '0.009', 'recall_orders': '0.012', 'w_recall_clicks': '0.001', 'w_recall_carts': '0.003', 'w_recall_orders': '0.007', 'score': '0.011'}
# 0:40:06.922211 	 [make_candidate] session_latest_type_wt_pair18 : start
# 0:40:07.426708 	 [add_candidate] session_latest_type_wt_pair18 : start
# 0:40:10.584312 	 session_latest_type_wt_pair18
# 0:40:10.585558 	 {'num_clicks': 97121, 'hit_clicks': 899, 'num_carts': 37741, 'hit_carts': 325, 'num_orders': 17683, 'hit_orders': 248, 'recall_clicks': '0.009', 'recall_carts': '0.009', 'recall_orders': '0.014', 'w_recall_clicks': '0.001', 'w_recall_carts': '0.003', 'w_recall_orders': '0.008', 'score': '0.012'}
# 0:40:10.594851 	 [make_candidate] session_latest_clicks2carts_pair18 : start
# 0:40:10.846206 	 [add_candidate] session_latest_clicks2carts_pair18 : start
# 0:40:13.999981 	 session_latest_clicks2carts_pair18
# 0:40:14.001128 	 {'num_clicks': 97121, 'hit_clicks': 442, 'num_carts': 37741, 'hit_carts': 196, 'num_orders': 17683, 'hit_orders': 104, 'recall_clicks': '0.005', 'recall_carts': '0.005', 'recall_orders': '0.006', 'w_recall_clicks': '0.000', 'w_recall_carts': '0.002', 'w_recall_orders': '0.004', 'score': '0.006'}
# 0:40:14.010547 	 [make_candidate] session_latest_clicks2orders_pair18 : start
# 0:40:14.154659 	 [add_candidate] session_latest_clicks2orders_pair18 : start
# 0:40:16.699979 	 session_latest_clicks2orders_pair18
# 0:40:16.701044 	 {'num_clicks': 97121, 'hit_clicks': 200, 'num_carts': 37741, 'hit_carts': 91, 'num_orders': 17683, 'hit_orders': 66, 'recall_clicks': '0.002', 'recall_carts': '0.002', 'recall_orders': '0.004', 'w_recall_clicks': '0.000', 'w_recall_carts': '0.001', 'w_recall_orders': '0.002', 'score': '0.003'}
# 0:40:16.707951 	 [make_candidate] session_latest_time_wt_pair19 : start
# 0:40:17.121509 	 [add_candidate] session_latest_time_wt_pair19 : start
# 0:40:20.564787 	 session_latest_time_wt_pair19
# 0:40:20.565898 	 {'num_clicks': 97121, 'hit_clicks': 981, 'num_carts': 37741, 'hit_carts': 357, 'num_orders': 17683, 'hit_orders': 239, 'recall_clicks': '0.010', 'recall_carts': '0.009', 'recall_orders': '0.014', 'w_recall_clicks': '0.001', 'w_recall_carts': '0.003', 'w_recall_orders': '0.008', 'score': '0.012'}
# 0:40:20.578230 	 [make_candidate] session_latest_word2vec_pair19 : start
# 0:40:20.928819 	 [add_candidate] session_latest_word2vec_pair19 : start
# 0:40:24.394823 	 session_latest_word2vec_pair19
# 0:40:24.395989 	 {'num_clicks': 97121, 'hit_clicks': 701, 'num_carts': 37741, 'hit_carts': 270, 'num_orders': 17683, 'hit_orders': 138, 'recall_clicks': '0.007', 'recall_carts': '0.007', 'recall_orders': '0.008', 'w_recall_clicks': '0.001', 'w_recall_carts': '0.002', 'w_recall_orders': '0.005', 'score': '0.008'}
# 0:40:24.405982 	 [make_candidate] session_latest_pair19 : start
# 0:40:24.835738 	 [add_candidate] session_latest_pair19 : start
# 0:40:28.084470 	 session_latest_pair19
# 0:40:28.085635 	 {'num_clicks': 97121, 'hit_clicks': 795, 'num_carts': 37741, 'hit_carts': 311, 'num_orders': 17683, 'hit_orders': 184, 'recall_clicks': '0.008', 'recall_carts': '0.008', 'recall_orders': '0.010', 'w_recall_clicks': '0.001', 'w_recall_carts': '0.002', 'w_recall_orders': '0.006', 'score': '0.010'}
# 0:40:28.095619 	 [make_candidate] session_latest_type_wt_pair19 : start
# 0:40:28.603819 	 [add_candidate] session_latest_type_wt_pair19 : start
# 0:40:32.526787 	 session_latest_type_wt_pair19
# 0:40:32.528020 	 {'num_clicks': 97121, 'hit_clicks': 869, 'num_carts': 37741, 'hit_carts': 320, 'num_orders': 17683, 'hit_orders': 277, 'recall_clicks': '0.009', 'recall_carts': '0.008', 'recall_orders': '0.016', 'w_recall_clicks': '0.001', 'w_recall_carts': '0.003', 'w_recall_orders': '0.009', 'score': '0.013'}
# 0:40:32.538512 	 [make_candidate] session_latest_clicks2carts_pair19 : start
# 0:40:32.864149 	 [add_candidate] session_latest_clicks2carts_pair19 : start
# 0:40:36.373330 	 session_latest_clicks2carts_pair19
# 0:40:36.374619 	 {'num_clicks': 97121, 'hit_clicks': 442, 'num_carts': 37741, 'hit_carts': 187, 'num_orders': 17683, 'hit_orders': 107, 'recall_clicks': '0.005', 'recall_carts': '0.005', 'recall_orders': '0.006', 'w_recall_clicks': '0.000', 'w_recall_carts': '0.001', 'w_recall_orders': '0.004', 'score': '0.006'}
# 0:40:36.383973 	 [make_candidate] session_latest_clicks2orders_pair19 : start
# 0:40:36.705535 	 [add_candidate] session_latest_clicks2orders_pair19 : start
# 0:40:40.161506 	 session_latest_clicks2orders_pair19
# 0:40:40.162668 	 {'num_clicks': 97121, 'hit_clicks': 193, 'num_carts': 37741, 'hit_carts': 99, 'num_orders': 17683, 'hit_orders': 64, 'recall_clicks': '0.002', 'recall_carts': '0.003', 'recall_orders': '0.004', 'w_recall_clicks': '0.000', 'w_recall_carts': '0.001', 'w_recall_orders': '0.002', 'score': '0.003'}

# %%
df = pd.concat(results, axis=1)

# %%
df[["nametm_test_vl_week3", "scoretm_test_vl_week3", "scoretm_test_vl_week4", "scoretm_week3_vl_week3", "scoretm_week3_vl_week4", "scoretm_week4_vl_week3", "scoretm_week4_vl_week4"]].to_csv(cfg.output_dir + cfg.exp_name + "/scores.csv", index=False)
