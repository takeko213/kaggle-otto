# %% [markdown]
# # exp040
# exp039 cand_n = 15

# %%
import os
import sys
import traceback
import gc
import random
import pickle
import pathlib
import subprocess
from dataclasses import dataclass
from dotenv import load_dotenv
load_dotenv
sys.path.append(os.getenv('UTILS_PATH'))
from tqdm import tqdm
import multiprocessing
import inspect

import pandas as pd
import numpy as np
import itertools
import cudf
import lightgbm as lgb
import matplotlib.pyplot as plt
import seaborn as sns
import line_notify
import my_logger
from noglobal import noglobal

# %% [markdown]
# # 設定

# %%
@dataclass
class Cfg:
    loglevel = "INFO"
    exp_name = "exp040"
    seed = 42
    k = 20
    cand_n = 15
    negative_sample = 1
    type2id = {"clicks":0, "carts":1, "orders":2}
    id2type = {0:"clicks", 1:"carts", 2:"orders"}
    train_weeks = ["week3"]
    valid_week = "week4"
    valid_session_n = 100_000
    input_dir = os.getenv('INPUT_DIR')
    output_dir = os.getenv('OUTPUT_DIR')
    prep_dir = os.getenv("PREP_DIR")

cfg = Cfg()
os.makedirs(os.path.join(cfg.output_dir, cfg.exp_name), exist_ok=True)
os.makedirs(os.path.join(cfg.output_dir, cfg.exp_name, "cache"), exist_ok=True)
random.seed(cfg.seed)

logger = my_logger.init_logger(cfg.exp_name)

# %%
class Cache:
    @noglobal(excepts=["cfg", "logger"])
    def __init__(self):
        self.cache_dir = (os.path.join(cfg.output_dir, cfg.exp_name, "cache"))
        self.cache_dir_path = pathlib.Path(self.cache_dir)
        self.caches = list(self.cache_dir_path.glob("*.pkl"))

    @noglobal(excepts=["cfg", "logger"])
    def get_abspath(self, filename):
        return (os.path.join(self.cache_dir, filename))
    
    @noglobal(excepts=["cfg", "logger"])
    def exists(self, path):
        return len([str(c) for c in self.caches if path == str(c)]) > 0


cache = Cache()

# %%
def reduce_mem_usage(df):
    """ iterate through all the columns of a dataframe and modify the data type
        to reduce memory usage.        
    """
    start_mem = df.memory_usage().sum() / 1024**2
    print('Memory usage of dataframe is {:.2f} MB'.format(start_mem))
    
    for col in df.columns:
        col_type = df[col].dtype
        
        if col_type != object:
            c_min = df[col].min()
            c_max = df[col].max()
            if str(col_type)[:3] == 'int':
                if c_min > np.iinfo(np.int8).min and c_max < np.iinfo(np.int8).max:
                    df[col] = df[col].astype(np.int8)
                elif c_min > np.iinfo(np.int16).min and c_max < np.iinfo(np.int16).max:
                    df[col] = df[col].astype(np.int16)
                elif c_min > np.iinfo(np.int32).min and c_max < np.iinfo(np.int32).max:
                    df[col] = df[col].astype(np.int32)
                elif c_min > np.iinfo(np.int64).min and c_max < np.iinfo(np.int64).max:
                    df[col] = df[col].astype(np.int64)  
            else:
                if c_min > np.finfo(np.float16).min and c_max < np.finfo(np.float16).max:
                    df[col] = df[col].astype(np.float16)
                elif c_min > np.finfo(np.float32).min and c_max < np.finfo(np.float32).max:
                    df[col] = df[col].astype(np.float32)
                else:
                    df[col] = df[col].astype(np.float64)
        else:
            df[col] = df[col].astype('category')

    end_mem = df.memory_usage().sum() / 1024**2
    print('Memory usage after optimization is: {:.2f} MB'.format(end_mem))
    print('Decreased by {:.1f}%'.format(100 * (start_mem - end_mem) / start_mem))
    
    return df

# %%
@noglobal(excepts=["cfg", "logger"])
def evaluate(clicks_labels, carts_labels, orders_labels, 
             clicks_preds, carts_preds, orders_preds, k=20):

    num_clicks = 0
    num_carts = 0
    num_orders = 0
    hit_clicks = 0
    hit_carts = 0
    hit_orders = 0

    for i in range(len(clicks_labels)):
        clicks_label = clicks_labels[i]
        carts_label = carts_labels[i]
        orders_label = orders_labels[i]
        clicks_pred = clicks_preds[i]
        carts_pred = carts_preds[i]
        orders_pred = orders_preds[i]

        if type(clicks_pred) == list:
            clicks_pred = clicks_pred[:k]
        else:
            clicks_pred = []
        if type(carts_pred) == list:
            carts_pred = carts_pred[:k]
        else:
            carts_pred = []    
        if type(orders_pred) == list:
            orders_pred = orders_pred[:k]
        else:
            orders_pred = []

        if not np.isnan(clicks_label):
            num_clicks += 1
            hit_clicks += int(clicks_label in clicks_pred)

        if type(carts_label) == list:
            num_carts += min(len(carts_label), k)
            hit_carts += len(set(carts_pred) & set(carts_label))
            
        if type(orders_label) == list:
            num_orders += min(len(orders_label), k)
            hit_orders += len(set(orders_pred) & set(orders_label))


    recall_clicks = hit_clicks / num_clicks
    recall_carts = hit_carts / num_carts
    recall_orders = hit_orders / num_orders
    w_recall_clicks = recall_clicks * 0.10
    w_recall_carts = recall_carts * 0.30
    w_recall_orders = recall_orders * 0.60
    score = w_recall_clicks + w_recall_carts + w_recall_orders

    results = {}
    results["num_clicks"] = num_clicks
    results["hit_clicks"] = hit_clicks
    results["num_carts"] = num_carts
    results["hit_carts"] = hit_carts
    results["num_orders"] = num_orders
    results["hit_orders"] = hit_orders
    results["recall_clicks"] = format(recall_clicks, ".3f")
    results["recall_carts"] = format(recall_carts, ".3f")
    results["recall_orders"] = format(recall_orders, ".3f")
    results["w_recall_clicks"] = format(w_recall_clicks, ".3f")
    results["w_recall_carts"] = format(w_recall_carts, ".3f")
    results["w_recall_orders"] = format(w_recall_orders, ".3f")
    results["score"] = format(score, ".3f")

    return results

# %%
class Candidate:
    @noglobal(excepts=["cfg", "logger"])
    def __init__(self, pdf, labels=None):
        self.df = cudf.from_pandas(pdf)
        self.target_sessions = pdf["session"].unique().tolist()
        self.results = pd.DataFrame(columns=["name", "num_clicks", "hit_clicks", "num_carts", "hit_carts", "num_orders", "hit_orders", 
                                             "recall_clicks", "recall_carts", "recall_orders", "w_recall_clicks", "w_recall_carts", "w_recall_orders", "score"])
        self.output = pd.DataFrame(columns=["session", "aid"], dtype=int)
        self.labels = labels
    
    @noglobal(excepts=["cfg", "logger"])
    def _entry(self, new_candidate_df, name, k):
        logger.info(f"[add_candidate] {name} : start")
        new_candidate_df[f"{name}_rank"] = new_candidate_df.groupby("session")["session"].cumcount()
        new_candidate_df = new_candidate_df.to_pandas()
        self.output = pd.concat([self.output, new_candidate_df[["session", "aid"]]])
        self.output = self.output.drop_duplicates(subset=["session", "aid"])
        
        self.output = self.output.merge(new_candidate_df, on=["session", "aid"], how="left")

        if self.labels is not None:
            self._eval(new_candidate_df[["session", "aid"]], name, k)
    
    @noglobal(excepts=["cfg", "logger"])
    def _eval(self, new_candidate_df, name, k):
        new_candidate_df = new_candidate_df.groupby("session")["aid"].apply(list).reset_index()
        eval_df = pd.DataFrame(self.target_sessions, columns=["session"])
        eval_df = eval_df.merge(new_candidate_df, on=["session"], how="left")
        assert eval_df["session"].tolist() == self.labels["session"].tolist()
        eval_result = evaluate(self.labels["clicks_labels"].tolist(), self.labels["carts_labels"].tolist(), self.labels["orders_labels"].tolist(),
                               eval_df["aid"].tolist(), eval_df["aid"].tolist(), eval_df["aid"].tolist(), k)
        
        print(eval_result)
        self.results = pd.concat([self.results, pd.DataFrame([[name] + list(eval_result.values())], columns=["name"] + list(eval_result.keys()))])

    @noglobal(excepts=["cfg", "logger"])
    def add(self, strategy, name, usetypes=['clicks', 'carts', 'orders'], trans_map=None, k=20):
        logger.info(f"[make_candidate] {name} : start")
        candidate_df = self.df[self.df["type"].isin(usetypes)].copy()
        
        if strategy == "session_frequent":
            candidate_df = self._session_frequent(candidate_df, k)
        elif strategy == "session_latest":
            candidate_df = self._session_latest(candidate_df, k)
        elif strategy == "total_frequent":
            candidate_df = self._total_frequent(candidate_df, k)
        
        if trans_map is not None:
            candidate_df["aid"] = candidate_df["aid"].map(trans_map)
            candidate_df = candidate_df.dropna(subset=["aid"])
            
        self._entry(candidate_df, name, k)

    @noglobal(excepts=["cfg", "logger"])
    def _session_frequent(self, candidate_df, k):
        candidate_df = candidate_df.groupby(["session", "aid"])["ts"].count().reset_index()
        candidate_df.columns = ["session", "aid", "aid_count"]
        candidate_df = candidate_df.sort_values(["session", "aid_count", "aid"], ascending=(True, False, True))
        candidate_df = candidate_df[candidate_df.groupby("session")["aid_count"].cumcount() < k].copy()
        candidate_df = candidate_df[["session", "aid"]].copy()
        return candidate_df

    @noglobal(excepts=["cfg", "logger"])
    def _session_latest(self, candidate_df, k):
        candidate_df = candidate_df.sort_values(["session", "ts"], ascending=(True, False)).drop_duplicates(subset=["session", "aid"])
        candidate_df = candidate_df.sort_values(["session", "ts"], ascending=(True, False))[candidate_df.groupby("session")["ts"].cumcount() < k].copy()
        candidate_df = candidate_df[["session", "aid"]].copy()
        return candidate_df

    @noglobal(excepts=["cfg", "logger"])
    def _total_frequent(self, candidate_df, k):
        candidate_df = candidate_df.groupby("aid")["ts"].count().reset_index()
        candidate_df.columns = ["aid", "aid_count"]
        topk_freq_aids = candidate_df.sort_values("aid_count", ascending=False)["aid"].to_arrow().to_pylist()[:k]
        sessions = []
        aids = []
        for session, aid in itertools.product(self.target_sessions, topk_freq_aids):
            sessions.append(session)
            aids.append(aid)
        candidate_df = cudf.DataFrame({"session": sessions, "aid": aids})
        return candidate_df

# %%
@noglobal(excepts=["cfg", "logger"])
def add_labels(df, labels, type_):
    type_labels = labels[["session", f"{type_}_labels"]].dropna().copy()
    type_labels.columns = ["session", "aid"]
    type_labels = type_labels.explode("aid")
    type_labels["labels"] = 1
    df = df.merge(type_labels, on=["session", "aid"], how="left")
    df["labels"] = df["labels"].fillna(0)
    return df

# %%
@noglobal(excepts=["cfg", "logger"])
def add_ground_truth_candidate(df, labels, type_):
    gt = labels[["session", f"{type_}_labels"]].dropna().copy()
    gt.columns = ["session", "aid"]
    gt = gt.explode("aid")
    df = pd.concat([df, gt])
    df = df.drop_duplicates()
    return df

# %%
@noglobal(excepts=["cfg", "logger"])
def under_sampling(df, label_col):
    cfg = Cfg()
    pos_df = df[df[label_col]==1].copy()
    neg_df = df[df[label_col]==0].copy()
    pos_n = len(pos_df)
    return pd.concat([pos_df, neg_df.sample(pos_n * cfg.negative_sample, random_state=cfg.seed)])

# %%
class Features:
    @noglobal(excepts=["cfg", "logger"])
    def __init__(self, sessions, candidate, week):
        self.sessions = cudf.from_pandas(sessions)
        self.output = candidate
        self.type_dict = cfg.type2id
        self.week = week

    @noglobal(excepts=["cfg", "logger"])
    def add_features(self):
            self._prep()
            self._session_cnt()
            self._session_aid_nunique()
            self._session_last_type()
            # self._session_last_dt()
            self._aid_cnt()
            self._all_times_aid_features()
            # self._session_mean_ts()
            # self._aid_mean_ts()
            # self._aid_cnt_ratio_at_session_last()
            # self.output = self.output.drop(columns=["session_last_day"]) # 日時はtrainセット内のみで有効なので削除

    @noglobal(excepts=["cfg", "logger"])
    def _prep(self):
        logger.info("[features] prep : start")
        # ts関連の前処理
        self.sessions["relative_ts"] = self.sessions["ts"] - self.sessions["ts"].min()
        self.sessions["dt"] = cudf.to_datetime(self.sessions["ts"], unit="ms")
        self.sessions["hour"] = self.sessions["dt"].dt.hour
        self.sessions["week"] = self.sessions["dt"].dt.dayofweek
        self.sessions["day"] = self.sessions["dt"].dt.day
        
    @noglobal(excepts=["cfg", "logger"])
    def _session_cnt(self):
        logger.info("[features] session_cnt : start")
        agg_df = self.sessions.groupby(["session", "type"])["ts"].count().reset_index().rename(columns={"ts": "cnt"})
        # session_total_cnt
        features = agg_df.groupby("session")["cnt"].sum().reset_index().rename(columns={"cnt": "session_total_cnt"})
        self.output = self.output.merge(features.to_pandas(), on=["session"], how="left")
        self.output["session_total_cnt"] = self.output["session_total_cnt"].fillna(0)
        # session_{type}_cnt
        for type_ in ["clicks", "carts", "orders"]:
            col_name = f"session_{type_}_cnt"
            features = agg_df[agg_df["type"]==type_].copy()
            features = features.rename(columns={"cnt": col_name})
            features = features[["session", col_name]].copy()
            self.output = self.output.merge(features.to_pandas(), on=["session"], how="left")
            self.output[col_name] = self.output[col_name].fillna(0)
        
    @noglobal(excepts=["cfg", "logger"])
    def _session_aid_nunique(self):
        logger.info("[features] session_aid_nunique : start")
        features = self.sessions.groupby("session")["aid"].nunique().reset_index().rename(columns={"aid": "session_aid_nunique"})
        self.output = self.output.merge(features.to_pandas(), on=["session"], how="left")
        self.output["session_aid_nunique"] = self.output["session_aid_nunique"].fillna(0)
        
    @noglobal(excepts=["cfg", "logger"])
    def _session_last_type(self):
        logger.info("[features] session_last_type : start")
        features = self.sessions.groupby("session").nth(-1).reset_index()[["session", "type"]]
        features = features.rename(columns={"type": "session_last_type"})
        features["session_last_type"] = features["session_last_type"].map(self.type_dict)
        self.output = self.output.merge(features.to_pandas(), on=["session"], how="left")
        
    @noglobal(excepts=["cfg", "logger"])
    def _session_last_dt(self):
        logger.info("[features] session_last_dt : start")
        features = self.sessions.groupby("session").nth(-1).reset_index()[["session", "relative_ts", "week", "day", "hour"]]
        features.columns = ["session", "session_last_ts", "session_last_week", "session_last_day", "session_last_hour"]
        self.output = self.output.merge(features.to_pandas(), on=["session"], how="left")
        
    @noglobal(excepts=["cfg", "logger"])
    def _session_mean_ts(self):
        logger.info("[features] session_mean_ts : start")
        features = self.sessions.groupby("session")["relative_ts"].mean().reset_index().rename(columns={"relative_ts": "session_mean_ts"})
        self.output = self.output.merge(features.to_pandas(), on=["session"], how="left")
        
    @noglobal(excepts=["cfg", "logger"])
    def _aid_mean_ts(self):
        logger.info("[features] aid_mean_ts : start")
        features = self.sessions.groupby("aid")["relative_ts"].mean().reset_index().rename(columns={"relative_ts": "aid_mean_ts"})
        self.output = self.output.merge(features.to_pandas(), on=["aid"], how="left")
       
    @noglobal(excepts=["cfg", "logger"])
    def _aid_session_nunique(self):
        logger.info("[features] aid_session_unique : start")
        features = self.sessions.groupby("aid")["session"].nunique().reset_index().rename(columns={"session": "aid_session_nunique"})
        self.output = self.output.merge(features.to_pandas(), on=["aid"], how="left")

    @noglobal(excepts=["cfg", "logger"]) 
    def _aid_cnt_ratio_at_session_last(self):
        logger.info("[features] aid_cnt_ratio_atsession_last : start")
        for dt_ in ["week", "day", "hour"]:
            features = self.sessions[["aid", dt_]].copy()
            features["total_cnt"] = features.groupby(dt_)["aid"].transform("count")
            features = features.groupby(["aid", dt_])["total_cnt"].agg(["count", "max"]).reset_index()
            features[f"aid_cnt_ratio_at_session_last_{dt_}"] = features["count"] / features["max"]
            features = features.rename(columns={dt_: f"session_last_{dt_}"})
            self.output = self.output.merge(features[["aid", f"session_last_{dt_}", f"aid_cnt_ratio_at_session_last_{dt_}"]].to_pandas(), on=["aid", f"session_last_{dt_}"], how="left")
            self.output[f"aid_cnt_ratio_at_session_last_{dt_}"] = self.output[f"aid_cnt_ratio_at_session_last_{dt_}"].fillna(0)
        
    @noglobal(excepts=["cfg", "logger"])
    def _aid_cnt(self):
        logger.info("[features] aid_cnt : start")
        agg_df = self.sessions.groupby(["session", "aid", "type"])["ts"].count().reset_index().rename(columns={"ts": "cnt"})

        # aid_total_cnt
        features = agg_df.groupby(["session", "aid"])["cnt"].sum().reset_index().rename(columns={"cnt": "aid_total_cnt"})
        self.output = self.output.merge(features.to_pandas(), on=["session", "aid"], how="left")
        self.output["aid_total_cnt"] = self.output["aid_total_cnt"].fillna(0)

        # aid_{type}_cnt
        for type_ in ["clicks", "carts", "orders"]:
            col_name = f"aid_{type_}_cnt"
            features = agg_df[agg_df["type"]==type_].copy()
            features = features.rename(columns={"cnt": col_name})
            features = features[["session", "aid", col_name]].copy()
            self.output = self.output.merge(features.to_pandas(), on=["session", "aid"], how="left")
            self.output[col_name] = self.output[col_name].fillna(0)

    @noglobal(excepts=["cfg", "logger"])
    def _all_times_aid_features(self):
        feats = ["all_times_aid_freq",
                 "all_times_aid_clicks_freq",
                 "all_times_aid_carts_freq",
                 "all_times_aid_orders_freq",
                 "all_times_aid_session_freq",
                 "all_times_aid_session_clicks_freq",
                 "all_times_aid_session_carts_freq",
                 "all_times_aid_session_orders_freq",
                 "all_times_aid_carts_ratio_with_clicks",
                 "all_times_aid_orders_ratio_with_clicks",
                 "all_times_aid_date_std",
                 "all_times_aid_hour_std",
                 "all_times_aid_day_of_week_std"]
        
        for feat in feats:
            if self.week is None:
                with open(cfg.prep_dir + f"{feat}.pkl", "rb") as f:
                    feat_map = pickle.load(f)
            else:
                with open(cfg.prep_dir + f"{feat}_{self.week}.pkl", "rb") as f:
                    feat_map = pickle.load(f)
            self.output[feat] = self.output["aid"].map(feat_map)

# %%
@noglobal(excepts=["cfg", "logger"])
def add_features(sessions, cand_df, week=None):
    feat = Features(sessions, cand_df, week)
    feat.add_features()
    return feat.output

# %%
@noglobal(excepts=["cfg", "logger"])
def make_cand_df(sessions, labels=None, trans_maps=None):

    if labels is not None:
         cand = Candidate(sessions, labels)
    else:
        cand = Candidate(sessions)

    cand.add(strategy="session_frequent", name="session_frequent", k=cfg.cand_n)
    cand.add(strategy="session_latest", name="session_latest", k=cfg.cand_n)
    # cand.add(strategy="total_frequent", name="total_frequent", k=cfg.cand_n)
    cand.add(strategy="session_frequent", trans_map=trans_maps["pair0"], name="session_frequent_pair", k=cfg.cand_n)
    
    for i in range(10):
        cand.add(strategy="session_latest", trans_map=trans_maps[f"pair{str(i)}"], name=f"session_latest_pair{str(i)}", k=cfg.cand_n)
    
    for i in range(10):
        cand.add(strategy="session_latest", trans_map=trans_maps[f"time_wt_pair{str(i)}"], name=f"session_latest_time_wt_pair{str(i)}", k=cfg.cand_n)
    
    cand.add(strategy="session_latest", trans_map=trans_maps["type_wt_pair"], name="session_latest_type_wt_pair", k=cfg.cand_n)
    cand.add(strategy="session_latest", trans_map=trans_maps["clicks2carts_pair"], name="session_latest_clicks2carts_pair", k=cfg.cand_n)
    cand.add(strategy="session_latest", trans_map=trans_maps["clicks2orders_pair"], name="session_latest_clicks2orders_pair", k=cfg.cand_n)
    if labels is not None:
        return cand.output, cand.results
    else:
        return cand.output

# %%
@noglobal(excepts=["cfg", "logger"])
def get_pair_df(name, wt_col, week):
    if week is not None:
        name = f"{name}_{week}"
    pair_df = pd.read_pickle(cfg.prep_dir + f"{name}.pkl")
    pair_df = pair_df[pair_df[wt_col] > 3].copy()
    pair_df = pair_df.sort_values(["aid_x", wt_col], ascending=(True, False))
    return pair_df

@noglobal(excepts=["cfg", "logger"])
def get_pair_dict(name, wt_col, week):
    if week is not None:
        name = f"{name}_{week}"
    pair_df = pd.read_pickle(cfg.prep_dir + f"{name}.pkl")
    pair_df = pair_df[pair_df[wt_col] > 3].copy()
    pair_df = pair_df.sort_values(["aid_x", wt_col], ascending=(True, False))
    pair_df = pair_df.groupby("aid_x").head(1)[["aid_x", "aid_y"]]
    pair_dict = {k: v for k, v in zip(pair_df["aid_x"].tolist(), pair_df["aid_y"].tolist())}
    return pair_dict

@noglobal(excepts=["cfg", "logger"])
def get_trans_maps(week=None):
    """
    aidを別のaidに置き換えるmapping辞書を取得する
    """
    trans_maps = {}
    
    pair_df_org = get_pair_df("co_visitation_matrix", "cnt", week)
    for i in range(10):
        pair_df = pair_df_org.groupby("aid_x").nth(i).reset_index()[["aid_x", "aid_y"]]
        pair_dict = {k: v for k, v in zip(pair_df["aid_x"].tolist(), pair_df["aid_y"].tolist())}
        trans_maps[f"pair{str(i)}"] = pair_dict
    
    pair_df_org = get_pair_df("co_visitation_matrix_time_weighted", "wt", week)
    for i in range(10):
        pair_df = pair_df_org.groupby("aid_x").nth(i).reset_index()[["aid_x", "aid_y"]]
        pair_dict = {k: v for k, v in zip(pair_df["aid_x"].tolist(), pair_df["aid_y"].tolist())}
        trans_maps[f"time_wt_pair{str(i)}"] = pair_dict
    
    trans_maps["clicks_pair"] = get_pair_dict("co_visitation_matrix_clicks", "cnt", week)
    trans_maps["carts_pair"] = get_pair_dict("co_visitation_matrix_carts", "cnt", week)
    trans_maps["orders_pair"] = get_pair_dict("co_visitation_matrix_orders", "cnt", week)
    trans_maps["type_wt_pair"] = get_pair_dict("co_visitation_matrix_type_weighted", "wt", week)
    trans_maps["clicks2carts_pair"] = get_pair_dict("co_visitation_matrix_clicks2carts", "cnt", week)
    trans_maps["clicks2orders_pair"] = get_pair_dict("co_visitation_matrix_clicks2orders", "cnt", week)

    return trans_maps

# %%
@noglobal(excepts=["cfg", "logger", "cache"])
def make_train_data(type_):
    dfs = []
    for weeks in cfg.train_weeks:
        # データ読み込み
        week_sessions = pd.read_pickle(cfg.prep_dir + f"train_sessions_{weeks}.pkl")
        week_labels = pd.read_pickle(cfg.prep_dir + f"labels_{weeks}.pkl")
        
        cache_file = f"train_cand_{weeks}.pkl"
        cache_path = cache.get_abspath(cache_file)
        print(cache_path)
        if cache.exists(cache_path):
            logger.info(f"[{cache_file}] cache exists. read cache and skip process.")
            cand_df = pd.read_pickle(cache_path)
        else:
            trans_map_cache_file = f"trans_maps_{weeks}.pkl"
            trans_map_cache_path = cache.get_abspath(trans_map_cache_file)
            with open(trans_map_cache_path, "rb") as f:
                trans_maps = pickle.load(f)
            # 候補選出
            cand_df = make_cand_df(week_sessions, trans_maps=trans_maps)
            cand_df = reduce_mem_usage(cand_df)
            cand_df.to_pickle(cache_path)

        cand_df = add_labels(cand_df, week_labels, type_)
        cand_df = under_sampling(cand_df, "labels")

        # 特徴量付与
        train_tmp = add_features(week_sessions, cand_df, weeks)
        dfs.append(train_tmp)
        del cand_df, train_tmp
        gc.collect()
        
    train = pd.concat(dfs)
    train = train.reset_index(drop=True)
    train = reduce_mem_usage(train)
    
    return train

# %%
@noglobal(excepts=["cfg", "logger", "cache"])
def make_valid_cand():
    valid_week = cfg.valid_week
    # データ読み込み
    week_sessions = pd.read_pickle(os.getenv("PREP_DIR") + f"train_sessions_{valid_week}.pkl")
    week_labels = pd.read_pickle(os.getenv("PREP_DIR") + f"labels_{valid_week}.pkl")
    valid_session_ids = week_sessions["session"].unique().tolist()
    trans_map_cache_file = f"trans_maps_{valid_week}.pkl"
    trans_map_cache_path = cache.get_abspath(trans_map_cache_file)
    with open(trans_map_cache_path, "rb") as f:
        trans_maps = pickle.load(f)

    # validに使うsessionを絞る
    valid_session_n = min(cfg.valid_session_n, len(valid_session_ids))
    random.seed(cfg.seed)
    valid_session_ids = random.sample(valid_session_ids, valid_session_n)
    week_sessions = week_sessions[week_sessions["session"].isin(valid_session_ids)].copy()
    week_labels = week_labels[week_labels["session"].isin(valid_session_ids)].copy()

    # 候補選出
    cand_df = make_cand_df(week_sessions, trans_maps=trans_maps)
    cand_df = reduce_mem_usage(cand_df)
    return cand_df, week_sessions, week_labels

# %%
@noglobal(excepts=["cfg", "logger"])
def make_valid_data(cand_df, week_sessions, week_labels, type_):
    # 特徴量付与
    valid = add_features(week_sessions, cand_df, cfg.valid_week)
    valid = add_labels(valid, week_labels, type_)
    valid = valid.reset_index(drop=True)
    valid = reduce_mem_usage(valid)
    return valid

# %%
@noglobal(excepts=["cfg", "logger"])
def model_training(train, valid, features, target, valid_labels, type_):
    params = {'objective': 'binary', 
            'boosting': 'gbdt', 
            'learning_rate': 0.1, 
            'metric': 'binary_logloss', 
            'seed': cfg.seed
            }

    # 学習
    vl_pred_df = valid[["session", "aid"]].copy()

    tr_x, tr_y = train[features], train[target]
    vl_x, vl_y = valid[features], valid[target]
    tr_data = lgb.Dataset(tr_x, label=tr_y)
    vl_data = lgb.Dataset(vl_x, label=vl_y)

    model = lgb.train(params, tr_data, valid_sets=[tr_data, vl_data],
                      num_boost_round=2000000, early_stopping_rounds=100, verbose_eval=100)

    # 特徴量重要度
    fi = pd.DataFrame()
    fi["feature"] = model.feature_name()
    fi["importance"] = model.feature_importance(importance_type="gain")

    # 2値分類の出力を元にk個選定
    vl_pred_df["prob"] = model.predict(vl_x, num_iteration=model.best_iteration)
    vl_pred_df = vl_pred_df.sort_values(["session", "prob"], ascending=(True, False))
    vl_pred_df = vl_pred_df.groupby(["session"]).head(cfg.k)
    vl_pred_df = vl_pred_df.groupby(["session"])["aid"].apply(list).reset_index()
    
    # 評価
    assert valid_labels["session"].tolist() == vl_pred_df["session"].unique().tolist()
    score = evaluate(valid_labels["clicks_labels"].tolist(),
                     valid_labels["carts_labels"].tolist(),
                     valid_labels["orders_labels"].tolist(),
                     vl_pred_df["aid"].tolist(),
                     vl_pred_df["aid"].tolist(),
                     vl_pred_df["aid"].tolist(),
                     cfg.k)
    logger.info(f"{type_} valid score")
    logger.info(score)

    # モデル保存
    model.save_model(cfg.output_dir + f"{cfg.exp_name}/{type_}_model.lgb")

    # 特徴量重要度
    fi_n = fi['feature'].nunique()
    order = list(fi.groupby("feature").mean().sort_values("importance", ascending=False).index)
    plt.figure(figsize=(10, fi_n*0.2))
    sns.barplot(x="importance", y="feature", data=fi, order=order)
    plt.title(f"LGBM importance({type_})")
    plt.tight_layout()
    plt.savefig(cfg.output_dir + f'{cfg.exp_name}/lgbm_importance_{type_}.png')

    return score[f"recall_{type_}"]

# %%
@noglobal(excepts=["cfg", "logger", "cache"])
def make_test_data():
    # testデータ作成
    test_sessions = pd.read_pickle(cfg.prep_dir + f"test_sessions.pkl")
    trans_map_cache_file = f"trans_maps.pkl"
    trans_map_cache_path = cache.get_abspath(trans_map_cache_file)
    with open(trans_map_cache_path, "rb") as f:
        trans_maps = pickle.load(f)

    dfs =[]
    # 候補選出
    logger.info("[make_test] make_cand_df")
    cand_df = make_cand_df(test_sessions, trans_maps=trans_maps)
    cand_df = reduce_mem_usage(cand_df)
    # 特徴量付与
    logger.info("[make_test] add_features")
    test = add_features(test_sessions, cand_df)
    test = reduce_mem_usage(test)

    return test

# %%
@noglobal(excepts=["cfg", "logger"])
def inference(test, features):
    pred_dfs = []
    for type_ in ["clicks", "carts", "orders"]:
        pred_df_tmp = test[["session", "aid"]].copy()
        # 推論
        model = lgb.Booster(model_file = cfg.output_dir + f"{cfg.exp_name}/{type_}_model.lgb")

        # 2値分類の出力を元にk個選定
        pred_df_tmp["prob"] = model.predict(test[features], num_iteration=model.best_iteration)
        pred_df_tmp = pred_df_tmp.sort_values(["session", "prob"], ascending=(True, False))
        pred_df_tmp = pred_df_tmp.groupby(["session"]).head(cfg.k)
        pred_df_tmp["aid"] = pred_df_tmp["aid"].astype(str)
        pred_df_tmp = pred_df_tmp.groupby(["session"])["aid"].apply(list).reset_index()
        pred_df_tmp["aid"] = pred_df_tmp["aid"].apply(lambda x: ' '.join(x))
        pred_df_tmp["type"] = type_
        pred_dfs.append(pred_df_tmp)
    del test, model
    gc.collect()
    
    pred_df = pd.concat(pred_dfs)
    # sub作成
    sub = pd.read_csv(cfg.input_dir + f"sample_submission.csv", usecols=["session_type"])
    pred_df["session_type"] = pred_df["session"].astype(str) + "_" + pred_df["type"]
    pred_df = pred_df.rename(columns={"aid": "labels"})
    sub = sub.merge(pred_df[["session_type", "labels"]], on="session_type", how="left")
    sub.to_csv(cfg.output_dir + f"{cfg.exp_name}/{cfg.exp_name}_sub.csv", index=False)

# %%
@noglobal(excepts=["cfg", "logger", "cache"])
def main():
    scores = {}
    logger.info(f"START")
    line_notify.send(f"{cfg.exp_name} | START")
    
    # trans_map作成
    weeks = [None] + cfg.train_weeks + [cfg.valid_week]
    for week in weeks:
        if week is None:
            cache_file = "trans_maps.pkl"
        else:    
            cache_file = f"trans_maps_{week}.pkl"
        cache_path = cache.get_abspath(cache_file)
        if cache.exists(cache_path):
            logger.info(f"[{cache_file}] cache exists. load cache and skip process.")
            with open(cache_path, "rb") as f:
                trans_maps = pickle.load(f)
        else:
            trans_maps = get_trans_maps(week)
            with open(cache_path, "wb") as f:
                pickle.dump(trans_maps, f)

    for type_ in ["clicks", "carts", "orders"]:
        # train data作成
        logger.info(f"make {type_}_train_data")
        cache_file = f"{type_}_train.pkl"
        cache_path = cache.get_abspath(cache_file)
        if cache.exists(cache_path):
            logger.info(f"[{cache_file}] cache exists. read cache and skip process.")
            train = pd.read_pickle(cache_path)
        else:
            train = make_train_data(type_)
            train.to_pickle(cache_path)
        
        logger.info(f"make {type_}_valid_data")
        # valid cand作成
        cand_cache_path = cache.get_abspath("valid_cand.pkl")
        sessions_cache_path = cache.get_abspath("valid_sessions.pkl")
        labels_cache_path = cache.get_abspath("valid_labels.pkl")
        if cache.exists(cand_cache_path) & cache.exists(labels_cache_path) & cache.exists(sessions_cache_path):
            logger.info("[valid_cand.pkl] cache exists. read cache and skip process.")
            valid_cand = pd.read_pickle(cand_cache_path)
            valid_sessions = pd.read_pickle(sessions_cache_path)
            valid_labels = pd.read_pickle(labels_cache_path)
        else:
            valid_cand, valid_sessions, valid_labels = make_valid_cand()
            valid_cand.to_pickle(cand_cache_path)
            valid_sessions.to_pickle(sessions_cache_path)
            valid_labels.to_pickle(labels_cache_path)

        # valid data作成
        logger.info(f"make {type_}_valid_data")
        cache_file = f"{type_}_valid.pkl"
        cache_path = cache.get_abspath(cache_file)
        if cache.exists(cache_path):
            logger.info(f"[{cache_file}] cache exists. read cache and skip process.")
            valid = pd.read_pickle(cache_path)
        else:
            valid = make_valid_data(valid_cand, valid_sessions, valid_labels, type_)
            valid.to_pickle(cache_path)

        # モデル学習
        target = "labels"
        not_use_cols = ["session", "aid", target]
        features = [c for c in train.columns if c not in not_use_cols]

        scores[f"recall_{type_}"] = model_training(train, valid, features, target, valid_labels, type_)

        del train, valid, valid_labels
        gc.collect()
    
    scores["total"] = (float(scores["recall_clicks"]) * 0.1) + (float(scores["recall_carts"]) * 0.3) + (float(scores["recall_orders"]) * 0.6)
    report = f"\n{cfg.exp_name}\n"
    report += f'valid_end\n'
    report += str(scores)
    line_notify.send(report)

    # testデータ
    cache_path = cache.get_abspath("test.pkl")
    if cache.exists(cache_path):
        logger.info("cache exists. read cache and skip process.")
        test = pd.read_pickle(cache_path)
    else:
        test = make_test_data()
        test.to_pickle(cache_path)

    logger.info(f"-------- inference --------")
    inference(test, features)

    line_notify.send(f"{cfg.exp_name} | END!!")

# %%
try:
    main()
except Exception as e:
    logger.error(traceback.format_exc())
    line_notify.send(f"{cfg.exp_name} | ERROR!!\n{traceback.format_exc()}")
# Out:
# 0:00:00.835171 	 START
# 0:03:38.747860 	 make clicks_train_data
# /mnt/otto-recommender-system/output/exp040/cache/train_cand_week3.pkl
# 0:03:50.589916 	 [make_candidate] session_frequent : start
# 0:03:51.500219 	 [add_candidate] session_frequent : start
# 0:04:01.767896 	 [make_candidate] session_latest : start
# 0:04:03.004725 	 [add_candidate] session_latest : start
# 0:04:15.947253 	 [make_candidate] session_frequent_pair : start
# 0:04:17.604039 	 [add_candidate] session_frequent_pair : start
# 0:04:35.903762 	 [make_candidate] session_latest_pair0 : start
# 0:04:37.474069 	 [add_candidate] session_latest_pair0 : start
# 0:04:58.232678 	 [make_candidate] session_latest_pair1 : start
# 0:05:00.048169 	 [add_candidate] session_latest_pair1 : start
# 0:05:25.160768 	 [make_candidate] session_latest_pair2 : start
# 0:05:27.021749 	 [add_candidate] session_latest_pair2 : start
# 0:06:02.223546 	 [make_candidate] session_latest_pair3 : start
# 0:06:04.205291 	 [add_candidate] session_latest_pair3 : start
# 0:06:45.756612 	 [make_candidate] session_latest_pair4 : start
# 0:06:47.992326 	 [add_candidate] session_latest_pair4 : start
# 0:07:35.490266 	 [make_candidate] session_latest_pair5 : start
# 0:07:37.790345 	 [add_candidate] session_latest_pair5 : start
# 0:08:33.061663 	 [make_candidate] session_latest_pair6 : start
# 0:08:35.749434 	 [add_candidate] session_latest_pair6 : start
# 0:09:53.293725 	 [make_candidate] session_latest_pair7 : start
# 0:09:56.182265 	 [add_candidate] session_latest_pair7 : start
# 0:11:19.222464 	 [make_candidate] session_latest_pair8 : start
# 0:11:22.293489 	 [add_candidate] session_latest_pair8 : start
# 0:12:53.773145 	 [make_candidate] session_latest_pair9 : start
# 0:12:57.057759 	 [add_candidate] session_latest_pair9 : start
# 0:14:35.738400 	 [make_candidate] session_latest_time_wt_pair0 : start
# 0:14:39.458915 	 [add_candidate] session_latest_time_wt_pair0 : start
# 0:16:23.154572 	 [make_candidate] session_latest_time_wt_pair1 : start
# 0:16:27.009134 	 [add_candidate] session_latest_time_wt_pair1 : start
# 0:18:13.855078 	 [make_candidate] session_latest_time_wt_pair2 : start
# 0:18:17.739534 	 [add_candidate] session_latest_time_wt_pair2 : start
# 0:20:06.465873 	 [make_candidate] session_latest_time_wt_pair3 : start
# 0:20:10.498524 	 [add_candidate] session_latest_time_wt_pair3 : start
# 0:22:01.944436 	 [make_candidate] session_latest_time_wt_pair4 : start
# 0:22:06.229947 	 [add_candidate] session_latest_time_wt_pair4 : start
# 0:24:02.809893 	 [make_candidate] session_latest_time_wt_pair5 : start
# 0:24:07.191682 	 [add_candidate] session_latest_time_wt_pair5 : start
# 0:26:10.510497 	 [make_candidate] session_latest_time_wt_pair6 : start
# 0:26:14.375345 	 [add_candidate] session_latest_time_wt_pair6 : start
# 0:28:23.701811 	 [make_candidate] session_latest_time_wt_pair7 : start
# 0:28:28.484641 	 [add_candidate] session_latest_time_wt_pair7 : start
# 0:30:44.512761 	 [make_candidate] session_latest_time_wt_pair8 : start
# 0:30:49.023952 	 [add_candidate] session_latest_time_wt_pair8 : start
# 0:33:19.421613 	 [make_candidate] session_latest_time_wt_pair9 : start
# 0:33:24.794234 	 [add_candidate] session_latest_time_wt_pair9 : start
# 0:36:13.474237 	 [make_candidate] session_latest_type_wt_pair : start
# 0:36:19.434532 	 [add_candidate] session_latest_type_wt_pair : start
# 0:39:41.585575 	 [make_candidate] session_latest_clicks2carts_pair : start
# 0:39:48.156602 	 [add_candidate] session_latest_clicks2carts_pair : start
# 0:43:36.570496 	 [make_candidate] session_latest_clicks2orders_pair : start
# 0:43:42.873837 	 [add_candidate] session_latest_clicks2orders_pair : start
# Memory usage of dataframe is 42677.98 MB
# Memory usage after optimization is: 12509.06 MB
# Decreased by 70.7%
# 0:53:49.238695 	 [features] prep : start
# 0:53:49.594936 	 [features] session_cnt : start
# 0:53:57.555082 	 [features] session_aid_nunique : start
# 0:53:59.973980 	 [features] session_last_type : start
# 0:54:02.471984 	 [features] aid_cnt : start
# Memory usage of dataframe is 1092.23 MB
# Memory usage after optimization is: 506.48 MB
# Decreased by 53.6%
# 0:55:05.217819 	 make clicks_valid_data
# 0:55:18.668770 	 [make_candidate] session_frequent : start
# 0:55:18.893471 	 [add_candidate] session_frequent : start
# 0:55:19.004923 	 [make_candidate] session_latest : start
# 0:55:19.275092 	 [add_candidate] session_latest : start
# 0:55:19.398102 	 [make_candidate] session_frequent_pair : start
# 0:55:19.753775 	 [add_candidate] session_frequent_pair : start
# 0:55:19.922311 	 [make_candidate] session_latest_pair0 : start
# 0:55:20.298277 	 [add_candidate] session_latest_pair0 : start
# 0:55:20.495174 	 [make_candidate] session_latest_pair1 : start
# 0:55:20.867727 	 [add_candidate] session_latest_pair1 : start
# 0:55:21.151816 	 [make_candidate] session_latest_pair2 : start
# 0:55:21.530106 	 [add_candidate] session_latest_pair2 : start
# 0:55:21.888877 	 [make_candidate] session_latest_pair3 : start
# 0:55:22.252265 	 [add_candidate] session_latest_pair3 : start
# 0:55:22.724026 	 [make_candidate] session_latest_pair4 : start
# 0:55:23.111876 	 [add_candidate] session_latest_pair4 : start
# 0:55:23.791289 	 [make_candidate] session_latest_pair5 : start
# 0:55:24.194268 	 [add_candidate] session_latest_pair5 : start
# 0:55:24.989888 	 [make_candidate] session_latest_pair6 : start
# 0:55:25.364417 	 [add_candidate] session_latest_pair6 : start
# 0:55:26.225860 	 [make_candidate] session_latest_pair7 : start
# 0:55:26.603509 	 [add_candidate] session_latest_pair7 : start
# 0:55:27.579300 	 [make_candidate] session_latest_pair8 : start
# 0:55:27.916885 	 [add_candidate] session_latest_pair8 : start
# 0:55:29.080791 	 [make_candidate] session_latest_pair9 : start
# 0:55:29.440646 	 [add_candidate] session_latest_pair9 : start
# 0:55:30.615498 	 [make_candidate] session_latest_time_wt_pair0 : start
# 0:55:31.049299 	 [add_candidate] session_latest_time_wt_pair0 : start
# 0:55:32.363421 	 [make_candidate] session_latest_time_wt_pair1 : start
# 0:55:32.733298 	 [add_candidate] session_latest_time_wt_pair1 : start
# 0:55:34.054197 	 [make_candidate] session_latest_time_wt_pair2 : start
# 0:55:34.475997 	 [add_candidate] session_latest_time_wt_pair2 : start
# 0:55:36.164623 	 [make_candidate] session_latest_time_wt_pair3 : start
# 0:55:36.629302 	 [add_candidate] session_latest_time_wt_pair3 : start
# 0:55:38.336333 	 [make_candidate] session_latest_time_wt_pair4 : start
# 0:55:38.771011 	 [add_candidate] session_latest_time_wt_pair4 : start
# 0:55:40.494750 	 [make_candidate] session_latest_time_wt_pair5 : start
# 0:55:40.755233 	 [add_candidate] session_latest_time_wt_pair5 : start
# 0:55:42.545742 	 [make_candidate] session_latest_time_wt_pair6 : start
# 0:55:42.914604 	 [add_candidate] session_latest_time_wt_pair6 : start
# 0:55:44.764801 	 [make_candidate] session_latest_time_wt_pair7 : start
# 0:55:45.181182 	 [add_candidate] session_latest_time_wt_pair7 : start
# 0:55:47.117378 	 [make_candidate] session_latest_time_wt_pair8 : start
# 0:55:47.387302 	 [add_candidate] session_latest_time_wt_pair8 : start
# 0:55:49.447962 	 [make_candidate] session_latest_time_wt_pair9 : start
# 0:55:49.887246 	 [add_candidate] session_latest_time_wt_pair9 : start
# 0:55:52.198370 	 [make_candidate] session_latest_type_wt_pair : start
# 0:55:52.789124 	 [add_candidate] session_latest_type_wt_pair : start
# 0:55:55.226755 	 [make_candidate] session_latest_clicks2carts_pair : start
# 0:55:55.692960 	 [add_candidate] session_latest_clicks2carts_pair : start
# 0:55:58.179434 	 [make_candidate] session_latest_clicks2orders_pair : start
# 0:55:58.603427 	 [add_candidate] session_latest_clicks2orders_pair : start
# Memory usage of dataframe is 930.20 MB
# Memory usage after optimization is: 272.64 MB
# Decreased by 70.7%
# 0:56:05.015663 	 make clicks_valid_data
# 0:56:05.061077 	 [features] prep : start
# 0:56:05.073044 	 [features] session_cnt : start
# 0:56:07.226881 	 [features] session_aid_nunique : start
# 0:56:07.835701 	 [features] session_last_type : start
# 0:56:08.491143 	 [features] aid_cnt : start
# Memory usage of dataframe is 994.35 MB
# Memory usage after optimization is: 453.07 MB
# Decreased by 54.4%
# /home/kaggler/.local/lib/python3.8/site-packages/lightgbm/engine.py:181: UserWarning: 'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. Pass 'early_stopping()' callback via 'callbacks' argument instead.
#   _log_warning("'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. "
# /home/kaggler/.local/lib/python3.8/site-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# [LightGBM] [Info] Number of positive: 2309034, number of negative: 2309034
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.310745 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 4419
# [LightGBM] [Info] Number of data points in the train set: 4618068, number of used features: 49
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500000 -> initscore=0.000000
# Training until validation scores don't improve for 100 rounds
# [100]	training's binary_logloss: 0.387371	valid_1's binary_logloss: 0.378987
# [200]	training's binary_logloss: 0.385525	valid_1's binary_logloss: 0.377336
# [300]	training's binary_logloss: 0.384353	valid_1's binary_logloss: 0.376708
# [400]	training's binary_logloss: 0.383378	valid_1's binary_logloss: 0.376204
# [500]	training's binary_logloss: 0.38251	valid_1's binary_logloss: 0.375831
# [600]	training's binary_logloss: 0.381718	valid_1's binary_logloss: 0.375523
# [700]	training's binary_logloss: 0.380986	valid_1's binary_logloss: 0.375288
# [800]	training's binary_logloss: 0.380301	valid_1's binary_logloss: 0.375156
# [900]	training's binary_logloss: 0.379623	valid_1's binary_logloss: 0.374936
# [1000]	training's binary_logloss: 0.379005	valid_1's binary_logloss: 0.374784
# [1100]	training's binary_logloss: 0.378352	valid_1's binary_logloss: 0.374554
# [1200]	training's binary_logloss: 0.377752	valid_1's binary_logloss: 0.374449
# [1300]	training's binary_logloss: 0.377187	valid_1's binary_logloss: 0.374347
# [1400]	training's binary_logloss: 0.376629	valid_1's binary_logloss: 0.374208
# [1500]	training's binary_logloss: 0.376084	valid_1's binary_logloss: 0.374139
# [1600]	training's binary_logloss: 0.375581	valid_1's binary_logloss: 0.374125
# [1700]	training's binary_logloss: 0.375068	valid_1's binary_logloss: 0.374066
# [1800]	training's binary_logloss: 0.374584	valid_1's binary_logloss: 0.374042
# [1900]	training's binary_logloss: 0.374129	valid_1's binary_logloss: 0.37402
# [2000]	training's binary_logloss: 0.373633	valid_1's binary_logloss: 0.373959
# [2100]	training's binary_logloss: 0.373184	valid_1's binary_logloss: 0.373953
# [2200]	training's binary_logloss: 0.372713	valid_1's binary_logloss: 0.373913
# [2300]	training's binary_logloss: 0.372262	valid_1's binary_logloss: 0.373903
# Early stopping, best iteration is:
# [2287]	training's binary_logloss: 0.372322	valid_1's binary_logloss: 0.373895
# 1:00:01.359597 	 clicks valid score
# 1:00:01.360911 	 {'num_clicks': 97136, 'hit_clicks': 46476, 'num_carts': 43211, 'hit_carts': 14309, 'num_orders': 20082, 'hit_orders': 11179, 'recall_clicks': '0.478', 'recall_carts': '0.331', 'recall_orders': '0.557', 'w_recall_clicks': '0.048', 'w_recall_carts': '0.099', 'w_recall_orders': '0.334', 'score': '0.481'}
# 1:00:02.142307 	 make carts_train_data
# /mnt/otto-recommender-system/output/exp040/cache/train_cand_week3.pkl
# 1:00:13.264202 	 [make_candidate] session_frequent : start
# 1:00:14.135167 	 [add_candidate] session_frequent : start
# 1:00:24.060167 	 [make_candidate] session_latest : start
# 1:00:25.463142 	 [add_candidate] session_latest : start
# 1:00:37.567225 	 [make_candidate] session_frequent_pair : start
# 1:00:39.039942 	 [add_candidate] session_frequent_pair : start
# 1:00:57.594353 	 [make_candidate] session_latest_pair0 : start
# 1:00:59.290600 	 [add_candidate] session_latest_pair0 : start
# 1:01:20.286908 	 [make_candidate] session_latest_pair1 : start
# 1:01:22.091805 	 [add_candidate] session_latest_pair1 : start
# 1:01:47.145829 	 [make_candidate] session_latest_pair2 : start
# 1:01:49.058103 	 [add_candidate] session_latest_pair2 : start
# 1:02:24.281018 	 [make_candidate] session_latest_pair3 : start
# 1:02:26.224173 	 [add_candidate] session_latest_pair3 : start
# 1:03:07.126501 	 [make_candidate] session_latest_pair4 : start
# 1:03:09.252962 	 [add_candidate] session_latest_pair4 : start
# 1:03:57.278413 	 [make_candidate] session_latest_pair5 : start
# 1:03:59.603292 	 [add_candidate] session_latest_pair5 : start
# 1:04:53.204279 	 [make_candidate] session_latest_pair6 : start
# 1:04:55.797630 	 [add_candidate] session_latest_pair6 : start
# 1:06:10.409714 	 [make_candidate] session_latest_pair7 : start
# 1:06:13.162726 	 [add_candidate] session_latest_pair7 : start
# 1:07:34.605929 	 [make_candidate] session_latest_pair8 : start
# 1:07:37.535971 	 [add_candidate] session_latest_pair8 : start
# 1:09:05.039428 	 [make_candidate] session_latest_pair9 : start
# 1:09:08.520275 	 [add_candidate] session_latest_pair9 : start
# 1:10:44.162948 	 [make_candidate] session_latest_time_wt_pair0 : start
# 1:10:47.893142 	 [add_candidate] session_latest_time_wt_pair0 : start
# 1:12:27.395426 	 [make_candidate] session_latest_time_wt_pair1 : start
# 1:12:31.282473 	 [add_candidate] session_latest_time_wt_pair1 : start
# 1:14:13.256609 	 [make_candidate] session_latest_time_wt_pair2 : start
# 1:14:17.170812 	 [add_candidate] session_latest_time_wt_pair2 : start
# 1:16:02.314732 	 [make_candidate] session_latest_time_wt_pair3 : start
# 1:16:06.522611 	 [add_candidate] session_latest_time_wt_pair3 : start
# 1:17:55.164209 	 [make_candidate] session_latest_time_wt_pair4 : start
# 1:17:58.500657 	 [add_candidate] session_latest_time_wt_pair4 : start
# 1:19:51.765781 	 [make_candidate] session_latest_time_wt_pair5 : start
# 1:19:56.259605 	 [add_candidate] session_latest_time_wt_pair5 : start
# 1:21:52.200050 	 [make_candidate] session_latest_time_wt_pair6 : start
# 1:21:56.960541 	 [add_candidate] session_latest_time_wt_pair6 : start
# 1:23:58.493601 	 [make_candidate] session_latest_time_wt_pair7 : start
# 1:24:03.358696 	 [add_candidate] session_latest_time_wt_pair7 : start
# 1:26:13.195181 	 [make_candidate] session_latest_time_wt_pair8 : start
# 1:26:18.312302 	 [add_candidate] session_latest_time_wt_pair8 : start
# 1:28:34.926442 	 [make_candidate] session_latest_time_wt_pair9 : start
# 1:28:39.861913 	 [add_candidate] session_latest_time_wt_pair9 : start
# 1:31:25.121290 	 [make_candidate] session_latest_type_wt_pair : start
# 1:31:31.351976 	 [add_candidate] session_latest_type_wt_pair : start
# 1:34:48.594359 	 [make_candidate] session_latest_clicks2carts_pair : start
# 1:34:55.606143 	 [add_candidate] session_latest_clicks2carts_pair : start
# 1:38:38.547631 	 [make_candidate] session_latest_clicks2orders_pair : start
# 1:38:41.191430 	 [add_candidate] session_latest_clicks2orders_pair : start
# Memory usage of dataframe is 42677.98 MB
# Memory usage after optimization is: 12509.06 MB
# Decreased by 70.7%
# 1:49:02.029358 	 [features] prep : start
# 1:49:02.260866 	 [features] session_cnt : start
# 1:49:06.743659 	 [features] session_aid_nunique : start
# 1:49:08.385836 	 [features] session_last_type : start
# 1:49:10.167264 	 [features] aid_cnt : start
# Memory usage of dataframe is 365.84 MB
# 1:50:21.934852 	 make carts_valid_data
# Memory usage after optimization is: 177.87 MB
# Decreased by 51.4%
# 1:50:34.494277 	 [make_candidate] session_frequent : start
# 1:50:34.709183 	 [add_candidate] session_frequent : start
# 1:50:34.822533 	 [make_candidate] session_latest : start
# 1:50:35.125467 	 [add_candidate] session_latest : start
# 1:50:35.252274 	 [make_candidate] session_frequent_pair : start
# 1:50:35.536688 	 [add_candidate] session_frequent_pair : start
# 1:50:35.720384 	 [make_candidate] session_latest_pair0 : start
# 1:50:36.023645 	 [add_candidate] session_latest_pair0 : start
# 1:50:36.217514 	 [make_candidate] session_latest_pair1 : start
# 1:50:36.507064 	 [add_candidate] session_latest_pair1 : start
# 1:50:36.752174 	 [make_candidate] session_latest_pair2 : start
# 1:50:37.044482 	 [add_candidate] session_latest_pair2 : start
# 1:50:37.351221 	 [make_candidate] session_latest_pair3 : start
# 1:50:37.656617 	 [add_candidate] session_latest_pair3 : start
# 1:50:38.064352 	 [make_candidate] session_latest_pair4 : start
# 1:50:38.373618 	 [add_candidate] session_latest_pair4 : start
# 1:50:38.988607 	 [make_candidate] session_latest_pair5 : start
# 1:50:39.309118 	 [add_candidate] session_latest_pair5 : start
# 1:50:40.061791 	 [make_candidate] session_latest_pair6 : start
# 1:50:40.436976 	 [add_candidate] session_latest_pair6 : start
# 1:50:41.346658 	 [make_candidate] session_latest_pair7 : start
# 1:50:41.724092 	 [add_candidate] session_latest_pair7 : start
# 1:50:42.723237 	 [make_candidate] session_latest_pair8 : start
# 1:50:43.164728 	 [add_candidate] session_latest_pair8 : start
# 1:50:44.255002 	 [make_candidate] session_latest_pair9 : start
# 1:50:44.616127 	 [add_candidate] session_latest_pair9 : start
# 1:50:45.824427 	 [make_candidate] session_latest_time_wt_pair0 : start
# 1:50:46.243053 	 [add_candidate] session_latest_time_wt_pair0 : start
# 1:50:47.519818 	 [make_candidate] session_latest_time_wt_pair1 : start
# 1:50:47.975204 	 [add_candidate] session_latest_time_wt_pair1 : start
# 1:50:49.297252 	 [make_candidate] session_latest_time_wt_pair2 : start
# 1:50:49.666120 	 [add_candidate] session_latest_time_wt_pair2 : start
# 1:50:51.272226 	 [make_candidate] session_latest_time_wt_pair3 : start
# 1:50:51.759166 	 [add_candidate] session_latest_time_wt_pair3 : start
# 1:50:53.480873 	 [make_candidate] session_latest_time_wt_pair4 : start
# 1:50:53.861480 	 [add_candidate] session_latest_time_wt_pair4 : start
# 1:50:55.567630 	 [make_candidate] session_latest_time_wt_pair5 : start
# 1:50:55.835044 	 [add_candidate] session_latest_time_wt_pair5 : start
# 1:50:57.694571 	 [make_candidate] session_latest_time_wt_pair6 : start
# 1:50:58.046326 	 [add_candidate] session_latest_time_wt_pair6 : start
# 1:50:59.955909 	 [make_candidate] session_latest_time_wt_pair7 : start
# 1:51:00.439851 	 [add_candidate] session_latest_time_wt_pair7 : start
# 1:51:02.380997 	 [make_candidate] session_latest_time_wt_pair8 : start
# 1:51:02.824085 	 [add_candidate] session_latest_time_wt_pair8 : start
# 1:51:04.875707 	 [make_candidate] session_latest_time_wt_pair9 : start
# 1:51:05.119901 	 [add_candidate] session_latest_time_wt_pair9 : start
# 1:51:07.259427 	 [make_candidate] session_latest_type_wt_pair : start
# 1:51:07.665351 	 [add_candidate] session_latest_type_wt_pair : start
# 1:51:09.965215 	 [make_candidate] session_latest_clicks2carts_pair : start
# 1:51:10.426347 	 [add_candidate] session_latest_clicks2carts_pair : start
# 1:51:12.895576 	 [make_candidate] session_latest_clicks2orders_pair : start
# 1:51:13.267704 	 [add_candidate] session_latest_clicks2orders_pair : start
# Memory usage of dataframe is 930.20 MB
# Memory usage after optimization is: 272.64 MB
# Decreased by 70.7%
# 1:51:19.792961 	 make carts_valid_data
# 1:51:19.840010 	 [features] prep : start
# 1:51:19.856021 	 [features] session_cnt : start
# 1:51:24.165018 	 [features] session_aid_nunique : start
# 1:51:24.695596 	 [features] session_last_type : start
# 1:51:25.308155 	 [features] aid_cnt : start
# Memory usage of dataframe is 1010.39 MB
# Memory usage after optimization is: 473.67 MB
# Decreased by 53.1%
# /home/kaggler/.local/lib/python3.8/site-packages/lightgbm/engine.py:181: UserWarning: 'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. Pass 'early_stopping()' callback via 'callbacks' argument instead.
#   _log_warning("'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. "
# /home/kaggler/.local/lib/python3.8/site-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# [LightGBM] [Info] Number of positive: 761126, number of negative: 761126
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.067965 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 4519
# [LightGBM] [Info] Number of data points in the train set: 1522252, number of used features: 49
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500000 -> initscore=0.000000
# Training until validation scores don't improve for 100 rounds
# [100]	training's binary_logloss: 0.379935	valid_1's binary_logloss: 0.369667
# [200]	training's binary_logloss: 0.375541	valid_1's binary_logloss: 0.366445
# [300]	training's binary_logloss: 0.373336	valid_1's binary_logloss: 0.365856
# [400]	training's binary_logloss: 0.371413	valid_1's binary_logloss: 0.36545
# [500]	training's binary_logloss: 0.369594	valid_1's binary_logloss: 0.365083
# [600]	training's binary_logloss: 0.367869	valid_1's binary_logloss: 0.364928
# [700]	training's binary_logloss: 0.366265	valid_1's binary_logloss: 0.364711
# [800]	training's binary_logloss: 0.364788	valid_1's binary_logloss: 0.364628
# [900]	training's binary_logloss: 0.363357	valid_1's binary_logloss: 0.364596
# Early stopping, best iteration is:
# [813]	training's binary_logloss: 0.364599	valid_1's binary_logloss: 0.364586
# 1:52:44.790956 	 carts valid score
# 1:52:44.792179 	 {'num_clicks': 97136, 'hit_clicks': 45597, 'num_carts': 43211, 'hit_carts': 14626, 'num_orders': 20082, 'hit_orders': 11470, 'recall_clicks': '0.469', 'recall_carts': '0.338', 'recall_orders': '0.571', 'w_recall_clicks': '0.047', 'w_recall_carts': '0.102', 'w_recall_orders': '0.343', 'score': '0.491'}
# 1:52:45.407382 	 make orders_train_data
# /mnt/otto-recommender-system/output/exp040/cache/train_cand_week3.pkl
# 1:52:56.605232 	 [make_candidate] session_frequent : start
# 1:52:57.475339 	 [add_candidate] session_frequent : start
# 1:53:07.561688 	 [make_candidate] session_latest : start
# 1:53:08.879720 	 [add_candidate] session_latest : start
# 1:53:21.242441 	 [make_candidate] session_frequent_pair : start
# 1:53:22.757742 	 [add_candidate] session_frequent_pair : start
# 1:53:41.565040 	 [make_candidate] session_latest_pair0 : start
# 1:53:43.238333 	 [add_candidate] session_latest_pair0 : start
# 1:54:04.350543 	 [make_candidate] session_latest_pair1 : start
# 1:54:06.182023 	 [add_candidate] session_latest_pair1 : start
# 1:54:31.126327 	 [make_candidate] session_latest_pair2 : start
# 1:54:33.028271 	 [add_candidate] session_latest_pair2 : start
# 1:55:09.615967 	 [make_candidate] session_latest_pair3 : start
# 1:55:11.590333 	 [add_candidate] session_latest_pair3 : start
# 1:55:53.275548 	 [make_candidate] session_latest_pair4 : start
# 1:55:55.386533 	 [add_candidate] session_latest_pair4 : start
# 1:56:44.057077 	 [make_candidate] session_latest_pair5 : start
# 1:56:46.333146 	 [add_candidate] session_latest_pair5 : start
# 1:57:41.759911 	 [make_candidate] session_latest_pair6 : start
# 1:57:44.308961 	 [add_candidate] session_latest_pair6 : start
# 1:59:01.309475 	 [make_candidate] session_latest_pair7 : start
# 1:59:04.052790 	 [add_candidate] session_latest_pair7 : start
# 2:00:27.972580 	 [make_candidate] session_latest_pair8 : start
# 2:00:31.101302 	 [add_candidate] session_latest_pair8 : start
# 2:02:01.745519 	 [make_candidate] session_latest_pair9 : start
# 2:02:05.006651 	 [add_candidate] session_latest_pair9 : start
# 2:03:44.815026 	 [make_candidate] session_latest_time_wt_pair0 : start
# 2:03:48.406940 	 [add_candidate] session_latest_time_wt_pair0 : start
# 2:05:31.839835 	 [make_candidate] session_latest_time_wt_pair1 : start
# 2:05:35.754688 	 [add_candidate] session_latest_time_wt_pair1 : start
# 2:07:21.799904 	 [make_candidate] session_latest_time_wt_pair2 : start
# 2:07:25.728216 	 [add_candidate] session_latest_time_wt_pair2 : start
# 2:09:15.084564 	 [make_candidate] session_latest_time_wt_pair3 : start
# 2:09:19.188190 	 [add_candidate] session_latest_time_wt_pair3 : start
# 2:11:14.091074 	 [make_candidate] session_latest_time_wt_pair4 : start
# 2:11:17.779924 	 [add_candidate] session_latest_time_wt_pair4 : start
# 2:13:15.178082 	 [make_candidate] session_latest_time_wt_pair5 : start
# 2:13:19.583565 	 [add_candidate] session_latest_time_wt_pair5 : start
# 2:15:27.034547 	 [make_candidate] session_latest_time_wt_pair6 : start
# 2:15:31.846875 	 [add_candidate] session_latest_time_wt_pair6 : start
# 2:17:42.222814 	 [make_candidate] session_latest_time_wt_pair7 : start
# 2:17:47.047238 	 [add_candidate] session_latest_time_wt_pair7 : start
# 2:20:00.678023 	 [make_candidate] session_latest_time_wt_pair8 : start
# 2:20:05.859565 	 [add_candidate] session_latest_time_wt_pair8 : start
# 2:22:29.046588 	 [make_candidate] session_latest_time_wt_pair9 : start
# 2:22:34.230085 	 [add_candidate] session_latest_time_wt_pair9 : start
# 2:25:12.843098 	 [make_candidate] session_latest_type_wt_pair : start
# 2:25:19.996918 	 [add_candidate] session_latest_type_wt_pair : start
# 2:28:47.959301 	 [make_candidate] session_latest_clicks2carts_pair : start
# 2:28:55.799274 	 [add_candidate] session_latest_clicks2carts_pair : start
# 2:32:41.712307 	 [make_candidate] session_latest_clicks2orders_pair : start
# 2:32:49.400105 	 [add_candidate] session_latest_clicks2orders_pair : start
# Memory usage of dataframe is 42677.98 MB
# Memory usage after optimization is: 12509.06 MB
# Decreased by 70.7%
# 2:43:08.423570 	 [features] prep : start
# 2:43:08.671588 	 [features] session_cnt : start
# 2:43:14.401915 	 [features] session_aid_nunique : start
# 2:43:15.890445 	 [features] session_last_type : start
# 2:43:17.443313 	 [features] aid_cnt : start
# Memory usage of dataframe is 272.74 MB
# 2:44:27.087472 	 make orders_valid_data
# Memory usage after optimization is: 134.97 MB
# Decreased by 50.5%
# 2:44:39.754933 	 [make_candidate] session_frequent : start
# 2:44:39.990637 	 [add_candidate] session_frequent : start
# 2:44:40.124360 	 [make_candidate] session_latest : start
# 2:44:40.324261 	 [add_candidate] session_latest : start
# 2:44:40.457218 	 [make_candidate] session_frequent_pair : start
# 2:44:40.792526 	 [add_candidate] session_frequent_pair : start
# 2:44:40.980538 	 [make_candidate] session_latest_pair0 : start
# 2:44:41.359583 	 [add_candidate] session_latest_pair0 : start
# 2:44:41.564169 	 [make_candidate] session_latest_pair1 : start
# 2:44:41.924498 	 [add_candidate] session_latest_pair1 : start
# 2:44:42.181809 	 [make_candidate] session_latest_pair2 : start
# 2:44:42.525340 	 [add_candidate] session_latest_pair2 : start
# 2:44:42.867435 	 [make_candidate] session_latest_pair3 : start
# 2:44:43.169891 	 [add_candidate] session_latest_pair3 : start
# 2:44:43.578493 	 [make_candidate] session_latest_pair4 : start
# 2:44:43.871231 	 [add_candidate] session_latest_pair4 : start
# 2:44:44.513886 	 [make_candidate] session_latest_pair5 : start
# 2:44:44.847619 	 [add_candidate] session_latest_pair5 : start
# 2:44:45.611081 	 [make_candidate] session_latest_pair6 : start
# 2:44:45.981067 	 [add_candidate] session_latest_pair6 : start
# 2:44:46.862483 	 [make_candidate] session_latest_pair7 : start
# 2:44:47.263181 	 [add_candidate] session_latest_pair7 : start
# 2:44:48.237139 	 [make_candidate] session_latest_pair8 : start
# 2:44:48.621581 	 [add_candidate] session_latest_pair8 : start
# 2:44:49.766488 	 [make_candidate] session_latest_pair9 : start
# 2:44:50.117513 	 [add_candidate] session_latest_pair9 : start
# 2:44:51.378999 	 [make_candidate] session_latest_time_wt_pair0 : start
# 2:44:51.757848 	 [add_candidate] session_latest_time_wt_pair0 : start
# 2:44:53.045606 	 [make_candidate] session_latest_time_wt_pair1 : start
# 2:44:53.361280 	 [add_candidate] session_latest_time_wt_pair1 : start
# 2:44:54.709004 	 [make_candidate] session_latest_time_wt_pair2 : start
# 2:44:55.132895 	 [add_candidate] session_latest_time_wt_pair2 : start
# 2:44:56.761472 	 [make_candidate] session_latest_time_wt_pair3 : start
# 2:44:57.177286 	 [add_candidate] session_latest_time_wt_pair3 : start
# 2:44:58.857934 	 [make_candidate] session_latest_time_wt_pair4 : start
# 2:44:59.125093 	 [add_candidate] session_latest_time_wt_pair4 : start
# 2:45:00.870897 	 [make_candidate] session_latest_time_wt_pair5 : start
# 2:45:01.250269 	 [add_candidate] session_latest_time_wt_pair5 : start
# 2:45:03.071596 	 [make_candidate] session_latest_time_wt_pair6 : start
# 2:45:03.563498 	 [add_candidate] session_latest_time_wt_pair6 : start
# 2:45:05.466593 	 [make_candidate] session_latest_time_wt_pair7 : start
# 2:45:05.724558 	 [add_candidate] session_latest_time_wt_pair7 : start
# 2:45:07.721200 	 [make_candidate] session_latest_time_wt_pair8 : start
# 2:45:08.077869 	 [add_candidate] session_latest_time_wt_pair8 : start
# 2:45:10.194553 	 [make_candidate] session_latest_time_wt_pair9 : start
# 2:45:10.627300 	 [add_candidate] session_latest_time_wt_pair9 : start
# 2:45:12.836618 	 [make_candidate] session_latest_type_wt_pair : start
# 2:45:13.377115 	 [add_candidate] session_latest_type_wt_pair : start
# 2:45:15.616224 	 [make_candidate] session_latest_clicks2carts_pair : start
# 2:45:15.891543 	 [add_candidate] session_latest_clicks2carts_pair : start
# 2:45:18.405518 	 [make_candidate] session_latest_clicks2orders_pair : start
# 2:45:18.852535 	 [add_candidate] session_latest_clicks2orders_pair : start
# Memory usage of dataframe is 930.20 MB
# Memory usage after optimization is: 272.64 MB
# Decreased by 70.7%
# 2:45:25.319599 	 make orders_valid_data
# 2:45:25.367096 	 [features] prep : start
# 2:45:25.380661 	 [features] session_cnt : start
# 2:45:28.990811 	 [features] session_aid_nunique : start
# 2:45:29.739106 	 [features] session_last_type : start
# 2:45:30.379977 	 [features] aid_cnt : start
# Memory usage of dataframe is 1010.39 MB
# Memory usage after optimization is: 473.67 MB
# Decreased by 53.1%
# /home/kaggler/.local/lib/python3.8/site-packages/lightgbm/engine.py:181: UserWarning: 'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. Pass 'early_stopping()' callback via 'callbacks' argument instead.
#   _log_warning("'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. "
# /home/kaggler/.local/lib/python3.8/site-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# [LightGBM] [Info] Number of positive: 567444, number of negative: 567444
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.053069 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 4522
# [LightGBM] [Info] Number of data points in the train set: 1134888, number of used features: 49
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500000 -> initscore=0.000000
# Training until validation scores don't improve for 100 rounds
# [100]	training's binary_logloss: 0.235557	valid_1's binary_logloss: 0.219675
# [200]	training's binary_logloss: 0.231312	valid_1's binary_logloss: 0.21798
# [300]	training's binary_logloss: 0.228737	valid_1's binary_logloss: 0.217732
# [400]	training's binary_logloss: 0.226564	valid_1's binary_logloss: 0.217687
# Early stopping, best iteration is:
# [367]	training's binary_logloss: 0.227251	valid_1's binary_logloss: 0.217671
# 2:46:29.236167 	 orders valid score
# 2:46:29.237472 	 {'num_clicks': 97136, 'hit_clicks': 44417, 'num_carts': 43211, 'hit_carts': 14285, 'num_orders': 20082, 'hit_orders': 11519, 'recall_clicks': '0.457', 'recall_carts': '0.331', 'recall_orders': '0.574', 'w_recall_clicks': '0.046', 'w_recall_carts': '0.099', 'w_recall_orders': '0.344', 'score': '0.489'}
# 2:46:36.825740 	 [make_test] make_cand_df
# 2:46:37.192826 	 [make_candidate] session_frequent : start
# 2:46:37.794195 	 [add_candidate] session_frequent : start
# 2:46:40.017590 	 [make_candidate] session_latest : start
# 2:46:40.507470 	 [add_candidate] session_latest : start
# 2:46:43.310760 	 [make_candidate] session_frequent_pair : start
# 2:46:44.144378 	 [add_candidate] session_frequent_pair : start
# 2:46:48.470404 	 [make_candidate] session_latest_pair0 : start
# 2:46:49.271151 	 [add_candidate] session_latest_pair0 : start
# 2:46:54.050003 	 [make_candidate] session_latest_pair1 : start
# 2:46:54.872902 	 [add_candidate] session_latest_pair1 : start
# 2:47:00.647794 	 [make_candidate] session_latest_pair2 : start
# 2:47:01.476932 	 [add_candidate] session_latest_pair2 : start
# 2:47:09.863689 	 [make_candidate] session_latest_pair3 : start
# 2:47:10.866265 	 [add_candidate] session_latest_pair3 : start
# 2:47:20.476634 	 [make_candidate] session_latest_pair4 : start
# 2:47:21.486813 	 [add_candidate] session_latest_pair4 : start
# 2:47:33.277527 	 [make_candidate] session_latest_pair5 : start
# 2:47:34.278929 	 [add_candidate] session_latest_pair5 : start
# 2:47:50.462459 	 [make_candidate] session_latest_pair6 : start
# 2:47:51.642389 	 [add_candidate] session_latest_pair6 : start
# 2:48:08.810169 	 [make_candidate] session_latest_pair7 : start
# 2:48:10.014772 	 [add_candidate] session_latest_pair7 : start
# 2:48:29.646866 	 [make_candidate] session_latest_pair8 : start
# 2:48:30.830360 	 [add_candidate] session_latest_pair8 : start
# 2:48:52.070529 	 [make_candidate] session_latest_pair9 : start
# 2:48:53.399395 	 [add_candidate] session_latest_pair9 : start
# 2:49:16.325495 	 [make_candidate] session_latest_time_wt_pair0 : start
# 2:49:17.683556 	 [add_candidate] session_latest_time_wt_pair0 : start
# 2:49:41.523094 	 [make_candidate] session_latest_time_wt_pair1 : start
# 2:49:42.998395 	 [add_candidate] session_latest_time_wt_pair1 : start
# 2:50:07.599992 	 [make_candidate] session_latest_time_wt_pair2 : start
# 2:50:08.869959 	 [add_candidate] session_latest_time_wt_pair2 : start
# 2:50:34.301060 	 [make_candidate] session_latest_time_wt_pair3 : start
# 2:50:35.778078 	 [add_candidate] session_latest_time_wt_pair3 : start
# 2:51:02.312196 	 [make_candidate] session_latest_time_wt_pair4 : start
# 2:51:03.720128 	 [add_candidate] session_latest_time_wt_pair4 : start
# 2:51:31.573462 	 [make_candidate] session_latest_time_wt_pair5 : start
# 2:51:32.998511 	 [add_candidate] session_latest_time_wt_pair5 : start
# 2:52:01.787743 	 [make_candidate] session_latest_time_wt_pair6 : start
# 2:52:03.396328 	 [add_candidate] session_latest_time_wt_pair6 : start
# 2:52:33.052482 	 [make_candidate] session_latest_time_wt_pair7 : start
# 2:52:34.663278 	 [add_candidate] session_latest_time_wt_pair7 : start
# 2:53:05.690739 	 [make_candidate] session_latest_time_wt_pair8 : start
# 2:53:07.221920 	 [add_candidate] session_latest_time_wt_pair8 : start
# 2:53:40.115063 	 [make_candidate] session_latest_time_wt_pair9 : start
# 2:53:41.934757 	 [add_candidate] session_latest_time_wt_pair9 : start
# 2:54:21.942157 	 [make_candidate] session_latest_type_wt_pair : start
# 2:54:23.770059 	 [add_candidate] session_latest_type_wt_pair : start
# 2:55:04.570865 	 [make_candidate] session_latest_clicks2carts_pair : start
# 2:55:06.298239 	 [add_candidate] session_latest_clicks2carts_pair : start
# 2:55:47.923032 	 [make_candidate] session_latest_clicks2orders_pair : start
# 2:55:49.882540 	 [add_candidate] session_latest_clicks2orders_pair : start
# Memory usage of dataframe is 12280.14 MB
# 2:57:17.473379 	 [make_test] add_features
# Memory usage after optimization is: 3599.35 MB
# Decreased by 70.7%
# 2:57:17.791065 	 [features] prep : start
# 2:57:17.912108 	 [features] session_cnt : start
# 2:57:53.502024 	 [features] session_aid_nunique : start
# 2:58:03.633948 	 [features] session_last_type : start
# 2:58:13.955721 	 [features] aid_cnt : start
# Memory usage of dataframe is 13127.05 MB
# Memory usage after optimization is: 6510.59 MB
# Decreased by 50.4%
# 3:01:02.078964 	 -------- inference --------
