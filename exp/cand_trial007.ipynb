# %% [markdown]
# # cand_trial007

# %%
import os
import sys
import traceback
import gc
import random
import pickle
import pathlib
import subprocess
from dataclasses import dataclass
from dotenv import load_dotenv
load_dotenv
sys.path.append(os.getenv('UTILS_PATH'))
from tqdm import tqdm
import multiprocessing
import inspect

import pandas as pd
import numpy as np
import itertools
import cudf
import lightgbm as lgb
import matplotlib.pyplot as plt
import seaborn as sns
import line_notify
import my_logger
from noglobal import noglobal
import optuna

# %% [markdown]
# # 設定

# %%
@dataclass
class Cfg:
    loglevel = "INFO"
    exp_name = "cand_trial007"
    seed = 42
    k = 20
    cand_n = 15
    type2id = {"clicks":0, "carts":1, "orders":2}
    id2type = {0:"clicks", 1:"carts", 2:"orders"}
    train_weeks = ["week3"]
    valid_week = "week4"
    valid_session_n = 100_000
    input_dir = os.getenv('INPUT_DIR')
    output_dir = os.getenv('OUTPUT_DIR')
    prep_dir = os.getenv("PREP_DIR")

cfg = Cfg()
os.makedirs(os.path.join(cfg.output_dir, cfg.exp_name), exist_ok=True)
os.makedirs(os.path.join(cfg.output_dir, cfg.exp_name, "cache"), exist_ok=True)
random.seed(cfg.seed)

# %%
class Cache:
    @noglobal(excepts=["cfg", "logger"])
    def __init__(self):
        self.cache_dir = (os.path.join(cfg.output_dir, cfg.exp_name, "cache"))
        self.cache_dir_path = pathlib.Path(self.cache_dir)
        self.caches = list(self.cache_dir_path.glob("*.pkl"))

    @noglobal(excepts=["cfg", "logger"])
    def get_abspath(self, filename):
        return (os.path.join(self.cache_dir, f"{cfg.exp_name}_{filename}"))
    
    @noglobal(excepts=["cfg", "logger"])
    def exists(self, path):
        return len([str(c) for c in self.caches if path == str(c)]) > 0

# %%
logger = my_logger.init_logger(cfg.exp_name)
cache = Cache()

# %%
@noglobal(excepts=["cfg", "logger"])
def evaluate(clicks_labels, carts_labels, orders_labels, 
             clicks_preds, carts_preds, orders_preds, k=20):

    num_clicks = 0
    num_carts = 0
    num_orders = 0
    hit_clicks = 0
    hit_carts = 0
    hit_orders = 0

    for i in range(len(clicks_labels)):
        clicks_label = clicks_labels[i]
        carts_label = carts_labels[i]
        orders_label = orders_labels[i]
        clicks_pred = clicks_preds[i]
        carts_pred = carts_preds[i]
        orders_pred = orders_preds[i]

        if type(clicks_pred) == list:
            clicks_pred = clicks_pred[:k]
        else:
            clicks_pred = []
        if type(carts_pred) == list:
            carts_pred = carts_pred[:k]
        else:
            carts_pred = []    
        if type(orders_pred) == list:
            orders_pred = orders_pred[:k]
        else:
            orders_pred = []

        if not np.isnan(clicks_label):
            num_clicks += 1
            hit_clicks += int(clicks_label in clicks_pred)

        if type(carts_label) == list:
            num_carts += min(len(carts_label), k)
            hit_carts += len(set(carts_pred) & set(carts_label))
            
        if type(orders_label) == list:
            num_orders += min(len(orders_label), k)
            hit_orders += len(set(orders_pred) & set(orders_label))


    recall_clicks = hit_clicks / num_clicks
    recall_carts = hit_carts / num_carts
    recall_orders = hit_orders / num_orders
    w_recall_clicks = recall_clicks * 0.10
    w_recall_carts = recall_carts * 0.30
    w_recall_orders = recall_orders * 0.60
    score = w_recall_clicks + w_recall_carts + w_recall_orders

    results = {}
    results["num_clicks"] = num_clicks
    results["hit_clicks"] = hit_clicks
    results["num_carts"] = num_carts
    results["hit_carts"] = hit_carts
    results["num_orders"] = num_orders
    results["hit_orders"] = hit_orders
    results["recall_clicks"] = format(recall_clicks, ".3f")
    results["recall_carts"] = format(recall_carts, ".3f")
    results["recall_orders"] = format(recall_orders, ".3f")
    results["w_recall_clicks"] = format(w_recall_clicks, ".3f")
    results["w_recall_carts"] = format(w_recall_carts, ".3f")
    results["w_recall_orders"] = format(w_recall_orders, ".3f")
    results["score"] = format(score, ".3f")

    return results

# %%
class Candidate:
    @noglobal(excepts=["cfg", "logger"])
    def __init__(self, pdf, week, labels=None):
        self.df = cudf.from_pandas(pdf)
        self.target_sessions = pdf["session"].unique().tolist()
        self.results = pd.DataFrame(columns=["name", "num_clicks", "hit_clicks", "num_carts", "hit_carts", "num_orders", "hit_orders", 
                                             "recall_clicks", "recall_carts", "recall_orders", "w_recall_clicks", "w_recall_carts", "w_recall_orders", "score"])
        self.output = pd.DataFrame(columns=["session", "aid"], dtype=int)
        self.labels = labels
        self.week = week
    
    @noglobal(excepts=["cfg", "logger"])
    def _entry(self, new_candidate_df, name, k):
        logger.info(f"[add_candidate] {name} : start")
        new_candidate_df = new_candidate_df.to_pandas()
        self.output = pd.concat([self.output, new_candidate_df[["session", "aid"]]])
        self.output = self.output.drop_duplicates(subset=["session", "aid"])

        if self.labels is not None:
            self._eval(new_candidate_df[["session", "aid"]], name, k)
    
    @noglobal(excepts=["cfg", "logger"])
    def _eval(self, new_candidate_df, name, k):
        new_candidate_df = new_candidate_df.groupby("session")["aid"].apply(list).reset_index()
        eval_df = pd.DataFrame(self.target_sessions, columns=["session"])
        eval_df = eval_df.merge(new_candidate_df, on=["session"], how="left")
        assert eval_df["session"].tolist() == self.labels["session"].tolist()
        eval_result = evaluate(self.labels["clicks_labels"].tolist(), self.labels["carts_labels"].tolist(), self.labels["orders_labels"].tolist(),
                               eval_df["aid"].tolist(), eval_df["aid"].tolist(), eval_df["aid"].tolist(), k)
        
        logger.info(name)
        logger.info(eval_result)
        self.results = pd.concat([self.results, pd.DataFrame([[name] + list(eval_result.values())], columns=["name"] + list(eval_result.keys()))])

    @noglobal(excepts=["cfg", "logger"])
    def add(self, strategy, name, usetypes=['clicks', 'carts', 'orders'], trans_map=None, k=20):
        logger.info(f"[make_candidate] {name} : start")
        candidate_df = self.df[self.df["type"].isin(usetypes)].copy()
        
        if strategy == "session_frequent":
            candidate_df = self._session_frequent(candidate_df, k)
        elif strategy == "session_latest":
            candidate_df = self._session_latest(candidate_df, k)
        elif strategy == "total_frequent":
            candidate_df = self._total_frequent(candidate_df, k)
        elif strategy == "w2v_session_total_aid_vec_sim":
            candidate_df = self._w2v_session_total_aid_vec_sim()
        elif strategy == "w2v_session_carts_total_aid_vec_sim":
            candidate_df = self._w2v_session_carts_total_aid_vec_sim()
        
        if trans_map is not None:
            candidate_df["aid"] = candidate_df["aid"].map(trans_map)
            candidate_df = candidate_df.dropna(subset=["aid"])
            
        self._entry(candidate_df, name, k)

    @noglobal(excepts=["cfg", "logger"])
    def _session_frequent(self, candidate_df, k):
        candidate_df = candidate_df.groupby(["session", "aid"])["ts"].count().reset_index()
        candidate_df.columns = ["session", "aid", "aid_count"]
        candidate_df = candidate_df.sort_values(["session", "aid_count", "aid"], ascending=(True, False, True))
        candidate_df = candidate_df[candidate_df.groupby("session")["aid_count"].cumcount() < k].copy()
        candidate_df = candidate_df[["session", "aid"]].copy()
        return candidate_df

    @noglobal(excepts=["cfg", "logger"])
    def _session_latest(self, candidate_df, k):
        candidate_df = candidate_df.sort_values(["session", "ts"], ascending=(True, False)).drop_duplicates(subset=["session", "aid"])
        candidate_df = candidate_df.sort_values(["session", "ts"], ascending=(True, False))[candidate_df.groupby("session")["ts"].cumcount() < k].copy()
        candidate_df = candidate_df[["session", "aid"]].copy()
        return candidate_df

    @noglobal(excepts=["cfg", "logger"])
    def _total_frequent(self, candidate_df, k):
        candidate_df = candidate_df.groupby("aid")["ts"].count().reset_index()
        candidate_df.columns = ["aid", "aid_count"]
        topk_freq_aids = candidate_df.sort_values("aid_count", ascending=False)["aid"].to_arrow().to_pylist()[:k]
        sessions = []
        aids = []
        for session, aid in itertools.product(self.target_sessions, topk_freq_aids):
            sessions.append(session)
            aids.append(aid)
        candidate_df = cudf.DataFrame({"session": sessions, "aid": aids})
        return candidate_df

    @noglobal(excepts=["cfg", "logger"])
    def _w2v_session_total_aid_vec_sim(self):
        if self.week is not None:
            candidate_df = pd.read_pickle(cfg.prep_dir + f"w2v_session_total_avg_similar_aids_{self.week}.pkl")
        else:
            candidate_df = pd.read_pickle(cfg.prep_dir + "w2v_session_total_avg_similar_aids.pkl")
        candidate_df = cudf.from_pandas(candidate_df)
        candidate_df = candidate_df[["session", "aid"]].copy()
        candidate_df = candidate_df[candidate_df["session"].isin(self.target_sessions)]
        return candidate_df

    @noglobal(excepts=["cfg", "logger"])
    def _w2v_session_carts_total_aid_vec_sim(self):
        if self.week is not None:
            candidate_df = pd.read_pickle(cfg.prep_dir + f"w2v_session_carts_total_avg_similar_aids_{self.week}.pkl")
        else:
            candidate_df = pd.read_pickle(cfg.prep_dir + "w2v_session_carts_total_avg_similar_aids.pkl")
        candidate_df = cudf.from_pandas(candidate_df)
        candidate_df = candidate_df[["session", "aid"]].copy()
        candidate_df = candidate_df[candidate_df["session"].isin(self.target_sessions)]
        return candidate_df

# %%
@noglobal(excepts=["cfg", "logger"])
def make_cand_df(sessions, week, labels=None, trans_maps=None):

    if labels is not None:
         cand = Candidate(sessions, week, labels)
    else:
        cand = Candidate(sessions, week)

    cand.add(strategy="session_frequent", name="session_frequent", k=15)
    cand.add(strategy="session_latest", name="session_latest", k=15)
    cand.add(strategy="w2v_session_total_aid_vec_sim", name="w2v_session_total_aid_vec_sim")
    cand.add(strategy="w2v_session_carts_total_aid_vec_sim", name="w2v_session_carts_total_aid_vec_sim")
    
    for i in range(20):
        cand.add(strategy="session_latest", trans_map=trans_maps[f"time_wt_pair{str(i)}"], name=f"session_latest_time_wt_pair{str(i)}", k=5)
        cand.add(strategy="session_latest", trans_map=trans_maps[f"word2vec_pair{str(i)}"], name=f"session_latest_word2vec_pair{str(i)}", k=5)
        cand.add(strategy="session_latest", trans_map=trans_maps[f"pair{str(i)}"], name=f"session_latest_pair{str(i)}", k=5)
        cand.add(strategy="session_latest", trans_map=trans_maps[f"type_wt_pair{str(i)}"], name=f"session_latest_type_wt_pair{str(i)}", k=5)
        cand.add(strategy="session_latest", trans_map=trans_maps[f"clicks2carts_pair{str(i)}"], name=f"session_latest_clicks2carts_pair{str(i)}", k=5)
        cand.add(strategy="session_latest", trans_map=trans_maps[f"clicks2orders_pair{str(i)}"], name=f"session_latest_clicks2orders_pair{str(i)}", k=5)

    if labels is not None:
        return cand.output, cand.results
    else:
        return cand.output

# %%
@noglobal(excepts=["cfg", "logger"])
def get_pair_df(name, wt_col, week):
    if week is not None:
        name = f"{name}_{week}"
    pair_df = pd.read_pickle(cfg.prep_dir + f"{name}.pkl")
    pair_df = pair_df.sort_values(["aid_x", wt_col], ascending=(True, False))
    return pair_df

@noglobal(excepts=["cfg", "logger"])
def get_pair_dict(name, wt_col, week):
    if week is not None:
        name = f"{name}_{week}"
    pair_df = pd.read_pickle(cfg.prep_dir + f"{name}.pkl")
    pair_df = pair_df.sort_values(["aid_x", wt_col], ascending=(True, False))
    pair_df = pair_df.groupby("aid_x").head(1)[["aid_x", "aid_y"]]
    pair_dict = {k: v for k, v in zip(pair_df["aid_x"].tolist(), pair_df["aid_y"].tolist())}
    return pair_dict

@noglobal(excepts=["cfg", "logger"])
def get_trans_maps(week=None):
    """
    aidを別のaidに置き換えるmapping辞書を取得する
    """
    trans_maps = {}
    
    pair_df_org = get_pair_df("co_visitation_matrix", "cnt", week)
    for i in range(20):
        pair_df = pair_df_org.groupby("aid_x").nth(i).reset_index()[["aid_x", "aid_y"]]
        pair_dict = {k: v for k, v in zip(pair_df["aid_x"].tolist(), pair_df["aid_y"].tolist())}
        trans_maps[f"pair{str(i)}"] = pair_dict
    
    pair_df_org = get_pair_df("co_visitation_matrix_time_weighted", "wt", week)
    for i in range(20):
        pair_df = pair_df_org.groupby("aid_x").nth(i).reset_index()[["aid_x", "aid_y"]]
        pair_dict = {k: v for k, v in zip(pair_df["aid_x"].tolist(), pair_df["aid_y"].tolist())}
        trans_maps[f"time_wt_pair{str(i)}"] = pair_dict

    pair_df_org = get_pair_df("co_visitation_matrix_type_weighted", "wt", week)
    for i in range(20):
        pair_df = pair_df_org.groupby("aid_x").nth(i).reset_index()[["aid_x", "aid_y"]]
        pair_dict = {k: v for k, v in zip(pair_df["aid_x"].tolist(), pair_df["aid_y"].tolist())}
        trans_maps[f"type_wt_pair{str(i)}"] = pair_dict

    pair_df_org = get_pair_df("co_visitation_matrix_clicks2carts", "cnt", week)
    for i in range(20):
        pair_df = pair_df_org.groupby("aid_x").nth(i).reset_index()[["aid_x", "aid_y"]]
        pair_dict = {k: v for k, v in zip(pair_df["aid_x"].tolist(), pair_df["aid_y"].tolist())}
        trans_maps[f"clicks2carts_pair{str(i)}"] = pair_dict

    pair_df_org = get_pair_df("co_visitation_matrix_clicks2orders", "cnt", week)
    for i in range(20):
        pair_df = pair_df_org.groupby("aid_x").nth(i).reset_index()[["aid_x", "aid_y"]]
        pair_dict = {k: v for k, v in zip(pair_df["aid_x"].tolist(), pair_df["aid_y"].tolist())}
        trans_maps[f"clicks2orders_pair{str(i)}"] = pair_dict

    pair_df_org = get_pair_df("word2vec_similar", "sim", None)
    for i in range(20):
        pair_df = pair_df_org.groupby("aid_x").nth(i).reset_index()[["aid_x", "aid_y"]]
        pair_dict = {k: v for k, v in zip(pair_df["aid_x"].tolist(), pair_df["aid_y"].tolist())}
        trans_maps[f"word2vec_pair{str(i)}"] = pair_dict

    with open(cfg.prep_dir + "matrix_factorization_embeddings_similar_top20.pkl", "rb") as f:
        nns = pickle.load(f)
    for i in range(20):
        pair_dict = {aid_x:aid_ys[i] for aid_x, aid_ys in enumerate(nns)}
        trans_maps[f"matrix_fact_pair{str(i)}"] = pair_dict

    return trans_maps

# %%
@noglobal(excepts=["cfg", "logger"])
def make_valid_data(trans_maps):
    valid_week = cfg.valid_week
    dfs = []
    
    logger.info(f"[make_valid] valid_week : {valid_week}")
    # データ読み込み
    logger.info("[make_valid] read_data : start")
    week_sessions = pd.read_pickle(os.getenv("PREP_DIR") + f"train_sessions_{valid_week}.pkl")
    week_labels = pd.read_pickle(os.getenv("PREP_DIR") + f"labels_{valid_week}.pkl")
    valid_session_ids = week_sessions["session"].unique().tolist()
    logger.info("[make_valid] read_data : end")

    # validに使うsessionを絞る (trainに存在するsessionを除外した上で設定した数に絞る)
    logger.info("[make_valid] valid_session_extract : start")
    valid_session_n = min(cfg.valid_session_n, len(valid_session_ids))
    valid_session_ids = random.sample(valid_session_ids, valid_session_n)
    week_sessions = week_sessions[week_sessions["session"].isin(valid_session_ids)].copy()
    week_labels = week_labels[week_labels["session"].isin(valid_session_ids)].copy()
    logger.info("[make_valid] valid_session_extract : end")

    # 候補選出
    logger.info("[make_valid] make_cand_df : start")
    valid, results = make_cand_df(week_sessions, valid_week, labels=week_labels, trans_maps=trans_maps)

    return valid, week_labels, results

# %%
logger.info("\n\nSTART\n\n")
cache_file = f"trans_maps.pkl"
cache_path = cache.get_abspath(cache_file)

if cache.exists(cache_path):
    logger.info(f"[{cache_file}] cache exists. load cache and skip process.")
    with open(cache_path, "rb") as f:
        trans_maps = pickle.load(f)
else:
    trans_maps = get_trans_maps("week4")
    with open(cache_path, "wb") as f:
        pickle.dump(trans_maps, f)

valid, valid_labels, results = make_valid_data(trans_maps)
# Out:
# 0:00:00.248637
#
# START
#
#
# 0:36:38.785543 	 [make_valid] valid_week : week4
# 0:36:38.803654 	 [make_valid] read_data : start
# 0:36:45.919562 	 [make_valid] read_data : end
# 0:36:45.921329 	 [make_valid] valid_session_extract : start
# 0:36:46.918705 	 [make_valid] valid_session_extract : end
# 0:36:46.920149 	 [make_valid] make_cand_df : start
# 0:36:47.021346 	 [make_candidate] session_frequent : start
# 0:36:47.362487 	 [add_candidate] session_frequent : start
# 0:36:49.045184 	 session_frequent
# 0:36:49.046338 	 {'num_clicks': 97136, 'hit_clicks': 29467, 'num_carts': 42864, 'hit_carts': 10730, 'num_orders': 19985, 'hit_orders': 10185, 'recall_clicks': '0.303', 'recall_carts': '0.250', 'recall_orders': '0.510', 'w_recall_clicks': '0.030', 'w_recall_carts': '0.075', 'w_recall_orders': '0.306', 'score': '0.411'}
# 0:36:49.056151 	 [make_candidate] session_latest : start
# 0:36:49.343903 	 [add_candidate] session_latest : start
# 0:36:51.126946 	 session_latest
# 0:36:51.128101 	 {'num_clicks': 97136, 'hit_clicks': 29677, 'num_carts': 42864, 'hit_carts': 10822, 'num_orders': 19985, 'hit_orders': 9838, 'recall_clicks': '0.306', 'recall_carts': '0.252', 'recall_orders': '0.492', 'w_recall_clicks': '0.031', 'w_recall_carts': '0.076', 'w_recall_orders': '0.295', 'score': '0.402'}
# 0:36:51.138667 	 [make_candidate] w2v_session_total_aid_vec_sim : start
# 0:36:55.078579 	 [add_candidate] w2v_session_total_aid_vec_sim : start
# 0:36:57.289901 	 w2v_session_total_aid_vec_sim
# 0:36:57.291128 	 {'num_clicks': 97136, 'hit_clicks': 33577, 'num_carts': 43211, 'hit_carts': 8796, 'num_orders': 20082, 'hit_orders': 5541, 'recall_clicks': '0.346', 'recall_carts': '0.204', 'recall_orders': '0.276', 'w_recall_clicks': '0.035', 'w_recall_carts': '0.061', 'w_recall_orders': '0.166', 'score': '0.261'}
# 0:36:57.321866 	 [make_candidate] w2v_session_carts_total_aid_vec_sim : start
# 0:36:58.157184 	 [add_candidate] w2v_session_carts_total_aid_vec_sim : start
# 0:36:59.064813 	 w2v_session_carts_total_aid_vec_sim
# 0:36:59.066203 	 {'num_clicks': 97136, 'hit_clicks': 4803, 'num_carts': 43211, 'hit_carts': 3151, 'num_orders': 20082, 'hit_orders': 4854, 'recall_clicks': '0.049', 'recall_carts': '0.073', 'recall_orders': '0.242', 'w_recall_clicks': '0.005', 'w_recall_carts': '0.022', 'w_recall_orders': '0.145', 'score': '0.172'}
# 0:36:59.074154 	 [make_candidate] session_latest_time_wt_pair0 : start
# 0:36:59.565033 	 [add_candidate] session_latest_time_wt_pair0 : start
# 0:37:01.594292 	 session_latest_time_wt_pair0
# 0:37:01.595560 	 {'num_clicks': 97136, 'hit_clicks': 7618, 'num_carts': 37850, 'hit_carts': 2266, 'num_orders': 17856, 'hit_orders': 1476, 'recall_clicks': '0.078', 'recall_carts': '0.060', 'recall_orders': '0.083', 'w_recall_clicks': '0.008', 'w_recall_carts': '0.018', 'w_recall_orders': '0.050', 'score': '0.075'}
# 0:37:01.607538 	 [make_candidate] session_latest_word2vec_pair0 : start
# 0:37:02.085226 	 [add_candidate] session_latest_word2vec_pair0 : start
# 0:37:03.988508 	 session_latest_word2vec_pair0
# 0:37:03.990044 	 {'num_clicks': 97136, 'hit_clicks': 4513, 'num_carts': 37850, 'hit_carts': 1459, 'num_orders': 17856, 'hit_orders': 806, 'recall_clicks': '0.046', 'recall_carts': '0.039', 'recall_orders': '0.045', 'w_recall_clicks': '0.005', 'w_recall_carts': '0.012', 'w_recall_orders': '0.027', 'score': '0.043'}
# 0:37:04.000283 	 [make_candidate] session_latest_pair0 : start
# 0:37:04.486819 	 [add_candidate] session_latest_pair0 : start
# 0:37:06.527523 	 session_latest_pair0
# 0:37:06.528896 	 {'num_clicks': 97136, 'hit_clicks': 6545, 'num_carts': 37850, 'hit_carts': 2105, 'num_orders': 17856, 'hit_orders': 1450, 'recall_clicks': '0.067', 'recall_carts': '0.056', 'recall_orders': '0.081', 'w_recall_clicks': '0.007', 'w_recall_carts': '0.017', 'w_recall_orders': '0.049', 'score': '0.072'}
# 0:37:06.538878 	 [make_candidate] session_latest_type_wt_pair0 : start
# 0:37:06.959709 	 [add_candidate] session_latest_type_wt_pair0 : start
# 0:37:09.018555 	 session_latest_type_wt_pair0
# 0:37:09.019760 	 {'num_clicks': 97136, 'hit_clicks': 6448, 'num_carts': 37850, 'hit_carts': 2324, 'num_orders': 17856, 'hit_orders': 1686, 'recall_clicks': '0.066', 'recall_carts': '0.061', 'recall_orders': '0.094', 'w_recall_clicks': '0.007', 'w_recall_carts': '0.018', 'w_recall_orders': '0.057', 'score': '0.082'}
# 0:37:09.030520 	 [make_candidate] session_latest_clicks2carts_pair0 : start
# 0:37:09.502530 	 [add_candidate] session_latest_clicks2carts_pair0 : start
# 0:37:11.493182 	 session_latest_clicks2carts_pair0
# 0:37:11.494336 	 {'num_clicks': 97136, 'hit_clicks': 4076, 'num_carts': 37850, 'hit_carts': 1700, 'num_orders': 17856, 'hit_orders': 1165, 'recall_clicks': '0.042', 'recall_carts': '0.045', 'recall_orders': '0.065', 'w_recall_clicks': '0.004', 'w_recall_carts': '0.013', 'w_recall_orders': '0.039', 'score': '0.057'}
# 0:37:11.504153 	 [make_candidate] session_latest_clicks2orders_pair0 : start
# 0:37:11.903065 	 [add_candidate] session_latest_clicks2orders_pair0 : start
# 0:37:13.820025 	 session_latest_clicks2orders_pair0
# 0:37:13.822327 	 {'num_clicks': 97136, 'hit_clicks': 2474, 'num_carts': 37850, 'hit_carts': 1174, 'num_orders': 17856, 'hit_orders': 801, 'recall_clicks': '0.025', 'recall_carts': '0.031', 'recall_orders': '0.045', 'w_recall_clicks': '0.003', 'w_recall_carts': '0.009', 'w_recall_orders': '0.027', 'score': '0.039'}
# 0:37:13.831905 	 [make_candidate] session_latest_time_wt_pair1 : start
# 0:37:14.370274 	 [add_candidate] session_latest_time_wt_pair1 : start
# 0:37:16.461975 	 session_latest_time_wt_pair1
# 0:37:16.463128 	 {'num_clicks': 97136, 'hit_clicks': 5373, 'num_carts': 37850, 'hit_carts': 1660, 'num_orders': 17856, 'hit_orders': 1017, 'recall_clicks': '0.055', 'recall_carts': '0.044', 'recall_orders': '0.057', 'w_recall_clicks': '0.006', 'w_recall_carts': '0.013', 'w_recall_orders': '0.034', 'score': '0.053'}
# 0:37:16.473172 	 [make_candidate] session_latest_word2vec_pair1 : start
# 0:37:17.005585 	 [add_candidate] session_latest_word2vec_pair1 : start
# 0:37:19.122581 	 session_latest_word2vec_pair1
# 0:37:19.123823 	 {'num_clicks': 97136, 'hit_clicks': 3132, 'num_carts': 37850, 'hit_carts': 1037, 'num_orders': 17856, 'hit_orders': 580, 'recall_clicks': '0.032', 'recall_carts': '0.027', 'recall_orders': '0.032', 'w_recall_clicks': '0.003', 'w_recall_carts': '0.008', 'w_recall_orders': '0.019', 'score': '0.031'}
# 0:37:19.135058 	 [make_candidate] session_latest_pair1 : start
# 0:37:19.619708 	 [add_candidate] session_latest_pair1 : start
# 0:37:21.893312 	 session_latest_pair1
# 0:37:21.894937 	 {'num_clicks': 97136, 'hit_clicks': 4546, 'num_carts': 37850, 'hit_carts': 1556, 'num_orders': 17856, 'hit_orders': 975, 'recall_clicks': '0.047', 'recall_carts': '0.041', 'recall_orders': '0.055', 'w_recall_clicks': '0.005', 'w_recall_carts': '0.012', 'w_recall_orders': '0.033', 'score': '0.050'}
# 0:37:21.905533 	 [make_candidate] session_latest_type_wt_pair1 : start
# 0:37:22.321454 	 [add_candidate] session_latest_type_wt_pair1 : start
# 0:37:24.606605 	 session_latest_type_wt_pair1
# 0:37:24.607731 	 {'num_clicks': 97136, 'hit_clicks': 4502, 'num_carts': 37850, 'hit_carts': 1629, 'num_orders': 17856, 'hit_orders': 1146, 'recall_clicks': '0.046', 'recall_carts': '0.043', 'recall_orders': '0.064', 'w_recall_clicks': '0.005', 'w_recall_carts': '0.013', 'w_recall_orders': '0.039', 'score': '0.056'}
# 0:37:24.618482 	 [make_candidate] session_latest_clicks2carts_pair1 : start
# 0:37:24.978695 	 [add_candidate] session_latest_clicks2carts_pair1 : start
# 0:37:27.188019 	 session_latest_clicks2carts_pair1
# 0:37:27.189182 	 {'num_clicks': 97136, 'hit_clicks': 2792, 'num_carts': 37850, 'hit_carts': 1165, 'num_orders': 17856, 'hit_orders': 788, 'recall_clicks': '0.029', 'recall_carts': '0.031', 'recall_orders': '0.044', 'w_recall_clicks': '0.003', 'w_recall_carts': '0.009', 'w_recall_orders': '0.026', 'score': '0.039'}
# 0:37:27.199006 	 [make_candidate] session_latest_clicks2orders_pair1 : start
# 0:37:27.384989 	 [add_candidate] session_latest_clicks2orders_pair1 : start
# 0:37:29.469399 	 session_latest_clicks2orders_pair1
# 0:37:29.470581 	 {'num_clicks': 97136, 'hit_clicks': 1539, 'num_carts': 37850, 'hit_carts': 672, 'num_orders': 17856, 'hit_orders': 464, 'recall_clicks': '0.016', 'recall_carts': '0.018', 'recall_orders': '0.026', 'w_recall_clicks': '0.002', 'w_recall_carts': '0.005', 'w_recall_orders': '0.016', 'score': '0.023'}
# 0:37:29.480284 	 [make_candidate] session_latest_time_wt_pair2 : start
# 0:37:30.191998 	 [add_candidate] session_latest_time_wt_pair2 : start
# 0:37:32.492811 	 session_latest_time_wt_pair2
# 0:37:32.493909 	 {'num_clicks': 97136, 'hit_clicks': 4175, 'num_carts': 37850, 'hit_carts': 1366, 'num_orders': 17856, 'hit_orders': 864, 'recall_clicks': '0.043', 'recall_carts': '0.036', 'recall_orders': '0.048', 'w_recall_clicks': '0.004', 'w_recall_carts': '0.011', 'w_recall_orders': '0.029', 'score': '0.044'}
# 0:37:32.504433 	 [make_candidate] session_latest_word2vec_pair2 : start
# 0:37:32.897182 	 [add_candidate] session_latest_word2vec_pair2 : start
# 0:37:35.178519 	 session_latest_word2vec_pair2
# 0:37:35.179641 	 {'num_clicks': 97136, 'hit_clicks': 2525, 'num_carts': 37850, 'hit_carts': 832, 'num_orders': 17856, 'hit_orders': 472, 'recall_clicks': '0.026', 'recall_carts': '0.022', 'recall_orders': '0.026', 'w_recall_clicks': '0.003', 'w_recall_carts': '0.007', 'w_recall_orders': '0.016', 'score': '0.025'}
# 0:37:35.190019 	 [make_candidate] session_latest_pair2 : start
# 0:37:35.804150 	 [add_candidate] session_latest_pair2 : start
# 0:37:37.979147 	 session_latest_pair2
# 0:37:37.981021 	 {'num_clicks': 97136, 'hit_clicks': 3634, 'num_carts': 37850, 'hit_carts': 1301, 'num_orders': 17856, 'hit_orders': 848, 'recall_clicks': '0.037', 'recall_carts': '0.034', 'recall_orders': '0.047', 'w_recall_clicks': '0.004', 'w_recall_carts': '0.010', 'w_recall_orders': '0.028', 'score': '0.043'}
# 0:37:37.992367 	 [make_candidate] session_latest_type_wt_pair2 : start
# 0:37:38.311217 	 [add_candidate] session_latest_type_wt_pair2 : start
# 0:37:40.561613 	 session_latest_type_wt_pair2
# 0:37:40.562956 	 {'num_clicks': 97136, 'hit_clicks': 3486, 'num_carts': 37850, 'hit_carts': 1353, 'num_orders': 17856, 'hit_orders': 928, 'recall_clicks': '0.036', 'recall_carts': '0.036', 'recall_orders': '0.052', 'w_recall_clicks': '0.004', 'w_recall_carts': '0.011', 'w_recall_orders': '0.031', 'score': '0.045'}
# 0:37:40.573947 	 [make_candidate] session_latest_clicks2carts_pair2 : start
# 0:37:40.885012 	 [add_candidate] session_latest_clicks2carts_pair2 : start
# 0:37:43.084454 	 session_latest_clicks2carts_pair2
# 0:37:43.085672 	 {'num_clicks': 97136, 'hit_clicks': 2130, 'num_carts': 37850, 'hit_carts': 991, 'num_orders': 17856, 'hit_orders': 601, 'recall_clicks': '0.022', 'recall_carts': '0.026', 'recall_orders': '0.034', 'w_recall_clicks': '0.002', 'w_recall_carts': '0.008', 'w_recall_orders': '0.020', 'score': '0.030'}
# 0:37:43.096103 	 [make_candidate] session_latest_clicks2orders_pair2 : start
# 0:37:43.479743 	 [add_candidate] session_latest_clicks2orders_pair2 : start
# 0:37:45.570720 	 session_latest_clicks2orders_pair2
# 0:37:45.571977 	 {'num_clicks': 97136, 'hit_clicks': 1141, 'num_carts': 37850, 'hit_carts': 526, 'num_orders': 17856, 'hit_orders': 337, 'recall_clicks': '0.012', 'recall_carts': '0.014', 'recall_orders': '0.019', 'w_recall_clicks': '0.001', 'w_recall_carts': '0.004', 'w_recall_orders': '0.011', 'score': '0.017'}
# 0:37:45.581109 	 [make_candidate] session_latest_time_wt_pair3 : start
# 0:37:46.059066 	 [add_candidate] session_latest_time_wt_pair3 : start
# 0:37:48.362634 	 session_latest_time_wt_pair3
# 0:37:48.363736 	 {'num_clicks': 97136, 'hit_clicks': 3595, 'num_carts': 37850, 'hit_carts': 1288, 'num_orders': 17856, 'hit_orders': 690, 'recall_clicks': '0.037', 'recall_carts': '0.034', 'recall_orders': '0.039', 'w_recall_clicks': '0.004', 'w_recall_carts': '0.010', 'w_recall_orders': '0.023', 'score': '0.037'}
# 0:37:48.374375 	 [make_candidate] session_latest_word2vec_pair3 : start
# 0:37:48.848357 	 [add_candidate] session_latest_word2vec_pair3 : start
# 0:37:51.258272 	 session_latest_word2vec_pair3
# 0:37:51.259482 	 {'num_clicks': 97136, 'hit_clicks': 1970, 'num_carts': 37850, 'hit_carts': 715, 'num_orders': 17856, 'hit_orders': 427, 'recall_clicks': '0.020', 'recall_carts': '0.019', 'recall_orders': '0.024', 'w_recall_clicks': '0.002', 'w_recall_carts': '0.006', 'w_recall_orders': '0.014', 'score': '0.022'}
# 0:37:51.269651 	 [make_candidate] session_latest_pair3 : start
# 0:37:51.741298 	 [add_candidate] session_latest_pair3 : start
# 0:37:54.086556 	 session_latest_pair3
# 0:37:54.087601 	 {'num_clicks': 97136, 'hit_clicks': 2997, 'num_carts': 37850, 'hit_carts': 1064, 'num_orders': 17856, 'hit_orders': 686, 'recall_clicks': '0.031', 'recall_carts': '0.028', 'recall_orders': '0.038', 'w_recall_clicks': '0.003', 'w_recall_carts': '0.008', 'w_recall_orders': '0.023', 'score': '0.035'}
# 0:37:54.097984 	 [make_candidate] session_latest_type_wt_pair3 : start
# 0:37:54.524718 	 [add_candidate] session_latest_type_wt_pair3 : start
# 0:37:56.914132 	 session_latest_type_wt_pair3
# 0:37:56.915357 	 {'num_clicks': 97136, 'hit_clicks': 3009, 'num_carts': 37850, 'hit_carts': 1121, 'num_orders': 17856, 'hit_orders': 795, 'recall_clicks': '0.031', 'recall_carts': '0.030', 'recall_orders': '0.045', 'w_recall_clicks': '0.003', 'w_recall_carts': '0.009', 'w_recall_orders': '0.027', 'score': '0.039'}
# 0:37:56.927340 	 [make_candidate] session_latest_clicks2carts_pair3 : start
# 0:37:57.329689 	 [add_candidate] session_latest_clicks2carts_pair3 : start
# 0:37:59.489943 	 session_latest_clicks2carts_pair3
# 0:37:59.491499 	 {'num_clicks': 97136, 'hit_clicks': 1694, 'num_carts': 37850, 'hit_carts': 811, 'num_orders': 17856, 'hit_orders': 486, 'recall_clicks': '0.017', 'recall_carts': '0.021', 'recall_orders': '0.027', 'w_recall_clicks': '0.002', 'w_recall_carts': '0.006', 'w_recall_orders': '0.016', 'score': '0.025'}
# 0:37:59.502170 	 [make_candidate] session_latest_clicks2orders_pair3 : start
# 0:37:59.671183 	 [add_candidate] session_latest_clicks2orders_pair3 : start
# 0:38:01.847956 	 session_latest_clicks2orders_pair3
# 0:38:01.849231 	 {'num_clicks': 97136, 'hit_clicks': 931, 'num_carts': 37850, 'hit_carts': 435, 'num_orders': 17856, 'hit_orders': 272, 'recall_clicks': '0.010', 'recall_carts': '0.011', 'recall_orders': '0.015', 'w_recall_clicks': '0.001', 'w_recall_carts': '0.003', 'w_recall_orders': '0.009', 'score': '0.014'}
# 0:38:01.857732 	 [make_candidate] session_latest_time_wt_pair4 : start
# 0:38:02.464062 	 [add_candidate] session_latest_time_wt_pair4 : start
# 0:38:04.869758 	 session_latest_time_wt_pair4
# 0:38:04.871213 	 {'num_clicks': 97136, 'hit_clicks': 3085, 'num_carts': 37850, 'hit_carts': 1059, 'num_orders': 17856, 'hit_orders': 661, 'recall_clicks': '0.032', 'recall_carts': '0.028', 'recall_orders': '0.037', 'w_recall_clicks': '0.003', 'w_recall_carts': '0.008', 'w_recall_orders': '0.022', 'score': '0.034'}
# 0:38:04.881685 	 [make_candidate] session_latest_word2vec_pair4 : start
# 0:38:05.414020 	 [add_candidate] session_latest_word2vec_pair4 : start
# 0:38:07.832791 	 session_latest_word2vec_pair4
# 0:38:07.833963 	 {'num_clicks': 97136, 'hit_clicks': 1810, 'num_carts': 37850, 'hit_carts': 600, 'num_orders': 17856, 'hit_orders': 324, 'recall_clicks': '0.019', 'recall_carts': '0.016', 'recall_orders': '0.018', 'w_recall_clicks': '0.002', 'w_recall_carts': '0.005', 'w_recall_orders': '0.011', 'score': '0.018'}
# 0:38:07.844359 	 [make_candidate] session_latest_pair4 : start
# 0:38:08.409814 	 [add_candidate] session_latest_pair4 : start
# 0:38:10.883482 	 session_latest_pair4
# 0:38:10.884947 	 {'num_clicks': 97136, 'hit_clicks': 2561, 'num_carts': 37850, 'hit_carts': 908, 'num_orders': 17856, 'hit_orders': 617, 'recall_clicks': '0.026', 'recall_carts': '0.024', 'recall_orders': '0.035', 'w_recall_clicks': '0.003', 'w_recall_carts': '0.007', 'w_recall_orders': '0.021', 'score': '0.031'}
# 0:38:10.896217 	 [make_candidate] session_latest_type_wt_pair4 : start
# 0:38:11.424501 	 [add_candidate] session_latest_type_wt_pair4 : start
# 0:38:13.867000 	 session_latest_type_wt_pair4
# 0:38:13.868169 	 {'num_clicks': 97136, 'hit_clicks': 2539, 'num_carts': 37850, 'hit_carts': 931, 'num_orders': 17856, 'hit_orders': 686, 'recall_clicks': '0.026', 'recall_carts': '0.025', 'recall_orders': '0.038', 'w_recall_clicks': '0.003', 'w_recall_carts': '0.007', 'w_recall_orders': '0.023', 'score': '0.033'}
# 0:38:13.878731 	 [make_candidate] session_latest_clicks2carts_pair4 : start
# 0:38:14.160282 	 [add_candidate] session_latest_clicks2carts_pair4 : start
# 0:38:16.509792 	 session_latest_clicks2carts_pair4
# 0:38:16.511056 	 {'num_clicks': 97136, 'hit_clicks': 1514, 'num_carts': 37850, 'hit_carts': 675, 'num_orders': 17856, 'hit_orders': 391, 'recall_clicks': '0.016', 'recall_carts': '0.018', 'recall_orders': '0.022', 'w_recall_clicks': '0.002', 'w_recall_carts': '0.005', 'w_recall_orders': '0.013', 'score': '0.020'}
# 0:38:16.521108 	 [make_candidate] session_latest_clicks2orders_pair4 : start
# 0:38:16.879339 	 [add_candidate] session_latest_clicks2orders_pair4 : start
# 0:38:19.054820 	 session_latest_clicks2orders_pair4
# 0:38:19.056119 	 {'num_clicks': 97136, 'hit_clicks': 734, 'num_carts': 37850, 'hit_carts': 355, 'num_orders': 17856, 'hit_orders': 217, 'recall_clicks': '0.008', 'recall_carts': '0.009', 'recall_orders': '0.012', 'w_recall_clicks': '0.001', 'w_recall_carts': '0.003', 'w_recall_orders': '0.007', 'score': '0.011'}
# 0:38:19.065016 	 [make_candidate] session_latest_time_wt_pair5 : start
# 0:38:19.529214 	 [add_candidate] session_latest_time_wt_pair5 : start
# 0:38:21.985484 	 session_latest_time_wt_pair5
# 0:38:21.986677 	 {'num_clicks': 97136, 'hit_clicks': 2645, 'num_carts': 37850, 'hit_carts': 938, 'num_orders': 17856, 'hit_orders': 550, 'recall_clicks': '0.027', 'recall_carts': '0.025', 'recall_orders': '0.031', 'w_recall_clicks': '0.003', 'w_recall_carts': '0.007', 'w_recall_orders': '0.018', 'score': '0.029'}
# 0:38:21.998283 	 [make_candidate] session_latest_word2vec_pair5 : start
# 0:38:22.404588 	 [add_candidate] session_latest_word2vec_pair5 : start
# 0:38:24.848909 	 session_latest_word2vec_pair5
# 0:38:24.850202 	 {'num_clicks': 97136, 'hit_clicks': 1690, 'num_carts': 37850, 'hit_carts': 569, 'num_orders': 17856, 'hit_orders': 338, 'recall_clicks': '0.017', 'recall_carts': '0.015', 'recall_orders': '0.019', 'w_recall_clicks': '0.002', 'w_recall_carts': '0.005', 'w_recall_orders': '0.011', 'score': '0.018'}
# 0:38:24.861377 	 [make_candidate] session_latest_pair5 : start
# 0:38:25.547880 	 [add_candidate] session_latest_pair5 : start
# 0:38:27.859375 	 session_latest_pair5
# 0:38:27.860518 	 {'num_clicks': 97136, 'hit_clicks': 2317, 'num_carts': 37850, 'hit_carts': 784, 'num_orders': 17856, 'hit_orders': 575, 'recall_clicks': '0.024', 'recall_carts': '0.021', 'recall_orders': '0.032', 'w_recall_clicks': '0.002', 'w_recall_carts': '0.006', 'w_recall_orders': '0.019', 'score': '0.028'}
# 0:38:27.871162 	 [make_candidate] session_latest_type_wt_pair5 : start
# 0:38:28.204689 	 [add_candidate] session_latest_type_wt_pair5 : start
# 0:38:30.665684 	 session_latest_type_wt_pair5
# 0:38:30.666975 	 {'num_clicks': 97136, 'hit_clicks': 2285, 'num_carts': 37850, 'hit_carts': 819, 'num_orders': 17856, 'hit_orders': 582, 'recall_clicks': '0.024', 'recall_carts': '0.022', 'recall_orders': '0.033', 'w_recall_clicks': '0.002', 'w_recall_carts': '0.006', 'w_recall_orders': '0.020', 'score': '0.028'}
# 0:38:30.678591 	 [make_candidate] session_latest_clicks2carts_pair5 : start
# 0:38:30.979781 	 [add_candidate] session_latest_clicks2carts_pair5 : start
# 0:38:33.322047 	 session_latest_clicks2carts_pair5
# 0:38:33.323367 	 {'num_clicks': 97136, 'hit_clicks': 1265, 'num_carts': 37850, 'hit_carts': 531, 'num_orders': 17856, 'hit_orders': 325, 'recall_clicks': '0.013', 'recall_carts': '0.014', 'recall_orders': '0.018', 'w_recall_clicks': '0.001', 'w_recall_carts': '0.004', 'w_recall_orders': '0.011', 'score': '0.016'}
# 0:38:33.334555 	 [make_candidate] session_latest_clicks2orders_pair5 : start
# 0:38:33.693658 	 [add_candidate] session_latest_clicks2orders_pair5 : start
# 0:38:35.890558 	 session_latest_clicks2orders_pair5
# 0:38:35.891989 	 {'num_clicks': 97136, 'hit_clicks': 648, 'num_carts': 37850, 'hit_carts': 292, 'num_orders': 17856, 'hit_orders': 206, 'recall_clicks': '0.007', 'recall_carts': '0.008', 'recall_orders': '0.012', 'w_recall_clicks': '0.001', 'w_recall_carts': '0.002', 'w_recall_orders': '0.007', 'score': '0.010'}
# 0:38:35.900790 	 [make_candidate] session_latest_time_wt_pair6 : start
# 0:38:36.380388 	 [add_candidate] session_latest_time_wt_pair6 : start
# 0:38:38.893004 	 session_latest_time_wt_pair6
# 0:38:38.894166 	 {'num_clicks': 97136, 'hit_clicks': 2386, 'num_carts': 37850, 'hit_carts': 791, 'num_orders': 17856, 'hit_orders': 485, 'recall_clicks': '0.025', 'recall_carts': '0.021', 'recall_orders': '0.027', 'w_recall_clicks': '0.002', 'w_recall_carts': '0.006', 'w_recall_orders': '0.016', 'score': '0.025'}
# 0:38:38.905634 	 [make_candidate] session_latest_word2vec_pair6 : start
# 0:38:39.314976 	 [add_candidate] session_latest_word2vec_pair6 : start
# 0:38:41.832359 	 session_latest_word2vec_pair6
# 0:38:41.833406 	 {'num_clicks': 97136, 'hit_clicks': 1628, 'num_carts': 37850, 'hit_carts': 572, 'num_orders': 17856, 'hit_orders': 276, 'recall_clicks': '0.017', 'recall_carts': '0.015', 'recall_orders': '0.015', 'w_recall_clicks': '0.002', 'w_recall_carts': '0.005', 'w_recall_orders': '0.009', 'score': '0.015'}
# 0:38:41.843866 	 [make_candidate] session_latest_pair6 : start
# 0:38:42.543981 	 [add_candidate] session_latest_pair6 : start
# 0:38:45.084334 	 session_latest_pair6
# 0:38:45.085627 	 {'num_clicks': 97136, 'hit_clicks': 1998, 'num_carts': 37850, 'hit_carts': 712, 'num_orders': 17856, 'hit_orders': 494, 'recall_clicks': '0.021', 'recall_carts': '0.019', 'recall_orders': '0.028', 'w_recall_clicks': '0.002', 'w_recall_carts': '0.006', 'w_recall_orders': '0.017', 'score': '0.024'}
# 0:38:45.096234 	 [make_candidate] session_latest_type_wt_pair6 : start
# 0:38:45.453455 	 [add_candidate] session_latest_type_wt_pair6 : start
# 0:38:48.033768 	 session_latest_type_wt_pair6
# 0:38:48.035196 	 {'num_clicks': 97136, 'hit_clicks': 2097, 'num_carts': 37850, 'hit_carts': 800, 'num_orders': 17856, 'hit_orders': 563, 'recall_clicks': '0.022', 'recall_carts': '0.021', 'recall_orders': '0.032', 'w_recall_clicks': '0.002', 'w_recall_carts': '0.006', 'w_recall_orders': '0.019', 'score': '0.027'}
# 0:38:48.046247 	 [make_candidate] session_latest_clicks2carts_pair6 : start
# 0:38:48.448965 	 [add_candidate] session_latest_clicks2carts_pair6 : start
# 0:38:50.799238 	 session_latest_clicks2carts_pair6
# 0:38:50.800482 	 {'num_clicks': 97136, 'hit_clicks': 1146, 'num_carts': 37850, 'hit_carts': 477, 'num_orders': 17856, 'hit_orders': 310, 'recall_clicks': '0.012', 'recall_carts': '0.013', 'recall_orders': '0.017', 'w_recall_clicks': '0.001', 'w_recall_carts': '0.004', 'w_recall_orders': '0.010', 'score': '0.015'}
# 0:38:50.810862 	 [make_candidate] session_latest_clicks2orders_pair6 : start
# 0:38:51.237557 	 [add_candidate] session_latest_clicks2orders_pair6 : start
# 0:38:53.492722 	 session_latest_clicks2orders_pair6
# 0:38:53.493797 	 {'num_clicks': 97136, 'hit_clicks': 543, 'num_carts': 37850, 'hit_carts': 235, 'num_orders': 17856, 'hit_orders': 160, 'recall_clicks': '0.006', 'recall_carts': '0.006', 'recall_orders': '0.009', 'w_recall_clicks': '0.001', 'w_recall_carts': '0.002', 'w_recall_orders': '0.005', 'score': '0.008'}
# 0:38:53.502690 	 [make_candidate] session_latest_time_wt_pair7 : start
# 0:38:53.980805 	 [add_candidate] session_latest_time_wt_pair7 : start
# 0:38:56.593098 	 session_latest_time_wt_pair7
# 0:38:56.594297 	 {'num_clicks': 97136, 'hit_clicks': 2122, 'num_carts': 37850, 'hit_carts': 767, 'num_orders': 17856, 'hit_orders': 452, 'recall_clicks': '0.022', 'recall_carts': '0.020', 'recall_orders': '0.025', 'w_recall_clicks': '0.002', 'w_recall_carts': '0.006', 'w_recall_orders': '0.015', 'score': '0.023'}
# 0:38:56.606334 	 [make_candidate] session_latest_word2vec_pair7 : start
# 0:38:57.156555 	 [add_candidate] session_latest_word2vec_pair7 : start
# 0:38:59.749294 	 session_latest_word2vec_pair7
# 0:38:59.750485 	 {'num_clicks': 97136, 'hit_clicks': 1381, 'num_carts': 37850, 'hit_carts': 469, 'num_orders': 17856, 'hit_orders': 252, 'recall_clicks': '0.014', 'recall_carts': '0.012', 'recall_orders': '0.014', 'w_recall_clicks': '0.001', 'w_recall_carts': '0.004', 'w_recall_orders': '0.008', 'score': '0.014'}
# 0:38:59.761617 	 [make_candidate] session_latest_pair7 : start
# 0:39:00.365888 	 [add_candidate] session_latest_pair7 : start
# 0:39:03.001400 	 session_latest_pair7
# 0:39:03.002774 	 {'num_clicks': 97136, 'hit_clicks': 1852, 'num_carts': 37850, 'hit_carts': 668, 'num_orders': 17856, 'hit_orders': 421, 'recall_clicks': '0.019', 'recall_carts': '0.018', 'recall_orders': '0.024', 'w_recall_clicks': '0.002', 'w_recall_carts': '0.005', 'w_recall_orders': '0.014', 'score': '0.021'}
# 0:39:03.013846 	 [make_candidate] session_latest_type_wt_pair7 : start
# 0:39:03.358469 	 [add_candidate] session_latest_type_wt_pair7 : start
# 0:39:06.261202 	 session_latest_type_wt_pair7
# 0:39:06.262724 	 {'num_clicks': 97136, 'hit_clicks': 1822, 'num_carts': 37850, 'hit_carts': 663, 'num_orders': 17856, 'hit_orders': 477, 'recall_clicks': '0.019', 'recall_carts': '0.018', 'recall_orders': '0.027', 'w_recall_clicks': '0.002', 'w_recall_carts': '0.005', 'w_recall_orders': '0.016', 'score': '0.023'}
# 0:39:06.273130 	 [make_candidate] session_latest_clicks2carts_pair7 : start
# 0:39:06.666744 	 [add_candidate] session_latest_clicks2carts_pair7 : start
# 0:39:09.269816 	 session_latest_clicks2carts_pair7
# 0:39:09.271365 	 {'num_clicks': 97136, 'hit_clicks': 977, 'num_carts': 37850, 'hit_carts': 438, 'num_orders': 17856, 'hit_orders': 265, 'recall_clicks': '0.010', 'recall_carts': '0.012', 'recall_orders': '0.015', 'w_recall_clicks': '0.001', 'w_recall_carts': '0.003', 'w_recall_orders': '0.009', 'score': '0.013'}
# 0:39:09.281030 	 [make_candidate] session_latest_clicks2orders_pair7 : start
# 0:39:09.434975 	 [add_candidate] session_latest_clicks2orders_pair7 : start
# 0:39:11.980004 	 session_latest_clicks2orders_pair7
# 0:39:11.981430 	 {'num_clicks': 97136, 'hit_clicks': 511, 'num_carts': 37850, 'hit_carts': 236, 'num_orders': 17856, 'hit_orders': 147, 'recall_clicks': '0.005', 'recall_carts': '0.006', 'recall_orders': '0.008', 'w_recall_clicks': '0.001', 'w_recall_carts': '0.002', 'w_recall_orders': '0.005', 'score': '0.007'}
# 0:39:11.990046 	 [make_candidate] session_latest_time_wt_pair8 : start
# 0:39:12.570037 	 [add_candidate] session_latest_time_wt_pair8 : start
# 0:39:15.562007 	 session_latest_time_wt_pair8
# 0:39:15.563084 	 {'num_clicks': 97136, 'hit_clicks': 2053, 'num_carts': 37850, 'hit_carts': 682, 'num_orders': 17856, 'hit_orders': 417, 'recall_clicks': '0.021', 'recall_carts': '0.018', 'recall_orders': '0.023', 'w_recall_clicks': '0.002', 'w_recall_carts': '0.005', 'w_recall_orders': '0.014', 'score': '0.022'}
# 0:39:15.573977 	 [make_candidate] session_latest_word2vec_pair8 : start
# 0:39:16.025943 	 [add_candidate] session_latest_word2vec_pair8 : start
# 0:39:19.004073 	 session_latest_word2vec_pair8
# 0:39:19.005195 	 {'num_clicks': 97136, 'hit_clicks': 1295, 'num_carts': 37850, 'hit_carts': 448, 'num_orders': 17856, 'hit_orders': 238, 'recall_clicks': '0.013', 'recall_carts': '0.012', 'recall_orders': '0.013', 'w_recall_clicks': '0.001', 'w_recall_carts': '0.004', 'w_recall_orders': '0.008', 'score': '0.013'}
# 0:39:19.016151 	 [make_candidate] session_latest_pair8 : start
# 0:39:19.540390 	 [add_candidate] session_latest_pair8 : start
# 0:39:22.570566 	 session_latest_pair8
# 0:39:22.571906 	 {'num_clicks': 97136, 'hit_clicks': 1795, 'num_carts': 37850, 'hit_carts': 643, 'num_orders': 17856, 'hit_orders': 432, 'recall_clicks': '0.018', 'recall_carts': '0.017', 'recall_orders': '0.024', 'w_recall_clicks': '0.002', 'w_recall_carts': '0.005', 'w_recall_orders': '0.015', 'score': '0.021'}
# 0:39:22.583063 	 [make_candidate] session_latest_type_wt_pair8 : start
# 0:39:23.132187 	 [add_candidate] session_latest_type_wt_pair8 : start
# 0:39:26.166298 	 session_latest_type_wt_pair8
# 0:39:26.167488 	 {'num_clicks': 97136, 'hit_clicks': 1697, 'num_carts': 37850, 'hit_carts': 640, 'num_orders': 17856, 'hit_orders': 458, 'recall_clicks': '0.017', 'recall_carts': '0.017', 'recall_orders': '0.026', 'w_recall_clicks': '0.002', 'w_recall_carts': '0.005', 'w_recall_orders': '0.015', 'score': '0.022'}
# 0:39:26.178809 	 [make_candidate] session_latest_clicks2carts_pair8 : start
# 0:39:26.514156 	 [add_candidate] session_latest_clicks2carts_pair8 : start
# 0:39:29.357484 	 session_latest_clicks2carts_pair8
# 0:39:29.358709 	 {'num_clicks': 97136, 'hit_clicks': 928, 'num_carts': 37850, 'hit_carts': 397, 'num_orders': 17856, 'hit_orders': 264, 'recall_clicks': '0.010', 'recall_carts': '0.010', 'recall_orders': '0.015', 'w_recall_clicks': '0.001', 'w_recall_carts': '0.003', 'w_recall_orders': '0.009', 'score': '0.013'}
# 0:39:29.368928 	 [make_candidate] session_latest_clicks2orders_pair8 : start
# 0:39:29.566432 	 [add_candidate] session_latest_clicks2orders_pair8 : start
# 0:39:32.007126 	 session_latest_clicks2orders_pair8
# 0:39:32.008754 	 {'num_clicks': 97136, 'hit_clicks': 453, 'num_carts': 37850, 'hit_carts': 194, 'num_orders': 17856, 'hit_orders': 130, 'recall_clicks': '0.005', 'recall_carts': '0.005', 'recall_orders': '0.007', 'w_recall_clicks': '0.000', 'w_recall_carts': '0.002', 'w_recall_orders': '0.004', 'score': '0.006'}
# 0:39:32.017683 	 [make_candidate] session_latest_time_wt_pair9 : start
# 0:39:32.561205 	 [add_candidate] session_latest_time_wt_pair9 : start
# 0:39:35.640138 	 session_latest_time_wt_pair9
# 0:39:35.641421 	 {'num_clicks': 97136, 'hit_clicks': 1852, 'num_carts': 37850, 'hit_carts': 665, 'num_orders': 17856, 'hit_orders': 437, 'recall_clicks': '0.019', 'recall_carts': '0.018', 'recall_orders': '0.024', 'w_recall_clicks': '0.002', 'w_recall_carts': '0.005', 'w_recall_orders': '0.015', 'score': '0.022'}
# 0:39:35.652645 	 [make_candidate] session_latest_word2vec_pair9 : start
# 0:39:36.153864 	 [add_candidate] session_latest_word2vec_pair9 : start
# 0:39:39.205187 	 session_latest_word2vec_pair9
# 0:39:39.206465 	 {'num_clicks': 97136, 'hit_clicks': 1134, 'num_carts': 37850, 'hit_carts': 385, 'num_orders': 17856, 'hit_orders': 207, 'recall_clicks': '0.012', 'recall_carts': '0.010', 'recall_orders': '0.012', 'w_recall_clicks': '0.001', 'w_recall_carts': '0.003', 'w_recall_orders': '0.007', 'score': '0.011'}
# 0:39:39.217105 	 [make_candidate] session_latest_pair9 : start
# 0:39:39.713562 	 [add_candidate] session_latest_pair9 : start
# 0:39:42.708497 	 session_latest_pair9
# 0:39:42.710028 	 {'num_clicks': 97136, 'hit_clicks': 1559, 'num_carts': 37850, 'hit_carts': 596, 'num_orders': 17856, 'hit_orders': 386, 'recall_clicks': '0.016', 'recall_carts': '0.016', 'recall_orders': '0.022', 'w_recall_clicks': '0.002', 'w_recall_carts': '0.005', 'w_recall_orders': '0.013', 'score': '0.019'}
# 0:39:42.720447 	 [make_candidate] session_latest_type_wt_pair9 : start
# 0:39:43.220926 	 [add_candidate] session_latest_type_wt_pair9 : start
# 0:39:46.306403 	 session_latest_type_wt_pair9
# 0:39:46.307654 	 {'num_clicks': 97136, 'hit_clicks': 1635, 'num_carts': 37850, 'hit_carts': 594, 'num_orders': 17856, 'hit_orders': 454, 'recall_clicks': '0.017', 'recall_carts': '0.016', 'recall_orders': '0.025', 'w_recall_clicks': '0.002', 'w_recall_carts': '0.005', 'w_recall_orders': '0.015', 'score': '0.022'}
# 0:39:46.318425 	 [make_candidate] session_latest_clicks2carts_pair9 : start
# 0:39:46.587501 	 [add_candidate] session_latest_clicks2carts_pair9 : start
# 0:39:49.474113 	 session_latest_clicks2carts_pair9
# 0:39:49.475286 	 {'num_clicks': 97136, 'hit_clicks': 816, 'num_carts': 37850, 'hit_carts': 338, 'num_orders': 17856, 'hit_orders': 232, 'recall_clicks': '0.008', 'recall_carts': '0.009', 'recall_orders': '0.013', 'w_recall_clicks': '0.001', 'w_recall_carts': '0.003', 'w_recall_orders': '0.008', 'score': '0.011'}
# 0:39:49.484704 	 [make_candidate] session_latest_clicks2orders_pair9 : start
# 0:39:49.844696 	 [add_candidate] session_latest_clicks2orders_pair9 : start
# 0:39:52.421565 	 session_latest_clicks2orders_pair9
# 0:39:52.423021 	 {'num_clicks': 97136, 'hit_clicks': 386, 'num_carts': 37850, 'hit_carts': 202, 'num_orders': 17856, 'hit_orders': 131, 'recall_clicks': '0.004', 'recall_carts': '0.005', 'recall_orders': '0.007', 'w_recall_clicks': '0.000', 'w_recall_carts': '0.002', 'w_recall_orders': '0.004', 'score': '0.006'}
# 0:39:52.432044 	 [make_candidate] session_latest_time_wt_pair10 : start
# 0:39:52.821011 	 [add_candidate] session_latest_time_wt_pair10 : start
# 0:39:55.927669 	 session_latest_time_wt_pair10
# 0:39:55.928792 	 {'num_clicks': 97136, 'hit_clicks': 1720, 'num_carts': 37850, 'hit_carts': 583, 'num_orders': 17856, 'hit_orders': 388, 'recall_clicks': '0.018', 'recall_carts': '0.015', 'recall_orders': '0.022', 'w_recall_clicks': '0.002', 'w_recall_carts': '0.005', 'w_recall_orders': '0.013', 'score': '0.019'}
# 0:39:55.940032 	 [make_candidate] session_latest_word2vec_pair10 : start
# 0:39:56.404202 	 [add_candidate] session_latest_word2vec_pair10 : start
# 0:39:59.507096 	 session_latest_word2vec_pair10
# 0:39:59.508302 	 {'num_clicks': 97136, 'hit_clicks': 1080, 'num_carts': 37850, 'hit_carts': 367, 'num_orders': 17856, 'hit_orders': 234, 'recall_clicks': '0.011', 'recall_carts': '0.010', 'recall_orders': '0.013', 'w_recall_clicks': '0.001', 'w_recall_carts': '0.003', 'w_recall_orders': '0.008', 'score': '0.012'}
# 0:39:59.520069 	 [make_candidate] session_latest_pair10 : start
# 0:40:00.056020 	 [add_candidate] session_latest_pair10 : start
# 0:40:03.172783 	 session_latest_pair10
# 0:40:03.173901 	 {'num_clicks': 97136, 'hit_clicks': 1394, 'num_carts': 37850, 'hit_carts': 514, 'num_orders': 17856, 'hit_orders': 325, 'recall_clicks': '0.014', 'recall_carts': '0.014', 'recall_orders': '0.018', 'w_recall_clicks': '0.001', 'w_recall_carts': '0.004', 'w_recall_orders': '0.011', 'score': '0.016'}
# 0:40:03.185605 	 [make_candidate] session_latest_type_wt_pair10 : start
# 0:40:03.725524 	 [add_candidate] session_latest_type_wt_pair10 : start
# 0:40:06.822536 	 session_latest_type_wt_pair10
# 0:40:06.823642 	 {'num_clicks': 97136, 'hit_clicks': 1471, 'num_carts': 37850, 'hit_carts': 581, 'num_orders': 17856, 'hit_orders': 397, 'recall_clicks': '0.015', 'recall_carts': '0.015', 'recall_orders': '0.022', 'w_recall_clicks': '0.002', 'w_recall_carts': '0.005', 'w_recall_orders': '0.013', 'score': '0.019'}
# 0:40:06.834704 	 [make_candidate] session_latest_clicks2carts_pair10 : start
# 0:40:07.250061 	 [add_candidate] session_latest_clicks2carts_pair10 : start
# 0:40:10.191036 	 session_latest_clicks2carts_pair10
# 0:40:10.192448 	 {'num_clicks': 97136, 'hit_clicks': 787, 'num_carts': 37850, 'hit_carts': 320, 'num_orders': 17856, 'hit_orders': 232, 'recall_clicks': '0.008', 'recall_carts': '0.008', 'recall_orders': '0.013', 'w_recall_clicks': '0.001', 'w_recall_carts': '0.003', 'w_recall_orders': '0.008', 'score': '0.011'}
# 0:40:10.202498 	 [make_candidate] session_latest_clicks2orders_pair10 : start
# 0:40:10.390840 	 [add_candidate] session_latest_clicks2orders_pair10 : start
# 0:40:13.166952 	 session_latest_clicks2orders_pair10
# 0:40:13.168107 	 {'num_clicks': 97136, 'hit_clicks': 380, 'num_carts': 37850, 'hit_carts': 178, 'num_orders': 17856, 'hit_orders': 113, 'recall_clicks': '0.004', 'recall_carts': '0.005', 'recall_orders': '0.006', 'w_recall_clicks': '0.000', 'w_recall_carts': '0.001', 'w_recall_orders': '0.004', 'score': '0.006'}
# 0:40:13.177554 	 [make_candidate] session_latest_time_wt_pair11 : start
# 0:40:13.727269 	 [add_candidate] session_latest_time_wt_pair11 : start
# 0:40:16.839040 	 session_latest_time_wt_pair11
# 0:40:16.840359 	 {'num_clicks': 97136, 'hit_clicks': 1571, 'num_carts': 37850, 'hit_carts': 588, 'num_orders': 17856, 'hit_orders': 362, 'recall_clicks': '0.016', 'recall_carts': '0.016', 'recall_orders': '0.020', 'w_recall_clicks': '0.002', 'w_recall_carts': '0.005', 'w_recall_orders': '0.012', 'score': '0.018'}
# 0:40:16.852709 	 [make_candidate] session_latest_word2vec_pair11 : start
# 0:40:17.378233 	 [add_candidate] session_latest_word2vec_pair11 : start
# 0:40:20.563107 	 session_latest_word2vec_pair11
# 0:40:20.564540 	 {'num_clicks': 97136, 'hit_clicks': 1016, 'num_carts': 37850, 'hit_carts': 386, 'num_orders': 17856, 'hit_orders': 199, 'recall_clicks': '0.010', 'recall_carts': '0.010', 'recall_orders': '0.011', 'w_recall_clicks': '0.001', 'w_recall_carts': '0.003', 'w_recall_orders': '0.007', 'score': '0.011'}
# 0:40:20.576379 	 [make_candidate] session_latest_pair11 : start
# 0:40:21.113306 	 [add_candidate] session_latest_pair11 : start
# 0:40:24.112803 	 session_latest_pair11
# 0:40:24.114044 	 {'num_clicks': 97136, 'hit_clicks': 1288, 'num_carts': 37850, 'hit_carts': 518, 'num_orders': 17856, 'hit_orders': 332, 'recall_clicks': '0.013', 'recall_carts': '0.014', 'recall_orders': '0.019', 'w_recall_clicks': '0.001', 'w_recall_carts': '0.004', 'w_recall_orders': '0.011', 'score': '0.017'}
# 0:40:24.124736 	 [make_candidate] session_latest_type_wt_pair11 : start
# 0:40:24.605221 	 [add_candidate] session_latest_type_wt_pair11 : start
# 0:40:27.703136 	 session_latest_type_wt_pair11
# 0:40:27.704313 	 {'num_clicks': 97136, 'hit_clicks': 1349, 'num_carts': 37850, 'hit_carts': 520, 'num_orders': 17856, 'hit_orders': 392, 'recall_clicks': '0.014', 'recall_carts': '0.014', 'recall_orders': '0.022', 'w_recall_clicks': '0.001', 'w_recall_carts': '0.004', 'w_recall_orders': '0.013', 'score': '0.019'}
# 0:40:27.715716 	 [make_candidate] session_latest_clicks2carts_pair11 : start
# 0:40:27.981849 	 [add_candidate] session_latest_clicks2carts_pair11 : start
# 0:40:30.920922 	 session_latest_clicks2carts_pair11
# 0:40:30.922211 	 {'num_clicks': 97136, 'hit_clicks': 707, 'num_carts': 37850, 'hit_carts': 292, 'num_orders': 17856, 'hit_orders': 195, 'recall_clicks': '0.007', 'recall_carts': '0.008', 'recall_orders': '0.011', 'w_recall_clicks': '0.001', 'w_recall_carts': '0.002', 'w_recall_orders': '0.007', 'score': '0.010'}
# 0:40:30.932366 	 [make_candidate] session_latest_clicks2orders_pair11 : start
# 0:40:31.243072 	 [add_candidate] session_latest_clicks2orders_pair11 : start
# 0:40:33.980062 	 session_latest_clicks2orders_pair11
# 0:40:33.981372 	 {'num_clicks': 97136, 'hit_clicks': 319, 'num_carts': 37850, 'hit_carts': 160, 'num_orders': 17856, 'hit_orders': 112, 'recall_clicks': '0.003', 'recall_carts': '0.004', 'recall_orders': '0.006', 'w_recall_clicks': '0.000', 'w_recall_carts': '0.001', 'w_recall_orders': '0.004', 'score': '0.005'}
# 0:40:33.989207 	 [make_candidate] session_latest_time_wt_pair12 : start
# 0:40:34.320138 	 [add_candidate] session_latest_time_wt_pair12 : start
# 0:40:37.550195 	 session_latest_time_wt_pair12
# 0:40:37.551440 	 {'num_clicks': 97136, 'hit_clicks': 1496, 'num_carts': 37850, 'hit_carts': 576, 'num_orders': 17856, 'hit_orders': 338, 'recall_clicks': '0.015', 'recall_carts': '0.015', 'recall_orders': '0.019', 'w_recall_clicks': '0.002', 'w_recall_carts': '0.005', 'w_recall_orders': '0.011', 'score': '0.017'}
# 0:40:37.562258 	 [make_candidate] session_latest_word2vec_pair12 : start
# 0:40:37.999333 	 [add_candidate] session_latest_word2vec_pair12 : start
# 0:40:41.225489 	 session_latest_word2vec_pair12
# 0:40:41.226595 	 {'num_clicks': 97136, 'hit_clicks': 990, 'num_carts': 37850, 'hit_carts': 359, 'num_orders': 17856, 'hit_orders': 208, 'recall_clicks': '0.010', 'recall_carts': '0.009', 'recall_orders': '0.012', 'w_recall_clicks': '0.001', 'w_recall_carts': '0.003', 'w_recall_orders': '0.007', 'score': '0.011'}
# 0:40:41.237654 	 [make_candidate] session_latest_pair12 : start
# 0:40:41.753982 	 [add_candidate] session_latest_pair12 : start
# 0:40:44.882642 	 session_latest_pair12
# 0:40:44.883817 	 {'num_clicks': 97136, 'hit_clicks': 1223, 'num_carts': 37850, 'hit_carts': 464, 'num_orders': 17856, 'hit_orders': 277, 'recall_clicks': '0.013', 'recall_carts': '0.012', 'recall_orders': '0.016', 'w_recall_clicks': '0.001', 'w_recall_carts': '0.004', 'w_recall_orders': '0.009', 'score': '0.014'}
# 0:40:44.895401 	 [make_candidate] session_latest_type_wt_pair12 : start
# 0:40:45.408476 	 [add_candidate] session_latest_type_wt_pair12 : start
# 0:40:48.693857 	 session_latest_type_wt_pair12
# 0:40:48.694978 	 {'num_clicks': 97136, 'hit_clicks': 1316, 'num_carts': 37850, 'hit_carts': 492, 'num_orders': 17856, 'hit_orders': 365, 'recall_clicks': '0.014', 'recall_carts': '0.013', 'recall_orders': '0.020', 'w_recall_clicks': '0.001', 'w_recall_carts': '0.004', 'w_recall_orders': '0.012', 'score': '0.018'}
# 0:40:48.706321 	 [make_candidate] session_latest_clicks2carts_pair12 : start
# 0:40:48.992604 	 [add_candidate] session_latest_clicks2carts_pair12 : start
# 0:40:52.054653 	 session_latest_clicks2carts_pair12
# 0:40:52.055851 	 {'num_clicks': 97136, 'hit_clicks': 642, 'num_carts': 37850, 'hit_carts': 257, 'num_orders': 17856, 'hit_orders': 184, 'recall_clicks': '0.007', 'recall_carts': '0.007', 'recall_orders': '0.010', 'w_recall_clicks': '0.001', 'w_recall_carts': '0.002', 'w_recall_orders': '0.006', 'score': '0.009'}
# 0:40:52.065643 	 [make_candidate] session_latest_clicks2orders_pair12 : start
# 0:40:52.415633 	 [add_candidate] session_latest_clicks2orders_pair12 : start
# 0:40:55.194415 	 session_latest_clicks2orders_pair12
# 0:40:55.195863 	 {'num_clicks': 97136, 'hit_clicks': 301, 'num_carts': 37850, 'hit_carts': 142, 'num_orders': 17856, 'hit_orders': 108, 'recall_clicks': '0.003', 'recall_carts': '0.004', 'recall_orders': '0.006', 'w_recall_clicks': '0.000', 'w_recall_carts': '0.001', 'w_recall_orders': '0.004', 'score': '0.005'}
# 0:40:55.204566 	 [make_candidate] session_latest_time_wt_pair13 : start
# 0:40:55.618414 	 [add_candidate] session_latest_time_wt_pair13 : start
# 0:40:58.882310 	 session_latest_time_wt_pair13
# 0:40:58.883405 	 {'num_clicks': 97136, 'hit_clicks': 1354, 'num_carts': 37850, 'hit_carts': 530, 'num_orders': 17856, 'hit_orders': 341, 'recall_clicks': '0.014', 'recall_carts': '0.014', 'recall_orders': '0.019', 'w_recall_clicks': '0.001', 'w_recall_carts': '0.004', 'w_recall_orders': '0.011', 'score': '0.017'}
# 0:40:58.894037 	 [make_candidate] session_latest_word2vec_pair13 : start
# 0:40:59.374325 	 [add_candidate] session_latest_word2vec_pair13 : start
# 0:41:02.475788 	 session_latest_word2vec_pair13
# 0:41:02.476907 	 {'num_clicks': 97136, 'hit_clicks': 923, 'num_carts': 37850, 'hit_carts': 348, 'num_orders': 17856, 'hit_orders': 169, 'recall_clicks': '0.010', 'recall_carts': '0.009', 'recall_orders': '0.009', 'w_recall_clicks': '0.001', 'w_recall_carts': '0.003', 'w_recall_orders': '0.006', 'score': '0.009'}
# 0:41:02.487876 	 [make_candidate] session_latest_pair13 : start
# 0:41:03.027656 	 [add_candidate] session_latest_pair13 : start
# 0:41:06.270506 	 session_latest_pair13
# 0:41:06.271773 	 {'num_clicks': 97136, 'hit_clicks': 1154, 'num_carts': 37850, 'hit_carts': 433, 'num_orders': 17856, 'hit_orders': 285, 'recall_clicks': '0.012', 'recall_carts': '0.011', 'recall_orders': '0.016', 'w_recall_clicks': '0.001', 'w_recall_carts': '0.003', 'w_recall_orders': '0.010', 'score': '0.014'}
# 0:41:06.283077 	 [make_candidate] session_latest_type_wt_pair13 : start
# 0:41:06.788834 	 [add_candidate] session_latest_type_wt_pair13 : start
# 0:41:10.091999 	 session_latest_type_wt_pair13
# 0:41:10.093112 	 {'num_clicks': 97136, 'hit_clicks': 1146, 'num_carts': 37850, 'hit_carts': 496, 'num_orders': 17856, 'hit_orders': 326, 'recall_clicks': '0.012', 'recall_carts': '0.013', 'recall_orders': '0.018', 'w_recall_clicks': '0.001', 'w_recall_carts': '0.004', 'w_recall_orders': '0.011', 'score': '0.016'}
# 0:41:10.104702 	 [make_candidate] session_latest_clicks2carts_pair13 : start
# 0:41:10.318878 	 [add_candidate] session_latest_clicks2carts_pair13 : start
# 0:41:13.426113 	 session_latest_clicks2carts_pair13
# 0:41:13.427613 	 {'num_clicks': 97136, 'hit_clicks': 586, 'num_carts': 37850, 'hit_carts': 233, 'num_orders': 17856, 'hit_orders': 150, 'recall_clicks': '0.006', 'recall_carts': '0.006', 'recall_orders': '0.008', 'w_recall_clicks': '0.001', 'w_recall_carts': '0.002', 'w_recall_orders': '0.005', 'score': '0.007'}
# 0:41:13.437574 	 [make_candidate] session_latest_clicks2orders_pair13 : start
# 0:41:13.812151 	 [add_candidate] session_latest_clicks2orders_pair13 : start
# 0:41:16.682447 	 session_latest_clicks2orders_pair13
# 0:41:16.683745 	 {'num_clicks': 97136, 'hit_clicks': 312, 'num_carts': 37850, 'hit_carts': 121, 'num_orders': 17856, 'hit_orders': 86, 'recall_clicks': '0.003', 'recall_carts': '0.003', 'recall_orders': '0.005', 'w_recall_clicks': '0.000', 'w_recall_carts': '0.001', 'w_recall_orders': '0.003', 'score': '0.004'}
# 0:41:16.692297 	 [make_candidate] session_latest_time_wt_pair14 : start
# 0:41:17.046648 	 [add_candidate] session_latest_time_wt_pair14 : start
# 0:41:20.398609 	 session_latest_time_wt_pair14
# 0:41:20.399846 	 {'num_clicks': 97136, 'hit_clicks': 1285, 'num_carts': 37850, 'hit_carts': 504, 'num_orders': 17856, 'hit_orders': 286, 'recall_clicks': '0.013', 'recall_carts': '0.013', 'recall_orders': '0.016', 'w_recall_clicks': '0.001', 'w_recall_carts': '0.004', 'w_recall_orders': '0.010', 'score': '0.015'}
# 0:41:20.411710 	 [make_candidate] session_latest_word2vec_pair14 : start
# 0:41:20.952877 	 [add_candidate] session_latest_word2vec_pair14 : start
# 0:41:24.300152 	 session_latest_word2vec_pair14
# 0:41:24.301411 	 {'num_clicks': 97136, 'hit_clicks': 852, 'num_carts': 37850, 'hit_carts': 308, 'num_orders': 17856, 'hit_orders': 161, 'recall_clicks': '0.009', 'recall_carts': '0.008', 'recall_orders': '0.009', 'w_recall_clicks': '0.001', 'w_recall_carts': '0.002', 'w_recall_orders': '0.005', 'score': '0.009'}
# 0:41:24.312790 	 [make_candidate] session_latest_pair14 : start
# 0:41:24.870005 	 [add_candidate] session_latest_pair14 : start
# 0:41:28.085819 	 session_latest_pair14
# 0:41:28.087130 	 {'num_clicks': 97136, 'hit_clicks': 1112, 'num_carts': 37850, 'hit_carts': 417, 'num_orders': 17856, 'hit_orders': 292, 'recall_clicks': '0.011', 'recall_carts': '0.011', 'recall_orders': '0.016', 'w_recall_clicks': '0.001', 'w_recall_carts': '0.003', 'w_recall_orders': '0.010', 'score': '0.014'}
# 0:41:28.100259 	 [make_candidate] session_latest_type_wt_pair14 : start
# 0:41:28.501889 	 [add_candidate] session_latest_type_wt_pair14 : start
# 0:41:31.836646 	 session_latest_type_wt_pair14
# 0:41:31.837800 	 {'num_clicks': 97136, 'hit_clicks': 1108, 'num_carts': 37850, 'hit_carts': 416, 'num_orders': 17856, 'hit_orders': 328, 'recall_clicks': '0.011', 'recall_carts': '0.011', 'recall_orders': '0.018', 'w_recall_clicks': '0.001', 'w_recall_carts': '0.003', 'w_recall_orders': '0.011', 'score': '0.015'}
# 0:41:31.849330 	 [make_candidate] session_latest_clicks2carts_pair14 : start
# 0:41:32.235623 	 [add_candidate] session_latest_clicks2carts_pair14 : start
# 0:41:35.406939 	 session_latest_clicks2carts_pair14
# 0:41:35.408156 	 {'num_clicks': 97136, 'hit_clicks': 601, 'num_carts': 37850, 'hit_carts': 223, 'num_orders': 17856, 'hit_orders': 143, 'recall_clicks': '0.006', 'recall_carts': '0.006', 'recall_orders': '0.008', 'w_recall_clicks': '0.001', 'w_recall_carts': '0.002', 'w_recall_orders': '0.005', 'score': '0.007'}
# 0:41:35.418398 	 [make_candidate] session_latest_clicks2orders_pair14 : start
# 0:41:35.664760 	 [add_candidate] session_latest_clicks2orders_pair14 : start
# 0:41:38.561352 	 session_latest_clicks2orders_pair14
# 0:41:38.562519 	 {'num_clicks': 97136, 'hit_clicks': 239, 'num_carts': 37850, 'hit_carts': 101, 'num_orders': 17856, 'hit_orders': 65, 'recall_clicks': '0.002', 'recall_carts': '0.003', 'recall_orders': '0.004', 'w_recall_clicks': '0.000', 'w_recall_carts': '0.001', 'w_recall_orders': '0.002', 'score': '0.003'}
# 0:41:38.570580 	 [make_candidate] session_latest_time_wt_pair15 : start
# 0:41:39.126180 	 [add_candidate] session_latest_time_wt_pair15 : start
# 0:41:42.425764 	 session_latest_time_wt_pair15
# 0:41:42.426891 	 {'num_clicks': 97136, 'hit_clicks': 1199, 'num_carts': 37850, 'hit_carts': 434, 'num_orders': 17856, 'hit_orders': 278, 'recall_clicks': '0.012', 'recall_carts': '0.011', 'recall_orders': '0.016', 'w_recall_clicks': '0.001', 'w_recall_carts': '0.003', 'w_recall_orders': '0.009', 'score': '0.014'}
# 0:41:42.438030 	 [make_candidate] session_latest_word2vec_pair15 : start
# 0:41:42.862861 	 [add_candidate] session_latest_word2vec_pair15 : start
# 0:41:46.250978 	 session_latest_word2vec_pair15
# 0:41:46.252338 	 {'num_clicks': 97136, 'hit_clicks': 877, 'num_carts': 37850, 'hit_carts': 306, 'num_orders': 17856, 'hit_orders': 176, 'recall_clicks': '0.009', 'recall_carts': '0.008', 'recall_orders': '0.010', 'w_recall_clicks': '0.001', 'w_recall_carts': '0.002', 'w_recall_orders': '0.006', 'score': '0.009'}
# 0:41:46.264255 	 [make_candidate] session_latest_pair15 : start
# 0:41:46.879461 	 [add_candidate] session_latest_pair15 : start
# 0:41:50.119051 	 session_latest_pair15
# 0:41:50.120289 	 {'num_clicks': 97136, 'hit_clicks': 1024, 'num_carts': 37850, 'hit_carts': 369, 'num_orders': 17856, 'hit_orders': 260, 'recall_clicks': '0.011', 'recall_carts': '0.010', 'recall_orders': '0.015', 'w_recall_clicks': '0.001', 'w_recall_carts': '0.003', 'w_recall_orders': '0.009', 'score': '0.013'}
# 0:41:50.131308 	 [make_candidate] session_latest_type_wt_pair15 : start
# 0:41:50.544544 	 [add_candidate] session_latest_type_wt_pair15 : start
# 0:41:54.026751 	 session_latest_type_wt_pair15
# 0:41:54.028124 	 {'num_clicks': 97136, 'hit_clicks': 1085, 'num_carts': 37850, 'hit_carts': 422, 'num_orders': 17856, 'hit_orders': 311, 'recall_clicks': '0.011', 'recall_carts': '0.011', 'recall_orders': '0.017', 'w_recall_clicks': '0.001', 'w_recall_carts': '0.003', 'w_recall_orders': '0.010', 'score': '0.015'}
# 0:41:54.040016 	 [make_candidate] session_latest_clicks2carts_pair15 : start
# 0:41:54.416917 	 [add_candidate] session_latest_clicks2carts_pair15 : start
# 0:41:57.557386 	 session_latest_clicks2carts_pair15
# 0:41:57.558613 	 {'num_clicks': 97136, 'hit_clicks': 488, 'num_carts': 37850, 'hit_carts': 241, 'num_orders': 17856, 'hit_orders': 148, 'recall_clicks': '0.005', 'recall_carts': '0.006', 'recall_orders': '0.008', 'w_recall_clicks': '0.001', 'w_recall_carts': '0.002', 'w_recall_orders': '0.005', 'score': '0.007'}
# 0:41:57.568836 	 [make_candidate] session_latest_clicks2orders_pair15 : start
# 0:41:57.798543 	 [add_candidate] session_latest_clicks2orders_pair15 : start
# 0:42:00.725441 	 session_latest_clicks2orders_pair15
# 0:42:00.726677 	 {'num_clicks': 97136, 'hit_clicks': 238, 'num_carts': 37850, 'hit_carts': 110, 'num_orders': 17856, 'hit_orders': 70, 'recall_clicks': '0.002', 'recall_carts': '0.003', 'recall_orders': '0.004', 'w_recall_clicks': '0.000', 'w_recall_carts': '0.001', 'w_recall_orders': '0.002', 'score': '0.003'}
# 0:42:00.734439 	 [make_candidate] session_latest_time_wt_pair16 : start
# 0:42:01.268844 	 [add_candidate] session_latest_time_wt_pair16 : start
# 0:42:04.668542 	 session_latest_time_wt_pair16
# 0:42:04.669644 	 {'num_clicks': 97136, 'hit_clicks': 1148, 'num_carts': 37850, 'hit_carts': 443, 'num_orders': 17856, 'hit_orders': 298, 'recall_clicks': '0.012', 'recall_carts': '0.012', 'recall_orders': '0.017', 'w_recall_clicks': '0.001', 'w_recall_carts': '0.004', 'w_recall_orders': '0.010', 'score': '0.015'}
# 0:42:04.681087 	 [make_candidate] session_latest_word2vec_pair16 : start
# 0:42:05.183281 	 [add_candidate] session_latest_word2vec_pair16 : start
# 0:42:08.567919 	 session_latest_word2vec_pair16
# 0:42:08.569204 	 {'num_clicks': 97136, 'hit_clicks': 789, 'num_carts': 37850, 'hit_carts': 268, 'num_orders': 17856, 'hit_orders': 140, 'recall_clicks': '0.008', 'recall_carts': '0.007', 'recall_orders': '0.008', 'w_recall_clicks': '0.001', 'w_recall_carts': '0.002', 'w_recall_orders': '0.005', 'score': '0.008'}
# 0:42:08.582423 	 [make_candidate] session_latest_pair16 : start
# 0:42:09.077225 	 [add_candidate] session_latest_pair16 : start
# 0:42:12.386755 	 session_latest_pair16
# 0:42:12.387862 	 {'num_clicks': 97136, 'hit_clicks': 918, 'num_carts': 37850, 'hit_carts': 377, 'num_orders': 17856, 'hit_orders': 260, 'recall_clicks': '0.009', 'recall_carts': '0.010', 'recall_orders': '0.015', 'w_recall_clicks': '0.001', 'w_recall_carts': '0.003', 'w_recall_orders': '0.009', 'score': '0.013'}
# 0:42:12.398964 	 [make_candidate] session_latest_type_wt_pair16 : start
# 0:42:12.953030 	 [add_candidate] session_latest_type_wt_pair16 : start
# 0:42:16.368868 	 session_latest_type_wt_pair16
# 0:42:16.369949 	 {'num_clicks': 97136, 'hit_clicks': 975, 'num_carts': 37850, 'hit_carts': 376, 'num_orders': 17856, 'hit_orders': 270, 'recall_clicks': '0.010', 'recall_carts': '0.010', 'recall_orders': '0.015', 'w_recall_clicks': '0.001', 'w_recall_carts': '0.003', 'w_recall_orders': '0.009', 'score': '0.013'}
# 0:42:16.381414 	 [make_candidate] session_latest_clicks2carts_pair16 : start
# 0:42:16.636423 	 [add_candidate] session_latest_clicks2carts_pair16 : start
# 0:42:19.930096 	 session_latest_clicks2carts_pair16
# 0:42:19.931568 	 {'num_clicks': 97136, 'hit_clicks': 488, 'num_carts': 37850, 'hit_carts': 200, 'num_orders': 17856, 'hit_orders': 129, 'recall_clicks': '0.005', 'recall_carts': '0.005', 'recall_orders': '0.007', 'w_recall_clicks': '0.001', 'w_recall_carts': '0.002', 'w_recall_orders': '0.004', 'score': '0.006'}
# 0:42:19.940993 	 [make_candidate] session_latest_clicks2orders_pair16 : start
# 0:42:20.296588 	 [add_candidate] session_latest_clicks2orders_pair16 : start
# 0:42:23.243253 	 session_latest_clicks2orders_pair16
# 0:42:23.244433 	 {'num_clicks': 97136, 'hit_clicks': 201, 'num_carts': 37850, 'hit_carts': 98, 'num_orders': 17856, 'hit_orders': 60, 'recall_clicks': '0.002', 'recall_carts': '0.003', 'recall_orders': '0.003', 'w_recall_clicks': '0.000', 'w_recall_carts': '0.001', 'w_recall_orders': '0.002', 'score': '0.003'}
# 0:42:23.252382 	 [make_candidate] session_latest_time_wt_pair17 : start
# 0:42:23.750164 	 [add_candidate] session_latest_time_wt_pair17 : start
# 0:42:27.073615 	 session_latest_time_wt_pair17
# 0:42:27.074718 	 {'num_clicks': 97136, 'hit_clicks': 1125, 'num_carts': 37850, 'hit_carts': 443, 'num_orders': 17856, 'hit_orders': 270, 'recall_clicks': '0.012', 'recall_carts': '0.012', 'recall_orders': '0.015', 'w_recall_clicks': '0.001', 'w_recall_carts': '0.004', 'w_recall_orders': '0.009', 'score': '0.014'}
# 0:42:27.086103 	 [make_candidate] session_latest_word2vec_pair17 : start
# 0:42:27.496878 	 [add_candidate] session_latest_word2vec_pair17 : start
# 0:42:31.041234 	 session_latest_word2vec_pair17
# 0:42:31.042911 	 {'num_clicks': 97136, 'hit_clicks': 721, 'num_carts': 37850, 'hit_carts': 269, 'num_orders': 17856, 'hit_orders': 134, 'recall_clicks': '0.007', 'recall_carts': '0.007', 'recall_orders': '0.008', 'w_recall_clicks': '0.001', 'w_recall_carts': '0.002', 'w_recall_orders': '0.005', 'score': '0.007'}
# 0:42:31.057636 	 [make_candidate] session_latest_pair17 : start
# 0:42:31.636975 	 [add_candidate] session_latest_pair17 : start
# 0:42:35.102945 	 session_latest_pair17
# 0:42:35.104051 	 {'num_clicks': 97136, 'hit_clicks': 871, 'num_carts': 37850, 'hit_carts': 341, 'num_orders': 17856, 'hit_orders': 219, 'recall_clicks': '0.009', 'recall_carts': '0.009', 'recall_orders': '0.012', 'w_recall_clicks': '0.001', 'w_recall_carts': '0.003', 'w_recall_orders': '0.007', 'score': '0.011'}
# 0:42:35.117140 	 [make_candidate] session_latest_type_wt_pair17 : start
# 0:42:35.528342 	 [add_candidate] session_latest_type_wt_pair17 : start
# 0:42:38.977548 	 session_latest_type_wt_pair17
# 0:42:38.978975 	 {'num_clicks': 97136, 'hit_clicks': 979, 'num_carts': 37850, 'hit_carts': 361, 'num_orders': 17856, 'hit_orders': 307, 'recall_clicks': '0.010', 'recall_carts': '0.010', 'recall_orders': '0.017', 'w_recall_clicks': '0.001', 'w_recall_carts': '0.003', 'w_recall_orders': '0.010', 'score': '0.014'}
# 0:42:38.991048 	 [make_candidate] session_latest_clicks2carts_pair17 : start
# 0:42:39.385638 	 [add_candidate] session_latest_clicks2carts_pair17 : start
# 0:42:42.688028 	 session_latest_clicks2carts_pair17
# 0:42:42.689404 	 {'num_clicks': 97136, 'hit_clicks': 424, 'num_carts': 37850, 'hit_carts': 190, 'num_orders': 17856, 'hit_orders': 117, 'recall_clicks': '0.004', 'recall_carts': '0.005', 'recall_orders': '0.007', 'w_recall_clicks': '0.000', 'w_recall_carts': '0.002', 'w_recall_orders': '0.004', 'score': '0.006'}
# 0:42:42.699120 	 [make_candidate] session_latest_clicks2orders_pair17 : start
# 0:42:42.980423 	 [add_candidate] session_latest_clicks2orders_pair17 : start
# 0:42:45.981752 	 session_latest_clicks2orders_pair17
# 0:42:45.982869 	 {'num_clicks': 97136, 'hit_clicks': 209, 'num_carts': 37850, 'hit_carts': 97, 'num_orders': 17856, 'hit_orders': 63, 'recall_clicks': '0.002', 'recall_carts': '0.003', 'recall_orders': '0.004', 'w_recall_clicks': '0.000', 'w_recall_carts': '0.001', 'w_recall_orders': '0.002', 'score': '0.003'}
# 0:42:45.990663 	 [make_candidate] session_latest_time_wt_pair18 : start
# 0:42:46.543682 	 [add_candidate] session_latest_time_wt_pair18 : start
# 0:42:50.009265 	 session_latest_time_wt_pair18
# 0:42:50.010454 	 {'num_clicks': 97136, 'hit_clicks': 1034, 'num_carts': 37850, 'hit_carts': 394, 'num_orders': 17856, 'hit_orders': 233, 'recall_clicks': '0.011', 'recall_carts': '0.010', 'recall_orders': '0.013', 'w_recall_clicks': '0.001', 'w_recall_carts': '0.003', 'w_recall_orders': '0.008', 'score': '0.012'}
# 0:42:50.023036 	 [make_candidate] session_latest_word2vec_pair18 : start
# 0:42:50.439364 	 [add_candidate] session_latest_word2vec_pair18 : start
# 0:42:54.000443 	 session_latest_word2vec_pair18
# 0:42:54.001884 	 {'num_clicks': 97136, 'hit_clicks': 755, 'num_carts': 37850, 'hit_carts': 287, 'num_orders': 17856, 'hit_orders': 131, 'recall_clicks': '0.008', 'recall_carts': '0.008', 'recall_orders': '0.007', 'w_recall_clicks': '0.001', 'w_recall_carts': '0.002', 'w_recall_orders': '0.004', 'score': '0.007'}
# 0:42:54.014708 	 [make_candidate] session_latest_pair18 : start
# 0:42:54.620016 	 [add_candidate] session_latest_pair18 : start
# 0:42:58.016227 	 session_latest_pair18
# 0:42:58.017504 	 {'num_clicks': 97136, 'hit_clicks': 825, 'num_carts': 37850, 'hit_carts': 318, 'num_orders': 17856, 'hit_orders': 251, 'recall_clicks': '0.008', 'recall_carts': '0.008', 'recall_orders': '0.014', 'w_recall_clicks': '0.001', 'w_recall_carts': '0.003', 'w_recall_orders': '0.008', 'score': '0.012'}
# 0:42:58.029827 	 [make_candidate] session_latest_type_wt_pair18 : start
# 0:42:58.557458 	 [add_candidate] session_latest_type_wt_pair18 : start
# 0:43:02.064432 	 session_latest_type_wt_pair18
# 0:43:02.065628 	 {'num_clicks': 97136, 'hit_clicks': 856, 'num_carts': 37850, 'hit_carts': 346, 'num_orders': 17856, 'hit_orders': 282, 'recall_clicks': '0.009', 'recall_carts': '0.009', 'recall_orders': '0.016', 'w_recall_clicks': '0.001', 'w_recall_carts': '0.003', 'w_recall_orders': '0.009', 'score': '0.013'}
# 0:43:02.077439 	 [make_candidate] session_latest_clicks2carts_pair18 : start
# 0:43:02.338936 	 [add_candidate] session_latest_clicks2carts_pair18 : start
# 0:43:05.605412 	 session_latest_clicks2carts_pair18
# 0:43:05.606605 	 {'num_clicks': 97136, 'hit_clicks': 474, 'num_carts': 37850, 'hit_carts': 204, 'num_orders': 17856, 'hit_orders': 142, 'recall_clicks': '0.005', 'recall_carts': '0.005', 'recall_orders': '0.008', 'w_recall_clicks': '0.000', 'w_recall_carts': '0.002', 'w_recall_orders': '0.005', 'score': '0.007'}
# 0:43:05.615787 	 [make_candidate] session_latest_clicks2orders_pair18 : start
# 0:43:05.977833 	 [add_candidate] session_latest_clicks2orders_pair18 : start
# 0:43:09.001570 	 session_latest_clicks2orders_pair18
# 0:43:09.002770 	 {'num_clicks': 97136, 'hit_clicks': 203, 'num_carts': 37850, 'hit_carts': 91, 'num_orders': 17856, 'hit_orders': 50, 'recall_clicks': '0.002', 'recall_carts': '0.002', 'recall_orders': '0.003', 'w_recall_clicks': '0.000', 'w_recall_carts': '0.001', 'w_recall_orders': '0.002', 'score': '0.003'}
# 0:43:09.010057 	 [make_candidate] session_latest_time_wt_pair19 : start
# 0:43:09.371227 	 [add_candidate] session_latest_time_wt_pair19 : start
# 0:43:12.897270 	 session_latest_time_wt_pair19
# 0:43:12.898416 	 {'num_clicks': 97136, 'hit_clicks': 1008, 'num_carts': 37850, 'hit_carts': 374, 'num_orders': 17856, 'hit_orders': 216, 'recall_clicks': '0.010', 'recall_carts': '0.010', 'recall_orders': '0.012', 'w_recall_clicks': '0.001', 'w_recall_carts': '0.003', 'w_recall_orders': '0.007', 'score': '0.011'}
# 0:43:12.912296 	 [make_candidate] session_latest_word2vec_pair19 : start
# 0:43:13.452192 	 [add_candidate] session_latest_word2vec_pair19 : start
# 0:43:16.910362 	 session_latest_word2vec_pair19
# 0:43:16.911552 	 {'num_clicks': 97136, 'hit_clicks': 709, 'num_carts': 37850, 'hit_carts': 297, 'num_orders': 17856, 'hit_orders': 143, 'recall_clicks': '0.007', 'recall_carts': '0.008', 'recall_orders': '0.008', 'w_recall_clicks': '0.001', 'w_recall_carts': '0.002', 'w_recall_orders': '0.005', 'score': '0.008'}
# 0:43:16.923535 	 [make_candidate] session_latest_pair19 : start
# 0:43:17.545348 	 [add_candidate] session_latest_pair19 : start
# 0:43:21.152572 	 session_latest_pair19
# 0:43:21.153734 	 {'num_clicks': 97136, 'hit_clicks': 810, 'num_carts': 37850, 'hit_carts': 311, 'num_orders': 17856, 'hit_orders': 224, 'recall_clicks': '0.008', 'recall_carts': '0.008', 'recall_orders': '0.013', 'w_recall_clicks': '0.001', 'w_recall_carts': '0.002', 'w_recall_orders': '0.008', 'score': '0.011'}
# 0:43:21.165553 	 [make_candidate] session_latest_type_wt_pair19 : start
# 0:43:21.718381 	 [add_candidate] session_latest_type_wt_pair19 : start
# 0:43:25.902934 	 session_latest_type_wt_pair19
# 0:43:25.904162 	 {'num_clicks': 97136, 'hit_clicks': 875, 'num_carts': 37850, 'hit_carts': 378, 'num_orders': 17856, 'hit_orders': 233, 'recall_clicks': '0.009', 'recall_carts': '0.010', 'recall_orders': '0.013', 'w_recall_clicks': '0.001', 'w_recall_carts': '0.003', 'w_recall_orders': '0.008', 'score': '0.012'}
# 0:43:25.917400 	 [make_candidate] session_latest_clicks2carts_pair19 : start
# 0:43:26.198774 	 [add_candidate] session_latest_clicks2carts_pair19 : start
# 0:43:30.257514 	 session_latest_clicks2carts_pair19
# 0:43:30.258865 	 {'num_clicks': 97136, 'hit_clicks': 396, 'num_carts': 37850, 'hit_carts': 208, 'num_orders': 17856, 'hit_orders': 122, 'recall_clicks': '0.004', 'recall_carts': '0.005', 'recall_orders': '0.007', 'w_recall_clicks': '0.000', 'w_recall_carts': '0.002', 'w_recall_orders': '0.004', 'score': '0.006'}
# 0:43:30.269987 	 [make_candidate] session_latest_clicks2orders_pair19 : start
# 0:43:30.593223 	 [add_candidate] session_latest_clicks2orders_pair19 : start
# 0:43:34.329071 	 session_latest_clicks2orders_pair19
# 0:43:34.330402 	 {'num_clicks': 97136, 'hit_clicks': 218, 'num_carts': 37850, 'hit_carts': 103, 'num_orders': 17856, 'hit_orders': 64, 'recall_clicks': '0.002', 'recall_carts': '0.003', 'recall_orders': '0.004', 'w_recall_clicks': '0.000', 'w_recall_carts': '0.001', 'w_recall_orders': '0.002', 'score': '0.003'}

# %%
results
# Out:
#                                    name num_clicks hit_clicks num_carts  \
# 0                      session_frequent      97136      29467     42864
# 0                        session_latest      97136      29677     42864
# 0         w2v_session_total_aid_vec_sim      97136      33577     43211
# 0   w2v_session_carts_total_aid_vec_sim      97136       4803     43211
# 0          session_latest_time_wt_pair0      97136       7618     37850
# ..                                  ...        ...        ...       ...
# 0        session_latest_word2vec_pair19      97136        709     37850
# 0                 session_latest_pair19      97136        810     37850
# 0         session_latest_type_wt_pair19      97136        875     37850
# 0    session_latest_clicks2carts_pair19      97136        396     37850
# 0   session_latest_clicks2orders_pair19      97136        218     37850
#
#    hit_carts num_orders hit_orders recall_clicks recall_carts recall_orders  \
# 0      10730      19985      10185         0.303        0.250         0.510
# 0      10822      19985       9838         0.306        0.252         0.492
# 0       8796      20082       5541         0.346        0.204         0.276
# 0       3151      20082       4854         0.049        0.073         0.242
# 0       2266      17856       1476         0.078        0.060         0.083
# ..       ...        ...        ...           ...          ...           ...
# 0        297      17856        143         0.007        0.008         0.008
# 0        311      17856        224         0.008        0.008         0.013
# 0        378      17856        233         0.009        0.010         0.013
# 0        208      17856        122         0.004        0.005         0.007
# 0        103      17856         64         0.002        0.003         0.004
#
#    w_recall_clicks w_recall_carts w_recall_orders  score
# 0            0.030          0.075           0.306  0.411
# 0            0.031          0.076           0.295  0.402
# 0            0.035          0.061           0.166  0.261
# 0            0.005          0.022           0.145  0.172
# 0            0.008          0.018           0.050  0.075
# ..             ...            ...             ...    ...
# 0            0.001          0.002           0.005  0.008
# 0            0.001          0.002           0.008  0.011
# 0            0.001          0.003           0.008  0.012
# 0            0.000          0.002           0.004  0.006
# 0            0.000          0.001           0.002  0.003
#
# [124 rows x 14 columns]

# %%
fig, axs = plt.subplots(1, 3)
sns.heatmap(results.set_index("name")[["recall_clicks"]].astype(float),
            annot=True, linewidths=.5, fmt="1.2f", cmap="Reds", cbar=False, ax=axs[0])
sns.heatmap(results.set_index("name")[["recall_carts"]].astype(float),
            annot=True, linewidths=.5, fmt="1.2f", cmap="Reds", cbar=False, ax=axs[1], yticklabels=False)
sns.heatmap(results.set_index("name")[["recall_orders"]].astype(float),
            annot=True, linewidths=.5, fmt="1.2f", cmap="Reds", cbar=False, ax=axs[2], yticklabels=False)
plt.savefig(cfg.output_dir + f'{cfg.exp_name}/candidate_strategy_recalls.png')

# %%
# 予測値を全て使えたときのrecall
valid_all = valid.drop_duplicates(subset= ["session", "aid"])
session_cnt_max = valid_all["session"].value_counts().max()
valid_all = valid_all.groupby("session")["aid"].apply(list).reset_index()

all_results = evaluate(valid_labels["clicks_labels"].tolist(),
                       valid_labels["carts_labels"].tolist(),
                       valid_labels["orders_labels"].tolist(),
                       valid_all["aid"].tolist(),
                       valid_all["aid"].tolist(),
                       valid_all["aid"].tolist(),
                       session_cnt_max)
logger.info("session_cnt_max")
logger.info(session_cnt_max)
logger.info("all_pred_results")
logger.info(all_results)
# Out:
# 0:43:42.190635 	 session_cnt_max
# 0:43:42.191971 	 403
# 0:43:42.192878 	 all_pred_results
# 0:43:42.193769 	 {'num_clicks': 97136, 'hit_clicks': 57419, 'num_carts': 43611, 'hit_carts': 19033, 'num_orders': 20109, 'hit_orders': 12867, 'recall_clicks': '0.591', 'recall_carts': '0.436', 'recall_orders': '0.640', 'w_recall_clicks': '0.059', 'w_recall_carts': '0.131', 'w_recall_orders': '0.384', 'score': '0.574'}
