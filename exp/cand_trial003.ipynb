# %% [markdown]
# # cand_trial003

# %%
import os
import sys
import traceback
import gc
import random
import pickle
import pathlib
import subprocess
from dataclasses import dataclass
from dotenv import load_dotenv
load_dotenv
sys.path.append(os.getenv('UTILS_PATH'))
from tqdm import tqdm
import multiprocessing
import inspect

import pandas as pd
import numpy as np
import itertools
import cudf
import lightgbm as lgb
import matplotlib.pyplot as plt
import seaborn as sns
import line_notify
import my_logger
from noglobal import noglobal
import optuna

# %% [markdown]
# # 設定

# %%
@dataclass
class Cfg:
    loglevel = "INFO"
    exp_name = "cand_trial003"
    seed = 42
    k = 20
    cand_n = 15
    type2id = {"clicks":0, "carts":1, "orders":2}
    id2type = {0:"clicks", 1:"carts", 2:"orders"}
    train_weeks = ["week3"]
    valid_week = "week4"
    valid_session_n = 100_000
    input_dir = os.getenv('INPUT_DIR')
    output_dir = os.getenv('OUTPUT_DIR')
    prep_dir = os.getenv("PREP_DIR")

cfg = Cfg()
os.makedirs(os.path.join(cfg.output_dir, cfg.exp_name), exist_ok=True)
os.makedirs(os.path.join(cfg.output_dir, cfg.exp_name, "cache"), exist_ok=True)
random.seed(cfg.seed)

# %%
class Cache:
    @noglobal(excepts=["cfg", "logger"])
    def __init__(self):
        self.cache_dir = (os.path.join(cfg.output_dir, cfg.exp_name, "cache"))
        self.cache_dir_path = pathlib.Path(self.cache_dir)
        self.caches = list(self.cache_dir_path.glob("*.pkl"))

    @noglobal(excepts=["cfg", "logger"])
    def get_abspath(self, filename):
        return (os.path.join(self.cache_dir, f"{cfg.exp_name}_{filename}"))
    
    @noglobal(excepts=["cfg", "logger"])
    def exists(self, path):
        return len([str(c) for c in self.caches if path == str(c)]) > 0

# %%
logger = my_logger.init_logger(cfg.exp_name)
cache = Cache()

# %%
@noglobal(excepts=["cfg", "logger"])
def evaluate(clicks_labels, carts_labels, orders_labels, 
             clicks_preds, carts_preds, orders_preds, k=20):

    num_clicks = 0
    num_carts = 0
    num_orders = 0
    hit_clicks = 0
    hit_carts = 0
    hit_orders = 0

    for i in range(len(clicks_labels)):
        clicks_label = clicks_labels[i]
        carts_label = carts_labels[i]
        orders_label = orders_labels[i]
        clicks_pred = clicks_preds[i]
        carts_pred = carts_preds[i]
        orders_pred = orders_preds[i]

        if type(clicks_pred) == list:
            clicks_pred = clicks_pred[:k]
        else:
            clicks_pred = []
        if type(carts_pred) == list:
            carts_pred = carts_pred[:k]
        else:
            carts_pred = []    
        if type(orders_pred) == list:
            orders_pred = orders_pred[:k]
        else:
            orders_pred = []

        if not np.isnan(clicks_label):
            num_clicks += 1
            hit_clicks += int(clicks_label in clicks_pred)

        if type(carts_label) == list:
            num_carts += min(len(carts_label), k)
            hit_carts += len(set(carts_pred) & set(carts_label))
            
        if type(orders_label) == list:
            num_orders += min(len(orders_label), k)
            hit_orders += len(set(orders_pred) & set(orders_label))


    recall_clicks = hit_clicks / num_clicks
    recall_carts = hit_carts / num_carts
    recall_orders = hit_orders / num_orders
    w_recall_clicks = recall_clicks * 0.10
    w_recall_carts = recall_carts * 0.30
    w_recall_orders = recall_orders * 0.60
    score = w_recall_clicks + w_recall_carts + w_recall_orders

    results = {}
    results["num_clicks"] = num_clicks
    results["hit_clicks"] = hit_clicks
    results["num_carts"] = num_carts
    results["hit_carts"] = hit_carts
    results["num_orders"] = num_orders
    results["hit_orders"] = hit_orders
    results["recall_clicks"] = format(recall_clicks, ".3f")
    results["recall_carts"] = format(recall_carts, ".3f")
    results["recall_orders"] = format(recall_orders, ".3f")
    results["w_recall_clicks"] = format(w_recall_clicks, ".3f")
    results["w_recall_carts"] = format(w_recall_carts, ".3f")
    results["w_recall_orders"] = format(w_recall_orders, ".3f")
    results["score"] = format(score, ".3f")

    return results

# %%
class Candidate:
    @noglobal(excepts=["cfg", "logger"])
    def __init__(self, pdf, week, labels=None):
        self.df = cudf.from_pandas(pdf)
        self.target_sessions = pdf["session"].unique().tolist()
        self.results = pd.DataFrame(columns=["name", "num_clicks", "hit_clicks", "num_carts", "hit_carts", "num_orders", "hit_orders", 
                                             "recall_clicks", "recall_carts", "recall_orders", "w_recall_clicks", "w_recall_carts", "w_recall_orders", "score"])
        self.output = pd.DataFrame(columns=["session", "aid"], dtype=int)
        self.labels = labels
        self.week = week
    
    @noglobal(excepts=["cfg", "logger"])
    def _entry(self, new_candidate_df, name, k):
        logger.info(f"[add_candidate] {name} : start")
        new_candidate_df = new_candidate_df.to_pandas()
        self.output = pd.concat([self.output, new_candidate_df[["session", "aid"]]])
        self.output = self.output.drop_duplicates(subset=["session", "aid"])

        if self.labels is not None:
            self._eval(new_candidate_df[["session", "aid"]], name, k)
    
    @noglobal(excepts=["cfg", "logger"])
    def _eval(self, new_candidate_df, name, k):
        new_candidate_df = new_candidate_df.groupby("session")["aid"].apply(list).reset_index()
        eval_df = pd.DataFrame(self.target_sessions, columns=["session"])
        eval_df = eval_df.merge(new_candidate_df, on=["session"], how="left")
        assert eval_df["session"].tolist() == self.labels["session"].tolist()
        eval_result = evaluate(self.labels["clicks_labels"].tolist(), self.labels["carts_labels"].tolist(), self.labels["orders_labels"].tolist(),
                               eval_df["aid"].tolist(), eval_df["aid"].tolist(), eval_df["aid"].tolist(), k)
        
        logger.info(name)
        logger.info(eval_result)
        self.results = pd.concat([self.results, pd.DataFrame([[name] + list(eval_result.values())], columns=["name"] + list(eval_result.keys()))])

    @noglobal(excepts=["cfg", "logger"])
    def add(self, strategy, name, usetypes=['clicks', 'carts', 'orders'], trans_map=None, k=20):
        logger.info(f"[make_candidate] {name} : start")
        candidate_df = self.df[self.df["type"].isin(usetypes)].copy()
        
        if strategy == "session_frequent":
            candidate_df = self._session_frequent(candidate_df, k)
        elif strategy == "session_latest":
            candidate_df = self._session_latest(candidate_df, k)
        elif strategy == "total_frequent":
            candidate_df = self._total_frequent(candidate_df, k)
        elif strategy == "w2v_session_total_aid_vec_sim":
            candidate_df = self._w2v_session_total_aid_vec_sim()
        elif strategy == "w2v_session_carts_total_aid_vec_sim":
            candidate_df = self._w2v_session_carts_total_aid_vec_sim()
        
        if trans_map is not None:
            candidate_df["aid"] = candidate_df["aid"].map(trans_map)
            candidate_df = candidate_df.dropna(subset=["aid"])
            
        self._entry(candidate_df, name, k)

    @noglobal(excepts=["cfg", "logger"])
    def _session_frequent(self, candidate_df, k):
        candidate_df = candidate_df.groupby(["session", "aid"])["ts"].count().reset_index()
        candidate_df.columns = ["session", "aid", "aid_count"]
        candidate_df = candidate_df.sort_values(["session", "aid_count", "aid"], ascending=(True, False, True))
        candidate_df = candidate_df[candidate_df.groupby("session")["aid_count"].cumcount() < k].copy()
        candidate_df = candidate_df[["session", "aid"]].copy()
        return candidate_df

    @noglobal(excepts=["cfg", "logger"])
    def _session_latest(self, candidate_df, k):
        candidate_df = candidate_df.sort_values(["session", "ts"], ascending=(True, False)).drop_duplicates(subset=["session", "aid"])
        candidate_df = candidate_df.sort_values(["session", "ts"], ascending=(True, False))[candidate_df.groupby("session")["ts"].cumcount() < k].copy()
        candidate_df = candidate_df[["session", "aid"]].copy()
        return candidate_df

    @noglobal(excepts=["cfg", "logger"])
    def _total_frequent(self, candidate_df, k):
        candidate_df = candidate_df.groupby("aid")["ts"].count().reset_index()
        candidate_df.columns = ["aid", "aid_count"]
        topk_freq_aids = candidate_df.sort_values("aid_count", ascending=False)["aid"].to_arrow().to_pylist()[:k]
        sessions = []
        aids = []
        for session, aid in itertools.product(self.target_sessions, topk_freq_aids):
            sessions.append(session)
            aids.append(aid)
        candidate_df = cudf.DataFrame({"session": sessions, "aid": aids})
        return candidate_df

    @noglobal(excepts=["cfg", "logger"])
    def _w2v_session_total_aid_vec_sim(self):
        if self.week is not None:
            candidate_df = pd.read_pickle(cfg.prep_dir + f"w2v_session_total_avg_similar_aids_{self.week}.pkl")
        else:
            candidate_df = pd.read_pickle(cfg.prep_dir + "w2v_session_total_avg_similar_aids.pkl")
        candidate_df = cudf.from_pandas(candidate_df)
        candidate_df = candidate_df[["session", "aid"]].copy()
        candidate_df = candidate_df[candidate_df["session"].isin(self.target_sessions)]
        return candidate_df

    @noglobal(excepts=["cfg", "logger"])
    def _w2v_session_carts_total_aid_vec_sim(self):
        if self.week is not None:
            candidate_df = pd.read_pickle(cfg.prep_dir + f"w2v_session_carts_total_avg_similar_aids_{self.week}.pkl")
        else:
            candidate_df = pd.read_pickle(cfg.prep_dir + "w2v_session_carts_total_avg_similar_aids.pkl")
        candidate_df = cudf.from_pandas(candidate_df)
        candidate_df = candidate_df[["session", "aid"]].copy()
        candidate_df = candidate_df[candidate_df["session"].isin(self.target_sessions)]
        return candidate_df

# %%
@noglobal(excepts=["cfg", "logger"])
def make_cand_df(sessions, week, labels=None, trans_maps=None):

    if labels is not None:
         cand = Candidate(sessions, week, labels)
    else:
        cand = Candidate(sessions, week)

    cand.add(strategy="session_frequent", name="session_frequent", k=15)
    cand.add(strategy="session_latest", name="session_latest", k=15)
    cand.add(strategy="w2v_session_total_aid_vec_sim", name="w2v_session_total_aid_vec_sim")
    cand.add(strategy="w2v_session_carts_total_aid_vec_sim", name="w2v_session_carts_total_aid_vec_sim")
    
    for i in range(20):
        cand.add(strategy="session_latest", trans_map=trans_maps[f"time_wt_pair{str(i)}"], name=f"session_latest_time_wt_pair{str(i)}", k=5)
        cand.add(strategy="session_latest", trans_map=trans_maps[f"word2vec_pair{str(i)}"], name=f"session_latest_word2vec_pair{str(i)}", k=5)
        cand.add(strategy="session_latest", trans_map=trans_maps[f"pair{str(i)}"], name=f"session_latest_pair{str(i)}", k=5)
        cand.add(strategy="session_latest", trans_map=trans_maps[f"type_wt_pair{str(i)}"], name=f"session_latest_type_wt_pair{str(i)}", k=5)
        cand.add(strategy="session_latest", trans_map=trans_maps[f"clicks2carts_pair{str(i)}"], name=f"session_latest_clicks2carts_pair{str(i)}", k=5)
        cand.add(strategy="session_latest", trans_map=trans_maps[f"clicks2orders_pair{str(i)}"], name=f"session_latest_clicks2orders_pair{str(i)}", k=5)

    if labels is not None:
        return cand.output, cand.results
    else:
        return cand.output

# %%
@noglobal(excepts=["cfg", "logger"])
def get_pair_df(name, wt_col, week):
    if week is not None:
        name = f"{name}_{week}"
    pair_df = pd.read_pickle(cfg.prep_dir + f"{name}.pkl")
    pair_df = pair_df.sort_values(["aid_x", wt_col], ascending=(True, False))
    return pair_df

@noglobal(excepts=["cfg", "logger"])
def get_pair_dict(name, wt_col, week):
    if week is not None:
        name = f"{name}_{week}"
    pair_df = pd.read_pickle(cfg.prep_dir + f"{name}.pkl")
    pair_df = pair_df.sort_values(["aid_x", wt_col], ascending=(True, False))
    pair_df = pair_df.groupby("aid_x").head(1)[["aid_x", "aid_y"]]
    pair_dict = {k: v for k, v in zip(pair_df["aid_x"].tolist(), pair_df["aid_y"].tolist())}
    return pair_dict

@noglobal(excepts=["cfg", "logger"])
def get_trans_maps(week=None):
    """
    aidを別のaidに置き換えるmapping辞書を取得する
    """
    trans_maps = {}
    
    pair_df_org = get_pair_df("co_visitation_matrix", "cnt", week)
    for i in range(20):
        pair_df = pair_df_org.groupby("aid_x").nth(i).reset_index()[["aid_x", "aid_y"]]
        pair_dict = {k: v for k, v in zip(pair_df["aid_x"].tolist(), pair_df["aid_y"].tolist())}
        trans_maps[f"pair{str(i)}"] = pair_dict
    
    pair_df_org = get_pair_df("co_visitation_matrix_time_weighted", "wt", week)
    for i in range(20):
        pair_df = pair_df_org.groupby("aid_x").nth(i).reset_index()[["aid_x", "aid_y"]]
        pair_dict = {k: v for k, v in zip(pair_df["aid_x"].tolist(), pair_df["aid_y"].tolist())}
        trans_maps[f"time_wt_pair{str(i)}"] = pair_dict

    pair_df_org = get_pair_df("co_visitation_matrix_type_weighted", "wt", week)
    for i in range(20):
        pair_df = pair_df_org.groupby("aid_x").nth(i).reset_index()[["aid_x", "aid_y"]]
        pair_dict = {k: v for k, v in zip(pair_df["aid_x"].tolist(), pair_df["aid_y"].tolist())}
        trans_maps[f"type_wt_pair{str(i)}"] = pair_dict

    pair_df_org = get_pair_df("co_visitation_matrix_clicks2carts", "cnt", week)
    for i in range(20):
        pair_df = pair_df_org.groupby("aid_x").nth(i).reset_index()[["aid_x", "aid_y"]]
        pair_dict = {k: v for k, v in zip(pair_df["aid_x"].tolist(), pair_df["aid_y"].tolist())}
        trans_maps[f"clicks2carts_pair{str(i)}"] = pair_dict

    pair_df_org = get_pair_df("co_visitation_matrix_clicks2orders", "cnt", week)
    for i in range(20):
        pair_df = pair_df_org.groupby("aid_x").nth(i).reset_index()[["aid_x", "aid_y"]]
        pair_dict = {k: v for k, v in zip(pair_df["aid_x"].tolist(), pair_df["aid_y"].tolist())}
        trans_maps[f"clicks2orders_pair{str(i)}"] = pair_dict

    pair_df_org = get_pair_df("word2vec_similar", "sim", None)
    for i in range(20):
        pair_df = pair_df_org.groupby("aid_x").nth(i).reset_index()[["aid_x", "aid_y"]]
        pair_dict = {k: v for k, v in zip(pair_df["aid_x"].tolist(), pair_df["aid_y"].tolist())}
        trans_maps[f"word2vec_pair{str(i)}"] = pair_dict

    with open(cfg.prep_dir + "matrix_factorization_embeddings_similar_top20.pkl", "rb") as f:
        nns = pickle.load(f)
    for i in range(20):
        pair_dict = {aid_x:aid_ys[i] for aid_x, aid_ys in enumerate(nns)}
        trans_maps[f"matrix_fact_pair{str(i)}"] = pair_dict

    return trans_maps

# %%
@noglobal(excepts=["cfg", "logger"])
def make_valid_data(trans_maps):
    valid_week = cfg.valid_week
    dfs = []
    
    logger.info(f"[make_valid] valid_week : {valid_week}")
    # データ読み込み
    logger.info("[make_valid] read_data : start")
    week_sessions = pd.read_pickle(os.getenv("PREP_DIR") + f"train_sessions_{valid_week}.pkl")
    week_labels = pd.read_pickle(os.getenv("PREP_DIR") + f"labels_{valid_week}.pkl")
    valid_session_ids = week_sessions["session"].unique().tolist()
    logger.info("[make_valid] read_data : end")

    # validに使うsessionを絞る (trainに存在するsessionを除外した上で設定した数に絞る)
    logger.info("[make_valid] valid_session_extract : start")
    valid_session_n = min(cfg.valid_session_n, len(valid_session_ids))
    valid_session_ids = random.sample(valid_session_ids, valid_session_n)
    week_sessions = week_sessions[week_sessions["session"].isin(valid_session_ids)].copy()
    week_labels = week_labels[week_labels["session"].isin(valid_session_ids)].copy()
    logger.info("[make_valid] valid_session_extract : end")

    # 候補選出
    logger.info("[make_valid] make_cand_df : start")
    valid, results = make_cand_df(week_sessions, valid_week, labels=week_labels, trans_maps=trans_maps)

    return valid, week_labels, results

# %%
logger.info("\n\nSTART\n\n")
cache_file = f"trans_maps.pkl"
cache_path = cache.get_abspath(cache_file)

if cache.exists(cache_path):
    logger.info(f"[{cache_file}] cache exists. load cache and skip process.")
    with open(cache_path, "rb") as f:
        trans_maps = pickle.load(f)
else:
    trans_maps = get_trans_maps(cfg.valid_week)
    with open(cache_path, "wb") as f:
        pickle.dump(trans_maps, f)

valid, valid_labels, results = make_valid_data(trans_maps)
# Out:
# 0:00:00.350041
#
# START
#
#
# 0:00:00.351751 	 [trans_maps.pkl] cache exists. load cache and skip process.
# 0:00:29.888904 	 [make_valid] valid_week : week4
# 0:00:29.890021 	 [make_valid] read_data : start
# 0:00:36.487128 	 [make_valid] read_data : end
# 0:00:36.488658 	 [make_valid] valid_session_extract : start
# 0:00:37.622825 	 [make_valid] valid_session_extract : end
# 0:00:37.624126 	 [make_valid] make_cand_df : start
# 0:00:37.684778 	 [make_candidate] session_frequent : start
# 0:00:37.931504 	 [add_candidate] session_frequent : start
# 0:00:39.967105 	 session_frequent
# 0:00:39.968386 	 {'num_clicks': 97136, 'hit_clicks': 29467, 'num_carts': 42864, 'hit_carts': 10730, 'num_orders': 19985, 'hit_orders': 10185, 'recall_clicks': '0.303', 'recall_carts': '0.250', 'recall_orders': '0.510', 'w_recall_clicks': '0.030', 'w_recall_carts': '0.075', 'w_recall_orders': '0.306', 'score': '0.411'}
# 0:00:39.984901 	 [make_candidate] session_latest : start
# 0:00:40.267175 	 [add_candidate] session_latest : start
# 0:00:41.854333 	 session_latest
# 0:00:41.855617 	 {'num_clicks': 97136, 'hit_clicks': 29677, 'num_carts': 42864, 'hit_carts': 10822, 'num_orders': 19985, 'hit_orders': 9838, 'recall_clicks': '0.306', 'recall_carts': '0.252', 'recall_orders': '0.492', 'w_recall_clicks': '0.031', 'w_recall_carts': '0.076', 'w_recall_orders': '0.295', 'score': '0.402'}
# 0:00:41.866322 	 [make_candidate] w2v_session_total_aid_vec_sim : start
# 0:00:45.958120 	 [add_candidate] w2v_session_total_aid_vec_sim : start
# 0:00:48.471318 	 w2v_session_total_aid_vec_sim
# 0:00:48.472539 	 {'num_clicks': 97136, 'hit_clicks': 33577, 'num_carts': 43211, 'hit_carts': 8796, 'num_orders': 20082, 'hit_orders': 5541, 'recall_clicks': '0.346', 'recall_carts': '0.204', 'recall_orders': '0.276', 'w_recall_clicks': '0.035', 'w_recall_carts': '0.061', 'w_recall_orders': '0.166', 'score': '0.261'}
# 0:00:48.502595 	 [make_candidate] w2v_session_carts_total_aid_vec_sim : start
# 0:00:49.456281 	 [add_candidate] w2v_session_carts_total_aid_vec_sim : start
# 0:00:50.263750 	 w2v_session_carts_total_aid_vec_sim
# 0:00:50.264963 	 {'num_clicks': 97136, 'hit_clicks': 4803, 'num_carts': 43211, 'hit_carts': 3151, 'num_orders': 20082, 'hit_orders': 4854, 'recall_clicks': '0.049', 'recall_carts': '0.073', 'recall_orders': '0.242', 'w_recall_clicks': '0.005', 'w_recall_carts': '0.022', 'w_recall_orders': '0.145', 'score': '0.172'}
# 0:00:50.272862 	 [make_candidate] session_latest_time_wt_pair0 : start
# 0:00:50.661115 	 [add_candidate] session_latest_time_wt_pair0 : start
# 0:00:52.515316 	 session_latest_time_wt_pair0
# 0:00:52.516919 	 {'num_clicks': 97136, 'hit_clicks': 7907, 'num_carts': 41843, 'hit_carts': 2522, 'num_orders': 19599, 'hit_orders': 1815, 'recall_clicks': '0.081', 'recall_carts': '0.060', 'recall_orders': '0.093', 'w_recall_clicks': '0.008', 'w_recall_carts': '0.018', 'w_recall_orders': '0.056', 'score': '0.082'}
# 0:00:52.529469 	 [make_candidate] session_latest_word2vec_pair0 : start
# 0:00:53.083909 	 [add_candidate] session_latest_word2vec_pair0 : start
# 0:00:55.347176 	 session_latest_word2vec_pair0
# 0:00:55.348605 	 {'num_clicks': 97136, 'hit_clicks': 4795, 'num_carts': 41843, 'hit_carts': 1674, 'num_orders': 19599, 'hit_orders': 1047, 'recall_clicks': '0.049', 'recall_carts': '0.040', 'recall_orders': '0.053', 'w_recall_clicks': '0.005', 'w_recall_carts': '0.012', 'w_recall_orders': '0.032', 'score': '0.049'}
# 0:00:55.362218 	 [make_candidate] session_latest_pair0 : start
# 0:00:55.842502 	 [add_candidate] session_latest_pair0 : start
# 0:00:57.693682 	 session_latest_pair0
# 0:00:57.695089 	 {'num_clicks': 97136, 'hit_clicks': 6836, 'num_carts': 41843, 'hit_carts': 2364, 'num_orders': 19599, 'hit_orders': 1768, 'recall_clicks': '0.070', 'recall_carts': '0.056', 'recall_orders': '0.090', 'w_recall_clicks': '0.007', 'w_recall_carts': '0.017', 'w_recall_orders': '0.054', 'score': '0.078'}
# 0:00:57.707629 	 [make_candidate] session_latest_type_wt_pair0 : start
# 0:00:58.248017 	 [add_candidate] session_latest_type_wt_pair0 : start
# 0:01:00.499167 	 session_latest_type_wt_pair0
# 0:01:00.500452 	 {'num_clicks': 97136, 'hit_clicks': 6743, 'num_carts': 41843, 'hit_carts': 2590, 'num_orders': 19599, 'hit_orders': 2083, 'recall_clicks': '0.069', 'recall_carts': '0.062', 'recall_orders': '0.106', 'w_recall_clicks': '0.007', 'w_recall_carts': '0.019', 'w_recall_orders': '0.064', 'score': '0.089'}
# 0:01:00.511579 	 [make_candidate] session_latest_clicks2carts_pair0 : start
# 0:01:00.832490 	 [add_candidate] session_latest_clicks2carts_pair0 : start
# 0:01:02.633128 	 session_latest_clicks2carts_pair0
# 0:01:02.634373 	 {'num_clicks': 97136, 'hit_clicks': 4314, 'num_carts': 41843, 'hit_carts': 1935, 'num_orders': 19599, 'hit_orders': 1460, 'recall_clicks': '0.044', 'recall_carts': '0.046', 'recall_orders': '0.074', 'w_recall_clicks': '0.004', 'w_recall_carts': '0.014', 'w_recall_orders': '0.045', 'score': '0.063'}
# 0:01:02.645376 	 [make_candidate] session_latest_clicks2orders_pair0 : start
# 0:01:03.082917 	 [add_candidate] session_latest_clicks2orders_pair0 : start
# 0:01:05.263257 	 session_latest_clicks2orders_pair0
# 0:01:05.264537 	 {'num_clicks': 97136, 'hit_clicks': 2625, 'num_carts': 41843, 'hit_carts': 1342, 'num_orders': 19599, 'hit_orders': 1010, 'recall_clicks': '0.027', 'recall_carts': '0.032', 'recall_orders': '0.052', 'w_recall_clicks': '0.003', 'w_recall_carts': '0.010', 'w_recall_orders': '0.031', 'score': '0.043'}
# 0:01:05.275691 	 [make_candidate] session_latest_time_wt_pair1 : start
# 0:01:05.823537 	 [add_candidate] session_latest_time_wt_pair1 : start
# 0:01:07.905525 	 session_latest_time_wt_pair1
# 0:01:07.907273 	 {'num_clicks': 97136, 'hit_clicks': 5676, 'num_carts': 41843, 'hit_carts': 1943, 'num_orders': 19599, 'hit_orders': 1326, 'recall_clicks': '0.058', 'recall_carts': '0.046', 'recall_orders': '0.068', 'w_recall_clicks': '0.006', 'w_recall_carts': '0.014', 'w_recall_orders': '0.041', 'score': '0.060'}
# 0:01:07.919546 	 [make_candidate] session_latest_word2vec_pair1 : start
# 0:01:08.288945 	 [add_candidate] session_latest_word2vec_pair1 : start
# 0:01:10.443121 	 session_latest_word2vec_pair1
# 0:01:10.444451 	 {'num_clicks': 97136, 'hit_clicks': 3331, 'num_carts': 41843, 'hit_carts': 1207, 'num_orders': 19599, 'hit_orders': 742, 'recall_clicks': '0.034', 'recall_carts': '0.029', 'recall_orders': '0.038', 'w_recall_clicks': '0.003', 'w_recall_carts': '0.009', 'w_recall_orders': '0.023', 'score': '0.035'}
# 0:01:10.456693 	 [make_candidate] session_latest_pair1 : start
# 0:01:10.932581 	 [add_candidate] session_latest_pair1 : start
# 0:01:13.404803 	 session_latest_pair1
# 0:01:13.406237 	 {'num_clicks': 97136, 'hit_clicks': 4859, 'num_carts': 41843, 'hit_carts': 1835, 'num_orders': 19599, 'hit_orders': 1293, 'recall_clicks': '0.050', 'recall_carts': '0.044', 'recall_orders': '0.066', 'w_recall_clicks': '0.005', 'w_recall_carts': '0.013', 'w_recall_orders': '0.040', 'score': '0.058'}
# 0:01:13.418575 	 [make_candidate] session_latest_type_wt_pair1 : start
# 0:01:14.003361 	 [add_candidate] session_latest_type_wt_pair1 : start
# 0:01:16.102034 	 session_latest_type_wt_pair1
# 0:01:16.103220 	 {'num_clicks': 97136, 'hit_clicks': 4836, 'num_carts': 41843, 'hit_carts': 1926, 'num_orders': 19599, 'hit_orders': 1497, 'recall_clicks': '0.050', 'recall_carts': '0.046', 'recall_orders': '0.076', 'w_recall_clicks': '0.005', 'w_recall_carts': '0.014', 'w_recall_orders': '0.046', 'score': '0.065'}
# 0:01:16.115876 	 [make_candidate] session_latest_clicks2carts_pair1 : start
# 0:01:16.545691 	 [add_candidate] session_latest_clicks2carts_pair1 : start
# 0:01:18.994510 	 session_latest_clicks2carts_pair1
# 0:01:18.995682 	 {'num_clicks': 97136, 'hit_clicks': 2999, 'num_carts': 41843, 'hit_carts': 1370, 'num_orders': 19599, 'hit_orders': 1033, 'recall_clicks': '0.031', 'recall_carts': '0.033', 'recall_orders': '0.053', 'w_recall_clicks': '0.003', 'w_recall_carts': '0.010', 'w_recall_orders': '0.032', 'score': '0.045'}
# 0:01:19.006747 	 [make_candidate] session_latest_clicks2orders_pair1 : start
# 0:01:19.223612 	 [add_candidate] session_latest_clicks2orders_pair1 : start
# 0:01:21.180440 	 session_latest_clicks2orders_pair1
# 0:01:21.181720 	 {'num_clicks': 97136, 'hit_clicks': 1644, 'num_carts': 41843, 'hit_carts': 799, 'num_orders': 19599, 'hit_orders': 602, 'recall_clicks': '0.017', 'recall_carts': '0.019', 'recall_orders': '0.031', 'w_recall_clicks': '0.002', 'w_recall_carts': '0.006', 'w_recall_orders': '0.018', 'score': '0.026'}
# 0:01:21.193854 	 [make_candidate] session_latest_time_wt_pair2 : start
# 0:01:21.632519 	 [add_candidate] session_latest_time_wt_pair2 : start
# 0:01:24.165026 	 session_latest_time_wt_pair2
# 0:01:24.166435 	 {'num_clicks': 97136, 'hit_clicks': 4490, 'num_carts': 41843, 'hit_carts': 1604, 'num_orders': 19599, 'hit_orders': 1131, 'recall_clicks': '0.046', 'recall_carts': '0.038', 'recall_orders': '0.058', 'w_recall_clicks': '0.005', 'w_recall_carts': '0.012', 'w_recall_orders': '0.035', 'score': '0.051'}
# 0:01:24.178176 	 [make_candidate] session_latest_word2vec_pair2 : start
# 0:01:24.687070 	 [add_candidate] session_latest_word2vec_pair2 : start
# 0:01:26.807395 	 session_latest_word2vec_pair2
# 0:01:26.808604 	 {'num_clicks': 97136, 'hit_clicks': 2722, 'num_carts': 41843, 'hit_carts': 1009, 'num_orders': 19599, 'hit_orders': 630, 'recall_clicks': '0.028', 'recall_carts': '0.024', 'recall_orders': '0.032', 'w_recall_clicks': '0.003', 'w_recall_carts': '0.007', 'w_recall_orders': '0.019', 'score': '0.029'}
# 0:01:26.821043 	 [make_candidate] session_latest_pair2 : start
# 0:01:27.381538 	 [add_candidate] session_latest_pair2 : start
# 0:01:29.478402 	 session_latest_pair2
# 0:01:29.479552 	 {'num_clicks': 97136, 'hit_clicks': 3942, 'num_carts': 41843, 'hit_carts': 1553, 'num_orders': 19599, 'hit_orders': 1121, 'recall_clicks': '0.041', 'recall_carts': '0.037', 'recall_orders': '0.057', 'w_recall_clicks': '0.004', 'w_recall_carts': '0.011', 'w_recall_orders': '0.034', 'score': '0.050'}
# 0:01:29.491677 	 [make_candidate] session_latest_type_wt_pair2 : start
# 0:01:30.017770 	 [add_candidate] session_latest_type_wt_pair2 : start
# 0:01:32.537040 	 session_latest_type_wt_pair2
# 0:01:32.538265 	 {'num_clicks': 97136, 'hit_clicks': 3764, 'num_carts': 41843, 'hit_carts': 1608, 'num_orders': 19599, 'hit_orders': 1217, 'recall_clicks': '0.039', 'recall_carts': '0.038', 'recall_orders': '0.062', 'w_recall_clicks': '0.004', 'w_recall_carts': '0.012', 'w_recall_orders': '0.037', 'score': '0.053'}
# 0:01:32.550544 	 [make_candidate] session_latest_clicks2carts_pair2 : start
# 0:01:32.850863 	 [add_candidate] session_latest_clicks2carts_pair2 : start
# 0:01:34.885106 	 session_latest_clicks2carts_pair2
# 0:01:34.886403 	 {'num_clicks': 97136, 'hit_clicks': 2338, 'num_carts': 41843, 'hit_carts': 1182, 'num_orders': 19599, 'hit_orders': 799, 'recall_clicks': '0.024', 'recall_carts': '0.028', 'recall_orders': '0.041', 'w_recall_clicks': '0.002', 'w_recall_carts': '0.008', 'w_recall_orders': '0.024', 'score': '0.035'}
# 0:01:34.897249 	 [make_candidate] session_latest_clicks2orders_pair2 : start
# 0:01:35.254553 	 [add_candidate] session_latest_clicks2orders_pair2 : start
# 0:01:37.613761 	 session_latest_clicks2orders_pair2
# 0:01:37.615364 	 {'num_clicks': 97136, 'hit_clicks': 1239, 'num_carts': 41843, 'hit_carts': 610, 'num_orders': 19599, 'hit_orders': 435, 'recall_clicks': '0.013', 'recall_carts': '0.015', 'recall_orders': '0.022', 'w_recall_clicks': '0.001', 'w_recall_carts': '0.004', 'w_recall_orders': '0.013', 'score': '0.019'}
# 0:01:37.626012 	 [make_candidate] session_latest_time_wt_pair3 : start
# 0:01:38.061949 	 [add_candidate] session_latest_time_wt_pair3 : start
# 0:01:40.195352 	 session_latest_time_wt_pair3
# 0:01:40.196676 	 {'num_clicks': 97136, 'hit_clicks': 3903, 'num_carts': 41843, 'hit_carts': 1543, 'num_orders': 19599, 'hit_orders': 955, 'recall_clicks': '0.040', 'recall_carts': '0.037', 'recall_orders': '0.049', 'w_recall_clicks': '0.004', 'w_recall_carts': '0.011', 'w_recall_orders': '0.029', 'score': '0.044'}
# 0:01:40.209180 	 [make_candidate] session_latest_word2vec_pair3 : start
# 0:01:40.745863 	 [add_candidate] session_latest_word2vec_pair3 : start
# 0:01:43.361086 	 session_latest_word2vec_pair3
# 0:01:43.362364 	 {'num_clicks': 97136, 'hit_clicks': 2163, 'num_carts': 41843, 'hit_carts': 852, 'num_orders': 19599, 'hit_orders': 560, 'recall_clicks': '0.022', 'recall_carts': '0.020', 'recall_orders': '0.029', 'w_recall_clicks': '0.002', 'w_recall_carts': '0.006', 'w_recall_orders': '0.017', 'score': '0.025'}
# 0:01:43.375606 	 [make_candidate] session_latest_pair3 : start
# 0:01:43.903255 	 [add_candidate] session_latest_pair3 : start
# 0:01:46.063385 	 session_latest_pair3
# 0:01:46.064700 	 {'num_clicks': 97136, 'hit_clicks': 3234, 'num_carts': 41843, 'hit_carts': 1287, 'num_orders': 19599, 'hit_orders': 937, 'recall_clicks': '0.033', 'recall_carts': '0.031', 'recall_orders': '0.048', 'w_recall_clicks': '0.003', 'w_recall_carts': '0.009', 'w_recall_orders': '0.029', 'score': '0.041'}
# 0:01:46.077572 	 [make_candidate] session_latest_type_wt_pair3 : start
# 0:01:46.582829 	 [add_candidate] session_latest_type_wt_pair3 : start
# 0:01:48.783445 	 session_latest_type_wt_pair3
# 0:01:48.784698 	 {'num_clicks': 97136, 'hit_clicks': 3271, 'num_carts': 41843, 'hit_carts': 1377, 'num_orders': 19599, 'hit_orders': 1081, 'recall_clicks': '0.034', 'recall_carts': '0.033', 'recall_orders': '0.055', 'w_recall_clicks': '0.003', 'w_recall_carts': '0.010', 'w_recall_orders': '0.033', 'score': '0.046'}
# 0:01:48.796865 	 [make_candidate] session_latest_clicks2carts_pair3 : start
# 0:01:49.021000 	 [add_candidate] session_latest_clicks2carts_pair3 : start
# 0:01:51.532100 	 session_latest_clicks2carts_pair3
# 0:01:51.533422 	 {'num_clicks': 97136, 'hit_clicks': 1846, 'num_carts': 41843, 'hit_carts': 971, 'num_orders': 19599, 'hit_orders': 661, 'recall_clicks': '0.019', 'recall_carts': '0.023', 'recall_orders': '0.034', 'w_recall_clicks': '0.002', 'w_recall_carts': '0.007', 'w_recall_orders': '0.020', 'score': '0.029'}
# 0:01:51.544521 	 [make_candidate] session_latest_clicks2orders_pair3 : start
# 0:01:51.874248 	 [add_candidate] session_latest_clicks2orders_pair3 : start
# 0:01:53.816366 	 session_latest_clicks2orders_pair3
# 0:01:53.817541 	 {'num_clicks': 97136, 'hit_clicks': 1022, 'num_carts': 41843, 'hit_carts': 543, 'num_orders': 19599, 'hit_orders': 368, 'recall_clicks': '0.011', 'recall_carts': '0.013', 'recall_orders': '0.019', 'w_recall_clicks': '0.001', 'w_recall_carts': '0.004', 'w_recall_orders': '0.011', 'score': '0.016'}
# 0:01:53.826802 	 [make_candidate] session_latest_time_wt_pair4 : start
# 0:01:54.189033 	 [add_candidate] session_latest_time_wt_pair4 : start
# 0:01:56.827964 	 session_latest_time_wt_pair4
# 0:01:56.829236 	 {'num_clicks': 97136, 'hit_clicks': 3362, 'num_carts': 41843, 'hit_carts': 1300, 'num_orders': 19599, 'hit_orders': 900, 'recall_clicks': '0.035', 'recall_carts': '0.031', 'recall_orders': '0.046', 'w_recall_clicks': '0.003', 'w_recall_carts': '0.009', 'w_recall_orders': '0.028', 'score': '0.040'}
# 0:01:56.841412 	 [make_candidate] session_latest_word2vec_pair4 : start
# 0:01:57.323341 	 [add_candidate] session_latest_word2vec_pair4 : start
# 0:01:59.530455 	 session_latest_word2vec_pair4
# 0:01:59.532046 	 {'num_clicks': 97136, 'hit_clicks': 1985, 'num_carts': 41843, 'hit_carts': 739, 'num_orders': 19599, 'hit_orders': 439, 'recall_clicks': '0.020', 'recall_carts': '0.018', 'recall_orders': '0.022', 'w_recall_clicks': '0.002', 'w_recall_carts': '0.005', 'w_recall_orders': '0.013', 'score': '0.021'}
# 0:01:59.543965 	 [make_candidate] session_latest_pair4 : start
# 0:02:00.052443 	 [add_candidate] session_latest_pair4 : start
# 0:02:02.278226 	 session_latest_pair4
# 0:02:02.279712 	 {'num_clicks': 97136, 'hit_clicks': 2817, 'num_carts': 41843, 'hit_carts': 1102, 'num_orders': 19599, 'hit_orders': 844, 'recall_clicks': '0.029', 'recall_carts': '0.026', 'recall_orders': '0.043', 'w_recall_clicks': '0.003', 'w_recall_carts': '0.008', 'w_recall_orders': '0.026', 'score': '0.037'}
# 0:02:02.292083 	 [make_candidate] session_latest_type_wt_pair4 : start
# 0:02:02.660770 	 [add_candidate] session_latest_type_wt_pair4 : start
# 0:02:05.293307 	 session_latest_type_wt_pair4
# 0:02:05.294720 	 {'num_clicks': 97136, 'hit_clicks': 2790, 'num_carts': 41843, 'hit_carts': 1133, 'num_orders': 19599, 'hit_orders': 924, 'recall_clicks': '0.029', 'recall_carts': '0.027', 'recall_orders': '0.047', 'w_recall_clicks': '0.003', 'w_recall_carts': '0.008', 'w_recall_orders': '0.028', 'score': '0.039'}
# 0:02:05.307836 	 [make_candidate] session_latest_clicks2carts_pair4 : start
# 0:02:05.683325 	 [add_candidate] session_latest_clicks2carts_pair4 : start
# 0:02:07.823671 	 session_latest_clicks2carts_pair4
# 0:02:07.825001 	 {'num_clicks': 97136, 'hit_clicks': 1664, 'num_carts': 41843, 'hit_carts': 801, 'num_orders': 19599, 'hit_orders': 522, 'recall_clicks': '0.017', 'recall_carts': '0.019', 'recall_orders': '0.027', 'w_recall_clicks': '0.002', 'w_recall_carts': '0.006', 'w_recall_orders': '0.016', 'score': '0.023'}
# 0:02:07.836106 	 [make_candidate] session_latest_clicks2orders_pair4 : start
# 0:02:08.016263 	 [add_candidate] session_latest_clicks2orders_pair4 : start
# 0:02:10.474296 	 session_latest_clicks2orders_pair4
# 0:02:10.475799 	 {'num_clicks': 97136, 'hit_clicks': 810, 'num_carts': 41843, 'hit_carts': 427, 'num_orders': 19599, 'hit_orders': 292, 'recall_clicks': '0.008', 'recall_carts': '0.010', 'recall_orders': '0.015', 'w_recall_clicks': '0.001', 'w_recall_carts': '0.003', 'w_recall_orders': '0.009', 'score': '0.013'}
# 0:02:10.486183 	 [make_candidate] session_latest_time_wt_pair5 : start
# 0:02:10.926398 	 [add_candidate] session_latest_time_wt_pair5 : start
# 0:02:13.251181 	 session_latest_time_wt_pair5
# 0:02:13.252853 	 {'num_clicks': 97136, 'hit_clicks': 2923, 'num_carts': 41843, 'hit_carts': 1145, 'num_orders': 19599, 'hit_orders': 745, 'recall_clicks': '0.030', 'recall_carts': '0.027', 'recall_orders': '0.038', 'w_recall_clicks': '0.003', 'w_recall_carts': '0.008', 'w_recall_orders': '0.023', 'score': '0.034'}
# 0:02:13.266221 	 [make_candidate] session_latest_word2vec_pair5 : start
# 0:02:13.773809 	 [add_candidate] session_latest_word2vec_pair5 : start
# 0:02:16.524013 	 session_latest_word2vec_pair5
# 0:02:16.525304 	 {'num_clicks': 97136, 'hit_clicks': 1869, 'num_carts': 41843, 'hit_carts': 703, 'num_orders': 19599, 'hit_orders': 447, 'recall_clicks': '0.019', 'recall_carts': '0.017', 'recall_orders': '0.023', 'w_recall_clicks': '0.002', 'w_recall_carts': '0.005', 'w_recall_orders': '0.014', 'score': '0.021'}
# 0:02:16.537595 	 [make_candidate] session_latest_pair5 : start
# 0:02:16.947917 	 [add_candidate] session_latest_pair5 : start
# 0:02:19.257812 	 session_latest_pair5
# 0:02:19.258951 	 {'num_clicks': 97136, 'hit_clicks': 2544, 'num_carts': 41843, 'hit_carts': 986, 'num_orders': 19599, 'hit_orders': 798, 'recall_clicks': '0.026', 'recall_carts': '0.024', 'recall_orders': '0.041', 'w_recall_clicks': '0.003', 'w_recall_carts': '0.007', 'w_recall_orders': '0.024', 'score': '0.034'}
# 0:02:19.273954 	 [make_candidate] session_latest_type_wt_pair5 : start
# 0:02:19.799710 	 [add_candidate] session_latest_type_wt_pair5 : start
# 0:02:22.195980 	 session_latest_type_wt_pair5
# 0:02:22.197450 	 {'num_clicks': 97136, 'hit_clicks': 2531, 'num_carts': 41843, 'hit_carts': 1016, 'num_orders': 19599, 'hit_orders': 830, 'recall_clicks': '0.026', 'recall_carts': '0.024', 'recall_orders': '0.042', 'w_recall_clicks': '0.003', 'w_recall_carts': '0.007', 'w_recall_orders': '0.025', 'score': '0.035'}
# 0:02:22.210492 	 [make_candidate] session_latest_clicks2carts_pair5 : start
# 0:02:22.501435 	 [add_candidate] session_latest_clicks2carts_pair5 : start
# 0:02:25.210675 	 session_latest_clicks2carts_pair5
# 0:02:25.211907 	 {'num_clicks': 97136, 'hit_clicks': 1392, 'num_carts': 41843, 'hit_carts': 646, 'num_orders': 19599, 'hit_orders': 457, 'recall_clicks': '0.014', 'recall_carts': '0.015', 'recall_orders': '0.023', 'w_recall_clicks': '0.001', 'w_recall_carts': '0.005', 'w_recall_orders': '0.014', 'score': '0.020'}
# 0:02:25.223160 	 [make_candidate] session_latest_clicks2orders_pair5 : start
# 0:02:25.598267 	 [add_candidate] session_latest_clicks2orders_pair5 : start
# 0:02:28.056460 	 session_latest_clicks2orders_pair5
# 0:02:28.057699 	 {'num_clicks': 97136, 'hit_clicks': 726, 'num_carts': 41843, 'hit_carts': 360, 'num_orders': 19599, 'hit_orders': 275, 'recall_clicks': '0.007', 'recall_carts': '0.009', 'recall_orders': '0.014', 'w_recall_clicks': '0.001', 'w_recall_carts': '0.003', 'w_recall_orders': '0.008', 'score': '0.012'}
# 0:02:28.067754 	 [make_candidate] session_latest_time_wt_pair6 : start
# 0:02:28.587134 	 [add_candidate] session_latest_time_wt_pair6 : start
# 0:02:31.722151 	 session_latest_time_wt_pair6
# 0:02:31.723414 	 {'num_clicks': 97136, 'hit_clicks': 2646, 'num_carts': 41843, 'hit_carts': 987, 'num_orders': 19599, 'hit_orders': 660, 'recall_clicks': '0.027', 'recall_carts': '0.024', 'recall_orders': '0.034', 'w_recall_clicks': '0.003', 'w_recall_carts': '0.007', 'w_recall_orders': '0.020', 'score': '0.030'}
# 0:02:31.736453 	 [make_candidate] session_latest_word2vec_pair6 : start
# 0:02:32.163373 	 [add_candidate] session_latest_word2vec_pair6 : start
# 0:02:34.832619 	 session_latest_word2vec_pair6
# 0:02:34.833851 	 {'num_clicks': 97136, 'hit_clicks': 1788, 'num_carts': 41843, 'hit_carts': 681, 'num_orders': 19599, 'hit_orders': 374, 'recall_clicks': '0.018', 'recall_carts': '0.016', 'recall_orders': '0.019', 'w_recall_clicks': '0.002', 'w_recall_carts': '0.005', 'w_recall_orders': '0.011', 'score': '0.018'}
# 0:02:34.846669 	 [make_candidate] session_latest_pair6 : start
# 0:02:35.368385 	 [add_candidate] session_latest_pair6 : start
# 0:02:38.054702 	 session_latest_pair6
# 0:02:38.056019 	 {'num_clicks': 97136, 'hit_clicks': 2222, 'num_carts': 41843, 'hit_carts': 914, 'num_orders': 19599, 'hit_orders': 684, 'recall_clicks': '0.023', 'recall_carts': '0.022', 'recall_orders': '0.035', 'w_recall_clicks': '0.002', 'w_recall_carts': '0.007', 'w_recall_orders': '0.021', 'score': '0.030'}
# 0:02:38.069466 	 [make_candidate] session_latest_type_wt_pair6 : start
# 0:02:38.471749 	 [add_candidate] session_latest_type_wt_pair6 : start
# 0:02:41.639078 	 session_latest_type_wt_pair6
# 0:02:41.640394 	 {'num_clicks': 97136, 'hit_clicks': 2313, 'num_carts': 41843, 'hit_carts': 976, 'num_orders': 19599, 'hit_orders': 810, 'recall_clicks': '0.024', 'recall_carts': '0.023', 'recall_orders': '0.041', 'w_recall_clicks': '0.002', 'w_recall_carts': '0.007', 'w_recall_orders': '0.025', 'score': '0.034'}
# 0:02:41.654545 	 [make_candidate] session_latest_clicks2carts_pair6 : start
# 0:02:42.052148 	 [add_candidate] session_latest_clicks2carts_pair6 : start
# 0:02:44.652778 	 session_latest_clicks2carts_pair6
# 0:02:44.654035 	 {'num_clicks': 97136, 'hit_clicks': 1263, 'num_carts': 41843, 'hit_carts': 584, 'num_orders': 19599, 'hit_orders': 431, 'recall_clicks': '0.013', 'recall_carts': '0.014', 'recall_orders': '0.022', 'w_recall_clicks': '0.001', 'w_recall_carts': '0.004', 'w_recall_orders': '0.013', 'score': '0.019'}
# 0:02:44.665936 	 [make_candidate] session_latest_clicks2orders_pair6 : start
# 0:02:44.906685 	 [add_candidate] session_latest_clicks2orders_pair6 : start
# 0:02:47.752473 	 session_latest_clicks2orders_pair6
# 0:02:47.753728 	 {'num_clicks': 97136, 'hit_clicks': 608, 'num_carts': 41843, 'hit_carts': 303, 'num_orders': 19599, 'hit_orders': 229, 'recall_clicks': '0.006', 'recall_carts': '0.007', 'recall_orders': '0.012', 'w_recall_clicks': '0.001', 'w_recall_carts': '0.002', 'w_recall_orders': '0.007', 'score': '0.010'}
# 0:02:47.763384 	 [make_candidate] session_latest_time_wt_pair7 : start
# 0:02:48.330397 	 [add_candidate] session_latest_time_wt_pair7 : start
# 0:02:51.086788 	 session_latest_time_wt_pair7
# 0:02:51.088026 	 {'num_clicks': 97136, 'hit_clicks': 2377, 'num_carts': 41843, 'hit_carts': 949, 'num_orders': 19599, 'hit_orders': 625, 'recall_clicks': '0.024', 'recall_carts': '0.023', 'recall_orders': '0.032', 'w_recall_clicks': '0.002', 'w_recall_carts': '0.007', 'w_recall_orders': '0.019', 'score': '0.028'}
# 0:02:51.100816 	 [make_candidate] session_latest_word2vec_pair7 : start
# 0:02:51.604534 	 [add_candidate] session_latest_word2vec_pair7 : start
# 0:02:54.852201 	 session_latest_word2vec_pair7
# 0:02:54.853591 	 {'num_clicks': 97136, 'hit_clicks': 1544, 'num_carts': 41843, 'hit_carts': 573, 'num_orders': 19599, 'hit_orders': 349, 'recall_clicks': '0.016', 'recall_carts': '0.014', 'recall_orders': '0.018', 'w_recall_clicks': '0.002', 'w_recall_carts': '0.004', 'w_recall_orders': '0.011', 'score': '0.016'}
# 0:02:54.866273 	 [make_candidate] session_latest_pair7 : start
# 0:02:55.271193 	 [add_candidate] session_latest_pair7 : start
# 0:02:58.125233 	 session_latest_pair7
# 0:02:58.127026 	 {'num_clicks': 97136, 'hit_clicks': 2063, 'num_carts': 41843, 'hit_carts': 847, 'num_orders': 19599, 'hit_orders': 608, 'recall_clicks': '0.021', 'recall_carts': '0.020', 'recall_orders': '0.031', 'w_recall_clicks': '0.002', 'w_recall_carts': '0.006', 'w_recall_orders': '0.019', 'score': '0.027'}
# 0:02:58.139548 	 [make_candidate] session_latest_type_wt_pair7 : start
# 0:02:58.601546 	 [add_candidate] session_latest_type_wt_pair7 : start
# 0:03:01.414852 	 session_latest_type_wt_pair7
# 0:03:01.416212 	 {'num_clicks': 97136, 'hit_clicks': 2047, 'num_carts': 41843, 'hit_carts': 844, 'num_orders': 19599, 'hit_orders': 664, 'recall_clicks': '0.021', 'recall_carts': '0.020', 'recall_orders': '0.034', 'w_recall_clicks': '0.002', 'w_recall_carts': '0.006', 'w_recall_orders': '0.020', 'score': '0.028'}
# 0:03:01.428899 	 [make_candidate] session_latest_clicks2carts_pair7 : start
# 0:03:01.660820 	 [add_candidate] session_latest_clicks2carts_pair7 : start
# 0:03:04.789201 	 session_latest_clicks2carts_pair7
# 0:03:04.790454 	 {'num_clicks': 97136, 'hit_clicks': 1108, 'num_carts': 41843, 'hit_carts': 553, 'num_orders': 19599, 'hit_orders': 399, 'recall_clicks': '0.011', 'recall_carts': '0.013', 'recall_orders': '0.020', 'w_recall_clicks': '0.001', 'w_recall_carts': '0.004', 'w_recall_orders': '0.012', 'score': '0.017'}
# 0:03:04.802443 	 [make_candidate] session_latest_clicks2orders_pair7 : start
# 0:03:05.171721 	 [add_candidate] session_latest_clicks2orders_pair7 : start
# 0:03:07.640766 	 session_latest_clicks2orders_pair7
# 0:03:07.642034 	 {'num_clicks': 97136, 'hit_clicks': 566, 'num_carts': 41843, 'hit_carts': 274, 'num_orders': 19599, 'hit_orders': 195, 'recall_clicks': '0.006', 'recall_carts': '0.007', 'recall_orders': '0.010', 'w_recall_clicks': '0.001', 'w_recall_carts': '0.002', 'w_recall_orders': '0.006', 'score': '0.009'}
# 0:03:07.651739 	 [make_candidate] session_latest_time_wt_pair8 : start
# 0:03:08.180251 	 [add_candidate] session_latest_time_wt_pair8 : start
# 0:03:11.446225 	 session_latest_time_wt_pair8
# 0:03:11.447400 	 {'num_clicks': 97136, 'hit_clicks': 2273, 'num_carts': 41843, 'hit_carts': 869, 'num_orders': 19599, 'hit_orders': 592, 'recall_clicks': '0.023', 'recall_carts': '0.021', 'recall_orders': '0.030', 'w_recall_clicks': '0.002', 'w_recall_carts': '0.006', 'w_recall_orders': '0.018', 'score': '0.027'}
# 0:03:11.459859 	 [make_candidate] session_latest_word2vec_pair8 : start
# 0:03:11.861507 	 [add_candidate] session_latest_word2vec_pair8 : start
# 0:03:14.819701 	 session_latest_word2vec_pair8
# 0:03:14.821030 	 {'num_clicks': 97136, 'hit_clicks': 1439, 'num_carts': 41843, 'hit_carts': 551, 'num_orders': 19599, 'hit_orders': 319, 'recall_clicks': '0.015', 'recall_carts': '0.013', 'recall_orders': '0.016', 'w_recall_clicks': '0.001', 'w_recall_carts': '0.004', 'w_recall_orders': '0.010', 'score': '0.015'}
# 0:03:14.834836 	 [make_candidate] session_latest_pair8 : start
# 0:03:15.350599 	 [add_candidate] session_latest_pair8 : start
# 0:03:18.636358 	 session_latest_pair8
# 0:03:18.637610 	 {'num_clicks': 97136, 'hit_clicks': 2005, 'num_carts': 41843, 'hit_carts': 808, 'num_orders': 19599, 'hit_orders': 585, 'recall_clicks': '0.021', 'recall_carts': '0.019', 'recall_orders': '0.030', 'w_recall_clicks': '0.002', 'w_recall_carts': '0.006', 'w_recall_orders': '0.018', 'score': '0.026'}
# 0:03:18.649722 	 [make_candidate] session_latest_type_wt_pair8 : start
# 0:03:19.094440 	 [add_candidate] session_latest_type_wt_pair8 : start
# 0:03:21.947183 	 session_latest_type_wt_pair8
# 0:03:21.948524 	 {'num_clicks': 97136, 'hit_clicks': 1903, 'num_carts': 41843, 'hit_carts': 838, 'num_orders': 19599, 'hit_orders': 667, 'recall_clicks': '0.020', 'recall_carts': '0.020', 'recall_orders': '0.034', 'w_recall_clicks': '0.002', 'w_recall_carts': '0.006', 'w_recall_orders': '0.020', 'score': '0.028'}
# 0:03:21.961115 	 [make_candidate] session_latest_clicks2carts_pair8 : start
# 0:03:22.356486 	 [add_candidate] session_latest_clicks2carts_pair8 : start
# 0:03:25.139644 	 session_latest_clicks2carts_pair8
# 0:03:25.140931 	 {'num_clicks': 97136, 'hit_clicks': 1036, 'num_carts': 41843, 'hit_carts': 516, 'num_orders': 19599, 'hit_orders': 366, 'recall_clicks': '0.011', 'recall_carts': '0.012', 'recall_orders': '0.019', 'w_recall_clicks': '0.001', 'w_recall_carts': '0.004', 'w_recall_orders': '0.011', 'score': '0.016'}
# 0:03:25.152864 	 [make_candidate] session_latest_clicks2orders_pair8 : start
# 0:03:25.511743 	 [add_candidate] session_latest_clicks2orders_pair8 : start
# 0:03:28.468362 	 session_latest_clicks2orders_pair8
# 0:03:28.469707 	 {'num_clicks': 97136, 'hit_clicks': 503, 'num_carts': 41843, 'hit_carts': 252, 'num_orders': 19599, 'hit_orders': 185, 'recall_clicks': '0.005', 'recall_carts': '0.006', 'recall_orders': '0.009', 'w_recall_clicks': '0.001', 'w_recall_carts': '0.002', 'w_recall_orders': '0.006', 'score': '0.008'}
# 0:03:28.479366 	 [make_candidate] session_latest_time_wt_pair9 : start
# 0:03:28.993222 	 [add_candidate] session_latest_time_wt_pair9 : start
# 0:03:31.802633 	 session_latest_time_wt_pair9
# 0:03:31.803993 	 {'num_clicks': 97136, 'hit_clicks': 2081, 'num_carts': 41843, 'hit_carts': 814, 'num_orders': 19599, 'hit_orders': 610, 'recall_clicks': '0.021', 'recall_carts': '0.019', 'recall_orders': '0.031', 'w_recall_clicks': '0.002', 'w_recall_carts': '0.006', 'w_recall_orders': '0.019', 'score': '0.027'}
# 0:03:31.816398 	 [make_candidate] session_latest_word2vec_pair9 : start
# 0:03:32.223924 	 [add_candidate] session_latest_word2vec_pair9 : start
# 0:03:35.496427 	 session_latest_word2vec_pair9
# 0:03:35.497669 	 {'num_clicks': 97136, 'hit_clicks': 1277, 'num_carts': 41843, 'hit_carts': 486, 'num_orders': 19599, 'hit_orders': 290, 'recall_clicks': '0.013', 'recall_carts': '0.012', 'recall_orders': '0.015', 'w_recall_clicks': '0.001', 'w_recall_carts': '0.003', 'w_recall_orders': '0.009', 'score': '0.014'}
# 0:03:35.510133 	 [make_candidate] session_latest_pair9 : start
# 0:03:35.986608 	 [add_candidate] session_latest_pair9 : start
# 0:03:38.887594 	 session_latest_pair9
# 0:03:38.889196 	 {'num_clicks': 97136, 'hit_clicks': 1806, 'num_carts': 41843, 'hit_carts': 755, 'num_orders': 19599, 'hit_orders': 539, 'recall_clicks': '0.019', 'recall_carts': '0.018', 'recall_orders': '0.028', 'w_recall_clicks': '0.002', 'w_recall_carts': '0.005', 'w_recall_orders': '0.017', 'score': '0.024'}
# 0:03:38.902133 	 [make_candidate] session_latest_type_wt_pair9 : start
# 0:03:39.329219 	 [add_candidate] session_latest_type_wt_pair9 : start
# 0:03:42.261468 	 session_latest_type_wt_pair9
# 0:03:42.262650 	 {'num_clicks': 97136, 'hit_clicks': 1830, 'num_carts': 41843, 'hit_carts': 759, 'num_orders': 19599, 'hit_orders': 637, 'recall_clicks': '0.019', 'recall_carts': '0.018', 'recall_orders': '0.033', 'w_recall_clicks': '0.002', 'w_recall_carts': '0.005', 'w_recall_orders': '0.020', 'score': '0.027'}
# 0:03:42.275673 	 [make_candidate] session_latest_clicks2carts_pair9 : start
# 0:03:42.649181 	 [add_candidate] session_latest_clicks2carts_pair9 : start
# 0:03:45.881991 	 session_latest_clicks2carts_pair9
# 0:03:45.883285 	 {'num_clicks': 97136, 'hit_clicks': 936, 'num_carts': 41843, 'hit_carts': 449, 'num_orders': 19599, 'hit_orders': 332, 'recall_clicks': '0.010', 'recall_carts': '0.011', 'recall_orders': '0.017', 'w_recall_clicks': '0.001', 'w_recall_carts': '0.003', 'w_recall_orders': '0.010', 'score': '0.014'}
# 0:03:45.894713 	 [make_candidate] session_latest_clicks2orders_pair9 : start
# 0:03:46.214592 	 [add_candidate] session_latest_clicks2orders_pair9 : start
# 0:03:48.822054 	 session_latest_clicks2orders_pair9
# 0:03:48.823375 	 {'num_clicks': 97136, 'hit_clicks': 441, 'num_carts': 41843, 'hit_carts': 259, 'num_orders': 19599, 'hit_orders': 180, 'recall_clicks': '0.005', 'recall_carts': '0.006', 'recall_orders': '0.009', 'w_recall_clicks': '0.000', 'w_recall_carts': '0.002', 'w_recall_orders': '0.006', 'score': '0.008'}
# 0:03:48.833012 	 [make_candidate] session_latest_time_wt_pair10 : start
# 0:03:49.271911 	 [add_candidate] session_latest_time_wt_pair10 : start
# 0:03:52.690503 	 session_latest_time_wt_pair10
# 0:03:52.691943 	 {'num_clicks': 97136, 'hit_clicks': 1969, 'num_carts': 41843, 'hit_carts': 754, 'num_orders': 19599, 'hit_orders': 538, 'recall_clicks': '0.020', 'recall_carts': '0.018', 'recall_orders': '0.027', 'w_recall_clicks': '0.002', 'w_recall_carts': '0.005', 'w_recall_orders': '0.016', 'score': '0.024'}
# 0:03:52.706027 	 [make_candidate] session_latest_word2vec_pair10 : start
# 0:03:53.197907 	 [add_candidate] session_latest_word2vec_pair10 : start
# 0:03:56.123382 	 session_latest_word2vec_pair10
# 0:03:56.124725 	 {'num_clicks': 97136, 'hit_clicks': 1213, 'num_carts': 41843, 'hit_carts': 467, 'num_orders': 19599, 'hit_orders': 325, 'recall_clicks': '0.012', 'recall_carts': '0.011', 'recall_orders': '0.017', 'w_recall_clicks': '0.001', 'w_recall_carts': '0.003', 'w_recall_orders': '0.010', 'score': '0.015'}
# 0:03:56.138031 	 [make_candidate] session_latest_pair10 : start
# 0:03:56.512503 	 [add_candidate] session_latest_pair10 : start
# 0:03:59.500763 	 session_latest_pair10
# 0:03:59.502053 	 {'num_clicks': 97136, 'hit_clicks': 1586, 'num_carts': 41843, 'hit_carts': 678, 'num_orders': 19599, 'hit_orders': 469, 'recall_clicks': '0.016', 'recall_carts': '0.016', 'recall_orders': '0.024', 'w_recall_clicks': '0.002', 'w_recall_carts': '0.005', 'w_recall_orders': '0.014', 'score': '0.021'}
# 0:03:59.514435 	 [make_candidate] session_latest_type_wt_pair10 : start
# 0:04:00.002916 	 [add_candidate] session_latest_type_wt_pair10 : start
# 0:04:03.359761 	 session_latest_type_wt_pair10
# 0:04:03.361272 	 {'num_clicks': 97136, 'hit_clicks': 1677, 'num_carts': 41843, 'hit_carts': 733, 'num_orders': 19599, 'hit_orders': 594, 'recall_clicks': '0.017', 'recall_carts': '0.018', 'recall_orders': '0.030', 'w_recall_clicks': '0.002', 'w_recall_carts': '0.005', 'w_recall_orders': '0.018', 'score': '0.025'}
# 0:04:03.375733 	 [make_candidate] session_latest_clicks2carts_pair10 : start
# 0:04:03.641417 	 [add_candidate] session_latest_clicks2carts_pair10 : start
# 0:04:06.476102 	 session_latest_clicks2carts_pair10
# 0:04:06.477447 	 {'num_clicks': 97136, 'hit_clicks': 896, 'num_carts': 41843, 'hit_carts': 413, 'num_orders': 19599, 'hit_orders': 326, 'recall_clicks': '0.009', 'recall_carts': '0.010', 'recall_orders': '0.017', 'w_recall_clicks': '0.001', 'w_recall_carts': '0.003', 'w_recall_orders': '0.010', 'score': '0.014'}
# 0:04:06.490234 	 [make_candidate] session_latest_clicks2orders_pair10 : start
# 0:04:06.812406 	 [add_candidate] session_latest_clicks2orders_pair10 : start
# 0:04:09.471138 	 session_latest_clicks2orders_pair10
# 0:04:09.472339 	 {'num_clicks': 97136, 'hit_clicks': 435, 'num_carts': 41843, 'hit_carts': 229, 'num_orders': 19599, 'hit_orders': 164, 'recall_clicks': '0.004', 'recall_carts': '0.005', 'recall_orders': '0.008', 'w_recall_clicks': '0.000', 'w_recall_carts': '0.002', 'w_recall_orders': '0.005', 'score': '0.007'}
# 0:04:09.481835 	 [make_candidate] session_latest_time_wt_pair11 : start
# 0:04:09.892966 	 [add_candidate] session_latest_time_wt_pair11 : start
# 0:04:13.230727 	 session_latest_time_wt_pair11
# 0:04:13.232013 	 {'num_clicks': 97136, 'hit_clicks': 1756, 'num_carts': 41843, 'hit_carts': 726, 'num_orders': 19599, 'hit_orders': 482, 'recall_clicks': '0.018', 'recall_carts': '0.017', 'recall_orders': '0.025', 'w_recall_clicks': '0.002', 'w_recall_carts': '0.005', 'w_recall_orders': '0.015', 'score': '0.022'}
# 0:04:13.246033 	 [make_candidate] session_latest_word2vec_pair11 : start
# 0:04:13.768936 	 [add_candidate] session_latest_word2vec_pair11 : start
# 0:04:16.854018 	 session_latest_word2vec_pair11
# 0:04:16.855515 	 {'num_clicks': 97136, 'hit_clicks': 1122, 'num_carts': 41843, 'hit_carts': 482, 'num_orders': 19599, 'hit_orders': 264, 'recall_clicks': '0.012', 'recall_carts': '0.012', 'recall_orders': '0.013', 'w_recall_clicks': '0.001', 'w_recall_carts': '0.003', 'w_recall_orders': '0.008', 'score': '0.013'}
# 0:04:16.868957 	 [make_candidate] session_latest_pair11 : start
# 0:04:17.279900 	 [add_candidate] session_latest_pair11 : start
# 0:04:20.744362 	 session_latest_pair11
# 0:04:20.745857 	 {'num_clicks': 97136, 'hit_clicks': 1473, 'num_carts': 41843, 'hit_carts': 659, 'num_orders': 19599, 'hit_orders': 465, 'recall_clicks': '0.015', 'recall_carts': '0.016', 'recall_orders': '0.024', 'w_recall_clicks': '0.002', 'w_recall_carts': '0.005', 'w_recall_orders': '0.014', 'score': '0.020'}
# 0:04:20.758346 	 [make_candidate] session_latest_type_wt_pair11 : start
# 0:04:21.285435 	 [add_candidate] session_latest_type_wt_pair11 : start
# 0:04:24.442274 	 session_latest_type_wt_pair11
# 0:04:24.443518 	 {'num_clicks': 97136, 'hit_clicks': 1569, 'num_carts': 41843, 'hit_carts': 677, 'num_orders': 19599, 'hit_orders': 565, 'recall_clicks': '0.016', 'recall_carts': '0.016', 'recall_orders': '0.029', 'w_recall_clicks': '0.002', 'w_recall_carts': '0.005', 'w_recall_orders': '0.017', 'score': '0.024'}
# 0:04:24.457244 	 [make_candidate] session_latest_clicks2carts_pair11 : start
# 0:04:24.884816 	 [add_candidate] session_latest_clicks2carts_pair11 : start
# 0:04:28.251941 	 session_latest_clicks2carts_pair11
# 0:04:28.253216 	 {'num_clicks': 97136, 'hit_clicks': 793, 'num_carts': 41843, 'hit_carts': 367, 'num_orders': 19599, 'hit_orders': 271, 'recall_clicks': '0.008', 'recall_carts': '0.009', 'recall_orders': '0.014', 'w_recall_clicks': '0.001', 'w_recall_carts': '0.003', 'w_recall_orders': '0.008', 'score': '0.012'}
# 0:04:28.264320 	 [make_candidate] session_latest_clicks2orders_pair11 : start
# 0:04:28.476255 	 [add_candidate] session_latest_clicks2orders_pair11 : start
# 0:04:31.218392 	 session_latest_clicks2orders_pair11
# 0:04:31.219557 	 {'num_clicks': 97136, 'hit_clicks': 359, 'num_carts': 41843, 'hit_carts': 202, 'num_orders': 19599, 'hit_orders': 159, 'recall_clicks': '0.004', 'recall_carts': '0.005', 'recall_orders': '0.008', 'w_recall_clicks': '0.000', 'w_recall_carts': '0.001', 'w_recall_orders': '0.005', 'score': '0.007'}
# 0:04:31.228796 	 [make_candidate] session_latest_time_wt_pair12 : start
# 0:04:31.828781 	 [add_candidate] session_latest_time_wt_pair12 : start
# 0:04:34.981481 	 session_latest_time_wt_pair12
# 0:04:34.983028 	 {'num_clicks': 97136, 'hit_clicks': 1710, 'num_carts': 41843, 'hit_carts': 721, 'num_orders': 19599, 'hit_orders': 484, 'recall_clicks': '0.018', 'recall_carts': '0.017', 'recall_orders': '0.025', 'w_recall_clicks': '0.002', 'w_recall_carts': '0.005', 'w_recall_orders': '0.015', 'score': '0.022'}
# 0:04:34.996739 	 [make_candidate] session_latest_word2vec_pair12 : start
# 0:04:35.450188 	 [add_candidate] session_latest_word2vec_pair12 : start
# 0:04:39.004329 	 session_latest_word2vec_pair12
# 0:04:39.005678 	 {'num_clicks': 97136, 'hit_clicks': 1112, 'num_carts': 41843, 'hit_carts': 441, 'num_orders': 19599, 'hit_orders': 277, 'recall_clicks': '0.011', 'recall_carts': '0.011', 'recall_orders': '0.014', 'w_recall_clicks': '0.001', 'w_recall_carts': '0.003', 'w_recall_orders': '0.008', 'score': '0.013'}
# 0:04:39.018759 	 [make_candidate] session_latest_pair12 : start
# 0:04:39.547740 	 [add_candidate] session_latest_pair12 : start
# 0:04:42.724355 	 session_latest_pair12
# 0:04:42.725737 	 {'num_clicks': 97136, 'hit_clicks': 1407, 'num_carts': 41843, 'hit_carts': 601, 'num_orders': 19599, 'hit_orders': 414, 'recall_clicks': '0.014', 'recall_carts': '0.014', 'recall_orders': '0.021', 'w_recall_clicks': '0.001', 'w_recall_carts': '0.004', 'w_recall_orders': '0.013', 'score': '0.018'}
# 0:04:42.739587 	 [make_candidate] session_latest_type_wt_pair12 : start
# 0:04:43.206439 	 [add_candidate] session_latest_type_wt_pair12 : start
# 0:04:46.832483 	 session_latest_type_wt_pair12
# 0:04:46.833707 	 {'num_clicks': 97136, 'hit_clicks': 1497, 'num_carts': 41843, 'hit_carts': 625, 'num_orders': 19599, 'hit_orders': 527, 'recall_clicks': '0.015', 'recall_carts': '0.015', 'recall_orders': '0.027', 'w_recall_clicks': '0.002', 'w_recall_carts': '0.004', 'w_recall_orders': '0.016', 'score': '0.022'}
# 0:04:46.845962 	 [make_candidate] session_latest_clicks2carts_pair12 : start
# 0:04:47.232441 	 [add_candidate] session_latest_clicks2carts_pair12 : start
# 0:04:50.292718 	 session_latest_clicks2carts_pair12
# 0:04:50.294117 	 {'num_clicks': 97136, 'hit_clicks': 727, 'num_carts': 41843, 'hit_carts': 357, 'num_orders': 19599, 'hit_orders': 263, 'recall_clicks': '0.007', 'recall_carts': '0.009', 'recall_orders': '0.013', 'w_recall_clicks': '0.001', 'w_recall_carts': '0.003', 'w_recall_orders': '0.008', 'score': '0.011'}
# 0:04:50.306490 	 [make_candidate] session_latest_clicks2orders_pair12 : start
# 0:04:50.572104 	 [add_candidate] session_latest_clicks2orders_pair12 : start
# 0:04:53.777852 	 session_latest_clicks2orders_pair12
# 0:04:53.779119 	 {'num_clicks': 97136, 'hit_clicks': 333, 'num_carts': 41843, 'hit_carts': 185, 'num_orders': 19599, 'hit_orders': 140, 'recall_clicks': '0.003', 'recall_carts': '0.004', 'recall_orders': '0.007', 'w_recall_clicks': '0.000', 'w_recall_carts': '0.001', 'w_recall_orders': '0.004', 'score': '0.006'}
# 0:04:53.789703 	 [make_candidate] session_latest_time_wt_pair13 : start
# 0:04:54.400118 	 [add_candidate] session_latest_time_wt_pair13 : start
# 0:04:57.780415 	 session_latest_time_wt_pair13
# 0:04:57.782198 	 {'num_clicks': 97136, 'hit_clicks': 1549, 'num_carts': 41843, 'hit_carts': 638, 'num_orders': 19599, 'hit_orders': 474, 'recall_clicks': '0.016', 'recall_carts': '0.015', 'recall_orders': '0.024', 'w_recall_clicks': '0.002', 'w_recall_carts': '0.005', 'w_recall_orders': '0.015', 'score': '0.021'}
# 0:04:57.795006 	 [make_candidate] session_latest_word2vec_pair13 : start
# 0:04:58.199523 	 [add_candidate] session_latest_word2vec_pair13 : start
# 0:05:01.450120 	 session_latest_word2vec_pair13
# 0:05:01.451322 	 {'num_clicks': 97136, 'hit_clicks': 1039, 'num_carts': 41843, 'hit_carts': 429, 'num_orders': 19599, 'hit_orders': 235, 'recall_clicks': '0.011', 'recall_carts': '0.010', 'recall_orders': '0.012', 'w_recall_clicks': '0.001', 'w_recall_carts': '0.003', 'w_recall_orders': '0.007', 'score': '0.011'}
# 0:05:01.464916 	 [make_candidate] session_latest_pair13 : start
# 0:05:02.022204 	 [add_candidate] session_latest_pair13 : start
# 0:05:05.742576 	 session_latest_pair13
# 0:05:05.743875 	 {'num_clicks': 97136, 'hit_clicks': 1308, 'num_carts': 41843, 'hit_carts': 583, 'num_orders': 19599, 'hit_orders': 419, 'recall_clicks': '0.013', 'recall_carts': '0.014', 'recall_orders': '0.021', 'w_recall_clicks': '0.001', 'w_recall_carts': '0.004', 'w_recall_orders': '0.013', 'score': '0.018'}
# 0:05:05.757540 	 [make_candidate] session_latest_type_wt_pair13 : start
# 0:05:06.207699 	 [add_candidate] session_latest_type_wt_pair13 : start
# 0:05:09.691520 	 session_latest_type_wt_pair13
# 0:05:09.692840 	 {'num_clicks': 97136, 'hit_clicks': 1334, 'num_carts': 41843, 'hit_carts': 644, 'num_orders': 19599, 'hit_orders': 500, 'recall_clicks': '0.014', 'recall_carts': '0.015', 'recall_orders': '0.026', 'w_recall_clicks': '0.001', 'w_recall_carts': '0.005', 'w_recall_orders': '0.015', 'score': '0.021'}
# 0:05:09.707940 	 [make_candidate] session_latest_clicks2carts_pair13 : start
# 0:05:10.199588 	 [add_candidate] session_latest_clicks2carts_pair13 : start
# 0:05:13.943585 	 session_latest_clicks2carts_pair13
# 0:05:13.944805 	 {'num_clicks': 97136, 'hit_clicks': 669, 'num_carts': 41843, 'hit_carts': 312, 'num_orders': 19599, 'hit_orders': 240, 'recall_clicks': '0.007', 'recall_carts': '0.007', 'recall_orders': '0.012', 'w_recall_clicks': '0.001', 'w_recall_carts': '0.002', 'w_recall_orders': '0.007', 'score': '0.010'}
# 0:05:13.956794 	 [make_candidate] session_latest_clicks2orders_pair13 : start
# 0:05:14.336025 	 [add_candidate] session_latest_clicks2orders_pair13 : start
# 0:05:17.241456 	 session_latest_clicks2orders_pair13
# 0:05:17.242677 	 {'num_clicks': 97136, 'hit_clicks': 347, 'num_carts': 41843, 'hit_carts': 160, 'num_orders': 19599, 'hit_orders': 126, 'recall_clicks': '0.004', 'recall_carts': '0.004', 'recall_orders': '0.006', 'w_recall_clicks': '0.000', 'w_recall_carts': '0.001', 'w_recall_orders': '0.004', 'score': '0.005'}
# 0:05:17.252686 	 [make_candidate] session_latest_time_wt_pair14 : start
# 0:05:17.794058 	 [add_candidate] session_latest_time_wt_pair14 : start
# 0:05:21.141791 	 session_latest_time_wt_pair14
# 0:05:21.143022 	 {'num_clicks': 97136, 'hit_clicks': 1494, 'num_carts': 41843, 'hit_carts': 664, 'num_orders': 19599, 'hit_orders': 413, 'recall_clicks': '0.015', 'recall_carts': '0.016', 'recall_orders': '0.021', 'w_recall_clicks': '0.002', 'w_recall_carts': '0.005', 'w_recall_orders': '0.013', 'score': '0.019'}
# 0:05:21.156260 	 [make_candidate] session_latest_word2vec_pair14 : start
# 0:05:21.560792 	 [add_candidate] session_latest_word2vec_pair14 : start
# 0:05:25.502938 	 session_latest_word2vec_pair14
# 0:05:25.504193 	 {'num_clicks': 97136, 'hit_clicks': 971, 'num_carts': 41843, 'hit_carts': 388, 'num_orders': 19599, 'hit_orders': 234, 'recall_clicks': '0.010', 'recall_carts': '0.009', 'recall_orders': '0.012', 'w_recall_clicks': '0.001', 'w_recall_carts': '0.003', 'w_recall_orders': '0.007', 'score': '0.011'}
# 0:05:25.519007 	 [make_candidate] session_latest_pair14 : start
# 0:05:26.064679 	 [add_candidate] session_latest_pair14 : start
# 0:05:29.419645 	 session_latest_pair14
# 0:05:29.420875 	 {'num_clicks': 97136, 'hit_clicks': 1277, 'num_carts': 41843, 'hit_carts': 552, 'num_orders': 19599, 'hit_orders': 421, 'recall_clicks': '0.013', 'recall_carts': '0.013', 'recall_orders': '0.021', 'w_recall_clicks': '0.001', 'w_recall_carts': '0.004', 'w_recall_orders': '0.013', 'score': '0.018'}
# 0:05:29.433430 	 [make_candidate] session_latest_type_wt_pair14 : start
# 0:05:29.994702 	 [add_candidate] session_latest_type_wt_pair14 : start
# 0:05:33.867768 	 session_latest_type_wt_pair14
# 0:05:33.868992 	 {'num_clicks': 97136, 'hit_clicks': 1258, 'num_carts': 41843, 'hit_carts': 535, 'num_orders': 19599, 'hit_orders': 483, 'recall_clicks': '0.013', 'recall_carts': '0.013', 'recall_orders': '0.025', 'w_recall_clicks': '0.001', 'w_recall_carts': '0.004', 'w_recall_orders': '0.015', 'score': '0.020'}
# 0:05:33.881489 	 [make_candidate] session_latest_clicks2carts_pair14 : start
# 0:05:34.189607 	 [add_candidate] session_latest_clicks2carts_pair14 : start
# 0:05:37.241836 	 session_latest_clicks2carts_pair14
# 0:05:37.243175 	 {'num_clicks': 97136, 'hit_clicks': 689, 'num_carts': 41843, 'hit_carts': 293, 'num_orders': 19599, 'hit_orders': 200, 'recall_clicks': '0.007', 'recall_carts': '0.007', 'recall_orders': '0.010', 'w_recall_clicks': '0.001', 'w_recall_carts': '0.002', 'w_recall_orders': '0.006', 'score': '0.009'}
# 0:05:37.254301 	 [make_candidate] session_latest_clicks2orders_pair14 : start
# 0:05:37.598438 	 [add_candidate] session_latest_clicks2orders_pair14 : start
# 0:05:40.918571 	 session_latest_clicks2orders_pair14
# 0:05:40.919775 	 {'num_clicks': 97136, 'hit_clicks': 273, 'num_carts': 41843, 'hit_carts': 132, 'num_orders': 19599, 'hit_orders': 101, 'recall_clicks': '0.003', 'recall_carts': '0.003', 'recall_orders': '0.005', 'w_recall_clicks': '0.000', 'w_recall_carts': '0.001', 'w_recall_orders': '0.003', 'score': '0.004'}
# 0:05:40.929340 	 [make_candidate] session_latest_time_wt_pair15 : start
# 0:05:41.347080 	 [add_candidate] session_latest_time_wt_pair15 : start
# 0:05:44.680994 	 session_latest_time_wt_pair15
# 0:05:44.682203 	 {'num_clicks': 97136, 'hit_clicks': 1379, 'num_carts': 41843, 'hit_carts': 564, 'num_orders': 19599, 'hit_orders': 387, 'recall_clicks': '0.014', 'recall_carts': '0.013', 'recall_orders': '0.020', 'w_recall_clicks': '0.001', 'w_recall_carts': '0.004', 'w_recall_orders': '0.012', 'score': '0.017'}
# 0:05:44.694501 	 [make_candidate] session_latest_word2vec_pair15 : start
# 0:05:45.283188 	 [add_candidate] session_latest_word2vec_pair15 : start
# 0:05:48.655436 	 session_latest_word2vec_pair15
# 0:05:48.656959 	 {'num_clicks': 97136, 'hit_clicks': 976, 'num_carts': 41843, 'hit_carts': 386, 'num_orders': 19599, 'hit_orders': 234, 'recall_clicks': '0.010', 'recall_carts': '0.009', 'recall_orders': '0.012', 'w_recall_clicks': '0.001', 'w_recall_carts': '0.003', 'w_recall_orders': '0.007', 'score': '0.011'}
# 0:05:48.670552 	 [make_candidate] session_latest_pair15 : start
# 0:05:49.155163 	 [add_candidate] session_latest_pair15 : start
# 0:05:53.534503 	 session_latest_pair15
# 0:05:53.535973 	 {'num_clicks': 97136, 'hit_clicks': 1201, 'num_carts': 41843, 'hit_carts': 482, 'num_orders': 19599, 'hit_orders': 389, 'recall_clicks': '0.012', 'recall_carts': '0.012', 'recall_orders': '0.020', 'w_recall_clicks': '0.001', 'w_recall_carts': '0.003', 'w_recall_orders': '0.012', 'score': '0.017'}
# 0:05:53.549184 	 [make_candidate] session_latest_type_wt_pair15 : start
# 0:05:54.120817 	 [add_candidate] session_latest_type_wt_pair15 : start
# 0:05:58.027635 	 session_latest_type_wt_pair15
# 0:05:58.029227 	 {'num_clicks': 97136, 'hit_clicks': 1244, 'num_carts': 41843, 'hit_carts': 550, 'num_orders': 19599, 'hit_orders': 482, 'recall_clicks': '0.013', 'recall_carts': '0.013', 'recall_orders': '0.025', 'w_recall_clicks': '0.001', 'w_recall_carts': '0.004', 'w_recall_orders': '0.015', 'score': '0.020'}
# 0:05:58.042628 	 [make_candidate] session_latest_clicks2carts_pair15 : start
# 0:05:58.411633 	 [add_candidate] session_latest_clicks2carts_pair15 : start
# 0:06:02.689170 	 session_latest_clicks2carts_pair15
# 0:06:02.690527 	 {'num_clicks': 97136, 'hit_clicks': 561, 'num_carts': 41843, 'hit_carts': 305, 'num_orders': 19599, 'hit_orders': 202, 'recall_clicks': '0.006', 'recall_carts': '0.007', 'recall_orders': '0.010', 'w_recall_clicks': '0.001', 'w_recall_carts': '0.002', 'w_recall_orders': '0.006', 'score': '0.009'}
# 0:06:02.700889 	 [make_candidate] session_latest_clicks2orders_pair15 : start
# 0:06:02.957520 	 [add_candidate] session_latest_clicks2orders_pair15 : start
# 0:06:06.378592 	 session_latest_clicks2orders_pair15
# 0:06:06.379902 	 {'num_clicks': 97136, 'hit_clicks': 263, 'num_carts': 41843, 'hit_carts': 134, 'num_orders': 19599, 'hit_orders': 95, 'recall_clicks': '0.003', 'recall_carts': '0.003', 'recall_orders': '0.005', 'w_recall_clicks': '0.000', 'w_recall_carts': '0.001', 'w_recall_orders': '0.003', 'score': '0.004'}
# 0:06:06.389123 	 [make_candidate] session_latest_time_wt_pair16 : start
# 0:06:06.939142 	 [add_candidate] session_latest_time_wt_pair16 : start
# 0:06:11.389782 	 session_latest_time_wt_pair16
# 0:06:11.391232 	 {'num_clicks': 97136, 'hit_clicks': 1311, 'num_carts': 41843, 'hit_carts': 581, 'num_orders': 19599, 'hit_orders': 431, 'recall_clicks': '0.013', 'recall_carts': '0.014', 'recall_orders': '0.022', 'w_recall_clicks': '0.001', 'w_recall_carts': '0.004', 'w_recall_orders': '0.013', 'score': '0.019'}
# 0:06:11.404679 	 [make_candidate] session_latest_word2vec_pair16 : start
# 0:06:11.864621 	 [add_candidate] session_latest_word2vec_pair16 : start
# 0:06:15.906608 	 session_latest_word2vec_pair16
# 0:06:15.907781 	 {'num_clicks': 97136, 'hit_clicks': 899, 'num_carts': 41843, 'hit_carts': 358, 'num_orders': 19599, 'hit_orders': 211, 'recall_clicks': '0.009', 'recall_carts': '0.009', 'recall_orders': '0.011', 'w_recall_clicks': '0.001', 'w_recall_carts': '0.003', 'w_recall_orders': '0.006', 'score': '0.010'}
# 0:06:15.921283 	 [make_candidate] session_latest_pair16 : start
# 0:06:16.463359 	 [add_candidate] session_latest_pair16 : start
# 0:06:20.457230 	 session_latest_pair16
# 0:06:20.458397 	 {'num_clicks': 97136, 'hit_clicks': 1064, 'num_carts': 41843, 'hit_carts': 477, 'num_orders': 19599, 'hit_orders': 367, 'recall_clicks': '0.011', 'recall_carts': '0.011', 'recall_orders': '0.019', 'w_recall_clicks': '0.001', 'w_recall_carts': '0.003', 'w_recall_orders': '0.011', 'score': '0.016'}
# 0:06:20.471543 	 [make_candidate] session_latest_type_wt_pair16 : start
# 0:06:20.932780 	 [add_candidate] session_latest_type_wt_pair16 : start
# 0:06:25.408057 	 session_latest_type_wt_pair16
# 0:06:25.409671 	 {'num_clicks': 97136, 'hit_clicks': 1148, 'num_carts': 41843, 'hit_carts': 516, 'num_orders': 19599, 'hit_orders': 412, 'recall_clicks': '0.012', 'recall_carts': '0.012', 'recall_orders': '0.021', 'w_recall_clicks': '0.001', 'w_recall_carts': '0.004', 'w_recall_orders': '0.013', 'score': '0.017'}
# 0:06:25.424609 	 [make_candidate] session_latest_clicks2carts_pair16 : start
# 0:06:25.811408 	 [add_candidate] session_latest_clicks2carts_pair16 : start
# 0:06:29.655877 	 session_latest_clicks2carts_pair16
# 0:06:29.657147 	 {'num_clicks': 97136, 'hit_clicks': 568, 'num_carts': 41843, 'hit_carts': 272, 'num_orders': 19599, 'hit_orders': 202, 'recall_clicks': '0.006', 'recall_carts': '0.007', 'recall_orders': '0.010', 'w_recall_clicks': '0.001', 'w_recall_carts': '0.002', 'w_recall_orders': '0.006', 'score': '0.009'}
# 0:06:29.668909 	 [make_candidate] session_latest_clicks2orders_pair16 : start
# 0:06:29.981935 	 [add_candidate] session_latest_clicks2orders_pair16 : start
# 0:06:34.048110 	 session_latest_clicks2orders_pair16
# 0:06:34.049340 	 {'num_clicks': 97136, 'hit_clicks': 229, 'num_carts': 41843, 'hit_carts': 127, 'num_orders': 19599, 'hit_orders': 80, 'recall_clicks': '0.002', 'recall_carts': '0.003', 'recall_orders': '0.004', 'w_recall_clicks': '0.000', 'w_recall_carts': '0.001', 'w_recall_orders': '0.002', 'score': '0.004'}
# 0:06:34.058235 	 [make_candidate] session_latest_time_wt_pair17 : start
# 0:06:34.548341 	 [add_candidate] session_latest_time_wt_pair17 : start
# 0:06:38.623523 	 session_latest_time_wt_pair17
# 0:06:38.624831 	 {'num_clicks': 97136, 'hit_clicks': 1315, 'num_carts': 41843, 'hit_carts': 578, 'num_orders': 19599, 'hit_orders': 391, 'recall_clicks': '0.014', 'recall_carts': '0.014', 'recall_orders': '0.020', 'w_recall_clicks': '0.001', 'w_recall_carts': '0.004', 'w_recall_orders': '0.012', 'score': '0.017'}
# 0:06:38.637153 	 [make_candidate] session_latest_word2vec_pair17 : start
# 0:06:39.107034 	 [add_candidate] session_latest_word2vec_pair17 : start
# 0:06:43.296889 	 session_latest_word2vec_pair17
# 0:06:43.298289 	 {'num_clicks': 97136, 'hit_clicks': 823, 'num_carts': 41843, 'hit_carts': 344, 'num_orders': 19599, 'hit_orders': 204, 'recall_clicks': '0.008', 'recall_carts': '0.008', 'recall_orders': '0.010', 'w_recall_clicks': '0.001', 'w_recall_carts': '0.002', 'w_recall_orders': '0.006', 'score': '0.010'}
# 0:06:43.311668 	 [make_candidate] session_latest_pair17 : start
# 0:06:43.872196 	 [add_candidate] session_latest_pair17 : start
# 0:06:48.441563 	 session_latest_pair17
# 0:06:48.442983 	 {'num_clicks': 97136, 'hit_clicks': 1020, 'num_carts': 41843, 'hit_carts': 453, 'num_orders': 19599, 'hit_orders': 318, 'recall_clicks': '0.011', 'recall_carts': '0.011', 'recall_orders': '0.016', 'w_recall_clicks': '0.001', 'w_recall_carts': '0.003', 'w_recall_orders': '0.010', 'score': '0.014'}
# 0:06:48.456139 	 [make_candidate] session_latest_type_wt_pair17 : start
# 0:06:48.928988 	 [add_candidate] session_latest_type_wt_pair17 : start
# 0:06:53.022308 	 session_latest_type_wt_pair17
# 0:06:53.023700 	 {'num_clicks': 97136, 'hit_clicks': 1134, 'num_carts': 41843, 'hit_carts': 485, 'num_orders': 19599, 'hit_orders': 445, 'recall_clicks': '0.012', 'recall_carts': '0.012', 'recall_orders': '0.023', 'w_recall_clicks': '0.001', 'w_recall_carts': '0.003', 'w_recall_orders': '0.014', 'score': '0.018'}
# 0:06:53.036882 	 [make_candidate] session_latest_clicks2carts_pair17 : start
# 0:06:53.333392 	 [add_candidate] session_latest_clicks2carts_pair17 : start
# 0:06:57.731000 	 session_latest_clicks2carts_pair17
# 0:06:57.732347 	 {'num_clicks': 97136, 'hit_clicks': 475, 'num_carts': 41843, 'hit_carts': 255, 'num_orders': 19599, 'hit_orders': 178, 'recall_clicks': '0.005', 'recall_carts': '0.006', 'recall_orders': '0.009', 'w_recall_clicks': '0.000', 'w_recall_carts': '0.002', 'w_recall_orders': '0.005', 'score': '0.008'}
# 0:06:57.743120 	 [make_candidate] session_latest_clicks2orders_pair17 : start
# 0:06:58.143047 	 [add_candidate] session_latest_clicks2orders_pair17 : start
# 0:07:01.720221 	 session_latest_clicks2orders_pair17
# 0:07:01.721597 	 {'num_clicks': 97136, 'hit_clicks': 243, 'num_carts': 41843, 'hit_carts': 126, 'num_orders': 19599, 'hit_orders': 93, 'recall_clicks': '0.003', 'recall_carts': '0.003', 'recall_orders': '0.005', 'w_recall_clicks': '0.000', 'w_recall_carts': '0.001', 'w_recall_orders': '0.003', 'score': '0.004'}
# 0:07:01.731249 	 [make_candidate] session_latest_time_wt_pair18 : start
# 0:07:02.302418 	 [add_candidate] session_latest_time_wt_pair18 : start
# 0:07:06.839227 	 session_latest_time_wt_pair18
# 0:07:06.840499 	 {'num_clicks': 97136, 'hit_clicks': 1199, 'num_carts': 41843, 'hit_carts': 517, 'num_orders': 19599, 'hit_orders': 373, 'recall_clicks': '0.012', 'recall_carts': '0.012', 'recall_orders': '0.019', 'w_recall_clicks': '0.001', 'w_recall_carts': '0.004', 'w_recall_orders': '0.011', 'score': '0.016'}
# 0:07:06.853911 	 [make_candidate] session_latest_word2vec_pair18 : start
# 0:07:07.354187 	 [add_candidate] session_latest_word2vec_pair18 : start
# 0:07:11.571045 	 session_latest_word2vec_pair18
# 0:07:11.572361 	 {'num_clicks': 97136, 'hit_clicks': 853, 'num_carts': 41843, 'hit_carts': 366, 'num_orders': 19599, 'hit_orders': 199, 'recall_clicks': '0.009', 'recall_carts': '0.009', 'recall_orders': '0.010', 'w_recall_clicks': '0.001', 'w_recall_carts': '0.003', 'w_recall_orders': '0.006', 'score': '0.010'}
# 0:07:11.588122 	 [make_candidate] session_latest_pair18 : start
# 0:07:12.100909 	 [add_candidate] session_latest_pair18 : start
# 0:07:16.233477 	 session_latest_pair18
# 0:07:16.234775 	 {'num_clicks': 97136, 'hit_clicks': 985, 'num_carts': 41843, 'hit_carts': 433, 'num_orders': 19599, 'hit_orders': 367, 'recall_clicks': '0.010', 'recall_carts': '0.010', 'recall_orders': '0.019', 'w_recall_clicks': '0.001', 'w_recall_carts': '0.003', 'w_recall_orders': '0.011', 'score': '0.015'}
# 0:07:16.248432 	 [make_candidate] session_latest_type_wt_pair18 : start
# 0:07:16.766330 	 [add_candidate] session_latest_type_wt_pair18 : start
# 0:07:21.349162 	 session_latest_type_wt_pair18
# 0:07:21.350571 	 {'num_clicks': 97136, 'hit_clicks': 992, 'num_carts': 41843, 'hit_carts': 463, 'num_orders': 19599, 'hit_orders': 397, 'recall_clicks': '0.010', 'recall_carts': '0.011', 'recall_orders': '0.020', 'w_recall_clicks': '0.001', 'w_recall_carts': '0.003', 'w_recall_orders': '0.012', 'score': '0.016'}
# 0:07:21.364174 	 [make_candidate] session_latest_clicks2carts_pair18 : start
# 0:07:21.758906 	 [add_candidate] session_latest_clicks2carts_pair18 : start
# 0:07:25.781424 	 session_latest_clicks2carts_pair18
# 0:07:25.782820 	 {'num_clicks': 97136, 'hit_clicks': 555, 'num_carts': 41843, 'hit_carts': 268, 'num_orders': 19599, 'hit_orders': 190, 'recall_clicks': '0.006', 'recall_carts': '0.006', 'recall_orders': '0.010', 'w_recall_clicks': '0.001', 'w_recall_carts': '0.002', 'w_recall_orders': '0.006', 'score': '0.008'}
# 0:07:25.793628 	 [make_candidate] session_latest_clicks2orders_pair18 : start
# 0:07:26.070329 	 [add_candidate] session_latest_clicks2orders_pair18 : start
# 0:07:30.197213 	 session_latest_clicks2orders_pair18
# 0:07:30.198617 	 {'num_clicks': 97136, 'hit_clicks': 242, 'num_carts': 41843, 'hit_carts': 124, 'num_orders': 19599, 'hit_orders': 72, 'recall_clicks': '0.002', 'recall_carts': '0.003', 'recall_orders': '0.004', 'w_recall_clicks': '0.000', 'w_recall_carts': '0.001', 'w_recall_orders': '0.002', 'score': '0.003'}
# 0:07:30.207072 	 [make_candidate] session_latest_time_wt_pair19 : start
# 0:07:30.705986 	 [add_candidate] session_latest_time_wt_pair19 : start
# 0:07:35.009674 	 session_latest_time_wt_pair19
# 0:07:35.010967 	 {'num_clicks': 97136, 'hit_clicks': 1184, 'num_carts': 41843, 'hit_carts': 518, 'num_orders': 19599, 'hit_orders': 334, 'recall_clicks': '0.012', 'recall_carts': '0.012', 'recall_orders': '0.017', 'w_recall_clicks': '0.001', 'w_recall_carts': '0.004', 'w_recall_orders': '0.010', 'score': '0.015'}
# 0:07:35.023568 	 [make_candidate] session_latest_word2vec_pair19 : start
# 0:07:35.529133 	 [add_candidate] session_latest_word2vec_pair19 : start
# 0:07:39.723918 	 session_latest_word2vec_pair19
# 0:07:39.725363 	 {'num_clicks': 97136, 'hit_clicks': 799, 'num_carts': 41843, 'hit_carts': 376, 'num_orders': 19599, 'hit_orders': 196, 'recall_clicks': '0.008', 'recall_carts': '0.009', 'recall_orders': '0.010', 'w_recall_clicks': '0.001', 'w_recall_carts': '0.003', 'w_recall_orders': '0.006', 'score': '0.010'}
# 0:07:39.738859 	 [make_candidate] session_latest_pair19 : start
# 0:07:40.256470 	 [add_candidate] session_latest_pair19 : start
# 0:07:44.861138 	 session_latest_pair19
# 0:07:44.862497 	 {'num_clicks': 97136, 'hit_clicks': 968, 'num_carts': 41843, 'hit_carts': 414, 'num_orders': 19599, 'hit_orders': 319, 'recall_clicks': '0.010', 'recall_carts': '0.010', 'recall_orders': '0.016', 'w_recall_clicks': '0.001', 'w_recall_carts': '0.003', 'w_recall_orders': '0.010', 'score': '0.014'}
# 0:07:44.876029 	 [make_candidate] session_latest_type_wt_pair19 : start
# 0:07:45.468295 	 [add_candidate] session_latest_type_wt_pair19 : start
# 0:07:49.664653 	 session_latest_type_wt_pair19
# 0:07:49.666078 	 {'num_clicks': 97136, 'hit_clicks': 1023, 'num_carts': 41843, 'hit_carts': 483, 'num_orders': 19599, 'hit_orders': 367, 'recall_clicks': '0.011', 'recall_carts': '0.012', 'recall_orders': '0.019', 'w_recall_clicks': '0.001', 'w_recall_carts': '0.003', 'w_recall_orders': '0.011', 'score': '0.016'}
# 0:07:49.679386 	 [make_candidate] session_latest_clicks2carts_pair19 : start
# 0:07:50.108747 	 [add_candidate] session_latest_clicks2carts_pair19 : start
# 0:07:54.614097 	 session_latest_clicks2carts_pair19
# 0:07:54.616168 	 {'num_clicks': 97136, 'hit_clicks': 461, 'num_carts': 41843, 'hit_carts': 273, 'num_orders': 19599, 'hit_orders': 185, 'recall_clicks': '0.005', 'recall_carts': '0.007', 'recall_orders': '0.009', 'w_recall_clicks': '0.000', 'w_recall_carts': '0.002', 'w_recall_orders': '0.006', 'score': '0.008'}
# 0:07:54.629412 	 [make_candidate] session_latest_clicks2orders_pair19 : start
# 0:07:54.963653 	 [add_candidate] session_latest_clicks2orders_pair19 : start
# 0:07:58.875103 	 session_latest_clicks2orders_pair19
# 0:07:58.876368 	 {'num_clicks': 97136, 'hit_clicks': 238, 'num_carts': 41843, 'hit_carts': 126, 'num_orders': 19599, 'hit_orders': 94, 'recall_clicks': '0.002', 'recall_carts': '0.003', 'recall_orders': '0.005', 'w_recall_clicks': '0.000', 'w_recall_carts': '0.001', 'w_recall_orders': '0.003', 'score': '0.004'}

# %%
results
# Out:
#                                    name num_clicks hit_clicks num_carts  \
# 0                      session_frequent      97136      29467     42864
# 0                        session_latest      97136      29677     42864
# 0         w2v_session_total_aid_vec_sim      97136      33577     43211
# 0   w2v_session_carts_total_aid_vec_sim      97136       4803     43211
# 0          session_latest_time_wt_pair0      97136       7907     41843
# ..                                  ...        ...        ...       ...
# 0        session_latest_word2vec_pair19      97136        799     41843
# 0                 session_latest_pair19      97136        968     41843
# 0         session_latest_type_wt_pair19      97136       1023     41843
# 0    session_latest_clicks2carts_pair19      97136        461     41843
# 0   session_latest_clicks2orders_pair19      97136        238     41843
#
#    hit_carts num_orders hit_orders recall_clicks recall_carts recall_orders  \
# 0      10730      19985      10185         0.303        0.250         0.510
# 0      10822      19985       9838         0.306        0.252         0.492
# 0       8796      20082       5541         0.346        0.204         0.276
# 0       3151      20082       4854         0.049        0.073         0.242
# 0       2522      19599       1815         0.081        0.060         0.093
# ..       ...        ...        ...           ...          ...           ...
# 0        376      19599        196         0.008        0.009         0.010
# 0        414      19599        319         0.010        0.010         0.016
# 0        483      19599        367         0.011        0.012         0.019
# 0        273      19599        185         0.005        0.007         0.009
# 0        126      19599         94         0.002        0.003         0.005
#
#    w_recall_clicks w_recall_carts w_recall_orders  score
# 0            0.030          0.075           0.306  0.411
# 0            0.031          0.076           0.295  0.402
# 0            0.035          0.061           0.166  0.261
# 0            0.005          0.022           0.145  0.172
# 0            0.008          0.018           0.056  0.082
# ..             ...            ...             ...    ...
# 0            0.001          0.003           0.006  0.010
# 0            0.001          0.003           0.010  0.014
# 0            0.001          0.003           0.011  0.016
# 0            0.000          0.002           0.006  0.008
# 0            0.000          0.001           0.003  0.004
#
# [124 rows x 14 columns]

# %%
fig, axs = plt.subplots(1, 3)
sns.heatmap(results.set_index("name")[["recall_clicks"]].astype(float),
            annot=True, linewidths=.5, fmt="1.2f", cmap="Reds", cbar=False, ax=axs[0])
sns.heatmap(results.set_index("name")[["recall_carts"]].astype(float),
            annot=True, linewidths=.5, fmt="1.2f", cmap="Reds", cbar=False, ax=axs[1], yticklabels=False)
sns.heatmap(results.set_index("name")[["recall_orders"]].astype(float),
            annot=True, linewidths=.5, fmt="1.2f", cmap="Reds", cbar=False, ax=axs[2], yticklabels=False)
plt.savefig(cfg.output_dir + f'{cfg.exp_name}/candidate_strategy_recalls.png')

# %%
# 予測値を全て使えたときのrecall
valid_all = valid.drop_duplicates(subset= ["session", "aid"])
session_cnt_max = valid_all["session"].value_counts().max()
valid_all = valid_all.groupby("session")["aid"].apply(list).reset_index()

all_results = evaluate(valid_labels["clicks_labels"].tolist(),
                       valid_labels["carts_labels"].tolist(),
                       valid_labels["orders_labels"].tolist(),
                       valid_all["aid"].tolist(),
                       valid_all["aid"].tolist(),
                       valid_all["aid"].tolist(),
                       session_cnt_max)
logger.info("session_cnt_max")
logger.info(session_cnt_max)
logger.info("all_pred_results")
logger.info(all_results)
# Out:
# 0:08:07.664317 	 session_cnt_max
# 0:08:07.665756 	 722
# 0:08:07.666681 	 all_pred_results
# 0:08:07.667333 	 {'num_clicks': 97136, 'hit_clicks': 57822, 'num_carts': 43611, 'hit_carts': 19652, 'num_orders': 20109, 'hit_orders': 13101, 'recall_clicks': '0.595', 'recall_carts': '0.451', 'recall_orders': '0.651', 'w_recall_clicks': '0.060', 'w_recall_carts': '0.135', 'w_recall_orders': '0.391', 'score': '0.586'}
