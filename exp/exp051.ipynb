# %% [markdown]
# # exp051
# latest_aid 5 -> 10

# %%
import os
import sys
import traceback
import gc
import random
import pickle
import pathlib
import subprocess
from dataclasses import dataclass
from dotenv import load_dotenv
load_dotenv
sys.path.append(os.getenv('UTILS_PATH'))
from tqdm import tqdm
import multiprocessing
import inspect

import pandas as pd
import numpy as np
import itertools
import cudf
import lightgbm as lgb
import matplotlib.pyplot as plt
import seaborn as sns
import line_notify
import my_logger
from noglobal import noglobal

# %% [markdown]
# # 設定

# %%
@dataclass
class Cfg:
    loglevel = "INFO"
    exp_name = "exp051"
    seed = 42
    k = 20
    cand_n = 15
    negative_sample = 1
    train_chunk_n = 2
    test_chunk_n = 2
    type2id = {"clicks":0, "carts":1, "orders":2}
    id2type = {0:"clicks", 1:"carts", 2:"orders"}
    train_weeks = ["week3"]
    valid_week = "week4"
    valid_session_n = 100_000
    input_dir = os.getenv('INPUT_DIR')
    output_dir = os.getenv('OUTPUT_DIR')
    prep_dir = os.getenv("PREP_DIR")

cfg = Cfg()
os.makedirs(os.path.join(cfg.output_dir, cfg.exp_name), exist_ok=True)
os.makedirs(os.path.join(cfg.output_dir, cfg.exp_name, "cache"), exist_ok=True)
random.seed(cfg.seed)

logger = my_logger.init_logger(cfg.exp_name)

# %%
class Cache:
    @noglobal(excepts=["cfg", "logger"])
    def __init__(self):
        self.cache_dir = (os.path.join(cfg.output_dir, cfg.exp_name, "cache"))
        self.cache_dir_path = pathlib.Path(self.cache_dir)
        self.caches = list(self.cache_dir_path.glob("*.pkl"))

    @noglobal(excepts=["cfg", "logger"])
    def get_abspath(self, filename):
        return (os.path.join(self.cache_dir, filename))
    
    @noglobal(excepts=["cfg", "logger"])
    def exists(self, path):
        return len([str(c) for c in self.caches if path == str(c)]) > 0


cache = Cache()

# %%
def reduce_mem_usage(df):
    """ iterate through all the columns of a dataframe and modify the data type
        to reduce memory usage.        
    """
    start_mem = df.memory_usage().sum() / 1024**2
    print('Memory usage of dataframe is {:.2f} MB'.format(start_mem))
    
    for col in df.columns:
        col_type = df[col].dtype
        
        if col_type != object:
            c_min = df[col].min()
            c_max = df[col].max()
            if str(col_type)[:3] == 'int':
                if c_min > np.iinfo(np.int8).min and c_max < np.iinfo(np.int8).max:
                    df[col] = df[col].astype(np.int8)
                elif c_min > np.iinfo(np.int16).min and c_max < np.iinfo(np.int16).max:
                    df[col] = df[col].astype(np.int16)
                elif c_min > np.iinfo(np.int32).min and c_max < np.iinfo(np.int32).max:
                    df[col] = df[col].astype(np.int32)
                elif c_min > np.iinfo(np.int64).min and c_max < np.iinfo(np.int64).max:
                    df[col] = df[col].astype(np.int64)  
            else:
                if c_min > np.finfo(np.float16).min and c_max < np.finfo(np.float16).max:
                    df[col] = df[col].astype(np.float16)
                elif c_min > np.finfo(np.float32).min and c_max < np.finfo(np.float32).max:
                    df[col] = df[col].astype(np.float32)
                else:
                    df[col] = df[col].astype(np.float64)
        else:
            df[col] = df[col].astype('category')

    end_mem = df.memory_usage().sum() / 1024**2
    print('Memory usage after optimization is: {:.2f} MB'.format(end_mem))
    print('Decreased by {:.1f}%'.format(100 * (start_mem - end_mem) / start_mem))
    
    return df

# %%
@noglobal(excepts=["cfg", "logger"])
def evaluate(clicks_labels, carts_labels, orders_labels, 
             clicks_preds, carts_preds, orders_preds, k=20):

    num_clicks = 0
    num_carts = 0
    num_orders = 0
    hit_clicks = 0
    hit_carts = 0
    hit_orders = 0

    for i in range(len(clicks_labels)):
        clicks_label = clicks_labels[i]
        carts_label = carts_labels[i]
        orders_label = orders_labels[i]
        clicks_pred = clicks_preds[i]
        carts_pred = carts_preds[i]
        orders_pred = orders_preds[i]

        if type(clicks_pred) == list:
            clicks_pred = clicks_pred[:k]
        else:
            clicks_pred = []
        if type(carts_pred) == list:
            carts_pred = carts_pred[:k]
        else:
            carts_pred = []    
        if type(orders_pred) == list:
            orders_pred = orders_pred[:k]
        else:
            orders_pred = []

        if not np.isnan(clicks_label):
            num_clicks += 1
            hit_clicks += int(clicks_label in clicks_pred)

        if type(carts_label) == list:
            num_carts += min(len(carts_label), k)
            hit_carts += len(set(carts_pred) & set(carts_label))
            
        if type(orders_label) == list:
            num_orders += min(len(orders_label), k)
            hit_orders += len(set(orders_pred) & set(orders_label))


    recall_clicks = hit_clicks / num_clicks
    recall_carts = hit_carts / num_carts
    recall_orders = hit_orders / num_orders
    w_recall_clicks = recall_clicks * 0.10
    w_recall_carts = recall_carts * 0.30
    w_recall_orders = recall_orders * 0.60
    score = w_recall_clicks + w_recall_carts + w_recall_orders

    results = {}
    results["num_clicks"] = num_clicks
    results["hit_clicks"] = hit_clicks
    results["num_carts"] = num_carts
    results["hit_carts"] = hit_carts
    results["num_orders"] = num_orders
    results["hit_orders"] = hit_orders
    results["recall_clicks"] = format(recall_clicks, ".3f")
    results["recall_carts"] = format(recall_carts, ".3f")
    results["recall_orders"] = format(recall_orders, ".3f")
    results["w_recall_clicks"] = format(w_recall_clicks, ".3f")
    results["w_recall_carts"] = format(w_recall_carts, ".3f")
    results["w_recall_orders"] = format(w_recall_orders, ".3f")
    results["score"] = format(score, ".3f")

    return results

# %%
class Candidate:
    @noglobal(excepts=["cfg", "logger"])
    def __init__(self, pdf, labels=None):
        self.df = cudf.from_pandas(pdf)
        self.target_sessions = pdf["session"].unique().tolist()
        self.results = pd.DataFrame(columns=["name", "num_clicks", "hit_clicks", "num_carts", "hit_carts", "num_orders", "hit_orders", 
                                             "recall_clicks", "recall_carts", "recall_orders", "w_recall_clicks", "w_recall_carts", "w_recall_orders", "score"])
        self.output = pd.DataFrame(columns=["session", "aid"], dtype=int)
        self.labels = labels
    
    @noglobal(excepts=["cfg", "logger"])
    def _entry(self, new_candidate_df, name, k):
        logger.info(f"[add_candidate] {name} : start")
        new_candidate_df = new_candidate_df.to_pandas()
        self.output = pd.concat([self.output, new_candidate_df[["session", "aid"]]])
        self.output = self.output.drop_duplicates(subset=["session", "aid"])

        if self.labels is not None:
            self._eval(new_candidate_df[["session", "aid"]], name, k)
    
    @noglobal(excepts=["cfg", "logger"])
    def _eval(self, new_candidate_df, name, k):
        new_candidate_df = new_candidate_df.groupby("session")["aid"].apply(list).reset_index()
        eval_df = pd.DataFrame(self.target_sessions, columns=["session"])
        eval_df = eval_df.merge(new_candidate_df, on=["session"], how="left")
        assert eval_df["session"].tolist() == self.labels["session"].tolist()
        eval_result = evaluate(self.labels["clicks_labels"].tolist(), self.labels["carts_labels"].tolist(), self.labels["orders_labels"].tolist(),
                               eval_df["aid"].tolist(), eval_df["aid"].tolist(), eval_df["aid"].tolist(), k)
        
        print(eval_result)
        self.results = pd.concat([self.results, pd.DataFrame([[name] + list(eval_result.values())], columns=["name"] + list(eval_result.keys()))])

    @noglobal(excepts=["cfg", "logger"])
    def add(self, strategy, name, usetypes=['clicks', 'carts', 'orders'], trans_map=None, k=20):
        logger.info(f"[make_candidate] {name} : start")
        candidate_df = self.df[self.df["type"].isin(usetypes)].copy()
        
        if strategy == "session_frequent":
            candidate_df = self._session_frequent(candidate_df, k)
        elif strategy == "session_latest":
            candidate_df = self._session_latest(candidate_df, k)
        elif strategy == "total_frequent":
            candidate_df = self._total_frequent(candidate_df, k)
        
        if trans_map is not None:
            candidate_df["aid"] = candidate_df["aid"].map(trans_map)
            candidate_df = candidate_df.dropna(subset=["aid"])
            
        self._entry(candidate_df, name, k)

    @noglobal(excepts=["cfg", "logger"])
    def _session_frequent(self, candidate_df, k):
        candidate_df = candidate_df.groupby(["session", "aid"])["ts"].count().reset_index()
        candidate_df.columns = ["session", "aid", "aid_count"]
        candidate_df = candidate_df.sort_values(["session", "aid_count", "aid"], ascending=(True, False, True))
        candidate_df = candidate_df[candidate_df.groupby("session")["aid_count"].cumcount() < k].copy()
        candidate_df = candidate_df[["session", "aid"]].copy()
        return candidate_df

    @noglobal(excepts=["cfg", "logger"])
    def _session_latest(self, candidate_df, k):
        candidate_df = candidate_df.sort_values(["session", "ts"], ascending=(True, False)).drop_duplicates(subset=["session", "aid"])
        candidate_df = candidate_df.sort_values(["session", "ts"], ascending=(True, False))[candidate_df.groupby("session")["ts"].cumcount() < k].copy()
        candidate_df = candidate_df[["session", "aid"]].copy()
        return candidate_df

    @noglobal(excepts=["cfg", "logger"])
    def _total_frequent(self, candidate_df, k):
        candidate_df = candidate_df.groupby("aid")["ts"].count().reset_index()
        candidate_df.columns = ["aid", "aid_count"]
        topk_freq_aids = candidate_df.sort_values("aid_count", ascending=False)["aid"].to_arrow().to_pylist()[:k]
        sessions = []
        aids = []
        for session, aid in itertools.product(self.target_sessions, topk_freq_aids):
            sessions.append(session)
            aids.append(aid)
        candidate_df = cudf.DataFrame({"session": sessions, "aid": aids})
        return candidate_df

# %%
@noglobal(excepts=["cfg", "logger"])
def add_labels(df, labels, type_):
    type_labels = labels[["session", f"{type_}_labels"]].dropna().copy()
    type_labels.columns = ["session", "aid"]
    type_labels = type_labels.explode("aid")
    type_labels["labels"] = 1
    df = df.merge(type_labels, on=["session", "aid"], how="left")
    df["labels"] = df["labels"].fillna(0)
    return df

# %%
@noglobal(excepts=["cfg", "logger"])
def add_ground_truth_candidate(df, labels, type_):
    gt = labels[["session", f"{type_}_labels"]].dropna().copy()
    gt.columns = ["session", "aid"]
    gt = gt.explode("aid")
    df = pd.concat([df, gt])
    df = df.drop_duplicates()
    return df

# %%
@noglobal(excepts=["cfg", "logger"])
def under_sampling(df, label_col):
    cfg = Cfg()
    pos_df = df[df[label_col]==1].copy()
    neg_df = df[df[label_col]==0].copy()
    pos_n = len(pos_df)
    return pd.concat([pos_df, neg_df.sample(pos_n * cfg.negative_sample, random_state=cfg.seed)])

# %%
class Features:
    @noglobal(excepts=["cfg", "logger"])
    def __init__(self, sessions, candidate, week):
        self.sessions = cudf.from_pandas(sessions)
        self.output = candidate
        self.type_dict = cfg.type2id
        self.week = week
        self.latest_aid_n = 5

    @noglobal(excepts=["cfg", "logger"])
    def add_features(self):
        # self._prep()
        self._session_cnt()
        self._session_aid_nunique()
        self._session_last_type()
        self._aid_cnt()
        self._all_times_aid_features()
        self._w2v_vectors()
        self._relative_ts()
        self._add_aid_latest()
        self._co_visit_rank("co_visitation_matrix")
        self._co_visit_rank("co_visitation_matrix_time_weighted", "wt")
        self._co_visit_rank("co_visitation_matrix_type_weighted", "wt")
        self._co_visit_rank("co_visitation_matrix_clicks2carts")
        self._co_visit_rank("co_visitation_matrix_clicks2orders")
        self._drop_aid_latest()
        # self._session_mean_ts()
        # self._aid_mean_ts()
        # self._aid_cnt_ratio_at_session_last()
        # self.output = self.output.drop(columns=["session_last_day"]) # 日時はtrainセット内のみで有効なので削除

    @noglobal(excepts=["cfg", "logger"])
    def _prep(self):
        logger.info("[features] prep : start")
        # ts関連の前処理
        self.sessions["relative_ts"] = self.sessions["ts"] - self.sessions["ts"].min()
        self.sessions["dt"] = cudf.to_datetime(self.sessions["ts"], unit="ms")
        self.sessions["hour"] = self.sessions["dt"].dt.hour
        self.sessions["week"] = self.sessions["dt"].dt.dayofweek
        self.sessions["day"] = self.sessions["dt"].dt.day
        
    @noglobal(excepts=["cfg", "logger"])
    def _session_cnt(self):
        logger.info("[features] session_cnt : start")
        agg_df = self.sessions.groupby(["session", "type"])["ts"].count().reset_index().rename(columns={"ts": "cnt"})
        # session_total_cnt
        features = agg_df.groupby("session")["cnt"].sum().reset_index().rename(columns={"cnt": "session_total_cnt"})
        self.output = self.output.merge(features.to_pandas(), on=["session"], how="left")
        self.output["session_total_cnt"] = self.output["session_total_cnt"].fillna(0)
        # session_{type}_cnt
        for type_ in ["clicks", "carts", "orders"]:
            col_name = f"session_{type_}_cnt"
            features = agg_df[agg_df["type"]==type_].copy()
            features = features.rename(columns={"cnt": col_name})
            features = features[["session", col_name]].copy()
            self.output = self.output.merge(features.to_pandas(), on=["session"], how="left")
            self.output[col_name] = self.output[col_name].fillna(0)
        
    @noglobal(excepts=["cfg", "logger"])
    def _session_aid_nunique(self):
        logger.info("[features] session_aid_nunique : start")
        features = self.sessions.groupby("session")["aid"].nunique().reset_index().rename(columns={"aid": "session_aid_nunique"})
        self.output = self.output.merge(features.to_pandas(), on=["session"], how="left")
        self.output["session_aid_nunique"] = self.output["session_aid_nunique"].fillna(0)
        
    @noglobal(excepts=["cfg", "logger"])
    def _session_last_type(self):
        logger.info("[features] session_last_type : start")
        features = self.sessions.groupby("session").nth(-1).reset_index()[["session", "type"]]
        features = features.rename(columns={"type": "session_last_type"})
        features["session_last_type"] = features["session_last_type"].map(self.type_dict)
        self.output = self.output.merge(features.to_pandas(), on=["session"], how="left")
        
    @noglobal(excepts=["cfg", "logger"])
    def _session_last_dt(self):
        logger.info("[features] session_last_dt : start")
        features = self.sessions.groupby("session").nth(-1).reset_index()[["session", "relative_ts", "week", "day", "hour"]]
        features.columns = ["session", "session_last_ts", "session_last_week", "session_last_day", "session_last_hour"]
        self.output = self.output.merge(features.to_pandas(), on=["session"], how="left")
        
    @noglobal(excepts=["cfg", "logger"])
    def _session_mean_ts(self):
        logger.info("[features] session_mean_ts : start")
        features = self.sessions.groupby("session")["relative_ts"].mean().reset_index().rename(columns={"relative_ts": "session_mean_ts"})
        self.output = self.output.merge(features.to_pandas(), on=["session"], how="left")
        
    @noglobal(excepts=["cfg", "logger"])
    def _aid_mean_ts(self):
        logger.info("[features] aid_mean_ts : start")
        features = self.sessions.groupby("aid")["relative_ts"].mean().reset_index().rename(columns={"relative_ts": "aid_mean_ts"})
        self.output = self.output.merge(features.to_pandas(), on=["aid"], how="left")
       
    @noglobal(excepts=["cfg", "logger"])
    def _aid_session_nunique(self):
        logger.info("[features] aid_session_unique : start")
        features = self.sessions.groupby("aid")["session"].nunique().reset_index().rename(columns={"session": "aid_session_nunique"})
        self.output = self.output.merge(features.to_pandas(), on=["aid"], how="left")

    @noglobal(excepts=["cfg", "logger"]) 
    def _aid_cnt_ratio_at_session_last(self):
        logger.info("[features] aid_cnt_ratio_atsession_last : start")
        for dt_ in ["week", "day", "hour"]:
            features = self.sessions[["aid", dt_]].copy()
            features["total_cnt"] = features.groupby(dt_)["aid"].transform("count")
            features = features.groupby(["aid", dt_])["total_cnt"].agg(["count", "max"]).reset_index()
            features[f"aid_cnt_ratio_at_session_last_{dt_}"] = features["count"] / features["max"]
            features = features.rename(columns={dt_: f"session_last_{dt_}"})
            self.output = self.output.merge(features[["aid", f"session_last_{dt_}", f"aid_cnt_ratio_at_session_last_{dt_}"]].to_pandas(), on=["aid", f"session_last_{dt_}"], how="left")
            self.output[f"aid_cnt_ratio_at_session_last_{dt_}"] = self.output[f"aid_cnt_ratio_at_session_last_{dt_}"].fillna(0)
        
    @noglobal(excepts=["cfg", "logger"])
    def _aid_cnt(self):
        logger.info("[features] aid_cnt : start")
        agg_df = self.sessions.groupby(["session", "aid", "type"])["ts"].count().reset_index().rename(columns={"ts": "cnt"})

        # aid_total_cnt
        features = agg_df.groupby(["session", "aid"])["cnt"].sum().reset_index().rename(columns={"cnt": "aid_total_cnt"})
        self.output = self.output.merge(features.to_pandas(), on=["session", "aid"], how="left")
        self.output["aid_total_cnt"] = self.output["aid_total_cnt"].fillna(0)

        # aid_{type}_cnt
        for type_ in ["clicks", "carts", "orders"]:
            col_name = f"aid_{type_}_cnt"
            features = agg_df[agg_df["type"]==type_].copy()
            features = features.rename(columns={"cnt": col_name})
            features = features[["session", "aid", col_name]].copy()
            self.output = self.output.merge(features.to_pandas(), on=["session", "aid"], how="left")
            self.output[col_name] = self.output[col_name].fillna(0)

    @noglobal(excepts=["cfg", "logger"])
    def _all_times_aid_features(self):
        feats = ["all_times_aid_freq",
                 "all_times_aid_clicks_freq",
                 "all_times_aid_carts_freq",
                 "all_times_aid_orders_freq",
                 "all_times_aid_session_freq",
                 "all_times_aid_session_clicks_freq",
                 "all_times_aid_session_carts_freq",
                 "all_times_aid_session_orders_freq",
                 "all_times_aid_carts_ratio_with_clicks",
                 "all_times_aid_orders_ratio_with_clicks",
                 "all_times_aid_date_std",
                 "all_times_aid_hour_std",
                 "all_times_aid_day_of_week_std"]
        
        for feat in feats:
            if self.week is None:
                with open(cfg.prep_dir + f"{feat}.pkl", "rb") as f:
                    feat_map = pickle.load(f)
            else:
                with open(cfg.prep_dir + f"{feat}_{self.week}.pkl", "rb") as f:
                    feat_map = pickle.load(f)
            self.output[feat] = self.output["aid"].map(feat_map)

    @noglobal(excepts=["cfg", "logger"])
    def _w2v_vectors(self):
        w2v_vecs = pd.read_pickle(cfg.prep_dir + "w2v_vector_n5.pkl")
        self.output = self.output.merge(w2v_vecs, on="aid", how="left")

    @noglobal(excepts=["cfg", "logger"])
    def _relative_ts(self):
        features = self.sessions.sort_values(["session", "ts"]).drop_duplicates(subset=["session", "aid"], keep="last")
        features["relative_ts_in_session"] = features.groupby("session")["ts"].transform("max") - features["ts"]
        features = features.sort_values(["session", "ts"], ascending=(True, False)).reset_index(drop=True)
        features["ts_rank_in_session"] = features.groupby("session").cumcount()
        features = features[["session", "aid", "relative_ts_in_session", "ts_rank_in_session"]]
        self.output = self.output.merge(features.to_pandas(), on=["session", "aid"], how="left")

    @noglobal(excepts=["cfg", "logger"])
    def _add_aid_latest(self):
        sorted_df = self.sessions.sort_values(["session", "ts"], ascending=(True, False), ignore_index=True)
        for i in range(self.latest_aid_n):
            latest_aid = sorted_df.groupby("session").nth(i)["aid"].to_pandas().to_dict()
            self.output[f"aid_latest{i}"] = self.output["session"].map(latest_aid)
            self.output[f"aid_latest{i}"] = self.output[f"aid_latest{i}"].fillna(-1).astype("int32")
    
    @noglobal(excepts=["cfg", "logger"])
    def _drop_aid_latest(self):
        drop_cols = [f"aid_latest{str(i)}" for i in range(self.latest_aid_n)]
        self.output = self.output.drop(columns=drop_cols)

    @noglobal(excepts=["cfg", "logger"])
    def _co_visit_rank(self, co_visit_name, wt_col="cnt"):
        if self.week is None:
            co_visit_df = pd.read_pickle(cfg.prep_dir + f"{co_visit_name}.pkl")
        else:
            co_visit_df = pd.read_pickle(cfg.prep_dir + f"{co_visit_name}_{self.week}.pkl")
        co_visit_df = co_visit_df.sort_values(["aid_x", wt_col], ascending=(True, False), ignore_index=True)
        co_visit_df[f"rank"] = co_visit_df.groupby(["aid_x"]).cumcount()

        for i in range(self.latest_aid_n):
            self.output = self.output.merge(co_visit_df[["aid_x", "aid_y", "rank"]], left_on=[f"aid_latest{i}", "aid"], right_on=["aid_x", "aid_y"], how="left")
            self.output["rank"] = self.output["rank"].fillna(-1).astype("int32")
            self.output = self.output.rename(columns={"rank": f"{co_visit_name}_lt{i}"})
            self.output = self.output.drop(columns=["aid_x", "aid_y"])

# %%
@noglobal(excepts=["cfg", "logger"])
def add_features(sessions, cand_df, week=None):
    feat = Features(sessions, cand_df, week)
    feat.add_features()
    return feat.output

# %%
@noglobal(excepts=["cfg", "logger"])
def make_cand_df(sessions, labels=None, trans_maps=None):

    if labels is not None:
         cand = Candidate(sessions, labels)
    else:
        cand = Candidate(sessions)

    cand.add(strategy="session_frequent", name="session_frequent", k=15)
    cand.add(strategy="session_latest", name="session_latest", k=15)
    
    for i in range(20):
        cand.add(strategy="session_latest", trans_map=trans_maps[f"time_wt_pair{str(i)}"], name=f"session_latest_time_wt_pair{str(i)}", k=10)
        cand.add(strategy="session_latest", trans_map=trans_maps[f"word2vec_pair{str(i)}"], name=f"session_latest_word2vec_pair{str(i)}", k=10)
        cand.add(strategy="session_latest", trans_map=trans_maps[f"pair{str(i)}"], name=f"session_latest_pair{str(i)}", k=10)
    for i in range(5):
        cand.add(strategy="session_latest", trans_map=trans_maps[f"type_wt_pair{str(i)}"], name=f"session_latest_type_wt_pair{str(i)}", k=10)
        cand.add(strategy="session_latest", trans_map=trans_maps[f"clicks2carts_pair{str(i)}"], name=f"session_latest_clicks2carts_pair{str(i)}", k=10)
        cand.add(strategy="session_latest", trans_map=trans_maps[f"clicks2orders_pair{str(i)}"], name=f"session_latest_clicks2orders_pair{str(i)}", k=10)
        

    if labels is not None:
        return cand.output, cand.results
    else:
        return cand.output

# %%
@noglobal(excepts=["cfg", "logger"])
def get_pair_df(name, wt_col, week):
    if week is not None:
        name = f"{name}_{week}"
    pair_df = pd.read_pickle(cfg.prep_dir + f"{name}.pkl")
    pair_df = pair_df.sort_values(["aid_x", wt_col], ascending=(True, False))
    return pair_df

@noglobal(excepts=["cfg", "logger"])
def get_pair_dict(name, wt_col, week):
    if week is not None:
        name = f"{name}_{week}"
    pair_df = pd.read_pickle(cfg.prep_dir + f"{name}.pkl")
    pair_df = pair_df.sort_values(["aid_x", wt_col], ascending=(True, False))
    pair_df = pair_df.groupby("aid_x").head(1)[["aid_x", "aid_y"]]
    pair_dict = {k: v for k, v in zip(pair_df["aid_x"].tolist(), pair_df["aid_y"].tolist())}
    return pair_dict

@noglobal(excepts=["cfg", "logger"])
def get_trans_maps(week=None):
    """
    aidを別のaidに置き換えるmapping辞書を取得する
    """
    trans_maps = {}
    
    pair_df_org = get_pair_df("co_visitation_matrix", "cnt", week)
    for i in range(20):
        pair_df = pair_df_org.groupby("aid_x").nth(i).reset_index()[["aid_x", "aid_y"]]
        pair_dict = {k: v for k, v in zip(pair_df["aid_x"].tolist(), pair_df["aid_y"].tolist())}
        trans_maps[f"pair{str(i)}"] = pair_dict
    
    pair_df_org = get_pair_df("co_visitation_matrix_time_weighted", "wt", week)
    for i in range(20):
        pair_df = pair_df_org.groupby("aid_x").nth(i).reset_index()[["aid_x", "aid_y"]]
        pair_dict = {k: v for k, v in zip(pair_df["aid_x"].tolist(), pair_df["aid_y"].tolist())}
        trans_maps[f"time_wt_pair{str(i)}"] = pair_dict

    pair_df_org = get_pair_df("co_visitation_matrix_type_weighted", "wt", week)
    for i in range(5):
        pair_df = pair_df_org.groupby("aid_x").nth(i).reset_index()[["aid_x", "aid_y"]]
        pair_dict = {k: v for k, v in zip(pair_df["aid_x"].tolist(), pair_df["aid_y"].tolist())}
        trans_maps[f"type_wt_pair{str(i)}"] = pair_dict

    pair_df_org = get_pair_df("co_visitation_matrix_clicks2carts", "cnt", week)
    for i in range(5):
        pair_df = pair_df_org.groupby("aid_x").nth(i).reset_index()[["aid_x", "aid_y"]]
        pair_dict = {k: v for k, v in zip(pair_df["aid_x"].tolist(), pair_df["aid_y"].tolist())}
        trans_maps[f"clicks2carts_pair{str(i)}"] = pair_dict

    pair_df_org = get_pair_df("co_visitation_matrix_clicks2orders", "cnt", week)
    for i in range(5):
        pair_df = pair_df_org.groupby("aid_x").nth(i).reset_index()[["aid_x", "aid_y"]]
        pair_dict = {k: v for k, v in zip(pair_df["aid_x"].tolist(), pair_df["aid_y"].tolist())}
        trans_maps[f"clicks2orders_pair{str(i)}"] = pair_dict

    pair_df_org = get_pair_df("word2vec_similar", "sim", None)
    for i in range(20):
        pair_df = pair_df_org.groupby("aid_x").nth(i).reset_index()[["aid_x", "aid_y"]]
        pair_dict = {k: v for k, v in zip(pair_df["aid_x"].tolist(), pair_df["aid_y"].tolist())}
        trans_maps[f"word2vec_pair{str(i)}"] = pair_dict

    return trans_maps

# %%
@noglobal(excepts=["cfg", "logger", "cache"])
def make_train_data(type_):
    dfs = []
    for weeks in cfg.train_weeks:
        # データ読み込み
        week_sessions = pd.read_pickle(cfg.prep_dir + f"train_sessions_{weeks}.pkl")
        week_labels = pd.read_pickle(cfg.prep_dir + f"labels_{weeks}.pkl")
        sessions_lists = np.array_split(week_sessions["session"].unique().tolist(), cfg.train_chunk_n)

        # cand作成
        for chunk in range(cfg.train_chunk_n):
            cache_file = f"train_cand_{weeks}_{chunk}.pkl"
            cache_path = cache.get_abspath(cache_file)
            print(cache_path)
            if cache.exists(cache_path):
                logger.info(f"[{cache_file}] cache exists. read cache and skip process.")
                cand_df = pd.read_pickle(cache_path)
            else:
                trans_map_cache_file = f"trans_maps_{weeks}.pkl"
                trans_map_cache_path = cache.get_abspath(trans_map_cache_file)
                with open(trans_map_cache_path, "rb") as f:
                    trans_maps = pickle.load(f)
                # 候補選出
                week_sessions_chunk = week_sessions[week_sessions["session"].isin(sessions_lists[chunk])].reset_index(drop=True)
                cand_df = make_cand_df(week_sessions_chunk, trans_maps=trans_maps)
                cand_df = reduce_mem_usage(cand_df)
                cand_df.to_pickle(cache_path)
                del week_sessions_chunk
                gc.collect()

        # candラベル付け・サンプリング
        cand_dfs = []
        for chunk in range(cfg.train_chunk_n):
            cache_file = f"train_cand_{weeks}_{chunk}.pkl"
            cache_path = cache.get_abspath(cache_file)
            cand_df_chunk = pd.read_pickle(cache_path)
            week_labels_chunk = week_labels[week_labels["session"].isin(sessions_lists[chunk])].reset_index(drop=True)
            cand_df_chunk = add_labels(cand_df_chunk, week_labels_chunk, type_)
            cand_df_chunk = under_sampling(cand_df_chunk, "labels")
            cand_dfs.append(cand_df_chunk)
            del cand_df_chunk, week_labels_chunk
            gc.collect()
        cand_df = pd.concat(cand_dfs)
        del cand_dfs
        gc.collect()

        # データ確認
        pos_cnt = len(cand_df[cand_df["labels"]==1])
        neg_cnt = len(cand_df[cand_df["labels"]==0])
        logger.info(f"train({type_}) pos : {str(pos_cnt)}  neg : {str(neg_cnt)}")

        # 特徴量付与
        train_tmp = add_features(week_sessions, cand_df, weeks)
        dfs.append(train_tmp)
        del cand_df, train_tmp
        gc.collect()
        
    train = pd.concat(dfs)
    train = train.reset_index(drop=True)
    train = reduce_mem_usage(train)

    # データ確認
    pos_cnt = len(train[train["labels"]==1])
    neg_cnt = len(train[train["labels"]==0])
    logger.info(f"train({type_}) pos : {str(pos_cnt)}  neg : {str(neg_cnt)}")

    return train

# %%
@noglobal(excepts=["cfg", "logger", "cache"])
def make_valid_cand():
    valid_week = cfg.valid_week
    # データ読み込み
    week_sessions = pd.read_pickle(os.getenv("PREP_DIR") + f"train_sessions_{valid_week}.pkl")
    week_labels = pd.read_pickle(os.getenv("PREP_DIR") + f"labels_{valid_week}.pkl")
    valid_session_ids = week_sessions["session"].unique().tolist()
    trans_map_cache_file = f"trans_maps_{valid_week}.pkl"
    trans_map_cache_path = cache.get_abspath(trans_map_cache_file)
    with open(trans_map_cache_path, "rb") as f:
        trans_maps = pickle.load(f)

    # validに使うsessionを絞る
    valid_session_n = min(cfg.valid_session_n, len(valid_session_ids))
    random.seed(cfg.seed)
    valid_session_ids = random.sample(valid_session_ids, valid_session_n)
    week_sessions = week_sessions[week_sessions["session"].isin(valid_session_ids)].copy()
    week_labels = week_labels[week_labels["session"].isin(valid_session_ids)].copy()

    # 候補選出
    cand_df = make_cand_df(week_sessions, trans_maps=trans_maps)
    cand_df = reduce_mem_usage(cand_df)
    return cand_df, week_sessions, week_labels

# %%
@noglobal(excepts=["cfg", "logger"])
def make_valid_data(cand_df, week_sessions, week_labels, type_):
    # 特徴量付与
    valid = add_features(week_sessions, cand_df, cfg.valid_week)
    valid = add_labels(valid, week_labels, type_)
    valid = valid.reset_index(drop=True)
    valid = reduce_mem_usage(valid)

    # データ確認
    pos_cnt = len(valid[valid["labels"]==1])
    neg_cnt = len(valid[valid["labels"]==0])
    logger.info(f"valid({type_}) pos : {str(pos_cnt)}  neg : {str(neg_cnt)}")
    
    return valid

# %%
@noglobal(excepts=["cfg", "logger"])
def model_training(train, valid, features, target, valid_labels, type_):
    params = {'objective': 'binary', 
            'boosting': 'gbdt', 
            'learning_rate': 0.1, 
            'metric': 'binary_logloss', 
            'seed': cfg.seed
            }

    # 学習
    vl_pred_df = valid[["session", "aid"]].copy()

    tr_x, tr_y = train[features], train[target]
    vl_x, vl_y = valid[features], valid[target]
    tr_data = lgb.Dataset(tr_x, label=tr_y)
    vl_data = lgb.Dataset(vl_x, label=vl_y)

    model = lgb.train(params, tr_data, valid_sets=[tr_data, vl_data],
                      num_boost_round=2000000, early_stopping_rounds=100, verbose_eval=100)

    # 特徴量重要度
    fi = pd.DataFrame()
    fi["feature"] = model.feature_name()
    fi["importance"] = model.feature_importance(importance_type="gain")

    # 2値分類の出力を元にk個選定
    vl_pred_df["prob"] = model.predict(vl_x, num_iteration=model.best_iteration)
    vl_pred_df = vl_pred_df.sort_values(["session", "prob"], ascending=(True, False))
    vl_pred_df = vl_pred_df.groupby(["session"]).head(cfg.k)
    vl_pred_df = vl_pred_df.groupby(["session"])["aid"].apply(list).reset_index()
    
    # 評価
    assert valid_labels["session"].tolist() == vl_pred_df["session"].unique().tolist()
    score = evaluate(valid_labels["clicks_labels"].tolist(),
                     valid_labels["carts_labels"].tolist(),
                     valid_labels["orders_labels"].tolist(),
                     vl_pred_df["aid"].tolist(),
                     vl_pred_df["aid"].tolist(),
                     vl_pred_df["aid"].tolist(),
                     cfg.k)
    logger.info(f"{type_} valid score")
    logger.info(score)

    # モデル保存
    model.save_model(cfg.output_dir + f"{cfg.exp_name}/{type_}_model.lgb")

    # 特徴量重要度
    fi_n = fi['feature'].nunique()
    order = list(fi.groupby("feature").mean().sort_values("importance", ascending=False).index)
    plt.figure(figsize=(10, fi_n*0.2))
    sns.barplot(x="importance", y="feature", data=fi, order=order)
    plt.title(f"LGBM importance({type_})")
    plt.tight_layout()
    plt.savefig(cfg.output_dir + f'{cfg.exp_name}/lgbm_importance_{type_}.png')

    return score[f"recall_{type_}"]

# %%
@noglobal(excepts=["cfg", "logger", "cache"])
def make_test_data():
    # testデータ作成
    test_sessions = pd.read_pickle(cfg.prep_dir + f"test_sessions.pkl")
    sessions_lists = np.array_split(test_sessions["session"].unique().tolist(), cfg.test_chunk_n)
    trans_map_cache_file = f"trans_maps.pkl"
    trans_map_cache_path = cache.get_abspath(trans_map_cache_file)
    with open(trans_map_cache_path, "rb") as f:
        trans_maps = pickle.load(f)

    for chunk in range(cfg.test_chunk_n):
        cache_file = f"test_{chunk}.pkl"
        cache_path = cache.get_abspath(cache_file)
        if cache.exists(cache_path):
            logger.info(f"[{cache_file}] cache exists. read cache and skip process.")
        else:
            test_sessions_chunk = test_sessions[test_sessions["session"].isin(sessions_lists[chunk])].reset_index(drop=True)
        # 候補選出
        logger.info("[make_test] make_cand_df")
        cand_df = make_cand_df(test_sessions_chunk, trans_maps=trans_maps)
        cand_df = reduce_mem_usage(cand_df)
        # 特徴量付与
        logger.info("[make_test] add_features")
        test = add_features(test_sessions, cand_df)
        test = reduce_mem_usage(test)
        test.to_pickle(cache_path)

# %%
@noglobal(excepts=["cfg", "logger", "cache"])
def inference(features):
    pred_dfs = []
    for chunk in range(cfg.test_chunk_n):
        cache_file = f"test_{chunk}.pkl"
        cache_path = cache.get_abspath(cache_file)
        test = pd.read_pickle(cache_path)

        for type_ in ["clicks", "carts", "orders"]:    
            pred_df_tmp = test[["session", "aid"]].copy()
            # 推論
            model = lgb.Booster(model_file = cfg.output_dir + f"{cfg.exp_name}/{type_}_model.lgb")
            # 2値分類の出力を元にk個選定
            pred_df_tmp["prob"] = model.predict(test[features], num_iteration=model.best_iteration)
            pred_df_tmp = pred_df_tmp.sort_values(["session", "prob"], ascending=(True, False))
            pred_df_tmp = pred_df_tmp.groupby(["session"]).head(cfg.k)
            pred_df_tmp["aid"] = pred_df_tmp["aid"].astype(str)
            pred_df_tmp = pred_df_tmp.groupby(["session"])["aid"].apply(list).reset_index()
            pred_df_tmp["aid"] = pred_df_tmp["aid"].apply(lambda x: ' '.join(x))
            pred_df_tmp["type"] = type_
            pred_dfs.append(pred_df_tmp)
        del test, model
        gc.collect()
    
    pred_df = pd.concat(pred_dfs)
    # sub作成
    sub = pd.read_csv(cfg.input_dir + f"sample_submission.csv", usecols=["session_type"])
    pred_df["session_type"] = pred_df["session"].astype(str) + "_" + pred_df["type"]
    pred_df = pred_df.rename(columns={"aid": "labels"})
    sub = sub.merge(pred_df[["session_type", "labels"]], on="session_type", how="left")
    sub.to_csv(cfg.output_dir + f"{cfg.exp_name}/{cfg.exp_name}_sub.csv", index=False)

# %%
@noglobal(excepts=["cfg", "logger", "cache"])
def main():
    scores = {}
    logger.info(f"START")
    line_notify.send(f"{cfg.exp_name} | START")
    
    # trans_map作成
    weeks = [None] + cfg.train_weeks + [cfg.valid_week]
    for week in weeks:
        if week is None:
            cache_file = "trans_maps.pkl"
        else:    
            cache_file = f"trans_maps_{week}.pkl"
        cache_path = cache.get_abspath(cache_file)
        if cache.exists(cache_path):
            logger.info(f"[{cache_file}] cache exists. load cache and skip process.")
            with open(cache_path, "rb") as f:
                trans_maps = pickle.load(f)
        else:
            trans_maps = get_trans_maps(week)
            with open(cache_path, "wb") as f:
                pickle.dump(trans_maps, f)

    for type_ in ["clicks", "carts", "orders"]:
        # train data作成
        logger.info(f"make {type_}_train_data")
        cache_file = f"{type_}_train.pkl"
        cache_path = cache.get_abspath(cache_file)
        if cache.exists(cache_path):
            logger.info(f"[{cache_file}] cache exists. read cache and skip process.")
            train = pd.read_pickle(cache_path)
        else:
            train = make_train_data(type_)
            train.to_pickle(cache_path)
        
        logger.info(f"make {type_}_valid_data")
        # valid cand作成
        cand_cache_path = cache.get_abspath("valid_cand.pkl")
        sessions_cache_path = cache.get_abspath("valid_sessions.pkl")
        labels_cache_path = cache.get_abspath("valid_labels.pkl")
        if cache.exists(cand_cache_path) & cache.exists(labels_cache_path) & cache.exists(sessions_cache_path):
            logger.info("[valid_cand.pkl] cache exists. read cache and skip process.")
            valid_cand = pd.read_pickle(cand_cache_path)
            valid_sessions = pd.read_pickle(sessions_cache_path)
            valid_labels = pd.read_pickle(labels_cache_path)
        else:
            valid_cand, valid_sessions, valid_labels = make_valid_cand()
            valid_cand.to_pickle(cand_cache_path)
            valid_sessions.to_pickle(sessions_cache_path)
            valid_labels.to_pickle(labels_cache_path)

        # valid data作成
        logger.info(f"make {type_}_valid_data")
        cache_file = f"{type_}_valid.pkl"
        cache_path = cache.get_abspath(cache_file)
        if cache.exists(cache_path):
            logger.info(f"[{cache_file}] cache exists. read cache and skip process.")
            valid = pd.read_pickle(cache_path)
        else:
            valid = make_valid_data(valid_cand, valid_sessions, valid_labels, type_)
            valid.to_pickle(cache_path)

        # モデル学習
        target = "labels"
        not_use_cols = ["session", "aid", target]
        features = [c for c in train.columns if c not in not_use_cols]

        scores[f"recall_{type_}"] = model_training(train, valid, features, target, valid_labels, type_)

        del train, valid, valid_labels
        gc.collect()
    
    scores["total"] = (float(scores["recall_clicks"]) * 0.1) + (float(scores["recall_carts"]) * 0.3) + (float(scores["recall_orders"]) * 0.6)
    report = f"\n{cfg.exp_name}\n"
    report += f'valid_end\n'
    report += str(scores)
    line_notify.send(report)

    # testデータ
    make_test_data()

    logger.info(f"-------- inference --------")
    inference(features)

    line_notify.send(f"{cfg.exp_name} | END!!")

# %%
try:
    main()
except Exception as e:
    logger.error(traceback.format_exc())
    line_notify.send(f"{cfg.exp_name} | ERROR!!\n{traceback.format_exc()}")
# Out:
# 0:00:00.787060 	 START
# 0:00:05.101606 	 [trans_maps.pkl] cache exists. load cache and skip process.
# 0:00:21.963217 	 [trans_maps_week3.pkl] cache exists. load cache and skip process.
# 0:00:39.758693 	 [trans_maps_week4.pkl] cache exists. load cache and skip process.
# 0:00:58.145854 	 make clicks_train_data
# /mnt/otto-recommender-system/output/exp051/cache/train_cand_week3_0.pkl
# 0:01:22.144117 	 [make_candidate] session_frequent : start
# 0:01:22.969208 	 [add_candidate] session_frequent : start
# 0:01:24.636484 	 [make_candidate] session_latest : start
# 0:01:25.379040 	 [add_candidate] session_latest : start
# 0:01:28.020073 	 [make_candidate] session_latest_time_wt_pair0 : start
# 0:01:29.206277 	 [add_candidate] session_latest_time_wt_pair0 : start
# 0:01:32.279799 	 [make_candidate] session_latest_word2vec_pair0 : start
# 0:01:33.278829 	 [add_candidate] session_latest_word2vec_pair0 : start
# 0:01:37.134337 	 [make_candidate] session_latest_pair0 : start
# 0:01:38.241072 	 [add_candidate] session_latest_pair0 : start
# 0:01:42.881556 	 [make_candidate] session_latest_time_wt_pair1 : start
# 0:01:44.164637 	 [add_candidate] session_latest_time_wt_pair1 : start
# 0:01:50.388401 	 [make_candidate] session_latest_word2vec_pair1 : start
# 0:01:51.672402 	 [add_candidate] session_latest_word2vec_pair1 : start
# 0:01:58.802628 	 [make_candidate] session_latest_pair1 : start
# 0:02:00.114667 	 [add_candidate] session_latest_pair1 : start
# 0:02:07.753355 	 [make_candidate] session_latest_time_wt_pair2 : start
# 0:02:09.078463 	 [add_candidate] session_latest_time_wt_pair2 : start
# 0:02:17.084452 	 [make_candidate] session_latest_word2vec_pair2 : start
# 0:02:18.306822 	 [add_candidate] session_latest_word2vec_pair2 : start
# 0:02:27.309260 	 [make_candidate] session_latest_pair2 : start
# 0:02:28.678354 	 [add_candidate] session_latest_pair2 : start
# 0:02:40.858396 	 [make_candidate] session_latest_time_wt_pair3 : start
# 0:02:42.213880 	 [add_candidate] session_latest_time_wt_pair3 : start
# 0:02:54.108827 	 [make_candidate] session_latest_word2vec_pair3 : start
# 0:02:55.420735 	 [add_candidate] session_latest_word2vec_pair3 : start
# 0:03:08.408653 	 [make_candidate] session_latest_pair3 : start
# 0:03:09.812327 	 [add_candidate] session_latest_pair3 : start
# 0:03:23.665845 	 [make_candidate] session_latest_time_wt_pair4 : start
# 0:03:24.728423 	 [add_candidate] session_latest_time_wt_pair4 : start
# 0:03:39.509130 	 [make_candidate] session_latest_word2vec_pair4 : start
# 0:03:40.580682 	 [add_candidate] session_latest_word2vec_pair4 : start
# 0:03:55.201825 	 [make_candidate] session_latest_pair4 : start
# 0:03:56.316207 	 [add_candidate] session_latest_pair4 : start
# 0:04:12.780521 	 [make_candidate] session_latest_time_wt_pair5 : start
# 0:04:14.014530 	 [add_candidate] session_latest_time_wt_pair5 : start
# 0:04:30.140904 	 [make_candidate] session_latest_word2vec_pair5 : start
# 0:04:31.619988 	 [add_candidate] session_latest_word2vec_pair5 : start
# 0:04:48.540954 	 [make_candidate] session_latest_pair5 : start
# 0:04:49.977408 	 [add_candidate] session_latest_pair5 : start
# 0:05:07.433987 	 [make_candidate] session_latest_time_wt_pair6 : start
# 0:05:08.967584 	 [add_candidate] session_latest_time_wt_pair6 : start
# 0:05:27.636701 	 [make_candidate] session_latest_word2vec_pair6 : start
# 0:05:29.029555 	 [add_candidate] session_latest_word2vec_pair6 : start
# 0:05:54.902666 	 [make_candidate] session_latest_pair6 : start
# 0:05:56.090351 	 [add_candidate] session_latest_pair6 : start
# 0:06:21.813251 	 [make_candidate] session_latest_time_wt_pair7 : start
# 0:06:23.360669 	 [add_candidate] session_latest_time_wt_pair7 : start
# 0:06:50.046154 	 [make_candidate] session_latest_word2vec_pair7 : start
# 0:06:51.570147 	 [add_candidate] session_latest_word2vec_pair7 : start
# 0:07:18.211016 	 [make_candidate] session_latest_pair7 : start
# 0:07:19.718288 	 [add_candidate] session_latest_pair7 : start
# 0:07:47.953128 	 [make_candidate] session_latest_time_wt_pair8 : start
# 0:07:49.543154 	 [add_candidate] session_latest_time_wt_pair8 : start
# 0:08:18.999388 	 [make_candidate] session_latest_word2vec_pair8 : start
# 0:08:20.512405 	 [add_candidate] session_latest_word2vec_pair8 : start
# 0:08:50.693377 	 [make_candidate] session_latest_pair8 : start
# 0:08:52.271116 	 [add_candidate] session_latest_pair8 : start
# 0:09:22.905678 	 [make_candidate] session_latest_time_wt_pair9 : start
# 0:09:24.517823 	 [add_candidate] session_latest_time_wt_pair9 : start
# 0:09:55.498751 	 [make_candidate] session_latest_word2vec_pair9 : start
# 0:09:57.091736 	 [add_candidate] session_latest_word2vec_pair9 : start
# 0:10:28.723432 	 [make_candidate] session_latest_pair9 : start
# 0:10:30.387470 	 [add_candidate] session_latest_pair9 : start
# 0:11:02.339069 	 [make_candidate] session_latest_time_wt_pair10 : start
# 0:11:04.002671 	 [add_candidate] session_latest_time_wt_pair10 : start
# 0:11:36.422041 	 [make_candidate] session_latest_word2vec_pair10 : start
# 0:11:38.060290 	 [add_candidate] session_latest_word2vec_pair10 : start
# 0:12:10.944316 	 [make_candidate] session_latest_pair10 : start
# 0:12:12.622948 	 [add_candidate] session_latest_pair10 : start
# 0:12:47.142764 	 [make_candidate] session_latest_time_wt_pair11 : start
# 0:12:48.685580 	 [add_candidate] session_latest_time_wt_pair11 : start
# 0:13:24.206685 	 [make_candidate] session_latest_word2vec_pair11 : start
# 0:13:25.734968 	 [add_candidate] session_latest_word2vec_pair11 : start
# 0:14:00.301081 	 [make_candidate] session_latest_pair11 : start
# 0:14:01.997540 	 [add_candidate] session_latest_pair11 : start
# 0:14:38.837408 	 [make_candidate] session_latest_time_wt_pair12 : start
# 0:14:40.592698 	 [add_candidate] session_latest_time_wt_pair12 : start
# 0:15:18.845732 	 [make_candidate] session_latest_word2vec_pair12 : start
# 0:15:20.393087 	 [add_candidate] session_latest_word2vec_pair12 : start
# 0:15:58.322330 	 [make_candidate] session_latest_pair12 : start
# 0:16:00.133590 	 [add_candidate] session_latest_pair12 : start
# 0:16:39.559965 	 [make_candidate] session_latest_time_wt_pair13 : start
# 0:16:41.352054 	 [add_candidate] session_latest_time_wt_pair13 : start
# 0:17:20.610636 	 [make_candidate] session_latest_word2vec_pair13 : start
# 0:17:22.188683 	 [add_candidate] session_latest_word2vec_pair13 : start
# 0:18:01.861503 	 [make_candidate] session_latest_pair13 : start
# 0:18:03.701702 	 [add_candidate] session_latest_pair13 : start
# 0:18:45.025524 	 [make_candidate] session_latest_time_wt_pair14 : start
# 0:18:46.926069 	 [add_candidate] session_latest_time_wt_pair14 : start
# 0:19:28.479569 	 [make_candidate] session_latest_word2vec_pair14 : start
# 0:19:30.062496 	 [add_candidate] session_latest_word2vec_pair14 : start
# 0:20:29.901100 	 [make_candidate] session_latest_pair14 : start
# 0:20:31.597975 	 [add_candidate] session_latest_pair14 : start
# 0:21:33.778430 	 [make_candidate] session_latest_time_wt_pair15 : start
# 0:21:35.873438 	 [add_candidate] session_latest_time_wt_pair15 : start
# 0:22:37.301550 	 [make_candidate] session_latest_word2vec_pair15 : start
# 0:22:39.260282 	 [add_candidate] session_latest_word2vec_pair15 : start
# 0:23:40.476003 	 [make_candidate] session_latest_pair15 : start
# 0:23:42.389819 	 [add_candidate] session_latest_pair15 : start
# 0:24:43.615667 	 [make_candidate] session_latest_time_wt_pair16 : start
# 0:24:45.594996 	 [add_candidate] session_latest_time_wt_pair16 : start
# 0:25:46.076489 	 [make_candidate] session_latest_word2vec_pair16 : start
# 0:25:48.189449 	 [add_candidate] session_latest_word2vec_pair16 : start
# 0:26:48.998900 	 [make_candidate] session_latest_pair16 : start
# 0:26:51.027297 	 [add_candidate] session_latest_pair16 : start
# 0:27:52.847507 	 [make_candidate] session_latest_time_wt_pair17 : start
# 0:27:54.929085 	 [add_candidate] session_latest_time_wt_pair17 : start
# 0:28:56.935941 	 [make_candidate] session_latest_word2vec_pair17 : start
# 0:28:58.889774 	 [add_candidate] session_latest_word2vec_pair17 : start
# 0:30:01.701903 	 [make_candidate] session_latest_pair17 : start
# 0:30:03.765598 	 [add_candidate] session_latest_pair17 : start
# 0:31:08.808405 	 [make_candidate] session_latest_time_wt_pair18 : start
# 0:31:10.872671 	 [add_candidate] session_latest_time_wt_pair18 : start
# 0:32:16.567059 	 [make_candidate] session_latest_word2vec_pair18 : start
# 0:32:18.727053 	 [add_candidate] session_latest_word2vec_pair18 : start
# 0:33:24.562096 	 [make_candidate] session_latest_pair18 : start
# 0:33:26.679870 	 [add_candidate] session_latest_pair18 : start
# 0:34:34.416249 	 [make_candidate] session_latest_time_wt_pair19 : start
# 0:34:36.559253 	 [add_candidate] session_latest_time_wt_pair19 : start
# 0:35:45.276652 	 [make_candidate] session_latest_word2vec_pair19 : start
# 0:35:47.478809 	 [add_candidate] session_latest_word2vec_pair19 : start
# 0:36:56.436435 	 [make_candidate] session_latest_pair19 : start
# 0:36:58.614819 	 [add_candidate] session_latest_pair19 : start
# 0:38:07.991120 	 [make_candidate] session_latest_type_wt_pair0 : start
# 0:38:10.139708 	 [add_candidate] session_latest_type_wt_pair0 : start
# 0:39:18.611419 	 [make_candidate] session_latest_clicks2carts_pair0 : start
# 0:39:20.796685 	 [add_candidate] session_latest_clicks2carts_pair0 : start
# 0:40:29.966396 	 [make_candidate] session_latest_clicks2orders_pair0 : start
# 0:40:32.115796 	 [add_candidate] session_latest_clicks2orders_pair0 : start
# 0:41:41.219984 	 [make_candidate] session_latest_type_wt_pair1 : start
# 0:41:43.440995 	 [add_candidate] session_latest_type_wt_pair1 : start
# 0:42:52.753477 	 [make_candidate] session_latest_clicks2carts_pair1 : start
# 0:42:54.924370 	 [add_candidate] session_latest_clicks2carts_pair1 : start
# 0:44:03.659805 	 [make_candidate] session_latest_clicks2orders_pair1 : start
# 0:44:05.802053 	 [add_candidate] session_latest_clicks2orders_pair1 : start
# 0:45:13.740208 	 [make_candidate] session_latest_type_wt_pair2 : start
# 0:45:15.990673 	 [add_candidate] session_latest_type_wt_pair2 : start
# 0:46:25.717183 	 [make_candidate] session_latest_clicks2carts_pair2 : start
# 0:46:27.856069 	 [add_candidate] session_latest_clicks2carts_pair2 : start
# 0:47:38.561896 	 [make_candidate] session_latest_clicks2orders_pair2 : start
# 0:47:40.700936 	 [add_candidate] session_latest_clicks2orders_pair2 : start
# 0:48:49.172443 	 [make_candidate] session_latest_type_wt_pair3 : start
# 0:48:51.477201 	 [add_candidate] session_latest_type_wt_pair3 : start
# 0:50:01.839531 	 [make_candidate] session_latest_clicks2carts_pair3 : start
# 0:50:03.978704 	 [add_candidate] session_latest_clicks2carts_pair3 : start
# 0:51:14.979152 	 [make_candidate] session_latest_clicks2orders_pair3 : start
# 0:51:17.094840 	 [add_candidate] session_latest_clicks2orders_pair3 : start
# 0:52:26.045655 	 [make_candidate] session_latest_type_wt_pair4 : start
# 0:52:28.369511 	 [add_candidate] session_latest_type_wt_pair4 : start
# 0:53:39.602181 	 [make_candidate] session_latest_clicks2carts_pair4 : start
# 0:53:41.792089 	 [add_candidate] session_latest_clicks2carts_pair4 : start
# 0:54:53.466163 	 [make_candidate] session_latest_clicks2orders_pair4 : start
# 0:54:55.600851 	 [add_candidate] session_latest_clicks2orders_pair4 : start
# Memory usage of dataframe is 6875.07 MB
# Memory usage after optimization is: 4583.38 MB
# Decreased by 33.3%
# /mnt/otto-recommender-system/output/exp051/cache/train_cand_week3_1.pkl
# 0:56:32.884870 	 [make_candidate] session_frequent : start
# 0:56:33.515313 	 [add_candidate] session_frequent : start
# 0:56:34.747919 	 [make_candidate] session_latest : start
# 0:56:35.180034 	 [add_candidate] session_latest : start
# 0:56:37.038444 	 [make_candidate] session_latest_time_wt_pair0 : start
# 0:56:37.919158 	 [add_candidate] session_latest_time_wt_pair0 : start
# 0:56:39.760445 	 [make_candidate] session_latest_word2vec_pair0 : start
# 0:56:40.553871 	 [add_candidate] session_latest_word2vec_pair0 : start
# 0:56:43.473397 	 [make_candidate] session_latest_pair0 : start
# 0:56:44.345514 	 [add_candidate] session_latest_pair0 : start
# 0:56:47.737760 	 [make_candidate] session_latest_time_wt_pair1 : start
# 0:56:48.646183 	 [add_candidate] session_latest_time_wt_pair1 : start
# 0:56:52.104155 	 [make_candidate] session_latest_word2vec_pair1 : start
# 0:56:53.018113 	 [add_candidate] session_latest_word2vec_pair1 : start
# 0:56:57.980870 	 [make_candidate] session_latest_pair1 : start
# 0:56:59.005697 	 [add_candidate] session_latest_pair1 : start
# 0:57:04.684764 	 [make_candidate] session_latest_time_wt_pair2 : start
# 0:57:05.708801 	 [add_candidate] session_latest_time_wt_pair2 : start
# 0:57:11.615102 	 [make_candidate] session_latest_word2vec_pair2 : start
# 0:57:12.687240 	 [add_candidate] session_latest_word2vec_pair2 : start
# 0:57:18.655075 	 [make_candidate] session_latest_pair2 : start
# 0:57:19.717557 	 [add_candidate] session_latest_pair2 : start
# 0:57:26.155640 	 [make_candidate] session_latest_time_wt_pair3 : start
# 0:57:27.258470 	 [add_candidate] session_latest_time_wt_pair3 : start
# 0:57:33.831820 	 [make_candidate] session_latest_word2vec_pair3 : start
# 0:57:34.929254 	 [add_candidate] session_latest_word2vec_pair3 : start
# 0:57:42.205894 	 [make_candidate] session_latest_pair3 : start
# 0:57:43.281404 	 [add_candidate] session_latest_pair3 : start
# 0:57:51.212659 	 [make_candidate] session_latest_time_wt_pair4 : start
# 0:57:52.316849 	 [add_candidate] session_latest_time_wt_pair4 : start
# 0:58:03.048141 	 [make_candidate] session_latest_word2vec_pair4 : start
# 0:58:04.096097 	 [add_candidate] session_latest_word2vec_pair4 : start
# 0:58:14.873016 	 [make_candidate] session_latest_pair4 : start
# 0:58:16.067748 	 [add_candidate] session_latest_pair4 : start
# 0:58:27.972989 	 [make_candidate] session_latest_time_wt_pair5 : start
# 0:58:29.085449 	 [add_candidate] session_latest_time_wt_pair5 : start
# 0:58:40.413112 	 [make_candidate] session_latest_word2vec_pair5 : start
# 0:58:41.501477 	 [add_candidate] session_latest_word2vec_pair5 : start
# 0:58:53.223804 	 [make_candidate] session_latest_pair5 : start
# 0:58:54.463634 	 [add_candidate] session_latest_pair5 : start
# 0:59:06.783969 	 [make_candidate] session_latest_time_wt_pair6 : start
# 0:59:07.886199 	 [add_candidate] session_latest_time_wt_pair6 : start
# 0:59:20.513618 	 [make_candidate] session_latest_word2vec_pair6 : start
# 0:59:21.671974 	 [add_candidate] session_latest_word2vec_pair6 : start
# 0:59:35.197380 	 [make_candidate] session_latest_pair6 : start
# 0:59:36.448595 	 [add_candidate] session_latest_pair6 : start
# 0:59:49.955042 	 [make_candidate] session_latest_time_wt_pair7 : start
# 0:59:51.211190 	 [add_candidate] session_latest_time_wt_pair7 : start
# 1:00:05.770771 	 [make_candidate] session_latest_word2vec_pair7 : start
# 1:00:07.033755 	 [add_candidate] session_latest_word2vec_pair7 : start
# 1:00:21.014451 	 [make_candidate] session_latest_pair7 : start
# 1:00:22.215895 	 [add_candidate] session_latest_pair7 : start
# 1:00:37.538366 	 [make_candidate] session_latest_time_wt_pair8 : start
# 1:00:38.816628 	 [add_candidate] session_latest_time_wt_pair8 : start
# 1:00:53.563661 	 [make_candidate] session_latest_word2vec_pair8 : start
# 1:00:54.835391 	 [add_candidate] session_latest_word2vec_pair8 : start
# 1:01:10.783188 	 [make_candidate] session_latest_pair8 : start
# 1:01:11.992854 	 [add_candidate] session_latest_pair8 : start
# 1:01:27.826211 	 [make_candidate] session_latest_time_wt_pair9 : start
# 1:01:29.048975 	 [add_candidate] session_latest_time_wt_pair9 : start
# 1:01:45.468511 	 [make_candidate] session_latest_word2vec_pair9 : start
# 1:01:46.800392 	 [add_candidate] session_latest_word2vec_pair9 : start
# 1:02:09.304368 	 [make_candidate] session_latest_pair9 : start
# 1:02:10.576829 	 [add_candidate] session_latest_pair9 : start
# 1:02:34.525128 	 [make_candidate] session_latest_time_wt_pair10 : start
# 1:02:35.829940 	 [add_candidate] session_latest_time_wt_pair10 : start
# 1:02:59.637777 	 [make_candidate] session_latest_word2vec_pair10 : start
# 1:03:00.971239 	 [add_candidate] session_latest_word2vec_pair10 : start
# 1:03:25.537691 	 [make_candidate] session_latest_pair10 : start
# 1:03:26.910386 	 [add_candidate] session_latest_pair10 : start
# 1:03:51.926745 	 [make_candidate] session_latest_time_wt_pair11 : start
# 1:03:53.305316 	 [add_candidate] session_latest_time_wt_pair11 : start
# 1:04:19.030189 	 [make_candidate] session_latest_word2vec_pair11 : start
# 1:04:20.366691 	 [add_candidate] session_latest_word2vec_pair11 : start
# 1:04:45.875213 	 [make_candidate] session_latest_pair11 : start
# 1:04:47.129709 	 [add_candidate] session_latest_pair11 : start
# 1:05:12.827327 	 [make_candidate] session_latest_time_wt_pair12 : start
# 1:05:14.133330 	 [add_candidate] session_latest_time_wt_pair12 : start
# 1:05:40.263919 	 [make_candidate] session_latest_word2vec_pair12 : start
# 1:05:41.730188 	 [add_candidate] session_latest_word2vec_pair12 : start
# 1:06:08.512619 	 [make_candidate] session_latest_pair12 : start
# 1:06:09.880386 	 [add_candidate] session_latest_pair12 : start
# 1:06:36.872030 	 [make_candidate] session_latest_time_wt_pair13 : start
# 1:06:38.307554 	 [add_candidate] session_latest_time_wt_pair13 : start
# 1:07:05.853407 	 [make_candidate] session_latest_word2vec_pair13 : start
# 1:07:07.313722 	 [add_candidate] session_latest_word2vec_pair13 : start
# 1:07:35.585092 	 [make_candidate] session_latest_pair13 : start
# 1:07:37.079441 	 [add_candidate] session_latest_pair13 : start
# 1:08:05.610848 	 [make_candidate] session_latest_time_wt_pair14 : start
# 1:08:07.060925 	 [add_candidate] session_latest_time_wt_pair14 : start
# 1:08:35.901356 	 [make_candidate] session_latest_word2vec_pair14 : start
# 1:08:37.423246 	 [add_candidate] session_latest_word2vec_pair14 : start
# 1:09:07.054751 	 [make_candidate] session_latest_pair14 : start
# 1:09:08.427955 	 [add_candidate] session_latest_pair14 : start
# 1:09:38.321082 	 [make_candidate] session_latest_time_wt_pair15 : start
# 1:09:39.860269 	 [add_candidate] session_latest_time_wt_pair15 : start
# 1:10:10.361658 	 [make_candidate] session_latest_word2vec_pair15 : start
# 1:10:11.838247 	 [add_candidate] session_latest_word2vec_pair15 : start
# 1:10:42.528986 	 [make_candidate] session_latest_pair15 : start
# 1:10:43.992555 	 [add_candidate] session_latest_pair15 : start
# 1:11:15.010024 	 [make_candidate] session_latest_time_wt_pair16 : start
# 1:11:16.569545 	 [add_candidate] session_latest_time_wt_pair16 : start
# 1:11:48.062497 	 [make_candidate] session_latest_word2vec_pair16 : start
# 1:11:49.601035 	 [add_candidate] session_latest_word2vec_pair16 : start
# 1:12:21.376540 	 [make_candidate] session_latest_pair16 : start
# 1:12:22.979363 	 [add_candidate] session_latest_pair16 : start
# 1:12:54.746391 	 [make_candidate] session_latest_time_wt_pair17 : start
# 1:12:56.391275 	 [add_candidate] session_latest_time_wt_pair17 : start
# 1:13:29.594761 	 [make_candidate] session_latest_word2vec_pair17 : start
# 1:13:31.180778 	 [add_candidate] session_latest_word2vec_pair17 : start
# 1:14:04.728353 	 [make_candidate] session_latest_pair17 : start
# 1:14:06.297871 	 [add_candidate] session_latest_pair17 : start
# 1:14:40.779755 	 [make_candidate] session_latest_time_wt_pair18 : start
# 1:14:42.330099 	 [add_candidate] session_latest_time_wt_pair18 : start
# 1:15:17.161624 	 [make_candidate] session_latest_word2vec_pair18 : start
# 1:15:18.745944 	 [add_candidate] session_latest_word2vec_pair18 : start
# 1:15:53.657467 	 [make_candidate] session_latest_pair18 : start
# 1:15:55.289433 	 [add_candidate] session_latest_pair18 : start
# 1:16:31.167303 	 [make_candidate] session_latest_time_wt_pair19 : start
# 1:16:32.715220 	 [add_candidate] session_latest_time_wt_pair19 : start
# 1:17:08.927788 	 [make_candidate] session_latest_word2vec_pair19 : start
# 1:17:10.661520 	 [add_candidate] session_latest_word2vec_pair19 : start
# 1:17:47.201365 	 [make_candidate] session_latest_pair19 : start
# 1:17:48.830090 	 [add_candidate] session_latest_pair19 : start
# 1:18:25.812847 	 [make_candidate] session_latest_type_wt_pair0 : start
# 1:18:27.492537 	 [add_candidate] session_latest_type_wt_pair0 : start
# 1:19:04.858474 	 [make_candidate] session_latest_clicks2carts_pair0 : start
# 1:19:06.601142 	 [add_candidate] session_latest_clicks2carts_pair0 : start
# 1:19:43.567172 	 [make_candidate] session_latest_clicks2orders_pair0 : start
# 1:19:45.124727 	 [add_candidate] session_latest_clicks2orders_pair0 : start
# 1:20:22.644160 	 [make_candidate] session_latest_type_wt_pair1 : start
# 1:20:24.249972 	 [add_candidate] session_latest_type_wt_pair1 : start
# 1:21:02.227050 	 [make_candidate] session_latest_clicks2carts_pair1 : start
# 1:21:03.880881 	 [add_candidate] session_latest_clicks2carts_pair1 : start
# 1:21:42.095418 	 [make_candidate] session_latest_clicks2orders_pair1 : start
# 1:21:43.661553 	 [add_candidate] session_latest_clicks2orders_pair1 : start
# 1:22:37.445566 	 [make_candidate] session_latest_type_wt_pair2 : start
# 1:22:38.998538 	 [add_candidate] session_latest_type_wt_pair2 : start
# 1:23:32.297656 	 [make_candidate] session_latest_clicks2carts_pair2 : start
# 1:23:33.870025 	 [add_candidate] session_latest_clicks2carts_pair2 : start
# 1:24:27.772971 	 [make_candidate] session_latest_clicks2orders_pair2 : start
# 1:24:29.436172 	 [add_candidate] session_latest_clicks2orders_pair2 : start
# 1:25:23.866601 	 [make_candidate] session_latest_type_wt_pair3 : start
# 1:25:25.534985 	 [add_candidate] session_latest_type_wt_pair3 : start
# 1:26:20.185322 	 [make_candidate] session_latest_clicks2carts_pair3 : start
# 1:26:21.607767 	 [add_candidate] session_latest_clicks2carts_pair3 : start
# 1:27:15.802082 	 [make_candidate] session_latest_clicks2orders_pair3 : start
# 1:27:17.353849 	 [add_candidate] session_latest_clicks2orders_pair3 : start
# 1:28:11.674555 	 [make_candidate] session_latest_type_wt_pair4 : start
# 1:28:13.484185 	 [add_candidate] session_latest_type_wt_pair4 : start
# 1:29:07.393078 	 [make_candidate] session_latest_clicks2carts_pair4 : start
# 1:29:08.976238 	 [add_candidate] session_latest_clicks2carts_pair4 : start
# 1:30:03.049092 	 [make_candidate] session_latest_clicks2orders_pair4 : start
# 1:30:04.689442 	 [add_candidate] session_latest_clicks2orders_pair4 : start
# Memory usage of dataframe is 5015.18 MB
# Memory usage after optimization is: 3343.45 MB
# Decreased by 33.3%
# 1:36:14.845238 	 train(clicks) pos : 2653515  neg : 2653515
# 1:36:16.988389 	 [features] session_cnt : start
# 1:36:24.284347 	 [features] session_aid_nunique : start
# 1:36:26.481945 	 [features] session_last_type : start
# 1:36:28.733024 	 [features] aid_cnt : start
# Memory usage of dataframe is 1680.31 MB
# Memory usage after optimization is: 693.38 MB
# Decreased by 58.7%
# 2:35:36.700182 	 train(clicks) pos : 2653515  neg : 2653515
# 2:35:39.535327 	 make clicks_valid_data
# 2:36:07.393679 	 [make_candidate] session_frequent : start
# 2:36:07.638668 	 [add_candidate] session_frequent : start
# 2:36:07.674365 	 [make_candidate] session_latest : start
# 2:36:07.938355 	 [add_candidate] session_latest : start
# 2:36:07.983541 	 [make_candidate] session_latest_time_wt_pair0 : start
# 2:36:08.365096 	 [add_candidate] session_latest_time_wt_pair0 : start
# 2:36:08.410244 	 [make_candidate] session_latest_word2vec_pair0 : start
# 2:36:08.771528 	 [add_candidate] session_latest_word2vec_pair0 : start
# 2:36:08.849233 	 [make_candidate] session_latest_pair0 : start
# 2:36:09.213788 	 [add_candidate] session_latest_pair0 : start
# 2:36:09.309207 	 [make_candidate] session_latest_time_wt_pair1 : start
# 2:36:09.698484 	 [add_candidate] session_latest_time_wt_pair1 : start
# 2:36:09.830654 	 [make_candidate] session_latest_word2vec_pair1 : start
# 2:36:10.204908 	 [add_candidate] session_latest_word2vec_pair1 : start
# 2:36:10.370269 	 [make_candidate] session_latest_pair1 : start
# 2:36:10.741788 	 [add_candidate] session_latest_pair1 : start
# 2:36:10.922270 	 [make_candidate] session_latest_time_wt_pair2 : start
# 2:36:11.296856 	 [add_candidate] session_latest_time_wt_pair2 : start
# 2:36:11.503723 	 [make_candidate] session_latest_word2vec_pair2 : start
# 2:36:11.854056 	 [add_candidate] session_latest_word2vec_pair2 : start
# 2:36:12.072356 	 [make_candidate] session_latest_pair2 : start
# 2:36:12.416300 	 [add_candidate] session_latest_pair2 : start
# 2:36:12.655532 	 [make_candidate] session_latest_time_wt_pair3 : start
# 2:36:12.995665 	 [add_candidate] session_latest_time_wt_pair3 : start
# 2:36:13.227943 	 [make_candidate] session_latest_word2vec_pair3 : start
# 2:36:13.575821 	 [add_candidate] session_latest_word2vec_pair3 : start
# 2:36:13.823864 	 [make_candidate] session_latest_pair3 : start
# 2:36:14.173457 	 [add_candidate] session_latest_pair3 : start
# 2:36:14.438901 	 [make_candidate] session_latest_time_wt_pair4 : start
# 2:36:14.809566 	 [add_candidate] session_latest_time_wt_pair4 : start
# 2:36:15.068894 	 [make_candidate] session_latest_word2vec_pair4 : start
# 2:36:15.499624 	 [add_candidate] session_latest_word2vec_pair4 : start
# 2:36:15.784094 	 [make_candidate] session_latest_pair4 : start
# 2:36:16.121598 	 [add_candidate] session_latest_pair4 : start
# 2:36:16.435087 	 [make_candidate] session_latest_time_wt_pair5 : start
# 2:36:16.782648 	 [add_candidate] session_latest_time_wt_pair5 : start
# 2:36:17.083826 	 [make_candidate] session_latest_word2vec_pair5 : start
# 2:36:17.439456 	 [add_candidate] session_latest_word2vec_pair5 : start
# 2:36:17.879215 	 [make_candidate] session_latest_pair5 : start
# 2:36:18.223151 	 [add_candidate] session_latest_pair5 : start
# 2:36:18.685285 	 [make_candidate] session_latest_time_wt_pair6 : start
# 2:36:19.045041 	 [add_candidate] session_latest_time_wt_pair6 : start
# 2:36:19.530938 	 [make_candidate] session_latest_word2vec_pair6 : start
# 2:36:19.890681 	 [add_candidate] session_latest_word2vec_pair6 : start
# 2:36:20.375560 	 [make_candidate] session_latest_pair6 : start
# 2:36:20.712745 	 [add_candidate] session_latest_pair6 : start
# 2:36:21.229978 	 [make_candidate] session_latest_time_wt_pair7 : start
# 2:36:21.590869 	 [add_candidate] session_latest_time_wt_pair7 : start
# 2:36:22.144035 	 [make_candidate] session_latest_word2vec_pair7 : start
# 2:36:22.582848 	 [add_candidate] session_latest_word2vec_pair7 : start
# 2:36:23.126862 	 [make_candidate] session_latest_pair7 : start
# 2:36:23.472188 	 [add_candidate] session_latest_pair7 : start
# 2:36:24.035573 	 [make_candidate] session_latest_time_wt_pair8 : start
# 2:36:24.374524 	 [add_candidate] session_latest_time_wt_pair8 : start
# 2:36:24.962460 	 [make_candidate] session_latest_word2vec_pair8 : start
# 2:36:25.313552 	 [add_candidate] session_latest_word2vec_pair8 : start
# 2:36:25.899989 	 [make_candidate] session_latest_pair8 : start
# 2:36:26.238843 	 [add_candidate] session_latest_pair8 : start
# 2:36:26.844926 	 [make_candidate] session_latest_time_wt_pair9 : start
# 2:36:27.196904 	 [add_candidate] session_latest_time_wt_pair9 : start
# 2:36:27.840160 	 [make_candidate] session_latest_word2vec_pair9 : start
# 2:36:28.239430 	 [add_candidate] session_latest_word2vec_pair9 : start
# 2:36:28.875278 	 [make_candidate] session_latest_pair9 : start
# 2:36:29.216712 	 [add_candidate] session_latest_pair9 : start
# 2:36:29.868444 	 [make_candidate] session_latest_time_wt_pair10 : start
# 2:36:30.230113 	 [add_candidate] session_latest_time_wt_pair10 : start
# 2:36:30.891869 	 [make_candidate] session_latest_word2vec_pair10 : start
# 2:36:31.335899 	 [add_candidate] session_latest_word2vec_pair10 : start
# 2:36:32.014422 	 [make_candidate] session_latest_pair10 : start
# 2:36:32.351093 	 [add_candidate] session_latest_pair10 : start
# 2:36:33.051849 	 [make_candidate] session_latest_time_wt_pair11 : start
# 2:36:33.500794 	 [add_candidate] session_latest_time_wt_pair11 : start
# 2:36:34.220977 	 [make_candidate] session_latest_word2vec_pair11 : start
# 2:36:34.597044 	 [add_candidate] session_latest_word2vec_pair11 : start
# 2:36:35.335626 	 [make_candidate] session_latest_pair11 : start
# 2:36:35.757281 	 [add_candidate] session_latest_pair11 : start
# 2:36:36.834587 	 [make_candidate] session_latest_time_wt_pair12 : start
# 2:36:37.211599 	 [add_candidate] session_latest_time_wt_pair12 : start
# 2:36:38.288440 	 [make_candidate] session_latest_word2vec_pair12 : start
# 2:36:38.744211 	 [add_candidate] session_latest_word2vec_pair12 : start
# 2:36:39.798387 	 [make_candidate] session_latest_pair12 : start
# 2:36:40.150529 	 [add_candidate] session_latest_pair12 : start
# 2:36:41.236105 	 [make_candidate] session_latest_time_wt_pair13 : start
# 2:36:41.695518 	 [add_candidate] session_latest_time_wt_pair13 : start
# 2:36:42.833691 	 [make_candidate] session_latest_word2vec_pair13 : start
# 2:36:43.244740 	 [add_candidate] session_latest_word2vec_pair13 : start
# 2:36:44.387568 	 [make_candidate] session_latest_pair13 : start
# 2:36:44.726114 	 [add_candidate] session_latest_pair13 : start
# 2:36:45.862892 	 [make_candidate] session_latest_time_wt_pair14 : start
# 2:36:46.337153 	 [add_candidate] session_latest_time_wt_pair14 : start
# 2:36:47.442851 	 [make_candidate] session_latest_word2vec_pair14 : start
# 2:36:47.838387 	 [add_candidate] session_latest_word2vec_pair14 : start
# 2:36:48.977869 	 [make_candidate] session_latest_pair14 : start
# 2:36:49.337590 	 [add_candidate] session_latest_pair14 : start
# 2:36:50.501514 	 [make_candidate] session_latest_time_wt_pair15 : start
# 2:36:50.995059 	 [add_candidate] session_latest_time_wt_pair15 : start
# 2:36:52.176943 	 [make_candidate] session_latest_word2vec_pair15 : start
# 2:36:52.618818 	 [add_candidate] session_latest_word2vec_pair15 : start
# 2:36:53.775863 	 [make_candidate] session_latest_pair15 : start
# 2:36:54.120943 	 [add_candidate] session_latest_pair15 : start
# 2:36:55.298970 	 [make_candidate] session_latest_time_wt_pair16 : start
# 2:36:55.745859 	 [add_candidate] session_latest_time_wt_pair16 : start
# 2:36:56.955167 	 [make_candidate] session_latest_word2vec_pair16 : start
# 2:36:57.329792 	 [add_candidate] session_latest_word2vec_pair16 : start
# 2:36:58.547615 	 [make_candidate] session_latest_pair16 : start
# 2:36:58.885068 	 [add_candidate] session_latest_pair16 : start
# 2:37:00.123644 	 [make_candidate] session_latest_time_wt_pair17 : start
# 2:37:00.482048 	 [add_candidate] session_latest_time_wt_pair17 : start
# 2:37:01.724243 	 [make_candidate] session_latest_word2vec_pair17 : start
# 2:37:02.101496 	 [add_candidate] session_latest_word2vec_pair17 : start
# 2:37:03.356632 	 [make_candidate] session_latest_pair17 : start
# 2:37:03.693092 	 [add_candidate] session_latest_pair17 : start
# 2:37:05.019078 	 [make_candidate] session_latest_time_wt_pair18 : start
# 2:37:05.456412 	 [add_candidate] session_latest_time_wt_pair18 : start
# 2:37:06.791789 	 [make_candidate] session_latest_word2vec_pair18 : start
# 2:37:07.156950 	 [add_candidate] session_latest_word2vec_pair18 : start
# 2:37:08.512005 	 [make_candidate] session_latest_pair18 : start
# 2:37:08.917701 	 [add_candidate] session_latest_pair18 : start
# 2:37:10.313137 	 [make_candidate] session_latest_time_wt_pair19 : start
# 2:37:10.684820 	 [add_candidate] session_latest_time_wt_pair19 : start
# 2:37:12.073755 	 [make_candidate] session_latest_word2vec_pair19 : start
# 2:37:12.453773 	 [add_candidate] session_latest_word2vec_pair19 : start
# 2:37:13.841427 	 [make_candidate] session_latest_pair19 : start
# 2:37:14.138154 	 [add_candidate] session_latest_pair19 : start
# 2:37:15.575873 	 [make_candidate] session_latest_type_wt_pair0 : start
# 2:37:16.046077 	 [add_candidate] session_latest_type_wt_pair0 : start
# 2:37:17.472687 	 [make_candidate] session_latest_clicks2carts_pair0 : start
# 2:37:17.784756 	 [add_candidate] session_latest_clicks2carts_pair0 : start
# 2:37:19.203140 	 [make_candidate] session_latest_clicks2orders_pair0 : start
# 2:37:19.449591 	 [add_candidate] session_latest_clicks2orders_pair0 : start
# 2:37:20.847585 	 [make_candidate] session_latest_type_wt_pair1 : start
# 2:37:21.311686 	 [add_candidate] session_latest_type_wt_pair1 : start
# 2:37:22.745219 	 [make_candidate] session_latest_clicks2carts_pair1 : start
# 2:37:23.020845 	 [add_candidate] session_latest_clicks2carts_pair1 : start
# 2:37:24.459457 	 [make_candidate] session_latest_clicks2orders_pair1 : start
# 2:37:24.688349 	 [add_candidate] session_latest_clicks2orders_pair1 : start
# 2:37:26.106489 	 [make_candidate] session_latest_type_wt_pair2 : start
# 2:37:26.479953 	 [add_candidate] session_latest_type_wt_pair2 : start
# 2:37:27.928567 	 [make_candidate] session_latest_clicks2carts_pair2 : start
# 2:37:28.181918 	 [add_candidate] session_latest_clicks2carts_pair2 : start
# 2:37:29.638334 	 [make_candidate] session_latest_clicks2orders_pair2 : start
# 2:37:29.887933 	 [add_candidate] session_latest_clicks2orders_pair2 : start
# 2:37:31.328533 	 [make_candidate] session_latest_type_wt_pair3 : start
# 2:37:31.710342 	 [add_candidate] session_latest_type_wt_pair3 : start
# 2:37:33.183915 	 [make_candidate] session_latest_clicks2carts_pair3 : start
# 2:37:33.444957 	 [add_candidate] session_latest_clicks2carts_pair3 : start
# 2:37:34.895815 	 [make_candidate] session_latest_clicks2orders_pair3 : start
# 2:37:35.189316 	 [add_candidate] session_latest_clicks2orders_pair3 : start
# 2:37:36.670150 	 [make_candidate] session_latest_type_wt_pair4 : start
# 2:37:37.059705 	 [add_candidate] session_latest_type_wt_pair4 : start
# 2:37:38.514811 	 [make_candidate] session_latest_clicks2carts_pair4 : start
# 2:37:38.774827 	 [add_candidate] session_latest_clicks2carts_pair4 : start
# 2:37:40.240188 	 [make_candidate] session_latest_clicks2orders_pair4 : start
# 2:37:40.458638 	 [add_candidate] session_latest_clicks2orders_pair4 : start
# Memory usage of dataframe is 258.98 MB
# Memory usage after optimization is: 172.65 MB
# Decreased by 33.3%
# 2:37:43.650610 	 make clicks_valid_data
# 2:37:43.748034 	 [features] session_cnt : start
# 2:37:47.734701 	 [features] session_aid_nunique : start
# 2:37:48.854260 	 [features] session_last_type : start
# 2:37:50.148206 	 [features] aid_cnt : start
# Memory usage of dataframe is 3582.57 MB
# Memory usage after optimization is: 1456.77 MB
# Decreased by 59.3%
# 3:38:23.566456 	 valid(clicks) pos : 56765  neg : 11258287
# /home/kaggler/.local/lib/python3.8/site-packages/lightgbm/engine.py:181: UserWarning: 'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. Pass 'early_stopping()' callback via 'callbacks' argument instead.
#   _log_warning("'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. "
# /home/kaggler/.local/lib/python3.8/site-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# [LightGBM] [Info] Number of positive: 2653515, number of negative: 2653515
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.409835 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 11931
# [LightGBM] [Info] Number of data points in the train set: 5307030, number of used features: 55
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500000 -> initscore=0.000000
# Training until validation scores don't improve for 100 rounds
# [100]	training's binary_logloss: 0.333801	valid_1's binary_logloss: 0.320859
# [200]	training's binary_logloss: 0.331387	valid_1's binary_logloss: 0.319149
# [300]	training's binary_logloss: 0.330097	valid_1's binary_logloss: 0.318423
# [400]	training's binary_logloss: 0.329012	valid_1's binary_logloss: 0.317882
# [500]	training's binary_logloss: 0.328147	valid_1's binary_logloss: 0.317631
# [600]	training's binary_logloss: 0.327311	valid_1's binary_logloss: 0.31732
# [700]	training's binary_logloss: 0.326506	valid_1's binary_logloss: 0.317091
# [800]	training's binary_logloss: 0.325799	valid_1's binary_logloss: 0.316886
# [900]	training's binary_logloss: 0.32515	valid_1's binary_logloss: 0.316763
# [1000]	training's binary_logloss: 0.324515	valid_1's binary_logloss: 0.31663
# [1100]	training's binary_logloss: 0.323843	valid_1's binary_logloss: 0.316443
# [1200]	training's binary_logloss: 0.323222	valid_1's binary_logloss: 0.316341
# [1300]	training's binary_logloss: 0.322632	valid_1's binary_logloss: 0.316205
# [1400]	training's binary_logloss: 0.32202	valid_1's binary_logloss: 0.316059
# [1500]	training's binary_logloss: 0.3215	valid_1's binary_logloss: 0.316012
# [1600]	training's binary_logloss: 0.320936	valid_1's binary_logloss: 0.315949
# [1700]	training's binary_logloss: 0.320398	valid_1's binary_logloss: 0.315904
# Early stopping, best iteration is:
# [1668]	training's binary_logloss: 0.320542	valid_1's binary_logloss: 0.315901
# 3:43:17.532003 	 clicks valid score
# 3:43:17.533381 	 {'num_clicks': 97136, 'hit_clicks': 49133, 'num_carts': 43211, 'hit_carts': 14610, 'num_orders': 20082, 'hit_orders': 11064, 'recall_clicks': '0.506', 'recall_carts': '0.338', 'recall_orders': '0.551', 'w_recall_clicks': '0.051', 'w_recall_carts': '0.101', 'w_recall_orders': '0.331', 'score': '0.483'}
# 3:43:18.417760 	 make carts_train_data
# /mnt/otto-recommender-system/output/exp051/cache/train_cand_week3_0.pkl
# 3:43:46.556882 	 [make_candidate] session_frequent : start
# 3:43:47.258467 	 [add_candidate] session_frequent : start
# 3:43:48.823947 	 [make_candidate] session_latest : start
# 3:43:49.529786 	 [add_candidate] session_latest : start
# 3:43:52.107606 	 [make_candidate] session_latest_time_wt_pair0 : start
# 3:43:53.154414 	 [add_candidate] session_latest_time_wt_pair0 : start
# 3:43:56.235075 	 [make_candidate] session_latest_word2vec_pair0 : start
# 3:43:57.320246 	 [add_candidate] session_latest_word2vec_pair0 : start
# 3:44:01.119146 	 [make_candidate] session_latest_pair0 : start
# 3:44:02.269116 	 [add_candidate] session_latest_pair0 : start
# 3:44:06.996331 	 [make_candidate] session_latest_time_wt_pair1 : start
# 3:44:08.261622 	 [add_candidate] session_latest_time_wt_pair1 : start
# 3:44:14.651844 	 [make_candidate] session_latest_word2vec_pair1 : start
# 3:44:15.958814 	 [add_candidate] session_latest_word2vec_pair1 : start
# 3:44:22.736367 	 [make_candidate] session_latest_pair1 : start
# 3:44:24.049854 	 [add_candidate] session_latest_pair1 : start
# 3:44:31.251759 	 [make_candidate] session_latest_time_wt_pair2 : start
# 3:44:32.528128 	 [add_candidate] session_latest_time_wt_pair2 : start
# 3:44:40.594227 	 [make_candidate] session_latest_word2vec_pair2 : start
# 3:44:41.918797 	 [add_candidate] session_latest_word2vec_pair2 : start
# 3:44:50.907465 	 [make_candidate] session_latest_pair2 : start
# 3:44:52.333689 	 [add_candidate] session_latest_pair2 : start
# 3:45:04.217323 	 [make_candidate] session_latest_time_wt_pair3 : start
# 3:45:05.484115 	 [add_candidate] session_latest_time_wt_pair3 : start
# 3:45:18.312544 	 [make_candidate] session_latest_word2vec_pair3 : start
# 3:45:19.708346 	 [add_candidate] session_latest_word2vec_pair3 : start
# 3:45:32.794456 	 [make_candidate] session_latest_pair3 : start
# 3:45:34.094105 	 [add_candidate] session_latest_pair3 : start
# 3:45:47.732826 	 [make_candidate] session_latest_time_wt_pair4 : start
# 3:45:49.089565 	 [add_candidate] session_latest_time_wt_pair4 : start
# 3:46:03.660763 	 [make_candidate] session_latest_word2vec_pair4 : start
# 3:46:05.077639 	 [add_candidate] session_latest_word2vec_pair4 : start
# 3:46:19.716163 	 [make_candidate] session_latest_pair4 : start
# 3:46:21.033904 	 [add_candidate] session_latest_pair4 : start
# 3:46:36.814642 	 [make_candidate] session_latest_time_wt_pair5 : start
# 3:46:38.282922 	 [add_candidate] session_latest_time_wt_pair5 : start
# 3:46:54.163810 	 [make_candidate] session_latest_word2vec_pair5 : start
# 3:46:55.678369 	 [add_candidate] session_latest_word2vec_pair5 : start
# 3:47:12.445786 	 [make_candidate] session_latest_pair5 : start
# 3:47:13.827286 	 [add_candidate] session_latest_pair5 : start
# 3:47:31.143593 	 [make_candidate] session_latest_time_wt_pair6 : start
# 3:47:32.668163 	 [add_candidate] session_latest_time_wt_pair6 : start
# 3:47:50.890638 	 [make_candidate] session_latest_word2vec_pair6 : start
# 3:47:52.443551 	 [add_candidate] session_latest_word2vec_pair6 : start
# 3:48:17.235946 	 [make_candidate] session_latest_pair6 : start
# 3:48:18.758657 	 [add_candidate] session_latest_pair6 : start
# 3:48:44.639333 	 [make_candidate] session_latest_time_wt_pair7 : start
# 3:48:46.222761 	 [add_candidate] session_latest_time_wt_pair7 : start
# 3:49:12.571132 	 [make_candidate] session_latest_word2vec_pair7 : start
# 3:49:14.218266 	 [add_candidate] session_latest_word2vec_pair7 : start
# 3:49:41.084769 	 [make_candidate] session_latest_pair7 : start
# 3:49:42.569246 	 [add_candidate] session_latest_pair7 : start
# 3:50:10.180046 	 [make_candidate] session_latest_time_wt_pair8 : start
# 3:50:11.802512 	 [add_candidate] session_latest_time_wt_pair8 : start
# 3:50:39.926904 	 [make_candidate] session_latest_word2vec_pair8 : start
# 3:50:41.631517 	 [add_candidate] session_latest_word2vec_pair8 : start
# 3:51:09.641483 	 [make_candidate] session_latest_pair8 : start
# 3:51:11.287418 	 [add_candidate] session_latest_pair8 : start
# 3:51:40.682893 	 [make_candidate] session_latest_time_wt_pair9 : start
# 3:51:42.398419 	 [add_candidate] session_latest_time_wt_pair9 : start
# 3:52:12.469148 	 [make_candidate] session_latest_word2vec_pair9 : start
# 3:52:14.152438 	 [add_candidate] session_latest_word2vec_pair9 : start
# 3:52:44.649941 	 [make_candidate] session_latest_pair9 : start
# 3:52:46.329100 	 [add_candidate] session_latest_pair9 : start
# 3:53:17.815191 	 [make_candidate] session_latest_time_wt_pair10 : start
# 3:53:19.540788 	 [add_candidate] session_latest_time_wt_pair10 : start
# 3:53:51.734333 	 [make_candidate] session_latest_word2vec_pair10 : start
# 3:53:53.458758 	 [add_candidate] session_latest_word2vec_pair10 : start
# 3:54:26.030324 	 [make_candidate] session_latest_pair10 : start
# 3:54:27.696358 	 [add_candidate] session_latest_pair10 : start
# 3:55:00.835081 	 [make_candidate] session_latest_time_wt_pair11 : start
# 3:55:02.650206 	 [add_candidate] session_latest_time_wt_pair11 : start
# 3:55:36.501030 	 [make_candidate] session_latest_word2vec_pair11 : start
# 3:55:38.292946 	 [add_candidate] session_latest_word2vec_pair11 : start
# 3:56:12.831558 	 [make_candidate] session_latest_pair11 : start
# 3:56:14.642428 	 [add_candidate] session_latest_pair11 : start
# 3:56:50.378318 	 [make_candidate] session_latest_time_wt_pair12 : start
# 3:56:52.245214 	 [add_candidate] session_latest_time_wt_pair12 : start
# 3:57:28.083460 	 [make_candidate] session_latest_word2vec_pair12 : start
# 3:57:29.854861 	 [add_candidate] session_latest_word2vec_pair12 : start
# 3:58:06.639543 	 [make_candidate] session_latest_pair12 : start
# 3:58:08.406263 	 [add_candidate] session_latest_pair12 : start
# 3:58:45.713302 	 [make_candidate] session_latest_time_wt_pair13 : start
# 3:58:47.618584 	 [add_candidate] session_latest_time_wt_pair13 : start
# 3:59:25.528113 	 [make_candidate] session_latest_word2vec_pair13 : start
# 3:59:27.395093 	 [add_candidate] session_latest_word2vec_pair13 : start
# 4:00:05.751898 	 [make_candidate] session_latest_pair13 : start
# 4:00:07.573634 	 [add_candidate] session_latest_pair13 : start
# 4:00:47.098100 	 [make_candidate] session_latest_time_wt_pair14 : start
# 4:00:48.988188 	 [add_candidate] session_latest_time_wt_pair14 : start
# 4:01:29.051257 	 [make_candidate] session_latest_word2vec_pair14 : start
# 4:01:30.973608 	 [add_candidate] session_latest_word2vec_pair14 : start
# 4:02:27.839701 	 [make_candidate] session_latest_pair14 : start
# 4:02:29.706551 	 [add_candidate] session_latest_pair14 : start
# 4:03:27.406729 	 [make_candidate] session_latest_time_wt_pair15 : start
# 4:03:29.331116 	 [add_candidate] session_latest_time_wt_pair15 : start
# 4:04:28.121513 	 [make_candidate] session_latest_word2vec_pair15 : start
# 4:04:30.111825 	 [add_candidate] session_latest_word2vec_pair15 : start
# 4:05:29.467243 	 [make_candidate] session_latest_pair15 : start
# 4:05:31.405406 	 [add_candidate] session_latest_pair15 : start
# 4:06:31.512128 	 [make_candidate] session_latest_time_wt_pair16 : start
# 4:06:33.353191 	 [add_candidate] session_latest_time_wt_pair16 : start
# 4:07:34.000240 	 [make_candidate] session_latest_word2vec_pair16 : start
# 4:07:36.031828 	 [add_candidate] session_latest_word2vec_pair16 : start
# 4:08:36.922738 	 [make_candidate] session_latest_pair16 : start
# 4:08:38.946059 	 [add_candidate] session_latest_pair16 : start
# 4:09:40.961796 	 [make_candidate] session_latest_time_wt_pair17 : start
# 4:09:43.001322 	 [add_candidate] session_latest_time_wt_pair17 : start
# 4:10:45.374332 	 [make_candidate] session_latest_word2vec_pair17 : start
# 4:10:47.380710 	 [add_candidate] session_latest_word2vec_pair17 : start
# 4:11:50.534342 	 [make_candidate] session_latest_pair17 : start
# 4:11:52.519654 	 [add_candidate] session_latest_pair17 : start
# 4:12:56.306079 	 [make_candidate] session_latest_time_wt_pair18 : start
# 4:12:58.338167 	 [add_candidate] session_latest_time_wt_pair18 : start
# 4:14:02.979501 	 [make_candidate] session_latest_word2vec_pair18 : start
# 4:14:05.148319 	 [add_candidate] session_latest_word2vec_pair18 : start
# 4:15:10.494062 	 [make_candidate] session_latest_pair18 : start
# 4:15:12.607779 	 [add_candidate] session_latest_pair18 : start
# 4:16:18.794398 	 [make_candidate] session_latest_time_wt_pair19 : start
# 4:16:21.011428 	 [add_candidate] session_latest_time_wt_pair19 : start
# 4:17:27.974035 	 [make_candidate] session_latest_word2vec_pair19 : start
# 4:17:30.216901 	 [add_candidate] session_latest_word2vec_pair19 : start
# 4:18:37.768045 	 [make_candidate] session_latest_pair19 : start
# 4:18:39.922370 	 [add_candidate] session_latest_pair19 : start
# 4:19:47.798928 	 [make_candidate] session_latest_type_wt_pair0 : start
# 4:19:49.985771 	 [add_candidate] session_latest_type_wt_pair0 : start
# 4:20:57.061064 	 [make_candidate] session_latest_clicks2carts_pair0 : start
# 4:20:59.215307 	 [add_candidate] session_latest_clicks2carts_pair0 : start
# 4:22:06.589358 	 [make_candidate] session_latest_clicks2orders_pair0 : start
# 4:22:08.634852 	 [add_candidate] session_latest_clicks2orders_pair0 : start
# 4:23:16.029088 	 [make_candidate] session_latest_type_wt_pair1 : start
# 4:23:18.291972 	 [add_candidate] session_latest_type_wt_pair1 : start
# 4:24:26.112260 	 [make_candidate] session_latest_clicks2carts_pair1 : start
# 4:24:28.184646 	 [add_candidate] session_latest_clicks2carts_pair1 : start
# 4:25:36.253232 	 [make_candidate] session_latest_clicks2orders_pair1 : start
# 4:25:38.366978 	 [add_candidate] session_latest_clicks2orders_pair1 : start
# 4:26:46.678961 	 [make_candidate] session_latest_type_wt_pair2 : start
# 4:26:48.986187 	 [add_candidate] session_latest_type_wt_pair2 : start
# 4:27:57.367618 	 [make_candidate] session_latest_clicks2carts_pair2 : start
# 4:27:59.527118 	 [add_candidate] session_latest_clicks2carts_pair2 : start
# 4:29:07.748529 	 [make_candidate] session_latest_clicks2orders_pair2 : start
# 4:29:09.864676 	 [add_candidate] session_latest_clicks2orders_pair2 : start
# 4:30:18.770626 	 [make_candidate] session_latest_type_wt_pair3 : start
# 4:30:20.992326 	 [add_candidate] session_latest_type_wt_pair3 : start
# 4:31:30.792765 	 [make_candidate] session_latest_clicks2carts_pair3 : start
# 4:31:32.978598 	 [add_candidate] session_latest_clicks2carts_pair3 : start
# 4:32:42.912836 	 [make_candidate] session_latest_clicks2orders_pair3 : start
# 4:32:44.983450 	 [add_candidate] session_latest_clicks2orders_pair3 : start
# 4:33:55.563622 	 [make_candidate] session_latest_type_wt_pair4 : start
# 4:33:57.825505 	 [add_candidate] session_latest_type_wt_pair4 : start
# 4:35:08.982591 	 [make_candidate] session_latest_clicks2carts_pair4 : start
# 4:35:11.127920 	 [add_candidate] session_latest_clicks2carts_pair4 : start
# 4:36:22.459620 	 [make_candidate] session_latest_clicks2orders_pair4 : start
# 4:36:24.641137 	 [add_candidate] session_latest_clicks2orders_pair4 : start
# Memory usage of dataframe is 6875.07 MB
# Memory usage after optimization is: 4583.38 MB
# Decreased by 33.3%
# /mnt/otto-recommender-system/output/exp051/cache/train_cand_week3_1.pkl
# 4:38:02.493695 	 [make_candidate] session_frequent : start
# 4:38:03.165466 	 [add_candidate] session_frequent : start
# 4:38:04.374326 	 [make_candidate] session_latest : start
# ...
# 7:04:41.140880 	 [make_candidate] session_latest_clicks2orders_pair0 : start
# 7:04:41.395148 	 [add_candidate] session_latest_clicks2orders_pair0 : start
# 7:04:42.773057 	 [make_candidate] session_latest_type_wt_pair1 : start
# 7:04:43.231260 	 [add_candidate] session_latest_type_wt_pair1 : start
# 7:04:44.629520 	 [make_candidate] session_latest_clicks2carts_pair1 : start
# 7:04:44.950846 	 [add_candidate] session_latest_clicks2carts_pair1 : start
# 7:04:46.413750 	 [make_candidate] session_latest_clicks2orders_pair1 : start
# 7:04:46.654651 	 [add_candidate] session_latest_clicks2orders_pair1 : start
# 7:04:48.063731 	 [make_candidate] session_latest_type_wt_pair2 : start
# 7:04:48.413362 	 [add_candidate] session_latest_type_wt_pair2 : start
# 7:04:49.853961 	 [make_candidate] session_latest_clicks2carts_pair2 : start
# 7:04:50.148987 	 [add_candidate] session_latest_clicks2carts_pair2 : start
# 7:04:51.590223 	 [make_candidate] session_latest_clicks2orders_pair2 : start
# 7:04:51.911858 	 [add_candidate] session_latest_clicks2orders_pair2 : start
# 7:04:53.344755 	 [make_candidate] session_latest_type_wt_pair3 : start
# 7:04:53.710015 	 [add_candidate] session_latest_type_wt_pair3 : start
# 7:04:55.129115 	 [make_candidate] session_latest_clicks2carts_pair3 : start
# 7:04:55.485194 	 [add_candidate] session_latest_clicks2carts_pair3 : start
# 7:04:56.956573 	 [make_candidate] session_latest_clicks2orders_pair3 : start
# 7:04:57.203464 	 [add_candidate] session_latest_clicks2orders_pair3 : start
# 7:04:58.659555 	 [make_candidate] session_latest_type_wt_pair4 : start
# 7:04:59.041968 	 [add_candidate] session_latest_type_wt_pair4 : start
# 7:05:00.541924 	 [make_candidate] session_latest_clicks2carts_pair4 : start
# 7:05:00.905243 	 [add_candidate] session_latest_clicks2carts_pair4 : start
# 7:05:02.355001 	 [make_candidate] session_latest_clicks2orders_pair4 : start
# 7:05:02.580504 	 [add_candidate] session_latest_clicks2orders_pair4 : start
# Memory usage of dataframe is 258.98 MB
# Memory usage after optimization is: 172.65 MB
# Decreased by 33.3%
# 7:05:07.377982 	 make carts_valid_data
# 7:05:07.445017 	 [features] session_cnt : start
# 7:05:11.877210 	 [features] session_aid_nunique : start
# 7:05:13.037789 	 [features] session_last_type : start
# 7:05:14.200451 	 [features] aid_cnt : start
# Memory usage of dataframe is 3625.73 MB
# Memory usage after optimization is: 1498.80 MB
# Decreased by 58.7%
# 8:05:29.225844 	 valid(carts) pos : 18944  neg : 11296108
# /home/kaggler/.local/lib/python3.8/site-packages/lightgbm/engine.py:181: UserWarning: 'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. Pass 'early_stopping()' callback via 'callbacks' argument instead.
#   _log_warning("'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. "
# /home/kaggler/.local/lib/python3.8/site-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# [LightGBM] [Info] Number of positive: 861641, number of negative: 861641
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.109569 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 12036
# [LightGBM] [Info] Number of data points in the train set: 1723282, number of used features: 55
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500000 -> initscore=0.000000
# Training until validation scores don't improve for 100 rounds
# [100]	training's binary_logloss: 0.328558	valid_1's binary_logloss: 0.316841
# [200]	training's binary_logloss: 0.32362	valid_1's binary_logloss: 0.313953
# [300]	training's binary_logloss: 0.321097	valid_1's binary_logloss: 0.313178
# [400]	training's binary_logloss: 0.319019	valid_1's binary_logloss: 0.312758
# [500]	training's binary_logloss: 0.317258	valid_1's binary_logloss: 0.312561
# [600]	training's binary_logloss: 0.315477	valid_1's binary_logloss: 0.312419
# [700]	training's binary_logloss: 0.313807	valid_1's binary_logloss: 0.312267
# [800]	training's binary_logloss: 0.312174	valid_1's binary_logloss: 0.312189
# [900]	training's binary_logloss: 0.310645	valid_1's binary_logloss: 0.312148
# [1000]	training's binary_logloss: 0.309148	valid_1's binary_logloss: 0.312099
# [1100]	training's binary_logloss: 0.307669	valid_1's binary_logloss: 0.312036
# [1200]	training's binary_logloss: 0.30633	valid_1's binary_logloss: 0.31205
# Early stopping, best iteration is:
# [1158]	training's binary_logloss: 0.306861	valid_1's binary_logloss: 0.312006
# 8:07:49.869196 	 carts valid score
# 8:07:49.870869 	 {'num_clicks': 97136, 'hit_clicks': 46928, 'num_carts': 43211, 'hit_carts': 15174, 'num_orders': 20082, 'hit_orders': 11612, 'recall_clicks': '0.483', 'recall_carts': '0.351', 'recall_orders': '0.578', 'w_recall_clicks': '0.048', 'w_recall_carts': '0.105', 'w_recall_orders': '0.347', 'score': '0.501'}
# 8:07:50.803120 	 make orders_train_data
# /mnt/otto-recommender-system/output/exp051/cache/train_cand_week3_0.pkl
# 8:08:20.040405 	 [make_candidate] session_frequent : start
# 8:08:20.729505 	 [add_candidate] session_frequent : start
# 8:08:22.318610 	 [make_candidate] session_latest : start
# 8:08:22.962763 	 [add_candidate] session_latest : start
# 8:08:25.602521 	 [make_candidate] session_latest_time_wt_pair0 : start
# 8:08:26.638182 	 [add_candidate] session_latest_time_wt_pair0 : start
# 8:08:29.837008 	 [make_candidate] session_latest_word2vec_pair0 : start
# 8:08:30.905802 	 [add_candidate] session_latest_word2vec_pair0 : start
# 8:08:34.862418 	 [make_candidate] session_latest_pair0 : start
# 8:08:36.076761 	 [add_candidate] session_latest_pair0 : start
# 8:08:40.761590 	 [make_candidate] session_latest_time_wt_pair1 : start
# 8:08:41.919481 	 [add_candidate] session_latest_time_wt_pair1 : start
# 8:08:48.436894 	 [make_candidate] session_latest_word2vec_pair1 : start
# 8:08:49.748523 	 [add_candidate] session_latest_word2vec_pair1 : start
# 8:08:56.775572 	 [make_candidate] session_latest_pair1 : start
# 8:08:58.114650 	 [add_candidate] session_latest_pair1 : start
# 8:09:05.786725 	 [make_candidate] session_latest_time_wt_pair2 : start
# 8:09:07.102384 	 [add_candidate] session_latest_time_wt_pair2 : start
# 8:09:14.988968 	 [make_candidate] session_latest_word2vec_pair2 : start
# 8:09:16.343479 	 [add_candidate] session_latest_word2vec_pair2 : start
# 8:09:25.248630 	 [make_candidate] session_latest_pair2 : start
# 8:09:26.544249 	 [add_candidate] session_latest_pair2 : start
# 8:09:39.083821 	 [make_candidate] session_latest_time_wt_pair3 : start
# 8:09:40.480028 	 [add_candidate] session_latest_time_wt_pair3 : start
# 8:09:53.319267 	 [make_candidate] session_latest_word2vec_pair3 : start
# 8:09:54.679746 	 [add_candidate] session_latest_word2vec_pair3 : start
# 8:10:07.938262 	 [make_candidate] session_latest_pair3 : start
# 8:10:09.290211 	 [add_candidate] session_latest_pair3 : start
# 8:10:23.112090 	 [make_candidate] session_latest_time_wt_pair4 : start
# 8:10:24.508830 	 [add_candidate] session_latest_time_wt_pair4 : start
# 8:10:39.494778 	 [make_candidate] session_latest_word2vec_pair4 : start
# 8:10:40.895193 	 [add_candidate] session_latest_word2vec_pair4 : start
# 8:10:55.727325 	 [make_candidate] session_latest_pair4 : start
# 8:10:57.089606 	 [add_candidate] session_latest_pair4 : start
# 8:11:13.253735 	 [make_candidate] session_latest_time_wt_pair5 : start
# 8:11:14.686557 	 [add_candidate] session_latest_time_wt_pair5 : start
# 8:11:31.202893 	 [make_candidate] session_latest_word2vec_pair5 : start
# 8:11:32.705001 	 [add_candidate] session_latest_word2vec_pair5 : start
# 8:11:50.010194 	 [make_candidate] session_latest_pair5 : start
# 8:11:51.449324 	 [add_candidate] session_latest_pair5 : start
# 8:12:09.022324 	 [make_candidate] session_latest_time_wt_pair6 : start
# 8:12:10.472756 	 [add_candidate] session_latest_time_wt_pair6 : start
# 8:12:29.160109 	 [make_candidate] session_latest_word2vec_pair6 : start
# 8:12:30.655032 	 [add_candidate] session_latest_word2vec_pair6 : start
# 8:12:56.344595 	 [make_candidate] session_latest_pair6 : start
# 8:12:57.843841 	 [add_candidate] session_latest_pair6 : start
# 8:13:24.605284 	 [make_candidate] session_latest_time_wt_pair7 : start
# 8:13:26.206483 	 [add_candidate] session_latest_time_wt_pair7 : start
# 8:13:53.469942 	 [make_candidate] session_latest_word2vec_pair7 : start
# 8:13:55.031794 	 [add_candidate] session_latest_word2vec_pair7 : start
# 8:14:22.553329 	 [make_candidate] session_latest_pair7 : start
# 8:14:24.173439 	 [add_candidate] session_latest_pair7 : start
# 8:14:52.386940 	 [make_candidate] session_latest_time_wt_pair8 : start
# 8:14:54.023296 	 [add_candidate] session_latest_time_wt_pair8 : start
# 8:15:23.700194 	 [make_candidate] session_latest_word2vec_pair8 : start
# 8:15:25.238053 	 [add_candidate] session_latest_word2vec_pair8 : start
# 8:15:54.574156 	 [make_candidate] session_latest_pair8 : start
# 8:15:56.168237 	 [add_candidate] session_latest_pair8 : start
# 8:16:26.549353 	 [make_candidate] session_latest_time_wt_pair9 : start
# 8:16:28.173468 	 [add_candidate] session_latest_time_wt_pair9 : start
# 8:16:59.112888 	 [make_candidate] session_latest_word2vec_pair9 : start
# 8:17:00.777099 	 [add_candidate] session_latest_word2vec_pair9 : start
# 8:17:32.234473 	 [make_candidate] session_latest_pair9 : start
# 8:17:33.638870 	 [add_candidate] session_latest_pair9 : start
# 8:18:06.359379 	 [make_candidate] session_latest_time_wt_pair10 : start
# 8:18:08.100207 	 [add_candidate] session_latest_time_wt_pair10 : start
# 8:18:40.846710 	 [make_candidate] session_latest_word2vec_pair10 : start
# 8:18:42.537304 	 [add_candidate] session_latest_word2vec_pair10 : start
# 8:19:15.467586 	 [make_candidate] session_latest_pair10 : start
# 8:19:16.935858 	 [add_candidate] session_latest_pair10 : start
# 8:19:51.147369 	 [make_candidate] session_latest_time_wt_pair11 : start
# 8:19:52.667489 	 [add_candidate] session_latest_time_wt_pair11 : start
# 8:20:27.579333 	 [make_candidate] session_latest_word2vec_pair11 : start
# 8:20:29.305107 	 [add_candidate] session_latest_word2vec_pair11 : start
# 8:21:04.841729 	 [make_candidate] session_latest_pair11 : start
# 8:21:06.685527 	 [add_candidate] session_latest_pair11 : start
# 8:21:43.035332 	 [make_candidate] session_latest_time_wt_pair12 : start
# 8:21:44.886068 	 [add_candidate] session_latest_time_wt_pair12 : start
# 8:22:22.302805 	 [make_candidate] session_latest_word2vec_pair12 : start
# 8:22:24.073262 	 [add_candidate] session_latest_word2vec_pair12 : start
# 8:23:01.816871 	 [make_candidate] session_latest_pair12 : start
# 8:23:03.617241 	 [add_candidate] session_latest_pair12 : start
# 8:23:42.113232 	 [make_candidate] session_latest_time_wt_pair13 : start
# 8:23:43.989001 	 [add_candidate] session_latest_time_wt_pair13 : start
# 8:24:23.253750 	 [make_candidate] session_latest_word2vec_pair13 : start
# 8:24:25.034652 	 [add_candidate] session_latest_word2vec_pair13 : start
# 8:25:05.166764 	 [make_candidate] session_latest_pair13 : start
# 8:25:06.793874 	 [add_candidate] session_latest_pair13 : start
# 8:25:47.955363 	 [make_candidate] session_latest_time_wt_pair14 : start
# 8:25:49.651597 	 [add_candidate] session_latest_time_wt_pair14 : start
# 8:26:31.410538 	 [make_candidate] session_latest_word2vec_pair14 : start
# 8:26:33.392086 	 [add_candidate] session_latest_word2vec_pair14 : start
# 8:27:30.943640 	 [make_candidate] session_latest_pair14 : start
# 8:27:32.878074 	 [add_candidate] session_latest_pair14 : start
# 8:28:32.115681 	 [make_candidate] session_latest_time_wt_pair15 : start
# 8:28:34.116728 	 [add_candidate] session_latest_time_wt_pair15 : start
# 8:29:34.060308 	 [make_candidate] session_latest_word2vec_pair15 : start
# 8:29:35.815078 	 [add_candidate] session_latest_word2vec_pair15 : start
# 8:30:36.372872 	 [make_candidate] session_latest_pair15 : start
# 8:30:38.267694 	 [add_candidate] session_latest_pair15 : start
# 8:31:39.391140 	 [make_candidate] session_latest_time_wt_pair16 : start
# 8:31:41.480634 	 [add_candidate] session_latest_time_wt_pair16 : start
# 8:32:43.567168 	 [make_candidate] session_latest_word2vec_pair16 : start
# 8:32:45.380091 	 [add_candidate] session_latest_word2vec_pair16 : start
# 8:33:48.325533 	 [make_candidate] session_latest_pair16 : start
# 8:33:50.055871 	 [add_candidate] session_latest_pair16 : start
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In [21], line 2
#       1 try:
# ----> 2     main()
#       3 except Exception as e:
#       4     logger.error(traceback.format_exc())
#
# Cell In [20], line 33, in main()
#      31     train = pd.read_pickle(cache_path)
#      32 else:
# ---> 33     train = make_train_data(type_)
#      34     train.to_pickle(cache_path)
#      36 logger.info(f"make {type_}_valid_data")
#
# Cell In [14], line 25, in make_train_data(type_)
#      23 # 候補選出
#      24 week_sessions_chunk = week_sessions[week_sessions["session"].isin(sessions_lists[chunk])].reset_index(drop=True)
# ---> 25 cand_df = make_cand_df(week_sessions_chunk, trans_maps=trans_maps)
#      26 cand_df = reduce_mem_usage(cand_df)
#      27 cand_df.to_pickle(cache_path)
#
# Cell In [12], line 15, in make_cand_df(sessions, labels, trans_maps)
#      13     cand.add(strategy="session_latest", trans_map=trans_maps[f"time_wt_pair{str(i)}"], name=f"session_latest_time_wt_pair{str(i)}", k=10)
#      14     cand.add(strategy="session_latest", trans_map=trans_maps[f"word2vec_pair{str(i)}"], name=f"session_latest_word2vec_pair{str(i)}", k=10)
# ---> 15     cand.add(strategy="session_latest", trans_map=trans_maps[f"pair{str(i)}"], name=f"session_latest_pair{str(i)}", k=10)
#      16 for i in range(5):
#      17     cand.add(strategy="session_latest", trans_map=trans_maps[f"type_wt_pair{str(i)}"], name=f"session_latest_type_wt_pair{str(i)}", k=10)
#
# Cell In [6], line 49, in Candidate.add(self, strategy, name, usetypes, trans_map, k)
#      46     candidate_df["aid"] = candidate_df["aid"].map(trans_map)
#      47     candidate_df = candidate_df.dropna(subset=["aid"])
# ---> 49 self._entry(candidate_df, name, k)
#
# Cell In [6], line 16, in Candidate._entry(self, new_candidate_df, name, k)
#      14 new_candidate_df = new_candidate_df.to_pandas()
#      15 self.output = pd.concat([self.output, new_candidate_df[["session", "aid"]]])
# ---> 16 self.output = self.output.drop_duplicates(subset=["session", "aid"])
#      18 if self.labels is not None:
#      19     self._eval(new_candidate_df[["session", "aid"]], name, k)
#
# File /opt/conda/lib/python3.8/site-packages/pandas/util/_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File /opt/conda/lib/python3.8/site-packages/pandas/core/frame.py:6125, in DataFrame.drop_duplicates(self, subset, keep, inplace, ignore_index)
#    6123 inplace = validate_bool_kwarg(inplace, "inplace")
#    6124 ignore_index = validate_bool_kwarg(ignore_index, "ignore_index")
# -> 6125 duplicated = self.duplicated(subset, keep=keep)
#    6127 result = self[-duplicated]
#    6128 if ignore_index:
#
# File /opt/conda/lib/python3.8/site-packages/pandas/core/frame.py:6272, in DataFrame.duplicated(self, subset, keep)
#    6262 labels, shape = map(list, zip(*map(f, vals)))
#    6264 ids = get_group_index(
#    6265     labels,
#    6266     # error: Argument 1 to "tuple" has incompatible type "List[_T]";
#    (...)
#    6270     xnull=False,
#    6271 )
# -> 6272 result = self._constructor_sliced(duplicated(ids, keep), index=self.index)
#    6273 return result.__finalize__(self, method="duplicated")
#
# KeyboardInterrupt:
