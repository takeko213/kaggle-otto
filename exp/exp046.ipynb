# %% [markdown]
# # exp046
# cand_trial調整
# candは単純concatに変更

# %%
import os
import sys
import traceback
import gc
import random
import pickle
import pathlib
import subprocess
from dataclasses import dataclass
from dotenv import load_dotenv
load_dotenv
sys.path.append(os.getenv('UTILS_PATH'))
from tqdm import tqdm
import multiprocessing
import inspect

import pandas as pd
import numpy as np
import itertools
import cudf
import lightgbm as lgb
import matplotlib.pyplot as plt
import seaborn as sns
import line_notify
import my_logger
from noglobal import noglobal

# %% [markdown]
# # 設定

# %%
@dataclass
class Cfg:
    loglevel = "INFO"
    exp_name = "exp046"
    seed = 42
    k = 20
    cand_n = 15
    negative_sample = 1
    train_chunk_n = 1
    type2id = {"clicks":0, "carts":1, "orders":2}
    id2type = {0:"clicks", 1:"carts", 2:"orders"}
    train_weeks = ["week3"]
    valid_week = "week4"
    valid_session_n = 100_000
    input_dir = os.getenv('INPUT_DIR')
    output_dir = os.getenv('OUTPUT_DIR')
    prep_dir = os.getenv("PREP_DIR")

cfg = Cfg()
os.makedirs(os.path.join(cfg.output_dir, cfg.exp_name), exist_ok=True)
os.makedirs(os.path.join(cfg.output_dir, cfg.exp_name, "cache"), exist_ok=True)
random.seed(cfg.seed)

logger = my_logger.init_logger(cfg.exp_name)

# %%
class Cache:
    @noglobal(excepts=["cfg", "logger"])
    def __init__(self):
        self.cache_dir = (os.path.join(cfg.output_dir, cfg.exp_name, "cache"))
        self.cache_dir_path = pathlib.Path(self.cache_dir)
        self.caches = list(self.cache_dir_path.glob("*.pkl"))

    @noglobal(excepts=["cfg", "logger"])
    def get_abspath(self, filename):
        return (os.path.join(self.cache_dir, filename))
    
    @noglobal(excepts=["cfg", "logger"])
    def exists(self, path):
        return len([str(c) for c in self.caches if path == str(c)]) > 0


cache = Cache()

# %%
def reduce_mem_usage(df):
    """ iterate through all the columns of a dataframe and modify the data type
        to reduce memory usage.        
    """
    start_mem = df.memory_usage().sum() / 1024**2
    print('Memory usage of dataframe is {:.2f} MB'.format(start_mem))
    
    for col in df.columns:
        col_type = df[col].dtype
        
        if col_type != object:
            c_min = df[col].min()
            c_max = df[col].max()
            if str(col_type)[:3] == 'int':
                if c_min > np.iinfo(np.int8).min and c_max < np.iinfo(np.int8).max:
                    df[col] = df[col].astype(np.int8)
                elif c_min > np.iinfo(np.int16).min and c_max < np.iinfo(np.int16).max:
                    df[col] = df[col].astype(np.int16)
                elif c_min > np.iinfo(np.int32).min and c_max < np.iinfo(np.int32).max:
                    df[col] = df[col].astype(np.int32)
                elif c_min > np.iinfo(np.int64).min and c_max < np.iinfo(np.int64).max:
                    df[col] = df[col].astype(np.int64)  
            else:
                if c_min > np.finfo(np.float16).min and c_max < np.finfo(np.float16).max:
                    df[col] = df[col].astype(np.float16)
                elif c_min > np.finfo(np.float32).min and c_max < np.finfo(np.float32).max:
                    df[col] = df[col].astype(np.float32)
                else:
                    df[col] = df[col].astype(np.float64)
        else:
            df[col] = df[col].astype('category')

    end_mem = df.memory_usage().sum() / 1024**2
    print('Memory usage after optimization is: {:.2f} MB'.format(end_mem))
    print('Decreased by {:.1f}%'.format(100 * (start_mem - end_mem) / start_mem))
    
    return df

# %%
@noglobal(excepts=["cfg", "logger"])
def evaluate(clicks_labels, carts_labels, orders_labels, 
             clicks_preds, carts_preds, orders_preds, k=20):

    num_clicks = 0
    num_carts = 0
    num_orders = 0
    hit_clicks = 0
    hit_carts = 0
    hit_orders = 0

    for i in range(len(clicks_labels)):
        clicks_label = clicks_labels[i]
        carts_label = carts_labels[i]
        orders_label = orders_labels[i]
        clicks_pred = clicks_preds[i]
        carts_pred = carts_preds[i]
        orders_pred = orders_preds[i]

        if type(clicks_pred) == list:
            clicks_pred = clicks_pred[:k]
        else:
            clicks_pred = []
        if type(carts_pred) == list:
            carts_pred = carts_pred[:k]
        else:
            carts_pred = []    
        if type(orders_pred) == list:
            orders_pred = orders_pred[:k]
        else:
            orders_pred = []

        if not np.isnan(clicks_label):
            num_clicks += 1
            hit_clicks += int(clicks_label in clicks_pred)

        if type(carts_label) == list:
            num_carts += min(len(carts_label), k)
            hit_carts += len(set(carts_pred) & set(carts_label))
            
        if type(orders_label) == list:
            num_orders += min(len(orders_label), k)
            hit_orders += len(set(orders_pred) & set(orders_label))


    recall_clicks = hit_clicks / num_clicks
    recall_carts = hit_carts / num_carts
    recall_orders = hit_orders / num_orders
    w_recall_clicks = recall_clicks * 0.10
    w_recall_carts = recall_carts * 0.30
    w_recall_orders = recall_orders * 0.60
    score = w_recall_clicks + w_recall_carts + w_recall_orders

    results = {}
    results["num_clicks"] = num_clicks
    results["hit_clicks"] = hit_clicks
    results["num_carts"] = num_carts
    results["hit_carts"] = hit_carts
    results["num_orders"] = num_orders
    results["hit_orders"] = hit_orders
    results["recall_clicks"] = format(recall_clicks, ".3f")
    results["recall_carts"] = format(recall_carts, ".3f")
    results["recall_orders"] = format(recall_orders, ".3f")
    results["w_recall_clicks"] = format(w_recall_clicks, ".3f")
    results["w_recall_carts"] = format(w_recall_carts, ".3f")
    results["w_recall_orders"] = format(w_recall_orders, ".3f")
    results["score"] = format(score, ".3f")

    return results

# %%
class Candidate:
    @noglobal(excepts=["cfg", "logger"])
    def __init__(self, pdf, labels=None):
        self.df = cudf.from_pandas(pdf)
        self.target_sessions = pdf["session"].unique().tolist()
        self.results = pd.DataFrame(columns=["name", "num_clicks", "hit_clicks", "num_carts", "hit_carts", "num_orders", "hit_orders", 
                                             "recall_clicks", "recall_carts", "recall_orders", "w_recall_clicks", "w_recall_carts", "w_recall_orders", "score"])
        self.output = pd.DataFrame(columns=["session", "aid"], dtype=int)
        self.labels = labels
    
    @noglobal(excepts=["cfg", "logger"])
    def _entry(self, new_candidate_df, name, k):
        logger.info(f"[add_candidate] {name} : start")
        new_candidate_df = new_candidate_df.to_pandas()
        self.output = pd.concat([self.output, new_candidate_df[["session", "aid"]]])
        self.output = self.output.drop_duplicates(subset=["session", "aid"])

        if self.labels is not None:
            self._eval(new_candidate_df[["session", "aid"]], name, k)
    
    @noglobal(excepts=["cfg", "logger"])
    def _eval(self, new_candidate_df, name, k):
        new_candidate_df = new_candidate_df.groupby("session")["aid"].apply(list).reset_index()
        eval_df = pd.DataFrame(self.target_sessions, columns=["session"])
        eval_df = eval_df.merge(new_candidate_df, on=["session"], how="left")
        assert eval_df["session"].tolist() == self.labels["session"].tolist()
        eval_result = evaluate(self.labels["clicks_labels"].tolist(), self.labels["carts_labels"].tolist(), self.labels["orders_labels"].tolist(),
                               eval_df["aid"].tolist(), eval_df["aid"].tolist(), eval_df["aid"].tolist(), k)
        
        print(eval_result)
        self.results = pd.concat([self.results, pd.DataFrame([[name] + list(eval_result.values())], columns=["name"] + list(eval_result.keys()))])

    @noglobal(excepts=["cfg", "logger"])
    def add(self, strategy, name, usetypes=['clicks', 'carts', 'orders'], trans_map=None, k=20):
        logger.info(f"[make_candidate] {name} : start")
        candidate_df = self.df[self.df["type"].isin(usetypes)].copy()
        
        if strategy == "session_frequent":
            candidate_df = self._session_frequent(candidate_df, k)
        elif strategy == "session_latest":
            candidate_df = self._session_latest(candidate_df, k)
        elif strategy == "total_frequent":
            candidate_df = self._total_frequent(candidate_df, k)
        
        if trans_map is not None:
            candidate_df["aid"] = candidate_df["aid"].map(trans_map)
            candidate_df = candidate_df.dropna(subset=["aid"])
            
        self._entry(candidate_df, name, k)

    @noglobal(excepts=["cfg", "logger"])
    def _session_frequent(self, candidate_df, k):
        candidate_df = candidate_df.groupby(["session", "aid"])["ts"].count().reset_index()
        candidate_df.columns = ["session", "aid", "aid_count"]
        candidate_df = candidate_df.sort_values(["session", "aid_count", "aid"], ascending=(True, False, True))
        candidate_df = candidate_df[candidate_df.groupby("session")["aid_count"].cumcount() < k].copy()
        candidate_df = candidate_df[["session", "aid"]].copy()
        return candidate_df

    @noglobal(excepts=["cfg", "logger"])
    def _session_latest(self, candidate_df, k):
        candidate_df = candidate_df.sort_values(["session", "ts"], ascending=(True, False)).drop_duplicates(subset=["session", "aid"])
        candidate_df = candidate_df.sort_values(["session", "ts"], ascending=(True, False))[candidate_df.groupby("session")["ts"].cumcount() < k].copy()
        candidate_df = candidate_df[["session", "aid"]].copy()
        return candidate_df

    @noglobal(excepts=["cfg", "logger"])
    def _total_frequent(self, candidate_df, k):
        candidate_df = candidate_df.groupby("aid")["ts"].count().reset_index()
        candidate_df.columns = ["aid", "aid_count"]
        topk_freq_aids = candidate_df.sort_values("aid_count", ascending=False)["aid"].to_arrow().to_pylist()[:k]
        sessions = []
        aids = []
        for session, aid in itertools.product(self.target_sessions, topk_freq_aids):
            sessions.append(session)
            aids.append(aid)
        candidate_df = cudf.DataFrame({"session": sessions, "aid": aids})
        return candidate_df

# %%
@noglobal(excepts=["cfg", "logger"])
def add_labels(df, labels, type_):
    type_labels = labels[["session", f"{type_}_labels"]].dropna().copy()
    type_labels.columns = ["session", "aid"]
    type_labels = type_labels.explode("aid")
    type_labels["labels"] = 1
    df = df.merge(type_labels, on=["session", "aid"], how="left")
    df["labels"] = df["labels"].fillna(0)
    return df

# %%
@noglobal(excepts=["cfg", "logger"])
def add_ground_truth_candidate(df, labels, type_):
    gt = labels[["session", f"{type_}_labels"]].dropna().copy()
    gt.columns = ["session", "aid"]
    gt = gt.explode("aid")
    df = pd.concat([df, gt])
    df = df.drop_duplicates()
    return df

# %%
@noglobal(excepts=["cfg", "logger"])
def under_sampling(df, label_col):
    cfg = Cfg()
    pos_df = df[df[label_col]==1].copy()
    neg_df = df[df[label_col]==0].copy()
    pos_n = len(pos_df)
    return pd.concat([pos_df, neg_df.sample(pos_n * cfg.negative_sample, random_state=cfg.seed)])

# %%
class Features:
    @noglobal(excepts=["cfg", "logger"])
    def __init__(self, sessions, candidate, week):
        self.sessions = cudf.from_pandas(sessions)
        self.output = candidate
        self.type_dict = cfg.type2id
        self.week = week

    @noglobal(excepts=["cfg", "logger"])
    def add_features(self):
            self._prep()
            self._session_cnt()
            self._session_aid_nunique()
            self._session_last_type()
            # self._session_last_dt()
            self._aid_cnt()
            self._all_times_aid_features()
            self._w2v_vectors()
            # self._session_mean_ts()
            # self._aid_mean_ts()
            # self._aid_cnt_ratio_at_session_last()
            # self.output = self.output.drop(columns=["session_last_day"]) # 日時はtrainセット内のみで有効なので削除

    @noglobal(excepts=["cfg", "logger"])
    def _prep(self):
        logger.info("[features] prep : start")
        # ts関連の前処理
        self.sessions["relative_ts"] = self.sessions["ts"] - self.sessions["ts"].min()
        self.sessions["dt"] = cudf.to_datetime(self.sessions["ts"], unit="ms")
        self.sessions["hour"] = self.sessions["dt"].dt.hour
        self.sessions["week"] = self.sessions["dt"].dt.dayofweek
        self.sessions["day"] = self.sessions["dt"].dt.day
        
    @noglobal(excepts=["cfg", "logger"])
    def _session_cnt(self):
        logger.info("[features] session_cnt : start")
        agg_df = self.sessions.groupby(["session", "type"])["ts"].count().reset_index().rename(columns={"ts": "cnt"})
        # session_total_cnt
        features = agg_df.groupby("session")["cnt"].sum().reset_index().rename(columns={"cnt": "session_total_cnt"})
        self.output = self.output.merge(features.to_pandas(), on=["session"], how="left")
        self.output["session_total_cnt"] = self.output["session_total_cnt"].fillna(0)
        # session_{type}_cnt
        for type_ in ["clicks", "carts", "orders"]:
            col_name = f"session_{type_}_cnt"
            features = agg_df[agg_df["type"]==type_].copy()
            features = features.rename(columns={"cnt": col_name})
            features = features[["session", col_name]].copy()
            self.output = self.output.merge(features.to_pandas(), on=["session"], how="left")
            self.output[col_name] = self.output[col_name].fillna(0)
        
    @noglobal(excepts=["cfg", "logger"])
    def _session_aid_nunique(self):
        logger.info("[features] session_aid_nunique : start")
        features = self.sessions.groupby("session")["aid"].nunique().reset_index().rename(columns={"aid": "session_aid_nunique"})
        self.output = self.output.merge(features.to_pandas(), on=["session"], how="left")
        self.output["session_aid_nunique"] = self.output["session_aid_nunique"].fillna(0)
        
    @noglobal(excepts=["cfg", "logger"])
    def _session_last_type(self):
        logger.info("[features] session_last_type : start")
        features = self.sessions.groupby("session").nth(-1).reset_index()[["session", "type"]]
        features = features.rename(columns={"type": "session_last_type"})
        features["session_last_type"] = features["session_last_type"].map(self.type_dict)
        self.output = self.output.merge(features.to_pandas(), on=["session"], how="left")
        
    @noglobal(excepts=["cfg", "logger"])
    def _session_last_dt(self):
        logger.info("[features] session_last_dt : start")
        features = self.sessions.groupby("session").nth(-1).reset_index()[["session", "relative_ts", "week", "day", "hour"]]
        features.columns = ["session", "session_last_ts", "session_last_week", "session_last_day", "session_last_hour"]
        self.output = self.output.merge(features.to_pandas(), on=["session"], how="left")
        
    @noglobal(excepts=["cfg", "logger"])
    def _session_mean_ts(self):
        logger.info("[features] session_mean_ts : start")
        features = self.sessions.groupby("session")["relative_ts"].mean().reset_index().rename(columns={"relative_ts": "session_mean_ts"})
        self.output = self.output.merge(features.to_pandas(), on=["session"], how="left")
        
    @noglobal(excepts=["cfg", "logger"])
    def _aid_mean_ts(self):
        logger.info("[features] aid_mean_ts : start")
        features = self.sessions.groupby("aid")["relative_ts"].mean().reset_index().rename(columns={"relative_ts": "aid_mean_ts"})
        self.output = self.output.merge(features.to_pandas(), on=["aid"], how="left")
       
    @noglobal(excepts=["cfg", "logger"])
    def _aid_session_nunique(self):
        logger.info("[features] aid_session_unique : start")
        features = self.sessions.groupby("aid")["session"].nunique().reset_index().rename(columns={"session": "aid_session_nunique"})
        self.output = self.output.merge(features.to_pandas(), on=["aid"], how="left")

    @noglobal(excepts=["cfg", "logger"]) 
    def _aid_cnt_ratio_at_session_last(self):
        logger.info("[features] aid_cnt_ratio_atsession_last : start")
        for dt_ in ["week", "day", "hour"]:
            features = self.sessions[["aid", dt_]].copy()
            features["total_cnt"] = features.groupby(dt_)["aid"].transform("count")
            features = features.groupby(["aid", dt_])["total_cnt"].agg(["count", "max"]).reset_index()
            features[f"aid_cnt_ratio_at_session_last_{dt_}"] = features["count"] / features["max"]
            features = features.rename(columns={dt_: f"session_last_{dt_}"})
            self.output = self.output.merge(features[["aid", f"session_last_{dt_}", f"aid_cnt_ratio_at_session_last_{dt_}"]].to_pandas(), on=["aid", f"session_last_{dt_}"], how="left")
            self.output[f"aid_cnt_ratio_at_session_last_{dt_}"] = self.output[f"aid_cnt_ratio_at_session_last_{dt_}"].fillna(0)
        
    @noglobal(excepts=["cfg", "logger"])
    def _aid_cnt(self):
        logger.info("[features] aid_cnt : start")
        agg_df = self.sessions.groupby(["session", "aid", "type"])["ts"].count().reset_index().rename(columns={"ts": "cnt"})

        # aid_total_cnt
        features = agg_df.groupby(["session", "aid"])["cnt"].sum().reset_index().rename(columns={"cnt": "aid_total_cnt"})
        self.output = self.output.merge(features.to_pandas(), on=["session", "aid"], how="left")
        self.output["aid_total_cnt"] = self.output["aid_total_cnt"].fillna(0)

        # aid_{type}_cnt
        for type_ in ["clicks", "carts", "orders"]:
            col_name = f"aid_{type_}_cnt"
            features = agg_df[agg_df["type"]==type_].copy()
            features = features.rename(columns={"cnt": col_name})
            features = features[["session", "aid", col_name]].copy()
            self.output = self.output.merge(features.to_pandas(), on=["session", "aid"], how="left")
            self.output[col_name] = self.output[col_name].fillna(0)

    @noglobal(excepts=["cfg", "logger"])
    def _all_times_aid_features(self):
        feats = ["all_times_aid_freq",
                 "all_times_aid_clicks_freq",
                 "all_times_aid_carts_freq",
                 "all_times_aid_orders_freq",
                 "all_times_aid_session_freq",
                 "all_times_aid_session_clicks_freq",
                 "all_times_aid_session_carts_freq",
                 "all_times_aid_session_orders_freq",
                 "all_times_aid_carts_ratio_with_clicks",
                 "all_times_aid_orders_ratio_with_clicks",
                 "all_times_aid_date_std",
                 "all_times_aid_hour_std",
                 "all_times_aid_day_of_week_std"]
        
        for feat in feats:
            if self.week is None:
                with open(cfg.prep_dir + f"{feat}.pkl", "rb") as f:
                    feat_map = pickle.load(f)
            else:
                with open(cfg.prep_dir + f"{feat}_{self.week}.pkl", "rb") as f:
                    feat_map = pickle.load(f)
            self.output[feat] = self.output["aid"].map(feat_map)

    @noglobal(excepts=["cfg", "logger"])
    def _w2v_vectors(self):
        w2v_vecs = pd.read_pickle(cfg.prep_dir + "w2v_vector_n5.pkl")
        self.output = self.output.merge(w2v_vecs, on="aid", how="left")

# %%
@noglobal(excepts=["cfg", "logger"])
def add_features(sessions, cand_df, week=None):
    feat = Features(sessions, cand_df, week)
    feat.add_features()
    return feat.output

# %%
@noglobal(excepts=["cfg", "logger"])
def make_cand_df(sessions, labels=None, trans_maps=None):

    if labels is not None:
         cand = Candidate(sessions, labels)
    else:
        cand = Candidate(sessions)

    cand.add(strategy="session_frequent", name="session_frequent", k=15)
    cand.add(strategy="session_latest", name="session_latest", k=15)
    
    for i in range(20):
        cand.add(strategy="session_latest", trans_map=trans_maps[f"time_wt_pair{str(i)}"], name=f"session_latest_time_wt_pair{str(i)}", k=5)
        cand.add(strategy="session_latest", trans_map=trans_maps[f"word2vec_pair{str(i)}"], name=f"session_latest_word2vec_pair{str(i)}", k=5)
        cand.add(strategy="session_latest", trans_map=trans_maps[f"pair{str(i)}"], name=f"session_latest_pair{str(i)}", k=5)
    for i in range(5):
        cand.add(strategy="session_latest", trans_map=trans_maps[f"type_wt_pair{str(i)}"], name=f"session_latest_type_wt_pair{str(i)}", k=5)
        cand.add(strategy="session_latest", trans_map=trans_maps[f"clicks2carts_pair{str(i)}"], name=f"session_latest_clicks2carts_pair{str(i)}", k=5)
        cand.add(strategy="session_latest", trans_map=trans_maps[f"clicks2orders_pair{str(i)}"], name=f"session_latest_clicks2orders_pair{str(i)}", k=5)
        

    if labels is not None:
        return cand.output, cand.results
    else:
        return cand.output

# %%
@noglobal(excepts=["cfg", "logger"])
def get_pair_df(name, wt_col, week):
    if week is not None:
        name = f"{name}_{week}"
    pair_df = pd.read_pickle(cfg.prep_dir + f"{name}.pkl")
    pair_df = pair_df.sort_values(["aid_x", wt_col], ascending=(True, False))
    return pair_df

@noglobal(excepts=["cfg", "logger"])
def get_pair_dict(name, wt_col, week):
    if week is not None:
        name = f"{name}_{week}"
    pair_df = pd.read_pickle(cfg.prep_dir + f"{name}.pkl")
    pair_df = pair_df.sort_values(["aid_x", wt_col], ascending=(True, False))
    pair_df = pair_df.groupby("aid_x").head(1)[["aid_x", "aid_y"]]
    pair_dict = {k: v for k, v in zip(pair_df["aid_x"].tolist(), pair_df["aid_y"].tolist())}
    return pair_dict

@noglobal(excepts=["cfg", "logger"])
def get_trans_maps(week=None):
    """
    aidを別のaidに置き換えるmapping辞書を取得する
    """
    trans_maps = {}
    
    pair_df_org = get_pair_df("co_visitation_matrix", "cnt", week)
    for i in range(20):
        pair_df = pair_df_org.groupby("aid_x").nth(i).reset_index()[["aid_x", "aid_y"]]
        pair_dict = {k: v for k, v in zip(pair_df["aid_x"].tolist(), pair_df["aid_y"].tolist())}
        trans_maps[f"pair{str(i)}"] = pair_dict
    
    pair_df_org = get_pair_df("co_visitation_matrix_time_weighted", "wt", week)
    for i in range(20):
        pair_df = pair_df_org.groupby("aid_x").nth(i).reset_index()[["aid_x", "aid_y"]]
        pair_dict = {k: v for k, v in zip(pair_df["aid_x"].tolist(), pair_df["aid_y"].tolist())}
        trans_maps[f"time_wt_pair{str(i)}"] = pair_dict

    pair_df_org = get_pair_df("co_visitation_matrix_type_weighted", "wt", week)
    for i in range(5):
        pair_df = pair_df_org.groupby("aid_x").nth(i).reset_index()[["aid_x", "aid_y"]]
        pair_dict = {k: v for k, v in zip(pair_df["aid_x"].tolist(), pair_df["aid_y"].tolist())}
        trans_maps[f"type_wt_pair{str(i)}"] = pair_dict

    pair_df_org = get_pair_df("co_visitation_matrix_clicks2carts", "cnt", week)
    for i in range(5):
        pair_df = pair_df_org.groupby("aid_x").nth(i).reset_index()[["aid_x", "aid_y"]]
        pair_dict = {k: v for k, v in zip(pair_df["aid_x"].tolist(), pair_df["aid_y"].tolist())}
        trans_maps[f"clicks2carts_pair{str(i)}"] = pair_dict

    pair_df_org = get_pair_df("co_visitation_matrix_clicks2orders", "cnt", week)
    for i in range(5):
        pair_df = pair_df_org.groupby("aid_x").nth(i).reset_index()[["aid_x", "aid_y"]]
        pair_dict = {k: v for k, v in zip(pair_df["aid_x"].tolist(), pair_df["aid_y"].tolist())}
        trans_maps[f"clicks2orders_pair{str(i)}"] = pair_dict

    pair_df_org = get_pair_df("word2vec_similar", "sim", None)
    for i in range(20):
        pair_df = pair_df_org.groupby("aid_x").nth(i).reset_index()[["aid_x", "aid_y"]]
        pair_dict = {k: v for k, v in zip(pair_df["aid_x"].tolist(), pair_df["aid_y"].tolist())}
        trans_maps[f"word2vec_pair{str(i)}"] = pair_dict

    return trans_maps

# %%
@noglobal(excepts=["cfg", "logger", "cache"])
def make_train_data(type_):
    dfs = []
    for weeks in cfg.train_weeks:
        # データ読み込み
        week_sessions = pd.read_pickle(cfg.prep_dir + f"train_sessions_{weeks}.pkl")
        week_labels = pd.read_pickle(cfg.prep_dir + f"labels_{weeks}.pkl")
        sessions_lists = np.array_split(week_sessions["session"].unique().tolist(), cfg.train_chunk_n)

        # cand作成
        for chunk in range(cfg.train_chunk_n):
            cache_file = f"train_cand_{weeks}_{chunk}.pkl"
            cache_path = cache.get_abspath(cache_file)
            print(cache_path)
            if cache.exists(cache_path):
                logger.info(f"[{cache_file}] cache exists. read cache and skip process.")
                cand_df = pd.read_pickle(cache_path)
            else:
                trans_map_cache_file = f"trans_maps_{weeks}.pkl"
                trans_map_cache_path = cache.get_abspath(trans_map_cache_file)
                with open(trans_map_cache_path, "rb") as f:
                    trans_maps = pickle.load(f)
                # 候補選出
                week_sessions_chunk = week_sessions[week_sessions["session"].isin(sessions_lists[chunk])].reset_index(drop=True)
                cand_df = make_cand_df(week_sessions_chunk, trans_maps=trans_maps)
                cand_df = reduce_mem_usage(cand_df)
                cand_df.to_pickle(cache_path)
                del week_sessions_chunk
                gc.collect()

        # candラベル付け・サンプリング
        cand_dfs = []
        for chunk in range(cfg.train_chunk_n):
            cache_file = f"train_cand_{weeks}_{chunk}.pkl"
            cache_path = cache.get_abspath(cache_file)
            cand_df_chunk = pd.read_pickle(cache_path)
            week_labels_chunk = week_labels[week_labels["session"].isin(sessions_lists[chunk])].reset_index(drop=True)
            cand_df_chunk = add_labels(cand_df_chunk, week_labels_chunk, type_)
            cand_df_chunk = under_sampling(cand_df_chunk, "labels")
            cand_dfs.append(cand_df_chunk)
            del cand_df_chunk, week_labels_chunk
            gc.collect()
        cand_df = pd.concat(cand_dfs)
        del cand_dfs
        gc.collect()

        # 特徴量付与
        train_tmp = add_features(week_sessions, cand_df, weeks)
        dfs.append(train_tmp)
        del cand_df, train_tmp
        gc.collect()
        
    train = pd.concat(dfs)
    train = train.reset_index(drop=True)
    train = reduce_mem_usage(train)
    
    return train

# %%
@noglobal(excepts=["cfg", "logger", "cache"])
def make_valid_cand():
    valid_week = cfg.valid_week
    # データ読み込み
    week_sessions = pd.read_pickle(os.getenv("PREP_DIR") + f"train_sessions_{valid_week}.pkl")
    week_labels = pd.read_pickle(os.getenv("PREP_DIR") + f"labels_{valid_week}.pkl")
    valid_session_ids = week_sessions["session"].unique().tolist()
    trans_map_cache_file = f"trans_maps_{valid_week}.pkl"
    trans_map_cache_path = cache.get_abspath(trans_map_cache_file)
    with open(trans_map_cache_path, "rb") as f:
        trans_maps = pickle.load(f)

    # validに使うsessionを絞る
    valid_session_n = min(cfg.valid_session_n, len(valid_session_ids))
    random.seed(cfg.seed)
    valid_session_ids = random.sample(valid_session_ids, valid_session_n)
    week_sessions = week_sessions[week_sessions["session"].isin(valid_session_ids)].copy()
    week_labels = week_labels[week_labels["session"].isin(valid_session_ids)].copy()

    # 候補選出
    cand_df = make_cand_df(week_sessions, trans_maps=trans_maps)
    cand_df = reduce_mem_usage(cand_df)
    return cand_df, week_sessions, week_labels

# %%
@noglobal(excepts=["cfg", "logger"])
def make_valid_data(cand_df, week_sessions, week_labels, type_):
    # 特徴量付与
    valid = add_features(week_sessions, cand_df, cfg.valid_week)
    valid = add_labels(valid, week_labels, type_)
    valid = valid.reset_index(drop=True)
    valid = reduce_mem_usage(valid)
    return valid

# %%
@noglobal(excepts=["cfg", "logger"])
def model_training(train, valid, features, target, valid_labels, type_):
    params = {'objective': 'binary', 
            'boosting': 'gbdt', 
            'learning_rate': 0.1, 
            'metric': 'binary_logloss', 
            'seed': cfg.seed
            }

    # 学習
    vl_pred_df = valid[["session", "aid"]].copy()

    tr_x, tr_y = train[features], train[target]
    vl_x, vl_y = valid[features], valid[target]
    tr_data = lgb.Dataset(tr_x, label=tr_y)
    vl_data = lgb.Dataset(vl_x, label=vl_y)

    model = lgb.train(params, tr_data, valid_sets=[tr_data, vl_data],
                      num_boost_round=2000000, early_stopping_rounds=100, verbose_eval=100)

    # 特徴量重要度
    fi = pd.DataFrame()
    fi["feature"] = model.feature_name()
    fi["importance"] = model.feature_importance(importance_type="gain")

    # 2値分類の出力を元にk個選定
    vl_pred_df["prob"] = model.predict(vl_x, num_iteration=model.best_iteration)
    vl_pred_df = vl_pred_df.sort_values(["session", "prob"], ascending=(True, False))
    vl_pred_df = vl_pred_df.groupby(["session"]).head(cfg.k)
    vl_pred_df = vl_pred_df.groupby(["session"])["aid"].apply(list).reset_index()
    
    # 評価
    assert valid_labels["session"].tolist() == vl_pred_df["session"].unique().tolist()
    score = evaluate(valid_labels["clicks_labels"].tolist(),
                     valid_labels["carts_labels"].tolist(),
                     valid_labels["orders_labels"].tolist(),
                     vl_pred_df["aid"].tolist(),
                     vl_pred_df["aid"].tolist(),
                     vl_pred_df["aid"].tolist(),
                     cfg.k)
    logger.info(f"{type_} valid score")
    logger.info(score)

    # モデル保存
    model.save_model(cfg.output_dir + f"{cfg.exp_name}/{type_}_model.lgb")

    # 特徴量重要度
    fi_n = fi['feature'].nunique()
    order = list(fi.groupby("feature").mean().sort_values("importance", ascending=False).index)
    plt.figure(figsize=(10, fi_n*0.2))
    sns.barplot(x="importance", y="feature", data=fi, order=order)
    plt.title(f"LGBM importance({type_})")
    plt.tight_layout()
    plt.savefig(cfg.output_dir + f'{cfg.exp_name}/lgbm_importance_{type_}.png')

    return score[f"recall_{type_}"]

# %%
@noglobal(excepts=["cfg", "logger", "cache"])
def make_test_data():
    # testデータ作成
    test_sessions = pd.read_pickle(cfg.prep_dir + f"test_sessions.pkl")
    trans_map_cache_file = f"trans_maps.pkl"
    trans_map_cache_path = cache.get_abspath(trans_map_cache_file)
    with open(trans_map_cache_path, "rb") as f:
        trans_maps = pickle.load(f)

    dfs =[]
    # 候補選出
    logger.info("[make_test] make_cand_df")
    cand_df = make_cand_df(test_sessions, trans_maps=trans_maps)
    cand_df = reduce_mem_usage(cand_df)
    # 特徴量付与
    logger.info("[make_test] add_features")
    test = add_features(test_sessions, cand_df)
    test = reduce_mem_usage(test)

    return test

# %%
@noglobal(excepts=["cfg", "logger"])
def inference(test, features):
    pred_dfs = []
    for type_ in ["clicks", "carts", "orders"]:
        pred_df_tmp = test[["session", "aid"]].copy()
        # 推論
        model = lgb.Booster(model_file = cfg.output_dir + f"{cfg.exp_name}/{type_}_model.lgb")

        # 2値分類の出力を元にk個選定
        pred_df_tmp["prob"] = model.predict(test[features], num_iteration=model.best_iteration)
        pred_df_tmp = pred_df_tmp.sort_values(["session", "prob"], ascending=(True, False))
        pred_df_tmp = pred_df_tmp.groupby(["session"]).head(cfg.k)
        pred_df_tmp["aid"] = pred_df_tmp["aid"].astype(str)
        pred_df_tmp = pred_df_tmp.groupby(["session"])["aid"].apply(list).reset_index()
        pred_df_tmp["aid"] = pred_df_tmp["aid"].apply(lambda x: ' '.join(x))
        pred_df_tmp["type"] = type_
        pred_dfs.append(pred_df_tmp)
    del test, model
    gc.collect()
    
    pred_df = pd.concat(pred_dfs)
    # sub作成
    sub = pd.read_csv(cfg.input_dir + f"sample_submission.csv", usecols=["session_type"])
    pred_df["session_type"] = pred_df["session"].astype(str) + "_" + pred_df["type"]
    pred_df = pred_df.rename(columns={"aid": "labels"})
    sub = sub.merge(pred_df[["session_type", "labels"]], on="session_type", how="left")
    sub.to_csv(cfg.output_dir + f"{cfg.exp_name}/{cfg.exp_name}_sub.csv", index=False)

# %%
@noglobal(excepts=["cfg", "logger", "cache"])
def main():
    scores = {}
    logger.info(f"START")
    line_notify.send(f"{cfg.exp_name} | START")
    
    # trans_map作成
    weeks = [None] + cfg.train_weeks + [cfg.valid_week]
    for week in weeks:
        if week is None:
            cache_file = "trans_maps.pkl"
        else:    
            cache_file = f"trans_maps_{week}.pkl"
        cache_path = cache.get_abspath(cache_file)
        if cache.exists(cache_path):
            logger.info(f"[{cache_file}] cache exists. load cache and skip process.")
            with open(cache_path, "rb") as f:
                trans_maps = pickle.load(f)
        else:
            trans_maps = get_trans_maps(week)
            with open(cache_path, "wb") as f:
                pickle.dump(trans_maps, f)

    for type_ in ["clicks", "carts", "orders"]:
        # train data作成
        logger.info(f"make {type_}_train_data")
        cache_file = f"{type_}_train.pkl"
        cache_path = cache.get_abspath(cache_file)
        if cache.exists(cache_path):
            logger.info(f"[{cache_file}] cache exists. read cache and skip process.")
            train = pd.read_pickle(cache_path)
        else:
            train = make_train_data(type_)
            train.to_pickle(cache_path)
        
        logger.info(f"make {type_}_valid_data")
        # valid cand作成
        cand_cache_path = cache.get_abspath("valid_cand.pkl")
        sessions_cache_path = cache.get_abspath("valid_sessions.pkl")
        labels_cache_path = cache.get_abspath("valid_labels.pkl")
        if cache.exists(cand_cache_path) & cache.exists(labels_cache_path) & cache.exists(sessions_cache_path):
            logger.info("[valid_cand.pkl] cache exists. read cache and skip process.")
            valid_cand = pd.read_pickle(cand_cache_path)
            valid_sessions = pd.read_pickle(sessions_cache_path)
            valid_labels = pd.read_pickle(labels_cache_path)
        else:
            valid_cand, valid_sessions, valid_labels = make_valid_cand()
            valid_cand.to_pickle(cand_cache_path)
            valid_sessions.to_pickle(sessions_cache_path)
            valid_labels.to_pickle(labels_cache_path)

        # valid data作成
        logger.info(f"make {type_}_valid_data")
        cache_file = f"{type_}_valid.pkl"
        cache_path = cache.get_abspath(cache_file)
        if cache.exists(cache_path):
            logger.info(f"[{cache_file}] cache exists. read cache and skip process.")
            valid = pd.read_pickle(cache_path)
        else:
            valid = make_valid_data(valid_cand, valid_sessions, valid_labels, type_)
            valid.to_pickle(cache_path)

        # モデル学習
        target = "labels"
        not_use_cols = ["session", "aid", target]
        features = [c for c in train.columns if c not in not_use_cols]

        scores[f"recall_{type_}"] = model_training(train, valid, features, target, valid_labels, type_)

        del train, valid, valid_labels
        gc.collect()
    
    scores["total"] = (float(scores["recall_clicks"]) * 0.1) + (float(scores["recall_carts"]) * 0.3) + (float(scores["recall_orders"]) * 0.6)
    report = f"\n{cfg.exp_name}\n"
    report += f'valid_end\n'
    report += str(scores)
    line_notify.send(report)

    # testデータ
    cache_path = cache.get_abspath("test.pkl")
    if cache.exists(cache_path):
        logger.info("cache exists. read cache and skip process.")
        test = pd.read_pickle(cache_path)
    else:
        test = make_test_data()
        test.to_pickle(cache_path)

    logger.info(f"-------- inference --------")
    inference(test, features)

    line_notify.send(f"{cfg.exp_name} | END!!")

# %%
try:
    main()
except Exception as e:
    logger.error(traceback.format_exc())
    line_notify.send(f"{cfg.exp_name} | ERROR!!\n{traceback.format_exc()}")
# Out:
# 0:00:00.805391 	 START
# 0:00:05.928270 	 [trans_maps.pkl] cache exists. load cache and skip process.
# 0:00:20.220364 	 [trans_maps_week3.pkl] cache exists. load cache and skip process.
# 0:00:36.120644 	 [trans_maps_week4.pkl] cache exists. load cache and skip process.
# 0:00:53.232270 	 make clicks_train_data
# 0:01:00.346058 	 [train_cand_week3_0.pkl] cache exists. read cache and skip process.
# /mnt/otto-recommender-system/output/exp046/cache/train_cand_week3_0.pkl
# 0:05:58.487832 	 [features] prep : start
# 0:05:58.525997 	 [features] session_cnt : start
# 0:06:06.564972 	 [features] session_aid_nunique : start
# 0:06:08.596225 	 [features] session_last_type : start
# 0:06:11.159747 	 [features] aid_cnt : start
# Memory usage of dataframe is 1085.58 MB
# Memory usage after optimization is: 356.83 MB
# Decreased by 67.1%
# 0:06:45.780143 	 make clicks_valid_data
# 0:07:09.969943 	 [make_candidate] session_frequent : start
# 0:07:10.209394 	 [add_candidate] session_frequent : start
# 0:07:10.235282 	 [make_candidate] session_latest : start
# 0:07:10.363552 	 [add_candidate] session_latest : start
# 0:07:10.404975 	 [make_candidate] session_latest_time_wt_pair0 : start
# 0:07:10.716402 	 [add_candidate] session_latest_time_wt_pair0 : start
# 0:07:10.757232 	 [make_candidate] session_latest_word2vec_pair0 : start
# 0:07:11.061483 	 [add_candidate] session_latest_word2vec_pair0 : start
# 0:07:11.125636 	 [make_candidate] session_latest_pair0 : start
# 0:07:11.427408 	 [add_candidate] session_latest_pair0 : start
# 0:07:11.493219 	 [make_candidate] session_latest_time_wt_pair1 : start
# 0:07:11.800968 	 [add_candidate] session_latest_time_wt_pair1 : start
# 0:07:11.875668 	 [make_candidate] session_latest_word2vec_pair1 : start
# 0:07:12.181236 	 [add_candidate] session_latest_word2vec_pair1 : start
# 0:07:12.259452 	 [make_candidate] session_latest_pair1 : start
# 0:07:12.558521 	 [add_candidate] session_latest_pair1 : start
# 0:07:12.647985 	 [make_candidate] session_latest_time_wt_pair2 : start
# 0:07:12.955923 	 [add_candidate] session_latest_time_wt_pair2 : start
# 0:07:13.051542 	 [make_candidate] session_latest_word2vec_pair2 : start
# 0:07:13.359646 	 [add_candidate] session_latest_word2vec_pair2 : start
# 0:07:13.470842 	 [make_candidate] session_latest_pair2 : start
# 0:07:13.770452 	 [add_candidate] session_latest_pair2 : start
# 0:07:13.962286 	 [make_candidate] session_latest_time_wt_pair3 : start
# 0:07:14.331525 	 [add_candidate] session_latest_time_wt_pair3 : start
# 0:07:14.545483 	 [make_candidate] session_latest_word2vec_pair3 : start
# 0:07:14.905828 	 [add_candidate] session_latest_word2vec_pair3 : start
# 0:07:15.116676 	 [make_candidate] session_latest_pair3 : start
# 0:07:15.472598 	 [add_candidate] session_latest_pair3 : start
# 0:07:15.698595 	 [make_candidate] session_latest_time_wt_pair4 : start
# 0:07:16.072420 	 [add_candidate] session_latest_time_wt_pair4 : start
# 0:07:16.310813 	 [make_candidate] session_latest_word2vec_pair4 : start
# 0:07:16.683038 	 [add_candidate] session_latest_word2vec_pair4 : start
# 0:07:16.928892 	 [make_candidate] session_latest_pair4 : start
# 0:07:17.298183 	 [add_candidate] session_latest_pair4 : start
# 0:07:17.558287 	 [make_candidate] session_latest_time_wt_pair5 : start
# 0:07:17.947076 	 [add_candidate] session_latest_time_wt_pair5 : start
# 0:07:18.252055 	 [make_candidate] session_latest_word2vec_pair5 : start
# 0:07:18.595576 	 [add_candidate] session_latest_word2vec_pair5 : start
# 0:07:18.888275 	 [make_candidate] session_latest_pair5 : start
# 0:07:19.192531 	 [add_candidate] session_latest_pair5 : start
# 0:07:19.485362 	 [make_candidate] session_latest_time_wt_pair6 : start
# 0:07:19.805439 	 [add_candidate] session_latest_time_wt_pair6 : start
# 0:07:20.145278 	 [make_candidate] session_latest_word2vec_pair6 : start
# 0:07:20.470502 	 [add_candidate] session_latest_word2vec_pair6 : start
# 0:07:20.932583 	 [make_candidate] session_latest_pair6 : start
# 0:07:21.244483 	 [add_candidate] session_latest_pair6 : start
# 0:07:21.724705 	 [make_candidate] session_latest_time_wt_pair7 : start
# 0:07:22.085814 	 [add_candidate] session_latest_time_wt_pair7 : start
# 0:07:22.555919 	 [make_candidate] session_latest_word2vec_pair7 : start
# 0:07:22.904694 	 [add_candidate] session_latest_word2vec_pair7 : start
# 0:07:23.386070 	 [make_candidate] session_latest_pair7 : start
# 0:07:23.729519 	 [add_candidate] session_latest_pair7 : start
# 0:07:24.231946 	 [make_candidate] session_latest_time_wt_pair8 : start
# 0:07:24.606320 	 [add_candidate] session_latest_time_wt_pair8 : start
# 0:07:25.123288 	 [make_candidate] session_latest_word2vec_pair8 : start
# 0:07:25.590951 	 [add_candidate] session_latest_word2vec_pair8 : start
# 0:07:26.113534 	 [make_candidate] session_latest_pair8 : start
# 0:07:26.471173 	 [add_candidate] session_latest_pair8 : start
# 0:07:27.023211 	 [make_candidate] session_latest_time_wt_pair9 : start
# 0:07:27.342041 	 [add_candidate] session_latest_time_wt_pair9 : start
# 0:07:27.910488 	 [make_candidate] session_latest_word2vec_pair9 : start
# 0:07:28.203913 	 [add_candidate] session_latest_word2vec_pair9 : start
# 0:07:28.779480 	 [make_candidate] session_latest_pair9 : start
# 0:07:29.076039 	 [add_candidate] session_latest_pair9 : start
# 0:07:29.673156 	 [make_candidate] session_latest_time_wt_pair10 : start
# 0:07:29.980291 	 [add_candidate] session_latest_time_wt_pair10 : start
# 0:07:30.613977 	 [make_candidate] session_latest_word2vec_pair10 : start
# 0:07:31.001835 	 [add_candidate] session_latest_word2vec_pair10 : start
# 0:07:31.639077 	 [make_candidate] session_latest_pair10 : start
# 0:07:32.079205 	 [add_candidate] session_latest_pair10 : start
# 0:07:32.734779 	 [make_candidate] session_latest_time_wt_pair11 : start
# 0:07:33.116714 	 [add_candidate] session_latest_time_wt_pair11 : start
# 0:07:33.763094 	 [make_candidate] session_latest_word2vec_pair11 : start
# 0:07:34.087312 	 [add_candidate] session_latest_word2vec_pair11 : start
# 0:07:34.744000 	 [make_candidate] session_latest_pair11 : start
# 0:07:35.017771 	 [add_candidate] session_latest_pair11 : start
# 0:07:35.667382 	 [make_candidate] session_latest_time_wt_pair12 : start
# 0:07:35.991546 	 [add_candidate] session_latest_time_wt_pair12 : start
# 0:07:36.652591 	 [make_candidate] session_latest_word2vec_pair12 : start
# 0:07:36.971492 	 [add_candidate] session_latest_word2vec_pair12 : start
# 0:07:37.677936 	 [make_candidate] session_latest_pair12 : start
# 0:07:38.046108 	 [add_candidate] session_latest_pair12 : start
# 0:07:38.771123 	 [make_candidate] session_latest_time_wt_pair13 : start
# 0:07:39.184520 	 [add_candidate] session_latest_time_wt_pair13 : start
# 0:07:39.957981 	 [make_candidate] session_latest_word2vec_pair13 : start
# 0:07:40.381007 	 [add_candidate] session_latest_word2vec_pair13 : start
# 0:07:41.109204 	 [make_candidate] session_latest_pair13 : start
# 0:07:41.394146 	 [add_candidate] session_latest_pair13 : start
# 0:07:42.170569 	 [make_candidate] session_latest_time_wt_pair14 : start
# 0:07:42.493547 	 [add_candidate] session_latest_time_wt_pair14 : start
# 0:07:43.229411 	 [make_candidate] session_latest_word2vec_pair14 : start
# 0:07:43.537596 	 [add_candidate] session_latest_word2vec_pair14 : start
# 0:07:44.604988 	 [make_candidate] session_latest_pair14 : start
# 0:07:44.949854 	 [add_candidate] session_latest_pair14 : start
# 0:07:46.065386 	 [make_candidate] session_latest_time_wt_pair15 : start
# 0:07:46.552700 	 [add_candidate] session_latest_time_wt_pair15 : start
# 0:07:47.640509 	 [make_candidate] session_latest_word2vec_pair15 : start
# 0:07:48.072699 	 [add_candidate] session_latest_word2vec_pair15 : start
# 0:07:49.149572 	 [make_candidate] session_latest_pair15 : start
# 0:07:49.520060 	 [add_candidate] session_latest_pair15 : start
# 0:07:50.614442 	 [make_candidate] session_latest_time_wt_pair16 : start
# 0:07:51.094903 	 [add_candidate] session_latest_time_wt_pair16 : start
# 0:07:52.218700 	 [make_candidate] session_latest_word2vec_pair16 : start
# 0:07:52.561034 	 [add_candidate] session_latest_word2vec_pair16 : start
# 0:07:53.685422 	 [make_candidate] session_latest_pair16 : start
# 0:07:54.026362 	 [add_candidate] session_latest_pair16 : start
# 0:07:55.156692 	 [make_candidate] session_latest_time_wt_pair17 : start
# 0:07:55.494181 	 [add_candidate] session_latest_time_wt_pair17 : start
# 0:07:56.616749 	 [make_candidate] session_latest_word2vec_pair17 : start
# 0:07:56.933459 	 [add_candidate] session_latest_word2vec_pair17 : start
# 0:07:58.046426 	 [make_candidate] session_latest_pair17 : start
# 0:07:58.351507 	 [add_candidate] session_latest_pair17 : start
# 0:07:59.524173 	 [make_candidate] session_latest_time_wt_pair18 : start
# 0:07:59.959784 	 [add_candidate] session_latest_time_wt_pair18 : start
# 0:08:01.135729 	 [make_candidate] session_latest_word2vec_pair18 : start
# 0:08:01.464940 	 [add_candidate] session_latest_word2vec_pair18 : start
# 0:08:02.696572 	 [make_candidate] session_latest_pair18 : start
# 0:08:02.960361 	 [add_candidate] session_latest_pair18 : start
# 0:08:04.148992 	 [make_candidate] session_latest_time_wt_pair19 : start
# 0:08:04.479747 	 [add_candidate] session_latest_time_wt_pair19 : start
# 0:08:05.689814 	 [make_candidate] session_latest_word2vec_pair19 : start
# 0:08:06.110038 	 [add_candidate] session_latest_word2vec_pair19 : start
# 0:08:07.271610 	 [make_candidate] session_latest_pair19 : start
# 0:08:07.585999 	 [add_candidate] session_latest_pair19 : start
# 0:08:08.804763 	 [make_candidate] session_latest_type_wt_pair0 : start
# 0:08:09.104072 	 [add_candidate] session_latest_type_wt_pair0 : start
# 0:08:10.324392 	 [make_candidate] session_latest_clicks2carts_pair0 : start
# 0:08:10.676230 	 [add_candidate] session_latest_clicks2carts_pair0 : start
# 0:08:11.870299 	 [make_candidate] session_latest_clicks2orders_pair0 : start
# 0:08:12.190823 	 [add_candidate] session_latest_clicks2orders_pair0 : start
# 0:08:13.392311 	 [make_candidate] session_latest_type_wt_pair1 : start
# 0:08:13.736639 	 [add_candidate] session_latest_type_wt_pair1 : start
# 0:08:14.943159 	 [make_candidate] session_latest_clicks2carts_pair1 : start
# 0:08:15.237088 	 [add_candidate] session_latest_clicks2carts_pair1 : start
# 0:08:16.442873 	 [make_candidate] session_latest_clicks2orders_pair1 : start
# 0:08:16.756428 	 [add_candidate] session_latest_clicks2orders_pair1 : start
# 0:08:18.010469 	 [make_candidate] session_latest_type_wt_pair2 : start
# 0:08:18.507203 	 [add_candidate] session_latest_type_wt_pair2 : start
# 0:08:19.767658 	 [make_candidate] session_latest_clicks2carts_pair2 : start
# 0:08:19.989767 	 [add_candidate] session_latest_clicks2carts_pair2 : start
# 0:08:21.247431 	 [make_candidate] session_latest_clicks2orders_pair2 : start
# 0:08:21.465354 	 [add_candidate] session_latest_clicks2orders_pair2 : start
# 0:08:22.665191 	 [make_candidate] session_latest_type_wt_pair3 : start
# 0:08:23.092219 	 [add_candidate] session_latest_type_wt_pair3 : start
# 0:08:24.349041 	 [make_candidate] session_latest_clicks2carts_pair3 : start
# 0:08:24.615943 	 [add_candidate] session_latest_clicks2carts_pair3 : start
# 0:08:25.824691 	 [make_candidate] session_latest_clicks2orders_pair3 : start
# 0:08:26.178949 	 [add_candidate] session_latest_clicks2orders_pair3 : start
# 0:08:27.439847 	 [make_candidate] session_latest_type_wt_pair4 : start
# 0:08:27.904292 	 [add_candidate] session_latest_type_wt_pair4 : start
# 0:08:29.290529 	 [make_candidate] session_latest_clicks2carts_pair4 : start
# 0:08:29.583032 	 [add_candidate] session_latest_clicks2carts_pair4 : start
# 0:08:30.889147 	 [make_candidate] session_latest_clicks2orders_pair4 : start
# 0:08:31.144525 	 [add_candidate] session_latest_clicks2orders_pair4 : start
# Memory usage of dataframe is 212.81 MB
# Memory usage after optimization is: 141.87 MB
# Decreased by 33.3%
# 0:08:34.148189 	 make clicks_valid_data
# 0:08:34.242360 	 [features] prep : start
# 0:08:34.253614 	 [features] session_cnt : start
# 0:08:37.400096 	 [features] session_aid_nunique : start
# 0:08:38.320938 	 [features] session_last_type : start
# 0:08:39.324568 	 [features] aid_cnt : start
# Memory usage of dataframe is 1915.25 MB
# Memory usage after optimization is: 611.82 MB
# Decreased by 68.1%
# /home/kaggler/.local/lib/python3.8/site-packages/lightgbm/engine.py:181: UserWarning: 'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. Pass 'early_stopping()' callback via 'callbacks' argument instead.
#   _log_warning("'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. "
# /home/kaggler/.local/lib/python3.8/site-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# [LightGBM] [Info] Number of positive: 2634979, number of negative: 2634979
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.312245 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 5228
# [LightGBM] [Info] Number of data points in the train set: 5269958, number of used features: 28
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500000 -> initscore=0.000000
# Training until validation scores don't improve for 100 rounds
# [100]	training's binary_logloss: 0.466826	valid_1's binary_logloss: 0.43612
# [200]	training's binary_logloss: 0.464618	valid_1's binary_logloss: 0.434983
# [300]	training's binary_logloss: 0.463326	valid_1's binary_logloss: 0.434227
# [400]	training's binary_logloss: 0.462325	valid_1's binary_logloss: 0.43385
# [500]	training's binary_logloss: 0.461494	valid_1's binary_logloss: 0.43367
# [600]	training's binary_logloss: 0.460645	valid_1's binary_logloss: 0.433443
# [700]	training's binary_logloss: 0.459956	valid_1's binary_logloss: 0.433274
# [800]	training's binary_logloss: 0.459261	valid_1's binary_logloss: 0.433132
# [900]	training's binary_logloss: 0.45863	valid_1's binary_logloss: 0.433069
# [1000]	training's binary_logloss: 0.458035	valid_1's binary_logloss: 0.432977
# [1100]	training's binary_logloss: 0.457483	valid_1's binary_logloss: 0.432872
# [1200]	training's binary_logloss: 0.456924	valid_1's binary_logloss: 0.432774
# [1300]	training's binary_logloss: 0.456382	valid_1's binary_logloss: 0.432727
# [1400]	training's binary_logloss: 0.45585	valid_1's binary_logloss: 0.432646
# Early stopping, best iteration is:
# [1392]	training's binary_logloss: 0.455894	valid_1's binary_logloss: 0.432639
# 0:12:32.152965 	 clicks valid score
# 0:12:32.154448 	 {'num_clicks': 97136, 'hit_clicks': 40631, 'num_carts': 43211, 'hit_carts': 12354, 'num_orders': 20082, 'hit_orders': 10832, 'recall_clicks': '0.418', 'recall_carts': '0.286', 'recall_orders': '0.539', 'w_recall_clicks': '0.042', 'w_recall_carts': '0.086', 'w_recall_orders': '0.324', 'score': '0.451'}
# 0:12:32.644526 	 make carts_train_data
# 0:12:39.457553 	 [train_cand_week3_0.pkl] cache exists. read cache and skip process.
# /mnt/otto-recommender-system/output/exp046/cache/train_cand_week3_0.pkl
# 0:18:02.206544 	 [features] prep : start
# 0:18:02.331123 	 [features] session_cnt : start
# 0:18:06.418943 	 [features] session_aid_nunique : start
# 0:18:08.015386 	 [features] session_last_type : start
# 0:18:09.639028 	 [features] aid_cnt : start
# Memory usage of dataframe is 349.78 MB
# 0:18:59.241285 	 make carts_valid_data
# Memory usage after optimization is: 132.80 MB
# Decreased by 62.0%
# 0:19:20.962924 	 [make_candidate] session_frequent : start
# 0:19:21.178165 	 [add_candidate] session_frequent : start
# 0:19:21.208207 	 [make_candidate] session_latest : start
# 0:19:21.484724 	 [add_candidate] session_latest : start
# 0:19:21.522148 	 [make_candidate] session_latest_time_wt_pair0 : start
# 0:19:21.830933 	 [add_candidate] session_latest_time_wt_pair0 : start
# 0:19:21.873690 	 [make_candidate] session_latest_word2vec_pair0 : start
# 0:19:22.179711 	 [add_candidate] session_latest_word2vec_pair0 : start
# 0:19:22.236002 	 [make_candidate] session_latest_pair0 : start
# 0:19:22.548669 	 [add_candidate] session_latest_pair0 : start
# 0:19:22.623427 	 [make_candidate] session_latest_time_wt_pair1 : start
# 0:19:22.930151 	 [add_candidate] session_latest_time_wt_pair1 : start
# 0:19:23.005435 	 [make_candidate] session_latest_word2vec_pair1 : start
# 0:19:23.317266 	 [add_candidate] session_latest_word2vec_pair1 : start
# 0:19:23.400696 	 [make_candidate] session_latest_pair1 : start
# 0:19:23.715860 	 [add_candidate] session_latest_pair1 : start
# 0:19:23.805068 	 [make_candidate] session_latest_time_wt_pair2 : start
# 0:19:24.126481 	 [add_candidate] session_latest_time_wt_pair2 : start
# 0:19:24.227899 	 [make_candidate] session_latest_word2vec_pair2 : start
# 0:19:24.552844 	 [add_candidate] session_latest_word2vec_pair2 : start
# 0:19:24.670174 	 [make_candidate] session_latest_pair2 : start
# 0:19:24.985288 	 [add_candidate] session_latest_pair2 : start
# 0:19:25.162481 	 [make_candidate] session_latest_time_wt_pair3 : start
# 0:19:25.502200 	 [add_candidate] session_latest_time_wt_pair3 : start
# 0:19:25.694251 	 [make_candidate] session_latest_word2vec_pair3 : start
# 0:19:26.062689 	 [add_candidate] session_latest_word2vec_pair3 : start
# 0:19:26.261090 	 [make_candidate] session_latest_pair3 : start
# 0:19:26.635319 	 [add_candidate] session_latest_pair3 : start
# 0:19:26.851707 	 [make_candidate] session_latest_time_wt_pair4 : start
# 0:19:27.231721 	 [add_candidate] session_latest_time_wt_pair4 : start
# 0:19:27.472837 	 [make_candidate] session_latest_word2vec_pair4 : start
# 0:19:27.843301 	 [add_candidate] session_latest_word2vec_pair4 : start
# 0:19:28.096836 	 [make_candidate] session_latest_pair4 : start
# 0:19:28.516210 	 [add_candidate] session_latest_pair4 : start
# 0:19:28.764422 	 [make_candidate] session_latest_time_wt_pair5 : start
# 0:19:29.143966 	 [add_candidate] session_latest_time_wt_pair5 : start
# 0:19:29.406105 	 [make_candidate] session_latest_word2vec_pair5 : start
# 0:19:29.784943 	 [add_candidate] session_latest_word2vec_pair5 : start
# 0:19:30.060106 	 [make_candidate] session_latest_pair5 : start
# 0:19:30.426695 	 [add_candidate] session_latest_pair5 : start
# 0:19:30.708112 	 [make_candidate] session_latest_time_wt_pair6 : start
# 0:19:31.087795 	 [add_candidate] session_latest_time_wt_pair6 : start
# 0:19:31.368919 	 [make_candidate] session_latest_word2vec_pair6 : start
# 0:19:31.745249 	 [add_candidate] session_latest_word2vec_pair6 : start
# 0:19:32.164732 	 [make_candidate] session_latest_pair6 : start
# 0:19:32.575666 	 [add_candidate] session_latest_pair6 : start
# 0:19:33.020185 	 [make_candidate] session_latest_time_wt_pair7 : start
# 0:19:33.409160 	 [add_candidate] session_latest_time_wt_pair7 : start
# 0:19:33.854705 	 [make_candidate] session_latest_word2vec_pair7 : start
# 0:19:34.253820 	 [add_candidate] session_latest_word2vec_pair7 : start
# 0:19:34.736012 	 [make_candidate] session_latest_pair7 : start
# 0:19:35.087069 	 [add_candidate] session_latest_pair7 : start
# 0:19:35.559525 	 [make_candidate] session_latest_time_wt_pair8 : start
# 0:19:35.935588 	 [add_candidate] session_latest_time_wt_pair8 : start
# 0:19:36.404490 	 [make_candidate] session_latest_word2vec_pair8 : start
# 0:19:36.786620 	 [add_candidate] session_latest_word2vec_pair8 : start
# 0:19:37.262155 	 [make_candidate] session_latest_pair8 : start
# 0:19:37.609971 	 [add_candidate] session_latest_pair8 : start
# 0:19:38.115369 	 [make_candidate] session_latest_time_wt_pair9 : start
# 0:19:38.472731 	 [add_candidate] session_latest_time_wt_pair9 : start
# 0:19:38.981471 	 [make_candidate] session_latest_word2vec_pair9 : start
# 0:19:39.366809 	 [add_candidate] session_latest_word2vec_pair9 : start
# 0:19:39.920997 	 [make_candidate] session_latest_pair9 : start
# 0:19:40.351960 	 [add_candidate] session_latest_pair9 : start
# 0:19:40.976584 	 [make_candidate] session_latest_time_wt_pair10 : start
# 0:19:41.377266 	 [add_candidate] session_latest_time_wt_pair10 : start
# 0:19:42.007494 	 [make_candidate] session_latest_word2vec_pair10 : start
# 0:19:42.398046 	 [add_candidate] session_latest_word2vec_pair10 : start
# 0:19:43.039716 	 [make_candidate] session_latest_pair10 : start
# 0:19:43.438484 	 [add_candidate] session_latest_pair10 : start
# 0:19:44.126541 	 [make_candidate] session_latest_time_wt_pair11 : start
# 0:19:44.464909 	 [add_candidate] session_latest_time_wt_pair11 : start
# 0:19:45.098069 	 [make_candidate] session_latest_word2vec_pair11 : start
# 0:19:45.485409 	 [add_candidate] session_latest_word2vec_pair11 : start
# 0:19:46.162237 	 [make_candidate] session_latest_pair11 : start
# 0:19:46.515849 	 [add_candidate] session_latest_pair11 : start
# 0:19:47.201864 	 [make_candidate] session_latest_time_wt_pair12 : start
# 0:19:47.699200 	 [add_candidate] session_latest_time_wt_pair12 : start
# 0:19:48.436251 	 [make_candidate] session_latest_word2vec_pair12 : start
# 0:19:48.762420 	 [add_candidate] session_latest_word2vec_pair12 : start
# 0:19:49.491251 	 [make_candidate] session_latest_pair12 : start
# 0:19:49.796995 	 [add_candidate] session_latest_pair12 : start
# 0:19:50.550125 	 [make_candidate] session_latest_time_wt_pair13 : start
# 0:19:50.906938 	 [add_candidate] session_latest_time_wt_pair13 : start
# 0:19:51.652144 	 [make_candidate] session_latest_word2vec_pair13 : start
# 0:19:52.050750 	 [add_candidate] session_latest_word2vec_pair13 : start
# 0:19:52.795874 	 [make_candidate] session_latest_pair13 : start
# 0:19:53.190399 	 [add_candidate] session_latest_pair13 : start
# 0:19:54.002025 	 [make_candidate] session_latest_time_wt_pair14 : start
# 0:19:54.402014 	 [add_candidate] session_latest_time_wt_pair14 : start
# 0:19:55.186943 	 [make_candidate] session_latest_word2vec_pair14 : start
# 0:19:55.549293 	 [add_candidate] session_latest_word2vec_pair14 : start
# 0:19:56.672840 	 [make_candidate] session_latest_pair14 : start
# 0:19:57.066856 	 [add_candidate] session_latest_pair14 : start
# 0:19:58.195796 	 [make_candidate] session_latest_time_wt_pair15 : start
# 0:19:58.604078 	 [add_candidate] session_latest_time_wt_pair15 : start
# 0:19:59.792285 	 [make_candidate] session_latest_word2vec_pair15 : start
# 0:20:00.195611 	 [add_candidate] session_latest_word2vec_pair15 : start
# 0:20:01.393113 	 [make_candidate] session_latest_pair15 : start
# 0:20:01.761726 	 [add_candidate] session_latest_pair15 : start
# 0:20:02.915353 	 [make_candidate] session_latest_time_wt_pair16 : start
# 0:20:03.325446 	 [add_candidate] session_latest_time_wt_pair16 : start
# 0:20:04.509795 	 [make_candidate] session_latest_word2vec_pair16 : start
# 0:20:04.931743 	 [add_candidate] session_latest_word2vec_pair16 : start
# 0:20:06.123727 	 [make_candidate] session_latest_pair16 : start
# 0:20:06.607672 	 [add_candidate] session_latest_pair16 : start
# 0:20:07.817638 	 [make_candidate] session_latest_time_wt_pair17 : start
# 0:20:08.142057 	 [add_candidate] session_latest_time_wt_pair17 : start
# 0:20:09.316146 	 [make_candidate] session_latest_word2vec_pair17 : start
# 0:20:09.664237 	 [add_candidate] session_latest_word2vec_pair17 : start
# 0:20:10.898708 	 [make_candidate] session_latest_pair17 : start
# 0:20:11.275207 	 [add_candidate] session_latest_pair17 : start
# 0:20:12.505135 	 [make_candidate] session_latest_time_wt_pair18 : start
# 0:20:13.042315 	 [add_candidate] session_latest_time_wt_pair18 : start
# 0:20:14.286790 	 [make_candidate] session_latest_word2vec_pair18 : start
# 0:20:14.606223 	 [add_candidate] session_latest_word2vec_pair18 : start
# 0:20:15.860714 	 [make_candidate] session_latest_pair18 : start
# 0:20:16.207212 	 [add_candidate] session_latest_pair18 : start
# 0:20:17.502511 	 [make_candidate] session_latest_time_wt_pair19 : start
# 0:20:17.907351 	 [add_candidate] session_latest_time_wt_pair19 : start
# 0:20:19.178698 	 [make_candidate] session_latest_word2vec_pair19 : start
# 0:20:19.611748 	 [add_candidate] session_latest_word2vec_pair19 : start
# 0:20:20.945323 	 [make_candidate] session_latest_pair19 : start
# 0:20:21.293870 	 [add_candidate] session_latest_pair19 : start
# 0:20:22.570918 	 [make_candidate] session_latest_type_wt_pair0 : start
# 0:20:22.997021 	 [add_candidate] session_latest_type_wt_pair0 : start
# 0:20:24.324634 	 [make_candidate] session_latest_clicks2carts_pair0 : start
# 0:20:24.676796 	 [add_candidate] session_latest_clicks2carts_pair0 : start
# 0:20:25.937174 	 [make_candidate] session_latest_clicks2orders_pair0 : start
# 0:20:26.353644 	 [add_candidate] session_latest_clicks2orders_pair0 : start
# 0:20:27.677083 	 [make_candidate] session_latest_type_wt_pair1 : start
# 0:20:27.962529 	 [add_candidate] session_latest_type_wt_pair1 : start
# 0:20:29.277523 	 [make_candidate] session_latest_clicks2carts_pair1 : start
# 0:20:29.546134 	 [add_candidate] session_latest_clicks2carts_pair1 : start
# 0:20:30.848339 	 [make_candidate] session_latest_clicks2orders_pair1 : start
# 0:20:31.129892 	 [add_candidate] session_latest_clicks2orders_pair1 : start
# 0:20:32.538816 	 [make_candidate] session_latest_type_wt_pair2 : start
# 0:20:33.050031 	 [add_candidate] session_latest_type_wt_pair2 : start
# 0:20:34.358592 	 [make_candidate] session_latest_clicks2carts_pair2 : start
# 0:20:34.557691 	 [add_candidate] session_latest_clicks2carts_pair2 : start
# 0:20:35.849068 	 [make_candidate] session_latest_clicks2orders_pair2 : start
# 0:20:36.084830 	 [add_candidate] session_latest_clicks2orders_pair2 : start
# 0:20:37.444712 	 [make_candidate] session_latest_type_wt_pair3 : start
# 0:20:37.870564 	 [add_candidate] session_latest_type_wt_pair3 : start
# 0:20:39.167692 	 [make_candidate] session_latest_clicks2carts_pair3 : start
# 0:20:39.594994 	 [add_candidate] session_latest_clicks2carts_pair3 : start
# 0:20:40.893469 	 [make_candidate] session_latest_clicks2orders_pair3 : start
# 0:20:41.156380 	 [add_candidate] session_latest_clicks2orders_pair3 : start
# 0:20:42.483900 	 [make_candidate] session_latest_type_wt_pair4 : start
# 0:20:43.021588 	 [add_candidate] session_latest_type_wt_pair4 : start
# 0:20:44.364531 	 [make_candidate] session_latest_clicks2carts_pair4 : start
# 0:20:44.644450 	 [add_candidate] session_latest_clicks2carts_pair4 : start
# 0:20:45.955240 	 [make_candidate] session_latest_clicks2orders_pair4 : start
# 0:20:46.185280 	 [add_candidate] session_latest_clicks2orders_pair4 : start
# Memory usage of dataframe is 212.81 MB
# Memory usage after optimization is: 141.87 MB
# Decreased by 33.3%
# 0:20:49.636436 	 make carts_valid_data
# 0:20:49.683891 	 [features] prep : start
# 0:20:49.699250 	 [features] session_cnt : start
# 0:20:52.593880 	 [features] session_aid_nunique : start
# 0:20:53.421449 	 [features] session_last_type : start
# 0:20:54.391376 	 [features] aid_cnt : start
# Memory usage of dataframe is 1950.72 MB
# Memory usage after optimization is: 653.18 MB
# Decreased by 66.5%
# /home/kaggler/.local/lib/python3.8/site-packages/lightgbm/engine.py:181: UserWarning: 'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. Pass 'early_stopping()' callback via 'callbacks' argument instead.
#   _log_warning("'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. "
# /home/kaggler/.local/lib/python3.8/site-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# [LightGBM] [Info] Number of positive: 833564, number of negative: 833564
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.169106 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 5345
# [LightGBM] [Info] Number of data points in the train set: 1667128, number of used features: 28
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500000 -> initscore=0.000000
# Training until validation scores don't improve for 100 rounds
# [100]	training's binary_logloss: 0.410946	valid_1's binary_logloss: 0.391974
# [200]	training's binary_logloss: 0.407827	valid_1's binary_logloss: 0.390463
# [300]	training's binary_logloss: 0.405755	valid_1's binary_logloss: 0.389971
# [400]	training's binary_logloss: 0.403915	valid_1's binary_logloss: 0.389662
# [500]	training's binary_logloss: 0.402258	valid_1's binary_logloss: 0.389532
# [600]	training's binary_logloss: 0.400768	valid_1's binary_logloss: 0.389406
# [700]	training's binary_logloss: 0.399254	valid_1's binary_logloss: 0.389362
# [800]	training's binary_logloss: 0.397911	valid_1's binary_logloss: 0.389289
# [900]	training's binary_logloss: 0.396598	valid_1's binary_logloss: 0.389303
# Early stopping, best iteration is:
# [844]	training's binary_logloss: 0.397312	valid_1's binary_logloss: 0.389254
# 0:23:00.181200 	 carts valid score
# 0:23:00.182458 	 {'num_clicks': 97136, 'hit_clicks': 37445, 'num_carts': 43211, 'hit_carts': 13107, 'num_orders': 20082, 'hit_orders': 11139, 'recall_clicks': '0.385', 'recall_carts': '0.303', 'recall_orders': '0.555', 'w_recall_clicks': '0.039', 'w_recall_carts': '0.091', 'w_recall_orders': '0.333', 'score': '0.462'}
# 0:23:00.652632 	 make orders_train_data
# 0:23:07.003570 	 [train_cand_week3_0.pkl] cache exists. read cache and skip process.
# /mnt/otto-recommender-system/output/exp046/cache/train_cand_week3_0.pkl
# 0:28:35.984777 	 [features] prep : start
# 0:28:36.119245 	 [features] session_cnt : start
# 0:28:39.093039 	 [features] session_aid_nunique : start
# 0:28:40.357994 	 [features] session_last_type : start
# 0:28:41.677001 	 [features] aid_cnt : start
# Memory usage of dataframe is 242.54 MB
# 0:29:24.099795 	 make orders_valid_data
# Memory usage after optimization is: 89.36 MB
# Decreased by 63.2%
# 0:29:47.900813 	 [make_candidate] session_frequent : start
# 0:29:48.129755 	 [add_candidate] session_frequent : start
# 0:29:48.158568 	 [make_candidate] session_latest : start
# 0:29:48.391655 	 [add_candidate] session_latest : start
# 0:29:48.435519 	 [make_candidate] session_latest_time_wt_pair0 : start
# 0:29:48.834901 	 [add_candidate] session_latest_time_wt_pair0 : start
# 0:29:48.879331 	 [make_candidate] session_latest_word2vec_pair0 : start
# 0:29:49.254966 	 [add_candidate] session_latest_word2vec_pair0 : start
# 0:29:49.315226 	 [make_candidate] session_latest_pair0 : start
# 0:29:49.688301 	 [add_candidate] session_latest_pair0 : start
# 0:29:49.759141 	 [make_candidate] session_latest_time_wt_pair1 : start
# 0:29:50.144178 	 [add_candidate] session_latest_time_wt_pair1 : start
# 0:29:50.253832 	 [make_candidate] session_latest_word2vec_pair1 : start
# 0:29:50.652026 	 [add_candidate] session_latest_word2vec_pair1 : start
# 0:29:50.736575 	 [make_candidate] session_latest_pair1 : start
# 0:29:51.116837 	 [add_candidate] session_latest_pair1 : start
# 0:29:51.209862 	 [make_candidate] session_latest_time_wt_pair2 : start
# 0:29:51.586252 	 [add_candidate] session_latest_time_wt_pair2 : start
# 0:29:51.696919 	 [make_candidate] session_latest_word2vec_pair2 : start
# 0:29:52.063096 	 [add_candidate] session_latest_word2vec_pair2 : start
# 0:29:52.169516 	 [make_candidate] session_latest_pair2 : start
# 0:29:52.521052 	 [add_candidate] session_latest_pair2 : start
# 0:29:52.703752 	 [make_candidate] session_latest_time_wt_pair3 : start
# 0:29:53.085083 	 [add_candidate] session_latest_time_wt_pair3 : start
# 0:29:53.275577 	 [make_candidate] session_latest_word2vec_pair3 : start
# 0:29:53.646834 	 [add_candidate] session_latest_word2vec_pair3 : start
# 0:29:53.858432 	 [make_candidate] session_latest_pair3 : start
# 0:29:54.221681 	 [add_candidate] session_latest_pair3 : start
# 0:29:54.442487 	 [make_candidate] session_latest_time_wt_pair4 : start
# 0:29:54.812306 	 [add_candidate] session_latest_time_wt_pair4 : start
# 0:29:55.036958 	 [make_candidate] session_latest_word2vec_pair4 : start
# 0:29:55.402821 	 [add_candidate] session_latest_word2vec_pair4 : start
# 0:29:55.623341 	 [make_candidate] session_latest_pair4 : start
# 0:29:55.981793 	 [add_candidate] session_latest_pair4 : start
# 0:29:56.216862 	 [make_candidate] session_latest_time_wt_pair5 : start
# 0:29:56.579439 	 [add_candidate] session_latest_time_wt_pair5 : start
# 0:29:56.837908 	 [make_candidate] session_latest_word2vec_pair5 : start
# 0:29:57.210425 	 [add_candidate] session_latest_word2vec_pair5 : start
# 0:29:57.491444 	 [make_candidate] session_latest_pair5 : start
# 0:29:57.834608 	 [add_candidate] session_latest_pair5 : start
# 0:29:58.113528 	 [make_candidate] session_latest_time_wt_pair6 : start
# 0:29:58.485326 	 [add_candidate] session_latest_time_wt_pair6 : start
# 0:29:58.768297 	 [make_candidate] session_latest_word2vec_pair6 : start
# 0:29:59.142332 	 [add_candidate] session_latest_word2vec_pair6 : start
# 0:29:59.599882 	 [make_candidate] session_latest_pair6 : start
# 0:29:59.988669 	 [add_candidate] session_latest_pair6 : start
# 0:30:00.446037 	 [make_candidate] session_latest_time_wt_pair7 : start
# 0:30:00.831028 	 [add_candidate] session_latest_time_wt_pair7 : start
# 0:30:01.278162 	 [make_candidate] session_latest_word2vec_pair7 : start
# 0:30:01.638402 	 [add_candidate] session_latest_word2vec_pair7 : start
# 0:30:02.081128 	 [make_candidate] session_latest_pair7 : start
# 0:30:02.450204 	 [add_candidate] session_latest_pair7 : start
# 0:30:02.929505 	 [make_candidate] session_latest_time_wt_pair8 : start
# 0:30:03.303921 	 [add_candidate] session_latest_time_wt_pair8 : start
# 0:30:03.800858 	 [make_candidate] session_latest_word2vec_pair8 : start
# 0:30:04.203522 	 [add_candidate] session_latest_word2vec_pair8 : start
# 0:30:04.707071 	 [make_candidate] session_latest_pair8 : start
# 0:30:05.101343 	 [add_candidate] session_latest_pair8 : start
# 0:30:05.601060 	 [make_candidate] session_latest_time_wt_pair9 : start
# 0:30:06.002548 	 [add_candidate] session_latest_time_wt_pair9 : start
# 0:30:06.548448 	 [make_candidate] session_latest_word2vec_pair9 : start
# 0:30:06.949577 	 [add_candidate] session_latest_word2vec_pair9 : start
# 0:30:07.508643 	 [make_candidate] session_latest_pair9 : start
# 0:30:07.872184 	 [add_candidate] session_latest_pair9 : start
# 0:30:08.474418 	 [make_candidate] session_latest_time_wt_pair10 : start
# 0:30:08.878542 	 [add_candidate] session_latest_time_wt_pair10 : start
# 0:30:09.427268 	 [make_candidate] session_latest_word2vec_pair10 : start
# 0:30:09.826035 	 [add_candidate] session_latest_word2vec_pair10 : start
# 0:30:10.437397 	 [make_candidate] session_latest_pair10 : start
# 0:30:10.794642 	 [add_candidate] session_latest_pair10 : start
# 0:30:11.440650 	 [make_candidate] session_latest_time_wt_pair11 : start
# 0:30:11.818825 	 [add_candidate] session_latest_time_wt_pair11 : start
# 0:30:12.467499 	 [make_candidate] session_latest_word2vec_pair11 : start
# 0:30:12.851463 	 [add_candidate] session_latest_word2vec_pair11 : start
# 0:30:13.462117 	 [make_candidate] session_latest_pair11 : start
# 0:30:13.821293 	 [add_candidate] session_latest_pair11 : start
# 0:30:14.465608 	 [make_candidate] session_latest_time_wt_pair12 : start
# 0:30:14.842180 	 [add_candidate] session_latest_time_wt_pair12 : start
# 0:30:15.521784 	 [make_candidate] session_latest_word2vec_pair12 : start
# 0:30:15.942543 	 [add_candidate] session_latest_word2vec_pair12 : start
# 0:30:16.627143 	 [make_candidate] session_latest_pair12 : start
# 0:30:17.070441 	 [add_candidate] session_latest_pair12 : start
# 0:30:17.724879 	 [make_candidate] session_latest_time_wt_pair13 : start
# 0:30:18.123586 	 [add_candidate] session_latest_time_wt_pair13 : start
# 0:30:18.790018 	 [make_candidate] session_latest_word2vec_pair13 : start
# 0:30:19.206438 	 [add_candidate] session_latest_word2vec_pair13 : start
# 0:30:20.028727 	 [make_candidate] session_latest_pair13 : start
# 0:30:20.407719 	 [add_candidate] session_latest_pair13 : start
# 0:30:21.102811 	 [make_candidate] session_latest_time_wt_pair14 : start
# 0:30:21.484165 	 [add_candidate] session_latest_time_wt_pair14 : start
# 0:30:22.170012 	 [make_candidate] session_latest_word2vec_pair14 : start
# 0:30:22.581738 	 [add_candidate] session_latest_word2vec_pair14 : start
# 0:30:23.599660 	 [make_candidate] session_latest_pair14 : start
# 0:30:23.947443 	 [add_candidate] session_latest_pair14 : start
# 0:30:25.039295 	 [make_candidate] session_latest_time_wt_pair15 : start
# 0:30:25.445855 	 [add_candidate] session_latest_time_wt_pair15 : start
# 0:30:26.534220 	 [make_candidate] session_latest_word2vec_pair15 : start
# 0:30:26.921510 	 [add_candidate] session_latest_word2vec_pair15 : start
# 0:30:28.025228 	 [make_candidate] session_latest_pair15 : start
# 0:30:28.436709 	 [add_candidate] session_latest_pair15 : start
# 0:30:29.560814 	 [make_candidate] session_latest_time_wt_pair16 : start
# 0:30:29.976385 	 [add_candidate] session_latest_time_wt_pair16 : start
# 0:30:31.053900 	 [make_candidate] session_latest_word2vec_pair16 : start
# 0:30:31.450859 	 [add_candidate] session_latest_word2vec_pair16 : start
# 0:30:32.595099 	 [make_candidate] session_latest_pair16 : start
# 0:30:32.969620 	 [add_candidate] session_latest_pair16 : start
# 0:30:34.212602 	 [make_candidate] session_latest_time_wt_pair17 : start
# 0:30:34.596204 	 [add_candidate] session_latest_time_wt_pair17 : start
# 0:30:35.753911 	 [make_candidate] session_latest_word2vec_pair17 : start
# 0:30:36.102187 	 [add_candidate] session_latest_word2vec_pair17 : start
# 0:30:37.272084 	 [make_candidate] session_latest_pair17 : start
# 0:30:37.610357 	 [add_candidate] session_latest_pair17 : start
# 0:30:38.751436 	 [make_candidate] session_latest_time_wt_pair18 : start
# 0:30:39.060769 	 [add_candidate] session_latest_time_wt_pair18 : start
# 0:30:40.295436 	 [make_candidate] session_latest_word2vec_pair18 : start
# 0:30:40.615858 	 [add_candidate] session_latest_word2vec_pair18 : start
# 0:30:41.785320 	 [make_candidate] session_latest_pair18 : start
# 0:30:42.104159 	 [add_candidate] session_latest_pair18 : start
# 0:30:43.311078 	 [make_candidate] session_latest_time_wt_pair19 : start
# 0:30:43.734116 	 [add_candidate] session_latest_time_wt_pair19 : start
# 0:30:45.003561 	 [make_candidate] session_latest_word2vec_pair19 : start
# 0:30:45.430212 	 [add_candidate] session_latest_word2vec_pair19 : start
# 0:30:46.799023 	 [make_candidate] session_latest_pair19 : start
# 0:30:47.189738 	 [add_candidate] session_latest_pair19 : start
# 0:30:48.446775 	 [make_candidate] session_latest_type_wt_pair0 : start
# 0:30:48.771397 	 [add_candidate] session_latest_type_wt_pair0 : start
# 0:30:50.046429 	 [make_candidate] session_latest_clicks2carts_pair0 : start
# 0:30:50.292188 	 [add_candidate] session_latest_clicks2carts_pair0 : start
# 0:30:51.534644 	 [make_candidate] session_latest_clicks2orders_pair0 : start
# 0:30:51.808044 	 [add_candidate] session_latest_clicks2orders_pair0 : start
# 0:30:53.057734 	 [make_candidate] session_latest_type_wt_pair1 : start
# 0:30:53.400995 	 [add_candidate] session_latest_type_wt_pair1 : start
# 0:30:54.615995 	 [make_candidate] session_latest_clicks2carts_pair1 : start
# 0:30:54.866861 	 [add_candidate] session_latest_clicks2carts_pair1 : start
# 0:30:56.105684 	 [make_candidate] session_latest_clicks2orders_pair1 : start
# 0:30:56.345643 	 [add_candidate] session_latest_clicks2orders_pair1 : start
# 0:30:57.562852 	 [make_candidate] session_latest_type_wt_pair2 : start
# 0:30:57.906441 	 [add_candidate] session_latest_type_wt_pair2 : start
# 0:30:59.172919 	 [make_candidate] session_latest_clicks2carts_pair2 : start
# 0:30:59.372058 	 [add_candidate] session_latest_clicks2carts_pair2 : start
# 0:31:00.664260 	 [make_candidate] session_latest_clicks2orders_pair2 : start
# 0:31:00.885921 	 [add_candidate] session_latest_clicks2orders_pair2 : start
# 0:31:02.184612 	 [make_candidate] session_latest_type_wt_pair3 : start
# 0:31:02.619082 	 [add_candidate] session_latest_type_wt_pair3 : start
# 0:31:03.998967 	 [make_candidate] session_latest_clicks2carts_pair3 : start
# 0:31:04.357195 	 [add_candidate] session_latest_clicks2carts_pair3 : start
# 0:31:05.726731 	 [make_candidate] session_latest_clicks2orders_pair3 : start
# 0:31:05.975496 	 [add_candidate] session_latest_clicks2orders_pair3 : start
# 0:31:07.280548 	 [make_candidate] session_latest_type_wt_pair4 : start
# 0:31:07.715896 	 [add_candidate] session_latest_type_wt_pair4 : start
# 0:31:09.038781 	 [make_candidate] session_latest_clicks2carts_pair4 : start
# 0:31:09.471193 	 [add_candidate] session_latest_clicks2carts_pair4 : start
# 0:31:10.788999 	 [make_candidate] session_latest_clicks2orders_pair4 : start
# 0:31:10.955688 	 [add_candidate] session_latest_clicks2orders_pair4 : start
# Memory usage of dataframe is 212.81 MB
# Memory usage after optimization is: 141.87 MB
# Decreased by 33.3%
# 0:31:14.872776 	 make orders_valid_data
# 0:31:14.927069 	 [features] prep : start
# 0:31:14.935458 	 [features] session_cnt : start
# 0:31:18.292759 	 [features] session_aid_nunique : start
# 0:31:19.233942 	 [features] session_last_type : start
# 0:31:20.169306 	 [features] aid_cnt : start
# Memory usage of dataframe is 1950.72 MB
# Memory usage after optimization is: 653.18 MB
# Decreased by 66.5%
# /home/kaggler/.local/lib/python3.8/site-packages/lightgbm/engine.py:181: UserWarning: 'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. Pass 'early_stopping()' callback via 'callbacks' argument instead.
#   _log_warning("'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. "
# /home/kaggler/.local/lib/python3.8/site-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# [LightGBM] [Info] Number of positive: 578003, number of negative: 578003
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.036881 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 5361
# [LightGBM] [Info] Number of data points in the train set: 1156006, number of used features: 28
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500000 -> initscore=0.000000
# Training until validation scores don't improve for 100 rounds
# [100]	training's binary_logloss: 0.241614	valid_1's binary_logloss: 0.21502
# [200]	training's binary_logloss: 0.238187	valid_1's binary_logloss: 0.214499
# [300]	training's binary_logloss: 0.235766	valid_1's binary_logloss: 0.214493
# Early stopping, best iteration is:
# [236]	training's binary_logloss: 0.237202	valid_1's binary_logloss: 0.214427
# 0:32:35.952044 	 orders valid score
# 0:32:35.953424 	 {'num_clicks': 97136, 'hit_clicks': 36076, 'num_carts': 43211, 'hit_carts': 12523, 'num_orders': 20082, 'hit_orders': 11192, 'recall_clicks': '0.371', 'recall_carts': '0.290', 'recall_orders': '0.557', 'w_recall_clicks': '0.037', 'w_recall_carts': '0.087', 'w_recall_orders': '0.334', 'score': '0.458'}
# 0:32:52.371809 	 [make_test] make_cand_df
# 0:32:52.725980 	 [make_candidate] session_frequent : start
# 0:32:53.272119 	 [add_candidate] session_frequent : start
# 0:32:53.905011 	 [make_candidate] session_latest : start
# 0:32:54.244912 	 [add_candidate] session_latest : start
# 0:32:55.233735 	 [make_candidate] session_latest_time_wt_pair0 : start
# 0:32:55.780059 	 [add_candidate] session_latest_time_wt_pair0 : start
# 0:32:57.059811 	 [make_candidate] session_latest_word2vec_pair0 : start
# 0:32:57.625311 	 [add_candidate] session_latest_word2vec_pair0 : start
# 0:32:59.114180 	 [make_candidate] session_latest_pair0 : start
# 0:32:59.870027 	 [add_candidate] session_latest_pair0 : start
# 0:33:01.623828 	 [make_candidate] session_latest_time_wt_pair1 : start
# 0:33:02.397569 	 [add_candidate] session_latest_time_wt_pair1 : start
# 0:33:04.954018 	 [make_candidate] session_latest_word2vec_pair1 : start
# 0:33:05.678468 	 [add_candidate] session_latest_word2vec_pair1 : start
# 0:33:08.380509 	 [make_candidate] session_latest_pair1 : start
# 0:33:09.165748 	 [add_candidate] session_latest_pair1 : start
# 0:33:12.125100 	 [make_candidate] session_latest_time_wt_pair2 : start
# 0:33:12.873929 	 [add_candidate] session_latest_time_wt_pair2 : start
# 0:33:15.947355 	 [make_candidate] session_latest_word2vec_pair2 : start
# 0:33:16.653206 	 [add_candidate] session_latest_word2vec_pair2 : start
# 0:33:20.083461 	 [make_candidate] session_latest_pair2 : start
# 0:33:20.870770 	 [add_candidate] session_latest_pair2 : start
# 0:33:24.609077 	 [make_candidate] session_latest_time_wt_pair3 : start
# 0:33:25.560083 	 [add_candidate] session_latest_time_wt_pair3 : start
# 0:33:30.845746 	 [make_candidate] session_latest_word2vec_pair3 : start
# 0:33:31.826045 	 [add_candidate] session_latest_word2vec_pair3 : start
# 0:33:37.342820 	 [make_candidate] session_latest_pair3 : start
# 0:33:38.215482 	 [add_candidate] session_latest_pair3 : start
# 0:33:43.626093 	 [make_candidate] session_latest_time_wt_pair4 : start
# 0:33:44.611420 	 [add_candidate] session_latest_time_wt_pair4 : start
# 0:33:50.530637 	 [make_candidate] session_latest_word2vec_pair4 : start
# 0:33:51.475430 	 [add_candidate] session_latest_word2vec_pair4 : start
# 0:33:57.448024 	 [make_candidate] session_latest_pair4 : start
# 0:33:58.464435 	 [add_candidate] session_latest_pair4 : start
# 0:34:04.536817 	 [make_candidate] session_latest_time_wt_pair5 : start
# 0:34:05.448044 	 [add_candidate] session_latest_time_wt_pair5 : start
# 0:34:11.918888 	 [make_candidate] session_latest_word2vec_pair5 : start
# 0:34:12.862156 	 [add_candidate] session_latest_word2vec_pair5 : start
# 0:34:19.133193 	 [make_candidate] session_latest_pair5 : start
# 0:34:20.214497 	 [add_candidate] session_latest_pair5 : start
# 0:34:27.091899 	 [make_candidate] session_latest_time_wt_pair6 : start
# 0:34:28.070689 	 [add_candidate] session_latest_time_wt_pair6 : start
# 0:34:35.049772 	 [make_candidate] session_latest_word2vec_pair6 : start
# 0:34:36.056787 	 [add_candidate] session_latest_word2vec_pair6 : start
# 0:34:43.466005 	 [make_candidate] session_latest_pair6 : start
# 0:34:44.442994 	 [add_candidate] session_latest_pair6 : start
# 0:34:51.647817 	 [make_candidate] session_latest_time_wt_pair7 : start
# 0:34:52.651922 	 [add_candidate] session_latest_time_wt_pair7 : start
# 0:35:00.449933 	 [make_candidate] session_latest_word2vec_pair7 : start
# 0:35:01.457189 	 [add_candidate] session_latest_word2vec_pair7 : start
# 0:35:12.233342 	 [make_candidate] session_latest_pair7 : start
# 0:35:13.247473 	 [add_candidate] session_latest_pair7 : start
# 0:35:24.015852 	 [make_candidate] session_latest_time_wt_pair8 : start
# 0:35:25.018817 	 [add_candidate] session_latest_time_wt_pair8 : start
# 0:35:35.973065 	 [make_candidate] session_latest_word2vec_pair8 : start
# 0:35:37.033775 	 [add_candidate] session_latest_word2vec_pair8 : start
# 0:35:48.757424 	 [make_candidate] session_latest_pair8 : start
# 0:35:49.840563 	 [add_candidate] session_latest_pair8 : start
# 0:36:01.285146 	 [make_candidate] session_latest_time_wt_pair9 : start
# 0:36:02.412038 	 [add_candidate] session_latest_time_wt_pair9 : start
# 0:36:14.297930 	 [make_candidate] session_latest_word2vec_pair9 : start
# 0:36:15.424000 	 [add_candidate] session_latest_word2vec_pair9 : start
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In [21], line 2
#       1 try:
# ----> 2     main()
#       3 except Exception as e:
#       4     logger.error(traceback.format_exc())
#
# Cell In [20], line 85, in main()
#      83     test = pd.read_pickle(cache_path)
#      84 else:
# ---> 85     test = make_test_data()
#      86     test.to_pickle(cache_path)
#      88 logger.info(f"-------- inference --------")
#
# Cell In [18], line 13, in make_test_data()
#      11 # 候補選出
#      12 logger.info("[make_test] make_cand_df")
# ---> 13 cand_df = make_cand_df(test_sessions, trans_maps=trans_maps)
#      14 cand_df = reduce_mem_usage(cand_df)
#      15 # 特徴量付与
#
# Cell In [12], line 14, in make_cand_df(sessions, labels, trans_maps)
#      12 for i in range(20):
#      13     cand.add(strategy="session_latest", trans_map=trans_maps[f"time_wt_pair{str(i)}"], name=f"session_latest_time_wt_pair{str(i)}", k=5)
# ---> 14     cand.add(strategy="session_latest", trans_map=trans_maps[f"word2vec_pair{str(i)}"], name=f"session_latest_word2vec_pair{str(i)}", k=5)
#      15     cand.add(strategy="session_latest", trans_map=trans_maps[f"pair{str(i)}"], name=f"session_latest_pair{str(i)}", k=5)
#      16 for i in range(5):
#
# Cell In [6], line 49, in Candidate.add(self, strategy, name, usetypes, trans_map, k)
#      46     candidate_df["aid"] = candidate_df["aid"].map(trans_map)
#      47     candidate_df = candidate_df.dropna(subset=["aid"])
# ---> 49 self._entry(candidate_df, name, k)
#
# Cell In [6], line 16, in Candidate._entry(self, new_candidate_df, name, k)
#      14 new_candidate_df = new_candidate_df.to_pandas()
#      15 self.output = pd.concat([self.output, new_candidate_df[["session", "aid"]]])
# ---> 16 self.output = self.output.drop_duplicates(subset=["session", "aid"])
#      18 if self.labels is not None:
#      19     self._eval(new_candidate_df[["session", "aid"]], name, k)
#
# File /opt/conda/lib/python3.8/site-packages/pandas/util/_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File /opt/conda/lib/python3.8/site-packages/pandas/core/frame.py:6125, in DataFrame.drop_duplicates(self, subset, keep, inplace, ignore_index)
#    6123 inplace = validate_bool_kwarg(inplace, "inplace")
#    6124 ignore_index = validate_bool_kwarg(ignore_index, "ignore_index")
# -> 6125 duplicated = self.duplicated(subset, keep=keep)
#    6127 result = self[-duplicated]
#    6128 if ignore_index:
#
# File /opt/conda/lib/python3.8/site-packages/pandas/core/frame.py:6264, in DataFrame.duplicated(self, subset, keep)
#    6261 vals = (col.values for name, col in self.items() if name in subset)
#    6262 labels, shape = map(list, zip(*map(f, vals)))
# -> 6264 ids = get_group_index(
#    6265     labels,
#    6266     # error: Argument 1 to "tuple" has incompatible type "List[_T]";
#    6267     # expected "Iterable[int]"
#    6268     tuple(shape),  # type: ignore[arg-type]
#    6269     sort=False,
#    6270     xnull=False,
#    6271 )
#    6272 result = self._constructor_sliced(duplicated(ids, keep), index=self.index)
#    6273 return result.__finalize__(self, method="duplicated")
#
# File /opt/conda/lib/python3.8/site-packages/pandas/core/sorting.py:173, in get_group_index(labels, shape, sort, xnull)
#     171     else:
#     172         stride //= lshape[i]
# --> 173     out += labels[i] * stride
#     175 if xnull:  # exclude nulls
#     176     mask = labels[0] == -1
#
# KeyboardInterrupt:
