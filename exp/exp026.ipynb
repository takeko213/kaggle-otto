# %% [markdown]
# # exp026
# 重みでリランク版

# %%
import os
import sys
import traceback
import gc
import random
import pickle
import pathlib
import subprocess
from dataclasses import dataclass
from dotenv import load_dotenv
load_dotenv
sys.path.append(os.getenv('UTILS_PATH'))
from tqdm import tqdm
import multiprocessing
import inspect

import pandas as pd
import numpy as np
import itertools
import cudf
import lightgbm as lgb
import matplotlib.pyplot as plt
import seaborn as sns
import line_notify
import my_logger
from noglobal import noglobal
import optuna

# %% [markdown]
# # 設定

# %%
@dataclass
class Cfg:
    loglevel = "INFO"
    exp_name = "exp026"
    seed = 42
    k = 20
    type2id = {"clicks":0, "carts":1, "orders":2}
    id2type = {0:"clicks", 1:"carts", 2:"orders"}
    train_weeks = ["week3"]
    valid_week = "week4"
    valid_session_n = 100_000
    input_dir = os.getenv('INPUT_DIR')
    output_dir = os.getenv('OUTPUT_DIR')
    prep_dir = os.getenv("PREP_DIR")

cfg = Cfg()
os.makedirs(os.path.join(cfg.output_dir, cfg.exp_name), exist_ok=True)
os.makedirs(os.path.join(cfg.output_dir, cfg.exp_name, "cache"), exist_ok=True)
random.seed(cfg.seed)

logger = my_logger.init_logger(cfg.exp_name)

# %%
@noglobal(excepts=["cfg", "logger"])
def evaluate(clicks_labels, carts_labels, orders_labels, 
             clicks_preds, carts_preds, orders_preds, k=20):

    num_clicks = 0
    num_carts = 0
    num_orders = 0
    hit_clicks = 0
    hit_carts = 0
    hit_orders = 0

    for i in range(len(clicks_labels)):
        clicks_label = clicks_labels[i]
        carts_label = carts_labels[i]
        orders_label = orders_labels[i]
        clicks_pred = clicks_preds[i]
        carts_pred = carts_preds[i]
        orders_pred = orders_preds[i]

        if type(clicks_pred) == list:
            clicks_pred = clicks_pred[:k]
        else:
            clicks_pred = []
        if type(carts_pred) == list:
            carts_pred = carts_pred[:k]
        else:
            carts_pred = []    
        if type(orders_pred) == list:
            orders_pred = orders_pred[:k]
        else:
            orders_pred = []

        if not np.isnan(clicks_label):
            num_clicks += 1
            hit_clicks += int(clicks_label in clicks_pred)

        if type(carts_label) == list:
            num_carts += min(len(carts_label), k)
            hit_carts += len(set(carts_pred) & set(carts_label))
            
        if type(orders_label) == list:
            num_orders += min(len(orders_label), k)
            hit_orders += len(set(orders_pred) & set(orders_label))


    recall_clicks = hit_clicks / num_clicks
    recall_carts = hit_carts / num_carts
    recall_orders = hit_orders / num_orders
    w_recall_clicks = recall_clicks * 0.10
    w_recall_carts = recall_carts * 0.30
    w_recall_orders = recall_orders * 0.60
    score = w_recall_clicks + w_recall_carts + w_recall_orders

    results = {}
    results["num_clicks"] = num_clicks
    results["hit_clicks"] = hit_clicks
    results["num_carts"] = num_carts
    results["hit_carts"] = hit_carts
    results["num_orders"] = num_orders
    results["hit_orders"] = hit_orders
    results["recall_clicks"] = format(recall_clicks, ".3f")
    results["recall_carts"] = format(recall_carts, ".3f")
    results["recall_orders"] = format(recall_orders, ".3f")
    results["w_recall_clicks"] = format(w_recall_clicks, ".3f")
    results["w_recall_carts"] = format(w_recall_carts, ".3f")
    results["w_recall_orders"] = format(w_recall_orders, ".3f")
    results["score"] = format(score, ".3f")

    return results

# %%
class Candidate:
    @noglobal(excepts=["cfg", "logger"])
    def __init__(self, pdf, labels=None):
        self.df = cudf.from_pandas(pdf)
        self.target_sessions = pdf["session"].unique().tolist()
        self.results = pd.DataFrame(columns=["name", "num_clicks", "hit_clicks", "num_carts", "hit_carts", "num_orders", "hit_orders", 
                                             "recall_clicks", "recall_carts", "recall_orders", "w_recall_clicks", "w_recall_carts", "w_recall_orders", "score"])
        self.output = pd.DataFrame(columns=["session", "aid", "strategy", "rank"], dtype=int)
        self.labels = labels
    
    @noglobal(excepts=["cfg", "logger"])
    def _entry(self, new_candidate_df, name, k):
        logger.info(f"[add_candidate] {name} : start")
        new_candidate_df["strategy"] = name
        new_candidate_df[f"rank"] = new_candidate_df.groupby("session")["session"].cumcount() + 1
        new_candidate_df = new_candidate_df.to_pandas()
        self.output = pd.concat([self.output, new_candidate_df[["session", "aid", "strategy", "rank"]]])

        if self.labels is not None:
            self._eval(new_candidate_df[["session", "aid"]], name, k)
    
    @noglobal(excepts=["cfg", "logger"])
    def _eval(self, new_candidate_df, name, k):
        new_candidate_df = new_candidate_df.groupby("session")["aid"].apply(list).reset_index()
        eval_df = pd.DataFrame(self.target_sessions, columns=["session"])
        eval_df = eval_df.merge(new_candidate_df, on=["session"], how="left")
        assert eval_df["session"].tolist() == self.labels["session"].tolist()
        eval_result = evaluate(self.labels["clicks_labels"].tolist(), self.labels["carts_labels"].tolist(), self.labels["orders_labels"].tolist(),
                               eval_df["aid"].tolist(), eval_df["aid"].tolist(), eval_df["aid"].tolist(), k)
        
        logger.info(str(eval_result))
        self.results = pd.concat([self.results, pd.DataFrame([[name] + list(eval_result.values())], columns=["name"] + list(eval_result.keys()))])

    @noglobal(excepts=["cfg", "logger"])
    def add(self, strategy, name, usetypes=['clicks', 'carts', 'orders'], trans_map=None, k=20):
        logger.info(f"[make_candidate] {name} : start")
        candidate_df = self.df[self.df["type"].isin(usetypes)].copy()
        
        if strategy == "session_frequent":
            candidate_df = self._session_frequent(candidate_df, k)
        elif strategy == "session_latest":
            candidate_df = self._session_latest(candidate_df, k)
        elif strategy == "total_frequent":
            candidate_df = self._total_frequent(candidate_df, k)
        
        if trans_map is not None:
            candidate_df["aid"] = candidate_df["aid"].map(trans_map)
            candidate_df = candidate_df.dropna(subset=["aid"])
            
        self._entry(candidate_df, name, k)

    @noglobal(excepts=["cfg", "logger"])
    def _session_frequent(self, candidate_df, k):
        candidate_df = candidate_df.groupby(["session", "aid"])["ts"].count().reset_index()
        candidate_df.columns = ["session", "aid", "aid_count"]
        candidate_df = candidate_df.sort_values(["session", "aid_count", "aid"], ascending=(True, False, True))
        candidate_df = candidate_df[candidate_df.groupby("session")["aid_count"].cumcount() < k].copy()
        candidate_df = candidate_df[["session", "aid"]].copy()
        return candidate_df

    @noglobal(excepts=["cfg", "logger"])
    def _session_latest(self, candidate_df, k):
        candidate_df = candidate_df.sort_values(["session", "ts"], ascending=(True, False)).drop_duplicates(subset=["session", "aid"])
        candidate_df = candidate_df.sort_values(["session", "ts"], ascending=(True, False))[candidate_df.groupby("session")["ts"].cumcount() < k].copy()
        candidate_df = candidate_df[["session", "aid"]].copy()
        return candidate_df

    @noglobal(excepts=["cfg", "logger"])
    def _total_frequent(self, candidate_df, k):
        candidate_df = candidate_df.groupby("aid")["ts"].count().reset_index()
        candidate_df.columns = ["aid", "aid_count"]
        topk_freq_aids = candidate_df.sort_values("aid_count", ascending=False)["aid"].to_arrow().to_pylist()[:k]
        sessions = []
        aids = []
        for session, aid in itertools.product(self.target_sessions, topk_freq_aids):
            sessions.append(session)
            aids.append(aid)
        candidate_df = cudf.DataFrame({"session": sessions, "aid": aids})
        return candidate_df

# %%
@noglobal(excepts=["cfg", "logger"])
def make_cand_df(sessions, labels=None, trans_maps=None):

    if labels is not None:
         cand = Candidate(sessions, labels)
    else:
        cand = Candidate(sessions)

    cand.add(strategy="session_frequent", name="session_frequent")
    cand.add(strategy="session_latest", name="session_latest")
    cand.add(strategy="total_frequent", name="total_frequent")
    cand.add(strategy="session_frequent", trans_map=trans_maps["pair0"], name="session_frequent_pair")
    
    for i in range(5):
        cand.add(strategy="session_latest", trans_map=trans_maps[f"pair{str(i)}"], name=f"session_latest_pair{str(i)}")
      
    cand.add(strategy="session_frequent", trans_map=trans_maps["clicks_pair"], name="session_frequent_clicks_pair")
    cand.add(strategy="session_latest", trans_map=trans_maps["clicks_pair"], name="session_latest_clicks_pair")
    # cand.add(strategy="session_frequent", trans_map=trans_maps["carts_pair"], name="session_frequent_carts_pair")
    cand.add(strategy="session_latest", trans_map=trans_maps["carts_pair"], name="session_latest_carts_pair")
    cand.add(strategy="session_latest", trans_map=trans_maps["time_wt_pair"], name="session_latest_time_wt_pair")
    cand.add(strategy="session_latest", trans_map=trans_maps["clicks_carts_pair"], name="session_latest_clicks_carts_pair")
    cand.add(strategy="session_latest", trans_map=trans_maps["clicks_orders_pair"], name="session_latest_clicks_orders_pair")
    # cand.add(strategy="session_frequent", trans_map=trans_maps["orders_pair"], name="session_frequent_orders_pair")
    # cand.add(strategy="session_latest", trans_map=trans_maps["orders_pair"], name="session_latest_orders_pair")
    if labels is not None:
        return cand.output, cand.results
    else:
        return cand.output

# %%
@noglobal(excepts=["cfg", "logger"])
def get_trans_maps():
    """
    aidを別のaidに置き換えるmapping辞書を取得する
    """
    trans_maps = {}
    pair_df_org = pd.read_pickle(cfg.prep_dir + "co_visitation_matrix.pkl")
    pair_df_org = pair_df_org[pair_df_org["cnt"] > 3].copy()
    pair_df_org = pair_df_org.sort_values(["aid_x", "cnt"], ascending=(True, False))

    for i in range(5):
        pair_df = pair_df_org.groupby("aid_x").nth(i).reset_index()[["aid_x", "aid_y"]]
        pair_dict = {k: v for k, v in zip(pair_df["aid_x"].tolist(), pair_df["aid_y"].tolist())}
        trans_maps[f"pair{str(i)}"] = pair_dict

    pair_df = pd.read_pickle(cfg.prep_dir + "co_visitation_matrix_clicks.pkl")
    pair_df = pair_df[pair_df["cnt"] > 3].copy()
    pair_df = pair_df.sort_values(["aid_x", "cnt"], ascending=(True, False))
    pair_df = pair_df.groupby("aid_x").head(1)[["aid_x", "aid_y"]]
    pair_dict = {k: v for k, v in zip(pair_df["aid_x"].tolist(), pair_df["aid_y"].tolist())}
    trans_maps["clicks_pair"] = pair_dict

    pair_df = pd.read_pickle(cfg.prep_dir + "co_visitation_matrix_carts.pkl")
    pair_df = pair_df[pair_df["cnt"] > 3].copy()
    pair_df = pair_df.sort_values(["aid_x", "cnt"], ascending=(True, False))
    pair_df = pair_df.groupby("aid_x").head(1)[["aid_x", "aid_y"]]
    pair_dict = {k: v for k, v in zip(pair_df["aid_x"].tolist(), pair_df["aid_y"].tolist())}
    trans_maps["carts_pair"] = pair_dict

    pair_df = pd.read_pickle(cfg.prep_dir + "co_visitation_matrix_orders.pkl")
    pair_df = pair_df[pair_df["cnt"] > 3].copy()
    pair_df = pair_df.sort_values(["aid_x", "cnt"], ascending=(True, False))
    pair_df = pair_df.groupby("aid_x").head(1)[["aid_x", "aid_y"]]
    pair_dict = {k: v for k, v in zip(pair_df["aid_x"].tolist(), pair_df["aid_y"].tolist())}
    trans_maps["orders_pair"] = pair_dict

    pair_df = pd.read_pickle(cfg.prep_dir + "co_visitation_matrix_time_weighted.pkl")
    pair_df = pair_df.sort_values(["aid_x", "wt"], ascending=(True, False))
    pair_df = pair_df.groupby("aid_x").head(1)[["aid_x", "aid_y"]]
    pair_dict = {k: v for k, v in zip(pair_df["aid_x"].tolist(), pair_df["aid_y"].tolist())}
    trans_maps["time_wt_pair"] = pair_dict

    pair_df = pd.read_pickle(cfg.prep_dir + "co_visitation_matrix_clicks_carts.pkl")
    pair_df = pair_df.sort_values(["aid_x", "cnt"], ascending=(True, False))
    pair_df = pair_df.groupby("aid_x").head(1)[["aid_x", "aid_y"]]
    pair_dict = {k: v for k, v in zip(pair_df["aid_x"].tolist(), pair_df["aid_y"].tolist())}
    trans_maps["clicks_carts_pair"] = pair_dict

    pair_df = pd.read_pickle(cfg.prep_dir + "co_visitation_matrix_clicks_orders.pkl")
    pair_df = pair_df.sort_values(["aid_x", "cnt"], ascending=(True, False))
    pair_df = pair_df.groupby("aid_x").head(1)[["aid_x", "aid_y"]]
    pair_dict = {k: v for k, v in zip(pair_df["aid_x"].tolist(), pair_df["aid_y"].tolist())}
    trans_maps["clicks_orders_pair"] = pair_dict

    return trans_maps

# %%
class Cache:
    @noglobal(excepts=["cfg", "logger"])
    def __init__(self):
        self.cache_dir = (os.path.join(cfg.output_dir, cfg.exp_name, "cache"))
        self.cache_dir_path = pathlib.Path(self.cache_dir)
        self.caches = list(self.cache_dir_path.glob("*.pkl"))

    @noglobal(excepts=["cfg", "logger"])
    def get_abspath(self, filename):
        return (os.path.join(self.cache_dir, f"{cfg.exp_name}_{filename}"))
    
    @noglobal(excepts=["cfg", "logger"])
    def exists(self, path):
        return len([str(c) for c in self.caches if path == str(c)]) > 0

# %%
@noglobal(excepts=["cfg", "logger"])
def make_valid_data(trans_maps):
    valid_week = cfg.valid_week
    dfs = []
    
    logger.info(f"[make_valid] valid_week : {valid_week}")
    # データ読み込み
    logger.info("[make_valid] read_data : start")
    week_sessions = pd.read_pickle(os.getenv("PREP_DIR") + f"train_sessions_{valid_week}.pkl")
    week_labels = pd.read_pickle(os.getenv("PREP_DIR") + f"labels_{valid_week}.pkl")
    valid_session_ids = week_sessions["session"].unique().tolist()
    logger.info("[make_valid] read_data : end")

    # validに使うsessionを絞る (trainに存在するsessionを除外した上で設定した数に絞る)
    logger.info("[make_valid] valid_session_extract : start")
    valid_session_n = min(cfg.valid_session_n, len(valid_session_ids))
    valid_session_ids = random.sample(valid_session_ids, valid_session_n)
    week_sessions = week_sessions[week_sessions["session"].isin(valid_session_ids)].copy()
    week_labels = week_labels[week_labels["session"].isin(valid_session_ids)].copy()
    logger.info("[make_valid] valid_session_extract : end")

    # 候補選出
    logger.info("[make_valid] make_cand_df : start")
    valid, results = make_cand_df(week_sessions, labels=week_labels, trans_maps=trans_maps)

    return valid, week_labels, results

# %%
@noglobal(excepts=["cfg", "logger"])
def make_test_data(trans_maps):
    # testデータ作成
    test_sessions = pd.read_pickle(cfg.prep_dir + f"test_sessions.pkl")

    dfs =[]
    # 候補選出
    logger.info("[make_test] make_cand_df")
    test = make_cand_df(test_sessions, trans_maps=trans_maps)
    return test

# %%
logger.info(f"START")
line_notify.send(f"{cfg.exp_name} | START")

cache = Cache()

logger.info(f"-------- get_trans_maps --------")
cache_path = cache.get_abspath("trans_maps.pkl")
if cache.exists(cache_path):
    logger.info("cache exists. load cache and skip process.")
    with open(cache_path, "rb") as f:
        trans_maps = pickle.load(f)
else:
    trans_maps = get_trans_maps()
    with open(cache_path, "wb") as f:
        pickle.dump(trans_maps, f)

valid, valid_labels, results = make_valid_data(trans_maps)
# Out:
# 0:00:00.416243 	 START
# 0:00:00.575472 	 -------- get_trans_maps --------
# 0:00:00.576498 	 cache exists. load cache and skip process.
# 0:00:02.670026 	 [make_valid] valid_week : week4
# 0:00:02.671369 	 [make_valid] read_data : start
# 0:00:09.128151 	 [make_valid] read_data : end
# 0:00:09.129356 	 [make_valid] valid_session_extract : start
# 0:00:10.054033 	 [make_valid] valid_session_extract : end
# 0:00:10.055300 	 [make_valid] make_cand_df : start
# 0:00:10.104835 	 [make_candidate] session_frequent : start
# 0:00:10.340491 	 [add_candidate] session_frequent : start
# 0:00:11.999415 	 {'num_clicks': 97136, 'hit_clicks': 29631, 'num_carts': 43211, 'hit_carts': 10937, 'num_orders': 20082, 'hit_orders': 10387, 'recall_clicks': '0.305', 'recall_carts': '0.253', 'recall_orders': '0.517', 'w_recall_clicks': '0.031', 'w_recall_carts': '0.076', 'w_recall_orders': '0.310', 'score': '0.417'}
# 0:00:12.016176 	 [make_candidate] session_latest : start
# 0:00:12.287236 	 [add_candidate] session_latest : start
# 0:00:13.835775 	 {'num_clicks': 97136, 'hit_clicks': 29762, 'num_carts': 43211, 'hit_carts': 10988, 'num_orders': 20082, 'hit_orders': 10168, 'recall_clicks': '0.306', 'recall_carts': '0.254', 'recall_orders': '0.506', 'w_recall_clicks': '0.031', 'w_recall_carts': '0.076', 'w_recall_orders': '0.304', 'score': '0.411'}
# 0:00:13.847027 	 [make_candidate] total_frequent : start
# 0:00:14.266415 	 [add_candidate] total_frequent : start
# 0:00:16.142418 	 {'num_clicks': 97136, 'hit_clicks': 1392, 'num_carts': 43211, 'hit_carts': 617, 'num_orders': 20082, 'hit_orders': 112, 'recall_clicks': '0.014', 'recall_carts': '0.014', 'recall_orders': '0.006', 'w_recall_clicks': '0.001', 'w_recall_carts': '0.004', 'w_recall_orders': '0.003', 'score': '0.009'}
# 0:00:16.175711 	 [make_candidate] session_frequent_pair : start
# 0:00:16.586418 	 [add_candidate] session_frequent_pair : start
# 0:00:18.675318 	 {'num_clicks': 97136, 'hit_clicks': 7719, 'num_carts': 43211, 'hit_carts': 3394, 'num_orders': 20082, 'hit_orders': 2563, 'recall_clicks': '0.079', 'recall_carts': '0.079', 'recall_orders': '0.128', 'w_recall_clicks': '0.008', 'w_recall_carts': '0.024', 'w_recall_orders': '0.077', 'score': '0.108'}
# 0:00:18.688178 	 [make_candidate] session_latest_pair0 : start
# 0:00:19.201981 	 [add_candidate] session_latest_pair0 : start
# 0:00:20.807373 	 {'num_clicks': 97136, 'hit_clicks': 7761, 'num_carts': 43211, 'hit_carts': 3395, 'num_orders': 20082, 'hit_orders': 2555, 'recall_clicks': '0.080', 'recall_carts': '0.079', 'recall_orders': '0.127', 'w_recall_clicks': '0.008', 'w_recall_carts': '0.024', 'w_recall_orders': '0.076', 'score': '0.108'}
# 0:00:20.820671 	 [make_candidate] session_latest_pair1 : start
# 0:00:21.272734 	 [add_candidate] session_latest_pair1 : start
# 0:00:22.889224 	 {'num_clicks': 97136, 'hit_clicks': 5561, 'num_carts': 43211, 'hit_carts': 2790, 'num_orders': 20082, 'hit_orders': 1967, 'recall_clicks': '0.057', 'recall_carts': '0.065', 'recall_orders': '0.098', 'w_recall_clicks': '0.006', 'w_recall_carts': '0.019', 'w_recall_orders': '0.059', 'score': '0.084'}
# 0:00:22.901803 	 [make_candidate] session_latest_pair2 : start
# 0:00:23.206135 	 [add_candidate] session_latest_pair2 : start
# 0:00:25.322076 	 {'num_clicks': 97136, 'hit_clicks': 4430, 'num_carts': 43211, 'hit_carts': 2395, 'num_orders': 20082, 'hit_orders': 1808, 'recall_clicks': '0.046', 'recall_carts': '0.055', 'recall_orders': '0.090', 'w_recall_clicks': '0.005', 'w_recall_carts': '0.017', 'w_recall_orders': '0.054', 'score': '0.075'}
# 0:00:25.334675 	 [make_candidate] session_latest_pair3 : start
# 0:00:25.764637 	 [add_candidate] session_latest_pair3 : start
# 0:00:27.361168 	 {'num_clicks': 97136, 'hit_clicks': 3722, 'num_carts': 43211, 'hit_carts': 2083, 'num_orders': 20082, 'hit_orders': 1568, 'recall_clicks': '0.038', 'recall_carts': '0.048', 'recall_orders': '0.078', 'w_recall_clicks': '0.004', 'w_recall_carts': '0.014', 'w_recall_orders': '0.047', 'score': '0.065'}
# 0:00:27.374173 	 [make_candidate] session_latest_pair4 : start
# 0:00:27.889951 	 [add_candidate] session_latest_pair4 : start
# 0:00:29.593098 	 {'num_clicks': 97136, 'hit_clicks': 3158, 'num_carts': 43211, 'hit_carts': 1876, 'num_orders': 20082, 'hit_orders': 1410, 'recall_clicks': '0.033', 'recall_carts': '0.043', 'recall_orders': '0.070', 'w_recall_clicks': '0.003', 'w_recall_carts': '0.013', 'w_recall_orders': '0.042', 'score': '0.058'}
# 0:00:29.607120 	 [make_candidate] session_frequent_clicks_pair : start
# 0:00:30.054338 	 [add_candidate] session_frequent_clicks_pair : start
# 0:00:31.706317 	 {'num_clicks': 97136, 'hit_clicks': 7706, 'num_carts': 43211, 'hit_carts': 2878, 'num_orders': 20082, 'hit_orders': 1963, 'recall_clicks': '0.079', 'recall_carts': '0.067', 'recall_orders': '0.098', 'w_recall_clicks': '0.008', 'w_recall_carts': '0.020', 'w_recall_orders': '0.059', 'score': '0.087'}
# 0:00:31.719667 	 [make_candidate] session_latest_clicks_pair : start
# 0:00:32.234938 	 [add_candidate] session_latest_clicks_pair : start
# 0:00:34.386578 	 {'num_clicks': 97136, 'hit_clicks': 7746, 'num_carts': 43211, 'hit_carts': 2892, 'num_orders': 20082, 'hit_orders': 1955, 'recall_clicks': '0.080', 'recall_carts': '0.067', 'recall_orders': '0.097', 'w_recall_clicks': '0.008', 'w_recall_carts': '0.020', 'w_recall_orders': '0.058', 'score': '0.086'}
# 0:00:34.401035 	 [make_candidate] session_latest_carts_pair : start
# 0:00:34.756110 	 [add_candidate] session_latest_carts_pair : start
# 0:00:36.171335 	 {'num_clicks': 97136, 'hit_clicks': 4225, 'num_carts': 43211, 'hit_carts': 2380, 'num_orders': 20082, 'hit_orders': 1834, 'recall_clicks': '0.043', 'recall_carts': '0.055', 'recall_orders': '0.091', 'w_recall_clicks': '0.004', 'w_recall_carts': '0.017', 'w_recall_orders': '0.055', 'score': '0.076'}
# 0:00:36.182173 	 [make_candidate] session_latest_time_wt_pair : start
# 0:00:36.488750 	 [add_candidate] session_latest_time_wt_pair : start
# 0:00:38.149635 	 {'num_clicks': 97136, 'hit_clicks': 8928, 'num_carts': 43211, 'hit_carts': 2866, 'num_orders': 20082, 'hit_orders': 2121, 'recall_clicks': '0.092', 'recall_carts': '0.066', 'recall_orders': '0.106', 'w_recall_clicks': '0.009', 'w_recall_carts': '0.020', 'w_recall_orders': '0.063', 'score': '0.092'}
# 0:00:38.163852 	 [make_candidate] session_latest_clicks_carts_pair : start
# 0:00:38.494154 	 [add_candidate] session_latest_clicks_carts_pair : start
# 0:00:40.622341 	 {'num_clicks': 97136, 'hit_clicks': 4789, 'num_carts': 43211, 'hit_carts': 3195, 'num_orders': 20082, 'hit_orders': 2119, 'recall_clicks': '0.049', 'recall_carts': '0.074', 'recall_orders': '0.106', 'w_recall_clicks': '0.005', 'w_recall_carts': '0.022', 'w_recall_orders': '0.063', 'score': '0.090'}
# 0:00:40.635325 	 [make_candidate] session_latest_clicks_orders_pair : start
# 0:00:40.982544 	 [add_candidate] session_latest_clicks_orders_pair : start
# 0:00:42.536454 	 {'num_clicks': 97136, 'hit_clicks': 3102, 'num_carts': 43211, 'hit_carts': 2175, 'num_orders': 20082, 'hit_orders': 2221, 'recall_clicks': '0.032', 'recall_carts': '0.050', 'recall_orders': '0.111', 'w_recall_clicks': '0.003', 'w_recall_carts': '0.015', 'w_recall_orders': '0.066', 'score': '0.085'}

# %%
results
# Out:
#                                 name num_clicks hit_clicks num_carts  \
# 0                   session_frequent      97136      29631     43211
# 0                     session_latest      97136      29762     43211
# 0                     total_frequent      97136       1392     43211
# 0              session_frequent_pair      97136       7719     43211
# 0               session_latest_pair0      97136       7761     43211
# 0               session_latest_pair1      97136       5561     43211
# 0               session_latest_pair2      97136       4430     43211
# 0               session_latest_pair3      97136       3722     43211
# 0               session_latest_pair4      97136       3158     43211
# 0       session_frequent_clicks_pair      97136       7706     43211
# 0         session_latest_clicks_pair      97136       7746     43211
# 0          session_latest_carts_pair      97136       4225     43211
# 0        session_latest_time_wt_pair      97136       8928     43211
# 0   session_latest_clicks_carts_pair      97136       4789     43211
# 0  session_latest_clicks_orders_pair      97136       3102     43211
#
#   hit_carts num_orders hit_orders recall_clicks recall_carts recall_orders  \
# 0     10937      20082      10387         0.305        0.253         0.517
# 0     10988      20082      10168         0.306        0.254         0.506
# 0       617      20082        112         0.014        0.014         0.006
# 0      3394      20082       2563         0.079        0.079         0.128
# 0      3395      20082       2555         0.080        0.079         0.127
# 0      2790      20082       1967         0.057        0.065         0.098
# 0      2395      20082       1808         0.046        0.055         0.090
# 0      2083      20082       1568         0.038        0.048         0.078
# 0      1876      20082       1410         0.033        0.043         0.070
# 0      2878      20082       1963         0.079        0.067         0.098
# 0      2892      20082       1955         0.080        0.067         0.097
# 0      2380      20082       1834         0.043        0.055         0.091
# 0      2866      20082       2121         0.092        0.066         0.106
# 0      3195      20082       2119         0.049        0.074         0.106
# 0      2175      20082       2221         0.032        0.050         0.111
#
#   w_recall_clicks w_recall_carts w_recall_orders  score
# 0           0.031          0.076           0.310  0.417
# 0           0.031          0.076           0.304  0.411
# 0           0.001          0.004           0.003  0.009
# 0           0.008          0.024           0.077  0.108
# 0           0.008          0.024           0.076  0.108
# 0           0.006          0.019           0.059  0.084
# 0           0.005          0.017           0.054  0.075
# 0           0.004          0.014           0.047  0.065
# 0           0.003          0.013           0.042  0.058
# 0           0.008          0.020           0.059  0.087
# 0           0.008          0.020           0.058  0.086
# 0           0.004          0.017           0.055  0.076
# 0           0.009          0.020           0.063  0.092
# 0           0.005          0.022           0.063  0.090
# 0           0.003          0.015           0.066  0.085

# %%
fig, axs = plt.subplots(1, 3)
sns.heatmap(results.set_index("name")[["recall_clicks"]].astype(float),
            annot=True, linewidths=.5, fmt="1.2f", cmap="Reds", cbar=False, ax=axs[0])
sns.heatmap(results.set_index("name")[["recall_carts"]].astype(float),
            annot=True, linewidths=.5, fmt="1.2f", cmap="Reds", cbar=False, ax=axs[1], yticklabels=False)
sns.heatmap(results.set_index("name")[["recall_orders"]].astype(float),
            annot=True, linewidths=.5, fmt="1.2f", cmap="Reds", cbar=False, ax=axs[2], yticklabels=False)
plt.savefig(cfg.output_dir + f'{cfg.exp_name}/candidate_strategy_recalls.png')

# %%
# 予測値を全て使えたときのrecall
valid_all = valid.drop_duplicates(subset= ["session", "aid"])
session_cnt_max = valid_all["session"].value_counts().max()
valid_all = valid_all.groupby("session")["aid"].apply(list).reset_index()

all_results = evaluate(valid_labels["clicks_labels"].tolist(),
                       valid_labels["carts_labels"].tolist(),
                       valid_labels["orders_labels"].tolist(),
                       valid_all["aid"].tolist(),
                       valid_all["aid"].tolist(),
                       valid_all["aid"].tolist(),
                       session_cnt_max)
logger.info("all_pred_results")
logger.info(all_results)
# Out:
# 0:00:45.984101 	 all_pred_results
# 0:00:45.985343 	 {'num_clicks': 97136, 'hit_clicks': 43073, 'num_carts': 43611, 'hit_carts': 16738, 'num_orders': 20109, 'hit_orders': 12540, 'recall_clicks': '0.443', 'recall_carts': '0.384', 'recall_orders': '0.624', 'w_recall_clicks': '0.044', 'w_recall_carts': '0.115', 'w_recall_orders': '0.374', 'score': '0.534'}

# %%
def objective_type_recall(df, labels, type_):
    def objective(trial):
        trial_df = df.copy()
        session_frequent = trial.suggest_float("session_frequent", 0, 1)
        session_latest = trial.suggest_float("session_latest", 0, 1)
        total_frequent = trial.suggest_float("total_frequent", 0, 1)
        session_frequent_pair = trial.suggest_float("session_frequent_pair", 0, 1)
        session_latest_pair0 = trial.suggest_float("session_latest_pair0", 0, 1)
        session_latest_pair1 = trial.suggest_float("session_latest_pair1", 0, 1)
        session_latest_pair2 = trial.suggest_float("session_latest_pair2", 0, 1)
        session_latest_pair3 = trial.suggest_float("session_latest_pair3", 0, 1)
        session_latest_pair4 = trial.suggest_float("session_latest_pair4", 0, 1)
        session_frequent_clicks_pair  = trial.suggest_float("session_frequent_clicks_pair", 0, 1)
        session_latest_clicks_pair = trial.suggest_float("session_latest_clicks_pair", 0, 1)
        session_latest_carts_pair  = trial.suggest_float("session_latest_carts_pair", 0, 1)
        session_latest_time_wt_pair = trial.suggest_float("session_latest_time_wt_pair", 0, 1)
        session_latest_clicks_carts_pair = trial.suggest_float("session_latest_clicks_carts_pair", 0, 1)
        session_latest_clicks_orders_pair = trial.suggest_float("session_latest_clicks_orders_pair", 0, 1)

        wt_dict = {
            'session_frequent': session_frequent,
            'session_latest': session_latest, 
            'total_frequent': total_frequent,
            'session_frequent_pair': session_frequent_pair, 
            'session_latest_pair0': session_latest_pair0,
            'session_latest_pair1': session_latest_pair1, 
            'session_latest_pair2': session_latest_pair2,
            'session_latest_pair3': session_latest_pair3, 
            'session_latest_pair4': session_latest_pair4,
            'session_frequent_clicks_pair': session_frequent_clicks_pair, 
            'session_latest_clicks_pair': session_latest_clicks_pair,
            'session_latest_carts_pair': session_latest_carts_pair, 
            'session_latest_time_wt_pair': session_latest_time_wt_pair,
            'session_latest_clicks_carts_pair': session_latest_clicks_carts_pair,
            'session_latest_clicks_orders_pair': session_latest_clicks_orders_pair
        }

        trial_df["rank"] = trial_df["rank"] * trial_df["strategy"].map(wt_dict)
        trial_df = trial_df.sort_values(["session", "rank"])
        trial_df = trial_df.drop_duplicates(subset= ["session", "aid"], keep="first")
        trial_df = trial_df.groupby(["session"]).head(20)
        trial_df = trial_df.groupby("session")["aid"].apply(list).reset_index()

        result = evaluate(labels["clicks_labels"].tolist(),
                          labels["carts_labels"].tolist(),
                          labels["orders_labels"].tolist(),
                          trial_df["aid"].tolist(),
                          trial_df["aid"].tolist(),
                          trial_df["aid"].tolist(),
                          cfg.k)

        return float(result[f"recall_{type_}"])
    return objective

# %%
n_trials = 100

# %% [markdown]
# # パラメータチューニング

# %%
wt = {}
recall = {}

for type_ in ["clicks", "carts", "orders"]:
    logger.info(type_)
    study = optuna.create_study(direction="maximize")
    study.optimize(objective_type_recall(valid, valid_labels, type_), n_trials=n_trials)
    wt[type_] = study.best_params
    recall[type_] = study.best_value
    logger.info(f"{type_}_recall_best_value : {study.best_value}")

score = (recall["clicks"] * 0.1) + (recall["carts"] * 0.3) + (recall["orders"] * 0.6)
logger.info(f"SCORE : {score}")
# Out:
# 0:00:46.169728 	 clicks
# [I 2022-12-04 08:59:55,157] A new study created in memory with name: no-name-3210a494-0f97-4311-b459-b1e05459222b
# [I 2022-12-04 08:59:59,742] Trial 0 finished with value: 0.417 and parameters: {'session_frequent': 0.20652152336611285, 'session_latest': 0.15667570230911065, 'total_frequent': 0.5653565140184447, 'session_frequent_pair': 0.020041301961948088, 'session_latest_pair0': 0.03483822465902364, 'session_latest_pair1': 0.2521074174549205, 'session_latest_pair2': 0.1127127179541183, 'session_latest_pair3': 0.1025875354573057, 'session_latest_pair4': 0.44676907234349716, 'session_frequent_clicks_pair': 0.6344959843954567, 'session_latest_clicks_pair': 0.6955940076016964, 'session_latest_carts_pair': 0.48164078413069145, 'session_latest_time_wt_pair': 0.3152857138966346, 'session_latest_clicks_carts_pair': 0.1007007922625398, 'session_latest_clicks_orders_pair': 0.48520950755808634}. Best is trial 0 with value: 0.417.
# [I 2022-12-04 09:00:04,868] Trial 1 finished with value: 0.422 and parameters: {'session_frequent': 0.7428620627241291, 'session_latest': 0.09722290331353178, 'total_frequent': 0.7477650271098044, 'session_frequent_pair': 0.1403676585192455, 'session_latest_pair0': 0.7160494880055835, 'session_latest_pair1': 0.29150909832110106, 'session_latest_pair2': 0.5308374256274646, 'session_latest_pair3': 0.5528812768102944, 'session_latest_pair4': 0.3563014024594541, 'session_frequent_clicks_pair': 0.4696175020523068, 'session_latest_clicks_pair': 0.652543691336564, 'session_latest_carts_pair': 0.03584718388732422, 'session_latest_time_wt_pair': 0.0458854829888784, 'session_latest_clicks_carts_pair': 0.16721516048214524, 'session_latest_clicks_orders_pair': 0.8638884576986678}. Best is trial 1 with value: 0.422.
# [I 2022-12-04 09:00:09,483] Trial 2 finished with value: 0.399 and parameters: {'session_frequent': 0.5923807852035331, 'session_latest': 0.96729624415503, 'total_frequent': 0.688907617982963, 'session_frequent_pair': 0.5664667983314173, 'session_latest_pair0': 0.21102581207449023, 'session_latest_pair1': 0.0780825043612089, 'session_latest_pair2': 0.5207253663272091, 'session_latest_pair3': 0.40650911246608534, 'session_latest_pair4': 0.20552700007707836, 'session_frequent_clicks_pair': 0.2817267702198496, 'session_latest_clicks_pair': 0.8196812283644719, 'session_latest_carts_pair': 0.4282607578373946, 'session_latest_time_wt_pair': 0.3408551642741924, 'session_latest_clicks_carts_pair': 0.79073489695015, 'session_latest_clicks_orders_pair': 0.6878156567602765}. Best is trial 1 with value: 0.422.
# [I 2022-12-04 09:00:14,111] Trial 3 finished with value: 0.422 and parameters: {'session_frequent': 0.7351654805829506, 'session_latest': 0.17461915220501578, 'total_frequent': 0.749458017467736, 'session_frequent_pair': 0.6446831792533524, 'session_latest_pair0': 0.4967291347661835, 'session_latest_pair1': 0.8416597411068604, 'session_latest_pair2': 0.20738782980348458, 'session_latest_pair3': 0.19345112852726243, 'session_latest_pair4': 0.1452250116307604, 'session_frequent_clicks_pair': 0.9266181702069938, 'session_latest_clicks_pair': 0.20730231690504408, 'session_latest_carts_pair': 0.3701261174161057, 'session_latest_time_wt_pair': 0.7201558425598116, 'session_latest_clicks_carts_pair': 0.7244321130075897, 'session_latest_clicks_orders_pair': 0.2843561768309023}. Best is trial 1 with value: 0.422.
# [I 2022-12-04 09:00:19,195] Trial 4 finished with value: 0.398 and parameters: {'session_frequent': 0.5315090741356718, 'session_latest': 0.2588731406856948, 'total_frequent': 0.6469783600765013, 'session_frequent_pair': 0.054122768860369375, 'session_latest_pair0': 0.6761286678276192, 'session_latest_pair1': 0.19264163311199733, 'session_latest_pair2': 0.06753246133756208, 'session_latest_pair3': 0.55547552311731, 'session_latest_pair4': 0.9777172771594611, 'session_frequent_clicks_pair': 0.05774660214319116, 'session_latest_clicks_pair': 0.012372899642654867, 'session_latest_carts_pair': 0.17007765380844309, 'session_latest_time_wt_pair': 0.968273720125235, 'session_latest_clicks_carts_pair': 0.014235815524931139, 'session_latest_clicks_orders_pair': 0.6369825645859938}. Best is trial 1 with value: 0.422.
# [I 2022-12-04 09:00:23,909] Trial 5 finished with value: 0.422 and parameters: {'session_frequent': 0.9636368691844187, 'session_latest': 0.0659584087537951, 'total_frequent': 0.7252411675252545, 'session_frequent_pair': 0.29249802206470754, 'session_latest_pair0': 0.03836105426304959, 'session_latest_pair1': 0.7220017910630412, 'session_latest_pair2': 0.7735027318493823, 'session_latest_pair3': 0.9919603888052212, 'session_latest_pair4': 0.7811461281899592, 'session_frequent_clicks_pair': 0.22561860845622816, 'session_latest_clicks_pair': 0.0337065915968483, 'session_latest_carts_pair': 0.6853780217906961, 'session_latest_time_wt_pair': 0.9013530713477753, 'session_latest_clicks_carts_pair': 0.6759550085692254, 'session_latest_clicks_orders_pair': 0.3851943231737335}. Best is trial 1 with value: 0.422.
# [I 2022-12-04 09:00:28,643] Trial 6 finished with value: 0.373 and parameters: {'session_frequent': 0.6200587906053031, 'session_latest': 0.8955749696091314, 'total_frequent': 0.12977169258138788, 'session_frequent_pair': 0.7939016957724466, 'session_latest_pair0': 0.12210054625540068, 'session_latest_pair1': 0.43120816438234943, 'session_latest_pair2': 0.40232588469763564, 'session_latest_pair3': 0.7743592450460318, 'session_latest_pair4': 0.7319313126917125, 'session_frequent_clicks_pair': 0.8602770687591866, 'session_latest_clicks_pair': 0.2641082200851531, 'session_latest_carts_pair': 0.6673134118376819, 'session_latest_time_wt_pair': 0.5263110082836506, 'session_latest_clicks_carts_pair': 0.11677784710865025, 'session_latest_clicks_orders_pair': 0.32294928462448536}. Best is trial 1 with value: 0.422.
# [I 2022-12-04 09:00:33,422] Trial 7 finished with value: 0.389 and parameters: {'session_frequent': 0.5871794485032757, 'session_latest': 0.5721342198462411, 'total_frequent': 0.275288713560784, 'session_frequent_pair': 0.721478540465298, 'session_latest_pair0': 0.3541588396264065, 'session_latest_pair1': 0.8776324065022307, 'session_latest_pair2': 0.023074001223576057, 'session_latest_pair3': 0.305581968843852, 'session_latest_pair4': 0.07679424975482785, 'session_frequent_clicks_pair': 0.6280039486437371, 'session_latest_clicks_pair': 0.9441061052798821, 'session_latest_carts_pair': 0.8466366121481435, 'session_latest_time_wt_pair': 0.47884375879245333, 'session_latest_clicks_carts_pair': 0.9875214972863391, 'session_latest_clicks_orders_pair': 0.8567143163649021}. Best is trial 1 with value: 0.422.
# [I 2022-12-04 09:00:38,502] Trial 8 finished with value: 0.425 and parameters: {'session_frequent': 0.7105599193026377, 'session_latest': 0.015940331476093306, 'total_frequent': 0.9176608199984757, 'session_frequent_pair': 0.2232619977177961, 'session_latest_pair0': 0.6676936808345096, 'session_latest_pair1': 0.7073488357865689, 'session_latest_pair2': 0.5060736789790099, 'session_latest_pair3': 0.9352935624524576, 'session_latest_pair4': 0.6212959579531449, 'session_frequent_clicks_pair': 0.523332514487567, 'session_latest_clicks_pair': 0.3056060220870107, 'session_latest_carts_pair': 0.7434966658604063, 'session_latest_time_wt_pair': 0.8856245462105562, 'session_latest_clicks_carts_pair': 0.26868246828436215, 'session_latest_clicks_orders_pair': 0.5967372401979604}. Best is trial 8 with value: 0.425.
# [I 2022-12-04 09:00:43,264] Trial 9 finished with value: 0.405 and parameters: {'session_frequent': 0.8080752919551595, 'session_latest': 0.9811159892821718, 'total_frequent': 0.5295408045486718, 'session_frequent_pair': 0.21121494631198157, 'session_latest_pair0': 0.7879345413300424, 'session_latest_pair1': 0.620104085785041, 'session_latest_pair2': 0.9915209700829684, 'session_latest_pair3': 0.33109124787273625, 'session_latest_pair4': 0.5706096184141046, 'session_frequent_clicks_pair': 0.5956901198975998, 'session_latest_clicks_pair': 0.5945591735892973, 'session_latest_carts_pair': 0.607970729078954, 'session_latest_time_wt_pair': 0.5862887932292226, 'session_latest_clicks_carts_pair': 0.6160808998354198, 'session_latest_clicks_orders_pair': 0.31715675096651563}. Best is trial 8 with value: 0.425.
# [I 2022-12-04 09:00:47,979] Trial 10 finished with value: 0.413 and parameters: {'session_frequent': 0.3208701488608331, 'session_latest': 0.4062358954513098, 'total_frequent': 0.9955120888471491, 'session_frequent_pair': 0.9810649517719181, 'session_latest_pair0': 0.9630586331543682, 'session_latest_pair1': 0.9728364264517904, 'session_latest_pair2': 0.7041996299732903, 'session_latest_pair3': 0.9914922357662597, 'session_latest_pair4': 0.6511972918205909, 'session_frequent_clicks_pair': 0.35709782077189633, 'session_latest_clicks_pair': 0.38623162679988354, 'session_latest_carts_pair': 0.8843556918906701, 'session_latest_time_wt_pair': 0.7984338001815998, 'session_latest_clicks_carts_pair': 0.35181380684462904, 'session_latest_clicks_orders_pair': 0.008971025817069544}. Best is trial 8 with value: 0.425.
# [I 2022-12-04 09:00:53,108] Trial 11 finished with value: 0.419 and parameters: {'session_frequent': 0.8882416634656081, 'session_latest': 0.055133544689679424, 'total_frequent': 0.9874235170401262, 'session_frequent_pair': 0.3420401640184473, 'session_latest_pair0': 0.6622658747400212, 'session_latest_pair1': 0.4613989787123528, 'session_latest_pair2': 0.4367278129871665, 'session_latest_pair3': 0.6422136794434746, 'session_latest_pair4': 0.3852829077287019, 'session_frequent_clicks_pair': 0.41699298691619585, 'session_latest_clicks_pair': 0.5060588518339421, 'session_latest_carts_pair': 0.02399569339189215, 'session_latest_time_wt_pair': 0.00031993664014667855, 'session_latest_clicks_carts_pair': 0.34336327755570273, 'session_latest_clicks_orders_pair': 0.9454770928429139}. Best is trial 8 with value: 0.425.
# [I 2022-12-04 09:00:57,769] Trial 12 finished with value: 0.426 and parameters: {'session_frequent': 0.02438981736740059, 'session_latest': 0.3705192825117354, 'total_frequent': 0.8662192427572081, 'session_frequent_pair': 0.41436248438106105, 'session_latest_pair0': 0.8768211390606866, 'session_latest_pair1': 0.35541266970286683, 'session_latest_pair2': 0.6157206456377425, 'session_latest_pair3': 0.7854073880518917, 'session_latest_pair4': 0.29973546352416136, 'session_frequent_clicks_pair': 0.7610342062133233, 'session_latest_clicks_pair': 0.3816078477962816, 'session_latest_carts_pair': 0.2542371066923612, 'session_latest_time_wt_pair': 0.09239338062069002, 'session_latest_clicks_carts_pair': 0.28980353373302165, 'session_latest_clicks_orders_pair': 0.7747491941240798}. Best is trial 12 with value: 0.426.
# [I 2022-12-04 09:01:02,518] Trial 13 finished with value: 0.417 and parameters: {'session_frequent': 0.38701066659704264, 'session_latest': 0.6408019252732321, 'total_frequent': 0.8756984489412445, 'session_frequent_pair': 0.40912012655484153, 'session_latest_pair0': 0.963062286906902, 'session_latest_pair1': 0.6094883843261449, 'session_latest_pair2': 0.69116098337202, 'session_latest_pair3': 0.8091597108086328, 'session_latest_pair4': 0.2701062645210025, 'session_frequent_clicks_pair': 0.7485813398796075, 'session_latest_clicks_pair': 0.3445999066927008, 'session_latest_carts_pair': 0.25339991915484056, 'session_latest_time_wt_pair': 0.15826670608954585, 'session_latest_clicks_carts_pair': 0.36664241856411467, 'session_latest_clicks_orders_pair': 0.6870973566162824}. Best is trial 12 with value: 0.426.
# [I 2022-12-04 09:01
. Best is trial 21 with value: 0.427.
# [I 2022-12-04 09:02:10,151] Trial 27 finished with value: 0.42 and parameters: {'session_frequent': 0.2794577414634947, 'session_latest': 0.3921565132375068, 'total_frequent': 0.8112136014827421, 'session_frequent_pair': 0.39025087024548943, 'session_latest_pair0': 0.915128000923891, 'session_latest_pair1': 0.900569835193028, 'session_latest_pair2': 0.9037284113200907, 'session_latest_pair3': 0.6493308023987151, 'session_latest_pair4': 0.2461582266945186, 'session_frequent_clicks_pair': 0.664991240349402, 'session_latest_clicks_pair': 0.5454051894997032, 'session_latest_carts_pair': 0.1602932821726582, 'session_latest_time_wt_pair': 0.09573933966613013, 'session_latest_clicks_carts_pair': 0.40447634894303314, 'session_latest_clicks_orders_pair': 0.7041798571444218}. Best is trial 21 with value: 0.427.
# [I 2022-12-04 09:02:15,374] Trial 28 finished with value: 0.427 and parameters: {'session_frequent': 0.19953078974717908, 'session_latest': 0.12391319613067692, 'total_frequent': 0.6083484996320496, 'session_frequent_pair': 0.28654796148420947, 'session_latest_pair0': 0.8137308196315889, 'session_latest_pair1': 0.7920612870091295, 'session_latest_pair2': 0.7222161282288801, 'session_latest_pair3': 0.9483724797658502, 'session_latest_pair4': 0.53095804584427, 'session_frequent_clicks_pair': 0.46350502259380677, 'session_latest_clicks_pair': 0.42366926546352773, 'session_latest_carts_pair': 0.5297043570773301, 'session_latest_time_wt_pair': 0.42344623723897507, 'session_latest_clicks_carts_pair': 0.5380205724782554, 'session_latest_clicks_orders_pair': 0.7735080194598023}. Best is trial 21 with value: 0.427.
# [I 2022-12-04 09:02:20,030] Trial 29 finished with value: 0.425 and parameters: {'session_frequent': 0.16874547365906364, 'session_latest': 0.0007099696889406593, 'total_frequent': 0.5975071203030131, 'session_frequent_pair': 0.27690196185904575, 'session_latest_pair0': 0.6024835491289482, 'session_latest_pair1': 0.7919996039410979, 'session_latest_pair2': 0.7619964557137078, 'session_latest_pair3': 0.9322809016122465, 'session_latest_pair4': 0.4949884101577786, 'session_frequent_clicks_pair': 0.3936072816636893, 'session_latest_clicks_pair': 0.7391311552964293, 'session_latest_carts_pair': 0.5209256821823502, 'session_latest_time_wt_pair': 0.4028571434216134, 'session_latest_clicks_carts_pair': 0.6165959976915061, 'session_latest_clicks_orders_pair': 0.9153362576259665}. Best is trial 21 with value: 0.427.
# [I 2022-12-04 09:02:24,714] Trial 30 finished with value: 0.421 and parameters: {'session_frequent': 0.19854816962158134, 'session_latest': 0.15046315941134553, 'total_frequent': 0.528213723193076, 'session_frequent_pair': 0.003193368889481296, 'session_latest_pair0': 0.8153872452596647, 'session_latest_pair1': 0.6513349647128698, 'session_latest_pair2': 0.6840969781680799, 'session_latest_pair3': 0.8724398571643293, 'session_latest_pair4': 0.9506515121081076, 'session_frequent_clicks_pair': 0.473917313820186, 'session_latest_clicks_pair': 0.4450918778909495, 'session_latest_carts_pair': 0.514881511057055, 'session_latest_time_wt_pair': 0.3134972488785861, 'session_latest_clicks_carts_pair': 0.780863795346542, 'session_latest_clicks_orders_pair': 0.9962244302515908}. Best is trial 21 with value: 0.427.
# [I 2022-12-04 09:02:29,339] Trial 31 finished with value: 0.423 and parameters: {'session_frequent': 0.058826557622898186, 'session_latest': 0.1280470321074665, 'total_frequent': 0.674087946844621, 'session_frequent_pair': 0.31797471729070137, 'session_latest_pair0': 0.9153575855070128, 'session_latest_pair1': 0.7820788808578636, 'session_latest_pair2': 0.5632642100387464, 'session_latest_pair3': 0.03734097052244151, 'session_latest_pair4': 0.6878213593638407, 'session_frequent_clicks_pair': 0.5841513582358852, 'session_latest_clicks_pair': 0.36932600833944657, 'session_latest_carts_pair': 0.42168274451325505, 'session_latest_time_wt_pair': 0.5390698537501948, 'session_latest_clicks_carts_pair': 0.42303885137578384, 'session_latest_clicks_orders_pair': 0.8166158713975579}. Best is trial 21 with value: 0.427.
# [I 2022-12-04 09:02:34,498] Trial 32 finished with value: 0.427 and parameters: {'session_frequent': 0.17374192848650416, 'session_latest': 0.2108366747358117, 'total_frequent': 0.7726687221494923, 'session_frequent_pair': 0.42826230451365466, 'session_latest_pair0': 0.7314476754934063, 'session_latest_pair1': 0.9175736548040957, 'session_latest_pair2': 0.46525185209593567, 'session_latest_pair3': 0.9845318357031334, 'session_latest_pair4': 0.4442768939311188, 'session_frequent_clicks_pair': 0.47897305364931875, 'session_latest_clicks_pair': 0.612438305396687, 'session_latest_carts_pair': 0.25555286321434956, 'session_latest_time_wt_pair': 0.21414103474932278, 'session_latest_clicks_carts_pair': 0.5159762222644722, 'session_latest_clicks_orders_pair': 0.7497590969845147}. Best is trial 21 with value: 0.427.
# [I 2022-12-04 09:02:39,229] Trial 33 finished with value: 0.428 and parameters: {'session_frequent': 0.30103138177654387, 'session_latest': 0.09493297171449289, 'total_frequent': 0.7347288717142187, 'session_frequent_pair': 0.530967937902383, 'session_latest_pair0': 0.7303163539252404, 'session_latest_pair1': 0.922192321656617, 'session_latest_pair2': 0.4563979739506603, 'session_latest_pair3': 0.9793421733346881, 'session_latest_pair4': 0.458790150598745, 'session_frequent_clicks_pair': 0.4661237936993876, 'session_latest_clicks_pair': 0.6583853968092847, 'session_latest_carts_pair': 0.47679901092991406, 'session_latest_time_wt_pair': 0.2483150645786733, 'session_latest_clicks_carts_pair': 0.5419337446573369, 'session_latest_clicks_orders_pair': 0.7327921025650127}. Best is trial 33 with value: 0.428.
# [I 2022-12-04 09:02:43,930] Trial 34 finished with value: 0.428 and parameters: {'session_frequent': 0.30668982758807367, 'session_latest': 0.09250202898183375, 'total_frequent': 0.7058529009237897, 'session_frequent_pair': 0.5351902188074311, 'session_latest_pair0': 0.8162763516125283, 'session_latest_pair1': 0.9308910298957995, 'session_latest_pair2': 0.34945590049321795, 'session_latest_pair3': 0.932331187962199, 'session_latest_pair4': 0.5531869817430147, 'session_frequent_clicks_pair': 0.32606262353554255, 'session_latest_clicks_pair': 0.7138077330047552, 'session_latest_carts_pair': 0.46730074410410016, 'session_latest_time_wt_pair': 0.38871165282614295, 'session_latest_clicks_carts_pair': 0.602542341294833, 'session_latest_clicks_orders_pair': 0.6521447697796234}. Best is trial 33 with value: 0.428.
# [I 2022-12-04 09
. Best is trial 33 with value: 0.428.
# [I 2022-12-04 09:03:32,714] Trial 44 finished with value: 0.427 and parameters: {'session_frequent': 0.35924184798512593, 'session_latest': 0.08526724566296683, 'total_frequent': 0.7254205325778634, 'session_frequent_pair': 0.7811990817654726, 'session_latest_pair0': 0.6658442944288752, 'session_latest_pair1': 0.8691057002586827, 'session_latest_pair2': 0.21196589157317794, 'session_latest_pair3': 0.18614597263410745, 'session_latest_pair4': 0.5974118537920033, 'session_frequent_clicks_pair': 0.1584190749195099, 'session_latest_clicks_pair': 0.7173177482402278, 'session_latest_carts_pair': 0.5561317531160324, 'session_latest_time_wt_pair': 0.2970460381284832, 'session_latest_clicks_carts_pair': 0.6247091341761071, 'session_latest_clicks_orders_pair': 0.6196516142445422}. Best is trial 33 with value: 0.428.
# [I 2022-12-04 09:03:37,972] Trial 45 finished with value: 0.426 and parameters: {'session_frequent': 0.2771292344575867, 'session_latest': 0.2833140162735324, 'total_frequent': 0.7550225897291871, 'session_frequent_pair': 0.6219212860319672, 'session_latest_pair0': 0.7632194275170581, 'session_latest_pair1': 0.6761939852286042, 'session_latest_pair2': 0.4631101303636115, 'session_latest_pair3': 0.3684255747122781, 'session_latest_pair4': 0.6682074267782088, 'session_frequent_clicks_pair': 0.24915476857014696, 'session_latest_clicks_pair': 0.8930265604483756, 'session_latest_carts_pair': 0.3701395170864633, 'session_latest_time_wt_pair': 0.6620868530509704, 'session_latest_clicks_carts_pair': 0.6817118257458697, 'session_latest_clicks_orders_pair': 0.685616684815448}. Best is trial 33 with value: 0.428.
# [I 2022-12-04 09:03:42,703] Trial 46 finished with value: 0.423 and parameters: {'session_frequent': 0.44834305534542696, 'session_latest': 0.33141166108583076, 'total_frequent': 0.6595377020941857, 'session_frequent_pair': 0.5534633781284317, 'session_latest_pair0': 0.9562522981531832, 'session_latest_pair1': 0.830358708096566, 'session_latest_pair2': 0.36653843851297785, 'session_latest_pair3': 0.24462570546848955, 'session_latest_pair4': 0.7263174651278758, 'session_frequent_clicks_pair': 0.19936292523730556, 'session_latest_clicks_pair': 0.6809440941274708, 'session_latest_carts_pair': 0.46076891731752595, 'session_latest_time_wt_pair': 0.4730506792545402, 'session_latest_clicks_carts_pair': 0.7913505873735164, 'session_latest_clicks_orders_pair': 0.7240042246479625}. Best is trial 33 with value: 0.428.
# [I 2022-12-04 09:03:47,403] Trial 47 finished with value: 0.423 and parameters: {'session_frequent': 0.373719421048432, 'session_latest': 0.1706649188278231, 'total_frequent': 0.555626890743363, 'session_frequent_pair': 0.8600856794997387, 'session_latest_pair0': 0.6614528532583213, 'session_latest_pair1': 0.8671094130955356, 'session_latest_pair2': 0.2214166865269661, 'session_latest_pair3': 0.13370142498264537, 'session_latest_pair4': 0.614927728904426, 'session_frequent_clicks_pair': 0.08524139575025336, 'session_latest_clicks_pair': 0.7787034500240235, 'session_latest_carts_pair': 0.7259346106614615, 'session_latest_time_wt_pair': 0.31903290780870924, 'session_latest_clicks_carts_pair': 0.49395313111620265, 'session_latest_clicks_orders_pair': 0.6143844817581964}. Best is trial 33 with value: 0.428.
# [I 2022-12-04 09:03:52,114] Trial 48 finished with value: 0.429 and parameters: {'session_frequent': 0.2526567120056858, 'session_latest': 0.05238048658054774, 'total_frequent': 0.9425599908067133, 'session_frequent_pair': 0.48936166462050146, 'session_latest_pair0': 0.9382235020025795, 'session_latest_pair1': 0.7403219299768715, 'session_latest_pair2': 0.5299617635670932, 'session_latest_pair3': 0.5706586390761687, 'session_latest_pair4': 0.4926338640702045, 'session_frequent_clicks_pair': 0.3604266776511108, 'session_latest_clicks_pair': 0.8526159209883074, 'session_latest_carts_pair': 0.655807763328285, 'session_latest_time_wt_pair': 0.27229652560719964, 'session_latest_clicks_carts_pair': 0.4508258898499003, 'session_latest_clicks_orders_pair': 0.9360931890849056}. Best is trial 48 with value: 0.429.
# [I 2022-12-04 09:03:57,269] Trial 49 finished with value: 0.428 and parameters: {'session_frequent': 0.6073008282532093, 'session_latest': 0.05378366725426187, 'total_frequent': 0.626058683733572, 'session_frequent_pair': 0.28598448762319806, 'session_latest_pair0': 0.23895840460060275, 'session_latest_pair1': 0.9650163613654069, 'session_latest_pair2': 0.4723601126975021, 'session_latest_pair3': 0.531827014857569, 'session_latest_pair4': 0.5069289642879008, 'session_frequent_clicks_pair': 0.29247159461422334, 'session_latest_clicks_pair': 0.9727635023519805, 'session_latest_carts_pair': 0.6413966299481803, 'session_latest_time_wt_pair': 0.27548562807852994, 'session_latest_clicks_carts_pair': 0.5825848434840126, 'session_latest_clicks_orders_pair': 0.6572229345869889}. Best is trial 48 with value: 0.429.
# [I 2022-12-04 09:04:02,072] Trial 50 finished with value: 0.429 and parameters: {'session_frequent': 0.592910159821493, 'session_latest': 0.03982169525043923, 'total_frequent': 0.9742198532361969, 'session_frequent_pair': 0.37798259389483246, 'session_latest_pair0': 0.20545967203823373, 'session_latest_pair1': 0.9670021316032793, 'session_latest_pair2': 0.489732297514355, 'session_latest_pair3': 0.526392451719419, 'session_latest_pair4': 0.5182487436290906, 'session_frequent_clicks_pair': 0.3790339150771361, 'session_latest_clicks_pair': 0.999835260915013, 'session_latest_carts_pair': 0.6315073471357079, 'session_latest_time_wt_pair': 0.1920372563947586, 'session_latest_clicks_carts_pair': 0.5764632138298872, 'session_latest_clicks_orders_pair': 0.5271123439632741}. Best is trial 48 with value: 0.429.
# [I 2022-12-04 09:04:06,872] Trial 51 finished with value: 0.428 and parameters: {'session_frequent': 0.6468185696782552, 'session_latest': 0.038202840956156475, 'total_frequent': 0.9256918456446445, 'session_frequent_pair': 0.36620319386319794, 'session_latest_pair0': 0.20425604626614813, 'session_latest_pair1': 0.9586661224240457, 'session_latest_pair2': 0.48380849035361057, 'session_latest_pair3': 0.5760096597551245, 'session_latest_pair4': 0.5036996025116453, 'session_frequent_clicks_pair': 0.3679676376548375, 'session_latest_clicks_pair': 0.9870424817698343, 'session_latest_carts_pair': 0.6398768830064122, 'session_latest_time_wt_pair': 0.2769825665507299, 'session_latest_clicks_carts_pair': 0.5951473494282354, 'session_latest_clicks_orders_pair': 0.5237257317887365}. Best is trial 48 with value: 0.429.
# [I 2022-12-04 09:04:12,058] Trial 52 finished with value: 0.429 and parameters: {'session_frequent': 0.6561065954507403, 'session_latest': 0.04569179525634479, 'total_frequent': 0.9727629386111208, 'session_frequent_pair': 0.3664893836597408, 'session_latest_pair0': 0.19780459339295473, 'session_latest_pair1': 0.9718830788131002, 'session_latest_pair2': 0.5005377833185346, 'session_latest_pair3': 0.5349667633909176, 'session_latest_pair4': 0.5214188727670928, 'session_frequent_clicks_pair': 0.36173988005270863, 'session_latest_clicks_pair': 0.9919000062576637, 'session_latest_carts_pair': 0.6307549365027678, 'session_latest_time_wt_pair': 0.18984947053343565, 'session_latest_clicks_carts_pair': 0.5716759268343742, 'session_latest_clicks_orders_pair': 0.5260025964070355}. Best is trial 48 with value: 0.429.
# [I 2022-12-04 09:04:16,830] Trial 53 finished with value: 0.428 and parameters: {'session_frequent': 0.6622714621615038, 'session_latest': 0.038208564889649244, 'total_frequent': 0.9614759210215321, 'session_frequent_pair': 0.36988281241567994, 'session_latest_pair0': 0.20017886583755878, 'session_latest_pair1': 0.9715479751273053, 'session_latest_pair2': 0.5396094058839044, 'session_latest_pair3': 0.5433667543591426, 'session_latest_pair4': 0.48797585977301716, 'session_frequent_clicks_pair': 0.3763113788806658, 'session_latest_clicks_pair': 0.999346354830627, 'session_latest_carts_pair': 0.6303054124664288, 'session_latest_time_wt_pair': 0.10570537897222732, 'session_latest_clicks_carts_pair': 0.5711957105868612, 'session_latest_clicks_orders_pair': 0.4496355257947036}. Best is trial 48 with value: 0.429.
# [I 2022-12-04 09:04:21,616] Trial 54 finished with value: 0.419 and parameters: {'session_frequent': 0.6746693532000528, 'session_latest': 0.024919713875810493, 'total_frequent': 0.957012501175091, 'session_frequent_pair': 0.38022090385056345, 'session_latest_pair0': 0.16731327428834752, 'session_latest_pair1': 0.9673679879982309, 'session_latest_pair2': 0.5059269825566758, 'session_latest_pair3': 0.5535253780474191, 'session_latest_pair4': 0.3587105297712551, 'session_frequent_clicks_pair': 0.36500745191659406, 'session_latest_clicks_pair': 0.9959990238577136, 'session_latest_carts_pair': 0.6369358176110378, 'session_latest_time_wt_pair': 0.04033629253351398, 'session_latest_clicks_carts_pair': 0.002064973769136058, 'session_latest_clicks_orders_pair': 0.4531064605245735}. Best is trial 48 with value: 0.429.
# [I 2022-12-04 09:04:26,231] Trial 55 finished with value: 0.428 and parameters: {'session_frequent': 0.6121810819729772, 'session_latest': 0.0491899698313473, 'total_frequent': 0.9694732263360283, 'session_frequent_pair': 0.24003023739313975, 'session_latest_pair0': 0.24774257545583217, 'session_latest_pair1': 0.9989470464133128, 'session_latest_pair2': 0.5624449208028941, 'session_latest_pair3': 0.6030853719956047, 'session_latest_pair4': 0.5094552935006559, 'session_frequent_clicks_pair': 0.3680568138545836, 'session_latest_clicks_pair': 0.9965142701805267, 'session_latest_carts_pair': 0.7980373000037381, 'session_latest_time_wt_pair': 0.09622793246708582, 'session_latest_clicks_carts_pair': 0.5913854312057736, 'session_latest_clicks_orders_pair': 0.34762308559283317}. Best is trial 48 with value: 0.429.
# [I 2022-12-04 09:04:31,398] Trial 56 finished with value: 0.422 and parameters: {'session_frequent': 0.5548476979130759, 'session_latest': 0.07382733711471581, 'total_frequent': 0.9961873501624741, 'session_frequent_pair': 0.48455453672119686, 'session_latest_pair0': 0.00352301492880136, 'session_latest_pair1': 0.999386715506408, 'session_latest_pair2': 0.5640721611959004, 'session_latest_pair3': 0.44539061954674564, 'session_latest_pair4': 0.38348715459425003, 'session_frequent_clicks_pair': 0.4550475283717539, 'session_latest_clicks_pair': 0.9093538130599433, 'session_latest_carts_pair': 0.828778682996707, 'session_latest_time_wt_pair': 0.17655501521185935, 'session_latest_clicks_carts_pair': 0.6588108872725853, 'session_latest_clicks_orders_pair': 0.24649471961950964}. Best is trial 48 with value: 0.429.
# [I 2022-12-04 09:04:36,047] Trial 57 finished with value: 0.427 and parameters: {'session_frequent': 0.7756131609963924, 'session_latest': 0.002094294641408638, 'total_frequent': 0.9078898324998086, 'session_frequent_pair': 0.3680914384169521, 'session_latest_pair0': 0.28588099516024484, 'session_latest_pair1': 0.8681925654778828, 'session_latest_pair2': 0.5442931530857936, 'session_latest_pair3': 0.5088153056563388, 'session_latest_pair4': 0.4708259985441351, 'session_frequent_clicks_pair': 0.37848854778860025, 'session_latest_clicks_pair': 0.9300046084714315, 'session_latest_carts_pair': 0.6996195163650292, 'session_latest_time_wt_pair': 0.12810525959220856, 'session_latest_clicks_carts_pair': 0.45299834966628727, 'session_latest_clicks_orders_pair': 0.5223792671570672}. Best is trial 48 with value: 0.429.
# ...
# [I 2022-12-04 09:22:45,891] Trial 81 finished with value: 0.57 and parameters: {'session_frequent': 0.040690253272852764, 'session_latest': 0.458467381385375, 'total_frequent': 0.8054040315517598, 'session_frequent_pair': 0.5252615016392623, 'session_latest_pair0': 0.7418344279830924, 'session_latest_pair1': 0.6895055173212326, 'session_latest_pair2': 0.8180295848186402, 'session_latest_pair3': 0.7269417026998073, 'session_latest_pair4': 0.8736367468659113, 'session_frequent_clicks_pair': 0.19965860643450797, 'session_latest_clicks_pair': 0.7599256448274588, 'session_latest_carts_pair': 0.612493063445866, 'session_latest_time_wt_pair': 0.36507206508461787, 'session_latest_clicks_carts_pair': 0.9259989784431787, 'session_latest_clicks_orders_pair': 0.7059919562567175}. Best is trial 54 with value: 0.574.
# [I 2022-12-04 09:22:50,595] Trial 82 finished with value: 0.564 and parameters: {'session_frequent': 0.06378261614277951, 'session_latest': 0.5443970903253464, 'total_frequent': 0.7516607321804397, 'session_frequent_pair': 0.5173071868457849, 'session_latest_pair0': 0.7877128771155716, 'session_latest_pair1': 0.6245183550686884, 'session_latest_pair2': 0.8424870496369268, 'session_latest_pair3': 0.8363569426454529, 'session_latest_pair4': 0.9832467006934529, 'session_frequent_clicks_pair': 0.28336279856494495, 'session_latest_clicks_pair': 0.7687802992301499, 'session_latest_carts_pair': 0.6116580894175893, 'session_latest_time_wt_pair': 0.3305334155751428, 'session_latest_clicks_carts_pair': 0.7990199542985298, 'session_latest_clicks_orders_pair': 0.5445263848836068}. Best is trial 54 with value: 0.574.
# [I 2022-12-04 09:22:55,265] Trial 83 finished with value: 0.568 and parameters: {'session_frequent': 0.029345343261340473, 'session_latest': 0.6263910689790272, 'total_frequent': 0.8681456764182676, 'session_frequent_pair': 0.29734728994639376, 'session_latest_pair0': 0.7087619285375472, 'session_latest_pair1': 0.7609794459349875, 'session_latest_pair2': 0.863491443024284, 'session_latest_pair3': 0.8823830197934627, 'session_latest_pair4': 0.943334023776083, 'session_frequent_clicks_pair': 0.1447218456439482, 'session_latest_clicks_pair': 0.9217096837901313, 'session_latest_carts_pair': 0.6598670997251029, 'session_latest_time_wt_pair': 0.2727025027007356, 'session_latest_clicks_carts_pair': 0.9584628357824067, 'session_latest_clicks_orders_pair': 0.8095456126357309}. Best is trial 54 with value: 0.574.
# [I 2022-12-04 09:23:00,445] Trial 84 finished with value: 0.57 and parameters: {'session_frequent': 0.02389406226672499, 'session_latest': 0.6722406677536882, 'total_frequent': 0.7780556117197706, 'session_frequent_pair': 0.6594723276946747, 'session_latest_pair0': 0.6594863391692893, 'session_latest_pair1': 0.6837628095405335, 'session_latest_pair2': 0.8263872175563012, 'session_latest_pair3': 0.7220773679546431, 'session_latest_pair4': 0.8636426445557834, 'session_frequent_clicks_pair': 0.21153138953622688, 'session_latest_clicks_pair': 0.9587092763594477, 'session_latest_carts_pair': 0.5639886624625982, 'session_latest_time_wt_pair': 0.3732831869822639, 'session_latest_clicks_carts_pair': 0.9262361208530032, 'session_latest_clicks_orders_pair': 0.708364147060515}. Best is trial 54 with value: 0.574.
# [I 2022-12-04 09:23:05,099] Trial 85 finished with value: 0.573 and parameters: {'session_frequent': 0.0016883988845327986, 'session_latest': 0.6700067934066732, 'total_frequent': 0.6758743707225935, 'session_frequent_pair': 0.7291271661809513, 'session_latest_pair0': 0.7371370527016191, 'session_latest_pair1': 0.6839755191095456, 'session_latest_pair2': 0.9983189316562089, 'session_latest_pair3': 0.727012085400454, 'session_latest_pair4': 0.8705206679842585, 'session_frequent_clicks_pair': 0.32506130956487606, 'session_latest_clicks_pair': 0.8739091116348716, 'session_latest_carts_pair': 0.5219838182503357, 'session_latest_time_wt_pair': 0.39896343933683065, 'session_latest_clicks_carts_pair': 0.8803182688496851, 'session_latest_clicks_orders_pair': 0.2697881246401032}. Best is trial 54 with value: 0.574.
# [I 2022-12-04 09:23:09,726] Trial 86 finished with value: 0.572 and parameters: {'session_frequent': 0.0017807738023166084, 'session_latest': 0.368278376953701, 'total_frequent': 0.6788964922473713, 'session_frequent_pair': 0.722885447622914, 'session_latest_pair0': 0.311379091643777, 'session_latest_pair1': 0.6454874691250836, 'session_latest_pair2': 0.9950077374377908, 'session_latest_pair3': 0.6121806185184264, 'session_latest_pair4': 0.8625305560836553, 'session_frequent_clicks_pair': 0.365927797602176, 'session_latest_clicks_pair': 0.8645579130704373, 'session_latest_carts_pair': 0.36518014255295533, 'session_latest_time_wt_pair': 0.5259541715762329, 'session_latest_clicks_carts_pair': 0.8430275996851575, 'session_latest_clicks_orders_pair': 0.8594303336027365}. Best is trial 54 with value: 0.574.
# [I 2022-12-04 09:23:14,387] Trial 87 finished with value: 0.468 and parameters: {'session_frequent': 0.6429226332302369, 'session_latest': 0.8155990951629468, 'total_frequent': 0.6873838307931058, 'session_frequent_pair': 0.7573646275669081, 'session_latest_pair0': 0.3549461669146824, 'session_latest_pair1': 0.6506054148979838, 'session_latest_pair2': 0.9953552470958773, 'session_latest_pair3': 0.6309005788227399, 'session_latest_pair4': 0.8137571618486655, 'session_frequent_clicks_pair': 0.39389139966331915, 'session_latest_clicks_pair': 0.8764496415763351, 'session_latest_carts_pair': 0.34417711741465884, 'session_latest_time_wt_pair': 0.5214024619822849, 'session_latest_clicks_carts_pair': 0.8509252814873149, 'session_latest_clicks_orders_pair': 0.8677034225402951}. Best is trial 54 with value: 0.574.
# [I 2022-12-04 09:23:19,509] Trial 88 finished with value: 0.573 and parameters: {'session_frequent': 0.0021039300811919667, 'session_latest': 0.37271949460761916, 'total_frequent': 0.6105812378367377, 'session_frequent_pair': 0.8499614880133577, 'session_latest_pair0': 0.3360264452292855, 'session_latest_pair1': 0.5319162626345351, 'session_latest_pair2': 0.9739232211019854, 'session_latest_pair3': 0.5749487331172422, 'session_latest_pair4': 0.924234241649863, 'session_frequent_clicks_pair': 0.3322702560762155, 'session_latest_clicks_pair': 0.5219994334516316, 'session_latest_carts_pair': 0.40725646448237907, 'session_latest_time_wt_pair': 0.43004254634466116, 'session_latest_clicks_carts_pair': 0.8291493583821142, 'session_latest_clicks_orders_pair': 0.2738011523538218}. Best is trial 54 with value: 0.574.
# [I 2022-12-04 09:23:24,234] Trial 89 finished with value: 0.573 and parameters: {'session_frequent': 0.005058618226527757, 'session_latest': 0.284275393859092, 'total_frequent': 0.6056765462105422, 'session_frequent_pair': 0.9785531920118481, 'session_latest_pair0': 0.3232904776142733, 'session_latest_pair1': 0.5764970511501608, 'session_latest_pair2': 0.970010951718971, 'session_latest_pair3': 0.569223888250787, 'session_latest_pair4': 0.9284595191878575, 'session_frequent_clicks_pair': 0.32587347310847853, 'session_latest_clicks_pair': 0.9114353173086261, 'session_latest_carts_pair': 0.28488289163955965, 'session_latest_time_wt_pair': 0.4984556363114179, 'session_latest_clicks_carts_pair': 0.81515228576836, 'session_latest_clicks_orders_pair': 0.25388650358268944}. Best is trial 54 with value: 0.574.
# [I 2022-12-04 09:23:28,875] Trial 90 finished with value: 0.573 and parameters: {'session_frequent': 0.0013518899009098472, 'session_latest': 0.24686530710655297, 'total_frequent': 0.5949847610860897, 'session_frequent_pair': 0.9021251087905358, 'session_latest_pair0': 0.17014882979678012, 'session_latest_pair1': 0.5370489836420944, 'session_latest_pair2': 0.9672569126368142, 'session_latest_pair3': 0.5466751411457912, 'session_latest_pair4': 0.9244001811996266, 'session_frequent_clicks_pair': 0.32920769441883724, 'session_latest_clicks_pair': 0.9130822040798071, 'session_latest_carts_pair': 0.2609113105766666, 'session_latest_time_wt_pair': 0.5949907165020923, 'session_latest_clicks_carts_pair': 0.8174437742740219, 'session_latest_clicks_orders_pair': 0.26188697862883564}. Best is trial 54 with value: 0.574.
# [I 2022-12-04 09:23:34,104] Trial 91 finished with value: 0.572 and parameters: {'session_frequent': 0.0025101266979133396, 'session_latest': 0.2692643841971339, 'total_frequent': 0.5819673092897496, 'session_frequent_pair': 0.9395579905788205, 'session_latest_pair0': 0.07841531806200513, 'session_latest_pair1': 0.5348335932468401, 'session_latest_pair2': 0.97164236050737, 'session_latest_pair3': 0.5592119517739829, 'session_latest_pair4': 0.9096524373735465, 'session_frequent_clicks_pair': 0.32847646398256425, 'session_latest_clicks_pair': 0.5176774121319767, 'session_latest_carts_pair': 0.29267944740870383, 'session_latest_time_wt_pair': 0.5936956018887367, 'session_latest_clicks_carts_pair': 0.8174012794792358, 'session_latest_clicks_orders_pair': 0.27038132677727783}. Best is trial 54 with value: 0.574.
# [I 2022-12-04 09:23:38,741] Trial 92 finished with value: 0.572 and parameters: {'session_frequent': 0.0004656219872881609, 'session_latest': 0.2725042204408966, 'total_frequent': 0.5637783753274481, 'session_frequent_pair': 0.9729587983089812, 'session_latest_pair0': 0.1440354623487588, 'session_latest_pair1': 0.5597988213388043, 'session_latest_pair2': 0.9707344060655219, 'session_latest_pair3': 0.5441874896388305, 'session_latest_pair4': 0.9208797435649052, 'session_frequent_clicks_pair': 0.32762981016541404, 'session_latest_clicks_pair': 0.5843566170574551, 'session_latest_carts_pair': 0.2684607877477876, 'session_latest_time_wt_pair': 0.6268642199783465, 'session_latest_clicks_carts_pair': 0.7775524337837155, 'session_latest_clicks_orders_pair': 0.2649636278803607}. Best is trial 54 with value: 0.574.
# [I 2022-12-04 09:23:43,341] Trial 93 finished with value: 0.558 and parameters: {'session_frequent': 0.05928665973554324, 'session_latest': 0.24423467336508115, 'total_frequent': 0.5696498291224783, 'session_frequent_pair': 0.9421991641909, 'session_latest_pair0': 0.12782360511220286, 'session_latest_pair1': 0.5422330831971442, 'session_latest_pair2': 0.96060184724225, 'session_latest_pair3': 0.5462120638800647, 'session_latest_pair4': 0.9267133346570846, 'session_frequent_clicks_pair': 0.3248223601050062, 'session_latest_clicks_pair': 0.45770884127858863, 'session_latest_carts_pair': 0.26328337124117895, 'session_latest_time_wt_pair': 0.5931620016205086, 'session_latest_clicks_carts_pair': 0.8192800860923996, 'session_latest_clicks_orders_pair': 0.26217343709029906}. Best is trial 54 with value: 0.574.
# [I 2022-12-04 09:23:48,610] Trial 94 finished with value: 0.557 and parameters: {'session_frequent': 0.0857340546523358, 'session_latest': 0.20571624305158742, 'total_frequent': 0.6059173959046882, 'session_frequent_pair': 0.8715989765659464, 'session_latest_pair0': 0.2886748972577874, 'session_latest_pair1': 0.4815783681775604, 'session_latest_pair2': 0.9306952027312527, 'session_latest_pair3': 0.4951071736928263, 'session_latest_pair4': 0.8927909876613713, 'session_frequent_clicks_pair': 0.36052563233442897, 'session_latest_clicks_pair': 0.9688927347413967, 'session_latest_carts_pair': 0.3296670473542457, 'session_latest_time_wt_pair': 0.718130078324207, 'session_latest_clicks_carts_pair': 0.881152928391856, 'session_latest_clicks_orders_pair': 0.2154444328350743}. Best is trial 54 with value: 0.574.
# [I 2022-12-04 09:23:53,189] Trial 95 finished with value: 0.561 and parameters: {'session_frequent': 0.05924853323625719, 'session_latest': 0.2927664147650708, 'total_frequent': 0.6444842443522983, 'session_frequent_pair': 0.9928007042637013, 'session_latest_pair0': 0.19251033292825442, 'session_latest_pair1': 0.6054268268885873, 'session_latest_pair2': 0.9927392432693547, 'session_latest_pair3': 0.6770396945066883, 'session_latest_pair4': 0.8244870745544208, 'session_frequent_clicks_pair': 0.4427205221521002, 'session_latest_clicks_pair': 0.9038794182167179, 'session_latest_carts_pair': 0.15294727232388347, 'session_latest_time_wt_pair': 0.5133065323675562, 'session_latest_clicks_carts_pair': 0.7395010293524696, 'session_latest_clicks_orders_pair': 0.3095480804947277}. Best is trial 54 with value: 0.574.
# [I 2022-12-04 09:23:57,998] Trial 96 finished with value: 0.529 and parameters: {'session_frequent': 0.11044379624335984, 'session_latest': 0.36995731973042073, 'total_frequent': 0.5345729572912415, 'session_frequent_pair': 0.9131045340314459, 'session_latest_pair0': 0.0909380980167719, 'session_latest_pair1': 0.5297397938456482, 'session_latest_pair2': 0.9433454248080735, 'session_latest_pair3': 0.5902015940698236, 'session_latest_pair4': 0.8586508739595862, 'session_frequent_clicks_pair': 0.3754246123862733, 'session_latest_clicks_pair': 0.526701679373393, 'session_latest_carts_pair': 0.3778668658123427, 'session_latest_time_wt_pair': 0.5348920382807136, 'session_latest_clicks_carts_pair': 0.8159998521969376, 'session_latest_clicks_orders_pair': 0.13137938114456682}. Best is trial 54 with value: 0.574.
# [I 2022-12-04 09:24:02,701] Trial 97 finished with value: 0.574 and parameters: {'session_frequent': 0.019502273286773997, 'session_latest': 0.32800545290559063, 'total_frequent': 0.6193654283346484, 'session_frequent_pair': 0.8576763433910455, 'session_latest_pair0': 0.36663054664696776, 'session_latest_pair1': 0.5707548524515051, 'session_latest_pair2': 0.8996106514661354, 'session_latest_pair3': 0.6297687174218353, 'session_latest_pair4': 0.7414168834473795, 'session_frequent_clicks_pair': 0.29146033336258403, 'session_latest_clicks_pair': 0.9263334457937838, 'session_latest_carts_pair': 0.41111486224505334, 'session_latest_time_wt_pair': 0.4047592046612697, 'session_latest_clicks_carts_pair': 0.7808756075244788, 'session_latest_clicks_orders_pair': 0.3665784137224698}. Best is trial 54 with value: 0.574.
# [I 2022-12-04 09:24:07,892] Trial 98 finished with value: 0.573 and parameters: {'session_frequent': 0.02309240793150289, 'session_latest': 0.2579204593605211, 'total_frequent': 0.549014686670992, 'session_frequent_pair': 0.8569254322444053, 'session_latest_pair0': 0.41121657998103356, 'session_latest_pair1': 0.5644437046753059, 'session_latest_pair2': 0.9698506680655814, 'session_latest_pair3': 0.5430126533023435, 'session_latest_pair4': 0.7960310935448279, 'session_frequent_clicks_pair': 0.30605286222522926, 'session_latest_clicks_pair': 0.4984075001352507, 'session_latest_carts_pair': 0.2850495429448435, 'session_latest_time_wt_pair': 0.6562337493922237, 'session_latest_clicks_carts_pair': 0.7810562325142304, 'session_latest_clicks_orders_pair': 0.2706023237628629}. Best is trial 54 with value: 0.574.
# [I 2022-12-04 09:24:12,672] Trial 99 finished with value: 0.558 and parameters: {'session_frequent': 0.08874806281015377, 'session_latest': 0.13425909187411256, 'total_frequent': 0.4488574881534929, 'session_frequent_pair': 0.8348661903357686, 'session_latest_pair0': 0.40387175571912054, 'session_latest_pair1': 0.5027029565745157, 'session_latest_pair2': 0.9052273096476376, 'session_latest_pair3': 0.48037271720198294, 'session_latest_pair4': 0.7983934400653772, 'session_frequent_clicks_pair': 0.40755456525514, 'session_latest_clicks_pair': 0.9310717167552397, 'session_latest_carts_pair': 0.20822477874220988, 'session_latest_time_wt_pair': 0.7025522045182736, 'session_latest_clicks_carts_pair': 0.7790899643959034, 'session_latest_clicks_orders_pair': 0.360224841579473}. Best is trial 54 with value: 0.574.
# 0:25:03.687491 	 orders_recall_best_value : 0.574
# 0:25:03.688654 	 SCORE : 0.4887

# %% [markdown]
# # sub作成

# %%
test = make_test_data(trans_maps)
sub = pd.read_csv(cfg.input_dir + f"sample_submission.csv", usecols=["session_type"])
dfs = []

for type_ in ["clicks", "carts", "orders"]:
    test_type = test.copy()
    test_type["rank"] 
    test_type["rank"] = test_type["rank"] * test_type["strategy"].map(wt[type_])
    test_type = test_type.sort_values(["session", "rank"])
    test_type = test_type.drop_duplicates(subset= ["session", "aid"], keep="first")
    test_type = test_type.groupby(["session"]).head(20)
    test_type["aid"] = test_type["aid"].astype(str)
    test_type = test_type.groupby("session")["aid"].apply(list).reset_index()
    test_type["aid"] = test_type["aid"].apply(lambda x: ' '.join(x))
    test_type["session_type"] = test_type["session"].astype(str) + f"_{type_}"
    test_type =test_type.rename(columns={"aid": "labels"})
    dfs.append(test_type)
test_preds = pd.concat(dfs)

sub = sub.merge(test_preds, on="session_type", how="left")
sub[["session_type", "labels"]].to_csv(cfg.output_dir + f"{cfg.exp_name}/{cfg.exp_name}_sub.csv", index=False)
# Out:
# 0:25:05.339462 	 [make_test] make_cand_df
# 0:25:05.701726 	 [make_candidate] session_frequent : start
# 0:25:06.230716 	 [add_candidate] session_frequent : start
# 0:25:06.587510 	 [make_candidate] session_latest : start
# 0:25:06.876791 	 [add_candidate] session_latest : start
# 0:25:07.272724 	 [make_candidate] total_frequent : start
# 0:25:13.217825 	 [add_candidate] total_frequent : start
# 0:25:15.835530 	 [make_candidate] session_frequent_pair : start
# 0:25:16.671347 	 [add_candidate] session_frequent_pair : start
# 0:25:17.552676 	 [make_candidate] session_latest_pair0 : start
# 0:25:18.301158 	 [add_candidate] session_latest_pair0 : start
# 0:25:19.144188 	 [make_candidate] session_latest_pair1 : start
# 0:25:19.854772 	 [add_candidate] session_latest_pair1 : start
# 0:25:21.096556 	 [make_candidate] session_latest_pair2 : start
# 0:25:21.606180 	 [add_candidate] session_latest_pair2 : start
# 0:25:22.906071 	 [make_candidate] session_latest_pair3 : start
# 0:25:23.411244 	 [add_candidate] session_latest_pair3 : start
# 0:25:24.507190 	 [make_candidate] session_latest_pair4 : start
# 0:25:25.168338 	 [add_candidate] session_latest_pair4 : start
# 0:25:26.532600 	 [make_candidate] session_frequent_clicks_pair : start
# 0:25:27.014104 	 [add_candidate] session_frequent_clicks_pair : start
# 0:25:28.452969 	 [make_candidate] session_latest_clicks_pair : start
# 0:25:29.013381 	 [add_candidate] session_latest_clicks_pair : start
# 0:25:30.476638 	 [make_candidate] session_latest_carts_pair : start
# 0:25:30.914111 	 [add_candidate] session_latest_carts_pair : start
# 0:25:32.173029 	 [make_candidate] session_latest_time_wt_pair : start
# 0:25:32.913191 	 [add_candidate] session_latest_time_wt_pair : start
# 0:25:34.491002 	 [make_candidate] session_latest_clicks_carts_pair : start
# 0:25:35.027687 	 [add_candidate] session_latest_clicks_carts_pair : start
# 0:25:36.516484 	 [make_candidate] session_latest_clicks_orders_pair : start
# 0:25:37.327185 	 [add_candidate] session_latest_clicks_orders_pair : start

# %%
sub.head()
# Out:
#       session_type   session  \
# 0  12899779_clicks  12899779
# 1   12899779_carts  12899779
# 2  12899779_orders  12899779
# 3  12899780_clicks  12899780
# 4   12899780_carts  12899780
#
#                                               labels
# 0  59625 737445 1130911 225209 894169 1854910 485...
# 1  59625 1854910 894169 225209 1130911 737445 485...
# 2  59625 1130911 225209 737445 1854910 894169 485...
# 3  1142000 736515 973453 582732 1502122 1419849 8...
# 4  1142000 582732 736515 487136 973453 636101 141...
