# %% [markdown]
# # exp030
# co-visitation-matrix v3に

# %%
import os
import sys
import traceback
import gc
import random
import pickle
import pathlib
import subprocess
from dataclasses import dataclass
from dotenv import load_dotenv
load_dotenv
sys.path.append(os.getenv('UTILS_PATH'))
from tqdm import tqdm
import multiprocessing
import inspect

import pandas as pd
import numpy as np
import itertools
import cudf
import lightgbm as lgb
import matplotlib.pyplot as plt
import seaborn as sns
import line_notify
import my_logger
from noglobal import noglobal
import optuna

# %% [markdown]
# # 設定

# %%
@dataclass
class Cfg:
    loglevel = "INFO"
    exp_name = "exp030"
    seed = 42
    k = 20
    cand_n = 10
    type2id = {"clicks":0, "carts":1, "orders":2}
    id2type = {0:"clicks", 1:"carts", 2:"orders"}
    train_weeks = ["week3"]
    valid_week = "week4"
    valid_session_n = 100_000
    input_dir = os.getenv('INPUT_DIR')
    output_dir = os.getenv('OUTPUT_DIR')
    prep_dir = os.getenv("PREP_DIR")

cfg = Cfg()
os.makedirs(os.path.join(cfg.output_dir, cfg.exp_name), exist_ok=True)
os.makedirs(os.path.join(cfg.output_dir, cfg.exp_name, "cache"), exist_ok=True)
random.seed(cfg.seed)

logger = my_logger.init_logger(cfg.exp_name)

# %%
@noglobal(excepts=["cfg", "logger"])
def evaluate(clicks_labels, carts_labels, orders_labels, 
             clicks_preds, carts_preds, orders_preds, k=20):

    num_clicks = 0
    num_carts = 0
    num_orders = 0
    hit_clicks = 0
    hit_carts = 0
    hit_orders = 0

    for i in range(len(clicks_labels)):
        clicks_label = clicks_labels[i]
        carts_label = carts_labels[i]
        orders_label = orders_labels[i]
        clicks_pred = clicks_preds[i]
        carts_pred = carts_preds[i]
        orders_pred = orders_preds[i]

        if type(clicks_pred) == list:
            clicks_pred = clicks_pred[:k]
        else:
            clicks_pred = []
        if type(carts_pred) == list:
            carts_pred = carts_pred[:k]
        else:
            carts_pred = []    
        if type(orders_pred) == list:
            orders_pred = orders_pred[:k]
        else:
            orders_pred = []

        if not np.isnan(clicks_label):
            num_clicks += 1
            hit_clicks += int(clicks_label in clicks_pred)

        if type(carts_label) == list:
            num_carts += min(len(carts_label), k)
            hit_carts += len(set(carts_pred) & set(carts_label))
            
        if type(orders_label) == list:
            num_orders += min(len(orders_label), k)
            hit_orders += len(set(orders_pred) & set(orders_label))


    recall_clicks = hit_clicks / num_clicks
    recall_carts = hit_carts / num_carts
    recall_orders = hit_orders / num_orders
    w_recall_clicks = recall_clicks * 0.10
    w_recall_carts = recall_carts * 0.30
    w_recall_orders = recall_orders * 0.60
    score = w_recall_clicks + w_recall_carts + w_recall_orders

    results = {}
    results["num_clicks"] = num_clicks
    results["hit_clicks"] = hit_clicks
    results["num_carts"] = num_carts
    results["hit_carts"] = hit_carts
    results["num_orders"] = num_orders
    results["hit_orders"] = hit_orders
    results["recall_clicks"] = format(recall_clicks, ".3f")
    results["recall_carts"] = format(recall_carts, ".3f")
    results["recall_orders"] = format(recall_orders, ".3f")
    results["w_recall_clicks"] = format(w_recall_clicks, ".3f")
    results["w_recall_carts"] = format(w_recall_carts, ".3f")
    results["w_recall_orders"] = format(w_recall_orders, ".3f")
    results["score"] = format(score, ".3f")

    return results

# %%
class Candidate:
    @noglobal(excepts=["cfg", "logger"])
    def __init__(self, pdf, labels=None):
        self.df = cudf.from_pandas(pdf)
        self.target_sessions = pdf["session"].unique().tolist()
        self.results = pd.DataFrame(columns=["name", "num_clicks", "hit_clicks", "num_carts", "hit_carts", "num_orders", "hit_orders", 
                                             "recall_clicks", "recall_carts", "recall_orders", "w_recall_clicks", "w_recall_carts", "w_recall_orders", "score"])
        self.output = pd.DataFrame(columns=["session", "aid", "strategy", "rank"], dtype=int)
        self.labels = labels
    
    @noglobal(excepts=["cfg", "logger"])
    def _entry(self, new_candidate_df, name, k):
        logger.info(f"[add_candidate] {name} : start")
        new_candidate_df["strategy"] = name
        new_candidate_df[f"rank"] = new_candidate_df.groupby("session")["session"].cumcount() + 1
        new_candidate_df = new_candidate_df.to_pandas()
        self.output = pd.concat([self.output, new_candidate_df[["session", "aid", "strategy", "rank"]]])

        if self.labels is not None:
            self._eval(new_candidate_df[["session", "aid"]], name, k)
    
    @noglobal(excepts=["cfg", "logger"])
    def _eval(self, new_candidate_df, name, k):
        new_candidate_df = new_candidate_df.groupby("session")["aid"].apply(list).reset_index()
        eval_df = pd.DataFrame(self.target_sessions, columns=["session"])
        eval_df = eval_df.merge(new_candidate_df, on=["session"], how="left")
        assert eval_df["session"].tolist() == self.labels["session"].tolist()
        eval_result = evaluate(self.labels["clicks_labels"].tolist(), self.labels["carts_labels"].tolist(), self.labels["orders_labels"].tolist(),
                               eval_df["aid"].tolist(), eval_df["aid"].tolist(), eval_df["aid"].tolist(), k)
        
        logger.info(str(eval_result))
        self.results = pd.concat([self.results, pd.DataFrame([[name] + list(eval_result.values())], columns=["name"] + list(eval_result.keys()))])

    @noglobal(excepts=["cfg", "logger"])
    def add(self, strategy, name, usetypes=['clicks', 'carts', 'orders'], trans_map=None, k=20):
        logger.info(f"[make_candidate] {name} : start")
        candidate_df = self.df[self.df["type"].isin(usetypes)].copy()
        
        if strategy == "session_frequent":
            candidate_df = self._session_frequent(candidate_df, k)
        elif strategy == "session_latest":
            candidate_df = self._session_latest(candidate_df, k)
        elif strategy == "total_frequent":
            candidate_df = self._total_frequent(candidate_df, k)
        
        if trans_map is not None:
            candidate_df["aid"] = candidate_df["aid"].map(trans_map)
            candidate_df = candidate_df.dropna(subset=["aid"])
            
        self._entry(candidate_df, name, k)

    @noglobal(excepts=["cfg", "logger"])
    def _session_frequent(self, candidate_df, k):
        candidate_df = candidate_df.groupby(["session", "aid"])["ts"].count().reset_index()
        candidate_df.columns = ["session", "aid", "aid_count"]
        candidate_df = candidate_df.sort_values(["session", "aid_count", "aid"], ascending=(True, False, True))
        candidate_df = candidate_df[candidate_df.groupby("session")["aid_count"].cumcount() < k].copy()
        candidate_df = candidate_df[["session", "aid"]].copy()
        return candidate_df

    @noglobal(excepts=["cfg", "logger"])
    def _session_latest(self, candidate_df, k):
        candidate_df = candidate_df.sort_values(["session", "ts"], ascending=(True, False)).drop_duplicates(subset=["session", "aid"])
        candidate_df = candidate_df.sort_values(["session", "ts"], ascending=(True, False))[candidate_df.groupby("session")["ts"].cumcount() < k].copy()
        candidate_df = candidate_df[["session", "aid"]].copy()
        return candidate_df

    @noglobal(excepts=["cfg", "logger"])
    def _total_frequent(self, candidate_df, k):
        candidate_df = candidate_df.groupby("aid")["ts"].count().reset_index()
        candidate_df.columns = ["aid", "aid_count"]
        topk_freq_aids = candidate_df.sort_values("aid_count", ascending=False)["aid"].to_arrow().to_pylist()[:k]
        sessions = []
        aids = []
        for session, aid in itertools.product(self.target_sessions, topk_freq_aids):
            sessions.append(session)
            aids.append(aid)
        candidate_df = cudf.DataFrame({"session": sessions, "aid": aids})
        return candidate_df

# %%
@noglobal(excepts=["cfg", "logger"])
def make_cand_df(sessions, labels=None, trans_maps=None):

    if labels is not None:
         cand = Candidate(sessions, labels)
    else:
        cand = Candidate(sessions)

    cand.add(strategy="session_frequent", name="session_frequent", k=cfg.cand_n)
    cand.add(strategy="session_latest", name="session_latest", k=cfg.cand_n)
    # cand.add(strategy="total_frequent", name="total_frequent", k=cfg.cand_n)
    cand.add(strategy="session_frequent", trans_map=trans_maps["pair0"], name="session_frequent_pair", k=cfg.cand_n)
    
    for i in range(10):
        cand.add(strategy="session_latest", trans_map=trans_maps[f"pair{str(i)}"], name=f"session_latest_pair{str(i)}", k=cfg.cand_n)
    
    for i in range(10):
        cand.add(strategy="session_latest", trans_map=trans_maps[f"time_wt_pair{str(i)}"], name=f"session_latest_time_wt_pair{str(i)}", k=cfg.cand_n)
    
    cand.add(strategy="session_latest", trans_map=trans_maps["type_wt_pair"], name="session_latest_type_wt_pair", k=cfg.cand_n)
    cand.add(strategy="session_latest", trans_map=trans_maps["clicks2carts_pair"], name="session_latest_clicks2carts_pair", k=cfg.cand_n)
    cand.add(strategy="session_latest", trans_map=trans_maps["clicks2orders_pair"], name="session_latest_clicks2orders_pair", k=cfg.cand_n)
    if labels is not None:
        return cand.output, cand.results
    else:
        return cand.output

# %%
@noglobal(excepts=["cfg", "logger"])
def get_trans_maps():
    """
    aidを別のaidに置き換えるmapping辞書を取得する
    """
    trans_maps = {}

    pair_df_org = pd.read_pickle(cfg.prep_dir + "co_visitation_matrix_v5.pkl")
    pair_df_org = pair_df_org[pair_df_org["cnt"] > 3].copy()
    pair_df_org = pair_df_org.sort_values(["aid_x", "cnt"], ascending=(True, False))
    for i in range(10):
        pair_df = pair_df_org.groupby("aid_x").nth(i).reset_index()[["aid_x", "aid_y"]]
        pair_dict = {k: v for k, v in zip(pair_df["aid_x"].tolist(), pair_df["aid_y"].tolist())}
        trans_maps[f"pair{str(i)}"] = pair_dict

    pair_df = pd.read_pickle(cfg.prep_dir + "co_visitation_matrix_clicks.pkl")
    pair_df = pair_df[pair_df["cnt"] > 3].copy()
    pair_df = pair_df.sort_values(["aid_x", "cnt"], ascending=(True, False))
    pair_df = pair_df.groupby("aid_x").head(1)[["aid_x", "aid_y"]]
    pair_dict = {k: v for k, v in zip(pair_df["aid_x"].tolist(), pair_df["aid_y"].tolist())}
    trans_maps["clicks_pair"] = pair_dict

    pair_df = pd.read_pickle(cfg.prep_dir + "co_visitation_matrix_carts.pkl")
    pair_df = pair_df[pair_df["cnt"] > 3].copy()
    pair_df = pair_df.sort_values(["aid_x", "cnt"], ascending=(True, False))
    pair_df = pair_df.groupby("aid_x").head(1)[["aid_x", "aid_y"]]
    pair_dict = {k: v for k, v in zip(pair_df["aid_x"].tolist(), pair_df["aid_y"].tolist())}
    trans_maps["carts_pair"] = pair_dict

    pair_df = pd.read_pickle(cfg.prep_dir + "co_visitation_matrix_orders.pkl")
    pair_df = pair_df[pair_df["cnt"] > 3].copy()
    pair_df = pair_df.sort_values(["aid_x", "cnt"], ascending=(True, False))
    pair_df = pair_df.groupby("aid_x").head(1)[["aid_x", "aid_y"]]
    pair_dict = {k: v for k, v in zip(pair_df["aid_x"].tolist(), pair_df["aid_y"].tolist())}
    trans_maps["orders_pair"] = pair_dict

    pair_df_org = pd.read_pickle(cfg.prep_dir + "co_visitation_matrix_time_weighted_v2.pkl")
    pair_df_org = pair_df_org.sort_values(["aid_x", "wt"], ascending=(True, False))
    for i in range(10):
        pair_df = pair_df_org.groupby("aid_x").nth(i).reset_index()[["aid_x", "aid_y"]]
        pair_dict = {k: v for k, v in zip(pair_df["aid_x"].tolist(), pair_df["aid_y"].tolist())}
        trans_maps[f"time_wt_pair{str(i)}"] = pair_dict

    pair_df = pd.read_pickle(cfg.prep_dir + "co_visitation_matrix_type_weighted.pkl")
    pair_df = pair_df.sort_values(["aid_x", "wt"], ascending=(True, False))
    pair_df = pair_df.groupby("aid_x").head(1)[["aid_x", "aid_y"]]
    pair_dict = {k: v for k, v in zip(pair_df["aid_x"].tolist(), pair_df["aid_y"].tolist())}
    trans_maps["type_wt_pair"] = pair_dict

    pair_df = pd.read_pickle(cfg.prep_dir + "co_visitation_matrix_clicks2carts.pkl")
    pair_df = pair_df.sort_values(["aid_x", "cnt"], ascending=(True, False))
    pair_df = pair_df.groupby("aid_x").head(1)[["aid_x", "aid_y"]]
    pair_dict = {k: v for k, v in zip(pair_df["aid_x"].tolist(), pair_df["aid_y"].tolist())}
    trans_maps["clicks2carts_pair"] = pair_dict

    pair_df = pd.read_pickle(cfg.prep_dir + "co_visitation_matrix_clicks2orders.pkl")
    pair_df = pair_df.sort_values(["aid_x", "cnt"], ascending=(True, False))
    pair_df = pair_df.groupby("aid_x").head(1)[["aid_x", "aid_y"]]
    pair_dict = {k: v for k, v in zip(pair_df["aid_x"].tolist(), pair_df["aid_y"].tolist())}
    trans_maps["clicks2orders_pair"] = pair_dict

    return trans_maps

# %%
class Cache:
    @noglobal(excepts=["cfg", "logger"])
    def __init__(self):
        self.cache_dir = (os.path.join(cfg.output_dir, cfg.exp_name, "cache"))
        self.cache_dir_path = pathlib.Path(self.cache_dir)
        self.caches = list(self.cache_dir_path.glob("*.pkl"))

    @noglobal(excepts=["cfg", "logger"])
    def get_abspath(self, filename):
        return (os.path.join(self.cache_dir, f"{cfg.exp_name}_{filename}"))
    
    @noglobal(excepts=["cfg", "logger"])
    def exists(self, path):
        return len([str(c) for c in self.caches if path == str(c)]) > 0

# %%
@noglobal(excepts=["cfg", "logger"])
def make_valid_data(trans_maps):
    valid_week = cfg.valid_week
    dfs = []
    
    logger.info(f"[make_valid] valid_week : {valid_week}")
    # データ読み込み
    logger.info("[make_valid] read_data : start")
    week_sessions = pd.read_pickle(os.getenv("PREP_DIR") + f"train_sessions_{valid_week}.pkl")
    week_labels = pd.read_pickle(os.getenv("PREP_DIR") + f"labels_{valid_week}.pkl")
    valid_session_ids = week_sessions["session"].unique().tolist()
    logger.info("[make_valid] read_data : end")

    # validに使うsessionを絞る (trainに存在するsessionを除外した上で設定した数に絞る)
    logger.info("[make_valid] valid_session_extract : start")
    valid_session_n = min(cfg.valid_session_n, len(valid_session_ids))
    valid_session_ids = random.sample(valid_session_ids, valid_session_n)
    week_sessions = week_sessions[week_sessions["session"].isin(valid_session_ids)].copy()
    week_labels = week_labels[week_labels["session"].isin(valid_session_ids)].copy()
    logger.info("[make_valid] valid_session_extract : end")

    # 候補選出
    logger.info("[make_valid] make_cand_df : start")
    valid, results = make_cand_df(week_sessions, labels=week_labels, trans_maps=trans_maps)

    return valid, week_labels, results

# %%
@noglobal(excepts=["cfg", "logger"])
def make_test_data(trans_maps):
    # testデータ作成
    test_sessions = pd.read_pickle(cfg.prep_dir + f"test_sessions.pkl")

    dfs =[]
    # 候補選出
    logger.info("[make_test] make_cand_df")
    test = make_cand_df(test_sessions, trans_maps=trans_maps)
    return test

# %%
logger.info(f"START")
line_notify.send(f"{cfg.exp_name} | START")

cache = Cache()

logger.info(f"-------- get_trans_maps --------")
cache_path = cache.get_abspath("trans_maps.pkl")
if cache.exists(cache_path):
    logger.info("cache exists. load cache and skip process.")
    with open(cache_path, "rb") as f:
        trans_maps = pickle.load(f)
else:
    trans_maps = get_trans_maps()
    with open(cache_path, "wb") as f:
        pickle.dump(trans_maps, f)

valid, valid_labels, results = make_valid_data(trans_maps)
# Out:
# 0:00:00.409531 	 START
# 0:00:00.546936 	 -------- get_trans_maps --------
# 0:01:08.867054 	 [make_valid] valid_week : week4
# 0:01:08.868674 	 [make_valid] read_data : start
# 0:01:15.717699 	 [make_valid] read_data : end
# 0:01:15.718786 	 [make_valid] valid_session_extract : start
# 0:01:16.696352 	 [make_valid] valid_session_extract : end
# 0:01:16.697456 	 [make_valid] make_cand_df : start
# 0:01:16.749613 	 [make_candidate] session_frequent : start
# 0:01:16.965213 	 [add_candidate] session_frequent : start
# 0:01:18.766547 	 {'num_clicks': 97136, 'hit_clicks': 29086, 'num_carts': 41843, 'hit_carts': 10282, 'num_orders': 19599, 'hit_orders': 9741, 'recall_clicks': '0.299', 'recall_carts': '0.246', 'recall_orders': '0.497', 'w_recall_clicks': '0.030', 'w_recall_carts': '0.074', 'w_recall_orders': '0.298', 'score': '0.402'}
# 0:01:18.781755 	 [make_candidate] session_latest : start
# 0:01:19.100422 	 [add_candidate] session_latest : start
# 0:01:20.692197 	 {'num_clicks': 97136, 'hit_clicks': 29497, 'num_carts': 41843, 'hit_carts': 10523, 'num_orders': 19599, 'hit_orders': 9242, 'recall_clicks': '0.304', 'recall_carts': '0.251', 'recall_orders': '0.472', 'w_recall_clicks': '0.030', 'w_recall_carts': '0.075', 'w_recall_orders': '0.283', 'score': '0.389'}
# 0:01:20.703197 	 [make_candidate] session_frequent_pair : start
# 0:01:21.073855 	 [add_candidate] session_frequent_pair : start
# 0:01:22.989009 	 {'num_clicks': 97136, 'hit_clicks': 8077, 'num_carts': 41843, 'hit_carts': 3468, 'num_orders': 19599, 'hit_orders': 2551, 'recall_clicks': '0.083', 'recall_carts': '0.083', 'recall_orders': '0.130', 'w_recall_clicks': '0.008', 'w_recall_carts': '0.025', 'w_recall_orders': '0.078', 'score': '0.111'}
# 0:01:23.001026 	 [make_candidate] session_latest_pair0 : start
# 0:01:23.506010 	 [add_candidate] session_latest_pair0 : start
# 0:01:25.426566 	 {'num_clicks': 97136, 'hit_clicks': 8240, 'num_carts': 41843, 'hit_carts': 3553, 'num_orders': 19599, 'hit_orders': 2549, 'recall_clicks': '0.085', 'recall_carts': '0.085', 'recall_orders': '0.130', 'w_recall_clicks': '0.008', 'w_recall_carts': '0.025', 'w_recall_orders': '0.078', 'score': '0.112'}
# 0:01:25.438300 	 [make_candidate] session_latest_pair1 : start
# 0:01:25.964830 	 [add_candidate] session_latest_pair1 : start
# 0:01:27.581651 	 {'num_clicks': 97136, 'hit_clicks': 5861, 'num_carts': 41843, 'hit_carts': 2817, 'num_orders': 19599, 'hit_orders': 1940, 'recall_clicks': '0.060', 'recall_carts': '0.067', 'recall_orders': '0.099', 'w_recall_clicks': '0.006', 'w_recall_carts': '0.020', 'w_recall_orders': '0.059', 'score': '0.086'}
# 0:01:27.593490 	 [make_candidate] session_latest_pair2 : start
# 0:01:28.073579 	 [add_candidate] session_latest_pair2 : start
# 0:01:29.881623 	 {'num_clicks': 97136, 'hit_clicks': 4552, 'num_carts': 41843, 'hit_carts': 2261, 'num_orders': 19599, 'hit_orders': 1568, 'recall_clicks': '0.047', 'recall_carts': '0.054', 'recall_orders': '0.080', 'w_recall_clicks': '0.005', 'w_recall_carts': '0.016', 'w_recall_orders': '0.048', 'score': '0.069'}
# 0:01:29.893759 	 [make_candidate] session_latest_pair3 : start
# 0:01:30.355210 	 [add_candidate] session_latest_pair3 : start
# 0:01:31.939387 	 {'num_clicks': 97136, 'hit_clicks': 3881, 'num_carts': 41843, 'hit_carts': 2034, 'num_orders': 19599, 'hit_orders': 1438, 'recall_clicks': '0.040', 'recall_carts': '0.049', 'recall_orders': '0.073', 'w_recall_clicks': '0.004', 'w_recall_carts': '0.015', 'w_recall_orders': '0.044', 'score': '0.063'}
# 0:01:31.953436 	 [make_candidate] session_latest_pair4 : start
# 0:01:32.225187 	 [add_candidate] session_latest_pair4 : start
# 0:01:34.031653 	 {'num_clicks': 97136, 'hit_clicks': 3347, 'num_carts': 41843, 'hit_carts': 1692, 'num_orders': 19599, 'hit_orders': 1229, 'recall_clicks': '0.034', 'recall_carts': '0.040', 'recall_orders': '0.063', 'w_recall_clicks': '0.003', 'w_recall_carts': '0.012', 'w_recall_orders': '0.038', 'score': '0.053'}
# 0:01:34.043095 	 [make_candidate] session_latest_pair5 : start
# 0:01:34.404426 	 [add_candidate] session_latest_pair5 : start
# 0:01:36.025002 	 {'num_clicks': 97136, 'hit_clicks': 2978, 'num_carts': 41843, 'hit_carts': 1639, 'num_orders': 19599, 'hit_orders': 1065, 'recall_clicks': '0.031', 'recall_carts': '0.039', 'recall_orders': '0.054', 'w_recall_clicks': '0.003', 'w_recall_carts': '0.012', 'w_recall_orders': '0.033', 'score': '0.047'}
# 0:01:36.037305 	 [make_candidate] session_latest_pair6 : start
# 0:01:36.497433 	 [add_candidate] session_latest_pair6 : start
# 0:01:38.293494 	 {'num_clicks': 97136, 'hit_clicks': 2707, 'num_carts': 41843, 'hit_carts': 1476, 'num_orders': 19599, 'hit_orders': 999, 'recall_clicks': '0.028', 'recall_carts': '0.035', 'recall_orders': '0.051', 'w_recall_clicks': '0.003', 'w_recall_carts': '0.011', 'w_recall_orders': '0.031', 'score': '0.044'}
# 0:01:38.305424 	 [make_candidate] session_latest_pair7 : start
# 0:01:38.725574 	 [add_candidate] session_latest_pair7 : start
# 0:01:40.534997 	 {'num_clicks': 97136, 'hit_clicks': 2483, 'num_carts': 41843, 'hit_carts': 1372, 'num_orders': 19599, 'hit_orders': 898, 'recall_clicks': '0.026', 'recall_carts': '0.033', 'recall_orders': '0.046', 'w_recall_clicks': '0.003', 'w_recall_carts': '0.010', 'w_recall_orders': '0.027', 'score': '0.040'}
# 0:01:40.547422 	 [make_candidate] session_latest_pair8 : start
# 0:01:40.799100 	 [add_candidate] session_latest_pair8 : start
# 0:01:42.378082 	 {'num_clicks': 97136, 'hit_clicks': 2243, 'num_carts': 41843, 'hit_carts': 1249, 'num_orders': 19599, 'hit_orders': 827, 'recall_clicks': '0.023', 'recall_carts': '0.030', 'recall_orders': '0.042', 'w_recall_clicks': '0.002', 'w_recall_carts': '0.009', 'w_recall_orders': '0.025', 'score': '0.037'}
# 0:01:42.390717 	 [make_candidate] session_latest_pair9 : start
# 0:01:42.728174 	 [add_candidate] session_latest_pair9 : start
# 0:01:44.566911 	 {'num_clicks': 97136, 'hit_clicks': 2061, 'num_carts': 41843, 'hit_carts': 1089, 'num_orders': 19599, 'hit_orders': 737, 'recall_clicks': '0.021', 'recall_carts': '0.026', 'recall_orders': '0.038', 'w_recall_clicks': '0.002', 'w_recall_carts': '0.008', 'w_recall_orders': '0.023', 'score': '0.032'}
# 0:01:44.579771 	 [make_candidate] session_latest_time_wt_pair0 : start
# 0:01:45.086209 	 [add_candidate] session_latest_time_wt_pair0 : start
# 0:01:46.782569 	 {'num_clicks': 97136, 'hit_clicks': 9259, 'num_carts': 41843, 'hit_carts': 2857, 'num_orders': 19599, 'hit_orders': 2007, 'recall_clicks': '0.095', 'recall_carts': '0.068', 'recall_orders': '0.102', 'w_recall_clicks': '0.010', 'w_recall_carts': '0.020', 'w_recall_orders': '0.061', 'score': '0.091'}
# 0:01:46.795337 	 [make_candidate] session_latest_time_wt_pair1 : start
# 0:01:47.332152 	 [add_candidate] session_latest_time_wt_pair1 : start
# 0:01:49.314622 	 {'num_clicks': 97136, 'hit_clicks': 6638, 'num_carts': 41843, 'hit_carts': 2305, 'num_orders': 19599, 'hit_orders': 1548, 'recall_clicks': '0.068', 'recall_carts': '0.055', 'recall_orders': '0.079', 'w_recall_clicks': '0.007', 'w_recall_carts': '0.017', 'w_recall_orders': '0.047', 'score': '0.071'}
# 0:01:49.328202 	 [make_candidate] session_latest_time_wt_pair2 : start
# 0:01:49.786165 	 [add_candidate] session_latest_time_wt_pair2 : start
# 0:01:51.457834 	 {'num_clicks': 97136, 'hit_clicks': 5146, 'num_carts': 41843, 'hit_carts': 1859, 'num_orders': 19599, 'hit_orders': 1323, 'recall_clicks': '0.053', 'recall_carts': '0.044', 'recall_orders': '0.068', 'w_recall_clicks': '0.005', 'w_recall_carts': '0.013', 'w_recall_orders': '0.041', 'score': '0.059'}
# 0:01:51.471019 	 [make_candidate] session_latest_time_wt_pair3 : start
# 0:01:51.777381 	 [add_candidate] session_latest_time_wt_pair3 : start
# 0:01:53.632327 	 {'num_clicks': 97136, 'hit_clicks': 4495, 'num_carts': 41843, 'hit_carts': 1625, 'num_orders': 19599, 'hit_orders': 1136, 'recall_clicks': '0.046', 'recall_carts': '0.039', 'recall_orders': '0.058', 'w_recall_clicks': '0.005', 'w_recall_carts': '0.012', 'w_recall_orders': '0.035', 'score': '0.051'}
# 0:01:53.644959 	 [make_candidate] session_latest_time_wt_pair4 : start
# 0:01:54.085122 	 [add_candidate] session_latest_time_wt_pair4 : start
# 0:01:56.032622 	 {'num_clicks': 97136, 'hit_clicks': 3872, 'num_carts': 41843, 'hit_carts': 1464, 'num_orders': 19599, 'hit_orders': 1022, 'recall_clicks': '0.040', 'recall_carts': '0.035', 'recall_orders': '0.052', 'w_recall_clicks': '0.004', 'w_recall_carts': '0.010', 'w_recall_orders': '0.031', 'score': '0.046'}
# 0:01:56.045527 	 [make_candidate] session_latest_time_wt_pair5 : start
# 0:01:56.538804 	 [add_candidate] session_latest_time_wt_pair5 : start
# 0:01:58.239745 	 {'num_clicks': 97136, 'hit_clicks': 3467, 'num_carts': 41843, 'hit_carts': 1203, 'num_orders': 19599, 'hit_orders': 913, 'recall_clicks': '0.036', 'recall_carts': '0.029', 'recall_orders': '0.047', 'w_recall_clicks': '0.004', 'w_recall_carts': '0.009', 'w_recall_orders': '0.028', 'score': '0.040'}
# 0:01:58.253358 	 [make_candidate] session_latest_time_wt_pair6 : start
# 0:01:58.752293 	 [add_candidate] session_latest_time_wt_pair6 : start
# 0:02:00.655597 	 {'num_clicks': 97136, 'hit_clicks': 3177, 'num_carts': 41843, 'hit_carts': 1196, 'num_orders': 19599, 'hit_orders': 836, 'recall_clicks': '0.033', 'recall_carts': '0.029', 'recall_orders': '0.043', 'w_recall_clicks': '0.003', 'w_recall_carts': '0.009', 'w_recall_orders': '0.026', 'score': '0.037'}
# 0:02:00.669482 	 [make_candidate] session_latest_time_wt_pair7 : start
# 0:02:00.983650 	 [add_candidate] session_latest_time_wt_pair7 : start
# 0:02:02.715569 	 {'num_clicks': 97136, 'hit_clicks': 2860, 'num_carts': 41843, 'hit_carts': 1146, 'num_orders': 19599, 'hit_orders': 763, 'recall_clicks': '0.029', 'recall_carts': '0.027', 'recall_orders': '0.039', 'w_recall_clicks': '0.003', 'w_recall_carts': '0.008', 'w_recall_orders': '0.023', 'score': '0.035'}
# 0:02:02.729378 	 [make_candidate] session_latest_time_wt_pair8 : start
# 0:02:03.138649 	 [add_candidate] session_latest_time_wt_pair8 : start
# 0:02:05.060437 	 {'num_clicks': 97136, 'hit_clicks': 2735, 'num_carts': 41843, 'hit_carts': 1011, 'num_orders': 19599, 'hit_orders': 712, 'recall_clicks': '0.028', 'recall_carts': '0.024', 'recall_orders': '0.036', 'w_recall_clicks': '0.003', 'w_recall_carts': '0.007', 'w_recall_orders': '0.022', 'score': '0.032'}
# 0:02:05.074871 	 [make_candidate] session_latest_time_wt_pair9 : start
# 0:02:05.558674 	 [add_candidate] session_latest_time_wt_pair9 : start
# 0:02:07.562681 	 {'num_clicks': 97136, 'hit_clicks': 2539, 'num_carts': 41843, 'hit_carts': 960, 'num_orders': 19599, 'hit_orders': 654, 'recall_clicks': '0.026', 'recall_carts': '0.023', 'recall_orders': '0.033', 'w_recall_clicks': '0.003', 'w_recall_carts': '0.007', 'w_recall_orders': '0.020', 'score': '0.030'}
# 0:02:07.576060 	 [make_candidate] session_latest_type_wt_pair : start
# 0:02:07.933746 	 [add_candidate] session_latest_type_wt_pair : start
# 0:02:09.598138 	 {'num_clicks': 97136, 'hit_clicks': 7411, 'num_carts': 41843, 'hit_carts': 3719, 'num_orders': 19599, 'hit_orders': 2775, 'recall_clicks': '0.076', 'recall_carts': '0.089', 'recall_orders': '0.142', 'w_recall_clicks': '0.008', 'w_recall_carts': '0.027', 'w_recall_orders': '0.085', 'score': '0.119'}
# 0:02:09.611160 	 [make_candidate] session_latest_clicks2carts_pair : start
# 0:02:10.064456 	 [add_candidate] session_latest_clicks2carts_pair : start
# 0:02:12.075589 	 {'num_clicks': 97136, 'hit_clicks': 4696, 'num_carts': 41843, 'hit_carts': 3006, 'num_orders': 19599, 'hit_orders': 1904, 'recall_clicks': '0.048', 'recall_carts': '0.072', 'recall_orders': '0.097', 'w_recall_clicks': '0.005', 'w_recall_carts': '0.022', 'w_recall_orders': '0.058', 'score': '0.085'}
# 0:02:12.088104 	 [make_candidate] session_latest_clicks2orders_pair : start
# 0:02:12.470147 	 [add_candidate] session_latest_clicks2orders_pair : start
# 0:02:14.055700 	 {'num_clicks': 97136, 'hit_clicks': 3034, 'num_carts': 41843, 'hit_carts': 2037, 'num_orders': 19599, 'hit_orders': 1999, 'recall_clicks': '0.031', 'recall_carts': '0.049', 'recall_orders': '0.102', 'w_recall_clicks': '0.003', 'w_recall_carts': '0.015', 'w_recall_orders': '0.061', 'score': '0.079'}

# %%
results
# Out:
#                                 name num_clicks hit_clicks num_carts  \
# 0                   session_frequent      97136      29086     41843
# 0                     session_latest      97136      29497     41843
# 0              session_frequent_pair      97136       8077     41843
# 0               session_latest_pair0      97136       8240     41843
# 0               session_latest_pair1      97136       5861     41843
# 0               session_latest_pair2      97136       4552     41843
# 0               session_latest_pair3      97136       3881     41843
# 0               session_latest_pair4      97136       3347     41843
# 0               session_latest_pair5      97136       2978     41843
# 0               session_latest_pair6      97136       2707     41843
# 0               session_latest_pair7      97136       2483     41843
# 0               session_latest_pair8      97136       2243     41843
# 0               session_latest_pair9      97136       2061     41843
# 0       session_latest_time_wt_pair0      97136       9259     41843
# 0       session_latest_time_wt_pair1      97136       6638     41843
# 0       session_latest_time_wt_pair2      97136       5146     41843
# 0       session_latest_time_wt_pair3      97136       4495     41843
# 0       session_latest_time_wt_pair4      97136       3872     41843
# 0       session_latest_time_wt_pair5      97136       3467     41843
# 0       session_latest_time_wt_pair6      97136       3177     41843
# 0       session_latest_time_wt_pair7      97136       2860     41843
# 0       session_latest_time_wt_pair8      97136       2735     41843
# 0       session_latest_time_wt_pair9      97136       2539     41843
# 0        session_latest_type_wt_pair      97136       7411     41843
# 0   session_latest_clicks2carts_pair      97136       4696     41843
# 0  session_latest_clicks2orders_pair      97136       3034     41843
#
#   hit_carts num_orders hit_orders recall_clicks recall_carts recall_orders  \
# 0     10282      19599       9741         0.299        0.246         0.497
# 0     10523      19599       9242         0.304        0.251         0.472
# 0      3468      19599       2551         0.083        0.083         0.130
# 0      3553      19599       2549         0.085        0.085         0.130
# 0      2817      19599       1940         0.060        0.067         0.099
# 0      2261      19599       1568         0.047        0.054         0.080
# 0      2034      19599       1438         0.040        0.049         0.073
# 0      1692      19599       1229         0.034        0.040         0.063
# 0      1639      19599       1065         0.031        0.039         0.054
# 0      1476      19599        999         0.028        0.035         0.051
# 0      1372      19599        898         0.026        0.033         0.046
# 0      1249      19599        827         0.023        0.030         0.042
# 0      1089      19599        737         0.021        0.026         0.038
# 0      2857      19599       2007         0.095        0.068         0.102
# 0      2305      19599       1548         0.068        0.055         0.079
# 0      1859      19599       1323         0.053        0.044         0.068
# 0      1625      19599       1136         0.046        0.039         0.058
# 0      1464      19599       1022         0.040        0.035         0.052
# 0      1203      19599        913         0.036        0.029         0.047
# 0      1196      19599        836         0.033        0.029         0.043
# 0      1146      19599        763         0.029        0.027         0.039
# 0      1011      19599        712         0.028        0.024         0.036
# 0       960      19599        654         0.026        0.023         0.033
# 0      3719      19599       2775         0.076        0.089         0.142
# 0      3006      19599       1904         0.048        0.072         0.097
# 0      2037      19599       1999         0.031        0.049         0.102
#
#   w_recall_clicks w_recall_carts w_recall_orders  score
# 0           0.030          0.074           0.298  0.402
# 0           0.030          0.075           0.283  0.389
# 0           0.008          0.025           0.078  0.111
# 0           0.008          0.025           0.078  0.112
# 0           0.006          0.020           0.059  0.086
# 0           0.005          0.016           0.048  0.069
# 0           0.004          0.015           0.044  0.063
# 0           0.003          0.012           0.038  0.053
# 0           0.003          0.012           0.033  0.047
# 0           0.003          0.011           0.031  0.044
# 0           0.003          0.010           0.027  0.040
# 0           0.002          0.009           0.025  0.037
# 0           0.002          0.008           0.023  0.032
# 0           0.010          0.020           0.061  0.091
# 0           0.007          0.017           0.047  0.071
# 0           0.005          0.013           0.041  0.059
# 0           0.005          0.012           0.035  0.051
# 0           0.004          0.010           0.031  0.046
# 0           0.004          0.009           0.028  0.040
# 0           0.003          0.009           0.026  0.037
# 0           0.003          0.008           0.023  0.035
# 0           0.003          0.007           0.022  0.032
# 0           0.003          0.007           0.020  0.030
# 0           0.008          0.027           0.085  0.119
# 0           0.005          0.022           0.058  0.085
# 0           0.003          0.015           0.061  0.079

# %%
fig, axs = plt.subplots(1, 3)
sns.heatmap(results.set_index("name")[["recall_clicks"]].astype(float),
            annot=True, linewidths=.5, fmt="1.2f", cmap="Reds", cbar=False, ax=axs[0])
sns.heatmap(results.set_index("name")[["recall_carts"]].astype(float),
            annot=True, linewidths=.5, fmt="1.2f", cmap="Reds", cbar=False, ax=axs[1], yticklabels=False)
sns.heatmap(results.set_index("name")[["recall_orders"]].astype(float),
            annot=True, linewidths=.5, fmt="1.2f", cmap="Reds", cbar=False, ax=axs[2], yticklabels=False)
plt.savefig(cfg.output_dir + f'{cfg.exp_name}/candidate_strategy_recalls.png')

# %%
# 予測値を全て使えたときのrecall
valid_all = valid.drop_duplicates(subset= ["session", "aid"])
session_cnt_max = valid_all["session"].value_counts().max()
valid_all = valid_all.groupby("session")["aid"].apply(list).reset_index()

all_results = evaluate(valid_labels["clicks_labels"].tolist(),
                       valid_labels["carts_labels"].tolist(),
                       valid_labels["orders_labels"].tolist(),
                       valid_all["aid"].tolist(),
                       valid_all["aid"].tolist(),
                       valid_all["aid"].tolist(),
                       session_cnt_max)
logger.info("session_cnt_max")
logger.info(session_cnt_max)
logger.info("all_pred_results")
logger.info(all_results)
# Out:
# 0:02:18.107496 	 session_cnt_max
# 0:02:18.108712 	 214
# 0:02:18.109535 	 all_pred_results
# 0:02:18.110231 	 {'num_clicks': 97136, 'hit_clicks': 54016, 'num_carts': 43611, 'hit_carts': 19921, 'num_orders': 20109, 'hit_orders': 13444, 'recall_clicks': '0.556', 'recall_carts': '0.457', 'recall_orders': '0.669', 'w_recall_clicks': '0.056', 'w_recall_carts': '0.137', 'w_recall_orders': '0.401', 'score': '0.594'}

# %%
def objective_type_recall(df, labels, type_):
    def objective(trial):
        trial_df = df.copy()
        session_frequent = trial.suggest_float("session_frequent", 0, 1)
        session_latest = trial.suggest_float("session_latest", 0, 1)
        session_frequent_pair = trial.suggest_float("session_frequent_pair", 0, 1)
        session_latest_pair0 = trial.suggest_float("session_latest_pair0", 0, 1)
        session_latest_pair1 = trial.suggest_float("session_latest_pair1", 0, 1)
        session_latest_pair2 = trial.suggest_float("session_latest_pair2", 0, 1)
        session_latest_pair3 = trial.suggest_float("session_latest_pair3", 0, 1)
        session_latest_pair4 = trial.suggest_float("session_latest_pair4", 0, 1)
        session_latest_pair5 = trial.suggest_float("session_latest_pair5", 0, 1)
        session_latest_pair6 = trial.suggest_float("session_latest_pair6", 0, 1)
        session_latest_pair7 = trial.suggest_float("session_latest_pair7", 0, 1)
        session_latest_pair8 = trial.suggest_float("session_latest_pair8", 0, 1)
        session_latest_pair9 = trial.suggest_float("session_latest_pair9", 0, 1)

        session_latest_time_wt_pair0 = trial.suggest_float("session_latest_time_wt_pair0", 0, 1)
        session_latest_time_wt_pair1 = trial.suggest_float("session_latest_time_wt_pair1", 0, 1)
        session_latest_time_wt_pair2 = trial.suggest_float("session_latest_time_wt_pair2", 0, 1)
        session_latest_time_wt_pair3 = trial.suggest_float("session_latest_time_wt_pair3", 0, 1)
        session_latest_time_wt_pair4 = trial.suggest_float("session_latest_time_wt_pair4", 0, 1)
        session_latest_time_wt_pair5 = trial.suggest_float("session_latest_time_wt_pair5", 0, 1)
        session_latest_time_wt_pair6 = trial.suggest_float("session_latest_time_wt_pair6", 0, 1)
        session_latest_time_wt_pair7 = trial.suggest_float("session_latest_time_wt_pair7", 0, 1)
        session_latest_time_wt_pair8 = trial.suggest_float("session_latest_time_wt_pair8", 0, 1)
        session_latest_time_wt_pair9 = trial.suggest_float("session_latest_time_wt_pair9", 0, 1)
        
        session_latest_time_wt_pair = trial.suggest_float("session_latest_time_wt_pair", 0, 1)
        session_latest_type_wt_pair = trial.suggest_float("session_latest_type_wt_pair", 0, 1)
        session_latest_clicks2carts_pair = trial.suggest_float("session_latest_clicks2carts_pair", 0, 1)
        session_latest_clicks2orders_pair = trial.suggest_float("session_latest_clicks2orders_pair", 0, 1)
        
        wt_dict = {
            'session_frequent': session_frequent,
            'session_latest': session_latest, 
            'session_frequent_pair': session_frequent_pair, 
            'session_latest_pair0': session_latest_pair0,
            'session_latest_pair1': session_latest_pair1, 
            'session_latest_pair2': session_latest_pair2,
            'session_latest_pair3': session_latest_pair3, 
            'session_latest_pair4': session_latest_pair4,
            'session_latest_pair5': session_latest_pair5,
            'session_latest_pair6': session_latest_pair6,
            'session_latest_pair7': session_latest_pair7,
            'session_latest_pair8': session_latest_pair8,
            'session_latest_pair9': session_latest_pair9,
            'session_latest_time_wt_pair0': session_latest_time_wt_pair0,
            'session_latest_time_wt_pair1': session_latest_time_wt_pair1, 
            'session_latest_time_wt_pair2': session_latest_time_wt_pair2,
            'session_latest_time_wt_pair3': session_latest_time_wt_pair3, 
            'session_latest_time_wt_pair4': session_latest_time_wt_pair4,
            'session_latest_time_wt_pair5': session_latest_time_wt_pair5,
            'session_latest_time_wt_pair6': session_latest_time_wt_pair6,
            'session_latest_time_wt_pair7': session_latest_time_wt_pair7,
            'session_latest_time_wt_pair8': session_latest_time_wt_pair8,
            'session_latest_time_wt_pair9': session_latest_time_wt_pair9,
            'session_latest_time_wt_time_wt_pair': session_latest_time_wt_pair,
            'session_latest_time_wt_type_wt_pair': session_latest_type_wt_pair,
            'session_latest_clicks2carts_pair': session_latest_clicks2carts_pair,
            'session_latest_clicks2orders_pair': session_latest_clicks2orders_pair,
        }

        trial_df["rank"] = trial_df["rank"] * trial_df["strategy"].map(wt_dict)
        trial_df = trial_df.sort_values(["session", "rank"])
        trial_df = trial_df.drop_duplicates(subset= ["session", "aid"], keep="first")
        trial_df = trial_df.groupby(["session"]).head(20)
        trial_df = trial_df.groupby("session")["aid"].apply(list).reset_index()

        result = evaluate(labels["clicks_labels"].tolist(),
                          labels["carts_labels"].tolist(),
                          labels["orders_labels"].tolist(),
                          trial_df["aid"].tolist(),
                          trial_df["aid"].tolist(),
                          trial_df["aid"].tolist(),
                          cfg.k)

        return float(result[f"recall_{type_}"])
    return objective

# %%
n_trials = 100

# %% [markdown]
# # パラメータチューニング

# %%
wt = {}
recall = {}

for type_ in ["clicks", "carts", "orders"]:
    logger.info(type_)
    study = optuna.create_study(direction="maximize")
    study.optimize(objective_type_recall(valid, valid_labels, type_), n_trials=n_trials)
    wt[type_] = study.best_params
    recall[type_] = study.best_value
    logger.info(f"{type_}_recall_best_weights : {str(study.best_params)}")
    logger.info(f"{type_}_recall_best_value : {study.best_value}")

score = (recall["clicks"] * 0.1) + (recall["carts"] * 0.3) + (recall["orders"] * 0.6)
logger.info(f"SCORE : {score}")
# Out:
# 0:02:18.225416 	 clicks
# [I 2022-12-07 01:43:39,183] A new study created in memory with name: no-name-60dd3b89-961d-41ca-9c3e-d7bd15cdabd5
# [I 2022-12-07 01:43:44,759] Trial 0 finished with value: 0.446 and parameters: {'session_frequent': 0.7175572238957875, 'session_latest': 0.30470957773967877, 'session_frequent_pair': 0.612588099406637, 'session_latest_pair0': 0.6450374296811144, 'session_latest_pair1': 0.6872861278118704, 'session_latest_pair2': 0.9277449804835949, 'session_latest_pair3': 0.09508048867287255, 'session_latest_pair4': 0.3967959350366074, 'session_latest_pair5': 0.309692955962262, 'session_latest_pair6': 0.3011300642670671, 'session_latest_pair7': 0.3899952187822827, 'session_latest_pair8': 0.08874014433729094, 'session_latest_pair9': 0.13766152897434558, 'session_latest_time_wt_pair0': 0.9597703490343167, 'session_latest_time_wt_pair1': 0.06219466277225516, 'session_latest_time_wt_pair2': 0.8722789658945269, 'session_latest_time_wt_pair3': 0.8022377117253073, 'session_latest_time_wt_pair4': 0.7934617172713557, 'session_latest_time_wt_pair5': 0.7266454514766082, 'session_latest_time_wt_pair6': 0.336134951283675, 'session_latest_time_wt_pair7': 0.07782526309340276, 'session_latest_time_wt_pair8': 0.5020221930611475, 'session_latest_time_wt_pair9': 0.20961192066259315, 'session_latest_time_wt_pair': 0.3265647327841863, 'session_latest_type_wt_pair': 0.3904446875918849, 'session_latest_clicks2carts_pair': 0.7707387716209447, 'session_latest_clicks2orders_pair': 0.16719179267114304}. Best is trial 0 with value: 0.446.
# [I 2022-12-07 01:43:49,950] Trial 1 finished with value: 0.444 and parameters: {'session_frequent': 0.6264120335363401, 'session_latest': 0.4175565399782467, 'session_frequent_pair': 0.4485962886593333, 'session_latest_pair0': 0.9180654434387503, 'session_latest_pair1': 0.7889535969640906, 'session_latest_pair2': 0.7061982450625565, 'session_latest_pair3': 0.023688440956013412, 'session_latest_pair4': 0.6394987805361193, 'session_latest_pair5': 0.4612017046075947, 'session_latest_pair6': 0.24017871666470847, 'session_latest_pair7': 0.2400767698287587, 'session_latest_pair8': 0.5012226074704517, 'session_latest_pair9': 0.11083750587542718, 'session_latest_time_wt_pair0': 0.1673421181074104, 'session_latest_time_wt_pair1': 0.30520211947423836, 'session_latest_time_wt_pair2': 0.30649818319557753, 'session_latest_time_wt_pair3': 0.6666747621424356, 'session_latest_time_wt_pair4': 0.9243574790587386, 'session_latest_time_wt_pair5': 0.028467560384792256, 'session_latest_time_wt_pair6': 0.7669796225874176, 'session_latest_time_wt_pair7': 0.764391697949773, 'session_latest_time_wt_pair8': 0.23699688578813027, 'session_latest_time_wt_pair9': 0.8821882380661266, 'session_latest_time_wt_pair': 0.964116027079619, 'session_latest_type_wt_pair': 0.049173995187257624, 'session_latest_clicks2carts_pair': 0.23740430517039768, 'session_latest_clicks2orders_pair': 0.7439724396357772}. Best is trial 0 with value: 0.446.
# [I 2022-12-07 01:43:55,560] Trial 2 finished with value: 0.415 and parameters: {'session_frequent': 0.3517094510977171, 'session_latest': 0.7114842713623054, 'session_frequent_pair': 0.14241128369527567, 'session_latest_pair0': 0.48339283569170943, 'session_latest_pair1': 0.5737830966514491, 'session_latest_pair2': 0.4920826879156178, 'session_latest_pair3': 0.7950922669802253, 'session_latest_pair4': 0.05481460161601148, 'session_latest_pair5': 0.41978023087266214, 'session_latest_pair6': 0.7350609009906249, 'session_latest_pair7': 0.1238352646439882, 'session_latest_pair8': 0.08373951158963044, 'session_latest_pair9': 0.835701772704021, 'session_latest_time_wt_pair0': 0.7520986706839784, 'session_latest_time_wt_pair1': 0.9167706232222669, 'session_latest_time_wt_pair2': 0.05666707470968324, 'session_latest_time_wt_pair3': 0.05615602502877004, 'session_latest_time_wt_pair4': 0.9222206674078791, 'session_latest_time_wt_pair5': 0.903614369738019, 'session_latest_time_wt_pair6': 0.6599747225564505, 'session_latest_time_wt_pair7': 0.3319402890177522, 'session_latest_time_wt_pair8': 0.009628092765632701, 'session_latest_time_wt_pair9': 0.3356288501749206, 'session_latest_time_wt_pair': 0.7250006605425281, 'session_latest_type_wt_pair': 0.9065152145939716, 'session_latest_clicks2carts_pair': 0.39554645503251973, 'session_latest_clicks2orders_pair': 0.08671491309485302}. Best is trial 0 with value: 0.446.
# [I 2022-12-07 01:44:00,931] Trial 3 finished with value: 0.446 and parameters: {'session_frequent': 0.5079721955415146, 'session_latest': 0.8234270611386617, 'session_frequent_pair': 0.396692809024883, 'session_latest_pair0': 0.7293628748498692, 'session_latest_pair1': 0.8998535750190553, 'session_latest_pair2': 0.5876823551960174, 'session_latest_pair3': 0.8164190753992376, 'session_latest_pair4': 0.23483561194992109, 'session_latest_pair5': 0.18823490107217455, 'session_latest_pair6': 0.8907730050475646, 'session_latest_pair7': 0.6734810318199554, 'session_latest_pair8': 0.27748372301004887, 'session_latest_pair9': 0.08322509108288967, 'session_latest_time_wt_pair0': 0.18352360306714743, 'session_latest_time_wt_pair1': 0.755001721498707, 'session_latest_time_wt_pair2': 0.5986438641913919, 'session_latest_time_wt_pair3': 0.8134328698895413, 'session_latest_time_wt_pair4': 0.5544793299571257, 'session_latest_time_wt_pair5': 0.15216978910294476, 'session_latest_time_wt_pair6': 0.46420663233842663, 'session_latest_time_wt_pair7': 0.7828069558819736, 'session_latest_time_wt_pair8': 0.7239407962245703, 'session_latest_time_wt_pair9': 0.3718570272625783, 'session_latest_time_wt_pair': 0.8354156874847352, 'session_latest_type_wt_pair': 0.9383770800935506, 'session_latest_clicks2carts_pair': 0.4763408865932246, 'session_latest_clicks2orders_pair': 0.521254893899861}. Best is trial 0 with value: 0.446.
# [I 2022-12-07 01:44:06,166] Trial 4 finished with value: 0.451 and parameters: {'session_frequent': 0.9466870116252639, 'session_latest': 0.42512018747870084, 'session_frequent_pair': 0.07792895599006955, 'session_latest_pair0': 0.45302956236623226, 'session_latest_pair1': 0.1563805559106295, 'session_latest_pair2': 0.9679869830820415, 'session_latest_pair3': 0.6218024708498189, 'session_latest_pair4': 0.9763992566089099, 'session_latest_pair5': 0.22511740308966488, 'session_latest_pair6': 0.296188531089297, 'session_latest_pair7': 0.2722639546412102, 'session_latest_pair8': 0.7402102446607152, 'session_latest_pair9': 0.17243629274686745, 'session_latest_time_wt_pair0': 0.1351304727319047, 'session_latest_time_wt_pair1': 0.4083828362987938, 'session_latest_time_wt_pair2': 0.08978878799645207, 'session_latest_time_wt_pair3': 0.04541919130617211, 'session_latest_time_wt_pair4': 0.7819145980584791, 'session_latest_time_wt_pair5': 0.4468483579627568, 'session_latest_time_wt_pair6': 0.53749794546812, 'session_latest_time_wt_pair7': 0.39551626821702945, 'session_latest_time_wt_pair8': 0.5525494138052114, 'session_latest_time_wt_pair9': 0.4998439036561919, 'session_latest_time_wt_pair': 0.16371467992162492, 'session_latest_type_wt_pair': 0.31493583253172874, 'session_latest_clicks2carts_pair': 0.354011549254563, 'session_latest_clicks2orders_pair': 0.7128602365885547}. Best is trial 4 with value: 0.451.
# [I 2022-12-07 01:44:11,481] Trial 5 finished with value: 0.469 and parameters: {'session_frequent': 0.19786329345113196, 'session_latest': 0.7264896942676672, 'session_frequent_pair': 0.9312131015522961, 'session_latest_pair0': 0.08040478088795477, 'session_latest_pair1': 0.8176122446473618, 'session_latest_pair2': 0.8084324894412244, 'session_latest_pair3': 0.2652649849471531, 'session_latest_pair4': 0.5991145366140548, 'session_latest_pair5': 0.8974406934507759, 'session_latest_pair6': 0.2108757523663749, 'session_latest_pair7': 0.3089748413064727, 'session_latest_pair8': 0.7242991670058324, 'session_latest_pair9': 0.18832610490122015, 'session_latest_time_wt_pair0': 0.03865397839732976, 'session_latest_time_wt_pair1': 0.5643325266561152, 'session_latest_time_wt_pair2': 0.48833226859307555, 'session_latest_time_wt_pair3': 0.7053039611765154, 'session_latest_time_wt_pair4': 0.32058973350227205, 'session_latest_time_wt_pair5': 0.3380885128113289, 'session_latest_time_wt_pair6': 0.43553460778499187, 'session_latest_time_wt_pair7': 0.3415530569329427, 'session_latest_time_wt_pair8': 0.8140657571230884, 'session_latest_time_wt_pair9': 0.3142280283975728, 'session_latest_time_wt_pair': 0.8277080275793217, 'session_latest_type_wt_pair': 0.21834810791869386, 'session_latest_clicks2carts_pair': 0.16052142013553428, 'session_latest_clicks2orders_pair': 0.15427951638465842}. Best is trial 5 with value: 0.469.
# [I 2022-12-07 01:44:16,772] Trial 6 finished with value: 0.424 and parameters: {'session_frequent': 0.7820420130316904, 'session_latest': 0.5560038762768145, 'session_frequent_pair': 0.741679040819153, 'session_latest_pair0': 0.6856467849747485, 'session_latest_pair1': 0.6329959002312351, 'session_latest_pair2': 0.1797872822932267, 'session_latest_pair3': 0.828799701536461, 'session_latest_pair4': 0.2044723184524374, 'session_latest_pair5': 0.2895659355173906, 'session_latest_pair6': 0.34464885052160266, 'session_latest_pair7': 0.328293492710661, 'session_latest_pair8': 0.1607261451169959, 'session_latest_pair9': 0.16698476663957018, 'session_latest_time_wt_pair0': 0.9648378381358627, 'session_latest_time_wt_pair1': 0.7301901035713421, 'session_latest_time_wt_pair2': 0.7608042218357621, 'session_latest_time_wt_pair3': 0.5574275499071955, 'session_latest_time_wt_pair4': 0.7898150464244361, 'session_latest_time_wt_pair5': 0.04879061419249908, 'session_latest_time_wt_pair6': 0.9440333452793028, 'session_latest_time_wt_pair7': 0.5957675015260603, 'session_latest_time_wt_pair8': 0.45170573056634034, 'session_latest_time_wt_pair9': 0.5322674383356862, 'session_latest_time_wt_pair': 0.6991900817689535, 'session_latest_type_wt_pair': 0.9165459598606472, 'session_latest_clicks2carts_pair': 0.6240090945239398, 'session_latest_clicks2orders_pair': 0.7891308728160933}. Best is trial 5 with value: 0.469.
# [I 2022-12-07 01:44:22,236] Trial 7 finished with value: 0.45 and parameters: {'session_frequent': 0.27889473672817977, 'session_latest': 0.35957222123065324, 'session_frequent_pair': 0.42740042345501905, 'session_latest_pair0': 0.8085067418670542, 'session_latest_pair1': 0.061629500481199306, 'session_latest_pair2': 0.6027986567883539, 'session_latest_pair3': 0.8031390137137759, 'session_latest_pair4': 0.45934984676929247, 'session_latest_pair5': 0.27525220251007054, 'session_latest_pair6': 0.05908807482627043, 'session_latest_pair7': 0.9836797809846521, 'session_latest_pair8': 0.29822606291168363, 'session_latest_pair9': 0.14826366899839283, 'session_latest_time_wt_pair0': 0.8006555249011709, 'session_latest_time_wt_pair1': 0.6869524810075882, 'session_latest_time_wt_pair2': 0.43353425524187905, 'session_latest_time_wt_pair3': 0.5271618355316346, 'session_latest_time_wt_pair4': 0.7874277311496553, 'session_latest_time_wt_pair5': 0.3308152115585915, 'session_latest_time_wt_pair6': 0.35606193225521876, 'session_latest_time_wt_pair7': 0.41301849520202305, 'session_latest_time_wt_pair8': 0.2422869390728365, 'session_latest_time_wt_pair9': 0.04042068795879794, 'session_latest_time_wt_pair': 0.38024671007041044, 'session_latest_type_wt_pair': 0.48653354018033756, 'session_latest_clicks2carts_pair': 0.5134429220333279, 'session_latest_clicks2orders_pair': 0.7111578947782204}. Best is trial 5 with value: 0.469.
# [I 2022-12-07 01:44:27,517] Trial 8 finished with value: 0.448 and parameters: {'session_frequent': 0.6708318647706772, 'session_latest': 0.29195481178251836, 'session_frequent_pair': 0.4349215287559459, 'session_latest_pair0': 0.6915559317323473, 'session_latest_pair1': 0.45216716063363593, 'session_latest_pair2': 0.15098989549063135, 'session_latest_pair3': 0.028012115926592918, 'session_latest_pair4': 0.019296634992765793, 'session_latest_pair5': 0.22323955112868754, 'session_latest_pair6': 0.7900292572999305, 'session_latest_pair7': 0.37010603607852044, 'session_latest_pair8': 0.8669825817413049, 'session_latest_pair9': 0.9767289329511366, 'session_latest_time_wt_pair0': 0.6256889441844738, 'session_latest_time_wt_pair1': 0.16081099816393274, 'session_latest_time_wt_pair2': 0.7897466004952342, 'session_latest_time_wt_pair3': 0.735133177164048, 'session_latest_time_wt_pair4': 0.10765358415373816, 'session_latest_time_wt_pair5': 0.4937445985029355, 'session_latest_time_wt_pair6': 0.9176263725213671, 'session_latest_time_wt_pair7': 0.7396495368405046, 'session_latest_time_wt_pair8': 0.3012429622591748, 'session_latest_time_wt_pair9': 0.8837566191313342, 'session_latest_time_wt_pair': 0.008552279462605061, 'session_latest_type_wt_pair': 0.1957255515588361, 'session_latest_clicks2carts_pair': 0.11857413698034158, 'session_latest_clicks2orders_pair': 0.22117272586516945}. Best is trial 5 with value: 0.469.
# [I 2022-12-07 01:44:32,933] Trial 9 finished with value: 0.49 and parameters: {'session_frequent': 0.12182354026910214, 'session_latest': 0.8051536234002206, 'session_frequent_pair': 0.481861733133773, 'session_latest_pair0': 0.20545240014322375, 'session_latest_pair1': 0.37443538102149043, 'session_latest_pair2': 0.5334281040694845, 'session_latest_pair3': 0.14987703795724439, 'session_latest_pair4': 0.5551205964152516, 'session_latest_pair5': 0.8195725418830487, 'session_latest_pair6': 0.828601849396411, 'session_latest_pair7': 0.5480132394061111, 'session_latest_pair8': 0.36699560954932, 'session_latest_pair9': 0.6732674942751004, 'session_latest_time_wt_pair0': 0.1252715938382084, 'session_latest_time_wt_pair1': 0.33748949084927826, 'session_latest_time_wt_pair2': 0.7647212563194161, 'session_latest_time_wt_pair3': 0.9812928353774895, 'session_latest_time_wt_pair4': 0.06373236173400465, 'session_latest_time_wt_pair5': 0.3043778448841349, 'session_latest_time_wt_pair6': 0.8276115861098889, 'session_latest_time_wt_pair7': 0.8831824029606589, 'session_latest_time_wt_pair8': 0.6473196703038236, 'session_latest_time_wt_pair9': 0.5065632395714312, 'session_latest_time_wt_pair': 0.29120701260772563, 'session_latest_type_wt_pair': 0.09579653438623059, 'session_latest_clicks2carts_pair': 0.5850617317127351, 'session_latest_clicks2orders_pair': 0.7671699897183321}. Best is trial 9 with value: 0.49.
# [I 2022-12-07 01:44:38,340] Trial 10 finished with value: 0.495 and parameters: {'session_frequent': 0.0796879980937863, 'session_latest': 0.9497787878092203, 'session_frequent_pair': 0.2723040711042667, 'session_latest_pair0': 0.14607848142117896, 'session_latest_pair1': 0.345449362816925, 'session_latest_pair2': 0.35839500175826944, 'session_latest_pair3': 0.32972687895421826, 'session_latest_pair4': 0.8432744032140799, 'session_latest_pair5': 0.810902327680692, 'session_latest_pair6': 0.5857081710314812, 'session_latest_pair7': 0.629778301189625, 'session_latest_pair8': 0.47130431608740186, 'session_latest_pair9': 0.5961233957290455, 'session_latest_time_wt_pair0': 0.3906403191637065, 'session_latest_time_wt_pair1': 0.28535484868491523, 'session_latest_time_wt_pair2': 0.9899693454331112, 'session_latest_time_wt_pair3': 0.30899524189523575, 'session_latest_time_wt_pair4': 0.02641249149649466, 'session_latest_time_wt_pair5': 0.6884858605192989, 'session_latest_time_wt_pair6': 0.747128838070872, 'session_latest_time_wt_pair7': 0.9714037191559677, 'session_latest_time_wt_pair8': 0.992910361113944, 'session_latest_time_wt_pair9': 0.6717812873737992, 'session_latest_time_wt_pair': 0.5190408124350097, 'session_latest_type_wt_pair': 0.6550180862062429, 'session_latest_clicks2carts_pair': 0.9962336362200153, 'session_latest_clicks2orders_pair': 0.9673465558701175}. Best is trial 10 with value: 0.495.
# [I 2022-12-07 01:44:43,596] Trial 11 finished with value: 0.496 and parameters: {'session_frequent': 0.01619170089235708, 'session_latest': 0.9891743127580225, 'session_frequent_pair': 0.2249172600180842, 'session_latest_pair0': 0.13880746629057697, 'session_latest_pair1': 0.3272441345121431, 'session_latest_pair2': 0.3627029596673023, 'session_latest_pair3': 0.3715961939523957, 'session_latest_pair4': 0.836887213360482, 'session_latest_pair5': 0.7991523825569055, 'session_latest_pair6': 0.580089595619521, 'session_latest_pair7': 0.621828241931818, 'session_latest_pair8': 0.4404871538343128, 'session_latest_pair9': 0.5857772723921025, 'session_latest_time_wt_pair0': 0.36872770220660556, 'session_latest_time_wt_pair1': 0.2808528665864718, 'session_latest_time_wt_pair2': 0.9964320768366268, 'session_latest_time_wt_pair3': 0.9955796253294251, 'session_latest_time_wt_pair4': 0.03315868330254433, 'session_latest_time_wt_pair5': 0.7181523669365246, 'session_latest_time_wt_pair6': 0.16288482618615324, 'session_latest_time_wt_pair7': 0.9496938847567326, 'session_latest_time_wt_pair8': 0.8823163492241303, 'session_latest_time_wt_pair9': 0.6789444166431825, 'session_latest_time_wt_pair': 0.5237285572954009, 'session_latest_type_wt_pair': 0.7064696109719034, 'session_latest_clicks2carts_pair': 0.9963863048778464, 'session_latest_clicks2orders_pair': 0.9606203867076776}. Best is trial 11 with value: 0.496.
# [I 2022-12-07 01:44:49,115] Trial 12 finished with value: 0.5 and parameters: {'session_frequent': 0.016324053228351405, 'session_latest': 0.9840101824823552, 'session_frequent_pair': 0.23275779471389701, 'session_latest_pair0': 0.2702629467665508, 'session_latest_pair1': 0.2948964412641, 'session_latest_pair2': 0.3349200397233625, 'session_latest_pair3': 0.4118768682120517, 'session_latest_pair4': 0.8783155095953121, 'session_latest_pair5': 0.6597450311639899, 'session_latest_pair6': 0.5709976044798001, 'session_latest_pair7': 0.7192013113698406, 'session_latest_pair8': 0.53287175987299, 'session_latest_pair9': 0.48677209784387676, 'session_latest_time_wt_pair0': 0.4571737988271328, 'session_latest_time_wt_pair1': 0.20150391406645818, 'session_latest_time_wt_pair2': 0.9977238310123066, 'session_latest_time_wt_pair3': 0.2707660423808064, 'session_latest_time_wt_pair4': 0.2619085710235479, 'session_latest_time_wt_pair5': 0.702423972853895, 'session_latest_time_wt_pair6': 0.042388542632083595, 'session_latest_time_wt_pair7': 0.9958741904889213, 'session_latest_time_wt_pair8': 0.991418556267134, 'session_latest_time_wt_pair9': 0.7182635166203616, 'session_latest_time_wt_pair': 0.5401428335706263, 'session_latest_type_wt_pair': 0.699784819218601, 'session_latest_clicks2carts_pair': 0.9776139224942992, 'session_latest_clicks2orders_pair': 0.9777717295342592}. Best is trial 12 with value: 0.5.
# [I 2022-12-07 01:44:54,306] Trial 13 finished with value: 0.495 and parameters: {'session_frequent': 0.022620377686480002, 'session_latest': 0.034412874501865254, 'session_frequent_pair': 0.2490885285757814, 'session_latest_pair0': 0.30471748842369206, 'session_latest_pair1': 0.2388892616343427, 'session_latest_pair2': 0.3176279640375317, 'session_latest_pair3': 0.4802354707627957, 'session_latest_pair4': 0.7929772220387383, 'session_latest_pair5': 0.6694961193185541, 'session_latest_pair6': 0.5343008639267485, 'session_latest_pair7': 0.8395394162317225, 'session_latest_pair8': 0.5890643277610687, 'session_latest_pair9': 0.380550307799233, 'session_latest_time_wt_pair0': 0.4020829207821276, 'session_latest_time_wt_pair1': 0.011675596865985516, 'session_latest_time_wt_pair2': 0.9958898747299998, 'session_latest_time_wt_pair3': 0.2954608493579516, 'session_latest_time_wt_pair4': 0.26536151751450554, 'session_latest_time_wt_pair5': 0.7009405784163156, 'session_latest_time_wt_pair6': 0.008470699626474586, 'session_latest_time_wt_pair7': 0.9843305042548195, 'session_latest_time_wt_pair8': 0.9829969101477348, 'session_latest_time_wt_pair9': 0.7515767449059689, 'session_latest_time_wt_pair': 0.5581033884983759, 'session_latest_type_wt_pair': 0.6971987814864833, 'session_latest_clicks2carts_pair': 0.9124340355424874, 'session_latest_clicks2orders_pair': 0.9023396877094173}. Best is trial 12 with value: 0.5.
# [I 2022-12-07 01:44:59,991] Trial 14 finished with value: 0.455 and parameters: {'session_frequent': 0.3412421883606336, 'session_latest': 0.973181623220753, 'session_frequent_pair': 0.025118875048380063, 'session_latest_pair0': 0.008878540961486325, 'session_latest_pair1': 0.254892688645583, 'session_latest_pair2': 0.006461812102109776, 'session_latest_pair3': 0.49017668834447925, 'session_latest_pair4': 0.9973110500130056, 'session_latest_pair5': 0.6447290705984697, 'session_latest_pair6': 0.6754201943862633, 'session_latest_pair7': 0.7501236980685113, 'session_latest_pair8': 0.9959126474808263, 'session_latest_pair9': 0.4299300208047945, 'session_latest_time_wt_pair0': 0.4631992050049396, 'session_latest_time_wt_pair1': 0.20300323349743252, 'session_latest_time_wt_pair2': 0.60713229060653, 'session_latest_time_wt_pair3': 0.3090202786054699, 'session_latest_time_wt_pair4': 0.25570898381676316, 'session_latest_time_wt_pair5': 0.8157573608479194, 'session_latest_time_wt_pair6': 0.03406976945401602, 'session_latest_time_wt_pair7': 0.6061576913022588, 'session_latest_time_wt_pair8': 0.8643805201867496, 'session_latest_time_wt_pair9': 0.9911665747026976, 'session_latest_time_wt_pair': 0.6059325764603045, 'session_latest_type_wt_pair': 0.6962925965563346, 'session_latest_clicks2carts_pair': 0.7813708974575293, 'session_latest_clicks2orders_pair': 0.4957621599351738}. Best is trial 12 with value: 0.5.
# [I 2022-12-07 01:45:05,476] Trial 15 finished with value: 0.485 and parameters: {'session_frequent': 0.19784806821926898, 'session_latest': 0.6121069723051551, 'session_frequent_pair': 0.22139863099587953, 'session_latest_pair0': 0.314935079367962, 'session_latest_pair1': 0.008475653463766997, 'session_latest_pair2': 0.3782161239665557, 'session_latest_pair3': 0.3436628389856667, 'session_latest_pair4': 0.7565151090308009, 'session_latest_pair5': 0.6376791338304517, 'session_latest_pair6': 0.4550869552248995, 'session_latest_pair7': 0.864766612888852, 'session_latest_pair8': 0.6021401819597144, 'session_latest_pair9': 0.5700797596446964, 'session_latest_time_wt_pair0': 0.31434593448035053, 'session_latest_time_wt_pair1': 0.44313191539516184, 'session_latest_time_wt_pair2': 0.8902024274630879, 'session_latest_time_wt_pair3': 0.9933283065810042, 'session_latest_time_wt_pair4': 0.4877163431170036, 'session_latest_time_wt_pair5': 0.6078268053290208, 'session_latest_time_wt_pair6': 0.17221058941166614, 'session_latest_time_wt_pair7': 0.864734432130402, 'session_latest_time_wt_pair8': 0.8629075686646169, 'session_latest_time_wt_pair9': 0.6780859894998935, 'session_latest_time_wt_pair': 0.4474694305401575, 'session_latest_type_wt_pair': 0.5744654650638942, 'session_latest_clicks2carts_pair': 0.811290548101096, 'session_latest_clicks2orders_pair': 0.5406920340691643}. Best is trial 12 with value: 0.5.
# [I 2022-12-07 01:45:10,729] Trial 16 finished with value: 0.435 and parameters: {'session_frequent': 0.49794703325978007, 'session_latest': 0.8924106127898401, 'session_frequent_pair': 0.31536566546074973, 'session_latest_pair0': 0.2739509739509894, 'session_latest_pair1': 0.5212902946401977, 'session_latest_pair2': 0.2190519486125854, 'session_latest_pair3': 0.6282155797272618, 'session_latest_pair4': 0.8775404628974492, 'session_latest_pair5': 0.02550397382620967, 'session_latest_pair6': 0.9665297017127658, 'session_latest_pair7': 0.4993201540970685, 'session_latest_pair8': 0.4379735408236422, 'session_latest_pair9': 0.35546925507975125, 'session_latest_time_wt_pair0': 0.5775466085568485, 'session_latest_time_wt_pair1': 0.13931834132829019, 'session_latest_time_wt_pair2': 0.6425223707276585, 'session_latest_time_wt_pair3': 0.1623756787057158, 'session_latest_time_wt_pair4': 0.17316074932298137, 'session_latest_time_wt_pair5': 0.9325126209518355, 'session_latest_time_wt_pair6': 0.2347617148640942, 'session_latest_time_wt_pair7': 0.04355929986607904, 'session_latest_time_wt_pair8': 0.7430549703196192, 'session_latest_time_wt_pair9': 0.7364801721134656, 'session_latest_time_wt_pair': 0.6422535853248645, 'session_latest_type_wt_pair': 0.8116776376104888, 'session_latest_clicks2carts_pair': 0.9901162342112904, 'session_latest_clicks2orders_pair': 0.9812749507236417}. Best is trial 12 with value: 0.5.
# [I 2022-12-07 01:45:16,152] Trial 17 finished with value: 0.504 and parameters: {'session_frequent': 0.009946705370819375, 'session_latest': 0.9987179771207334, 'session_frequent_pair': 0.1472787562942193, 'session_latest_pair0': 0.3937548927150745, 'session_latest_pair1': 0.41511718034600986, 'session_latest_pair2': 0.43956765409872844, 'session_latest_pair3': 0.9927439513130447, 'session_latest_pair4': 0.6971738105102128, 'session_latest_pair5': 0.9546683675283969, 'session_latest_pair6': 0.4508246051760639, 'session_latest_pair7': 0.5155425139299328, 'session_latest_pair8': 0.6281229118498213, 'session_latest_pair9': 0.7438169775569865, 'session_latest_time_wt_pair0': 0.5675670679613068, 'session_latest_time_wt_pair1': 0.5539218637766644, 'session_latest_time_wt_pair2': 0.2190754242945795, 'session_latest_time_wt_pair3': 0.38813845162026267, 'session_latest_time_wt_pair4': 0.4180159037477749, 'session_latest_time_wt_pair5': 0.5769535004326345, 'session_latest_time_wt_pair6': 0.13978272898762953, 'session_latest_time_wt_pair7': 0.6370864902367999, 'session_latest_time_wt_pair8': 0.9291139894450331, 'session_latest_time_wt_pair9': 0.5937715384988256, 'session_latest_time_wt_pair': 0.23090287748791977, 'session_latest_type_wt_pair': 0.7870426403302249, 'session_latest_clicks2carts_pair': 0.6949143747026351, 'session_latest_clicks2orders_pair': 0.33395916743287646}. Best is trial 17 with value: 0.504.
# [I 2022-12-07 01:45:21,282] Trial 18 finished with value: 0.509 and parameters: {'session_frequent': 0.18062956313040074, 'session_latest': 0.12381441003852939, 'session_frequent_pair': 0.6253614216053017, 'session_latest_pair0': 0.4209067109948506, 'session_latest_pair1': 0.4446800866626991, 'session_latest_pair2': 0.4526961355392102, 'session_latest_pair3': 0.9854352573763272, 'session_latest_pair4': 0.6688029759384495, 'session_latest_pair5': 0.960287786776838, 'session_latest_pair6': 0.44651298999998107, 'session_latest_pair7': 0.4917910750422736, 'session_latest_pair8': 0.6732325854616458, 'session_latest_pair9': 0.7116030870096172, 'session_latest_time_wt_pair0': 0.6067279516124556, 'session_latest_time_wt_pair1': 0.5601746055541069, 'session_latest_time_wt_pair2': 0.22205489608300263, 'session_latest_time_wt_pair3': 0.4020482766876641, 'session_latest_time_wt_pair4': 0.4286279705206814, 'session_latest_time_wt_pair5': 0.5246544112721612, 'session_latest_time_wt_pair6': 0.15388827714866127, 'session_latest_time_wt_pair7': 0.19067393451367803, 'session_latest_time_wt_pair8': 0.9841821323101303, 'session_latest_time_wt_pair9': 0.5951028594016499, 'session_latest_time_wt_pair': 0.15299935053123292, 'session_latest_type_wt_pair': 0.8132929555731734, 'session_latest_clicks2carts_pair': 0.6464292871843144, 'session_latest_clicks2orders_pair': 0.35330370753809226}. Best is trial 18 with value: 0.509.
# [I 2022-12-07 01:45:26,832] Trial 19 finished with value: 0.498 and parameters: {'session_frequent': 0.18139218231037005, 'session_latest': 0.1290111736547047, 'session_frequent_pair': 0.6294202446781668, 'session_latest_pair0': 0.4076204157810251, 'session_latest_pair1': 0.4356609317775926, 'session_latest_pair2': 0.46285067536019264, 'session_latest_pair3': 0.9952122603981375, 'session_latest_pair4': 0.6696904764552891, 'session_latest_pair5': 0.9798938504016443, 'session_latest_pair6': 0.41282648027627616, 'session_latest_pair7': 0.011443576147409651, 'session_latest_pair8': 0.7115926429615752, 'session_latest_pair9': 0.7604968111916334, 'session_latest_time_wt_pair0': 0.6928290415450569, 'session_latest_time_wt_pair1': 0.5842097084925834, 'session_latest_time_wt_pair2': 0.22497907391082883, 'session_latest_time_wt_pair3': 0.43836587484457484, 'session_latest_time_wt_pair4': 0.46689665132723684, 'session_latest_time_wt_pair5': 0.506112854921458, 'session_latest_time_wt_pair6': 0.26034767361718075, 'session_latest_time_wt_pair7': 0.18367325207086727, 'session_latest_time_wt_pair8': 0.634014022443619, 'session_latest_time_wt_pair9': 0.5781191742130148, 'session_latest_time_wt_pair': 0.16950734314751206, 'session_latest_type_wt_pair': 0.8187142262989651, 'session_latest_clicks2carts_pair': 0.6731253002440601, 'session_latest_clicks2orders_pair': 0.33137861465814444}. Best is trial 18 with value: 0.509.
# [I 2022-12-07 01:45:32,278] Trial 20 finished with value: 0.496 and parameters: {'session_frequent': 0.41642132655355346, 'session_latest': 0.18227194053084073, 'session_frequent_pair': 0.8744456718435971, 'session_latest_pair0': 0.57392957807992, 'session_latest_pair1': 0.6842730338909301, 'session_latest_pair2': 0.7522768679845788, 'session_latest_pair3': 0.9438455138693436, 'session_latest_pair4': 0.7141777439227271, 'session_latest_pair5': 0.9613572970343568, 'session_latest_pair6': 0.08195208090233325, 'session_latest_pair7': 0.48950671558892583, 'session_latest_pair8': 0.85507110448772, 'session_latest_pair9': 0.92655968058202, 'session_latest_time_wt_pair0': 0.848720559623092, 'session_latest_time_wt_pair1': 0.8893171308246657, 'session_latest_time_wt_pair2': 0.19502614392169537, 'session_latest_time_wt_pair3': 0.4178349013585016, 'session_latest_time_wt_pair4': 0.6285304202473914, 'session_latest_time_wt_pair5': 0.5934451995501783, 'session_latest_time_wt_pair6': 0.5844365187128233, 'session_latest_time_wt_pair7': 0.17636590209817132, 'session_latest_time_wt_pair8': 0.3918250672456414, 'session_latest_time_wt_pair9': 0.4214327443254846, 'session_latest_time_wt_pair': 0.017017512441909632, 'session_latest_type_wt_pair': 0.8227828342064238, 'session_latest_clicks2carts_pair': 0.6933484056575582, 'session_latest_clicks2orders_pair': 0.37393733018217595}. Best is trial 18 with value: 0.509.
# [I 2022-12-07 01:45:37,528] Trial 21 finished with value: 0.502 and parameters: {'session_frequent': 0.009957498224257205, 'session_latest': 0.6591384128585895, 'session_frequent_pair': 0.6251374333659753, 'session_latest_pair0': 0.39829356594415727, 'session_latest_pair1': 0.12932376055362937, 'session_latest_pair2': 0.43810711590805596, 'session_latest_pair3': 0.6761156091310572, 'session_latest_pair4': 0.9001458885665917, 'session_latest_pair5': 0.5746676534069686, 'session_latest_pair6': 0.635676614506378, 'session_latest_pair7': 0.43544476733097615, 'session_latest_pair8': 0.6154797448648693, 'session_latest_pair9': 0.7883110471529036, 'session_latest_time_wt_pair0': 0.5363954065715646, 'session_latest_time_wt_pair1': 0.5343953544046894, 'session_latest_time_wt_pair2': 0.371836494060109, 'session_latest_time_wt_pair3': 0.2207976944494196, 'session_latest_time_wt_pair4': 0.40681263118405264, 'session_latest_time_wt_pair5': 0.5790054173791972, 'session_latest_time_wt_pair6': 0.09196169379997206, 'session_latest_time_wt_pair7': 0.6699998304398967, 'session_latest_time_wt_pair8': 0.9971589543386753, 'session_latest_time_wt_pair9': 0.8118170598402081, 'session_latest_time_wt_pair': 0.17375081950642568, 'session_latest_type_wt_pair': 0.5711972173958912, 'session_latest_clicks2carts_pair': 0.866091485677235, 'session_latest_clicks2orders_pair': 0.36641981309220156}. Best is trial 18 with value: 0.509.
# [I 2022-12-07 01:45:42,892] Trial 22 finished with value: 0.502 and parameters: {'session_frequent': 0.08278349364885075, 'session_latest': 0.6288444458461555, 'session_frequent_pair': 0.5909162591954661, 'session_latest_pair0': 0.3709827099603622, 'session_latest_pair1': 0.16918212658996906, 'session_latest_pair2': 0.44360720616160937, 'session_latest_pair3': 0.9160516263687228, 'session_latest_pair4': 0.4941278671086025, 'session_latest_pair5': 0.7408548674337335, 'session_latest_pair6': 0.42331672819775934, 'session_latest_pair7': 0.44490341225566793, 'session_latest_pair8': 0.6749447503087385, 'session_latest_pair9': 0.7564492542439711, 'session_latest_time_wt_pair0': 0.5662983358987899, 'session_latest_time_wt_pair1': 0.5321033044068207, 'session_latest_time_wt_pair2': 0.34447566748472336, 'session_latest_time_wt_pair3': 0.19365854041571062, 'session_latest_time_wt_pair4': 0.383888024646303, 'session_latest_time_wt_pair5': 0.5770681337139654, 'session_latest_time_wt_pair6': 0.14535795479901262, 'session_latest_time_wt_pair7': 0.6055172287401152, 'session_latest_time_wt_pair8': 0.9236898449031287, 'session_latest_time_wt_pair9': 0.8169133859738003, 'session_latest_time_wt_pair': 0.17171556866116006, 'session_latest_type_wt_pair': 0.533839830080557, 'session_latest_clicks2carts_pair': 0.8645991181468468, 'session_latest_clicks2orders_pair': 0.3352047294857524}. Best is trial 18 with value: 0.509.
# [I 2022-12-07 01:45:48,288] Trial 23 finished with value: 0.501 and parameters: {'session_frequent': 0.12193722028270537, 'session_latest': 0.524721309456385, 'session_frequent_pair': 0.734242269129372, 'session_latest_pair0': 0.5497561066165504, 'session_latest_pair1': 0.19576953933098304, 'session_latest_pair2': 0.6381588500356171, 'session_latest_pair3': 0.9202498727549101, 'session_latest_pair4': 0.39942480300821176, 'session_latest_pair5': 0.8855223325550554, 'session_latest_pair6': 0.4069672875173139, 'session_latest_pair7': 0.5285494237312562, 'session_latest_pair8': 0.6702771597588559, 'session_latest_pair9': 0.694292852535224, 'session_latest_time_wt_pair0': 0.628413406870438, 'session_latest_time_wt_pair1': 0.6264970039381784, 'session_latest_time_wt_pair2': 0.17387693884253624, 'session_latest_time_wt_pair3': 0.42225469643468816, 'session_latest_time_wt_pair4': 0.37161549598881943, 'session_latest_time_wt_pair5': 0.4065657743347797, 'session_latest_time_wt_pair6': 0.12866259608812824, 'session_latest_time_wt_pair7': 0.4944395832983674, 'session_latest_time_wt_pair8': 0.7705888528466796, 'session_latest_time_wt_pair9': 0.6061251593538949, 'session_latest_time_wt_pair': 0.0957112605196006, 'session_latest_type_wt_pair': 0.4278184838317305, 'session_latest_clicks2carts_pair': 0.7222389123488785, 'session_latest_clicks2orders_pair': 0.276020180344133}. Best is trial 18 with value: 0.509.
# [I 2022-12-07 01:45:53,459] Trial 24 finished with value: 0.494 and parameters: {'session_frequent': 0.2522413857508924, 'session_latest': 0.0004949686159784195, 'session_frequent_pair': 0.737027095309686, 'session_latest_pair0': 0.39445847316208965, 'session_latest_pair1': 0.08474997823182442, 'session_latest_pair2': 0.2574421585128717, 'session_latest_pair3': 0.667048863858751, 'session_latest_pair4': 0.7294599613132248, 'session_latest_pair5': 0.5671892612573413, 'session_latest_pair6': 0.671245851522867, 'session_latest_pair7': 0.19424834859576384, 'session_latest_pair8': 0.8225299685409799, 'session_latest_pair9': 0.851955363317812, 'session_latest_time_wt_pair0': 0.5290010553610861, 'session_latest_time_wt_pair1': 0.4580175200230138, 'session_latest_time_wt_pair2': 0.3613167925351032, 'session_latest_time_wt_pair3': 0.14280493835712268, 'session_latest_time_wt_pair4': 0.6159917740411638, 'session_latest_time_wt_pair5': 0.21405454198845852, 'session_latest_time_wt_pair6': 0.27109028983262395, 'session_latest_time_wt_pair7': 0.6817096168656738, 'session_latest_time_wt_pair8': 0.9283540766135121, 'session_latest_time_wt_pair9': 0.9764820301855703, 'session_latest_time_wt_pair': 0.246811868803326, 'session_latest_type_wt_pair': 0.9978472565537694, 'session_latest_clicks2carts_pair': 0.014170427972227728, 'session_latest_clicks2orders_pair': 0.4289425483197418}. Best is trial 18 with value: 0.509.
# [I 2022-12-07 01:45:58,937] Trial 25 finished with value: 0.501 and parameters: {'session_frequent': 0.09417919164014986, 'session_latest': 0.17374886985092905, 'session_frequent_pair': 0.5675634478634646, 'session_latest_pair0': 0.5464172893365566, 'session_latest_pair1': 0.40156970780051515, 'session_latest_pair2': 0.5498715137829977, 'session_latest_pair3': 0.901279384883118, 'session_latest_pair4': 0.573501659406252, 'session_latest_pair5': 0.7343817546118464, 'session_latest_pair6': 0.4600894896497997, 'session_latest_pair7': 0.5742557675458155, 'session_latest_pair8': 0.7960953538939622, 'session_latest_pair9': 0.7006010965434233, 'session_latest_time_wt_pair0': 0.6962810727126436, 'session_latest_time_wt_pair1': 0.8090988655279427, 'session_latest_time_wt_pair2': 0.27056933833755015, 'session_latest_time_wt_pair3': 0.3536967729401607, 'session_latest_time_wt_pair4': 0.44586505312179214, 'session_latest_time_wt_pair5': 0.5283560852073893, 'session_latest_time_wt_pair6': 0.3574549633172416, 'session_latest_time_wt_pair7': 0.5241598998250034, 'session_latest_time_wt_pair8': 0.6493165680141617, 'session_latest_time_wt_pair9': 0.8220627611008355, 'session_latest_time_wt_pair': 0.09625137198538161, 'session_latest_type_wt_pair': 0.5456122080228423, 'session_latest_clicks2carts_pair': 0.5755822019057422, 'session_latest_clicks2orders_pair': 0.005754678128700785}. Best is trial 18 with value: 0.509.
# [I 2022-12-07 01:46:04,208] Trial 26 finished with value: 0.493 and parameters: {'session_frequent': 0.16724575496292324, 'session_latest': 0.8184445330019944, 'session_frequent_pair': 0.5349934782454007, 'session_latest_pair0': 0.34976281567014367, 'session_latest_pair1': 0.518510500731509, 'session_latest_pair2': 0.4340190036414586, 'session_latest_pair3': 0.99288631816803, 'session_latest_pair4': 0.45586780125313003, 'session_latest_pair5': 0.9003009792192243, 'session_latest_pair6': 0.1886518071152743, 'session_latest_pair7': 0.4395293811941964, 'session_latest_pair8': 0.9470473404511173, 'session_latest_pair9': 0.8858022105307313, 'session_latest_time_wt_pair0': 0.27641770454271125, 'session_latest_time_wt_pair1': 0.644405619321833, 'session_latest_time_wt_pair2': 0.141863664203979, 'session_latest_time_wt_pair3': 0.6196532017110203, 'session_latest_time_wt_pair4': 0.5515843015787844, 'session_latest_time_wt_pair5': 0.8347282501513567, 'session_latest_time_wt_pair6': 0.20961793910065793, 'session_latest_time_wt_pair7': 0.5032162144326094, 'session_latest_time_wt_pair8': 0.8970194889459122, 'session_latest_time_wt_pair9': 0.6225293031936561, 'session_latest_time_wt_pair': 0.41330054863173565, 'session_latest_type_wt_pair': 0.7754238719350333, 'session_latest_clicks2carts_pair': 0.855525170734827, 'session_latest_clicks2orders_pair': 0.5977579064822995}. Best is trial 18 with value: 0.509.
# [I 2022-12-07 01:46:09,778] Trial 27 finished with value: 0.468 and parameters: {'session_frequent': 0.2603411295106103, 'session_latest': 0.4782803676937566, 'session_frequent_pair': 0.8252197262768846, 'session_latest_pair0': 0.2063360403973087, 'session_latest_pair1': 0.4722399502842485, 'session_latest_pair2': 0.6726912586346192, 'session_latest_pair3': 0.741792227968808, 'session_latest_pair4': 0.3231142807859779, 'session_latest_pair5': 0.9808745860748542, 'session_latest_pair6': 0.37439152257104646, 'session_latest_pair7': 0.46869082711908217, 'session_latest_pair8': 0.6220331575100777, 'session_latest_pair9': 0.7713295244087635, 'session_latest_time_wt_pair0': 0.8651719993834546, 'session_latest_time_wt_pair1': 0.9952541138991822, 'session_latest_time_wt_pair2': 0.025850545872457803, 'session_latest_time_wt_pair3': 0.14616890895145218, 'session_latest_time_wt_pair4': 0.3740335860953406, 'session_latest_time_wt_pair5': 0.3931597980809001, 'session_latest_time_wt_pair6': 0.08546640460426903, 'session_latest_time_wt_pair7': 0.2965327632807265, 'session_latest_time_wt_pair8': 0.8032989263290968, 'session_latest_time_wt_pair9': 0.44134469978362373, 'session_latest_time_wt_pair': 0.24318102299159491, 'session_latest_type_wt_pair': 0.6216214475402012, 'session_latest_clicks2carts_pair': 0.49256412787581727, 'session_latest_clicks2orders_pair': 0.2759562787016236}. Best is trial 18 with value: 0.509.
# [I 2022-12-07 01:46:15,296] Trial 28 finished with value: 0.499 and parameters: {'session_frequent': 0.08180125987741695, 'session_latest': 0.2555418301479292, 'session_frequent_pair': 0.35686226808671573, 'session_latest_pair0': 0.47040533398254086, 'session_latest_pair1': 0.5825065721613085, 'session_latest_pair2': 0.05766166484381907, 'session_latest_pair3': 0.881547765020269, 'session_latest_pair4': 0.5192148135237765, 'session_latest_pair5': 0.7390938184467426, 'session_latest_pair6': 0.5044160840297149, 'session_latest_pair7': 0.3822374366121684, 'session_latest_pair8': 0.5361620144895695, 'session_latest_pair9': 0.6467467507468901, 'session_latest_time_wt_pair0': 0.6215106021353052, 'session_latest_time_wt_pair1': 0.4759607683359965, 'session_latest_time_wt_pair2': 0.28389914555984896, 'session_latest_time_wt_pair3': 0.47768002172809126, 'session_latest_time_wt_pair4': 0.6191127919617638, 'session_latest_time_wt_pair5': 0.6213501005495933, 'session_latest_time_wt_pair6': 0.3040457266883304, 'session_latest_time_wt_pair7': 0.5783317238379683, 'session_latest_time_wt_pair8': 0.9231043383874016, 'session_latest_time_wt_pair9': 0.26893852141781444, 'session_latest_time_wt_pair': 0.10149948643671838, 'session_latest_type_wt_pair': 0.7775735343450966, 'session_latest_clicks2carts_pair': 0.7300126486004819, 'session_latest_clicks2orders_pair': 0.46627437459183085}. Best is trial 18 with value: 0.509.
# [I 2022-12-07 01:46:20,688] Trial 29 finished with value: 0.486 and parameters: {'session_frequent': 0.01655486309306877, 'session_latest': 0.7065419636687824, 'session_frequent_pair': 0.6582514834146596, 'session_latest_pair0': 0.5965140549087724, 'session_latest_pair1': 0.758696003192906, 'session_latest_pair2': 0.856276586708488, 'session_latest_pair3': 0.7198476799634341, 'session_latest_pair4': 0.9408815108469886, 'session_latest_pair5': 0.5433045536835648, 'session_latest_pair6': 0.6416771312002534, 'session_latest_pair7': 0.40659347976894405, 'session_latest_pair8': 0.7857616516222171, 'session_latest_pair9': 0.9910188265763633, 'session_latest_time_wt_pair0': 0.5049910935357965, 'session_latest_time_wt_pair1': 0.4001527121207734, 'session_latest_time_wt_pair2': 0.38293388249770155, 'session_latest_time_wt_pair3': 0.2479672223603704, 'session_latest_time_wt_pair4': 0.172131339420952, 'session_latest_time_wt_pair5': 0.7856481565215239, 'session_latest_time_wt_pair6': 0.09486218724522805, 'session_latest_time_wt_pair7': 0.1460996521845324, 'session_latest_time_wt_pair8': 0.01357663310462337, 'session_latest_time_wt_pair9': 0.026897178629904872, 'session_latest_time_wt_pair': 0.364966653835053, 'session_latest_type_wt_pair': 0.46139435495341674, 'session_latest_clicks2carts_pair': 0.6339040778507865, 'session_latest_clicks2orders_pair': 0.6297351171471717}. Best is trial 18 with value: 0.509.
# [I 2022-12-07 01:46:26,069] Trial 30 finished with value: 0.48 and parameters: {'session_frequent': 0.3417830734681825, 'session_latest': 0.5821152812487231, 'session_frequent_pair': 0.5356075763448052, 'session_latest_pair0': 0.9907127416748942, 'session_latest_pair1': 0.21489028378808187, 'session_latest_pair2': 0.2813512839404739, 'session_latest_pair3': 0.5609084216743299, 'session_latest_pair4': 0.6614940076783752, 'session_latest_pair5': 0.8569621576548818, 'session_latest_pair6': 0.30408475508544186, 'session_latest_pair7': 0.6091341822911024, 'session_latest_pair8': 0.905163924173613, 'session_latest_pair9': 0.4995060517126685, 'session_latest_time_wt_pair0': 0.7204407380463292, 'session_latest_time_wt_pair1': 0.5189647481775013, 'session_latest_time_wt_pair2': 0.11990514099972963, 'session_latest_time_wt_pair3': 0.401468187571987, 'session_latest_time_wt_pair4': 0.7024468510265215, 'session_latest_time_wt_pair5': 0.6492486150234782, 'session_latest_time_wt_pair6': 0.3953934099831232, 'session_latest_time_wt_pair7': 0.2688126552176928, 'session_latest_time_wt_pair8': 0.7143463797764786, 'session_latest_time_wt_pair9': 0.842269182484721, 'session_latest_time_wt_pair': 0.2852118499005244, 'session_latest_type_wt_pair': 0.3370122991538847, 'session_latest_clicks2carts_pair': 0.8020448216508619, 'session_latest_clicks2orders_pair': 0.1469871123656678}. Best is trial 18 with value: 0.509.
# [I 2022-12-07 01:46:31,188] Trial 31 finished with value: 0.5 and parameters: {'session_frequent': 0.07715453735231362, 'session_latest': 0.6237000848471624, 'session_frequent_pair': 0.6388168037032725, 'session_latest_pair0': 0.3572040392305351, 'session_latest_pair1': 0.09722274325111413, 'session_latest_pair2': 0.44195697822432056, 'session_latest_pair3': 0.9985294164516103, 'session_latest_pair4': 0.3770084479503577, 'session_latest_pair5': 0.7434630724604818, 'session_latest_pair6': 0.4793077788701612, 'session_latest_pair7': 0.42104745028242546, 'session_latest_pair8': 0.6660624783521579, 'session_latest_pair9': 0.7595524269294729, 'session_latest_time_wt_pair0': 0.5412079194862643, 'session_latest_time_wt_pair1': 0.5413974521128673, 'session_latest_time_wt_pair2': 0.3645067209402022, 'session_latest_time_wt_pair3': 0.19295725010992051, 'session_latest_time_wt_pair4': 0.39259783152014616, 'session_latest_time_wt_pair5': 0.5174839643053665, 'session_latest_time_wt_pair6': 0.17085847309214303, 'session_latest_time_wt_pair7': 0.6692257837182127, 'session_latest_time_wt_pair8': 0.9366836574134588, 'session_latest_time_wt_pair9': 0.7993231738735913, 'session_latest_time_wt_pair': 0.18398388710965727, 'session_latest_type_wt_pair': 0.5639782432680527, 'session_latest_clicks2carts_pair': 0.8804206434439057, 'session_latest_clicks2orders_pair': 0.38035501844520353}. Best is trial 18 with value: 0.509.
# [I 2022-12-07 01:46:36,699] Trial 32 finished with value: 0.5 and parameters: {'session_frequent': 0.0014303938442640218, 'session_latest': 0.6551749629233572, 'session_frequent_pair': 0.5950933326177443, 'session_latest_pair0': 0.4140022128181944, 'session_latest_pair1': 0.138632746979638, 'session_latest_pair2': 0.4265571284098211, 'session_latest_pair3': 0.8686932663398, 'session_latest_pair4': 0.6292558951270514, 'session_latest_pair5': 0.4248716275342736, 'session_latest_pair6': 0.6239409501684867, 'session_latest_pair7': 0.344540042892573, 'session_latest_pair8': 0.6367686943639034, 'session_latest_pair9': 0.799478248736916, 'session_latest_time_wt_pair0': 0.5815989070134759, 'session_latest_time_wt_pair1': 0.601712164068215, 'session_latest_time_wt_pair2': 0.48939646034049983, 'session_latest_time_wt_pair3': 0.21556495274095644, 'session_latest_time_wt_pair4': 0.41419091961356336, 'session_latest_time_wt_pair5': 0.5710905498519396, 'session_latest_time_wt_pair6': 0.098660075784567, 'session_latest_time_wt_pair7': 0.6936973341459669, 'session_latest_time_wt_pair8': 0.8346543752286045, 'session_latest_time_wt_pair9': 0.9206665719281747, 'session_latest_time_wt_pair': 0.20869659899281673, 'session_latest_type_wt_pair': 0.6203831383494066, 'session_latest_clicks2carts_pair': 0.9076106406201433, 'session_latest_clicks2orders_pair': 0.29728878639200723}. Best is trial 18 with value: 0.509.
# ...
# [I 2022-12-07 02:09:53,939] Trial 90 finished with value: 0.578 and parameters: {'session_frequent': 0.0006024123723970126, 'session_latest': 0.10297686726596264, 'session_frequent_pair': 0.5385690738044914, 'session_latest_pair0': 0.37044213899705003, 'session_latest_pair1': 0.2928865069452995, 'session_latest_pair2': 0.6738248554575306, 'session_latest_pair3': 0.7107622773817015, 'session_latest_pair4': 0.8711630677055764, 'session_latest_pair5': 0.6508326842145136, 'session_latest_pair6': 0.9713687619233502, 'session_latest_pair7': 0.6545619897820999, 'session_latest_pair8': 0.41821925843861774, 'session_latest_pair9': 0.8188242161028209, 'session_latest_time_wt_pair0': 0.3896670873936677, 'session_latest_time_wt_pair1': 0.8366529878238861, 'session_latest_time_wt_pair2': 0.34486433061444044, 'session_latest_time_wt_pair3': 0.5088292861693086, 'session_latest_time_wt_pair4': 0.8112709300392352, 'session_latest_time_wt_pair5': 0.6434045319178231, 'session_latest_time_wt_pair6': 0.7676587490078995, 'session_latest_time_wt_pair7': 0.12292053785690255, 'session_latest_time_wt_pair8': 0.6209254709471599, 'session_latest_time_wt_pair9': 0.8271588717032875, 'session_latest_time_wt_pair': 0.2878098705326094, 'session_latest_type_wt_pair': 0.9541476792394903, 'session_latest_clicks2carts_pair': 0.5781350129155082, 'session_latest_clicks2orders_pair': 0.5416262738709252}. Best is trial 89 with value: 0.583.
# [I 2022-12-07 02:09:59,196] Trial 91 finished with value: 0.586 and parameters: {'session_frequent': 0.0011228457770860402, 'session_latest': 0.09322721111993586, 'session_frequent_pair': 0.9243063584262667, 'session_latest_pair0': 0.556249930498, 'session_latest_pair1': 0.2878100109093529, 'session_latest_pair2': 0.6717487288251923, 'session_latest_pair3': 0.6099714214953857, 'session_latest_pair4': 0.9954636918664291, 'session_latest_pair5': 0.6499750771510867, 'session_latest_pair6': 0.9598712582114762, 'session_latest_pair7': 0.6687855979262891, 'session_latest_pair8': 0.4305054484257799, 'session_latest_pair9': 0.8175061205573175, 'session_latest_time_wt_pair0': 0.4045760962402099, 'session_latest_time_wt_pair1': 0.9280858337208739, 'session_latest_time_wt_pair2': 0.3563500653992832, 'session_latest_time_wt_pair3': 0.5085443870698833, 'session_latest_time_wt_pair4': 0.8158925392431151, 'session_latest_time_wt_pair5': 0.7201113116884978, 'session_latest_time_wt_pair6': 0.7586019164412234, 'session_latest_time_wt_pair7': 0.8587395472860962, 'session_latest_time_wt_pair8': 0.6222511552446013, 'session_latest_time_wt_pair9': 0.8740184186097779, 'session_latest_time_wt_pair': 0.35196469369301736, 'session_latest_type_wt_pair': 0.9667088609646083, 'session_latest_clicks2carts_pair': 0.6812165400934871, 'session_latest_clicks2orders_pair': 0.5501499773169691}. Best is trial 91 with value: 0.586.
# [I 2022-12-07 02:10:04,631] Trial 92 finished with value: 0.58 and parameters: {'session_frequent': 0.0004634506293645438, 'session_latest': 0.09725506899971037, 'session_frequent_pair': 0.41898884197684333, 'session_latest_pair0': 0.3591351729898833, 'session_latest_pair1': 0.2892609178662221, 'session_latest_pair2': 0.668862508393189, 'session_latest_pair3': 0.5980356398144157, 'session_latest_pair4': 0.9851211940979103, 'session_latest_pair5': 0.6459745509244126, 'session_latest_pair6': 0.8984912044571645, 'session_latest_pair7': 0.6538569621202045, 'session_latest_pair8': 0.49718465429366987, 'session_latest_pair9': 0.8137925321417103, 'session_latest_time_wt_pair0': 0.3242356636615642, 'session_latest_time_wt_pair1': 0.8369478516993359, 'session_latest_time_wt_pair2': 0.3611707018065079, 'session_latest_time_wt_pair3': 0.4185842569300606, 'session_latest_time_wt_pair4': 0.8034229631486628, 'session_latest_time_wt_pair5': 0.7646778839434081, 'session_latest_time_wt_pair6': 0.7429117054996027, 'session_latest_time_wt_pair7': 0.12034340975785618, 'session_latest_time_wt_pair8': 0.6371019336726634, 'session_latest_time_wt_pair9': 0.9528435709870001, 'session_latest_time_wt_pair': 0.24074159789474578, 'session_latest_type_wt_pair': 0.9378573643153093, 'session_latest_clicks2carts_pair': 0.5892424526924374, 'session_latest_clicks2orders_pair': 0.5361206640345934}. Best is trial 91 with value: 0.586.
# [I 2022-12-07 02:10:10,115] Trial 93 finished with value: 0.578 and parameters: {'session_frequent': 0.05961299980138001, 'session_latest': 0.08825036546980833, 'session_frequent_pair': 0.4502635707343316, 'session_latest_pair0': 0.34604660807657106, 'session_latest_pair1': 0.2827900633708392, 'session_latest_pair2': 0.5152428582245504, 'session_latest_pair3': 0.6227794522177645, 'session_latest_pair4': 0.8728725612687145, 'session_latest_pair5': 0.6458305177172321, 'session_latest_pair6': 0.9097079517145685, 'session_latest_pair7': 0.6533083685328415, 'session_latest_pair8': 0.48654123920874864, 'session_latest_pair9': 0.7218578019238531, 'session_latest_time_wt_pair0': 0.3950630158558861, 'session_latest_time_wt_pair1': 0.8421725818769644, 'session_latest_time_wt_pair2': 0.3626369606991011, 'session_latest_time_wt_pair3': 0.5068916327656204, 'session_latest_time_wt_pair4': 0.8191336145528162, 'session_latest_time_wt_pair5': 0.801841493144005, 'session_latest_time_wt_pair6': 0.7618141629510994, 'session_latest_time_wt_pair7': 0.13184895941383154, 'session_latest_time_wt_pair8': 0.6113605318469831, 'session_latest_time_wt_pair9': 0.9586330626703079, 'session_latest_time_wt_pair': 0.10419983291726237, 'session_latest_type_wt_pair': 0.9646108429680664, 'session_latest_clicks2carts_pair': 0.5972884949471975, 'session_latest_clicks2orders_pair': 0.5195442151327543}. Best is trial 91 with value: 0.586.
# [I 2022-12-07 02:10:15,332] Trial 94 finished with value: 0.562 and parameters: {'session_frequent': 0.06632112332066864, 'session_latest': 0.09349422589692007, 'session_frequent_pair': 0.4552105696090922, 'session_latest_pair0': 0.3539475300707972, 'session_latest_pair1': 0.2835055575984748, 'session_latest_pair2': 0.5216947355947436, 'session_latest_pair3': 0.6250566545776519, 'session_latest_pair4': 0.869794875368105, 'session_latest_pair5': 0.6455353135064502, 'session_latest_pair6': 0.9149104757865676, 'session_latest_pair7': 0.6588545529227904, 'session_latest_pair8': 0.5136187497627287, 'session_latest_pair9': 0.8191293347161119, 'session_latest_time_wt_pair0': 0.3941841570812062, 'session_latest_time_wt_pair1': 0.8444127256819216, 'session_latest_time_wt_pair2': 0.3508408591730156, 'session_latest_time_wt_pair3': 0.4224303209750433, 'session_latest_time_wt_pair4': 0.8150257227570081, 'session_latest_time_wt_pair5': 0.7883807521223634, 'session_latest_time_wt_pair6': 0.7813682797453374, 'session_latest_time_wt_pair7': 0.07326747845837969, 'session_latest_time_wt_pair8': 0.6185643829783486, 'session_latest_time_wt_pair9': 0.9716545693355129, 'session_latest_time_wt_pair': 0.0890884654070248, 'session_latest_type_wt_pair': 0.9655284929905963, 'session_latest_clicks2carts_pair': 0.5625518260691424, 'session_latest_clicks2orders_pair': 0.5265969308071826}. Best is trial 91 with value: 0.586.
# [I 2022-12-07 02:10:20,856] Trial 95 finished with value: 0.58 and parameters: {'session_frequent': 0.01576427819230761, 'session_latest': 0.03545424212031571, 'session_frequent_pair': 0.38275645964356486, 'session_latest_pair0': 0.2952482933496732, 'session_latest_pair1': 0.3254960856980676, 'session_latest_pair2': 0.5784185495726925, 'session_latest_pair3': 0.6712282845851681, 'session_latest_pair4': 0.8000993024164227, 'session_latest_pair5': 0.6571279653080583, 'session_latest_pair6': 0.9579970275713757, 'session_latest_pair7': 0.5284241593116319, 'session_latest_pair8': 0.5676847490820596, 'session_latest_pair9': 0.70811153328454, 'session_latest_time_wt_pair0': 0.3278783421293678, 'session_latest_time_wt_pair1': 0.8347652880359464, 'session_latest_time_wt_pair2': 0.38033239822335396, 'session_latest_time_wt_pair3': 0.5051264618831022, 'session_latest_time_wt_pair4': 0.8104045600846941, 'session_latest_time_wt_pair5': 0.8382206569697513, 'session_latest_time_wt_pair6': 0.7430972737278667, 'session_latest_time_wt_pair7': 0.049843783883706944, 'session_latest_time_wt_pair8': 0.6671507481235592, 'session_latest_time_wt_pair9': 0.997590029998863, 'session_latest_time_wt_pair': 0.12245773364458452, 'session_latest_type_wt_pair': 0.9591345241500395, 'session_latest_clicks2carts_pair': 0.6091739713230765, 'session_latest_clicks2orders_pair': 0.564186255363182}. Best is trial 91 with value: 0.586.
# [I 2022-12-07 02:10:26,162] Trial 96 finished with value: 0.586 and parameters: {'session_frequent': 0.00034573825052284135, 'session_latest': 0.02984283760398066, 'session_frequent_pair': 0.3730830769264466, 'session_latest_pair0': 0.28440317126962267, 'session_latest_pair1': 0.3336864081677452, 'session_latest_pair2': 0.5809296176226287, 'session_latest_pair3': 0.6525992204374267, 'session_latest_pair4': 0.8927547978767371, 'session_latest_pair5': 0.5983835417854035, 'session_latest_pair6': 0.9550874538366696, 'session_latest_pair7': 0.5335677775844856, 'session_latest_pair8': 0.5794586384167594, 'session_latest_pair9': 0.705332422781004, 'session_latest_time_wt_pair0': 0.32673485204714003, 'session_latest_time_wt_pair1': 0.8339872993776933, 'session_latest_time_wt_pair2': 0.3860639931628087, 'session_latest_time_wt_pair3': 0.5232883899249153, 'session_latest_time_wt_pair4': 0.8478755816967818, 'session_latest_time_wt_pair5': 0.8667447401517608, 'session_latest_time_wt_pair6': 0.7591071330027545, 'session_latest_time_wt_pair7': 0.12396998231065534, 'session_latest_time_wt_pair8': 0.6485886804729439, 'session_latest_time_wt_pair9': 0.9506918086754101, 'session_latest_time_wt_pair': 0.1075501063643684, 'session_latest_type_wt_pair': 0.9612247526382091, 'session_latest_clicks2carts_pair': 0.6059558677504759, 'session_latest_clicks2orders_pair': 0.557864641154004}. Best is trial 91 with value: 0.586.
# [I 2022-12-07 02:10:31,660] Trial 97 finished with value: 0.583 and parameters: {'session_frequent': 0.00022128255254779056, 'session_latest': 0.04298406929785009, 'session_frequent_pair': 0.38227212822008966, 'session_latest_pair0': 0.2866398319381218, 'session_latest_pair1': 0.32359521674971364, 'session_latest_pair2': 0.43662759341449053, 'session_latest_pair3': 0.6494251381325, 'session_latest_pair4': 0.5804858865948368, 'session_latest_pair5': 0.5688903810172622, 'session_latest_pair6': 0.9560447427291199, 'session_latest_pair7': 0.5315679555110085, 'session_latest_pair8': 0.6112366923214423, 'session_latest_pair9': 0.7155207533874347, 'session_latest_time_wt_pair0': 0.332446815572096, 'session_latest_time_wt_pair1': 0.8259780352990582, 'session_latest_time_wt_pair2': 0.3684563485128623, 'session_latest_time_wt_pair3': 0.5159689192637281, 'session_latest_time_wt_pair4': 0.8063496418821455, 'session_latest_time_wt_pair5': 0.8502407025327628, 'session_latest_time_wt_pair6': 0.7488785329610494, 'session_latest_time_wt_pair7': 0.07943454410202595, 'session_latest_time_wt_pair8': 0.6679780210180868, 'session_latest_time_wt_pair9': 0.9499690590118927, 'session_latest_time_wt_pair': 0.18260797282979185, 'session_latest_type_wt_pair': 0.9574238413272775, 'session_latest_clicks2carts_pair': 0.6102712100905932, 'session_latest_clicks2orders_pair': 0.5587911255823641}. Best is trial 91 with value: 0.586.
# [I 2022-12-07 02:10:37,188] Trial 98 finished with value: 0.587 and parameters: {'session_frequent': 0.015497057391457725, 'session_latest': 0.03858053711017642, 'session_frequent_pair': 0.3778171033984854, 'session_latest_pair0': 0.2769805165601608, 'session_latest_pair1': 0.33986224239988694, 'session_latest_pair2': 0.4013306564668577, 'session_latest_pair3': 0.6625096152337718, 'session_latest_pair4': 0.5821941842871228, 'session_latest_pair5': 0.5857567687855021, 'session_latest_pair6': 0.9484094975986572, 'session_latest_pair7': 0.5329686867786199, 'session_latest_pair8': 0.5733119078938566, 'session_latest_pair9': 0.7109778315639825, 'session_latest_time_wt_pair0': 0.3254240444084473, 'session_latest_time_wt_pair1': 0.794572246000052, 'session_latest_time_wt_pair2': 0.36981411305329415, 'session_latest_time_wt_pair3': 0.5104854324450393, 'session_latest_time_wt_pair4': 0.8057197563391172, 'session_latest_time_wt_pair5': 0.8548745187055846, 'session_latest_time_wt_pair6': 0.7508747042136189, 'session_latest_time_wt_pair7': 0.1364497851154466, 'session_latest_time_wt_pair8': 0.6658660444210673, 'session_latest_time_wt_pair9': 0.9486082221037875, 'session_latest_time_wt_pair': 0.12445969577841691, 'session_latest_type_wt_pair': 0.9995815270537161, 'session_latest_clicks2carts_pair': 0.6086840883967894, 'session_latest_clicks2orders_pair': 0.5111350318131114}. Best is trial 98 with value: 0.587.
# [I 2022-12-07 02:10:42,507] Trial 99 finished with value: 0.586 and parameters: {'session_frequent': 0.004033697109083195, 'session_latest': 0.05036951459316649, 'session_frequent_pair': 0.37825439002763084, 'session_latest_pair0': 0.30253950247651373, 'session_latest_pair1': 0.3365806586510129, 'session_latest_pair2': 0.39282879198508214, 'session_latest_pair3': 0.6577281081931721, 'session_latest_pair4': 0.55739705417999, 'session_latest_pair5': 0.5985823726015659, 'session_latest_pair6': 0.9498420172807678, 'session_latest_pair7': 0.537231684645884, 'session_latest_pair8': 0.601452409916029, 'session_latest_pair9': 0.7120477929464131, 'session_latest_time_wt_pair0': 0.3241854314279412, 'session_latest_time_wt_pair1': 0.7936741978342257, 'session_latest_time_wt_pair2': 0.37236383547112023, 'session_latest_time_wt_pair3': 0.5097303186313477, 'session_latest_time_wt_pair4': 0.8133827462481957, 'session_latest_time_wt_pair5': 0.8493705991949076, 'session_latest_time_wt_pair6': 0.7442650936013527, 'session_latest_time_wt_pair7': 0.13526180991344647, 'session_latest_time_wt_pair8': 0.7543619295388971, 'session_latest_time_wt_pair9': 0.945378166103469, 'session_latest_time_wt_pair': 0.12801873868397468, 'session_latest_type_wt_pair': 0.962625564824313, 'session_latest_clicks2carts_pair': 0.5842264764089017, 'session_latest_clicks2orders_pair': 0.4598253588882302}. Best is trial 98 with value: 0.587.
# 0:29:21.552983 	 orders_recall_best_weights : {'session_frequent': 0.015497057391457725, 'session_latest': 0.03858053711017642, 'session_frequent_pair': 0.3778171033984854, 'session_latest_pair0': 0.2769805165601608, 'session_latest_pair1': 0.33986224239988694, 'session_latest_pair2': 0.4013306564668577, 'session_latest_pair3': 0.6625096152337718, 'session_latest_pair4': 0.5821941842871228, 'session_latest_pair5': 0.5857567687855021, 'session_latest_pair6': 0.9484094975986572, 'session_latest_pair7': 0.5329686867786199, 'session_latest_pair8': 0.5733119078938566, 'session_latest_pair9': 0.7109778315639825, 'session_latest_time_wt_pair0': 0.3254240444084473, 'session_latest_time_wt_pair1': 0.794572246000052, 'session_latest_time_wt_pair2': 0.36981411305329415, 'session_latest_time_wt_pair3': 0.5104854324450393, 'session_latest_time_wt_pair4': 0.8057197563391172, 'session_latest_time_wt_pair5': 0.8548745187055846, 'session_latest_time_wt_pair6': 0.7508747042136189, 'session_latest_time_wt_pair7': 0.1364497851154466, 'session_latest_time_wt_pair8': 0.6658660444210673, 'session_latest_time_wt_pair9': 0.9486082221037875, 'session_latest_time_wt_pair': 0.12445969577841691, 'session_latest_type_wt_pair': 0.9995815270537161, 'session_latest_clicks2carts_pair': 0.6086840883967894, 'session_latest_clicks2orders_pair': 0.5111350318131114}
# 0:29:21.554369 	 orders_recall_best_value : 0.587
# 0:29:21.555423 	 SCORE : 0.5131999999999999

# %% [markdown]
# # sub作成

# %%
test = make_test_data(trans_maps)
sub = pd.read_csv(cfg.input_dir + f"sample_submission.csv", usecols=["session_type"])
dfs = []

for type_ in ["clicks", "carts", "orders"]:
    test_type = test.copy()
    test_type["rank"] 
    test_type["rank"] = test_type["rank"] * test_type["strategy"].map(wt[type_])
    test_type = test_type.sort_values(["session", "rank"])
    test_type = test_type.drop_duplicates(subset= ["session", "aid"], keep="first")
    test_type = test_type.groupby(["session"]).head(20)
    test_type["aid"] = test_type["aid"].astype(str)
    test_type = test_type.groupby("session")["aid"].apply(list).reset_index()
    test_type["aid"] = test_type["aid"].apply(lambda x: ' '.join(x))
    test_type["session_type"] = test_type["session"].astype(str) + f"_{type_}"
    test_type =test_type.rename(columns={"aid": "labels"})
    dfs.append(test_type)
test_preds = pd.concat(dfs)

sub = sub.merge(test_preds, on="session_type", how="left")
sub[["session_type", "labels"]].to_csv(cfg.output_dir + f"{cfg.exp_name}/{cfg.exp_name}_sub.csv", index=False)
# Out:
# 0:29:22.762408 	 [make_test] make_cand_df
# 0:29:23.139073 	 [make_candidate] session_frequent : start
# 0:29:23.668382 	 [add_candidate] session_frequent : start
# 0:29:24.022727 	 [make_candidate] session_latest : start
# 0:29:24.339656 	 [add_candidate] session_latest : start
# 0:29:24.746067 	 [make_candidate] session_frequent_pair : start
# 0:29:25.273066 	 [add_candidate] session_frequent_pair : start
# 0:29:25.741896 	 [make_candidate] session_latest_pair0 : start
# 0:29:26.291206 	 [add_candidate] session_latest_pair0 : start
# 0:29:26.792678 	 [make_candidate] session_latest_pair1 : start
# 0:29:27.356534 	 [add_candidate] session_latest_pair1 : start
# 0:29:27.911163 	 [make_candidate] session_latest_pair2 : start
# 0:29:28.484378 	 [add_candidate] session_latest_pair2 : start
# 0:29:29.039453 	 [make_candidate] session_latest_pair3 : start
# 0:29:29.605923 	 [add_candidate] session_latest_pair3 : start
# 0:29:30.265695 	 [make_candidate] session_latest_pair4 : start
# 0:29:30.850944 	 [add_candidate] session_latest_pair4 : start
# 0:29:31.544252 	 [make_candidate] session_latest_pair5 : start
# 0:29:32.124425 	 [add_candidate] session_latest_pair5 : start
# 0:29:32.810544 	 [make_candidate] session_latest_pair6 : start
# 0:29:33.417613 	 [add_candidate] session_latest_pair6 : start
# 0:29:34.168299 	 [make_candidate] session_latest_pair7 : start
# 0:29:34.752473 	 [add_candidate] session_latest_pair7 : start
# 0:29:35.584307 	 [make_candidate] session_latest_pair8 : start
# 0:29:36.175007 	 [add_candidate] session_latest_pair8 : start
# 0:29:37.035900 	 [make_candidate] session_latest_pair9 : start
# 0:29:37.651228 	 [add_candidate] session_latest_pair9 : start
# 0:29:38.754577 	 [make_candidate] session_latest_time_wt_pair0 : start
# 0:29:39.249120 	 [add_candidate] session_latest_time_wt_pair0 : start
# 0:29:40.507902 	 [make_candidate] session_latest_time_wt_pair1 : start
# 0:29:40.999788 	 [add_candidate] session_latest_time_wt_pair1 : start
# 0:29:42.314052 	 [make_candidate] session_latest_time_wt_pair2 : start
# 0:29:42.802441 	 [add_candidate] session_latest_time_wt_pair2 : start
# 0:29:43.975925 	 [make_candidate] session_latest_time_wt_pair3 : start
# 0:29:44.668860 	 [add_candidate] session_latest_time_wt_pair3 : start
# 0:29:46.014063 	 [make_candidate] session_latest_time_wt_pair4 : start
# 0:29:46.595425 	 [add_candidate] session_latest_time_wt_pair4 : start
# 0:29:48.011608 	 [make_candidate] session_latest_time_wt_pair5 : start
# 0:29:48.545833 	 [add_candidate] session_latest_time_wt_pair5 : start
# 0:29:49.851249 	 [make_candidate] session_latest_time_wt_pair6 : start
# 0:29:50.672655 	 [add_candidate] session_latest_time_wt_pair6 : start
# 0:29:52.115746 	 [make_candidate] session_latest_time_wt_pair7 : start
# 0:29:53.013490 	 [add_candidate] session_latest_time_wt_pair7 : start
# 0:29:54.525373 	 [make_candidate] session_latest_time_wt_pair8 : start
# 0:29:55.339366 	 [add_candidate] session_latest_time_wt_pair8 : start
# 0:29:56.826950 	 [make_candidate] session_latest_time_wt_pair9 : start
# 0:29:57.777636 	 [add_candidate] session_latest_time_wt_pair9 : start
# 0:29:59.596557 	 [make_candidate] session_latest_type_wt_pair : start
# 0:30:00.426886 	 [add_candidate] session_latest_type_wt_pair : start
# 0:30:01.983443 	 [make_candidate] session_latest_clicks2carts_pair : start
# 0:30:02.888168 	 [add_candidate] session_latest_clicks2carts_pair : start
# 0:30:04.492304 	 [make_candidate] session_latest_clicks2orders_pair : start
# 0:30:05.380228 	 [add_candidate] session_latest_clicks2orders_pair : start

# %%
sub.head()
# Out:
#       session_type   session  \
# 0  12899779_clicks  12899779
# 1   12899779_carts  12899779
# 2  12899779_orders  12899779
# 3  12899780_clicks  12899780
# 4   12899780_carts  12899780
#
#                                               labels
# 0  59625 448688 941596 731692 1253524 1854910 438...
# 1  59625 1130911 1854910 894169 1790770 737445 43...
# 2  59625 941596 1854910 737445 523135 731692 8941...
# 3  1142000 1360606 1383529 889686 736515 409620 4...
# 4  1142000 582732 736515 973453 1502122 636101 17...
